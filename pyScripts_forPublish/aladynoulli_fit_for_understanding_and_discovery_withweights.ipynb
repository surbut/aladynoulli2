# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess
from clust_huge_amp import *
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning, module="sklearn.utils.extmath")

# %% [markdown]
# ## Aladynoulli retrospective
#
# Here we show the ability of the model to estatime when having access to all data for signature and genomic discovery, heterogeneity characterization, and cohort similarity.

# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_98755/2084552305.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_98755/2084552305.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_98755/2084552305.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_98755/2084552305.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
# Test reading the file
import pandas as pd
df = pd.read_csv('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/UKBWeights-main/UKBSelectionWeights.csv', sep='\s+', engine='python')
print(df.head())
print(df.columns)
print(df.shape)
# Out:
#        f.eid  LassoWeight
# 0  1482136.0     0.400256
# 1  4261840.0     0.746818
# 2  1021212.0     0.526333
# 3  3857942.0     0.411219
# 4  3868072.0     0.517283
# Index(['f.eid', 'LassoWeight'], dtype='object')
# (469553, 2)

# %%
pids=pd.read_csv('/Users/sarahurbut/aladynoulli2/pyScripts/processed_ids.csv')['eid'].values

# %%
def match_weights_to_ids(weights_df, processed_ids):
    """
    Match weights to processed IDs
    
    Parameters:
    -----------
    weights_df : pd.DataFrame
        DataFrame with columns ['f.eid', 'LassoWeight']
    processed_ids : numpy array
        Array of IDs corresponding to rows in Y [N]
        
    Returns:
    --------
    matched_weights : numpy array
        Weights matched to processed_ids order [N]
    match_mask : numpy array (bool)
        Boolean mask indicating which IDs were found [N]
    """
    print("Matching weights to IDs...")
    print(f"  Weights available: {len(weights_df)}")
    print(f"  Processed IDs: {len(processed_ids)}")
    
    # Create a mapping from f.eid to LassoWeight
    weight_dict = dict(zip(weights_df['f.eid'].values, weights_df['LassoWeight'].values))
    
    # Match weights to processed_ids
    matched_weights = np.zeros(len(processed_ids))
    match_mask = np.zeros(len(processed_ids), dtype=bool)
    
    for i, pid in enumerate(processed_ids):
        if pid in weight_dict:
            matched_weights[i] = weight_dict[pid]
            match_mask[i] = True
    
    n_matched = match_mask.sum()
    print(f"  Matched: {n_matched} ({100*n_matched/len(processed_ids):.1f}%)")
    print(f"  Unmatched: {len(processed_ids) - n_matched}")
    
    if n_matched == 0:
        raise ValueError("No IDs matched! Check that f.eid values match processed_ids")
    
    return matched_weights, match_mask

# %%
weights_df=df
import numpy as np
matched_weights, match_mask = match_weights_to_ids(weights_df, pids[:400000])
    
print(f"\nMatched weight statistics (for matched individuals):")
matched_weight_values = matched_weights[match_mask]
print(f"  Mean: {matched_weight_values.mean():.3f}")
print(f"  Std: {matched_weight_values.std():.3f}")
print(f"  Range: [{matched_weight_values.min():.3f}, {matched_weight_values.max():.3f}]")

print(f"\nMatched weight statistics (for matched individuals):")
matched_weight_values = matched_weights[match_mask]
print(f"  Mean: {matched_weight_values.mean():.3f}")
print(f"  Std: {matched_weight_values.std():.3f}")
print(f"  Range: [{matched_weight_values.min():.3f}, {matched_weight_values.max():.3f}]")
# Out:
# Matching weights to IDs...
#   Weights available: 469553
#   Processed IDs: 400000
#   Matched: 376505 (94.1%)
#   Unmatched: 23495
#
# Matched weight statistics (for matched individuals):
#   Mean: 0.906
#   Std: 1.006
#   Range: [0.169, 6.631]
#
# Matched weight statistics (for matched individuals):
#   Mean: 0.906
#   Std: 1.006
#   Range: [0.169, 6.631]

# %%
## match y, e, g, etc to weight, and then run the model for fit and retprospectivion for the first 10k or something

# %%
from clust_huge_amp import *
# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, start_index=0, end_index=10000)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data

del Y

# %%
# Load references (signatures only, no healthy)
refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/reference_trajectories.pt')
signature_refs = refs['signature_refs']
# When initializing the model:
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_44384/2694258374.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/reference_trajectories.pt')

# %%
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the RDS file
readRDS = robjects.r['readRDS']
pce_data = readRDS('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_df_prevent.rds')
pce_df = pandas2ri.rpy2py(pce_data)  # Convert to pandas DataFrame

# %%
readRDS = robjects.r['readRDS']
pce_data = readRDS('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_df_prevent.rds')
pce_df = pandas2ri.rpy2py(pce_data)  # Convert to pandas DataFrame
sex=pce_df['Sex'].values

# Convert to numeric: Female=0, Male=1

pce_df['sex_numeric'] = pce_df['Sex'].map({'Female': 0, 'Male': 1}).astype(int)

sex=pce_df['sex_numeric'].values
G_with_sex = np.column_stack([G_100k, sex])  # sex should be numeric (e.g., 0/1)
# N

# %%
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_with_sex.shape[1],
    init_sd_scaler=1e-1,
    G=G_with_sex, 
    Y=Y_100k,
    genetic_scale=1,
    W=0.0001,
    R=0,
    prevalence_t=essentials['prevalence_t'],
    signature_references=signature_refs,  # Only pass signature refs
    healthy_reference=True,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

torch.manual_seed(0)
np.random.seed(0)
# Initialize with psi and clusters


import cProfile
import pstats
from pstats import SortKey

# Now in your batch run, load and verify:
initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')

model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0008,  0.0071,  0.0117,  0.0152, -0.0106])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0219,  0.0117,  0.0025, -0.0018, -0.0047])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0018, -0.0023,  0.0065,  0.0024, -0.0054])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0020, -0.0039,  0.0022,  0.0021, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0060, -0.0015, -0.0132,  0.0367, -0.0098])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0048,  0.0060, -0.0042,  0.0057,  0.0247])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0017,  0.0011, -0.0008, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0073,  0.0049, -0.0054,  0.0056, -0.0040])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0013,  0.0009,  0.0006,  0.0133, -0.0011])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([ 9.8607e-06,  9.0586e-03,  1.5898e-02, -3.2695e-03,  5.4494e-04])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0122, -0.0048,  0.0013, -0.0042,  0.0020])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0062,  0.0047, -0.0075,  0.0032,  0.0006])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0072,  0.0011, -0.0018,  0.0015,  0.0025])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 7.6968e-03,  1.0931e-02,  8.1495e-05,  7.9375e-03, -1.5938e-03])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0121, -0.0034, -0.0035,  0.0132,  0.0054])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0023, 0.0029, 0.0010, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([ 0.0023,  0.0108,  0.0118, -0.0026,  0.0093])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0068,  0.0176,  0.0005, -0.0053, -0.0091])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0158, -0.0017,  0.0114,  0.0180, -0.0033])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0006, -0.0010,  0.0008,  0.0037,  0.0014])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_44384/612023066.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_44384/612023066.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.9623, -13.8155])
# Base value centered (first 5): tensor([-0.1879, -0.1879, -0.1879,  1.6653, -0.1879])
# Base value centered mean: -3.345489574257954e-07
# Gamma init for k=0 (first 5): tensor([ 0.0069,  0.0066, -0.0055,  0.0062,  0.0243])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.3449, -13.3449, -12.4036])
# Base value centered (first 5): tensor([ 0.1505, -0.3201,  0.1505,  0.1505,  1.0918])
# Base value centered mean: -1.8495559288567165e-06
# Gamma init for k=1 (first 5): tensor([0.0044, 0.0012, 0.0007, 0.0026, 0.0014])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1566, -11.8388, -12.4977])
# Base value centered (first 5): tensor([-0.3849, -0.3849,  0.2740,  1.5918,  0.9329])
# Base value centered mean: 9.290695288655115e-07
# Gamma init for k=2 (first 5): tensor([-0.0001,  0.0092,  0.0113,  0.0160, -0.0109])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.6950, -13.5744])
# Base value centered (first 5): tensor([-0.1026, -0.1026, -0.1026,  0.0179,  0.1384])
# Base value centered mean: 4.7445297468584613e-07
# Gamma init for k=3 (first 5): tensor([ 0.0011,  0.0003,  0.0017,  0.0019, -0.0006])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155,  -9.8620, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1133,  3.8402, -0.1133, -0.1133, -0.1133])
# Base value centered mean: -2.841758714566822e-06
# Gamma init for k=4 (first 5): tensor([-0.0169, -0.0023,  0.0140,  0.0213, -0.0032])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=5 (first 5): tensor([ 0.0219,  0.0117,  0.0025, -0.0018, -0.0047])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1523, -0.1523, -0.1523, -0.1523, -0.1523])
# Base value centered mean: -1.0890006478803116e-06
# Gamma init for k=6 (first 5): tensor([ 0.0075,  0.0130,  0.0004,  0.0055, -0.0025])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.3663, -13.8155, -13.3663, -13.8155, -11.1200])
# Base value centered (first 5): tensor([-0.1005, -0.5497, -0.1005, -0.5497,  2.1458])
# Base value centered mean: 1.2460708376238472e-06
# Gamma init for k=7 (first 5): tensor([ 0.0027, -0.0039, -0.0122,  0.0250, -0.0020])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1159, -0.1159, -0.1159, -0.1159, -0.1159])
# Base value centered mean: -1.4129639112070436e-06
# Gamma init for k=8 (first 5): tensor([ 0.0066, -0.0056,  0.0009, -0.0016, -0.0004])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=9 (first 5): tensor([ 0.0062,  0.0047, -0.0075,  0.0032,  0.0006])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=10 (first 5): tensor([-0.0068,  0.0176,  0.0005, -0.0053, -0.0091])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=11 (first 5): tensor([0.0026, 0.0023, 0.0029, 0.0010, 0.0098])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0860, -0.0860, -0.0860, -0.0860, -0.0860])
# Base value centered mean: -1.034450519910024e-06
# Gamma init for k=12 (first 5): tensor([ 8.2098e-03, -7.1588e-03,  4.5737e-06, -3.0368e-04, -7.6238e-03])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.7744, -12.2949])
# Base value centered (first 5): tensor([-0.1777, -0.1777, -0.1777,  2.8635,  1.3429])
# Base value centered mean: -1.0064125035569305e-06
# Gamma init for k=13 (first 5): tensor([ 0.0003,  0.0065,  0.0122, -0.0056,  0.0007])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.8388, -12.8271])
# Base value centered (first 5): tensor([-0.2562, -0.2562, -0.2562,  1.7205,  0.7322])
# Base value centered mean: -1.5125274330785032e-06
# Gamma init for k=14 (first 5): tensor([ 0.0021, -0.0037, -0.0087,  0.0178,  0.0010])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.8388])
# Base value centered (first 5): tensor([-0.2850, -0.2850, -0.2850, -0.2850,  1.6917])
# Base value centered mean: -1.2931823221151717e-06
# Gamma init for k=15 (first 5): tensor([ 0.0013,  0.0041,  0.0077, -0.0082,  0.0078])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.7706, -13.1339])
# Base value centered (first 5): tensor([-0.2428, -0.2428, -0.2428,  1.8021,  0.4388])
# Base value centered mean: -1.9989013253507437e-06
# Gamma init for k=16 (first 5): tensor([ 0.0014,  0.0004,  0.0086,  0.0059, -0.0034])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.3272, -12.0713])
# Base value centered (first 5): tensor([-0.4228, -0.4228, -0.4228,  3.0656,  1.3214])
# Base value centered mean: -2.227592403869494e-06
# Gamma init for k=17 (first 5): tensor([ 0.0078,  0.0057, -0.0059,  0.0059, -0.0039])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=18 (first 5): tensor([-0.0121, -0.0034, -0.0035,  0.0132,  0.0054])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([-0.1519, -0.1519, -0.1519, -0.1519,  0.2779])
# Base value centered mean: -1.1179923831150518e-06
# Gamma init for k=19 (first 5): tensor([-0.0027,  0.0051,  0.0015, -0.0011, -0.0017])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Clusters match exactly: True

# %% [markdown]
# # you can see that we use the full unmodified E matrix here

# %%
## now we will run the model with the full data and sex specific
import cProfile
import pstats
from pstats import SortKey
# 5. Train on FULL data
profiler = cProfile.Profile()
profiler.enable()

history_new = model.fit(E_100k, num_epochs=200, learning_rate=1e-1, lambda_reg=1e-2)
profiler.disable()
stats = pstats.Stats(profiler).sort_stats(SortKey.CUMULATIVE)
stats.print_stats(20)
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:238: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 65.7505
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.38):
#   Theta for diagnosed: 0.150 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.81):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.097 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.51):
#   Theta for diagnosed: 0.149 ± 0.070
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.94):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 1
# Loss: 707.3983
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.57):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.82):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 2
# Loss: 117.7784
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.72):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.81):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 3
# Loss: 211.5558
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.85):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.81):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 4
# Loss: 422.7003
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.96):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.81):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 5
# Loss: 331.1166
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.04):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.81):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.47):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 6
# Loss: 148.9460
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.09):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.81):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.52):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.01):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 7
# Loss: 81.4004
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.10):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.80):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.56):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.24):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 8
# Loss: 150.6737
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.07):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.58):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.46):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 9
# Loss: 229.8457
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.01):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 114 (signature 5, LR=29.68):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 347 (signature 3, LR=29.59):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.000
#
# Epoch 10
# Loss: 219.7454
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.91):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.74):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.51):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 114 (signature 5, LR=29.91):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 347 (signature 3, LR=29.58):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.000
#
# Epoch 11
# Loss: 144.4014
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.77):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.72):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 114 (signature 5, LR=30.13):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 188 (signature 2, LR=29.67):
#   Theta for diagnosed: 0.068 ± 0.014
#   Theta for others: 0.067
#   Proportion difference: 0.000
#
# Epoch 12
# Loss: 82.4039
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.61):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.69):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 114 (signature 5, LR=30.35):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 188 (signature 2, LR=29.85):
#   Theta for diagnosed: 0.068 ± 0.014
#   Theta for others: 0.067
#   Proportion difference: 0.000
#
# Epoch 13
# Loss: 80.8313
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.43):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.66):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=30.56):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 260 (signature 8, LR=30.53):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 188 (signature 2, LR=30.03):
#   Theta for diagnosed: 0.068 ± 0.014
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 14
# Loss: 121.8425
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.22):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 114 (signature 5, LR=30.77):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 76 (signature 7, LR=30.62):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.53):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 188 (signature 2, LR=30.20):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 15
# Loss: 151.6299
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.00):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=30.97):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 76 (signature 7, LR=30.58):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.53):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 188 (signature 2, LR=30.36):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 16
# Loss: 139.4889
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.77):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.16):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 260 (signature 8, LR=30.53):
#   Theta for diagnosed: 0.097 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.53):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.006
#
# Disease 188 (signature 2, LR=30.52):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 17
# Loss: 101.1480
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.52):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.35):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=30.67):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 260 (signature 8, LR=30.53):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.48):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.006
#
# Epoch 18
# Loss: 72.7888
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=31.53):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 161 (signature 7, LR=31.26):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=30.81):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.42):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.006
#
# Epoch 19
# Loss: 74.5209
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=31.70):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 161 (signature 7, LR=31.00):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=30.94):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 336 (signature 9, LR=30.45):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 20
# Loss: 95.4173
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=31.87):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=31.07):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.73):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=30.59):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Epoch 21
# Loss: 109.0242
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.03):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=31.19):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=30.74):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.55):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 22
# Loss: 101.3058
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.18):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=31.29):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=30.88):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.64):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 23
# Loss: 81.3593
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.32):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=31.39):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=31.03):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.72):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 24
# Loss: 68.1254
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.45):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=31.48):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=31.17):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.77):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 25
# Loss: 70.8492
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.56):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=31.56):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=31.32):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.82):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 26
# Loss: 81.9897
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.67):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=31.63):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=31.46):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.84):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.51):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 27
# Loss: 87.3328
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.76):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 188 (signature 2, LR=31.68):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=31.59):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.86):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.51):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 28
# Loss: 81.1507
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.85):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 336 (signature 9, LR=31.73):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.72):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=30.85):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 29
# Loss: 70.2901
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.92):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 336 (signature 9, LR=31.86):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.75):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=30.84):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 30
# Loss: 65.1091
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=32.98):
#   Theta for diagnosed: 0.064 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 336 (signature 9, LR=32.00):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.77):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=30.81):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 31
# Loss: 68.5752
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=33.03):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 336 (signature 9, LR=32.13):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.79):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=30.78):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Epoch 32
# Loss: 74.4788
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=33.07):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 336 (signature 9, LR=32.26):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.79):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=30.73):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=30.60):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Epoch 33
# Loss: 75.3089
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=33.10):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 336 (signature 9, LR=32.39):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.79):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=30.76):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 33 (signature 17, LR=30.67):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Epoch 34
# Loss: 70.2426
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=33.13):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 336 (signature 9, LR=32.53):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.78):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=30.91):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 33 (signature 17, LR=30.61):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Epoch 35
# Loss: 64.8187
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=33.14):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 336 (signature 9, LR=32.66):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.75):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=31.07):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 33 (signature 17, LR=30.54):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Epoch 36
# Loss: 64.0333
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=33.14):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 336 (signature 9, LR=32.79):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.72):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=31.23):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 33 (signature 17, LR=30.46):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Epoch 37
# Loss: 67.1467
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=33.13):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 336 (signature 9, LR=32.92):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.68):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 21 (signature 13, LR=31.39):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.012
#
# Epoch 38
# Loss: 69.4274
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=33.11):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 336 (signature 9, LR=33.05):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=31.64):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 21 (signature 13, LR=31.56):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 260 (signature 8, LR=30.42):
#   Theta for diagnosed: 0.100 ± 0.083
#   Theta for others: 0.087
#   Proportion difference: 0.012
#
# Epoch 39
# Loss: 67.9569
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.17):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 114 (signature 5, LR=33.09):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 21 (signature 13, LR=31.72):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=31.58):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.41):
#   Theta for diagnosed: 0.100 ± 0.083
#   Theta for others: 0.087
#   Proportion difference: 0.012
#
# Epoch 40
# Loss: 64.5036
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.30):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 114 (signature 5, LR=33.06):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 21 (signature 13, LR=31.88):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=31.53):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.40):
#   Theta for diagnosed: 0.100 ± 0.083
#   Theta for others: 0.087
#   Proportion difference: 0.012
#
# Epoch 41
# Loss: 62.7558
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.43):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 114 (signature 5, LR=33.02):
#   Theta for diagnosed: 0.064 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 21 (signature 13, LR=32.04):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=31.46):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.39):
#   Theta for diagnosed: 0.100 ± 0.083
#   Theta for others: 0.087
#   Proportion difference: 0.013
#
# Epoch 42
# Loss: 63.8873
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.55):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 114 (signature 5, LR=32.98):
#   Theta for diagnosed: 0.064 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 21 (signature 13, LR=32.21):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=31.39):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.38):
#   Theta for diagnosed: 0.100 ± 0.083
#   Theta for others: 0.087
#   Proportion difference: 0.013
#
# Epoch 43
# Loss: 65.6573
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.68):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=32.93):
#   Theta for diagnosed: 0.065 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 21 (signature 13, LR=32.38):
#   Theta for diagnosed: 0.027 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=31.32):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.37):
#   Theta for diagnosed: 0.100 ± 0.083
#   Theta for others: 0.087
#   Proportion difference: 0.013
#
# Epoch 44
# Loss: 65.5338
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.81):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=32.88):
#   Theta for diagnosed: 0.065 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 21 (signature 13, LR=32.55):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=31.25):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.36):
#   Theta for diagnosed: 0.100 ± 0.083
#   Theta for others: 0.087
#   Proportion difference: 0.013
#
# Epoch 45
# Loss: 63.6491
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.94):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=32.83):
#   Theta for diagnosed: 0.065 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 21 (signature 13, LR=32.72):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=31.17):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.35):
#   Theta for diagnosed: 0.101 ± 0.083
#   Theta for others: 0.087
#   Proportion difference: 0.013
#
# Epoch 46
# Loss: 62.1842
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.06):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=32.89):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.77):
#   Theta for diagnosed: 0.065 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 188 (signature 2, LR=31.09):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.34):
#   Theta for diagnosed: 0.101 ± 0.084
#   Theta for others: 0.087
#   Proportion difference: 0.013
#
# Epoch 47
# Loss: 62.4701
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.19):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=33.06):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.71):
#   Theta for diagnosed: 0.065 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 188 (signature 2, LR=31.01):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.32):
#   Theta for diagnosed: 0.101 ± 0.084
#   Theta for others: 0.087
#   Proportion difference: 0.013
#
# Epoch 48
# Loss: 63.5609
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.32):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=33.23):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.65):
#   Theta for diagnosed: 0.065 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 188 (signature 2, LR=30.93):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.31):
#   Theta for diagnosed: 0.101 ± 0.084
#   Theta for others: 0.087
#   Proportion difference: 0.013
#
# Epoch 49
# Loss: 63.7444
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.45):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=33.41):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.58):
#   Theta for diagnosed: 0.065 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 188 (signature 2, LR=30.85):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 85 (signature 10, LR=30.35):
#   Theta for diagnosed: 0.028 ± 0.027
#   Theta for others: 0.026
#   Proportion difference: 0.002
#
# Epoch 50
# Loss: 62.7273
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.57):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=33.58):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.52):
#   Theta for diagnosed: 0.065 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 188 (signature 2, LR=30.76):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 85 (signature 10, LR=30.44):
#   Theta for diagnosed: 0.028 ± 0.028
#   Theta for others: 0.026
#   Proportion difference: 0.002
#
# Epoch 51
# Loss: 61.7435
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.70):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=33.76):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.45):
#   Theta for diagnosed: 0.065 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 188 (signature 2, LR=30.68):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 85 (signature 10, LR=30.54):
#   Theta for diagnosed: 0.028 ± 0.028
#   Theta for others: 0.026
#   Proportion difference: 0.002
#
# Epoch 52
# Loss: 61.7837
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.83):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=33.94):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.38):
#   Theta for diagnosed: 0.065 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 85 (signature 10, LR=30.63):
#   Theta for diagnosed: 0.028 ± 0.028
#   Theta for others: 0.026
#   Proportion difference: 0.002
#
# Disease 188 (signature 2, LR=30.59):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Epoch 53
# Loss: 62.4166
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.96):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=34.12):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.32):
#   Theta for diagnosed: 0.066 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.019
#
# Disease 85 (signature 10, LR=30.73):
#   Theta for diagnosed: 0.028 ± 0.028
#   Theta for others: 0.026
#   Proportion difference: 0.002
#
# Disease 188 (signature 2, LR=30.51):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Epoch 54
# Loss: 62.5673
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.10):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=34.31):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.25):
#   Theta for diagnosed: 0.066 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=30.82):
#   Theta for diagnosed: 0.028 ± 0.028
#   Theta for others: 0.026
#   Proportion difference: 0.002
#
# Disease 15 (signature 19, LR=30.56):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 55
# Loss: 61.9727
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.23):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=34.49):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.19):
#   Theta for diagnosed: 0.066 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=30.92):
#   Theta for diagnosed: 0.028 ± 0.029
#   Theta for others: 0.026
#   Proportion difference: 0.002
#
# Disease 15 (signature 19, LR=30.68):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 56
# Loss: 61.3713
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.37):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=34.68):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.13):
#   Theta for diagnosed: 0.066 ± 0.046
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=31.01):
#   Theta for diagnosed: 0.028 ± 0.029
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=30.80):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 57
# Loss: 61.3890
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.50):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=34.87):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.07):
#   Theta for diagnosed: 0.066 ± 0.046
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=31.11):
#   Theta for diagnosed: 0.028 ± 0.029
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=30.92):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 58
# Loss: 61.7553
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.64):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=35.06):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.01):
#   Theta for diagnosed: 0.066 ± 0.046
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=31.21):
#   Theta for diagnosed: 0.028 ± 0.029
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=31.04):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 59
# Loss: 61.8073
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.77):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=35.26):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.95):
#   Theta for diagnosed: 0.066 ± 0.046
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=31.31):
#   Theta for diagnosed: 0.028 ± 0.029
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=31.17):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 60
# Loss: 61.4205
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.91):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=35.45):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.90):
#   Theta for diagnosed: 0.066 ± 0.046
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=31.41):
#   Theta for diagnosed: 0.028 ± 0.030
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=31.29):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 61
# Loss: 61.0775
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.05):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=35.65):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.85):
#   Theta for diagnosed: 0.066 ± 0.046
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=31.51):
#   Theta for diagnosed: 0.028 ± 0.030
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=31.41):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 62
# Loss: 61.1235
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.19):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=35.85):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.80):
#   Theta for diagnosed: 0.066 ± 0.047
#   Theta for others: 0.046
#   Proportion difference: 0.020
#
# Disease 85 (signature 10, LR=31.61):
#   Theta for diagnosed: 0.028 ± 0.030
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=31.54):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 63
# Loss: 61.3299
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.34):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=36.05):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.76):
#   Theta for diagnosed: 0.067 ± 0.047
#   Theta for others: 0.046
#   Proportion difference: 0.021
#
# Disease 85 (signature 10, LR=31.72):
#   Theta for diagnosed: 0.029 ± 0.030
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=31.67):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 64
# Loss: 61.3000
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.48):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=36.26):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 85 (signature 10, LR=31.82):
#   Theta for diagnosed: 0.029 ± 0.031
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=31.80):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=31.71):
#   Theta for diagnosed: 0.067 ± 0.047
#   Theta for others: 0.046
#   Proportion difference: 0.021
#
# Epoch 65
# Loss: 61.0340
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.63):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=36.46):
#   Theta for diagnosed: 0.027 ± 0.009
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 85 (signature 10, LR=31.93):
#   Theta for diagnosed: 0.029 ± 0.031
#   Theta for others: 0.026
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=31.92):
#   Theta for diagnosed: 0.047 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=31.68):
#   Theta for diagnosed: 0.067 ± 0.047
#   Theta for others: 0.046
#   Proportion difference: 0.021
#
# Epoch 66
# Loss: 60.8587
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.77):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 21 (signature 13, LR=36.67):
#   Theta for diagnosed: 0.027 ± 0.009
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# ...
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 249 (signature 13, LR=64.29):
#   Theta for diagnosed: 0.030 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=60.31):
#   Theta for diagnosed: 0.036 ± 0.030
#   Theta for others: 0.030
#   Proportion difference: 0.006
#
# Disease 127 (signature 0, LR=55.74):
#   Theta for diagnosed: 0.036 ± 0.041
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 182
# Loss: 57.9790
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=75.41):
#   Theta for diagnosed: 0.016 ± 0.008
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 21 (signature 13, LR=72.10):
#   Theta for diagnosed: 0.031 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 249 (signature 13, LR=64.70):
#   Theta for diagnosed: 0.030 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=60.56):
#   Theta for diagnosed: 0.036 ± 0.030
#   Theta for others: 0.030
#   Proportion difference: 0.006
#
# Disease 127 (signature 0, LR=56.09):
#   Theta for diagnosed: 0.036 ± 0.042
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 183
# Loss: 57.9555
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=75.95):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 21 (signature 13, LR=72.46):
#   Theta for diagnosed: 0.031 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=65.10):
#   Theta for diagnosed: 0.030 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=60.80):
#   Theta for diagnosed: 0.036 ± 0.030
#   Theta for others: 0.030
#   Proportion difference: 0.006
#
# Disease 127 (signature 0, LR=56.44):
#   Theta for diagnosed: 0.036 ± 0.042
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 184
# Loss: 57.9320
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=76.49):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 21 (signature 13, LR=72.81):
#   Theta for diagnosed: 0.032 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=65.51):
#   Theta for diagnosed: 0.031 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=61.05):
#   Theta for diagnosed: 0.036 ± 0.031
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=56.79):
#   Theta for diagnosed: 0.036 ± 0.042
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 185
# Loss: 57.9084
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=77.03):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 21 (signature 13, LR=73.17):
#   Theta for diagnosed: 0.032 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=65.92):
#   Theta for diagnosed: 0.031 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=61.30):
#   Theta for diagnosed: 0.037 ± 0.031
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=57.14):
#   Theta for diagnosed: 0.036 ± 0.043
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 186
# Loss: 57.8850
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=77.58):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=73.52):
#   Theta for diagnosed: 0.032 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=66.33):
#   Theta for diagnosed: 0.031 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=61.54):
#   Theta for diagnosed: 0.037 ± 0.031
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=57.49):
#   Theta for diagnosed: 0.036 ± 0.043
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 187
# Loss: 57.8616
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=78.13):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=73.88):
#   Theta for diagnosed: 0.032 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=66.73):
#   Theta for diagnosed: 0.031 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=61.79):
#   Theta for diagnosed: 0.037 ± 0.032
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=57.85):
#   Theta for diagnosed: 0.036 ± 0.043
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 188
# Loss: 57.8382
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=78.68):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=74.23):
#   Theta for diagnosed: 0.032 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=67.14):
#   Theta for diagnosed: 0.031 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=62.04):
#   Theta for diagnosed: 0.037 ± 0.032
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=58.20):
#   Theta for diagnosed: 0.036 ± 0.043
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 189
# Loss: 57.8148
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=79.24):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=74.59):
#   Theta for diagnosed: 0.032 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=67.55):
#   Theta for diagnosed: 0.031 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=62.29):
#   Theta for diagnosed: 0.037 ± 0.033
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=58.55):
#   Theta for diagnosed: 0.036 ± 0.044
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 190
# Loss: 57.7914
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=79.80):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=74.94):
#   Theta for diagnosed: 0.032 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=67.96):
#   Theta for diagnosed: 0.031 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=62.54):
#   Theta for diagnosed: 0.037 ± 0.033
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=58.91):
#   Theta for diagnosed: 0.037 ± 0.044
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 191
# Loss: 57.7681
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=80.36):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=75.30):
#   Theta for diagnosed: 0.032 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=68.37):
#   Theta for diagnosed: 0.031 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=62.79):
#   Theta for diagnosed: 0.037 ± 0.033
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=59.26):
#   Theta for diagnosed: 0.037 ± 0.044
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 192
# Loss: 57.7447
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=80.92):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=75.65):
#   Theta for diagnosed: 0.032 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=68.78):
#   Theta for diagnosed: 0.031 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=63.04):
#   Theta for diagnosed: 0.037 ± 0.034
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=59.62):
#   Theta for diagnosed: 0.037 ± 0.045
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 193
# Loss: 57.7214
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=81.48):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=76.01):
#   Theta for diagnosed: 0.032 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=69.19):
#   Theta for diagnosed: 0.031 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=63.29):
#   Theta for diagnosed: 0.037 ± 0.034
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=59.98):
#   Theta for diagnosed: 0.037 ± 0.045
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 194
# Loss: 57.6981
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=82.05):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=76.36):
#   Theta for diagnosed: 0.032 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=69.60):
#   Theta for diagnosed: 0.031 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=63.54):
#   Theta for diagnosed: 0.037 ± 0.035
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=60.33):
#   Theta for diagnosed: 0.037 ± 0.045
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 195
# Loss: 57.6750
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=82.62):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=76.72):
#   Theta for diagnosed: 0.032 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=70.00):
#   Theta for diagnosed: 0.031 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=63.79):
#   Theta for diagnosed: 0.037 ± 0.035
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 127 (signature 0, LR=60.69):
#   Theta for diagnosed: 0.037 ± 0.045
#   Theta for others: 0.027
#   Proportion difference: 0.010
#
# Epoch 196
# Loss: 57.6518
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=83.19):
#   Theta for diagnosed: 0.016 ± 0.009
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=77.07):
#   Theta for diagnosed: 0.032 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=70.41):
#   Theta for diagnosed: 0.031 ± 0.027
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=64.04):
#   Theta for diagnosed: 0.038 ± 0.035
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 127 (signature 0, LR=61.05):
#   Theta for diagnosed: 0.037 ± 0.046
#   Theta for others: 0.027
#   Proportion difference: 0.010
#
# Epoch 197
# Loss: 57.6285
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=83.77):
#   Theta for diagnosed: 0.016 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=77.42):
#   Theta for diagnosed: 0.032 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 249 (signature 13, LR=70.82):
#   Theta for diagnosed: 0.031 ± 0.027
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=64.29):
#   Theta for diagnosed: 0.038 ± 0.036
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 127 (signature 0, LR=61.41):
#   Theta for diagnosed: 0.037 ± 0.046
#   Theta for others: 0.027
#   Proportion difference: 0.010
#
# Epoch 198
# Loss: 57.6052
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=84.34):
#   Theta for diagnosed: 0.016 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=77.78):
#   Theta for diagnosed: 0.032 ± 0.027
#   Theta for others: 0.023
#   Proportion difference: 0.010
#
# Disease 249 (signature 13, LR=71.23):
#   Theta for diagnosed: 0.032 ± 0.027
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=64.54):
#   Theta for diagnosed: 0.038 ± 0.036
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 127 (signature 0, LR=61.77):
#   Theta for diagnosed: 0.037 ± 0.046
#   Theta for others: 0.027
#   Proportion difference: 0.010
#
# Epoch 199
# Loss: 57.5821
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=84.92):
#   Theta for diagnosed: 0.016 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 21 (signature 13, LR=78.13):
#   Theta for diagnosed: 0.033 ± 0.027
#   Theta for others: 0.023
#   Proportion difference: 0.010
#
# Disease 249 (signature 13, LR=71.64):
#   Theta for diagnosed: 0.032 ± 0.028
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=64.79):
#   Theta for diagnosed: 0.038 ± 0.036
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 127 (signature 0, LR=62.13):
#   Theta for diagnosed: 0.037 ± 0.046
#   Theta for others: 0.027
#   Proportion difference: 0.010
#          93988803 function calls (93967951 primitive calls) in 4218.138 seconds
#
#    Ordered by: cumulative time
#    List reduced from 4184 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000 4218.139 2109.070 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#    1885/2    0.077    0.000 4218.139 2109.070 {built-in method builtins.exec}
#         1    0.701    0.701 4218.139 4218.139 /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_60132/3239544722.py:9(<module>)
#         1  135.014  135.014 4217.438 4217.438 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:329(fit)
#       200    0.008    0.000 2970.208   14.851 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:525(backward)
#       200    0.002    0.000 2970.199   14.851 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#       200    0.002    0.000 2970.189   14.851 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/graph.py:816(_engine_run_backward)
#       200 2970.187   14.851 2970.187   14.851 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       200  140.997    0.705 1079.922    5.400 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:230(compute_loss)
#       200  436.756    2.184  861.605    4.308 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:287(compute_gp_prior_loss)
#  43461600  305.866    0.000  305.866    0.000 {built-in method torch.cholesky_solve}
#  43531800  125.542    0.000  126.497    0.000 {built-in method torch.sum}
#       400   12.840    0.032   54.035    0.135 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:221(forward)
#       200    0.968    0.005   30.654    0.153 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:403(analyze_signature_responses)
#       400    0.004    0.000   29.596    0.074 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/functional.py:210(einsum)
#       400   29.590    0.074   29.590    0.074 {built-in method torch.einsum}
#       600   20.485    0.034   20.485    0.034 {built-in method torch.log}
#       600   15.974    0.027   15.974    0.027 {built-in method torch.clamp}
#       600    0.003    0.000   11.149    0.019 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:33(wrapped)
#       600    0.003    0.000   11.146    0.019 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:1026(__rsub__)

# %%
from utils import *
plot_training_evolution(history_new)

# %%
# Save model
W=0.0001
torch.save({
    'model_state_dict': model.state_dict(),
    'phi': model.phi,
    'Y': model.Y,
    'prevalence_t': model.prevalence_t,
    'logit_prevalence_t': model.logit_prev_t,
    'G': model.G,
}, f'/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_model_W{W}_fulldata_sexspecific.pt')

# %%
plot_theta_differences(model, diseases=[112,67,127,10,17,114], signatures=[5,7,0,17,19,5])
