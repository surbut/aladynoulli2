# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess
from clust_huge_amp_withlogger import *
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning, module="sklearn.utils.extmath")

# %% [markdown]
# ## Aladynoulli retrospective
#
# Here we show the ability of the model to estatime when having access to all data for signature and genomic discovery, heterogeneity characterization, and cohort similarity.

# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/2084552305.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/2084552305.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/2084552305.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/2084552305.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
from clust_huge_amp import *
# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, start_index=0, end_index=10000)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data

del Y

# %%
# Load references (signatures only, no healthy)
refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/reference_trajectories.pt')
signature_refs = refs['signature_refs']
# When initializing the model:
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/2694258374.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/reference_trajectories.pt')

# %%
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the RDS file
readRDS = robjects.r['readRDS']
pce_data = readRDS('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_df_prevent.rds')
pce_df = pandas2ri.rpy2py(pce_data)  # Convert to pandas DataFrame

# %%
readRDS = robjects.r['readRDS']
pce_data = readRDS('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_df_prevent.rds')
pce_df = pandas2ri.rpy2py(pce_data)  # Convert to pandas DataFrame
sex=pce_df['Sex'].values

# Convert to numeric: Female=0, Male=1

pce_df['sex_numeric'] = pce_df['Sex'].map({'Female': 0, 'Male': 1}).astype(int)

sex=pce_df['sex_numeric'].values
G_with_sex = np.column_stack([G_100k, sex])  # sex should be numeric (e.g., 0/1)
# N

# %%
type(model), model.fit.__code__.co_filename, model.compute_gp_prior_loss.__code__.co_filename
# Out:
# (clust_huge_amp_withlogger.AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest,
#  '/Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py',
#  '/Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py')

# %%
model = m.AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_with_sex.shape[1],
    init_sd_scaler=1e-1,
    G=G_with_sex, 
    Y=Y_100k,
    genetic_scale=1,
    W=0,
    R=0,
    prevalence_t=essentials['prevalence_t'],
    signature_references=signature_refs,  # Only pass signature refs
    healthy_reference=True,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

torch.manual_seed(0)
np.random.seed(0)
# Initialize with psi and clusters


import cProfile
import pstats
from pstats import SortKey

# Now in your batch run, load and verify:
initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')

model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0008,  0.0071,  0.0117,  0.0152, -0.0106])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0219,  0.0117,  0.0025, -0.0018, -0.0047])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0018, -0.0023,  0.0065,  0.0024, -0.0054])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0020, -0.0039,  0.0022,  0.0021, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0060, -0.0015, -0.0132,  0.0367, -0.0098])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0048,  0.0060, -0.0042,  0.0057,  0.0247])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0017,  0.0011, -0.0008, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0073,  0.0049, -0.0054,  0.0056, -0.0040])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0013,  0.0009,  0.0006,  0.0133, -0.0011])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([ 9.8607e-06,  9.0586e-03,  1.5898e-02, -3.2695e-03,  5.4494e-04])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0122, -0.0048,  0.0013, -0.0042,  0.0020])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0062,  0.0047, -0.0075,  0.0032,  0.0006])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0072,  0.0011, -0.0018,  0.0015,  0.0025])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 7.6968e-03,  1.0931e-02,  8.1495e-05,  7.9375e-03, -1.5938e-03])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0121, -0.0034, -0.0035,  0.0132,  0.0054])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0023, 0.0029, 0.0010, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([ 0.0023,  0.0108,  0.0118, -0.0026,  0.0093])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0068,  0.0176,  0.0005, -0.0053, -0.0091])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0158, -0.0017,  0.0114,  0.0180, -0.0033])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0006, -0.0010,  0.0008,  0.0037,  0.0014])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.9623, -13.8155])
# Base value centered (first 5): tensor([-0.1879, -0.1879, -0.1879,  1.6653, -0.1879])
# Base value centered mean: -3.345489574257954e-07
# Gamma init for k=0 (first 5): tensor([ 0.0069,  0.0066, -0.0055,  0.0062,  0.0243])
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/872472158.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/872472158.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.3449, -13.3449, -12.4036])
# Base value centered (first 5): tensor([ 0.1505, -0.3201,  0.1505,  0.1505,  1.0918])
# Base value centered mean: -1.8495559288567165e-06
# Gamma init for k=1 (first 5): tensor([0.0044, 0.0012, 0.0007, 0.0026, 0.0014])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1566, -11.8388, -12.4977])
# Base value centered (first 5): tensor([-0.3849, -0.3849,  0.2740,  1.5918,  0.9329])
# Base value centered mean: 9.290695288655115e-07
# Gamma init for k=2 (first 5): tensor([-0.0001,  0.0092,  0.0113,  0.0160, -0.0109])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.6950, -13.5744])
# Base value centered (first 5): tensor([-0.1026, -0.1026, -0.1026,  0.0179,  0.1384])
# Base value centered mean: 4.7445297468584613e-07
# Gamma init for k=3 (first 5): tensor([ 0.0011,  0.0003,  0.0017,  0.0019, -0.0006])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155,  -9.8620, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1133,  3.8402, -0.1133, -0.1133, -0.1133])
# Base value centered mean: -2.841758714566822e-06
# Gamma init for k=4 (first 5): tensor([-0.0169, -0.0023,  0.0140,  0.0213, -0.0032])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=5 (first 5): tensor([ 0.0219,  0.0117,  0.0025, -0.0018, -0.0047])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1523, -0.1523, -0.1523, -0.1523, -0.1523])
# Base value centered mean: -1.0890006478803116e-06
# Gamma init for k=6 (first 5): tensor([ 0.0075,  0.0130,  0.0004,  0.0055, -0.0025])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.3663, -13.8155, -13.3663, -13.8155, -11.1200])
# Base value centered (first 5): tensor([-0.1005, -0.5497, -0.1005, -0.5497,  2.1458])
# Base value centered mean: 1.2460708376238472e-06
# Gamma init for k=7 (first 5): tensor([ 0.0027, -0.0039, -0.0122,  0.0250, -0.0020])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1159, -0.1159, -0.1159, -0.1159, -0.1159])
# Base value centered mean: -1.4129639112070436e-06
# Gamma init for k=8 (first 5): tensor([ 0.0066, -0.0056,  0.0009, -0.0016, -0.0004])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=9 (first 5): tensor([ 0.0062,  0.0047, -0.0075,  0.0032,  0.0006])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=10 (first 5): tensor([-0.0068,  0.0176,  0.0005, -0.0053, -0.0091])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=11 (first 5): tensor([0.0026, 0.0023, 0.0029, 0.0010, 0.0098])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0860, -0.0860, -0.0860, -0.0860, -0.0860])
# Base value centered mean: -1.034450519910024e-06
# Gamma init for k=12 (first 5): tensor([ 8.2098e-03, -7.1588e-03,  4.5737e-06, -3.0368e-04, -7.6238e-03])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.7744, -12.2949])
# Base value centered (first 5): tensor([-0.1777, -0.1777, -0.1777,  2.8635,  1.3429])
# Base value centered mean: -1.0064125035569305e-06
# Gamma init for k=13 (first 5): tensor([ 0.0003,  0.0065,  0.0122, -0.0056,  0.0007])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.8388, -12.8271])
# Base value centered (first 5): tensor([-0.2562, -0.2562, -0.2562,  1.7205,  0.7322])
# Base value centered mean: -1.5125274330785032e-06
# Gamma init for k=14 (first 5): tensor([ 0.0021, -0.0037, -0.0087,  0.0178,  0.0010])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.8388])
# Base value centered (first 5): tensor([-0.2850, -0.2850, -0.2850, -0.2850,  1.6917])
# Base value centered mean: -1.2931823221151717e-06
# Gamma init for k=15 (first 5): tensor([ 0.0013,  0.0041,  0.0077, -0.0082,  0.0078])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.7706, -13.1339])
# Base value centered (first 5): tensor([-0.2428, -0.2428, -0.2428,  1.8021,  0.4388])
# Base value centered mean: -1.9989013253507437e-06
# Gamma init for k=16 (first 5): tensor([ 0.0014,  0.0004,  0.0086,  0.0059, -0.0034])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.3272, -12.0713])
# Base value centered (first 5): tensor([-0.4228, -0.4228, -0.4228,  3.0656,  1.3214])
# Base value centered mean: -2.227592403869494e-06
# Gamma init for k=17 (first 5): tensor([ 0.0078,  0.0057, -0.0059,  0.0059, -0.0039])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=18 (first 5): tensor([-0.0121, -0.0034, -0.0035,  0.0132,  0.0054])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([-0.1519, -0.1519, -0.1519, -0.1519,  0.2779])
# Base value centered mean: -1.1179923831150518e-06
# Gamma init for k=19 (first 5): tensor([-0.0027,  0.0051,  0.0015, -0.0011, -0.0017])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Clusters match exactly: True

# %% [markdown]
# # you can see that we use the full unmodified E matrix here

# %%
from importlib import reload
import clust_huge_amp_withlogger as m
reload(m)
# Out:
# <module 'clust_huge_amp_withlogger' from '/Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py'>

# %%
## now we will run the model with the full data and sex specific
import cProfile
import pstats
from pstats import SortKey
# 5. Train on FULL data
profiler = cProfile.Profile()
profiler.enable()

history_new = model.fit(E_100k, num_epochs=100, learning_rate=1e-1, lambda_reg=1e-2)
profiler.disable()
stats = pstats.Stats(profiler).sort_stats(SortKey.CUMULATIVE)
stats.print_stats(20)
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py:238: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# {'data_plus_other': 1070.3902587890625, 'gp_loss': 6535072.5, 'scaled_gp': 6535072.5, 'gp_frac': 6105.317613216284}
#
# Epoch 0
# Loss: 1070.3903
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.09):
#   Theta for diagnosed: 0.150 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.76):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.39):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.070
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.015 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 6535137.5, 'gp_loss': 529680.0, 'scaled_gp': 529680.0, 'gp_frac': 0.08105108729540886}
#
# Epoch 1
# Loss: 6535137.5000
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 529744.6875, 'gp_loss': 1461496.625, 'scaled_gp': 1461496.625, 'gp_frac': 2.758869809336219}
#
# Epoch 2
# Loss: 529744.6875
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 1461561.0, 'gp_loss': 3655908.25, 'scaled_gp': 3655908.25, 'gp_frac': 2.5013723341003216}
#
# Epoch 3
# Loss: 1461561.0000
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.13):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.80):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.51):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 3655972.25, 'gp_loss': 2751482.25, 'scaled_gp': 2751482.25, 'gp_frac': 0.7525993256650129}
#
# Epoch 4
# Loss: 3655972.2500
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.13):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.80):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 2751546.0, 'gp_loss': 877429.375, 'scaled_gp': 877429.375, 'gp_frac': 0.3188859553865354}
#
# Epoch 5
# Loss: 2751546.0000
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 877492.875, 'gp_loss': 157675.828125, 'scaled_gp': 157675.828125, 'gp_frac': 0.17968901243215224}
#
# Epoch 6
# Loss: 877492.8750
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 157739.078125, 'gp_loss': 861587.875, 'scaled_gp': 861587.875, 'gp_frac': 5.46210796488386}
#
# Epoch 7
# Loss: 157739.0781
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 861650.9375, 'gp_loss': 1699781.25, 'scaled_gp': 1699781.25, 'gp_frac': 1.9727028382650602}
#
# Epoch 8
# Loss: 861650.9375
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.10):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 1699844.125, 'gp_loss': 1624030.625, 'scaled_gp': 1624030.625, 'gp_frac': 0.9553997340785585}
#
# Epoch 9
# Loss: 1699844.1250
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.10):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 1624093.375, 'gp_loss': 854131.5, 'scaled_gp': 854131.5, 'gp_frac': 0.5259128035049093}
#
# Epoch 10
# Loss: 1624093.3750
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 854194.125, 'gp_loss': 199609.703125, 'scaled_gp': 199609.703125, 'gp_frac': 0.23368189651854607}
#
# Epoch 11
# Loss: 854194.1250
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 199672.234375, 'gp_loss': 166629.328125, 'scaled_gp': 166629.328125, 'gp_frac': 0.8345142660749574}
#
# Epoch 12
# Loss: 199672.2344
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 166691.78125, 'gp_loss': 590853.6875, 'scaled_gp': 590853.6875, 'gp_frac': 3.5445879998957657}
#
# Epoch 13
# Loss: 166691.7812
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 590916.0625, 'gp_loss': 915480.125, 'scaled_gp': 915480.125, 'gp_frac': 1.5492557794534483}
#
# Epoch 14
# Loss: 590916.0625
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 915542.4375, 'gp_loss': 805341.25, 'scaled_gp': 805341.25, 'gp_frac': 0.8796329006868128}
#
# Epoch 15
# Loss: 915542.4375
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 805403.5, 'gp_loss': 409856.3125, 'scaled_gp': 409856.3125, 'gp_frac': 0.5088832026431472}
#
# Epoch 16
# Loss: 805403.5000
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 409918.5, 'gp_loss': 105995.1171875, 'scaled_gp': 105995.1171875, 'gp_frac': 0.2585760759455843}
#
# Epoch 17
# Loss: 409918.5000
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 106057.265625, 'gp_loss': 115126.03125, 'scaled_gp': 115126.03125, 'gp_frac': 1.0855081975907768}
#
# Epoch 18
# Loss: 106057.2656
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 115188.140625, 'gp_loss': 334056.5625, 'scaled_gp': 334056.5625, 'gp_frac': 2.9000951025638626}
#
# Epoch 19
# Loss: 115188.1406
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 334118.65625, 'gp_loss': 485776.875, 'scaled_gp': 485776.875, 'gp_frac': 1.4539052696193167}
#
# Epoch 20
# Loss: 334118.6562
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 485838.9375, 'gp_loss': 413701.9375, 'scaled_gp': 413701.9375, 'gp_frac': 0.8515207521834333}
#
# Epoch 21
# Loss: 485838.9375
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 413763.96875, 'gp_loss': 205434.484375, 'scaled_gp': 205434.484375, 'gp_frac': 0.4965016286836842}
#
# Epoch 22
# Loss: 413763.9688
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 205496.5, 'gp_loss': 60926.609375, 'scaled_gp': 60926.609375, 'gp_frac': 0.296484900594414}
#
# Epoch 23
# Loss: 205496.5000
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 60988.61328125, 'gp_loss': 84924.484375, 'scaled_gp': 84924.484375, 'gp_frac': 1.392464589797596}
#
# Epoch 24
# Loss: 60988.6133
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 84986.4765625, 'gp_loss': 203929.125, 'scaled_gp': 203929.125, 'gp_frac': 2.3995479427839115}
#
# Epoch 25
# Loss: 84986.4766
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 203991.109375, 'gp_loss': 266597.21875, 'scaled_gp': 266597.21875, 'gp_frac': 1.306906068440023}
#
# Epoch 26
# Loss: 203991.1094
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 266659.1875, 'gp_loss': 206148.09375, 'scaled_gp': 206148.09375, 'gp_frac': 0.7730770339574368}
#
# Epoch 27
# Loss: 266659.1875
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 206210.0625, 'gp_loss': 90886.9296875, 'scaled_gp': 90886.9296875, 'gp_frac': 0.4407492465965379}
#
# Epoch 28
# Loss: 206210.0625
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 90948.8984375, 'gp_loss': 32331.2109375, 'scaled_gp': 32331.2109375, 'gp_frac': 0.35548765837684093}
#
# Epoch 29
# Loss: 90948.8984
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 32393.17578125, 'gp_loss': 67051.40625, 'scaled_gp': 67051.40625, 'gp_frac': 2.069923822930973}
#
# Epoch 30
# Loss: 32393.1758
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 67113.3671875, 'gp_loss': 131888.484375, 'scaled_gp': 131888.484375, 'gp_frac': 1.9651596977176329}
#
# Epoch 31
# Loss: 67113.3672
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 131950.4375, 'gp_loss': 144846.75, 'scaled_gp': 144846.75, 'gp_frac': 1.0977360344106475}
#
# Epoch 32
# Loss: 131950.4375
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 144908.703125, 'gp_loss': 93065.15625, 'scaled_gp': 93065.15625, 'gp_frac': 0.6422330353044486}
#
# Epoch 33
# Loss: 144908.7031
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 93127.1171875, 'gp_loss': 34124.71484375, 'scaled_gp': 34124.71484375, 'gp_frac': 0.36643156015496625}
#
# Epoch 34
# Loss: 93127.1172
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 34186.67578125, 'gp_loss': 23666.791015625, 'scaled_gp': 23666.791015625, 'gp_frac': 0.6922811438895522}
#
# Epoch 35
# Loss: 34186.6758
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 23728.751953125, 'gp_loss': 56890.9296875, 'scaled_gp': 56890.9296875, 'gp_frac': 2.397552547217202}
#
# Epoch 36
# Loss: 23728.7520
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 56952.890625, 'gp_loss': 83591.6328125, 'scaled_gp': 83591.6328125, 'gp_frac': 1.467732926198599}
#
# Epoch 37
# Loss: 56952.8906
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 83653.59375, 'gp_loss': 70141.546875, 'scaled_gp': 70141.546875, 'gp_frac': 0.8384761936781706}
#
# Epoch 38
# Loss: 83653.5938
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 70203.5078125, 'gp_loss': 33402.9765625, 'scaled_gp': 33402.9765625, 'gp_frac': 0.4758021016800598}
#
# Epoch 39
# Loss: 70203.5078
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 33464.9375, 'gp_loss': 13435.435546875, 'scaled_gp': 13435.435546875, 'gp_frac': 0.4014779811519146}
#
# Epoch 40
# Loss: 33464.9375
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 13497.3984375, 'gp_loss': 25016.521484375, 'scaled_gp': 25016.521484375, 'gp_frac': 1.853432837462312}
#
# Epoch 41
# Loss: 13497.3984
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 25078.484375, 'gp_loss': 45184.1328125, 'scaled_gp': 45184.1328125, 'gp_frac': 1.8017090720818332}
#
# Epoch 42
# Loss: 25078.4844
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 45246.09765625, 'gp_loss': 45623.6328125, 'scaled_gp': 45623.6328125, 'gp_frac': 1.0083440379570028}
#
# Epoch 43
# Loss: 45246.0977
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 45685.59765625, 'gp_loss': 26043.150390625, 'scaled_gp': 26043.150390625, 'gp_frac': 0.5700516514324767}
#
# Epoch 44
# Loss: 45685.5977
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 26105.1171875, 'gp_loss': 9708.509765625, 'scaled_gp': 9708.509765625, 'gp_frac': 0.37190063909285026}
#
# Epoch 45
# Loss: 26105.1172
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 9770.4765625, 'gp_loss': 12291.513671875, 'scaled_gp': 12291.513671875, 'gp_frac': 1.258026012676902}
#
# Epoch 46
# Loss: 9770.4766
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 12353.48046875, 'gp_loss': 24666.005859375, 'scaled_gp': 24666.005859375, 'gp_frac': 1.9966847336482538}
#
# Epoch 47
# Loss: 12353.4805
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 24727.97265625, 'gp_loss': 27901.76953125, 'scaled_gp': 27901.76953125, 'gp_frac': 1.1283484464788027}
#
# Epoch 48
# Loss: 24727.9727
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 27963.736328125, 'gp_loss': 17620.12890625, 'scaled_gp': 17620.12890625, 'gp_frac': 0.6301063884845838}
#
# Epoch 49
# Loss: 27963.7363
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 17682.095703125, 'gp_loss': 6786.40087890625, 'scaled_gp': 6786.40087890625, 'gp_frac': 0.3838007096470399}
#
# Epoch 50
# Loss: 17682.0957
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 6848.36767578125, 'gp_loss': 6928.9453125, 'scaled_gp': 6928.9453125, 'gp_frac': 1.0117659624210462}
#
# Epoch 51
# Loss: 6848.3677
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 6990.912109375, 'gp_loss': 14194.7216796875, 'scaled_gp': 14194.7216796875, 'gp_frac': 2.0304534598070543}
#
# Epoch 52
# Loss: 6990.9121
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 14256.6884765625, 'gp_loss': 16726.8203125, 'scaled_gp': 16726.8203125, 'gp_frac': 1.1732612618981126}
#
# Epoch 53
# Loss: 14256.6885
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 16788.787109375, 'gp_loss': 10851.078125, 'scaled_gp': 10851.078125, 'gp_frac': 0.646328889294252}
#
# Epoch 54
# Loss: 16788.7871
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 10913.0439453125, 'gp_loss': 4288.68359375, 'scaled_gp': 4288.68359375, 'gp_frac': 0.3929869260347042}
#
# Epoch 55
# Loss: 10913.0439
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 4350.6494140625, 'gp_loss': 4376.3125, 'scaled_gp': 4376.3125, 'gp_frac': 1.0058986793683145}
#
# Epoch 56
# Loss: 4350.6494
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# ...
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 364.5128479003906, 'gp_loss': 548.958251953125, 'scaled_gp': 548.958251953125, 'gp_frac': 1.506005220707988}
#
# Epoch 85
# Loss: 364.5128
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 610.9178466796875, 'gp_loss': 542.8179321289062, 'scaled_gp': 542.8179321289062, 'gp_frac': 0.8885285232361415}
#
# Epoch 86
# Loss: 610.9178
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 604.7774658203125, 'gp_loss': 279.09075927734375, 'scaled_gp': 279.09075927734375, 'gp_frac': 0.4614767828672131}
#
# Epoch 87
# Loss: 604.7775
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 341.05029296875, 'gp_loss': 161.45852661132812, 'scaled_gp': 161.45852661132812, 'gp_frac': 0.4734155927733578}
#
# Epoch 88
# Loss: 341.0503
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 223.41806030273438, 'gp_loss': 297.0232849121094, 'scaled_gp': 297.0232849121094, 'gp_frac': 1.3294506474079981}
#
# Epoch 89
# Loss: 223.4181
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 358.9828186035156, 'gp_loss': 379.3611145019531, 'scaled_gp': 379.3611145019531, 'gp_frac': 1.0567667722308032}
#
# Epoch 90
# Loss: 358.9828
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 441.3206481933594, 'gp_loss': 246.3047637939453, 'scaled_gp': 246.3047637939453, 'gp_frac': 0.5581084066704031}
#
# Epoch 91
# Loss: 441.3206
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 308.2643127441406, 'gp_loss': 111.78173065185547, 'scaled_gp': 111.78173065185547, 'gp_frac': 0.36261651456435146}
#
# Epoch 92
# Loss: 308.2643
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 173.74127197265625, 'gp_loss': 157.15399169921875, 'scaled_gp': 157.15399169921875, 'gp_frac': 0.9045288428874398}
#
# Epoch 93
# Loss: 173.7413
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 219.11354064941406, 'gp_loss': 245.55441284179688, 'scaled_gp': 245.55441284179688, 'gp_frac': 1.1206720137606134}
#
# Epoch 94
# Loss: 219.1135
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 307.5139465332031, 'gp_loss': 198.2279815673828, 'scaled_gp': 198.2279815673828, 'gp_frac': 0.6446146062711324}
#
# Epoch 95
# Loss: 307.5139
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 260.1875305175781, 'gp_loss': 91.66266632080078, 'scaled_gp': 91.66266632080078, 'gp_frac': 0.3522946166500016}
#
# Epoch 96
# Loss: 260.1875
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 153.6221923828125, 'gp_loss': 87.73912811279297, 'scaled_gp': 87.73912811279297, 'gp_frac': 0.5711357633417642}
#
# Epoch 97
# Loss: 153.6222
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 149.69863891601562, 'gp_loss': 153.04891967773438, 'scaled_gp': 153.04891967773438, 'gp_frac': 1.022380168490365}
#
# Epoch 98
# Loss: 149.6986
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.10):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
# {'data_plus_other': 215.00845336914062, 'gp_loss': 148.54937744140625, 'scaled_gp': 148.54937744140625, 'gp_frac': 0.6909001721265672}
#
# Epoch 99
# Loss: 215.0085
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.10):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#          90688247 function calls (90687247 primitive calls) in 2454.265 seconds
#
#    Ordered by: cumulative time
#    List reduced from 185 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000 2454.265 1227.132 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#         2    0.000    0.000 2454.265 1227.132 {built-in method builtins.exec}
#         1    0.795    0.795 2454.265 2454.265 /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/627991137.py:9(<module>)
#         1   68.857   68.857 2453.469 2453.469 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py:329(fit)
#       100    0.004    0.000 1452.044   14.520 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:525(backward)
#       100    0.001    0.000 1452.039   14.520 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#       100    0.001    0.000 1452.034   14.520 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/graph.py:816(_engine_run_backward)
#       100 1452.033   14.520 1452.033   14.520 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       200  412.587    2.063  801.938    4.010 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py:287(compute_gp_prior_loss)
#       100   72.941    0.729  591.565    5.916 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py:230(compute_loss)
#  43461600  299.575    0.000  299.575    0.000 {built-in method torch.cholesky_solve}
#  43496700   93.673    0.000   94.230    0.000 {built-in method torch.sum}
#       200    6.189    0.031   28.063    0.140 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py:221(forward)
#       100    0.546    0.005   15.913    0.159 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/clust_huge_amp_withlogger.py:411(analyze_signature_responses)
#       200    0.003    0.000   15.684    0.078 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/functional.py:210(einsum)
#       200   15.680    0.078   15.680    0.078 {built-in method torch.einsum}
#       300   10.977    0.037   10.977    0.037 {built-in method torch.log}
#       300    8.334    0.028    8.334    0.028 {built-in method torch.clamp}
#       300    0.001    0.000    5.773    0.019 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:33(wrapped)
#       300    0.001    0.000    5.772    0.019 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:1026(__rsub__)

# %%
from utils import *
compare_with_pce(model, pce_df)
# Out:
# ROC AUC Comparison (10-year prediction from enrollment):
# Our model: 0.688
# PCE: 0.678

# %%
from utils import *
plot_training_evolution(history_new)

# %%
# Save model
W=0.0001
torch.save({
    'model_state_dict': model.state_dict(),
    'phi': model.phi,
    'Y': model.Y,
    'prevalence_t': model.prevalence_t,
    'logit_prevalence_t': model.logit_prev_t,
    'G': model.G,
}, f'/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_model_W{W}_fulldata_sexspecific.pt')

# %%
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/enrollment_model_W0.0001_fulldata_sexspecific.pt')
import os
import sys
import torch
# %load_ext autoreload
# %autoreload 2
sys.path.append('/Users/sarahurbut/aladynoulli2/pyScripts/')
from fig5utils import *
disease_names=essentials['disease_names']
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, Y_100k, E_100k, disease_names, pce_df, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_99135/3124392669.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/enrollment_model_W0.0001_fulldata_sexspecific.pt')
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.862 (0.831-0.892) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.680 (0.640-0.727) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.713 (0.604-0.816) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.571 (0.484-0.669) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.667 (0.610-0.720) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.515 (0.409-0.618) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.686 (0.589-0.780) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.609 (0.540-0.686) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.715 (0.662-0.772) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.619 (0.540-0.695) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.666 (0.625-0.711) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.734 (0.644-0.859) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.810 (0.757-0.849) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.803 (0.726-0.859) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.764 (0.593-0.922) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.631 (0.421-0.851) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.563 (0.489-0.631) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.761 (0.726-0.794) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.700 (0.655-0.747) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.697 (0.567-0.813) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.721 (0.624-0.813) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.610 (0.484-0.761) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.905 (0.848-0.943) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.735 (0.620-0.849) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.759 (0.726-0.800) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.626 (0.447-0.802) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.673 (0.485-0.829) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.758 (0.713-0.797) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.862 (0.831-0.892)       136        5.4
# Diabetes             0.680 (0.640-0.727)       137        5.4
# Atrial_Fib           0.713 (0.604-0.816)       29         1.1
# CKD                  0.571 (0.484-0.669)       33         1.3
# All_Cancers          0.667 (0.610-0.720)       94         3.7
# Stroke               0.515 (0.409-0.618)       30         1.2
# Heart_Failure        0.686 (0.589-0.780)       32         1.3
# Pneumonia            0.609 (0.540-0.686)       70         2.8
# COPD                 0.715 (0.662-0.772)       81         3.2
# Osteoporosis         0.619 (0.540-0.695)       41         1.6
# Anemia               0.666 (0.625-0.711)       154        6.1
# Colorectal_Cancer    0.734 (0.644-0.859)       25         1.0
# Breast_Cancer        0.810 (0.757-0.849)       65         4.6
# Prostate_Cancer      0.803 (0.726-0.859)       35         3.1
# Lung_Cancer          0.764 (0.593-0.922)       9          0.4
# Bladder_Cancer       0.631 (0.421-0.851)       9          0.4
# Secondary_Cancer     0.563 (0.489-0.631)       71         2.8
# Depression           0.761 (0.726-0.794)       192        7.6
# Anxiety              0.700 (0.655-0.747)       136        5.4
# Bipolar_Disorder     0.697 (0.567-0.813)       17         0.7
# Rheumatoid_Arthritis 0.721 (0.624-0.813)       36         1.4
# Psoriasis            0.610 (0.484-0.761)       24         0.9
# Ulcerative_Colitis   0.905 (0.848-0.943)       22         0.9
# Crohns_Disease       0.735 (0.620-0.849)       20         0.8
# Asthma               0.759 (0.726-0.800)       218        8.8
# Parkinsons           0.626 (0.447-0.802)       2          0.1
# Multiple_Sclerosis   0.673 (0.485-0.829)       11         0.4
# Thyroid_Disorders    0.758 (0.713-0.797)       145        5.7
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.8622813990461049,
#   'n_events': 136,
#   'event_rate': 5.352223534041716,
#   'ci_lower': 0.8312935278634285,
#   'ci_upper': 0.8924531711813893},
#  'Diabetes': {'auc': 0.6798917861957565,
#   'n_events': 137,
#   'event_rate': 5.3915781188508465,
#   'ci_lower': 0.6404533337260816,
#   'ci_upper': 0.7271752441303956},
#  'Atrial_Fib': {'auc': 0.7125518343505035,
#   'n_events': 29,
#   'event_rate': 1.1453396524486572,
#   'ci_lower': 0.6042900754485754,
#   'ci_upper': 0.8155550443735969},
#  'CKD': {'auc': 0.5709003914745542,
#   'n_events': 33,
#   'event_rate': 1.2987012987012987,
#   'ci_lower': 0.48400380269016646,
#   'ci_upper': 0.6685776104162963},
#  'All_Cancers': {'auc': 0.6665217504717021,
#   'n_events': 94,
#   'event_rate': 3.699330972058245,
#   'ci_lower': 0.6101530241820612,
#   'ci_upper': 0.7196882315340842},
#  'Stroke': {'auc': 0.5151068631355369,
#   'n_events': 30,
#   'event_rate': 1.1806375442739079,
#   'ci_lower': 0.40936659220417754,
#   'ci_upper': 0.6180674704155377},
#  'Heart_Failure': {'auc': 0.6864537664408131,
#   'n_events': 32,
#   'event_rate': 1.2593467138921683,
#   'ci_lower': 0.589247119496903,
#   'ci_upper': 0.780065040483334},
#  'Pneumonia': {'auc': 0.6085737411111752,
#   'n_events': 70,
#   'event_rate': 2.7548209366391188,
#   'ci_lower': 0.5397436638621018,
#   'ci_upper': 0.6863509915383985},
#  'COPD': {'auc': 0.7148399076583358,
#   'n_events': 81,
#   'event_rate': 3.187721369539551,
#   'ci_lower': 0.6621990089052614,
#   'ci_upper': 0.7715201821698172},
#  'Osteoporosis': {'auc': 0.6193306590929055,
#   'n_events': 41,
#   'event_rate': 1.6141732283464567,
#   'ci_lower': 0.5396766481643356,
#   'ci_upper': 0.6948276879898685},
#  'Anemia': {'auc': 0.6663937235784744,
#   'n_events': 154,
#   'event_rate': 6.0606060606060606,
#   'ci_lower': 0.6252874806713622,
#   'ci_upper': 0.7107176683868749},
#  'Colorectal_Cancer': {'auc': 0.7336883942766296,
#   'n_events': 25,
#   'event_rate': 0.9838646202282565,
#   'ci_lower': 0.6443221027648713,
#   'ci_upper': 0.8591012166330676},
#  'Breast_Cancer': {'auc': 0.810137506472585,
#   'n_events': 65,
#   'event_rate': 4.636233951497861,
#   'ci_lower': 0.7566180000007906,
#   'ci_upper': 0.8490454406283268},
#  'Prostate_Cancer': {'auc': 0.8034420289855072,
#   'n_events': 35,
#   'event_rate': 3.0728709394205445,
#   'ci_lower': 0.7259734633902394,
#   'ci_upper': 0.8585182362240289},
#  'Lung_Cancer': {'auc': 0.7637352992803229,
#   'n_events': 9,
#   'event_rate': 0.3541912632821724,
#   'ci_lower': 0.5927237210186999,
#   'ci_upper': 0.9222240405931642},
#  'Bladder_Cancer': {'auc': 0.6311953992712587,
#   'n_events': 9,
#   'event_rate': 0.3543307086614173,
#   'ci_lower': 0.4205045200353751,
#   'ci_upper': 0.8505426421762898},
#  'Secondary_Cancer': {'auc': 0.5630951702115528,
#   'n_events': 71,
#   'event_rate': 2.7941755214482487,
#   'ci_lower': 0.48941827817479117,
#   'ci_upper': 0.6310636379037458},
#  'Depression': {'auc': 0.7606502443582003,
#   'n_events': 192,
#   'event_rate': 7.646356033452808,
#   'ci_lower': 0.7259607864354656,
#   'ci_upper': 0.7936335197865269},
#  'Anxiety': {'auc': 0.7003063725490196,
#   'n_events': 136,
#   'event_rate': 5.3627760252365935,
#   'ci_lower': 0.6553855138132406,
#   'ci_upper': 0.7467365783041967},
#  'Bipolar_Disorder': {'auc': 0.6974523036685893,
#   'n_events': 17,
#   'event_rate': 0.6703470031545742,
#   'ci_lower': 0.5673174476517417,
#   'ci_upper': 0.8130238853598128},
#  'Rheumatoid_Arthritis': {'auc': 0.7212341238120614,
#   'n_events': 36,
#   'event_rate': 1.4184397163120568,
#   'ci_lower': 0.6238205589062594,
#   'ci_upper': 0.8129916107116324},
#  'Psoriasis': {'auc': 0.6096090125911199,
#   'n_events': 24,
#   'event_rate': 0.9452540370224497,
#   'ci_lower': 0.48379098773890544,
#   'ci_upper': 0.761275464459893},
#  'Ulcerative_Colitis': {'auc': 0.9049916563883045,
#   'n_events': 22,
#   'event_rate': 0.870253164556962,
#   'ci_lower': 0.8478351028278076,
#   'ci_upper': 0.9425831568828114},
#  'Crohns_Disease': {'auc': 0.7347791484281734,
#   'n_events': 20,
#   'event_rate': 0.7895775759968418,
#   'ci_lower': 0.6202623566462826,
#   'ci_upper': 0.8488175986415175},
#  'Asthma': {'auc': 0.7585108634598633,
#   'n_events': 218,
#   'event_rate': 8.818770226537216,
#   'ci_lower': 0.725584761529212,
#   'ci_upper': 0.8004749209374701},
#  'Parkinsons': {'auc': 0.6264277274517527,
#   'n_events': 2,
#   'event_rate': 0.07870916961826052,
#   'ci_lower': 0.44684197905669065,
#   'ci_upper': 0.8015748031496064},
#  'Multiple_Sclerosis': {'auc': 0.672979297929793,
#   'n_events': 11,
#   'event_rate': 0.4337539432176656,
#   'ci_lower': 0.4854405666227425,
#   'ci_upper': 0.8287290729072907},
#  'Thyroid_Disorders': {'auc': 0.7578147487191296,
#   'n_events': 145,
#   'event_rate': 5.706414797323888,
#   'ci_lower': 0.7132706368154451,
#   'ci_upper': 0.7973075459341864}}

# %%
plot_theta_differences(model, diseases=[112,67,127,10,17,114], signatures=[5,7,0,17,19,5])
