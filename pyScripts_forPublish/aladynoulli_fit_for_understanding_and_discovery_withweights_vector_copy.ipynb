# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess
from clust_huge_amp import *
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning, module="sklearn.utils.extmath")

# %% [markdown]
# ## Aladynoulli retrospective
#
# Here we show the ability of the model to estatime when having access to all data for signature and genomic discovery, heterogeneity characterization, and cohort similarity.

# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix_corrected.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/3629226493.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/3629226493.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix_corrected.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/3629226493.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/3629226493.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
import pandas as pd
pids=pd.read_csv('/Users/sarahurbut/aladynoulli2/pyScripts/csv/processed_ids.csv')['eid'].values

# %%
# Test reading the file
import pandas as pd
df = pd.read_csv('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/UKBWeights-main/UKBSelectionWeights.csv', sep='\s+', engine='python')
print(df.head())
print(df.columns)
print(df.shape)
# Out:
#        f.eid  LassoWeight
# 0  1482136.0     0.400256
# 1  4261840.0     0.746818
# 2  1021212.0     0.526333
# 3  3857942.0     0.411219
# 4  3868072.0     0.517283
# Index(['f.eid', 'LassoWeight'], dtype='object')
# (469553, 2)

# %%
import pandas as pd
import numpy as np
import torch
from weighted_aladyn_vec import * 
from weightedprev import *
# Config
N_Y = 400000  # set to the number of rows of Y (the slice of pids that corresponds to Y)
idx_start, idx_end = 0, 10000

# 1) Load covariates (must include f.eid, sex, and optional PC columns)
covariates_path = '/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/baselinagefamh_withpcs.csv'
cov_df = pd.read_csv(covariates_path)

# Define column names present in your file
sex_col = 'sex'  # adjust if different (e.g., 'f.31.0.0' or similar)
pc_columns = [
    'f.22009.0.1','f.22009.0.2','f.22009.0.3','f.22009.0.4','f.22009.0.5',
    'f.22009.0.6','f.22009.0.7','f.22009.0.8','f.22009.0.9','f.22009.0.10'
]
use_pcs = True  # toggle if you do/don't want PCs

# 2) Build mapping from f.eid -> covariates
cov_df = cov_df[['identifier', sex_col] + (pc_columns if use_pcs else [])].dropna(subset=['identifier'])
cov_df = cov_df.drop_duplicates(subset=['identifier'])
cov_map = cov_df.set_index('identifier')

# 3) Create covariate arrays aligned to pids[:N_Y]
pids_y = pids[:N_Y]
sex_aligned = np.zeros(N_Y, dtype=float)
if use_pcs:
    pcs_aligned = np.zeros((N_Y, len(pc_columns)), dtype=float)

matched_cov = 0
for i, pid in enumerate(pids_y):
    if pid in cov_map.index:
        sex_aligned[i] = cov_map.at[pid, sex_col]
        if use_pcs:
            pcs_aligned[i, :] = cov_map.loc[pid, pc_columns].values
        matched_cov += 1
    else:
        # leave zeros if missing; you can choose an imputation if preferred
        pass

print(f"Covariates matched: {matched_cov} / {N_Y} ({matched_cov*100.0/N_Y:.1f}%)")

# 4) Subset Y/E/G and covariates to the same indices
Y_10k, E_10k, G_10k, indices = subset_data(Y, E, G, start_index=idx_start, end_index=idx_end)
sex_10k = sex_aligned[idx_start:idx_end].reshape(-1, 1)
if use_pcs:
    pcs_10k = pcs_aligned[idx_start:idx_end, :]

# 5) Combine G with covariates
if use_pcs:
    G_with_covs_10k = np.column_stack([G_10k, sex_10k, pcs_10k])
else:
    G_with_covs_10k = np.column_stack([G_10k, sex_10k])

print(f"G_with_covs_10k shape: {G_with_covs_10k.shape}")

# 6) Prepare weights aligned and subset to the same individuals
matched_weights, match_mask = match_weights_to_ids(df, pids[:N_Y])
weights_10k = matched_weights[idx_start:idx_end].copy()
num_unmatched_in_10k = int((weights_10k == 0).sum())
if num_unmatched_in_10k > 0:
    print(f"Warning: {num_unmatched_in_10k} of {idx_end - idx_start} had no matched weight; setting weight=1.0.")
    weights_10k[weights_10k == 0] = 1.0
# Out:
# Covariates matched: 400000 / 400000 (100.0%)
# G_with_covs_10k shape: (10000, 47)
# Matching weights to IDs...
#   Weights available: 469553
#   Processed IDs: 400000
#   Matched: 376505 (94.1%)
#   Unmatched: 23495
# Warning: 587 of 10000 had no matched weight; setting weight=1.0.

# %%
# Load references (signatures only, no healthy)
refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/reference_trajectories.pt')
signature_refs = refs['signature_refs']
prevalence_t=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/prevalence_t_corrected.pt')
# When initializing the model:
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/1363122406.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/reference_trajectories.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/1363122406.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prevalence_t=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/prevalence_t_corrected.pt')

# %%
# 7) Build weighted model using the augmented G
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest_weighted(
    N=Y_10k.shape[0],
    D=Y_10k.shape[1],
    T=Y_10k.shape[2],
    K=20,
    P=G_with_covs_10k.shape[1],
    G=G_with_covs_10k,
    Y=Y_10k,
    W=1e-4,
    R=0,
    prevalence_t=prevalence_t,
    signature_references=signature_refs,
    healthy_reference=True,
    disease_names=essentials['disease_names'],
    init_sd_scaler=1e-1,
    genetic_scale=1.0,
    learn_kappa=True,
    weights=weights_10k
)

# Optional: initialize with stored psi/clusters (ensure shapes match K)
initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
print(f"Clusters match exactly: {np.array_equal(initial_clusters, model.clusters)}")
# Out:
# ============================================================
# INVERSE PROBABILITY WEIGHTING ENABLED
# ============================================================
# Weight statistics:
#   Mean: 1.000
#   Std: 1.065
#   Min: 0.185
#   Max: 7.238
#
# Effective sample size: 4684 out of 10000
# Efficiency: 46.8%
# ============================================================
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:104: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:121: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/3594816515.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/3594816515.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
# Clusters match exactly: True

# %% [markdown]
# # you can see that we use the full unmodified E matrix here

# %%
E_10k
# Out:
# tensor([[51, 51, 51,  ..., 51, 51, 51],
#         [29, 29, 29,  ..., 29, 29, 29],
#         [51, 51, 51,  ..., 51, 51, 51],
#         ...,
#         [43, 43, 43,  ..., 43, 43, 43],
#         [42, 42, 42,  ..., 42, 42, 42],
#         [32, 32, 32,  ..., 32, 32, 32]])

# %%
## now we will run the model with the full data and sex specific
import cProfile
import pstats
from pstats import SortKey
# 5. Train on FULL data
profiler = cProfile.Profile()
profiler.enable()

history_new = model.fit(E_10k, num_epochs=200, learning_rate=1e-1, lambda_reg=1e-2)
profiler.disable()
stats = pstats.Stats(profiler).sort_stats(SortKey.CUMULATIVE)
stats.print_stats(20)
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:253: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 65.4321
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.71):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=30.91):
#   Theta for diagnosed: 0.151 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.10):
#   Theta for diagnosed: 0.082 ± 0.018
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=29.62):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=29.31):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 1
# Loss: 707.3859
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.69):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.03):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.11):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=29.74):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=29.36):
#   Theta for diagnosed: 0.069 ± 0.014
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 2
# Loss: 117.2718
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.66):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.13):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.13):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=29.83):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=29.38):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 3
# Loss: 211.0344
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.65):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.22):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.15):
#   Theta for diagnosed: 0.082 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=29.92):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=29.41):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 4
# Loss: 422.4929
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.66):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.29):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.19):
#   Theta for diagnosed: 0.082 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=30.02):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=29.46):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 5
# Loss: 330.8416
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.68):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.35):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.23):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=30.13):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=29.51):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 6
# Loss: 148.3230
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.70):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.40):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.27):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=30.25):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=29.56):
#   Theta for diagnosed: 0.069 ± 0.014
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 7
# Loss: 80.5292
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.72):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.43):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=30.38):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.30):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=29.62):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Epoch 8
# Loss: 149.8645
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.73):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.44):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=30.52):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.33):
#   Theta for diagnosed: 0.082 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=29.77):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 9
# Loss: 229.2119
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.73):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.44):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=30.66):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.36):
#   Theta for diagnosed: 0.082 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=30.02):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 10
# Loss: 219.1389
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.73):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.41):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=30.80):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.38):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=30.27):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 11
# Loss: 143.6316
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.73):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.36):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=30.95):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.51):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 321 (signature 1, LR=30.41):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Epoch 12
# Loss: 81.4307
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.72):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 161 (signature 7, LR=31.28):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=31.09):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=30.75):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 321 (signature 1, LR=30.44):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Epoch 13
# Loss: 79.7730
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.72):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 336 (signature 9, LR=31.23):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 161 (signature 7, LR=31.18):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 33 (signature 17, LR=30.98):
#   Theta for diagnosed: 0.088 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 321 (signature 1, LR=30.47):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Epoch 14
# Loss: 120.8343
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.72):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 336 (signature 9, LR=31.36):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.19):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 161 (signature 7, LR=31.06):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.49):
#   Theta for diagnosed: 0.082 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Epoch 15
# Loss: 150.6855
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.73):
#   Theta for diagnosed: 0.008 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 336 (signature 9, LR=31.50):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.40):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 161 (signature 7, LR=30.93):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.51):
#   Theta for diagnosed: 0.083 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Epoch 16
# Loss: 138.5126
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.75):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: -0.000
#
# Disease 336 (signature 9, LR=31.63):
#   Theta for diagnosed: 0.030 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.59):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 161 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.53):
#   Theta for diagnosed: 0.083 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Epoch 17
# Loss: 100.0495
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.76):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.77):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=31.77):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 161 (signature 7, LR=30.60):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.54):
#   Theta for diagnosed: 0.083 ± 0.016
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Epoch 18
# Loss: 71.5722
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.77):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.94):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=31.90):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.55):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=30.42):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Epoch 19
# Loss: 73.2666
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.78):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.09):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=32.05):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.55):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.27):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Epoch 20
# Loss: 94.1969
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.79):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.24):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=32.19):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.55):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=30.32):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Epoch 21
# Loss: 107.8303
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.79):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.37):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=32.34):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.55):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=30.37):
#   Theta for diagnosed: 0.070 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Epoch 22
# Loss: 100.0709
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.79):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.49):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=32.48):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 321 (signature 1, LR=30.55):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=30.42):
#   Theta for diagnosed: 0.070 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Epoch 23
# Loss: 80.0321
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.79):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 336 (signature 9, LR=32.63):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.59):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.54):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=30.46):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Epoch 24
# Loss: 66.7186
#
# Monitoring signature responses:
#
# Disease 241 (signature 12, LR=32.79):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 336 (signature 9, LR=32.78):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.68):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.53):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=30.50):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Epoch 25
# Loss: 69.4212
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=32.92):
#   Theta for diagnosed: 0.031 ± 0.004
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 241 (signature 12, LR=32.80):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.74):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.54):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 321 (signature 1, LR=30.52):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 26
# Loss: 80.5820
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.07):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 241 (signature 12, LR=32.81):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.79):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.58):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.50):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 27
# Loss: 85.9319
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.22):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.82):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=32.82):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=30.62):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.48):
#   Theta for diagnosed: 0.083 ± 0.017
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 28
# Loss: 79.7108
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.36):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.83):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=32.83):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=30.66):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.46):
#   Theta for diagnosed: 0.083 ± 0.018
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 29
# Loss: 68.7862
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.51):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 241 (signature 12, LR=32.84):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.83):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.70):
#   Theta for diagnosed: 0.070 ± 0.019
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.43):
#   Theta for diagnosed: 0.083 ± 0.018
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 30
# Loss: 63.5598
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.65):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 241 (signature 12, LR=32.85):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.81):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.74):
#   Theta for diagnosed: 0.070 ± 0.019
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.40):
#   Theta for diagnosed: 0.083 ± 0.018
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 31
# Loss: 67.0155
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.80):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 241 (signature 12, LR=32.86):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.78):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.77):
#   Theta for diagnosed: 0.070 ± 0.020
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.37):
#   Theta for diagnosed: 0.083 ± 0.018
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 32
# Loss: 72.9249
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=33.94):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.86):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.73):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.81):
#   Theta for diagnosed: 0.070 ± 0.020
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.33):
#   Theta for diagnosed: 0.084 ± 0.018
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 33
# Loss: 73.7435
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.09):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.86):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.67):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.84):
#   Theta for diagnosed: 0.071 ± 0.020
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.29):
#   Theta for diagnosed: 0.084 ± 0.018
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 34
# Loss: 68.6401
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.23):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.87):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.60):
#   Theta for diagnosed: 0.089 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.87):
#   Theta for diagnosed: 0.071 ± 0.021
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.25):
#   Theta for diagnosed: 0.084 ± 0.019
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 35
# Loss: 63.1750
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.38):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.87):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.52):
#   Theta for diagnosed: 0.089 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.90):
#   Theta for diagnosed: 0.071 ± 0.021
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.21):
#   Theta for diagnosed: 0.084 ± 0.019
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 36
# Loss: 62.3676
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.53):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.88):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.42):
#   Theta for diagnosed: 0.089 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.93):
#   Theta for diagnosed: 0.071 ± 0.022
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 321 (signature 1, LR=30.16):
#   Theta for diagnosed: 0.084 ± 0.019
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 37
# Loss: 65.4775
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.68):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.89):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.32):
#   Theta for diagnosed: 0.089 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=30.95):
#   Theta for diagnosed: 0.071 ± 0.022
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Disease 321 (signature 1, LR=30.11):
#   Theta for diagnosed: 0.084 ± 0.019
#   Theta for others: 0.079
#   Proportion difference: 0.004
#
# Epoch 38
# Loss: 67.7529
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.82):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.90):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.20):
#   Theta for diagnosed: 0.089 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=30.97):
#   Theta for diagnosed: 0.071 ± 0.023
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=30.14):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Epoch 39
# Loss: 66.2606
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=34.97):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.91):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=32.08):
#   Theta for diagnosed: 0.089 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=31.00):
#   Theta for diagnosed: 0.071 ± 0.023
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=30.36):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Epoch 40
# Loss: 62.7757
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.12):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.92):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.94):
#   Theta for diagnosed: 0.089 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=31.02):
#   Theta for diagnosed: 0.071 ± 0.024
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=30.59):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Epoch 41
# Loss: 61.0037
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.27):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.92):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.80):
#   Theta for diagnosed: 0.089 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=31.04):
#   Theta for diagnosed: 0.071 ± 0.024
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=30.82):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Epoch 42
# Loss: 62.1250
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.42):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.93):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.66):
#   Theta for diagnosed: 0.089 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=31.06):
#   Theta for diagnosed: 0.071 ± 0.025
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=31.05):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Epoch 43
# Loss: 63.8888
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.57):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.94):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 33 (signature 17, LR=31.51):
#   Theta for diagnosed: 0.090 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=31.28):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=31.09):
#   Theta for diagnosed: 0.072 ± 0.025
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Epoch 44
# Loss: 63.7508
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.72):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.94):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 249 (signature 13, LR=31.51):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=31.35):
#   Theta for diagnosed: 0.090 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=31.10):
#   Theta for diagnosed: 0.072 ± 0.026
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Epoch 45
# Loss: 61.8427
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=35.87):
#   Theta for diagnosed: 0.031 ± 0.007
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.95):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 249 (signature 13, LR=31.74):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=31.20):
#   Theta for diagnosed: 0.090 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 186 (signature 2, LR=31.12):
#   Theta for diagnosed: 0.072 ± 0.026
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Epoch 46
# Loss: 60.3558
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.02):
#   Theta for diagnosed: 0.031 ± 0.007
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.96):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 249 (signature 13, LR=31.98):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=31.14):
#   Theta for diagnosed: 0.072 ± 0.027
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Disease 33 (signature 17, LR=31.04):
#   Theta for diagnosed: 0.090 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Epoch 47
# Loss: 60.6283
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.17):
#   Theta for diagnosed: 0.031 ± 0.007
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.97):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 249 (signature 13, LR=32.21):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=31.15):
#   Theta for diagnosed: 0.072 ± 0.027
#   Theta for others: 0.067
#   Proportion difference: 0.005
#
# Disease 33 (signature 17, LR=30.87):
#   Theta for diagnosed: 0.090 ± 0.023
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Epoch 48
# Loss: 61.7105
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.32):
#   Theta for diagnosed: 0.031 ± 0.007
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.98):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 249 (signature 13, LR=32.45):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=31.16):
#   Theta for diagnosed: 0.072 ± 0.028
#   Theta for others: 0.067
#   Proportion difference: 0.005
#
# Disease 33 (signature 17, LR=30.71):
#   Theta for diagnosed: 0.090 ± 0.023
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Epoch 49
# Loss: 61.8815
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.48):
#   Theta for diagnosed: 0.031 ± 0.008
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=32.99):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 249 (signature 13, LR=32.69):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=31.18):
#   Theta for diagnosed: 0.072 ± 0.028
#   Theta for others: 0.067
#   Proportion difference: 0.005
#
# Disease 131 (signature 0, LR=30.71):
#   Theta for diagnosed: 0.029 ± 0.023
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 50
# Loss: 60.8456
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.63):
#   Theta for diagnosed: 0.031 ± 0.008
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 241 (signature 12, LR=33.00):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 249 (signature 13, LR=32.92):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 186 (signature 2, LR=31.19):
#   Theta for diagnosed: 0.072 ± 0.029
#   Theta for others: 0.067
#   Proportion difference: 0.005
#
# Disease 131 (signature 0, LR=30.78):
#   Theta for diagnosed: 0.029 ± 0.023
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 51
# Loss: 59.8426
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.79):
#   Theta for diagnosed: 0.031 ± 0.008
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=33.16):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.00):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=31.20):
#   Theta for diagnosed: 0.073 ± 0.029
#   Theta for others: 0.067
#   Proportion difference: 0.005
#
# Disease 131 (signature 0, LR=30.85):
#   Theta for diagnosed: 0.030 ± 0.023
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 52
# Loss: 59.8691
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=36.95):
#   Theta for diagnosed: 0.031 ± 0.008
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=33.40):
#   Theta for diagnosed: 0.026 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.01):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=31.22):
#   Theta for diagnosed: 0.073 ± 0.030
#   Theta for others: 0.067
#   Proportion difference: 0.005
#
# Disease 131 (signature 0, LR=30.91):
#   Theta for diagnosed: 0.030 ± 0.023
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 53
# Loss: 60.4921
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=37.11):
#   Theta for diagnosed: 0.031 ± 0.009
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=33.65):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.02):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=31.23):
#   Theta for diagnosed: 0.073 ± 0.030
#   Theta for others: 0.067
#   Proportion difference: 0.005
#
# Disease 131 (signature 0, LR=30.98):
#   Theta for diagnosed: 0.030 ± 0.023
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 54
# Loss: 60.6304
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=37.27):
#   Theta for diagnosed: 0.031 ± 0.009
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=33.89):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.03):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.009
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=31.24):
#   Theta for diagnosed: 0.073 ± 0.031
#   Theta for others: 0.067
#   Proportion difference: 0.005
#
# Disease 131 (signature 0, LR=31.05):
#   Theta for diagnosed: 0.030 ± 0.023
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 55
# Loss: 60.0191
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=37.43):
#   Theta for diagnosed: 0.031 ± 0.009
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=34.14):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.04):
#   Theta for diagnosed: 0.009 ± 0.002
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=31.25):
#   Theta for diagnosed: 0.073 ± 0.031
#   Theta for others: 0.067
#   Proportion difference: 0.006
#
# Disease 131 (signature 0, LR=31.11):
#   Theta for diagnosed: 0.030 ± 0.024
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 56
# Loss: 59.4008
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=37.59):
#   Theta for diagnosed: 0.031 ± 0.010
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=34.39):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.05):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=31.26):
#   Theta for diagnosed: 0.073 ± 0.032
#   Theta for others: 0.067
#   Proportion difference: 0.006
#
# Disease 131 (signature 0, LR=31.18):
#   Theta for diagnosed: 0.030 ± 0.024
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 57
# Loss: 59.4054
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=37.76):
#   Theta for diagnosed: 0.031 ± 0.010
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=34.64):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.06):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 186 (signature 2, LR=31.27):
#   Theta for diagnosed: 0.073 ± 0.032
#   Theta for others: 0.067
#   Proportion difference: 0.006
#
# Disease 131 (signature 0, LR=31.24):
#   Theta for diagnosed: 0.030 ± 0.024
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 58
# Loss: 59.7611
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=37.92):
#   Theta for diagnosed: 0.031 ± 0.010
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=34.89):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.07):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 231 (signature 19, LR=31.33):
#   Theta for diagnosed: 0.046 ± 0.009
#   Theta for others: 0.046
#   Proportion difference: 0.000
#
# Disease 131 (signature 0, LR=31.31):
#   Theta for diagnosed: 0.030 ± 0.024
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 59
# Loss: 59.8006
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=38.09):
#   Theta for diagnosed: 0.031 ± 0.011
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=35.15):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.08):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 231 (signature 19, LR=31.44):
#   Theta for diagnosed: 0.046 ± 0.009
#   Theta for others: 0.046
#   Proportion difference: 0.000
#
# Disease 131 (signature 0, LR=31.37):
#   Theta for diagnosed: 0.030 ± 0.024
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 60
# Loss: 59.3985
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=38.26):
#   Theta for diagnosed: 0.031 ± 0.011
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=35.40):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.09):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 231 (signature 19, LR=31.54):
#   Theta for diagnosed: 0.046 ± 0.009
#   Theta for others: 0.046
#   Proportion difference: 0.000
#
# Disease 131 (signature 0, LR=31.43):
#   Theta for diagnosed: 0.030 ± 0.024
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 61
# Loss: 59.0404
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=38.43):
#   Theta for diagnosed: 0.031 ± 0.011
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=35.66):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.10):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 231 (signature 19, LR=31.65):
#   Theta for diagnosed: 0.046 ± 0.009
#   Theta for others: 0.046
#   Proportion difference: 0.000
#
# Disease 131 (signature 0, LR=31.50):
#   Theta for diagnosed: 0.030 ± 0.024
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 62
# Loss: 59.0742
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=38.60):
#   Theta for diagnosed: 0.031 ± 0.012
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=35.92):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.003
#
# Disease 241 (signature 12, LR=33.11):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 231 (signature 19, LR=31.75):
#   Theta for diagnosed: 0.046 ± 0.009
#   Theta for others: 0.046
#   Proportion difference: 0.000
#
# Disease 131 (signature 0, LR=31.56):
#   Theta for diagnosed: 0.030 ± 0.024
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 63
# Loss: 59.2697
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=38.77):
#   Theta for diagnosed: 0.031 ± 0.012
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=36.18):
#   Theta for diagnosed: 0.026 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 241 (signature 12, LR=33.12):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 231 (signature 19, LR=31.86):
#   Theta for diagnosed: 0.046 ± 0.009
#   Theta for others: 0.046
#   Proportion difference: 0.000
#
# Disease 131 (signature 0, LR=31.62):
#   Theta for diagnosed: 0.030 ± 0.025
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 64
# Loss: 59.2273
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=38.95):
#   Theta for diagnosed: 0.032 ± 0.012
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=36.45):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 241 (signature 12, LR=33.13):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 231 (signature 19, LR=31.96):
#   Theta for diagnosed: 0.046 ± 0.009
#   Theta for others: 0.046
#   Proportion difference: 0.000
#
# Disease 131 (signature 0, LR=31.68):
#   Theta for diagnosed: 0.030 ± 0.025
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 65
# Loss: 58.9472
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=39.13):
#   Theta for diagnosed: 0.032 ± 0.013
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Disease 249 (signature 13, LR=36.72):
#   Theta for diagnosed: 0.027 ± 0.008
#   Theta for others: 0.023
#   Proportion difference: 0.004
#
# Disease 241 (signature 12, LR=33.14):
#   Theta for diagnosed: 0.009 ± 0.003
#   Theta for others: 0.008
#   Proportion difference: 0.000
#
# Disease 231 (signature 19, LR=32.06):
#   Theta for diagnosed: 0.046 ± 0.009
#   Theta for others: 0.046
#   Proportion difference: 0.000
#
# Disease 131 (signature 0, LR=31.75):
#   Theta for diagnosed: 0.030 ± 0.025
#   Theta for others: 0.028
#   Proportion difference: 0.002
#
# Epoch 66
# Loss: 58.7585
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=39.30):
#   Theta for diagnosed: 0.032 ± 0.013
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# ...
#   Theta for diagnosed: 0.039 ± 0.052
#   Theta for others: 0.030
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=65.13):
#   Theta for diagnosed: 0.030 ± 0.040
#   Theta for others: 0.024
#   Proportion difference: 0.006
#
# Disease 127 (signature 0, LR=57.90):
#   Theta for diagnosed: 0.036 ± 0.044
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 182
# Loss: 55.3196
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=83.44):
#   Theta for diagnosed: 0.017 ± 0.017
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=74.14):
#   Theta for diagnosed: 0.031 ± 0.028
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=68.28):
#   Theta for diagnosed: 0.039 ± 0.052
#   Theta for others: 0.030
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=65.58):
#   Theta for diagnosed: 0.030 ± 0.040
#   Theta for others: 0.024
#   Proportion difference: 0.006
#
# Disease 127 (signature 0, LR=58.19):
#   Theta for diagnosed: 0.036 ± 0.044
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 183
# Loss: 55.2960
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=84.16):
#   Theta for diagnosed: 0.017 ± 0.017
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=74.41):
#   Theta for diagnosed: 0.031 ± 0.029
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=68.54):
#   Theta for diagnosed: 0.039 ± 0.052
#   Theta for others: 0.030
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=66.03):
#   Theta for diagnosed: 0.030 ± 0.041
#   Theta for others: 0.024
#   Proportion difference: 0.006
#
# Disease 127 (signature 0, LR=58.49):
#   Theta for diagnosed: 0.036 ± 0.045
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 184
# Loss: 55.2724
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=84.88):
#   Theta for diagnosed: 0.017 ± 0.017
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=74.68):
#   Theta for diagnosed: 0.031 ± 0.029
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=68.81):
#   Theta for diagnosed: 0.039 ± 0.053
#   Theta for others: 0.030
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=66.48):
#   Theta for diagnosed: 0.030 ± 0.041
#   Theta for others: 0.024
#   Proportion difference: 0.006
#
# Disease 127 (signature 0, LR=58.78):
#   Theta for diagnosed: 0.036 ± 0.045
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 185
# Loss: 55.2488
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=85.62):
#   Theta for diagnosed: 0.017 ± 0.017
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=74.95):
#   Theta for diagnosed: 0.031 ± 0.029
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=69.07):
#   Theta for diagnosed: 0.039 ± 0.053
#   Theta for others: 0.030
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=66.93):
#   Theta for diagnosed: 0.030 ± 0.041
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=59.07):
#   Theta for diagnosed: 0.036 ± 0.045
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 186
# Loss: 55.2253
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=86.35):
#   Theta for diagnosed: 0.017 ± 0.017
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=75.22):
#   Theta for diagnosed: 0.031 ± 0.029
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=69.33):
#   Theta for diagnosed: 0.039 ± 0.053
#   Theta for others: 0.030
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=67.39):
#   Theta for diagnosed: 0.030 ± 0.041
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=59.37):
#   Theta for diagnosed: 0.036 ± 0.045
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Epoch 187
# Loss: 55.2020
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=87.09):
#   Theta for diagnosed: 0.017 ± 0.017
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=75.49):
#   Theta for diagnosed: 0.031 ± 0.030
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=69.59):
#   Theta for diagnosed: 0.039 ± 0.054
#   Theta for others: 0.030
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=67.84):
#   Theta for diagnosed: 0.030 ± 0.042
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=59.66):
#   Theta for diagnosed: 0.036 ± 0.046
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 188
# Loss: 55.1786
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=87.84):
#   Theta for diagnosed: 0.017 ± 0.017
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=75.75):
#   Theta for diagnosed: 0.031 ± 0.030
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=69.86):
#   Theta for diagnosed: 0.040 ± 0.054
#   Theta for others: 0.030
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=68.30):
#   Theta for diagnosed: 0.030 ± 0.042
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=59.96):
#   Theta for diagnosed: 0.036 ± 0.046
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 189
# Loss: 55.1552
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=88.59):
#   Theta for diagnosed: 0.017 ± 0.017
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=76.02):
#   Theta for diagnosed: 0.031 ± 0.030
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=70.12):
#   Theta for diagnosed: 0.040 ± 0.054
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 70 (signature 14, LR=68.76):
#   Theta for diagnosed: 0.031 ± 0.042
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=60.26):
#   Theta for diagnosed: 0.036 ± 0.046
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 190
# Loss: 55.1319
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=89.35):
#   Theta for diagnosed: 0.017 ± 0.018
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=76.28):
#   Theta for diagnosed: 0.031 ± 0.030
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=70.38):
#   Theta for diagnosed: 0.040 ± 0.054
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 70 (signature 14, LR=69.22):
#   Theta for diagnosed: 0.031 ± 0.042
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=60.55):
#   Theta for diagnosed: 0.036 ± 0.046
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 191
# Loss: 55.1088
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=90.11):
#   Theta for diagnosed: 0.017 ± 0.018
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=76.54):
#   Theta for diagnosed: 0.031 ± 0.031
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=70.64):
#   Theta for diagnosed: 0.040 ± 0.055
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 70 (signature 14, LR=69.68):
#   Theta for diagnosed: 0.031 ± 0.042
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=60.85):
#   Theta for diagnosed: 0.036 ± 0.047
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 192
# Loss: 55.0857
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=90.87):
#   Theta for diagnosed: 0.017 ± 0.018
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=76.81):
#   Theta for diagnosed: 0.031 ± 0.031
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=70.90):
#   Theta for diagnosed: 0.040 ± 0.055
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 70 (signature 14, LR=70.15):
#   Theta for diagnosed: 0.031 ± 0.043
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=61.15):
#   Theta for diagnosed: 0.036 ± 0.047
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 193
# Loss: 55.0625
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=91.64):
#   Theta for diagnosed: 0.018 ± 0.018
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=77.07):
#   Theta for diagnosed: 0.031 ± 0.031
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=71.16):
#   Theta for diagnosed: 0.040 ± 0.055
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 70 (signature 14, LR=70.61):
#   Theta for diagnosed: 0.031 ± 0.043
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=61.44):
#   Theta for diagnosed: 0.036 ± 0.047
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 194
# Loss: 55.0394
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=92.42):
#   Theta for diagnosed: 0.018 ± 0.018
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=77.33):
#   Theta for diagnosed: 0.032 ± 0.031
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=71.42):
#   Theta for diagnosed: 0.040 ± 0.056
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 70 (signature 14, LR=71.08):
#   Theta for diagnosed: 0.031 ± 0.043
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=61.74):
#   Theta for diagnosed: 0.036 ± 0.047
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 195
# Loss: 55.0165
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=93.20):
#   Theta for diagnosed: 0.018 ± 0.018
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=77.59):
#   Theta for diagnosed: 0.032 ± 0.032
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 336 (signature 9, LR=71.68):
#   Theta for diagnosed: 0.040 ± 0.056
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 70 (signature 14, LR=71.54):
#   Theta for diagnosed: 0.031 ± 0.043
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 127 (signature 0, LR=62.04):
#   Theta for diagnosed: 0.036 ± 0.048
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 196
# Loss: 54.9936
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=93.98):
#   Theta for diagnosed: 0.018 ± 0.018
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=77.85):
#   Theta for diagnosed: 0.032 ± 0.032
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=72.01):
#   Theta for diagnosed: 0.031 ± 0.044
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 336 (signature 9, LR=71.93):
#   Theta for diagnosed: 0.040 ± 0.056
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 127 (signature 0, LR=62.34):
#   Theta for diagnosed: 0.037 ± 0.048
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 197
# Loss: 54.9708
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=94.77):
#   Theta for diagnosed: 0.018 ± 0.018
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=78.11):
#   Theta for diagnosed: 0.032 ± 0.032
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=72.48):
#   Theta for diagnosed: 0.031 ± 0.044
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 336 (signature 9, LR=72.19):
#   Theta for diagnosed: 0.040 ± 0.056
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 127 (signature 0, LR=62.64):
#   Theta for diagnosed: 0.037 ± 0.048
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 198
# Loss: 54.9482
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=95.57):
#   Theta for diagnosed: 0.018 ± 0.019
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=78.37):
#   Theta for diagnosed: 0.032 ± 0.032
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=72.95):
#   Theta for diagnosed: 0.031 ± 0.044
#   Theta for others: 0.024
#   Proportion difference: 0.007
#
# Disease 336 (signature 9, LR=72.45):
#   Theta for diagnosed: 0.040 ± 0.057
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 127 (signature 0, LR=62.94):
#   Theta for diagnosed: 0.037 ± 0.048
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Epoch 199
# Loss: 54.9255
#
# Monitoring signature responses:
#
# Disease 47 (signature 15, LR=96.36):
#   Theta for diagnosed: 0.018 ± 0.019
#   Theta for others: 0.014
#   Proportion difference: 0.004
#
# Disease 249 (signature 13, LR=78.63):
#   Theta for diagnosed: 0.032 ± 0.033
#   Theta for others: 0.023
#   Proportion difference: 0.009
#
# Disease 70 (signature 14, LR=73.42):
#   Theta for diagnosed: 0.031 ± 0.044
#   Theta for others: 0.024
#   Proportion difference: 0.008
#
# Disease 336 (signature 9, LR=72.71):
#   Theta for diagnosed: 0.040 ± 0.057
#   Theta for others: 0.030
#   Proportion difference: 0.010
#
# Disease 127 (signature 0, LR=63.24):
#   Theta for diagnosed: 0.037 ± 0.049
#   Theta for others: 0.027
#   Proportion difference: 0.009
#          1854648 function calls (1833537 primitive calls) in 468.446 seconds
#
#    Ordered by: cumulative time
#    List reduced from 4186 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000  468.446  234.223 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#    1885/2    0.031    0.000  468.446  234.223 {built-in method builtins.exec}
#         1    0.001    0.001  468.446  468.446 /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/185814452.py:9(<module>)
#         1    9.080    9.080  468.445  468.445 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:381(fit)
#       200  159.738    0.799  243.777    1.219 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:241(compute_loss)
#       200    0.002    0.000  184.590    0.923 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:525(backward)
#       200    0.002    0.000  184.589    0.923 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#       200    0.002    0.000  184.578    0.923 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/graph.py:816(_engine_run_backward)
#       200  184.576    0.923  184.576    0.923 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       400   10.656    0.027   53.173    0.133 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:233(forward)
#       400    0.005    0.000   29.623    0.074 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/functional.py:210(einsum)
#       400   29.615    0.074   29.615    0.074 {built-in method torch.einsum}
#       200    1.145    0.006   29.015    0.145 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:419(analyze_signature_responses)
#       600   24.749    0.041   24.749    0.041 {built-in method torch.log}
#       600   17.506    0.029   17.506    0.029 {built-in method torch.clamp}
#       600    0.003    0.000   12.086    0.020 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:33(wrapped)
#       600    0.003    0.000   12.082    0.020 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:1026(__rsub__)
#       600   12.080    0.020   12.080    0.020 {built-in method torch.rsub}
#       400    8.024    0.020    8.024    0.020 {method 'float' of 'torch._C.TensorBase' objects}
#       200    1.480    0.007    4.678    0.023 /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:317(compute_gp_prior_loss)

# %%
from utils import *
plot_training_evolution(history_new)

# %%
# Save model
W=0.0001
torch.save({
    'model_state_dict': model.state_dict(),
    'phi': model.phi,
    'Y': model.Y,
    'prevalence_t': model.prevalence_t,
    'logit_prevalence_t': model.logit_prev_t,
    'G': model.G,
}, f'/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_model_W{W}_fulldata_sexspecific_withpcs_and_weights_vec_correctedE.pt')

# %%
plot_theta_differences(model, diseases=[112,67,127,10,17,114], signatures=[5,7,0,17,19,5])

# %%
W = 0.0001  # or whatever W value you used
model_old = torch.load(f'/Users/sarahurbut/Library/CloudStorage/Dropbox/censor_e_batchrun_vectorized/enrollment_model_W0.0001_batch_0_10000.pt')
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/2294348496.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_old = torch.load(f'/Users/sarahurbut/Library/CloudStorage/Dropbox/censor_e_batchrun_vectorized/enrollment_model_W0.0001_batch_0_10000.pt')

# %%
# Compare phi values between weighted and unweighted models
old_phi = model_old['phi']
new_phi = model.phi

print("=== PHI COMPARISON ===")
print(f"Old phi shape: {old_phi.shape}")
print(f"New phi shape: {new_phi.shape}")

# Basic statistics
print(f"\nOld phi stats:")
print(f"  Mean: {old_phi.mean():.4f}")
print(f"  Std: {old_phi.std():.4f}")
print(f"  Range: [{old_phi.min():.4f}, {old_phi.max():.4f}]")

print(f"\nNew phi stats:")
print(f"  Mean: {new_phi.mean():.4f}")
print(f"  Std: {new_phi.std():.4f}")
print(f"  Range: [{new_phi.min():.4f}, {new_phi.max():.4f}]")

# Difference analysis
phi_diff = new_phi - old_phi
print(f"\nDifference (new - old):")
print(f"  Mean diff: {phi_diff.mean():.4f}")
print(f"  Std diff: {phi_diff.std():.4f}")
print(f"  Range: [{phi_diff.min():.4f}, {phi_diff.max():.4f}]")

# Correlation
phi_corr = torch.corrcoef(torch.stack([old_phi.flatten(), new_phi.flatten()]))[0,1]
print(f"\nCorrelation between old and new phi: {phi_corr:.4f}")

# Per-signature comparison
print(f"\nPer-signature mean differences:")
for k in range(min(old_phi.shape[0], new_phi.shape[0])):
    sig_diff = (new_phi[k] - old_phi[k]).mean()
    print(f"  Signature {k}: {sig_diff:.4f}")

# Per-disease comparison  
print(f"\nPer-disease mean differences:")
for d in range(min(old_phi.shape[1], new_phi.shape[1])):
    dis_diff = (new_phi[:,d] - old_phi[:,d]).mean()
    print(f"  Disease {d}: {dis_diff:.4f}")
# Out:
# === PHI COMPARISON ===
# Old phi shape: torch.Size([21, 348, 52])
# New phi shape: torch.Size([21, 348, 52])
#
# Old phi stats:
#   Mean: -10.9056
#   Std: 2.5700
#   Range: [-22.8308, -1.7358]
#
# New phi stats:
#   Mean: -10.9025
#   Std: 2.5708
#   Range: [-22.7053, -1.9921]
#
# Difference (new - old):
#   Mean diff: 0.0031
#   Std diff: 0.1457
#   Range: [-1.0149, 1.5892]
#
# Correlation between old and new phi: 0.9984
#
# Per-signature mean differences:
#   Signature 0: 0.0045
#   Signature 1: 0.0086
#   Signature 2: 0.0002
#   Signature 3: 0.0007
#   Signature 4: 0.0058
#   Signature 5: 0.0110
#   Signature 6: -0.0081
#   Signature 7: 0.0068
#   Signature 8: 0.0029
#   Signature 9: 0.0066
#   Signature 10: -0.0032
#   Signature 11: 0.0031
#   Signature 12: 0.0042
#   Signature 13: -0.0015
#   Signature 14: 0.0126
#   Signature 15: -0.0044
#   Signature 16: 0.0118
#   Signature 17: -0.0105
#   Signature 18: 0.0083
#   Signature 19: 0.0019
#   Signature 20: 0.0036
#
# Per-disease mean differences:
#   Disease 0: -0.0195
#   Disease 1: -0.0154
#   Disease 2: -0.0556
#   Disease 3: 0.0240
#   Disease 4: -0.0013
#   Disease 5: -0.0155
#   Disease 6: -0.0012
#   Disease 7: 0.0278
#   Disease 8: 0.0141
#   Disease 9: 0.0278
#   Disease 10: -0.0384
#   Disease 11: -0.0241
#   Disease 12: 0.0004
#   Disease 13: 0.0259
#   Disease 14: 0.0365
#   Disease 15: -0.0243
#   Disease 16: 0.0387
#   Disease 17: 0.0116
#   Disease 18: -0.0350
#   Disease 19: -0.0171
#   Disease 20: 0.0104
#   Disease 21: 0.0068
#   Disease 22: 0.0158
#   Disease 23: 0.0071
#   Disease 24: 0.0078
#   Disease 25: -0.0222
#   Disease 26: -0.0075
#   Disease 27: 0.0125
#   Disease 28: 0.0093
#   Disease 29: 0.0045
#   Disease 30: 0.0293
#   Disease 31: 0.0233
#   Disease 32: 0.0071
#   Disease 33: -0.0021
#   Disease 34: -0.0094
#   Disease 35: 0.0041
#   Disease 36: -0.0025
#   Disease 37: 0.0556
#   Disease 38: 0.0073
#   Disease 39: 0.0134
#   Disease 40: 0.0055
#   Disease 41: 0.0163
#   Disease 42: -0.0196
#   Disease 43: -0.0062
#   Disease 44: 0.0052
#   Disease 45: -0.0069
#   Disease 46: 0.0155
#   Disease 47: 0.0345
#   Disease 48: 0.0281
#   Disease 49: 0.0087
#   Disease 50: -0.0028
#   Disease 51: 0.0176
#   Disease 52: -0.0038
#   Disease 53: -0.0417
#   Disease 54: 0.0112
#   Disease 55: -0.0035
#   Disease 56: -0.0040
#   Disease 57: 0.0124
#   Disease 58: 0.0690
#   Disease 59: -0.0101
#   Disease 60: -0.0098
#   Disease 61: 0.0605
#   Disease 62: 0.0249
#   Disease 63: -0.0117
#   Disease 64: -0.0139
#   Disease 65: -0.0063
#   Disease 66: -0.0009
#   Disease 67: 0.0541
#   Disease 68: -0.0051
#   Disease 69: 0.0086
#   Disease 70: 0.0376
#   Disease 71: -0.0445
#   Disease 72: 0.0037
#   Disease 73: -0.0054
#   Disease 74: 0.0330
#   Disease 75: -0.0018
#   Disease 76: 0.0305
#   Disease 77: 0.0368
#   Disease 78: 0.0181
#   Disease 79: -0.0239
#   Disease 80: -0.0022
#   Disease 81: 0.0299
#   Disease 82: -0.0002
#   Disease 83: -0.0329
#   Disease 84: 0.0104
#   Disease 85: -0.0162
#   Disease 86: -0.0067
#   Disease 87: 0.0249
#   Disease 88: 0.0323
#   Disease 89: 0.0085
#   Disease 90: -0.0251
#   Disease 91: 0.0275
#   Disease 92: -0.0141
#   Disease 93: -0.0477
#   Disease 94: -0.0001
#   Disease 95: 0.0153
#   Disease 96: -0.0003
#   Disease 97: -0.0209
#   Disease 98: 0.0103
#   Disease 99: 0.0028
#   Disease 100: 0.0103
#   Disease 101: 0.0241
#   Disease 102: -0.0222
#   Disease 103: 0.0157
#   Disease 104: 0.0417
#   Disease 105: 0.0130
#   Disease 106: -0.0448
#   Disease 107: 0.0072
#   Disease 108: -0.0055
#   Disease 109: 0.0305
#   Disease 110: 0.0443
#   Disease 111: -0.0258
#   Disease 112: 0.0006
#   Disease 113: 0.0353
#   Disease 114: 0.0141
#   Disease 115: 0.0064
#   Disease 116: 0.0098
#   Disease 117: 0.0068
#   Disease 118: -0.0389
#   Disease 119: -0.0154
#   Disease 120: -0.0074
#   Disease 121: 0.0130
#   Disease 122: 0.0078
#   Disease 123: -0.0230
#   Disease 124: 0.0314
#   Disease 125: -0.0243
#   Disease 126: 0.0097
#   Disease 127: -0.0252
#   Disease 128: 0.0351
#   Disease 129: 0.0266
#   Disease 130: 0.0092
#   Disease 131: 0.0289
#   Disease 132: 0.0232
#   Disease 133: 0.0228
#   Disease 134: 0.0319
#   Disease 135: -0.0140
#   Disease 136: 0.0136
#   Disease 137: 0.0190
#   Disease 138: 0.0014
#   Disease 139: -0.0467
#   Disease 140: -0.0014
#   Disease 141: 0.0329
#   Disease 142: -0.0221
#   Disease 143: 0.0403
#   Disease 144: -0.0550
#   Disease 145: -0.0246
#   Disease 146: -0.0098
#   Disease 147: 0.0145
#   Disease 148: -0.0366
#   Disease 149: 0.0164
#   Disease 150: 0.0148
#   Disease 151: 0.0201
#   Disease 152: -0.0168
#   Disease 153: 0.0459
#   Disease 154: 0.0168
#   Disease 155: 0.0010
#   Disease 156: 0.0056
#   Disease 157: -0.0057
#   Disease 158: -0.0087
#   Disease 159: -0.0039
#   Disease 160: -0.0243
#   Disease 161: 0.0505
#   Disease 162: 0.0271
#   Disease 163: 0.0152
#   Disease 164: 0.0195
#   Disease 165: -0.0091
#   Disease 166: 0.0035
#   Disease 167: -0.0025
#   Disease 168: 0.0128
#   Disease 169: -0.0261
#   Disease 170: 0.0183
#   Disease 171: -0.0050
#   Disease 172: -0.0390
#   Disease 173: -0.0042
#   Disease 174: -0.0164
#   Disease 175: 0.0019
#   Disease 176: -0.0020
#   Disease 177: 0.0008
#   Disease 178: 0.0068
#   Disease 179: 0.0093
#   Disease 180: -0.0178
#   Disease 181: 0.0090
#   Disease 182: -0.0112
#   Disease 183: 0.0159
#   Disease 184: -0.0013
#   Disease 185: 0.0107
#   Disease 186: -0.0586
#   Disease 187: -0.0077
#   Disease 188: -0.0146
#   Disease 189: -0.0077
#   Disease 190: 0.0174
#   Disease 191: -0.0269
#   Disease 192: -0.0169
#   Disease 193: 0.0149
#   Disease 194: 0.0046
#   Disease 195: 0.0070
#   Disease 196: -0.0169
#   Disease 197: -0.0188
#   Disease 198: 0.0483
#   Disease 199: -0.0123
#   Disease 200: -0.0067
#   Disease 201: 0.0256
#   Disease 202: 0.0414
#   Disease 203: -0.0269
#   Disease 204: -0.0197
#   Disease 205: -0.0282
#   Disease 206: 0.0168
#   Disease 207: 0.0206
#   Disease 208: 0.0230
#   Disease 209: -0.0073
#   Disease 210: -0.0334
#   Disease 211: 0.0073
#   Disease 212: 0.0341
#   Disease 213: -0.0139
#   Disease 214: 0.0377
#   Disease 215: 0.0265
#   Disease 216: -0.0026
#   Disease 217: 0.0384
#   Disease 218: -0.0104
#   Disease 219: 0.0717
#   Disease 220: 0.0104
#   Disease 221: 0.0023
#   Disease 222: 0.0089
#   Disease 223: 0.0121
#   Disease 224: -0.0059
#   Disease 225: -0.0261
#   Disease 226: -0.0340
#   Disease 227: 0.0484
#   Disease 228: 0.0075
#   Disease 229: -0.0564
#   Disease 230: 0.0309
#   Disease 231: -0.0088
#   Disease 232: -0.0457
#   Disease 233: 0.0062
#   Disease 234: -0.0122
#   Disease 235: 0.0024
#   Disease 236: 0.0334
#   Disease 237: -0.0071
#   Disease 238: 0.0261
#   Disease 239: -0.0452
#   Disease 240: -0.0292
#   Disease 241: 0.0268
#   Disease 242: -0.0058
#   Disease 243: -0.0074
#   Disease 244: -0.0163
#   Disease 245: 0.0073
#   Disease 246: 0.0295
#   Disease 247: 0.0010
#   Disease 248: 0.0061
#   Disease 249: -0.0291
#   Disease 250: -0.0176
#   Disease 251: -0.0313
#   Disease 252: 0.0220
#   Disease 253: 0.0161
#   Disease 254: 0.0054
#   Disease 255: 0.0195
#   Disease 256: -0.0041
#   Disease 257: 0.0239
#   Disease 258: 0.0087
#   Disease 259: 0.0661
#   Disease 260: 0.0076
#   Disease 261: -0.0106
#   Disease 262: -0.0239
#   Disease 263: -0.0061
#   Disease 264: -0.0216
#   Disease 265: 0.0117
#   Disease 266: 0.0001
#   Disease 267: 0.0233
#   Disease 268: -0.0178
#   Disease 269: -0.0078
#   Disease 270: -0.0349
#   Disease 271: -0.0056
#   Disease 272: -0.0217
#   Disease 273: -0.0264
#   Disease 274: 0.0272
#   Disease 275: -0.0015
#   Disease 276: 0.0076
#   Disease 277: -0.0198
#   Disease 278: -0.0124
#   Disease 279: -0.0017
#   Disease 280: -0.0114
#   Disease 281: -0.0469
#   Disease 282: 0.0240
#   Disease 283: 0.0151
#   Disease 284: 0.0304
#   Disease 285: -0.0165
#   Disease 286: -0.0289
#   Disease 287: 0.0188
#   Disease 288: 0.0322
#   Disease 289: -0.0067
#   Disease 290: 0.0241
#   Disease 291: -0.0275
#   Disease 292: 0.0181
#   Disease 293: -0.0092
#   Disease 294: 0.0541
#   Disease 295: -0.0159
#   Disease 296: 0.0489
#   Disease 297: 0.0018
#   Disease 298: 0.0209
#   Disease 299: 0.0124
#   Disease 300: 0.0001
#   Disease 301: -0.0144
#   Disease 302: 0.0287
#   Disease 303: -0.0109
#   Disease 304: -0.0419
#   Disease 305: 0.0661
#   Disease 306: 0.0239
#   Disease 307: -0.0016
#   Disease 308: 0.0062
#   Disease 309: -0.0046
#   Disease 310: 0.0039
#   Disease 311: 0.0072
#   Disease 312: -0.0166
#   Disease 313: -0.0316
#   Disease 314: 0.0304
#   Disease 315: 0.0041
#   Disease 316: 0.0050
#   Disease 317: -0.0091
#   Disease 318: -0.0464
#   Disease 319: -0.0320
#   Disease 320: 0.0158
#   Disease 321: -0.0012
#   Disease 322: -0.0156
#   Disease 323: 0.0028
#   Disease 324: -0.0002
#   Disease 325: -0.0069
#   Disease 326: -0.0232
#   Disease 327: 0.0030
#   Disease 328: -0.0011
#   Disease 329: 0.0048
#   Disease 330: -0.0123
#   Disease 331: 0.0451
#   Disease 332: 0.0355
#   Disease 333: 0.0114
#   Disease 334: 0.0247
#   Disease 335: 0.0052
#   Disease 336: 0.0140
#   Disease 337: -0.0202
#   Disease 338: 0.0238
#   Disease 339: 0.0092
#   Disease 340: -0.0102
#   Disease 341: 0.0088
#   Disease 342: 0.0170
#   Disease 343: 0.0325
#   Disease 344: 0.0541
#   Disease 345: 0.0076
#   Disease 346: -0.0259
#   Disease 347: 0.0184

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot phi comparison
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# 1. Scatter plot: old vs new phi
axes[0,0].scatter(old_phi.detach().numpy().flatten(), new_phi.detach().numpy().flatten(), alpha=0.5)
axes[0,0].plot([old_phi.detach().min(), old_phi.detach().max()], [old_phi.detach().min(), old_phi.detach().max()], 'r--', alpha=0.7)
axes[0,0].set_xlabel('Old phi')
axes[0,0].set_ylabel('New phi')
axes[0,0].set_title('Old vs New phi')

# 2. Difference histogram
phi_diff = new_phi - old_phi
axes[0,1].hist(phi_diff.detach().numpy().flatten(), bins=50, alpha=0.7)
axes[0,1].axvline(0, color='red', linestyle='--')
axes[0,1].set_xlabel('Difference (new - old)')
axes[0,1].set_ylabel('Count')
axes[0,1].set_title('Distribution of phi differences')

# 3. Heatmap of differences by signature and disease (averaged across time)
diff_matrix = phi_diff.mean(dim=2).detach().numpy()  # Average across time dimension
im = axes[1,0].imshow(diff_matrix, aspect='auto', cmap='RdBu_r')
axes[1,0].set_xlabel('Disease')
axes[1,0].set_ylabel('Signature')
axes[1,0].set_title('Phi differences (new - old, avg across time)')
plt.colorbar(im, ax=axes[1,0])

# 4. Mean difference per signature (average across both diseases and time)
sig_means = phi_diff.mean(dim=(1,2)).detach().numpy()  # Average across diseases AND time
axes[1,1].bar(range(len(sig_means)), sig_means)
axes[1,1].axhline(0, color='red', linestyle='--')
axes[1,1].set_xlabel('Signature')
axes[1,1].set_ylabel('Mean difference')
axes[1,1].set_title('Mean phi difference per signature')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot phi trajectories for specific diseases
diseases_to_plot = [112, 57, 19]
fig, axes = plt.subplots(1, len(diseases_to_plot), figsize=(15, 5))

for i, d in enumerate(diseases_to_plot):
    ax = axes[i] if len(diseases_to_plot) > 1 else axes
    
    # Plot phi trajectories for all signatures for this disease
    for k in range(old_phi.shape[0]):  # All signatures
        old_traj = old_phi[k, d, :].detach().numpy()
        new_traj = new_phi[k, d, :].detach().numpy()
        
        ax.plot(old_traj, alpha=0.7, linestyle='-', label=f'Sig {k} (old)' if i == 0 else "")
        ax.plot(new_traj, alpha=0.7, linestyle='--', label=f'Sig {k} (new)' if i == 0 else "")
    
    ax.set_xlabel('Time')
    ax.set_ylabel('Phi value')
    ax.set_title(f'Disease {d} - Phi trajectories')
    ax.grid(True, alpha=0.3)
    
    if i == 0:
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/284196259.py:26: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Find signature/disease combinations with largest differences
phi_diff = new_phi - old_phi

# Get absolute differences
abs_diff = torch.abs(phi_diff)

# Find maximum difference across all dimensions
max_diff_val, max_indices = torch.max(abs_diff.view(-1), dim=0)
max_idx = max_indices.item()

# Convert flat index back to 3D coordinates
k_max, d_max, t_max = np.unravel_index(max_idx, phi_diff.shape)

print(f"Largest absolute difference: {max_diff_val:.4f}")
print(f"Location: Signature {k_max}, Disease {d_max}, Time {t_max}")
print(f"Old value: {old_phi[k_max, d_max, t_max]:.4f}")
print(f"New value: {new_phi[k_max, d_max, t_max]:.4f}")
print(f"Difference: {phi_diff[k_max, d_max, t_max]:.4f}")

# Top 10 largest differences
print(f"\nTop 10 largest absolute differences:")
flat_diff = abs_diff.view(-1)
top_10_vals, top_10_indices = torch.topk(flat_diff, 10)

for i, (val, idx) in enumerate(zip(top_10_vals, top_10_indices)):
    k, d, t = np.unravel_index(idx.item(), phi_diff.shape)
    actual_diff = phi_diff[k, d, t].item()
    print(f"{i+1:2d}. Sig {k:2d}, Dis {d:3d}, Time {t:2d}: {actual_diff:+.4f} (abs: {val:.4f})")

# Per-signature maximum differences
print(f"\nMaximum difference per signature:")
for k in range(phi_diff.shape[0]):
    sig_max = torch.max(abs_diff[k]).item()
    sig_max_idx = torch.argmax(abs_diff[k]).item()
    d_max_sig, t_max_sig = np.unravel_index(sig_max_idx, phi_diff[k].shape)
    actual_diff_sig = phi_diff[k, d_max_sig, t_max_sig].item()
    print(f"Signature {k:2d}: {actual_diff_sig:+.4f} at Disease {d_max_sig:3d}, Time {t_max_sig:2d}")
# Out:
# Largest absolute difference: 1.5892
# Location: Signature 15, Disease 46, Time 0
# Old value: -9.8347
# New value: -8.2455
# Difference: 1.5892
#
# Top 10 largest absolute differences:
#  1. Sig 15, Dis  46, Time  0: +1.5892 (abs: 1.5892)
#  2. Sig 15, Dis  46, Time  1: +1.2463 (abs: 1.2463)
#  3. Sig  0, Dis 119, Time 24: +1.1209 (abs: 1.1209)
#  4. Sig  0, Dis 119, Time 23: +1.1118 (abs: 1.1118)
#  5. Sig  0, Dis 119, Time 25: +1.1026 (abs: 1.1026)
#  6. Sig  0, Dis 119, Time 22: +1.0827 (abs: 1.0827)
#  7. Sig  0, Dis 119, Time 26: +1.0525 (abs: 1.0525)
#  8. Sig  3, Dis 267, Time  0: +1.0364 (abs: 1.0364)
#  9. Sig 16, Dis 204, Time 11: +1.0332 (abs: 1.0332)
# 10. Sig 18, Dis 210, Time  0: +1.0321 (abs: 1.0321)
#
# Maximum difference per signature:
# Signature  0: +1.1209 at Disease 119, Time 24
# Signature  1: +0.8408 at Disease 334, Time 12
# Signature  2: +0.9246 at Disease 191, Time 11
# Signature  3: +1.0364 at Disease 267, Time  0
# Signature  4: +0.7244 at Disease 150, Time  9
# Signature  5: +1.0042 at Disease 115, Time 15
# Signature  6: -1.0149 at Disease  24, Time 51
# Signature  7: +0.9818 at Disease  70, Time 23
# Signature  8: +0.5490 at Disease 283, Time 46
# Signature  9: +0.8586 at Disease 306, Time 11
# Signature 10: -0.9955 at Disease  87, Time 51
# Signature 11: -0.6084 at Disease 138, Time 51
# Signature 12: +0.7851 at Disease 241, Time  6
# Signature 13: +0.7220 at Disease 249, Time 22
# Signature 14: +1.0191 at Disease  70, Time 19
# Signature 15: +1.5892 at Disease  46, Time  0
# Signature 16: +1.0332 at Disease 204, Time 11
# Signature 17: +0.6714 at Disease 208, Time 19
# Signature 18: +1.0321 at Disease 210, Time  0
# Signature 19: -0.8688 at Disease 291, Time 42
# Signature 20: +0.6103 at Disease 305, Time  7

# %%
# Convert phi differences to prevalence differences
old_prev = torch.sigmoid(old_phi)
new_prev = torch.sigmoid(new_phi)
prev_diff = new_prev - old_prev

print("=== PREVALENCE SCALE COMPARISON ===")
print(f"Old prevalence stats:")
print(f"  Mean: {old_prev.mean():.6f}")
print(f"  Range: [{old_prev.min():.6f}, {old_prev.max():.6f}]")

print(f"\nNew prevalence stats:")
print(f"  Mean: {new_prev.mean():.6f}")
print(f"  Range: [{new_prev.min():.6f}, {new_prev.max():.6f}]")

print(f"\nPrevalence differences (new - old):")
print(f"  Mean diff: {prev_diff.mean():.6f}")
print(f"  Std diff: {prev_diff.std():.6f}")
print(f"  Range: [{prev_diff.min():.6f}, {prev_diff.max():.6f}]")

# Find largest prevalence differences
abs_prev_diff = torch.abs(prev_diff)
max_prev_diff_val, max_prev_idx = torch.max(abs_prev_diff.view(-1), dim=0)
k_max, d_max, t_max = np.unravel_index(max_prev_idx.item(), prev_diff.shape)

print(f"\nLargest prevalence difference: {max_prev_diff_val:.6f}")
print(f"Location: Signature {k_max}, Disease {d_max}, Time {t_max}")
print(f"Old prevalence: {old_prev[k_max, d_max, t_max]:.6f}")
print(f"New prevalence: {new_prev[k_max, d_max, t_max]:.6f}")
print(f"Relative change: {100 * prev_diff[k_max, d_max, t_max] / old_prev[k_max, d_max, t_max]:.2f}%")
# Out:
# === PREVALENCE SCALE COMPARISON ===
# Old prevalence stats:
#   Mean: 0.000214
#   Range: [0.000000, 0.149852]
#
# New prevalence stats:
#   Mean: 0.000210
#   Range: [0.000000, 0.120039]
#
# Prevalence differences (new - old):
#   Mean diff: -0.000003
#   Std diff: 0.000367
#   Range: [-0.050168, 0.017157]
#
# Largest prevalence difference: 0.050168
# Location: Signature 15, Disease 47, Time 51
# Old prevalence: 0.102721
# New prevalence: 0.052554
# Relative change: -48.84%

# %%
disease_names=pd.read_csv('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/disease_names.csv')['x'].values

# %%
import pandas as pd
import numpy as np
import torch
from weighted_aladyn_vec import AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest_weighted, subset_data

# Config
N_Y = 400000  # rows of Y corresponding to pids[:N_Y]
batch_size = 10000
n_batches = 10

# Load covariates
covariates_path = '/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/baselinagefamh_withpcs.csv'
cov_df = pd.read_csv(covariates_path)

sex_col = 'sex'
pc_columns = [
    'f.22009.0.1','f.22009.0.2','f.22009.0.3','f.22009.0.4','f.22009.0.5',
    'f.22009.0.6','f.22009.0.7','f.22009.0.8','f.22009.0.9','f.22009.0.10'
]
use_pcs = True

# Build covariate mapping
cov_df = cov_df[['identifier', sex_col] + (pc_columns if use_pcs else [])].dropna(subset=['identifier'])
cov_df = cov_df.drop_duplicates(subset=['identifier'])
cov_map = cov_df.set_index('identifier')

# Match weights to all pids[:N_Y]
matched_weights, match_mask = match_weights_to_ids(df, pids[:N_Y])

# Run batches
results = []
for batch_idx in range(n_batches):
    print(f"\n{'='*60}")
    print(f"BATCH {batch_idx + 1}/{n_batches}")
    print(f"{'='*60}")
    
    # Calculate batch indices
    idx_start = batch_idx * batch_size
    idx_end = min((batch_idx + 1) * batch_size, N_Y)
    
    print(f"Processing individuals {idx_start} to {idx_end-1}")
    
    # Subset data
    Y_batch, E_batch, G_batch, indices = subset_data(Y, E, G, start_index=idx_start, end_index=idx_end)
    
    # Subset covariates
    pids_batch = pids[idx_start:idx_end]
    sex_batch = np.zeros(len(pids_batch), dtype=float)
    if use_pcs:
        pcs_batch = np.zeros((len(pids_batch), len(pc_columns)), dtype=float)
    
    matched_cov_batch = 0
    for i, pid in enumerate(pids_batch):
        if pid in cov_map.index:
            sex_batch[i] = cov_map.at[pid, sex_col]
            if use_pcs:
                pcs_batch[i, :] = cov_map.loc[pid, pc_columns].values
            matched_cov_batch += 1
    
    print(f"Covariates matched: {matched_cov_batch} / {len(pids_batch)} ({matched_cov_batch*100.0/len(pids_batch):.1f}%)")
    
    # Combine G with covariates
    sex_batch = sex_batch.reshape(-1, 1)
    if use_pcs:
        G_with_covs_batch = np.column_stack([G_batch, sex_batch, pcs_batch])
    else:
        G_with_covs_batch = np.column_stack([G_batch, sex_batch])
    
    # Subset weights
    weights_batch = matched_weights[idx_start:idx_end].copy()
    num_unmatched = int((weights_batch == 0).sum())
    if num_unmatched > 0:
        print(f"Warning: {num_unmatched} had no matched weight; setting weight=1.0.")
        weights_batch[weights_batch == 0] = 1.0
    
    print(f"Weight stats: mean={weights_batch.mean():.3f}, std={weights_batch.std():.3f}")
    
    # Build model
    model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest_weighted(
        N=Y_batch.shape[0],
        D=Y_batch.shape[1],
        T=Y_batch.shape[2],
        K=20,
        P=G_with_covs_batch.shape[1],
        G=G_with_covs_batch,
        Y=Y_batch,
        W=1e-4,
        R=0,
        prevalence_t=prevalence_t,
        signature_references=signature_refs,
        healthy_reference=True,
        disease_names=essentials['disease_names'],
        init_sd_scaler=1e-1,
        genetic_scale=1.0,
        learn_kappa=True,
        weights=weights_batch
    )
    
    # Initialize with stored psi/clusters
    initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
    initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')
    model.initialize_params(true_psi=initial_psi)
    model.clusters = initial_clusters
    
    # Train
    print("Training...")
    losses, grads = model.fit(event_times=E_batch, num_epochs=200, learning_rate=1e-1, lambda_reg=1e-2)
    
    # Store results
    results.append({
        'batch_idx': batch_idx,
        'model': model,
        'losses': losses,
        'weights_stats': {
            'mean': weights_batch.mean(),
            'std': weights_batch.std(),
            'min': weights_batch.min(),
            'max': weights_batch.max()
        },
        'final_loss': losses[-1] if losses else None
    })
    
    print(f"Batch {batch_idx + 1} complete. Final loss: {losses[-1]:.4f}")

print(f"\n{'='*60}")
print(f"ALL {n_batches} BATCHES COMPLETE")
print(f"{'='*60}")
# Out:
# Matching weights to IDs...
#   Weights available: 469553
#   Processed IDs: 400000
#   Matched: 376505 (94.1%)
#   Unmatched: 23495
#
# ============================================================
# BATCH 1/10
# ============================================================
# Processing individuals 0 to 9999
# Covariates matched: 10000 / 10000 (100.0%)
# Warning: 587 had no matched weight; setting weight=1.0.
# Weight stats: mean=0.916, std=0.976
#
# ============================================================
# INVERSE PROBABILITY WEIGHTING ENABLED
# ============================================================
# Weight statistics:
#   Mean: 1.000
#   Std: 1.065
#   Min: 0.185
#   Max: 7.238
#
# Effective sample size: 4684 out of 10000
# Efficiency: 46.8%
# ============================================================
#
#
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:104: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:121: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/2697553852.py:100: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_3958/2697553852.py:101: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
# Training...
# /Users/sarahurbut/aladynoulli2/pyScripts_forPublish/weighted_aladyn_vec.py:253: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 65.4817
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=29.54):
#   Theta for diagnosed: 0.151 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=28.75):
#   Theta for diagnosed: 0.028 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 343 (signature 7, LR=28.56):
#   Theta for diagnosed: 0.150 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 149 (signature 3, LR=28.53):
#   Theta for diagnosed: 0.145 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.005
#
# Disease 15 (signature 19, LR=28.41):
#   Theta for diagnosed: 0.046 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Epoch 1
# Loss: 707.4340
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=29.72):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=28.90):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 343 (signature 7, LR=28.60):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=28.51):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 149 (signature 3, LR=28.51):
#   Theta for diagnosed: 0.146 ± 0.067
#   Theta for others: 0.150
#   Proportion difference: -0.005
#
# Epoch 2
# Loss: 117.3281
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=29.89):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 131 (signature 0, LR=29.04):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.000
#
# Disease 343 (signature 7, LR=28.63):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 15 (signature 19, LR=28.61):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=28.52):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.000
#
# Epoch 3
# Loss: 211.0840
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.04):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 131 (signature 0, LR=29.16):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.000
#
# Disease 15 (signature 19, LR=28.72):
#   Theta for diagnosed: 0.046 ± 0.008
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=28.72):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.000
#
# Disease 343 (signature 7, LR=28.67):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Epoch 4
# Loss: 422.5040
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.19):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 131 (signature 0, LR=29.30):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.000
#
# Disease 188 (signature 2, LR=28.91):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.000
#
# Disease 15 (signature 19, LR=28.84):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 343 (signature 7, LR=28.72):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Epoch 5
# Loss: 330.8618
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.34):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=29.44):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=29.11):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.000
#
# Disease 15 (signature 19, LR=28.97):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 343 (signature 7, LR=28.77):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Epoch 6
# Loss: 148.3719
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.47):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=29.58):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=29.31):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=29.09):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 343 (signature 7, LR=28.82):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Epoch 7
# Loss: 80.5910
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.58):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=29.73):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=29.50):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=29.20):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 343 (signature 7, LR=28.86):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Epoch 8
# Loss: 149.9052
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.67):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=29.89):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=29.70):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=29.32):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 343 (signature 7, LR=28.89):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Epoch 9
# Loss: 229.2186
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.74):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=30.06):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=29.90):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=29.43):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 343 (signature 7, LR=28.91):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Epoch 10
# Loss: 219.1318
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=30.21):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=30.10):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=29.54):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=28.99):
#   Theta for diagnosed: 0.087 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.001
#
# Epoch 11
# Loss: 143.6406
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=30.36):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=30.29):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=29.65):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.10):
#   Theta for diagnosed: 0.087 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.001
#
# Epoch 12
# Loss: 81.4660
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.76):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 131 (signature 0, LR=30.50):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=30.49):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=29.76):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.21):
#   Theta for diagnosed: 0.087 ± 0.017
#   Theta for others: 0.086
#   Proportion difference: 0.001
#
# Epoch 13
# Loss: 79.8163
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.71):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 188 (signature 2, LR=30.67):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=30.65):
#   Theta for diagnosed: 0.028 ± 0.020
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=29.87):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.31):
#   Theta for diagnosed: 0.087 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.001
#
# Epoch 14
# Loss: 120.8602
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=30.86):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=30.79):
#   Theta for diagnosed: 0.028 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.63):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 15 (signature 19, LR=29.97):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.41):
#   Theta for diagnosed: 0.087 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.001
#
# Epoch 15
# Loss: 150.6880
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=31.04):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=30.94):
#   Theta for diagnosed: 0.028 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.53):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 15 (signature 19, LR=30.07):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.50):
#   Theta for diagnosed: 0.087 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.001
#
# Epoch 16
# Loss: 138.5073
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=31.22):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=31.08):
#   Theta for diagnosed: 0.028 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.42):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 15 (signature 19, LR=30.17):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.59):
#   Theta for diagnosed: 0.087 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.001
#
# Epoch 17
# Loss: 100.0536
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=31.39):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=31.23):
#   Theta for diagnosed: 0.028 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.28):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 15 (signature 19, LR=30.26):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.66):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 18
# Loss: 71.5891
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=31.55):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=31.37):
#   Theta for diagnosed: 0.028 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.34):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.13):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=29.76):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Epoch 19
# Loss: 73.2860
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=31.71):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=31.52):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.43):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=29.96):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=29.90):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Epoch 20
# Loss: 94.2059
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=31.86):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=31.65):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.51):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.04):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=29.86):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 21
# Loss: 107.8268
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.01):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=31.79):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.58):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.17):
#   Theta for diagnosed: 0.063 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=29.92):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 22
# Loss: 100.0643
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.14):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=31.91):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.65):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.30):
#   Theta for diagnosed: 0.063 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=29.96):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 23
# Loss: 80.0328
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.28):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=32.04):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.71):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.42):
#   Theta for diagnosed: 0.063 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=30.01):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 24
# Loss: 66.7277
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.40):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=32.16):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.77):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.53):
#   Theta for diagnosed: 0.063 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=30.04):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 25
# Loss: 69.4305
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.51):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=32.29):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.83):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.62):
#   Theta for diagnosed: 0.063 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=30.06):
#   Theta for diagnosed: 0.088 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 26
# Loss: 80.5837
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.61):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=32.41):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.87):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.71):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=30.07):
#   Theta for diagnosed: 0.088 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 27
# Loss: 85.9262
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.70):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=32.53):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.91):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.79):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=30.08):
#   Theta for diagnosed: 0.088 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 28
# Loss: 79.7036
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.78):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=32.65):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.94):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.86):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 225 (signature 17, LR=30.07):
#   Theta for diagnosed: 0.088 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 29
# Loss: 68.7823
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.85):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=32.76):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.97):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.92):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 225 (signature 17, LR=30.06):
#   Theta for diagnosed: 0.088 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 30
# Loss: 63.5596
#
# Monitoring signature responses:
#
# Disease 188 (signature 2, LR=32.91):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 131 (signature 0, LR=32.86):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 15 (signature 19, LR=30.99):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 114 (signature 5, LR=30.97):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 225 (signature 17, LR=30.04):
#   Theta for diagnosed: 0.088 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 31
# Loss: 67.0166
#
# Monitoring signature responses:
#
# Disease 131 (signature 0, LR=32.96):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=32.96):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=31.01):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 15 (signature 19, LR=31.00):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=30.02):
#   Theta for diagnosed: 0.088 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 32
# Loss: 72.9245
#
# Monitoring signature responses:
#
# Disease 131 (signature 0, LR=33.06):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=33.00):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=31.05):
#   Theta for diagnosed: 0.064 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 15 (signature 19, LR=31.01):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.99):
#   Theta for diagnosed: 0.088 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 33
# Loss: 73.7407
#
# Monitoring signature responses:
#
# Disease 131 (signature 0, LR=33.15):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=33.03):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=31.08):
#   Theta for diagnosed: 0.064 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 15 (signature 19, LR=31.02):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.95):
#   Theta for diagnosed: 0.088 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 34
# Loss: 68.6357
#
# Monitoring signature responses:
#
# Disease 131 (signature 0, LR=33.23):
#   Theta for diagnosed: 0.029 ± 0.021
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=33.06):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=31.09):
#   Theta for diagnosed: 0.064 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 15 (signature 19, LR=31.02):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 225 (signature 17, LR=29.91):
#   Theta for diagnosed: 0.089 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Epoch 35
# Loss: 63.1707
#
# Monitoring signature responses:
#
# Disease 131 (signature 0, LR=33.32):
#   Theta for diagnosed: 0.029 ± 0.022
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=33.07):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=31.10):
#   Theta for diagnosed: 0.064 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 15 (signature 19, LR=31.01):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=30.05):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 36
# Loss: 62.3646
#
# Monitoring signature responses:
#
# Disease 131 (signature 0, LR=33.40):
#   Theta for diagnosed: 0.029 ± 0.022
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=33.07):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=31.10):
#   Theta for diagnosed: 0.064 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 15 (signature 19, LR=31.00):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=30.21):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 37
# Loss: 65.4755
#
# Monitoring signature responses:
#
# Disease 131 (signature 0, LR=33.48):
#   Theta for diagnosed: 0.029 ± 0.022
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=33.07):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=31.09):
#   Theta for diagnosed: 0.064 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 15 (signature 19, LR=30.98):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=30.37):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 38
# Loss: 67.7509
#
# Monitoring signature responses:
#
# Disease 131 (signature 0, LR=33.56):
#   Theta for diagnosed: 0.029 ± 0.022
#   Theta for others: 0.028
#   Proportion difference: 0.001
#
# Disease 188 (signature 2, LR=33.05):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=31.07):
#   Theta for diagnosed: 0.064 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.018
#
# Disease 15 (signature 19, LR=30.95):
#   Theta for diagnosed: 0.046 ± 0.007
#   Theta for others: 0.046
#   Proportion difference: 0.001
#
# Disease 336 (signature 9, LR=30.53):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001

# %%
# POST-PROCESSING: Save models, plot losses, combine phis

import matplotlib.pyplot as plt
import numpy as np
import torch
import os

# Create output directory
output_dir = '/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/batch_models_weighted_vec_censoredE/'
os.makedirs(output_dir, exist_ok=True)

print(f"Processing {len(results)} batches from results object...")

# 1. SAVE EACH BATCH MODEL (without losses)
print("\n1. Saving batch models...")
for i, result in enumerate(results):
    batch_idx = result['batch_idx']
    model = result['model']
    
    # Save model state dict (without losses)
    model_filename = f"batch_{batch_idx:02d}_model.pt"
    model_path = os.path.join(output_dir, model_filename)
    
    torch.save({
        'model_state_dict': model.state_dict(),
        'batch_idx': batch_idx,
        'weights_stats': result['weights_stats'],
        'final_loss': result['final_loss']
    }, model_path)
    
    print(f"  Saved batch {batch_idx} to {model_path}")

# 2. PLOT LOSSES COMPARISON
print("\n2. Plotting losses comparison...")
plt.figure(figsize=(12, 8))

for i, result in enumerate(results):
    batch_idx = result['batch_idx']
    losses = result['losses']
    
    if losses:
        plt.plot(losses, label=f'Batch {batch_idx}', alpha=0.7, linewidth=1)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Losses by Batch')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save plot
plot_path = os.path.join(output_dir, 'batch_losses_comparison.png')
plt.savefig(plot_path, dpi=300, bbox_inches='tight')
plt.show()

print(f"Loss comparison plot saved to: {plot_path}")

# 3. COMBINE/AVERAGE PHIS FROM ALL BATCHES
print("\n3. Combining phis from all batches...")

# Get phi shape from first batch
first_model = results[0]['model']
phi_shape = first_model.phi.shape
print(f"Phi shape: {phi_shape}")

# Initialize combined phi
combined_phi = torch.zeros(phi_shape)

# Sum phis from all batches
for i, result in enumerate(results):
    batch_idx = result['batch_idx']
    model = result['model']
    phi = model.phi.detach()
    combined_phi += phi
    print(f"  Batch {batch_idx}: phi shape {phi.shape}")

# Average the phis
combined_phi /= len(results)

# Save combined phi
combined_phi_path = os.path.join(output_dir, 'combined_phi.pt')
torch.save({
    'phi': combined_phi,
    'num_batches': len(results),
    'phi_shape': phi_shape
}, combined_phi_path)

print(f"Combined phi saved to: {combined_phi_path}")
print(f"Combined phi shape: {combined_phi.shape}")
print(f"Combined phi stats: mean={combined_phi.mean():.4f}, std={combined_phi.std():.4f}")

# 4. PRINT SUMMARY STATISTICS
print(f"\n{'='*60}")
print(f"BATCH TRAINING SUMMARY")
print(f"{'='*60}")

# Calculate statistics
all_losses = [result['final_loss'] for result in results if result['final_loss'] is not None]
all_weight_means = [result['weights_stats']['mean'] for result in results]

print(f"Total batches: {len(results)}")
print(f"Batch size: {batch_size:,}")
print(f"Total patients: {len(results) * batch_size:,}")

print(f"\nFinal Loss Statistics:")
print(f"  Average: {np.mean(all_losses):.4f} ± {np.std(all_losses):.4f}")
print(f"  Min: {np.min(all_losses):.4f}")
print(f"  Max: {np.max(all_losses):.4f}")

print(f"\nWeight Statistics:")
print(f"  Average weight mean: {np.mean(all_weight_means):.3f} ± {np.std(all_weight_means):.3f}")
print(f"  Min weight mean: {np.min(all_weight_means):.3f}")
print(f"  Max weight mean: {np.max(all_weight_means):.3f}")

print(f"\nFiles created:")
print(f"  - {len(results)} batch model files")
print(f"  - batch_losses_comparison.png")
print(f"  - combined_phi.pt")

print(f"\n✅ All processing complete!")

# %%
# FIXED PHI COMPARISON: Detach tensors before plotting

import torch
import numpy as np
import matplotlib.pyplot as plt
import os

# Load the first 10 batches from the old model
old_model_dir = '/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_retrospective_full/'
print("=== LOADING OLD MODEL BATCHES ===")

old_phis = []
old_models = []

for batch_idx in range(10):
    model_path = os.path.join(old_model_dir, f'enrollment_model_W0.0001_batch_{batch_idx*10000}_{(batch_idx+1)*10000}.pt')
    
    if os.path.exists(model_path):
        print(f"Loading batch {batch_idx}: {model_path}")
        model = torch.load(model_path, map_location=torch.device('cpu'))
        old_phis.append(model['phi'].detach())  # Detach here
        old_models.append(model)
        print(f"  Phi shape: {model['phi'].shape}")
    else:
        print(f"⚠️  Batch {batch_idx} not found: {model_path}")

if len(old_phis) == 0:
    print("❌ No old model batches found!")
else:
    print(f"✅ Loaded {len(old_phis)} old model batches")
    
    # Combine phis from old models
    print("\n=== COMBINING OLD MODEL PHIS ===")
    phi_shape = old_phis[0].shape
    print(f"Phi shape: {phi_shape}")
    
    # Initialize combined old phi
    combined_old_phi = torch.zeros(phi_shape)
    
    # Sum phis from all old batches
    for i, phi in enumerate(old_phis):
        combined_old_phi += phi
        print(f"  Batch {i}: phi shape {phi.shape}")
    
    # Average the phis
    combined_old_phi /= len(old_phis)
    
    print(f"Combined old phi shape: {combined_old_phi.shape}")
    print(f"Combined old phi stats: mean={combined_old_phi.mean():.4f}, std={combined_old_phi.std():.4f}")

# Load combined phi from weighted training
print("\n=== LOADING WEIGHTED MODEL PHI ===")
combined_phi_path = '/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/batch_models_weighted/combined_phi.pt'
combined_phi_data = torch.load(combined_phi_path, map_location=torch.device('cpu'))
combined_weighted_phi = combined_phi_data['phi'].detach()  # Detach here

print(f"Combined weighted phi shape: {combined_weighted_phi.shape}")
print(f"Combined weighted phi stats: mean={combined_weighted_phi.mean():.4f}, std={combined_weighted_phi.std():.4f}")
print(f"Combined from {combined_phi_data['num_batches']} batches")

# Compare the two combined phis
print(f"\n=== FAIR PHI COMPARISON ===")
print(f"Old model: {len(old_phis)} batches combined")
print(f"Weighted model: {combined_phi_data['num_batches']} batches combined")

# Check if shapes match
if combined_old_phi.shape != combined_weighted_phi.shape:
    print(f"⚠️  WARNING: Phi shapes don't match!")
    print(f"  Old combined: {combined_old_phi.shape}")
    print(f"  Weighted combined: {combined_weighted_phi.shape}")
else:
    print("✅ Phi shapes match!")

# Calculate differences
phi_diff = combined_weighted_phi - combined_old_phi
phi_abs_diff = torch.abs(phi_diff)

print(f"\n=== PHI DIFFERENCE STATISTICS ===")
print(f"Mean difference: {phi_diff.mean():.6f}")
print(f"Std difference: {phi_diff.std():.6f}")
print(f"Max absolute difference: {phi_abs_diff.max():.6f}")
print(f"Mean absolute difference: {phi_abs_diff.mean():.6f}")

# Create visualization comparing the two combined phis
def plot_fair_phi_comparison(old_phi, weighted_phi, max_diseases=10):
    """
    Plot comparison of combined phi values
    """
    K, D, T = old_phi.shape
    
    # Take first few diseases for visualization
    n_diseases = min(max_diseases, D)
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('Fair Phi Comparison: Old (10 batches) vs Weighted (10 batches)', fontsize=16)
    
    # 1. Mean phi values across time for each disease
    ax1 = axes[0, 0]
    old_mean = old_phi[:, :n_diseases, :].mean(dim=2).detach().numpy()  # Detach and convert to numpy
    weighted_mean = weighted_phi[:, :n_diseases, :].mean(dim=2).detach().numpy()
    
    x_pos = np.arange(n_diseases)
    width = 0.35
    
    ax1.bar(x_pos - width/2, old_mean.mean(axis=0), width, label='Old (10 batches)', alpha=0.7)
    ax1.bar(x_pos + width/2, weighted_mean.mean(axis=0), width, label='Weighted (10 batches)', alpha=0.7)
    ax1.set_xlabel('Disease Index')
    ax1.set_ylabel('Mean Phi Value')
    ax1.set_title('Mean Phi Values by Disease')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # 2. Difference heatmap
    ax2 = axes[0, 1]
    phi_diff_subset = phi_diff[:, :n_diseases, :].mean(dim=2).detach().numpy()  # Detach and convert
    im = ax2.imshow(phi_diff_subset, aspect='auto', cmap='RdBu_r')
    ax2.set_xlabel('Disease Index')
    ax2.set_ylabel('Signature Index')
    ax2.set_title('Phi Differences (Weighted - Old)')
    plt.colorbar(im, ax=ax2)
    
    # 3. Distribution of differences
    ax3 = axes[1, 0]
    phi_diff_flat = phi_diff.flatten().detach().numpy()  # Detach and convert
    ax3.hist(phi_diff_flat, bins=50, alpha=0.7, edgecolor='black')
    ax3.set_xlabel('Phi Difference')
    ax3.set_ylabel('Frequency')
    ax3.set_title('Distribution of Phi Differences')
    ax3.grid(True, alpha=0.3)
    
    # 4. Absolute differences by signature
    ax4 = axes[1, 1]
    phi_abs_diff_mean = phi_abs_diff.mean(dim=(1, 2)).detach().numpy()  # Detach and convert
    ax4.bar(range(K), phi_abs_diff_mean, alpha=0.7)
    ax4.set_xlabel('Signature Index')
    ax4.set_ylabel('Mean Absolute Difference')
    ax4.set_title('Mean Absolute Difference by Signature')
    ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    
    # Save plot
    plot_path = '/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/batch_models_weighted/fair_phi_comparison.png'
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"Fair phi comparison plot saved to: {plot_path}")

# Create the fair comparison plot
if len(old_phis) > 0:
    plot_fair_phi_comparison(combined_old_phi, combined_weighted_phi)
    
    # Save fair comparison results
    fair_comparison_results = {
        'old_model_dir': old_model_dir,
        'weighted_model_path': combined_phi_path,
        'old_batches_combined': len(old_phis),
        'weighted_batches_combined': combined_phi_data['num_batches'],
        'phi_shapes_match': combined_old_phi.shape == combined_weighted_phi.shape,
        'mean_difference': phi_diff.mean().item(),
        'std_difference': phi_diff.std().item(),
        'max_absolute_difference': phi_abs_diff.max().item(),
        'mean_absolute_difference': phi_abs_diff.mean().item()
    }
    
    fair_comparison_path = '/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/batch_models_weighted/fair_phi_comparison_results.pt'
    torch.save(fair_comparison_results, fair_comparison_path)
    
    print(f"\n=== FAIR COMPARISON COMPLETE ===")
    print(f"Fair comparison results saved to: {fair_comparison_path}")
    print(f"Key findings:")
    print(f"  - Old model: {fair_comparison_results['old_batches_combined']} batches combined")
    print(f"  - Weighted model: {fair_comparison_results['weighted_batches_combined']} batches combined")
    print(f"  - Phi shapes match: {fair_comparison_results['phi_shapes_match']}")
    print(f"  - Mean difference: {fair_comparison_results['mean_difference']:.6f}")
    print(f"  - Max absolute difference: {fair_comparison_results['max_absolute_difference']:.6f}")
else:
    print("❌ Cannot perform fair comparison - no old model batches found!")

# %%
# SAMPLE DISEASE ANALYSIS: Compare old vs weighted phi for specific diseases

import matplotlib.pyplot as plt
import numpy as np

# Define sample diseases to analyze
sample_diseases = [112, 57, 19]  # You can change these to any disease indices you want
disease_names = ['Myocardial Infarction', 'Type 2 Diabetes', 'Essential Hypertension']  # Optional names

print("=== SAMPLE DISEASE PHI COMPARISON ===")
print(f"Analyzing diseases: {sample_diseases}")

# Calculate average phi across signatures for each disease
old_avg_phi = combined_old_phi.mean(dim=0)  # Average across signatures: shape (348, 52)
weighted_avg_phi = combined_weighted_phi.mean(dim=0)  # Average across signatures: shape (348, 52)

# 1. Plot averaged phi trajectories for sample diseases
fig, axes = plt.subplots(1, len(sample_diseases), figsize=(15, 5))
if len(sample_diseases) == 1:
    axes = [axes]

for i, disease_idx in enumerate(sample_diseases):
    ax = axes[i]
    
    # Get trajectories for this disease
    old_traj = old_avg_phi[disease_idx, :].detach().numpy()
    weighted_traj = weighted_avg_phi[disease_idx, :].detach().numpy()
    
    # Plot trajectories
    ax.plot(old_traj, label='Old (10 batches)', linewidth=2, alpha=0.8)
    ax.plot(weighted_traj, label='Weighted (10 batches)', linewidth=2, alpha=0.8, linestyle='--')
    
    ax.set_xlabel('Time')
    ax.set_ylabel('Average Phi Value')
    ax.set_title(f'Disease {disease_idx} - Average Phi Trajectory')
    ax.grid(True, alpha=0.3)
    ax.legend()
    
    # Add some statistics
    diff = np.abs(weighted_traj - old_traj)
    max_diff = np.max(diff)
    mean_diff = np.mean(diff)
    ax.text(0.02, 0.98, f'Max diff: {max_diff:.4f}\nMean diff: {mean_diff:.4f}', 
            transform=ax.transAxes, verticalalignment='top',
            bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

plt.tight_layout()
plt.show()

# 2. Scatter plot of all old vs weighted average phi values
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# Flatten all values for scatter plot
old_flat = old_avg_phi.detach().numpy().flatten()
weighted_flat = weighted_avg_phi.detach().numpy().flatten()

# Create scatter plot
ax.scatter(old_flat, weighted_flat, alpha=0.5, s=1)
ax.plot([old_flat.min(), old_flat.max()], [old_flat.min(), old_flat.max()], 'r--', alpha=0.7)

ax.set_xlabel('Old Average Phi')
ax.set_ylabel('Weighted Average Phi')
ax.set_title('Old vs Weighted Average Phi (All Diseases, All Time)')
ax.grid(True, alpha=0.3)

# Calculate correlation
correlation = np.corrcoef(old_flat, weighted_flat)[0, 1]
ax.text(0.05, 0.95, f'Correlation: {correlation:.6f}', transform=ax.transAxes, 
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

plt.tight_layout()
plt.show()

# 3. Focus on sample diseases scatter plot
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# Get values for sample diseases only
sample_old_values = []
sample_weighted_values = []

for disease_idx in sample_diseases:
    old_vals = old_avg_phi[disease_idx, :].detach().numpy()
    weighted_vals = weighted_avg_phi[disease_idx, :].detach().numpy()
    
    sample_old_values.extend(old_vals)
    sample_weighted_values.extend(weighted_vals)

sample_old_values = np.array(sample_old_values)
sample_weighted_values = np.array(sample_weighted_values)

# Create scatter plot for sample diseases
ax.scatter(sample_old_values, sample_weighted_values, alpha=0.7, s=20)
ax.plot([sample_old_values.min(), sample_old_values.max()], 
        [sample_old_values.min(), sample_old_values.max()], 'r--', alpha=0.7)

ax.set_xlabel('Old Average Phi')
ax.set_ylabel('Weighted Average Phi')
ax.set_title(f'Sample Diseases {sample_diseases} - Old vs Weighted Average Phi')
ax.grid(True, alpha=0.3)

# Calculate correlation for sample diseases
sample_correlation = np.corrcoef(sample_old_values, sample_weighted_values)[0, 1]
ax.text(0.05, 0.95, f'Correlation: {sample_correlation:.6f}', transform=ax.transAxes, 
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

plt.tight_layout()
plt.show()

# 4. Print detailed statistics for sample diseases
print(f"\n=== DETAILED STATISTICS FOR SAMPLE DISEASES ===")
for i, disease_idx in enumerate(sample_diseases):
    old_traj = old_avg_phi[disease_idx, :].detach().numpy()
    weighted_traj = weighted_avg_phi[disease_idx, :].detach().numpy()
    
    diff = weighted_traj - old_traj
    abs_diff = np.abs(diff)
    
    print(f"\nDisease {disease_idx}:")
    print(f"  Mean old phi: {old_traj.mean():.4f}")
    print(f"  Mean weighted phi: {weighted_traj.mean():.4f}")
    print(f"  Mean difference: {diff.mean():.6f}")
    print(f"  Max absolute difference: {abs_diff.max():.6f}")
    print(f"  Mean absolute difference: {abs_diff.mean():.6f}")
    print(f"  Correlation: {np.corrcoef(old_traj, weighted_traj)[0, 1]:.6f}")

# 5. Overall statistics
print(f"\n=== OVERALL STATISTICS ===")
overall_correlation = np.corrcoef(old_flat, weighted_flat)[0, 1]
overall_diff = weighted_flat - old_flat
overall_abs_diff = np.abs(overall_diff)

print(f"Overall correlation: {overall_correlation:.6f}")
print(f"Overall mean difference: {overall_diff.mean():.6f}")
print(f"Overall max absolute difference: {overall_abs_diff.max():.6f}")
print(f"Overall mean absolute difference: {overall_abs_diff.mean():.6f}")

print(f"\n✅ Sample disease analysis complete!")

# %%
# CORRECTED SAMPLE DISEASE ANALYSIS: Compare old vs weighted phi for each signature

import matplotlib.pyplot as plt
import numpy as np

# Define sample diseases to analyze
sample_diseases = [112,57,47,19]  # You can change these to any disease indices you want

print("=== SAMPLE DISEASE PHI COMPARISON (PER SIGNATURE) ===")
print(f"Analyzing diseases: {sample_diseases}")

# 1. Plot phi trajectories for each signature for sample diseases
fig, axes = plt.subplots(1, len(sample_diseases), figsize=(15, 5))
if len(sample_diseases) == 1:
    axes = [axes]

for i, disease_idx in enumerate(sample_diseases):
    ax = axes[i]
    
    # Plot phi trajectories for each signature (K) for this disease
    for k in range(combined_old_phi.shape[0]):  # All signatures (K=21)
        old_traj = combined_old_phi[k, disease_idx, :].detach().numpy()
        weighted_traj = combined_weighted_phi[k, disease_idx, :].detach().numpy()
        
        ax.plot(old_traj, alpha=0.7, linestyle='-', label=f'Sig {k} (old)' if i == 0 else "")
        ax.plot(weighted_traj, alpha=0.7, linestyle='--', label=f'Sig {k} (new)' if i == 0 else "")
    
    ax.set_xlabel('Time')
    ax.set_ylabel('Phi Value')
    ax.set_title(f'Disease {disease_idx} - Phi Trajectories (All Signatures)')
    ax.grid(True, alpha=0.3)
    
    if i == 0:
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# 2. Scatter plot of all old vs weighted phi values (each K, each D, each T)
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# Flatten all values for scatter plot (K, D, T)
old_flat = combined_old_phi.detach().numpy().flatten()
weighted_flat = combined_weighted_phi.detach().numpy().flatten()

# Create scatter plot
ax.scatter(old_flat, weighted_flat, alpha=0.5, s=1)
ax.plot([old_flat.min(), old_flat.max()], [old_flat.min(), old_flat.max()], 'r--', alpha=0.7)

ax.set_xlabel('Old Phi')
ax.set_ylabel('Weighted Phi')
ax.set_title('Old vs Weighted Phi (All K, All D, All T)')
ax.grid(True, alpha=0.3)

# Calculate correlation
correlation = np.corrcoef(old_flat, weighted_flat)[0, 1]
ax.text(0.05, 0.95, f'Correlation: {correlation:.6f}', transform=ax.transAxes, 
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

plt.tight_layout()
plt.show()

# 3. Focus on sample diseases scatter plot (each K, each T for sample diseases)
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# Get values for sample diseases only (each K, each T)
sample_old_values = []
sample_weighted_values = []

for disease_idx in sample_diseases:
    for k in range(combined_old_phi.shape[0]):  # All signatures
        old_vals = combined_old_phi[k, disease_idx, :].detach().numpy()
        weighted_vals = combined_weighted_phi[k, disease_idx, :].detach().numpy()
        
        sample_old_values.extend(old_vals)
        sample_weighted_values.extend(weighted_vals)

sample_old_values = np.array(sample_old_values)
sample_weighted_values = np.array(sample_weighted_values)

# Create scatter plot for sample diseases
ax.scatter(sample_old_values, sample_weighted_values, alpha=0.7, s=20)
ax.plot([sample_old_values.min(), sample_old_values.max()], 
        [sample_old_values.min(), sample_old_values.max()], 'r--', alpha=0.7)

ax.set_xlabel('Old Phi')
ax.set_ylabel('Weighted Phi')
ax.set_title(f'Sample Diseases {sample_diseases} - Old vs Weighted Phi (All K, All T)')
ax.grid(True, alpha=0.3)

# Calculate correlation for sample diseases
sample_correlation = np.corrcoef(sample_old_values, sample_weighted_values)[0, 1]
ax.text(0.05, 0.95, f'Correlation: {sample_correlation:.6f}', transform=ax.transAxes, 
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

plt.tight_layout()
plt.show()

# 4. Print detailed statistics for sample diseases (per signature)
print(f"\n=== DETAILED STATISTICS FOR SAMPLE DISEASES (PER SIGNATURE) ===")
for i, disease_idx in enumerate(sample_diseases):
    print(f"\nDisease {disease_idx}:")
    
    for k in range(combined_old_phi.shape[0]):  # All signatures
        old_traj = combined_old_phi[k, disease_idx, :].detach().numpy()
        weighted_traj = combined_weighted_phi[k, disease_idx, :].detach().numpy()
        
        diff = weighted_traj - old_traj
        abs_diff = np.abs(diff)
        
        print(f"  Signature {k}:")
        print(f"    Mean old phi: {old_traj.mean():.4f}")
        print(f"    Mean weighted phi: {weighted_traj.mean():.4f}")
        print(f"    Mean difference: {diff.mean():.6f}")
        print(f"    Max absolute difference: {abs_diff.max():.6f}")
        print(f"    Mean absolute difference: {abs_diff.mean():.6f}")
        print(f"    Correlation: {np.corrcoef(old_traj, weighted_traj)[0, 1]:.6f}")

# 5. Overall statistics
print(f"\n=== OVERALL STATISTICS ===")
overall_correlation = np.corrcoef(old_flat, weighted_flat)[0, 1]
overall_diff = weighted_flat - old_flat
overall_abs_diff = np.abs(overall_diff)

print(f"Overall correlation: {overall_correlation:.6f}")
print(f"Overall mean difference: {overall_diff.mean():.6f}")
print(f"Overall max absolute difference: {overall_abs_diff.max():.6f}")
print(f"Overall mean absolute difference: {overall_abs_diff.mean():.6f}")

print(f"\n✅ Sample disease analysis complete!")
