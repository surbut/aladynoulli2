# %% [markdown]
# # Batch 0 (0–10K): LOO-style pool 1–39 vs holdout-style pool 10–39
#
# Predict the **same** batch (0–10K) twice:
# 1. **Pool 1–39 (LOO-style):** Gamma from batches 1,2,…,39 (39 batches; excludes batch 0). Fit delta on batch 0 → π₁.
# 2. **Pool 10–39 (holdout-style):** Gamma from batches 10,11,…,39 (30 batches; excludes 0–9). Fit delta on batch 0 → π₂.
#
# Run **identical** static 10yr AUC evaluation on π₁ and π₂ (same Y, E, pce for 0–10K). Compare AUCs side by side.

# %% [markdown]
# ## Setup paths and imports

# %%
import sys
import gc
from pathlib import Path

import numpy as np
import pandas as pd
import torch

CLAUDE_DIR = Path('/Users/sarahurbut/aladynoulli2/claudefile').resolve()
DATA_DIR = Path('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running')
PCE_PATH = '/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_prevent_full.csv'
BATCH_SIZE = 10_000
N_BATCH = 0  # batch 0 = 0-10K

sys.path.insert(0, str(CLAUDE_DIR))
sys.path.insert(0, str(CLAUDE_DIR.parent / 'pyScripts'))

from slope_holdout_auc import (
    load_data,
    load_and_pool_slope_params,
    fit_slope_delta_and_extract_pi,
    SLOPE_CKPT_DIR_1PHASE,
)
from fig5utils import evaluate_major_diseases_wsex_with_bootstrap_from_pi

print('Imports OK. Slope checkpoints:', SLOPE_CKPT_DIR_1PHASE)
# Out:
# Imports OK. Slope checkpoints: /Users/sarahurbut/Library/CloudStorage/Dropbox/slope_model_nokappa_v3_single_phase

# %% [markdown]
# ## Load data for batch 0 (0–10K)

# %%
Y_full, E_full, G_full, prevalence_t, signature_refs, disease_names, pce_df_full = load_data()

start = N_BATCH * BATCH_SIZE
stop = start + BATCH_SIZE
Y_batch = Y_full[start:stop]
E_batch = E_full[start:stop]
G_batch = G_full[start:stop]
pce_batch = pce_df_full.iloc[start:stop].reset_index(drop=True)

print(f'Batch 0: Y {Y_batch.shape}, E {E_batch.shape}, G {G_batch.shape}, pce {len(pce_batch)}')
# Out:
# Batch 0: Y torch.Size([10000, 348, 52]), E torch.Size([10000, 348]), G (10000, 47), pce 10000

# %% [markdown]
# ## Prediction 1: Pool from batches 1–39 (LOO-style for batch 0)

# %%
train_indices_1_39 = list(range(1, 40))  # 39 batches (true LOO-style for batch 0)
print('Loading slope params pooled from batches 1-39...')
gl_1_39, gs_1_39, psi_1_39, eps_1_39, gh_1_39 = load_and_pool_slope_params(
    train_indices_1_39, slope_ckpt_dir=SLOPE_CKPT_DIR_1PHASE)

print('Fitting delta on batch 0 (pool 1-39)...')
pi_1_39, nll_1_39 = fit_slope_delta_and_extract_pi(
    Y_batch, E_batch, G_batch, prevalence_t, signature_refs,
    gl_1_39, gs_1_39, psi_1_39, eps_1_39,
    gamma_health=gh_1_39,
    pretrained_delta=None,
    n_epochs=200,
)
print(f'  NLL = {nll_1_39:.4f}')
del gl_1_39, gs_1_39, psi_1_39, eps_1_39, gh_1_39
gc.collect()
# Out:
# Loading slope params pooled from batches 1-39...
#   Slope: pooled 39 checkpoints, |gamma_level|=0.1137, |gamma_slope|=0.0596, |epsilon|=0.1075
# Fitting delta on batch 0 (pool 1-39)...
# Warm-starting from pretrained gamma (torch.Size([47, 21])), psi (torch.Size([21, 348]))
# Using provided gamma_health for alpha_i
#   alpha_i: mean=0.0000, std=0.0009, range=[-0.0039, 0.0046]
# Slope model init: gamma_level torch.Size([47, 21]), gamma_slope torch.Size([47, 21]) (zeros), delta torch.Size([10000, 21, 52]), epsilon torch.Size([21, 348, 52])
#   NLL = 11.7463
# 0

# %% [markdown]
# ## Prediction 2: Pool from batches 10–39 (holdout-style)

# %%
train_indices_10_39 = list(range(10, 40))  # 30 batches
print('Loading slope params pooled from batches 10-39...')
gl_10_39, gs_10_39, psi_10_39, eps_10_39, gh_10_39 = load_and_pool_slope_params(
    train_indices_10_39, slope_ckpt_dir=SLOPE_CKPT_DIR_1PHASE)

print('Fitting delta on batch 0 (pool 10-39)...')
pi_10_39, nll_10_39 = fit_slope_delta_and_extract_pi(
    Y_batch, E_batch, G_batch, prevalence_t, signature_refs,
    gl_10_39, gs_10_39, psi_10_39, eps_10_39,
    gamma_health=gh_10_39,
    pretrained_delta=None,
    n_epochs=200,
)
print(f'  NLL = {nll_10_39:.4f}')
del gl_10_39, gs_10_39, psi_10_39, eps_10_39, gh_10_39
gc.collect()
# Out:
# Loading slope params pooled from batches 10-39...
#   Slope: pooled 30 checkpoints, |gamma_level|=0.1134, |gamma_slope|=0.0611, |epsilon|=0.1076
# Fitting delta on batch 0 (pool 10-39)...
# Warm-starting from pretrained gamma (torch.Size([47, 21])), psi (torch.Size([21, 348]))
# Using provided gamma_health for alpha_i
#   alpha_i: mean=-0.0000, std=0.0010, range=[-0.0054, 0.0051]
# Slope model init: gamma_level torch.Size([47, 21]), gamma_slope torch.Size([47, 21]) (zeros), delta torch.Size([10000, 21, 52]), epsilon torch.Size([21, 348, 52])
#   NLL = 11.7284
# 0

# %% [markdown]
# ## Identical AUC evaluation (static 10yr, same Y, E, pce)

# %%
N_BOOTSTRAPS = 100
FOLLOW_UP_YEARS = 10

print('Evaluating pool 1-39 (static 10yr)...')
res_1_39 = evaluate_major_diseases_wsex_with_bootstrap_from_pi(
    pi=pi_1_39, Y_100k=Y_batch, E_100k=E_batch,
    disease_names=disease_names, pce_df=pce_batch,
    n_bootstraps=N_BOOTSTRAPS, follow_up_duration_years=FOLLOW_UP_YEARS)

print('\nEvaluating pool 10-39 (static 10yr)...')
res_10_39 = evaluate_major_diseases_wsex_with_bootstrap_from_pi(
    pi=pi_10_39, Y_100k=Y_batch, E_100k=E_batch,
    disease_names=disease_names, pce_df=pce_batch,
    n_bootstraps=N_BOOTSTRAPS, follow_up_duration_years=FOLLOW_UP_YEARS)
# Out:
# Evaluating pool 1-39 (static 10yr)...
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.758 (0.744-0.777) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.728, Events = 273/5409
#    Male: AUC = 0.723, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.823, Events = 8/37
#    Breast_Cancer: AUC = 0.759, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.699 (0.675-0.724) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.694, Events = 264/5409
#    Male: AUC = 0.701, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.717 (0.694-0.746) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.714, Events = 197/5372
#    Male: AUC = 0.726, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.756 (0.731-0.785) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.767, Events = 101/5409
#    Male: AUC = 0.745, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.734 (0.712-0.749) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.676, Events = 134/5409
#    Male: AUC = 0.670, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.642 (0.601-0.692) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.641, Events = 64/5409
#    Male: AUC = 0.645, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.745 (0.706-0.781) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.738, Events = 83/5409
#    Male: AUC = 0.727, Events = 122/4591
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.722 (0.696-0.749) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.720, Events = 135/5409
#    Male: AUC = 0.704, Events = 200/4591
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.715 (0.693-0.740) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.728, Events = 176/5409
#    Male: AUC = 0.697, Events = 218/4591
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.637 (0.602-0.662) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.639, Events = 128/5379
#    Male: AUC = 0.640, Events = 90/4582
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.634 (0.610-0.660) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.642, Events = 280/5409
#    Male: AUC = 0.635, Events = 243/4591
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.625 (0.593-0.676) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.642, Events = 56/5409
#    Male: AUC = 0.603, Events = 49/4591
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.587 (0.543-0.623) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.661 (0.629-0.689) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.4%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.696 (0.643-0.746) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.720, Events = 48/5406
#    Male: AUC = 0.653, Events = 27/4586
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.804 (0.740-0.853) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.728, Events = 24/5399
#    Male: AUC = 0.876, Events = 25/4577
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.633 (0.603-0.659) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.637, Events = 147/5409
#    Male: AUC = 0.623, Events = 129/4591
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.530 (0.502-0.554) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.0%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.533, Events = 210/5351
#    Male: AUC = 0.541, Events = 191/4561
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.567 (0.519-0.606) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.591, Events = 130/5391
#    Male: AUC = 0.545, Events = 110/4584
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.604 (0.532-0.698) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.528, Events = 14/5399
#    Male: AUC = 0.690, Events = 19/4585
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.606 (0.552-0.645) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.589, Events = 62/5381
#    Male: AUC = 0.630, Events = 60/4582
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.513 (0.421-0.604) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.478, Events = 15/5405
#    Male: AUC = 0.524, Events = 25/4576
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.606 (0.524-0.691) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.591, Events = 31/5378
#    Male: AUC = 0.636, Events = 19/4569
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.648 (0.554-0.730) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.715, Events = 20/5388
#    Male: AUC = 0.530, Events = 11/4579
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.562 (0.533-0.589) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.1%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.558, Events = 321/5214
#    Male: AUC = 0.599, Events = 264/4473
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.690 (0.614-0.745) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.726, Events = 21/5407
#    Male: AUC = 0.643, Events = 25/4590
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.443 (0.359-0.577) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.494, Events = 13/5394
#    Male: AUC = 0.364, Events = 8/4585
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.525 (0.494-0.552) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.567, Events = 385/5409
#    Male: AUC = 0.596, Events = 94/4591
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.758 (0.744-0.777)       831        8.3
# Diabetes             0.699 (0.675-0.724)       581        5.8
# Atrial_Fib           0.717 (0.694-0.746)       376        3.8
# CKD                  0.756 (0.731-0.785)       207        2.1
# All_Cancers          0.734 (0.712-0.749)       480        4.8
# Stroke               0.642 (0.601-0.692)       129        1.3
# Heart_Failure        0.745 (0.706-0.781)       205        2.1
# Pneumonia            0.722 (0.696-0.749)       335        3.4
# COPD                 0.715 (0.693-0.740)       394        3.9
# Osteoporosis         0.637 (0.602-0.662)       219        2.2
# Anemia               0.634 (0.610-0.660)       523        5.2
# Colorectal_Cancer    0.625 (0.593-0.676)       105        1.1
# Breast_Cancer        0.587 (0.543-0.623)       214        4.0
# Prostate_Cancer      0.661 (0.629-0.689)       204        4.4
# Lung_Cancer          0.696 (0.643-0.746)       75         0.8
# Bladder_Cancer       0.804 (0.740-0.853)       49         0.5
# Secondary_Cancer     0.633 (0.603-0.659)       276        2.8
# Depression           0.530 (0.502-0.554)       405        4.0
# Anxiety              0.567 (0.519-0.606)       241        2.4
# Bipolar_Disorder     0.604 (0.532-0.698)       34         0.3
# Rheumatoid_Arthritis 0.606 (0.552-0.645)       123        1.2
# Psoriasis            0.513 (0.421-0.604)       40         0.4
# Ulcerative_Colitis   0.606 (0.524-0.691)       50         0.5
# Crohns_Disease       0.648 (0.554-0.730)       31         0.3
# Asthma               0.562 (0.533-0.589)       606        6.1
# Parkinsons           0.690 (0.614-0.745)       46         0.5
# Multiple_Sclerosis   0.443 (0.359-0.577)       21         0.2
# Thyroid_Disorders    0.525 (0.494-0.552)       479        4.8
# --------------------------------------------------------------------------------
#
# Evaluating pool 10-39 (static 10yr)...
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.758 (0.742-0.776) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.728, Events = 273/5409
#    Male: AUC = 0.723, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.819, Events = 8/37
#    Breast_Cancer: AUC = 0.758, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.699 (0.676-0.721) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.694, Events = 264/5409
#    Male: AUC = 0.700, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.717 (0.693-0.740) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.713, Events = 197/5372
#    Male: AUC = 0.725, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.756 (0.726-0.786) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.766, Events = 101/5409
#    Male: AUC = 0.746, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.734 (0.714-0.759) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.676, Events = 134/5409
#    Male: AUC = 0.671, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.643 (0.590-0.692) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.640, Events = 64/5409
#    Male: AUC = 0.645, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.746 (0.715-0.780) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.738, Events = 83/5409
#    Male: AUC = 0.727, Events = 122/4591
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.722 (0.700-0.749) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.719, Events = 135/5409
#    Male: AUC = 0.703, Events = 200/4591
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.716 (0.694-0.742) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.728, Events = 176/5409
#    Male: AUC = 0.698, Events = 218/4591
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.640 (0.616-0.670) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.641, Events = 128/5379
#    Male: AUC = 0.643, Events = 90/4582
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.635 (0.608-0.658) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.643, Events = 280/5409
#    Male: AUC = 0.635, Events = 243/4591
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.626 (0.574-0.677) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.642, Events = 56/5409
#    Male: AUC = 0.604, Events = 49/4591
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.586 (0.550-0.629) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.661 (0.630-0.694) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.4%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.697 (0.651-0.760) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.723, Events = 48/5406
#    Male: AUC = 0.652, Events = 27/4586
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.803 (0.753-0.856) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.727, Events = 24/5399
#    Male: AUC = 0.877, Events = 25/4577
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.633 (0.604-0.665) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.636, Events = 147/5409
#    Male: AUC = 0.623, Events = 129/4591
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.531 (0.493-0.566) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.0%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.535, Events = 210/5351
#    Male: AUC = 0.541, Events = 191/4561
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.568 (0.541-0.607) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.592, Events = 130/5391
#    Male: AUC = 0.545, Events = 110/4584
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.608 (0.494-0.693) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.533, Events = 14/5399
#    Male: AUC = 0.692, Events = 19/4585
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.608 (0.560-0.674) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.591, Events = 62/5381
#    Male: AUC = 0.632, Events = 60/4582
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.513 (0.437-0.600) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.478, Events = 15/5405
#    Male: AUC = 0.524, Events = 25/4576
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.604 (0.526-0.692) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.590, Events = 31/5378
#    Male: AUC = 0.633, Events = 19/4569
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.642 (0.566-0.737) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.710, Events = 20/5388
#    Male: AUC = 0.523, Events = 11/4579
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.562 (0.538-0.587) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.1%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.559, Events = 321/5214
#    Male: AUC = 0.599, Events = 264/4473
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.688 (0.616-0.738) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.725, Events = 21/5407
#    Male: AUC = 0.642, Events = 25/4590
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.445 (0.304-0.552) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.495, Events = 13/5394
#    Male: AUC = 0.368, Events = 8/4585
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.527 (0.502-0.556) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.566, Events = 385/5409
#    Male: AUC = 0.596, Events = 94/4591
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.758 (0.742-0.776)       831        8.3
# Diabetes             0.699 (0.676-0.721)       581        5.8
# Atrial_Fib           0.717 (0.693-0.740)       376        3.8
# CKD                  0.756 (0.726-0.786)       207        2.1
# All_Cancers          0.734 (0.714-0.759)       480        4.8
# Stroke               0.643 (0.590-0.692)       129        1.3
# Heart_Failure        0.746 (0.715-0.780)       205        2.1
# Pneumonia            0.722 (0.700-0.749)       335        3.4
# COPD                 0.716 (0.694-0.742)       394        3.9
# Osteoporosis         0.640 (0.616-0.670)       219        2.2
# Anemia               0.635 (0.608-0.658)       523        5.2
# Colorectal_Cancer    0.626 (0.574-0.677)       105        1.1
# Breast_Cancer        0.586 (0.550-0.629)       214        4.0
# Prostate_Cancer      0.661 (0.630-0.694)       204        4.4
# Lung_Cancer          0.697 (0.651-0.760)       75         0.8
# Bladder_Cancer       0.803 (0.753-0.856)       49         0.5
# Secondary_Cancer     0.633 (0.604-0.665)       276        2.8
# Depression           0.531 (0.493-0.566)       405        4.0
# Anxiety              0.568 (0.541-0.607)       241        2.4
# Bipolar_Disorder     0.608 (0.494-0.693)       34         0.3
# Rheumatoid_Arthritis 0.608 (0.560-0.674)       123        1.2
# Psoriasis            0.513 (0.437-0.600)       40         0.4
# Ulcerative_Colitis   0.604 (0.526-0.692)       50         0.5
# Crohns_Disease       0.642 (0.566-0.737)       31         0.3
# Asthma               0.562 (0.538-0.587)       606        6.1
# Parkinsons           0.688 (0.616-0.738)       46         0.5
# Multiple_Sclerosis   0.445 (0.304-0.552)       21         0.2
# Thyroid_Disorders    0.527 (0.502-0.556)       479        4.8
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Comparison table

# %%
rows = []
for disease, m1 in res_1_39.items():
    m2 = res_10_39.get(disease, {})
    rows.append({
        'disease': disease,
        'auc_pool_1_39': m1.get('auc', np.nan),
        'ci_lower_1_39': m1.get('ci_lower', np.nan),
        'ci_upper_1_39': m1.get('ci_upper', np.nan),
        'auc_pool_10_39': m2.get('auc', np.nan),
        'ci_lower_10_39': m2.get('ci_lower', np.nan),
        'ci_upper_10_39': m2.get('ci_upper', np.nan),
        'diff_auc': (m1.get('auc', np.nan) - m2.get('auc', np.nan)) if m2 else np.nan,
    })

df = pd.DataFrame(rows).sort_values('auc_pool_1_39', ascending=False)
df['diff_auc'] = df['auc_pool_1_39'] - df['auc_pool_10_39']
display(df)

print('Summary (batch 0, 10k):')
print(f'  Mean AUC pool 1-39:   {df["auc_pool_1_39"].mean():.4f}')
print(f'  Mean AUC pool 10-39:  {df["auc_pool_10_39"].mean():.4f}')
print(f'  Mean diff (1-39 − 10-39): {df["diff_auc"].mean():.4f}')
print(f'  N better with 1-39:   {(df["diff_auc"] > 0).sum()} / {len(df)}')
# Out:
#                  disease  auc_pool_1_39  ci_lower_1_39  ci_upper_1_39  \
# 15        Bladder_Cancer       0.803666       0.739964       0.853036
# 0                  ASCVD       0.757990       0.744151       0.776985
# 3                    CKD       0.755575       0.731128       0.785194
# 6          Heart_Failure       0.745388       0.706419       0.780646
# 4            All_Cancers       0.733820       0.712185       0.749374
# 7              Pneumonia       0.722300       0.696048       0.749325
# 2             Atrial_Fib       0.717288       0.693854       0.745826
# 8                   COPD       0.715313       0.692881       0.740001
# 1               Diabetes       0.699067       0.674746       0.723710
# 14           Lung_Cancer       0.696307       0.642931       0.745619
# 25            Parkinsons       0.689529       0.614285       0.745029
# 13       Prostate_Cancer       0.661257       0.629237       0.689353
# 23        Crohns_Disease       0.647548       0.553759       0.730473
# 5                 Stroke       0.642406       0.601056       0.692274
# 9           Osteoporosis       0.636997       0.601517       0.662353
# 10                Anemia       0.634129       0.610119       0.660428
# 16      Secondary_Cancer       0.633042       0.603004       0.658624
# 11     Colorectal_Cancer       0.625461       0.592676       0.676253
# 20  Rheumatoid_Arthritis       0.606335       0.552136       0.645151
# 22    Ulcerative_Colitis       0.605797       0.524496       0.691488
# 19      Bipolar_Disorder       0.603791       0.532354       0.698223
# 12         Breast_Cancer       0.586840       0.542829       0.622630
# 18               Anxiety       0.567027       0.519025       0.606222
# 24                Asthma       0.561702       0.532622       0.588669
# 17            Depression       0.529587       0.502450       0.553888
# 27     Thyroid_Disorders       0.524952       0.493711       0.551659
# 21             Psoriasis       0.512549       0.421393       0.604242
# 26    Multiple_Sclerosis       0.442882       0.359403       0.576866
#
#     auc_pool_10_39  ci_lower_10_39  ci_upper_10_39  diff_auc
# 15        0.803315        0.752888        0.856371  0.000351
# 0         0.757846        0.742000        0.776431  0.000144
# 3         0.755872        0.726437        0.785918 -0.000297
# 6         0.745607        0.715366        0.780376 -0.000220
# 4         0.734022        0.714240        0.759037 -0.000202
# 7         0.721927        0.699513        0.748989  0.000373
# 2         0.716976        0.692894        0.739545  0.000312
# 8         0.716315        0.694494        0.742038 -0.001002
# 1         0.699139        0.676353        0.720697 -0.000071
# 14        0.696993        0.651205        0.759525 -0.000686
# 25        0.688373        0.616335        0.738422  0.001156
# 13        0.661295        0.629562        0.693606 -0.000038
# 23        0.641689        0.566201        0.736815  0.005858
# 5         0.642628        0.589816        0.691777 -0.000222
# 9         0.639630        0.616319        0.670301 -0.002633
# 10        0.635159        0.608365        0.658001 -0.001029
# 16        0.632922        0.603679        0.664597  0.000120
# 11        0.626105        0.574323        0.677158 -0.000644
# 20        0.608482        0.559762        0.674346 -0.002147
# 22        0.603536        0.526046        0.692037  0.002260
# 19        0.607684        0.493730        0.693252 -0.003893
# 12        0.586357        0.549830        0.629137  0.000483
# 18        0.567828        0.541230        0.606576 -0.000801
# 24        0.562349        0.538253        0.586787 -0.000647
# 17        0.530844        0.492539        0.566463 -0.001257
# 27        0.527390        0.502255        0.555517 -0.002438
# 21        0.512822        0.437123        0.599548 -0.000273
# 26        0.444775        0.303806        0.551733 -0.001894
# Summary (batch 0, 10k):
#   Mean AUC pool 1-39:   0.6449
#   Mean AUC pool 10-39:  0.6453
#   Mean diff (1-39 − 10-39): -0.0003
#   N better with 1-39:   9 / 28

# %% [markdown]
# ## Optional: save results

# %%
out_dir = CLAUDE_DIR / 'results_holdout_auc'
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / 'batch0_pool1_39_vs_10_39_auc.csv'
df.to_csv(out_path, index=False)
print(f'Saved: {out_path}')
# Out:
# Saved: /Users/sarahurbut/aladynoulli2/claudefile/results_holdout_auc/batch0_pool1_39_vs_10_39_auc.csv

# %%
cd /Users/sarahurbut/aladynoulli2/claudefile

nohup python slope_loo_like_400k_eval.py \
  --n_patients 400000 \
  --n_bootstraps 100 \
  > slope_loo_like_400k_eval.log 2>&1 &
