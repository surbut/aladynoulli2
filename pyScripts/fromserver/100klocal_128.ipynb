# %%
from cluster_g_logit_init import *
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/home/surbut/Downloads/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# Loading components...
# Loaded all components successfully!

# %%
def subset_data(Y, E, G, n_samples=50000, seed=42):
    """
    Subset the data to n_samples individuals while maintaining consistency
    
    Args:
        Y: tensor of shape [N, D, T]
        E: tensor of shape [N, D]
        G: tensor of shape [N, P]
        n_samples: number of individuals to keep
        seed: random seed for reproducibility
    
    Returns:
        Y_sub, E_sub, G_sub: subsetted tensors
    """
    torch.manual_seed(seed)
    
    # Get total number of individuals
    N = Y.shape[0]
    
    # Randomly select n_samples indices
    indices = torch.randperm(N)[:n_samples]
    
    # Subset all matrices using the same indices
    Y_sub = Y[indices]
    E_sub = E[indices]
    G_sub = G[indices]
    
    print(f"Original shapes: Y={Y.shape}, E={E.shape}, G={G.shape}")
    print(f"New shapes: Y={Y_sub.shape}, E={E_sub.shape}, G={G_sub.shape}")
    
    return Y_sub, E_sub, G_sub, indices

# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000)
# Out:
# Original shapes: Y=torch.Size([407878, 348, 52]), E=torch.Size([407878, 348]), G=torch.Size([407878, 36])
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=torch.Size([10000, 36])

# %%
torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(
    N=Y_100k.shape[0],
    D=Y_100k.shape[1],
    T=Y_100k.shape[2],
    K=essentials['K'],
    P=essentials['P'],
    G=G_100k,
    Y=Y_100k,
    prevalence_t=essentials['prevalence_t']
)
# Out:
# /home/surbut/aladynoulli/pyScripts/cluster_g_logit_init.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /home/surbut/aladynoulli/pyScripts/cluster_g_logit_init.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 402362656.00
# Phi kernel condition number: 1310707584.00
# /home/surbut/miniconda3/lib/python3.8/site-packages/sklearn/manifold/_spectral_embedding.py:247: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)
# Cluster Sizes:
# Cluster 0: 11 diseases
# Cluster 1: 74 diseases
# Cluster 2: 30 diseases
# Cluster 3: 7 diseases
# Cluster 4: 23 diseases
# Cluster 5: 10 diseases
# Cluster 6: 17 diseases
# Cluster 7: 14 diseases
# Cluster 8: 21 diseases
# Cluster 9: 5 diseases
# Cluster 10: 8 diseases
# Cluster 11: 9 diseases
# Cluster 12: 12 diseases
# Cluster 13: 31 diseases
# Cluster 14: 25 diseases
# Cluster 15: 5 diseases
# Cluster 16: 9 diseases
# Cluster 17: 17 diseases
# Cluster 18: 11 diseases
# Cluster 19: 9 diseases
# Initialization complete!

# %%
disease_names=essentials['disease_names']

# %%
disease_names
# Out:
# ['Bacterial enteritis',
#  'Viral Enteritis',
#  'Gram negative septicemia',
#  'Bacterial infection NOS',
#  'Staphylococcus infections',
#  'Streptococcus infection',
#  'E. coli',
#  'Viral warts & HPV',
#  'Viral infection',
#  'Candidiasis',
#  'Colon cancer',
#  'Malignant neoplasm of rectum, rectosigmoid junction, and anus',
#  'Neoplasm of unspecified nature of digestive system',
#  'Cancer of bronchus; lung',
#  'Melanomas of skin',
#  'Other non-epithelial cancer of skin',
#  'Breast cancer [female]',
#  'Malignant neoplasm of female breast',
#  'Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]',
#  'Malignant neoplasm of uterus',
#  'Malignant neoplasm of ovary',
#  'Cancer of prostate',
#  'Malignant neoplasm of kidney, except pelvis',
#  'Malignant neoplasm of bladder',
#  'Malignant neoplasm, other',
#  'Secondary malignant neoplasm',
#  'Secondary malignancy of lymph nodes',
#  'Secondary malignancy of respiratory organs',
#  'Secondary malignant neoplasm of digestive systems',
#  'Secondary malignant neoplasm of liver',
#  'Secondary malignancy of bone',
#  'Neoplasm of uncertain behavior',
#  'Non-Hodgkins lymphoma',
#  'Benign neoplasm of colon',
#  'Benign neoplasm of lip, oral cavity, and pharynx',
#  'Benign neoplasm of other parts of digestive system',
#  'Lipoma',
#  'Lipoma of skin and subcutaneous tissue',
#  'Other benign neoplasm of connective and other soft tissue',
#  'Benign neoplasm of skin',
#  'Uterine leiomyoma',
#  'Benign neoplasm of ovary',
#  'Hemangioma and lymphangioma, any site',
#  'Thyrotoxicosis with or without goiter',
#  'Secondary hypothyroidism',
#  'Hypothyroidism NOS',
#  'Type 1 diabetes',
#  'Type 2 diabetes',
#  'Type 2 diabetes with ophthalmic manifestations',
#  'Diabetic retinopathy',
#  'Hypoglycemia',
#  'Hyperlipidemia',
#  'Hypercholesterolemia',
#  'Gout',
#  'Disorders of calcium/phosphorus metabolism',
#  'Hyposmolality and/or hyponatremia',
#  'Hyperpotassemia',
#  'Hypopotassemia',
#  'Acidosis',
#  'Hypovolemia',
#  'Obesity',
#  'Iron deficiency anemias, unspecified or not due to blood loss',
#  'Other anemias',
#  'Thrombocytopenia',
#  'Neutropenia',
#  'Bipolar',
#  'Major depressive disorder',
#  'Anxiety disorder',
#  'Alcohol-related disorders',
#  'Alcoholic liver damage',
#  'Tobacco use disorder',
#  'Sleep disorders',
#  'Sleep apnea',
#  "Parkinson's disease",
#  'Degenerative disease of the spinal cord',
#  'Multiple sclerosis',
#  'Migraine',
#  'Hemiplegia',
#  'Epilepsy, recurrent seizures, convulsions',
#  'Other peripheral nerve disorders',
#  'Facial nerve disorders [CN7]',
#  'Inflammatory and toxic neuropathy',
#  'Retinal detachments and defects',
#  'Retinal detachment with retinal defect',
#  'Other retinal disorders',
#  'Macular degeneration (senile) of retina NOS',
#  'Retinal vascular changes and abnomalities',
#  'Glaucoma',
#  'Primary open angle glaucoma',
#  'Cataract',
#  'Senile cataract',
#  'Myopia',
#  'Visual disturbances',
#  'Inflammation of eyelids',
#  'Disorders of conjunctiva',
#  'Other disorders of eyelids',
#  'Ectropion or entropion',
#  'Ptosis of eyelid',
#  'Disorders of lacrimal system',
#  'Epiphora',
#  'Strabismus (not specified as paralytic)',
#  'Disorders of vitreous body',
#  'Otitis media',
#  'Perforation of tympanic membrane',
#  'Hearing loss',
#  'Rheumatic disease of the heart valves',
#  'Mitral valve disease',
#  'Aortic valve disease',
#  'Disease of tricuspid valve',
#  'Essential hypertension',
#  'Hypertensive chronic kidney disease',
#  'Unstable angina (intermediate coronary syndrome)',
#  'Myocardial infarction',
#  'Angina pectoris',
#  'Coronary atherosclerosis',
#  'Other chronic ischemic heart disease, unspecified',
#  'Other acute and subacute forms of ischemic heart disease',
#  'Other forms of chronic heart disease',
#  'Pulmonary heart disease',
#  'Cardiomegaly',
#  'Pericarditis',
#  'Primary/intrinsic cardiomyopathies',
#  'First degree AV block',
#  'Right bundle branch block',
#  'Left bundle branch block',
#  'Paroxysmal supraventricular tachycardia',
#  'Paroxysmal ventricular tachycardia',
#  'Atrial fibrillation and flutter',
#  'Cardiac arrest',
#  'Arrhythmia (cardiac) NOS',
#  'Congestive heart failure (CHF) NOS',
#  'Heart failure NOS',
#  'Cerebrovascular disease',
#  'Occlusion and stenosis of precerebral arteries',
#  'Occlusion of cerebral arteries',
#  'Cerebral artery occlusion, with cerebral infarction',
#  'Cerebral ischemia',
#  'Transient cerebral ischemia',
#  'Late effects of cerebrovascular disease',
#  'Abdominal aortic aneurysm',
#  "Raynaud's syndrome",
#  'Peripheral vascular disease, unspecified',
#  'Stricture of artery',
#  'Phlebitis and thrombophlebitis of lower extremities',
#  'Varicose veins of lower extremity',
#  'Hemorrhoids',
#  'Orthostatic hypotension',
#  'Hypotension NOS',
#  'Acute upper respiratory infections of multiple or unspecified sites',
#  'Acute pharyngitis',
#  'Septal Deviations/Turbinate Hypertrophy',
#  'Nasal polyps',
#  'Chronic pharyngitis and nasopharyngitis',
#  'Diseases of the larynx and vocal cords',
#  'Chronic tonsillitis and adenoiditis',
#  'Chronic sinusitis',
#  'Allergic rhinitis',
#  'Other upper respiratory disease',
#  'Pneumonia',
#  'Bacterial pneumonia',
#  'Pneumococcal pneumonia',
#  'Asthma',
#  'Chronic airway obstruction',
#  'Emphysema',
#  'Obstructive chronic bronchitis',
#  'Bronchiectasis',
#  'Postinflammatory pulmonary fibrosis',
#  'Empyema and pneumothorax',
#  'Pleurisy; pleural effusion',
#  'Pulmonary collapse; interstitial and compensatory emphysema',
#  'Respiratory failure',
#  'Other diseases of respiratory system, NEC',
#  'Disturbances in tooth eruption',
#  'Dental caries',
#  'Periapical abscess',
#  'Chronic periodontitis',
#  'Other diseases of the teeth and supporting structures',
#  'Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue',
#  'Diseases and other conditions of the tongue',
#  'Esophagitis, GERD and related diseases',
#  'GERD',
#  'Ulcer of esophagus',
#  "Barrett's esophagus",
#  'Reflux esophagitis',
#  'Esophageal bleeding (varices/hemorrhage)',
#  'Stricture and stenosis of esophagus',
#  'Gastric ulcer',
#  'Duodenal ulcer',
#  'Gastritis and duodenitis',
#  'Acute gastritis',
#  'Duodenitis',
#  'Other specified gastritis',
#  'Other disorders of stomach and duodenum',
#  'Acute appendicitis',
#  'Inguinal hernia',
#  'Diaphragmatic hernia',
#  'Umbilical hernia',
#  'Ventral hernia',
#  'Regional enteritis',
#  'Ulcerative colitis',
#  'Celiac disease',
#  'Noninfectious gastroenteritis',
#  'Other intestinal obstruction',
#  'Diverticulosis',
#  'Constipation',
#  'Functional digestive disorders',
#  'Irritable Bowel Syndrome',
#  'Anal and rectal conditions',
#  'Anal and rectal polyp',
#  'Peritonitis and retroperitoneal infections',
#  'Peritoneal adhesions (postoperative) (postinfection)',
#  'Other disorders of intestine',
#  'Gastrointestinal complications',
#  'Other chronic nonalcoholic liver disease',
#  'Other disorders of liver',
#  'Cholelithiasis',
#  'Cholelithiasis with acute cholecystitis',
#  'Cholelithiasis with other cholecystitis',
#  'Calculus of bile duct',
#  'Cholecystitis without cholelithiasis',
#  'Other disorders of gallbladder',
#  'Other disorders of biliary tract',
#  'Acute pancreatitis',
#  'Hematemesis',
#  'Blood in stool',
#  'Hemorrhage of rectum and anus',
#  'Hemorrhage of gastrointestinal tract',
#  'Chronic glomerulonephritis, NOS',
#  'Acute renal failure',
#  'Renal failure NOS',
#  'Chronic renal failure [CKD]',
#  'Chronic Kidney Disease, Stage III',
#  'Other disorders of the kidney and ureters',
#  'Cyst of kidney, acquired',
#  'Stricture/obstruction of ureter',
#  'Pyelonephritis',
#  'Urinary tract infection',
#  'Cystitis',
#  'Chronic cystitis',
#  'Calculus of kidney',
#  'Calculus of ureter',
#  'Renal colic',
#  'Hydronephrosis',
#  'Other disorders of bladder',
#  'Bladder neck obstruction',
#  'Functional disorders of bladder',
#  'Urethral stricture (not specified as infectious)',
#  'Other symptoms/disorders or the urinary system',
#  'Urinary incontinence',
#  'Hyperplasia of prostate',
#  'Chronic prostatitis',
#  'Other disorders of prostate',
#  'Other disorders of testis',
#  'Hydrocele',
#  'Redundant prepuce and phimosis/BXO',
#  'Other disorders of male genital organs',
#  'Benign neoplasm of breast',
#  'Lump or mass in breast',
#  'Hypertrophy of breast (Gynecomastia)',
#  'Pelvic peritoneal adhesions, female (postoperative) (postinfection)',
#  'Cervicitis and endocervicitis',
#  'Endometriosis',
#  'Prolapse of vaginal walls',
#  'Uterine/Uterovaginal prolapse',
#  'Disorders of uterus, NEC',
#  'Noninflammatory disorders of cervix',
#  'Noninflammatory disorders of vagina',
#  'Noninflammatory disorders of vulva and perineum',
#  'Endometrial hyperplasia',
#  'Polyp of corpus uteri',
#  'Mucous polyp of cervix',
#  'Hypertrophy of female genital organs',
#  'Pain and other symptoms associated with female genital organs',
#  'Dyspareunia',
#  'Disorders of menstruation and other abnormal bleeding from female genital tract',
#  'Irregular menstrual cycle/bleeding',
#  'Excessive or frequent menstruation',
#  'Irregular menstrual cycle',
#  'Irregular menstrual bleeding',
#  'Dysmenorrhea',
#  'Infertility, female',
#  'Postmenopausal bleeding',
#  'Postmenopausal atrophic vaginitis',
#  'Ovarian cyst',
#  'Cellulitis and abscess of arm/hand',
#  'Other local infections of skin and subcutaneous tissue',
#  'Carbuncle and furuncle',
#  'Disorder of skin and subcutaneous tissue NOS',
#  'Psoriasis vulgaris',
#  'Other hypertrophic and atrophic conditions of skin',
#  'Scar conditions and fibrosis of skin',
#  'Actinic keratosis',
#  'Seborrheic keratosis',
#  'Ingrowing nail',
#  'Sebaceous cyst',
#  'Chronic ulcer of skin',
#  'Decubitus ulcer',
#  'Rheumatoid arthritis',
#  'Other inflammatory spondylopathies',
#  'Arthropathy NOS',
#  'Polymyalgia Rheumatica',
#  'Spinal stenosis',
#  'Spondylosis and allied disorders',
#  'Spondylosis without myelopathy',
#  'Displacement of intervertebral disc',
#  'Degeneration of intervertebral disc',
#  'Other and unspecified disc disorder',
#  'Peripheral enthesopathies and allied syndromes',
#  'Enthesopathy',
#  'Bursitis',
#  'Other disorders of synovium, tendon, and bursa',
#  'Synovitis and tenosynovitis',
#  'Ganglion and cyst of synovium, tendon, and bursa',
#  "Contracture of palmar fascia [Dupuytren's disease]",
#  'Other disorders of soft tissues',
#  'Rheumatism, unspecified and fibrositis',
#  'Other disorders of bone and cartilage',
#  'Malunion and nonunion of fracture',
#  'Acquired toe deformities',
#  'Hammer toe (acquired)',
#  'Hallux rigidus',
#  'Hallux valgus (Bunion)',
#  'Other acquired deformities of limbs',
#  'Kyphoscoliosis and scoliosis',
#  'Acquired spondylolisthesis',
#  'Osteoarthritis; localized',
#  'Osteoarthrosis, localized, primary',
#  'Osteoarthrosis, generalized',
#  'Osteoarthrosis NOS',
#  'Symptoms and disorders of the joints',
#  'Joint effusions',
#  'Other derangement of joint',
#  'Osteoporosis NOS',
#  'Osteopenia or other disorder of bone and cartilage',
#  'Pain in joint',
#  'Congenital anomalies of great vessels',
#  'Back pain',
#  'Cervicalgia',
#  'Thoracic or lumbosacral neuritis or radiculitis, unspecified',
#  'Sciatica',
#  'Neuralgia, neuritis, and radiculitis NOS',
#  'Myalgia and myositis unspecified',
#  'Pain in limb',
#  'Abdominal pain',
#  'Internal derangement of knee',
#  'Atopic/contact dermatitis due to other or unspecified',
#  'Sepsis',
#  'Other tests']

# %%
model.visualize_clusters(disease_names)
model.visualize_initialization()
# Out:
# Cluster Assignments:
#
# Cluster 0:
#   - Retinal detachments and defects (prevalence: 0.0002)
#   - Retinal detachment with retinal defect (prevalence: 0.0001)
#   - Other retinal disorders (prevalence: 0.0001)
#   - Macular degeneration (senile) of retina NOS (prevalence: 0.0005)
#   - Retinal vascular changes and abnomalities (prevalence: 0.0001)
#   - Glaucoma (prevalence: 0.0006)
#   - Primary open angle glaucoma (prevalence: 0.0001)
#   - Cataract (prevalence: 0.0021)
#   - Senile cataract (prevalence: 0.0017)
#   - Myopia (prevalence: 0.0002)
#   - Disorders of vitreous body (prevalence: 0.0002)
#
# Cluster 1:
#   - Bacterial enteritis (prevalence: 0.0002)
#   - Viral Enteritis (prevalence: 0.0001)
#   - Viral warts & HPV (prevalence: 0.0001)
#   - Melanomas of skin (prevalence: 0.0003)
#   - Other non-epithelial cancer of skin (prevalence: 0.0011)
#   - Breast cancer [female] (prevalence: 0.0002)
#   - Malignant neoplasm of female breast (prevalence: 0.0008)
#   - Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] (prevalence: 0.0001)
#   - Neoplasm of uncertain behavior (prevalence: 0.0001)
#   - Non-Hodgkins lymphoma (prevalence: 0.0001)
#   - Benign neoplasm of lip, oral cavity, and pharynx (prevalence: 0.0001)
#   - Lipoma (prevalence: 0.0001)
#   - Lipoma of skin and subcutaneous tissue (prevalence: 0.0003)
#   - Other benign neoplasm of connective and other soft tissue (prevalence: 0.0001)
#   - Benign neoplasm of skin (prevalence: 0.0006)
#   - Hemangioma and lymphangioma, any site (prevalence: 0.0001)
#   - Thyrotoxicosis with or without goiter (prevalence: 0.0002)
#   - Secondary hypothyroidism (prevalence: 0.0002)
#   - Hyperlipidemia (prevalence: 0.0006)
#   - Bipolar (prevalence: 0.0001)
#   - Sleep disorders (prevalence: 0.0001)
#   - Multiple sclerosis (prevalence: 0.0001)
#   - Facial nerve disorders [CN7] (prevalence: 0.0001)
#   - Visual disturbances (prevalence: 0.0001)
#   - Inflammation of eyelids (prevalence: 0.0002)
#   - Disorders of conjunctiva (prevalence: 0.0001)
#   - Other disorders of eyelids (prevalence: 0.0002)
#   - Ectropion or entropion (prevalence: 0.0001)
#   - Ptosis of eyelid (prevalence: 0.0001)
#   - Disorders of lacrimal system (prevalence: 0.0002)
#   - Epiphora (prevalence: 0.0001)
#   - Strabismus (not specified as paralytic) (prevalence: 0.0001)
#   - Otitis media (prevalence: 0.0001)
#   - Perforation of tympanic membrane (prevalence: 0.0001)
#   - Hearing loss (prevalence: 0.0006)
#   - Pulmonary heart disease (prevalence: 0.0005)
#   - First degree AV block (prevalence: 0.0002)
#   - Arrhythmia (cardiac) NOS (prevalence: 0.0001)
#   - Raynaud's syndrome (prevalence: 0.0002)
#   - Acute upper respiratory infections of multiple or unspecified sites (prevalence: 0.0001)
#   - Acute pharyngitis (prevalence: 0.0001)
#   - Diseases of the larynx and vocal cords (prevalence: 0.0001)
#   - Chronic tonsillitis and adenoiditis (prevalence: 0.0001)
#   - Allergic rhinitis (prevalence: 0.0003)
#   - Disturbances in tooth eruption (prevalence: 0.0001)
#   - Dental caries (prevalence: 0.0003)
#   - Periapical abscess (prevalence: 0.0001)
#   - Chronic periodontitis (prevalence: 0.0001)
#   - Other diseases of the teeth and supporting structures (prevalence: 0.0002)
#   - Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue (prevalence: 0.0002)
#   - Diseases and other conditions of the tongue (prevalence: 0.0001)
#   - Acute gastritis (prevalence: 0.0001)
#   - Acute appendicitis (prevalence: 0.0002)
#   - Celiac disease (prevalence: 0.0001)
#   - Functional digestive disorders (prevalence: 0.0001)
#   - Benign neoplasm of breast (prevalence: 0.0001)
#   - Lump or mass in breast (prevalence: 0.0001)
#   - Hypertrophy of breast (Gynecomastia) (prevalence: 0.0000)
#   - Noninflammatory disorders of vulva and perineum (prevalence: 0.0001)
#   - Dyspareunia (prevalence: 0.0001)
#   - Infertility, female (prevalence: 0.0000)
#   - Disorder of skin and subcutaneous tissue NOS (prevalence: 0.0006)
#   - Other hypertrophic and atrophic conditions of skin (prevalence: 0.0001)
#   - Scar conditions and fibrosis of skin (prevalence: 0.0002)
#   - Actinic keratosis (prevalence: 0.0003)
#   - Seborrheic keratosis (prevalence: 0.0003)
#   - Polymyalgia Rheumatica (prevalence: 0.0002)
#   - Ganglion and cyst of synovium, tendon, and bursa (prevalence: 0.0002)
#   - Contracture of palmar fascia [Dupuytren's disease] (prevalence: 0.0003)
#   - Other disorders of bone and cartilage (prevalence: 0.0003)
#   - Malunion and nonunion of fracture (prevalence: 0.0001)
#   - Kyphoscoliosis and scoliosis (prevalence: 0.0001)
#   - Symptoms and disorders of the joints (prevalence: 0.0001)
#   - Osteopenia or other disorder of bone and cartilage (prevalence: 0.0001)
#
# Cluster 2:
#   - Gram negative septicemia (prevalence: 0.0002)
#   - Bacterial infection NOS (prevalence: 0.0006)
#   - E. coli (prevalence: 0.0004)
#   - Malignant neoplasm of kidney, except pelvis (prevalence: 0.0001)
#   - Disorders of calcium/phosphorus metabolism (prevalence: 0.0002)
#   - Hyposmolality and/or hyponatremia (prevalence: 0.0005)
#   - Hyperpotassemia (prevalence: 0.0002)
#   - Acidosis (prevalence: 0.0002)
#   - Hypovolemia (prevalence: 0.0006)
#   - Other anemias (prevalence: 0.0015)
#   - Hypertensive chronic kidney disease (prevalence: 0.0001)
#   - Hypotension NOS (prevalence: 0.0006)
#   - Bacterial pneumonia (prevalence: 0.0001)
#   - Pulmonary collapse; interstitial and compensatory emphysema (prevalence: 0.0005)
#   - Peritonitis and retroperitoneal infections (prevalence: 0.0001)
#   - Chronic glomerulonephritis, NOS (prevalence: 0.0001)
#   - Acute renal failure (prevalence: 0.0012)
#   - Renal failure NOS (prevalence: 0.0001)
#   - Chronic renal failure [CKD] (prevalence: 0.0006)
#   - Chronic Kidney Disease, Stage III (prevalence: 0.0006)
#   - Other disorders of the kidney and ureters (prevalence: 0.0002)
#   - Cyst of kidney, acquired (prevalence: 0.0002)
#   - Stricture/obstruction of ureter (prevalence: 0.0001)
#   - Pyelonephritis (prevalence: 0.0002)
#   - Urinary tract infection (prevalence: 0.0015)
#   - Calculus of kidney (prevalence: 0.0003)
#   - Calculus of ureter (prevalence: 0.0002)
#   - Renal colic (prevalence: 0.0002)
#   - Hydronephrosis (prevalence: 0.0003)
#   - Sepsis (prevalence: 0.0007)
#
# Cluster 3:
#   - Hypercholesterolemia (prevalence: 0.0034)
#   - Unstable angina (intermediate coronary syndrome) (prevalence: 0.0004)
#   - Myocardial infarction (prevalence: 0.0012)
#   - Angina pectoris (prevalence: 0.0014)
#   - Coronary atherosclerosis (prevalence: 0.0017)
#   - Other chronic ischemic heart disease, unspecified (prevalence: 0.0015)
#   - Other acute and subacute forms of ischemic heart disease (prevalence: 0.0002)
#
# Cluster 4:
#   - Viral infection (prevalence: 0.0004)
#   - Hypothyroidism NOS (prevalence: 0.0014)
#   - Major depressive disorder (prevalence: 0.0015)
#   - Anxiety disorder (prevalence: 0.0010)
#   - Parkinson's disease (prevalence: 0.0002)
#   - Migraine (prevalence: 0.0004)
#   - Epilepsy, recurrent seizures, convulsions (prevalence: 0.0003)
#   - Essential hypertension (prevalence: 0.0073)
#   - Orthostatic hypotension (prevalence: 0.0003)
#   - Asthma (prevalence: 0.0022)
#   - Other diseases of respiratory system, NEC (prevalence: 0.0009)
#   - Constipation (prevalence: 0.0015)
#   - Irritable Bowel Syndrome (prevalence: 0.0006)
#   - Other chronic nonalcoholic liver disease (prevalence: 0.0004)
#   - Urinary incontinence (prevalence: 0.0005)
#   - Spondylosis and allied disorders (prevalence: 0.0004)
#   - Other disorders of soft tissues (prevalence: 0.0006)
#   - Rheumatism, unspecified and fibrositis (prevalence: 0.0001)
#   - Osteoporosis NOS (prevalence: 0.0009)
#   - Cervicalgia (prevalence: 0.0002)
#   - Myalgia and myositis unspecified (prevalence: 0.0002)
#   - Pain in limb (prevalence: 0.0006)
#   - Abdominal pain (prevalence: 0.0009)
#
# Cluster 5:
#   - Malignant neoplasm of bladder (prevalence: 0.0002)
#   - Cystitis (prevalence: 0.0002)
#   - Chronic cystitis (prevalence: 0.0001)
#   - Other disorders of bladder (prevalence: 0.0007)
#   - Bladder neck obstruction (prevalence: 0.0001)
#   - Functional disorders of bladder (prevalence: 0.0001)
#   - Urethral stricture (not specified as infectious) (prevalence: 0.0003)
#   - Other symptoms/disorders or the urinary system (prevalence: 0.0001)
#   - Hyperplasia of prostate (prevalence: 0.0012)
#   - Other disorders of prostate (prevalence: 0.0001)
#
# Cluster 6:
#   - Colon cancer (prevalence: 0.0003)
#   - Malignant neoplasm of rectum, rectosigmoid junction, and anus (prevalence: 0.0002)
#   - Neoplasm of unspecified nature of digestive system (prevalence: 0.0001)
#   - Benign neoplasm of colon (prevalence: 0.0024)
#   - Hemorrhoids (prevalence: 0.0023)
#   - Ventral hernia (prevalence: 0.0003)
#   - Regional enteritis (prevalence: 0.0002)
#   - Ulcerative colitis (prevalence: 0.0002)
#   - Noninfectious gastroenteritis (prevalence: 0.0011)
#   - Other intestinal obstruction (prevalence: 0.0004)
#   - Diverticulosis (prevalence: 0.0031)
#   - Anal and rectal conditions (prevalence: 0.0007)
#   - Anal and rectal polyp (prevalence: 0.0008)
#   - Other disorders of intestine (prevalence: 0.0004)
#   - Gastrointestinal complications (prevalence: 0.0001)
#   - Hemorrhage of rectum and anus (prevalence: 0.0009)
#   - Hemorrhage of gastrointestinal tract (prevalence: 0.0008)
#
# Cluster 7:
#   - Benign neoplasm of other parts of digestive system (prevalence: 0.0006)
#   - Iron deficiency anemias, unspecified or not due to blood loss (prevalence: 0.0011)
#   - Esophagitis, GERD and related diseases (prevalence: 0.0007)
#   - GERD (prevalence: 0.0019)
#   - Ulcer of esophagus (prevalence: 0.0004)
#   - Barrett's esophagus (prevalence: 0.0003)
#   - Reflux esophagitis (prevalence: 0.0010)
#   - Stricture and stenosis of esophagus (prevalence: 0.0002)
#   - Gastric ulcer (prevalence: 0.0004)
#   - Duodenal ulcer (prevalence: 0.0002)
#   - Gastritis and duodenitis (prevalence: 0.0016)
#   - Duodenitis (prevalence: 0.0006)
#   - Other specified gastritis (prevalence: 0.0009)
#   - Diaphragmatic hernia (prevalence: 0.0025)
#
# Cluster 8:
#   - Obesity (prevalence: 0.0019)
#   - Other peripheral nerve disorders (prevalence: 0.0010)
#   - Rheumatoid arthritis (prevalence: 0.0005)
#   - Arthropathy NOS (prevalence: 0.0041)
#   - Peripheral enthesopathies and allied syndromes (prevalence: 0.0005)
#   - Enthesopathy (prevalence: 0.0009)
#   - Other disorders of synovium, tendon, and bursa (prevalence: 0.0001)
#   - Synovitis and tenosynovitis (prevalence: 0.0002)
#   - Acquired toe deformities (prevalence: 0.0002)
#   - Hammer toe (acquired) (prevalence: 0.0002)
#   - Hallux rigidus (prevalence: 0.0001)
#   - Hallux valgus (Bunion) (prevalence: 0.0004)
#   - Other acquired deformities of limbs (prevalence: 0.0002)
#   - Osteoarthritis; localized (prevalence: 0.0011)
#   - Osteoarthrosis, localized, primary (prevalence: 0.0007)
#   - Osteoarthrosis, generalized (prevalence: 0.0006)
#   - Osteoarthrosis NOS (prevalence: 0.0001)
#   - Other derangement of joint (prevalence: 0.0002)
#   - Pain in joint (prevalence: 0.0008)
#   - Internal derangement of knee (prevalence: 0.0011)
#   - Other tests (prevalence: 0.0002)
#
# Cluster 9:
#   - Septal Deviations/Turbinate Hypertrophy (prevalence: 0.0003)
#   - Nasal polyps (prevalence: 0.0002)
#   - Chronic pharyngitis and nasopharyngitis (prevalence: 0.0001)
#   - Chronic sinusitis (prevalence: 0.0003)
#   - Other upper respiratory disease (prevalence: 0.0003)
#
# Cluster 10:
#   - Hemiplegia (prevalence: 0.0002)
#   - Cerebrovascular disease (prevalence: 0.0002)
#   - Occlusion and stenosis of precerebral arteries (prevalence: 0.0001)
#   - Occlusion of cerebral arteries (prevalence: 0.0003)
#   - Cerebral artery occlusion, with cerebral infarction (prevalence: 0.0003)
#   - Cerebral ischemia (prevalence: 0.0003)
#   - Transient cerebral ischemia (prevalence: 0.0003)
#   - Late effects of cerebrovascular disease (prevalence: 0.0002)
#
# Cluster 11:
#   - Peritoneal adhesions (postoperative) (postinfection) (prevalence: 0.0004)
#   - Cholelithiasis (prevalence: 0.0008)
#   - Cholelithiasis with acute cholecystitis (prevalence: 0.0002)
#   - Cholelithiasis with other cholecystitis (prevalence: 0.0005)
#   - Calculus of bile duct (prevalence: 0.0002)
#   - Cholecystitis without cholelithiasis (prevalence: 0.0002)
#   - Other disorders of gallbladder (prevalence: 0.0002)
#   - Other disorders of biliary tract (prevalence: 0.0002)
#   - Acute pancreatitis (prevalence: 0.0002)
#
# Cluster 12:
#   - Degenerative disease of the spinal cord (prevalence: 0.0002)
#   - Other inflammatory spondylopathies (prevalence: 0.0001)
#   - Spinal stenosis (prevalence: 0.0005)
#   - Spondylosis without myelopathy (prevalence: 0.0007)
#   - Displacement of intervertebral disc (prevalence: 0.0003)
#   - Degeneration of intervertebral disc (prevalence: 0.0003)
#   - Other and unspecified disc disorder (prevalence: 0.0005)
#   - Acquired spondylolisthesis (prevalence: 0.0002)
#   - Back pain (prevalence: 0.0013)
#   - Thoracic or lumbosacral neuritis or radiculitis, unspecified (prevalence: 0.0004)
#   - Sciatica (prevalence: 0.0003)
#   - Neuralgia, neuritis, and radiculitis NOS (prevalence: 0.0002)
#
# Cluster 13:
#   - Staphylococcus infections (prevalence: 0.0004)
#   - Streptococcus infection (prevalence: 0.0002)
#   - Candidiasis (prevalence: 0.0003)
#   - Cancer of prostate (prevalence: 0.0007)
#   - Gout (prevalence: 0.0005)
#   - Sleep apnea (prevalence: 0.0005)
#   - Inflammatory and toxic neuropathy (prevalence: 0.0002)
#   - Right bundle branch block (prevalence: 0.0003)
#   - Abdominal aortic aneurysm (prevalence: 0.0001)
#   - Peripheral vascular disease, unspecified (prevalence: 0.0003)
#   - Stricture of artery (prevalence: 0.0001)
#   - Phlebitis and thrombophlebitis of lower extremities (prevalence: 0.0004)
#   - Varicose veins of lower extremity (prevalence: 0.0007)
#   - Inguinal hernia (prevalence: 0.0013)
#   - Umbilical hernia (prevalence: 0.0004)
#   - Chronic prostatitis (prevalence: 0.0001)
#   - Other disorders of testis (prevalence: 0.0001)
#   - Hydrocele (prevalence: 0.0001)
#   - Redundant prepuce and phimosis/BXO (prevalence: 0.0002)
#   - Other disorders of male genital organs (prevalence: 0.0002)
#   - Cellulitis and abscess of arm/hand (prevalence: 0.0006)
#   - Other local infections of skin and subcutaneous tissue (prevalence: 0.0001)
#   - Carbuncle and furuncle (prevalence: 0.0002)
#   - Psoriasis vulgaris (prevalence: 0.0002)
#   - Ingrowing nail (prevalence: 0.0001)
#   - Sebaceous cyst (prevalence: 0.0006)
#   - Chronic ulcer of skin (prevalence: 0.0002)
#   - Decubitus ulcer (prevalence: 0.0003)
#   - Bursitis (prevalence: 0.0001)
#   - Joint effusions (prevalence: 0.0002)
#   - Atopic/contact dermatitis due to other or unspecified (prevalence: 0.0003)
#
# Cluster 14:
#   - Malignant neoplasm of uterus (prevalence: 0.0001)
#   - Uterine leiomyoma (prevalence: 0.0006)
#   - Benign neoplasm of ovary (prevalence: 0.0001)
#   - Pelvic peritoneal adhesions, female (postoperative) (postinfection) (prevalence: 0.0002)
#   - Cervicitis and endocervicitis (prevalence: 0.0001)
#   - Endometriosis (prevalence: 0.0003)
#   - Prolapse of vaginal walls (prevalence: 0.0005)
#   - Uterine/Uterovaginal prolapse (prevalence: 0.0004)
#   - Disorders of uterus, NEC (prevalence: 0.0002)
#   - Noninflammatory disorders of cervix (prevalence: 0.0002)
#   - Noninflammatory disorders of vagina (prevalence: 0.0001)
#   - Endometrial hyperplasia (prevalence: 0.0001)
#   - Polyp of corpus uteri (prevalence: 0.0005)
#   - Mucous polyp of cervix (prevalence: 0.0002)
#   - Hypertrophy of female genital organs (prevalence: 0.0001)
#   - Pain and other symptoms associated with female genital organs (prevalence: 0.0001)
#   - Disorders of menstruation and other abnormal bleeding from female genital tract (prevalence: 0.0001)
#   - Irregular menstrual cycle/bleeding (prevalence: 0.0001)
#   - Excessive or frequent menstruation (prevalence: 0.0005)
#   - Irregular menstrual cycle (prevalence: 0.0001)
#   - Irregular menstrual bleeding (prevalence: 0.0002)
#   - Dysmenorrhea (prevalence: 0.0001)
#   - Postmenopausal bleeding (prevalence: 0.0006)
#   - Postmenopausal atrophic vaginitis (prevalence: 0.0001)
#   - Ovarian cyst (prevalence: 0.0003)
#
# Cluster 15:
#   - Type 1 diabetes (prevalence: 0.0002)
#   - Type 2 diabetes (prevalence: 0.0019)
#   - Type 2 diabetes with ophthalmic manifestations (prevalence: 0.0002)
#   - Diabetic retinopathy (prevalence: 0.0002)
#   - Hypoglycemia (prevalence: 0.0002)
#
# Cluster 16:
#   - Hypopotassemia (prevalence: 0.0004)
#   - Thrombocytopenia (prevalence: 0.0002)
#   - Alcohol-related disorders (prevalence: 0.0005)
#   - Alcoholic liver damage (prevalence: 0.0001)
#   - Esophageal bleeding (varices/hemorrhage) (prevalence: 0.0002)
#   - Other disorders of stomach and duodenum (prevalence: 0.0004)
#   - Other disorders of liver (prevalence: 0.0002)
#   - Hematemesis (prevalence: 0.0002)
#   - Blood in stool (prevalence: 0.0003)
#
# Cluster 17:
#   - Rheumatic disease of the heart valves (prevalence: 0.0002)
#   - Mitral valve disease (prevalence: 0.0003)
#   - Aortic valve disease (prevalence: 0.0002)
#   - Disease of tricuspid valve (prevalence: 0.0003)
#   - Other forms of chronic heart disease (prevalence: 0.0004)
#   - Cardiomegaly (prevalence: 0.0005)
#   - Pericarditis (prevalence: 0.0002)
#   - Primary/intrinsic cardiomyopathies (prevalence: 0.0001)
#   - Left bundle branch block (prevalence: 0.0003)
#   - Paroxysmal supraventricular tachycardia (prevalence: 0.0002)
#   - Paroxysmal ventricular tachycardia (prevalence: 0.0001)
#   - Atrial fibrillation and flutter (prevalence: 0.0010)
#   - Cardiac arrest (prevalence: 0.0001)
#   - Congestive heart failure (CHF) NOS (prevalence: 0.0004)
#   - Heart failure NOS (prevalence: 0.0007)
#   - Pleurisy; pleural effusion (prevalence: 0.0009)
#   - Congenital anomalies of great vessels (prevalence: 0.0003)
#
# Cluster 18:
#   - Cancer of bronchus; lung (prevalence: 0.0003)
#   - Tobacco use disorder (prevalence: 0.0011)
#   - Pneumonia (prevalence: 0.0006)
#   - Pneumococcal pneumonia (prevalence: 0.0010)
#   - Chronic airway obstruction (prevalence: 0.0010)
#   - Emphysema (prevalence: 0.0003)
#   - Obstructive chronic bronchitis (prevalence: 0.0004)
#   - Bronchiectasis (prevalence: 0.0003)
#   - Postinflammatory pulmonary fibrosis (prevalence: 0.0002)
#   - Empyema and pneumothorax (prevalence: 0.0001)
#   - Respiratory failure (prevalence: 0.0004)
#
# Cluster 19:
#   - Malignant neoplasm of ovary (prevalence: 0.0001)
#   - Malignant neoplasm, other (prevalence: 0.0002)
#   - Secondary malignant neoplasm (prevalence: 0.0002)
#   - Secondary malignancy of lymph nodes (prevalence: 0.0006)
#   - Secondary malignancy of respiratory organs (prevalence: 0.0003)
#   - Secondary malignant neoplasm of digestive systems (prevalence: 0.0002)
#   - Secondary malignant neoplasm of liver (prevalence: 0.0003)
#   - Secondary malignancy of bone (prevalence: 0.0003)
#   - Neutropenia (prevalence: 0.0004)
# /home/surbut/aladynoulli/pyScripts/cluster_g_logit_init.py:804: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
initial_psi = model.psi.detach().clone()

# Run for just 10 epochs to check behavior
E_tensor = torch.tensor(E_100k, dtype=torch.long)
# don't run below this line, computer will crash
# Out:
# <ipython-input-7-f697def48246>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   E_tensor = torch.tensor(E_100k, dtype=torch.long)

# %%
E_100k.shape
# Out:
# torch.Size([10000, 348])

# %%
history = model.fit(E_100k, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2)

# Compare final vs initial psi
print("\nOverall psi changes:")
# Out:
# Starting training...
# /home/surbut/aladynoulli/pyScripts/cluster_g_logit_init.py:290: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 1110.8492
# Psi gradient stats:
# Mean: -2.1017e-05
# Std:  4.7456e-03
# Max:  1.8284e-02
# Min:  -1.5351e-02
# Average psi change: 9.9902e-05
# Epoch 0, Loss: 1110.8492, Gradients - Lambda: 5.207e-01, Phi: 1.437e+01, Gamma: 5.166e-02, Psi: 1.828e-02
#
# Epoch 1
# Loss: 839.9232
# Psi gradient stats:
# Mean: -2.1409e-05
# Std:  4.7301e-03
# Max:  1.7983e-02
# Min:  -1.5282e-02
# Average psi change: 9.9427e-05
# Epoch 1, Loss: 839.9232, Gradients - Lambda: 4.851e-01, Phi: 1.254e+01, Gamma: 5.086e-02, Psi: 1.798e-02
#
# Estimated total training time: 585.4 minutes
#
# Epoch 2
# Loss: 647.3206
# Psi gradient stats:
# Mean: -2.1917e-05
# Std:  4.7147e-03
# Max:  1.7667e-02
# Min:  -1.5391e-02
# Average psi change: 9.9014e-05
# Epoch 2, Loss: 647.3206, Gradients - Lambda: 4.507e-01, Phi: 1.168e+01, Gamma: 4.990e-02, Psi: 1.767e-02
#
# Epoch 3
# Loss: 515.6475
# Psi gradient stats:
# Mean: -2.2412e-05
# Std:  4.6994e-03
# Max:  1.7348e-02
# Min:  -1.5511e-02
# Average psi change: 9.8662e-05
# Epoch 3, Loss: 515.6475, Gradients - Lambda: 4.287e-01, Phi: 1.077e+01, Gamma: 4.880e-02, Psi: 1.735e-02
#
# Epoch 4
# Loss: 428.3231
# Psi gradient stats:
# Mean: -2.2658e-05
# Std:  4.6839e-03
# Max:  1.7036e-02
# Min:  -1.5621e-02
# Average psi change: 9.8382e-05
# Epoch 4, Loss: 428.3231, Gradients - Lambda: 4.000e-01, Phi: 9.865e+00, Gamma: 4.767e-02, Psi: 1.704e-02
#
# Epoch 5
# Loss: 371.9991
# Psi gradient stats:
# Mean: -2.2608e-05
# Std:  4.6682e-03
# Max:  1.6735e-02
# Min:  -1.5709e-02
# Average psi change: 9.8059e-05
# Epoch 5, Loss: 371.9991, Gradients - Lambda: 3.656e-01, Phi: 8.956e+00, Gamma: 4.663e-02, Psi: 1.673e-02
#
# Epoch 6
# Loss: 336.7117
# Psi gradient stats:
# Mean: -2.2256e-05
# Std:  4.6524e-03
# Max:  1.6452e-02
# Min:  -1.5774e-02
# Average psi change: 9.7680e-05
# Epoch 6, Loss: 336.7117, Gradients - Lambda: 3.277e-01, Phi: 8.049e+00, Gamma: 4.567e-02, Psi: 1.645e-02
#
# Epoch 7
# Loss: 315.1275
# Psi gradient stats:
# Mean: -2.1737e-05
# Std:  4.6366e-03
# Max:  1.6183e-02
# Min:  -1.5814e-02
# Average psi change: 9.7238e-05
# Epoch 7, Loss: 315.1275, Gradients - Lambda: 2.886e-01, Phi: 7.153e+00, Gamma: 4.475e-02, Psi: 1.618e-02
#
# Epoch 8
# Loss: 301.9475
# Psi gradient stats:
# Mean: -2.1267e-05
# Std:  4.6210e-03
# Max:  1.5928e-02
# Min:  -1.5840e-02
# Average psi change: 9.6859e-05
# Epoch 8, Loss: 301.9475, Gradients - Lambda: 2.543e-01, Phi: 6.288e+00, Gamma: 4.384e-02, Psi: 1.593e-02
#
# Epoch 9
# Loss: 293.5593
# Psi gradient stats:
# Mean: -2.1024e-05
# Std:  4.6057e-03
# Max:  1.5691e-02
# Min:  -1.5856e-02
# Average psi change: 9.6539e-05
# Epoch 9, Loss: 293.5593, Gradients - Lambda: 2.309e-01, Phi: 5.609e+00, Gamma: 4.293e-02, Psi: 1.586e-02
#
# Epoch 10
# Loss: 287.6744
# Psi gradient stats:
# Mean: -2.1109e-05
# Std:  4.5909e-03
# Max:  1.5468e-02
# Min:  -1.5870e-02
# Average psi change: 9.6294e-05
# Epoch 10, Loss: 287.6744, Gradients - Lambda: 2.086e-01, Phi: 5.094e+00, Gamma: 4.203e-02, Psi: 1.587e-02
#
# Epoch 11
# Loss: 282.9518
# Psi gradient stats:
# Mean: -2.1466e-05
# Std:  4.5769e-03
# Max:  1.5445e-02
# Min:  -1.5886e-02
# Average psi change: 9.6093e-05
#
# Epoch 12
# Loss: 278.6735
# Psi gradient stats:
# Mean: -2.1978e-05
# Std:  4.5640e-03
# Max:  1.5556e-02
# Min:  -1.5905e-02
# Average psi change: 9.5884e-05
#
# Epoch 13
# Loss: 274.5228
# Psi gradient stats:
# Mean: -2.2532e-05
# Std:  4.5523e-03
# Max:  1.5636e-02
# Min:  -1.5928e-02
# Average psi change: 9.5650e-05
#
# Epoch 14
# Loss: 270.4188
# Psi gradient stats:
# Mean: -2.3045e-05
# Std:  4.5419e-03
# Max:  1.5689e-02
# Min:  -1.5955e-02
# Average psi change: 9.5418e-05
#
# Epoch 15
# Loss: 266.4227
# Psi gradient stats:
# Mean: -2.3484e-05
# Std:  4.5329e-03
# Max:  1.5726e-02
# Min:  -1.5988e-02
# Average psi change: 9.5223e-05
#
# Epoch 16
# Loss: 262.6364
# Psi gradient stats:
# Mean: -2.3845e-05
# Std:  4.5252e-03
# Max:  1.5758e-02
# Min:  -1.6026e-02
# Average psi change: 9.5031e-05
#
# Epoch 17
# Loss: 259.1553
# Psi gradient stats:
# Mean: -2.4083e-05
# Std:  4.5186e-03
# Max:  1.5790e-02
# Min:  -1.6073e-02
# Average psi change: 9.4914e-05
#
# Epoch 18
# Loss: 256.0444
# Psi gradient stats:
# Mean: -2.4214e-05
# Std:  4.5130e-03
# Max:  1.5827e-02
# Min:  -1.6127e-02
# Average psi change: 9.4846e-05
#
# Epoch 19
# Loss: 253.3313
# Psi gradient stats:
# Mean: -2.4318e-05
# Std:  4.5081e-03
# Max:  1.5866e-02
# Min:  -1.6186e-02
# Average psi change: 9.4829e-05
#
# Epoch 20
# Loss: 251.0087
# Psi gradient stats:
# Mean: -2.4487e-05
# Std:  4.5038e-03
# Max:  1.5904e-02
# Min:  -1.6245e-02
# Average psi change: 9.4863e-05
# Epoch 20, Loss: 251.0087, Gradients - Lambda: 7.216e-02, Phi: 1.763e+00, Gamma: 3.531e-02, Psi: 1.625e-02
#
# Epoch 21
# Loss: 249.0362
# Psi gradient stats:
# Mean: -2.4800e-05
# Std:  4.4999e-03
# Max:  1.5935e-02
# Min:  -1.6300e-02
# Average psi change: 9.4898e-05
#
# Epoch 22
# Loss: 247.3607
# Psi gradient stats:
# Mean: -2.5235e-05
# Std:  4.4965e-03
# Max:  1.5956e-02
# Min:  -1.6346e-02
# Average psi change: 9.4940e-05
#
# Epoch 23
# Loss: 245.9358
# Psi gradient stats:
# Mean: -2.5684e-05
# Std:  4.4935e-03
# Max:  1.5964e-02
# Min:  -1.6379e-02
# Average psi change: 9.4954e-05
#
# Epoch 24
# Loss: 244.7076
# Psi gradient stats:
# Mean: -2.6010e-05
# Std:  4.4908e-03
# Max:  1.5963e-02
# Min:  -1.6399e-02
# Average psi change: 9.4966e-05
#
# Epoch 25
# Loss: 243.6316
# Psi gradient stats:
# Mean: -2.6131e-05
# Std:  4.4884e-03
# Max:  1.5953e-02
# Min:  -1.6408e-02
# Average psi change: 9.4983e-05
#
# Epoch 26
# Loss: 242.6722
# Psi gradient stats:
# Mean: -2.6060e-05
# Std:  4.4862e-03
# Max:  1.5941e-02
# Min:  -1.6409e-02
# Average psi change: 9.4982e-05
#
# Epoch 27
# Loss: 241.8023
# Psi gradient stats:
# Mean: -2.5886e-05
# Std:  4.4842e-03
# Max:  1.5929e-02
# Min:  -1.6407e-02
# Average psi change: 9.4980e-05
#
# Epoch 28
# Loss: 241.0005
# Psi gradient stats:
# Mean: -2.5756e-05
# Std:  4.4822e-03
# Max:  1.5917e-02
# Min:  -1.6405e-02
# Average psi change: 9.4962e-05
#
# Epoch 29
# Loss: 240.2604
# Psi gradient stats:
# Mean: -2.5754e-05
# Std:  4.4802e-03
# Max:  1.5905e-02
# Min:  -1.6406e-02
# Average psi change: 9.4932e-05
#
# Epoch 30
# Loss: 239.5728
# Psi gradient stats:
# Mean: -2.5887e-05
# Std:  4.4782e-03
# Max:  1.5896e-02
# Min:  -1.6411e-02
# Average psi change: 9.4890e-05
# Epoch 30, Loss: 239.5728, Gradients - Lambda: 3.658e-02, Phi: 8.845e-01, Gamma: 3.011e-02, Psi: 1.641e-02
#
# Epoch 31
# Loss: 238.9307
# Psi gradient stats:
# Mean: -2.6054e-05
# Std:  4.4763e-03
# Max:  1.5888e-02
# Min:  -1.6420e-02
# Average psi change: 9.4838e-05
#
# Epoch 32
# Loss: 238.3299
# Psi gradient stats:
# Mean: -2.6183e-05
# Std:  4.4744e-03
# Max:  1.5881e-02
# Min:  -1.6431e-02
# Average psi change: 9.4769e-05
#
# Epoch 33
# Loss: 237.7664
# Psi gradient stats:
# Mean: -2.6233e-05
# Std:  4.4727e-03
# Max:  1.5873e-02
# Min:  -1.6440e-02
# Average psi change: 9.4685e-05
#
# Epoch 34
# Loss: 237.2390
# Psi gradient stats:
# Mean: -2.6281e-05
# Std:  4.4710e-03
# Max:  1.5865e-02
# Min:  -1.6443e-02
# Average psi change: 9.4592e-05
#
# Epoch 35
# Loss: 236.7421
# Psi gradient stats:
# Mean: -2.6369e-05
# Std:  4.4694e-03
# Max:  1.5854e-02
# Min:  -1.6437e-02
# Average psi change: 9.4488e-05
#
# Epoch 36
# Loss: 236.2706
# Psi gradient stats:
# Mean: -2.6522e-05
# Std:  4.4678e-03
# Max:  1.5844e-02
# Min:  -1.6422e-02
# Average psi change: 9.4379e-05
#
# Epoch 37
# Loss: 235.8249
# Psi gradient stats:
# Mean: -2.6709e-05
# Std:  4.4662e-03
# Max:  1.5836e-02
# Min:  -1.6404e-02
# Average psi change: 9.4267e-05
#
# Epoch 38
# Loss: 235.4023
# Psi gradient stats:
# Mean: -2.6856e-05
# Std:  4.4646e-03
# Max:  1.5828e-02
# Min:  -1.6387e-02
# Average psi change: 9.4153e-05
#
# Epoch 39
# Loss: 234.9976
# Psi gradient stats:
# Mean: -2.6926e-05
# Std:  4.4631e-03
# Max:  1.5820e-02
# Min:  -1.6375e-02
# Average psi change: 9.4037e-05
#
# Epoch 40
# Loss: 234.6078
# Psi gradient stats:
# Mean: -2.6923e-05
# Std:  4.4616e-03
# Max:  1.5811e-02
# Min:  -1.6366e-02
# Average psi change: 9.3922e-05
# Epoch 40, Loss: 234.6078, Gradients - Lambda: 2.410e-02, Phi: 6.241e-01, Gamma: 2.533e-02, Psi: 1.637e-02
#
# Epoch 41
# Loss: 234.2394
# Psi gradient stats:
# Mean: -2.6878e-05
# Std:  4.4601e-03
# Max:  1.5800e-02
# Min:  -1.6359e-02
# Average psi change: 9.3809e-05
#
# Epoch 42
# Loss: 233.8833
# Psi gradient stats:
# Mean: -2.6820e-05
# Std:  4.4586e-03
# Max:  1.5787e-02
# Min:  -1.6348e-02
# Average psi change: 9.3703e-05
#
# Epoch 43
# Loss: 233.5384
# Psi gradient stats:
# Mean: -2.6767e-05
# Std:  4.4570e-03
# Max:  1.5777e-02
# Min:  -1.6332e-02
# Average psi change: 9.3601e-05
#
# Epoch 44
# Loss: 233.2107
# Psi gradient stats:
# Mean: -2.6704e-05
# Std:  4.4554e-03
# Max:  1.5772e-02
# Min:  -1.6315e-02
# Average psi change: 9.3513e-05
#
# Epoch 45
# Loss: 232.8913
# Psi gradient stats:
# Mean: -2.6594e-05
# Std:  4.4539e-03
# Max:  1.5770e-02
# Min:  -1.6300e-02
# Average psi change: 9.3429e-05
#
# Epoch 46
# Loss: 232.5814
# Psi gradient stats:
# Mean: -2.6463e-05
# Std:  4.4524e-03
# Max:  1.5769e-02
# Min:  -1.6290e-02
# Average psi change: 9.3355e-05
#
# Epoch 47
# Loss: 232.2842
# Psi gradient stats:
# Mean: -2.6362e-05
# Std:  4.4508e-03
# Max:  1.5768e-02
# Min:  -1.6284e-02
# Average psi change: 9.3286e-05
#
# Epoch 48
# Loss: 231.9951
# Psi gradient stats:
# Mean: -2.6328e-05
# Std:  4.4491e-03
# Max:  1.5765e-02
# Min:  -1.6281e-02
# Average psi change: 9.3224e-05
#
# Epoch 49
# Loss: 231.7114
# Psi gradient stats:
# Mean: -2.6356e-05
# Std:  4.4474e-03
# Max:  1.5761e-02
# Min:  -1.6277e-02
# Average psi change: 9.3164e-05
#
# Epoch 50
# Loss: 231.4398
# Psi gradient stats:
# Mean: -2.6386e-05
# Std:  4.4456e-03
# Max:  1.5759e-02
# Min:  -1.6274e-02
# Average psi change: 9.3111e-05
# Epoch 50, Loss: 231.4398, Gradients - Lambda: 2.560e-02, Phi: 7.656e-01, Gamma: 2.120e-02, Psi: 1.627e-02
#
# Epoch 51
# Loss: 231.1746
# Psi gradient stats:
# Mean: -2.6370e-05
# Std:  4.4439e-03
# Max:  1.5757e-02
# Min:  -1.6272e-02
# Average psi change: 9.3063e-05
#
# Epoch 52
# Loss: 230.9133
# Psi gradient stats:
# Mean: -2.6304e-05
# Std:  4.4423e-03
# Max:  1.5756e-02
# Min:  -1.6274e-02
# Average psi change: 9.3019e-05
#
# Epoch 53
# Loss: 230.6628
# Psi gradient stats:
# Mean: -2.6215e-05
# Std:  4.4407e-03
# Max:  1.5756e-02
# Min:  -1.6275e-02
# Average psi change: 9.2975e-05
#
# Epoch 54
# Loss: 230.4167
# Psi gradient stats:
# Mean: -2.6162e-05
# Std:  4.4390e-03
# Max:  1.5757e-02
# Min:  -1.6277e-02
# Average psi change: 9.2935e-05
#
# Epoch 55
# Loss: 230.1758
# Psi gradient stats:
# Mean: -2.6161e-05
# Std:  4.4372e-03
# Max:  1.5757e-02
# Min:  -1.6275e-02
# Average psi change: 9.2896e-05
#
# Epoch 56
# Loss: 229.9430
# Psi gradient stats:
# Mean: -2.6182e-05
# Std:  4.4354e-03
# Max:  1.5760e-02
# Min:  -1.6269e-02
# Average psi change: 9.2858e-05
#
# Epoch 57
# Loss: 229.7146
# Psi gradient stats:
# Mean: -2.6189e-05
# Std:  4.4338e-03
# Max:  1.5761e-02
# Min:  -1.6262e-02
# Average psi change: 9.2824e-05
#
# Epoch 58
# Loss: 229.4902
# Psi gradient stats:
# Mean: -2.6170e-05
# Std:  4.4322e-03
# Max:  1.5761e-02
# Min:  -1.6259e-02
# Average psi change: 9.2792e-05
#
# Epoch 59
# Loss: 229.2720
# Psi gradient stats:
# Mean: -2.6149e-05
# Std:  4.4306e-03
# Max:  1.5757e-02
# Min:  -1.6258e-02
# Average psi change: 9.2763e-05
#
# Epoch 60
# Loss: 229.0581
# Psi gradient stats:
# Mean: -2.6157e-05
# Std:  4.4288e-03
# Max:  1.5753e-02
# Min:  -1.6258e-02
# Average psi change: 9.2733e-05
# Epoch 60, Loss: 229.0581, Gradients - Lambda: 3.185e-02, Phi: 7.920e-01, Gamma: 1.810e-02, Psi: 1.626e-02
#
# Epoch 61
# Loss: 228.8487
# Psi gradient stats:
# Mean: -2.6186e-05
# Std:  4.4269e-03
# Max:  1.5751e-02
# Min:  -1.6255e-02
# Average psi change: 9.2706e-05
#
# Epoch 62
# Loss: 228.6447
# Psi gradient stats:
# Mean: -2.6227e-05
# Std:  4.4251e-03
# Max:  1.5751e-02
# Min:  -1.6249e-02
# Average psi change: 9.2680e-05
#
# Epoch 63
# Loss: 228.4435
# Psi gradient stats:
# Mean: -2.6256e-05
# Std:  4.4234e-03
# Max:  1.5752e-02
# Min:  -1.6241e-02
# Average psi change: 9.2652e-05
#
# Epoch 64
# Loss: 228.2470
# Psi gradient stats:
# Mean: -2.6268e-05
# Std:  4.4218e-03
# Max:  1.5748e-02
# Min:  -1.6238e-02
# Average psi change: 9.2626e-05
#
# Epoch 65
# Loss: 228.0567
# Psi gradient stats:
# Mean: -2.6299e-05
# Std:  4.4201e-03
# Max:  1.5741e-02
# Min:  -1.6238e-02
# Average psi change: 9.2600e-05
#
# Epoch 66
# Loss: 227.8674
# Psi gradient stats:
# Mean: -2.6327e-05
# Std:  4.4183e-03
# Max:  1.5733e-02
# Min:  -1.6238e-02
# Average psi change: 9.2577e-05
#
# Epoch 67
# Loss: 227.6849
# Psi gradient stats:
# Mean: -2.6350e-05
# Std:  4.4164e-03
# Max:  1.5729e-02
# Min:  -1.6234e-02
# Average psi change: 9.2553e-05
#
# Epoch 68
# Loss: 227.5061
# Psi gradient stats:
# Mean: -2.6353e-05
# Std:  4.4146e-03
# Max:  1.5731e-02
# Min:  -1.6224e-02
# Average psi change: 9.2527e-05
#
# Epoch 69
# Loss: 227.3289
# Psi gradient stats:
# Mean: -2.6341e-05
# Std:  4.4129e-03
# Max:  1.5734e-02
# Min:  -1.6213e-02
# Average psi change: 9.2498e-05
#
# Epoch 70
# Loss: 227.1571
# Psi gradient stats:
# Mean: -2.6346e-05
# Std:  4.4113e-03
# Max:  1.5732e-02
# Min:  -1.6207e-02
# Average psi change: 9.2472e-05
# Epoch 70, Loss: 227.1571, Gradients - Lambda: 3.834e-02, Phi: 9.330e-01, Gamma: 1.539e-02, Psi: 1.621e-02
#
# Epoch 71
# Loss: 226.9889
# Psi gradient stats:
# Mean: -2.6380e-05
# Std:  4.4095e-03
# Max:  1.5724e-02
# Min:  -1.6208e-02
# Average psi change: 9.2446e-05
#
# Epoch 72
# Loss: 226.8209
# Psi gradient stats:
# Mean: -2.6392e-05
# Std:  4.4076e-03
# Max:  1.5714e-02
# Min:  -1.6213e-02
# Average psi change: 9.2421e-05
#
# Epoch 73
# Loss: 226.6627
# Psi gradient stats:
# Mean: -2.6383e-05
# Std:  4.4057e-03
# Max:  1.5709e-02
# Min:  -1.6214e-02
# Average psi change: 9.2394e-05
#
# Epoch 74
# Loss: 226.5032
# Psi gradient stats:
# Mean: -2.6350e-05
# Std:  4.4039e-03
# Max:  1.5712e-02
# Min:  -1.6206e-02
# Average psi change: 9.2366e-05
#
# Epoch 75
# Loss: 226.3467
# Psi gradient stats:
# Mean: -2.6328e-05
# Std:  4.4023e-03
# Max:  1.5717e-02
# Min:  -1.6192e-02
# Average psi change: 9.2336e-05
#
# Epoch 76
# Loss: 226.2010
# Psi gradient stats:
# Mean: -2.6355e-05
# Std:  4.4007e-03
# Max:  1.5717e-02
# Min:  -1.6182e-02
# Average psi change: 9.2305e-05
#
# Epoch 77
# Loss: 226.0516
# Psi gradient stats:
# Mean: -2.6421e-05
# Std:  4.3989e-03
# Max:  1.5708e-02
# Min:  -1.6180e-02
# Average psi change: 9.2274e-05
#
# Epoch 78
# Loss: 225.9047
# Psi gradient stats:
# Mean: -2.6456e-05
# Std:  4.3970e-03
# Max:  1.5698e-02
# Min:  -1.6185e-02
# Average psi change: 9.2251e-05
#
# Epoch 79
# Loss: 225.7692
# Psi gradient stats:
# Mean: -2.6418e-05
# Std:  4.3951e-03
# Max:  1.5693e-02
# Min:  -1.6190e-02
# Average psi change: 9.2227e-05
#
# Epoch 80
# Loss: 225.6282
# Psi gradient stats:
# Mean: -2.6342e-05
# Std:  4.3933e-03
# Max:  1.5695e-02
# Min:  -1.6186e-02
# Average psi change: 9.2200e-05
# Epoch 80, Loss: 225.6282, Gradients - Lambda: 3.933e-02, Phi: 1.033e+00, Gamma: 1.304e-02, Psi: 1.619e-02
#
# Epoch 81
# Loss: 225.4909
# Psi gradient stats:
# Mean: -2.6297e-05
# Std:  4.3916e-03
# Max:  1.5700e-02
# Min:  -1.6174e-02
# Average psi change: 9.2172e-05
#
# Epoch 82
# Loss: 225.3669
# Psi gradient stats:
# Mean: -2.6324e-05
# Std:  4.3899e-03
# Max:  1.5698e-02
# Min:  -1.6159e-02
# Average psi change: 9.2138e-05
#
# Epoch 83
# Loss: 225.2344
# Psi gradient stats:
# Mean: -2.6410e-05
# Std:  4.3882e-03
# Max:  1.5690e-02
# Min:  -1.6150e-02
# Average psi change: 9.2109e-05
#
# Epoch 84
# Loss: 225.1055
# Psi gradient stats:
# Mean: -2.6479e-05
# Std:  4.3863e-03
# Max:  1.5681e-02
# Min:  -1.6151e-02
# Average psi change: 9.2084e-05
#
# Epoch 85
# Loss: 224.9936
# Psi gradient stats:
# Mean: -2.6478e-05
# Std:  4.3845e-03
# Max:  1.5678e-02
# Min:  -1.6158e-02
# Average psi change: 9.2061e-05
#
# Epoch 86
# Loss: 224.8691
# Psi gradient stats:
# Mean: -2.6406e-05
# Std:  4.3826e-03
# Max:  1.5681e-02
# Min:  -1.6161e-02
# Average psi change: 9.2036e-05
#
# Epoch 87
# Loss: 224.7496
# Psi gradient stats:
# Mean: -2.6322e-05
# Std:  4.3809e-03
# Max:  1.5684e-02
# Min:  -1.6153e-02
# Average psi change: 9.2007e-05
#
# Epoch 88
# Loss: 224.6458
# Psi gradient stats:
# Mean: -2.6318e-05
# Std:  4.3791e-03
# Max:  1.5680e-02
# Min:  -1.6138e-02
# Average psi change: 9.1974e-05
#
# Epoch 89
# Loss: 224.5308
# Psi gradient stats:
# Mean: -2.6369e-05
# Std:  4.3774e-03
# Max:  1.5670e-02
# Min:  -1.6127e-02
# Average psi change: 9.1940e-05
#
# Epoch 90
# Loss: 224.4210
# Psi gradient stats:
# Mean: -2.6452e-05
# Std:  4.3756e-03
# Max:  1.5661e-02
# Min:  -1.6123e-02
# Average psi change: 9.1912e-05
# Epoch 90, Loss: 224.4210, Gradients - Lambda: 4.434e-02, Phi: 1.254e+00, Gamma: 1.106e-02, Psi: 1.612e-02
#
# Epoch 91
# Loss: 224.3236
# Psi gradient stats:
# Mean: -2.6504e-05
# Std:  4.3738e-03
# Max:  1.5661e-02
# Min:  -1.6127e-02
# Average psi change: 9.1889e-05
#
# Epoch 92
# Loss: 224.2185
# Psi gradient stats:
# Mean: -2.6477e-05
# Std:  4.3719e-03
# Max:  1.5668e-02
# Min:  -1.6130e-02
# Average psi change: 9.1867e-05
#
# Epoch 93
# Loss: 224.1187
# Psi gradient stats:
# Mean: -2.6393e-05
# Std:  4.3701e-03
# Max:  1.5671e-02
# Min:  -1.6126e-02
# Average psi change: 9.1841e-05
#
# Epoch 94
# Loss: 224.0282
# Psi gradient stats:
# Mean: -2.6307e-05
# Std:  4.3683e-03
# Max:  1.5664e-02
# Min:  -1.6114e-02
# Average psi change: 9.1813e-05
#
# Epoch 95
# Loss: 223.9316
# Psi gradient stats:
# Mean: -2.6320e-05
# Std:  4.3666e-03
# Max:  1.5651e-02
# Min:  -1.6103e-02
# Average psi change: 9.1781e-05
#
# Epoch 96
# Loss: 223.8387
# Psi gradient stats:
# Mean: -2.6426e-05
# Std:  4.3648e-03
# Max:  1.5642e-02
# Min:  -1.6098e-02
# Average psi change: 9.1747e-05
#
# Epoch 97
# Loss: 223.7566
# Psi gradient stats:
# Mean: -2.6558e-05
# Std:  4.3630e-03
# Max:  1.5644e-02
# Min:  -1.6100e-02
# Average psi change: 9.1722e-05
#
# Epoch 98
# Loss: 223.6658
# Psi gradient stats:
# Mean: -2.6607e-05
# Std:  4.3612e-03
# Max:  1.5652e-02
# Min:  -1.6102e-02
# Average psi change: 9.1699e-05
#
# Epoch 99
# Loss: 223.5822
# Psi gradient stats:
# Mean: -2.6517e-05
# Std:  4.3594e-03
# Max:  1.5655e-02
# Min:  -1.6098e-02
# Average psi change: 9.1675e-05
#
# Epoch 100
# Loss: 223.5088
# Psi gradient stats:
# Mean: -2.6343e-05
# Std:  4.3576e-03
# Max:  1.5649e-02
# Min:  -1.6088e-02
# Average psi change: 9.1650e-05
# Epoch 100, Loss: 223.5088, Gradients - Lambda: 4.680e-02, Phi: 1.282e+00, Gamma: 9.310e-03, Psi: 1.609e-02
#
# Epoch 101
# Loss: 223.4219
# Psi gradient stats:
# Mean: -2.6240e-05
# Std:  4.3558e-03
# Max:  1.5634e-02
# Min:  -1.6079e-02
# Average psi change: 9.1619e-05
#
# Epoch 102
# Loss: 223.3448
# Psi gradient stats:
# Mean: -2.6305e-05
# Std:  4.3539e-03
# Max:  1.5626e-02
# Min:  -1.6075e-02
# Average psi change: 9.1587e-05
#
# Epoch 103
# Loss: 223.2805
# Psi gradient stats:
# Mean: -2.6508e-05
# Std:  4.3521e-03
# Max:  1.5629e-02
# Min:  -1.6077e-02
# Average psi change: 9.1557e-05
#
# Epoch 104
# Loss: 223.1993
# Psi gradient stats:
# Mean: -2.6677e-05
# Std:  4.3504e-03
# Max:  1.5640e-02
# Min:  -1.6077e-02
# Average psi change: 9.1529e-05
#
# Epoch 105
# Loss: 223.1266
# Psi gradient stats:
# Mean: -2.6646e-05
# Std:  4.3486e-03
# Max:  1.5643e-02
# Min:  -1.6069e-02
# Average psi change: 9.1505e-05
#
# Epoch 106
# Loss: 223.0707
# Psi gradient stats:
# Mean: -2.6438e-05
# Std:  4.3468e-03
# Max:  1.5632e-02
# Min:  -1.6056e-02
# Average psi change: 9.1483e-05
#
# Epoch 107
# Loss: 222.9943
# Psi gradient stats:
# Mean: -2.6217e-05
# Std:  4.3449e-03
# Max:  1.5615e-02
# Min:  -1.6048e-02
# Average psi change: 9.1455e-05
#
# Epoch 108
# Loss: 222.9236
# Psi gradient stats:
# Mean: -2.6214e-05
# Std:  4.3431e-03
# Max:  1.5606e-02
# Min:  -1.6050e-02
# Average psi change: 9.1425e-05
#
# Epoch 109
# Loss: 222.8759
# Psi gradient stats:
# Mean: -2.6416e-05
# Std:  4.3413e-03
# Max:  1.5610e-02
# Min:  -1.6056e-02
# Average psi change: 9.1391e-05
#
# Epoch 110
# Loss: 222.8052
# Psi gradient stats:
# Mean: -2.6670e-05
# Std:  4.3395e-03
# Max:  1.5622e-02
# Min:  -1.6057e-02
# Average psi change: 9.1361e-05
# Epoch 110, Loss: 222.8052, Gradients - Lambda: 4.965e-02, Phi: 1.273e+00, Gamma: 8.211e-03, Psi: 1.606e-02
#
# Epoch 111
# Loss: 222.7347
# Psi gradient stats:
# Mean: -2.6758e-05
# Std:  4.3377e-03
# Max:  1.5626e-02
# Min:  -1.6044e-02
# Average psi change: 9.1333e-05
#
# Epoch 112
# Loss: 222.6950
# Psi gradient stats:
# Mean: -2.6609e-05
# Std:  4.3359e-03
# Max:  1.5617e-02
# Min:  -1.6023e-02
# Average psi change: 9.1310e-05
#
# Epoch 113
# Loss: 222.6320
# Psi gradient stats:
# Mean: -2.6359e-05
# Std:  4.3341e-03
# Max:  1.5599e-02
# Min:  -1.6010e-02
# Average psi change: 9.1287e-05
#
# Epoch 114
# Loss: 222.5595
# Psi gradient stats:
# Mean: -2.6241e-05
# Std:  4.3323e-03
# Max:  1.5590e-02
# Min:  -1.6015e-02
# Average psi change: 9.1261e-05
#
# Epoch 115
# Loss: 222.5222
# Psi gradient stats:
# Mean: -2.6347e-05
# Std:  4.3305e-03
# Max:  1.5595e-02
# Min:  -1.6031e-02
# Average psi change: 9.1229e-05
#
# Epoch 116
# Loss: 222.4696
# Psi gradient stats:
# Mean: -2.6606e-05
# Std:  4.3287e-03
# Max:  1.5606e-02
# Min:  -1.6040e-02
# Average psi change: 9.1197e-05
#
# Epoch 117
# Loss: 222.3967
# Psi gradient stats:
# Mean: -2.6772e-05
# Std:  4.3269e-03
# Max:  1.5610e-02
# Min:  -1.6029e-02
# Average psi change: 9.1166e-05
#
# Epoch 118
# Loss: 222.3574
# Psi gradient stats:
# Mean: -2.6708e-05
# Std:  4.3251e-03
# Max:  1.5598e-02
# Min:  -1.6000e-02
# Average psi change: 9.1144e-05
#
# Epoch 119
# Loss: 222.3157
# Psi gradient stats:
# Mean: -2.6481e-05
# Std:  4.3232e-03
# Max:  1.5579e-02
# Min:  -1.5976e-02
# Average psi change: 9.1120e-05
#
# Epoch 120
# Loss: 222.2439
# Psi gradient stats:
# Mean: -2.6294e-05
# Std:  4.3215e-03
# Max:  1.5569e-02
# Min:  -1.5975e-02
# Average psi change: 9.1096e-05
# Epoch 120, Loss: 222.2439, Gradients - Lambda: 5.054e-02, Phi: 1.399e+00, Gamma: 6.975e-03, Psi: 1.597e-02
#
# Epoch 121
# Loss: 222.1981
# Psi gradient stats:
# Mean: -2.6319e-05
# Std:  4.3197e-03
# Max:  1.5576e-02
# Min:  -1.5995e-02
# Average psi change: 9.1067e-05
#
# Epoch 122
# Loss: 222.1655
# Psi gradient stats:
# Mean: -2.6526e-05
# Std:  4.3180e-03
# Max:  1.5592e-02
# Min:  -1.6016e-02
# Average psi change: 9.1038e-05
#
# Epoch 123
# Loss: 222.0975
# Psi gradient stats:
# Mean: -2.6734e-05
# Std:  4.3162e-03
# Max:  1.5598e-02
# Min:  -1.6013e-02
# Average psi change: 9.1008e-05
#
# Epoch 124
# Loss: 222.0464
# Psi gradient stats:
# Mean: -2.6734e-05
# Std:  4.3143e-03
# Max:  1.5583e-02
# Min:  -1.5984e-02
# Average psi change: 9.0979e-05
#
# Epoch 125
# Loss: 222.0171
# Psi gradient stats:
# Mean: -2.6529e-05
# Std:  4.3124e-03
# Max:  1.5559e-02
# Min:  -1.5950e-02
# Average psi change: 9.0959e-05
#
# Epoch 126
# Loss: 221.9556
# Psi gradient stats:
# Mean: -2.6318e-05
# Std:  4.3107e-03
# Max:  1.5546e-02
# Min:  -1.5939e-02
# Average psi change: 9.0936e-05
#
# Epoch 127
# Loss: 221.8992
# Psi gradient stats:
# Mean: -2.6290e-05
# Std:  4.3090e-03
# Max:  1.5554e-02
# Min:  -1.5956e-02
# Average psi change: 9.0912e-05
#
# Epoch 128
# Loss: 221.8719
# Psi gradient stats:
# Mean: -2.6491e-05
# Std:  4.3073e-03
# Max:  1.5574e-02
# Min:  -1.5983e-02
# Average psi change: 9.0884e-05
#
# Epoch 129
# Loss: 221.8137
# Psi gradient stats:
# Mean: -2.6747e-05
# Std:  4.3054e-03
# Max:  1.5587e-02
# Min:  -1.5991e-02
# Average psi change: 9.0856e-05
#
# Epoch 130
# Loss: 221.7550
# Psi gradient stats:
# Mean: -2.6838e-05
# Std:  4.3035e-03
# Max:  1.5576e-02
# Min:  -1.5968e-02
# Average psi change: 9.0830e-05
# Epoch 130, Loss: 221.7550, Gradients - Lambda: 5.743e-02, Phi: 1.438e+00, Gamma: 6.033e-03, Psi: 1.597e-02
#
# Epoch 131
# Loss: 221.7254
# Psi gradient stats:
# Mean: -2.6668e-05
# Std:  4.3016e-03
# Max:  1.5549e-02
# Min:  -1.5931e-02
# Average psi change: 9.0807e-05
#
# Epoch 132
# Loss: 221.6712
# Psi gradient stats:
# Mean: -2.6380e-05
# Std:  4.2999e-03
# Max:  1.5526e-02
# Min:  -1.5909e-02
# Average psi change: 9.0785e-05
#
# Epoch 133
# Loss: 221.6100
# Psi gradient stats:
# Mean: -2.6231e-05
# Std:  4.2983e-03
# Max:  1.5526e-02
# Min:  -1.5920e-02
# Average psi change: 9.0758e-05
#
# Epoch 134
# Loss: 221.5789
# Psi gradient stats:
# Mean: -2.6346e-05
# Std:  4.2967e-03
# Max:  1.5547e-02
# Min:  -1.5947e-02
# Average psi change: 9.0730e-05
#
# Epoch 135
# Loss: 221.5268
# Psi gradient stats:
# Mean: -2.6647e-05
# Std:  4.2948e-03
# Max:  1.5567e-02
# Min:  -1.5961e-02
# Average psi change: 9.0703e-05
#
# Epoch 136
# Loss: 221.4642
# Psi gradient stats:
# Mean: -2.6856e-05
# Std:  4.2927e-03
# Max:  1.5567e-02
# Min:  -1.5945e-02
# Average psi change: 9.0678e-05
#
# Epoch 137
# Loss: 221.4304
# Psi gradient stats:
# Mean: -2.6803e-05
# Std:  4.2908e-03
# Max:  1.5544e-02
# Min:  -1.5911e-02
# Average psi change: 9.0656e-05
#
# Epoch 138
# Loss: 221.3781
# Psi gradient stats:
# Mean: -2.6536e-05
# Std:  4.2891e-03
# Max:  1.5516e-02
# Min:  -1.5885e-02
# Average psi change: 9.0634e-05
#
# Epoch 139
# Loss: 221.3165
# Psi gradient stats:
# Mean: -2.6324e-05
# Std:  4.2877e-03
# Max:  1.5506e-02
# Min:  -1.5887e-02
# Average psi change: 9.0610e-05
#
# Epoch 140
# Loss: 221.2790
# Psi gradient stats:
# Mean: -2.6350e-05
# Std:  4.2862e-03
# Max:  1.5520e-02
# Min:  -1.5910e-02
# Average psi change: 9.0581e-05
# Epoch 140, Loss: 221.2790, Gradients - Lambda: 5.352e-02, Phi: 1.404e+00, Gamma: 5.769e-03, Psi: 1.591e-02
#
# Epoch 141
# Loss: 221.2254
# Psi gradient stats:
# Mean: -2.6575e-05
# Std:  4.2843e-03
# Max:  1.5542e-02
# Min:  -1.5928e-02
# Average psi change: 9.0550e-05
#
# Epoch 142
# Loss: 221.1620
# Psi gradient stats:
# Mean: -2.6786e-05
# Std:  4.2822e-03
# Max:  1.5549e-02
# Min:  -1.5918e-02
# Average psi change: 9.0525e-05
#
# Epoch 143
# Loss: 221.1222
# Psi gradient stats:
# Mean: -2.6757e-05
# Std:  4.2801e-03
# Max:  1.5534e-02
# Min:  -1.5888e-02
# Average psi change: 9.0502e-05
#
# Epoch 144
# Loss: 221.0694
# Psi gradient stats:
# Mean: -2.6538e-05
# Std:  4.2783e-03
# Max:  1.5506e-02
# Min:  -1.5864e-02
# Average psi change: 9.0484e-05
#
# Epoch 145
# Loss: 221.0028
# Psi gradient stats:
# Mean: -2.6381e-05
# Std:  4.2769e-03
# Max:  1.5488e-02
# Min:  -1.5863e-02
# Average psi change: 9.0462e-05
#
# Epoch 146
# Loss: 220.9599
# Psi gradient stats:
# Mean: -2.6463e-05
# Std:  4.2756e-03
# Max:  1.5495e-02
# Min:  -1.5881e-02
# Average psi change: 9.0437e-05
#
# Epoch 147
# Loss: 220.9095
# Psi gradient stats:
# Mean: -2.6702e-05
# Std:  4.2740e-03
# Max:  1.5518e-02
# Min:  -1.5892e-02
# Average psi change: 9.0404e-05
#
# Epoch 148
# Loss: 220.8394
# Psi gradient stats:
# Mean: -2.6864e-05
# Std:  4.2718e-03
# Max:  1.5533e-02
# Min:  -1.5882e-02
# Average psi change: 9.0373e-05
#
# Epoch 149
# Loss: 220.7896
# Psi gradient stats:
# Mean: -2.6768e-05
# Std:  4.2695e-03
# Max:  1.5525e-02
# Min:  -1.5859e-02
# Average psi change: 9.0348e-05
#
# Epoch 150
# Loss: 220.7394
# Psi gradient stats:
# Mean: -2.6489e-05
# Std:  4.2675e-03
# Max:  1.5498e-02
# Min:  -1.5842e-02
# Average psi change: 9.0330e-05
# Epoch 150, Loss: 220.7394, Gradients - Lambda: 5.343e-02, Phi: 1.434e+00, Gamma: 5.645e-03, Psi: 1.584e-02
#
# Epoch 151
# Loss: 220.6713
# Psi gradient stats:
# Mean: -2.6295e-05
# Std:  4.2661e-03
# Max:  1.5472e-02
# Min:  -1.5845e-02
# Average psi change: 9.0311e-05
#
# Epoch 152
# Loss: 220.6151
# Psi gradient stats:
# Mean: -2.6378e-05
# Std:  4.2650e-03
# Max:  1.5469e-02
# Min:  -1.5859e-02
# Average psi change: 9.0285e-05
#
# Epoch 153
# Loss: 220.5620
# Psi gradient stats:
# Mean: -2.6691e-05
# Std:  4.2636e-03
# Max:  1.5490e-02
# Min:  -1.5863e-02
# Average psi change: 9.0255e-05
#
# Epoch 154
# Loss: 220.4964
# Psi gradient stats:
# Mean: -2.6943e-05
# Std:  4.2616e-03
# Max:  1.5516e-02
# Min:  -1.5845e-02
# Average psi change: 9.0217e-05
#
# Epoch 155
# Loss: 220.4384
# Psi gradient stats:
# Mean: -2.6904e-05
# Std:  4.2593e-03
# Max:  1.5521e-02
# Min:  -1.5817e-02
# Average psi change: 9.0189e-05
#
# Epoch 156
# Loss: 220.3803
# Psi gradient stats:
# Mean: -2.6604e-05
# Std:  4.2570e-03
# Max:  1.5498e-02
# Min:  -1.5808e-02
# Average psi change: 9.0166e-05
#
# Epoch 157
# Loss: 220.3125
# Psi gradient stats:
# Mean: -2.6297e-05
# Std:  4.2553e-03
# Max:  1.5463e-02
# Min:  -1.5823e-02
# Average psi change: 9.0146e-05
#
# Epoch 158
# Loss: 220.2538
# Psi gradient stats:
# Mean: -2.6243e-05
# Std:  4.2541e-03
# Max:  1.5443e-02
# Min:  -1.5847e-02
# Average psi change: 9.0123e-05
#
# Epoch 159
# Loss: 220.1978
# Psi gradient stats:
# Mean: -2.6483e-05
# Std:  4.2530e-03
# Max:  1.5452e-02
# Min:  -1.5849e-02
# Average psi change: 9.0096e-05
#
# Epoch 160
# Loss: 220.1242
# Psi gradient stats:
# Mean: -2.6812e-05
# Std:  4.2515e-03
# Max:  1.5482e-02
# Min:  -1.5821e-02
# Average psi change: 9.0065e-05
# Epoch 160, Loss: 220.1242, Gradients - Lambda: 5.467e-02, Phi: 1.388e+00, Gamma: 5.735e-03, Psi: 1.582e-02
#
# Epoch 161
# Loss: 220.0598
# Psi gradient stats:
# Mean: -2.6964e-05
# Std:  4.2493e-03
# Max:  1.5506e-02
# Min:  -1.5779e-02
# Average psi change: 9.0028e-05
#
# Epoch 162
# Loss: 220.0051
# Psi gradient stats:
# Mean: -2.6846e-05
# Std:  4.2468e-03
# Max:  1.5502e-02
# Min:  -1.5762e-02
# Average psi change: 8.9999e-05
#
# Epoch 163
# Loss: 219.9321
# Psi gradient stats:
# Mean: -2.6576e-05
# Std:  4.2447e-03
# Max:  1.5470e-02
# Min:  -1.5782e-02
# Average psi change: 8.9974e-05
#
# Epoch 164
# Loss: 219.8611
# Psi gradient stats:
# Mean: -2.6349e-05
# Std:  4.2432e-03
# Max:  1.5435e-02
# Min:  -1.5820e-02
# Average psi change: 8.9955e-05
#
# Epoch 165
# Loss: 219.8057
# Psi gradient stats:
# Mean: -2.6340e-05
# Std:  4.2421e-03
# Max:  1.5423e-02
# Min:  -1.5836e-02
# Average psi change: 8.9936e-05
#
# Epoch 166
# Loss: 219.7361
# Psi gradient stats:
# Mean: -2.6512e-05
# Std:  4.2410e-03
# Max:  1.5441e-02
# Min:  -1.5811e-02
# Average psi change: 8.9910e-05
#
# Epoch 167
# Loss: 219.6601
# Psi gradient stats:
# Mean: -2.6726e-05
# Std:  4.2392e-03
# Max:  1.5472e-02
# Min:  -1.5763e-02
# Average psi change: 8.9878e-05
#
# Epoch 168
# Loss: 219.5989
# Psi gradient stats:
# Mean: -2.6840e-05
# Std:  4.2370e-03
# Max:  1.5490e-02
# Min:  -1.5730e-02
# Average psi change: 8.9840e-05
#
# Epoch 169
# Loss: 219.5341
# Psi gradient stats:
# Mean: -2.6795e-05
# Std:  4.2347e-03
# Max:  1.5476e-02
# Min:  -1.5735e-02
# Average psi change: 8.9804e-05
#
# Epoch 170
# Loss: 219.4576
# Psi gradient stats:
# Mean: -2.6630e-05
# Std:  4.2327e-03
# Max:  1.5441e-02
# Min:  -1.5769e-02
# Average psi change: 8.9779e-05
# Epoch 170, Loss: 219.4576, Gradients - Lambda: 5.573e-02, Phi: 1.427e+00, Gamma: 5.531e-03, Psi: 1.577e-02
#
# Epoch 171
# Loss: 219.3866
# Psi gradient stats:
# Mean: -2.6457e-05
# Std:  4.2313e-03
# Max:  1.5409e-02
# Min:  -1.5797e-02
# Average psi change: 8.9765e-05
#
# Epoch 172
# Loss: 219.3257
# Psi gradient stats:
# Mean: -2.6378e-05
# Std:  4.2302e-03
# Max:  1.5406e-02
# Min:  -1.5795e-02
# Average psi change: 8.9748e-05
#
# Epoch 173
# Loss: 219.2542
# Psi gradient stats:
# Mean: -2.6449e-05
# Std:  4.2289e-03
# Max:  1.5430e-02
# Min:  -1.5763e-02
# Average psi change: 8.9721e-05
#
# Epoch 174
# Loss: 219.1746
# Psi gradient stats:
# Mean: -2.6624e-05
# Std:  4.2271e-03
# Max:  1.5461e-02
# Min:  -1.5727e-02
# Average psi change: 8.9687e-05
#
# Epoch 175
# Loss: 219.1078
# Psi gradient stats:
# Mean: -2.6790e-05
# Std:  4.2249e-03
# Max:  1.5470e-02
# Min:  -1.5712e-02
# Average psi change: 8.9648e-05
#
# Epoch 176
# Loss: 219.0453
# Psi gradient stats:
# Mean: -2.6820e-05
# Std:  4.2228e-03
# Max:  1.5449e-02
# Min:  -1.5720e-02
# Average psi change: 8.9612e-05
#
# Epoch 177
# Loss: 218.9631
# Psi gradient stats:
# Mean: -2.6676e-05
# Std:  4.2209e-03
# Max:  1.5411e-02
# Min:  -1.5737e-02
# Average psi change: 8.9586e-05
#
# Epoch 178
# Loss: 218.8872
# Psi gradient stats:
# Mean: -2.6452e-05
# Std:  4.2195e-03
# Max:  1.5386e-02
# Min:  -1.5746e-02
# Average psi change: 8.9573e-05
#
# Epoch 179
# Loss: 218.8278
# Psi gradient stats:
# Mean: -2.6324e-05
# Std:  4.2183e-03
# Max:  1.5390e-02
# Min:  -1.5741e-02
# Average psi change: 8.9553e-05
#
# Epoch 180
# Loss: 218.7554
# Psi gradient stats:
# Mean: -2.6397e-05
# Std:  4.2169e-03
# Max:  1.5420e-02
# Min:  -1.5730e-02
# Average psi change: 8.9529e-05
# Epoch 180, Loss: 218.7554, Gradients - Lambda: 5.496e-02, Phi: 1.417e+00, Gamma: 5.756e-03, Psi: 1.573e-02
#
# Epoch 181
# Loss: 218.6676
# Psi gradient stats:
# Mean: -2.6653e-05
# Std:  4.2151e-03
# Max:  1.5447e-02
# Min:  -1.5717e-02
# Average psi change: 8.9496e-05
#
# Epoch 182
# Loss: 218.6020
# Psi gradient stats:
# Mean: -2.6874e-05
# Std:  4.2130e-03
# Max:  1.5450e-02
# Min:  -1.5703e-02
# Average psi change: 8.9457e-05
#
# Epoch 183
# Loss: 218.5426
# Psi gradient stats:
# Mean: -2.6870e-05
# Std:  4.2110e-03
# Max:  1.5423e-02
# Min:  -1.5687e-02
# Average psi change: 8.9422e-05
#
# Epoch 184
# Loss: 218.4542
# Psi gradient stats:
# Mean: -2.6618e-05
# Std:  4.2092e-03
# Max:  1.5386e-02
# Min:  -1.5678e-02
# Average psi change: 8.9394e-05
#
# Epoch 185
# Loss: 218.3745
# Psi gradient stats:
# Mean: -2.6319e-05
# Std:  4.2077e-03
# Max:  1.5367e-02
# Min:  -1.5683e-02
# Average psi change: 8.9377e-05
#
# Epoch 186
# Loss: 218.3188
# Psi gradient stats:
# Mean: -2.6232e-05
# Std:  4.2064e-03
# Max:  1.5379e-02
# Min:  -1.5703e-02
# Average psi change: 8.9355e-05
#
# Epoch 187
# Loss: 218.2435
# Psi gradient stats:
# Mean: -2.6455e-05
# Std:  4.2050e-03
# Max:  1.5410e-02
# Min:  -1.5720e-02
# Average psi change: 8.9333e-05
#
# Epoch 188
# Loss: 218.1527
# Psi gradient stats:
# Mean: -2.6836e-05
# Std:  4.2033e-03
# Max:  1.5435e-02
# Min:  -1.5716e-02
# Average psi change: 8.9303e-05
#
# Epoch 189
# Loss: 218.0889
# Psi gradient stats:
# Mean: -2.7048e-05
# Std:  4.2013e-03
# Max:  1.5430e-02
# Min:  -1.5682e-02
# Average psi change: 8.9271e-05
#
# Epoch 190
# Loss: 218.0275
# Psi gradient stats:
# Mean: -2.6853e-05
# Std:  4.1993e-03
# Max:  1.5398e-02
# Min:  -1.5637e-02
# Average psi change: 8.9233e-05
# Epoch 190, Loss: 218.0275, Gradients - Lambda: 5.659e-02, Phi: 1.409e+00, Gamma: 5.534e-03, Psi: 1.564e-02
#
# Epoch 191
# Loss: 217.9381
# Psi gradient stats:
# Mean: -2.6402e-05
# Std:  4.1975e-03
# Max:  1.5361e-02
# Min:  -1.5614e-02
# Average psi change: 8.9201e-05
#
# Epoch 192
# Loss: 217.8613
# Psi gradient stats:
# Mean: -2.6058e-05
# Std:  4.1959e-03
# Max:  1.5347e-02
# Min:  -1.5635e-02
# Average psi change: 8.9175e-05
#
# Epoch 193
# Loss: 217.8040
# Psi gradient stats:
# Mean: -2.6140e-05
# Std:  4.1945e-03
# Max:  1.5363e-02
# Min:  -1.5686e-02
# Average psi change: 8.9152e-05
#
# Epoch 194
# Loss: 217.7234
# Psi gradient stats:
# Mean: -2.6614e-05
# Std:  4.1931e-03
# Max:  1.5395e-02
# Min:  -1.5720e-02
# Average psi change: 8.9130e-05
#
# Epoch 195
# Loss: 217.6421
# Psi gradient stats:
# Mean: -2.7101e-05
# Std:  4.1916e-03
# Max:  1.5416e-02
# Min:  -1.5705e-02
# Average psi change: 8.9108e-05
#
# Epoch 196
# Loss: 217.5787
# Psi gradient stats:
# Mean: -2.7166e-05
# Std:  4.1898e-03
# Max:  1.5407e-02
# Min:  -1.5645e-02
# Average psi change: 8.9078e-05
#
# Epoch 197
# Loss: 217.5049
# Psi gradient stats:
# Mean: -2.6739e-05
# Std:  4.1878e-03
# Max:  1.5374e-02
# Min:  -1.5583e-02
# Average psi change: 8.9043e-05
#
# Epoch 198
# Loss: 217.4266
# Psi gradient stats:
# Mean: -2.6161e-05
# Std:  4.1858e-03
# Max:  1.5340e-02
# Min:  -1.5568e-02
# Average psi change: 8.9009e-05
#
# Epoch 199
# Loss: 217.3553
# Psi gradient stats:
# Mean: -2.5911e-05
# Std:  4.1841e-03
# Max:  1.5329e-02
# Min:  -1.5610e-02
# Average psi change: 8.8979e-05
#
# Epoch 200
# Loss: 217.2823
# Psi gradient stats:
# Mean: -2.6215e-05
# Std:  4.1827e-03
# Max:  1.5348e-02
# Min:  -1.5673e-02
# Average psi change: 8.8952e-05
# Epoch 200, Loss: 217.2823, Gradients - Lambda: 5.625e-02, Phi: 1.416e+00, Gamma: 5.629e-03, Psi: 1.567e-02
#
# Epoch 201
# Loss: 217.2128
# Psi gradient stats:
# Mean: -2.6845e-05
# Std:  4.1814e-03
# Max:  1.5380e-02
# Min:  -1.5702e-02
# Average psi change: 8.8928e-05
#
# Epoch 202
# Loss: 217.1403
# Psi gradient stats:
# Mean: -2.7259e-05
# Std:  4.1800e-03
# Max:  1.5398e-02
# Min:  -1.5668e-02
# Average psi change: 8.8907e-05
#
# Epoch 203
# Loss: 217.0603
# Psi gradient stats:
# Mean: -2.7106e-05
# Std:  4.1783e-03
# Max:  1.5387e-02
# Min:  -1.5597e-02
# Average psi change: 8.8880e-05
#
# Epoch 204
# Loss: 216.9964
# Psi gradient stats:
# Mean: -2.6496e-05
# Std:  4.1764e-03
# Max:  1.5351e-02
# Min:  -1.5545e-02
# Average psi change: 8.8849e-05
#
# Epoch 205
# Loss: 216.9296
# Psi gradient stats:
# Mean: -2.5944e-05
# Std:  4.1743e-03
# Max:  1.5318e-02
# Min:  -1.5551e-02
# Average psi change: 8.8812e-05
#
# Epoch 206
# Loss: 216.8423
# Psi gradient stats:
# Mean: -2.5897e-05
# Std:  4.1725e-03
# Max:  1.5311e-02
# Min:  -1.5605e-02
# Average psi change: 8.8779e-05
#
# Epoch 207
# Loss: 216.7765
# Psi gradient stats:
# Mean: -2.6385e-05
# Std:  4.1711e-03
# Max:  1.5332e-02
# Min:  -1.5655e-02
# Average psi change: 8.8754e-05
#
# Epoch 208
# Loss: 216.7209
# Psi gradient stats:
# Mean: -2.7014e-05
# Std:  4.1699e-03
# Max:  1.5362e-02
# Min:  -1.5658e-02
# Average psi change: 8.8729e-05
#
# Epoch 209
# Loss: 216.6340
# Psi gradient stats:
# Mean: -2.7256e-05
# Std:  4.1686e-03
# Max:  1.5378e-02
# Min:  -1.5608e-02
# Average psi change: 8.8709e-05
#
# Epoch 210
# Loss: 216.5583
# Psi gradient stats:
# Mean: -2.6922e-05
# Std:  4.1669e-03
# Max:  1.5365e-02
# Min:  -1.5548e-02
# Average psi change: 8.8682e-05
# Epoch 210, Loss: 216.5583, Gradients - Lambda: 5.656e-02, Phi: 1.511e+00, Gamma: 5.566e-03, Psi: 1.555e-02
#
# Epoch 211
# Loss: 216.5100
# Psi gradient stats:
# Mean: -2.6296e-05
# Std:  4.1649e-03
# Max:  1.5332e-02
# Min:  -1.5525e-02
# Average psi change: 8.8648e-05
#
# Epoch 212
# Loss: 216.4315
# Psi gradient stats:
# Mean: -2.5904e-05
# Std:  4.1628e-03
# Max:  1.5302e-02
# Min:  -1.5554e-02
# Average psi change: 8.8612e-05
#
# Epoch 213
# Loss: 216.3443
# Psi gradient stats:
# Mean: -2.6058e-05
# Std:  4.1611e-03
# Max:  1.5296e-02
# Min:  -1.5604e-02
# Average psi change: 8.8579e-05
#
# Epoch 214
# Loss: 216.2954
# Psi gradient stats:
# Mean: -2.6592e-05
# Std:  4.1597e-03
# Max:  1.5317e-02
# Min:  -1.5625e-02
# Average psi change: 8.8552e-05
#
# Epoch 215
# Loss: 216.2323
# Psi gradient stats:
# Mean: -2.7070e-05
# Std:  4.1585e-03
# Max:  1.5345e-02
# Min:  -1.5597e-02
# Average psi change: 8.8533e-05
#
# Epoch 216
# Loss: 216.1403
# Psi gradient stats:
# Mean: -2.7093e-05
# Std:  4.1572e-03
# Max:  1.5359e-02
# Min:  -1.5539e-02
# Average psi change: 8.8511e-05
#
# Epoch 217
# Loss: 216.0808
# Psi gradient stats:
# Mean: -2.6675e-05
# Std:  4.1555e-03
# Max:  1.5345e-02
# Min:  -1.5503e-02
# Average psi change: 8.8480e-05
#
# Epoch 218
# Loss: 216.0326
# Psi gradient stats:
# Mean: -2.6170e-05
# Std:  4.1534e-03
# Max:  1.5313e-02
# Min:  -1.5516e-02
# Average psi change: 8.8444e-05
#
# Epoch 219
# Loss: 215.9440
# Psi gradient stats:
# Mean: -2.5984e-05
# Std:  4.1514e-03
# Max:  1.5285e-02
# Min:  -1.5563e-02
# Average psi change: 8.8410e-05
#
# Epoch 220
# Loss: 215.8691
# Psi gradient stats:
# Mean: -2.6231e-05
# Std:  4.1498e-03
# Max:  1.5282e-02
# Min:  -1.5600e-02
# Average psi change: 8.8380e-05
# Epoch 220, Loss: 215.8691, Gradients - Lambda: 5.762e-02, Phi: 1.506e+00, Gamma: 5.531e-03, Psi: 1.560e-02
#
# Epoch 221
# Loss: 215.8293
# Psi gradient stats:
# Mean: -2.6678e-05
# Std:  4.1485e-03
# Max:  1.5302e-02
# Min:  -1.5588e-02
# Average psi change: 8.8358e-05
#
# Epoch 222
# Loss: 215.7565
# Psi gradient stats:
# Mean: -2.6946e-05
# Std:  4.1473e-03
# Max:  1.5327e-02
# Min:  -1.5535e-02
# Average psi change: 8.8335e-05
#
# Epoch 223
# Loss: 215.6668
# Psi gradient stats:
# Mean: -2.6842e-05
# Std:  4.1458e-03
# Max:  1.5337e-02
# Min:  -1.5480e-02
# Average psi change: 8.8309e-05
#
# Epoch 224
# Loss: 215.6221
# Psi gradient stats:
# Mean: -2.6506e-05
# Std:  4.1441e-03
# Max:  1.5321e-02
# Min:  -1.5470e-02
# Average psi change: 8.8279e-05
#
# Epoch 225
# Loss: 215.5706
# Psi gradient stats:
# Mean: -2.6218e-05
# Std:  4.1421e-03
# Max:  1.5292e-02
# Min:  -1.5512e-02
# Average psi change: 8.8245e-05
#
# Epoch 226
# Loss: 215.4777
# Psi gradient stats:
# Mean: -2.6200e-05
# Std:  4.1402e-03
# Max:  1.5269e-02
# Min:  -1.5567e-02
# Average psi change: 8.8212e-05
#
# Epoch 227
# Loss: 215.4155
# Psi gradient stats:
# Mean: -2.6410e-05
# Std:  4.1386e-03
# Max:  1.5267e-02
# Min:  -1.5585e-02
# Average psi change: 8.8183e-05
#
# Epoch 228
# Loss: 215.3806
# Psi gradient stats:
# Mean: -2.6649e-05
# Std:  4.1373e-03
# Max:  1.5285e-02
# Min:  -1.5544e-02
# Average psi change: 8.8162e-05
#
# Epoch 229
# Loss: 215.2999
# Psi gradient stats:
# Mean: -2.6726e-05
# Std:  4.1360e-03
# Max:  1.5305e-02
# Min:  -1.5477e-02
# Average psi change: 8.8137e-05
#
# Epoch 230
# Loss: 215.2177
# Psi gradient stats:
# Mean: -2.6610e-05
# Std:  4.1345e-03
# Max:  1.5311e-02
# Min:  -1.5433e-02
# Average psi change: 8.8107e-05
# Epoch 230, Loss: 215.2177, Gradients - Lambda: 5.814e-02, Phi: 1.472e+00, Gamma: 5.660e-03, Psi: 1.543e-02
#
# Epoch 231
# Loss: 215.1825
# Psi gradient stats:
# Mean: -2.6447e-05
# Std:  4.1327e-03
# Max:  1.5296e-02
# Min:  -1.5447e-02
# Average psi change: 8.8077e-05
#
# Epoch 232
# Loss: 215.1261
# Psi gradient stats:
# Mean: -2.6364e-05
# Std:  4.1309e-03
# Max:  1.5270e-02
# Min:  -1.5506e-02
# Average psi change: 8.8043e-05
#
# Epoch 233
# Loss: 215.0341
# Psi gradient stats:
# Mean: -2.6399e-05
# Std:  4.1291e-03
# Max:  1.5252e-02
# Min:  -1.5555e-02
# Average psi change: 8.8016e-05
#
# Epoch 234
# Loss: 214.9832
# Psi gradient stats:
# Mean: -2.6491e-05
# Std:  4.1276e-03
# Max:  1.5255e-02
# Min:  -1.5553e-02
# Average psi change: 8.7993e-05
#
# Epoch 235
# Loss: 214.9455
# Psi gradient stats:
# Mean: -2.6545e-05
# Std:  4.1263e-03
# Max:  1.5271e-02
# Min:  -1.5497e-02
# Average psi change: 8.7971e-05
#
# Epoch 236
# Loss: 214.8669
# Psi gradient stats:
# Mean: -2.6524e-05
# Std:  4.1249e-03
# Max:  1.5289e-02
# Min:  -1.5433e-02
# Average psi change: 8.7942e-05
#
# Epoch 237
# Loss: 214.7937
# Psi gradient stats:
# Mean: -2.6471e-05
# Std:  4.1233e-03
# Max:  1.5290e-02
# Min:  -1.5405e-02
# Average psi change: 8.7909e-05
#
# Epoch 238
# Loss: 214.7583
# Psi gradient stats:
# Mean: -2.6444e-05
# Std:  4.1215e-03
# Max:  1.5273e-02
# Min:  -1.5436e-02
# Average psi change: 8.7872e-05
#
# Epoch 239
# Loss: 214.6998
# Psi gradient stats:
# Mean: -2.6470e-05
# Std:  4.1198e-03
# Max:  1.5251e-02
# Min:  -1.5493e-02
# Average psi change: 8.7840e-05
#
# Epoch 240
# Loss: 214.6206
# Psi gradient stats:
# Mean: -2.6497e-05
# Std:  4.1181e-03
# Max:  1.5238e-02
# Min:  -1.5528e-02
# Average psi change: 8.7816e-05
# Epoch 240, Loss: 214.6206, Gradients - Lambda: 5.668e-02, Phi: 1.502e+00, Gamma: 5.654e-03, Psi: 1.553e-02
#
# Epoch 241
# Loss: 214.5705
# Psi gradient stats:
# Mean: -2.6501e-05
# Std:  4.1167e-03
# Max:  1.5244e-02
# Min:  -1.5510e-02
# Average psi change: 8.7798e-05
#
# Epoch 242
# Loss: 214.5279
# Psi gradient stats:
# Mean: -2.6445e-05
# Std:  4.1153e-03
# Max:  1.5260e-02
# Min:  -1.5454e-02
# Average psi change: 8.7777e-05
#
# Epoch 243
# Loss: 214.4583
# Psi gradient stats:
# Mean: -2.6398e-05
# Std:  4.1138e-03
# Max:  1.5272e-02
# Min:  -1.5402e-02
# Average psi change: 8.7743e-05
#
# Epoch 244
# Loss: 214.3927
# Psi gradient stats:
# Mean: -2.6384e-05
# Std:  4.1122e-03
# Max:  1.5269e-02
# Min:  -1.5392e-02
# Average psi change: 8.7709e-05
#
# Epoch 245
# Loss: 214.3517
# Psi gradient stats:
# Mean: -2.6424e-05
# Std:  4.1104e-03
# Max:  1.5250e-02
# Min:  -1.5426e-02
# Average psi change: 8.7673e-05
#
# Epoch 246
# Loss: 214.2963
# Psi gradient stats:
# Mean: -2.6478e-05
# Std:  4.1087e-03
# Max:  1.5229e-02
# Min:  -1.5471e-02
# Average psi change: 8.7643e-05
#
# Epoch 247
# Loss: 214.2287
# Psi gradient stats:
# Mean: -2.6503e-05
# Std:  4.1071e-03
# Max:  1.5221e-02
# Min:  -1.5486e-02
# Average psi change: 8.7620e-05
#
# Epoch 248
# Loss: 214.1784
# Psi gradient stats:
# Mean: -2.6475e-05
# Std:  4.1058e-03
# Max:  1.5229e-02
# Min:  -1.5458e-02
# Average psi change: 8.7602e-05
#
# Epoch 249
# Loss: 214.1315
# Psi gradient stats:
# Mean: -2.6420e-05
# Std:  4.1044e-03
# Max:  1.5244e-02
# Min:  -1.5411e-02
# Average psi change: 8.7578e-05
#
# Epoch 250
# Loss: 214.0723
# Psi gradient stats:
# Mean: -2.6387e-05
# Std:  4.1030e-03
# Max:  1.5252e-02
# Min:  -1.5380e-02
# Average psi change: 8.7542e-05
# Epoch 250, Loss: 214.0723, Gradients - Lambda: 6.061e-02, Phi: 1.729e+00, Gamma: 5.635e-03, Psi: 1.538e-02
#
# Epoch 251
# Loss: 214.0135
# Psi gradient stats:
# Mean: -2.6375e-05
# Std:  4.1012e-03
# Max:  1.5245e-02
# Min:  -1.5387e-02
# Average psi change: 8.7508e-05
#
# Epoch 252
# Loss: 213.9675
# Psi gradient stats:
# Mean: -2.6400e-05
# Std:  4.0994e-03
# Max:  1.5227e-02
# Min:  -1.5419e-02
# Average psi change: 8.7473e-05
#
# Epoch 253
# Loss: 213.9166
# Psi gradient stats:
# Mean: -2.6429e-05
# Std:  4.0977e-03
# Max:  1.5209e-02
# Min:  -1.5445e-02
# Average psi change: 8.7446e-05
#
# Epoch 254
# Loss: 213.8564
# Psi gradient stats:
# Mean: -2.6446e-05
# Std:  4.0962e-03
# Max:  1.5206e-02
# Min:  -1.5439e-02
# Average psi change: 8.7425e-05
#
# Epoch 255
# Loss: 213.8054
# Psi gradient stats:
# Mean: -2.6454e-05
# Std:  4.0949e-03
# Max:  1.5215e-02
# Min:  -1.5404e-02
# Average psi change: 8.7405e-05
#
# Epoch 256
# Loss: 213.7617
# Psi gradient stats:
# Mean: -2.6455e-05
# Std:  4.0936e-03
# Max:  1.5228e-02
# Min:  -1.5369e-02
# Average psi change: 8.7376e-05
#
# Epoch 257
# Loss: 213.7076
# Psi gradient stats:
# Mean: -2.6438e-05
# Std:  4.0922e-03
# Max:  1.5233e-02
# Min:  -1.5359e-02
# Average psi change: 8.7345e-05
#
# Epoch 258
# Loss: 213.6502
# Psi gradient stats:
# Mean: -2.6416e-05
# Std:  4.0904e-03
# Max:  1.5226e-02
# Min:  -1.5381e-02
# Average psi change: 8.7313e-05
#
# Epoch 259
# Loss: 213.6058
# Psi gradient stats:
# Mean: -2.6379e-05
# Std:  4.0886e-03
# Max:  1.5208e-02
# Min:  -1.5410e-02
# Average psi change: 8.7285e-05
#
# Epoch 260
# Loss: 213.5596
# Psi gradient stats:
# Mean: -2.6329e-05
# Std:  4.0868e-03
# Max:  1.5194e-02
# Min:  -1.5418e-02
# Average psi change: 8.7262e-05
# Epoch 260, Loss: 213.5596, Gradients - Lambda: 6.166e-02, Phi: 1.923e+00, Gamma: 5.584e-03, Psi: 1.542e-02
#
# Epoch 261
# Loss: 213.5033
# Psi gradient stats:
# Mean: -2.6323e-05
# Std:  4.0854e-03
# Max:  1.5191e-02
# Min:  -1.5393e-02
# Average psi change: 8.7236e-05
#
# Epoch 262
# Loss: 213.4547
# Psi gradient stats:
# Mean: -2.6370e-05
# Std:  4.0842e-03
# Max:  1.5200e-02
# Min:  -1.5354e-02
# Average psi change: 8.7207e-05
#
# Epoch 263
# Loss: 213.4120
# Psi gradient stats:
# Mean: -2.6456e-05
# Std:  4.0829e-03
# Max:  1.5210e-02
# Min:  -1.5330e-02
# Average psi change: 8.7177e-05
#
# Epoch 264
# Loss: 213.3629
# Psi gradient stats:
# Mean: -2.6509e-05
# Std:  4.0814e-03
# Max:  1.5212e-02
# Min:  -1.5340e-02
# Average psi change: 8.7147e-05
#
# Epoch 265
# Loss: 213.3120
# Psi gradient stats:
# Mean: -2.6456e-05
# Std:  4.0797e-03
# Max:  1.5203e-02
# Min:  -1.5372e-02
# Average psi change: 8.7124e-05
#
# Epoch 266
# Loss: 213.2639
# Psi gradient stats:
# Mean: -2.6334e-05
# Std:  4.0778e-03
# Max:  1.5187e-02
# Min:  -1.5398e-02
# Average psi change: 8.7100e-05
#
# Epoch 267
# Loss: 213.2216
# Psi gradient stats:
# Mean: -2.6207e-05
# Std:  4.0761e-03
# Max:  1.5178e-02
# Min:  -1.5390e-02
# Average psi change: 8.7075e-05
#
# Epoch 268
# Loss: 213.1750
# Psi gradient stats:
# Mean: -2.6207e-05
# Std:  4.0747e-03
# Max:  1.5179e-02
# Min:  -1.5351e-02
# Average psi change: 8.7045e-05
#
# Epoch 269
# Loss: 213.1214
# Psi gradient stats:
# Mean: -2.6330e-05
# Std:  4.0735e-03
# Max:  1.5187e-02
# Min:  -1.5307e-02
# Average psi change: 8.7012e-05
#
# Epoch 270
# Loss: 213.0792
# Psi gradient stats:
# Mean: -2.6500e-05
# Std:  4.0723e-03
# Max:  1.5192e-02
# Min:  -1.5293e-02
# Average psi change: 8.6980e-05
# Epoch 270, Loss: 213.0792, Gradients - Lambda: 5.635e-02, Phi: 1.517e+00, Gamma: 5.427e-03, Psi: 1.529e-02
#
# Epoch 271
# Loss: 213.0435
# Psi gradient stats:
# Mean: -2.6561e-05
# Std:  4.0708e-03
# Max:  1.5189e-02
# Min:  -1.5317e-02
# Average psi change: 8.6957e-05
#
# Epoch 272
# Loss: 212.9882
# Psi gradient stats:
# Mean: -2.6457e-05
# Std:  4.0690e-03
# Max:  1.5177e-02
# Min:  -1.5358e-02
# Average psi change: 8.6933e-05
#
# Epoch 273
# Loss: 212.9389
# Psi gradient stats:
# Mean: -2.6260e-05
# Std:  4.0671e-03
# Max:  1.5166e-02
# Min:  -1.5382e-02
# Average psi change: 8.6912e-05
#
# Epoch 274
# Loss: 212.9116
# Psi gradient stats:
# Mean: -2.6144e-05
# Std:  4.0654e-03
# Max:  1.5163e-02
# Min:  -1.5363e-02
# Average psi change: 8.6885e-05
#
# Epoch 275
# Loss: 212.8608
# Psi gradient stats:
# Mean: -2.6192e-05
# Std:  4.0641e-03
# Max:  1.5167e-02
# Min:  -1.5314e-02
# Average psi change: 8.6852e-05
#
# Epoch 276
# Loss: 212.8044
# Psi gradient stats:
# Mean: -2.6382e-05
# Std:  4.0630e-03
# Max:  1.5173e-02
# Min:  -1.5269e-02
# Average psi change: 8.6816e-05
#
# Epoch 277
# Loss: 212.7806
# Psi gradient stats:
# Mean: -2.6534e-05
# Std:  4.0618e-03
# Max:  1.5173e-02
# Min:  -1.5261e-02
# Average psi change: 8.6791e-05
#
# Epoch 278
# Loss: 212.7400
# Psi gradient stats:
# Mean: -2.6510e-05
# Std:  4.0602e-03
# Max:  1.5166e-02
# Min:  -1.5293e-02
# Average psi change: 8.6771e-05
#
# Epoch 279
# Loss: 212.6736
# Psi gradient stats:
# Mean: -2.6329e-05
# Std:  4.0583e-03
# Max:  1.5155e-02
# Min:  -1.5339e-02
# Average psi change: 8.6750e-05
#
# Epoch 280
# Loss: 212.6488
# Psi gradient stats:
# Mean: -2.6150e-05
# Std:  4.0564e-03
# Max:  1.5150e-02
# Min:  -1.5359e-02
# Average psi change: 8.6730e-05
# Epoch 280, Loss: 212.6488, Gradients - Lambda: 5.471e-02, Phi: 1.486e+00, Gamma: 5.551e-03, Psi: 1.536e-02
#
# Epoch 281
# Loss: 212.6202
# Psi gradient stats:
# Mean: -2.6140e-05
# Std:  4.0548e-03
# Max:  1.5152e-02
# Min:  -1.5335e-02
# Average psi change: 8.6702e-05
#
# Epoch 282
# Loss: 212.5506
# Psi gradient stats:
# Mean: -2.6296e-05
# Std:  4.0536e-03
# Max:  1.5158e-02
# Min:  -1.5281e-02
# Average psi change: 8.6667e-05
#
# Epoch 283
# Loss: 212.5159
# Psi gradient stats:
# Mean: -2.6478e-05
# Std:  4.0526e-03
# Max:  1.5160e-02
# Min:  -1.5236e-02
# Average psi change: 8.6634e-05
#
# Epoch 284
# Loss: 212.5033
# Psi gradient stats:
# Mean: -2.6501e-05
# Std:  4.0514e-03
# Max:  1.5153e-02
# Min:  -1.5233e-02
# Average psi change: 8.6608e-05
#
# Epoch 285
# Loss: 212.4383
# Psi gradient stats:
# Mean: -2.6346e-05
# Std:  4.0497e-03
# Max:  1.5140e-02
# Min:  -1.5271e-02
# Average psi change: 8.6586e-05
#
# Epoch 286
# Loss: 212.3862
# Psi gradient stats:
# Mean: -2.6147e-05
# Std:  4.0478e-03
# Max:  1.5130e-02
# Min:  -1.5317e-02
# Average psi change: 8.6566e-05
#
# Epoch 287
# Loss: 212.3827
# Psi gradient stats:
# Mean: -2.6086e-05
# Std:  4.0459e-03
# Max:  1.5130e-02
# Min:  -1.5332e-02
# Average psi change: 8.6547e-05
#
# Epoch 288
# Loss: 212.3318
# Psi gradient stats:
# Mean: -2.6227e-05
# Std:  4.0444e-03
# Max:  1.5140e-02
# Min:  -1.5302e-02
# Average psi change: 8.6519e-05
#
# Epoch 289
# Loss: 212.2634
# Psi gradient stats:
# Mean: -2.6437e-05
# Std:  4.0433e-03
# Max:  1.5148e-02
# Min:  -1.5247e-02
# Average psi change: 8.6487e-05
#
# Epoch 290
# Loss: 212.2575
# Psi gradient stats:
# Mean: -2.6529e-05
# Std:  4.0423e-03
# Max:  1.5147e-02
# Min:  -1.5207e-02
# Average psi change: 8.6454e-05
# Epoch 290, Loss: 212.2575, Gradients - Lambda: 5.380e-02, Phi: 1.514e+00, Gamma: 5.447e-03, Psi: 1.521e-02
#
# Epoch 291
# Loss: 212.2275
# Psi gradient stats:
# Mean: -2.6402e-05
# Std:  4.0409e-03
# Max:  1.5133e-02
# Min:  -1.5209e-02
# Average psi change: 8.6429e-05
#
# Epoch 292
# Loss: 212.1500
# Psi gradient stats:
# Mean: -2.6154e-05
# Std:  4.0391e-03
# Max:  1.5115e-02
# Min:  -1.5249e-02
# Average psi change: 8.6407e-05
#
# Epoch 293
# Loss: 212.1318
# Psi gradient stats:
# Mean: -2.6009e-05
# Std:  4.0373e-03
# Max:  1.5107e-02
# Min:  -1.5293e-02
# Average psi change: 8.6390e-05
#
# Epoch 294
# Loss: 212.1223
# Psi gradient stats:
# Mean: -2.6084e-05
# Std:  4.0356e-03
# Max:  1.5111e-02
# Min:  -1.5302e-02
# Average psi change: 8.6367e-05
#
# Epoch 295
# Loss: 212.0474
# Psi gradient stats:
# Mean: -2.6333e-05
# Std:  4.0343e-03
# Max:  1.5125e-02
# Min:  -1.5269e-02
# Average psi change: 8.6342e-05
#
# Epoch 296
# Loss: 212.0089
# Psi gradient stats:
# Mean: -2.6529e-05
# Std:  4.0332e-03
# Max:  1.5135e-02
# Min:  -1.5215e-02
# Average psi change: 8.6306e-05
#
# Epoch 297
# Loss: 212.0153
# Psi gradient stats:
# Mean: -2.6494e-05
# Std:  4.0319e-03
# Max:  1.5130e-02
# Min:  -1.5180e-02
# Average psi change: 8.6275e-05
#
# Epoch 298
# Loss: 211.9516
# Psi gradient stats:
# Mean: -2.6264e-05
# Std:  4.0304e-03
# Max:  1.5111e-02
# Min:  -1.5188e-02
# Average psi change: 8.6250e-05
#
# Epoch 299
# Loss: 211.8927
# Psi gradient stats:
# Mean: -2.6012e-05
# Std:  4.0287e-03
# Max:  1.5092e-02
# Min:  -1.5229e-02
# Average psi change: 8.6230e-05
#
# Epoch 300
# Loss: 211.9005
# Psi gradient stats:
# Mean: -2.5964e-05
# Std:  4.0270e-03
# Max:  1.5087e-02
# Min:  -1.5267e-02
# Average psi change: 8.6212e-05
# Epoch 300, Loss: 211.9005, Gradients - Lambda: 5.724e-02, Phi: 1.627e+00, Gamma: 5.436e-03, Psi: 1.527e-02
#
# Epoch 301
# Loss: 211.8611
# Psi gradient stats:
# Mean: -2.6134e-05
# Std:  4.0255e-03
# Max:  1.5098e-02
# Min:  -1.5270e-02
# Average psi change: 8.6191e-05
#
# Epoch 302
# Loss: 211.7870
# Psi gradient stats:
# Mean: -2.6379e-05
# Std:  4.0242e-03
# Max:  1.5114e-02
# Min:  -1.5235e-02
# Average psi change: 8.6160e-05
#
# Epoch 303
# Loss: 211.7849
# Psi gradient stats:
# Mean: -2.6490e-05
# Std:  4.0230e-03
# Max:  1.5123e-02
# Min:  -1.5185e-02
# Average psi change: 8.6127e-05
#
# Epoch 304
# Loss: 211.7680
# Psi gradient stats:
# Mean: -2.6380e-05
# Std:  4.0216e-03
# Max:  1.5114e-02
# Min:  -1.5157e-02
# Average psi change: 8.6098e-05
#
# Epoch 305
# Loss: 211.6891
# Psi gradient stats:
# Mean: -2.6133e-05
# Std:  4.0200e-03
# Max:  1.5090e-02
# Min:  -1.5168e-02
# Average psi change: 8.6073e-05
#
# Epoch 306
# Loss: 211.6681
# Psi gradient stats:
# Mean: -2.5961e-05
# Std:  4.0184e-03
# Max:  1.5070e-02
# Min:  -1.5206e-02
# Average psi change: 8.6054e-05
#
# Epoch 307
# Loss: 211.6716
# Psi gradient stats:
# Mean: -2.6003e-05
# Std:  4.0168e-03
# Max:  1.5067e-02
# Min:  -1.5238e-02
# Average psi change: 8.6038e-05
#
# Epoch 308
# Loss: 211.6023
# Psi gradient stats:
# Mean: -2.6213e-05
# Std:  4.0155e-03
# Max:  1.5082e-02
# Min:  -1.5237e-02
# Average psi change: 8.6016e-05
#
# Epoch 309
# Loss: 211.5575
# Psi gradient stats:
# Mean: -2.6412e-05
# Std:  4.0142e-03
# Max:  1.5102e-02
# Min:  -1.5201e-02
# Average psi change: 8.5988e-05
#
# Epoch 310
# Loss: 211.5687
# Psi gradient stats:
# Mean: -2.6427e-05
# Std:  4.0128e-03
# Max:  1.5107e-02
# Min:  -1.5158e-02
# Average psi change: 8.5956e-05
# Epoch 310, Loss: 211.5687, Gradients - Lambda: 6.281e-02, Phi: 1.583e+00, Gamma: 5.590e-03, Psi: 1.516e-02
#
# Epoch 311
# Loss: 211.5199
# Psi gradient stats:
# Mean: -2.6255e-05
# Std:  4.0113e-03
# Max:  1.5093e-02
# Min:  -1.5137e-02
# Average psi change: 8.5925e-05
#
# Epoch 312
# Loss: 211.4565
# Psi gradient stats:
# Mean: -2.6043e-05
# Std:  4.0097e-03
# Max:  1.5068e-02
# Min:  -1.5152e-02
# Average psi change: 8.5904e-05
#
# Epoch 313
# Loss: 211.4611
# Psi gradient stats:
# Mean: -2.5964e-05
# Std:  4.0082e-03
# Max:  1.5050e-02
# Min:  -1.5186e-02
# Average psi change: 8.5884e-05
#
# Epoch 314
# Loss: 211.4349
# Psi gradient stats:
# Mean: -2.6062e-05
# Std:  4.0068e-03
# Max:  1.5052e-02
# Min:  -1.5207e-02
# Average psi change: 8.5862e-05
#
# Epoch 315
# Loss: 211.3664
# Psi gradient stats:
# Mean: -2.6241e-05
# Std:  4.0055e-03
# Max:  1.5070e-02
# Min:  -1.5198e-02
# Average psi change: 8.5840e-05
#
# Epoch 316
# Loss: 211.3549
# Psi gradient stats:
# Mean: -2.6364e-05
# Std:  4.0042e-03
# Max:  1.5088e-02
# Min:  -1.5165e-02
# Average psi change: 8.5814e-05
#
# Epoch 317
# Loss: 211.3471
# Psi gradient stats:
# Mean: -2.6302e-05
# Std:  4.0027e-03
# Max:  1.5090e-02
# Min:  -1.5132e-02
# Average psi change: 8.5786e-05
#
# Epoch 318
# Loss: 211.2832
# Psi gradient stats:
# Mean: -2.6121e-05
# Std:  4.0011e-03
# Max:  1.5070e-02
# Min:  -1.5121e-02
# Average psi change: 8.5759e-05
#
# Epoch 319
# Loss: 211.2535
# Psi gradient stats:
# Mean: -2.5972e-05
# Std:  3.9996e-03
# Max:  1.5045e-02
# Min:  -1.5137e-02
# Average psi change: 8.5733e-05
#
# Epoch 320
# Loss: 211.2552
# Psi gradient stats:
# Mean: -2.5970e-05
# Std:  3.9982e-03
# Max:  1.5032e-02
# Min:  -1.5163e-02
# Average psi change: 8.5710e-05
# Epoch 320, Loss: 211.2552, Gradients - Lambda: 5.843e-02, Phi: 1.620e+00, Gamma: 5.595e-03, Psi: 1.516e-02
#
# Epoch 321
# Loss: 211.2036
# Psi gradient stats:
# Mean: -2.6116e-05
# Std:  3.9969e-03
# Max:  1.5039e-02
# Min:  -1.5173e-02
# Average psi change: 8.5689e-05
#
# Epoch 322
# Loss: 211.1582
# Psi gradient stats:
# Mean: -2.6270e-05
# Std:  3.9957e-03
# Max:  1.5060e-02
# Min:  -1.5157e-02
# Average psi change: 8.5667e-05
#
# Epoch 323
# Loss: 211.1585
# Psi gradient stats:
# Mean: -2.6305e-05
# Std:  3.9942e-03
# Max:  1.5075e-02
# Min:  -1.5127e-02
# Average psi change: 8.5644e-05
#
# Converged at epoch 323. Loss change: 0.0002
#
# Overall psi changes:

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history['max_grad_lambda'], label='Lambda')
ax2.plot(history['max_grad_phi'], label='Phi')
ax2.plot(history['max_grad_gamma'], label='Gamma')
ax2.plot(history['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
import torch

# Save complete state for R
save_path = '13model_complete_for_R_127.pt'

torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t':essentials['prevalence_t'],
    'G': G_100k,
    'E': E,
    'indices' : indices,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T':Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, save_path)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000451
# Mean predicted risk (original): 0.000110
# Mean predicted risk (calibrated): 0.000451
# Calibration scale factor: 4.097

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.545
