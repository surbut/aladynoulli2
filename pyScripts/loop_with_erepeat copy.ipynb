# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Library/CloudStorage/Dropbox/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()

from clust_huge_amp import *
# Subset the data

# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, start_index=0, end_index=10000)


del Y

# Load references (signatures only, no healthy)
refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/data_for_running/reference_trajectories.pt')
signature_refs = refs['signature_refs']
# When initializing the model:
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the RDS file

import pandas as pd
fh_processed=pd.read_csv('/Users/sarahurbut/Library/Cloudstorage/Dropbox/baselinagefamh.csv')
len(fh_processed)



pce_df_subset = fh_processed.iloc[0:10000].reset_index(drop=True)
sex=pce_df_subset['sex'].values
G_with_sex = np.column_stack([G_100k, sex])
# Out:
# Loading components...
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_31000/2718424955.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_31000/2718424955.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_31000/2718424955.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_31000/2718424955.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_31000/2718424955.py:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/data_for_running/reference_trajectories.pt')

# %%
import torch
import numpy as np
import cProfile
import pstats
from pstats import SortKey

# Store predictions for each age
age_predictions = {}

for age_offset in range(0, 11):  # Ages 0-10 years after enrollment
    print(f"\n=== Predicting for age offset {age_offset} years ===")
    
    # Set seeds for reproducibility
    torch.manual_seed(42)
    np.random.seed(42)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(42)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    
    # Initialize fresh model for this age
    model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
        N=Y_100k.shape[0],
        D=Y_100k.shape[1],
        T=Y_100k.shape[2],
        K=20,
        P=G_with_sex.shape[1],
        init_sd_scaler=1e-1,
        G=G_with_sex,
        Y=Y_100k,
        genetic_scale=1,
        W=0.0001,
        R=0,
        prevalence_t=essentials['prevalence_t'],
        signature_references=signature_refs,
        healthy_reference=True,
        disease_names=essentials['disease_names']
    )
    
    # Reset seeds for parameter initialization
    torch.manual_seed(0)
    np.random.seed(0)
    
    # Load and set initial parameters
    initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/data_for_running/initial_psi_400k.pt')
    initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/data_for_running/initial_clusters_400k.pt')
    model.initialize_params(true_psi=initial_psi)
    model.clusters = initial_clusters
    
    # Verify clusters match
    clusters_match = np.array_equal(initial_clusters, model.clusters)
    print(f"Clusters match exactly: {clusters_match}")
    
    # Create age-specific event times
    E_age_specific = E_100k.clone()
    pce_df_subset = fh_processed.iloc[0:10000].reset_index(drop=True)

     
    # Initialize tracking variables for this age offset
    total_times_changed = 0
    max_cap_applied = 0
    min_cap_applied = float('inf')

    
    for patient_idx, row in enumerate(pce_df_subset.itertuples()):
        if patient_idx >= E_age_specific.shape[0]:
            break
            
        # Current age = enrollment age + age_offset
        current_age = row.age + age_offset
        
        # Time since age 30 for this current age
        time_since_30 = max(0, current_age - 30)

        max_cap_applied = max(max_cap_applied, time_since_30)
        min_cap_applied = min(min_cap_applied, time_since_30)
        
        # Store original times for this patient
        original_times = E_age_specific[patient_idx, :].clone()
        
        # Cap event times to current age
        E_age_specific[patient_idx, :] = torch.minimum(
            E_age_specific[patient_idx, :],
            torch.full_like(E_age_specific[patient_idx, :], time_since_30)
        )

        times_changed = torch.sum(E_age_specific[patient_idx, :] != original_times).item()
        total_times_changed += times_changed
    
    # Print censoring verification
    print(f"Censoring verification for age offset {age_offset}:")
    print(f"  Total event times changed: {total_times_changed}")
    print(f"  Max cap applied: {max_cap_applied:.1f}")
    print(f"  Min cap applied: {min_cap_applied:.1f}")
    
    # Check a few specific patients
    test_patients = [0, 1, 100]  # Check patients 0, 1, and 100
    for test_idx in test_patients:
        if test_idx < len(pce_df_subset):
            row = pce_df_subset.iloc[test_idx]
            enrollment_age = row.age
            current_age = enrollment_age + age_offset
            expected_cap = max(0, current_age - 30)
            
            # Check max value in this patient's event times
            max_time = torch.max(E_age_specific[test_idx, :]).item()
            
            print(f"  Patient {test_idx}: enrollment={enrollment_age:.0f}, current={current_age:.0f}, "
                  f"cap={expected_cap:.1f}, max_event_time={max_time:.1f}")
            
            # Verify cap was applied correctly
            if max_time > expected_cap + 0.01:  # Small tolerance
                print(f"    WARNING: Max time {max_time:.1f} exceeds cap {expected_cap:.1f}!")
    
  
    
    # Train model for this specific age
    print(f"Training model for age offset {age_offset}...")
    profiler = cProfile.Profile()
    profiler.enable()
    
    history_new = model.fit(
        E_age_specific, 
        num_epochs=200, 
        learning_rate=1e-1, 
        lambda_reg=1e-2
    )
    
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats(SortKey.CUMULATIVE)
    stats.print_stats(20)
    
    # Get predictions for this age
    with torch.no_grad():
        pi, _, _ = model.forward()
        
        # Save age-specific predictions
        filename = f"/Users/sarahurbut/Library/CloudStorage/Dropbox/pi_enroll_age_offset_{age_offset}_sex_0_10000.pt"
        torch.save(pi, filename)
        print(f"Saved predictions to {filename}")
        
        # Store in dictionary for potential analysis
        
    
    # Clean up to free memory
    del pi
    del model
    del E_age_specific
    torch.cuda.empty_cache() if torch.cuda.is_available() else None
# Out:
# === Predicting for age offset 0 years ===
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0008,  0.0071,  0.0117,  0.0152, -0.0106])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0219,  0.0117,  0.0025, -0.0018, -0.0047])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0018, -0.0023,  0.0065,  0.0024, -0.0054])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0020, -0.0039,  0.0022,  0.0021, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0060, -0.0015, -0.0132,  0.0367, -0.0098])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0048,  0.0060, -0.0042,  0.0057,  0.0247])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0017,  0.0011, -0.0008, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0073,  0.0049, -0.0054,  0.0056, -0.0040])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0013,  0.0009,  0.0006,  0.0133, -0.0011])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([ 9.8607e-06,  9.0586e-03,  1.5898e-02, -3.2695e-03,  5.4494e-04])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0122, -0.0048,  0.0013, -0.0042,  0.0020])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0062,  0.0047, -0.0075,  0.0032,  0.0006])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0072,  0.0011, -0.0018,  0.0015,  0.0025])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 7.6968e-03,  1.0931e-02,  8.1495e-05,  7.9375e-03, -1.5938e-03])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0121, -0.0034, -0.0035,  0.0132,  0.0054])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0023, 0.0029, 0.0010, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([ 0.0023,  0.0108,  0.0118, -0.0026,  0.0093])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0068,  0.0176,  0.0005, -0.0053, -0.0091])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0158, -0.0017,  0.0114,  0.0180, -0.0033])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0006, -0.0010,  0.0008,  0.0037,  0.0014])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.9623, -13.8155])
# Base value centered (first 5): tensor([-0.1879, -0.1879, -0.1879,  1.6653, -0.1879])
# Base value centered mean: -3.345489574257954e-07
# Gamma init for k=0 (first 5): tensor([ 0.0069,  0.0066, -0.0055,  0.0062,  0.0243])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.3449, -13.3449, -12.4036])
# Base value centered (first 5): tensor([ 0.1505, -0.3201,  0.1505,  0.1505,  1.0918])
# Base value centered mean: -1.8495559288567165e-06
# Gamma init for k=1 (first 5): tensor([0.0044, 0.0012, 0.0007, 0.0026, 0.0014])
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_31000/1322530357.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/data_for_running/initial_psi_400k.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_31000/1322530357.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/data_for_running/initial_clusters_400k.pt')
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1566, -11.8388, -12.4977])
# Base value centered (first 5): tensor([-0.3849, -0.3849,  0.2740,  1.5918,  0.9329])
# Base value centered mean: 9.290695288655115e-07
# Gamma init for k=2 (first 5): tensor([-0.0001,  0.0092,  0.0113,  0.0160, -0.0109])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.6950, -13.5744])
# Base value centered (first 5): tensor([-0.1026, -0.1026, -0.1026,  0.0179,  0.1384])
# Base value centered mean: 4.7445297468584613e-07
# Gamma init for k=3 (first 5): tensor([ 0.0011,  0.0003,  0.0017,  0.0019, -0.0006])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155,  -9.8620, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1133,  3.8402, -0.1133, -0.1133, -0.1133])
# Base value centered mean: -2.841758714566822e-06
# Gamma init for k=4 (first 5): tensor([-0.0169, -0.0023,  0.0140,  0.0213, -0.0032])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=5 (first 5): tensor([ 0.0219,  0.0117,  0.0025, -0.0018, -0.0047])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1523, -0.1523, -0.1523, -0.1523, -0.1523])
# Base value centered mean: -1.0890006478803116e-06
# Gamma init for k=6 (first 5): tensor([ 0.0075,  0.0130,  0.0004,  0.0055, -0.0025])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.3663, -13.8155, -13.3663, -13.8155, -11.1200])
# Base value centered (first 5): tensor([-0.1005, -0.5497, -0.1005, -0.5497,  2.1458])
# Base value centered mean: 1.2460708376238472e-06
# Gamma init for k=7 (first 5): tensor([ 0.0027, -0.0039, -0.0122,  0.0250, -0.0020])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1159, -0.1159, -0.1159, -0.1159, -0.1159])
# Base value centered mean: -1.4129639112070436e-06
# Gamma init for k=8 (first 5): tensor([ 0.0066, -0.0056,  0.0009, -0.0016, -0.0004])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=9 (first 5): tensor([ 0.0062,  0.0047, -0.0075,  0.0032,  0.0006])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=10 (first 5): tensor([-0.0068,  0.0176,  0.0005, -0.0053, -0.0091])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=11 (first 5): tensor([0.0026, 0.0023, 0.0029, 0.0010, 0.0098])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0860, -0.0860, -0.0860, -0.0860, -0.0860])
# Base value centered mean: -1.034450519910024e-06
# Gamma init for k=12 (first 5): tensor([ 8.2098e-03, -7.1588e-03,  4.5737e-06, -3.0368e-04, -7.6238e-03])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.7744, -12.2949])
# Base value centered (first 5): tensor([-0.1777, -0.1777, -0.1777,  2.8635,  1.3429])
# Base value centered mean: -1.0064125035569305e-06
# Gamma init for k=13 (first 5): tensor([ 0.0003,  0.0065,  0.0122, -0.0056,  0.0007])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.8388, -12.8271])
# Base value centered (first 5): tensor([-0.2562, -0.2562, -0.2562,  1.7205,  0.7322])
# Base value centered mean: -1.5125274330785032e-06
# Gamma init for k=14 (first 5): tensor([ 0.0021, -0.0037, -0.0087,  0.0178,  0.0010])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.8388])
# Base value centered (first 5): tensor([-0.2850, -0.2850, -0.2850, -0.2850,  1.6917])
# Base value centered mean: -1.2931823221151717e-06
# Gamma init for k=15 (first 5): tensor([ 0.0013,  0.0041,  0.0077, -0.0082,  0.0078])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.7706, -13.1339])
# Base value centered (first 5): tensor([-0.2428, -0.2428, -0.2428,  1.8021,  0.4388])
# Base value centered mean: -1.9989013253507437e-06
# Gamma init for k=16 (first 5): tensor([ 0.0014,  0.0004,  0.0086,  0.0059, -0.0034])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.3272, -12.0713])
# Base value centered (first 5): tensor([-0.4228, -0.4228, -0.4228,  3.0656,  1.3214])
# Base value centered mean: -2.227592403869494e-06
# Gamma init for k=17 (first 5): tensor([ 0.0078,  0.0057, -0.0059,  0.0059, -0.0039])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=18 (first 5): tensor([-0.0121, -0.0034, -0.0035,  0.0132,  0.0054])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([-0.1519, -0.1519, -0.1519, -0.1519,  0.2779])
# Base value centered mean: -1.1179923831150518e-06
# Gamma init for k=19 (first 5): tensor([-0.0027,  0.0051,  0.0015, -0.0011, -0.0017])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
# Clusters match exactly: True
# Censoring verification for age offset 0:
#   Total event times changed: 3460577
#   Max cap applied: 41.0
#   Min cap applied: 10.0
#   Patient 0: enrollment=69, current=69, cap=39.0, max_event_time=39.0
#   Patient 1: enrollment=44, current=44, cap=14.0, max_event_time=14.0
#   Patient 100: enrollment=52, current=52, cap=22.0, max_event_time=22.0
# Training model for age offset 0...
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:238: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 17.1567
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.14):
#   Theta for diagnosed: 0.150 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.74):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.097 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.070
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 1
# Loss: 663.9888
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.14):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 2
# Loss: 69.0951
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 3
# Loss: 164.3109
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.10):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 4
# Loss: 379.3873
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.08):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.096 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 5
# Loss: 287.2476
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.06):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.76):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 6
# Loss: 102.2140
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.03):
#   Theta for diagnosed: 0.150 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.73):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.009
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 7
# Loss: 33.3491
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.99):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.71):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 8
# Loss: 104.1930
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.93):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.69):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.45):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 9
# Loss: 185.6424
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.86):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.68):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.45):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 10
# Loss: 176.0285
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.78):
#   Theta for diagnosed: 0.150 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.67):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.45):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 11
# Loss: 99.3770
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.69):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.66):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.51):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 12
# Loss: 35.9566
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.60):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.65):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 13
# Loss: 34.2887
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.49):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.63):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 14
# Loss: 76.4578
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.38):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.61):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 15
# Loss: 107.3219
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.27):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.58):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.015 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.001
#
# Epoch 16
# Loss: 95.1580
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.15):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.55):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.080
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=28.89):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 17
# Loss: 55.9429
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.03):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.52):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=28.97):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 18
# Loss: 26.8608
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.90):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.097 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.48):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.05):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 19
# Loss: 28.7234
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.76):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.45):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.13):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 20
# Loss: 50.3796
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.63):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.42):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.45):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.21):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 21
# Loss: 64.5478
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 161 (signature 7, LR=30.48):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.39):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.45):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.28):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 22
# Loss: 56.6825
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.36):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 161 (signature 7, LR=30.33):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.45):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.36):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 23
# Loss: 36.1394
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.33):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 161 (signature 7, LR=30.18):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.44):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Epoch 24
# Loss: 22.5172
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.010
#
# Disease 76 (signature 7, LR=30.30):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 161 (signature 7, LR=30.03):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 114 (signature 5, LR=29.51):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Epoch 25
# Loss: 25.4232
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 76 (signature 7, LR=30.26):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 161 (signature 7, LR=29.87):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 114 (signature 5, LR=29.59):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Epoch 26
# Loss: 37.0636
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 76 (signature 7, LR=30.22):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 161 (signature 7, LR=29.72):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 114 (signature 5, LR=29.66):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.150 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Epoch 27
# Loss: 42.6856
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.51):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 76 (signature 7, LR=30.18):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=29.74):
#   Theta for diagnosed: 0.062 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 161 (signature 7, LR=29.56):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Epoch 28
# Loss: 36.3247
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.51):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 76 (signature 7, LR=30.13):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=29.81):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 161 (signature 7, LR=29.40):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Epoch 29
# Loss: 25.0886
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.098 ± 0.081
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 76 (signature 7, LR=30.09):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=29.88):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 161 (signature 7, LR=29.25):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Epoch 30
# Loss: 19.7555
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.098 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 76 (signature 7, LR=30.04):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=29.95):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 161 (signature 7, LR=29.09):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Epoch 31
# Loss: 23.4222
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 114 (signature 5, LR=30.02):
#   Theta for diagnosed: 0.063 ± 0.041
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 76 (signature 7, LR=30.00):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.40):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 161 (signature 7, LR=28.94):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Epoch 32
# Loss: 29.6232
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 114 (signature 5, LR=30.09):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 76 (signature 7, LR=29.95):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.39):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 33
# Loss: 30.5292
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 114 (signature 5, LR=30.16):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.016
#
# Disease 76 (signature 7, LR=29.91):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.39):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 34
# Loss: 25.2828
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 114 (signature 5, LR=30.23):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 76 (signature 7, LR=29.87):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.38):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 35
# Loss: 19.6673
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.011
#
# Disease 114 (signature 5, LR=30.30):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 76 (signature 7, LR=29.82):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.37):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 36
# Loss: 18.8980
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.012
#
# Disease 114 (signature 5, LR=30.37):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 76 (signature 7, LR=29.77):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.37):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 37
# Loss: 22.1971
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.012
#
# Disease 114 (signature 5, LR=30.44):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 76 (signature 7, LR=29.73):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.36):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 38
# Loss: 24.6148
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=30.51):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.012
#
# Disease 76 (signature 7, LR=29.68):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.35):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 39
# Loss: 23.1016
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=30.58):
#   Theta for diagnosed: 0.063 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.017
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.099 ± 0.082
#   Theta for others: 0.087
#   Proportion difference: 0.012
#
# Disease 76 (signature 7, LR=29.63):
#   Theta for diagnosed: 0.153 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 347 (signature 3, LR=29.34):
#   Theta for diagnosed: 0.150 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.000
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.005
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 40
# Loss: 19.5165
#
# Monitoring signature responses:
#
# ...
#
# Disease 127 (signature 0, LR=63.37):
#   Theta for diagnosed: 0.035 ± 0.039
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=61.57):
#   Theta for diagnosed: 0.031 ± 0.037
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Disease 15 (signature 19, LR=60.80):
#   Theta for diagnosed: 0.051 ± 0.020
#   Theta for others: 0.045
#   Proportion difference: 0.006
#
# Epoch 182
# Loss: 42.8549
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=70.62):
#   Theta for diagnosed: 0.030 ± 0.017
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=66.10):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=63.82):
#   Theta for diagnosed: 0.035 ± 0.039
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=61.84):
#   Theta for diagnosed: 0.031 ± 0.037
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Disease 15 (signature 19, LR=61.07):
#   Theta for diagnosed: 0.051 ± 0.020
#   Theta for others: 0.045
#   Proportion difference: 0.006
#
# Epoch 183
# Loss: 42.8359
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=71.04):
#   Theta for diagnosed: 0.030 ± 0.018
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=66.60):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=64.26):
#   Theta for diagnosed: 0.035 ± 0.039
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=62.11):
#   Theta for diagnosed: 0.031 ± 0.038
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Disease 15 (signature 19, LR=61.33):
#   Theta for diagnosed: 0.051 ± 0.021
#   Theta for others: 0.045
#   Proportion difference: 0.006
#
# Epoch 184
# Loss: 42.8171
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=71.46):
#   Theta for diagnosed: 0.030 ± 0.018
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=67.10):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=64.71):
#   Theta for diagnosed: 0.035 ± 0.040
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=62.38):
#   Theta for diagnosed: 0.031 ± 0.038
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Disease 15 (signature 19, LR=61.59):
#   Theta for diagnosed: 0.051 ± 0.021
#   Theta for others: 0.045
#   Proportion difference: 0.006
#
# Epoch 185
# Loss: 42.7983
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=71.88):
#   Theta for diagnosed: 0.030 ± 0.018
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=67.61):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=65.16):
#   Theta for diagnosed: 0.036 ± 0.040
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=62.65):
#   Theta for diagnosed: 0.031 ± 0.038
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 15 (signature 19, LR=61.85):
#   Theta for diagnosed: 0.051 ± 0.021
#   Theta for others: 0.045
#   Proportion difference: 0.006
#
# Epoch 186
# Loss: 42.7794
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=72.30):
#   Theta for diagnosed: 0.030 ± 0.018
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=68.12):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=65.60):
#   Theta for diagnosed: 0.036 ± 0.040
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=62.92):
#   Theta for diagnosed: 0.031 ± 0.038
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 15 (signature 19, LR=62.11):
#   Theta for diagnosed: 0.051 ± 0.021
#   Theta for others: 0.045
#   Proportion difference: 0.006
#
# Epoch 187
# Loss: 42.7606
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=72.73):
#   Theta for diagnosed: 0.030 ± 0.018
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=68.63):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=66.06):
#   Theta for diagnosed: 0.036 ± 0.040
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=63.18):
#   Theta for diagnosed: 0.031 ± 0.038
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=62.40):
#   Theta for diagnosed: 0.030 ± 0.035
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 188
# Loss: 42.7419
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=73.15):
#   Theta for diagnosed: 0.030 ± 0.019
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=69.15):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=66.51):
#   Theta for diagnosed: 0.036 ± 0.041
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=63.45):
#   Theta for diagnosed: 0.031 ± 0.039
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=62.71):
#   Theta for diagnosed: 0.030 ± 0.036
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 189
# Loss: 42.7232
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=73.58):
#   Theta for diagnosed: 0.030 ± 0.019
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=69.67):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=66.96):
#   Theta for diagnosed: 0.036 ± 0.041
#   Theta for others: 0.027
#   Proportion difference: 0.008
#
# Disease 90 (signature 10, LR=63.72):
#   Theta for diagnosed: 0.031 ± 0.039
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=63.02):
#   Theta for diagnosed: 0.030 ± 0.036
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 190
# Loss: 42.7044
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=74.00):
#   Theta for diagnosed: 0.030 ± 0.019
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 47 (signature 15, LR=70.19):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=67.41):
#   Theta for diagnosed: 0.036 ± 0.041
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=63.98):
#   Theta for diagnosed: 0.031 ± 0.039
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=63.33):
#   Theta for diagnosed: 0.030 ± 0.036
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 191
# Loss: 42.6856
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=74.43):
#   Theta for diagnosed: 0.031 ± 0.019
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=70.72):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=67.87):
#   Theta for diagnosed: 0.036 ± 0.041
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=64.24):
#   Theta for diagnosed: 0.031 ± 0.039
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=63.64):
#   Theta for diagnosed: 0.030 ± 0.036
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 192
# Loss: 42.6670
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=74.86):
#   Theta for diagnosed: 0.031 ± 0.019
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=71.25):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=68.32):
#   Theta for diagnosed: 0.036 ± 0.042
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=64.51):
#   Theta for diagnosed: 0.031 ± 0.040
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=63.95):
#   Theta for diagnosed: 0.030 ± 0.037
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 193
# Loss: 42.6482
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=75.29):
#   Theta for diagnosed: 0.031 ± 0.020
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=71.79):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=68.78):
#   Theta for diagnosed: 0.036 ± 0.042
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=64.77):
#   Theta for diagnosed: 0.031 ± 0.040
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=64.26):
#   Theta for diagnosed: 0.030 ± 0.037
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 194
# Loss: 42.6296
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=75.72):
#   Theta for diagnosed: 0.031 ± 0.020
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=72.33):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=69.24):
#   Theta for diagnosed: 0.036 ± 0.042
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=65.03):
#   Theta for diagnosed: 0.031 ± 0.040
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=64.57):
#   Theta for diagnosed: 0.030 ± 0.037
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 195
# Loss: 42.6111
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=76.15):
#   Theta for diagnosed: 0.031 ± 0.020
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=72.87):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=69.70):
#   Theta for diagnosed: 0.036 ± 0.043
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=65.29):
#   Theta for diagnosed: 0.031 ± 0.040
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=64.87):
#   Theta for diagnosed: 0.030 ± 0.037
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 196
# Loss: 42.5924
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=76.58):
#   Theta for diagnosed: 0.031 ± 0.020
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=73.42):
#   Theta for diagnosed: 0.016 ± 0.007
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=70.16):
#   Theta for diagnosed: 0.036 ± 0.043
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=65.55):
#   Theta for diagnosed: 0.031 ± 0.041
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=65.18):
#   Theta for diagnosed: 0.030 ± 0.037
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 197
# Loss: 42.5739
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=77.01):
#   Theta for diagnosed: 0.031 ± 0.020
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=73.97):
#   Theta for diagnosed: 0.016 ± 0.008
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=70.62):
#   Theta for diagnosed: 0.036 ± 0.043
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=65.81):
#   Theta for diagnosed: 0.031 ± 0.041
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=65.49):
#   Theta for diagnosed: 0.031 ± 0.038
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 198
# Loss: 42.5553
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=77.44):
#   Theta for diagnosed: 0.031 ± 0.021
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=74.53):
#   Theta for diagnosed: 0.016 ± 0.008
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=71.08):
#   Theta for diagnosed: 0.037 ± 0.043
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=66.06):
#   Theta for diagnosed: 0.032 ± 0.041
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=65.80):
#   Theta for diagnosed: 0.031 ± 0.038
#   Theta for others: 0.025
#   Proportion difference: 0.005
#
# Epoch 199
# Loss: 42.5368
#
# Monitoring signature responses:
#
# Disease 21 (signature 13, LR=77.87):
#   Theta for diagnosed: 0.031 ± 0.021
#   Theta for others: 0.023
#   Proportion difference: 0.008
#
# Disease 47 (signature 15, LR=75.09):
#   Theta for diagnosed: 0.016 ± 0.008
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 127 (signature 0, LR=71.54):
#   Theta for diagnosed: 0.037 ± 0.044
#   Theta for others: 0.027
#   Proportion difference: 0.009
#
# Disease 90 (signature 10, LR=66.32):
#   Theta for diagnosed: 0.032 ± 0.041
#   Theta for others: 0.025
#   Proportion difference: 0.006
#
# Disease 89 (signature 10, LR=66.11):
#   Theta for diagnosed: 0.031 ± 0.038
#   Theta for others: 0.025
#   Proportion difference: 0.006
#          92773512 function calls (92771512 primitive calls) in 3688.771 seconds
#
#    Ordered by: cumulative time
#    List reduced from 167 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1  136.408  136.408 3688.771 3688.771 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:329(fit)
#       200    0.009    0.000 2401.106   12.006 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:525(backward)
#       200    0.002    0.000 2401.097   12.005 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#       200    0.002    0.000 2401.087   12.005 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/graph.py:816(_engine_run_backward)
#       200 2401.085   12.005 2401.085   12.005 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       200  139.159    0.696 1118.379    5.592 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:230(compute_loss)
#       200  456.841    2.284  898.288    4.491 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:287(compute_gp_prior_loss)
#  43461600  317.809    0.000  317.809    0.000 {built-in method torch.cholesky_solve}
#  43531800  132.338    0.000  133.209    0.000 {built-in method torch.sum}
#       400   13.082    0.033   55.254    0.138 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:221(forward)
#       200    0.986    0.005   31.240    0.156 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:403(analyze_signature_responses)
#       400    0.005    0.000   30.772    0.077 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/functional.py:210(einsum)
#       400   30.766    0.077   30.766    0.077 {built-in method torch.einsum}
#       600   21.229    0.035   21.229    0.035 {built-in method torch.log}
#       600   15.470    0.026   15.470    0.026 {built-in method torch.clamp}
#       600    0.003    0.000   11.134    0.019 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:33(wrapped)
#       600    0.003    0.000   11.131    0.019 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:1026(__rsub__)
#       600   11.128    0.019   11.128    0.019 {built-in method torch.rsub}
#       400    7.844    0.020    7.844    0.020 {method 'float' of 'torch._C.TensorBase' objects}
#       200    0.004    0.000    1.173    0.006 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/optim/optimizer.py:467(wrapper)
#
#
# Saved predictions to /Users/sarahurbut/Library/CloudStorage/Dropbox/pi_enroll_age_offset_10_sex_0_10000.pt

# %%
import torch
import numpy as np
import pandas as pd

# Test function to verify age-specific censoring
def test_age_specific_censoring(E_100k, fh_processed, age_offset=5, test_patients=5):
    """
    Test that E_age_specific is correctly updated to reflect row.age + offset - 30
    """
    print(f"\n=== Testing Age-Specific Censoring (offset = {age_offset}) ===")
    
    # Create original and age-specific versions
    E_original = E_100k.clone()
    E_age_specific = E_100k.clone()
    
    # Get subset of patient data
    pce_df_subset = fh_processed.iloc[0:10000].reset_index(drop=True)
    
    # Apply age-specific censoring
    for patient_idx, row in enumerate(pce_df_subset.itertuples()):
        if patient_idx >= E_age_specific.shape[0]:
            break
            
        # Current age = enrollment age + age_offset
        current_age = row.age + age_offset
        
        # Time since age 30 for this current age
        time_since_30 = max(0, current_age - 30)
        
        # Cap event times to current age
        E_age_specific[patient_idx, :] = torch.minimum(
            E_age_specific[patient_idx, :],
            torch.full_like(E_age_specific[patient_idx, :], time_since_30)
        )
    
    # Test specific patients
    print(f"\nTesting first {test_patients} patients:")
    print("=" * 80)
    
    for i in range(min(test_patients, len(pce_df_subset))):
        row = pce_df_subset.iloc[i]
        
        enrollment_age = row.age
        current_age = enrollment_age + age_offset
        expected_cap = max(0, current_age - 30)
        
        # Get original and modified event times for this patient
        original_times = E_original[i, :].numpy()
        modified_times = E_age_specific[i, :].numpy()
        
        # Check if any times were actually capped
        times_changed = ~np.isclose(original_times, modified_times)
        
        print(f"\nPatient {i}:")
        print(f"  Enrollment age: {enrollment_age}")
        print(f"  Current age (enrollment + {age_offset}): {current_age}")
        print(f"  Expected cap (current_age - 30): {expected_cap}")
        print(f"  Times changed: {times_changed.sum()}/{len(times_changed)} diseases")
        
        if times_changed.any():
            # Show some examples of changed times
            changed_indices = np.where(times_changed)[0][:3]  # First 3 changes
            print(f"  Example changes:")
            for idx in changed_indices:
                print(f"    Disease {idx}: {original_times[idx]:.1f} → {modified_times[idx]:.1f}")
        
        # Show unchanged diseases and their values
        unchanged_indices = np.where(~times_changed)[0]
        if len(unchanged_indices) > 0:
            print(f"  Unchanged diseases (indices): {unchanged_indices[:5]}")  # Show first 5
            print(f"  Their original times: {original_times[unchanged_indices[:5]]}")
            print(f"  Their modified times: {modified_times[unchanged_indices[:5]]}")
            print(f"  DEBUG - E_original values: {E_original[i, unchanged_indices[:5]].numpy()}")
            print(f"  DEBUG - E_age_specific values: {E_age_specific[i, unchanged_indices[:5]].numpy()}")
        
        # Verify all modified times are <= expected cap
        all_capped_correctly = np.all(modified_times <= expected_cap + 1e-6)  # small tolerance
        print(f"  All times correctly capped: {all_capped_correctly}")
        
        # Check that no times increased
        no_times_increased = np.all(modified_times <= original_times + 1e-6)
        print(f"  No times increased: {no_times_increased}")
    
    return E_original, E_age_specific

# Example usage:
E_orig, E_modified = test_age_specific_censoring(E_100k, fh_processed, age_offset=5)

# Additional verification function
def compare_age_offsets(E_100k, fh_processed, patient_idx=0):
    """
    Show how one patient's event times change across different age offsets
    """
    print(f"\n=== Patient {patient_idx} Across Different Age Offsets ===")
    
    row = fh_processed.iloc[patient_idx]
    enrollment_age = row.age
    
    print(f"Enrollment age: {enrollment_age}")
    print(f"Original event times (first 5 diseases): {E_100k[patient_idx, :5].numpy()}")
    print()
    
    for age_offset in [0, 2, 5, 10]:
        E_test = E_100k.clone()
        current_age = enrollment_age + age_offset
        time_since_30 = max(0, current_age - 30)
        
        E_test[patient_idx, :] = torch.minimum(
            E_test[patient_idx, :],
            torch.full_like(E_test[patient_idx, :], time_since_30)
        )
        
        print(f"Age offset {age_offset:2d} (age {current_age:2.0f}, cap at {time_since_30:2.0f}): {E_test[patient_idx, :5].numpy()}")

# Example usage:
compare_age_offsets(E_100k, fh_processed, patient_idx=0)

# %%
E_100k[2,180]
