# %%
# %load_ext autoreload
# %autoreload 2

from cluster_g_logit_init_acceptpsi_flatlam_healthtoo import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/1184199116.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/1184199116.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/1184199116.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/1184199116.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000,seed=1)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([407878, 348, 52]), E=torch.Size([407878, 348]), G=torch.Size([407878, 36])
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=torch.Size([10000, 36])

# %%
# When initializing the model:
original_G = G_100k # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/1949801412.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/1949801412.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
# Load references (signatures only, no healthy)
refs = torch.load('reference_trajectories.pt')
signature_refs = refs['signature_refs']
# When initializing the model:

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

torch.manual_seed(7)
np.random.seed(4)
# Create model without healthy reference
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_100k.shape[1],
    init_var_scaler=1e-1,
    G=G_100k, 
    Y=Y_100k,
    genetic_scale=3,
    prevalence_t=essentials['prevalence_t'],
    signature_references=signature_refs,  # Only pass signature refs
    healthy_reference=True,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

torch.manual_seed(0)
np.random.seed(0)
# Initialize with psi and clusters
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/3989334210.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('reference_trajectories.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/3989334210.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_92840/3989334210.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:52: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
#
# Cluster Sizes:
# Cluster 0: 11 diseases
# Cluster 1: 6 diseases
# Cluster 2: 13 diseases
# Cluster 3: 97 diseases
# Cluster 4: 22 diseases
# Cluster 5: 22 diseases
# Cluster 6: 15 diseases
# Cluster 7: 17 diseases
# Cluster 8: 35 diseases
# Cluster 9: 6 diseases
# Cluster 10: 13 diseases
# Cluster 11: 9 diseases
# Cluster 12: 11 diseases
# Cluster 13: 6 diseases
# Cluster 14: 17 diseases
# Cluster 15: 5 diseases
# Cluster 16: 15 diseases
# Cluster 17: 8 diseases
# Cluster 18: 17 diseases
# Cluster 19: 3 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-18.4207, -17.1035, -15.7863, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3847,  0.9324,  2.2496, -0.3847, -0.3847])
# Base value centered mean: 4.0349959817831405e-07
# Gamma init for k=0 (first 5): tensor([ 0.0017,  0.0129, -0.0278, -0.0078,  0.0008])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1524, -0.1524, -0.1524, -0.1524, -0.1524])
# Base value centered mean: 2.1617888705804944e-06
# Gamma init for k=1 (first 5): tensor([-0.0078, -0.0002, -0.0140,  0.0062,  0.0005])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-18.4207, -18.4207, -17.3062, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2099, -0.2099,  0.9047, -0.2099, -0.2099])
# Base value centered mean: 1.808452566365304e-06
# Gamma init for k=2 (first 5): tensor([ 0.0058,  0.0004, -0.0085,  0.0127, -0.0053])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 97
# Base value (first 5): tensor([-18.4207, -17.8232, -18.1219, -17.8232, -18.2713])
# Base value centered (first 5): tensor([-0.1558,  0.4416,  0.1429,  0.4416, -0.0065])
# Base value centered mean: -2.099037146763294e-06
# Gamma init for k=3 (first 5): tensor([ 0.0003,  0.0013, -0.0013,  0.0009,  0.0023])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 22
# Base value (first 5): tensor([-18.4207, -17.7621, -15.1278, -17.7621, -18.4207])
# Base value centered (first 5): tensor([-0.3732,  0.2854,  2.9198,  0.2854, -0.3732])
# Base value centered mean: 3.078460792949045e-07
# Gamma init for k=4 (first 5): tensor([ 0.0082,  0.0070,  0.0071, -0.0045, -0.0048])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 22
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1835, -0.1835, -0.1835, -0.1835, -0.1835])
# Base value centered mean: 1.4454841448241496e-06
# Gamma init for k=5 (first 5): tensor([ 0.0128, -0.0085, -0.0167,  0.0006, -0.0008])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.5667, -0.5667, -0.5667, -0.5667, -0.5667])
# Base value centered mean: -2.4986266566884296e-07
# Gamma init for k=6 (first 5): tensor([-0.0126,  0.0152,  0.0192,  0.0115,  0.0020])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-18.4207, -17.5684, -17.5684, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2553,  0.5970,  0.5970, -0.2553, -0.2553])
# Base value centered mean: 1.050567675520142e-06
# Gamma init for k=7 (first 5): tensor([ 0.0070,  0.0021, -0.0016, -0.0026,  0.0410])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 35
# Base value (first 5): tensor([-18.0067, -16.7648, -17.5927, -15.9369, -18.4207])
# Base value centered (first 5): tensor([-0.3356,  0.9063,  0.0783,  1.7342, -0.7496])
# Base value centered mean: 1.6441344996565022e-07
# Gamma init for k=8 (first 5): tensor([-0.0037,  0.0009, -0.0141,  0.0259, -0.0076])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1468, -0.1468, -0.1468, -0.1468, -0.1468])
# Base value centered mean: 2.3044585759635083e-06
# Gamma init for k=9 (first 5): tensor([ 0.0129,  0.0178, -0.0027,  0.0339, -0.0083])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -17.3062, -18.4207])
# Base value centered (first 5): tensor([-0.3050, -0.3050, -0.3050,  0.8095, -0.3050])
# Base value centered mean: 5.588531593048174e-08
# Gamma init for k=10 (first 5): tensor([-0.0161, -0.0048, -0.0061,  0.0133, -0.0077])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2331, -0.2331, -0.2331, -0.2331, -0.2331])
# Base value centered mean: 1.1062621751989354e-06
# Gamma init for k=11 (first 5): tensor([-0.0162,  0.0023, -0.0202, -0.0005, -0.0045])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-18.4207, -17.1035, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3584,  0.9588, -0.3584, -0.3584, -0.3584])
# Base value centered mean: 1.3365745417104336e-06
# Gamma init for k=12 (first 5): tensor([ 0.0035,  0.0122,  0.0018,  0.0084, -0.0224])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2572, -0.2572, -0.2572, -0.2572, -0.2572])
# Base value centered mean: -6.942749308791463e-08
# Gamma init for k=13 (first 5): tensor([-0.0039,  0.0034,  0.0116, -0.0019,  0.0161])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-17.5684, -16.7161, -18.4207, -17.5684, -18.4207])
# Base value centered (first 5): tensor([ 0.2530,  1.1052, -0.5993,  0.2530, -0.5993])
# Base value centered mean: 3.859520063542732e-07
# Gamma init for k=14 (first 5): tensor([ 0.0037,  0.0023, -0.0012, -0.0016,  0.0140])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5
# Base value (first 5): tensor([-18.4207, -18.4207,  -9.7274, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3996, -0.3996,  8.2937, -0.3996, -0.3996])
# Base value centered mean: 3.6293029097578255e-06
# Gamma init for k=15 (first 5): tensor([-0.0219, -0.0045, -0.0280, -0.0213, -0.0033])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-18.4207, -18.4207, -16.4888, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2005, -0.2005,  1.7313, -0.2005, -0.2005])
# Base value centered mean: 4.268646307536983e-07
# Gamma init for k=16 (first 5): tensor([-0.0053,  0.0034, -0.0017, -0.0122, -0.0025])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-18.4207, -16.6096, -12.9874, -16.6096, -18.4207])
# Base value centered (first 5): tensor([-0.9876,  0.8235,  4.4457,  0.8235, -0.9876])
# Base value centered mean: 2.362060513405595e-06
# Gamma init for k=17 (first 5): tensor([ 0.0024,  0.0018, -0.0230, -0.0050, -0.0241])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-18.4207, -17.5684, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2697,  0.5825, -0.2697, -0.2697, -0.2697])
# Base value centered mean: 1.6757965113356477e-06
# Gamma init for k=18 (first 5): tensor([ 0.0025,  0.0010, -0.0088,  0.0021, -0.0040])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 3
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1937, -0.1937, -0.1937, -0.1937, -0.1937])
# Base value centered mean: 3.179931582053541e-06
# Gamma init for k=19 (first 5): tensor([-0.0138,  0.0087, -0.0050,  0.0135,  0.0098])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-18.4207, -17.5151, -17.5151, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2656,  0.6400,  0.6400, -0.2656, -0.2656])
# Base value centered mean: 6.359100552799646e-07
# Gamma init for k=0 (first 5): tensor([ 0.0075,  0.0025, -0.0024, -0.0024,  0.0416])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-17.7307, -17.7307, -17.7307, -17.7307, -18.4207])
# Base value centered (first 5): tensor([ 0.2193,  0.2193,  0.2193,  0.2193, -0.4706])
# Base value centered mean: 2.13127145798353e-06
# Gamma init for k=1 (first 5): tensor([-2.5005e-06, -2.3957e-03, -2.4260e-02,  2.0265e-02, -7.0649e-03])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.5667, -0.5667, -0.5667, -0.5667, -0.5667])
# Base value centered mean: -2.4986266566884296e-07
# Gamma init for k=2 (first 5): tensor([-0.0126,  0.0152,  0.0192,  0.0115,  0.0020])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-18.4207, -17.8906, -18.0673, -18.2440, -18.4207])
# Base value centered (first 5): tensor([-0.1526,  0.3775,  0.2008,  0.0241, -0.1526])
# Base value centered mean: 2.290534894200391e-06
# Gamma init for k=3 (first 5): tensor([ 0.0006,  0.0020, -0.0011,  0.0026,  0.0016])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1640, -0.1640, -0.1640, -0.1640, -0.1640])
# Base value centered mean: 9.56726125878049e-07
# Gamma init for k=4 (first 5): tensor([ 0.0170,  0.0167, -0.0036,  0.0401, -0.0092])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-18.4207, -16.3508, -12.2112, -16.3508, -18.4207])
# Base value centered (first 5): tensor([-1.0567,  1.0132,  5.1529,  1.0132, -1.0567])
# Base value centered mean: -1.300811760529541e-07
# Gamma init for k=5 (first 5): tensor([ 5.5867e-05,  7.5741e-04, -2.3455e-02, -6.3306e-03, -2.4462e-02])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2416, -0.2416, -0.2416, -0.2416, -0.2416])
# Base value centered mean: -1.8920898980923084e-07
# Gamma init for k=6 (first 5): tensor([-0.0048, -0.0006,  0.0111, -0.0032,  0.0114])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-18.4207, -15.7863, -17.7621, -14.4692, -18.4207])
# Base value centered (first 5): tensor([-0.8129,  1.8214, -0.1543,  3.1386, -0.8129])
# Base value centered mean: -1.0910034120570344e-07
# Gamma init for k=7 (first 5): tensor([-0.0092,  0.0009, -0.0024,  0.0218, -0.0032])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1712, -0.1712, -0.1712, -0.1712, -0.1712])
# Base value centered mean: 8.738517749407038e-07
# Gamma init for k=8 (first 5): tensor([ 0.0104, -0.0067, -0.0143,  0.0017, -0.0015])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -17.2133, -18.4207])
# Base value centered (first 5): tensor([-0.3052, -0.3052, -0.3052,  0.9022, -0.3052])
# Base value centered mean: 8.817672778604901e-07
# Gamma init for k=9 (first 5): tensor([-0.0142, -0.0034, -0.0060,  0.0141, -0.0083])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-18.4207, -17.1035, -15.7863, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3847,  0.9324,  2.2496, -0.3847, -0.3847])
# Base value centered mean: 4.0349959817831405e-07
# Gamma init for k=10 (first 5): tensor([ 0.0017,  0.0129, -0.0278, -0.0078,  0.0008])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-18.4207, -16.6096, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1592,  1.6519, -0.1592, -0.1592, -0.1592])
# Base value centered mean: 3.319835741422139e-06
# Gamma init for k=11 (first 5): tensor([-0.0057, -0.0003, -0.0138,  0.0043,  0.0013])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1331, -0.1331, -0.1331, -0.1331, -0.1331])
# Base value centered mean: 1.4870643099129666e-06
# Gamma init for k=12 (first 5): tensor([-1.6081e-03,  8.4591e-05, -3.2553e-03, -1.3995e-02, -1.9559e-03])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-18.4207, -17.3062, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2497,  0.8649, -0.2497, -0.2497, -0.2497])
# Base value centered mean: 3.136062559860875e-06
# Gamma init for k=13 (first 5): tensor([-0.0004, -0.0006, -0.0094,  0.0045, -0.0051])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-18.4207, -16.9718, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3705,  1.0784, -0.3705, -0.3705, -0.3705])
# Base value centered mean: 2.3533821149612777e-06
# Gamma init for k=14 (first 5): tensor([ 0.0067,  0.0169, -0.0005,  0.0079, -0.0234])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-18.4207, -18.4207,  -9.7274, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3996, -0.3996,  8.2937, -0.3996, -0.3996])
# Base value centered mean: 3.6293029097578255e-06
# Gamma init for k=15 (first 5): tensor([-0.0219, -0.0045, -0.0280, -0.0213, -0.0033])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-18.4207, -18.4207, -14.9234, -17.9211, -18.4207])
# Base value centered (first 5): tensor([-0.3621, -0.3621,  3.1352,  0.1375, -0.3621])
# Base value centered mean: 3.344821834616596e-06
# Gamma init for k=16 (first 5): tensor([ 0.0070,  0.0068,  0.0027, -0.0013, -0.0051])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-17.5684, -16.7161, -18.4207, -17.5684, -18.4207])
# Base value centered (first 5): tensor([ 0.2530,  1.1052, -0.5993,  0.2530, -0.5993])
# Base value centered mean: 3.859520063542732e-07
# Gamma init for k=17 (first 5): tensor([ 0.0037,  0.0023, -0.0012, -0.0016,  0.0140])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2331, -0.2331, -0.2331, -0.2331, -0.2331])
# Base value centered mean: 1.1062621751989354e-06
# Gamma init for k=18 (first 5): tensor([-0.0162,  0.0023, -0.0202, -0.0005, -0.0045])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-18.4207, -18.4207, -17.7907, -17.1608, -17.7907])
# Base value centered (first 5): tensor([-0.2259, -0.2259,  0.4041,  1.0340,  0.4041])
# Base value centered mean: 1.327228574155015e-06
# Gamma init for k=19 (first 5): tensor([-7.4955e-05,  3.4724e-03,  6.4879e-05, -3.7299e-03,  1.5206e-03])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Clusters match exactly: True

# %%
print(model.K_total)
print(model.K)
# Out:
# 21
# 20

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")

ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# Mean observed risk: 0.000439
# Mean predicted risk (original): 0.000143
# Mean predicted risk (calibrated): 0.000439
# Calibration scale factor: 3.063
# R^2: 0.734

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Initial Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Initial Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects for these patients
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]  # Already computed above
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
# Out:
# Genetic Effect Statistics for Sample Patients:
#
# Patient 4376:
# Mean shift: 0.060
# Std of shifts: 0.290
# Range of shifts: [-0.770, 0.546]
#
# Top states and average proportions:
# State 7: 0.190
# State 3: 0.137
# State 2: 0.087
# State 8: 0.084
# State 16: 0.084
#
# Patient 6640:
# Mean shift: 0.001
# Std of shifts: 0.386
# Range of shifts: [-0.313, 1.612]
#
# Top states and average proportions:
# State 5: 0.194
# State 3: 0.143
# State 7: 0.111
# State 8: 0.089
# State 17: 0.071

# %%
model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:847: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
history_new = model.fit(E_100k, num_epochs=100, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:238: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 0
# Loss: 76.8194
# Psi gradient stats:
# Mean: 1.3404e-05
# Std:  4.7403e-04
# Max:  1.6437e-03
# Min:  -1.7844e-03
# Epoch 0, Loss: 76.8194, Gradients - Lambda: 5.280e-02, Phi: 1.391e+00, Gamma: 1.575e-02, Psi: 1.784e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 1
# Loss: 76.6585
# Psi gradient stats:
# Mean: 1.3409e-05
# Std:  4.7396e-04
# Max:  1.6422e-03
# Min:  -1.7844e-03
# Epoch 1, Loss: 76.6585, Gradients - Lambda: 5.264e-02, Phi: 1.386e+00, Gamma: 1.571e-02, Psi: 1.784e-03
#
# Estimated total training time: 48.2 minutes
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 2
# Loss: 75.0365
# Psi gradient stats:
# Mean: 1.3440e-05
# Std:  4.7320e-04
# Max:  1.6365e-03
# Min:  -1.7855e-03
# Epoch 2, Loss: 75.0365, Gradients - Lambda: 5.087e-02, Phi: 1.331e+00, Gamma: 1.520e-02, Psi: 1.785e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 3
# Loss: 72.6127
# Psi gradient stats:
# Mean: 1.3481e-05
# Std:  4.7177e-04
# Max:  1.6350e-03
# Min:  -1.7878e-03
# Epoch 3, Loss: 72.6127, Gradients - Lambda: 4.764e-02, Phi: 1.227e+00, Gamma: 1.420e-02, Psi: 1.788e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 4
# Loss: 70.4745
# Psi gradient stats:
# Mean: 1.3499e-05
# Std:  4.6987e-04
# Max:  1.6246e-03
# Min:  -1.7960e-03
# Epoch 4, Loss: 70.4745, Gradients - Lambda: 4.261e-02, Phi: 1.074e+00, Gamma: 1.278e-02, Psi: 1.796e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 5
# Loss: 69.4433
# Psi gradient stats:
# Mean: 1.3481e-05
# Std:  4.6751e-04
# Max:  1.6237e-03
# Min:  -1.8068e-03
# Epoch 5, Loss: 69.4433, Gradients - Lambda: 3.548e-02, Phi: 9.100e-01, Gamma: 1.107e-02, Psi: 1.807e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 6
# Loss: 69.7226
# Psi gradient stats:
# Mean: 1.3350e-05
# Std:  4.6470e-04
# Max:  1.6603e-03
# Min:  -1.8103e-03
# Epoch 6, Loss: 69.7226, Gradients - Lambda: 2.948e-02, Phi: 7.032e-01, Gamma: 1.039e-02, Psi: 1.810e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 7
# Loss: 70.8699
# Psi gradient stats:
# Mean: 1.3126e-05
# Std:  4.6151e-04
# Max:  1.6935e-03
# Min:  -1.8042e-03
# Epoch 7, Loss: 70.8699, Gradients - Lambda: 2.940e-02, Phi: 6.350e-01, Gamma: 9.411e-03, Psi: 1.804e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 8
# Loss: 72.1278
# Psi gradient stats:
# Mean: 1.2796e-05
# Std:  4.5824e-04
# Max:  1.7204e-03
# Min:  -1.7895e-03
# Epoch 8, Loss: 72.1278, Gradients - Lambda: 2.894e-02, Phi: 7.095e-01, Gamma: 8.165e-03, Psi: 1.789e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 9
# Loss: 72.8551
# Psi gradient stats:
# Mean: 1.2371e-05
# Std:  4.5522e-04
# Max:  1.7320e-03
# Min:  -1.7666e-03
# Epoch 9, Loss: 72.8551, Gradients - Lambda: 3.064e-02, Phi: 7.419e-01, Gamma: 7.267e-03, Psi: 1.767e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 10
# Loss: 72.8069
# Psi gradient stats:
# Mean: 1.1898e-05
# Std:  4.5276e-04
# Max:  1.7258e-03
# Min:  -1.7329e-03
# Epoch 10, Loss: 72.8069, Gradients - Lambda: 3.210e-02, Phi: 8.561e-01, Gamma: 8.313e-03, Psi: 1.733e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 11
# Loss: 72.1551
# Psi gradient stats:
# Mean: 1.1354e-05
# Std:  4.5118e-04
# Max:  1.7054e-03
# Min:  -1.7322e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 12
# Loss: 71.2459
# Psi gradient stats:
# Mean: 1.0818e-05
# Std:  4.5035e-04
# Max:  1.6737e-03
# Min:  -1.7425e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 13
# Loss: 70.3832
# Psi gradient stats:
# Mean: 1.0343e-05
# Std:  4.5012e-04
# Max:  1.6373e-03
# Min:  -1.7424e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 14
# Loss: 69.7399
# Psi gradient stats:
# Mean: 9.9930e-06
# Std:  4.5025e-04
# Max:  1.6015e-03
# Min:  -1.7328e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 15
# Loss: 69.3572
# Psi gradient stats:
# Mean: 9.7685e-06
# Std:  4.5052e-04
# Max:  1.5680e-03
# Min:  -1.7177e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 16
# Loss: 69.1866
# Psi gradient stats:
# Mean: 9.6248e-06
# Std:  4.5073e-04
# Max:  1.5401e-03
# Min:  -1.7189e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 17
# Loss: 69.1410
# Psi gradient stats:
# Mean: 9.5413e-06
# Std:  4.5074e-04
# Max:  1.5198e-03
# Min:  -1.7308e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 18
# Loss: 69.1338
# Psi gradient stats:
# Mean: 9.4902e-06
# Std:  4.5041e-04
# Max:  1.5259e-03
# Min:  -1.7333e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 19
# Loss: 69.1037
# Psi gradient stats:
# Mean: 9.4789e-06
# Std:  4.4975e-04
# Max:  1.5252e-03
# Min:  -1.7276e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 20
# Loss: 69.0226
# Psi gradient stats:
# Mean: 9.4941e-06
# Std:  4.4876e-04
# Max:  1.5172e-03
# Min:  -1.7149e-03
# Epoch 20, Loss: 69.0226, Gradients - Lambda: 2.235e-02, Phi: 5.172e-01, Gamma: 6.662e-03, Psi: 1.715e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 21
# Loss: 68.8915
# Psi gradient stats:
# Mean: 9.5624e-06
# Std:  4.4751e-04
# Max:  1.5258e-03
# Min:  -1.6992e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 22
# Loss: 68.7302
# Psi gradient stats:
# Mean: 9.6799e-06
# Std:  4.4609e-04
# Max:  1.5363e-03
# Min:  -1.6823e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 23
# Loss: 68.5640
# Psi gradient stats:
# Mean: 9.8549e-06
# Std:  4.4459e-04
# Max:  1.5457e-03
# Min:  -1.6658e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 24
# Loss: 68.4148
# Psi gradient stats:
# Mean: 1.0044e-05
# Std:  4.4315e-04
# Max:  1.5522e-03
# Min:  -1.6610e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 25
# Loss: 68.2948
# Psi gradient stats:
# Mean: 1.0227e-05
# Std:  4.4192e-04
# Max:  1.5581e-03
# Min:  -1.6662e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 26
# Loss: 68.2066
# Psi gradient stats:
# Mean: 1.0414e-05
# Std:  4.4095e-04
# Max:  1.5625e-03
# Min:  -1.6727e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 27
# Loss: 68.1442
# Psi gradient stats:
# Mean: 1.0613e-05
# Std:  4.4024e-04
# Max:  1.5664e-03
# Min:  -1.6770e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 28
# Loss: 68.0983
# Psi gradient stats:
# Mean: 1.0835e-05
# Std:  4.3974e-04
# Max:  1.5686e-03
# Min:  -1.6769e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 29
# Loss: 68.0592
# Psi gradient stats:
# Mean: 1.1044e-05
# Std:  4.3938e-04
# Max:  1.5704e-03
# Min:  -1.6749e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 30
# Loss: 68.0202
# Psi gradient stats:
# Mean: 1.1227e-05
# Std:  4.3909e-04
# Max:  1.5723e-03
# Min:  -1.6723e-03
# Epoch 30, Loss: 68.0202, Gradients - Lambda: 1.649e-02, Phi: 3.789e-01, Gamma: 3.583e-03, Psi: 1.672e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 31
# Loss: 67.9782
# Psi gradient stats:
# Mean: 1.1403e-05
# Std:  4.3879e-04
# Max:  1.5752e-03
# Min:  -1.6755e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 32
# Loss: 67.9335
# Psi gradient stats:
# Mean: 1.1564e-05
# Std:  4.3842e-04
# Max:  1.5796e-03
# Min:  -1.6844e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 33
# Loss: 67.8881
# Psi gradient stats:
# Mean: 1.1678e-05
# Std:  4.3796e-04
# Max:  1.5867e-03
# Min:  -1.6883e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 34
# Loss: 67.8451
# Psi gradient stats:
# Mean: 1.1756e-05
# Std:  4.3742e-04
# Max:  1.5929e-03
# Min:  -1.6860e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 35
# Loss: 67.8065
# Psi gradient stats:
# Mean: 1.1761e-05
# Std:  4.3678e-04
# Max:  1.5984e-03
# Min:  -1.6805e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 36
# Loss: 67.7736
# Psi gradient stats:
# Mean: 1.1702e-05
# Std:  4.3603e-04
# Max:  1.6025e-03
# Min:  -1.6720e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 37
# Loss: 67.7459
# Psi gradient stats:
# Mean: 1.1611e-05
# Std:  4.3523e-04
# Max:  1.6037e-03
# Min:  -1.6633e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 38
# Loss: 67.7221
# Psi gradient stats:
# Mean: 1.1485e-05
# Std:  4.3442e-04
# Max:  1.6019e-03
# Min:  -1.6551e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 39
# Loss: 67.7008
# Psi gradient stats:
# Mean: 1.1336e-05
# Std:  4.3359e-04
# Max:  1.5971e-03
# Min:  -1.6457e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 40
# Loss: 67.6809
# Psi gradient stats:
# Mean: 1.1180e-05
# Std:  4.3275e-04
# Max:  1.5886e-03
# Min:  -1.6457e-03
# Epoch 40, Loss: 67.6809, Gradients - Lambda: 9.535e-03, Phi: 2.610e-01, Gamma: 4.038e-03, Psi: 1.646e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 41
# Loss: 67.6618
# Psi gradient stats:
# Mean: 1.1031e-05
# Std:  4.3194e-04
# Max:  1.5804e-03
# Min:  -1.6453e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 42
# Loss: 67.6435
# Psi gradient stats:
# Mean: 1.0880e-05
# Std:  4.3117e-04
# Max:  1.5731e-03
# Min:  -1.6438e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 43
# Loss: 67.6258
# Psi gradient stats:
# Mean: 1.0722e-05
# Std:  4.3044e-04
# Max:  1.5674e-03
# Min:  -1.6426e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 44
# Loss: 67.6093
# Psi gradient stats:
# Mean: 1.0596e-05
# Std:  4.2974e-04
# Max:  1.5645e-03
# Min:  -1.6428e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 45
# Loss: 67.5941
# Psi gradient stats:
# Mean: 1.0504e-05
# Std:  4.2908e-04
# Max:  1.5631e-03
# Min:  -1.6429e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 46
# Loss: 67.5806
# Psi gradient stats:
# Mean: 1.0439e-05
# Std:  4.2845e-04
# Max:  1.5624e-03
# Min:  -1.6432e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 47
# Loss: 67.5685
# Psi gradient stats:
# Mean: 1.0408e-05
# Std:  4.2782e-04
# Max:  1.5621e-03
# Min:  -1.6438e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 48
# Loss: 67.5579
# Psi gradient stats:
# Mean: 1.0433e-05
# Std:  4.2720e-04
# Max:  1.5627e-03
# Min:  -1.6451e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 49
# Loss: 67.5482
# Psi gradient stats:
# Mean: 1.0458e-05
# Std:  4.2660e-04
# Max:  1.5637e-03
# Min:  -1.6474e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 50
# Loss: 67.5393
# Psi gradient stats:
# Mean: 1.0482e-05
# Std:  4.2601e-04
# Max:  1.5654e-03
# Min:  -1.6497e-03
# Epoch 50, Loss: 67.5393, Gradients - Lambda: 6.250e-03, Phi: 1.766e-01, Gamma: 2.141e-03, Psi: 1.650e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 51
# Loss: 67.5307
# Psi gradient stats:
# Mean: 1.0506e-05
# Std:  4.2544e-04
# Max:  1.5670e-03
# Min:  -1.6512e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 52
# Loss: 67.5225
# Psi gradient stats:
# Mean: 1.0523e-05
# Std:  4.2489e-04
# Max:  1.5668e-03
# Min:  -1.6517e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 53
# Loss: 67.5147
# Psi gradient stats:
# Mean: 1.0569e-05
# Std:  4.2432e-04
# Max:  1.5672e-03
# Min:  -1.6508e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 54
# Loss: 67.5073
# Psi gradient stats:
# Mean: 1.0620e-05
# Std:  4.2374e-04
# Max:  1.5660e-03
# Min:  -1.6484e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 55
# Loss: 67.5004
# Psi gradient stats:
# Mean: 1.0656e-05
# Std:  4.2316e-04
# Max:  1.5620e-03
# Min:  -1.6448e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 56
# Loss: 67.4941
# Psi gradient stats:
# Mean: 1.0670e-05
# Std:  4.2257e-04
# Max:  1.5590e-03
# Min:  -1.6415e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 57
# Loss: 67.4882
# Psi gradient stats:
# Mean: 1.0684e-05
# Std:  4.2196e-04
# Max:  1.5546e-03
# Min:  -1.6389e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 58
# Loss: 67.4829
# Psi gradient stats:
# Mean: 1.0672e-05
# Std:  4.2136e-04
# Max:  1.5510e-03
# Min:  -1.6360e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 59
# Loss: 67.4779
# Psi gradient stats:
# Mean: 1.0642e-05
# Std:  4.2076e-04
# Max:  1.5500e-03
# Min:  -1.6329e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 60
# Loss: 67.4733
# Psi gradient stats:
# Mean: 1.0621e-05
# Std:  4.2016e-04
# Max:  1.5494e-03
# Min:  -1.6294e-03
# Epoch 60, Loss: 67.4733, Gradients - Lambda: 3.833e-03, Phi: 1.125e-01, Gamma: 2.636e-03, Psi: 1.629e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 61
# Loss: 67.4688
# Psi gradient stats:
# Mean: 1.0618e-05
# Std:  4.1957e-04
# Max:  1.5495e-03
# Min:  -1.6267e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 62
# Loss: 67.4647
# Psi gradient stats:
# Mean: 1.0607e-05
# Std:  4.1898e-04
# Max:  1.5496e-03
# Min:  -1.6240e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 63
# Loss: 67.4606
# Psi gradient stats:
# Mean: 1.0626e-05
# Std:  4.1840e-04
# Max:  1.5502e-03
# Min:  -1.6238e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 64
# Loss: 67.4567
# Psi gradient stats:
# Mean: 1.0641e-05
# Std:  4.1782e-04
# Max:  1.5520e-03
# Min:  -1.6243e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 65
# Loss: 67.4531
# Psi gradient stats:
# Mean: 1.0650e-05
# Std:  4.1725e-04
# Max:  1.5548e-03
# Min:  -1.6251e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 66
# Loss: 67.4496
# Psi gradient stats:
# Mean: 1.0630e-05
# Std:  4.1666e-04
# Max:  1.5571e-03
# Min:  -1.6265e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 67
# Loss: 67.4463
# Psi gradient stats:
# Mean: 1.0633e-05
# Std:  4.1608e-04
# Max:  1.5595e-03
# Min:  -1.6268e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 68
# Loss: 67.4432
# Psi gradient stats:
# Mean: 1.0637e-05
# Std:  4.1549e-04
# Max:  1.5609e-03
# Min:  -1.6263e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 69
# Loss: 67.4402
# Psi gradient stats:
# Mean: 1.0630e-05
# Std:  4.1491e-04
# Max:  1.5605e-03
# Min:  -1.6258e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 70
# Loss: 67.4373
# Psi gradient stats:
# Mean: 1.0605e-05
# Std:  4.1431e-04
# Max:  1.5591e-03
# Min:  -1.6245e-03
# Epoch 70, Loss: 67.4373, Gradients - Lambda: 2.756e-03, Phi: 6.177e-02, Gamma: 2.367e-03, Psi: 1.624e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 71
# Loss: 67.4344
# Psi gradient stats:
# Mean: 1.0586e-05
# Std:  4.1370e-04
# Max:  1.5575e-03
# Min:  -1.6235e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 72
# Loss: 67.4317
# Psi gradient stats:
# Mean: 1.0550e-05
# Std:  4.1309e-04
# Max:  1.5549e-03
# Min:  -1.6221e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 73
# Loss: 67.4291
# Psi gradient stats:
# Mean: 1.0512e-05
# Std:  4.1248e-04
# Max:  1.5531e-03
# Min:  -1.6213e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 74
# Loss: 67.4266
# Psi gradient stats:
# Mean: 1.0455e-05
# Std:  4.1188e-04
# Max:  1.5513e-03
# Min:  -1.6202e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 75
# Loss: 67.4242
# Psi gradient stats:
# Mean: 1.0431e-05
# Std:  4.1127e-04
# Max:  1.5496e-03
# Min:  -1.6171e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 76
# Loss: 67.4218
# Psi gradient stats:
# Mean: 1.0409e-05
# Std:  4.1065e-04
# Max:  1.5484e-03
# Min:  -1.6159e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 77
# Loss: 67.4195
# Psi gradient stats:
# Mean: 1.0391e-05
# Std:  4.1007e-04
# Max:  1.5470e-03
# Min:  -1.6144e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 78
# Loss: 67.4173
# Psi gradient stats:
# Mean: 1.0388e-05
# Std:  4.0948e-04
# Max:  1.5448e-03
# Min:  -1.6125e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 79
# Loss: 67.4151
# Psi gradient stats:
# Mean: 1.0382e-05
# Std:  4.0892e-04
# Max:  1.5442e-03
# Min:  -1.6129e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 80
# Loss: 67.4130
# Psi gradient stats:
# Mean: 1.0372e-05
# Std:  4.0834e-04
# Max:  1.5439e-03
# Min:  -1.6121e-03
# Epoch 80, Loss: 67.4130, Gradients - Lambda: 2.148e-03, Phi: 3.751e-02, Gamma: 2.372e-03, Psi: 1.612e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 81
# Loss: 67.4109
# Psi gradient stats:
# Mean: 1.0366e-05
# Std:  4.0776e-04
# Max:  1.5432e-03
# Min:  -1.6116e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 82
# Loss: 67.4088
# Psi gradient stats:
# Mean: 1.0364e-05
# Std:  4.0720e-04
# Max:  1.5439e-03
# Min:  -1.6123e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 83
# Loss: 67.4068
# Psi gradient stats:
# Mean: 1.0371e-05
# Std:  4.0663e-04
# Max:  1.5437e-03
# Min:  -1.6120e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 84
# Loss: 67.4049
# Psi gradient stats:
# Mean: 1.0365e-05
# Std:  4.0606e-04
# Max:  1.5416e-03
# Min:  -1.6111e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 85
# Loss: 67.4030
# Psi gradient stats:
# Mean: 1.0360e-05
# Std:  4.0551e-04
# Max:  1.5420e-03
# Min:  -1.6112e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 86
# Loss: 67.4011
# Psi gradient stats:
# Mean: 1.0363e-05
# Std:  4.0493e-04
# Max:  1.5409e-03
# Min:  -1.6096e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 87
# Loss: 67.3993
# Psi gradient stats:
# Mean: 1.0360e-05
# Std:  4.0436e-04
# Max:  1.5407e-03
# Min:  -1.6084e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 88
# Loss: 67.3975
# Psi gradient stats:
# Mean: 1.0349e-05
# Std:  4.0381e-04
# Max:  1.5398e-03
# Min:  -1.6062e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 89
# Loss: 67.3957
# Psi gradient stats:
# Mean: 1.0343e-05
# Std:  4.0323e-04
# Max:  1.5392e-03
# Min:  -1.6041e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 90
# Loss: 67.3939
# Psi gradient stats:
# Mean: 1.0327e-05
# Std:  4.0267e-04
# Max:  1.5381e-03
# Min:  -1.6029e-03
# Epoch 90, Loss: 67.3939, Gradients - Lambda: 2.414e-03, Phi: 3.799e-02, Gamma: 2.325e-03, Psi: 1.603e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 91
# Loss: 67.3922
# Psi gradient stats:
# Mean: 1.0317e-05
# Std:  4.0211e-04
# Max:  1.5387e-03
# Min:  -1.6011e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 92
# Loss: 67.3905
# Psi gradient stats:
# Mean: 1.0314e-05
# Std:  4.0154e-04
# Max:  1.5374e-03
# Min:  -1.6006e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 93
# Loss: 67.3888
# Psi gradient stats:
# Mean: 1.0294e-05
# Std:  4.0098e-04
# Max:  1.5372e-03
# Min:  -1.5996e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 94
# Loss: 67.3871
# Psi gradient stats:
# Mean: 1.0272e-05
# Std:  4.0042e-04
# Max:  1.5371e-03
# Min:  -1.5982e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 95
# Loss: 67.3855
# Psi gradient stats:
# Mean: 1.0265e-05
# Std:  3.9986e-04
# Max:  1.5368e-03
# Min:  -1.5977e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 96
# Loss: 67.3839
# Psi gradient stats:
# Mean: 1.0252e-05
# Std:  3.9930e-04
# Max:  1.5347e-03
# Min:  -1.5964e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 97
# Loss: 67.3823
# Psi gradient stats:
# Mean: 1.0237e-05
# Std:  3.9872e-04
# Max:  1.5344e-03
# Min:  -1.5956e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 98
# Loss: 67.3807
# Psi gradient stats:
# Mean: 1.0223e-05
# Std:  3.9816e-04
# Max:  1.5336e-03
# Min:  -1.5957e-03
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 99
# Loss: 67.3791
# Psi gradient stats:
# Mean: 1.0216e-05
# Std:  3.9760e-04
# Max:  1.5330e-03
# Min:  -1.5951e-03

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=1e-4:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Lambda changes with lr=1e-4:
# Mean absolute change: 1.785e-04
# Max absolute change: 5.022e-03
# Std of changes: 1.790e-04

# %%
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# Clusters match exactly: True

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history_new['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history_new['max_grad_lambda'], label='Lambda')
ax2.plot(history_new['max_grad_phi'], label='Phi')
ax2.plot(history_new['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
model_save_path='/Users/sarahurbut/Dropbox (Personal)/model_with_poptrajectory_lr1e-4_grad.pt'
torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'initial_phi': initial_phi, 
    'initial_lambda': initial_lambda, 
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t': essentials['prevalence_t'],
    'logit_prevalence_t': model.logit_prev_t,
    'G': G_100k,
    'E': E_100k,
    'indices': indices,
    'disease_names': essentials['disease_names'],
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T': Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, model_save_path)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000439
# Mean predicted risk (original): 0.000143
# Mean predicted risk (calibrated): 0.000439
# Calibration scale factor: 3.063

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.734

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Paroxysmal ventricular tachycardia: effect=1.253 (OR=3.50), std=0.046
# Aortic valve disease: effect=1.187 (OR=3.28), std=0.028
# Heart failure NOS: effect=1.150 (OR=3.16), std=0.049
# Pericarditis: effect=1.064 (OR=2.90), std=0.142
# Congestive heart failure (CHF) NOS: effect=1.032 (OR=2.81), std=0.037
# Left bundle branch block: effect=1.003 (OR=2.73), std=0.072
# Cardiomegaly: effect=1.002 (OR=2.72), std=0.019
# Mitral valve disease: effect=0.977 (OR=2.66), std=0.075
# Congenital anomalies of great vessels: effect=0.942 (OR=2.57), std=0.047
# Atrial fibrillation and flutter: effect=0.926 (OR=2.53), std=0.105
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Enthesopathy: effect=1.228 (OR=3.42), std=0.031
# Other disorders of synovium, tendon, and bursa: effect=1.170 (OR=3.22), std=0.014
# Hallux valgus (Bunion): effect=1.161 (OR=3.19), std=0.043
# Peripheral enthesopathies and allied syndromes: effect=1.116 (OR=3.05), std=0.041
# Other peripheral nerve disorders: effect=1.110 (OR=3.03), std=0.145
# Rheumatoid arthritis: effect=1.098 (OR=3.00), std=0.022
# Hallux rigidus: effect=1.090 (OR=2.98), std=0.089
# Pain in joint: effect=1.081 (OR=2.95), std=0.027
# Osteoarthrosis, localized, primary: effect=1.056 (OR=2.87), std=0.023
# Synovitis and tenosynovitis: effect=1.011 (OR=2.75), std=0.053
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Gastritis and duodenitis: effect=1.200 (OR=3.32), std=0.108
# Gastric ulcer: effect=1.154 (OR=3.17), std=0.049
# Barrett's esophagus: effect=1.140 (OR=3.13), std=0.031
# Stricture and stenosis of esophagus: effect=1.134 (OR=3.11), std=0.087
# Duodenitis: effect=1.002 (OR=2.72), std=0.093
# Other disorders of stomach and duodenum: effect=0.985 (OR=2.68), std=0.055
# Diaphragmatic hernia: effect=0.978 (OR=2.66), std=0.029
# Iron deficiency anemias, unspecified or not due to blood loss: effect=0.976 (OR=2.65), std=0.061
# Duodenal ulcer: effect=0.972 (OR=2.64), std=0.043
# Esophageal bleeding (varices/hemorrhage): effect=0.965 (OR=2.63), std=0.020
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Peripheral vascular disease, unspecified: effect=1.303 (OR=3.68), std=0.032
# Other tests: effect=1.282 (OR=3.61), std=0.020
# Celiac disease: effect=1.264 (OR=3.54), std=0.091
# Right bundle branch block: effect=1.218 (OR=3.38), std=0.064
# Hemangioma and lymphangioma, any site: effect=1.217 (OR=3.38), std=0.097
# Atopic/contact dermatitis due to other or unspecified: effect=1.210 (OR=3.35), std=0.038
# Blood in stool: effect=1.127 (OR=3.09), std=0.036
# Acute upper respiratory infections of multiple or unspecified sites: effect=1.125 (OR=3.08), std=0.101
# Perforation of tympanic membrane: effect=1.121 (OR=3.07), std=0.046
# Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: effect=1.118 (OR=3.06), std=0.124
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Other upper respiratory disease: effect=1.002 (OR=2.72), std=0.036
# Nasal polyps: effect=0.880 (OR=2.41), std=0.128
# Chronic sinusitis: effect=0.876 (OR=2.40), std=0.041
# Septal Deviations/Turbinate Hypertrophy: effect=0.875 (OR=2.40), std=0.100
# Chronic pharyngitis and nasopharyngitis: effect=0.861 (OR=2.37), std=0.116
# Hemangioma and lymphangioma, any site: effect=-1.736 (OR=0.18), std=0.082
# Other acquired deformities of limbs: effect=-1.774 (OR=0.17), std=0.075
# Enthesopathy: effect=-1.787 (OR=0.17), std=0.066
# Retinal detachment with retinal defect: effect=-1.801 (OR=0.17), std=0.034
# Other disorders of biliary tract: effect=-1.821 (OR=0.16), std=0.149
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Coronary atherosclerosis: effect=1.236 (OR=3.44), std=0.032
# Other acute and subacute forms of ischemic heart disease: effect=1.131 (OR=3.10), std=0.042
# Hypercholesterolemia: effect=1.096 (OR=2.99), std=0.014
# Angina pectoris: effect=0.854 (OR=2.35), std=0.110
# Unstable angina (intermediate coronary syndrome): effect=0.812 (OR=2.25), std=0.049
# Myocardial infarction: effect=0.776 (OR=2.17), std=0.021
# Other chronic ischemic heart disease, unspecified: effect=0.731 (OR=2.08), std=0.014
# Paroxysmal supraventricular tachycardia: effect=-1.753 (OR=0.17), std=0.051
# Allergic rhinitis: effect=-1.768 (OR=0.17), std=0.079
# Other specified gastritis: effect=-1.806 (OR=0.16), std=0.054
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Secondary malignant neoplasm of liver: effect=1.066 (OR=2.90), std=0.139
# Secondary malignancy of lymph nodes: effect=1.056 (OR=2.88), std=0.065
# Secondary malignant neoplasm: effect=1.033 (OR=2.81), std=0.058
# Cancer of bronchus; lung: effect=1.021 (OR=2.77), std=0.034
# Secondary malignant neoplasm of digestive systems: effect=1.017 (OR=2.77), std=0.125
# Secondary malignancy of bone: effect=0.943 (OR=2.57), std=0.036
# Malignant neoplasm, other: effect=0.935 (OR=2.55), std=0.056
# Secondary malignancy of respiratory organs: effect=0.703 (OR=2.02), std=0.059
# Other disorders of the kidney and ureters: effect=-1.757 (OR=0.17), std=0.060
# Anal and rectal polyp: effect=-1.770 (OR=0.17), std=0.108
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Asthma: effect=1.385 (OR=3.99), std=0.065
# Migraine: effect=1.359 (OR=3.89), std=0.047
# Osteoporosis NOS: effect=1.219 (OR=3.38), std=0.041
# Myalgia and myositis unspecified: effect=1.162 (OR=3.20), std=0.058
# Major depressive disorder: effect=1.142 (OR=3.13), std=0.077
# Obesity: effect=1.135 (OR=3.11), std=0.149
# Abdominal pain: effect=1.121 (OR=3.07), std=0.056
# Cervicalgia: effect=1.095 (OR=2.99), std=0.062
# Other disorders of bone and cartilage: effect=1.073 (OR=2.92), std=0.024
# Hyperlipidemia: effect=1.055 (OR=2.87), std=0.064
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Cervicitis and endocervicitis: effect=1.356 (OR=3.88), std=0.071
# Ovarian cyst: effect=1.260 (OR=3.52), std=0.070
# Polyp of corpus uteri: effect=1.198 (OR=3.31), std=0.030
# Noninflammatory disorders of cervix: effect=1.142 (OR=3.13), std=0.101
# Malignant neoplasm of uterus: effect=1.141 (OR=3.13), std=0.085
# Excessive or frequent menstruation: effect=1.140 (OR=3.13), std=0.050
# Endometrial hyperplasia: effect=1.116 (OR=3.05), std=0.060
# Noninflammatory disorders of vagina: effect=1.099 (OR=3.00), std=0.045
# Hypertrophy of female genital organs: effect=1.091 (OR=2.98), std=0.042
# Pain and other symptoms associated with female genital organs: effect=1.068 (OR=2.91), std=0.045
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Back pain: effect=1.313 (OR=3.72), std=0.058
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=1.115 (OR=3.05), std=0.083
# Displacement of intervertebral disc: effect=1.111 (OR=3.04), std=0.058
# Neuralgia, neuritis, and radiculitis NOS: effect=1.052 (OR=2.86), std=0.047
# Other and unspecified disc disorder: effect=0.989 (OR=2.69), std=0.055
# Degenerative disease of the spinal cord: effect=0.978 (OR=2.66), std=0.068
# Spondylosis without myelopathy: effect=0.971 (OR=2.64), std=0.023
# Kyphoscoliosis and scoliosis: effect=0.900 (OR=2.46), std=0.025
# Acquired spondylolisthesis: effect=0.890 (OR=2.43), std=0.060
# Spinal stenosis: effect=0.872 (OR=2.39), std=0.072
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Primary open angle glaucoma: effect=1.264 (OR=3.54), std=0.067
# Macular degeneration (senile) of retina NOS: effect=1.210 (OR=3.35), std=0.029
# Retinal vascular changes and abnomalities: effect=1.193 (OR=3.30), std=0.115
# Other retinal disorders: effect=1.160 (OR=3.19), std=0.161
# Myopia: effect=1.145 (OR=3.14), std=0.082
# Glaucoma: effect=1.027 (OR=2.79), std=0.031
# Disorders of vitreous body: effect=1.009 (OR=2.74), std=0.058
# Senile cataract: effect=0.997 (OR=2.71), std=0.040
# Retinal detachment with retinal defect: effect=0.876 (OR=2.40), std=0.083
# Cataract: effect=0.869 (OR=2.38), std=0.038
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Occlusion of cerebral arteries: effect=1.148 (OR=3.15), std=0.037
# Cerebral ischemia: effect=1.109 (OR=3.03), std=0.050
# Late effects of cerebrovascular disease: effect=1.093 (OR=2.98), std=0.050
# Cerebral artery occlusion, with cerebral infarction: effect=1.051 (OR=2.86), std=0.055
# Hemiplegia: effect=1.017 (OR=2.77), std=0.047
# Transient cerebral ischemia: effect=0.925 (OR=2.52), std=0.107
# Cerebrovascular disease: effect=0.922 (OR=2.51), std=0.058
# Occlusion and stenosis of precerebral arteries: effect=0.872 (OR=2.39), std=0.061
# Retinal detachment with retinal defect: effect=-1.769 (OR=0.17), std=0.019
# Scar conditions and fibrosis of skin: effect=-1.771 (OR=0.17), std=0.011
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Renal colic: effect=1.260 (OR=3.53), std=0.066
# Hydronephrosis: effect=1.068 (OR=2.91), std=0.102
# Other disorders of the kidney and ureters: effect=1.040 (OR=2.83), std=0.059
# Calculus of ureter: effect=1.011 (OR=2.75), std=0.065
# Stricture/obstruction of ureter: effect=0.995 (OR=2.71), std=0.132
# Calculus of kidney: effect=0.936 (OR=2.55), std=0.042
# Pyelonephritis: effect=0.858 (OR=2.36), std=0.025
# Streptococcus infection: effect=-1.788 (OR=0.17), std=0.048
# Occlusion of cerebral arteries: effect=-1.828 (OR=0.16), std=0.073
# Unstable angina (intermediate coronary syndrome): effect=-1.841 (OR=0.16), std=0.066
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Urethral stricture (not specified as infectious): effect=1.261 (OR=3.53), std=0.035
# Cystitis: effect=1.211 (OR=3.36), std=0.024
# Cancer of prostate: effect=1.154 (OR=3.17), std=0.053
# Other symptoms/disorders or the urinary system: effect=1.060 (OR=2.89), std=0.057
# Malignant neoplasm of bladder: effect=1.059 (OR=2.88), std=0.036
# Other disorders of bladder: effect=1.011 (OR=2.75), std=0.052
# Chronic cystitis: effect=0.981 (OR=2.67), std=0.139
# Urinary incontinence: effect=0.977 (OR=2.66), std=0.061
# Hyperplasia of prostate: effect=0.914 (OR=2.49), std=0.067
# Bladder neck obstruction: effect=0.910 (OR=2.48), std=0.053
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Empyema and pneumothorax: effect=1.105 (OR=3.02), std=0.096
# Pneumonia: effect=1.046 (OR=2.85), std=0.016
# Emphysema: effect=1.028 (OR=2.79), std=0.053
# Obstructive chronic bronchitis: effect=0.909 (OR=2.48), std=0.056
# Bronchiectasis: effect=0.905 (OR=2.47), std=0.134
# Pneumococcal pneumonia: effect=0.861 (OR=2.37), std=0.013
# Chronic airway obstruction: effect=0.793 (OR=2.21), std=0.012
# Postinflammatory pulmonary fibrosis: effect=0.786 (OR=2.20), std=0.085
# Respiratory failure: effect=0.763 (OR=2.15), std=0.042
# Tobacco use disorder: effect=0.735 (OR=2.09), std=0.038
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Hypoglycemia: effect=1.237 (OR=3.44), std=0.112
# Type 2 diabetes with ophthalmic manifestations: effect=1.106 (OR=3.02), std=0.088
# Type 1 diabetes: effect=0.989 (OR=2.69), std=0.101
# Diabetic retinopathy: effect=0.981 (OR=2.67), std=0.030
# Type 2 diabetes: effect=0.853 (OR=2.35), std=0.075
# Lipoma of skin and subcutaneous tissue: effect=-1.763 (OR=0.17), std=0.066
# Pleurisy; pleural effusion: effect=-1.772 (OR=0.17), std=0.049
# Disorders of uterus, NEC: effect=-1.807 (OR=0.16), std=0.063
# Spinal stenosis: effect=-1.815 (OR=0.16), std=0.019
# Calculus of bile duct: effect=-1.823 (OR=0.16), std=0.049
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Peritonitis and retroperitoneal infections: effect=1.110 (OR=3.04), std=0.030
# E. coli: effect=1.102 (OR=3.01), std=0.037
# Other diseases of respiratory system, NEC: effect=1.099 (OR=3.00), std=0.053
# Hypotension NOS: effect=1.086 (OR=2.96), std=0.040
# Hyperpotassemia: effect=1.084 (OR=2.96), std=0.143
# Cellulitis and abscess of arm/hand: effect=1.073 (OR=2.92), std=0.055
# Chronic ulcer of skin: effect=1.070 (OR=2.91), std=0.025
# Gram negative septicemia: effect=1.065 (OR=2.90), std=0.062
# Acute renal failure: effect=1.062 (OR=2.89), std=0.035
# Bacterial pneumonia: effect=1.056 (OR=2.87), std=0.115
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Hemorrhage of gastrointestinal tract: effect=1.172 (OR=3.23), std=0.031
# Benign neoplasm of colon: effect=1.168 (OR=3.22), std=0.032
# Regional enteritis: effect=1.151 (OR=3.16), std=0.109
# Neoplasm of unspecified nature of digestive system: effect=1.110 (OR=3.03), std=0.088
# Hemorrhoids: effect=1.109 (OR=3.03), std=0.024
# Ventral hernia: effect=1.106 (OR=3.02), std=0.024
# Hemorrhage of rectum and anus: effect=1.079 (OR=2.94), std=0.027
# Noninfectious gastroenteritis: effect=1.076 (OR=2.93), std=0.064
# Other disorders of intestine: effect=1.002 (OR=2.72), std=0.050
# Colon cancer: effect=1.000 (OR=2.72), std=0.053
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Other disorders of gallbladder: effect=1.262 (OR=3.53), std=0.035
# Peritoneal adhesions (postoperative) (postinfection): effect=1.182 (OR=3.26), std=0.126
# Cholelithiasis with acute cholecystitis: effect=1.158 (OR=3.18), std=0.075
# Acute pancreatitis: effect=1.052 (OR=2.86), std=0.029
# Calculus of bile duct: effect=1.047 (OR=2.85), std=0.073
# Cholelithiasis: effect=1.022 (OR=2.78), std=0.039
# Cholelithiasis with other cholecystitis: effect=0.960 (OR=2.61), std=0.050
# Other disorders of biliary tract: effect=0.937 (OR=2.55), std=0.100
# Cholecystitis without cholelithiasis: effect=0.916 (OR=2.50), std=0.094
# Other disorders of stomach and duodenum: effect=-1.777 (OR=0.17), std=0.062
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Thyrotoxicosis with or without goiter: effect=1.208 (OR=3.35), std=0.041
# Seborrheic keratosis: effect=1.205 (OR=3.34), std=0.055
# Other disorders of eyelids: effect=1.167 (OR=3.21), std=0.036
# Chronic glomerulonephritis, NOS: effect=1.142 (OR=3.13), std=0.076
# Other non-epithelial cancer of skin: effect=1.105 (OR=3.02), std=0.028
# Chronic Kidney Disease, Stage III: effect=1.065 (OR=2.90), std=0.028
# Actinic keratosis: effect=1.062 (OR=2.89), std=0.026
# Scar conditions and fibrosis of skin: effect=1.028 (OR=2.80), std=0.101
# Breast cancer [female]: effect=1.017 (OR=2.76), std=0.023
# Hypertensive chronic kidney disease: effect=1.005 (OR=2.73), std=0.078
#
# Top 10 diseases in Signature 20 (relative to baseline):
# Endometrial hyperplasia: effect=-4.736 (OR=0.01), std=0.110
# Noninfectious gastroenteritis: effect=-4.788 (OR=0.01), std=0.028
# Myalgia and myositis unspecified: effect=-4.789 (OR=0.01), std=0.043
# Other upper respiratory disease: effect=-4.790 (OR=0.01), std=0.084
# Aortic valve disease: effect=-4.821 (OR=0.01), std=0.091
# Major depressive disorder: effect=-4.833 (OR=0.01), std=0.006
# Urethral stricture (not specified as infectious): effect=-4.833 (OR=0.01), std=0.046
# Melanomas of skin: effect=-4.844 (OR=0.01), std=0.012
# Displacement of intervertebral disc: effect=-4.856 (OR=0.01), std=0.115
# Angina pectoris: effect=-4.867 (OR=0.01), std=0.048

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Aortic valve disease: 1.179
# 2. Heart failure NOS: 1.155
# 3. Paroxysmal ventricular tachycardia: 1.114
# 4. Left bundle branch block: 1.067
# 5. Congestive heart failure (CHF) NOS: 1.035
# 6. Congenital anomalies of great vessels: 1.024
# 7. Atrial fibrillation and flutter: 1.019
# 8. Pericarditis: 1.012
# 9. Cardiomegaly: 0.991
# 10. Mitral valve disease: 0.974
#
# Final top diseases:
# 1. Paroxysmal ventricular tachycardia: 1.253
# 2. Aortic valve disease: 1.187
# 3. Heart failure NOS: 1.150
# 4. Pericarditis: 1.064
# 5. Congestive heart failure (CHF) NOS: 1.032
# 6. Left bundle branch block: 1.003
# 7. Cardiomegaly: 1.002
# 8. Mitral valve disease: 0.977
# 9. Congenital anomalies of great vessels: 0.942
# 10. Atrial fibrillation and flutter: 0.926
#
# Congenital anomalies of great vessels changed from rank 6 to 9
#
# Pericarditis changed from rank 8 to 4
#
# Atrial fibrillation and flutter changed from rank 7 to 10
#
# Signature 1:
#
# Initial top diseases:
# 1. Other disorders of synovium, tendon, and bursa: 1.287
# 2. Hallux valgus (Bunion): 1.187
# 3. Enthesopathy: 1.144
# 4. Peripheral enthesopathies and allied syndromes: 1.079
# 5. Rheumatoid arthritis: 1.075
# 6. Acquired toe deformities: 1.074
# 7. Pain in joint: 1.053
# 8. Hallux rigidus: 1.043
# 9. Other peripheral nerve disorders: 1.026
# 10. Osteoarthrosis, localized, primary: 1.000
#
# Final top diseases:
# 1. Enthesopathy: 1.228
# 2. Other disorders of synovium, tendon, and bursa: 1.170
# 3. Hallux valgus (Bunion): 1.161
# 4. Peripheral enthesopathies and allied syndromes: 1.116
# 5. Other peripheral nerve disorders: 1.110
# 6. Rheumatoid arthritis: 1.098
# 7. Hallux rigidus: 1.090
# 8. Pain in joint: 1.081
# 9. Osteoarthrosis, localized, primary: 1.056
# 10. Synovitis and tenosynovitis: 1.011
#
# Other peripheral nerve disorders changed from rank 9 to 5
#
# Acquired toe deformities changed from rank 6 to 12
#
# Signature 2:
#
# Initial top diseases:
# 1. Gastric ulcer: 1.170
# 2. Gastritis and duodenitis: 1.165
# 3. Other disorders of stomach and duodenum: 1.040
# 4. Reflux esophagitis: 1.018
# 5. Duodenitis: 1.012
# 6. Stricture and stenosis of esophagus: 1.011
# 7. Barrett's esophagus: 0.988
# 8. Other specified gastritis: 0.967
# 9. Iron deficiency anemias, unspecified or not due to blood loss: 0.963
# 10. Esophageal bleeding (varices/hemorrhage): 0.947
#
# Final top diseases:
# 1. Gastritis and duodenitis: 1.200
# 2. Gastric ulcer: 1.154
# 3. Barrett's esophagus: 1.140
# 4. Stricture and stenosis of esophagus: 1.134
# 5. Duodenitis: 1.002
# 6. Other disorders of stomach and duodenum: 0.985
# 7. Diaphragmatic hernia: 0.978
# 8. Iron deficiency anemias, unspecified or not due to blood loss: 0.976
# 9. Duodenal ulcer: 0.972
# 10. Esophageal bleeding (varices/hemorrhage): 0.965
#
# Other disorders of stomach and duodenum changed from rank 3 to 6
#
# Diaphragmatic hernia changed from rank 12 to 7
#
# Barrett's esophagus changed from rank 7 to 3
#
# Reflux esophagitis changed from rank 4 to 12
#
# Duodenal ulcer changed from rank 12 to 9
#
# Other specified gastritis changed from rank 8 to 12
#
# Signature 3:
#
# Initial top diseases:
# 1. Celiac disease: 1.212
# 2. Other tests: 1.198
# 3. Peripheral vascular disease, unspecified: 1.182
# 4. Atopic/contact dermatitis due to other or unspecified: 1.177
# 5. Blood in stool: 1.155
# 6. Redundant prepuce and phimosis/BXO: 1.142
# 7. Hypertrophy of breast (Gynecomastia): 1.134
# 8. Inflammation of eyelids: 1.122
# 9. Diseases of the larynx and vocal cords: 1.104
# 10. Hemangioma and lymphangioma, any site: 1.104
#
# Final top diseases:
# 1. Peripheral vascular disease, unspecified: 1.303
# 2. Other tests: 1.282
# 3. Celiac disease: 1.264
# 4. Right bundle branch block: 1.218
# 5. Hemangioma and lymphangioma, any site: 1.217
# 6. Atopic/contact dermatitis due to other or unspecified: 1.210
# 7. Blood in stool: 1.127
# 8. Acute upper respiratory infections of multiple or unspecified sites: 1.125
# 9. Perforation of tympanic membrane: 1.121
# 10. Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: 1.118
#
# Hypertrophy of breast (Gynecomastia) changed from rank 7 to 12
#
# Acute upper respiratory infections of multiple or unspecified sites changed from rank 12 to 8
#
# Diseases of the larynx and vocal cords changed from rank 9 to 12
#
# Inflammation of eyelids changed from rank 8 to 12
#
# Perforation of tympanic membrane changed from rank 12 to 9
#
# Hemangioma and lymphangioma, any site changed from rank 10 to 5
#
# Right bundle branch block changed from rank 12 to 4
#
# Redundant prepuce and phimosis/BXO changed from rank 6 to 12
#
# Signature 4:
#
# Initial top diseases:
# 1. Other upper respiratory disease: 1.007
# 2. Septal Deviations/Turbinate Hypertrophy: 0.919
# 3. Chronic sinusitis: 0.909
# 4. Nasal polyps: 0.868
# 5. Chronic pharyngitis and nasopharyngitis: 0.859
# 6. Pyelonephritis: -1.971
# 7. Symptoms and disorders of the joints: -1.973
# 8. Hemiplegia: -1.974
# 9. Abdominal aortic aneurysm: -1.974
# 10. Streptococcus infection: -1.976
#
# Final top diseases:
# 1. Other upper respiratory disease: 1.002
# 2. Nasal polyps: 0.880
# 3. Chronic sinusitis: 0.876
# 4. Septal Deviations/Turbinate Hypertrophy: 0.875
# 5. Chronic pharyngitis and nasopharyngitis: 0.861
# 6. Hemangioma and lymphangioma, any site: -1.736
# 7. Other acquired deformities of limbs: -1.774
# 8. Enthesopathy: -1.787
# 9. Retinal detachment with retinal defect: -1.801
# 10. Other disorders of biliary tract: -1.821
#
# Other acquired deformities of limbs changed from rank 12 to 7
#
# Symptoms and disorders of the joints changed from rank 7 to 12
#
# Abdominal aortic aneurysm changed from rank 9 to 12
#
# Hemiplegia changed from rank 8 to 12
#
# Retinal detachment with retinal defect changed from rank 12 to 9
#
# Hemangioma and lymphangioma, any site changed from rank 12 to 6
#
# Pyelonephritis changed from rank 6 to 12
#
# Enthesopathy changed from rank 12 to 8
#
# Signature 5:
#
# Initial top diseases:
# 1. Coronary atherosclerosis: 1.187
# 2. Other acute and subacute forms of ischemic heart disease: 1.116
# 3. Hypercholesterolemia: 1.079
# 4. Other chronic ischemic heart disease, unspecified: 0.899
# 5. Myocardial infarction: 0.860
# 6. Angina pectoris: 0.849
# 7. Unstable angina (intermediate coronary syndrome): 0.816
# 8. Lipoma: -1.965
# 9. Neuralgia, neuritis, and radiculitis NOS: -1.972
# 10. Cholelithiasis with acute cholecystitis: -1.972
#
# Final top diseases:
# 1. Coronary atherosclerosis: 1.236
# 2. Other acute and subacute forms of ischemic heart disease: 1.131
# 3. Hypercholesterolemia: 1.096
# 4. Angina pectoris: 0.854
# 5. Unstable angina (intermediate coronary syndrome): 0.812
# 6. Myocardial infarction: 0.776
# 7. Other chronic ischemic heart disease, unspecified: 0.731
# 8. Paroxysmal supraventricular tachycardia: -1.753
# 9. Allergic rhinitis: -1.768
# 10. Other specified gastritis: -1.806
#
# Neuralgia, neuritis, and radiculitis NOS changed from rank 9 to 12
#
# Allergic rhinitis changed from rank 12 to 9
#
# Lipoma changed from rank 8 to 12
#
# Other chronic ischemic heart disease, unspecified changed from rank 4 to 7
#
# Paroxysmal supraventricular tachycardia changed from rank 12 to 8
#
# Signature 6:
#
# Initial top diseases:
# 1. Secondary malignant neoplasm of digestive systems: 1.072
# 2. Secondary malignancy of lymph nodes: 1.064
# 3. Secondary malignancy of bone: 1.038
# 4. Secondary malignant neoplasm of liver: 1.012
# 5. Malignant neoplasm, other: 0.996
# 6. Secondary malignant neoplasm: 0.990
# 7. Cancer of bronchus; lung: 0.974
# 8. Secondary malignancy of respiratory organs: 0.800
# 9. Urinary incontinence: -1.966
# 10. Emphysema: -1.968
#
# Final top diseases:
# 1. Secondary malignant neoplasm of liver: 1.066
# 2. Secondary malignancy of lymph nodes: 1.056
# 3. Secondary malignant neoplasm: 1.033
# 4. Cancer of bronchus; lung: 1.021
# 5. Secondary malignant neoplasm of digestive systems: 1.017
# 6. Secondary malignancy of bone: 0.943
# 7. Malignant neoplasm, other: 0.935
# 8. Secondary malignancy of respiratory organs: 0.703
# 9. Other disorders of the kidney and ureters: -1.757
# 10. Anal and rectal polyp: -1.770
#
# Cancer of bronchus; lung changed from rank 7 to 4
#
# Secondary malignant neoplasm changed from rank 6 to 3
#
# Secondary malignant neoplasm of digestive systems changed from rank 1 to 5
#
# Secondary malignant neoplasm of liver changed from rank 4 to 1
#
# Secondary malignancy of bone changed from rank 3 to 6
#
# Other disorders of the kidney and ureters changed from rank 12 to 9
#
# Urinary incontinence changed from rank 9 to 12
#
# Signature 7:
#
# Initial top diseases:
# 1. Asthma: 1.322
# 2. Migraine: 1.261
# 3. Myalgia and myositis unspecified: 1.178
# 4. Osteoporosis NOS: 1.148
# 5. Major depressive disorder: 1.128
# 6. Abdominal pain: 1.117
# 7. Spondylosis and allied disorders: 1.108
# 8. Essential hypertension: 1.103
# 9. Hyperlipidemia: 1.089
# 10. Obesity: 1.085
#
# Final top diseases:
# 1. Asthma: 1.385
# 2. Migraine: 1.359
# 3. Osteoporosis NOS: 1.219
# 4. Myalgia and myositis unspecified: 1.162
# 5. Major depressive disorder: 1.142
# 6. Obesity: 1.135
# 7. Abdominal pain: 1.121
# 8. Cervicalgia: 1.095
# 9. Other disorders of bone and cartilage: 1.073
# 10. Hyperlipidemia: 1.055
#
# Cervicalgia changed from rank 12 to 8
#
# Essential hypertension changed from rank 8 to 12
#
# Spondylosis and allied disorders changed from rank 7 to 12
#
# Other disorders of bone and cartilage changed from rank 12 to 9
#
# Obesity changed from rank 10 to 6
#
# Signature 8:
#
# Initial top diseases:
# 1. Ovarian cyst: 1.204
# 2. Malignant neoplasm of uterus: 1.149
# 3. Polyp of corpus uteri: 1.111
# 4. Noninflammatory disorders of cervix: 1.094
# 5. Excessive or frequent menstruation: 1.088
# 6. Cervicitis and endocervicitis: 1.084
# 7. Hypertrophy of female genital organs: 1.079
# 8. Noninflammatory disorders of vagina: 1.058
# 9. Uterine/Uterovaginal prolapse: 1.052
# 10. Endometrial hyperplasia: 1.018
#
# Final top diseases:
# 1. Cervicitis and endocervicitis: 1.356
# 2. Ovarian cyst: 1.260
# 3. Polyp of corpus uteri: 1.198
# 4. Noninflammatory disorders of cervix: 1.142
# 5. Malignant neoplasm of uterus: 1.141
# 6. Excessive or frequent menstruation: 1.140
# 7. Endometrial hyperplasia: 1.116
# 8. Noninflammatory disorders of vagina: 1.099
# 9. Hypertrophy of female genital organs: 1.091
# 10. Pain and other symptoms associated with female genital organs: 1.068
#
# Cervicitis and endocervicitis changed from rank 6 to 1
#
# Uterine/Uterovaginal prolapse changed from rank 9 to 12
#
# Endometrial hyperplasia changed from rank 10 to 7
#
# Malignant neoplasm of uterus changed from rank 2 to 5
#
# Signature 9:
#
# Initial top diseases:
# 1. Back pain: 1.250
# 2. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.080
# 3. Neuralgia, neuritis, and radiculitis NOS: 1.063
# 4. Spondylosis without myelopathy: 1.007
# 5. Degenerative disease of the spinal cord: 1.001
# 6. Displacement of intervertebral disc: 0.988
# 7. Acquired spondylolisthesis: 0.959
# 8. Kyphoscoliosis and scoliosis: 0.948
# 9. Other and unspecified disc disorder: 0.941
# 10. Sciatica: 0.913
#
# Final top diseases:
# 1. Back pain: 1.313
# 2. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.115
# 3. Displacement of intervertebral disc: 1.111
# 4. Neuralgia, neuritis, and radiculitis NOS: 1.052
# 5. Other and unspecified disc disorder: 0.989
# 6. Degenerative disease of the spinal cord: 0.978
# 7. Spondylosis without myelopathy: 0.971
# 8. Kyphoscoliosis and scoliosis: 0.900
# 9. Acquired spondylolisthesis: 0.890
# 10. Spinal stenosis: 0.872
#
# Spondylosis without myelopathy changed from rank 4 to 7
#
# Displacement of intervertebral disc changed from rank 6 to 3
#
# Other and unspecified disc disorder changed from rank 9 to 5
#
# Signature 10:
#
# Initial top diseases:
# 1. Macular degeneration (senile) of retina NOS: 1.177
# 2. Retinal vascular changes and abnomalities: 1.160
# 3. Other retinal disorders: 1.114
# 4. Primary open angle glaucoma: 1.089
# 5. Glaucoma: 1.022
# 6. Myopia: 1.009
# 7. Disorders of vitreous body: 0.991
# 8. Cataract: 0.964
# 9. Senile cataract: 0.962
# 10. Retinal detachments and defects: 0.833
#
# Final top diseases:
# 1. Primary open angle glaucoma: 1.264
# 2. Macular degeneration (senile) of retina NOS: 1.210
# 3. Retinal vascular changes and abnomalities: 1.193
# 4. Other retinal disorders: 1.160
# 5. Myopia: 1.145
# 6. Glaucoma: 1.027
# 7. Disorders of vitreous body: 1.009
# 8. Senile cataract: 0.997
# 9. Retinal detachment with retinal defect: 0.876
# 10. Cataract: 0.869
#
# Retinal detachment with retinal defect changed from rank 12 to 9
#
# Primary open angle glaucoma changed from rank 4 to 1
#
# Signature 11:
#
# Initial top diseases:
# 1. Hemiplegia: 1.102
# 2. Cerebral ischemia: 1.060
# 3. Occlusion of cerebral arteries: 1.039
# 4. Late effects of cerebrovascular disease: 1.025
# 5. Cerebrovascular disease: 0.959
# 6. Transient cerebral ischemia: 0.938
# 7. Cerebral artery occlusion, with cerebral infarction: 0.936
# 8. Occlusion and stenosis of precerebral arteries: 0.791
# 9. Other derangement of joint: -1.968
# 10. Benign neoplasm of ovary: -1.969
#
# Final top diseases:
# 1. Occlusion of cerebral arteries: 1.148
# 2. Cerebral ischemia: 1.109
# 3. Late effects of cerebrovascular disease: 1.093
# 4. Cerebral artery occlusion, with cerebral infarction: 1.051
# 5. Hemiplegia: 1.017
# 6. Transient cerebral ischemia: 0.925
# 7. Cerebrovascular disease: 0.922
# 8. Occlusion and stenosis of precerebral arteries: 0.872
# 9. Retinal detachment with retinal defect: -1.769
# 10. Scar conditions and fibrosis of skin: -1.771
#
# Cerebral artery occlusion, with cerebral infarction changed from rank 7 to 4
#
# Other derangement of joint changed from rank 9 to 12
#
# Hemiplegia changed from rank 1 to 5
#
# Retinal detachment with retinal defect changed from rank 12 to 9
#
# Signature 12:
#
# Initial top diseases:
# 1. Renal colic: 1.226
# 2. Calculus of ureter: 1.085
# 3. Stricture/obstruction of ureter: 1.056
# 4. Hydronephrosis: 1.018
# 5. Other disorders of the kidney and ureters: 1.014
# 6. Pyelonephritis: 0.898
# 7. Calculus of kidney: 0.862
# 8. Streptococcus infection: -1.947
# 9. Other disorders of bladder: -1.964
# 10. Emphysema: -1.969
#
# Final top diseases:
# 1. Renal colic: 1.260
# 2. Hydronephrosis: 1.068
# 3. Other disorders of the kidney and ureters: 1.040
# 4. Calculus of ureter: 1.011
# 5. Stricture/obstruction of ureter: 0.995
# 6. Calculus of kidney: 0.936
# 7. Pyelonephritis: 0.858
# 8. Streptococcus infection: -1.788
# 9. Occlusion of cerebral arteries: -1.828
# 10. Unstable angina (intermediate coronary syndrome): -1.841
#
# Occlusion of cerebral arteries changed from rank 12 to 9
#
# Other disorders of bladder changed from rank 9 to 12
#
# Signature 13:
#
# Initial top diseases:
# 1. Cystitis: 1.169
# 2. Urethral stricture (not specified as infectious): 1.152
# 3. Cancer of prostate: 1.087
# 4. Other disorders of bladder: 1.013
# 5. Malignant neoplasm of bladder: 1.010
# 6. Other symptoms/disorders or the urinary system: 0.997
# 7. Urinary incontinence: 0.985
# 8. Functional disorders of bladder: 0.975
# 9. Hyperplasia of prostate: 0.953
# 10. Chronic prostatitis: 0.934
#
# Final top diseases:
# 1. Urethral stricture (not specified as infectious): 1.261
# 2. Cystitis: 1.211
# 3. Cancer of prostate: 1.154
# 4. Other symptoms/disorders or the urinary system: 1.060
# 5. Malignant neoplasm of bladder: 1.059
# 6. Other disorders of bladder: 1.011
# 7. Chronic cystitis: 0.981
# 8. Urinary incontinence: 0.977
# 9. Hyperplasia of prostate: 0.914
# 10. Bladder neck obstruction: 0.910
#
# Chronic cystitis changed from rank 12 to 7
#
# Functional disorders of bladder changed from rank 8 to 12
#
# Signature 14:
#
# Initial top diseases:
# 1. Emphysema: 1.136
# 2. Bronchiectasis: 1.047
# 3. Empyema and pneumothorax: 1.038
# 4. Pneumonia: 1.037
# 5. Tobacco use disorder: 0.912
# 6. Pneumococcal pneumonia: 0.911
# 7. Postinflammatory pulmonary fibrosis: 0.866
# 8. Chronic airway obstruction: 0.862
# 9. Obstructive chronic bronchitis: 0.821
# 10. Respiratory failure: 0.807
#
# Final top diseases:
# 1. Empyema and pneumothorax: 1.105
# 2. Pneumonia: 1.046
# 3. Emphysema: 1.028
# 4. Obstructive chronic bronchitis: 0.909
# 5. Bronchiectasis: 0.905
# 6. Pneumococcal pneumonia: 0.861
# 7. Chronic airway obstruction: 0.793
# 8. Postinflammatory pulmonary fibrosis: 0.786
# 9. Respiratory failure: 0.763
# 10. Tobacco use disorder: 0.735
#
# Tobacco use disorder changed from rank 5 to 10
#
# Obstructive chronic bronchitis changed from rank 9 to 4
#
# Bronchiectasis changed from rank 2 to 5
#
# Signature 15:
#
# Initial top diseases:
# 1. Hypoglycemia: 1.171
# 2. Type 1 diabetes: 1.110
# 3. Type 2 diabetes with ophthalmic manifestations: 1.055
# 4. Type 2 diabetes: 0.932
# 5. Diabetic retinopathy: 0.917
# 6. Disorders of calcium/phosphorus metabolism: -1.967
# 7. Varicose veins of lower extremity: -1.967
# 8. Neoplasm of uncertain behavior: -1.972
# 9. Peritonitis and retroperitoneal infections: -1.973
# 10. First degree AV block: -1.973
#
# Final top diseases:
# 1. Hypoglycemia: 1.237
# 2. Type 2 diabetes with ophthalmic manifestations: 1.106
# 3. Type 1 diabetes: 0.989
# 4. Diabetic retinopathy: 0.981
# 5. Type 2 diabetes: 0.853
# 6. Lipoma of skin and subcutaneous tissue: -1.763
# 7. Pleurisy; pleural effusion: -1.772
# 8. Disorders of uterus, NEC: -1.807
# 9. Spinal stenosis: -1.815
# 10. Calculus of bile duct: -1.823
#
# Disorders of uterus, NEC changed from rank 12 to 8
#
# Varicose veins of lower extremity changed from rank 7 to 12
#
# Peritonitis and retroperitoneal infections changed from rank 9 to 12
#
# Neoplasm of uncertain behavior changed from rank 8 to 12
#
# Lipoma of skin and subcutaneous tissue changed from rank 12 to 6
#
# Pleurisy; pleural effusion changed from rank 12 to 7
#
# Spinal stenosis changed from rank 12 to 9
#
# Disorders of calcium/phosphorus metabolism changed from rank 6 to 12
#
# Signature 16:
#
# Initial top diseases:
# 1. Other diseases of respiratory system, NEC: 1.115
# 2. Peritonitis and retroperitoneal infections: 1.113
# 3. Hypopotassemia: 1.082
# 4. Chronic ulcer of skin: 1.057
# 5. Acute renal failure: 1.051
# 6. Hyperpotassemia: 1.033
# 7. Bacterial pneumonia: 1.023
# 8. Gram negative septicemia: 1.022
# 9. Hypotension NOS: 1.007
# 10. Disorders of calcium/phosphorus metabolism: 1.004
#
# Final top diseases:
# 1. Peritonitis and retroperitoneal infections: 1.110
# 2. E. coli: 1.102
# 3. Other diseases of respiratory system, NEC: 1.099
# 4. Hypotension NOS: 1.086
# 5. Hyperpotassemia: 1.084
# 6. Cellulitis and abscess of arm/hand: 1.073
# 7. Chronic ulcer of skin: 1.070
# 8. Gram negative septicemia: 1.065
# 9. Acute renal failure: 1.062
# 10. Bacterial pneumonia: 1.056
#
# E. coli changed from rank 12 to 2
#
# Hypotension NOS changed from rank 9 to 4
#
# Cellulitis and abscess of arm/hand changed from rank 12 to 6
#
# Bacterial pneumonia changed from rank 7 to 10
#
# Acute renal failure changed from rank 5 to 9
#
# Chronic ulcer of skin changed from rank 4 to 7
#
# Hypopotassemia changed from rank 3 to 12
#
# Signature 17:
#
# Initial top diseases:
# 1. Regional enteritis: 1.195
# 2. Ventral hernia: 1.166
# 3. Hemorrhoids: 1.123
# 4. Hemorrhage of gastrointestinal tract: 1.122
# 5. Hemorrhage of rectum and anus: 1.095
# 6. Benign neoplasm of colon: 1.085
# 7. Neoplasm of unspecified nature of digestive system: 1.046
# 8. Diverticulosis: 1.041
# 9. Noninfectious gastroenteritis: 1.038
# 10. Other intestinal obstruction: 0.993
#
# Final top diseases:
# 1. Hemorrhage of gastrointestinal tract: 1.172
# 2. Benign neoplasm of colon: 1.168
# 3. Regional enteritis: 1.151
# 4. Neoplasm of unspecified nature of digestive system: 1.110
# 5. Hemorrhoids: 1.109
# 6. Ventral hernia: 1.106
# 7. Hemorrhage of rectum and anus: 1.079
# 8. Noninfectious gastroenteritis: 1.076
# 9. Other disorders of intestine: 1.002
# 10. Colon cancer: 1.000
#
# Ventral hernia changed from rank 2 to 6
#
# Diverticulosis changed from rank 8 to 12
#
# Neoplasm of unspecified nature of digestive system changed from rank 7 to 4
#
# Other disorders of intestine changed from rank 12 to 9
#
# Hemorrhage of gastrointestinal tract changed from rank 4 to 1
#
# Benign neoplasm of colon changed from rank 6 to 2
#
# Signature 18:
#
# Initial top diseases:
# 1. Other disorders of gallbladder: 1.189
# 2. Cholelithiasis with acute cholecystitis: 1.062
# 3. Peritoneal adhesions (postoperative) (postinfection): 1.054
# 4. Acute pancreatitis: 1.054
# 5. Calculus of bile duct: 1.019
# 6. Other disorders of biliary tract: 0.992
# 7. Cholelithiasis: 0.992
# 8. Cholelithiasis with other cholecystitis: 0.922
# 9. Cholecystitis without cholelithiasis: 0.869
# 10. Anal and rectal polyp: -1.968
#
# Final top diseases:
# 1. Other disorders of gallbladder: 1.262
# 2. Peritoneal adhesions (postoperative) (postinfection): 1.182
# 3. Cholelithiasis with acute cholecystitis: 1.158
# 4. Acute pancreatitis: 1.052
# 5. Calculus of bile duct: 1.047
# 6. Cholelithiasis: 1.022
# 7. Cholelithiasis with other cholecystitis: 0.960
# 8. Other disorders of biliary tract: 0.937
# 9. Cholecystitis without cholelithiasis: 0.916
# 10. Other disorders of stomach and duodenum: -1.777
#
# Signature 19:
#
# Initial top diseases:
# 1. Other disorders of eyelids: 1.167
# 2. Chronic glomerulonephritis, NOS: 1.167
# 3. Seborrheic keratosis: 1.149
# 4. Thyrotoxicosis with or without goiter: 1.139
# 5. Disorders of lacrimal system: 1.118
# 6. Other non-epithelial cancer of skin: 1.103
# 7. Ectropion or entropion: 1.080
# 8. Hypertensive chronic kidney disease: 1.072
# 9. Viral warts & HPV: 1.046
# 10. Breast cancer [female]: 1.042
#
# Final top diseases:
# 1. Thyrotoxicosis with or without goiter: 1.208
# 2. Seborrheic keratosis: 1.205
# 3. Other disorders of eyelids: 1.167
# 4. Chronic glomerulonephritis, NOS: 1.142
# 5. Other non-epithelial cancer of skin: 1.105
# 6. Chronic Kidney Disease, Stage III: 1.065
# 7. Actinic keratosis: 1.062
# 8. Scar conditions and fibrosis of skin: 1.028
# 9. Breast cancer [female]: 1.017
# 10. Hypertensive chronic kidney disease: 1.005
#
# Viral warts & HPV changed from rank 9 to 12
#
# Ectropion or entropion changed from rank 7 to 12
#
# Disorders of lacrimal system changed from rank 5 to 12
#
# Scar conditions and fibrosis of skin changed from rank 12 to 8
#
# Actinic keratosis changed from rank 12 to 7
#
# Chronic Kidney Disease, Stage III changed from rank 12 to 6
#
# Thyrotoxicosis with or without goiter changed from rank 4 to 1
#
# Signature 20:
#
# Initial top diseases:
# 1. Alcoholic liver damage: -4.966
# 2. Hypothyroidism NOS: -4.969
# 3. Acquired spondylolisthesis: -4.972
# 4. First degree AV block: -4.972
# 5. Hypertrophy of female genital organs: -4.973
# 6. Malignant neoplasm of bladder: -4.973
# 7. Hypovolemia: -4.974
# 8. Other anemias: -4.974
# 9. Secondary malignant neoplasm of liver: -4.976
# 10. Cervicalgia: -4.976
#
# Final top diseases:
# 1. Endometrial hyperplasia: -4.736
# 2. Noninfectious gastroenteritis: -4.788
# 3. Myalgia and myositis unspecified: -4.789
# 4. Other upper respiratory disease: -4.790
# 5. Aortic valve disease: -4.821
# 6. Major depressive disorder: -4.833
# 7. Urethral stricture (not specified as infectious): -4.833
# 8. Melanomas of skin: -4.844
# 9. Displacement of intervertebral disc: -4.856
# 10. Angina pectoris: -4.867
#
# Major depressive disorder changed from rank 12 to 6
#
# Acquired spondylolisthesis changed from rank 3 to 12
#
# Alcoholic liver damage changed from rank 1 to 12
#
# Noninfectious gastroenteritis changed from rank 12 to 2
#
# Endometrial hyperplasia changed from rank 12 to 1
#
# Melanomas of skin changed from rank 12 to 8
#
# Hypertrophy of female genital organs changed from rank 5 to 12
#
# Myalgia and myositis unspecified changed from rank 12 to 3
#
# Malignant neoplasm of bladder changed from rank 6 to 12
#
# Secondary malignant neoplasm of liver changed from rank 9 to 12
#
# Other upper respiratory disease changed from rank 12 to 4
#
# Aortic valve disease changed from rank 12 to 5
#
# Hypothyroidism NOS changed from rank 2 to 12
#
# Displacement of intervertebral disc changed from rank 12 to 9
#
# Urethral stricture (not specified as infectious) changed from rank 12 to 7
#
# First degree AV block changed from rank 4 to 12
#
# Hypovolemia changed from rank 7 to 12
#
# Other anemias changed from rank 8 to 12

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Final Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Final Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects for these patients
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]  # Already computed above
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
# Out:
# Genetic Effect Statistics for Sample Patients:
#
# Patient 4376:
# Mean shift: 0.060
# Std of shifts: 0.290
# Range of shifts: [-0.768, 0.540]
#
# Top states and average proportions:
# State 7: 0.190
# State 3: 0.137
# State 2: 0.087
# State 8: 0.084
# State 16: 0.084
#
# Patient 6640:
# Mean shift: 0.001
# Std of shifts: 0.386
# Range of shifts: [-0.310, 1.614]
#
# Top states and average proportions:
# State 5: 0.194
# State 3: 0.143
# State 7: 0.111
# State 8: 0.089
# State 17: 0.071
