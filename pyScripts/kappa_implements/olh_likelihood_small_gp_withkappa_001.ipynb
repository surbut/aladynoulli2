# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess
from clust_huge_amp import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## here we're running with the likelihood only

# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/1184199116.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/1184199116.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/1184199116.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/1184199116.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, start_index=0, end_index=10000)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data

del Y

# %%
# When initializing the model:
original_G = G_100k # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/1949801412.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/1949801412.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
# Load references (signatures only, no healthy)
refs = torch.load('reference_trajectories.pt')
signature_refs = refs['signature_refs']
# When initializing the model:

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/2429096507.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('reference_trajectories.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/2429096507.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/2429096507.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
torch.manual_seed(7)
np.random.seed(4)
# Create model without healthy reference
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_100k.shape[1],
    init_sd_scaler=1e-1,
    G=G_100k, 
    Y=Y_100k,
    genetic_scale=1,
    W=0.001,
    R=0,
    prevalence_t=essentials['prevalence_t'],
    signature_references=signature_refs,  # Only pass signature refs
    healthy_reference=True,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

torch.manual_seed(0)
np.random.seed(0)
# Initialize with psi and clusters
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:73: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:80: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:85: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-18.4207, -18.4207, -17.3858, -16.3508, -16.3508])
# Base value centered (first 5): tensor([-0.5458, -0.5458,  0.4891,  1.5240,  1.5240])
# Base value centered mean: 3.23352810482902e-06
# Gamma init for k=0 (first 5): tensor([ 0.0013,  0.0101,  0.0173,  0.0224, -0.0156])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-1.0324, -1.0324, -1.0324, -1.0324, -1.0324])
# Base value centered mean: 2.2811889266449725e-06
# Gamma init for k=1 (first 5): tensor([ 0.0345,  0.0130,  0.0066, -0.0008, -0.0064])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -14.2810, -17.7307])
# Base value centered (first 5): tensor([-0.3508, -0.3508, -0.3508,  3.7888,  0.3391])
# Base value centered mean: 1.4835358115306008e-06
# Gamma init for k=2 (first 5): tensor([ 0.0028, -0.0037,  0.0097,  0.0037, -0.0078])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1693, -0.1693, -0.1693, -0.1693, -0.1693])
# Base value centered mean: 1.5007019555923762e-06
# Gamma init for k=3 (first 5): tensor([ 0.0032, -0.0061,  0.0035,  0.0032, -0.0085])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-17.5684, -18.4207, -17.5684, -17.5684, -15.0115])
# Base value centered (first 5): tensor([-0.0647, -0.9170, -0.0647, -0.0647,  2.4922])
# Base value centered mean: 1.28402712107345e-06
# Gamma init for k=4 (first 5): tensor([-0.0093, -0.0012, -0.0200,  0.0534, -0.0145])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -16.6096, -18.4207])
# Base value centered (first 5): tensor([-0.2438, -0.2438, -0.2438,  1.5673, -0.2438])
# Base value centered mean: 6.72149667479971e-07
# Gamma init for k=5 (first 5): tensor([ 0.0075,  0.0081, -0.0056,  0.0087,  0.0362])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -17.9123])
# Base value centered (first 5): tensor([-0.1640, -0.1640, -0.1640, -0.1640,  0.3444])
# Base value centered mean: 2.344417680433253e-06
# Gamma init for k=6 (first 5): tensor([ 0.0022,  0.0029,  0.0013, -0.0014, -0.0026])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -13.5911, -16.0059])
# Base value centered (first 5): tensor([-0.5885, -0.5885, -0.5885,  4.2411,  1.8263])
# Base value centered mean: -2.6187896651208575e-07
# Gamma init for k=7 (first 5): tensor([ 0.0109,  0.0068, -0.0077,  0.0083, -0.0058])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.0771, -17.3062])
# Base value centered (first 5): tensor([-0.3585, -0.3585, -0.3585,  2.9850,  0.7560])
# Base value centered mean: 6.065369007046684e-08
# Gamma init for k=8 (first 5): tensor([ 0.0023,  0.0006,  0.0013,  0.0198, -0.0015])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.7863, -14.4692])
# Base value centered (first 5): tensor([-0.3788, -0.3788, -0.3788,  2.2555,  3.5727])
# Base value centered mean: 1.1942863693548134e-06
# Gamma init for k=9 (first 5): tensor([ 0.0010,  0.0116,  0.0245, -0.0040,  0.0010])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1966, -0.1966, -0.1966, -0.1966, -0.1966])
# Base value centered mean: 2.228641506007989e-06
# Gamma init for k=10 (first 5): tensor([ 0.0168, -0.0052,  0.0006, -0.0071,  0.0027])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -17.2133])
# Base value centered (first 5): tensor([-0.2801, -0.2801, -0.2801, -0.2801,  0.9273])
# Base value centered mean: 9.216308853865485e-07
# Gamma init for k=11 (first 5): tensor([ 0.0089,  0.0071, -0.0111,  0.0046,  0.0008])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-17.8634, -18.4207, -17.8634, -17.8634, -16.1916])
# Base value centered (first 5): tensor([ 0.0841, -0.4732,  0.0841,  0.0841,  1.7559])
# Base value centered mean: -1.2168884211405384e-07
# Gamma init for k=12 (first 5): tensor([ 0.0103,  0.0020, -0.0029,  0.0020,  0.0037])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2215, -0.2215, -0.2215, -0.2215, -0.2215])
# Base value centered mean: 2.721500322877546e-06
# Gamma init for k=13 (first 5): tensor([ 0.0113,  0.0160,  0.0001,  0.0116, -0.0023])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2371, -0.2371, -0.2371, -0.2371, -0.2371])
# Base value centered mean: 1.2853622592956526e-06
# Gamma init for k=14 (first 5): tensor([-0.0180, -0.0045, -0.0054,  0.0192,  0.0079])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1735, -0.1735, -0.1735, -0.1735, -0.1735])
# Base value centered mean: 2.1408081920526456e-06
# Gamma init for k=15 (first 5): tensor([0.0041, 0.0030, 0.0047, 0.0018, 0.0145])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -16.3508])
# Base value centered (first 5): tensor([-0.3380, -0.3380, -0.3380, -0.3380,  1.7318])
# Base value centered mean: 3.2056807413027855e-06
# Gamma init for k=16 (first 5): tensor([ 0.0037,  0.0152,  0.0178, -0.0035,  0.0137])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3967, -0.3967, -0.3967, -0.3967, -0.3967])
# Base value centered mean: 8.644104241284367e-07
# Gamma init for k=17 (first 5): tensor([-0.0100,  0.0260,  0.0006, -0.0078, -0.0133])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-18.4207, -13.5911, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1475,  4.6821, -0.1475, -0.1475, -0.1475])
# Base value centered mean: 1.9518852241162676e-06
# Gamma init for k=18 (first 5): tensor([-0.0230, -0.0028,  0.0169,  0.0265, -0.0048])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -17.6304, -17.8938])
# Base value centered (first 5): tensor([-0.1783, -0.1783, -0.1783,  0.6120,  0.3485])
# Base value centered mean: 5.923271260144247e-07
# Gamma init for k=19 (first 5): tensor([ 0.0012, -0.0020,  0.0016,  0.0057,  0.0022])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.7040, -18.4207])
# Base value centered (first 5): tensor([-0.2754, -0.2754, -0.2754,  2.4413, -0.2754])
# Base value centered mean: 1.6399383184761973e-06
# Gamma init for k=0 (first 5): tensor([ 0.0106,  0.0089, -0.0075,  0.0094,  0.0357])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-17.7307, -18.4207, -17.7307, -17.7307, -16.3508])
# Base value centered (first 5): tensor([ 0.2206, -0.4693,  0.2206,  0.2206,  1.6005])
# Base value centered mean: 1.5804290569576551e-06
# Gamma init for k=1 (first 5): tensor([0.0061, 0.0023, 0.0006, 0.0035, 0.0020])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-18.4207, -18.4207, -17.4548, -15.5229, -16.4888])
# Base value centered (first 5): tensor([-0.5643, -0.5643,  0.4016,  2.3335,  1.3676])
# Base value centered mean: -3.667831549591938e-07
# Gamma init for k=2 (first 5): tensor([-5.4079e-05,  1.3310e-02,  1.6687e-02,  2.3508e-02, -1.6003e-02])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.2440, -18.0673])
# Base value centered (first 5): tensor([-0.1504, -0.1504, -0.1504,  0.0263,  0.2029])
# Base value centered mean: 1.4457702945946949e-06
# Gamma init for k=3 (first 5): tensor([ 0.0018,  0.0001,  0.0028,  0.0029, -0.0009])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-18.4207, -12.6251, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1660,  5.6295, -0.1660, -0.1660, -0.1660])
# Base value centered mean: 1.8896103028964717e-06
# Gamma init for k=4 (first 5): tensor([-0.0245, -0.0037,  0.0208,  0.0313, -0.0047])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-1.0324, -1.0324, -1.0324, -1.0324, -1.0324])
# Base value centered mean: 2.2811889266449725e-06
# Gamma init for k=5 (first 5): tensor([ 0.0345,  0.0130,  0.0066, -0.0008, -0.0064])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2233, -0.2233, -0.2233, -0.2233, -0.2233])
# Base value centered mean: 1.0049819820778794e-06
# Gamma init for k=6 (first 5): tensor([ 0.0111,  0.0190,  0.0006,  0.0081, -0.0036])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-17.7621, -18.4207, -17.7621, -18.4207, -14.4692])
# Base value centered (first 5): tensor([-0.1473, -0.8058, -0.1473, -0.8058,  3.1457])
# Base value centered mean: -1.2216568165968056e-06
# Gamma init for k=7 (first 5): tensor([ 0.0037, -0.0051, -0.0183,  0.0363, -0.0030])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1699, -0.1699, -0.1699, -0.1699, -0.1699])
# Base value centered mean: 4.0597916495244135e-07
# Gamma init for k=8 (first 5): tensor([ 0.0087, -0.0066,  0.0002, -0.0031, -0.0007])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -17.2133])
# Base value centered (first 5): tensor([-0.2801, -0.2801, -0.2801, -0.2801,  0.9273])
# Base value centered mean: 9.216308853865485e-07
# Gamma init for k=9 (first 5): tensor([ 0.0089,  0.0071, -0.0111,  0.0046,  0.0008])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3967, -0.3967, -0.3967, -0.3967, -0.3967])
# Base value centered mean: 8.644104241284367e-07
# Gamma init for k=10 (first 5): tensor([-0.0100,  0.0260,  0.0006, -0.0078, -0.0133])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1735, -0.1735, -0.1735, -0.1735, -0.1735])
# Base value centered mean: 2.1408081920526456e-06
# Gamma init for k=11 (first 5): tensor([0.0041, 0.0030, 0.0047, 0.0018, 0.0145])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1261, -0.1261, -0.1261, -0.1261, -0.1261])
# Base value centered mean: 2.155113179469481e-06
# Gamma init for k=12 (first 5): tensor([ 0.0122, -0.0107,  0.0002, -0.0003, -0.0111])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -13.9626, -16.1916])
# Base value centered (first 5): tensor([-0.2605, -0.2605, -0.2605,  4.1976,  1.9686])
# Base value centered mean: 3.2057762382464716e-06
# Gamma init for k=13 (first 5): tensor([ 0.0014,  0.0079,  0.0190, -0.0075,  0.0012])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.5229, -16.9718])
# Base value centered (first 5): tensor([-0.3756, -0.3756, -0.3756,  2.5222,  1.0733])
# Base value centered mean: -9.460449490461542e-08
# Gamma init for k=14 (first 5): tensor([ 0.0035, -0.0061, -0.0123,  0.0264,  0.0016])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -15.5229])
# Base value centered (first 5): tensor([-0.4179, -0.4179, -0.4179, -0.4179,  2.4799])
# Base value centered mean: 2.443695166221005e-06
# Gamma init for k=15 (first 5): tensor([ 0.0024,  0.0052,  0.0119, -0.0117,  0.0115])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.4230, -17.4215])
# Base value centered (first 5): tensor([-0.3560, -0.3560, -0.3560,  2.6417,  0.6433])
# Base value centered mean: 3.547668484316091e-06
# Gamma init for k=16 (first 5): tensor([ 0.0022,  0.0002,  0.0128,  0.0089, -0.0049])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -13.3070, -15.8638])
# Base value centered (first 5): tensor([-0.6198, -0.6198, -0.6198,  4.4939,  1.9371])
# Base value centered mean: -1.0757446489151334e-06
# Gamma init for k=17 (first 5): tensor([ 0.0116,  0.0080, -0.0084,  0.0089, -0.0057])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2371, -0.2371, -0.2371, -0.2371, -0.2371])
# Base value centered mean: 1.2853622592956526e-06
# Gamma init for k=18 (first 5): tensor([-0.0180, -0.0045, -0.0054,  0.0192,  0.0079])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -17.7907])
# Base value centered (first 5): tensor([-0.2226, -0.2226, -0.2226, -0.2226,  0.4073])
# Base value centered mean: 4.969596716364322e-07
# Gamma init for k=19 (first 5): tensor([-0.0042,  0.0079,  0.0019, -0.0018, -0.0025])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Clusters match exactly: True

# %%
print(model.K_total)
print(model.K)
print(model.lrtpen)
print(model.gpweight)
print(model.lambda_amplitude)
# Out:
# 21
# 20
# 0
# 0.001
# 1

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    # Get diagnosis times for this patient
    diagnoses = model.Y[patient]  # Shape: [D, T]
    diagnosis_times = []
    for d in range(model.D):
        diag_time = torch.where(diagnoses[d])[0]
        if len(diag_time) > 0:
            diagnosis_times.append(diag_time[0].item())
            
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')
    
    # Add vertical lines for diagnoses
    for t in diagnosis_times:
        ax1.axvline(x=t, color='red', alpha=0.2, linestyle=':')
        ax2.axvline(x=t, color='red', alpha=0.2, linestyle=':')

# Customize plots
ax1.set_title('Initial Lambda Values')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Initial Proportions')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects and top states
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
# Out:
# Genetic Effect Statistics for Sample Patients:
#
# Patient 4376:
# Mean shift: 0.063
# Std of shifts: 0.139
# Range of shifts: [-0.131, 0.461]
#
# Top states and average proportions:
# State 7: 0.172
# State 3: 0.139
# State 8: 0.080
# State 17: 0.076
# State 1: 0.076
#
# Patient 6640:
# Mean shift: 0.040
# Std of shifts: 0.079
# Range of shifts: [-0.164, 0.232]
#
# Top states and average proportions:
# State 7: 0.169
# State 3: 0.161
# State 8: 0.085
# State 16: 0.082
# State 2: 0.071

# %%
print(f"LRT penalty (R): {model.lrtpen}")
print(f"Lambda amplitude: {model.lambda_amplitude}")
print(f"GP Weight: {model.gpweight}")
# Out:
# LRT penalty (R): 0
# Lambda amplitude: 1
# GP Weight: 0.001

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
import cProfile
import pstats
from pstats import SortKey

# For the healthtoo version
profiler = cProfile.Profile()
profiler.enable()
history_new = model.fit(E_100k, num_epochs=200, learning_rate=1e-1, lambda_reg=1e-2)
profiler.disable()
stats = pstats.Stats(profiler).sort_stats(SortKey.CUMULATIVE)
stats.print_stats(20)
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:231: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Kappa gradient: -5.413e+00
#
# Epoch 0
# Loss: 66.6998
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.18):
#   Theta for diagnosed: 0.151 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.039
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.41):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.070
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -4.690e+00
#
# Epoch 1
# Loss: 6589.3823
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.15):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -4.093e+00
#
# Epoch 2
# Loss: 593.6402
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -3.592e+00
#
# Epoch 3
# Loss: 1527.6689
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.10):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.150 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.83):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -3.166e+00
#
# Epoch 4
# Loss: 3714.4885
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.11):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.79):
#   Theta for diagnosed: 0.150 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.84):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -2.801e+00
#
# Epoch 5
# Loss: 2807.7405
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.14):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -2.484e+00
#
# Epoch 6
# Loss: 937.8629
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.16):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -2.209e+00
#
# Epoch 7
# Loss: 222.8276
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.18):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.968e+00
#
# Epoch 8
# Loss: 926.7952
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.19):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.756e+00
#
# Epoch 9
# Loss: 1760.8232
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.18):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.568e+00
#
# Epoch 10
# Loss: 1681.9672
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.17):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.401e+00
#
# Epoch 11
# Loss: 912.8911
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.14):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.78):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.252e+00
#
# Epoch 12
# Loss: 261.6486
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.12):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.118e+00
#
# Epoch 13
# Loss: 230.9836
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.09):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -9.979e-01
#
# Epoch 14
# Loss: 654.4741
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.07):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.77):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.49):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -8.896e-01
#
# Epoch 15
# Loss: 976.4597
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.05):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.76):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -7.917e-01
#
# Epoch 16
# Loss: 864.6313
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.04):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.76):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -7.030e-01
#
# Epoch 17
# Loss: 469.8264
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.02):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.75):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -6.227e-01
#
# Epoch 18
# Loss: 168.0202
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.00):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.75):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -5.498e-01
#
# Epoch 19
# Loss: 178.4854
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.97):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.74):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.85):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -4.837e-01
#
# Epoch 20
# Loss: 396.8795
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.93):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.74):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -4.237e-01
#
# Epoch 21
# Loss: 546.9896
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.89):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.73):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -3.692e-01
#
# Epoch 22
# Loss: 473.9634
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.84):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.73):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -3.196e-01
#
# Epoch 23
# Loss: 266.2366
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.79):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.72):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -2.744e-01
#
# Epoch 24
# Loss: 123.0258
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.73):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.71):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -2.334e-01
#
# Epoch 25
# Loss: 147.7381
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.67):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.70):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.960e-01
#
# Epoch 26
# Loss: 266.2592
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.62):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.70):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.620e-01
#
# Epoch 27
# Loss: 327.9193
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.56):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.69):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.312e-01
#
# Epoch 28
# Loss: 267.0331
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.50):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.68):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.032e-01
#
# Epoch 29
# Loss: 152.2741
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.44):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.67):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.43):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -7.794e-02
#
# Epoch 30
# Loss: 94.5298
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.37):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.65):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -5.518e-02
#
# Epoch 31
# Loss: 129.5203
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.30):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.64):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -3.474e-02
#
# Epoch 32
# Loss: 193.8901
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.23):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.63):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -1.641e-02
#
# Epoch 33
# Loss: 206.2539
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.15):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.62):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: -3.298e-05
#
# Epoch 34
# Loss: 154.4033
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=31.07):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.61):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 1.456e-02
#
# Epoch 35
# Loss: 95.9179
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.98):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.60):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 2.749e-02
#
# Epoch 36
# Loss: 85.8855
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.90):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.59):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 3.890e-02
#
# Epoch 37
# Loss: 119.0609
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.81):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.57):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.40):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 4.890e-02
#
# Epoch 38
# Loss: 145.3722
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.72):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.56):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.46):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.40):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 5.758e-02
#
# Epoch 39
# Loss: 131.6810
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.64):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.54):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.40):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.89):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 6.502e-02
#
# Epoch 40
# Loss: 95.0959
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=30.55):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.53):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.39):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.89):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 7.131e-02
#
# Epoch 41
# Loss: 75.4489
#
# Monitoring signature responses:
#
# Disease 76 (signature 7, LR=30.52):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=30.46):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.39):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.89):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 7.652e-02
#
# Epoch 42
# Loss: 87.1325
#
# Monitoring signature responses:
#
# Disease 76 (signature 7, LR=30.50):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.36):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.39):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.89):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.073e-02
#
# Epoch 43
# Loss: 107.1053
#
# Monitoring signature responses:
#
# Disease 76 (signature 7, LR=30.49):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.27):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.38):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.89):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.405e-02
#
# Epoch 44
# Loss: 107.3287
#
# Monitoring signature responses:
#
# Disease 76 (signature 7, LR=30.47):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.17):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.38):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.89):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.654e-02
#
# Epoch 45
# Loss: 87.7654
#
# Monitoring signature responses:
#
# Disease 76 (signature 7, LR=30.45):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 161 (signature 7, LR=30.07):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.38):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.89):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.827e-02
#
# Epoch 46
# Loss: 71.6272
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 76 (signature 7, LR=30.44):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=29.98):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.37):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.931e-02
#
# Epoch 47
# Loss: 74.3252
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 76 (signature 7, LR=30.42):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=29.88):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.37):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.972e-02
#
# Epoch 48
# Loss: 86.6084
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 76 (signature 7, LR=30.41):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=29.78):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.36):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.955e-02
#
# Epoch 49
# Loss: 89.6892
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 76 (signature 7, LR=30.39):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=29.68):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.36):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.885e-02
#
# Epoch 50
# Loss: 79.3868
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.44):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 76 (signature 7, LR=30.37):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=29.58):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.35):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.766e-02
#
# Epoch 51
# Loss: 68.6697
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.35):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=29.48):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.35):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.602e-02
#
# Epoch 52
# Loss: 68.8997
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.34):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 161 (signature 7, LR=29.37):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.35):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.398e-02
#
# Epoch 53
# Loss: 76.1172
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.32):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.34):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 161 (signature 7, LR=29.27):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 8.159e-02
#
# Epoch 54
# Loss: 78.5451
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.30):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.34):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 161 (signature 7, LR=29.17):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 7.890e-02
#
# Epoch 55
# Loss: 72.6480
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.28):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.33):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 161 (signature 7, LR=29.07):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 50 (signature 15, LR=28.90):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 7.594e-02
#
# Epoch 56
# Loss: 66.1585
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.26):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.33):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 161 (signature 7, LR=28.97):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
# Kappa gradient: 7.277e-02
#
# Epoch 57
# Loss: 66.3017
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.25):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.32):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 161 (signature 7, LR=28.87):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
# Kappa gradient: 6.941e-02
#
# Epoch 58
# Loss: 70.6175
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.43):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.23):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.32):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 161 (signature 7, LR=28.77):
#   Theta for diagnosed: 0.151 ± 0.035
#   Theta for others: 0.147
#   Proportion difference: 0.003
# Kappa gradient: 6.588e-02
#
# Epoch 59
# Loss: 71.7906
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.42):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.21):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.31):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 161 (signature 7, LR=28.67):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
# Kappa gradient: 6.223e-02
#
# Epoch 60
# Loss: 67.9985
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.42):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.19):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.31):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 161 (signature 7, LR=28.56):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
# Kappa gradient: 5.847e-02
#
# Epoch 61
# Loss: 64.3443
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.42):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.17):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.30):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 283 (signature 8, LR=28.53):
#   Theta for diagnosed: 0.087 ± 0.073
#   Theta for others: 0.087
#   Proportion difference: 0.000
# Kappa gradient: 5.463e-02
#
# Epoch 62
# Loss: 64.9127
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.42):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.15):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.30):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.92):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 283 (signature 8, LR=28.52):
#   Theta for diagnosed: 0.087 ± 0.073
#   Theta for others: 0.087
#   Proportion difference: 0.000
# Kappa gradient: 5.074e-02
#
# Epoch 63
# Loss: 67.5046
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.42):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=30.13):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 347 (signature 3, LR=29.29):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.92):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 283 (signature 8, LR=28.52):
#   Theta for diagnosed: 0.087 ± 0.073
#   Theta for others: 0.087
#   Proportion difference: 0.000
# Kappa gradient: 4.682e-02
#
# Epoch 64
# Loss: 67.6622
#
# ...
#
# Epoch 182
# Loss: 61.5223
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.11):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.15):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.80):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.72):
#   Theta for diagnosed: 0.023 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.026 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -5.269e-03
#
# Epoch 183
# Loss: 61.5191
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.11):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.16):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.81):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.72):
#   Theta for diagnosed: 0.023 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.026 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -5.223e-03
#
# Epoch 184
# Loss: 61.5163
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.11):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.16):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.82):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.73):
#   Theta for diagnosed: 0.023 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.027 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -5.177e-03
#
# Epoch 185
# Loss: 61.5132
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.10):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.16):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.83):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.73):
#   Theta for diagnosed: 0.023 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.027 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -5.129e-03
#
# Epoch 186
# Loss: 61.5098
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.10):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.16):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.84):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.74):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.027 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -5.083e-03
#
# Epoch 187
# Loss: 61.5062
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.10):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.17):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.85):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.74):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.027 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -5.035e-03
#
# Epoch 188
# Loss: 61.5028
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.09):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.17):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.86):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.74):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.027 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.988e-03
#
# Epoch 189
# Loss: 61.4991
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.09):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.17):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.87):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.75):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.027 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.942e-03
#
# Epoch 190
# Loss: 61.4954
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.09):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.18):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.88):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.75):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.50):
#   Theta for diagnosed: 0.027 ± 0.024
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.894e-03
#
# Epoch 191
# Loss: 61.4921
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.08):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.18):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.89):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.76):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.849e-03
#
# Epoch 192
# Loss: 61.4895
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.08):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.18):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.90):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.76):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.800e-03
#
# Epoch 193
# Loss: 61.4867
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.08):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.18):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.91):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.77):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.759e-03
#
# Epoch 194
# Loss: 61.4833
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.07):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.19):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.92):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.77):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.708e-03
#
# Epoch 195
# Loss: 61.4797
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.07):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.19):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.93):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.77):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.669e-03
#
# Epoch 196
# Loss: 61.4759
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.07):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.19):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.94):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.78):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.621e-03
#
# Epoch 197
# Loss: 61.4720
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.06):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.19):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.95):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.78):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.579e-03
#
# Epoch 198
# Loss: 61.4687
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.06):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.20):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.96):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.79):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
# Kappa gradient: -4.536e-03
#
# Epoch 199
# Loss: 61.4660
#
# Monitoring signature responses:
#
# Disease 260 (signature 8, LR=30.06):
#   Theta for diagnosed: 0.091 ± 0.076
#   Theta for others: 0.087
#   Proportion difference: 0.004
#
# Disease 50 (signature 15, LR=29.20):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=28.97):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Disease 246 (signature 13, LR=28.79):
#   Theta for diagnosed: 0.024 ± 0.007
#   Theta for others: 0.023
#   Proportion difference: 0.000
#
# Disease 84 (signature 10, LR=28.51):
#   Theta for diagnosed: 0.027 ± 0.025
#   Theta for others: 0.026
#   Proportion difference: 0.001
#          94186006 function calls (94165150 primitive calls) in 5148.460 seconds
#
#    Ordered by: cumulative time
#    List reduced from 4183 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000 5148.461 2574.231 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#    1885/2    0.042    0.000 5148.461 2574.231 {built-in method builtins.exec}
#         1    0.733    0.733 5148.461 5148.461 /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_1502/4125118760.py:8(<module>)
#         1  174.526  174.526 5147.729 5147.729 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:322(fit)
#       200    0.008    0.000 3567.000   17.835 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:525(backward)
#       200    0.002    0.000 3566.992   17.835 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#       200    0.002    0.000 3566.980   17.835 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/graph.py:816(_engine_run_backward)
#       200 3566.977   17.835 3566.977   17.835 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       200  300.592    1.503 1361.737    6.809 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:223(compute_loss)
#       200  495.021    2.475  955.822    4.779 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:280(compute_gp_prior_loss)
#  43461600  331.638    0.000  331.638    0.000 {built-in method torch.cholesky_solve}
#  43531800  135.818    0.000  136.790    0.000 {built-in method torch.sum}
#       400   14.353    0.036   74.372    0.186 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:214(forward)
#       200    1.220    0.006   41.851    0.209 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:391(analyze_signature_responses)
#       400    0.005    0.000   37.681    0.094 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/functional.py:210(einsum)
#       400   37.674    0.094   37.674    0.094 {built-in method torch.einsum}
#       600   31.842    0.053   31.842    0.053 {built-in method torch.log}
#       600   30.407    0.051   30.407    0.051 {built-in method torch.clamp}
#       600    0.003    0.000   12.900    0.021 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:33(wrapped)
#       600    0.003    0.000   12.896    0.021 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:1026(__rsub__)

# %%
model.kappa
# Out:
# Parameter containing:
# tensor([3.2978], requires_grad=True)

# %%
def plot_disease_lambda_alignment(model):
    """
    Plot lambda values aligned with disease occurrences for selected patients
    """
    # Find patients with specific diseases and their diagnosis times
    disease_idx = 112  # MI
    patients_with_disease = []
    diagnosis_times = []
    
    for patient in range(model.Y.shape[0]):
        diag_time = torch.where(model.Y[patient, disease_idx])[0]
        if len(diag_time) > 0:
            patients_with_disease.append(patient)
            diagnosis_times.append(diag_time[0].item())
    
    # Sample a few patients
    n_samples = min(5, len(patients_with_disease))
    sample_indices = np.random.choice(len(patients_with_disease), n_samples, replace=False)
    
    # Create plot
    fig, ax = plt.subplots(figsize=(12, 6))
    time_points = np.arange(model.T)
    
    # Find signature that most strongly associates with this disease
    psi_disease = model.psi[:, disease_idx].detach()
    sig_idx = torch.argmax(psi_disease).item()
    
    # Plot for each sampled patient
    for idx in sample_indices:
        patient = patients_with_disease[idx]
        diag_time = diagnosis_times[idx]
        
        # Plot lambda (detached)
        lambda_values = torch.softmax(model.lambda_[patient].detach(), dim=0)[sig_idx]
        ax.plot(time_points, lambda_values.numpy(),
                alpha=0.5, label=f'Patient {patient}')
        
        # Mark diagnosis time
        ax.axvline(x=diag_time, linestyle=':', alpha=0.3)
    
    ax.set_title(f'Lambda Values for Signature {sig_idx} (Most Associated with MI)\nVertical Lines Show Diagnosis Times')
    ax.set_xlabel('Time')
    ax.set_ylabel('Lambda (proportion)')
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Call the plotting function
plot_disease_lambda_alignment(model)

# %%
def plot_training_evolution(history_tuple):
    losses, gradient_history = history_tuple
    
    plt.figure(figsize=(15, 5))
    
    # Plot loss
    plt.subplot(1, 3, 1)
    plt.plot(losses, label='Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Evolution')
    plt.yscale('log')
    plt.legend()
    
    # Plot lambda gradients
    plt.subplot(1, 3, 2)
    lambda_norms = [torch.norm(g).item() for g in gradient_history['lambda_grad']]
    plt.plot(lambda_norms, label='Lambda gradients')
    plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Gradient norm')
    plt.title('Lambda Gradient Evolution')
    plt.legend()
    
    # Plot phi gradients
    plt.subplot(1, 3, 3)
    phi_norms = [torch.norm(g).item() for g in gradient_history['phi_grad']]
    plt.plot(phi_norms, label='Phi gradients')
    plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Gradient norm')
    plt.title('Phi Gradient Evolution')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
plot_training_evolution(history_new)

# %%
model.psi[:,112]
# Out:
# tensor([-1.9900, -2.0138, -1.9812, -2.0601, -1.9267,  0.2891, -2.0699, -1.9253,
#         -2.0517, -2.0710, -2.0289, -2.0259, -2.0595, -1.9378, -1.9237, -1.9434,
#         -2.0622, -2.1082, -1.9811, -2.0242, -4.9740],
#        grad_fn=<SelectBackward0>)

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=1e-2:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Lambda changes with lr=1e-2:
# Mean absolute change: 8.087e-03
# Max absolute change: 2.288e+00
# Std of changes: 1.793e-02

# %%
final_psi= model.psi.detach().clone()
diff = torch.abs(final_psi - initial_psi)

print(f"Psi changes with lr=1e-2:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Psi changes with lr=1e-2:
# Mean absolute change: 6.301e-02
# Max absolute change: 2.098e+00
# Std of changes: 9.140e-02

# %%
final_phi= model.phi.detach().clone()
diff = torch.abs(final_phi - initial_phi)

print(f"Phi changes with lr=1e-2:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Phi changes with lr=1e-2:
# Mean absolute change: 2.567e-03
# Max absolute change: 7.233e-01
# Std of changes: 1.279e-02

# %%
final_psi.shape
# Out:
# torch.Size([21, 348])

# %%
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# Clusters match exactly: True

# %%
model.clusters[17]
# Out:
# np.int32(19)

# %%
def plot_theta_differences():
    diseases = [112, 67, 127, 10, 17,114]
    signatures = [5, 7, 0, 17, 19,5]
    
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    axes = axes.flatten()
    
    for i, (d, sig) in enumerate(zip(diseases, signatures)):
        ax = axes[i]
        
        # Get diagnosis times
        diagnosis_mask = model.Y[:, d, :].bool()
        diagnosed = torch.where(diagnosis_mask)[0]
        
        # Get thetas
        pi, theta, phi_prob = model.forward()
        
        # Plot distributions
        diagnosed_theta = theta[diagnosis_mask, sig].detach().numpy()
        others_theta = theta[~diagnosis_mask, sig].detach().numpy()
        
        ax.hist(diagnosed_theta, alpha=0.5, label='At diagnosis', density=True)
        ax.hist(others_theta, alpha=0.5, label='Others', density=True)
        
        ax.set_title(f'Disease {d} (sig {sig})')
        ax.set_xlabel('Theta')
        ax.set_ylabel('Density')
        ax.legend()
    
    plt.tight_layout()
    plt.show()

# %%
plot_theta_differences()

# %%
model.gpweight
# Out:
# 0.001

# %%
# Get μ_dt from checkpoint and predictions
mu_dt = model.prevalence_t  # Shape: (348, 52)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()
#observed_risk=mu_dt_flat
# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000438
# Mean predicted risk (original): 0.000454
# Mean predicted risk (calibrated): 0.000438
# Calibration scale factor: 0.963

# %%
# Get predictions
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
predicted_risk_2d = pi_pred.cpu().detach().numpy().mean(axis=0)  # average across individuals

# Get raw observations and calculate scale factor
Y_np = model.Y.cpu().detach().numpy()
Y_mean_2d = Y_np.mean(axis=0)  # average across individuals
scale_factor = Y_mean_2d.mean() / predicted_risk_2d.mean()
scaled_risk_2d = predicted_risk_2d * scale_factor

# Create plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Original predictions vs raw observations
ax1.scatter(Y_mean_2d.flatten(), predicted_risk_2d.flatten(), 
           alpha=0.3, color='blue', s=10)
ax1.plot([0, max(Y_mean_2d.max(), predicted_risk_2d.max())], 
         [0, max(Y_mean_2d.max(), predicted_risk_2d.max())], 
         'k--', label='x=y')
ax1.set_xlabel('Observed Event Rate (Y)')
ax1.set_ylabel('Original Predicted Risk')
ax1.set_title('Original Predictions vs Observed Events')
ax1.set_xscale('log')
ax1.set_yscale('log')

# Scaled predictions vs raw observations
ax2.scatter(Y_mean_2d.flatten(), scaled_risk_2d.flatten(), 
           alpha=0.3, color='green', s=10)
ax2.plot([0, max(Y_mean_2d.max(), scaled_risk_2d.max())], 
         [0, max(Y_mean_2d.max(), scaled_risk_2d.max())], 
         'k--', label='x=y')
ax2.set_xlabel('Observed Event Rate (Y)')
ax2.set_ylabel('Scaled Predicted Risk')
ax2.set_title(f'Simple Scaling (factor={scale_factor:.2f}) vs Observed Events')
ax2.set_xscale('log')
ax2.set_yscale('log')

plt.tight_layout()
plt.show()

print(f"Scale factor: {scale_factor:.3f}")
# Out:
# Scale factor: 0.963

# %%
ss_res = np.sum((observed_risk - predicted_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.839

# %%
def apply_loess_calibration(predicted_risks, observed_risks):
    # Fit LOESS calibration curve
    calibrated_risks = lowess(
        observed_risks, 
        predicted_risks,
        frac=0.3,  # Can tune this parameter
        return_sorted=False
    )
    
    # Apply to predictions
    pi_calibrated = np.zeros_like(pi)
    for d in range(model.D):
        for t in range(model.T):
            risks = pi[:, d, t]
            pi_calibrated[:, d, t] = lowess(
                observed_risks,  # Use same calibration curve
                risks,
                frac=0.3
            )
    
    return pi_calibrated

# %%
    calibrated_risks = lowess(
        observed_risk, 
        predicted_risk,
        frac=0.3,  # Can tune this parameter
        return_sorted=False
    )

# %%
def plot_signature_temporal_patterns(model, disease_names, plot_dir, n_top=10, selected_signatures=None):
    """Show temporal patterns of top diseases for each signature"""
    phi = model.phi.detach().numpy()
    prevalence_logit = model.logit_prev_t.detach().numpy()
    import os
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    phi_avg = phi_centered.mean(axis=2)
    
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            disease_name = disease_names[idx]
            ax.plot(temporal_pattern, label=disease_name)
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, 'temporal_patterns_withkappa.png'))
    plt.close('all')

# %%
plot_signature_temporal_patterns(model, essentials['disease_names'],'/Users/sarahurbut/Dropbox (Personal)/', n_top=10, selected_signatures=[0,5,6,19])

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Paroxysmal ventricular tachycardia: effect=1.216 (OR=3.38), std=0.057
# Aortic valve disease: effect=1.183 (OR=3.26), std=0.031
# Heart failure NOS: effect=1.164 (OR=3.20), std=0.053
# Congestive heart failure (CHF) NOS: effect=1.047 (OR=2.85), std=0.056
# Pericarditis: effect=1.042 (OR=2.84), std=0.128
# Left bundle branch block: effect=1.006 (OR=2.73), std=0.063
# Cardiomegaly: effect=0.997 (OR=2.71), std=0.033
# Atrial fibrillation and flutter: effect=0.995 (OR=2.71), std=0.080
# Congenital anomalies of great vessels: effect=0.965 (OR=2.63), std=0.026
# Mitral valve disease: effect=0.964 (OR=2.62), std=0.069
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Enthesopathy: effect=1.211 (OR=3.36), std=0.055
# Hallux valgus (Bunion): effect=1.174 (OR=3.23), std=0.039
# Other disorders of synovium, tendon, and bursa: effect=1.163 (OR=3.20), std=0.020
# Peripheral enthesopathies and allied syndromes: effect=1.118 (OR=3.06), std=0.036
# Other peripheral nerve disorders: effect=1.101 (OR=3.01), std=0.145
# Rheumatoid arthritis: effect=1.090 (OR=2.97), std=0.025
# Pain in joint: effect=1.090 (OR=2.97), std=0.026
# Hallux rigidus: effect=1.086 (OR=2.96), std=0.091
# Osteoarthrosis, localized, primary: effect=1.070 (OR=2.92), std=0.030
# Synovitis and tenosynovitis: effect=1.006 (OR=2.73), std=0.053
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Gastritis and duodenitis: effect=1.203 (OR=3.33), std=0.111
# Gastric ulcer: effect=1.159 (OR=3.19), std=0.058
# Stricture and stenosis of esophagus: effect=1.145 (OR=3.14), std=0.090
# Barrett's esophagus: effect=1.141 (OR=3.13), std=0.033
# Diaphragmatic hernia: effect=1.076 (OR=2.93), std=0.105
# Iron deficiency anemias, unspecified or not due to blood loss: effect=1.017 (OR=2.77), std=0.085
# Duodenitis: effect=1.008 (OR=2.74), std=0.071
# Other disorders of stomach and duodenum: effect=0.993 (OR=2.70), std=0.069
# Reflux esophagitis: effect=0.982 (OR=2.67), std=0.034
# Esophageal bleeding (varices/hemorrhage): effect=0.969 (OR=2.64), std=0.037
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Other tests: effect=1.275 (OR=3.58), std=0.025
# Peripheral vascular disease, unspecified: effect=1.261 (OR=3.53), std=0.054
# Celiac disease: effect=1.232 (OR=3.43), std=0.083
# Right bundle branch block: effect=1.203 (OR=3.33), std=0.079
# Atopic/contact dermatitis due to other or unspecified: effect=1.174 (OR=3.24), std=0.053
# Hemangioma and lymphangioma, any site: effect=1.165 (OR=3.21), std=0.102
# Perforation of tympanic membrane: effect=1.131 (OR=3.10), std=0.045
# First degree AV block: effect=1.124 (OR=3.08), std=0.052
# Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: effect=1.116 (OR=3.05), std=0.122
# Malunion and nonunion of fracture: effect=1.112 (OR=3.04), std=0.106
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Other upper respiratory disease: effect=1.018 (OR=2.77), std=0.043
# Chronic sinusitis: effect=0.898 (OR=2.46), std=0.037
# Septal Deviations/Turbinate Hypertrophy: effect=0.890 (OR=2.44), std=0.111
# Nasal polyps: effect=0.886 (OR=2.42), std=0.117
# Chronic pharyngitis and nasopharyngitis: effect=0.857 (OR=2.36), std=0.107
# Hemangioma and lymphangioma, any site: effect=-1.738 (OR=0.18), std=0.087
# Enthesopathy: effect=-1.771 (OR=0.17), std=0.076
# Other acquired deformities of limbs: effect=-1.786 (OR=0.17), std=0.066
# Retinal detachment with retinal defect: effect=-1.804 (OR=0.16), std=0.035
# Other disorders of biliary tract: effect=-1.805 (OR=0.16), std=0.154
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Coronary atherosclerosis: effect=1.262 (OR=3.53), std=0.052
# Hypercholesterolemia: effect=1.176 (OR=3.24), std=0.130
# Other acute and subacute forms of ischemic heart disease: effect=1.140 (OR=3.13), std=0.041
# Angina pectoris: effect=0.957 (OR=2.60), std=0.066
# Unstable angina (intermediate coronary syndrome): effect=0.837 (OR=2.31), std=0.031
# Myocardial infarction: effect=0.808 (OR=2.24), std=0.040
# Other chronic ischemic heart disease, unspecified: effect=0.791 (OR=2.21), std=0.058
# Paroxysmal supraventricular tachycardia: effect=-1.742 (OR=0.18), std=0.059
# Allergic rhinitis: effect=-1.803 (OR=0.16), std=0.091
# Bronchiectasis: effect=-1.812 (OR=0.16), std=0.088
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Secondary malignancy of lymph nodes: effect=1.125 (OR=3.08), std=0.033
# Secondary malignant neoplasm of liver: effect=1.077 (OR=2.94), std=0.146
# Cancer of bronchus; lung: effect=1.034 (OR=2.81), std=0.035
# Secondary malignant neoplasm: effect=1.028 (OR=2.80), std=0.067
# Secondary malignant neoplasm of digestive systems: effect=1.000 (OR=2.72), std=0.116
# Malignant neoplasm, other: effect=0.961 (OR=2.61), std=0.074
# Secondary malignancy of bone: effect=0.945 (OR=2.57), std=0.045
# Secondary malignancy of respiratory organs: effect=0.705 (OR=2.02), std=0.054
# Other disorders of the kidney and ureters: effect=-1.740 (OR=0.18), std=0.064
# Inflammation of eyelids: effect=-1.781 (OR=0.17), std=0.108
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Migraine: effect=1.239 (OR=3.45), std=0.065
# Myalgia and myositis unspecified: effect=1.168 (OR=3.21), std=0.060
# Osteoporosis NOS: effect=1.116 (OR=3.05), std=0.139
# Abdominal pain: effect=1.046 (OR=2.85), std=0.129
# Cervicalgia: effect=1.040 (OR=2.83), std=0.086
# Other disorders of bone and cartilage: effect=1.002 (OR=2.72), std=0.075
# Asthma: effect=0.989 (OR=2.69), std=0.178
# Rheumatism, unspecified and fibrositis: effect=0.983 (OR=2.67), std=0.020
# Hyperlipidemia: effect=0.973 (OR=2.65), std=0.052
# Spondylosis and allied disorders: effect=0.956 (OR=2.60), std=0.144
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Cervicitis and endocervicitis: effect=1.336 (OR=3.80), std=0.070
# Ovarian cyst: effect=1.251 (OR=3.50), std=0.047
# Polyp of corpus uteri: effect=1.173 (OR=3.23), std=0.055
# Noninflammatory disorders of cervix: effect=1.132 (OR=3.10), std=0.077
# Excessive or frequent menstruation: effect=1.124 (OR=3.08), std=0.084
# Endometrial hyperplasia: effect=1.117 (OR=3.06), std=0.056
# Malignant neoplasm of uterus: effect=1.108 (OR=3.03), std=0.082
# Noninflammatory disorders of vagina: effect=1.106 (OR=3.02), std=0.039
# Uterine/Uterovaginal prolapse: effect=1.084 (OR=2.96), std=0.058
# Pain and other symptoms associated with female genital organs: effect=1.083 (OR=2.95), std=0.063
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Back pain: effect=1.341 (OR=3.82), std=0.058
# Displacement of intervertebral disc: effect=1.120 (OR=3.06), std=0.077
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=1.113 (OR=3.04), std=0.080
# Neuralgia, neuritis, and radiculitis NOS: effect=1.064 (OR=2.90), std=0.036
# Other and unspecified disc disorder: effect=1.004 (OR=2.73), std=0.058
# Degenerative disease of the spinal cord: effect=0.998 (OR=2.71), std=0.063
# Spondylosis without myelopathy: effect=0.985 (OR=2.68), std=0.027
# Kyphoscoliosis and scoliosis: effect=0.931 (OR=2.54), std=0.022
# Acquired spondylolisthesis: effect=0.907 (OR=2.48), std=0.060
# Spinal stenosis: effect=0.897 (OR=2.45), std=0.087
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Primary open angle glaucoma: effect=1.239 (OR=3.45), std=0.071
# Macular degeneration (senile) of retina NOS: effect=1.231 (OR=3.42), std=0.032
# Retinal vascular changes and abnomalities: effect=1.193 (OR=3.30), std=0.108
# Other retinal disorders: effect=1.173 (OR=3.23), std=0.163
# Myopia: effect=1.154 (OR=3.17), std=0.079
# Glaucoma: effect=1.074 (OR=2.93), std=0.053
# Senile cataract: effect=1.070 (OR=2.92), std=0.096
# Disorders of vitreous body: effect=0.992 (OR=2.70), std=0.039
# Cataract: effect=0.939 (OR=2.56), std=0.100
# Retinal detachment with retinal defect: effect=0.871 (OR=2.39), std=0.085
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Occlusion of cerebral arteries: effect=1.165 (OR=3.21), std=0.037
# Late effects of cerebrovascular disease: effect=1.092 (OR=2.98), std=0.039
# Cerebral ischemia: effect=1.080 (OR=2.95), std=0.048
# Cerebral artery occlusion, with cerebral infarction: effect=1.057 (OR=2.88), std=0.045
# Hemiplegia: effect=1.055 (OR=2.87), std=0.051
# Cerebrovascular disease: effect=0.930 (OR=2.53), std=0.080
# Transient cerebral ischemia: effect=0.908 (OR=2.48), std=0.112
# Occlusion and stenosis of precerebral arteries: effect=0.885 (OR=2.42), std=0.064
# Retinal detachment with retinal defect: effect=-1.759 (OR=0.17), std=0.042
# Scar conditions and fibrosis of skin: effect=-1.765 (OR=0.17), std=0.021
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Renal colic: effect=1.238 (OR=3.45), std=0.078
# Hydronephrosis: effect=1.072 (OR=2.92), std=0.100
# Stricture/obstruction of ureter: effect=1.042 (OR=2.84), std=0.145
# Other disorders of the kidney and ureters: effect=1.025 (OR=2.79), std=0.046
# Calculus of ureter: effect=1.000 (OR=2.72), std=0.058
# Calculus of kidney: effect=0.938 (OR=2.55), std=0.049
# Pyelonephritis: effect=0.878 (OR=2.41), std=0.013
# Streptococcus infection: effect=-1.804 (OR=0.16), std=0.058
# Occlusion of cerebral arteries: effect=-1.815 (OR=0.16), std=0.071
# Chronic Kidney Disease, Stage III: effect=-1.831 (OR=0.16), std=0.109
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Urethral stricture (not specified as infectious): effect=1.272 (OR=3.57), std=0.038
# Cancer of prostate: effect=1.228 (OR=3.41), std=0.071
# Cystitis: effect=1.222 (OR=3.39), std=0.019
# Other disorders of bladder: effect=1.076 (OR=2.93), std=0.037
# Other symptoms/disorders or the urinary system: effect=1.074 (OR=2.93), std=0.055
# Malignant neoplasm of bladder: effect=1.043 (OR=2.84), std=0.044
# Urinary incontinence: effect=1.022 (OR=2.78), std=0.073
# Chronic cystitis: effect=0.979 (OR=2.66), std=0.133
# Hyperplasia of prostate: effect=0.941 (OR=2.56), std=0.043
# Functional disorders of bladder: effect=0.916 (OR=2.50), std=0.098
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Empyema and pneumothorax: effect=1.109 (OR=3.03), std=0.094
# Emphysema: effect=1.080 (OR=2.94), std=0.026
# Pneumonia: effect=1.042 (OR=2.83), std=0.012
# Obstructive chronic bronchitis: effect=0.935 (OR=2.55), std=0.079
# Bronchiectasis: effect=0.923 (OR=2.52), std=0.112
# Pneumococcal pneumonia: effect=0.902 (OR=2.47), std=0.050
# Chronic airway obstruction: effect=0.834 (OR=2.30), std=0.052
# Postinflammatory pulmonary fibrosis: effect=0.784 (OR=2.19), std=0.078
# Tobacco use disorder: effect=0.783 (OR=2.19), std=0.039
# Respiratory failure: effect=0.777 (OR=2.17), std=0.039
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Hypoglycemia: effect=1.243 (OR=3.47), std=0.110
# Type 2 diabetes with ophthalmic manifestations: effect=1.161 (OR=3.19), std=0.100
# Diabetic retinopathy: effect=0.999 (OR=2.72), std=0.032
# Type 1 diabetes: effect=0.985 (OR=2.68), std=0.116
# Type 2 diabetes: effect=0.945 (OR=2.57), std=0.149
# Pleurisy; pleural effusion: effect=-1.746 (OR=0.17), std=0.068
# Lipoma of skin and subcutaneous tissue: effect=-1.779 (OR=0.17), std=0.089
# Disorders of uterus, NEC: effect=-1.794 (OR=0.17), std=0.084
# First degree AV block: effect=-1.804 (OR=0.16), std=0.118
# Sleep disorders: effect=-1.806 (OR=0.16), std=0.015
#
# Top 10 diseases in Signature 16 (relative to baseline):
# E. coli: effect=1.103 (OR=3.01), std=0.099
# Other diseases of respiratory system, NEC: effect=1.082 (OR=2.95), std=0.089
# Hypotension NOS: effect=1.081 (OR=2.95), std=0.118
# Hyperpotassemia: effect=1.063 (OR=2.89), std=0.122
# Chronic ulcer of skin: effect=1.055 (OR=2.87), std=0.052
# Peritonitis and retroperitoneal infections: effect=1.054 (OR=2.87), std=0.017
# Gram negative septicemia: effect=1.051 (OR=2.86), std=0.101
# Bacterial pneumonia: effect=1.040 (OR=2.83), std=0.131
# Cellulitis and abscess of arm/hand: effect=1.029 (OR=2.80), std=0.100
# Other local infections of skin and subcutaneous tissue: effect=1.025 (OR=2.79), std=0.041
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Benign neoplasm of colon: effect=1.156 (OR=3.18), std=0.071
# Regional enteritis: effect=1.147 (OR=3.15), std=0.104
# Hemorrhage of gastrointestinal tract: effect=1.140 (OR=3.13), std=0.045
# Neoplasm of unspecified nature of digestive system: effect=1.092 (OR=2.98), std=0.088
# Ventral hernia: effect=1.080 (OR=2.95), std=0.038
# Hemorrhage of rectum and anus: effect=1.076 (OR=2.93), std=0.026
# Hemorrhoids: effect=1.058 (OR=2.88), std=0.080
# Noninfectious gastroenteritis: effect=1.024 (OR=2.78), std=0.044
# Colon cancer: effect=1.008 (OR=2.74), std=0.059
# Other disorders of intestine: effect=1.006 (OR=2.74), std=0.059
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Other disorders of gallbladder: effect=1.293 (OR=3.64), std=0.021
# Peritoneal adhesions (postoperative) (postinfection): effect=1.167 (OR=3.21), std=0.113
# Cholelithiasis with acute cholecystitis: effect=1.164 (OR=3.20), std=0.077
# Acute pancreatitis: effect=1.064 (OR=2.90), std=0.033
# Calculus of bile duct: effect=1.045 (OR=2.84), std=0.067
# Cholelithiasis: effect=1.019 (OR=2.77), std=0.029
# Cholelithiasis with other cholecystitis: effect=0.989 (OR=2.69), std=0.063
# Other disorders of biliary tract: effect=0.966 (OR=2.63), std=0.091
# Cholecystitis without cholelithiasis: effect=0.956 (OR=2.60), std=0.105
# Other disorders of stomach and duodenum: effect=-1.775 (OR=0.17), std=0.072
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Thyrotoxicosis with or without goiter: effect=1.213 (OR=3.36), std=0.055
# Other disorders of eyelids: effect=1.200 (OR=3.32), std=0.054
# Seborrheic keratosis: effect=1.189 (OR=3.28), std=0.048
# Other non-epithelial cancer of skin: effect=1.153 (OR=3.17), std=0.064
# Chronic glomerulonephritis, NOS: effect=1.152 (OR=3.17), std=0.066
# Actinic keratosis: effect=1.082 (OR=2.95), std=0.026
# Chronic Kidney Disease, Stage III: effect=1.070 (OR=2.91), std=0.070
# Breast cancer [female]: effect=1.052 (OR=2.86), std=0.016
# Hypertensive chronic kidney disease: effect=1.023 (OR=2.78), std=0.088
# Disorders of lacrimal system: effect=1.023 (OR=2.78), std=0.080
#
# Top 10 diseases in Signature 20 (relative to baseline):
# Endometrial hyperplasia: effect=-4.733 (OR=0.01), std=0.125
# Noninfectious gastroenteritis: effect=-4.775 (OR=0.01), std=0.029
# Other upper respiratory disease: effect=-4.796 (OR=0.01), std=0.083
# Aortic valve disease: effect=-4.811 (OR=0.01), std=0.094
# Myalgia and myositis unspecified: effect=-4.819 (OR=0.01), std=0.041
# Angina pectoris: effect=-4.823 (OR=0.01), std=0.033
# Urethral stricture (not specified as infectious): effect=-4.835 (OR=0.01), std=0.053
# Major depressive disorder: effect=-4.841 (OR=0.01), std=0.006
# Dyspareunia: effect=-4.842 (OR=0.01), std=0.018
# Chronic ulcer of skin: effect=-4.846 (OR=0.01), std=0.051

# %%
mean_phi=model.phi.detach().cpu().numpy()

# %%
initial_psi[:,112]

# %%
model.psi[:,112]

# %%
model.K=21

# %%
model.kappa

# %%
def plot_disease_signature_patterns(model, disease_idx=112):
    plt.figure(figsize=(12, 6))
    time_points = np.arange(model.T)
    
    # Get phi values for this disease across all signatures
    phi_disease = model.phi[:, disease_idx].detach()  # [K, T]
    psi_disease = model.psi[:, disease_idx].detach()  # [K]
    
    # Plot phi trajectories
    for k in range(model.K):
        # Make the assigned signature (highest psi) stand out
        is_assigned = (psi_disease[k] == psi_disease.max())
        alpha = 1.0 if is_assigned else 0.3
        linestyle = '-' if is_assigned else '--'
        
        plt.plot(time_points, phi_disease[k], 
                label=f'Signature {k}', 
                alpha=alpha,
                linestyle=linestyle)
    
    plt.title(f'Disease {disease_idx} - Temporal Patterns Across Signatures\n(solid=assigned signature)')
    plt.xlabel('Time')
    plt.ylabel('Phi Value')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    # Print psi values
    print(f"\nPsi values for disease {disease_idx}:")
    for k in range(model.K):
        print(f"Signature {k}: {psi_disease[k]:.3f}")

# Call the function for MI (disease 112)
plot_disease_signature_patterns(model, disease_idx=112)
# Out:
# Psi values for disease 112:
# Signature 0: -1.990
# Signature 1: -2.014
# Signature 2: -1.981
# Signature 3: -2.060
# Signature 4: -1.927
# Signature 5: 0.289
# Signature 6: -2.070
# Signature 7: -1.925
# Signature 8: -2.052
# Signature 9: -2.071
# Signature 10: -2.029
# Signature 11: -2.026
# Signature 12: -2.059
# Signature 13: -1.938
# Signature 14: -1.924
# Signature 15: -1.943
# Signature 16: -2.062
# Signature 17: -2.108
# Signature 18: -1.981
# Signature 19: -2.024

# %%
model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:541: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Paroxysmal ventricular tachycardia: 1.141
# 2. Pericarditis: 1.101
# 3. Aortic valve disease: 1.087
# 4. Heart failure NOS: 0.938
# 5. Left bundle branch block: 0.867
# 6. Paroxysmal supraventricular tachycardia: 0.769
# 7. Mitral valve disease: 0.753
# 8. Congenital anomalies of great vessels: 0.712
# 9. Cardiomegaly: 0.697
# 10. Congestive heart failure (CHF) NOS: 0.689
#
# Final top diseases:
# 1. Paroxysmal ventricular tachycardia: 1.216
# 2. Aortic valve disease: 1.183
# 3. Heart failure NOS: 1.164
# 4. Congestive heart failure (CHF) NOS: 1.047
# 5. Pericarditis: 1.042
# 6. Left bundle branch block: 1.006
# 7. Cardiomegaly: 0.997
# 8. Atrial fibrillation and flutter: 0.995
# 9. Congenital anomalies of great vessels: 0.965
# 10. Mitral valve disease: 0.964
#
# Congestive heart failure (CHF) NOS changed from rank 10 to 4
#
# Mitral valve disease changed from rank 7 to 10
#
# Pericarditis changed from rank 2 to 5
#
# Paroxysmal supraventricular tachycardia changed from rank 6 to 12
#
# Atrial fibrillation and flutter changed from rank 12 to 8
#
# Signature 1:
#
# Initial top diseases:
# 1. Peripheral enthesopathies and allied syndromes: 1.295
# 2. Osteoarthrosis, localized, primary: 1.263
# 3. Other disorders of synovium, tendon, and bursa: 1.107
# 4. Hallux rigidus: 0.976
# 5. Acquired toe deformities: 0.931
# 6. Joint effusions: 0.876
# 7. Rheumatoid arthritis: 0.866
# 8. Synovitis and tenosynovitis: 0.842
# 9. Hallux valgus (Bunion): 0.841
# 10. Other peripheral nerve disorders: 0.839
#
# Final top diseases:
# 1. Enthesopathy: 1.211
# 2. Hallux valgus (Bunion): 1.174
# 3. Other disorders of synovium, tendon, and bursa: 1.163
# 4. Peripheral enthesopathies and allied syndromes: 1.118
# 5. Other peripheral nerve disorders: 1.101
# 6. Rheumatoid arthritis: 1.090
# 7. Pain in joint: 1.090
# 8. Hallux rigidus: 1.086
# 9. Osteoarthrosis, localized, primary: 1.070
# 10. Synovitis and tenosynovitis: 1.006
#
# Hallux rigidus changed from rank 4 to 8
#
# Hallux valgus (Bunion) changed from rank 9 to 2
#
# Osteoarthrosis, localized, primary changed from rank 2 to 9
#
# Joint effusions changed from rank 6 to 12
#
# Pain in joint changed from rank 12 to 7
#
# Other peripheral nerve disorders changed from rank 10 to 5
#
# Peripheral enthesopathies and allied syndromes changed from rank 1 to 4
#
# Enthesopathy changed from rank 12 to 1
#
# Acquired toe deformities changed from rank 5 to 12
#
# Signature 2:
#
# Initial top diseases:
# 1. Gastric ulcer: 1.012
# 2. Other disorders of stomach and duodenum: 1.007
# 3. Reflux esophagitis: 1.003
# 4. Barrett's esophagus: 0.999
# 5. Stricture and stenosis of esophagus: 0.889
# 6. Duodenal ulcer: 0.871
# 7. Ulcer of esophagus: 0.832
# 8. Gastritis and duodenitis: 0.824
# 9. Duodenitis: 0.746
# 10. Benign neoplasm of other parts of digestive system: 0.671
#
# Final top diseases:
# 1. Gastritis and duodenitis: 1.203
# 2. Gastric ulcer: 1.159
# 3. Stricture and stenosis of esophagus: 1.145
# 4. Barrett's esophagus: 1.141
# 5. Diaphragmatic hernia: 1.076
# 6. Iron deficiency anemias, unspecified or not due to blood loss: 1.017
# 7. Duodenitis: 1.008
# 8. Other disorders of stomach and duodenum: 0.993
# 9. Reflux esophagitis: 0.982
# 10. Esophageal bleeding (varices/hemorrhage): 0.969
#
# Other disorders of stomach and duodenum changed from rank 2 to 8
#
# Diaphragmatic hernia changed from rank 12 to 5
#
# Ulcer of esophagus changed from rank 7 to 12
#
# Reflux esophagitis changed from rank 3 to 9
#
# Duodenal ulcer changed from rank 6 to 12
#
# Gastritis and duodenitis changed from rank 8 to 1
#
# Iron deficiency anemias, unspecified or not due to blood loss changed from rank 12 to 6
#
# Signature 3:
#
# Initial top diseases:
# 1. Hypertrophy of breast (Gynecomastia): 1.179
# 2. Chronic tonsillitis and adenoiditis: 1.166
# 3. Inflammation of eyelids: 1.162
# 4. Perforation of tympanic membrane: 1.150
# 5. Sleep disorders: 1.149
# 6. First degree AV block: 1.108
# 7. Malunion and nonunion of fracture: 1.108
# 8. Redundant prepuce and phimosis/BXO: 1.099
# 9. Cardiac arrest: 1.080
# 10. Neoplasm of uncertain behavior: 1.071
#
# Final top diseases:
# 1. Other tests: 1.275
# 2. Peripheral vascular disease, unspecified: 1.261
# 3. Celiac disease: 1.232
# 4. Right bundle branch block: 1.203
# 5. Atopic/contact dermatitis due to other or unspecified: 1.174
# 6. Hemangioma and lymphangioma, any site: 1.165
# 7. Perforation of tympanic membrane: 1.131
# 8. First degree AV block: 1.124
# 9. Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: 1.116
# 10. Malunion and nonunion of fracture: 1.112
#
# Cardiac arrest changed from rank 9 to 12
#
# Hypertrophy of breast (Gynecomastia) changed from rank 1 to 12
#
# Sleep disorders changed from rank 5 to 12
#
# Celiac disease changed from rank 12 to 3
#
# Peripheral vascular disease, unspecified changed from rank 12 to 2
#
# Atopic/contact dermatitis due to other or unspecified changed from rank 12 to 5
#
# Chronic tonsillitis and adenoiditis changed from rank 2 to 12
#
# Other tests changed from rank 12 to 1
#
# Inflammation of eyelids changed from rank 3 to 12
#
# Perforation of tympanic membrane changed from rank 4 to 7
#
# Hemangioma and lymphangioma, any site changed from rank 12 to 6
#
# Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue changed from rank 12 to 9
#
# Right bundle branch block changed from rank 12 to 4
#
# Malunion and nonunion of fracture changed from rank 7 to 10
#
# Redundant prepuce and phimosis/BXO changed from rank 8 to 12
#
# Signature 4:
#
# Initial top diseases:
# 1. Other upper respiratory disease: 1.031
# 2. Chronic sinusitis: 0.914
# 3. Septal Deviations/Turbinate Hypertrophy: 0.899
# 4. Chronic pharyngitis and nasopharyngitis: 0.891
# 5. Nasal polyps: 0.854
# 6. Strabismus (not specified as paralytic): -1.842
# 7. Enthesopathy: -1.842
# 8. Hemangioma and lymphangioma, any site: -1.843
# 9. Retinal detachment with retinal defect: -1.844
# 10. Other acquired deformities of limbs: -1.854
#
# Final top diseases:
# 1. Other upper respiratory disease: 1.018
# 2. Chronic sinusitis: 0.898
# 3. Septal Deviations/Turbinate Hypertrophy: 0.890
# 4. Nasal polyps: 0.886
# 5. Chronic pharyngitis and nasopharyngitis: 0.857
# 6. Hemangioma and lymphangioma, any site: -1.738
# 7. Enthesopathy: -1.771
# 8. Other acquired deformities of limbs: -1.786
# 9. Retinal detachment with retinal defect: -1.804
# 10. Other disorders of biliary tract: -1.805
#
# Strabismus (not specified as paralytic) changed from rank 6 to 12
#
# Signature 5:
#
# Initial top diseases:
# 1. Coronary atherosclerosis: 1.204
# 2. Unstable angina (intermediate coronary syndrome): 0.914
# 3. Other acute and subacute forms of ischemic heart disease: 0.912
# 4. Angina pectoris: 0.368
# 5. Myocardial infarction: 0.289
# 6. Other chronic ischemic heart disease, unspecified: 0.174
# 7. Hypercholesterolemia: -1.026
# 8. Paroxysmal supraventricular tachycardia: -1.773
# 9. Disease of tricuspid valve: -1.822
# 10. Uterine/Uterovaginal prolapse: -1.831
#
# Final top diseases:
# 1. Coronary atherosclerosis: 1.262
# 2. Hypercholesterolemia: 1.176
# 3. Other acute and subacute forms of ischemic heart disease: 1.140
# 4. Angina pectoris: 0.957
# 5. Unstable angina (intermediate coronary syndrome): 0.837
# 6. Myocardial infarction: 0.808
# 7. Other chronic ischemic heart disease, unspecified: 0.791
# 8. Paroxysmal supraventricular tachycardia: -1.742
# 9. Allergic rhinitis: -1.803
# 10. Bronchiectasis: -1.812
#
# Allergic rhinitis changed from rank 12 to 9
#
# Disease of tricuspid valve changed from rank 9 to 12
#
# Unstable angina (intermediate coronary syndrome) changed from rank 2 to 5
#
# Hypercholesterolemia changed from rank 7 to 2
#
# Signature 6:
#
# Initial top diseases:
# 1. Secondary malignancy of lymph nodes: 1.084
# 2. Malignant neoplasm, other: 1.049
# 3. Secondary malignant neoplasm of digestive systems: 1.003
# 4. Cancer of bronchus; lung: 0.999
# 5. Secondary malignant neoplasm of liver: 0.995
# 6. Secondary malignant neoplasm: 0.969
# 7. Secondary malignancy of bone: 0.935
# 8. Secondary malignancy of respiratory organs: 0.773
# 9. Other non-epithelial cancer of skin: -1.814
# 10. Bacterial pneumonia: -1.828
#
# Final top diseases:
# 1. Secondary malignancy of lymph nodes: 1.125
# 2. Secondary malignant neoplasm of liver: 1.077
# 3. Cancer of bronchus; lung: 1.034
# 4. Secondary malignant neoplasm: 1.028
# 5. Secondary malignant neoplasm of digestive systems: 1.000
# 6. Malignant neoplasm, other: 0.961
# 7. Secondary malignancy of bone: 0.945
# 8. Secondary malignancy of respiratory organs: 0.705
# 9. Other disorders of the kidney and ureters: -1.740
# 10. Inflammation of eyelids: -1.781
#
# Other non-epithelial cancer of skin changed from rank 9 to 12
#
# Malignant neoplasm, other changed from rank 2 to 6
#
# Secondary malignant neoplasm of liver changed from rank 5 to 2
#
# Other disorders of the kidney and ureters changed from rank 12 to 9
#
# Signature 7:
#
# Initial top diseases:
# 1. Abdominal pain: 1.036
# 2. Spondylosis and allied disorders: 1.002
# 3. Rheumatism, unspecified and fibrositis: 0.930
# 4. Cervicalgia: 0.859
# 5. Other inflammatory spondylopathies: 0.855
# 6. Other chronic nonalcoholic liver disease: 0.828
# 7. Sleep apnea: 0.816
# 8. Myalgia and myositis unspecified: 0.788
# 9. Migraine: 0.702
# 10. Other disorders of soft tissues: 0.573
#
# Final top diseases:
# 1. Migraine: 1.239
# 2. Myalgia and myositis unspecified: 1.168
# 3. Osteoporosis NOS: 1.116
# 4. Abdominal pain: 1.046
# 5. Cervicalgia: 1.040
# 6. Other disorders of bone and cartilage: 1.002
# 7. Asthma: 0.989
# 8. Rheumatism, unspecified and fibrositis: 0.983
# 9. Hyperlipidemia: 0.973
# 10. Spondylosis and allied disorders: 0.956
#
# Sleep apnea changed from rank 7 to 12
#
# Migraine changed from rank 9 to 1
#
# Osteoporosis NOS changed from rank 12 to 3
#
# Other chronic nonalcoholic liver disease changed from rank 6 to 12
#
# Myalgia and myositis unspecified changed from rank 8 to 2
#
# Abdominal pain changed from rank 1 to 4
#
# Asthma changed from rank 12 to 7
#
# Other inflammatory spondylopathies changed from rank 5 to 12
#
# Spondylosis and allied disorders changed from rank 2 to 10
#
# Hyperlipidemia changed from rank 12 to 9
#
# Rheumatism, unspecified and fibrositis changed from rank 3 to 8
#
# Other disorders of bone and cartilage changed from rank 12 to 6
#
# Signature 8:
#
# Initial top diseases:
# 1. Cervicitis and endocervicitis: 1.250
# 2. Malignant neoplasm of uterus: 1.146
# 3. Dysmenorrhea: 1.105
# 4. Uterine/Uterovaginal prolapse: 1.036
# 5. Noninflammatory disorders of cervix: 1.033
# 6. Endometrial hyperplasia: 0.985
# 7. Polyp of corpus uteri: 0.966
# 8. Pain and other symptoms associated with female genital organs: 0.951
# 9. Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: 0.949
# 10. Noninflammatory disorders of vagina: 0.934
#
# Final top diseases:
# 1. Cervicitis and endocervicitis: 1.336
# 2. Ovarian cyst: 1.251
# 3. Polyp of corpus uteri: 1.173
# 4. Noninflammatory disorders of cervix: 1.132
# 5. Excessive or frequent menstruation: 1.124
# 6. Endometrial hyperplasia: 1.117
# 7. Malignant neoplasm of uterus: 1.108
# 8. Noninflammatory disorders of vagina: 1.106
# 9. Uterine/Uterovaginal prolapse: 1.084
# 10. Pain and other symptoms associated with female genital organs: 1.083
#
# Uterine/Uterovaginal prolapse changed from rank 4 to 9
#
# Polyp of corpus uteri changed from rank 7 to 3
#
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] changed from rank 9 to 12
#
# Malignant neoplasm of uterus changed from rank 2 to 7
#
# Excessive or frequent menstruation changed from rank 12 to 5
#
# Dysmenorrhea changed from rank 3 to 12
#
# Ovarian cyst changed from rank 12 to 2
#
# Signature 9:
#
# Initial top diseases:
# 1. Displacement of intervertebral disc: 1.135
# 2. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.065
# 3. Neuralgia, neuritis, and radiculitis NOS: 1.007
# 4. Other and unspecified disc disorder: 0.968
# 5. Degenerative disease of the spinal cord: 0.961
# 6. Degeneration of intervertebral disc: 0.952
# 7. Spinal stenosis: 0.848
# 8. Acquired spondylolisthesis: 0.836
# 9. Spondylosis without myelopathy: 0.819
# 10. Kyphoscoliosis and scoliosis: 0.733
#
# Final top diseases:
# 1. Back pain: 1.341
# 2. Displacement of intervertebral disc: 1.120
# 3. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.113
# 4. Neuralgia, neuritis, and radiculitis NOS: 1.064
# 5. Other and unspecified disc disorder: 1.004
# 6. Degenerative disease of the spinal cord: 0.998
# 7. Spondylosis without myelopathy: 0.985
# 8. Kyphoscoliosis and scoliosis: 0.931
# 9. Acquired spondylolisthesis: 0.907
# 10. Spinal stenosis: 0.897
#
# Back pain changed from rank 12 to 1
#
# Spinal stenosis changed from rank 7 to 10
#
# Degeneration of intervertebral disc changed from rank 6 to 12
#
# Signature 10:
#
# Initial top diseases:
# 1. Myopia: 1.212
# 2. Retinal vascular changes and abnomalities: 1.084
# 3. Other retinal disorders: 1.000
# 4. Primary open angle glaucoma: 0.917
# 5. Retinal detachments and defects: 0.878
# 6. Glaucoma: 0.873
# 7. Disorders of vitreous body: 0.816
# 8. Macular degeneration (senile) of retina NOS: 0.810
# 9. Retinal detachment with retinal defect: 0.810
# 10. Senile cataract: 0.098
#
# Final top diseases:
# 1. Primary open angle glaucoma: 1.239
# 2. Macular degeneration (senile) of retina NOS: 1.231
# 3. Retinal vascular changes and abnomalities: 1.193
# 4. Other retinal disorders: 1.173
# 5. Myopia: 1.154
# 6. Glaucoma: 1.074
# 7. Senile cataract: 1.070
# 8. Disorders of vitreous body: 0.992
# 9. Cataract: 0.939
# 10. Retinal detachment with retinal defect: 0.871
#
# Retinal detachments and defects changed from rank 5 to 12
#
# Macular degeneration (senile) of retina NOS changed from rank 8 to 2
#
# Primary open angle glaucoma changed from rank 4 to 1
#
# Cataract changed from rank 12 to 9
#
# Senile cataract changed from rank 10 to 7
#
# Myopia changed from rank 1 to 5
#
# Signature 11:
#
# Initial top diseases:
# 1. Cerebral artery occlusion, with cerebral infarction: 1.122
# 2. Late effects of cerebrovascular disease: 0.991
# 3. Hemiplegia: 0.961
# 4. Transient cerebral ischemia: 0.903
# 5. Cerebrovascular disease: 0.899
# 6. Cerebral ischemia: 0.883
# 7. Occlusion of cerebral arteries: 0.869
# 8. Occlusion and stenosis of precerebral arteries: 0.823
# 9. Mitral valve disease: -1.810
# 10. Scar conditions and fibrosis of skin: -1.811
#
# Final top diseases:
# 1. Occlusion of cerebral arteries: 1.165
# 2. Late effects of cerebrovascular disease: 1.092
# 3. Cerebral ischemia: 1.080
# 4. Cerebral artery occlusion, with cerebral infarction: 1.057
# 5. Hemiplegia: 1.055
# 6. Cerebrovascular disease: 0.930
# 7. Transient cerebral ischemia: 0.908
# 8. Occlusion and stenosis of precerebral arteries: 0.885
# 9. Retinal detachment with retinal defect: -1.759
# 10. Scar conditions and fibrosis of skin: -1.765
#
# Occlusion of cerebral arteries changed from rank 7 to 1
#
# Cerebral artery occlusion, with cerebral infarction changed from rank 1 to 4
#
# Cerebral ischemia changed from rank 6 to 3
#
# Transient cerebral ischemia changed from rank 4 to 7
#
# Retinal detachment with retinal defect changed from rank 12 to 9
#
# Mitral valve disease changed from rank 9 to 12
#
# Signature 12:
#
# Initial top diseases:
# 1. Renal colic: 1.190
# 2. Calculus of ureter: 1.044
# 3. Stricture/obstruction of ureter: 1.039
# 4. Hydronephrosis: 1.015
# 5. Other disorders of the kidney and ureters: 0.969
# 6. Calculus of kidney: 0.890
# 7. Pyelonephritis: 0.849
# 8. Streptococcus infection: -1.782
# 9. Duodenitis: -1.823
# 10. Other upper respiratory disease: -1.864
#
# Final top diseases:
# 1. Renal colic: 1.238
# 2. Hydronephrosis: 1.072
# 3. Stricture/obstruction of ureter: 1.042
# 4. Other disorders of the kidney and ureters: 1.025
# 5. Calculus of ureter: 1.000
# 6. Calculus of kidney: 0.938
# 7. Pyelonephritis: 0.878
# 8. Streptococcus infection: -1.804
# 9. Occlusion of cerebral arteries: -1.815
# 10. Chronic Kidney Disease, Stage III: -1.831
#
# Occlusion of cerebral arteries changed from rank 12 to 9
#
# Calculus of ureter changed from rank 2 to 5
#
# Duodenitis changed from rank 9 to 12
#
# Signature 13:
#
# Initial top diseases:
# 1. Cystitis: 1.257
# 2. Urethral stricture (not specified as infectious): 1.229
# 3. Cancer of prostate: 1.140
# 4. Urinary incontinence: 1.095
# 5. Other symptoms/disorders or the urinary system: 1.084
# 6. Other disorders of bladder: 0.959
# 7. Bladder neck obstruction: 0.929
# 8. Functional disorders of bladder: 0.922
# 9. Hyperplasia of prostate: 0.919
# 10. Chronic cystitis: 0.914
#
# Final top diseases:
# 1. Urethral stricture (not specified as infectious): 1.272
# 2. Cancer of prostate: 1.228
# 3. Cystitis: 1.222
# 4. Other disorders of bladder: 1.076
# 5. Other symptoms/disorders or the urinary system: 1.074
# 6. Malignant neoplasm of bladder: 1.043
# 7. Urinary incontinence: 1.022
# 8. Chronic cystitis: 0.979
# 9. Hyperplasia of prostate: 0.941
# 10. Functional disorders of bladder: 0.916
#
# Malignant neoplasm of bladder changed from rank 12 to 6
#
# Bladder neck obstruction changed from rank 7 to 12
#
# Urinary incontinence changed from rank 4 to 7
#
# Signature 14:
#
# Initial top diseases:
# 1. Bronchiectasis: 1.044
# 2. Empyema and pneumothorax: 1.039
# 3. Emphysema: 0.970
# 4. Postinflammatory pulmonary fibrosis: 0.798
# 5. Pneumonia: 0.740
# 6. Obstructive chronic bronchitis: 0.630
# 7. Tobacco use disorder: 0.507
# 8. Pneumococcal pneumonia: 0.440
# 9. Respiratory failure: 0.427
# 10. Chronic airway obstruction: 0.278
#
# Final top diseases:
# 1. Empyema and pneumothorax: 1.109
# 2. Emphysema: 1.080
# 3. Pneumonia: 1.042
# 4. Obstructive chronic bronchitis: 0.935
# 5. Bronchiectasis: 0.923
# 6. Pneumococcal pneumonia: 0.902
# 7. Chronic airway obstruction: 0.834
# 8. Postinflammatory pulmonary fibrosis: 0.784
# 9. Tobacco use disorder: 0.783
# 10. Respiratory failure: 0.777
#
# Chronic airway obstruction changed from rank 10 to 7
#
# Bronchiectasis changed from rank 1 to 5
#
# Postinflammatory pulmonary fibrosis changed from rank 4 to 8
#
# Signature 15:
#
# Initial top diseases:
# 1. Type 2 diabetes with ophthalmic manifestations: 1.132
# 2. Hypoglycemia: 1.112
# 3. Diabetic retinopathy: 0.992
# 4. Type 1 diabetes: 0.938
# 5. Type 2 diabetes: 0.626
# 6. Sleep disorders: -1.790
# 7. Diseases and other conditions of the tongue: -1.843
# 8. Pleurisy; pleural effusion: -1.844
# 9. Scar conditions and fibrosis of skin: -1.852
# 10. Streptococcus infection: -1.859
#
# Final top diseases:
# 1. Hypoglycemia: 1.243
# 2. Type 2 diabetes with ophthalmic manifestations: 1.161
# 3. Diabetic retinopathy: 0.999
# 4. Type 1 diabetes: 0.985
# 5. Type 2 diabetes: 0.945
# 6. Pleurisy; pleural effusion: -1.746
# 7. Lipoma of skin and subcutaneous tissue: -1.779
# 8. Disorders of uterus, NEC: -1.794
# 9. First degree AV block: -1.804
# 10. Sleep disorders: -1.806
#
# Sleep disorders changed from rank 6 to 10
#
# Disorders of uterus, NEC changed from rank 12 to 8
#
# Scar conditions and fibrosis of skin changed from rank 9 to 12
#
# Lipoma of skin and subcutaneous tissue changed from rank 12 to 7
#
# Diseases and other conditions of the tongue changed from rank 7 to 12
#
# First degree AV block changed from rank 12 to 9
#
# Signature 16:
#
# Initial top diseases:
# 1. Staphylococcus infections: 1.092
# 2. Peritonitis and retroperitoneal infections: 1.077
# 3. Chronic ulcer of skin: 0.908
# 4. Streptococcus infection: 0.880
# 5. Bacterial pneumonia: 0.829
# 6. Other diseases of respiratory system, NEC: 0.802
# 7. Hypovolemia: 0.787
# 8. Sepsis: 0.739
# 9. Other local infections of skin and subcutaneous tissue: 0.723
# 10. Thrombocytopenia: 0.666
#
# Final top diseases:
# 1. E. coli: 1.103
# 2. Other diseases of respiratory system, NEC: 1.082
# 3. Hypotension NOS: 1.081
# 4. Hyperpotassemia: 1.063
# 5. Chronic ulcer of skin: 1.055
# 6. Peritonitis and retroperitoneal infections: 1.054
# 7. Gram negative septicemia: 1.051
# 8. Bacterial pneumonia: 1.040
# 9. Cellulitis and abscess of arm/hand: 1.029
# 10. Other local infections of skin and subcutaneous tissue: 1.025
#
# Gram negative septicemia changed from rank 12 to 7
#
# Staphylococcus infections changed from rank 1 to 12
#
# Streptococcus infection changed from rank 4 to 12
#
# E. coli changed from rank 12 to 1
#
# Peritonitis and retroperitoneal infections changed from rank 2 to 6
#
# Hypotension NOS changed from rank 12 to 3
#
# Sepsis changed from rank 8 to 12
#
# Cellulitis and abscess of arm/hand changed from rank 12 to 9
#
# Bacterial pneumonia changed from rank 5 to 8
#
# Other diseases of respiratory system, NEC changed from rank 6 to 2
#
# Hyperpotassemia changed from rank 12 to 4
#
# Hypovolemia changed from rank 7 to 12
#
# Signature 17:
#
# Initial top diseases:
# 1. Ventral hernia: 1.150
# 2. Neoplasm of unspecified nature of digestive system: 0.974
# 3. Other disorders of intestine: 0.951
# 4. Hemorrhage of rectum and anus: 0.937
# 5. Ulcerative colitis: 0.917
# 6. Regional enteritis: 0.912
# 7. Hemorrhage of gastrointestinal tract: 0.898
# 8. Gastrointestinal complications: 0.882
# 9. Noninfectious gastroenteritis: 0.788
# 10. Colon cancer: 0.757
#
# Final top diseases:
# 1. Benign neoplasm of colon: 1.156
# 2. Regional enteritis: 1.147
# 3. Hemorrhage of gastrointestinal tract: 1.140
# 4. Neoplasm of unspecified nature of digestive system: 1.092
# 5. Ventral hernia: 1.080
# 6. Hemorrhage of rectum and anus: 1.076
# 7. Hemorrhoids: 1.058
# 8. Noninfectious gastroenteritis: 1.024
# 9. Colon cancer: 1.008
# 10. Other disorders of intestine: 1.006
#
# Ventral hernia changed from rank 1 to 5
#
# Regional enteritis changed from rank 6 to 2
#
# Ulcerative colitis changed from rank 5 to 12
#
# Hemorrhoids changed from rank 12 to 7
#
# Other disorders of intestine changed from rank 3 to 10
#
# Gastrointestinal complications changed from rank 8 to 12
#
# Hemorrhage of gastrointestinal tract changed from rank 7 to 3
#
# Benign neoplasm of colon changed from rank 12 to 1
#
# Signature 18:
#
# Initial top diseases:
# 1. Other disorders of gallbladder: 1.191
# 2. Acute pancreatitis: 1.081
# 3. Cholelithiasis with acute cholecystitis: 1.078
# 4. Calculus of bile duct: 1.041
# 5. Other disorders of biliary tract: 1.003
# 6. Cholecystitis without cholelithiasis: 0.993
# 7. Cholelithiasis: 0.925
# 8. Peritoneal adhesions (postoperative) (postinfection): 0.902
# 9. Cholelithiasis with other cholecystitis: 0.895
# 10. Noninflammatory disorders of cervix: -1.836
#
# Final top diseases:
# 1. Other disorders of gallbladder: 1.293
# 2. Peritoneal adhesions (postoperative) (postinfection): 1.167
# 3. Cholelithiasis with acute cholecystitis: 1.164
# 4. Acute pancreatitis: 1.064
# 5. Calculus of bile duct: 1.045
# 6. Cholelithiasis: 1.019
# 7. Cholelithiasis with other cholecystitis: 0.989
# 8. Other disorders of biliary tract: 0.966
# 9. Cholecystitis without cholelithiasis: 0.956
# 10. Other disorders of stomach and duodenum: -1.775
#
# Peritoneal adhesions (postoperative) (postinfection) changed from rank 8 to 2
#
# Cholecystitis without cholelithiasis changed from rank 6 to 9
#
# Other disorders of biliary tract changed from rank 5 to 8
#
# Signature 19:
#
# Initial top diseases:
# 1. Chronic glomerulonephritis, NOS: 1.230
# 2. Seborrheic keratosis: 1.192
# 3. Other disorders of eyelids: 1.177
# 4. Disorders of lacrimal system: 1.119
# 5. Breast cancer [female]: 1.110
# 6. Hypertensive chronic kidney disease: 1.108
# 7. Renal failure NOS: 1.049
# 8. Ectropion or entropion: 1.042
# 9. Viral warts & HPV: 1.039
# 10. Malignant neoplasm of female breast: 1.021
#
# Final top diseases:
# 1. Thyrotoxicosis with or without goiter: 1.213
# 2. Other disorders of eyelids: 1.200
# 3. Seborrheic keratosis: 1.189
# 4. Other non-epithelial cancer of skin: 1.153
# 5. Chronic glomerulonephritis, NOS: 1.152
# 6. Actinic keratosis: 1.082
# 7. Chronic Kidney Disease, Stage III: 1.070
# 8. Breast cancer [female]: 1.052
# 9. Hypertensive chronic kidney disease: 1.023
# 10. Disorders of lacrimal system: 1.023
#
# Viral warts & HPV changed from rank 9 to 12
#
# Other non-epithelial cancer of skin changed from rank 12 to 4
#
# Breast cancer [female] changed from rank 5 to 8
#
# Ectropion or entropion changed from rank 8 to 12
#
# Disorders of lacrimal system changed from rank 4 to 10
#
# Chronic glomerulonephritis, NOS changed from rank 1 to 5
#
# Renal failure NOS changed from rank 7 to 12
#
# Actinic keratosis changed from rank 12 to 6
#
# Chronic Kidney Disease, Stage III changed from rank 12 to 7
#
# Thyrotoxicosis with or without goiter changed from rank 12 to 1
#
# Hypertensive chronic kidney disease changed from rank 6 to 9
#
# Signature 20:
#
# Initial top diseases:
# 1. Endometrial hyperplasia: -4.804
# 2. Noninfectious gastroenteritis: -4.813
# 3. Other upper respiratory disease: -4.827
# 4. Dyspareunia: -4.841
# 5. Melanomas of skin: -4.842
# 6. Chronic ulcer of skin: -4.843
# 7. Angina pectoris: -4.850
# 8. Major depressive disorder: -4.861
# 9. Orthostatic hypotension: -4.871
# 10. Pain and other symptoms associated with female genital organs: -4.874
#
# Final top diseases:
# 1. Endometrial hyperplasia: -4.733
# 2. Noninfectious gastroenteritis: -4.775
# 3. Other upper respiratory disease: -4.796
# 4. Aortic valve disease: -4.811
# 5. Myalgia and myositis unspecified: -4.819
# 6. Angina pectoris: -4.823
# 7. Urethral stricture (not specified as infectious): -4.835
# 8. Major depressive disorder: -4.841
# 9. Dyspareunia: -4.842
# 10. Chronic ulcer of skin: -4.846
#
# Melanomas of skin changed from rank 5 to 12
#
# Dyspareunia changed from rank 4 to 9
#
# Orthostatic hypotension changed from rank 9 to 12
#
# Myalgia and myositis unspecified changed from rank 12 to 5
#
# Chronic ulcer of skin changed from rank 6 to 10
#
# Aortic valve disease changed from rank 12 to 4
#
# Urethral stricture (not specified as infectious) changed from rank 12 to 7

# %%
model.K=21

# %%
def plot_psi_heatmap(model, disease_names=None, figsize=(12, 8)):
    """
    Plot heatmap of psi values (signature-disease associations)
    
    Args:
        model: The trained model containing psi parameter
        disease_names: Optional list of disease names
        figsize: Tuple specifying figure size
    """
    plt.figure(figsize=figsize)
    
    # Get psi values from model
    psi = model.psi.detach().numpy()
    
    # Create heatmap
    im = plt.imshow(psi, aspect='auto', cmap='RdBu_r', vmin=-5, vmax=5)
    
    # Add colorbar
    plt.colorbar(im, label='ψ value')
    
    # Labels
    plt.xlabel('Disease')
    plt.ylabel('Signature')
    plt.title('ψ (Signature-Disease Associations)')
    
    # Optional: Add disease names if provided
    if disease_names is not None:
        plt.xticks(range(len(disease_names)), disease_names, 
                  rotation=90, fontsize=8)
    
    # Signature labels
    plt.yticks(range(psi.shape[0]), [f'Signature {i}' for i in range(psi.shape[0])])
    
    plt.tight_layout()
    plt.show()

# Usage:
plot_psi_heatmap(model, disease_names=essentials['disease_names'])  # if you have disease names
# or simply:
# plot_psi_heatmap(model)

# %%
# For the notebook with kappa:
psi = model.psi.detach().numpy()
print("Psi with kappa:")
print(f"min={psi.min():.3f}, max={psi.max():.3f}")
print(f"mean={psi.mean():.3f}, std={psi.std():.3f}")
print(f"max={psi.max():.3f}, std={psi.std():.3f}")
# Quick histogram
plt.figure(figsize=(8, 4))
plt.hist(psi.flatten(), bins=50)
plt.title('Distribution of ψ values (with κ)')
plt.xlabel('ψ value')
plt.ylabel('Count')
plt.show()

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    # Get diagnosis times for this patient
    diagnoses = model.Y[patient]  # Shape: [D, T]
    diagnosis_times = []
    for d in range(model.D):
        diag_time = torch.where(diagnoses[d])[0]
        if len(diag_time) > 0:
            diagnosis_times.append(diag_time[0].item())
            
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')
    
    # Add vertical lines for diagnoses
    for t in diagnosis_times:
        ax1.axvline(x=t, color='red', alpha=0.2, linestyle=':')
        ax2.axvline(x=t, color='red', alpha=0.2, linestyle=':')

# Customize plots
ax1.set_title('Final Lambda Values')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Final Proportions')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects and top states
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")

# %%
model_save_path='/Users/sarahurbut/Dropbox (Personal)/model_with_kappa_bigam.pt'
torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'initial_phi': initial_phi, 
    'initial_lambda': initial_lambda, 
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t': essentials['prevalence_t'],
    'logit_prevalence_t': model.logit_prev_t,
    'G': G_100k,
    'E': E_100k,
    'indices': indices,
    'disease_names': essentials['disease_names'],
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T': Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, model_save_path)

# %%
n_samples = 2
sample_patients = [4376, 6640]
n_top_states = 5

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]
patient_props = torch.softmax(lambda_patients, dim=1)
mean_props = patient_props.mean(dim=-1)
top_states = mean_props.topk(n_top_states, dim=-1).indices

# Color map for states
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    # Get diagnosis times and associated clusters
    diagnoses = model.Y[patient]  # Shape: [D, T]
    for d in range(model.D):
        diag_times = torch.where(diagnoses[d])[0]
        if len(diag_times) > 0:
            diag_time = diag_times[0].item()
            # Get cluster assignment for this disease
            cluster = model.clusters[d]
            # Use cluster's color for the vertical line
            ax1.axvline(x=diag_time, color=colors[cluster], alpha=0.5, linestyle=':', 
                       label=f'Disease {d} (Cluster {cluster})')
            ax2.axvline(x=diag_time, color=colors[cluster], alpha=0.5, linestyle=':')
            
    # Plot lambda trajectories
    for j, k in enumerate(top_states[i]):
        k = k.item()
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'State {k}')
        
        # Plot proportions
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'State {k}')

# Customize plots
ax1.set_title(f'Lambda Values for Patient {patient}')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Signature Proportions')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the RDS file
readRDS = robjects.r['readRDS']
pce_data = readRDS('/Users/sarahurbut/Dropbox (Personal)/pce_df_prevent.rds')
pce_df = pandas2ri.rpy2py(pce_data)  # Convert to pandas DataFrame

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import numpy as np
import matplotlib.pyplot as plt

def plot_roc_curve(y_true, y_pred, label):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    plt.plot(fpr, tpr, label=label)

# %%
Y.shape
# Out:
# (10000, 348, 52)

# %% [markdown]
# # Now plot using just the time point (ie not accumulated)

# %%
def compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116]):
    """
    Compare 10-year predictions using single timepoint prediction
    """
    our_10yr_risks = []
    actual_10yr = []

    # Get predictions
    pi = model.forward()[0].detach().numpy()
    
    # Get mean risks across patients for calibration
    predicted_risk_2d = pi.mean(axis=0)  # Shape: [D, T]
    observed_risk_2d = model.Y.numpy().mean(axis=0)  # Shape: [D, T]
    
    # Sort and get LOESS calibration curve
    pred_flat = predicted_risk_2d.flatten()
    obs_flat = observed_risk_2d.flatten()
    sort_idx = np.argsort(pred_flat)
    smoothed = lowess(obs_flat[sort_idx], pred_flat[sort_idx], frac=0.3)
    
    # Apply calibration to all predictions using interpolation
    pi_calibrated = np.interp(pi.flatten(), smoothed[:, 0], smoothed[:, 1]).reshape(pi.shape)
    
    # Calculate 10-year risks using only enrollment time prediction
    for patient_idx, row in enumerate(pce_df.itertuples()):
        enroll_time = int(row.age - 30)
        if enroll_time + 10 >= model.T:
            continue
            
        # Only use predictions at enrollment time
        pi_ascvd = pi_calibrated[patient_idx, ascvd_indices, enroll_time]
        
        # Calculate 1-year risk first
        yearly_risk = 1 - np.prod(1 - pi_ascvd)
        
        # Convert to 10-year risk
        risk = 1 - (1 - yearly_risk)**10
        our_10yr_risks.append(risk)
        
        # Still look at actual events over 10 years
        Y_ascvd = model.Y[patient_idx, ascvd_indices, enroll_time:enroll_time+10]
        actual = torch.any(torch.any(Y_ascvd, dim=0))
        actual_10yr.append(actual.item())
   
    # Rest of the function remains the same
    our_10yr_risks = np.array(our_10yr_risks)
    actual_10yr = np.array(actual_10yr)
    pce_risks = pce_df['pce_goff_fuull'].values[:len(our_10yr_risks)]
    
    # Calculate ROC AUCs
    our_auc = roc_auc_score(actual_10yr, our_10yr_risks)
    pce_auc = roc_auc_score(actual_10yr, pce_risks)
    
    print(f"\nROC AUC Comparison (10-year prediction from enrollment):")
    print(f"Our model: {our_auc:.3f}")
    print(f"PCE: {pce_auc:.3f}")
    
    plt.figure(figsize=(8,6))
    plot_roc_curve(actual_10yr, our_10yr_risks, label=f'Our Model (AUC={our_auc:.3f})')
    plot_roc_curve(actual_10yr, pce_risks, label=f'PCE (AUC={pce_auc:.3f})')
    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for 10-year ASCVD Prediction')
    plt.legend()
    plt.grid(True)
    plt.show()

compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116])
# Out:
# ROC AUC Comparison (10-year prediction from enrollment):
# Our model: 0.685
# PCE: 0.678

# %% [markdown]
# # omit missing

# %%
def compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116]):
    """
    Compare 10-year predictions using single timepoint prediction, handling missing PCE values
    """
    our_10yr_risks = []
    actual_10yr = []

    # Get predictions
    pi = model.forward()[0].detach().numpy()
    
    # Get mean risks across patients for calibration
    predicted_risk_2d = pi.mean(axis=0)  # Shape: [D, T]
    observed_risk_2d = model.Y.numpy().mean(axis=0)  # Shape: [D, T]
    
    # Sort and get LOESS calibration curve
    pred_flat = predicted_risk_2d.flatten()
    obs_flat = observed_risk_2d.flatten()
    sort_idx = np.argsort(pred_flat)
    smoothed = lowess(obs_flat[sort_idx], pred_flat[sort_idx], frac=0.3)
    
    # Apply calibration to all predictions using interpolation
    pi_calibrated = np.interp(pi.flatten(), smoothed[:, 0], smoothed[:, 1]).reshape(pi.shape)
    
    # Calculate 10-year risks using only enrollment time prediction
    for patient_idx, row in enumerate(pce_df.itertuples()):
        enroll_time = int(row.age - 30)
        if enroll_time + 10 >= model.T:
            continue
            
        # Only use predictions at enrollment time
        pi_ascvd = pi_calibrated[patient_idx, ascvd_indices, enroll_time]
        
        # Calculate 1-year risk first
        yearly_risk = 1 - np.prod(1 - pi_ascvd)
        
        # Convert to 10-year risk
        risk = 1 - (1 - yearly_risk)**10
        our_10yr_risks.append(risk)
        
        # Still look at actual events over 10 years
        Y_ascvd = model.Y[patient_idx, ascvd_indices, enroll_time:enroll_time+10]
        actual = torch.any(torch.any(Y_ascvd, dim=0))
        actual_10yr.append(actual.item())
   
    our_10yr_risks = np.array(our_10yr_risks)
    actual_10yr = np.array(actual_10yr)
    pce_risks = pce_df['pce_goff'].values[:len(our_10yr_risks)]

    # Get indices of non-missing PCE values
    non_missing_idx = ~np.isnan(pce_risks)

    # Filter all arrays to only include non-missing cases
    our_10yr_risks_filtered = our_10yr_risks[non_missing_idx]
    actual_10yr_filtered = actual_10yr[non_missing_idx]
    pce_risks_filtered = pce_risks[non_missing_idx]

    # Calculate ROC AUCs on filtered data
    our_auc = roc_auc_score(actual_10yr_filtered, our_10yr_risks_filtered)
    pce_auc = roc_auc_score(actual_10yr_filtered, pce_risks_filtered)

    # Print results with sample size info
    n_total = len(our_10yr_risks)
    n_complete = len(our_10yr_risks_filtered)
    print(f"\nROC AUC Comparison (10-year prediction from enrollment):")
    print(f"Sample size: {n_complete}/{n_total} ({n_complete/n_total*100:.1f}% complete cases)")
    print(f"Our model: {our_auc:.3f}")
    print(f"PCE: {pce_auc:.3f}")
    
    plt.figure(figsize=(8,6))
    plot_roc_curve(actual_10yr_filtered, our_10yr_risks_filtered, label=f'Our Model (AUC={our_auc:.3f})')
    plot_roc_curve(actual_10yr_filtered, pce_risks_filtered, label=f'PCE (AUC={pce_auc:.3f})')
    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for 10-year ASCVD Prediction')
    plt.legend()
    plt.grid(True)
    plt.show()

    return our_10yr_risks_filtered, actual_10yr_filtered, pce_risks_filtered

# %%
compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116])

# %% [markdown]
# # with prevent

# %%
def compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116]):
    """
    Compare 10-year predictions using single timepoint prediction, handling missing PCE values
    """
    our_10yr_risks = []
    actual_10yr = []

    # Get predictions
    pi = model.forward()[0].detach().numpy()
    
    # Get mean risks across patients for calibration
    predicted_risk_2d = pi.mean(axis=0)  # Shape: [D, T]
    observed_risk_2d = model.Y.numpy().mean(axis=0)  # Shape: [D, T]
    
    # Sort and get LOESS calibration curve
    pred_flat = predicted_risk_2d.flatten()
    obs_flat = observed_risk_2d.flatten()
    sort_idx = np.argsort(pred_flat)
    smoothed = lowess(obs_flat[sort_idx], pred_flat[sort_idx], frac=0.3)
    
    # Apply calibration to all predictions using interpolation
    pi_calibrated = np.interp(pi.flatten(), smoothed[:, 0], smoothed[:, 1]).reshape(pi.shape)
    
    # Calculate 10-year risks using only enrollment time prediction
    for patient_idx, row in enumerate(pce_df.itertuples()):
        enroll_time = int(row.age - 30)
        if enroll_time + 10 >= model.T:
            continue
            
        # Only use predictions at enrollment time
        pi_ascvd = pi_calibrated[patient_idx, ascvd_indices, enroll_time]
        
        # Calculate 1-year risk first
        yearly_risk = 1 - np.prod(1 - pi_ascvd)
        
        # Convert to 10-year risk
        risk = 1 - (1 - yearly_risk)**10
        our_10yr_risks.append(risk)
        
        # Still look at actual events over 10 years
        Y_ascvd = model.Y[patient_idx, ascvd_indices, enroll_time:enroll_time+10]
        actual = torch.any(torch.any(Y_ascvd, dim=0))
        actual_10yr.append(actual.item())
   
    our_10yr_risks = np.array(our_10yr_risks)
    actual_10yr = np.array(actual_10yr)
    pce_risks = pce_df['prevent_base_ascvd_risk'].values[:len(our_10yr_risks)]

    # Get indices of non-missing PCE values
    non_missing_idx = ~np.isnan(pce_risks)

    # Filter all arrays to only include non-missing cases
    our_10yr_risks_filtered = our_10yr_risks[non_missing_idx]
    actual_10yr_filtered = actual_10yr[non_missing_idx]
    pce_risks_filtered = pce_risks[non_missing_idx]

    # Calculate ROC AUCs on filtered data
    our_auc = roc_auc_score(actual_10yr_filtered, our_10yr_risks_filtered)
    pce_auc = roc_auc_score(actual_10yr_filtered, pce_risks_filtered)

    # Print results with sample size info
    n_total = len(our_10yr_risks)
    n_complete = len(our_10yr_risks_filtered)
    print(f"\nROC AUC Comparison (10-year prediction from enrollment):")
    print(f"Sample size: {n_complete}/{n_total} ({n_complete/n_total*100:.1f}% complete cases)")
    print(f"Our model: {our_auc:.3f}")
    print(f"PCE: {pce_auc:.3f}")
    
    plt.figure(figsize=(8,6))
    plot_roc_curve(actual_10yr_filtered, our_10yr_risks_filtered, label=f'Our Model (AUC={our_auc:.3f})')
    plot_roc_curve(actual_10yr_filtered, pce_risks_filtered, label=f'Prevent (AUC={pce_auc:.3f})')
    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for 10-year ASCVD Prediction')
    plt.legend()
    plt.grid(True)
    plt.show()

    return our_10yr_risks_filtered, actual_10yr_filtered, pce_risks_filtered

# %%
compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116])

# %%
def compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116]):
    """
    Compare 10-year predictions using single timepoint prediction
    """
    our_10yr_risks = []
    actual_10yr = []

    # Get predictions
    pi = model.forward()[0].detach().numpy()
    
    # Get mean risks across patients for calibration
    predicted_risk_2d = pi.mean(axis=0)  # Shape: [D, T]
    observed_risk_2d = model.Y.numpy().mean(axis=0)  # Shape: [D, T]
    
    # Sort and get LOESS calibration curve
    pred_flat = predicted_risk_2d.flatten()
    obs_flat = observed_risk_2d.flatten()
    sort_idx = np.argsort(pred_flat)
    smoothed = lowess(obs_flat[sort_idx], pred_flat[sort_idx], frac=0.3)
    
    # Apply calibration to all predictions using interpolation
    pi_calibrated = np.interp(pi.flatten(), smoothed[:, 0], smoothed[:, 1]).reshape(pi.shape)
    
    # Calculate 10-year risks using only enrollment time prediction
    for patient_idx, row in enumerate(pce_df.itertuples()):
        enroll_time = int(row.age - 30)
        if enroll_time + 10 >= model.T:
            continue
            
        # Only use predictions at enrollment time
        pi_ascvd = pi_calibrated[patient_idx, ascvd_indices, enroll_time]
        
        # Calculate 1-year risk first
        yearly_risk = 1 - np.prod(1 - pi_ascvd)
        
        # Convert to 10-year risk
        risk = 1 - (1 - yearly_risk)**10
        our_10yr_risks.append(risk)
        
        # Still look at actual events over 10 years
        Y_ascvd = model.Y[patient_idx, ascvd_indices, enroll_time:enroll_time+10]
        actual = torch.any(torch.any(Y_ascvd, dim=0))
        actual_10yr.append(actual.item())
   
    # Rest of the function remains the same
    our_10yr_risks = np.array(our_10yr_risks)
    actual_10yr = np.array(actual_10yr)
    pce_risks = pce_df['prevent_impute'].values[:len(our_10yr_risks)]
    
    # Calculate ROC AUCs
    our_auc = roc_auc_score(actual_10yr, our_10yr_risks)
    pce_auc = roc_auc_score(actual_10yr, pce_risks)
    
    print(f"\nROC AUC Comparison (10-year prediction from enrollment):")
    print(f"Our model: {our_auc:.3f}")
    print(f"PCE: {pce_auc:.3f}")
    
    plt.figure(figsize=(8,6))
    plot_roc_curve(actual_10yr, our_10yr_risks, label=f'Our Model (AUC={our_auc:.3f})')
    plot_roc_curve(actual_10yr, pce_risks, label=f'PREVENT (AUC={pce_auc:.3f})')
    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for 10-year ASCVD Prediction')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116])

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients].detach()  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Final Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Final Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects for these patients
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]  # Already computed above
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")

# %%
predicted_risk.shape

# %%
# Calculate both calibration methods
# Simple scaling
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
print(scale_factor)
scaled_risk = predicted_risk * scale_factor

# LOESS calibration
loess_risk = lowess(observed_risk, predicted_risk, frac=0.3, return_sorted=False)

# Create comparison plots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# Original predictions
ax1.scatter(observed_risk, predicted_risk, alpha=0.5, s=20)
ax1.plot([0, max(observed_risk)], [0, max(observed_risk)], 'k--', label='x=y line')
ax1.set_title('Original Predictions')
ax1.set_xlabel('Observed Risk')
ax1.set_ylabel('Predicted Risk')
ax1.legend()

# Simple scaling calibration
ax2.scatter(observed_risk, scaled_risk, alpha=0.5, s=20)
ax2.plot([0, max(observed_risk)], [0, max(observed_risk)], 'k--', label='x=y line')
ax2.set_title(f'Simple Scaling (factor={scale_factor:.2f})')
ax2.set_xlabel('Observed Risk')
ax2.set_ylabel('Scaled Risk')
ax2.legend()

# LOESS calibration
ax3.scatter(observed_risk, loess_risk, alpha=0.5, s=20)
ax3.plot([0, max(observed_risk)], [0, max(observed_risk)], 'k--', label='x=y line')
ax3.set_title('LOESS Calibration')
ax3.set_xlabel('Observed Risk')
ax3.set_ylabel('LOESS Calibrated Risk')
ax3.legend()

# Calibration curves comparison
sort_idx = np.argsort(predicted_risk)
pred_sorted = predicted_risk[sort_idx]
obs_sorted = observed_risk[sort_idx]
smoothed = lowess(obs_sorted, pred_sorted, frac=0.3)

ax4.scatter(predicted_risk, observed_risk, alpha=0.3, s=20, label='Data points')
ax4.plot(pred_sorted, pred_sorted * scale_factor, 'g-', label='Simple scaling', linewidth=2)
ax4.plot(smoothed[:, 0], smoothed[:, 1], 'r-', label='LOESS curve', linewidth=2)
ax4.plot([0, max(predicted_risk)], [0, max(predicted_risk)], 'k--', label='x=y line')
ax4.set_title('Calibration Curves Comparison')
ax4.set_xlabel('Predicted Risk')
ax4.set_ylabel('Observed Risk')
ax4.legend()

plt.tight_layout()
plt.show()

# Print performance metrics
from sklearn.metrics import r2_score, mean_squared_error
print("\nPerformance Metrics:")
print(f"Original R²: {r2_score(observed_risk, predicted_risk):.3f}")
print(f"Simple Scaling R²: {r2_score(observed_risk, scaled_risk):.3f}")
print(f"LOESS Calibrated R²: {r2_score(observed_risk, loess_risk):.3f}")
print(f"\nOriginal RMSE: {np.sqrt(mean_squared_error(observed_risk, predicted_risk)):.6f}")
print(f"Simple Scaling RMSE: {np.sqrt(mean_squared_error(observed_risk, scaled_risk)):.6f}")
print(f"LOESS Calibrated RMSE: {np.sqrt(mean_squared_error(observed_risk, loess_risk)):.6f}")

# %%
essentials['prevalence_t']

# %%
# Get μ_dt from checkpoint and predictions

mu_dt = essentials['prevalence_t'] # Shape: (348, 52)
scale_factor = np.mean(mu_dt) / np.mean(predicted_risk_2d)
scaled_risk_2d = predicted_risk_2d * scale_factor

# Create two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Original predictions vs μ_dt
ax1.scatter(mu_dt.flatten(), predicted_risk_2d.flatten(), 
           alpha=0.3, color='blue', s=10)
ax1.plot([0, max(mu_dt.max(), predicted_risk_2d.max())], 
         [0, max(mu_dt.max(), predicted_risk_2d.max())], 
         'k--', label='x=y')
ax1.set_xlabel('Smoothed Prevalence (μ_dt)')
ax1.set_ylabel('Original Predicted Risk')
ax1.set_title('Original Predictions vs Smoothed Prevalence')
ax1.set_xscale('log')
ax1.set_yscale('log')

# Scaled predictions vs μ_dt
ax2.scatter(mu_dt.flatten(), scaled_risk_2d.flatten(), 
           alpha=0.3, color='green', s=10)
ax2.plot([0, max(mu_dt.max(), scaled_risk_2d.max())], 
         [0, max(mu_dt.max(), scaled_risk_2d.max())], 
         'k--', label='x=y')
ax2.set_xlabel('Smoothed Prevalence (μ_dt)')
ax2.set_ylabel('Scaled Predicted Risk')
ax2.set_title(f'Simple Scaling (factor={scale_factor:.2f}) vs Smoothed Prevalence')
ax2.set_xscale('log')
ax2.set_yscale('log')

plt.tight_layout()
plt.show()
