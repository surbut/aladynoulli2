# %%
import sys
import os

# Get the parent directory of current directory
parent_dir = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(parent_dir)

# Now you can import from pyScripts
from oldmarch.cluster_g_logit_init_acceptpsi import *

# %load_ext autoreload

# %%
# %autoreload 2
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

# %%
# Generate and plot
np.random.seed(42)
data = generate_clustered_survival_data(N=10000, D=20, T=50, K=5, P=5)
plot_synthetic_components(data)

# %%
# First generate synthetic data
np.random.seed(42)

# Convert data to tensors for the model
Y_tensor = torch.tensor(data['Y'], dtype=torch.float32)
G_tensor = torch.tensor(data['G'], dtype=torch.float32)
E_tensor = torch.tensor(data['event_times'], dtype=torch.float32)
true_psi = torch.tensor(data['psi'], dtype=torch.float32)

# %%
# Calculate prevalence_t from synthetic data
prevalence_t = compute_smoothed_prevalence(Y_tensor)  # Average over individuals

from clust_huge_amp import *

# %%
model_est = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=data['Y'].shape[0], 
    D=data['Y'].shape[1], 
    T=data['Y'].shape[2], 
    K=data['phi'].shape[0],  # number of clusters
    P=data['G'].shape[1],    # number of genetic features
    G=G_tensor,
    Y=Y_tensor,
    R=0,                     # Make sure R is provided
    W=1e-4,                # Make sure W is provided
    prevalence_t=prevalence_t,
    init_sd_scaler=1e-1,     # This matches your class definition
    genetic_scale=1,
    signature_references=None,
    healthy_reference=None,
    disease_names=None,
    flat_lambda=True,
    learn_kappa=True
)

model_est.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 3 diseases
# Cluster 1: 8 diseases
# Cluster 2: 4 diseases
# Cluster 3: 3 diseases
# Cluster 4: 2 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 3
# Base value (first 5): tensor([ -7.1997, -10.5076, -10.5076, -10.5076,  -7.1997])
# Base value centered (first 5): tensor([ 0.6275, -2.6804, -2.6804, -2.6804,  0.6275])
# Base value centered mean: 3.0059814548621944e-07
# Gamma init for k=0 (first 5): tensor([ 0.2781,  0.2558, -0.2568, -0.2966,  0.1783])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-10.0941, -10.0941, -10.0941, -10.0941, -10.0941])
# Base value centered (first 5): tensor([-0.0388, -0.0388, -0.0388, -0.0388, -0.0388])
# Base value centered mean: 4.2476654016354587e-07
# Gamma init for k=1 (first 5): tensor([ 0.0050, -0.0058,  0.0114,  0.0317, -0.0129])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 4
# Base value (first 5): tensor([ -3.8918, -11.3346,  -3.8918,  -6.3727,  -8.8537])
# Base value centered (first 5): tensor([ 3.0761, -4.3667,  3.0761,  0.5952, -1.8857])
# Base value centered mean: 2.918243353633443e-07
# Gamma init for k=2 (first 5): tensor([-1.7323,  0.0849,  0.6698,  0.0547, -0.2495])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 3
# Base value (first 5): tensor([-13.8155,  -7.1997, -13.8155, -10.5076, -13.8155])
# Base value centered (first 5): tensor([-1.6943,  4.9215, -1.6943,  1.6136, -1.6943])
# Base value centered mean: -1.7627716033530305e-06
# Gamma init for k=3 (first 5): tensor([ 0.5503, -0.3367, -0.1328, -0.1651, -0.1581])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 2
# Base value (first 5): tensor([-13.8155, -13.8155,  -8.8537, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-1.0266, -1.0266,  3.9352, -1.0266, -1.0266])
# Base value centered mean: -9.34600848268019e-07
# Gamma init for k=4 (first 5): tensor([-0.3141, -0.3490,  0.2380, -0.1672,  0.4931])
# Initializing with 5 disease states only
# Initialization complete!

# %%
from analyze_clusters import *
plot_confusion_matrix(data['clusters'], model_est.clusters, K=5)
# Out:
# Clustering Metrics:
# Adjusted Rand Index: 0.294
# Normalized Mutual Information: 0.592
# array([3, 0, 2, 4, 1])

# %%
from clust_huge_amp import *

# %%
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=data['Y'].shape[0], 
    D=data['Y'].shape[1], 
    T=data['Y'].shape[2], 
    K=data['phi'].shape[0],  # number of clusters
    P=data['G'].shape[1],    # number of genetic features
    G=G_tensor,
    Y=Y_tensor,
    R=0,                     # Make sure R is provided
    W=1e-4,                # Make sure W is provided
    prevalence_t=prevalence_t,
    init_sd_scaler=1e-1,     # This matches your class definition
    genetic_scale=1,
    signature_references=None,
    healthy_reference=None,
    disease_names=None,
    flat_lambda=True,
    learn_kappa=True
)

model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 3 diseases
# Cluster 1: 8 diseases
# Cluster 2: 4 diseases
# Cluster 3: 3 diseases
# Cluster 4: 2 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 3
# Base value (first 5): tensor([ -7.1997, -10.5076, -10.5076, -10.5076,  -7.1997])
# Base value centered (first 5): tensor([ 0.6275, -2.6804, -2.6804, -2.6804,  0.6275])
# Base value centered mean: 3.0059814548621944e-07
# Gamma init for k=0 (first 5): tensor([ 0.2781,  0.2558, -0.2568, -0.2966,  0.1783])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-10.0941, -10.0941, -10.0941, -10.0941, -10.0941])
# Base value centered (first 5): tensor([-0.0388, -0.0388, -0.0388, -0.0388, -0.0388])
# Base value centered mean: 4.2476654016354587e-07
# Gamma init for k=1 (first 5): tensor([ 0.0050, -0.0058,  0.0114,  0.0317, -0.0129])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 4
# Base value (first 5): tensor([ -3.8918, -11.3346,  -3.8918,  -6.3727,  -8.8537])
# Base value centered (first 5): tensor([ 3.0761, -4.3667,  3.0761,  0.5952, -1.8857])
# Base value centered mean: 2.918243353633443e-07
# Gamma init for k=2 (first 5): tensor([-1.7323,  0.0849,  0.6698,  0.0547, -0.2495])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 3
# Base value (first 5): tensor([-13.8155,  -7.1997, -13.8155, -10.5076, -13.8155])
# Base value centered (first 5): tensor([-1.6943,  4.9215, -1.6943,  1.6136, -1.6943])
# Base value centered mean: -1.7627716033530305e-06
# Gamma init for k=3 (first 5): tensor([ 0.5503, -0.3367, -0.1328, -0.1651, -0.1581])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 2
# Base value (first 5): tensor([-13.8155, -13.8155,  -8.8537, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-1.0266, -1.0266,  3.9352, -1.0266, -1.0266])
# Base value centered mean: -9.34600848268019e-07
# Gamma init for k=4 (first 5): tensor([-0.3141, -0.3490,  0.2380, -0.1672,  0.4931])
# Initializing with 5 disease states only
# Initialization complete!

# %%
# Initialize with true psi
model.initialize_params(true_psi=true_psi)
model.clusters = data['clusters'] 

model.visualize_initialization()
# Out:
# Calculating gamma for k=0:
# Number of diseases in cluster: 4.0
# Base value (first 5): tensor([-13.8155,  -8.8537, -13.8155, -11.3346, -13.8155])
# Base value centered (first 5): tensor([-1.2710,  3.6909, -1.2710,  1.2099, -1.2710])
# Base value centered mean: -3.94248957036325e-07
# Gamma init for k=0 (first 5): tensor([ 0.4125, -0.2524, -0.0999, -0.1241, -0.1186])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 4.0
# Base value (first 5): tensor([ -8.8537, -11.3346, -11.3346, -11.3346,  -8.8537])
# Base value centered (first 5): tensor([ 0.4602, -2.0207, -2.0207, -2.0207,  0.4602])
# Base value centered mean: 1.745605459291255e-06
# Gamma init for k=1 (first 5): tensor([ 0.2134,  0.1943, -0.1943, -0.2261,  0.1326])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 4.0
# Base value (first 5): tensor([ -6.3727, -11.3346,  -6.3727,  -8.8537, -11.3346])
# Base value centered (first 5): tensor([ 2.7838, -2.1780,  2.7838,  0.3029, -2.1780])
# Base value centered mean: 2.479553273815327e-08
# Gamma init for k=2 (first 5): tensor([-1.6011,  0.1384,  0.5971,  0.0474, -0.3158])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 4.0
# Base value (first 5): tensor([ -8.8537, -11.3346,  -6.3727,  -8.8537,  -8.8537])
# Base value centered (first 5): tensor([-0.2764, -2.7573,  2.2045, -0.2764, -0.2764])
# Base value centered mean: 9.256839916815807e-07
# Gamma init for k=3 (first 5): tensor([-0.3319, -0.2173,  0.2051, -0.0843,  0.3042])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 4.0
# Base value (first 5): tensor([-8.8537, -8.8537, -8.8537, -8.8537, -8.8537])
# Base value centered (first 5): tensor([-0.0117, -0.0117, -0.0117, -0.0117, -0.0117])
# Base value centered mean: 1.6778946019258e-06
# Gamma init for k=4 (first 5): tensor([ 0.0489, -0.0248,  0.0114,  0.0752, -0.0161])
# Initializing with 5 disease states only
# Initialization complete!

# %%
K=5
# Store initial psi values
initial_psi = model.psi.detach().clone()

import cProfile
import pstats
from pstats import SortKey

# For the healthtoo version
profiler = cProfile.Profile()
profiler.enable()
history_new = model.fit(E_tensor, num_epochs=100, learning_rate=1e-1, lambda_reg=1e-2)
profiler.disable()
stats = pstats.Stats(profiler).sort_stats(SortKey.CUMULATIVE)
stats.print_stats(20)
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:238: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 38.5673
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=63.62):
#   Theta for diagnosed: 0.376 ± 0.264
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 13 (signature 3, LR=60.16):
#   Theta for diagnosed: 0.215 ± 0.091
#   Theta for others: 0.160
#   Proportion difference: 0.055
#
# Disease 10 (signature 2, LR=59.45):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 11 (signature 2, LR=58.62):
#   Theta for diagnosed: 0.507 ± 0.277
#   Theta for others: 0.276
#   Proportion difference: 0.231
#
# Disease 19 (signature 4, LR=57.26):
#   Theta for diagnosed: 0.203 ± 0.062
#   Theta for others: 0.165
#   Proportion difference: 0.038
#
# Epoch 1
# Loss: 175.9119
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=64.19):
#   Theta for diagnosed: 0.377 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.285
#
# Disease 13 (signature 3, LR=60.12):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.160
#   Proportion difference: 0.054
#
# Disease 10 (signature 2, LR=59.96):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 11 (signature 2, LR=58.60):
#   Theta for diagnosed: 0.508 ± 0.277
#   Theta for others: 0.276
#   Proportion difference: 0.231
#
# Disease 19 (signature 4, LR=57.20):
#   Theta for diagnosed: 0.203 ± 0.060
#   Theta for others: 0.165
#   Proportion difference: 0.038
#
# Epoch 2
# Loss: 50.8160
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=64.75):
#   Theta for diagnosed: 0.377 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=60.48):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 13 (signature 3, LR=60.07):
#   Theta for diagnosed: 0.214 ± 0.089
#   Theta for others: 0.160
#   Proportion difference: 0.054
#
# Disease 11 (signature 2, LR=58.58):
#   Theta for diagnosed: 0.507 ± 0.277
#   Theta for others: 0.276
#   Proportion difference: 0.231
#
# Disease 17 (signature 4, LR=57.47):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.127
#   Proportion difference: 0.040
#
# Epoch 3
# Loss: 69.8588
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=65.26):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=60.99):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 13 (signature 3, LR=60.10):
#   Theta for diagnosed: 0.214 ± 0.090
#   Theta for others: 0.160
#   Proportion difference: 0.054
#
# Disease 11 (signature 2, LR=58.59):
#   Theta for diagnosed: 0.507 ± 0.277
#   Theta for others: 0.276
#   Proportion difference: 0.231
#
# Disease 17 (signature 4, LR=57.96):
#   Theta for diagnosed: 0.167 ± 0.066
#   Theta for others: 0.127
#   Proportion difference: 0.040
#
# Epoch 4
# Loss: 111.3757
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=65.77):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=61.51):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 13 (signature 3, LR=60.17):
#   Theta for diagnosed: 0.214 ± 0.089
#   Theta for others: 0.160
#   Proportion difference: 0.054
#
# Disease 11 (signature 2, LR=58.60):
#   Theta for diagnosed: 0.507 ± 0.277
#   Theta for others: 0.276
#   Proportion difference: 0.231
#
# Disease 17 (signature 4, LR=58.43):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.127
#   Proportion difference: 0.040
#
# Epoch 5
# Loss: 91.6151
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=66.26):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=62.04):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 13 (signature 3, LR=60.25):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.160
#   Proportion difference: 0.054
#
# Disease 17 (signature 4, LR=58.89):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.127
#   Proportion difference: 0.040
#
# Disease 11 (signature 2, LR=58.62):
#   Theta for diagnosed: 0.507 ± 0.277
#   Theta for others: 0.276
#   Proportion difference: 0.231
#
# Epoch 6
# Loss: 54.8764
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=66.75):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=62.56):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 13 (signature 3, LR=60.31):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.160
#   Proportion difference: 0.054
#
# Disease 17 (signature 4, LR=59.35):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.127
#   Proportion difference: 0.040
#
# Disease 11 (signature 2, LR=58.65):
#   Theta for diagnosed: 0.507 ± 0.277
#   Theta for others: 0.276
#   Proportion difference: 0.231
#
# Epoch 7
# Loss: 41.4887
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=67.25):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=63.08):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 13 (signature 3, LR=60.33):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.160
#   Proportion difference: 0.055
#
# Disease 17 (signature 4, LR=59.82):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 11 (signature 2, LR=58.67):
#   Theta for diagnosed: 0.507 ± 0.277
#   Theta for others: 0.276
#   Proportion difference: 0.231
#
# Epoch 8
# Loss: 54.6388
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=67.75):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=63.60):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 13 (signature 3, LR=60.33):
#   Theta for diagnosed: 0.215 ± 0.090
#   Theta for others: 0.160
#   Proportion difference: 0.055
#
# Disease 17 (signature 4, LR=60.30):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=58.93):
#   Theta for diagnosed: 0.167 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.032
#
# Epoch 9
# Loss: 69.1175
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=68.26):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=64.12):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 17 (signature 4, LR=60.78):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 13 (signature 3, LR=60.32):
#   Theta for diagnosed: 0.215 ± 0.090
#   Theta for others: 0.160
#   Proportion difference: 0.055
#
# Disease 12 (signature 3, LR=59.37):
#   Theta for diagnosed: 0.167 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.032
#
# Epoch 10
# Loss: 66.2028
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=68.76):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=64.64):
#   Theta for diagnosed: 0.325 ± 0.264
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 17 (signature 4, LR=61.28):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 13 (signature 3, LR=60.31):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Disease 12 (signature 3, LR=59.81):
#   Theta for diagnosed: 0.167 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.032
#
# Epoch 11
# Loss: 51.1249
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=69.26):
#   Theta for diagnosed: 0.376 ± 0.263
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=65.15):
#   Theta for diagnosed: 0.325 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 17 (signature 4, LR=61.78):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 13 (signature 3, LR=60.30):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Disease 12 (signature 3, LR=60.27):
#   Theta for diagnosed: 0.167 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.032
#
# Epoch 12
# Loss: 39.0711
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=69.76):
#   Theta for diagnosed: 0.376 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=65.66):
#   Theta for diagnosed: 0.325 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 17 (signature 4, LR=62.27):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.127
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=60.72):
#   Theta for diagnosed: 0.167 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.032
#
# Disease 13 (signature 3, LR=60.31):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Epoch 13
# Loss: 38.6867
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=70.23):
#   Theta for diagnosed: 0.376 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=66.17):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.247
#
# Disease 17 (signature 4, LR=62.76):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.127
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=61.16):
#   Theta for diagnosed: 0.167 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.032
#
# Disease 13 (signature 3, LR=60.33):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Epoch 14
# Loss: 46.2307
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=70.70):
#   Theta for diagnosed: 0.376 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=66.66):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=63.23):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.127
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=61.59):
#   Theta for diagnosed: 0.167 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.032
#
# Disease 13 (signature 3, LR=60.35):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Epoch 15
# Loss: 51.4839
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=71.14):
#   Theta for diagnosed: 0.376 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=67.15):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=63.70):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.127
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=62.01):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.38):
#   Theta for diagnosed: 0.215 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Epoch 16
# Loss: 48.8171
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=71.56):
#   Theta for diagnosed: 0.376 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=67.62):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=64.17):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=62.43):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.40):
#   Theta for diagnosed: 0.216 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Epoch 17
# Loss: 41.3090
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=71.97):
#   Theta for diagnosed: 0.376 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=68.08):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=64.62):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=62.84):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.42):
#   Theta for diagnosed: 0.216 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Epoch 18
# Loss: 35.7434
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=72.37):
#   Theta for diagnosed: 0.376 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=68.53):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=65.07):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=63.25):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.43):
#   Theta for diagnosed: 0.216 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Epoch 19
# Loss: 35.8133
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=72.74):
#   Theta for diagnosed: 0.375 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=68.96):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=65.52):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=63.67):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.43):
#   Theta for diagnosed: 0.216 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.055
#
# Epoch 20
# Loss: 39.4594
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=73.11):
#   Theta for diagnosed: 0.375 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=69.39):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=65.97):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=64.09):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.43):
#   Theta for diagnosed: 0.216 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.056
#
# Epoch 21
# Loss: 41.8090
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=73.45):
#   Theta for diagnosed: 0.375 ± 0.262
#   Theta for others: 0.092
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=69.80):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.078
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=66.41):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=64.53):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.42):
#   Theta for diagnosed: 0.216 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.056
#
# Epoch 22
# Loss: 40.2854
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=73.78):
#   Theta for diagnosed: 0.375 ± 0.262
#   Theta for others: 0.091
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=70.20):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=66.85):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=64.97):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.40):
#   Theta for diagnosed: 0.217 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.056
#
# Epoch 23
# Loss: 36.5251
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=74.09):
#   Theta for diagnosed: 0.375 ± 0.262
#   Theta for others: 0.091
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=70.59):
#   Theta for diagnosed: 0.324 ± 0.263
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=67.29):
#   Theta for diagnosed: 0.167 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.041
#
# Disease 12 (signature 3, LR=65.41):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.39):
#   Theta for diagnosed: 0.217 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.056
#
# Epoch 24
# Loss: 33.9530
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=74.37):
#   Theta for diagnosed: 0.375 ± 0.262
#   Theta for others: 0.091
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=70.96):
#   Theta for diagnosed: 0.324 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=67.71):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=65.84):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.37):
#   Theta for diagnosed: 0.217 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.056
#
# Epoch 25
# Loss: 34.2485
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=74.62):
#   Theta for diagnosed: 0.375 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.284
#
# Disease 10 (signature 2, LR=71.31):
#   Theta for diagnosed: 0.324 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=68.12):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=66.26):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.135
#   Proportion difference: 0.033
#
# Disease 13 (signature 3, LR=60.35):
#   Theta for diagnosed: 0.217 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.056
#
# Epoch 26
# Loss: 36.0785
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=74.85):
#   Theta for diagnosed: 0.375 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=71.64):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=68.52):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=66.68):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.034
#
# Disease 13 (signature 3, LR=60.33):
#   Theta for diagnosed: 0.217 ± 0.089
#   Theta for others: 0.161
#   Proportion difference: 0.056
#
# Epoch 27
# Loss: 36.9131
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.06):
#   Theta for diagnosed: 0.375 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=71.95):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=68.91):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=67.08):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.034
#
# Disease 15 (signature 3, LR=60.34):
#   Theta for diagnosed: 0.171 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 28
# Loss: 35.7223
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.23):
#   Theta for diagnosed: 0.375 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=72.24):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=69.28):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=67.48):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.034
#
# Disease 15 (signature 3, LR=60.71):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 29
# Loss: 33.7025
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.38):
#   Theta for diagnosed: 0.375 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=72.52):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=69.65):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=67.87):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.034
#
# Disease 15 (signature 3, LR=61.06):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 30
# Loss: 32.6782
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.51):
#   Theta for diagnosed: 0.374 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=72.77):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=70.00):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=68.27):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.034
#
# Disease 15 (signature 3, LR=61.42):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 31
# Loss: 33.1794
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.62):
#   Theta for diagnosed: 0.374 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=73.02):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=70.34):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.126
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=68.67):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.034
#
# Disease 15 (signature 3, LR=61.77):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 32
# Loss: 34.1248
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.71):
#   Theta for diagnosed: 0.374 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=73.25):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=70.68):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.125
#   Proportion difference: 0.042
#
# Disease 12 (signature 3, LR=69.08):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.034
#
# Disease 15 (signature 3, LR=62.11):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 33
# Loss: 34.1972
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.78):
#   Theta for diagnosed: 0.374 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=73.46):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=71.01):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.125
#   Proportion difference: 0.043
#
# Disease 12 (signature 3, LR=69.48):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.034
#
# Disease 15 (signature 3, LR=62.45):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 34
# Loss: 33.2409
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.82):
#   Theta for diagnosed: 0.374 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=73.67):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=71.32):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.125
#   Proportion difference: 0.043
#
# Disease 12 (signature 3, LR=69.88):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.035
#
# Disease 15 (signature 3, LR=62.79):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 35
# Loss: 32.2129
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.85):
#   Theta for diagnosed: 0.374 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=73.85):
#   Theta for diagnosed: 0.323 ± 0.262
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=71.62):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.125
#   Proportion difference: 0.043
#
# Disease 12 (signature 3, LR=70.28):
#   Theta for diagnosed: 0.168 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.035
#
# Disease 15 (signature 3, LR=63.12):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.135
#   Proportion difference: 0.037
#
# Epoch 36
# Loss: 31.9869
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.86):
#   Theta for diagnosed: 0.374 ± 0.261
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.02):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=71.91):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.125
#   Proportion difference: 0.043
#
# Disease 12 (signature 3, LR=70.67):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.035
#
# Disease 15 (signature 3, LR=63.44):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.134
#   Proportion difference: 0.038
#
# Epoch 37
# Loss: 32.4479
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.84):
#   Theta for diagnosed: 0.374 ± 0.260
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.18):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.077
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=72.19):
#   Theta for diagnosed: 0.168 ± 0.065
#   Theta for others: 0.125
#   Proportion difference: 0.043
#
# Disease 12 (signature 3, LR=71.04):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.035
#
# Disease 15 (signature 3, LR=63.75):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.134
#   Proportion difference: 0.038
#
# Epoch 38
# Loss: 32.7840
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.80):
#   Theta for diagnosed: 0.373 ± 0.260
#   Theta for others: 0.091
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.32):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=72.45):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.125
#   Proportion difference: 0.043
#
# Disease 12 (signature 3, LR=71.41):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.134
#   Proportion difference: 0.035
#
# Disease 15 (signature 3, LR=64.06):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.134
#   Proportion difference: 0.038
#
# Epoch 39
# Loss: 32.4829
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.75):
#   Theta for diagnosed: 0.373 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.45):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=72.70):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.125
#   Proportion difference: 0.043
#
# Disease 12 (signature 3, LR=71.78):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.133
#   Proportion difference: 0.035
#
# Disease 15 (signature 3, LR=64.36):
#   Theta for diagnosed: 0.172 ± 0.081
#   Theta for others: 0.134
#   Proportion difference: 0.038
#
# Epoch 40
# Loss: 31.8342
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.69):
#   Theta for diagnosed: 0.373 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.57):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=72.94):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.125
#   Proportion difference: 0.043
#
# Disease 12 (signature 3, LR=72.14):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.133
#   Proportion difference: 0.035
#
# Disease 15 (signature 3, LR=64.66):
#   Theta for diagnosed: 0.172 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.038
#
# Epoch 41
# Loss: 31.4661
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.61):
#   Theta for diagnosed: 0.373 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.68):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=73.17):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.125
#   Proportion difference: 0.044
#
# Disease 12 (signature 3, LR=72.50):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.133
#   Proportion difference: 0.036
#
# Disease 15 (signature 3, LR=64.94):
#   Theta for diagnosed: 0.172 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.038
#
# Epoch 42
# Loss: 31.5888
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.52):
#   Theta for diagnosed: 0.373 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.79):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=73.39):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.125
#   Proportion difference: 0.044
#
# Disease 12 (signature 3, LR=72.86):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.133
#   Proportion difference: 0.036
#
# Disease 15 (signature 3, LR=65.23):
#   Theta for diagnosed: 0.172 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.038
#
# Epoch 43
# Loss: 31.8319
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.43):
#   Theta for diagnosed: 0.373 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.89):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=73.60):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.044
#
# Disease 12 (signature 3, LR=73.23):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.133
#   Proportion difference: 0.036
#
# Disease 15 (signature 3, LR=65.51):
#   Theta for diagnosed: 0.172 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.038
#
# Epoch 44
# Loss: 31.7655
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.32):
#   Theta for diagnosed: 0.373 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=74.98):
#   Theta for diagnosed: 0.322 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=73.80):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.044
#
# Disease 12 (signature 3, LR=73.58):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.133
#   Proportion difference: 0.036
#
# Disease 15 (signature 3, LR=65.78):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.039
#
# Epoch 45
# Loss: 31.4020
#
# Monitoring signature responses:
#
# Disease 9 (signature 2, LR=75.20):
#   Theta for diagnosed: 0.373 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 10 (signature 2, LR=75.06):
#   Theta for diagnosed: 0.321 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=74.00):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.044
#
# Disease 12 (signature 3, LR=73.94):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.133
#   Proportion difference: 0.036
#
# Disease 15 (signature 3, LR=66.04):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.039
#
# Epoch 46
# Loss: 31.1021
#
# Monitoring signature responses:
#
# Disease 10 (signature 2, LR=75.14):
#   Theta for diagnosed: 0.321 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 9 (signature 2, LR=75.08):
#   Theta for diagnosed: 0.372 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 12 (signature 3, LR=74.28):
#   Theta for diagnosed: 0.169 ± 0.080
#   Theta for others: 0.133
#   Proportion difference: 0.036
#
# Disease 17 (signature 4, LR=74.18):
#   Theta for diagnosed: 0.168 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.044
#
# Disease 15 (signature 3, LR=66.31):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.039
#
# Epoch 47
# Loss: 31.0929
#
# Monitoring signature responses:
#
# Disease 10 (signature 2, LR=75.21):
#   Theta for diagnosed: 0.321 ± 0.261
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 9 (signature 2, LR=74.94):
#   Theta for diagnosed: 0.372 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 12 (signature 3, LR=74.63):
#   Theta for diagnosed: 0.169 ± 0.081
#   Theta for others: 0.133
#   Proportion difference: 0.036
#
# Disease 17 (signature 4, LR=74.36):
#   Theta for diagnosed: 0.169 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.045
#
# Disease 15 (signature 3, LR=66.56):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.039
#
# Epoch 48
# Loss: 31.2234
#
# Monitoring signature responses:
#
# Disease 10 (signature 2, LR=75.27):
#   Theta for diagnosed: 0.321 ± 0.260
#   Theta for others: 0.076
#   Proportion difference: 0.246
#
# Disease 12 (signature 3, LR=74.96):
#   Theta for diagnosed: 0.169 ± 0.081
#   Theta for others: 0.133
#   Proportion difference: 0.037
#
# Disease 9 (signature 2, LR=74.80):
#   Theta for diagnosed: 0.372 ± 0.260
#   Theta for others: 0.090
#   Proportion difference: 0.283
#
# Disease 17 (signature 4, LR=74.53):
#   Theta for diagnosed: 0.169 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.045
#
# Disease 15 (signature 3, LR=66.81):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.039
#
# Epoch 49
# Loss: 31.2099
#
# Monitoring signature responses:
#
# Disease 10 (signature 2, LR=75.33):
#   Theta for diagnosed: 0.321 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.246
#
# Disease 12 (signature 3, LR=75.29):
#   Theta for diagnosed: 0.169 ± 0.081
#   Theta for others: 0.132
#   Proportion difference: 0.037
#
# Disease 17 (signature 4, LR=74.68):
#   Theta for diagnosed: 0.169 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.045
#
# Disease 9 (signature 2, LR=74.65):
#   Theta for diagnosed: 0.372 ± 0.259
#   Theta for others: 0.090
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=67.06):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.134
#   Proportion difference: 0.039
#
# Epoch 50
# Loss: 30.9980
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=75.62):
#   Theta for diagnosed: 0.169 ± 0.081
#   Theta for others: 0.132
#   Proportion difference: 0.037
#
# Disease 10 (signature 2, LR=75.39):
#   Theta for diagnosed: 0.321 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=74.84):
#   Theta for diagnosed: 0.169 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.045
#
# Disease 9 (signature 2, LR=74.50):
#   Theta for diagnosed: 0.372 ± 0.259
#   Theta for others: 0.090
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=67.30):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.133
#   Proportion difference: 0.040
#
# Epoch 51
# Loss: 30.7875
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=75.94):
#   Theta for diagnosed: 0.169 ± 0.081
#   Theta for others: 0.132
#   Proportion difference: 0.037
#
# Disease 10 (signature 2, LR=75.44):
#   Theta for diagnosed: 0.321 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.246
#
# Disease 17 (signature 4, LR=74.98):
#   Theta for diagnosed: 0.169 ± 0.066
#   Theta for others: 0.124
#   Proportion difference: 0.045
#
# Disease 9 (signature 2, LR=74.34):
#   Theta for diagnosed: 0.372 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=67.54):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.133
#   Proportion difference: 0.040
#
# Epoch 52
# Loss: 30.7437
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=76.27):
#   Theta for diagnosed: 0.169 ± 0.081
#   Theta for others: 0.132
#   Proportion difference: 0.037
#
# Disease 10 (signature 2, LR=75.50):
#   Theta for diagnosed: 0.321 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.245
#
# Disease 17 (signature 4, LR=75.12):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.123
#   Proportion difference: 0.045
#
# Disease 9 (signature 2, LR=74.18):
#   Theta for diagnosed: 0.372 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=67.77):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.133
#   Proportion difference: 0.040
#
# Epoch 53
# Loss: 30.8011
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=76.59):
#   Theta for diagnosed: 0.169 ± 0.081
#   Theta for others: 0.132
#   Proportion difference: 0.037
#
# Disease 10 (signature 2, LR=75.55):
#   Theta for diagnosed: 0.321 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.245
#
# Disease 17 (signature 4, LR=75.26):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.123
#   Proportion difference: 0.046
#
# Disease 9 (signature 2, LR=74.02):
#   Theta for diagnosed: 0.372 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=68.00):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.133
#   Proportion difference: 0.040
#
# Epoch 54
# Loss: 30.7845
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=76.91):
#   Theta for diagnosed: 0.169 ± 0.081
#   Theta for others: 0.132
#   Proportion difference: 0.038
#
# Disease 10 (signature 2, LR=75.60):
#   Theta for diagnosed: 0.320 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.245
#
# Disease 17 (signature 4, LR=75.39):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.123
#   Proportion difference: 0.046
#
# Disease 9 (signature 2, LR=73.86):
#   Theta for diagnosed: 0.371 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=68.22):
#   Theta for diagnosed: 0.173 ± 0.082
#   Theta for others: 0.133
#   Proportion difference: 0.040
#
# Epoch 55
# Loss: 30.6471
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=77.23):
#   Theta for diagnosed: 0.170 ± 0.081
#   Theta for others: 0.132
#   Proportion difference: 0.038
#
# Disease 10 (signature 2, LR=75.65):
#   Theta for diagnosed: 0.320 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.245
#
# Disease 17 (signature 4, LR=75.52):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.123
#   Proportion difference: 0.046
#
# Disease 9 (signature 2, LR=73.70):
#   Theta for diagnosed: 0.371 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=68.44):
#   Theta for diagnosed: 0.173 ± 0.083
#   Theta for others: 0.133
#   Proportion difference: 0.040
#
# Epoch 56
# Loss: 30.5055
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=77.55):
#   Theta for diagnosed: 0.170 ± 0.081
#   Theta for others: 0.132
#   Proportion difference: 0.038
#
# Disease 10 (signature 2, LR=75.70):
#   Theta for diagnosed: 0.320 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.245
#
# Disease 17 (signature 4, LR=75.65):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.123
#   Proportion difference: 0.046
#
# Disease 9 (signature 2, LR=73.54):
#   Theta for diagnosed: 0.371 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=68.66):
#   Theta for diagnosed: 0.173 ± 0.083
#   Theta for others: 0.133
#   Proportion difference: 0.040
#
# Epoch 57
# Loss: 30.4626
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=77.86):
#   Theta for diagnosed: 0.170 ± 0.081
#   Theta for others: 0.131
#   Proportion difference: 0.038
#
# Disease 17 (signature 4, LR=75.77):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.123
#   Proportion difference: 0.046
#
# Disease 10 (signature 2, LR=75.75):
#   Theta for diagnosed: 0.320 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=73.37):
#   Theta for diagnosed: 0.371 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=68.87):
#   Theta for diagnosed: 0.173 ± 0.083
#   Theta for others: 0.133
#   Proportion difference: 0.041
#
# Epoch 58
# Loss: 30.4783
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=78.17):
#   Theta for diagnosed: 0.170 ± 0.081
#   Theta for others: 0.131
#   Proportion difference: 0.038
#
# Disease 17 (signature 4, LR=75.88):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.123
#   Proportion difference: 0.046
#
# Disease 10 (signature 2, LR=75.80):
#   Theta for diagnosed: 0.320 ± 0.260
#   Theta for others: 0.075
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=73.21):
#   Theta for diagnosed: 0.371 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=69.08):
#   Theta for diagnosed: 0.173 ± 0.083
#   Theta for others: 0.133
#   Proportion difference: 0.041
#
# Epoch 59
# Loss: 30.4469
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=78.47):
#   Theta for diagnosed: 0.170 ± 0.081
#   Theta for others: 0.131
#   Proportion difference: 0.038
#
# Disease 17 (signature 4, LR=75.99):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.122
#   Proportion difference: 0.047
#
# Disease 10 (signature 2, LR=75.85):
#   Theta for diagnosed: 0.320 ± 0.260
#   Theta for others: 0.074
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=73.04):
#   Theta for diagnosed: 0.371 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=69.29):
#   Theta for diagnosed: 0.174 ± 0.083
#   Theta for others: 0.133
#   Proportion difference: 0.041
#
# Epoch 60
# Loss: 30.3458
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=78.77):
#   Theta for diagnosed: 0.170 ± 0.082
#   Theta for others: 0.131
#   Proportion difference: 0.039
#
# Disease 17 (signature 4, LR=76.10):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.122
#   Proportion difference: 0.047
#
# Disease 10 (signature 2, LR=75.90):
#   Theta for diagnosed: 0.320 ± 0.260
#   Theta for others: 0.074
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=72.88):
#   Theta for diagnosed: 0.371 ± 0.259
#   Theta for others: 0.089
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=69.49):
#   Theta for diagnosed: 0.174 ± 0.083
#   Theta for others: 0.132
#   Proportion difference: 0.041
#
# Epoch 61
# Loss: 30.2499
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=79.08):
#   Theta for diagnosed: 0.170 ± 0.082
#   Theta for others: 0.131
#   Proportion difference: 0.039
#
# Disease 17 (signature 4, LR=76.21):
#   Theta for diagnosed: 0.169 ± 0.067
#   Theta for others: 0.122
#   Proportion difference: 0.047
#
# Disease 10 (signature 2, LR=75.96):
#   Theta for diagnosed: 0.320 ± 0.259
#   Theta for others: 0.074
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=72.72):
#   Theta for diagnosed: 0.371 ± 0.259
#   Theta for others: 0.088
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=69.70):
#   Theta for diagnosed: 0.174 ± 0.083
#   Theta for others: 0.132
#   Proportion difference: 0.041
#
# Epoch 62
# Loss: 30.2151
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=79.38):
#   Theta for diagnosed: 0.170 ± 0.082
#   Theta for others: 0.131
#   Proportion difference: 0.039
#
# Disease 17 (signature 4, LR=76.32):
#   Theta for diagnosed: 0.169 ± 0.068
#   Theta for others: 0.122
#   Proportion difference: 0.047
#
# Disease 10 (signature 2, LR=76.02):
#   Theta for diagnosed: 0.319 ± 0.259
#   Theta for others: 0.074
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=72.57):
#   Theta for diagnosed: 0.370 ± 0.259
#   Theta for others: 0.088
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=69.90):
#   Theta for diagnosed: 0.174 ± 0.083
#   Theta for others: 0.132
#   Proportion difference: 0.042
#
# Epoch 63
# Loss: 30.2074
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=79.68):
#   Theta for diagnosed: 0.170 ± 0.082
#   Theta for others: 0.131
#   Proportion difference: 0.039
#
# Disease 17 (signature 4, LR=76.43):
#   Theta for diagnosed: 0.169 ± 0.068
#   Theta for others: 0.122
#   Proportion difference: 0.047
#
# Disease 10 (signature 2, LR=76.08):
#   Theta for diagnosed: 0.319 ± 0.259
#   Theta for others: 0.074
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=72.41):
#   Theta for diagnosed: 0.370 ± 0.258
#   Theta for others: 0.088
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=70.10):
#   Theta for diagnosed: 0.174 ± 0.083
#   Theta for others: 0.132
#   Proportion difference: 0.042
#
# Epoch 64
# Loss: 30.1644
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=79.98):
#   Theta for diagnosed: 0.170 ± 0.082
#   Theta for others: 0.131
#   Proportion difference: 0.039
#
# Disease 17 (signature 4, LR=76.54):
#   Theta for diagnosed: 0.169 ± 0.068
#   Theta for others: 0.122
#   Proportion difference: 0.048
#
# Disease 10 (signature 2, LR=76.14):
#   Theta for diagnosed: 0.319 ± 0.259
#   Theta for others: 0.074
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=72.26):
#   Theta for diagnosed: 0.370 ± 0.258
#   Theta for others: 0.088
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=70.29):
#   Theta for diagnosed: 0.174 ± 0.083
#   Theta for others: 0.132
#   Proportion difference: 0.042
#
# Epoch 65
# Loss: 30.0844
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=80.28):
#   Theta for diagnosed: 0.170 ± 0.082
#   Theta for others: 0.130
#   Proportion difference: 0.040
#
# Disease 17 (signature 4, LR=76.65):
#   Theta for diagnosed: 0.169 ± 0.068
#   Theta for others: 0.122
#   Proportion difference: 0.048
#
# Disease 10 (signature 2, LR=76.20):
#   Theta for diagnosed: 0.319 ± 0.259
#   Theta for others: 0.074
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=72.12):
#   Theta for diagnosed: 0.370 ± 0.258
#   Theta for others: 0.088
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=70.49):
#   Theta for diagnosed: 0.174 ± 0.084
#   Theta for others: 0.132
#   Proportion difference: 0.042
#
# Epoch 66
# Loss: 30.0176
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=80.58):
#   Theta for diagnosed: 0.170 ± 0.082
#   Theta for others: 0.130
#   Proportion difference: 0.040
#
# Disease 17 (signature 4, LR=76.75):
#   Theta for diagnosed: 0.169 ± 0.068
#   Theta for others: 0.121
#   Proportion difference: 0.048
#
# Disease 10 (signature 2, LR=76.27):
#   Theta for diagnosed: 0.319 ± 0.259
#   Theta for others: 0.074
#   Proportion difference: 0.245
#
# Disease 9 (signature 2, LR=71.97):
#   Theta for diagnosed: 0.370 ± 0.258
#   Theta for others: 0.088
#   Proportion difference: 0.282
#
# Disease 15 (signature 3, LR=70.68):
#   Theta for diagnosed: 0.174 ± 0.084
#   Theta for others: 0.132
#   Proportion difference: 0.042
#
# Epoch 67
# Loss: 29.9880
#
# ...
#   Theta for diagnosed: 0.171 ± 0.084
#   Theta for others: 0.128
#   Proportion difference: 0.043
#
# Disease 17 (signature 4, LR=78.47):
#   Theta for diagnosed: 0.170 ± 0.070
#   Theta for others: 0.119
#   Proportion difference: 0.051
#
# Disease 10 (signature 2, LR=77.77):
#   Theta for diagnosed: 0.317 ± 0.258
#   Theta for others: 0.072
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=73.43):
#   Theta for diagnosed: 0.175 ± 0.086
#   Theta for others: 0.130
#   Proportion difference: 0.045
#
# Disease 9 (signature 2, LR=70.33):
#   Theta for diagnosed: 0.368 ± 0.257
#   Theta for others: 0.087
#   Proportion difference: 0.282
#
# Epoch 82
# Loss: 29.3701
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=85.28):
#   Theta for diagnosed: 0.171 ± 0.084
#   Theta for others: 0.128
#   Proportion difference: 0.043
#
# Disease 17 (signature 4, LR=78.60):
#   Theta for diagnosed: 0.170 ± 0.071
#   Theta for others: 0.119
#   Proportion difference: 0.051
#
# Disease 10 (signature 2, LR=77.90):
#   Theta for diagnosed: 0.317 ± 0.258
#   Theta for others: 0.072
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=73.61):
#   Theta for diagnosed: 0.175 ± 0.086
#   Theta for others: 0.130
#   Proportion difference: 0.045
#
# Disease 9 (signature 2, LR=70.26):
#   Theta for diagnosed: 0.368 ± 0.257
#   Theta for others: 0.086
#   Proportion difference: 0.282
#
# Epoch 83
# Loss: 29.3285
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=85.57):
#   Theta for diagnosed: 0.171 ± 0.084
#   Theta for others: 0.128
#   Proportion difference: 0.043
#
# Disease 17 (signature 4, LR=78.74):
#   Theta for diagnosed: 0.170 ± 0.071
#   Theta for others: 0.119
#   Proportion difference: 0.052
#
# Disease 10 (signature 2, LR=78.04):
#   Theta for diagnosed: 0.317 ± 0.258
#   Theta for others: 0.072
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=73.79):
#   Theta for diagnosed: 0.175 ± 0.086
#   Theta for others: 0.129
#   Proportion difference: 0.046
#
# Disease 9 (signature 2, LR=70.19):
#   Theta for diagnosed: 0.368 ± 0.257
#   Theta for others: 0.086
#   Proportion difference: 0.282
#
# Epoch 84
# Loss: 29.2860
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=85.87):
#   Theta for diagnosed: 0.171 ± 0.085
#   Theta for others: 0.127
#   Proportion difference: 0.043
#
# Disease 17 (signature 4, LR=78.87):
#   Theta for diagnosed: 0.170 ± 0.071
#   Theta for others: 0.118
#   Proportion difference: 0.052
#
# Disease 10 (signature 2, LR=78.19):
#   Theta for diagnosed: 0.317 ± 0.258
#   Theta for others: 0.072
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=73.96):
#   Theta for diagnosed: 0.175 ± 0.086
#   Theta for others: 0.129
#   Proportion difference: 0.046
#
# Disease 9 (signature 2, LR=70.13):
#   Theta for diagnosed: 0.368 ± 0.257
#   Theta for others: 0.086
#   Proportion difference: 0.281
#
# Epoch 85
# Loss: 29.2489
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=86.16):
#   Theta for diagnosed: 0.171 ± 0.085
#   Theta for others: 0.127
#   Proportion difference: 0.043
#
# Disease 17 (signature 4, LR=79.01):
#   Theta for diagnosed: 0.170 ± 0.071
#   Theta for others: 0.118
#   Proportion difference: 0.052
#
# Disease 10 (signature 2, LR=78.33):
#   Theta for diagnosed: 0.317 ± 0.258
#   Theta for others: 0.072
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=74.14):
#   Theta for diagnosed: 0.175 ± 0.086
#   Theta for others: 0.129
#   Proportion difference: 0.046
#
# Disease 5 (signature 1, LR=70.29):
#   Theta for diagnosed: 0.212 ± 0.116
#   Theta for others: 0.124
#   Proportion difference: 0.089
#
# Epoch 86
# Loss: 29.2146
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=86.46):
#   Theta for diagnosed: 0.171 ± 0.085
#   Theta for others: 0.127
#   Proportion difference: 0.044
#
# Disease 17 (signature 4, LR=79.15):
#   Theta for diagnosed: 0.171 ± 0.071
#   Theta for others: 0.118
#   Proportion difference: 0.052
#
# Disease 10 (signature 2, LR=78.48):
#   Theta for diagnosed: 0.317 ± 0.258
#   Theta for others: 0.071
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=74.32):
#   Theta for diagnosed: 0.175 ± 0.086
#   Theta for others: 0.129
#   Proportion difference: 0.046
#
# Disease 5 (signature 1, LR=70.48):
#   Theta for diagnosed: 0.212 ± 0.117
#   Theta for others: 0.124
#   Proportion difference: 0.089
#
# Epoch 87
# Loss: 29.1770
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=86.76):
#   Theta for diagnosed: 0.171 ± 0.085
#   Theta for others: 0.127
#   Proportion difference: 0.044
#
# Disease 17 (signature 4, LR=79.29):
#   Theta for diagnosed: 0.171 ± 0.071
#   Theta for others: 0.118
#   Proportion difference: 0.053
#
# Disease 10 (signature 2, LR=78.64):
#   Theta for diagnosed: 0.317 ± 0.258
#   Theta for others: 0.071
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=74.50):
#   Theta for diagnosed: 0.175 ± 0.086
#   Theta for others: 0.129
#   Proportion difference: 0.046
#
# Disease 5 (signature 1, LR=70.66):
#   Theta for diagnosed: 0.213 ± 0.117
#   Theta for others: 0.124
#   Proportion difference: 0.089
#
# Epoch 88
# Loss: 29.1366
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=87.05):
#   Theta for diagnosed: 0.171 ± 0.085
#   Theta for others: 0.127
#   Proportion difference: 0.044
#
# Disease 17 (signature 4, LR=79.43):
#   Theta for diagnosed: 0.171 ± 0.072
#   Theta for others: 0.118
#   Proportion difference: 0.053
#
# Disease 10 (signature 2, LR=78.79):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.071
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=74.67):
#   Theta for diagnosed: 0.175 ± 0.087
#   Theta for others: 0.129
#   Proportion difference: 0.047
#
# Disease 5 (signature 1, LR=70.85):
#   Theta for diagnosed: 0.213 ± 0.117
#   Theta for others: 0.124
#   Proportion difference: 0.089
#
# Epoch 89
# Loss: 29.0986
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=87.35):
#   Theta for diagnosed: 0.171 ± 0.085
#   Theta for others: 0.127
#   Proportion difference: 0.044
#
# Disease 17 (signature 4, LR=79.58):
#   Theta for diagnosed: 0.171 ± 0.072
#   Theta for others: 0.118
#   Proportion difference: 0.053
#
# Disease 10 (signature 2, LR=78.96):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.071
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=74.85):
#   Theta for diagnosed: 0.175 ± 0.087
#   Theta for others: 0.129
#   Proportion difference: 0.047
#
# Disease 5 (signature 1, LR=71.04):
#   Theta for diagnosed: 0.213 ± 0.117
#   Theta for others: 0.123
#   Proportion difference: 0.089
#
# Epoch 90
# Loss: 29.0637
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=87.65):
#   Theta for diagnosed: 0.171 ± 0.085
#   Theta for others: 0.126
#   Proportion difference: 0.044
#
# Disease 17 (signature 4, LR=79.73):
#   Theta for diagnosed: 0.171 ± 0.072
#   Theta for others: 0.117
#   Proportion difference: 0.053
#
# Disease 10 (signature 2, LR=79.12):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.071
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=75.02):
#   Theta for diagnosed: 0.175 ± 0.087
#   Theta for others: 0.128
#   Proportion difference: 0.047
#
# Disease 5 (signature 1, LR=71.22):
#   Theta for diagnosed: 0.213 ± 0.117
#   Theta for others: 0.123
#   Proportion difference: 0.090
#
# Epoch 91
# Loss: 29.0279
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=87.95):
#   Theta for diagnosed: 0.171 ± 0.086
#   Theta for others: 0.126
#   Proportion difference: 0.045
#
# Disease 17 (signature 4, LR=79.88):
#   Theta for diagnosed: 0.171 ± 0.072
#   Theta for others: 0.117
#   Proportion difference: 0.054
#
# Disease 10 (signature 2, LR=79.29):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.071
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=75.20):
#   Theta for diagnosed: 0.175 ± 0.087
#   Theta for others: 0.128
#   Proportion difference: 0.047
#
# Disease 5 (signature 1, LR=71.41):
#   Theta for diagnosed: 0.213 ± 0.118
#   Theta for others: 0.123
#   Proportion difference: 0.090
#
# Epoch 92
# Loss: 28.9898
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=88.25):
#   Theta for diagnosed: 0.171 ± 0.086
#   Theta for others: 0.126
#   Proportion difference: 0.045
#
# Disease 17 (signature 4, LR=80.04):
#   Theta for diagnosed: 0.171 ± 0.072
#   Theta for others: 0.117
#   Proportion difference: 0.054
#
# Disease 10 (signature 2, LR=79.46):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.071
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=75.37):
#   Theta for diagnosed: 0.175 ± 0.087
#   Theta for others: 0.128
#   Proportion difference: 0.047
#
# Disease 5 (signature 1, LR=71.59):
#   Theta for diagnosed: 0.213 ± 0.118
#   Theta for others: 0.123
#   Proportion difference: 0.090
#
# Epoch 93
# Loss: 28.9521
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=88.55):
#   Theta for diagnosed: 0.171 ± 0.086
#   Theta for others: 0.126
#   Proportion difference: 0.045
#
# Disease 17 (signature 4, LR=80.19):
#   Theta for diagnosed: 0.171 ± 0.073
#   Theta for others: 0.117
#   Proportion difference: 0.054
#
# Disease 10 (signature 2, LR=79.64):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.071
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=75.55):
#   Theta for diagnosed: 0.175 ± 0.087
#   Theta for others: 0.128
#   Proportion difference: 0.048
#
# Disease 5 (signature 1, LR=71.78):
#   Theta for diagnosed: 0.213 ± 0.118
#   Theta for others: 0.123
#   Proportion difference: 0.090
#
# Epoch 94
# Loss: 28.9168
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=88.86):
#   Theta for diagnosed: 0.171 ± 0.086
#   Theta for others: 0.126
#   Proportion difference: 0.045
#
# Disease 17 (signature 4, LR=80.35):
#   Theta for diagnosed: 0.171 ± 0.073
#   Theta for others: 0.117
#   Proportion difference: 0.054
#
# Disease 10 (signature 2, LR=79.82):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.070
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=75.72):
#   Theta for diagnosed: 0.176 ± 0.088
#   Theta for others: 0.128
#   Proportion difference: 0.048
#
# Disease 5 (signature 1, LR=71.96):
#   Theta for diagnosed: 0.213 ± 0.118
#   Theta for others: 0.123
#   Proportion difference: 0.090
#
# Epoch 95
# Loss: 28.8818
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=89.16):
#   Theta for diagnosed: 0.171 ± 0.086
#   Theta for others: 0.126
#   Proportion difference: 0.045
#
# Disease 17 (signature 4, LR=80.51):
#   Theta for diagnosed: 0.171 ± 0.073
#   Theta for others: 0.117
#   Proportion difference: 0.054
#
# Disease 10 (signature 2, LR=80.00):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.070
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=75.90):
#   Theta for diagnosed: 0.176 ± 0.088
#   Theta for others: 0.128
#   Proportion difference: 0.048
#
# Disease 5 (signature 1, LR=72.14):
#   Theta for diagnosed: 0.213 ± 0.118
#   Theta for others: 0.123
#   Proportion difference: 0.090
#
# Epoch 96
# Loss: 28.8453
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=89.46):
#   Theta for diagnosed: 0.171 ± 0.086
#   Theta for others: 0.125
#   Proportion difference: 0.046
#
# Disease 17 (signature 4, LR=80.67):
#   Theta for diagnosed: 0.171 ± 0.073
#   Theta for others: 0.116
#   Proportion difference: 0.055
#
# Disease 10 (signature 2, LR=80.19):
#   Theta for diagnosed: 0.316 ± 0.258
#   Theta for others: 0.070
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=76.07):
#   Theta for diagnosed: 0.176 ± 0.088
#   Theta for others: 0.127
#   Proportion difference: 0.048
#
# Disease 5 (signature 1, LR=72.33):
#   Theta for diagnosed: 0.214 ± 0.119
#   Theta for others: 0.123
#   Proportion difference: 0.091
#
# Epoch 97
# Loss: 28.8085
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=89.77):
#   Theta for diagnosed: 0.171 ± 0.087
#   Theta for others: 0.125
#   Proportion difference: 0.046
#
# Disease 17 (signature 4, LR=80.84):
#   Theta for diagnosed: 0.171 ± 0.074
#   Theta for others: 0.116
#   Proportion difference: 0.055
#
# Disease 10 (signature 2, LR=80.38):
#   Theta for diagnosed: 0.315 ± 0.257
#   Theta for others: 0.070
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=76.24):
#   Theta for diagnosed: 0.176 ± 0.088
#   Theta for others: 0.127
#   Proportion difference: 0.048
#
# Disease 5 (signature 1, LR=72.51):
#   Theta for diagnosed: 0.214 ± 0.119
#   Theta for others: 0.123
#   Proportion difference: 0.091
#
# Epoch 98
# Loss: 28.7731
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=90.07):
#   Theta for diagnosed: 0.171 ± 0.087
#   Theta for others: 0.125
#   Proportion difference: 0.046
#
# Disease 17 (signature 4, LR=81.01):
#   Theta for diagnosed: 0.171 ± 0.074
#   Theta for others: 0.116
#   Proportion difference: 0.055
#
# Disease 10 (signature 2, LR=80.57):
#   Theta for diagnosed: 0.315 ± 0.257
#   Theta for others: 0.070
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=76.42):
#   Theta for diagnosed: 0.176 ± 0.088
#   Theta for others: 0.127
#   Proportion difference: 0.049
#
# Disease 5 (signature 1, LR=72.70):
#   Theta for diagnosed: 0.214 ± 0.119
#   Theta for others: 0.123
#   Proportion difference: 0.091
#
# Epoch 99
# Loss: 28.7386
#
# Monitoring signature responses:
#
# Disease 12 (signature 3, LR=90.38):
#   Theta for diagnosed: 0.171 ± 0.087
#   Theta for others: 0.125
#   Proportion difference: 0.046
#
# Disease 17 (signature 4, LR=81.18):
#   Theta for diagnosed: 0.171 ± 0.074
#   Theta for others: 0.116
#   Proportion difference: 0.055
#
# Disease 10 (signature 2, LR=80.76):
#   Theta for diagnosed: 0.315 ± 0.257
#   Theta for others: 0.070
#   Proportion difference: 0.245
#
# Disease 15 (signature 3, LR=76.59):
#   Theta for diagnosed: 0.176 ± 0.089
#   Theta for others: 0.127
#   Proportion difference: 0.049
#
# Disease 5 (signature 1, LR=72.88):
#   Theta for diagnosed: 0.214 ± 0.119
#   Theta for others: 0.123
#   Proportion difference: 0.091
#          11860673 function calls (11840728 primitive calls) in 749.590 seconds
#
#    Ordered by: cumulative time
#    List reduced from 4183 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000  749.591  374.795 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#    1885/2    0.030    0.000  749.591  374.795 {built-in method builtins.exec}
#         1    0.133    0.133  749.591  749.591 /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_60213/3257942964.py:12(<module>)
#         1   14.607   14.607  749.457  749.457 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:329(fit)
#       100    0.004    0.000  637.850    6.378 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:525(backward)
#       100    0.001    0.000  637.846    6.378 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#       100    0.001    0.000  637.841    6.378 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/graph.py:816(_engine_run_backward)
#       100  637.840    6.378  637.840    6.378 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       100    2.137    0.021   94.925    0.949 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:230(compute_loss)
#       100   44.724    0.447   90.654    0.907 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:287(compute_gp_prior_loss)
#   5010000   31.829    0.000   31.829    0.000 {built-in method torch.cholesky_solve}
#   5012300   14.024    0.000   14.145    0.000 {built-in method torch.sum}
#       200    0.261    0.001    2.021    0.010 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:221(forward)
#       100    0.155    0.002    1.414    0.014 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:403(analyze_signature_responses)
#       200    0.002    0.000    1.350    0.007 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/functional.py:210(einsum)
#       200    1.348    0.007    1.348    0.007 {built-in method torch.einsum}
#       300    0.570    0.002    0.570    0.002 {built-in method torch.log}
#       105    0.000    0.000    0.523    0.005 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_compile.py:22(inner)
#    3521/2    0.004    0.000    0.498    0.249 <frozen importlib._bootstrap>:1002(_find_and_load)
#     870/2    0.001    0.000    0.498    0.249 <frozen importlib._bootstrap>:967(_find_and_load_unlocked)

# %%
history_new[0]
# Out:
# [38.567283630371094,
#  175.91188049316406,
#  50.815956115722656,
#  69.8587646484375,
#  111.37569427490234,
#  91.61507415771484,
#  54.876407623291016,
#  41.48872756958008,
#  54.63877487182617,
#  69.11747741699219,
#  66.20284271240234,
#  51.12487030029297,
#  39.07109069824219,
#  38.686683654785156,
#  46.230674743652344,
#  51.48394012451172,
#  48.817142486572266,
#  41.3089599609375,
#  35.743385314941406,
#  35.81332778930664,
#  39.45938491821289,
#  41.80901336669922,
#  40.28535079956055,
#  36.52508544921875,
#  33.952999114990234,
#  34.248512268066406,
#  36.07848358154297,
#  36.9130973815918,
#  35.72234344482422,
#  33.70249557495117,
#  32.678218841552734,
#  33.17937469482422,
#  34.12476348876953,
#  34.19719696044922,
#  33.24092102050781,
#  32.212886810302734,
#  31.98686408996582,
#  32.4478874206543,
#  32.783992767333984,
#  32.482872009277344,
#  31.83417510986328,
#  31.466114044189453,
#  31.58884048461914,
#  31.83188819885254,
#  31.765480041503906,
#  31.40199089050293,
#  31.102134704589844,
#  31.09286117553711,
#  31.223445892333984,
#  31.209922790527344,
#  30.99802589416504,
#  30.787460327148438,
#  30.74374008178711,
#  30.801084518432617,
#  30.784523010253906,
#  30.64713478088379,
#  30.505544662475586,
#  30.46257781982422,
#  30.478282928466797,
#  30.446901321411133,
#  30.34583282470703,
#  30.24993896484375,
#  30.21512794494629,
#  30.207395553588867,
#  30.164390563964844,
#  30.08439826965332,
#  30.017578125,
#  29.988004684448242,
#  29.965173721313477,
#  29.91604995727539,
#  29.851472854614258,
#  29.802886962890625,
#  29.774127960205078,
#  29.740936279296875,
#  29.69074249267578,
#  29.638578414916992,
#  29.60019302368164,
#  29.56894874572754,
#  29.529544830322266,
#  29.4821834564209,
#  29.439380645751953,
#  29.405019760131836,
#  29.37006950378418,
#  29.328533172607422,
#  29.285991668701172,
#  29.24892807006836,
#  29.214601516723633,
#  29.176950454711914,
#  29.136566162109375,
#  29.09855842590332,
#  29.06368064880371,
#  29.027936935424805,
#  28.989776611328125,
#  28.952089309692383,
#  28.916767120361328,
#  28.881832122802734,
#  28.845333099365234,
#  28.808494567871094,
#  28.773134231567383,
#  28.73858070373535]

# %%
model.kappa
# Out:
# Parameter containing:
# tensor([4.1750], requires_grad=True)

# %%
def plot_training_evolution(history_tuple):
    losses, gradient_history = history_tuple
    
    plt.figure(figsize=(15, 5))
    
    # Plot loss
    plt.subplot(1, 3, 1)
    plt.plot(losses, label='Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Evolution')
    #plt.yscale('log')
    plt.legend()
    
    # Plot lambda gradients
    plt.subplot(1, 3, 2)
    lambda_norms = [torch.norm(g).item() for g in gradient_history['lambda_grad']]
    plt.plot(lambda_norms, label='Lambda gradients')
    #plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Gradient norm')
    plt.title('Lambda Gradient Evolution')
    plt.legend()
    
    # Plot phi gradients
    plt.subplot(1, 3, 3)
    phi_norms = [torch.norm(g).item() for g in gradient_history['phi_grad']]
    plt.plot(phi_norms, label='Phi gradients')
    #plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Gradient norm')
    plt.title('Phi Gradient Evolution')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
plot_training_evolution(history_new)

# %%
lambda_nans = [torch.isnan(g).any().item() for g in history_new[1]['lambda_grad']]
phi_nans = [torch.isnan(g).any().item() for g in history_new[1]['phi_grad']]

# %%
initial_psi
# Out:
# tensor([[ 1.,  1.,  1.,  1., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3.,  1.,  1.,  1.,  1., -3., -3., -3., -3., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3.,  1.,  1.,  1.,  1., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,  1.,  1.,
#           1.,  1., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,
#          -3., -3.,  1.,  1.,  1.,  1.]])

# %%
model.psi
# Out:
# Parameter containing:
# tensor([[ 0.9678,  0.9404,  1.1762,  1.5202, -2.9575, -3.0039, -2.9336, -3.0267,
#          -3.0726, -3.0903, -2.9361, -3.0595, -3.1508, -3.0357, -2.9306, -3.0769,
#          -2.8171, -3.1153, -2.9663, -3.0258],
#         [-3.0755, -3.0943, -2.9355, -3.0469,  0.9336,  1.3202,  1.3046,  0.6715,
#          -2.9559, -3.0948, -2.8862, -2.9761, -3.0250, -3.0767, -3.0760, -3.0658,
#          -2.7624, -3.0203, -2.9755, -3.0433],
#         [-2.9628, -3.1361, -3.0723, -3.2058, -2.8912, -2.9936, -3.0321, -3.2418,
#           0.4111,  0.7559,  0.9422,  0.7140, -3.2694, -3.0147, -3.0468, -2.6448,
#          -2.7657, -3.2016, -2.7955, -2.9989],
#         [-2.9853, -3.0250, -2.9313, -3.0259, -3.0129, -2.9349, -2.9970, -3.1082,
#          -3.0547, -3.0442, -3.0467, -3.1421, -0.0938,  0.9967,  0.8102,  1.7079,
#          -2.9578, -3.1036, -3.1036, -2.9700],
#         [-3.0489, -2.9660, -3.0529, -2.8578, -2.9819, -2.8280, -2.9865, -3.0912,
#          -2.8952, -3.0660, -3.0218, -3.1449, -3.1301, -3.0035, -2.9635, -3.0033,
#           1.6455,  0.8654,  1.1486,  0.9449]], requires_grad=True)

# %%
model.kappa
# Out:
# Parameter containing:
# tensor([4.1750], requires_grad=True)

# %%
# For plotting smoothed prevalences
def plot_smoothed_prevalences(model, data):
    # Data smoothed prevalence
    data_prev = data['Y'].mean(axis=0)  # Average across individuals
    
    # Model smoothed prevalence (using mu_d/logit_prev_t)
    model_prev = torch.sigmoid(model.logit_prev_t)  # Convert logits to probabilities
    
    plt.figure(figsize=(10, 6))
    
    # Plot for each disease
    for d in range(data_prev.shape[0]):
        plt.plot(data_prev[d], 'b-', alpha=0.3, label='Data' if d==0 else '')
        plt.plot(model_prev[:, d].detach().numpy(), 'r--', alpha=0.3, 
                label='Model' if d==0 else '')
    
    plt.xlabel('Time')
    plt.ylabel('Prevalence')
    plt.title('Smoothed Prevalences: Data vs Model')
    plt.legend()
    plt.yscale('log')  # Optional: use log scale if prevalences vary widely
    plt.grid(True)
    plt.show()

# %%
with torch.no_grad():
    pi_pred, theta, phi = model.forward()
    pi_pred = pi_pred.cpu().numpy()

# %%
model.visualize_initialization()

# %%
# For plotting smoothed prevalences
def plot_smoothed_prevalences(model, data):
    # Data smoothed prevalence
    data_prev = compute_smoothed_prevalence(data['Y'])  # Average across individuals
    
    # Model smoothed prevalence (using mu_d/logit_prev_t)
    model_prev = torch.sigmoid(model.logit_prev_t)  # Convert logits to probabilities
    
    plt.figure(figsize=(10, 6))
    
    # Plot for each disease
    for d in range(data_prev.shape[0]):
        plt.plot(data_prev[d], 'b-', alpha=0.3, label='Data' if d==0 else '')
        plt.plot(model_prev[d, :].detach().numpy(), 'r--', alpha=0.3, 
                label='Model' if d==0 else '')
    
    plt.xlabel('Time')
    plt.ylabel('Prevalence')
    plt.title('Smoothed Prevalences: Data vs Model')
    plt.legend()
    plt.yscale('log')  # Optional: use log scale if prevalences vary widely
    plt.grid(True)
    plt.show()

plot_smoothed_prevalences(model, data)

# %%
# Mean predicted probability for disease 3 over time
mean_pred_d3 = pi_pred[:, 3, :].mean(axis=0)  # Average across people

# Actual prevalence for disease 3 over time
real_prev_pi = data['pi'][:, 3, :].mean(axis=0)  # Average across people

#real_prev_d3 = data['Y'][:, 3, :].mean(axis=0)  # Average across people

real_prev_d3 = model.prevalence_t[3,:]  # Average across people

# Plot comparison
plt.figure(figsize=(10,6))
plt.plot(mean_pred_d3, label='Model Predicted average pi for disease 3')
plt.plot(real_prev_pi, label='Actual Average Pi for disease 3 ')
plt.plot(real_prev_d3, label='Actual Incidence for disease 3')
plt.title('Disease 3: Predicted vs Actual Prevalence')
plt.legend()
plt.show()

# %%
# Mean predicted probability for disease 3 over time
mean_pred_d3 = pi_pred[1, 3, :]  # Average across people

# Actual prevalence for disease 3 over time
real_prev_pi = data['pi'][1,3, :]  # Average across people

#real_prev_d3 = data['Y'][:, 3, :].mean(axis=0)  # Average across people

#real_prev_d3 = model.prevalence_t[3,:]  # Average across people

# Plot comparison
plt.figure(figsize=(10,6))
plt.plot(mean_pred_d3, label='Model Predicted person 1 pi for disease 3')
plt.plot(real_prev_pi, label='Actual person 1  for disease 3 ')
#plt.plot(real_prev_d3, label='Actual Incidence for disease 3')
plt.title('Disease 3: Predicted vs Actual Prevalence')
plt.legend()
plt.show()

# %%
# Average over all diseases and all individuals
mean_pred_all = pi_pred.mean(axis=(0,1))  # Average across people and diseases
real_incidence_all = model.prevalence_t.mean(axis=0)  # Average across diseases
real_pi_all = data['pi'].mean(axis=(0,1)) # Average across diseases

plt.figure(figsize=(10,6))
plt.plot(mean_pred_all, 'b-', label='Model Predicted')
plt.plot(real_incidence_all, 'r-', label='Actual Prevalence') 
plt.plot(real_pi_all, 'g-', label='Simulated pi') 


plt.title('Average Disease Prevalence: Predicted vs Actual')
plt.xlabel('Time')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %%
model.kappa
# Out:
# Parameter containing:
# tensor([4.1750], requires_grad=True)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()
#observed_risk=mu_dt_flat
# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor
print(scale_factor)
print(np.mean(observed_risk))
print(np.mean(predicted_risk)) 
print(np.mean(calibrated_risk))
# Out:
# 0.39692518
# 0.0083208
# 0.020963145
# 0.0083208

# %%
calibrated_risk.shape
# Out:
# (1000,)

# %%
scale_factor
# Out:
# np.float32(0.39692518)

# %%
# Average over all diseases and all individuals
mean_pred_all = pi_pred.mean(axis=(0,1))
#mean_pred_all = pi_pred.mean(axis=(0,1))  # Average across people and diseases
real_incidence_all = model.prevalence_t.mean(axis=0)  # Average across diseases
#real_pi_all = calibrated_risk.mean(axis=(0,1)) # Average across diseases

plt.figure(figsize=(10,6))
plt.plot(mean_pred_all, 'b-', label='Model Predicted')
plt.plot(real_incidence_all, 'r-', label='Actual Prevalence') 
plt.plot(real_pi_all, 'g-', label='Simulated pi') 


plt.title('Average Disease Prevalence: Predicted vs Actual')
plt.xlabel('Time')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %%
# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.008321
# Mean predicted risk (original): 0.020963
# Mean predicted risk (calibrated): 0.008321
# Calibration scale factor: 0.397

# %%
def plot_hazard_comparison(Y, pi_pred, true_pi, calibration_factor):
    N, D, T = Y.shape
    
    # Create at_risk mask
    at_risk = np.ones_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            event_times = np.where(Y[n,d,:])[0]
            if len(event_times) > 0:
                at_risk[n,d,(event_times[0]+1):] = False
    
    # Apply calibration to predictions
    calibrated_pred = pi_pred * calibration_factor
    
    # Calculate means for at-risk only
    mean_pred = []
    mean_true = []
    mean_obs = []
    for t in range(T):
        mask_t = at_risk[:,:,t]
        if mask_t.sum() > 0:
            mean_pred.append(calibrated_pred[:,:,t][mask_t].mean())
            mean_true.append(true_pi[:,:,t][mask_t].mean())
            mean_obs.append(Y[:,:,t][mask_t].mean())
    
    plt.figure(figsize=(12,8))
    plt.plot(mean_pred, 'b-', label='Calibrated Model Prediction')
    plt.plot(mean_true, 'g--', label='True Hazard')
    plt.plot(mean_obs, 'r.', label='Observed Events')
    plt.title('Hazard Rates (At-Risk Individuals)')
    plt.xlabel('Time')
    plt.ylabel('Hazard')
    plt.legend()
    plt.show()

# %%
def calculate_calibration_factor(Y, pi_pred, true_pi):
    """
    Calculate calibration factor comparing predictions to true hazards
    Only using at-risk times
    """
    # Create at_risk mask
    N, D, T = Y.shape
    at_risk = np.ones_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            event_times = np.where(Y[n,d,:])[0]
            if len(event_times) > 0:
                at_risk[n,d,(event_times[0]+1):] = False
    
    # Get valid predictions and true values
    valid_pred = pi_pred[at_risk]
    valid_true = true_pi[at_risk]
    
    # Calculate calibration factor
    calibration_factor = valid_true.mean() / valid_pred.mean()
    
    print(f"Mean predicted: {valid_pred.mean():.6f}")
    print(f"Mean true: {valid_true.mean():.6f}")
    print(f"Calibration factor: {calibration_factor:.4f}")
    
    return calibration_factor

# %%
calculate_calibration_factor(Y, pi_pred, data['pi'])
# Out:
# Mean predicted: 0.009394
# Mean true: 0.009513
# Calibration factor: 1.0127
# np.float64(1.0127264350805427)

# %%
plot_hazard_comparison(data['Y'], pi_pred, data['pi'],1)

# %%
def calculate_fair_calibration_factor(Y, pi_pred):
    N, D, T = Y.shape
    
    # Create at_risk mask
    at_risk = np.ones_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            event_times = np.where(Y[n,d,:])[0]
            if len(event_times) > 0:
                at_risk[n,d,(event_times[0]+1):] = False
    
    # Calculate ratio of observed events to predictions for at-risk individuals
    total_observed = 0
    total_predicted = 0
    
    for t in range(T):
        mask_t = at_risk[:,:,t]
        if mask_t.sum() > 0:
            total_observed += Y[:,:,t][mask_t].sum()
            total_predicted += pi_pred[:,:,t][mask_t].sum()
    
    return total_observed / total_predicted if total_predicted > 0 else 1.0

cf=calculate_fair_calibration_factor(Y, pi_pred)

# %%
cf
# Out:
# np.float32(1.0123923)

# %%
# Calibration plot
from clust_huge_amp_w_warp import plot_calibration_at_risk
plot_calibration_at_risk(pi_pred, data['Y'],use_log_scale=True)
# Out:
# MSE: 8.09e-03
# Mean Predicted: 9.39e-03
# Mean Observed: 9.51e-03
# N total: 8,749,563
# ([np.float32(1.0223168e-06),
#   np.float32(2.8630873e-06),
#   np.float32(5.6846843e-06),
#   np.float32(1.13841625e-05),
#   np.float32(2.292729e-05),
#   np.float32(4.5582456e-05),
#   np.float32(9.139727e-05),
#   np.float32(0.00018336218),
#   np.float32(0.00036796342),
#   np.float32(0.0007354409),
#   np.float32(0.0014614967),
#   np.float32(0.0028774315),
#   np.float32(0.0058001042),
#   np.float32(0.011233682),
#   np.float32(0.02256532),
#   np.float32(0.04542197),
#   np.float32(0.08899129),
#   np.float32(0.16372822),
#   np.float32(0.30677485),
#   np.float32(0.65298504)],
#  [np.float64(5.9618220468697715e-06),
#   np.float64(5.053797676263828e-05),
#   np.float64(9.011874469889738e-05),
#   np.float64(0.0001261901306698803),
#   np.float64(8.792576360143928e-05),
#   np.float64(0.00019282188399835458),
#   np.float64(0.0002447053339936493),
#   np.float64(0.00022882247952038808),
#   np.float64(0.0004109392015451314),
#   np.float64(0.0005709480530361094),
#   np.float64(0.000727156145747182),
#   np.float64(0.0014449362942282142),
#   np.float64(0.0029047748615635776),
#   np.float64(0.007018888150742844),
#   np.float64(0.01713543569138358),
#   np.float64(0.03451631739440732),
#   np.float64(0.08906789575814986),
#   np.float64(0.24572001394700138),
#   np.float64(0.5297457417921501),
#   np.float64(0.9771754636233951)],
#  [np.int64(3857881),
#   np.int64(197871),
#   np.int64(188640),
#   np.int64(158491),
#   np.int64(147852),
#   np.int64(155584),
#   np.int64(171635),
#   np.int64(196659),
#   np.int64(243345),
#   np.int64(322271),
#   np.int64(430444),
#   np.int64(489987),
#   np.int64(543932),
#   np.int64(529856),
#   np.int64(369585),
#   np.int64(339086),
#   np.int64(282919),
#   np.int64(114720),
#   np.int64(8102),
#   np.int64(701)])

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_true_calibration(pi_pred, true_pi, Y, n_bins=20, use_log_scale=False, min_bin_count=50):
    """
    Plots calibration curve: predicted pi vs. true pi (ground truth), at at-risk times.
    """
    # Ensure numpy arrays
    if hasattr(pi_pred, 'detach'):
        pi_pred = pi_pred.detach().cpu().numpy()
    if hasattr(true_pi, 'detach'):
        true_pi = true_pi.detach().cpu().numpy()
    if hasattr(Y, 'detach'):
        Y = Y.detach().cpu().numpy()
    N, D, T = Y.shape

    # At-risk mask
    at_risk = np.ones_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            event_times = np.where(Y[n, d, :])[0]
            if len(event_times) > 0:
                at_risk[n, d, (event_times[0]+1):] = False

    pred = pi_pred[at_risk]
    truth = true_pi[at_risk]

    # Bin by predicted probability
    if use_log_scale:
        bin_edges = np.logspace(np.log10(max(1e-7, pred.min())), np.log10(pred.max()), n_bins + 1)
    else:
        bin_edges = np.linspace(pred.min(), pred.max(), n_bins + 1)

    bin_means = []
    truth_means = []
    counts = []

    for i in range(n_bins):
        mask = (pred >= bin_edges[i]) & (pred < bin_edges[i + 1])
        if np.sum(mask) >= min_bin_count:
            bin_means.append(np.mean(pred[mask]))
            truth_means.append(np.mean(truth[mask]))
            counts.append(np.sum(mask))

    # Plot
    plt.figure(figsize=(7, 7))
    if use_log_scale:
        plt.xscale('log')
        plt.yscale('log')
        plt.plot([1e-7, 1], [1e-7, 1], '--', color='gray', label='Perfect calibration')
    else:
        plt.plot([0, 1], [0, 1], '--', color='gray', label='Perfect calibration')

    plt.plot(bin_means, truth_means, 'o-', label='True risk')
    plt.xlabel('Predicted Event Rate')
    plt.ylabel('True Event Rate')
    plt.title('Calibration to Ground Truth (At-Risk Only)')
    plt.legend()
    plt.grid(True, which='both', linestyle='--', alpha=0.3)
    plt.show()

    # Print summary stats
    mse = np.mean((np.array(bin_means) - np.array(truth_means))**2)
    print(f'MSE: {mse:.2e}')
    print(f'Mean Predicted: {np.mean(pred):.2e}')
    print(f'Mean True: {np.mean(truth):.2e}')
    print(f'N total: {len(pred):,}')

    return bin_means, truth_means, counts

# Example usage:
plot_true_calibration(pi_pred, data['pi'], data['Y'], n_bins=20, use_log_scale=True)
# Out:
# MSE: 5.70e-03
# Mean Predicted: 9.39e-03
# Mean True: 9.51e-03
# N total: 8,749,563
# ([np.float32(1.0223168e-06),
#   np.float32(2.8630873e-06),
#   np.float32(5.6846843e-06),
#   np.float32(1.13841625e-05),
#   np.float32(2.292729e-05),
#   np.float32(4.5582456e-05),
#   np.float32(9.139727e-05),
#   np.float32(0.00018336218),
#   np.float32(0.00036796342),
#   np.float32(0.0007354409),
#   np.float32(0.0014614967),
#   np.float32(0.0028774315),
#   np.float32(0.0058001042),
#   np.float32(0.011233682),
#   np.float32(0.02256532),
#   np.float32(0.04542197),
#   np.float32(0.08899129),
#   np.float32(0.16372822),
#   np.float32(0.30677485),
#   np.float32(0.65298504)],
#  [np.float64(7.415973445148507e-06),
#   np.float64(7.023299990805937e-05),
#   np.float64(0.00011960481032888445),
#   np.float64(0.00013981734356819056),
#   np.float64(0.00014055276912096763),
#   np.float64(0.00019492813654580128),
#   np.float64(0.0002542571673830578),
#   np.float64(0.00034456338512557974),
#   np.float64(0.0004735219400534184),
#   np.float64(0.0006722989791865243),
#   np.float64(0.001002544212171623),
#   np.float64(0.001914120873498421),
#   np.float64(0.004084051665353146),
#   np.float64(0.00899710762293857),
#   np.float64(0.020425429200732998),
#   np.float64(0.04536884844938479),
#   np.float64(0.09737006602383765),
#   np.float64(0.1842793920300413),
#   np.float64(0.30263588120184254),
#   np.float64(0.31618013857707306)],
#  [np.int64(3857881),
#   np.int64(197871),
#   np.int64(188640),
#   np.int64(158491),
#   np.int64(147852),
#   np.int64(155584),
#   np.int64(171635),
#   np.int64(196659),
#   np.int64(243345),
#   np.int64(322271),
#   np.int64(430444),
#   np.int64(489987),
#   np.int64(543932),
#   np.int64(529856),
#   np.int64(369585),
#   np.int64(339086),
#   np.int64(282919),
#   np.int64(114720),
#   np.int64(8102),
#   np.int64(701)])
