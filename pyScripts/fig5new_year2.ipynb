# %% [markdown]
# ## interesting, seems better using joint phi that has

# %%
import glob
import os
from re import X
import torch
import numpy as np
import pandas as pd
from fig5utils import evaluate_major_diseases_wsex_with_bootstrap
from clust_huge_amp import *
# --- Fixed resources ---------------------------------------------------------
initial_psi = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt")
initial_clusters = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt")
signature_refs = torch.load(
    "/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/data_for_running/reference_trajectories.pt"
)["signature_refs"]

# master tensors; adjust paths if they live elsewhere
E_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_enrollment_full.pt")
pce_df = pd.read_csv("/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/pce_prevent_full.csv")
disease_names=pd.read_csv("/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/disease_names.csv")
# helper to build model & evaluate one batch
def eval_batch(ckpt_path):
    ckpt = torch.load(ckpt_path, map_location="cpu")
    start = ckpt["indices"][0]
    stop = ckpt["indices"][-1]+1  # indices saved in each checkpoint

    # slice tensors for this batch
    Y_batch = ckpt["Y"]
    E_batch = E_full[start:stop]
    cov_batch = pce_df.iloc[start:stop].reset_index(drop=True)
    if "Sex" not in cov_batch.columns and "sex" in cov_batch.columns:
        cov_batch = cov_batch.rename(columns={"sex": "Sex"})
    cov_batch = cov_batch.assign(Sex=cov_batch["Sex"], age=cov_batch["age"])  # keep original naming, but ensure present

    # append sex column to G slice (if training did)
    sex = cov_batch["Sex"].to_numpy()
    G_batch = ckpt["G"]

    model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
        N=Y_batch.shape[0],
        D=Y_batch.shape[1],
        T=Y_batch.shape[2],
        K=20,
        P=G_batch.shape[1],
        init_sd_scaler=1e-1,
        G=G_batch,
        Y=Y_batch.numpy(),
        genetic_scale=1,
        W=0.0001,
        R=0,
        prevalence_t=ckpt["prevalence_t"],
        signature_references=signature_refs,
        healthy_reference=True,
        disease_names=disease_names['x'],
    )
    model.initialize_params(true_psi=initial_psi)
    model.clusters = ckpt["clusters"]
    model.load_state_dict(ckpt["model_state_dict"])
    model.eval()

    results = evaluate_major_diseases_wsex_with_bootstrap(
        model=model,
        Y_100k=Y_batch,
        E_100k=E_batch,
        disease_names=disease_names['x'],
        pce_df=cov_batch,
        n_bootstraps=20,
        follow_up_duration_years=5,
    )
    return (start, stop), results

# --- loop through all checkpoints --------------------------------------------
ckpt_dir = "/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs"
ckpt_paths = sorted(glob.glob(os.path.join(ckpt_dir, "enrollment_model_W0.0001_batch_*_*.pt")))

batch_results = {}
for ckpt_path in ckpt_paths:
    (start, stop), res = eval_batch(ckpt_path)
    batch_results[(start, stop)] = res
    print(f"Finished {start}-{stop}")
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/3639063121.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/3639063121.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/3639063121.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   signature_refs = torch.load(
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/3639063121.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_enrollment_full.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/3639063121.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0026,  0.0050,  0.0103,  0.0132, -0.0116])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0011, -0.0023,  0.0073,  0.0020, -0.0051])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0014, -0.0038,  0.0025,  0.0024, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0088, -0.0010, -0.0120,  0.0372, -0.0093])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0051,  0.0055, -0.0040,  0.0058,  0.0238])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0018,  0.0010, -0.0011, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0075,  0.0045, -0.0065,  0.0055, -0.0043])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0032, -0.0005,  0.0003,  0.0114, -0.0019])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([-0.0003,  0.0084,  0.0164, -0.0027,  0.0004])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0123, -0.0048,  0.0016, -0.0047,  0.0018])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0068,  0.0008, -0.0014,  0.0007,  0.0027])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 0.0086,  0.0104, -0.0006,  0.0071, -0.0017])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([-0.0015,  0.0126,  0.0149, -0.0003,  0.0101])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0162, -0.0025,  0.0116,  0.0191, -0.0034])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0008, -0.0014,  0.0007,  0.0034,  0.0015])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.9623, -13.8155])
# Base value centered (first 5): tensor([-0.1879, -0.1879, -0.1879,  1.6653, -0.1879])
# Base value centered mean: -3.345489574257954e-07
# Gamma init for k=0 (first 5): tensor([ 0.0074,  0.0061, -0.0054,  0.0060,  0.0235])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.3449, -13.3449, -12.4036])
# Base value centered (first 5): tensor([ 0.1505, -0.3201,  0.1505,  0.1505,  1.0918])
# Base value centered mean: -1.8495559288567165e-06
# Gamma init for k=1 (first 5): tensor([0.0042, 0.0009, 0.0009, 0.0018, 0.0015])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1566, -11.8388, -12.4977])
# Base value centered (first 5): tensor([-0.3849, -0.3849,  0.2740,  1.5918,  0.9329])
# Base value centered mean: 9.290695288655115e-07
# Gamma init for k=2 (first 5): tensor([ 0.0016,  0.0073,  0.0100,  0.0140, -0.0118])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.6950, -13.5744])
# Base value centered (first 5): tensor([-0.1026, -0.1026, -0.1026,  0.0179,  0.1384])
# Base value centered mean: 4.7445297468584613e-07
# Gamma init for k=3 (first 5): tensor([ 0.0012,  0.0003,  0.0016,  0.0018, -0.0006])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155,  -9.8620, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1133,  3.8402, -0.1133, -0.1133, -0.1133])
# Base value centered mean: -2.841758714566822e-06
# Gamma init for k=4 (first 5): tensor([-0.0172, -0.0033,  0.0143,  0.0225, -0.0033])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=5 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1523, -0.1523, -0.1523, -0.1523, -0.1523])
# Base value centered mean: -1.0890006478803116e-06
# Gamma init for k=6 (first 5): tensor([ 0.0090,  0.0121, -0.0006,  0.0042, -0.0027])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.3663, -13.8155, -13.3663, -13.8155, -11.1200])
# Base value centered (first 5): tensor([-0.1005, -0.5497, -0.1005, -0.5497,  2.1458])
# Base value centered mean: 1.2460708376238472e-06
# Gamma init for k=7 (first 5): tensor([ 0.0003, -0.0038, -0.0111,  0.0251, -0.0016])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1159, -0.1159, -0.1159, -0.1159, -0.1159])
# Base value centered mean: -1.4129639112070436e-06
# Gamma init for k=8 (first 5): tensor([ 0.0066, -0.0055,  0.0011, -0.0020, -0.0005])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=9 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=10 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=11 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0860, -0.0860, -0.0860, -0.0860, -0.0860])
# Base value centered mean: -1.034450519910024e-06
# Gamma init for k=12 (first 5): tensor([ 0.0080, -0.0074,  0.0002, -0.0001, -0.0076])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.7744, -12.2949])
# Base value centered (first 5): tensor([-0.1777, -0.1777, -0.1777,  2.8635,  1.3429])
# Base value centered mean: -1.0064125035569305e-06
# Gamma init for k=13 (first 5): tensor([-0.0002,  0.0060,  0.0127, -0.0051,  0.0007])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.8388, -12.8271])
# Base value centered (first 5): tensor([-0.2562, -0.2562, -0.2562,  1.7205,  0.7322])
# Base value centered mean: -1.5125274330785032e-06
# Gamma init for k=14 (first 5): tensor([ 0.0038, -0.0052, -0.0089,  0.0162,  0.0005])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.8388])
# Base value centered (first 5): tensor([-0.2850, -0.2850, -0.2850, -0.2850,  1.6917])
# Base value centered mean: -1.2931823221151717e-06
# Gamma init for k=15 (first 5): tensor([-0.0039,  0.0064,  0.0118, -0.0049,  0.0086])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.7706, -13.1339])
# Base value centered (first 5): tensor([-0.2428, -0.2428, -0.2428,  1.8021,  0.4388])
# Base value centered mean: -1.9989013253507437e-06
# Gamma init for k=16 (first 5): tensor([ 0.0009,  0.0001,  0.0093,  0.0055, -0.0031])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.3272, -12.0713])
# Base value centered (first 5): tensor([-0.4228, -0.4228, -0.4228,  3.0656,  1.3214])
# Base value centered mean: -2.227592403869494e-06
# Gamma init for k=17 (first 5): tensor([ 0.0081,  0.0052, -0.0070,  0.0058, -0.0042])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=18 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([-0.1519, -0.1519, -0.1519, -0.1519,  0.2779])
# Base value centered mean: -1.1179923831150518e-06
# Gamma init for k=19 (first 5): tensor([-0.0027,  0.0053,  0.0013, -0.0016, -0.0018])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (5-Year Outcome, 1-Year Score)...
# AUC: 0.734 (0.698-0.761) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 419 (4.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.685, Events = 138/5409
#    Male: AUC = 0.724, Events = 281/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.731, Events = 5/37
#    Breast_Cancer: AUC = 0.636, Events = 6/170
#
# Evaluating Diabetes (5-Year Outcome, 1-Year Score)...
# AUC: 0.668 (0.631-0.703) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 248 (2.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.677, Events = 109/5409
#    Male: AUC = 0.652, Events = 139/4591
#
# Evaluating Atrial_Fib (5-Year Outcome, 1-Year Score)...
# AUC: 0.692 (0.659-0.721) (calculated on 9864 individuals)
# Events (5-Year in Eval Cohort): 156 (1.6%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.686, Events = 86/5372
#    Male: AUC = 0.707, Events = 70/4492
#
# Evaluating CKD (5-Year Outcome, 1-Year Score)...
# AUC: 0.690 (0.598-0.751) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 33 (0.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.759, Events = 16/5409
#    Male: AUC = 0.622, Events = 17/4591
#
# Evaluating All_Cancers (5-Year Outcome, 1-Year Score)...
# AUC: 0.705 (0.689-0.743) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 213 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.695, Events = 56/5409
#    Male: AUC = 0.691, Events = 157/4591
#
# Evaluating Stroke (5-Year Outcome, 1-Year Score)...
# AUC: 0.703 (0.625-0.763) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 41 (0.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.717, Events = 19/5409
#    Male: AUC = 0.690, Events = 22/4591
#
# Evaluating Heart_Failure (5-Year Outcome, 1-Year Score)...
# AUC: 0.741 (0.694-0.789) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 58 (0.6%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.743, Events = 24/5409
#    Male: AUC = 0.735, Events = 34/4591
#
# Evaluating Pneumonia (5-Year Outcome, 1-Year Score)...
# AUC: 0.629 (0.595-0.673) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 112 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.642, Events = 42/5409
#    Male: AUC = 0.615, Events = 70/4591
#
# Evaluating COPD (5-Year Outcome, 1-Year Score)...
# AUC: 0.653 (0.624-0.677) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 149 (1.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.665, Events = 60/5409
#    Male: AUC = 0.639, Events = 89/4591
#
# Evaluating Osteoporosis (5-Year Outcome, 1-Year Score)...
# AUC: 0.648 (0.597-0.685) (calculated on 9961 individuals)
# Events (5-Year in Eval Cohort): 73 (0.7%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.635, Events = 42/5379
#    Male: AUC = 0.668, Events = 31/4582
#
# Evaluating Anemia (5-Year Outcome, 1-Year Score)...
# AUC: 0.582 (0.540-0.618) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 201 (2.0%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.550, Events = 113/5409
#    Male: AUC = 0.623, Events = 88/4591
#
# Evaluating Colorectal_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.711 (0.667-0.790) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.663, Events = 22/5409
#    Male: AUC = 0.748, Events = 27/4591
#
# Evaluating Breast_Cancer (5-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.599 (0.548-0.656) (calculated on 5409 individuals)
# Events (5-Year in Eval Cohort): 102 (1.9%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (5-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.714 (0.683-0.755) (calculated on 4547 individuals)
# Events (5-Year in Eval Cohort): 86 (1.9%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.738 (0.658-0.798) (calculated on 9992 individuals)
# Events (5-Year in Eval Cohort): 35 (0.4%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.716, Events = 26/5406
#    Male: AUC = 0.796, Events = 9/4586
#
# Evaluating Bladder_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.729 (0.604-0.827) (calculated on 9976 individuals)
# Events (5-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.611, Events = 11/5399
#    Male: AUC = 0.860, Events = 10/4577
#
# Evaluating Secondary_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.639 (0.616-0.673) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 108 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.642, Events = 57/5409
#    Male: AUC = 0.633, Events = 51/4591
#
# Evaluating Depression (5-Year Outcome, 1-Year Score)...
# AUC: 0.514 (0.485-0.555) (calculated on 9912 individuals)
# Events (5-Year in Eval Cohort): 147 (1.5%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.497, Events = 85/5351
#    Male: AUC = 0.551, Events = 61/4561
#
# Evaluating Anxiety (5-Year Outcome, 1-Year Score)...
# AUC: 0.464 (0.404-0.499) (calculated on 9975 individuals)
# Events (5-Year in Eval Cohort): 58 (0.6%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.494, Events = 34/5391
#    Male: AUC = 0.423, Events = 24/4584
#
# Evaluating Bipolar_Disorder (5-Year Outcome, 1-Year Score)...
# AUC: 0.462 (0.261-0.572) (calculated on 9984 individuals)
# Events (5-Year in Eval Cohort): 19 (0.2%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.561, Events = 7/5399
#    Male: AUC = 0.407, Events = 12/4585
#
# Evaluating Rheumatoid_Arthritis (5-Year Outcome, 1-Year Score)...
# AUC: 0.594 (0.527-0.663) (calculated on 9963 individuals)
# Events (5-Year in Eval Cohort): 42 (0.4%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.618, Events = 24/5381
#    Male: AUC = 0.565, Events = 18/4582
#
# Evaluating Psoriasis (5-Year Outcome, 1-Year Score)...
# AUC: 0.393 (0.322-0.543) (calculated on 9981 individuals)
# Events (5-Year in Eval Cohort): 14 (0.1%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.525, Events = 5/5405
#    Male: AUC = 0.322, Events = 9/4576
#
# Evaluating Ulcerative_Colitis (5-Year Outcome, 1-Year Score)...
# AUC: 0.627 (0.475-0.715) (calculated on 9947 individuals)
# Events (5-Year in Eval Cohort): 23 (0.2%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.692, Events = 12/5378
#    Male: AUC = 0.558, Events = 11/4569
#
# Evaluating Crohns_Disease (5-Year Outcome, 1-Year Score)...
# AUC: 0.523 (0.246-0.809) (calculated on 9967 individuals)
# Events (5-Year in Eval Cohort): 9 (0.1%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.493, Events = 6/5388
#    Male: AUC = 0.582, Events = 3/4579
#
# Evaluating Asthma (5-Year Outcome, 1-Year Score)...
# AUC: 0.539 (0.504-0.569) (calculated on 9687 individuals)
# Events (5-Year in Eval Cohort): 302 (3.0%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.519, Events = 156/5214
#    Male: AUC = 0.606, Events = 134/4473
#
# Evaluating Parkinsons (5-Year Outcome, 1-Year Score)...
# AUC: 0.763 (0.639-0.865) (calculated on 9997 individuals)
# Events (5-Year in Eval Cohort): 15 (0.1%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.850, Events = 7/5407
#    Male: AUC = 0.687, Events = 8/4590
#
# Evaluating Multiple_Sclerosis (5-Year Outcome, 1-Year Score)...
# AUC: 0.595 (0.419-0.731) (calculated on 9979 individuals)
# Events (5-Year in Eval Cohort): 11 (0.1%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.552, Events = 8/5394
#    Male: AUC = 0.709, Events = 3/4585
#
# Evaluating Thyroid_Disorders (5-Year Outcome, 1-Year Score)...
# AUC: 0.602 (0.578-0.630) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 226 (2.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.598, Events = 191/5409
#    Male: AUC = 0.579, Events = 35/4591
#
# Summary of Results (Prospective 5-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.734 (0.698-0.761)       419        4.2
# Diabetes             0.668 (0.631-0.703)       248        2.5
# Atrial_Fib           0.692 (0.659-0.721)       156        1.6
# CKD                  0.690 (0.598-0.751)       33         0.3
# All_Cancers          0.705 (0.689-0.743)       213        2.1
# Stroke               0.703 (0.625-0.763)       41         0.4
# Heart_Failure        0.741 (0.694-0.789)       58         0.6
# Pneumonia            0.629 (0.595-0.673)       112        1.1
# COPD                 0.653 (0.624-0.677)       149        1.5
# Osteoporosis         0.648 (0.597-0.685)       73         0.7
# Anemia               0.582 (0.540-0.618)       201        2.0
# Colorectal_Cancer    0.711 (0.667-0.790)       49         0.5
# Breast_Cancer        0.599 (0.548-0.656)       102        1.9
# Prostate_Cancer      0.714 (0.683-0.755)       86         1.9
# Lung_Cancer          0.738 (0.658-0.798)       35         0.4
# Bladder_Cancer       0.729 (0.604-0.827)       21         0.2
# Secondary_Cancer     0.639 (0.616-0.673)       108        1.1
# Depression           0.514 (0.485-0.555)       147        1.5
# Anxiety              0.464 (0.404-0.499)       58         0.6
# Bipolar_Disorder     0.462 (0.261-0.572)       19         0.2
# Rheumatoid_Arthritis 0.594 (0.527-0.663)       42         0.4
# Psoriasis            0.393 (0.322-0.543)       14         0.1
# Ulcerative_Colitis   0.627 (0.475-0.715)       23         0.2
# Crohns_Disease       0.523 (0.246-0.809)       9          0.1
# Asthma               0.539 (0.504-0.569)       302        3.0
# Parkinsons           0.763 (0.639-0.865)       15         0.1
# Multiple_Sclerosis   0.595 (0.419-0.731)       11         0.1
# Thyroid_Disorders    0.602 (0.578-0.630)       226        2.3
# --------------------------------------------------------------------------------
# Finished 0-10000
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/3639063121.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 42 diseases
# Cluster 1: 24 diseases
# Cluster 2: 8 diseases
# Cluster 3: 5 diseases
# Cluster 4: 8 diseases
# Cluster 5: 13 diseases
# Cluster 6: 60 diseases
# Cluster 7: 30 diseases
# Cluster 8: 7 diseases
# Cluster 9: 19 diseases
# Cluster 10: 10 diseases
# Cluster 11: 15 diseases
# Cluster 12: 16 diseases
# Cluster 13: 11 diseases
# Cluster 14: 7 diseases
# Cluster 15: 7 diseases
# Cluster 16: 12 diseases
# Cluster 17: 16 diseases
# Cluster 18: 22 diseases
# Cluster 19: 16 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 42
# Base value (first 5): tensor([-13.5802, -13.8155, -13.8155, -13.8155, -13.5802])
# Base value centered (first 5): tensor([ 0.1123, -0.1230, -0.1230, -0.1230,  0.1123])
# Base value centered mean: -4.872322278970387e-07
# Gamma init for k=0 (first 5): tensor([ 3.5662e-04,  2.1659e-03, -1.1390e-05, -5.6056e-03,  4.5262e-03])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 24
# Base value (first 5): tensor([-13.8155, -13.4037, -13.8155, -12.9919, -13.8155])
# Base value centered (first 5): tensor([-0.2507,  0.1611, -0.2507,  0.5729, -0.2507])
# Base value centered mean: -3.0660628453915706e-06
# Gamma init for k=1 (first 5): tensor([-0.0004,  0.0093,  0.0011,  0.0004,  0.0019])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1150, -0.1150, -0.1150, -0.1150, -0.1150])
# Base value centered mean: -2.318954557267716e-06
# Gamma init for k=2 (first 5): tensor([ 0.0038,  0.0085,  0.0110, -0.0038,  0.0126])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 5
# Base value (first 5): tensor([-13.8155, -11.8388, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2868,  1.6899, -0.2868, -0.2868, -0.2868])
# Base value centered mean: -1.7898559008244774e-06
# Gamma init for k=3 (first 5): tensor([-0.0036, -0.0012, -0.0132, -0.0140, -0.0126])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1599, -0.1599, -0.1599, -0.1599, -0.1599])
# Base value centered mean: -1.6735076542317984e-06
# Gamma init for k=4 (first 5): tensor([ 0.0080,  0.0083,  0.0044,  0.0091, -0.0020])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1988, -0.1988, -0.1988, -0.1988, -0.1988])
# Base value centered mean: 5.046844648859405e-07
# Gamma init for k=5 (first 5): tensor([ 0.0004,  0.0035, -0.0051,  0.0044, -0.0024])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 60
# Base value (first 5): tensor([-13.6508, -13.6508, -13.6508, -13.6508, -13.8155])
# Base value centered (first 5): tensor([ 0.0040,  0.0040,  0.0040,  0.0040, -0.1608])
# Base value centered mean: -3.2844542374732555e-07
# Gamma init for k=6 (first 5): tensor([8.4989e-04, 2.9909e-05, 1.6180e-03, 7.6457e-03, 1.1674e-03])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 30
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1529, -0.1529, -0.1529, -0.1529, -0.1529])
# Base value centered mean: -1.6108513136714464e-06
# Gamma init for k=7 (first 5): tensor([ 0.0031,  0.0019, -0.0044,  0.0009,  0.0058])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -10.9916, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7101, -0.7101,  2.1138, -0.7101, -0.7101])
# Base value centered mean: -9.76181013356836e-07
# Gamma init for k=8 (first 5): tensor([-0.0026, -0.0134, -0.0256,  0.0107,  0.0261])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 19
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.2549])
# Base value centered (first 5): tensor([-0.1634, -0.1634, -0.1634, -0.1634,  1.3971])
# Base value centered mean: -1.4804840020588017e-06
# Gamma init for k=9 (first 5): tensor([-0.0019,  0.0037, -0.0023, -0.0002,  0.0255])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 10
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.8271, -13.8155])
# Base value centered (first 5): tensor([-0.1655, -0.1655, -0.1655,  0.8229, -0.1655])
# Base value centered mean: -1.396179243329243e-07
# Gamma init for k=10 (first 5): tensor([ 0.0023,  0.0027, -0.0070,  0.0057, -0.0029])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -11.8388, -11.1799, -13.8155])
# Base value centered (first 5): tensor([-0.3435, -0.3435,  1.6332,  2.2922, -0.3435])
# Base value centered mean: -8.144378398355911e-07
# Gamma init for k=11 (first 5): tensor([ 0.0070, -0.0061,  0.0014,  0.0077,  0.0029])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.1978, -13.1978])
# Base value centered (first 5): tensor([-0.2723, -0.2723, -0.2723,  0.3454,  0.3454])
# Base value centered mean: 2.2010803490957187e-07
# Gamma init for k=12 (first 5): tensor([-0.0067,  0.0030, -0.0134,  0.0127,  0.0048])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -12.9170, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2809, -0.2809,  0.6176, -0.2809, -0.2809])
# Base value centered mean: -1.080703782463388e-06
# Gamma init for k=13 (first 5): tensor([-0.0083,  0.0191, -0.0084,  0.0010, -0.0163])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0915, -0.0915, -0.0915, -0.0915, -0.0915])
# Base value centered mean: -9.2916491212236e-07
# Gamma init for k=14 (first 5): tensor([-0.0061,  0.0039,  0.0040,  0.0053,  0.0041])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0897, -0.0897, -0.0897, -0.0897, -0.0897])
# Base value centered mean: -6.519794624182396e-07
# Gamma init for k=15 (first 5): tensor([-0.0030,  0.0009,  0.0076,  0.0145,  0.0051])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1759, -0.1759, -0.1759, -0.1759, -0.1759])
# Base value centered mean: -6.105423153712763e-07
# Gamma init for k=16 (first 5): tensor([-0.0001,  0.0030,  0.0027,  0.0054,  0.0068])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.1978, -13.1978, -12.5800, -11.3446, -13.8155])
# Base value centered (first 5): tensor([ 0.1701,  0.1701,  0.7879,  2.0233, -0.4476])
# Base value centered mean: -1.1844634855151526e-06
# Gamma init for k=17 (first 5): tensor([-0.0038,  0.0090, -0.0029, -0.0063,  0.0135])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 22
# Base value (first 5): tensor([-13.3663, -13.3663, -13.3663, -12.9170, -13.3663])
# Base value centered (first 5): tensor([-0.1135, -0.1135, -0.1135,  0.3358, -0.1135])
# Base value centered mean: 6.504058660539158e-07
# Gamma init for k=18 (first 5): tensor([-0.0046,  0.0096, -0.0099,  0.0200,  0.0012])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.1978, -13.8155])
# Base value centered (first 5): tensor([-0.1494, -0.1494, -0.1494,  0.4684, -0.1494])
# Base value centered mean: -2.2361755327438004e-06
# Gamma init for k=19 (first 5): tensor([ 0.0138, -0.0006,  0.0039,  0.0002,  0.0027])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.9623])
# Base value centered (first 5): tensor([-0.1871, -0.1871, -0.1871, -0.1871,  1.6661])
# Base value centered mean: -6.058692747501482e-07
# Gamma init for k=0 (first 5): tensor([-0.0019,  0.0010, -0.0044, -0.0018,  0.0304])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 0.1585, -0.3122, -0.3122, -0.3122, -0.3122])
# Base value centered mean: 6.502151563836378e-07
# Gamma init for k=1 (first 5): tensor([-0.0020,  0.0073, -0.0074,  0.0131,  0.0025])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -11.8388, -10.5209, -13.8155])
# Base value centered (first 5): tensor([-0.3785, -0.3785,  1.5982,  2.9160, -0.3785])
# Base value centered mean: 5.493163968139925e-08
# Gamma init for k=2 (first 5): tensor([ 0.0079, -0.0051,  0.0011,  0.0071,  0.0031])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.5744, -13.6950, -13.8155, -13.5744, -13.8155])
# Base value centered (first 5): tensor([ 0.1365,  0.0159, -0.1046,  0.1365, -0.1046])
# Base value centered mean: -3.633499261468387e-07
# Gamma init for k=3 (first 5): tensor([ 0.0002,  0.0004,  0.0004, -0.0005,  0.0017])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1101, -0.1101, -0.1101, -0.1101, -0.1101])
# Base value centered mean: -3.237629016439314e-06
# Gamma init for k=4 (first 5): tensor([-0.0028, -0.0021,  0.0082,  0.0178,  0.0076])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -10.9916, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7101, -0.7101,  2.1138, -0.7101, -0.7101])
# Base value centered mean: -9.76181013356836e-07
# Gamma init for k=5 (first 5): tensor([-0.0026, -0.0134, -0.0256,  0.0107,  0.0261])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1599, -0.1599, -0.1599, -0.1599, -0.1599])
# Base value centered mean: -1.6735076542317984e-06
# Gamma init for k=6 (first 5): tensor([ 0.0080,  0.0083,  0.0044,  0.0091, -0.0020])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.8155, -12.9170, -12.9170, -12.0185, -13.3663])
# Base value centered (first 5): tensor([-0.5616,  0.3369,  0.3369,  1.2355, -0.1123])
# Base value centered mean: -1.0938643981717178e-06
# Gamma init for k=7 (first 5): tensor([-0.0061,  0.0077, -0.0027,  0.0276,  0.0085])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.4625, -13.8155])
# Base value centered (first 5): tensor([-0.1220, -0.1220, -0.1220,  0.2310, -0.1220])
# Base value centered mean: -1.5850066859002254e-07
# Gamma init for k=8 (first 5): tensor([ 0.0099, -0.0020,  0.0040, -0.0001,  0.0027])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1977, -0.1977, -0.1977, -0.1977, -0.1977])
# Base value centered mean: 6.660461622232106e-07
# Gamma init for k=9 (first 5): tensor([ 0.0021,  0.0036, -0.0056,  0.0024, -0.0043])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -12.9170, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2809, -0.2809,  0.6176, -0.2809, -0.2809])
# Base value centered mean: -1.080703782463388e-06
# Gamma init for k=10 (first 5): tensor([-0.0083,  0.0191, -0.0084,  0.0010, -0.0163])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1150, -0.1150, -0.1150, -0.1150, -0.1150])
# Base value centered mean: -2.318954557267716e-06
# Gamma init for k=11 (first 5): tensor([ 0.0038,  0.0085,  0.0110, -0.0038,  0.0126])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# ...
# Base value centered (first 5): tensor([-0.1177, -0.1177, -0.1177,  0.9413, -0.1177])
# Base value centered mean: 1.753807055138168e-07
# Gamma init for k=8 (first 5): tensor([ 0.0060, -0.0011, -0.0011, -0.0009,  0.0014])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.2068, -0.2068, -0.2068, -0.2068,  0.6168])
# Base value centered mean: -7.566451927232265e-07
# Gamma init for k=9 (first 5): tensor([-0.0004, -0.0078, -0.0034,  0.0076,  0.0033])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2663, -0.2663, -0.2663, -0.2663, -0.2663])
# Base value centered mean: -1.115417489927495e-06
# Gamma init for k=10 (first 5): tensor([-0.0041,  0.0153,  0.0086,  0.0102, -0.0016])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1109, -0.1109, -0.1109, -0.1109, -0.1109])
# Base value centered mean: -1.4264106766859186e-06
# Gamma init for k=11 (first 5): tensor([-0.0016, -0.0023, -0.0018, -0.0025,  0.0148])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -12.4036, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0998, -0.0998,  1.3121, -0.0998, -0.0998])
# Base value centered mean: -1.7006874486469314e-06
# Gamma init for k=12 (first 5): tensor([ 0.0005, -0.0005, -0.0056, -0.0004,  0.0101])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -11.5347, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1716, -0.1716,  2.1093, -0.1716, -0.1716])
# Base value centered mean: 2.187728824765145e-07
# Gamma init for k=13 (first 5): tensor([ 0.0055,  0.0017,  0.0070, -0.0034, -0.0028])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-12.8271, -13.8155, -12.8271, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 0.7084, -0.2800,  0.7084, -0.2800, -0.2800])
# Base value centered mean: 1.4724732011472952e-07
# Gamma init for k=14 (first 5): tensor([-0.0063,  0.0009, -0.0137,  0.0181,  0.0098])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([ -7.8853, -11.8388, -11.8388, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 5.6386,  1.6852,  1.6852, -0.2916, -0.2916])
# Base value centered mean: -1.1932372672163183e-06
# Gamma init for k=15 (first 5): tensor([-0.0180, -0.0068,  0.0047,  0.0275, -0.0032])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1339, -13.4747, -13.8155])
# Base value centered (first 5): tensor([-0.2561, -0.2561,  0.4255,  0.0847, -0.2561])
# Base value centered mean: -5.432128773463774e-07
# Gamma init for k=16 (first 5): tensor([-0.0109, -0.0037,  0.0114,  0.0130,  0.0150])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.2341])
# Base value centered (first 5): tensor([-0.4213, -0.4213, -0.4213, -0.4213,  0.1601])
# Base value centered mean: -1.363754222438729e-06
# Gamma init for k=17 (first 5): tensor([-0.0078,  0.0099, -0.0066,  0.0085,  0.0133])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1679, -0.1679, -0.1679, -0.1679, -0.1679])
# Base value centered mean: -1.7017364370985888e-06
# Gamma init for k=18 (first 5): tensor([ 0.0027,  0.0135,  0.0061,  0.0057, -0.0064])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-12.9561, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([ 0.7026, -0.1568, -0.1568, -0.1568,  0.2729])
# Base value centered mean: -1.2242317097843625e-06
# Gamma init for k=19 (first 5): tensor([ 0.0023, -0.0011, -0.0026,  0.0028,  0.0067])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (5-Year Outcome, 1-Year Score)...
# AUC: 0.751 (0.737-0.776) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 446 (4.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.698, Events = 148/5560
#    Male: AUC = 0.739, Events = 298/4440
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.931, Events = 6/52
#    Breast_Cancer: AUC = 0.454, Events = 3/155
#
# Evaluating Diabetes (5-Year Outcome, 1-Year Score)...
# AUC: 0.665 (0.626-0.705) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 247 (2.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.642, Events = 84/5560
#    Male: AUC = 0.660, Events = 163/4440
#
# Evaluating Atrial_Fib (5-Year Outcome, 1-Year Score)...
# AUC: 0.707 (0.678-0.743) (calculated on 9885 individuals)
# Events (5-Year in Eval Cohort): 189 (1.9%) (from 10000 individuals)
# Excluded 115 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.730, Events = 103/5519
#    Male: AUC = 0.689, Events = 84/4366
#
# Evaluating CKD (5-Year Outcome, 1-Year Score)...
# AUC: 0.703 (0.643-0.770) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 38 (0.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.682, Events = 19/5560
#    Male: AUC = 0.721, Events = 19/4440
#
# Evaluating All_Cancers (5-Year Outcome, 1-Year Score)...
# AUC: 0.677 (0.643-0.690) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.580, Events = 61/5560
#    Male: AUC = 0.700, Events = 146/4440
#
# Evaluating Stroke (5-Year Outcome, 1-Year Score)...
# AUC: 0.698 (0.631-0.760) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.612, Events = 15/5560
#    Male: AUC = 0.743, Events = 25/4440
#
# Evaluating Heart_Failure (5-Year Outcome, 1-Year Score)...
# AUC: 0.629 (0.592-0.684) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 80 (0.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.619, Events = 29/5560
#    Male: AUC = 0.619, Events = 51/4440
#
# Evaluating Pneumonia (5-Year Outcome, 1-Year Score)...
# AUC: 0.634 (0.602-0.665) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.567, Events = 48/5560
#    Male: AUC = 0.667, Events = 75/4440
#
# Evaluating COPD (5-Year Outcome, 1-Year Score)...
# AUC: 0.631 (0.605-0.664) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 150 (1.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.645, Events = 62/5560
#    Male: AUC = 0.610, Events = 88/4440
#
# Evaluating Osteoporosis (5-Year Outcome, 1-Year Score)...
# AUC: 0.651 (0.601-0.713) (calculated on 9968 individuals)
# Events (5-Year in Eval Cohort): 86 (0.9%) (from 10000 individuals)
# Excluded 32 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.620, Events = 47/5531
#    Male: AUC = 0.695, Events = 38/4437
#
# Evaluating Anemia (5-Year Outcome, 1-Year Score)...
# AUC: 0.564 (0.516-0.598) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 213 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.521, Events = 121/5560
#    Male: AUC = 0.623, Events = 92/4440
#
# Evaluating Colorectal_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.633 (0.557-0.705) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 43 (0.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.561, Events = 19/5560
#    Male: AUC = 0.685, Events = 24/4440
#
# Evaluating Breast_Cancer (5-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5560 individuals in cohort
# AUC: 0.590 (0.539-0.659) (calculated on 5560 individuals)
# Events (5-Year in Eval Cohort): 113 (2.0%) (from 5560 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (5-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4440 individuals in cohort
# AUC: 0.742 (0.693-0.780) (calculated on 4402 individuals)
# Events (5-Year in Eval Cohort): 80 (1.8%) (from 4440 individuals)
# Excluded 38 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.629 (0.561-0.685) (calculated on 9996 individuals)
# Events (5-Year in Eval Cohort): 25 (0.2%) (from 10000 individuals)
# Excluded 4 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.611, Events = 14/5557
#    Male: AUC = 0.656, Events = 11/4439
#
# Evaluating Bladder_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.808 (0.763-0.865) (calculated on 9973 individuals)
# Events (5-Year in Eval Cohort): 26 (0.3%) (from 10000 individuals)
# Excluded 27 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.789, Events = 13/5555
#    Male: AUC = 0.826, Events = 13/4418
#
# Evaluating Secondary_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.562 (0.524-0.623) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 116 (1.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.557, Events = 72/5560
#    Male: AUC = 0.573, Events = 44/4440
#
# Evaluating Depression (5-Year Outcome, 1-Year Score)...
# AUC: 0.493 (0.451-0.542) (calculated on 9893 individuals)
# Events (5-Year in Eval Cohort): 148 (1.5%) (from 10000 individuals)
# Excluded 107 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.516, Events = 85/5500
#    Male: AUC = 0.475, Events = 61/4393
#
# Evaluating Anxiety (5-Year Outcome, 1-Year Score)...
# AUC: 0.498 (0.446-0.559) (calculated on 9968 individuals)
# Events (5-Year in Eval Cohort): 74 (0.7%) (from 10000 individuals)
# Excluded 32 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.558, Events = 32/5545
#    Male: AUC = 0.457, Events = 42/4423
#
# Evaluating Bipolar_Disorder (5-Year Outcome, 1-Year Score)...
# AUC: 0.555 (0.427-0.624) (calculated on 9986 individuals)
# Events (5-Year in Eval Cohort): 16 (0.2%) (from 10000 individuals)
# Excluded 14 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.487, Events = 6/5553
#    Male: AUC = 0.597, Events = 10/4433
#
# Evaluating Rheumatoid_Arthritis (5-Year Outcome, 1-Year Score)...
# AUC: 0.626 (0.567-0.710) (calculated on 9948 individuals)
# Events (5-Year in Eval Cohort): 47 (0.5%) (from 10000 individuals)
# Excluded 52 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.632, Events = 27/5525
#    Male: AUC = 0.622, Events = 20/4423
#
# Evaluating Psoriasis (5-Year Outcome, 1-Year Score)...
# AUC: 0.442 (0.354-0.700) (calculated on 9980 individuals)
# Events (5-Year in Eval Cohort): 14 (0.1%) (from 10000 individuals)
# Excluded 20 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.420, Events = 8/5553
#    Male: AUC = 0.472, Events = 6/4427
#
# Evaluating Ulcerative_Colitis (5-Year Outcome, 1-Year Score)...
# AUC: 0.710 (0.623-0.818) (calculated on 9957 individuals)
# Events (5-Year in Eval Cohort): 29 (0.3%) (from 10000 individuals)
# Excluded 43 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.749, Events = 15/5537
#    Male: AUC = 0.669, Events = 14/4420
#
# Evaluating Crohns_Disease (5-Year Outcome, 1-Year Score)...
# AUC: 0.709 (0.584-0.876) (calculated on 9965 individuals)
# Events (5-Year in Eval Cohort): 13 (0.1%) (from 10000 individuals)
# Excluded 35 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.710, Events = 6/5545
#    Male: AUC = 0.713, Events = 7/4420
#
# Evaluating Asthma (5-Year Outcome, 1-Year Score)...
# AUC: 0.519 (0.486-0.556) (calculated on 9672 individuals)
# Events (5-Year in Eval Cohort): 312 (3.1%) (from 10000 individuals)
# Excluded 328 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.536, Events = 168/5339
#    Male: AUC = 0.525, Events = 136/4333
#
# Evaluating Parkinsons (5-Year Outcome, 1-Year Score)...
# AUC: 0.695 (0.533-0.757) (calculated on 9998 individuals)
# Events (5-Year in Eval Cohort): 20 (0.2%) (from 10000 individuals)
# Excluded 2 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.724, Events = 7/5559
#    Male: AUC = 0.676, Events = 13/4439
#
# Evaluating Multiple_Sclerosis (5-Year Outcome, 1-Year Score)...
# AUC: 0.538 (0.461-0.649) (calculated on 9982 individuals)
# Events (5-Year in Eval Cohort): 13 (0.1%) (from 10000 individuals)
# Excluded 18 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.567, Events = 7/5547
#    Male: AUC = 0.506, Events = 6/4435
#
# Evaluating Thyroid_Disorders (5-Year Outcome, 1-Year Score)...
# AUC: 0.628 (0.601-0.680) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 185 (1.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.608, Events = 152/5560
#    Male: AUC = 0.707, Events = 33/4440
#
# Summary of Results (Prospective 5-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.751 (0.737-0.776)       446        4.5
# Diabetes             0.665 (0.626-0.705)       247        2.5
# Atrial_Fib           0.707 (0.678-0.743)       189        1.9
# CKD                  0.703 (0.643-0.770)       38         0.4
# All_Cancers          0.677 (0.643-0.690)       207        2.1
# Stroke               0.698 (0.631-0.760)       40         0.4
# Heart_Failure        0.629 (0.592-0.684)       80         0.8
# Pneumonia            0.634 (0.602-0.665)       123        1.2
# COPD                 0.631 (0.605-0.664)       150        1.5
# Osteoporosis         0.651 (0.601-0.713)       86         0.9
# Anemia               0.564 (0.516-0.598)       213        2.1
# Colorectal_Cancer    0.633 (0.557-0.705)       43         0.4
# Breast_Cancer        0.590 (0.539-0.659)       113        2.0
# Prostate_Cancer      0.742 (0.693-0.780)       80         1.8
# Lung_Cancer          0.629 (0.561-0.685)       25         0.2
# Bladder_Cancer       0.808 (0.763-0.865)       26         0.3
# Secondary_Cancer     0.562 (0.524-0.623)       116        1.2
# Depression           0.493 (0.451-0.542)       148        1.5
# Anxiety              0.498 (0.446-0.559)       74         0.7
# Bipolar_Disorder     0.555 (0.427-0.624)       16         0.2
# Rheumatoid_Arthritis 0.626 (0.567-0.710)       47         0.5
# Psoriasis            0.442 (0.354-0.700)       14         0.1
# Ulcerative_Colitis   0.710 (0.623-0.818)       29         0.3
# Crohns_Disease       0.709 (0.584-0.876)       13         0.1
# Asthma               0.519 (0.486-0.556)       312        3.1
# Parkinsons           0.695 (0.533-0.757)       20         0.2
# Multiple_Sclerosis   0.538 (0.461-0.649)       13         0.1
# Thyroid_Disorders    0.628 (0.601-0.680)       185        1.8
# --------------------------------------------------------------------------------
# Finished 90000-100000

# %%
import pickle
from pathlib import Path

out_dir = Path("/Users/sarahurbut/aladynoulli2/claudefile/output")
out_dir.mkdir(parents=True, exist_ok=True)

# Save joint run (e.g., 10‑year evaluation)
with (out_dir / "batch_results_joint_10yr.pkl").open("wb") as f:
    pickle.dump(batch_results, f)
print("Saved:", out_dir / "batch_results_joint_5yr.pkl")
# Out:
# Saved: /Users/sarahurbut/aladynoulli2/claudefile/output/batch_results_joint_5yr.pkl

# %%
# Collect per-disease AUC lists
disease_aucs = {}
for batch_res in batch_results.values():
    for disease, metrics in batch_res.items():
        disease_aucs.setdefault(disease, []).append(metrics["auc"])

# Median AUC and optional IQR
median_auc_df = (
    pd.Series({d: np.nanmedian(vals) for d, vals in disease_aucs.items()}, name="MedianAUC")
      .reset_index()
      .rename(columns={"index": "Disease"})
      .sort_values("MedianAUC", ascending=False)
)
median_auc_df["IQR"] = [
    (np.nanpercentile(disease_aucs[d], 25), np.nanpercentile(disease_aucs[d], 75))
    for d in median_auc_df["Disease"]
]

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=median_auc_df,
    x="MedianAUC",
    y="Disease",
    color="#4c72b0"
)
plt.xlim(0.5, 1.0)
plt.xlabel("Median AUC (across PCS batches)")
plt.ylabel("")
plt.title("Enrollment 10-year predictions (PCS joint runs)")
plt.tight_layout()
plt.show()

# %%
median_auc_df
# Out:
#                  Disease  MedianAUC                                        IQR
# 0                  ASCVD   0.749374    (0.7432662319641535, 0.759262489411763)
# 25            Parkinsons   0.738263   (0.6914242583684105, 0.7739876809769337)
# 15        Bladder_Cancer   0.729395   (0.7035932507436868, 0.7718590550138343)
# 13       Prostate_Cancer   0.723797   (0.7101121108897497, 0.7418262859607219)
# 6          Heart_Failure   0.703824   (0.6745442922498723, 0.7328155958907681)
# 2             Atrial_Fib   0.698771   (0.6865630590749294, 0.7065197055462733)
# 9           Osteoporosis   0.694008    (0.6784736674889885, 0.707924230299624)
# 4            All_Cancers   0.687172   (0.6771003899174095, 0.7005193248748202)
# 14           Lung_Cancer   0.686782   (0.6466496600812961, 0.7125378199183238)
# 3                    CKD   0.683707    (0.661411452839555, 0.7036318202081997)
# 11     Colorectal_Cancer   0.677687   (0.6430213439038373, 0.7009178391474584)
# 5                 Stroke   0.677422   (0.6480393652535803, 0.6969372458889427)
# 8                   COPD   0.672879   (0.6552484309566938, 0.6823313172075698)
# 1               Diabetes   0.651528   (0.6435280505024428, 0.6605052921657347)
# 23        Crohns_Disease   0.639761   (0.5675896306321011, 0.7029872671002191)
# 7              Pneumonia   0.627192     (0.6087168853210247, 0.63915065762376)
# 20  Rheumatoid_Arthritis   0.625671    (0.608043385299085, 0.6542807733203831)
# 16      Secondary_Cancer   0.612656     (0.5854064058020776, 0.63201663796385)
# 22    Ulcerative_Colitis   0.611782   (0.5776649510619051, 0.6525882068642223)
# 27     Thyroid_Disorders   0.603821   (0.5896532576351797, 0.6096428448556587)
# 10                Anemia   0.582095   (0.5670447678267219, 0.5897096252024918)
# 12         Breast_Cancer   0.566506    (0.5537134049112031, 0.587355688262051)
# 21             Psoriasis   0.563931   (0.5036004868936672, 0.5913646534065268)
# 26    Multiple_Sclerosis   0.560764    (0.534973803405943, 0.6217675933598218)
# 24                Asthma   0.548790   (0.5344226694204025, 0.5588563799694699)
# 19      Bipolar_Disorder   0.520681   (0.4534748765750559, 0.5739155608554631)
# 18               Anxiety   0.506224  (0.48915899618570563, 0.5340668323600279)
# 17            Depression   0.491011   (0.4717510016147243, 0.5026744439506621)

# %% [markdown]
# # now with fixed phi

# %%
    # --- loop through all checkpoints --------------------------------------------
ckpt_dir = "/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs"
ckpt_paths = sorted(glob.glob(os.path.join(ckpt_dir, "enrollment_model_W0.0001_batch_*_*.pt")))

ckpt = torch.load(ckpt_path, map_location="cpu")
ckpt = torch.load(ckpt_paths[0], map_location="cpu")
G_batch_dummy=ckpt["G"]
G_batch_dummy.shape
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/3099413546.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/3099413546.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_paths[0], map_location="cpu")
# torch.Size([10000, 47])

# %%
import glob
import os
import torch
import numpy as np
import pandas as pd
from fig5utils import evaluate_major_diseases_wsex_with_bootstrap

# --- Fixed resources ---------------------------------------------------------
initial_psi = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt")
initial_clusters = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt")
signature_refs = torch.load(
    "/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/data_for_running/reference_trajectories.pt"
)["signature_refs"]


# master tensors; adjust paths if they live elsewhere
Y_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/Y_tensor.pt")
E_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_matrix.pt")
G_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/G_matrix.pt")

# helper to build model & evaluate one batch

# helper to build model & evaluate one batch
def eval_batch(ckpt_path):
    ckpt = torch.load(ckpt_path, map_location="cpu")
    start, stop = ckpt["start_index"], ckpt["end_index"]  # indices saved in each checkpoint

  
    Y_batch = Y_full[start:stop]
    E_batch = E_full[start:stop]
# master tensors; adjust paths if 
    cov_batch = pce_df.iloc[start:stop].reset_index(drop=True)
    if "Sex" not in cov_batch.columns and "sex" in cov_batch.columns:
        cov_batch = cov_batch.rename(columns={"sex": "Sex"})
    cov_batch = cov_batch.assign(Sex=cov_batch["Sex"], age=cov_batch["age"])  # keep original naming, but ensure present

  

    model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
        N=Y_batch.shape[0],
        D=Y_batch.shape[1],
        T=Y_batch.shape[2],
        K=20,
        P=G_batch_dummy.shape[1],
        init_sd_scaler=1e-1,
        G=G_batch_dummy,
        Y=Y_batch.numpy(),
        genetic_scale=1,
        W=0.0001,
        R=0,
        prevalence_t=ckpt["prevalence_t"],
        signature_references=signature_refs,
        healthy_reference=True,
        disease_names=disease_names['x'],
    )
    model.initialize_params(true_psi=initial_psi)
    model.clusters =  initial_clusters
    model.load_state_dict(ckpt["model_state_dict"])
    model.eval()

    results = evaluate_major_diseases_wsex_with_bootstrap(
        model=model,
        Y_100k=Y_batch,
        E_100k=E_batch,
        disease_names=disease_names['x'],
        pce_df=cov_batch,
        n_bootstraps=20,
        follow_up_duration_years=5,
    )
    return (start, stop), results

# --- loop through all checkpoints --------------------------------------------
ckpt_dir = "/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs_fromclaudeoutput/"
ckpt_paths = sorted(glob.glob(os.path.join(ckpt_dir, "model_enroll_fixedphi_sex_*_*pt")))

batch_results_fixed = {}
for ckpt_path in ckpt_paths:
    (start, stop), res = eval_batch(ckpt_path)
    batch_results_fixed[(start, stop)] = res
    print(f"Finished {start}-{stop}")


# Save fixed-φ run (10‑year evaluation)
with (out_dir / "batch_results_fixed_5yr.pkl").open("wb") as f:
    pickle.dump(batch_results_fixed, f)
print("Saved:", out_dir / "batch_results_fixed_10yr.pkl")
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/4257264809.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/4257264809.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/4257264809.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   signature_refs = torch.load(
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/4257264809.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/Y_tensor.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/4257264809.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_matrix.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/4257264809.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/G_matrix.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/4257264809.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0026,  0.0050,  0.0103,  0.0132, -0.0116])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0011, -0.0023,  0.0073,  0.0020, -0.0051])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0014, -0.0038,  0.0025,  0.0024, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0088, -0.0010, -0.0120,  0.0372, -0.0093])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0051,  0.0055, -0.0040,  0.0058,  0.0238])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0018,  0.0010, -0.0011, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0075,  0.0045, -0.0065,  0.0055, -0.0043])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0032, -0.0005,  0.0003,  0.0114, -0.0019])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([-0.0003,  0.0084,  0.0164, -0.0027,  0.0004])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0123, -0.0048,  0.0016, -0.0047,  0.0018])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0068,  0.0008, -0.0014,  0.0007,  0.0027])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 0.0086,  0.0104, -0.0006,  0.0071, -0.0017])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([-0.0015,  0.0126,  0.0149, -0.0003,  0.0101])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0162, -0.0025,  0.0116,  0.0191, -0.0034])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0008, -0.0014,  0.0007,  0.0034,  0.0015])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.9623, -13.8155])
# Base value centered (first 5): tensor([-0.1879, -0.1879, -0.1879,  1.6653, -0.1879])
# Base value centered mean: -3.345489574257954e-07
# Gamma init for k=0 (first 5): tensor([ 0.0074,  0.0061, -0.0054,  0.0060,  0.0235])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.3449, -13.3449, -12.4036])
# Base value centered (first 5): tensor([ 0.1505, -0.3201,  0.1505,  0.1505,  1.0918])
# Base value centered mean: -1.8495559288567165e-06
# Gamma init for k=1 (first 5): tensor([0.0042, 0.0009, 0.0009, 0.0018, 0.0015])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1566, -11.8388, -12.4977])
# Base value centered (first 5): tensor([-0.3849, -0.3849,  0.2740,  1.5918,  0.9329])
# Base value centered mean: 9.290695288655115e-07
# Gamma init for k=2 (first 5): tensor([ 0.0016,  0.0073,  0.0100,  0.0140, -0.0118])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.6950, -13.5744])
# Base value centered (first 5): tensor([-0.1026, -0.1026, -0.1026,  0.0179,  0.1384])
# Base value centered mean: 4.7445297468584613e-07
# Gamma init for k=3 (first 5): tensor([ 0.0012,  0.0003,  0.0016,  0.0018, -0.0006])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155,  -9.8620, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1133,  3.8402, -0.1133, -0.1133, -0.1133])
# Base value centered mean: -2.841758714566822e-06
# Gamma init for k=4 (first 5): tensor([-0.0172, -0.0033,  0.0143,  0.0225, -0.0033])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=5 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1523, -0.1523, -0.1523, -0.1523, -0.1523])
# Base value centered mean: -1.0890006478803116e-06
# Gamma init for k=6 (first 5): tensor([ 0.0090,  0.0121, -0.0006,  0.0042, -0.0027])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.3663, -13.8155, -13.3663, -13.8155, -11.1200])
# Base value centered (first 5): tensor([-0.1005, -0.5497, -0.1005, -0.5497,  2.1458])
# Base value centered mean: 1.2460708376238472e-06
# Gamma init for k=7 (first 5): tensor([ 0.0003, -0.0038, -0.0111,  0.0251, -0.0016])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1159, -0.1159, -0.1159, -0.1159, -0.1159])
# Base value centered mean: -1.4129639112070436e-06
# Gamma init for k=8 (first 5): tensor([ 0.0066, -0.0055,  0.0011, -0.0020, -0.0005])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=9 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=10 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=11 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0860, -0.0860, -0.0860, -0.0860, -0.0860])
# Base value centered mean: -1.034450519910024e-06
# Gamma init for k=12 (first 5): tensor([ 0.0080, -0.0074,  0.0002, -0.0001, -0.0076])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.7744, -12.2949])
# Base value centered (first 5): tensor([-0.1777, -0.1777, -0.1777,  2.8635,  1.3429])
# Base value centered mean: -1.0064125035569305e-06
# Gamma init for k=13 (first 5): tensor([-0.0002,  0.0060,  0.0127, -0.0051,  0.0007])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.8388, -12.8271])
# Base value centered (first 5): tensor([-0.2562, -0.2562, -0.2562,  1.7205,  0.7322])
# Base value centered mean: -1.5125274330785032e-06
# Gamma init for k=14 (first 5): tensor([ 0.0038, -0.0052, -0.0089,  0.0162,  0.0005])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.8388])
# Base value centered (first 5): tensor([-0.2850, -0.2850, -0.2850, -0.2850,  1.6917])
# Base value centered mean: -1.2931823221151717e-06
# Gamma init for k=15 (first 5): tensor([-0.0039,  0.0064,  0.0118, -0.0049,  0.0086])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.7706, -13.1339])
# Base value centered (first 5): tensor([-0.2428, -0.2428, -0.2428,  1.8021,  0.4388])
# Base value centered mean: -1.9989013253507437e-06
# Gamma init for k=16 (first 5): tensor([ 0.0009,  0.0001,  0.0093,  0.0055, -0.0031])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.3272, -12.0713])
# Base value centered (first 5): tensor([-0.4228, -0.4228, -0.4228,  3.0656,  1.3214])
# Base value centered mean: -2.227592403869494e-06
# Gamma init for k=17 (first 5): tensor([ 0.0081,  0.0052, -0.0070,  0.0058, -0.0042])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=18 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([-0.1519, -0.1519, -0.1519, -0.1519,  0.2779])
# Base value centered mean: -1.1179923831150518e-06
# Gamma init for k=19 (first 5): tensor([-0.0027,  0.0053,  0.0013, -0.0016, -0.0018])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (5-Year Outcome, 1-Year Score)...
# AUC: 0.717 (0.698-0.742) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 419 (4.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.715, Events = 138/5409
#    Male: AUC = 0.711, Events = 281/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.769, Events = 5/37
#    Breast_Cancer: AUC = 0.557, Events = 6/170
#
# Evaluating Diabetes (5-Year Outcome, 1-Year Score)...
# AUC: 0.653 (0.633-0.691) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 248 (2.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.655, Events = 109/5409
#    Male: AUC = 0.648, Events = 139/4591
#
# Evaluating Atrial_Fib (5-Year Outcome, 1-Year Score)...
# AUC: 0.703 (0.657-0.738) (calculated on 9864 individuals)
# Events (5-Year in Eval Cohort): 156 (1.6%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.708, Events = 86/5372
#    Male: AUC = 0.707, Events = 70/4492
#
# Evaluating CKD (5-Year Outcome, 1-Year Score)...
# AUC: 0.691 (0.635-0.751) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 33 (0.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.759, Events = 16/5409
#    Male: AUC = 0.625, Events = 17/4591
#
# Evaluating All_Cancers (5-Year Outcome, 1-Year Score)...
# AUC: 0.704 (0.668-0.734) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 213 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.694, Events = 56/5409
#    Male: AUC = 0.698, Events = 157/4591
#
# Evaluating Stroke (5-Year Outcome, 1-Year Score)...
# AUC: 0.705 (0.659-0.753) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 41 (0.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.726, Events = 19/5409
#    Male: AUC = 0.684, Events = 22/4591
#
# Evaluating Heart_Failure (5-Year Outcome, 1-Year Score)...
# AUC: 0.747 (0.674-0.793) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 58 (0.6%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.748, Events = 24/5409
#    Male: AUC = 0.743, Events = 34/4591
#
# Evaluating Pneumonia (5-Year Outcome, 1-Year Score)...
# AUC: 0.630 (0.589-0.657) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 112 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.643, Events = 42/5409
#    Male: AUC = 0.616, Events = 70/4591
#
# Evaluating COPD (5-Year Outcome, 1-Year Score)...
# AUC: 0.656 (0.621-0.686) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 149 (1.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.668, Events = 60/5409
#    Male: AUC = 0.642, Events = 89/4591
#
# Evaluating Osteoporosis (5-Year Outcome, 1-Year Score)...
# AUC: 0.639 (0.575-0.695) (calculated on 9961 individuals)
# Events (5-Year in Eval Cohort): 73 (0.7%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.629, Events = 42/5379
#    Male: AUC = 0.654, Events = 31/4582
#
# Evaluating Anemia (5-Year Outcome, 1-Year Score)...
# AUC: 0.579 (0.560-0.611) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 201 (2.0%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.545, Events = 113/5409
#    Male: AUC = 0.621, Events = 88/4591
#
# Evaluating Colorectal_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.716 (0.671-0.768) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.670, Events = 22/5409
#    Male: AUC = 0.751, Events = 27/4591
#
# Evaluating Breast_Cancer (5-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.625 (0.584-0.669) (calculated on 5409 individuals)
# Events (5-Year in Eval Cohort): 102 (1.9%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (5-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.725 (0.684-0.764) (calculated on 4547 individuals)
# Events (5-Year in Eval Cohort): 86 (1.9%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.734 (0.668-0.793) (calculated on 9992 individuals)
# Events (5-Year in Eval Cohort): 35 (0.4%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.711, Events = 26/5406
#    Male: AUC = 0.797, Events = 9/4586
#
# Evaluating Bladder_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.725 (0.604-0.818) (calculated on 9976 individuals)
# Events (5-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.585, Events = 11/5399
#    Male: AUC = 0.882, Events = 10/4577
#
# Evaluating Secondary_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.637 (0.584-0.685) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 108 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.641, Events = 57/5409
#    Male: AUC = 0.630, Events = 51/4591
#
# Evaluating Depression (5-Year Outcome, 1-Year Score)...
# AUC: 0.499 (0.464-0.541) (calculated on 9912 individuals)
# Events (5-Year in Eval Cohort): 147 (1.5%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.475, Events = 85/5351
#    Male: AUC = 0.548, Events = 61/4561
#
# Evaluating Anxiety (5-Year Outcome, 1-Year Score)...
# AUC: 0.473 (0.403-0.521) (calculated on 9975 individuals)
# Events (5-Year in Eval Cohort): 58 (0.6%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.493, Events = 34/5391
#    Male: AUC = 0.448, Events = 24/4584
#
# Evaluating Bipolar_Disorder (5-Year Outcome, 1-Year Score)...
# AUC: 0.482 (0.372-0.588) (calculated on 9984 individuals)
# Events (5-Year in Eval Cohort): 19 (0.2%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.593, Events = 7/5399
#    Male: AUC = 0.418, Events = 12/4585
#
# Evaluating Rheumatoid_Arthritis (5-Year Outcome, 1-Year Score)...
# AUC: 0.583 (0.486-0.629) (calculated on 9963 individuals)
# Events (5-Year in Eval Cohort): 42 (0.4%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.593, Events = 24/5381
#    Male: AUC = 0.573, Events = 18/4582
#
# Evaluating Psoriasis (5-Year Outcome, 1-Year Score)...
# AUC: 0.415 (0.263-0.526) (calculated on 9981 individuals)
# Events (5-Year in Eval Cohort): 14 (0.1%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.515, Events = 5/5405
#    Male: AUC = 0.362, Events = 9/4576
#
# Evaluating Ulcerative_Colitis (5-Year Outcome, 1-Year Score)...
# AUC: 0.629 (0.514-0.772) (calculated on 9947 individuals)
# Events (5-Year in Eval Cohort): 23 (0.2%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.656, Events = 12/5378
#    Male: AUC = 0.603, Events = 11/4569
#
# Evaluating Crohns_Disease (5-Year Outcome, 1-Year Score)...
# AUC: 0.517 (0.275-0.730) (calculated on 9967 individuals)
# Events (5-Year in Eval Cohort): 9 (0.1%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.455, Events = 6/5388
#    Male: AUC = 0.641, Events = 3/4579
#
# Evaluating Asthma (5-Year Outcome, 1-Year Score)...
# AUC: 0.530 (0.495-0.563) (calculated on 9687 individuals)
# Events (5-Year in Eval Cohort): 302 (3.0%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.520, Events = 156/5214
#    Male: AUC = 0.583, Events = 134/4473
#
# Evaluating Parkinsons (5-Year Outcome, 1-Year Score)...
# AUC: 0.776 (0.668-0.842) (calculated on 9997 individuals)
# Events (5-Year in Eval Cohort): 15 (0.1%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.870, Events = 7/5407
#    Male: AUC = 0.695, Events = 8/4590
#
# Evaluating Multiple_Sclerosis (5-Year Outcome, 1-Year Score)...
# AUC: 0.595 (0.414-0.800) (calculated on 9979 individuals)
# Events (5-Year in Eval Cohort): 11 (0.1%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.524, Events = 8/5394
#    Male: AUC = 0.783, Events = 3/4585
#
# Evaluating Thyroid_Disorders (5-Year Outcome, 1-Year Score)...
# AUC: 0.587 (0.552-0.627) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 226 (2.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.598, Events = 191/5409
#    Male: AUC = 0.553, Events = 35/4591
#
# Summary of Results (Prospective 5-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.717 (0.698-0.742)       419        4.2
# Diabetes             0.653 (0.633-0.691)       248        2.5
# Atrial_Fib           0.703 (0.657-0.738)       156        1.6
# CKD                  0.691 (0.635-0.751)       33         0.3
# All_Cancers          0.704 (0.668-0.734)       213        2.1
# Stroke               0.705 (0.659-0.753)       41         0.4
# Heart_Failure        0.747 (0.674-0.793)       58         0.6
# Pneumonia            0.630 (0.589-0.657)       112        1.1
# COPD                 0.656 (0.621-0.686)       149        1.5
# Osteoporosis         0.639 (0.575-0.695)       73         0.7
# Anemia               0.579 (0.560-0.611)       201        2.0
# Colorectal_Cancer    0.716 (0.671-0.768)       49         0.5
# Breast_Cancer        0.625 (0.584-0.669)       102        1.9
# Prostate_Cancer      0.725 (0.684-0.764)       86         1.9
# Lung_Cancer          0.734 (0.668-0.793)       35         0.4
# Bladder_Cancer       0.725 (0.604-0.818)       21         0.2
# Secondary_Cancer     0.637 (0.584-0.685)       108        1.1
# Depression           0.499 (0.464-0.541)       147        1.5
# Anxiety              0.473 (0.403-0.521)       58         0.6
# Bipolar_Disorder     0.482 (0.372-0.588)       19         0.2
# Rheumatoid_Arthritis 0.583 (0.486-0.629)       42         0.4
# Psoriasis            0.415 (0.263-0.526)       14         0.1
# Ulcerative_Colitis   0.629 (0.514-0.772)       23         0.2
# Crohns_Disease       0.517 (0.275-0.730)       9          0.1
# Asthma               0.530 (0.495-0.563)       302        3.0
# Parkinsons           0.776 (0.668-0.842)       15         0.1
# Multiple_Sclerosis   0.595 (0.414-0.800)       11         0.1
# Thyroid_Disorders    0.587 (0.552-0.627)       226        2.3
# --------------------------------------------------------------------------------
# Finished 0-10000
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_96959/4257264809.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 42 diseases
# Cluster 1: 24 diseases
# Cluster 2: 8 diseases
# Cluster 3: 5 diseases
# Cluster 4: 8 diseases
# Cluster 5: 13 diseases
# Cluster 6: 60 diseases
# Cluster 7: 30 diseases
# Cluster 8: 7 diseases
# Cluster 9: 19 diseases
# Cluster 10: 10 diseases
# Cluster 11: 15 diseases
# Cluster 12: 16 diseases
# Cluster 13: 11 diseases
# Cluster 14: 7 diseases
# Cluster 15: 7 diseases
# Cluster 16: 12 diseases
# Cluster 17: 16 diseases
# Cluster 18: 22 diseases
# Cluster 19: 16 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 42
# Base value (first 5): tensor([-13.5802, -13.8155, -13.8155, -13.8155, -13.5802])
# Base value centered (first 5): tensor([ 0.1123, -0.1230, -0.1230, -0.1230,  0.1123])
# Base value centered mean: -4.872322278970387e-07
# Gamma init for k=0 (first 5): tensor([-0.0032, -0.0004,  0.0024,  0.0001,  0.0007])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 24
# Base value (first 5): tensor([-13.8155, -13.4037, -13.8155, -12.9919, -13.8155])
# Base value centered (first 5): tensor([-0.2507,  0.1611, -0.2507,  0.5729, -0.2507])
# Base value centered mean: -3.0660628453915706e-06
# Gamma init for k=1 (first 5): tensor([-0.0034,  0.0084, -0.0081, -0.0016, -0.0014])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1150, -0.1150, -0.1150, -0.1150, -0.1150])
# Base value centered mean: -2.318954557267716e-06
# Gamma init for k=2 (first 5): tensor([-0.0023,  0.0033, -0.0088, -0.0063,  0.0050])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 5
# Base value (first 5): tensor([-13.8155, -11.8388, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2868,  1.6899, -0.2868, -0.2868, -0.2868])
# Base value centered mean: -1.7898559008244774e-06
# Gamma init for k=3 (first 5): tensor([ 0.0034,  0.0165,  0.0034, -0.0020, -0.0095])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1599, -0.1599, -0.1599, -0.1599, -0.1599])
# Base value centered mean: -1.6735076542317984e-06
# Gamma init for k=4 (first 5): tensor([-0.0093,  0.0117, -0.0036, -0.0108,  0.0038])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1988, -0.1988, -0.1988, -0.1988, -0.1988])
# Base value centered mean: 5.046844648859405e-07
# Gamma init for k=5 (first 5): tensor([ 0.0065,  0.0022, -0.0043, -0.0101,  0.0047])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 60
# Base value (first 5): tensor([-13.6508, -13.6508, -13.6508, -13.6508, -13.8155])
# Base value centered (first 5): tensor([ 0.0040,  0.0040,  0.0040,  0.0040, -0.1608])
# Base value centered mean: -3.2844542374732555e-07
# Gamma init for k=6 (first 5): tensor([ 1.8497e-03,  2.5832e-03, -1.0756e-03, -1.0755e-03,  8.9680e-05])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 30
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1529, -0.1529, -0.1529, -0.1529, -0.1529])
# Base value centered mean: -1.6108513136714464e-06
# Gamma init for k=7 (first 5): tensor([-0.0010,  0.0059, -0.0056, -0.0012, -0.0012])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -10.9916, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7101, -0.7101,  2.1138, -0.7101, -0.7101])
# Base value centered mean: -9.76181013356836e-07
# Gamma init for k=8 (first 5): tensor([ 0.0049,  0.0437, -0.0107, -0.0139, -0.0172])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 19
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.2549])
# Base value centered (first 5): tensor([-0.1634, -0.1634, -0.1634, -0.1634,  1.3971])
# Base value centered mean: -1.4804840020588017e-06
# Gamma init for k=9 (first 5): tensor([-0.0005,  0.0104, -0.0036,  0.0014, -0.0039])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 10
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.8271, -13.8155])
# Base value centered (first 5): tensor([-0.1655, -0.1655, -0.1655,  0.8229, -0.1655])
# Base value centered mean: -1.396179243329243e-07
# Gamma init for k=10 (first 5): tensor([0.0101, 0.0041, 0.0024, 0.0018, 0.0010])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -11.8388, -11.1799, -13.8155])
# Base value centered (first 5): tensor([-0.3435, -0.3435,  1.6332,  2.2922, -0.3435])
# Base value centered mean: -8.144378398355911e-07
# Gamma init for k=11 (first 5): tensor([ 0.0134,  0.0033, -0.0101,  0.0023,  0.0059])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.1978, -13.1978])
# Base value centered (first 5): tensor([-0.2723, -0.2723, -0.2723,  0.3454,  0.3454])
# Base value centered mean: 2.2010803490957187e-07
# Gamma init for k=12 (first 5): tensor([-0.0013,  0.0207, -0.0107,  0.0131,  0.0003])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -12.9170, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2809, -0.2809,  0.6176, -0.2809, -0.2809])
# Base value centered mean: -1.080703782463388e-06
# Gamma init for k=13 (first 5): tensor([-0.0210, -0.0059, -0.0088, -0.0006,  0.0081])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0915, -0.0915, -0.0915, -0.0915, -0.0915])
# Base value centered mean: -9.2916491212236e-07
# Gamma init for k=14 (first 5): tensor([-0.0005,  0.0033, -0.0031, -0.0045,  0.0123])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0897, -0.0897, -0.0897, -0.0897, -0.0897])
# Base value centered mean: -6.519794624182396e-07
# Gamma init for k=15 (first 5): tensor([-0.0030,  0.0084, -0.0033,  0.0004, -0.0037])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1759, -0.1759, -0.1759, -0.1759, -0.1759])
# Base value centered mean: -6.105423153712763e-07
# Gamma init for k=16 (first 5): tensor([ 5.1392e-03, -2.6544e-03,  4.4172e-03, -1.0849e-02,  5.0559e-06])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.1978, -13.1978, -12.5800, -11.3446, -13.8155])
# Base value centered (first 5): tensor([ 0.1701,  0.1701,  0.7879,  2.0233, -0.4476])
# Base value centered mean: -1.1844634855151526e-06
# Gamma init for k=17 (first 5): tensor([-0.0015,  0.0075, -0.0135,  0.0090, -0.0066])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 22
# Base value (first 5): tensor([-13.3663, -13.3663, -13.3663, -12.9170, -13.3663])
# Base value centered (first 5): tensor([-0.1135, -0.1135, -0.1135,  0.3358, -0.1135])
# Base value centered mean: 6.504058660539158e-07
# Gamma init for k=18 (first 5): tensor([-0.0097,  0.0089, -0.0178, -0.0072, -0.0061])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.1978, -13.8155])
# Base value centered (first 5): tensor([-0.1494, -0.1494, -0.1494,  0.4684, -0.1494])
# Base value centered mean: -2.2361755327438004e-06
# Gamma init for k=19 (first 5): tensor([ 0.0026, -0.0092, -0.0104,  0.0035,  0.0010])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.9623])
# Base value centered (first 5): tensor([-0.1871, -0.1871, -0.1871, -0.1871,  1.6661])
# Base value centered mean: -6.058692747501482e-07
# Gamma init for k=0 (first 5): tensor([-0.0033,  0.0132, -0.0078,  0.0028, -0.0062])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 0.1585, -0.3122, -0.3122, -0.3122, -0.3122])
# Base value centered mean: 6.502151563836378e-07
# Gamma init for k=1 (first 5): tensor([-0.0111,  0.0010, -0.0117, -0.0079,  0.0042])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -11.8388, -10.5209, -13.8155])
# Base value centered (first 5): tensor([-0.3785, -0.3785,  1.5982,  2.9160, -0.3785])
# Base value centered mean: 5.493163968139925e-08
# Gamma init for k=2 (first 5): tensor([ 0.0102,  0.0033, -0.0083,  0.0054,  0.0065])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.5744, -13.6950, -13.8155, -13.5744, -13.8155])
# Base value centered (first 5): tensor([ 0.1365,  0.0159, -0.1046,  0.1365, -0.1046])
# Base value centered mean: -3.633499261468387e-07
# Gamma init for k=3 (first 5): tensor([-0.0010,  0.0030, -0.0004, -0.0004, -0.0015])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1101, -0.1101, -0.1101, -0.1101, -0.1101])
# Base value centered mean: -3.237629016439314e-06
# Gamma init for k=4 (first 5): tensor([-0.0032,  0.0123, -0.0048,  0.0003, -0.0067])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -10.9916, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7101, -0.7101,  2.1138, -0.7101, -0.7101])
# Base value centered mean: -9.76181013356836e-07
# Gamma init for k=5 (first 5): tensor([ 0.0049,  0.0437, -0.0107, -0.0139, -0.0172])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1599, -0.1599, -0.1599, -0.1599, -0.1599])
# Base value centered mean: -1.6735076542317984e-06
# ...
# Base value centered mean: 1.753807055138168e-07
# Gamma init for k=8 (first 5): tensor([-0.0012,  0.0006,  0.0035, -0.0022,  0.0056])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.2068, -0.2068, -0.2068, -0.2068,  0.6168])
# Base value centered mean: -7.566451927232265e-07
# Gamma init for k=9 (first 5): tensor([0.0103, 0.0071, 0.0130, 0.0089, 0.0155])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2663, -0.2663, -0.2663, -0.2663, -0.2663])
# Base value centered mean: -1.115417489927495e-06
# Gamma init for k=10 (first 5): tensor([ 0.0089, -0.0068, -0.0078, -0.0064, -0.0124])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1109, -0.1109, -0.1109, -0.1109, -0.1109])
# Base value centered mean: -1.4264106766859186e-06
# Gamma init for k=11 (first 5): tensor([-6.3167e-04, -5.2316e-05,  2.1208e-03, -4.4305e-03,  2.1411e-03])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -12.4036, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0998, -0.0998,  1.3121, -0.0998, -0.0998])
# Base value centered mean: -1.7006874486469314e-06
# Gamma init for k=12 (first 5): tensor([-0.0015, -0.0011, -0.0045, -0.0050,  0.0026])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -11.5347, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1716, -0.1716,  2.1093, -0.1716, -0.1716])
# Base value centered mean: 2.187728824765145e-07
# Gamma init for k=13 (first 5): tensor([ 0.0050, -0.0047, -0.0048, -0.0038, -0.0003])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-12.8271, -13.8155, -12.8271, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 0.7084, -0.2800,  0.7084, -0.2800, -0.2800])
# Base value centered mean: 1.4724732011472952e-07
# Gamma init for k=14 (first 5): tensor([ 0.0124, -0.0042,  0.0063,  0.0072,  0.0029])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([ -7.8853, -11.8388, -11.8388, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 5.6386,  1.6852,  1.6852, -0.2916, -0.2916])
# Base value centered mean: -1.1932372672163183e-06
# Gamma init for k=15 (first 5): tensor([ 0.0106,  0.0268, -0.0023,  0.0092, -0.0190])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1339, -13.4747, -13.8155])
# Base value centered (first 5): tensor([-0.2561, -0.2561,  0.4255,  0.0847, -0.2561])
# Base value centered mean: -5.432128773463774e-07
# Gamma init for k=16 (first 5): tensor([-0.0029,  0.0013, -0.0044,  0.0045, -0.0052])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.2341])
# Base value centered (first 5): tensor([-0.4213, -0.4213, -0.4213, -0.4213,  0.1601])
# Base value centered mean: -1.363754222438729e-06
# Gamma init for k=17 (first 5): tensor([ 0.0015,  0.0083, -0.0007,  0.0017,  0.0133])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1679, -0.1679, -0.1679, -0.1679, -0.1679])
# Base value centered mean: -1.7017364370985888e-06
# Gamma init for k=18 (first 5): tensor([-0.0032,  0.0039,  0.0033,  0.0010, -0.0008])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-12.9561, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([ 0.7026, -0.1568, -0.1568, -0.1568,  0.2729])
# Base value centered mean: -1.2242317097843625e-06
# Gamma init for k=19 (first 5): tensor([-0.0005, -0.0045, -0.0011, -0.0031, -0.0021])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (5-Year Outcome, 1-Year Score)...
# AUC: 0.715 (0.702-0.738) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 446 (4.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.684, Events = 148/5560
#    Male: AUC = 0.720, Events = 298/4440
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.946, Events = 6/52
#    Breast_Cancer: AUC = 0.436, Events = 3/155
#
# Evaluating Diabetes (5-Year Outcome, 1-Year Score)...
# AUC: 0.632 (0.614-0.656) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 247 (2.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.628, Events = 84/5560
#    Male: AUC = 0.625, Events = 163/4440
#
# Evaluating Atrial_Fib (5-Year Outcome, 1-Year Score)...
# AUC: 0.712 (0.664-0.753) (calculated on 9885 individuals)
# Events (5-Year in Eval Cohort): 189 (1.9%) (from 10000 individuals)
# Excluded 115 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.736, Events = 103/5519
#    Male: AUC = 0.692, Events = 84/4366
#
# Evaluating CKD (5-Year Outcome, 1-Year Score)...
# AUC: 0.708 (0.653-0.758) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 38 (0.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.687, Events = 19/5560
#    Male: AUC = 0.722, Events = 19/4440
#
# Evaluating All_Cancers (5-Year Outcome, 1-Year Score)...
# AUC: 0.674 (0.650-0.701) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.581, Events = 61/5560
#    Male: AUC = 0.700, Events = 146/4440
#
# Evaluating Stroke (5-Year Outcome, 1-Year Score)...
# AUC: 0.697 (0.630-0.736) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.614, Events = 15/5560
#    Male: AUC = 0.740, Events = 25/4440
#
# Evaluating Heart_Failure (5-Year Outcome, 1-Year Score)...
# AUC: 0.630 (0.565-0.686) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 80 (0.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.619, Events = 29/5560
#    Male: AUC = 0.622, Events = 51/4440
#
# Evaluating Pneumonia (5-Year Outcome, 1-Year Score)...
# AUC: 0.640 (0.589-0.678) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.572, Events = 48/5560
#    Male: AUC = 0.675, Events = 75/4440
#
# Evaluating COPD (5-Year Outcome, 1-Year Score)...
# AUC: 0.640 (0.596-0.681) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 150 (1.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.657, Events = 62/5560
#    Male: AUC = 0.620, Events = 88/4440
#
# Evaluating Osteoporosis (5-Year Outcome, 1-Year Score)...
# AUC: 0.639 (0.600-0.687) (calculated on 9968 individuals)
# Events (5-Year in Eval Cohort): 86 (0.9%) (from 10000 individuals)
# Excluded 32 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.607, Events = 47/5531
#    Male: AUC = 0.684, Events = 38/4437
#
# Evaluating Anemia (5-Year Outcome, 1-Year Score)...
# AUC: 0.565 (0.519-0.596) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 213 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.524, Events = 121/5560
#    Male: AUC = 0.620, Events = 92/4440
#
# Evaluating Colorectal_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.630 (0.514-0.700) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 43 (0.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.561, Events = 19/5560
#    Male: AUC = 0.681, Events = 24/4440
#
# Evaluating Breast_Cancer (5-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5560 individuals in cohort
# AUC: 0.605 (0.545-0.645) (calculated on 5560 individuals)
# Events (5-Year in Eval Cohort): 113 (2.0%) (from 5560 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (5-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4440 individuals in cohort
# AUC: 0.736 (0.707-0.776) (calculated on 4402 individuals)
# Events (5-Year in Eval Cohort): 80 (1.8%) (from 4440 individuals)
# Excluded 38 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.630 (0.556-0.695) (calculated on 9996 individuals)
# Events (5-Year in Eval Cohort): 25 (0.2%) (from 10000 individuals)
# Excluded 4 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.616, Events = 14/5557
#    Male: AUC = 0.652, Events = 11/4439
#
# Evaluating Bladder_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.782 (0.706-0.832) (calculated on 9973 individuals)
# Events (5-Year in Eval Cohort): 26 (0.3%) (from 10000 individuals)
# Excluded 27 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.750, Events = 13/5555
#    Male: AUC = 0.815, Events = 13/4418
#
# Evaluating Secondary_Cancer (5-Year Outcome, 1-Year Score)...
# AUC: 0.563 (0.525-0.611) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 116 (1.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.561, Events = 72/5560
#    Male: AUC = 0.570, Events = 44/4440
#
# Evaluating Depression (5-Year Outcome, 1-Year Score)...
# AUC: 0.508 (0.462-0.561) (calculated on 9893 individuals)
# Events (5-Year in Eval Cohort): 148 (1.5%) (from 10000 individuals)
# Excluded 107 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.545, Events = 85/5500
#    Male: AUC = 0.472, Events = 61/4393
#
# Evaluating Anxiety (5-Year Outcome, 1-Year Score)...
# AUC: 0.480 (0.377-0.506) (calculated on 9968 individuals)
# Events (5-Year in Eval Cohort): 74 (0.7%) (from 10000 individuals)
# Excluded 32 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.536, Events = 32/5545
#    Male: AUC = 0.441, Events = 42/4423
#
# Evaluating Bipolar_Disorder (5-Year Outcome, 1-Year Score)...
# AUC: 0.588 (0.474-0.681) (calculated on 9986 individuals)
# Events (5-Year in Eval Cohort): 16 (0.2%) (from 10000 individuals)
# Excluded 14 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.546, Events = 6/5553
#    Male: AUC = 0.615, Events = 10/4433
#
# Evaluating Rheumatoid_Arthritis (5-Year Outcome, 1-Year Score)...
# AUC: 0.624 (0.513-0.691) (calculated on 9948 individuals)
# Events (5-Year in Eval Cohort): 47 (0.5%) (from 10000 individuals)
# Excluded 52 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.628, Events = 27/5525
#    Male: AUC = 0.624, Events = 20/4423
#
# Evaluating Psoriasis (5-Year Outcome, 1-Year Score)...
# AUC: 0.511 (0.341-0.689) (calculated on 9980 individuals)
# Events (5-Year in Eval Cohort): 14 (0.1%) (from 10000 individuals)
# Excluded 20 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.528, Events = 8/5553
#    Male: AUC = 0.488, Events = 6/4427
#
# Evaluating Ulcerative_Colitis (5-Year Outcome, 1-Year Score)...
# AUC: 0.641 (0.548-0.735) (calculated on 9957 individuals)
# Events (5-Year in Eval Cohort): 29 (0.3%) (from 10000 individuals)
# Excluded 43 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.703, Events = 15/5537
#    Male: AUC = 0.577, Events = 14/4420
#
# Evaluating Crohns_Disease (5-Year Outcome, 1-Year Score)...
# AUC: 0.721 (0.567-0.920) (calculated on 9965 individuals)
# Events (5-Year in Eval Cohort): 13 (0.1%) (from 10000 individuals)
# Excluded 35 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.770, Events = 6/5545
#    Male: AUC = 0.681, Events = 7/4420
#
# Evaluating Asthma (5-Year Outcome, 1-Year Score)...
# AUC: 0.514 (0.488-0.541) (calculated on 9672 individuals)
# Events (5-Year in Eval Cohort): 312 (3.1%) (from 10000 individuals)
# Excluded 328 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.529, Events = 168/5339
#    Male: AUC = 0.525, Events = 136/4333
#
# Evaluating Parkinsons (5-Year Outcome, 1-Year Score)...
# AUC: 0.688 (0.598-0.787) (calculated on 9998 individuals)
# Events (5-Year in Eval Cohort): 20 (0.2%) (from 10000 individuals)
# Excluded 2 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.713, Events = 7/5559
#    Male: AUC = 0.671, Events = 13/4439
#
# Evaluating Multiple_Sclerosis (5-Year Outcome, 1-Year Score)...
# AUC: 0.527 (0.422-0.687) (calculated on 9982 individuals)
# Events (5-Year in Eval Cohort): 13 (0.1%) (from 10000 individuals)
# Excluded 18 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.585, Events = 7/5547
#    Male: AUC = 0.460, Events = 6/4435
#
# Evaluating Thyroid_Disorders (5-Year Outcome, 1-Year Score)...
# AUC: 0.621 (0.581-0.652) (calculated on 10000 individuals)
# Events (5-Year in Eval Cohort): 185 (1.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.615, Events = 152/5560
#    Male: AUC = 0.670, Events = 33/4440
#
# Summary of Results (Prospective 5-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.715 (0.702-0.738)       446        4.5
# Diabetes             0.632 (0.614-0.656)       247        2.5
# Atrial_Fib           0.712 (0.664-0.753)       189        1.9
# CKD                  0.708 (0.653-0.758)       38         0.4
# All_Cancers          0.674 (0.650-0.701)       207        2.1
# Stroke               0.697 (0.630-0.736)       40         0.4
# Heart_Failure        0.630 (0.565-0.686)       80         0.8
# Pneumonia            0.640 (0.589-0.678)       123        1.2
# COPD                 0.640 (0.596-0.681)       150        1.5
# Osteoporosis         0.639 (0.600-0.687)       86         0.9
# Anemia               0.565 (0.519-0.596)       213        2.1
# Colorectal_Cancer    0.630 (0.514-0.700)       43         0.4
# Breast_Cancer        0.605 (0.545-0.645)       113        2.0
# Prostate_Cancer      0.736 (0.707-0.776)       80         1.8
# Lung_Cancer          0.630 (0.556-0.695)       25         0.2
# Bladder_Cancer       0.782 (0.706-0.832)       26         0.3
# Secondary_Cancer     0.563 (0.525-0.611)       116        1.2
# Depression           0.508 (0.462-0.561)       148        1.5
# Anxiety              0.480 (0.377-0.506)       74         0.7
# Bipolar_Disorder     0.588 (0.474-0.681)       16         0.2
# Rheumatoid_Arthritis 0.624 (0.513-0.691)       47         0.5
# Psoriasis            0.511 (0.341-0.689)       14         0.1
# Ulcerative_Colitis   0.641 (0.548-0.735)       29         0.3
# Crohns_Disease       0.721 (0.567-0.920)       13         0.1
# Asthma               0.514 (0.488-0.541)       312        3.1
# Parkinsons           0.688 (0.598-0.787)       20         0.2
# Multiple_Sclerosis   0.527 (0.422-0.687)       13         0.1
# Thyroid_Disorders    0.621 (0.581-0.652)       185        1.8
# --------------------------------------------------------------------------------
# Finished 90000-100000
# Saved: /Users/sarahurbut/aladynoulli2/claudefile/output/batch_results_fixed_10yr.pkl

# %%
# Collect per-disease AUC lists
# Collect per-disease AUC lists
disease_aucs = {}
for batch_res in batch_results_fixed.values():
    for disease, metrics in batch_res.items():
        disease_aucs.setdefault(disease, []).append(metrics["auc"])
# Median AUC and optional IQR
median_auc_df = (
    pd.Series({d: np.nanmedian(vals) for d, vals in disease_aucs.items()}, name="MedianAUC")
      .reset_index()
      .rename(columns={"index": "Disease"})
      .sort_values("MedianAUC", ascending=False)
)
median_auc_df["IQR"] = [
    (np.nanpercentile(disease_aucs[d], 25), np.nanpercentile(disease_aucs[d], 75))
    for d in median_auc_df["Disease"]
]

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=median_auc_df,
    x="MedianAUC",
    y="Disease",
    color="#4c72b0"
)
plt.xlim(0.5, 1.0)
plt.xlabel("Median AUC (across PCS batches)")
plt.ylabel("")
plt.title("Enrollment 10-year predictions (PCS fixed phi runs)")
plt.tight_layout()
plt.show()

# %%
median_auc_df
# Out:
#                  Disease  MedianAUC                                        IQR
# 25            Parkinsons   0.732987   (0.6872588426288877, 0.7781268360707765)
# 0                  ASCVD   0.724426   (0.7192962011937434, 0.7349425075504461)
# 13       Prostate_Cancer   0.722066   (0.7095705023399863, 0.7373543202163024)
# 15        Bladder_Cancer   0.721041    (0.691489913369369, 0.7507974793066272)
# 2             Atrial_Fib   0.706326   (0.6977923316874832, 0.7188068287176963)
# 6          Heart_Failure   0.706032   (0.6759712721335931, 0.7407717397943532)
# 14           Lung_Cancer   0.689615    (0.652265078877541, 0.7160281523355746)
# 9           Osteoporosis   0.686122   (0.6649244447619833, 0.6987864446192874)
# 3                    CKD   0.685250   (0.6672143815363356, 0.7110717952188402)
# 4            All_Cancers   0.683270     (0.6743102368973107, 0.69828125267972)
# 5                 Stroke   0.674497   (0.6488601740904889, 0.6969187336203062)
# 8                   COPD   0.673600   (0.6551647058190595, 0.6836252160912022)
# 11     Colorectal_Cancer   0.665967   (0.6377354560619141, 0.6856084936150713)
# 1               Diabetes   0.628829   (0.6167871551298322, 0.6365270832207435)
# 7              Pneumonia   0.627096   (0.6083643930440732, 0.6398263021361189)
# 20  Rheumatoid_Arthritis   0.625871   (0.5988273739934411, 0.6494823315907967)
# 23        Crohns_Disease   0.612389   (0.5637303356294948, 0.6614407510059406)
# 16      Secondary_Cancer   0.612193   (0.5865822362038586, 0.6290792379079098)
# 22    Ulcerative_Colitis   0.591983   (0.5579766211341431, 0.6245797825782712)
# 27     Thyroid_Disorders   0.589736   (0.5795114757662463, 0.6066114937384868)
# 10                Anemia   0.587608   (0.5726264821606967, 0.5938347779913302)
# 12         Breast_Cancer   0.578727   (0.5606260832464509, 0.5998411508473842)
# 26    Multiple_Sclerosis   0.563561   (0.5277475117937089, 0.6273140510663313)
# 21             Psoriasis   0.550294   (0.5066748134947461, 0.5978685353260389)
# 24                Asthma   0.535068   (0.5249192574110977, 0.5471137029480401)
# 19      Bipolar_Disorder   0.534014  (0.46924357137880646, 0.5832176250713292)
# 18               Anxiety   0.513455  (0.49159507610836994, 0.5288793286959126)
# 17            Depression   0.491795  (0.47499545698140166, 0.5030283571663686)
