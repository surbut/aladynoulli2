# %%
# %load_ext autoreload
# %autoreload 2

from clust_huge_amp_no_kappa import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## here we're running with the likelihood only

# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/1184199116.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/1184199116.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/1184199116.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/1184199116.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, start_index=0, end_index=10000)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data

del Y

# %%
# When initializing the model:
original_G = G_100k # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/1949801412.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/1949801412.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
# Load references (signatures only, no healthy)
refs = torch.load('reference_trajectories.pt')
signature_refs = refs['signature_refs']
# When initializing the model:

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/2429096507.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('reference_trajectories.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/2429096507.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/2429096507.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
torch.manual_seed(7)
np.random.seed(4)
# Create model without healthy reference
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_100k.shape[1],
    init_sd_scaler=1e-1,
    G=G_100k, 
    Y=Y_100k,
    genetic_scale=1,
    W=0.0001,
    R=0,
    prevalence_t=essentials['prevalence_t'],
    signature_references=signature_refs,  # Only pass signature refs
    healthy_reference=True,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

torch.manual_seed(0)
np.random.seed(0)
# Initialize with psi and clusters
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:73: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:80: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:85: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-18.4207, -18.4207, -17.3858, -16.3508, -16.3508])
# Base value centered (first 5): tensor([-0.5458, -0.5458,  0.4891,  1.5240,  1.5240])
# Base value centered mean: 3.23352810482902e-06
# Gamma init for k=0 (first 5): tensor([ 0.0013,  0.0101,  0.0173,  0.0224, -0.0156])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-1.0324, -1.0324, -1.0324, -1.0324, -1.0324])
# Base value centered mean: 2.2811889266449725e-06
# Gamma init for k=1 (first 5): tensor([ 0.0345,  0.0130,  0.0066, -0.0008, -0.0064])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -14.2810, -17.7307])
# Base value centered (first 5): tensor([-0.3508, -0.3508, -0.3508,  3.7888,  0.3391])
# Base value centered mean: 1.4835358115306008e-06
# Gamma init for k=2 (first 5): tensor([ 0.0028, -0.0037,  0.0097,  0.0037, -0.0078])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1693, -0.1693, -0.1693, -0.1693, -0.1693])
# Base value centered mean: 1.5007019555923762e-06
# Gamma init for k=3 (first 5): tensor([ 0.0032, -0.0061,  0.0035,  0.0032, -0.0085])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-17.5684, -18.4207, -17.5684, -17.5684, -15.0115])
# Base value centered (first 5): tensor([-0.0647, -0.9170, -0.0647, -0.0647,  2.4922])
# Base value centered mean: 1.28402712107345e-06
# Gamma init for k=4 (first 5): tensor([-0.0093, -0.0012, -0.0200,  0.0534, -0.0145])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -16.6096, -18.4207])
# Base value centered (first 5): tensor([-0.2438, -0.2438, -0.2438,  1.5673, -0.2438])
# Base value centered mean: 6.72149667479971e-07
# Gamma init for k=5 (first 5): tensor([ 0.0075,  0.0081, -0.0056,  0.0087,  0.0362])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -17.9123])
# Base value centered (first 5): tensor([-0.1640, -0.1640, -0.1640, -0.1640,  0.3444])
# Base value centered mean: 2.344417680433253e-06
# Gamma init for k=6 (first 5): tensor([ 0.0022,  0.0029,  0.0013, -0.0014, -0.0026])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -13.5911, -16.0059])
# Base value centered (first 5): tensor([-0.5885, -0.5885, -0.5885,  4.2411,  1.8263])
# Base value centered mean: -2.6187896651208575e-07
# Gamma init for k=7 (first 5): tensor([ 0.0109,  0.0068, -0.0077,  0.0083, -0.0058])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.0771, -17.3062])
# Base value centered (first 5): tensor([-0.3585, -0.3585, -0.3585,  2.9850,  0.7560])
# Base value centered mean: 6.065369007046684e-08
# Gamma init for k=8 (first 5): tensor([ 0.0023,  0.0006,  0.0013,  0.0198, -0.0015])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.7863, -14.4692])
# Base value centered (first 5): tensor([-0.3788, -0.3788, -0.3788,  2.2555,  3.5727])
# Base value centered mean: 1.1942863693548134e-06
# Gamma init for k=9 (first 5): tensor([ 0.0010,  0.0116,  0.0245, -0.0040,  0.0010])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1966, -0.1966, -0.1966, -0.1966, -0.1966])
# Base value centered mean: 2.228641506007989e-06
# Gamma init for k=10 (first 5): tensor([ 0.0168, -0.0052,  0.0006, -0.0071,  0.0027])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -17.2133])
# Base value centered (first 5): tensor([-0.2801, -0.2801, -0.2801, -0.2801,  0.9273])
# Base value centered mean: 9.216308853865485e-07
# Gamma init for k=11 (first 5): tensor([ 0.0089,  0.0071, -0.0111,  0.0046,  0.0008])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-17.8634, -18.4207, -17.8634, -17.8634, -16.1916])
# Base value centered (first 5): tensor([ 0.0841, -0.4732,  0.0841,  0.0841,  1.7559])
# Base value centered mean: -1.2168884211405384e-07
# Gamma init for k=12 (first 5): tensor([ 0.0103,  0.0020, -0.0029,  0.0020,  0.0037])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2215, -0.2215, -0.2215, -0.2215, -0.2215])
# Base value centered mean: 2.721500322877546e-06
# Gamma init for k=13 (first 5): tensor([ 0.0113,  0.0160,  0.0001,  0.0116, -0.0023])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2371, -0.2371, -0.2371, -0.2371, -0.2371])
# Base value centered mean: 1.2853622592956526e-06
# Gamma init for k=14 (first 5): tensor([-0.0180, -0.0045, -0.0054,  0.0192,  0.0079])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1735, -0.1735, -0.1735, -0.1735, -0.1735])
# Base value centered mean: 2.1408081920526456e-06
# Gamma init for k=15 (first 5): tensor([0.0041, 0.0030, 0.0047, 0.0018, 0.0145])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -16.3508])
# Base value centered (first 5): tensor([-0.3380, -0.3380, -0.3380, -0.3380,  1.7318])
# Base value centered mean: 3.2056807413027855e-06
# Gamma init for k=16 (first 5): tensor([ 0.0037,  0.0152,  0.0178, -0.0035,  0.0137])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3967, -0.3967, -0.3967, -0.3967, -0.3967])
# Base value centered mean: 8.644104241284367e-07
# Gamma init for k=17 (first 5): tensor([-0.0100,  0.0260,  0.0006, -0.0078, -0.0133])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-18.4207, -13.5911, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1475,  4.6821, -0.1475, -0.1475, -0.1475])
# Base value centered mean: 1.9518852241162676e-06
# Gamma init for k=18 (first 5): tensor([-0.0230, -0.0028,  0.0169,  0.0265, -0.0048])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -17.6304, -17.8938])
# Base value centered (first 5): tensor([-0.1783, -0.1783, -0.1783,  0.6120,  0.3485])
# Base value centered mean: 5.923271260144247e-07
# Gamma init for k=19 (first 5): tensor([ 0.0012, -0.0020,  0.0016,  0.0057,  0.0022])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.7040, -18.4207])
# Base value centered (first 5): tensor([-0.2754, -0.2754, -0.2754,  2.4413, -0.2754])
# Base value centered mean: 1.6399383184761973e-06
# Gamma init for k=0 (first 5): tensor([ 0.0106,  0.0089, -0.0075,  0.0094,  0.0357])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-17.7307, -18.4207, -17.7307, -17.7307, -16.3508])
# Base value centered (first 5): tensor([ 0.2206, -0.4693,  0.2206,  0.2206,  1.6005])
# Base value centered mean: 1.5804290569576551e-06
# Gamma init for k=1 (first 5): tensor([0.0061, 0.0023, 0.0006, 0.0035, 0.0020])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-18.4207, -18.4207, -17.4548, -15.5229, -16.4888])
# Base value centered (first 5): tensor([-0.5643, -0.5643,  0.4016,  2.3335,  1.3676])
# Base value centered mean: -3.667831549591938e-07
# Gamma init for k=2 (first 5): tensor([-5.4079e-05,  1.3310e-02,  1.6687e-02,  2.3508e-02, -1.6003e-02])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.2440, -18.0673])
# Base value centered (first 5): tensor([-0.1504, -0.1504, -0.1504,  0.0263,  0.2029])
# Base value centered mean: 1.4457702945946949e-06
# Gamma init for k=3 (first 5): tensor([ 0.0018,  0.0001,  0.0028,  0.0029, -0.0009])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-18.4207, -12.6251, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1660,  5.6295, -0.1660, -0.1660, -0.1660])
# Base value centered mean: 1.8896103028964717e-06
# Gamma init for k=4 (first 5): tensor([-0.0245, -0.0037,  0.0208,  0.0313, -0.0047])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-1.0324, -1.0324, -1.0324, -1.0324, -1.0324])
# Base value centered mean: 2.2811889266449725e-06
# Gamma init for k=5 (first 5): tensor([ 0.0345,  0.0130,  0.0066, -0.0008, -0.0064])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2233, -0.2233, -0.2233, -0.2233, -0.2233])
# Base value centered mean: 1.0049819820778794e-06
# Gamma init for k=6 (first 5): tensor([ 0.0111,  0.0190,  0.0006,  0.0081, -0.0036])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-17.7621, -18.4207, -17.7621, -18.4207, -14.4692])
# Base value centered (first 5): tensor([-0.1473, -0.8058, -0.1473, -0.8058,  3.1457])
# Base value centered mean: -1.2216568165968056e-06
# Gamma init for k=7 (first 5): tensor([ 0.0037, -0.0051, -0.0183,  0.0363, -0.0030])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1699, -0.1699, -0.1699, -0.1699, -0.1699])
# Base value centered mean: 4.0597916495244135e-07
# Gamma init for k=8 (first 5): tensor([ 0.0087, -0.0066,  0.0002, -0.0031, -0.0007])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -17.2133])
# Base value centered (first 5): tensor([-0.2801, -0.2801, -0.2801, -0.2801,  0.9273])
# Base value centered mean: 9.216308853865485e-07
# Gamma init for k=9 (first 5): tensor([ 0.0089,  0.0071, -0.0111,  0.0046,  0.0008])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.3967, -0.3967, -0.3967, -0.3967, -0.3967])
# Base value centered mean: 8.644104241284367e-07
# Gamma init for k=10 (first 5): tensor([-0.0100,  0.0260,  0.0006, -0.0078, -0.0133])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1735, -0.1735, -0.1735, -0.1735, -0.1735])
# Base value centered mean: 2.1408081920526456e-06
# Gamma init for k=11 (first 5): tensor([0.0041, 0.0030, 0.0047, 0.0018, 0.0145])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.1261, -0.1261, -0.1261, -0.1261, -0.1261])
# Base value centered mean: 2.155113179469481e-06
# Gamma init for k=12 (first 5): tensor([ 0.0122, -0.0107,  0.0002, -0.0003, -0.0111])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -13.9626, -16.1916])
# Base value centered (first 5): tensor([-0.2605, -0.2605, -0.2605,  4.1976,  1.9686])
# Base value centered mean: 3.2057762382464716e-06
# Gamma init for k=13 (first 5): tensor([ 0.0014,  0.0079,  0.0190, -0.0075,  0.0012])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.5229, -16.9718])
# Base value centered (first 5): tensor([-0.3756, -0.3756, -0.3756,  2.5222,  1.0733])
# Base value centered mean: -9.460449490461542e-08
# Gamma init for k=14 (first 5): tensor([ 0.0035, -0.0061, -0.0123,  0.0264,  0.0016])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -15.5229])
# Base value centered (first 5): tensor([-0.4179, -0.4179, -0.4179, -0.4179,  2.4799])
# Base value centered mean: 2.443695166221005e-06
# Gamma init for k=15 (first 5): tensor([ 0.0024,  0.0052,  0.0119, -0.0117,  0.0115])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -15.4230, -17.4215])
# Base value centered (first 5): tensor([-0.3560, -0.3560, -0.3560,  2.6417,  0.6433])
# Base value centered mean: 3.547668484316091e-06
# Gamma init for k=16 (first 5): tensor([ 0.0022,  0.0002,  0.0128,  0.0089, -0.0049])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -13.3070, -15.8638])
# Base value centered (first 5): tensor([-0.6198, -0.6198, -0.6198,  4.4939,  1.9371])
# Base value centered mean: -1.0757446489151334e-06
# Gamma init for k=17 (first 5): tensor([ 0.0116,  0.0080, -0.0084,  0.0089, -0.0057])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -18.4207])
# Base value centered (first 5): tensor([-0.2371, -0.2371, -0.2371, -0.2371, -0.2371])
# Base value centered mean: 1.2853622592956526e-06
# Gamma init for k=18 (first 5): tensor([-0.0180, -0.0045, -0.0054,  0.0192,  0.0079])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-18.4207, -18.4207, -18.4207, -18.4207, -17.7907])
# Base value centered (first 5): tensor([-0.2226, -0.2226, -0.2226, -0.2226,  0.4073])
# Base value centered mean: 4.969596716364322e-07
# Gamma init for k=19 (first 5): tensor([-0.0042,  0.0079,  0.0019, -0.0018, -0.0025])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Clusters match exactly: True

# %%
print(model.K_total)
print(model.K)
print(model.lrtpen)
# Out:
# 21
# 20
# 0

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    # Get diagnosis times for this patient
    diagnoses = model.Y[patient]  # Shape: [D, T]
    diagnosis_times = []
    for d in range(model.D):
        diag_time = torch.where(diagnoses[d])[0]
        if len(diag_time) > 0:
            diagnosis_times.append(diag_time[0].item())
            
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')
    
    # Add vertical lines for diagnoses
    for t in diagnosis_times:
        ax1.axvline(x=t, color='red', alpha=0.2, linestyle=':')
        ax2.axvline(x=t, color='red', alpha=0.2, linestyle=':')

# Customize plots
ax1.set_title('Initial Lambda Values')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Initial Proportions')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects and top states
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
# Out:
# Genetic Effect Statistics for Sample Patients:
#
# Patient 4376:
# Mean shift: 0.063
# Std of shifts: 0.139
# Range of shifts: [-0.131, 0.461]
#
# Top states and average proportions:
# State 7: 0.172
# State 3: 0.139
# State 8: 0.080
# State 17: 0.076
# State 1: 0.076
#
# Patient 6640:
# Mean shift: 0.040
# Std of shifts: 0.079
# Range of shifts: [-0.164, 0.232]
#
# Top states and average proportions:
# State 7: 0.169
# State 3: 0.161
# State 8: 0.085
# State 16: 0.082
# State 2: 0.071

# %%
print(f"LRT penalty (R): {model.lrtpen}")
print(f"Lambda amplitude: {model.lambda_amplitude}")
print(f"GP Weight: {model.gpweight}")
# Out:
# LRT penalty (R): 0
# Lambda amplitude: 1
# GP Weight: 0.0001

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
import cProfile
import pstats
from pstats import SortKey

# For the healthtoo version
profiler = cProfile.Profile()
profiler.enable()
history_new = model.fit(E_100k, num_epochs=200, learning_rate=1e-1, lambda_reg=1e-2)
profiler.disable()
stats = pstats.Stats(profiler).sort_stats(SortKey.CUMULATIVE)
stats.print_stats(20)
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:231: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 65.7955
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.38):
#   Theta for diagnosed: 0.151 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.81):
#   Theta for diagnosed: 0.150 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.45):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 347 (signature 3, LR=29.51):
#   Theta for diagnosed: 0.149 ± 0.070
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.94):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 1
# Loss: 707.9572
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.60):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.82):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.47):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.46):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 2
# Loss: 118.7613
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=32.81):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.82):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.48):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.42):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.87):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 3
# Loss: 212.9106
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.02):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.82):
#   Theta for diagnosed: 0.150 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.41):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.86):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 4
# Loss: 424.3810
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.24):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.84):
#   Theta for diagnosed: 0.150 ± 0.038
#   Theta for others: 0.148
#   Proportion difference: 0.002
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.44):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.88):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 5
# Loss: 333.0762
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.47):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.85):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.49):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 50 (signature 15, LR=28.91):
#   Theta for diagnosed: 0.016 ± 0.006
#   Theta for others: 0.014
#   Proportion difference: 0.002
#
# Epoch 6
# Loss: 151.1403
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.71):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.87):
#   Theta for diagnosed: 0.150 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.088 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.001
#
# Disease 347 (signature 3, LR=29.54):
#   Theta for diagnosed: 0.149 ± 0.068
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.04):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Epoch 7
# Loss: 83.7968
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=33.95):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.003
#
# Disease 76 (signature 7, LR=30.88):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 347 (signature 3, LR=29.59):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.28):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Epoch 8
# Loss: 153.2453
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=34.19):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 76 (signature 7, LR=30.89):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.50):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 347 (signature 3, LR=29.62):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Disease 114 (signature 5, LR=29.52):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Epoch 9
# Loss: 232.5675
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=34.45):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 76 (signature 7, LR=30.90):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.51):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=29.77):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 347 (signature 3, LR=29.64):
#   Theta for diagnosed: 0.149 ± 0.069
#   Theta for others: 0.150
#   Proportion difference: -0.001
#
# Epoch 10
# Loss: 222.5960
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=34.70):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 76 (signature 7, LR=30.91):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.52):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=30.02):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=29.68):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 11
# Loss: 147.3563
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=34.96):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 76 (signature 7, LR=30.92):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.54):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=30.27):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=29.91):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 12
# Loss: 85.4461
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=35.22):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 76 (signature 7, LR=30.94):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.55):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 114 (signature 5, LR=30.53):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=30.14):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 13
# Loss: 83.9468
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=35.47):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 76 (signature 7, LR=30.95):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 114 (signature 5, LR=30.79):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 260 (signature 8, LR=30.56):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Disease 188 (signature 2, LR=30.37):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Epoch 14
# Loss: 125.0201
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=35.73):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.05):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 76 (signature 7, LR=30.97):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 188 (signature 2, LR=30.61):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 260 (signature 8, LR=30.57):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Epoch 15
# Loss: 154.8578
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=35.99):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.31):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 76 (signature 7, LR=30.98):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 188 (signature 2, LR=30.85):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 260 (signature 8, LR=30.58):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Epoch 16
# Loss: 142.7556
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=36.25):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.58):
#   Theta for diagnosed: 0.057 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=31.09):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 76 (signature 7, LR=31.00):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 260 (signature 8, LR=30.59):
#   Theta for diagnosed: 0.089 ± 0.074
#   Theta for others: 0.087
#   Proportion difference: 0.002
#
# Epoch 17
# Loss: 104.4441
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=36.50):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=31.84):
#   Theta for diagnosed: 0.058 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=31.33):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 76 (signature 7, LR=31.01):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=30.71):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 18
# Loss: 76.1063
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=36.77):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.11):
#   Theta for diagnosed: 0.058 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=31.58):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 76 (signature 7, LR=31.03):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=30.98):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Epoch 19
# Loss: 77.8543
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=37.03):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.39):
#   Theta for diagnosed: 0.058 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=31.83):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=31.25):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 76 (signature 7, LR=31.05):
#   Theta for diagnosed: 0.151 ± 0.037
#   Theta for others: 0.148
#   Proportion difference: 0.003
#
# Epoch 20
# Loss: 98.7615
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=37.29):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.67):
#   Theta for diagnosed: 0.058 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=32.09):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=31.53):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=31.11):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 21
# Loss: 112.3756
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=37.56):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=32.95):
#   Theta for diagnosed: 0.058 ± 0.040
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=32.35):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=31.81):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.002
#
# Disease 336 (signature 9, LR=31.32):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 22
# Loss: 104.6599
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=37.83):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=33.24):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=32.61):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=32.10):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=31.53):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 23
# Loss: 84.7122
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=38.09):
#   Theta for diagnosed: 0.151 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=33.53):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=32.88):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=32.39):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=31.74):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 24
# Loss: 71.4743
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=38.36):
#   Theta for diagnosed: 0.152 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=33.82):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=33.15):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=32.68):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=31.96):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 25
# Loss: 74.1919
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=38.63):
#   Theta for diagnosed: 0.152 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=34.12):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=33.42):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=32.97):
#   Theta for diagnosed: 0.088 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=32.18):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 26
# Loss: 85.3242
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=38.89):
#   Theta for diagnosed: 0.152 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=34.42):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=33.69):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=33.26):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=32.40):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 27
# Loss: 90.6579
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=39.15):
#   Theta for diagnosed: 0.152 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=34.72):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=33.97):
#   Theta for diagnosed: 0.068 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=33.56):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=32.62):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 28
# Loss: 84.4656
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=39.41):
#   Theta for diagnosed: 0.152 ± 0.036
#   Theta for others: 0.147
#   Proportion difference: 0.004
#
# Disease 114 (signature 5, LR=35.02):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.011
#
# Disease 188 (signature 2, LR=34.25):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=33.85):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=32.85):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 29
# Loss: 73.5940
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=39.67):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=35.33):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=34.53):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=34.15):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=33.08):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 30
# Loss: 68.4008
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=39.92):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=35.64):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=34.81):
#   Theta for diagnosed: 0.069 ± 0.015
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=34.46):
#   Theta for diagnosed: 0.089 ± 0.018
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=33.31):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 31
# Loss: 71.8536
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=40.18):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=35.95):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=35.10):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=34.76):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=33.55):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 32
# Loss: 77.7434
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=40.44):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=36.27):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=35.40):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=35.08):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=33.80):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 33
# Loss: 78.5601
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=40.69):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=36.59):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=35.69):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=35.39):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=34.04):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 34
# Loss: 73.4806
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=40.94):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=36.92):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=35.99):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.001
#
# Disease 33 (signature 17, LR=35.71):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=34.30):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 35
# Loss: 68.0436
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=41.19):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=37.24):
#   Theta for diagnosed: 0.058 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=36.29):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=36.03):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=34.55):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 36
# Loss: 67.2442
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=41.43):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=37.57):
#   Theta for diagnosed: 0.059 ± 0.041
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=36.60):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=36.35):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=34.81):
#   Theta for diagnosed: 0.030 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 37
# Loss: 70.3429
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=41.67):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=37.91):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=36.91):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=36.67):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=35.07):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 38
# Loss: 72.6091
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=41.91):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=38.24):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=37.22):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=37.00):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=35.33):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 39
# Loss: 71.1244
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=42.14):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=38.58):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=37.53):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=37.33):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=35.60):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 40
# Loss: 67.6575
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=42.37):
#   Theta for diagnosed: 0.152 ± 0.037
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=38.93):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=37.85):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=37.66):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=35.87):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 41
# Loss: 65.8959
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=42.60):
#   Theta for diagnosed: 0.152 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=39.28):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=38.17):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=37.99):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=36.14):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 42
# Loss: 67.0131
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=42.82):
#   Theta for diagnosed: 0.152 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.005
#
# Disease 114 (signature 5, LR=39.63):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.047
#   Proportion difference: 0.012
#
# Disease 188 (signature 2, LR=38.49):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=38.33):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=36.42):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 43
# Loss: 68.7684
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=43.04):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=39.98):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.047
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=38.82):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=38.67):
#   Theta for diagnosed: 0.089 ± 0.019
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=36.71):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 44
# Loss: 68.6303
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=43.25):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=40.34):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=39.15):
#   Theta for diagnosed: 0.069 ± 0.016
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=39.02):
#   Theta for diagnosed: 0.090 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=36.99):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 45
# Loss: 66.7311
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=43.46):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=40.70):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=39.48):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=39.37):
#   Theta for diagnosed: 0.090 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=37.29):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 46
# Loss: 65.2519
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=43.67):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=41.07):
#   Theta for diagnosed: 0.059 ± 0.042
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=39.82):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=39.72):
#   Theta for diagnosed: 0.090 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=37.58):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 47
# Loss: 65.5232
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=43.87):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=41.43):
#   Theta for diagnosed: 0.059 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=40.15):
#   Theta for diagnosed: 0.069 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=40.07):
#   Theta for diagnosed: 0.090 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=37.88):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 48
# Loss: 66.5991
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=44.07):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=41.80):
#   Theta for diagnosed: 0.059 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=40.50):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=40.42):
#   Theta for diagnosed: 0.090 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=38.19):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 49
# Loss: 66.7674
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=44.26):
#   Theta for diagnosed: 0.153 ± 0.038
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=42.18):
#   Theta for diagnosed: 0.060 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=40.84):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=40.78):
#   Theta for diagnosed: 0.090 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=38.49):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 50
# Loss: 65.7351
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=44.44):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=42.55):
#   Theta for diagnosed: 0.060 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=41.19):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=41.14):
#   Theta for diagnosed: 0.090 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=38.80):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.000
#
# Epoch 51
# Loss: 64.7361
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=44.63):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=42.94):
#   Theta for diagnosed: 0.060 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=41.54):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.002
#
# Disease 33 (signature 17, LR=41.50):
#   Theta for diagnosed: 0.090 ± 0.020
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=39.11):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 52
# Loss: 64.7608
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=44.81):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=43.32):
#   Theta for diagnosed: 0.060 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=41.89):
#   Theta for diagnosed: 0.070 ± 0.017
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=41.87):
#   Theta for diagnosed: 0.090 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=39.43):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 53
# Loss: 65.3779
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=44.98):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=43.71):
#   Theta for diagnosed: 0.060 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.013
#
# Disease 188 (signature 2, LR=42.25):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=42.23):
#   Theta for diagnosed: 0.090 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.004
#
# Disease 336 (signature 9, LR=39.76):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 54
# Loss: 65.5126
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=45.15):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=44.10):
#   Theta for diagnosed: 0.060 ± 0.043
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 188 (signature 2, LR=42.61):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 33 (signature 17, LR=42.61):
#   Theta for diagnosed: 0.090 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 336 (signature 9, LR=40.09):
#   Theta for diagnosed: 0.031 ± 0.005
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 55
# Loss: 64.9018
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=45.32):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 114 (signature 5, LR=44.50):
#   Theta for diagnosed: 0.060 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 33 (signature 17, LR=42.98):
#   Theta for diagnosed: 0.090 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=42.97):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=40.42):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 56
# Loss: 64.2841
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=45.48):
#   Theta for diagnosed: 0.153 ± 0.039
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 114 (signature 5, LR=44.90):
#   Theta for diagnosed: 0.060 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 33 (signature 17, LR=43.36):
#   Theta for diagnosed: 0.090 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=43.34):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=40.76):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 57
# Loss: 64.2853
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=45.63):
#   Theta for diagnosed: 0.153 ± 0.040
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 114 (signature 5, LR=45.30):
#   Theta for diagnosed: 0.060 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 33 (signature 17, LR=43.74):
#   Theta for diagnosed: 0.091 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=43.71):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=41.10):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 58
# Loss: 64.6349
#
# Monitoring signature responses:
#
# Disease 161 (signature 7, LR=45.78):
#   Theta for diagnosed: 0.154 ± 0.040
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 114 (signature 5, LR=45.70):
#   Theta for diagnosed: 0.060 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 33 (signature 17, LR=44.12):
#   Theta for diagnosed: 0.091 ± 0.021
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=44.08):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=41.44):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 59
# Loss: 64.6699
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=46.11):
#   Theta for diagnosed: 0.060 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 161 (signature 7, LR=45.93):
#   Theta for diagnosed: 0.154 ± 0.040
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 33 (signature 17, LR=44.50):
#   Theta for diagnosed: 0.091 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=44.46):
#   Theta for diagnosed: 0.070 ± 0.018
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=41.79):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 60
# Loss: 64.2659
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=46.52):
#   Theta for diagnosed: 0.061 ± 0.044
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 161 (signature 7, LR=46.07):
#   Theta for diagnosed: 0.154 ± 0.040
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 33 (signature 17, LR=44.89):
#   Theta for diagnosed: 0.091 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=44.84):
#   Theta for diagnosed: 0.070 ± 0.019
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=42.14):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 61
# Loss: 63.9056
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=46.94):
#   Theta for diagnosed: 0.061 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 161 (signature 7, LR=46.21):
#   Theta for diagnosed: 0.154 ± 0.040
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 33 (signature 17, LR=45.28):
#   Theta for diagnosed: 0.091 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=45.22):
#   Theta for diagnosed: 0.070 ± 0.019
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=42.50):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 62
# Loss: 63.9342
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=47.36):
#   Theta for diagnosed: 0.061 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 161 (signature 7, LR=46.35):
#   Theta for diagnosed: 0.154 ± 0.040
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 33 (signature 17, LR=45.67):
#   Theta for diagnosed: 0.091 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=45.60):
#   Theta for diagnosed: 0.071 ± 0.019
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=42.87):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 63
# Loss: 64.1230
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=47.78):
#   Theta for diagnosed: 0.061 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.014
#
# Disease 161 (signature 7, LR=46.48):
#   Theta for diagnosed: 0.154 ± 0.041
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 33 (signature 17, LR=46.06):
#   Theta for diagnosed: 0.091 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=45.99):
#   Theta for diagnosed: 0.071 ± 0.019
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=43.23):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 64
# Loss: 64.0753
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=48.21):
#   Theta for diagnosed: 0.061 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.015
#
# Disease 161 (signature 7, LR=46.61):
#   Theta for diagnosed: 0.154 ± 0.041
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 33 (signature 17, LR=46.46):
#   Theta for diagnosed: 0.091 ± 0.022
#   Theta for others: 0.086
#   Proportion difference: 0.005
#
# Disease 188 (signature 2, LR=46.38):
#   Theta for diagnosed: 0.071 ± 0.019
#   Theta for others: 0.067
#   Proportion difference: 0.003
#
# Disease 336 (signature 9, LR=43.61):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 65
# Loss: 63.7913
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=48.63):
#   Theta for diagnosed: 0.061 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.015
#
# Disease 33 (signature 17, LR=46.86):
#   Theta for diagnosed: 0.091 ± 0.023
#   Theta for others: 0.086
#   Proportion difference: 0.006
#
# Disease 188 (signature 2, LR=46.77):
#   Theta for diagnosed: 0.071 ± 0.019
#   Theta for others: 0.067
#   Proportion difference: 0.004
#
# Disease 161 (signature 7, LR=46.73):
#   Theta for diagnosed: 0.154 ± 0.041
#   Theta for others: 0.147
#   Proportion difference: 0.007
#
# Disease 336 (signature 9, LR=43.98):
#   Theta for diagnosed: 0.031 ± 0.006
#   Theta for others: 0.030
#   Proportion difference: 0.001
#
# Epoch 66
# Loss: 63.5979
#
# Monitoring signature responses:
#
# Disease 114 (signature 5, LR=49.07):
#   Theta for diagnosed: 0.061 ± 0.045
#   Theta for others: 0.046
#   Proportion difference: 0.015
#
# Disease 33 (signature 17, LR=47.26):
#   Theta for diagnosed: 0.091 ± 0.023
#   Theta for others: 0.086
#   Proportion difference: 0.006
#
# ...
#   Theta for others: 0.045
#   Proportion difference: 0.038
#
# Disease 15 (signature 19, LR=103.41):
#   Theta for diagnosed: 0.053 ± 0.028
#   Theta for others: 0.045
#   Proportion difference: 0.008
#
# Disease 131 (signature 0, LR=98.35):
#   Theta for diagnosed: 0.040 ± 0.057
#   Theta for others: 0.027
#   Proportion difference: 0.013
#
# Epoch 182
# Loss: 58.7533
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=129.03):
#   Theta for diagnosed: 0.036 ± 0.031
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=120.30):
#   Theta for diagnosed: 0.029 ± 0.022
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=106.27):
#   Theta for diagnosed: 0.083 ± 0.091
#   Theta for others: 0.045
#   Proportion difference: 0.038
#
# Disease 15 (signature 19, LR=104.18):
#   Theta for diagnosed: 0.053 ± 0.028
#   Theta for others: 0.045
#   Proportion difference: 0.008
#
# Disease 131 (signature 0, LR=98.94):
#   Theta for diagnosed: 0.040 ± 0.057
#   Theta for others: 0.027
#   Proportion difference: 0.013
#
# Epoch 183
# Loss: 58.7178
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=130.09):
#   Theta for diagnosed: 0.036 ± 0.031
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=121.41):
#   Theta for diagnosed: 0.029 ± 0.022
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=106.65):
#   Theta for diagnosed: 0.083 ± 0.091
#   Theta for others: 0.045
#   Proportion difference: 0.038
#
# Disease 15 (signature 19, LR=104.95):
#   Theta for diagnosed: 0.054 ± 0.029
#   Theta for others: 0.045
#   Proportion difference: 0.008
#
# Disease 131 (signature 0, LR=99.54):
#   Theta for diagnosed: 0.040 ± 0.057
#   Theta for others: 0.027
#   Proportion difference: 0.013
#
# Epoch 184
# Loss: 58.6826
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=131.15):
#   Theta for diagnosed: 0.037 ± 0.031
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=122.52):
#   Theta for diagnosed: 0.029 ± 0.022
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=107.02):
#   Theta for diagnosed: 0.083 ± 0.092
#   Theta for others: 0.045
#   Proportion difference: 0.038
#
# Disease 15 (signature 19, LR=105.72):
#   Theta for diagnosed: 0.054 ± 0.029
#   Theta for others: 0.045
#   Proportion difference: 0.008
#
# Disease 131 (signature 0, LR=100.13):
#   Theta for diagnosed: 0.041 ± 0.058
#   Theta for others: 0.027
#   Proportion difference: 0.013
#
# Epoch 185
# Loss: 58.6474
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=132.22):
#   Theta for diagnosed: 0.037 ± 0.032
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=123.63):
#   Theta for diagnosed: 0.029 ± 0.022
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=107.39):
#   Theta for diagnosed: 0.083 ± 0.092
#   Theta for others: 0.045
#   Proportion difference: 0.039
#
# Disease 15 (signature 19, LR=106.49):
#   Theta for diagnosed: 0.054 ± 0.029
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 131 (signature 0, LR=100.72):
#   Theta for diagnosed: 0.041 ± 0.058
#   Theta for others: 0.027
#   Proportion difference: 0.013
#
# Epoch 186
# Loss: 58.6123
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=133.29):
#   Theta for diagnosed: 0.037 ± 0.032
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=124.76):
#   Theta for diagnosed: 0.029 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=107.76):
#   Theta for diagnosed: 0.084 ± 0.093
#   Theta for others: 0.045
#   Proportion difference: 0.039
#
# Disease 15 (signature 19, LR=107.26):
#   Theta for diagnosed: 0.054 ± 0.029
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 131 (signature 0, LR=101.31):
#   Theta for diagnosed: 0.041 ± 0.058
#   Theta for others: 0.027
#   Proportion difference: 0.013
#
# Epoch 187
# Loss: 58.5773
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=134.36):
#   Theta for diagnosed: 0.037 ± 0.032
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=125.89):
#   Theta for diagnosed: 0.029 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 114 (signature 5, LR=108.13):
#   Theta for diagnosed: 0.084 ± 0.093
#   Theta for others: 0.045
#   Proportion difference: 0.039
#
# Disease 15 (signature 19, LR=108.04):
#   Theta for diagnosed: 0.054 ± 0.030
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 47 (signature 15, LR=102.19):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 188
# Loss: 58.5426
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=135.44):
#   Theta for diagnosed: 0.037 ± 0.033
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=127.02):
#   Theta for diagnosed: 0.029 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 15 (signature 19, LR=108.81):
#   Theta for diagnosed: 0.054 ± 0.030
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 114 (signature 5, LR=108.49):
#   Theta for diagnosed: 0.084 ± 0.094
#   Theta for others: 0.045
#   Proportion difference: 0.039
#
# Disease 47 (signature 15, LR=103.12):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 189
# Loss: 58.5080
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=136.51):
#   Theta for diagnosed: 0.037 ± 0.033
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=128.17):
#   Theta for diagnosed: 0.029 ± 0.023
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 15 (signature 19, LR=109.58):
#   Theta for diagnosed: 0.054 ± 0.030
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 114 (signature 5, LR=108.84):
#   Theta for diagnosed: 0.084 ± 0.094
#   Theta for others: 0.045
#   Proportion difference: 0.040
#
# Disease 47 (signature 15, LR=104.06):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 190
# Loss: 58.4733
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=137.59):
#   Theta for diagnosed: 0.037 ± 0.034
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=129.31):
#   Theta for diagnosed: 0.029 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 15 (signature 19, LR=110.36):
#   Theta for diagnosed: 0.054 ± 0.030
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 114 (signature 5, LR=109.20):
#   Theta for diagnosed: 0.085 ± 0.095
#   Theta for others: 0.045
#   Proportion difference: 0.040
#
# Disease 47 (signature 15, LR=105.01):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 191
# Loss: 58.4387
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=138.67):
#   Theta for diagnosed: 0.037 ± 0.034
#   Theta for others: 0.030
#   Proportion difference: 0.007
#
# Disease 21 (signature 13, LR=130.47):
#   Theta for diagnosed: 0.029 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 15 (signature 19, LR=111.13):
#   Theta for diagnosed: 0.054 ± 0.031
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 114 (signature 5, LR=109.54):
#   Theta for diagnosed: 0.085 ± 0.095
#   Theta for others: 0.045
#   Proportion difference: 0.040
#
# Disease 47 (signature 15, LR=105.97):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 192
# Loss: 58.4045
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=139.75):
#   Theta for diagnosed: 0.037 ± 0.034
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 21 (signature 13, LR=131.63):
#   Theta for diagnosed: 0.029 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.006
#
# Disease 15 (signature 19, LR=111.90):
#   Theta for diagnosed: 0.054 ± 0.031
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 114 (signature 5, LR=109.89):
#   Theta for diagnosed: 0.085 ± 0.096
#   Theta for others: 0.045
#   Proportion difference: 0.040
#
# Disease 47 (signature 15, LR=106.93):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 193
# Loss: 58.3704
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=140.83):
#   Theta for diagnosed: 0.037 ± 0.035
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 21 (signature 13, LR=132.79):
#   Theta for diagnosed: 0.029 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 15 (signature 19, LR=112.68):
#   Theta for diagnosed: 0.055 ± 0.031
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 114 (signature 5, LR=110.23):
#   Theta for diagnosed: 0.085 ± 0.096
#   Theta for others: 0.045
#   Proportion difference: 0.040
#
# Disease 47 (signature 15, LR=107.90):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 194
# Loss: 58.3363
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=141.92):
#   Theta for diagnosed: 0.037 ± 0.035
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 21 (signature 13, LR=133.96):
#   Theta for diagnosed: 0.029 ± 0.024
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 15 (signature 19, LR=113.45):
#   Theta for diagnosed: 0.055 ± 0.032
#   Theta for others: 0.045
#   Proportion difference: 0.009
#
# Disease 114 (signature 5, LR=110.57):
#   Theta for diagnosed: 0.085 ± 0.097
#   Theta for others: 0.045
#   Proportion difference: 0.041
#
# Disease 47 (signature 15, LR=108.88):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 195
# Loss: 58.3023
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=143.00):
#   Theta for diagnosed: 0.038 ± 0.036
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 21 (signature 13, LR=135.14):
#   Theta for diagnosed: 0.029 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 15 (signature 19, LR=114.22):
#   Theta for diagnosed: 0.055 ± 0.032
#   Theta for others: 0.045
#   Proportion difference: 0.010
#
# Disease 114 (signature 5, LR=110.90):
#   Theta for diagnosed: 0.086 ± 0.097
#   Theta for others: 0.045
#   Proportion difference: 0.041
#
# Disease 47 (signature 15, LR=109.86):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 196
# Loss: 58.2685
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=144.09):
#   Theta for diagnosed: 0.038 ± 0.036
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 21 (signature 13, LR=136.32):
#   Theta for diagnosed: 0.030 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 15 (signature 19, LR=114.99):
#   Theta for diagnosed: 0.055 ± 0.032
#   Theta for others: 0.045
#   Proportion difference: 0.010
#
# Disease 114 (signature 5, LR=111.23):
#   Theta for diagnosed: 0.086 ± 0.097
#   Theta for others: 0.045
#   Proportion difference: 0.041
#
# Disease 47 (signature 15, LR=110.85):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Epoch 197
# Loss: 58.2347
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=145.18):
#   Theta for diagnosed: 0.038 ± 0.036
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 21 (signature 13, LR=137.50):
#   Theta for diagnosed: 0.030 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 15 (signature 19, LR=115.76):
#   Theta for diagnosed: 0.055 ± 0.032
#   Theta for others: 0.045
#   Proportion difference: 0.010
#
# Disease 47 (signature 15, LR=111.85):
#   Theta for diagnosed: 0.017 ± 0.010
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 114 (signature 5, LR=111.56):
#   Theta for diagnosed: 0.086 ± 0.098
#   Theta for others: 0.045
#   Proportion difference: 0.041
#
# Epoch 198
# Loss: 58.2011
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=146.26):
#   Theta for diagnosed: 0.038 ± 0.037
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 21 (signature 13, LR=138.70):
#   Theta for diagnosed: 0.030 ± 0.025
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 15 (signature 19, LR=116.53):
#   Theta for diagnosed: 0.055 ± 0.033
#   Theta for others: 0.045
#   Proportion difference: 0.010
#
# Disease 47 (signature 15, LR=112.85):
#   Theta for diagnosed: 0.017 ± 0.011
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 114 (signature 5, LR=111.88):
#   Theta for diagnosed: 0.086 ± 0.098
#   Theta for others: 0.045
#   Proportion difference: 0.042
#
# Epoch 199
# Loss: 58.1677
#
# Monitoring signature responses:
#
# Disease 336 (signature 9, LR=147.35):
#   Theta for diagnosed: 0.038 ± 0.037
#   Theta for others: 0.030
#   Proportion difference: 0.008
#
# Disease 21 (signature 13, LR=139.89):
#   Theta for diagnosed: 0.030 ± 0.026
#   Theta for others: 0.023
#   Proportion difference: 0.007
#
# Disease 15 (signature 19, LR=117.30):
#   Theta for diagnosed: 0.055 ± 0.033
#   Theta for others: 0.045
#   Proportion difference: 0.010
#
# Disease 47 (signature 15, LR=113.86):
#   Theta for diagnosed: 0.017 ± 0.011
#   Theta for others: 0.014
#   Proportion difference: 0.003
#
# Disease 114 (signature 5, LR=112.20):
#   Theta for diagnosed: 0.086 ± 0.099
#   Theta for others: 0.045
#   Proportion difference: 0.042
#          94170179 function calls (94149236 primitive calls) in 7570.273 seconds
#
#    Ordered by: cumulative time
#    List reduced from 4180 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000 7570.274 3785.137 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#    1885/2    0.111    0.000 7570.274 3785.137 {built-in method builtins.exec}
#         1    0.749    0.749 7570.274 7570.274 /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/4125118760.py:8(<module>)
#         1  190.088  190.088 7569.525 7569.525 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:322(fit)
#       200    0.010    0.000 5726.705   28.634 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:525(backward)
#       200    0.002    0.000 5726.694   28.633 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#       200    0.002    0.000 5726.683   28.633 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/autograd/graph.py:816(_engine_run_backward)
#       200 5726.681   28.633 5726.681   28.633 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       200  350.008    1.750 1610.803    8.054 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:223(compute_loss)
#       200  577.459    2.887 1134.134    5.671 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:280(compute_gp_prior_loss)
#  43461600  401.749    0.000  401.749    0.000 {built-in method torch.cholesky_solve}
#  43531800  163.425    0.000  164.363    0.000 {built-in method torch.sum}
#       400    2.442    0.006   73.643    0.184 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:214(forward)
#       400    0.006    0.000   42.986    0.107 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/functional.py:210(einsum)
#       400   42.978    0.107   42.978    0.107 {built-in method torch.einsum}
#       600   41.558    0.069   41.558    0.069 {built-in method torch.log}
#       200    1.557    0.008   39.405    0.197 /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:381(analyze_signature_responses)
#       600   39.126    0.065   39.126    0.065 {built-in method torch.clamp}
#       600    0.003    0.000   15.358    0.026 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:33(wrapped)
#       600    0.004    0.000   15.354    0.026 /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/torch/_tensor.py:1026(__rsub__)

# %%
def plot_disease_lambda_alignment(model):
    """
    Plot lambda values aligned with disease occurrences for selected patients
    """
    # Find patients with specific diseases and their diagnosis times
    disease_idx = 112  # MI
    patients_with_disease = []
    diagnosis_times = []
    
    for patient in range(model.Y.shape[0]):
        diag_time = torch.where(model.Y[patient, disease_idx])[0]
        if len(diag_time) > 0:
            patients_with_disease.append(patient)
            diagnosis_times.append(diag_time[0].item())
    
    # Sample a few patients
    n_samples = min(5, len(patients_with_disease))
    sample_indices = np.random.choice(len(patients_with_disease), n_samples, replace=False)
    
    # Create plot
    fig, ax = plt.subplots(figsize=(12, 6))
    time_points = np.arange(model.T)
    
    # Find signature that most strongly associates with this disease
    psi_disease = model.psi[:, disease_idx].detach()
    sig_idx = torch.argmax(psi_disease).item()
    
    # Plot for each sampled patient
    for idx in sample_indices:
        patient = patients_with_disease[idx]
        diag_time = diagnosis_times[idx]
        
        # Plot lambda (detached)
        lambda_values = torch.softmax(model.lambda_[patient].detach(), dim=0)[sig_idx]
        ax.plot(time_points, lambda_values.numpy(),
                alpha=0.5, label=f'Patient {patient}')
        
        # Mark diagnosis time
        ax.axvline(x=diag_time, linestyle=':', alpha=0.3)
    
    ax.set_title(f'Lambda Values for Signature {sig_idx} (Most Associated with MI)\nVertical Lines Show Diagnosis Times')
    ax.set_xlabel('Time')
    ax.set_ylabel('Lambda (proportion)')
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Call the plotting function
plot_disease_lambda_alignment(model)

# %%
def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

    # Plot total loss
    ax1.plot(history)
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Total Loss')
    ax1.set_title('Training Loss')
    ax1.grid(True)

    # Plot component losses
    # Extract from printed output
    epochs = range(len(history))
    #data_losses = [65.6950, 65.6198, 65.5456, 65.4711, 65.3961, 65.3208, 65.2452, 65.1694, 65.0936, 65.0177, 64.9418, 64.8659, 64.7899, 64.7138, 64.6375, 64.5610, 64.4845, 64.4078, 64.3310, 64.2542]
    #gp_losses = [5.6859, 459.7293, 32.8175, 100.4279, 259.7525, 182.3966, 42.2339, 6.2529, 75.5871, 130.6093, 105.0365, 40.0023, 4.2676, 21.8158, 58.3701, 68.2091, 43.7377, 13.1755, 4.6903, 19.4461]
    #lrt_losses = [16456.7656, 16413.8711, 16375.5742, 16337.2236, 16297.7764, 16257.2930, 16216.2754, 16175.0986, 16134.0918, 16093.5273, 16053.4570, 16013.7744, 15974.3174, 15934.9131, 15895.3779, 15855.5889, 15815.5312, 15775.2656, 15734.9033, 15694.5830]

    #ax2.plot(epochs, data_losses, label='Data Loss', color='blue')
    #ax2.plot(epochs, gp_losses, label='GP Loss', color='green')
    #ax2.plot(epochs, lrt_losses, label='LRT Loss', color='red')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss Components')
    ax2.set_title('Loss Components Over Time')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

# Call the plotting function
plot_training_history(history_new)
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_75983/2612062181.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend()

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=1e-2:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Lambda changes with lr=1e-2:
# Mean absolute change: 6.481e-02
# Max absolute change: 6.812e+00
# Std of changes: 1.626e-01

# %%
final_phi = model.phi.detach().clone()
diff = torch.abs(final_phi - initial_phi)

print(f"phi changes with lr=1e-2:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# phi changes with lr=1e-2:
# Mean absolute change: 2.944e-02
# Max absolute change: 2.305e+00
# Std of changes: 1.387e-01

# %%
final_psi = model.psi.detach().clone()
diff = torch.abs(final_psi - initial_psi)

print(f"Psi changes with lr=1e-2:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Psi changes with lr=1e-2:
# Mean absolute change: 1.243e-01
# Max absolute change: 2.668e+00
# Std of changes: 2.725e-01

# %%
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# Clusters match exactly: True

# %%
model.clusters[17]
# Out:
# np.int32(19)

# %%
def plot_theta_differences():
    diseases = [112, 67, 127, 10, 17]
    signatures = [5, 7, 0, 17, 19]
    
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    axes = axes.flatten()
    
    for i, (d, sig) in enumerate(zip(diseases, signatures)):
        ax = axes[i]
        
        # Get diagnosis times
        diagnosis_mask = model.Y[:, d, :].bool()
        diagnosed = torch.where(diagnosis_mask)[0]
        
        # Get thetas
        pi, theta, phi_prob = model.forward()
        
        # Plot distributions
        diagnosed_theta = theta[diagnosis_mask, sig].detach().numpy()
        others_theta = theta[~diagnosis_mask, sig].detach().numpy()
        
        ax.hist(diagnosed_theta, alpha=0.5, label='At diagnosis', density=True)
        ax.hist(others_theta, alpha=0.5, label='Others', density=True)
        
        ax.set_title(f'Disease {d} (sig {sig})')
        ax.set_xlabel('Theta')
        ax.set_ylabel('Density')
        ax.legend()
    
    plt.tight_layout()
    plt.show()

# %%
plot_theta_differences()

# %%
model.gpweight
# Out:
# 0.0001

# %%
# Get μ_dt from checkpoint and predictions
mu_dt = model.prevalence_t  # Shape: (348, 52)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()
#observed_risk=mu_dt_flat
# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000438
# Mean predicted risk (original): 0.000327
# Mean predicted risk (calibrated): 0.000438
# Calibration scale factor: 1.337

# %%
model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp_no_kappa.py:531: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
def plot_psi_heatmap(model, disease_names=None, figsize=(12, 8)):
    """
    Plot heatmap of psi values (signature-disease associations)
    
    Args:
        model: The trained model containing psi parameter
        disease_names: Optional list of disease names
        figsize: Tuple specifying figure size
    """
    plt.figure(figsize=figsize)
    
    # Get psi values from model
    psi = model.psi.detach().numpy()
    
    # Create heatmap
    im = plt.imshow(psi, aspect='auto', cmap='RdBu_r', vmin=-5, vmax=5)
    
    # Add colorbar
    plt.colorbar(im, label='ψ value')
    
    # Labels
    plt.xlabel('Disease')
    plt.ylabel('Signature')
    plt.title('ψ (Signature-Disease Associations)')
    
    # Optional: Add disease names if provided
    if disease_names is not None:
        plt.xticks(range(len(disease_names)), disease_names, 
                  rotation=90, fontsize=8)
    
    # Signature labels
    plt.yticks(range(psi.shape[0]), [f'Signature {i}' for i in range(psi.shape[0])])
    
    plt.tight_layout()
    plt.show()

# Usage:
plot_psi_heatmap(model, disease_names=essentials['disease_names'])  # if you have disease names
# or simply:
# plot_psi_heatmap(model)

# %%
# Get predictions
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
predicted_risk_2d = pi_pred.cpu().detach().numpy().mean(axis=0)  # average across individuals

# Get raw observations and calculate scale factor
Y_np = model.Y.cpu().detach().numpy()
Y_mean_2d = Y_np.mean(axis=0)  # average across individuals
scale_factor = Y_mean_2d.mean() / predicted_risk_2d.mean()
scaled_risk_2d = predicted_risk_2d * scale_factor

# Create plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Original predictions vs raw observations
ax1.scatter(Y_mean_2d.flatten(), predicted_risk_2d.flatten(), 
           alpha=0.3, color='blue', s=10)
ax1.plot([0, max(Y_mean_2d.max(), predicted_risk_2d.max())], 
         [0, max(Y_mean_2d.max(), predicted_risk_2d.max())], 
         'k--', label='x=y')
ax1.set_xlabel('Observed Event Rate (Y)')
ax1.set_ylabel('Original Predicted Risk')
ax1.set_title('Original Predictions vs Observed Events')
ax1.set_xscale('log')
ax1.set_yscale('log')

# Scaled predictions vs raw observations
ax2.scatter(Y_mean_2d.flatten(), scaled_risk_2d.flatten(), 
           alpha=0.3, color='green', s=10)
ax2.plot([0, max(Y_mean_2d.max(), scaled_risk_2d.max())], 
         [0, max(Y_mean_2d.max(), scaled_risk_2d.max())], 
         'k--', label='x=y')
ax2.set_xlabel('Observed Event Rate (Y)')
ax2.set_ylabel('Scaled Predicted Risk')
ax2.set_title(f'Simple Scaling (factor={scale_factor:.2f}) vs Observed Events')
ax2.set_xscale('log')
ax2.set_yscale('log')

plt.tight_layout()
plt.show()

print(f"Scale factor: {scale_factor:.3f}")
# Out:
# Scale factor: 1.337

# %%
model_save_path='/Users/sarahurbut/Dropbox (Personal)/model_NO_kappa_bigam.pt'
torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'initial_phi': initial_phi, 
    'initial_lambda': initial_lambda, 
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t': essentials['prevalence_t'],
    'logit_prevalence_t': model.logit_prev_t,
    'G': G_100k,
    'E': E_100k,
    'indices': indices,
    'disease_names': essentials['disease_names'],
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T': Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, model_save_path)

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.656

# %%
def apply_loess_calibration(predicted_risks, observed_risks):
    # Fit LOESS calibration curve
    calibrated_risks = lowess(
        observed_risks, 
        predicted_risks,
        frac=0.3,  # Can tune this parameter
        return_sorted=False
    )
    
    # Apply to predictions
    pi_calibrated = np.zeros_like(pi)
    for d in range(model.D):
        for t in range(model.T):
            risks = pi[:, d, t]
            pi_calibrated[:, d, t] = lowess(
                observed_risks,  # Use same calibration curve
                risks,
                frac=0.3
            )
    
    return pi_calibrated

# %%
def plot_signature_temporal_patterns(model, disease_names, plot_dir, n_top=10, selected_signatures=None):
    """Show temporal patterns of top diseases for each signature"""
    phi = model.phi.detach().numpy()
    prevalence_logit = model.logit_prev_t.detach().numpy()
    import os
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    phi_avg = phi_centered.mean(axis=2)
    
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            disease_name = disease_names[idx]
            ax.plot(temporal_pattern, label=disease_name)
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, 'temporal_patterns.png'))
    plt.close('all')

# %%
plot_signature_temporal_patterns(model, essentials['disease_names'],'/Users/sarahurbut/Dropbox (Personal)/', n_top=10, selected_signatures=[0,5,6,19])

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Heart failure NOS: effect=1.896 (OR=6.66), std=0.730
# Atrial fibrillation and flutter: effect=1.859 (OR=6.42), std=0.778
# Pleurisy; pleural effusion: effect=1.680 (OR=5.37), std=0.749
# Cardiomegaly: effect=1.588 (OR=4.90), std=0.619
# Congestive heart failure (CHF) NOS: effect=1.526 (OR=4.60), std=0.588
# Aortic valve disease: effect=1.400 (OR=4.06), std=0.248
# Mitral valve disease: effect=1.395 (OR=4.03), std=0.473
# Congenital anomalies of great vessels: effect=1.382 (OR=3.98), std=0.437
# Paroxysmal ventricular tachycardia: effect=1.369 (OR=3.93), std=0.204
# Left bundle branch block: effect=1.348 (OR=3.85), std=0.345
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Pain in joint: effect=2.107 (OR=8.22), std=0.410
# Arthropathy NOS: effect=2.103 (OR=8.19), std=0.738
# Enthesopathy: effect=2.062 (OR=7.86), std=0.568
# Other peripheral nerve disorders: effect=2.020 (OR=7.54), std=0.477
# Internal derangement of knee: effect=1.964 (OR=7.13), std=0.503
# Peripheral enthesopathies and allied syndromes: effect=1.900 (OR=6.68), std=0.527
# Osteoarthritis; localized: effect=1.894 (OR=6.65), std=0.640
# Hallux valgus (Bunion): effect=1.870 (OR=6.49), std=0.428
# Osteoarthrosis, localized, primary: effect=1.790 (OR=5.99), std=0.538
# Rheumatoid arthritis: effect=1.735 (OR=5.67), std=0.494
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Diaphragmatic hernia: effect=2.330 (OR=10.28), std=0.589
# Gastritis and duodenitis: effect=2.238 (OR=9.37), std=0.586
# Iron deficiency anemias, unspecified or not due to blood loss: effect=2.082 (OR=8.02), std=0.683
# Esophagitis, GERD and related diseases: effect=2.024 (OR=7.56), std=0.615
# Reflux esophagitis: effect=2.002 (OR=7.40), std=0.618
# Other specified gastritis: effect=1.920 (OR=6.82), std=0.628
# Gastric ulcer: effect=1.891 (OR=6.62), std=0.507
# Duodenitis: effect=1.788 (OR=5.98), std=0.497
# Benign neoplasm of other parts of digestive system: effect=1.707 (OR=5.51), std=0.631
# Barrett's esophagus: effect=1.640 (OR=5.16), std=0.466
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Inguinal hernia: effect=1.855 (OR=6.39), std=0.543
# Peripheral vascular disease, unspecified: effect=1.684 (OR=5.39), std=0.295
# Varicose veins of lower extremity: effect=1.616 (OR=5.03), std=0.364
# Gout: effect=1.608 (OR=4.99), std=0.519
# Atopic/contact dermatitis due to other or unspecified: effect=1.590 (OR=4.90), std=0.305
# Phlebitis and thrombophlebitis of lower extremities: effect=1.578 (OR=4.85), std=0.353
# Sebaceous cyst: effect=1.569 (OR=4.80), std=0.459
# Right bundle branch block: effect=1.560 (OR=4.76), std=0.305
# Hearing loss: effect=1.548 (OR=4.70), std=0.559
# Pulmonary heart disease: effect=1.541 (OR=4.67), std=0.219
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Other upper respiratory disease: effect=1.152 (OR=3.16), std=0.107
# Septal Deviations/Turbinate Hypertrophy: effect=1.045 (OR=2.84), std=0.112
# Nasal polyps: effect=1.001 (OR=2.72), std=0.164
# Chronic sinusitis: effect=0.981 (OR=2.67), std=0.062
# Chronic pharyngitis and nasopharyngitis: effect=0.893 (OR=2.44), std=0.106
# Hemangioma and lymphangioma, any site: effect=-1.738 (OR=0.18), std=0.087
# Enthesopathy: effect=-1.771 (OR=0.17), std=0.076
# Other acquired deformities of limbs: effect=-1.785 (OR=0.17), std=0.066
# Retinal detachment with retinal defect: effect=-1.802 (OR=0.16), std=0.036
# Other disorders of biliary tract: effect=-1.803 (OR=0.16), std=0.155
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Coronary atherosclerosis: effect=2.344 (OR=10.42), std=0.629
# Hypercholesterolemia: effect=2.321 (OR=10.18), std=0.668
# Angina pectoris: effect=2.123 (OR=8.36), std=0.631
# Myocardial infarction: effect=1.975 (OR=7.21), std=0.762
# Other chronic ischemic heart disease, unspecified: effect=1.914 (OR=6.78), std=0.784
# Unstable angina (intermediate coronary syndrome): effect=1.561 (OR=4.76), std=0.560
# Other acute and subacute forms of ischemic heart disease: effect=1.451 (OR=4.27), std=0.270
# Paroxysmal supraventricular tachycardia: effect=-1.716 (OR=0.18), std=0.069
# Bronchiectasis: effect=-1.788 (OR=0.17), std=0.111
# Allergic rhinitis: effect=-1.798 (OR=0.17), std=0.087
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Secondary malignancy of lymph nodes: effect=1.565 (OR=4.78), std=0.429
# Secondary malignant neoplasm of liver: effect=1.433 (OR=4.19), std=0.519
# Cancer of bronchus; lung: effect=1.262 (OR=3.53), std=0.277
# Secondary malignancy of bone: effect=1.230 (OR=3.42), std=0.341
# Malignant neoplasm, other: effect=1.229 (OR=3.42), std=0.427
# Secondary malignant neoplasm: effect=1.206 (OR=3.34), std=0.272
# Secondary malignant neoplasm of digestive systems: effect=1.142 (OR=3.13), std=0.070
# Secondary malignancy of respiratory organs: effect=0.949 (OR=2.58), std=0.243
# Other disorders of the kidney and ureters: effect=-1.736 (OR=0.18), std=0.068
# Inflammation of eyelids: effect=-1.780 (OR=0.17), std=0.107
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Essential hypertension: effect=1.924 (OR=6.85), std=0.390
# Asthma: effect=1.852 (OR=6.37), std=0.167
# Abdominal pain: effect=1.792 (OR=6.00), std=0.310
# Obesity: effect=1.791 (OR=6.00), std=0.262
# Major depressive disorder: effect=1.681 (OR=5.37), std=0.272
# Osteoporosis NOS: effect=1.673 (OR=5.33), std=0.349
# Hypothyroidism NOS: effect=1.651 (OR=5.21), std=0.421
# GERD: effect=1.643 (OR=5.17), std=0.359
# Irritable Bowel Syndrome: effect=1.549 (OR=4.71), std=0.272
# Myalgia and myositis unspecified: effect=1.541 (OR=4.67), std=0.287
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Polyp of corpus uteri: effect=1.783 (OR=5.95), std=0.598
# Excessive or frequent menstruation: effect=1.644 (OR=5.18), std=0.561
# Uterine/Uterovaginal prolapse: effect=1.613 (OR=5.02), std=0.485
# Ovarian cyst: effect=1.600 (OR=4.95), std=0.326
# Uterine leiomyoma: effect=1.524 (OR=4.59), std=0.596
# Postmenopausal bleeding: effect=1.503 (OR=4.49), std=0.732
# Prolapse of vaginal walls: effect=1.453 (OR=4.28), std=0.605
# Endometriosis: effect=1.437 (OR=4.21), std=0.452
# Cervicitis and endocervicitis: effect=1.427 (OR=4.17), std=0.160
# Noninflammatory disorders of cervix: effect=1.419 (OR=4.13), std=0.242
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Back pain: effect=2.638 (OR=13.98), std=0.664
# Spondylosis without myelopathy: effect=1.870 (OR=6.49), std=0.615
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=1.672 (OR=5.32), std=0.370
# Displacement of intervertebral disc: effect=1.577 (OR=4.84), std=0.330
# Other and unspecified disc disorder: effect=1.515 (OR=4.55), std=0.264
# Spinal stenosis: effect=1.421 (OR=4.14), std=0.561
# Degeneration of intervertebral disc: effect=1.265 (OR=3.54), std=0.245
# Neuralgia, neuritis, and radiculitis NOS: effect=1.255 (OR=3.51), std=0.145
# Sciatica: effect=1.161 (OR=3.19), std=0.264
# Degenerative disease of the spinal cord: effect=1.158 (OR=3.18), std=0.176
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Cataract: effect=1.946 (OR=7.00), std=0.853
# Senile cataract: effect=1.933 (OR=6.91), std=0.853
# Macular degeneration (senile) of retina NOS: effect=1.814 (OR=6.14), std=0.677
# Glaucoma: effect=1.675 (OR=5.34), std=0.693
# Primary open angle glaucoma: effect=1.480 (OR=4.39), std=0.279
# Myopia: effect=1.350 (OR=3.86), std=0.281
# Other retinal disorders: effect=1.350 (OR=3.86), std=0.342
# Retinal vascular changes and abnomalities: effect=1.305 (OR=3.69), std=0.037
# Disorders of vitreous body: effect=1.303 (OR=3.68), std=0.310
# Retinal detachment with retinal defect: effect=1.097 (OR=2.99), std=0.204
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Occlusion of cerebral arteries: effect=1.436 (OR=4.21), std=0.349
# Cerebral ischemia: effect=1.298 (OR=3.66), std=0.312
# Cerebral artery occlusion, with cerebral infarction: effect=1.288 (OR=3.63), std=0.312
# Late effects of cerebrovascular disease: effect=1.239 (OR=3.45), std=0.179
# Hemiplegia: effect=1.172 (OR=3.23), std=0.173
# Cerebrovascular disease: effect=1.110 (OR=3.03), std=0.340
# Transient cerebral ischemia: effect=1.000 (OR=2.72), std=0.043
# Occlusion and stenosis of precerebral arteries: effect=0.984 (OR=2.67), std=0.194
# Retinal detachment with retinal defect: effect=-1.757 (OR=0.17), std=0.043
# Scar conditions and fibrosis of skin: effect=-1.764 (OR=0.17), std=0.022
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Renal colic: effect=1.307 (OR=3.69), std=0.096
# Hydronephrosis: effect=1.158 (OR=3.18), std=0.157
# Stricture/obstruction of ureter: effect=1.074 (OR=2.93), std=0.154
# Calculus of ureter: effect=1.071 (OR=2.92), std=0.042
# Other disorders of the kidney and ureters: effect=1.060 (OR=2.89), std=0.065
# Calculus of kidney: effect=1.039 (OR=2.83), std=0.090
# Pyelonephritis: effect=0.919 (OR=2.51), std=0.028
# Streptococcus infection: effect=-1.804 (OR=0.16), std=0.058
# Occlusion of cerebral arteries: effect=-1.810 (OR=0.16), std=0.075
# Chronic Kidney Disease, Stage III: effect=-1.828 (OR=0.16), std=0.106
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Cancer of prostate: effect=2.096 (OR=8.13), std=0.849
# Hyperplasia of prostate: effect=1.975 (OR=7.21), std=0.836
# Other disorders of bladder: effect=1.804 (OR=6.07), std=0.511
# Urethral stricture (not specified as infectious): effect=1.707 (OR=5.51), std=0.370
# Urinary incontinence: effect=1.544 (OR=4.68), std=0.453
# Cystitis: effect=1.480 (OR=4.39), std=0.211
# Malignant neoplasm of bladder: effect=1.306 (OR=3.69), std=0.274
# Other symptoms/disorders or the urinary system: effect=1.169 (OR=3.22), std=0.107
# Bladder neck obstruction: effect=1.062 (OR=2.89), std=0.104
# Chronic cystitis: effect=1.024 (OR=2.78), std=0.099
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Tobacco use disorder: effect=1.883 (OR=6.58), std=0.890
# Chronic airway obstruction: effect=1.731 (OR=5.65), std=0.850
# Pneumonia: effect=1.697 (OR=5.46), std=0.669
# Pneumococcal pneumonia: effect=1.683 (OR=5.38), std=0.788
# Obstructive chronic bronchitis: effect=1.401 (OR=4.06), std=0.589
# Emphysema: effect=1.356 (OR=3.88), std=0.316
# Empyema and pneumothorax: effect=1.276 (OR=3.58), std=0.224
# Respiratory failure: effect=1.232 (OR=3.43), std=0.551
# Bronchiectasis: effect=1.225 (OR=3.40), std=0.310
# Postinflammatory pulmonary fibrosis: effect=0.981 (OR=2.67), std=0.322
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Type 2 diabetes: effect=2.185 (OR=8.89), std=1.036
# Hypoglycemia: effect=1.403 (OR=4.07), std=0.237
# Type 2 diabetes with ophthalmic manifestations: effect=1.333 (OR=3.79), std=0.277
# Diabetic retinopathy: effect=1.193 (OR=3.30), std=0.178
# Type 1 diabetes: effect=1.180 (OR=3.25), std=0.213
# Pleurisy; pleural effusion: effect=-1.733 (OR=0.18), std=0.074
# Lipoma of skin and subcutaneous tissue: effect=-1.777 (OR=0.17), std=0.090
# Disorders of uterus, NEC: effect=-1.791 (OR=0.17), std=0.083
# First degree AV block: effect=-1.803 (OR=0.16), std=0.119
# Sleep disorders: effect=-1.805 (OR=0.16), std=0.014
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Other anemias: effect=2.101 (OR=8.17), std=0.575
# Constipation: effect=1.973 (OR=7.19), std=0.548
# Other diseases of respiratory system, NEC: effect=1.856 (OR=6.40), std=0.519
# Urinary tract infection: effect=1.841 (OR=6.30), std=0.550
# Cellulitis and abscess of arm/hand: effect=1.772 (OR=5.89), std=0.500
# Hypotension NOS: effect=1.730 (OR=5.64), std=0.528
# Acute renal failure: effect=1.729 (OR=5.63), std=0.544
# Bacterial infection NOS: effect=1.675 (OR=5.34), std=0.480
# E. coli: effect=1.653 (OR=5.22), std=0.421
# Sepsis: effect=1.648 (OR=5.19), std=0.549
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Hemorrhoids: effect=2.266 (OR=9.64), std=0.443
# Benign neoplasm of colon: effect=2.190 (OR=8.94), std=0.555
# Diverticulosis: effect=2.094 (OR=8.12), std=0.629
# Hemorrhage of rectum and anus: effect=2.047 (OR=7.74), std=0.459
# Noninfectious gastroenteritis: effect=2.033 (OR=7.63), std=0.475
# Hemorrhage of gastrointestinal tract: effect=1.909 (OR=6.75), std=0.466
# Anal and rectal conditions: effect=1.874 (OR=6.52), std=0.320
# Anal and rectal polyp: effect=1.873 (OR=6.51), std=0.641
# Other disorders of intestine: effect=1.597 (OR=4.94), std=0.494
# Ventral hernia: effect=1.540 (OR=4.67), std=0.230
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Cholelithiasis: effect=1.786 (OR=5.96), std=0.457
# Peritoneal adhesions (postoperative) (postinfection): effect=1.619 (OR=5.05), std=0.390
# Cholelithiasis with other cholecystitis: effect=1.452 (OR=4.27), std=0.353
# Other disorders of gallbladder: effect=1.449 (OR=4.26), std=0.103
# Cholelithiasis with acute cholecystitis: effect=1.347 (OR=3.85), std=0.134
# Calculus of bile duct: effect=1.316 (OR=3.73), std=0.194
# Cholecystitis without cholelithiasis: effect=1.228 (OR=3.41), std=0.282
# Acute pancreatitis: effect=1.223 (OR=3.40), std=0.107
# Other disorders of biliary tract: effect=1.087 (OR=2.97), std=0.056
# Other disorders of stomach and duodenum: effect=-1.773 (OR=0.17), std=0.073
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Other non-epithelial cancer of skin: effect=2.172 (OR=8.78), std=0.699
# Benign neoplasm of skin: effect=1.847 (OR=6.34), std=0.473
# Malignant neoplasm of female breast: effect=1.812 (OR=6.12), std=0.620
# Actinic keratosis: effect=1.639 (OR=5.15), std=0.570
# Chronic Kidney Disease, Stage III: effect=1.589 (OR=4.90), std=0.681
# Seborrheic keratosis: effect=1.550 (OR=4.71), std=0.254
# Other disorders of eyelids: effect=1.550 (OR=4.71), std=0.277
# Thyrotoxicosis with or without goiter: effect=1.470 (OR=4.35), std=0.226
# Chronic renal failure [CKD]: effect=1.413 (OR=4.11), std=0.554
# Disorders of lacrimal system: effect=1.332 (OR=3.79), std=0.214
#
# Top 10 diseases in Signature 20 (relative to baseline):
# Endometrial hyperplasia: effect=-4.733 (OR=0.01), std=0.125
# Noninfectious gastroenteritis: effect=-4.775 (OR=0.01), std=0.029
# Other upper respiratory disease: effect=-4.796 (OR=0.01), std=0.083
# Aortic valve disease: effect=-4.811 (OR=0.01), std=0.094
# Myalgia and myositis unspecified: effect=-4.819 (OR=0.01), std=0.041
# Angina pectoris: effect=-4.823 (OR=0.01), std=0.033
# Urethral stricture (not specified as infectious): effect=-4.835 (OR=0.01), std=0.053
# Major depressive disorder: effect=-4.841 (OR=0.01), std=0.006
# Dyspareunia: effect=-4.842 (OR=0.01), std=0.018
# Chronic ulcer of skin: effect=-4.846 (OR=0.01), std=0.051

# %%
mean_phi=model.phi.detach().cpu().numpy()

# %%
initial_psi[:,112]
# Out:
# tensor([-1.9906, -2.0008, -2.0034, -2.0126, -1.9857,  0.8679, -1.9930, -2.0030,
#         -2.0053, -2.0097, -1.9918, -1.9775, -2.0165, -1.9968, -1.9910, -2.0046,
#         -1.9988, -1.9991, -1.9921, -1.9857, -5.0022])

# %%
model.psi[:,112]
# Out:
# tensor([-2.1515, -2.0704, -2.0291, -2.1782, -1.9224, -0.2188, -2.1021, -1.9312,
#         -2.0001, -2.1247, -2.0920, -2.0484, -2.0563, -1.9399, -1.9594, -1.9514,
#         -2.4023, -2.2346, -1.9879, -2.0486, -4.9742],
#        grad_fn=<SelectBackward0>)

# %%
model.K=21
def plot_disease_signature_patterns(model, disease_idx=112):
    plt.figure(figsize=(12, 6))
    time_points = np.arange(model.T)
    
    # Get phi values for this disease across all signatures
    phi_disease = model.phi[:, disease_idx].detach()  # [K, T]
    psi_disease = model.psi[:, disease_idx].detach()  # [K]
    
    # Plot phi trajectories
    for k in range(model.K):
        # Make the assigned signature (highest psi) stand out
        is_assigned = (psi_disease[k] == psi_disease.max())
        alpha = 1.0 if is_assigned else 0.3
        linestyle = '-' if is_assigned else '--'
        
        plt.plot(time_points, phi_disease[k], 
                label=f'Signature {k}', 
                alpha=alpha,
                linestyle=linestyle)
    
    plt.title(f'Disease {disease_idx} - Temporal Patterns Across Signatures\n(solid=assigned signature)')
    plt.xlabel('Time')
    plt.ylabel('Phi Value')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    # Print psi values
    print(f"\nPsi values for disease {disease_idx}:")
    for k in range(model.K):
        print(f"Signature {k}: {psi_disease[k]:.3f}")

# Call the function for MI (disease 112)
plot_disease_signature_patterns(model, disease_idx=112)
# Out:
# Psi values for disease 112:
# Signature 0: -2.152
# Signature 1: -2.070
# Signature 2: -2.029
# Signature 3: -2.178
# Signature 4: -1.922
# Signature 5: -0.219
# Signature 6: -2.102
# Signature 7: -1.931
# Signature 8: -2.000
# Signature 9: -2.125
# Signature 10: -2.092
# Signature 11: -2.048
# Signature 12: -2.056
# Signature 13: -1.940
# Signature 14: -1.959
# Signature 15: -1.951
# Signature 16: -2.402
# Signature 17: -2.235
# Signature 18: -1.988
# Signature 19: -2.049
# Signature 20: -4.974

# %%
# Get gradients for each parameter
psi_grad = model.psi.grad
phi_grad = model.phi.grad
lambda_grad = model.lambda_.grad
gamma_grad = model.gamma.grad
#lrtpen_grad = model.lrtpen.grad if model.lrtpen.grad is not None else None
#gpweight_grad = model.gpweight.grad if model.gpweight.grad is not None else None

# Print gradient statistics
print("PSI gradients:")
print(f"Mean: {psi_grad.abs().mean():.3e}")
print(f"Max: {psi_grad.abs().max():.3e}")

print("\nPHI gradients:")
print(f"Mean: {phi_grad.abs().mean():.3e}")
print(f"Max: {phi_grad.abs().max():.3e}")

print("\nLAMBDA gradients:")
print(f"Mean: {lambda_grad.abs().mean():.3e}")
print(f"Max: {lambda_grad.abs().max():.3e}")

print("\nGAMMA gradients:")
print(f"Mean: {gamma_grad.abs().mean():.3e}")
print(f"Max: {gamma_grad.abs().max():.3e}")

#if lrtpen_grad is not None:
    #print("\nLRT penalty gradient:", lrtpen_grad.item())
    
#if gpweight_grad is not None:
    #print("\nGP weight gradient:", gpweight_grad.item())
# Out:
# PSI gradients:
# Mean: 1.514e-08
# Max: 2.447e-06
#
# PHI gradients:
# Mean: 8.276e-06
# Max: 3.363e-03
#
# LAMBDA gradients:
# Mean: 1.433e-06
# Max: 3.676e-04
#
# GAMMA gradients:
# Mean: 1.150e-07
# Max: 2.803e-06

# %%
model.psi
# Out:
# Parameter containing:
# tensor([[-1.8415, -1.7789, -2.0241,  ..., -2.0496, -1.9539, -2.1073],
#         [-1.9173, -1.9291, -1.9201,  ..., -2.0855, -2.0116, -2.0997],
#         [-1.8651, -1.9259, -2.0535,  ..., -2.0503, -1.9964, -1.9811],
#         ...,
#         [-1.9647, -1.9995, -1.8866,  ..., -2.0005, -2.0740, -1.9125],
#         [-2.0278, -1.9404, -2.0017,  ..., -1.9534, -1.9934, -2.0810],
#         [-4.9893, -4.9906, -5.0868,  ..., -5.0225, -4.9879, -4.9182]],
#        requires_grad=True)

# %%
initial_psi
# Out:
# tensor([[-2.0162, -1.9909, -1.9982,  ..., -1.9936, -1.9885, -2.0048],
#         [-2.0034, -1.9774, -2.0040,  ..., -1.9989, -2.0033, -1.9827],
#         [-1.9909, -1.9892, -2.0000,  ..., -1.9940, -1.9808, -2.0092],
#         ...,
#         [-2.0022, -1.9927, -1.9903,  ..., -1.9766, -2.0031, -2.0167],
#         [-1.9907, -1.9997, -1.9918,  ..., -1.9948, -1.9953, -1.9874],
#         [-5.0113, -5.0115, -5.0025,  ..., -4.9993, -4.9923, -5.0097]])

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Heart failure NOS: 2.764
# 2. Pericarditis: 2.386
# 3. Congestive heart failure (CHF) NOS: 1.820
# 4. Mitral valve disease: 1.725
# 5. Cardiomegaly: 1.637
# 6. Paroxysmal ventricular tachycardia: 1.435
# 7. Aortic valve disease: 0.899
# 8. Congenital anomalies of great vessels: 0.877
# 9. Paroxysmal supraventricular tachycardia: 0.618
# 10. Disease of tricuspid valve: -0.071
#
# Final top diseases:
# 1. Heart failure NOS: 1.896
# 2. Atrial fibrillation and flutter: 1.859
# 3. Pleurisy; pleural effusion: 1.680
# 4. Cardiomegaly: 1.588
# 5. Congestive heart failure (CHF) NOS: 1.526
# 6. Aortic valve disease: 1.400
# 7. Mitral valve disease: 1.395
# 8. Congenital anomalies of great vessels: 1.382
# 9. Paroxysmal ventricular tachycardia: 1.369
# 10. Left bundle branch block: 1.348
#
# Pleurisy; pleural effusion changed from rank 12 to 3
#
# Mitral valve disease changed from rank 4 to 7
#
# Pericarditis changed from rank 2 to 12
#
# Paroxysmal supraventricular tachycardia changed from rank 9 to 12
#
# Paroxysmal ventricular tachycardia changed from rank 6 to 9
#
# Atrial fibrillation and flutter changed from rank 12 to 2
#
# Signature 1:
#
# Initial top diseases:
# 1. Peripheral enthesopathies and allied syndromes: 3.226
# 2. Osteoarthrosis, localized, primary: 2.574
# 3. Arthropathy NOS: 2.133
# 4. Internal derangement of knee: 1.561
# 5. Joint effusions: 0.963
# 6. Symptoms and disorders of the joints: 0.731
# 7. Acquired toe deformities: 0.623
# 8. Other disorders of synovium, tendon, and bursa: 0.582
# 9. Other peripheral nerve disorders: 0.505
# 10. Hallux rigidus: 0.246
#
# Final top diseases:
# 1. Pain in joint: 2.107
# 2. Arthropathy NOS: 2.103
# 3. Enthesopathy: 2.062
# 4. Other peripheral nerve disorders: 2.020
# 5. Internal derangement of knee: 1.964
# 6. Peripheral enthesopathies and allied syndromes: 1.900
# 7. Osteoarthritis; localized: 1.894
# 8. Hallux valgus (Bunion): 1.870
# 9. Osteoarthrosis, localized, primary: 1.790
# 10. Rheumatoid arthritis: 1.735
#
# Hallux valgus (Bunion) changed from rank 12 to 8
#
# Osteoarthritis; localized changed from rank 12 to 7
#
# Osteoarthrosis, localized, primary changed from rank 2 to 9
#
# Symptoms and disorders of the joints changed from rank 6 to 12
#
# Joint effusions changed from rank 5 to 12
#
# Pain in joint changed from rank 12 to 1
#
# Other peripheral nerve disorders changed from rank 9 to 4
#
# Peripheral enthesopathies and allied syndromes changed from rank 1 to 6
#
# Enthesopathy changed from rank 12 to 3
#
# Other disorders of synovium, tendon, and bursa changed from rank 8 to 12
#
# Acquired toe deformities changed from rank 7 to 12
#
# Signature 2:
#
# Initial top diseases:
# 1. Diaphragmatic hernia: 2.243
# 2. Other disorders of stomach and duodenum: 1.961
# 3. Reflux esophagitis: 1.321
# 4. Barrett's esophagus: 1.223
# 5. Ulcer of esophagus: 1.030
# 6. Duodenal ulcer: 0.683
# 7. Iron deficiency anemias, unspecified or not due to blood loss: 0.445
# 8. Gastritis and duodenitis: -0.220
# 9. Other specified gastritis: -0.264
# 10. Gastric ulcer: -0.617
#
# Final top diseases:
# 1. Diaphragmatic hernia: 2.330
# 2. Gastritis and duodenitis: 2.238
# 3. Iron deficiency anemias, unspecified or not due to blood loss: 2.082
# 4. Esophagitis, GERD and related diseases: 2.024
# 5. Reflux esophagitis: 2.002
# 6. Other specified gastritis: 1.920
# 7. Gastric ulcer: 1.891
# 8. Duodenitis: 1.788
# 9. Benign neoplasm of other parts of digestive system: 1.707
# 10. Barrett's esophagus: 1.640
#
# Other disorders of stomach and duodenum changed from rank 2 to 12
#
# Benign neoplasm of other parts of digestive system changed from rank 12 to 9
#
# Esophagitis, GERD and related diseases changed from rank 12 to 4
#
# Ulcer of esophagus changed from rank 5 to 12
#
# Barrett's esophagus changed from rank 4 to 10
#
# Gastric ulcer changed from rank 10 to 7
#
# Duodenal ulcer changed from rank 6 to 12
#
# Gastritis and duodenitis changed from rank 8 to 2
#
# Iron deficiency anemias, unspecified or not due to blood loss changed from rank 7 to 3
#
# Duodenitis changed from rank 12 to 8
#
# Other specified gastritis changed from rank 9 to 6
#
# Signature 3:
#
# Initial top diseases:
# 1. Lipoma of skin and subcutaneous tissue: 2.358
# 2. Sleep disorders: 2.351
# 3. Chronic tonsillitis and adenoiditis: 2.342
# 4. Inflammation of eyelids: 2.337
# 5. Epilepsy, recurrent seizures, convulsions: 2.254
# 6. Parkinson's disease: 2.245
# 7. Cardiac arrest: 2.232
# 8. Hypertrophy of breast (Gynecomastia): 2.197
# 9. Bacterial enteritis: 1.930
# 10. Disorders of conjunctiva: 1.838
#
# Final top diseases:
# 1. Inguinal hernia: 1.855
# 2. Peripheral vascular disease, unspecified: 1.684
# 3. Varicose veins of lower extremity: 1.616
# 4. Gout: 1.608
# 5. Atopic/contact dermatitis due to other or unspecified: 1.590
# 6. Phlebitis and thrombophlebitis of lower extremities: 1.578
# 7. Sebaceous cyst: 1.569
# 8. Right bundle branch block: 1.560
# 9. Hearing loss: 1.548
# 10. Pulmonary heart disease: 1.541
#
# Cardiac arrest changed from rank 7 to 12
#
# Bacterial enteritis changed from rank 9 to 12
#
# Hypertrophy of breast (Gynecomastia) changed from rank 8 to 12
#
# Inguinal hernia changed from rank 12 to 1
#
# Sleep disorders changed from rank 2 to 12
#
# Parkinson's disease changed from rank 6 to 12
#
# Peripheral vascular disease, unspecified changed from rank 12 to 2
#
# Epilepsy, recurrent seizures, convulsions changed from rank 5 to 12
#
# Phlebitis and thrombophlebitis of lower extremities changed from rank 12 to 6
#
# Varicose veins of lower extremity changed from rank 12 to 3
#
# Atopic/contact dermatitis due to other or unspecified changed from rank 12 to 5
#
# Chronic tonsillitis and adenoiditis changed from rank 3 to 12
#
# Inflammation of eyelids changed from rank 4 to 12
#
# Lipoma of skin and subcutaneous tissue changed from rank 1 to 12
#
# Sebaceous cyst changed from rank 12 to 7
#
# Hearing loss changed from rank 12 to 9
#
# Gout changed from rank 12 to 4
#
# Right bundle branch block changed from rank 12 to 8
#
# Signature 4:
#
# Initial top diseases:
# 1. Other upper respiratory disease: 1.836
# 2. Septal Deviations/Turbinate Hypertrophy: 1.249
# 3. Chronic pharyngitis and nasopharyngitis: 0.947
# 4. Chronic sinusitis: 0.730
# 5. Nasal polyps: 0.364
# 6. Strabismus (not specified as paralytic): -1.844
# 7. Hemangioma and lymphangioma, any site: -1.844
# 8. Enthesopathy: -1.845
# 9. Retinal detachment with retinal defect: -1.852
# 10. Facial nerve disorders [CN7]: -1.856
#
# Final top diseases:
# 1. Other upper respiratory disease: 1.152
# 2. Septal Deviations/Turbinate Hypertrophy: 1.045
# 3. Nasal polyps: 1.001
# 4. Chronic sinusitis: 0.981
# 5. Chronic pharyngitis and nasopharyngitis: 0.893
# 6. Hemangioma and lymphangioma, any site: -1.738
# 7. Enthesopathy: -1.771
# 8. Other acquired deformities of limbs: -1.785
# 9. Retinal detachment with retinal defect: -1.802
# 10. Other disorders of biliary tract: -1.803
#
# Other acquired deformities of limbs changed from rank 12 to 8
#
# Strabismus (not specified as paralytic) changed from rank 6 to 12
#
# Signature 5:
#
# Initial top diseases:
# 1. Coronary atherosclerosis: 1.758
# 2. Angina pectoris: 0.382
# 3. Hypercholesterolemia: 0.337
# 4. Unstable angina (intermediate coronary syndrome): -0.050
# 5. Myocardial infarction: -0.219
# 6. Other acute and subacute forms of ischemic heart disease: -0.298
# 7. Other chronic ischemic heart disease, unspecified: -0.551
# 8. Bronchiectasis: -1.561
# 9. Uterine/Uterovaginal prolapse: -1.660
# 10. Secondary malignancy of bone: -1.806
#
# Final top diseases:
# 1. Coronary atherosclerosis: 2.344
# 2. Hypercholesterolemia: 2.321
# 3. Angina pectoris: 2.123
# 4. Myocardial infarction: 1.975
# 5. Other chronic ischemic heart disease, unspecified: 1.914
# 6. Unstable angina (intermediate coronary syndrome): 1.561
# 7. Other acute and subacute forms of ischemic heart disease: 1.451
# 8. Paroxysmal supraventricular tachycardia: -1.716
# 9. Bronchiectasis: -1.788
# 10. Allergic rhinitis: -1.798
#
# Uterine/Uterovaginal prolapse changed from rank 9 to 12
#
# Paroxysmal supraventricular tachycardia changed from rank 12 to 8
#
# Signature 6:
#
# Initial top diseases:
# 1. Malignant neoplasm, other: 3.150
# 2. Secondary malignant neoplasm of liver: 2.675
# 3. Secondary malignant neoplasm: 1.495
# 4. Secondary malignancy of bone: 1.326
# 5. Secondary malignant neoplasm of digestive systems: 1.313
# 6. Secondary malignancy of respiratory organs: 1.097
# 7. Cancer of bronchus; lung: 0.047
# 8. Secondary malignancy of lymph nodes: -0.183
# 9. Bacterial pneumonia: -1.830
# 10. Inflammation of eyelids: -1.831
#
# Final top diseases:
# 1. Secondary malignancy of lymph nodes: 1.565
# 2. Secondary malignant neoplasm of liver: 1.433
# 3. Cancer of bronchus; lung: 1.262
# 4. Secondary malignancy of bone: 1.230
# 5. Malignant neoplasm, other: 1.229
# 6. Secondary malignant neoplasm: 1.206
# 7. Secondary malignant neoplasm of digestive systems: 1.142
# 8. Secondary malignancy of respiratory organs: 0.949
# 9. Other disorders of the kidney and ureters: -1.736
# 10. Inflammation of eyelids: -1.780
#
# Cancer of bronchus; lung changed from rank 7 to 3
#
# Malignant neoplasm, other changed from rank 1 to 5
#
# Secondary malignant neoplasm changed from rank 3 to 6
#
# Secondary malignancy of lymph nodes changed from rank 8 to 1
#
# Bacterial pneumonia changed from rank 9 to 12
#
# Other disorders of the kidney and ureters changed from rank 12 to 9
#
# Signature 7:
#
# Initial top diseases:
# 1. Spondylosis and allied disorders: 1.963
# 2. Obesity: 0.749
# 3. Abdominal pain: 0.629
# 4. Rheumatism, unspecified and fibrositis: 0.629
# 5. Asthma: 0.521
# 6. Sleep apnea: 0.288
# 7. Other inflammatory spondylopathies: 0.271
# 8. Essential hypertension: 0.132
# 9. Cervicalgia: 0.113
# 10. Other chronic nonalcoholic liver disease: -0.217
#
# Final top diseases:
# 1. Essential hypertension: 1.924
# 2. Asthma: 1.852
# 3. Abdominal pain: 1.792
# 4. Obesity: 1.791
# 5. Major depressive disorder: 1.681
# 6. Osteoporosis NOS: 1.673
# 7. Hypothyroidism NOS: 1.651
# 8. GERD: 1.643
# 9. Irritable Bowel Syndrome: 1.549
# 10. Myalgia and myositis unspecified: 1.541
#
# Major depressive disorder changed from rank 12 to 5
#
# Sleep apnea changed from rank 6 to 12
#
# Osteoporosis NOS changed from rank 12 to 6
#
# Irritable Bowel Syndrome changed from rank 12 to 9
#
# Cervicalgia changed from rank 9 to 12
#
# Asthma changed from rank 5 to 2
#
# Other inflammatory spondylopathies changed from rank 7 to 12
#
# Essential hypertension changed from rank 8 to 1
#
# Spondylosis and allied disorders changed from rank 1 to 12
#
# Hypothyroidism NOS changed from rank 12 to 7
#
# GERD changed from rank 12 to 8
#
# Rheumatism, unspecified and fibrositis changed from rank 4 to 12
#
# Signature 8:
#
# Initial top diseases:
# 1. Dysmenorrhea: 2.217
# 2. Mucous polyp of cervix: 2.174
# 3. Irregular menstrual bleeding: 1.808
# 4. Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: 1.515
# 5. Malignant neoplasm of uterus: 1.351
# 6. Cervicitis and endocervicitis: 1.325
# 7. Noninflammatory disorders of cervix: 1.080
# 8. Dyspareunia: 1.003
# 9. Pain and other symptoms associated with female genital organs: 1.000
# 10. Pelvic peritoneal adhesions, female (postoperative) (postinfection): 0.912
#
# Final top diseases:
# 1. Polyp of corpus uteri: 1.783
# 2. Excessive or frequent menstruation: 1.644
# 3. Uterine/Uterovaginal prolapse: 1.613
# 4. Ovarian cyst: 1.600
# 5. Uterine leiomyoma: 1.524
# 6. Postmenopausal bleeding: 1.503
# 7. Prolapse of vaginal walls: 1.453
# 8. Endometriosis: 1.437
# 9. Cervicitis and endocervicitis: 1.427
# 10. Noninflammatory disorders of cervix: 1.419
#
# Cervicitis and endocervicitis changed from rank 6 to 9
#
# Endometriosis changed from rank 12 to 8
#
# Prolapse of vaginal walls changed from rank 12 to 7
#
# Uterine/Uterovaginal prolapse changed from rank 12 to 3
#
# Noninflammatory disorders of cervix changed from rank 7 to 10
#
# Polyp of corpus uteri changed from rank 12 to 1
#
# Mucous polyp of cervix changed from rank 2 to 12
#
# Pain and other symptoms associated with female genital organs changed from rank 9 to 12
#
# Dyspareunia changed from rank 8 to 12
#
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] changed from rank 4 to 12
#
# Malignant neoplasm of uterus changed from rank 5 to 12
#
# Excessive or frequent menstruation changed from rank 12 to 2
#
# Irregular menstrual bleeding changed from rank 3 to 12
#
# Dysmenorrhea changed from rank 1 to 12
#
# Postmenopausal bleeding changed from rank 12 to 6
#
# Ovarian cyst changed from rank 12 to 4
#
# Uterine leiomyoma changed from rank 12 to 5
#
# Signature 9:
#
# Initial top diseases:
# 1. Degeneration of intervertebral disc: 3.229
# 2. Displacement of intervertebral disc: 3.181
# 3. Degenerative disease of the spinal cord: 1.430
# 4. Spinal stenosis: 0.889
# 5. Other and unspecified disc disorder: 0.845
# 6. Back pain: 0.389
# 7. Neuralgia, neuritis, and radiculitis NOS: 0.276
# 8. Acquired spondylolisthesis: 0.226
# 9. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 0.165
# 10. Sciatica: -0.363
#
# Final top diseases:
# 1. Back pain: 2.638
# 2. Spondylosis without myelopathy: 1.870
# 3. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.672
# 4. Displacement of intervertebral disc: 1.577
# 5. Other and unspecified disc disorder: 1.515
# 6. Spinal stenosis: 1.421
# 7. Degeneration of intervertebral disc: 1.265
# 8. Neuralgia, neuritis, and radiculitis NOS: 1.255
# 9. Sciatica: 1.161
# 10. Degenerative disease of the spinal cord: 1.158
#
# Acquired spondylolisthesis changed from rank 8 to 12
#
# Degenerative disease of the spinal cord changed from rank 3 to 10
#
# Back pain changed from rank 6 to 1
#
# Thoracic or lumbosacral neuritis or radiculitis, unspecified changed from rank 9 to 3
#
# Spondylosis without myelopathy changed from rank 12 to 2
#
# Degeneration of intervertebral disc changed from rank 1 to 7
#
# Signature 10:
#
# Initial top diseases:
# 1. Myopia: 2.511
# 2. Glaucoma: 2.476
# 3. Retinal detachments and defects: 2.163
# 4. Macular degeneration (senile) of retina NOS: 1.287
# 5. Retinal detachment with retinal defect: 0.557
# 6. Retinal vascular changes and abnomalities: 0.369
# 7. Other retinal disorders: 0.355
# 8. Senile cataract: 0.016
# 9. Disorders of vitreous body: -0.417
# 10. Primary open angle glaucoma: -0.569
#
# Final top diseases:
# 1. Cataract: 1.946
# 2. Senile cataract: 1.933
# 3. Macular degeneration (senile) of retina NOS: 1.814
# 4. Glaucoma: 1.675
# 5. Primary open angle glaucoma: 1.480
# 6. Myopia: 1.350
# 7. Other retinal disorders: 1.350
# 8. Retinal vascular changes and abnomalities: 1.305
# 9. Disorders of vitreous body: 1.303
# 10. Retinal detachment with retinal defect: 1.097
#
# Retinal detachments and defects changed from rank 3 to 12
#
# Retinal detachment with retinal defect changed from rank 5 to 10
#
# Primary open angle glaucoma changed from rank 10 to 5
#
# Cataract changed from rank 12 to 1
#
# Senile cataract changed from rank 8 to 2
#
# Myopia changed from rank 1 to 6
#
# Signature 11:
#
# Initial top diseases:
# 1. Cerebrovascular disease: 2.721
# 2. Cerebral artery occlusion, with cerebral infarction: 2.668
# 3. Occlusion and stenosis of precerebral arteries: 1.714
# 4. Late effects of cerebrovascular disease: 1.084
# 5. Cerebral ischemia: 0.908
# 6. Transient cerebral ischemia: 0.522
# 7. Hemiplegia: -0.029
# 8. Occlusion of cerebral arteries: -1.259
# 9. Scar conditions and fibrosis of skin: -1.819
# 10. Hyperpotassemia: -1.828
#
# Final top diseases:
# 1. Occlusion of cerebral arteries: 1.436
# 2. Cerebral ischemia: 1.298
# 3. Cerebral artery occlusion, with cerebral infarction: 1.288
# 4. Late effects of cerebrovascular disease: 1.239
# 5. Hemiplegia: 1.172
# 6. Cerebrovascular disease: 1.110
# 7. Transient cerebral ischemia: 1.000
# 8. Occlusion and stenosis of precerebral arteries: 0.984
# 9. Retinal detachment with retinal defect: -1.757
# 10. Scar conditions and fibrosis of skin: -1.764
#
# Cerebrovascular disease changed from rank 1 to 6
#
# Occlusion and stenosis of precerebral arteries changed from rank 3 to 8
#
# Occlusion of cerebral arteries changed from rank 8 to 1
#
# Cerebral ischemia changed from rank 5 to 2
#
# Retinal detachment with retinal defect changed from rank 12 to 9
#
# Signature 12:
#
# Initial top diseases:
# 1. Renal colic: 1.715
# 2. Calculus of ureter: 1.551
# 3. Hydronephrosis: 1.475
# 4. Stricture/obstruction of ureter: 1.243
# 5. Pyelonephritis: 1.125
# 6. Other disorders of the kidney and ureters: 0.686
# 7. Calculus of kidney: 0.612
# 8. Secondary malignant neoplasm of digestive systems: -1.772
# 9. Streptococcus infection: -1.785
# 10. Duodenitis: -1.828
#
# Final top diseases:
# 1. Renal colic: 1.307
# 2. Hydronephrosis: 1.158
# 3. Stricture/obstruction of ureter: 1.074
# 4. Calculus of ureter: 1.071
# 5. Other disorders of the kidney and ureters: 1.060
# 6. Calculus of kidney: 1.039
# 7. Pyelonephritis: 0.919
# 8. Streptococcus infection: -1.804
# 9. Occlusion of cerebral arteries: -1.810
# 10. Chronic Kidney Disease, Stage III: -1.828
#
# Occlusion of cerebral arteries changed from rank 12 to 9
#
# Secondary malignant neoplasm of digestive systems changed from rank 8 to 12
#
# Signature 13:
#
# Initial top diseases:
# 1. Urinary incontinence: 2.459
# 2. Cystitis: 1.932
# 3. Bladder neck obstruction: 1.767
# 4. Other disorders of bladder: 1.608
# 5. Other disorders of prostate: 1.493
# 6. Urethral stricture (not specified as infectious): 1.449
# 7. Other symptoms/disorders or the urinary system: 1.437
# 8. Chronic prostatitis: 1.377
# 9. Functional disorders of bladder: 1.214
# 10. Chronic cystitis: 0.712
#
# Final top diseases:
# 1. Cancer of prostate: 2.096
# 2. Hyperplasia of prostate: 1.975
# 3. Other disorders of bladder: 1.804
# 4. Urethral stricture (not specified as infectious): 1.707
# 5. Urinary incontinence: 1.544
# 6. Cystitis: 1.480
# 7. Malignant neoplasm of bladder: 1.306
# 8. Other symptoms/disorders or the urinary system: 1.169
# 9. Bladder neck obstruction: 1.062
# 10. Chronic cystitis: 1.024
#
# Cancer of prostate changed from rank 12 to 1
#
# Malignant neoplasm of bladder changed from rank 12 to 7
#
# Cystitis changed from rank 2 to 6
#
# Bladder neck obstruction changed from rank 3 to 9
#
# Functional disorders of bladder changed from rank 9 to 12
#
# Urinary incontinence changed from rank 1 to 5
#
# Hyperplasia of prostate changed from rank 12 to 2
#
# Chronic prostatitis changed from rank 8 to 12
#
# Other disorders of prostate changed from rank 5 to 12
#
# Signature 14:
#
# Initial top diseases:
# 1. Bronchiectasis: 2.233
# 2. Empyema and pneumothorax: 1.802
# 3. Pneumonia: 1.112
# 4. Pneumococcal pneumonia: 1.092
# 5. Postinflammatory pulmonary fibrosis: 1.086
# 6. Emphysema: -0.177
# 7. Obstructive chronic bronchitis: -1.093
# 8. Tobacco use disorder: -1.128
# 9. Chronic airway obstruction: -1.280
# 10. Respiratory failure: -1.639
#
# Final top diseases:
# 1. Tobacco use disorder: 1.883
# 2. Chronic airway obstruction: 1.731
# 3. Pneumonia: 1.697
# 4. Pneumococcal pneumonia: 1.683
# 5. Obstructive chronic bronchitis: 1.401
# 6. Emphysema: 1.356
# 7. Empyema and pneumothorax: 1.276
# 8. Respiratory failure: 1.232
# 9. Bronchiectasis: 1.225
# 10. Postinflammatory pulmonary fibrosis: 0.981
#
# Tobacco use disorder changed from rank 8 to 1
#
# Chronic airway obstruction changed from rank 9 to 2
#
# Bronchiectasis changed from rank 1 to 9
#
# Postinflammatory pulmonary fibrosis changed from rank 5 to 10
#
# Empyema and pneumothorax changed from rank 2 to 7
#
# Signature 15:
#
# Initial top diseases:
# 1. Type 2 diabetes with ophthalmic manifestations: 0.966
# 2. Hypoglycemia: 0.355
# 3. Type 1 diabetes: -0.023
# 4. Diabetic retinopathy: -0.307
# 5. Type 2 diabetes: -0.787
# 6. Sleep disorders: -1.787
# 7. Diseases and other conditions of the tongue: -1.846
# 8. Malignant neoplasm of female breast: -1.851
# 9. Scar conditions and fibrosis of skin: -1.860
# 10. Streptococcus infection: -1.860
#
# Final top diseases:
# 1. Type 2 diabetes: 2.185
# 2. Hypoglycemia: 1.403
# 3. Type 2 diabetes with ophthalmic manifestations: 1.333
# 4. Diabetic retinopathy: 1.193
# 5. Type 1 diabetes: 1.180
# 6. Pleurisy; pleural effusion: -1.733
# 7. Lipoma of skin and subcutaneous tissue: -1.777
# 8. Disorders of uterus, NEC: -1.791
# 9. First degree AV block: -1.803
# 10. Sleep disorders: -1.805
#
# Sleep disorders changed from rank 6 to 10
#
# Disorders of uterus, NEC changed from rank 12 to 8
#
# Malignant neoplasm of female breast changed from rank 8 to 12
#
# Scar conditions and fibrosis of skin changed from rank 9 to 12
#
# Lipoma of skin and subcutaneous tissue changed from rank 12 to 7
#
# Pleurisy; pleural effusion changed from rank 12 to 6
#
# Type 2 diabetes changed from rank 5 to 1
#
# Diseases and other conditions of the tongue changed from rank 7 to 12
#
# First degree AV block changed from rank 12 to 9
#
# Signature 16:
#
# Initial top diseases:
# 1. Staphylococcus infections: 2.969
# 2. Thrombocytopenia: 2.002
# 3. Hypovolemia: 1.648
# 4. Peritonitis and retroperitoneal infections: 1.618
# 5. Streptococcus infection: 1.551
# 6. Hyperpotassemia: 1.495
# 7. Chronic ulcer of skin: 1.220
# 8. Other anemias: 0.630
# 9. Acute renal failure: 0.506
# 10. Bacterial pneumonia: 0.236
#
# Final top diseases:
# 1. Other anemias: 2.101
# 2. Constipation: 1.973
# 3. Other diseases of respiratory system, NEC: 1.856
# 4. Urinary tract infection: 1.841
# 5. Cellulitis and abscess of arm/hand: 1.772
# 6. Hypotension NOS: 1.730
# 7. Acute renal failure: 1.729
# 8. Bacterial infection NOS: 1.675
# 9. E. coli: 1.653
# 10. Sepsis: 1.648
#
# Bacterial infection NOS changed from rank 12 to 8
#
# Staphylococcus infections changed from rank 1 to 12
#
# Streptococcus infection changed from rank 5 to 12
#
# E. coli changed from rank 12 to 9
#
# Constipation changed from rank 12 to 2
#
# Peritonitis and retroperitoneal infections changed from rank 4 to 12
#
# Hypotension NOS changed from rank 12 to 6
#
# Cellulitis and abscess of arm/hand changed from rank 12 to 5
#
# Chronic ulcer of skin changed from rank 7 to 12
#
# Other diseases of respiratory system, NEC changed from rank 12 to 3
#
# Urinary tract infection changed from rank 12 to 4
#
# Hyperpotassemia changed from rank 6 to 12
#
# Hypovolemia changed from rank 3 to 12
#
# Other anemias changed from rank 8 to 1
#
# Thrombocytopenia changed from rank 2 to 12
#
# Signature 17:
#
# Initial top diseases:
# 1. Hemorrhage of rectum and anus: 2.530
# 2. Ulcerative colitis: 1.877
# 3. Other disorders of intestine: 1.778
# 4. Noninfectious gastroenteritis: 1.251
# 5. Ventral hernia: 1.172
# 6. Neoplasm of unspecified nature of digestive system: 0.558
# 7. Gastrointestinal complications: 0.534
# 8. Hemorrhoids: -0.210
# 9. Benign neoplasm of colon: -0.219
# 10. Diverticulosis: -0.238
#
# Final top diseases:
# 1. Hemorrhoids: 2.266
# 2. Benign neoplasm of colon: 2.190
# 3. Diverticulosis: 2.094
# 4. Hemorrhage of rectum and anus: 2.047
# 5. Noninfectious gastroenteritis: 2.033
# 6. Hemorrhage of gastrointestinal tract: 1.909
# 7. Anal and rectal conditions: 1.874
# 8. Anal and rectal polyp: 1.873
# 9. Other disorders of intestine: 1.597
# 10. Ventral hernia: 1.540
#
# Ventral hernia changed from rank 5 to 10
#
# Ulcerative colitis changed from rank 2 to 12
#
# Diverticulosis changed from rank 10 to 3
#
# Neoplasm of unspecified nature of digestive system changed from rank 6 to 12
#
# Anal and rectal conditions changed from rank 12 to 7
#
# Anal and rectal polyp changed from rank 12 to 8
#
# Hemorrhoids changed from rank 8 to 1
#
# Other disorders of intestine changed from rank 3 to 9
#
# Gastrointestinal complications changed from rank 7 to 12
#
# Hemorrhage of rectum and anus changed from rank 1 to 4
#
# Benign neoplasm of colon changed from rank 9 to 2
#
# Hemorrhage of gastrointestinal tract changed from rank 12 to 6
#
# Signature 18:
#
# Initial top diseases:
# 1. Other disorders of biliary tract: 2.333
# 2. Acute pancreatitis: 2.003
# 3. Cholecystitis without cholelithiasis: 1.852
# 4. Other disorders of gallbladder: 1.031
# 5. Calculus of bile duct: 0.997
# 6. Cholelithiasis: 0.884
# 7. Cholelithiasis with acute cholecystitis: 0.773
# 8. Peritoneal adhesions (postoperative) (postinfection): 0.353
# 9. Cholelithiasis with other cholecystitis: 0.170
# 10. Bronchiectasis: -1.822
#
# Final top diseases:
# 1. Cholelithiasis: 1.786
# 2. Peritoneal adhesions (postoperative) (postinfection): 1.619
# 3. Cholelithiasis with other cholecystitis: 1.452
# 4. Other disorders of gallbladder: 1.449
# 5. Cholelithiasis with acute cholecystitis: 1.347
# 6. Calculus of bile duct: 1.316
# 7. Cholecystitis without cholelithiasis: 1.228
# 8. Acute pancreatitis: 1.223
# 9. Other disorders of biliary tract: 1.087
# 10. Other disorders of stomach and duodenum: -1.773
#
# Peritoneal adhesions (postoperative) (postinfection) changed from rank 8 to 2
#
# Cholelithiasis changed from rank 6 to 1
#
# Cholelithiasis with other cholecystitis changed from rank 9 to 3
#
# Cholecystitis without cholelithiasis changed from rank 3 to 7
#
# Other disorders of biliary tract changed from rank 1 to 9
#
# Acute pancreatitis changed from rank 2 to 8
#
# Signature 19:
#
# Initial top diseases:
# 1. Malignant neoplasm of female breast: 2.840
# 2. Disorders of lacrimal system: 2.790
# 3. Other disorders of eyelids: 2.436
# 4. Renal failure NOS: 2.288
# 5. Benign neoplasm of skin: 2.270
# 6. Seborrheic keratosis: 2.249
# 7. Breast cancer [female]: 2.050
# 8. Hypertensive chronic kidney disease: 1.950
# 9. Chronic glomerulonephritis, NOS: 1.731
# 10. Ectropion or entropion: 1.714
#
# Final top diseases:
# 1. Other non-epithelial cancer of skin: 2.172
# 2. Benign neoplasm of skin: 1.847
# 3. Malignant neoplasm of female breast: 1.812
# 4. Actinic keratosis: 1.639
# 5. Chronic Kidney Disease, Stage III: 1.589
# 6. Seborrheic keratosis: 1.550
# 7. Other disorders of eyelids: 1.550
# 8. Thyrotoxicosis with or without goiter: 1.470
# 9. Chronic renal failure [CKD]: 1.413
# 10. Disorders of lacrimal system: 1.332
#
# Other non-epithelial cancer of skin changed from rank 12 to 1
#
# Breast cancer [female] changed from rank 7 to 12
#
# Other disorders of eyelids changed from rank 3 to 7
#
# Disorders of lacrimal system changed from rank 2 to 10
#
# Chronic glomerulonephritis, NOS changed from rank 9 to 12
#
# Renal failure NOS changed from rank 4 to 12
#
# Actinic keratosis changed from rank 12 to 4
#
# Benign neoplasm of skin changed from rank 5 to 2
#
# Chronic renal failure [CKD] changed from rank 12 to 9
#
# Chronic Kidney Disease, Stage III changed from rank 12 to 5
#
# Thyrotoxicosis with or without goiter changed from rank 12 to 8
#
# Hypertensive chronic kidney disease changed from rank 8 to 12
#
# Signature 20:
#
# Initial top diseases:
# 1. Endometrial hyperplasia: -4.804
# 2. Noninfectious gastroenteritis: -4.813
# 3. Other upper respiratory disease: -4.827
# 4. Dyspareunia: -4.841
# 5. Melanomas of skin: -4.842
# 6. Chronic ulcer of skin: -4.844
# 7. Angina pectoris: -4.850
# 8. Major depressive disorder: -4.861
# 9. Orthostatic hypotension: -4.871
# 10. Pain and other symptoms associated with female genital organs: -4.874
#
# Final top diseases:
# 1. Endometrial hyperplasia: -4.733
# 2. Noninfectious gastroenteritis: -4.775
# 3. Other upper respiratory disease: -4.796
# 4. Aortic valve disease: -4.811
# 5. Myalgia and myositis unspecified: -4.819
# 6. Angina pectoris: -4.823
# 7. Urethral stricture (not specified as infectious): -4.835
# 8. Major depressive disorder: -4.841
# 9. Dyspareunia: -4.842
# 10. Chronic ulcer of skin: -4.846
#
# Melanomas of skin changed from rank 5 to 12
#
# Dyspareunia changed from rank 4 to 9
#
# Orthostatic hypotension changed from rank 9 to 12
#
# Myalgia and myositis unspecified changed from rank 12 to 5
#
# Chronic ulcer of skin changed from rank 6 to 10
#
# Aortic valve disease changed from rank 12 to 4
#
# Urethral stricture (not specified as infectious) changed from rank 12 to 7

# %%
model.K=21

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    # Get diagnosis times for this patient
    diagnoses = model.Y[patient]  # Shape: [D, T]
    diagnosis_times = []
    for d in range(model.D):
        diag_time = torch.where(diagnoses[d])[0]
        if len(diag_time) > 0:
            diagnosis_times.append(diag_time[0].item())
            
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')
    
    # Add vertical lines for diagnoses
    for t in diagnosis_times:
        ax1.axvline(x=t, color='red', alpha=0.2, linestyle=':')
        ax2.axvline(x=t, color='red', alpha=0.2, linestyle=':')

# Customize plots
ax1.set_title('Final Lambda Values')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Final Proportions')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects and top states
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
# Out:
# Genetic Effect Statistics for Sample Patients:
#
# Patient 4376:
# Mean shift: 0.058
# Std of shifts: 0.153
# Range of shifts: [-0.178, 0.443]
#
# Top states and average proportions:
# State 7: 0.165
# State 5: 0.128
# State 3: 0.122
# State 17: 0.079
# State 16: 0.068
#
# Patient 6640:
# Mean shift: 0.038
# Std of shifts: 0.089
# Range of shifts: [-0.129, 0.195]
#
# Top states and average proportions:
# State 7: 0.177
# State 3: 0.160
# State 8: 0.085
# State 16: 0.078
# State 2: 0.070

# %%
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the RDS file
readRDS = robjects.r['readRDS']
pce_data = readRDS('/Users/sarahurbut/Dropbox (Personal)/pce_df_goff_full.rds')
pce_df = pandas2ri.rpy2py(pce_data)  # Convert to pandas DataFrame

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import numpy as np
import matplotlib.pyplot as plt

def plot_roc_curve(y_true, y_pred, label):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    plt.plot(fpr, tpr, label=label)

# %%
Y.shape
# Out:
# (10000, 348, 52)

# %%
def compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116]):
    """
    Compare 10-year predictions using LOESS calibrated risks
    """
    our_10yr_risks = []
    actual_10yr = []

    # Get predictions
    pi = model.forward()[0].detach().numpy()
    
    # Get mean risks across patients for calibration
    predicted_risk_2d = pi.mean(axis=0)  # Shape: [D, T]
    observed_risk_2d = model.Y.numpy().mean(axis=0)  # Shape: [D, T]
    
    # Sort and get LOESS calibration curve
    pred_flat = predicted_risk_2d.flatten()
    obs_flat = observed_risk_2d.flatten()
    sort_idx = np.argsort(pred_flat)
    smoothed = lowess(obs_flat[sort_idx], pred_flat[sort_idx], frac=0.3)
    
    # Apply calibration to all predictions using interpolation
    pi_calibrated = np.interp(pi.flatten(), smoothed[:, 0], smoothed[:, 1]).reshape(pi.shape)
    
    # Calculate 10-year risks using calibrated predictions
    for patient_idx, row in enumerate(pce_df.itertuples()):
        enroll_time = int(row.age - 30)
        if enroll_time + 10 >= model.T:
            continue
            
        pi_ascvd = pi_calibrated[patient_idx, ascvd_indices, enroll_time:enroll_time+10]
        ascvd_timeprob = 1 - np.prod(1 - pi_ascvd, axis=0)
        risk = 1 - np.prod(1 - ascvd_timeprob)
        our_10yr_risks.append(risk)
        
        Y_ascvd = model.Y[patient_idx, ascvd_indices, enroll_time:enroll_time+10]
        actual = torch.any(torch.any(Y_ascvd, dim=0))
        actual_10yr.append(actual.item())
   
    our_10yr_risks = np.array(our_10yr_risks)
    actual_10yr = np.array(actual_10yr)
    pce_risks = pce_df['pce_goff_fuull'].values[:len(our_10yr_risks)]
    
    # Calculate ROC AUCs
    our_auc = roc_auc_score(actual_10yr, our_10yr_risks)
    pce_auc = roc_auc_score(actual_10yr, pce_risks)
    
    print(f"\nROC AUC Comparison (10-year prediction from enrollment):")
    print(f"Our model: {our_auc:.3f}")
    print(f"PCE: {pce_auc:.3f}")
    
    # Plot ROC curves
    plt.figure(figsize=(8,6))
    plot_roc_curve(actual_10yr, our_10yr_risks, label=f'Our Model (AUC={our_auc:.3f})')
    plot_roc_curve(actual_10yr, pce_risks, label=f'PCE (AUC={pce_auc:.3f})')
    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for 10-year ASCVD Prediction')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the function
compare_with_pce(model, pce_df)

## just use prediction at a given age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 64
#      61     plt.show()
#      63 # Call the function
# ---> 64 compare_with_pce(model, pce_df)
#      66 ## just use prediction at a given age
#
# Cell In[57], line 19, in compare_with_pce(model, pce_df, ascvd_indices)
#      17 obs_flat = observed_risk_2d.flatten()
#      18 sort_idx = np.argsort(pred_flat)
# ---> 19 smoothed = lowess(obs_flat[sort_idx], pred_flat[sort_idx], frac=0.3)
#      21 # Apply calibration to all predictions using interpolation
#      22 pi_calibrated = np.interp(pi.flatten(), smoothed[:, 0], smoothed[:, 1]).reshape(pi.shape)
#
# NameError: name 'lowess' is not defined

# %%
# For the notebook without kappa:
psi = model.psi.detach().numpy()
print("Psi without kappa:")
print(f"min={psi.min():.3f}, max={psi.max():.3f}")
print(f"mean={psi.mean():.3f}, std={psi.std():.3f}")
print(f"max={psi.max():.3f}, std={psi.std():.3f}")
# Quick histogram
plt.figure(figsize=(8, 4))
plt.hist(psi.flatten(), bins=50)
plt.title('Distribution of ψ values (without κ)')
plt.xlabel('ψ value')
plt.ylabel('Count')
plt.show()
# Out:
# Psi without kappa:
# min=-5.206, max=3.229
# mean=-2.056, std=0.892
# max=3.229, std=0.892

# %%
compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116])

# %%
def compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116]):
    """
    Compare 10-year predictions using single timepoint prediction
    """
    our_10yr_risks = []
    actual_10yr = []

    # Get predictions
    pi = model.forward()[0].detach().numpy()
    
    # Get mean risks across patients for calibration
    predicted_risk_2d = pi.mean(axis=0)  # Shape: [D, T]
    observed_risk_2d = model.Y.numpy().mean(axis=0)  # Shape: [D, T]
    
    # Sort and get LOESS calibration curve
    pred_flat = predicted_risk_2d.flatten()
    obs_flat = observed_risk_2d.flatten()
    sort_idx = np.argsort(pred_flat)
    smoothed = lowess(obs_flat[sort_idx], pred_flat[sort_idx], frac=0.3)
    
    # Apply calibration to all predictions using interpolation
    pi_calibrated = np.interp(pi.flatten(), smoothed[:, 0], smoothed[:, 1]).reshape(pi.shape)
    
    # Calculate 10-year risks using only enrollment time prediction
    for patient_idx, row in enumerate(pce_df.itertuples()):
        enroll_time = int(row.age - 30)
        if enroll_time + 10 >= model.T:
            continue
            
        # Only use predictions at enrollment time
        pi_ascvd = pi_calibrated[patient_idx, ascvd_indices, enroll_time]
        
        # Calculate 1-year risk first
        yearly_risk = 1 - np.prod(1 - pi_ascvd)
        
        # Convert to 10-year risk
        risk = 1 - (1 - yearly_risk)**10
        our_10yr_risks.append(risk)
        
        # Still look at actual events over 10 years
        Y_ascvd = model.Y[patient_idx, ascvd_indices, enroll_time:enroll_time+10]
        actual = torch.any(torch.any(Y_ascvd, dim=0))
        actual_10yr.append(actual.item())
   
    # Rest of the function remains the same
    our_10yr_risks = np.array(our_10yr_risks)
    actual_10yr = np.array(actual_10yr)
    pce_risks = pce_df['pce_goff_fuull'].values[:len(our_10yr_risks)]
    
    # Calculate ROC AUCs
    our_auc = roc_auc_score(actual_10yr, our_10yr_risks)
    pce_auc = roc_auc_score(actual_10yr, pce_risks)
    
    print(f"\nROC AUC Comparison (10-year prediction from enrollment):")
    print(f"Our model: {our_auc:.3f}")
    print(f"PCE: {pce_auc:.3f}")
    
    plt.figure(figsize=(8,6))
    plot_roc_curve(actual_10yr, our_10yr_risks, label=f'Our Model (AUC={our_auc:.3f})')
    plot_roc_curve(actual_10yr, pce_risks, label=f'PCE (AUC={pce_auc:.3f})')
    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for 10-year ASCVD Prediction')
    plt.legend()
    plt.grid(True)
    plt.show()

compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 69
#      66     plt.grid(True)
#      67     plt.show()
# ---> 69 compare_with_pce(model, pce_df, ascvd_indices=[111,112,113,114,115,116])
#
# NameError: name 'pce_df' is not defined

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients].detach()  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Final Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Final Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects for these patients
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]  # Already computed above
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
# Out:
# Genetic Effect Statistics for Sample Patients:
#
# Patient 4376:
# Mean shift: 0.058
# Std of shifts: 0.153
# Range of shifts: [-0.178, 0.443]
#
# Top states and average proportions:
# State 7: 0.165
# State 5: 0.128
# State 3: 0.122
# State 17: 0.079
# State 16: 0.068
#
# Patient 6640:
# Mean shift: 0.038
# Std of shifts: 0.089
# Range of shifts: [-0.129, 0.195]
#
# Top states and average proportions:
# State 7: 0.177
# State 3: 0.160
# State 8: 0.085
# State 16: 0.078
# State 2: 0.070

# %%
predicted_risk.shape
# Out:
# (18096,)

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess

# Calculate both calibration methods
# Simple scaling
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
scaled_risk = predicted_risk * scale_factor

# LOESS calibration
loess_risk = lowess(observed_risk, predicted_risk, frac=0.3, return_sorted=False)

# Create comparison plots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# Original predictions
ax1.scatter(observed_risk, predicted_risk, alpha=0.5, s=20)
ax1.plot([0, max(observed_risk)], [0, max(observed_risk)], 'k--', label='x=y line')
ax1.set_title('Original Predictions')
ax1.set_xlabel('Observed Risk')
ax1.set_ylabel('Predicted Risk')
ax1.legend()

# Simple scaling calibration
ax2.scatter(observed_risk, scaled_risk, alpha=0.5, s=20)
ax2.plot([0, max(observed_risk)], [0, max(observed_risk)], 'k--', label='x=y line')
ax2.set_title(f'Simple Scaling (factor={scale_factor:.2f})')
ax2.set_xlabel('Observed Risk')
ax2.set_ylabel('Scaled Risk')
ax2.legend()

# LOESS calibration
ax3.scatter(observed_risk, loess_risk, alpha=0.5, s=20)
ax3.plot([0, max(observed_risk)], [0, max(observed_risk)], 'k--', label='x=y line')
ax3.set_title('LOESS Calibration')
ax3.set_xlabel('Observed Risk')
ax3.set_ylabel('LOESS Calibrated Risk')
ax3.legend()

# Calibration curves comparison
sort_idx = np.argsort(predicted_risk)
pred_sorted = predicted_risk[sort_idx]
obs_sorted = observed_risk[sort_idx]
smoothed = lowess(obs_sorted, pred_sorted, frac=0.3)

ax4.scatter(predicted_risk, observed_risk, alpha=0.3, s=20, label='Data points')
ax4.plot(pred_sorted, pred_sorted * scale_factor, 'g-', label='Simple scaling', linewidth=2)
ax4.plot(smoothed[:, 0], smoothed[:, 1], 'r-', label='LOESS curve', linewidth=2)
ax4.plot([0, max(predicted_risk)], [0, max(predicted_risk)], 'k--', label='x=y line')
ax4.set_title('Calibration Curves Comparison')
ax4.set_xlabel('Predicted Risk')
ax4.set_ylabel('Observed Risk')
ax4.legend()

plt.tight_layout()
plt.show()

# Print performance metrics
from sklearn.metrics import r2_score, mean_squared_error
print("\nPerformance Metrics:")
print(f"Original R²: {r2_score(observed_risk, predicted_risk):.3f}")
print(f"Simple Scaling R²: {r2_score(observed_risk, scaled_risk):.3f}")
print(f"LOESS Calibrated R²: {r2_score(observed_risk, loess_risk):.3f}")
print(f"\nOriginal RMSE: {np.sqrt(mean_squared_error(observed_risk, predicted_risk)):.6f}")
print(f"Simple Scaling RMSE: {np.sqrt(mean_squared_error(observed_risk, scaled_risk)):.6f}")
print(f"LOESS Calibrated RMSE: {np.sqrt(mean_squared_error(observed_risk, loess_risk)):.6f}")
# Out:
# Performance Metrics:
# Original R²: 0.860
# Simple Scaling R²: 0.656
# LOESS Calibrated R²: 0.900
#
# Original RMSE: 0.000345
# Simple Scaling RMSE: 0.000542
# LOESS Calibrated RMSE: 0.000292

# %%
essentials['prevalence_t']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 essentials['prevalence_t']
#
# NameError: name 'essentials' is not defined

# %%
# Get μ_dt from checkpoint and predictions

mu_dt = essentials['prevalence_t'] # Shape: (348, 52)
scale_factor = np.mean(mu_dt) / np.mean(predicted_risk_2d)
scaled_risk_2d = predicted_risk_2d * scale_factor

# Create two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Original predictions vs μ_dt
ax1.scatter(mu_dt.flatten(), predicted_risk_2d.flatten(), 
           alpha=0.3, color='blue', s=10)
ax1.plot([0, max(mu_dt.max(), predicted_risk_2d.max())], 
         [0, max(mu_dt.max(), predicted_risk_2d.max())], 
         'k--', label='x=y')
ax1.set_xlabel('Smoothed Prevalence (μ_dt)')
ax1.set_ylabel('Original Predicted Risk')
ax1.set_title('Original Predictions vs Smoothed Prevalence')
ax1.set_xscale('log')
ax1.set_yscale('log')

# Scaled predictions vs μ_dt
ax2.scatter(mu_dt.flatten(), scaled_risk_2d.flatten(), 
           alpha=0.3, color='green', s=10)
ax2.plot([0, max(mu_dt.max(), scaled_risk_2d.max())], 
         [0, max(mu_dt.max(), scaled_risk_2d.max())], 
         'k--', label='x=y')
ax2.set_xlabel('Smoothed Prevalence (μ_dt)')
ax2.set_ylabel('Scaled Predicted Risk')
ax2.set_title(f'Simple Scaling (factor={scale_factor:.2f}) vs Smoothed Prevalence')
ax2.set_xscale('log')
ax2.set_yscale('log')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Get μ_dt from checkpoint and predictions
# ----> 3 mu_dt = essentials['prevalence_t'] # Shape: (348, 52)
#       4 scale_factor = np.mean(mu_dt) / np.mean(predicted_risk_2d)
#       5 scaled_risk_2d = predicted_risk_2d * scale_factor
#
# NameError: name 'essentials' is not defined
