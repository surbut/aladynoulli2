# %% [markdown]
# # Pathway Discovery and Analysis
# This notebook demonstrates the complete pathway analysis pipeline using the full 400K dataset

# %%
# Import the analysis functions
import sys
sys.path.append('/Users/sarahurbut/aladynoulli2/pyScripts/new_oct_revision')

from run_pathway_analysis import run_complete_pathway_analysis, run_multiple_diseases

# %% [markdown]
# ## Test with Myocardial Infarction

# %%
# Run complete analysis for myocardial infarction
results_mi = run_complete_pathway_analysis("myocardial infarction", n_pathways=4)
