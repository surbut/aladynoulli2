# %%
# PATHWAY DISCOVERY: How do patients arrive at the same disease?
# This analysis discovers the different pathways patients take to reach the same disease outcome

import torch
#not this is not the same as the other notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
from run_pathway_analysis import run_complete_pathway_analysis

# %%
results = run_complete_pathway_analysis("myocardial infarction", n_pathways=4)
# Out:
# ...
# COMPLETE PATHWAY ANALYSIS: MYOCARDIAL INFARCTION
# ...
#
# 1. LOADING FULL DATASET
# Loading full dataset...
# Loaded Y (full): torch.Size([407878, 348, 52])
# Loaded thetas: (400000, 21, 52)
# Loaded 400000 processed IDs
# Subset Y to first 400K patients: torch.Size([400000, 348, 52])
# Loaded 348 diseases
# Total patients with complete data: 400000
#
# 2. DISCOVERING PATHWAYS TO MYOCARDIAL INFARCTION
# === COMPARING CLUSTERING METHODS FOR MYOCARDIAL INFARCTION ===
#
# 1. Clustering by Average Signature Loading:
# === DISCOVERING PATHWAYS TO MYOCARDIAL INFARCTION ===
# Method: average_loading
# Found target disease: Myocardial infarction (index 112)
# Found 24920 patients who developed myocardial infarction
#
# Creating trajectory features for pathway discovery...
# Method: average_loading
# Created 21 features per patient (average loading 5 years PRE-disease)
# Kept 24903 patients with sufficient pre-disease history
#
# Discovered 4 pathways to myocardial infarction:
# ...

# %%
# Access deviation-based results (most interesting!):
pathway_data_dev = results['pathway_data_dev']
results_dev = results['results_dev']
medication_results_dev = results['medication_results_dev']
prs_results_dev = results['prs_results_dev']
granular_results_dev = results['granular_results_dev']

# %%
from run_pathway_analysis import run_complete_pathway_analysis
results = run_complete_pathway_analysis("myocardial infarction", n_pathways=4)

# %%
gp_scripts_path = '/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/gp_scripts.txt'
gp_scripts = pd.read_csv(gp_scripts_path, sep='\t')

# %%
# In your notebook or terminal:
from run_transition_analysis import main
main()
# Out:
# Loading data...
# Loading full dataset...
# Loaded Y (full): torch.Size([407878, 348, 52])
# Loaded thetas: (400000, 21, 52)
# Loaded 400000 processed IDs
# Subset Y to first 400K patients: torch.Size([400000, 348, 52])
# Loaded 348 diseases
# Total patients with complete data: 400000
# Analyzing transitions to Myocardial Infarction...
# Looking for patients who had these diseases before MI:
#   - rheumatoid arthritis
#   - diabetes
#   - hypertension
#   - hypercholesterolemia
#   - obesity
#   - Major depressive disorder
#   - Malignant neoplasm of breast
#   - Maligant neoplasm of prostate
#   - Maligant neoplasm of bladder
#   - Maligant neoplasm of colon
#   - Maligant neoplasm of lung
#   - Maligant neoplasm of esophagus
#   - Maligant neoplasm of rectum
#   - anxiety disorder
# ...
# TRANSITION SIGNATURE ANALYSIS: MYOCARDIAL INFARCTION
# ...
# === FINDING DISEASE TRANSITIONS TO MYOCARDIAL INFARCTION ===
# Target disease: Myocardial infarction (index 112)
# ...
