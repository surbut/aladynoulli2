# %% [markdown]
# # Disease Sequence Analysis
#
# This notebook demonstrates how to analyze disease sequences before target disease onset using granular ICD-10 data.
#
# ## What This Analysis Does:
#
# 1. **Identifies common disease sequences** before target disease (e.g., MI)
# 2. **Links sequences to signature patterns** - which signatures were elevated?
# 3. **Shows heterogeneity** - different paths to the same disease
# 4. **Integrates with medications and PRS** - complete pathway characterization
#
# ## Clinical Value:
#
# - **Precision prevention**: Identify high-risk pathways early
# - **Mechanistic understanding**: How do patients "morph" into different disease states?
# - **Treatment stratification**: Different pathways may need different interventions

# %%
import sys
sys.path.append('/Users/sarahurbut/aladynoulli2/pyScripts/new_oct_revision')

from run_pathway_analysis import run_complete_pathway_analysis

# This will run the complete analysis including:
# 1. Pathway discovery (clustering)
# 2. Disease pattern analysis
# 3. Medication integration
# 4. PRS analysis
# 5. Granular disease analysis
# 6. Disease sequence analysis (if ICD-10 data available)

results = run_complete_pathway_analysis("myocardial infarction", n_pathways=4)
# Out:
# ...
# COMPLETE PATHWAY ANALYSIS: MYOCARDIAL INFARCTION
# ...
#
# 1. LOADING FULL DATASET
# Loading full dataset...
# Loaded Y (full): torch.Size([407878, 348, 52])
# Loaded thetas: (400000, 21, 52)
# Loaded 400000 processed IDs
# Subset Y to first 400K patients: torch.Size([400000, 348, 52])
# Loaded 348 diseases
# Total patients with complete data: 400000
#
# 2. DISCOVERING PATHWAYS TO MYOCARDIAL INFARCTION
# === COMPARING CLUSTERING METHODS FOR MYOCARDIAL INFARCTION ===
#
# 1. Clustering by Average Signature Loading:
# === DISCOVERING PATHWAYS TO MYOCARDIAL INFARCTION ===
# Method: average_loading
# Found target disease: Myocardial infarction (index 112)
# Found 24920 patients who developed myocardial infarction
#
# Creating trajectory features for pathway discovery...
# Method: average_loading
# Created 21 features per patient (average loading 5 years PRE-disease)
# Kept 24903 patients with sufficient pre-disease history
#
# Discovered 4 pathways to myocardial infarction:
# ...
