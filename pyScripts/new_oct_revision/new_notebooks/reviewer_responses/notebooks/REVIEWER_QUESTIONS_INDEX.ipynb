# %% [markdown]
# # Reviewer Questions - Interactive Analysis Index
#
# This notebook provides links to interactive analyses addressing each reviewer question.
#
# ## How to Use
#
# 1. Click on any question below to navigate to its dedicated analysis notebook
# 2. Each notebook is self-contained and can be run independently
# 3. All notebooks use the same data paths and setup
#
# ---

# %% [markdown]
# ## Referee #1: Human Genetics, Disease Risk
#
# | Question | Notebook | Status |
# |----------|----------|--------|
# | **Q1**: Selection bias / socioeconomic bias | [`R1_Q1_Selection_Bias.ipynb`](R1_Q1_Selection_Bias.ipynb) | ✅ Complete |
# | **Q2**: Lifetime risk comparisons | [`R1_Q2_Lifetime_Risk.ipynb`](R1_Q2_Lifetime_Risk.ipynb) | 🔄 In Progress |
# | **Q3**: Clinical/biological meaningfulness | [`R1_Q3_Clinical_Meaning.ipynb`](R1_Q3_Clinical_Meaning.ipynb) | ✅ Complete |
# | **Q7**: Heritability estimates | [`R1_Q7_Heritability.ipynb`](R1_Q7_Heritability.ipynb) | ✅ Complete |
# | **Q9**: AUC vs clinical risk scores | [`R1_Q9_AUC_Comparisons.ipynb`](R1_Q9_AUC_Comparisons.ipynb) | ✅ Complete |
# | **Q10**: Age-specific discrimination | [`R1_Q10_Age_Specific.ipynb`](R1_Q10_Age_Specific.ipynb) | 🔄 In Progress |

# %% [markdown]
# ## Referee #2: EHRs
#
# | Concern | Notebook | Status |
# |---------|----------|--------|
# | Temporal accuracy / leakage | [`R2_Temporal_Leakage.ipynb`](R2_Temporal_Leakage.ipynb) | ✅ Complete |
# | Interpretability | [`R2_Interpretability.ipynb`](R2_Interpretability.ipynb) | ✅ Complete |
# to do some rerunnign e

# %% [markdown]
# ## Referee #3: Statistical Genetics, PRS
#
# | Question | Notebook | Status |
# |----------|----------|--------|
# | **Q1**: Selection/participation bias | [`R3_Q1_Participation_Bias.ipynb`](R3_Q1_Participation_Bias.ipynb) | ✅ Complete (same as R1 Q1) |
# | **Q3**: Washout windows | [`R3_Q3_Washout_Windows.ipynb`](R3_Q3_Washout_Windows.ipynb) | ✅ Complete (same as R2) |
# | **Q4**: Competing risks | [`R3_Q4_Competing_Risks.ipynb`](R3_Q4_Competing_Risks.ipynb) | ⚠️ Pending |
# | **Q8**: Heterogeneity definition | [`R3_Q8_Heterogeneity.ipynb`](R3_Q8_Heterogeneity.ipynb) | ✅ Complete |
# | **Q12**: Heritability methods | [`R3_Q12_Heritability_Methods.ipynb`](R3_Q12_Heritability_Methods.ipynb) | ✅ Complete (same as R1 Q7) |

# %% [markdown]
# ---
#
# ## Quick Navigation
#
# ### ✅ Completed Analyses
# - Selection bias (IPW): `R1_Q1_Selection_Bias.ipynb`
# - Clinical meaning (FH): `R1_Q3_Clinical_Meaning.ipynb`
# - Heritability: `R1_Q7_Heritability.ipynb`
# - AUC comparisons: `R1_Q9_AUC_Comparisons.ipynb`
# - Temporal leakage: `R2_Temporal_Leakage.ipynb`
# - Interpretability: `R2_Interpretability.ipynb`
# - Heterogeneity: `R3_Q8_Heterogeneity.ipynb`
#
# ### 🔄 In Progress
# - Lifetime risk: `R1_Q2_Lifetime_Risk.ipynb`
# - Age-specific: `R1_Q10_Age_Specific.ipynb`
#
# ### ⚠️ Pending
# - Competing risks: `R3_Q4_Competing_Risks.ipynb`
