# %% [markdown]
# ## interesting, seems better using joint phi that has

# %%
import glob
import os
from re import X
import torch
import numpy as np
import pandas as pd
from fig5utils import evaluate_major_diseases_wsex_with_bootstrap
from clust_huge_amp import *
# --- Fixed resources ---------------------------------------------------------
initial_psi = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt")
initial_clusters = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt")
signature_refs = torch.load(
    "/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/data_for_running/reference_trajectories.pt"
)["signature_refs"]

# master tensors; adjust paths if they live elsewhere
E_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_enrollment_full.pt")
pce_df = pd.read_csv("/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/pce_prevent_full.csv")
disease_names=pd.read_csv("/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/disease_names.csv")
# helper to build model & evaluate one batch
def eval_batch(ckpt_path):
    ckpt = torch.load(ckpt_path, map_location="cpu")
    start = ckpt["indices"][0]
    stop = ckpt["indices"][-1]+1  # indices saved in each checkpoint

    # slice tensors for this batch
    Y_batch = ckpt["Y"]
    E_batch = E_full[start:stop]
    cov_batch = pce_df.iloc[start:stop].reset_index(drop=True)
    if "Sex" not in cov_batch.columns and "sex" in cov_batch.columns:
        cov_batch = cov_batch.rename(columns={"sex": "Sex"})
    cov_batch = cov_batch.assign(Sex=cov_batch["Sex"], age=cov_batch["age"])  # keep original naming, but ensure present

    # append sex column to G slice (if training did)
    sex = cov_batch["Sex"].to_numpy()
    G_batch = ckpt["G"]

    model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
        N=Y_batch.shape[0],
        D=Y_batch.shape[1],
        T=Y_batch.shape[2],
        K=20,
        P=G_batch.shape[1],
        init_sd_scaler=1e-1,
        G=G_batch,
        Y=Y_batch.numpy(),
        genetic_scale=1,
        W=0.0001,
        R=0,
        prevalence_t=ckpt["prevalence_t"],
        signature_references=signature_refs,
        healthy_reference=True,
        disease_names=disease_names['x'],
    )
    model.initialize_params(true_psi=initial_psi)
    model.clusters = ckpt["clusters"]
    model.load_state_dict(ckpt["model_state_dict"])
    model.eval()

    results = evaluate_major_diseases_wsex_with_bootstrap(
        model=model,
        Y_100k=Y_batch,
        E_100k=E_batch,
        disease_names=disease_names['x'],
        pce_df=cov_batch,
        n_bootstraps=20,
        follow_up_duration_years=10,
    )
    return (start, stop), results

# --- loop through all checkpoints --------------------------------------------
ckpt_dir = "/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs"
ckpt_paths = sorted(glob.glob(os.path.join(ckpt_dir, "enrollment_model_W0.0001_batch_*_*.pt")))

batch_results = {}
for ckpt_path in ckpt_paths:
    (start, stop), res = eval_batch(ckpt_path)
    batch_results[(start, stop)] = res
    print(f"Finished {start}-{stop}")
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_92930/1864787717.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_92930/1864787717.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_92930/1864787717.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   signature_refs = torch.load(
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_92930/1864787717.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_enrollment_full.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_92930/1864787717.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0026,  0.0050,  0.0103,  0.0132, -0.0116])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0011, -0.0023,  0.0073,  0.0020, -0.0051])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0014, -0.0038,  0.0025,  0.0024, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0088, -0.0010, -0.0120,  0.0372, -0.0093])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0051,  0.0055, -0.0040,  0.0058,  0.0238])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0018,  0.0010, -0.0011, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0075,  0.0045, -0.0065,  0.0055, -0.0043])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0032, -0.0005,  0.0003,  0.0114, -0.0019])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([-0.0003,  0.0084,  0.0164, -0.0027,  0.0004])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0123, -0.0048,  0.0016, -0.0047,  0.0018])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0068,  0.0008, -0.0014,  0.0007,  0.0027])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 0.0086,  0.0104, -0.0006,  0.0071, -0.0017])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([-0.0015,  0.0126,  0.0149, -0.0003,  0.0101])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0162, -0.0025,  0.0116,  0.0191, -0.0034])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0008, -0.0014,  0.0007,  0.0034,  0.0015])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.9623, -13.8155])
# Base value centered (first 5): tensor([-0.1879, -0.1879, -0.1879,  1.6653, -0.1879])
# Base value centered mean: -3.345489574257954e-07
# Gamma init for k=0 (first 5): tensor([ 0.0074,  0.0061, -0.0054,  0.0060,  0.0235])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.3449, -13.3449, -12.4036])
# Base value centered (first 5): tensor([ 0.1505, -0.3201,  0.1505,  0.1505,  1.0918])
# Base value centered mean: -1.8495559288567165e-06
# Gamma init for k=1 (first 5): tensor([0.0042, 0.0009, 0.0009, 0.0018, 0.0015])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1566, -11.8388, -12.4977])
# Base value centered (first 5): tensor([-0.3849, -0.3849,  0.2740,  1.5918,  0.9329])
# Base value centered mean: 9.290695288655115e-07
# Gamma init for k=2 (first 5): tensor([ 0.0016,  0.0073,  0.0100,  0.0140, -0.0118])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.6950, -13.5744])
# Base value centered (first 5): tensor([-0.1026, -0.1026, -0.1026,  0.0179,  0.1384])
# Base value centered mean: 4.7445297468584613e-07
# Gamma init for k=3 (first 5): tensor([ 0.0012,  0.0003,  0.0016,  0.0018, -0.0006])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155,  -9.8620, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1133,  3.8402, -0.1133, -0.1133, -0.1133])
# Base value centered mean: -2.841758714566822e-06
# Gamma init for k=4 (first 5): tensor([-0.0172, -0.0033,  0.0143,  0.0225, -0.0033])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=5 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1523, -0.1523, -0.1523, -0.1523, -0.1523])
# Base value centered mean: -1.0890006478803116e-06
# Gamma init for k=6 (first 5): tensor([ 0.0090,  0.0121, -0.0006,  0.0042, -0.0027])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.3663, -13.8155, -13.3663, -13.8155, -11.1200])
# Base value centered (first 5): tensor([-0.1005, -0.5497, -0.1005, -0.5497,  2.1458])
# Base value centered mean: 1.2460708376238472e-06
# Gamma init for k=7 (first 5): tensor([ 0.0003, -0.0038, -0.0111,  0.0251, -0.0016])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1159, -0.1159, -0.1159, -0.1159, -0.1159])
# Base value centered mean: -1.4129639112070436e-06
# Gamma init for k=8 (first 5): tensor([ 0.0066, -0.0055,  0.0011, -0.0020, -0.0005])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=9 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=10 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=11 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0860, -0.0860, -0.0860, -0.0860, -0.0860])
# Base value centered mean: -1.034450519910024e-06
# Gamma init for k=12 (first 5): tensor([ 0.0080, -0.0074,  0.0002, -0.0001, -0.0076])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.7744, -12.2949])
# Base value centered (first 5): tensor([-0.1777, -0.1777, -0.1777,  2.8635,  1.3429])
# Base value centered mean: -1.0064125035569305e-06
# Gamma init for k=13 (first 5): tensor([-0.0002,  0.0060,  0.0127, -0.0051,  0.0007])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.8388, -12.8271])
# Base value centered (first 5): tensor([-0.2562, -0.2562, -0.2562,  1.7205,  0.7322])
# Base value centered mean: -1.5125274330785032e-06
# Gamma init for k=14 (first 5): tensor([ 0.0038, -0.0052, -0.0089,  0.0162,  0.0005])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.8388])
# Base value centered (first 5): tensor([-0.2850, -0.2850, -0.2850, -0.2850,  1.6917])
# Base value centered mean: -1.2931823221151717e-06
# Gamma init for k=15 (first 5): tensor([-0.0039,  0.0064,  0.0118, -0.0049,  0.0086])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.7706, -13.1339])
# Base value centered (first 5): tensor([-0.2428, -0.2428, -0.2428,  1.8021,  0.4388])
# Base value centered mean: -1.9989013253507437e-06
# Gamma init for k=16 (first 5): tensor([ 0.0009,  0.0001,  0.0093,  0.0055, -0.0031])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.3272, -12.0713])
# Base value centered (first 5): tensor([-0.4228, -0.4228, -0.4228,  3.0656,  1.3214])
# Base value centered mean: -2.227592403869494e-06
# Gamma init for k=17 (first 5): tensor([ 0.0081,  0.0052, -0.0070,  0.0058, -0.0042])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=18 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([-0.1519, -0.1519, -0.1519, -0.1519,  0.2779])
# Base value centered mean: -1.1179923831150518e-06
# Gamma init for k=19 (first 5): tensor([-0.0027,  0.0053,  0.0013, -0.0016, -0.0018])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.712 (0.700-0.730) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.666, Events = 273/5409
#    Male: AUC = 0.702, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.677, Events = 8/37
#    Breast_Cancer: AUC = 0.631, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.628 (0.618-0.641) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.618, Events = 264/5409
#    Male: AUC = 0.628, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.684 (0.662-0.713) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.697, Events = 197/5372
#    Male: AUC = 0.683, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.708 (0.693-0.735) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.732, Events = 101/5409
#    Male: AUC = 0.684, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.680 (0.662-0.701) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.672, Events = 134/5409
#    Male: AUC = 0.669, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.654 (0.604-0.689) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.624, Events = 64/5409
#    Male: AUC = 0.683, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.698 (0.677-0.733) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.717, Events = 83/5409
#    Male: AUC = 0.678, Events = 122/4591
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.683 (0.662-0.714) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.684, Events = 135/5409
#    Male: AUC = 0.676, Events = 200/4591
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.646 (0.632-0.659) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.672, Events = 176/5409
#    Male: AUC = 0.620, Events = 218/4591
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.676 (0.658-0.709) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.681, Events = 128/5379
#    Male: AUC = 0.677, Events = 90/4582
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.593 (0.574-0.615) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.549, Events = 280/5409
#    Male: AUC = 0.643, Events = 243/4591
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.654 (0.613-0.682) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.625, Events = 56/5409
#    Male: AUC = 0.688, Events = 49/4591
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.575 (0.557-0.604) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.672 (0.659-0.693) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.4%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.691 (0.651-0.745) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.696, Events = 48/5406
#    Male: AUC = 0.680, Events = 27/4586
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.740 (0.685-0.800) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.628, Events = 24/5399
#    Male: AUC = 0.847, Events = 25/4577
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.607 (0.566-0.632) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.613, Events = 147/5409
#    Male: AUC = 0.600, Events = 129/4591
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.470 (0.457-0.494) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.0%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.474, Events = 210/5351
#    Male: AUC = 0.476, Events = 191/4561
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.506 (0.473-0.525) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.512, Events = 130/5391
#    Male: AUC = 0.504, Events = 110/4584
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.373 (0.301-0.434) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.392, Events = 14/5399
#    Male: AUC = 0.359, Events = 19/4585
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.598 (0.549-0.651) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.597, Events = 62/5381
#    Male: AUC = 0.595, Events = 60/4582
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.432 (0.342-0.479) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.416, Events = 15/5405
#    Male: AUC = 0.443, Events = 25/4576
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.587 (0.482-0.644) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.599, Events = 31/5378
#    Male: AUC = 0.573, Events = 19/4569
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.503 (0.358-0.568) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.548, Events = 20/5388
#    Male: AUC = 0.423, Events = 11/4579
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.511 (0.474-0.535) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.1%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.505, Events = 321/5214
#    Male: AUC = 0.555, Events = 264/4473
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.741 (0.691-0.765) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.787, Events = 21/5407
#    Male: AUC = 0.700, Events = 25/4590
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.524 (0.391-0.592) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.533, Events = 13/5394
#    Male: AUC = 0.515, Events = 8/4585
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.579 (0.564-0.601) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.573, Events = 385/5409
#    Male: AUC = 0.573, Events = 94/4591
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.712 (0.700-0.730)       831        8.3
# Diabetes             0.628 (0.618-0.641)       581        5.8
# Atrial_Fib           0.684 (0.662-0.713)       376        3.8
# CKD                  0.708 (0.693-0.735)       207        2.1
# All_Cancers          0.680 (0.662-0.701)       480        4.8
# Stroke               0.654 (0.604-0.689)       129        1.3
# Heart_Failure        0.698 (0.677-0.733)       205        2.1
# Pneumonia            0.683 (0.662-0.714)       335        3.4
# COPD                 0.646 (0.632-0.659)       394        3.9
# Osteoporosis         0.676 (0.658-0.709)       219        2.2
# Anemia               0.593 (0.574-0.615)       523        5.2
# Colorectal_Cancer    0.654 (0.613-0.682)       105        1.1
# Breast_Cancer        0.575 (0.557-0.604)       214        4.0
# Prostate_Cancer      0.672 (0.659-0.693)       204        4.4
# Lung_Cancer          0.691 (0.651-0.745)       75         0.8
# Bladder_Cancer       0.740 (0.685-0.800)       49         0.5
# Secondary_Cancer     0.607 (0.566-0.632)       276        2.8
# Depression           0.470 (0.457-0.494)       405        4.0
# Anxiety              0.506 (0.473-0.525)       241        2.4
# Bipolar_Disorder     0.373 (0.301-0.434)       34         0.3
# Rheumatoid_Arthritis 0.598 (0.549-0.651)       123        1.2
# Psoriasis            0.432 (0.342-0.479)       40         0.4
# Ulcerative_Colitis   0.587 (0.482-0.644)       50         0.5
# Crohns_Disease       0.503 (0.358-0.568)       31         0.3
# Asthma               0.511 (0.474-0.535)       606        6.1
# Parkinsons           0.741 (0.691-0.765)       46         0.5
# Multiple_Sclerosis   0.524 (0.391-0.592)       21         0.2
# Thyroid_Disorders    0.579 (0.564-0.601)       479        4.8
# --------------------------------------------------------------------------------
# Finished 0-10000
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_92930/1864787717.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 42 diseases
# Cluster 1: 24 diseases
# Cluster 2: 8 diseases
# Cluster 3: 5 diseases
# Cluster 4: 8 diseases
# Cluster 5: 13 diseases
# Cluster 6: 60 diseases
# Cluster 7: 30 diseases
# Cluster 8: 7 diseases
# Cluster 9: 19 diseases
# Cluster 10: 10 diseases
# Cluster 11: 15 diseases
# Cluster 12: 16 diseases
# Cluster 13: 11 diseases
# Cluster 14: 7 diseases
# Cluster 15: 7 diseases
# Cluster 16: 12 diseases
# Cluster 17: 16 diseases
# Cluster 18: 22 diseases
# Cluster 19: 16 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 42
# Base value (first 5): tensor([-13.5802, -13.8155, -13.8155, -13.8155, -13.5802])
# Base value centered (first 5): tensor([ 0.1123, -0.1230, -0.1230, -0.1230,  0.1123])
# Base value centered mean: -4.872322278970387e-07
# Gamma init for k=0 (first 5): tensor([ 3.5662e-04,  2.1659e-03, -1.1390e-05, -5.6056e-03,  4.5262e-03])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 24
# Base value (first 5): tensor([-13.8155, -13.4037, -13.8155, -12.9919, -13.8155])
# Base value centered (first 5): tensor([-0.2507,  0.1611, -0.2507,  0.5729, -0.2507])
# Base value centered mean: -3.0660628453915706e-06
# Gamma init for k=1 (first 5): tensor([-0.0004,  0.0093,  0.0011,  0.0004,  0.0019])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1150, -0.1150, -0.1150, -0.1150, -0.1150])
# Base value centered mean: -2.318954557267716e-06
# Gamma init for k=2 (first 5): tensor([ 0.0038,  0.0085,  0.0110, -0.0038,  0.0126])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 5
# Base value (first 5): tensor([-13.8155, -11.8388, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2868,  1.6899, -0.2868, -0.2868, -0.2868])
# Base value centered mean: -1.7898559008244774e-06
# Gamma init for k=3 (first 5): tensor([-0.0036, -0.0012, -0.0132, -0.0140, -0.0126])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1599, -0.1599, -0.1599, -0.1599, -0.1599])
# Base value centered mean: -1.6735076542317984e-06
# Gamma init for k=4 (first 5): tensor([ 0.0080,  0.0083,  0.0044,  0.0091, -0.0020])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1988, -0.1988, -0.1988, -0.1988, -0.1988])
# Base value centered mean: 5.046844648859405e-07
# Gamma init for k=5 (first 5): tensor([ 0.0004,  0.0035, -0.0051,  0.0044, -0.0024])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 60
# Base value (first 5): tensor([-13.6508, -13.6508, -13.6508, -13.6508, -13.8155])
# Base value centered (first 5): tensor([ 0.0040,  0.0040,  0.0040,  0.0040, -0.1608])
# Base value centered mean: -3.2844542374732555e-07
# Gamma init for k=6 (first 5): tensor([8.4989e-04, 2.9909e-05, 1.6180e-03, 7.6457e-03, 1.1674e-03])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 30
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1529, -0.1529, -0.1529, -0.1529, -0.1529])
# Base value centered mean: -1.6108513136714464e-06
# Gamma init for k=7 (first 5): tensor([ 0.0031,  0.0019, -0.0044,  0.0009,  0.0058])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -10.9916, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7101, -0.7101,  2.1138, -0.7101, -0.7101])
# Base value centered mean: -9.76181013356836e-07
# Gamma init for k=8 (first 5): tensor([-0.0026, -0.0134, -0.0256,  0.0107,  0.0261])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 19
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.2549])
# Base value centered (first 5): tensor([-0.1634, -0.1634, -0.1634, -0.1634,  1.3971])
# Base value centered mean: -1.4804840020588017e-06
# Gamma init for k=9 (first 5): tensor([-0.0019,  0.0037, -0.0023, -0.0002,  0.0255])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 10
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.8271, -13.8155])
# Base value centered (first 5): tensor([-0.1655, -0.1655, -0.1655,  0.8229, -0.1655])
# Base value centered mean: -1.396179243329243e-07
# Gamma init for k=10 (first 5): tensor([ 0.0023,  0.0027, -0.0070,  0.0057, -0.0029])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -11.8388, -11.1799, -13.8155])
# Base value centered (first 5): tensor([-0.3435, -0.3435,  1.6332,  2.2922, -0.3435])
# Base value centered mean: -8.144378398355911e-07
# Gamma init for k=11 (first 5): tensor([ 0.0070, -0.0061,  0.0014,  0.0077,  0.0029])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.1978, -13.1978])
# Base value centered (first 5): tensor([-0.2723, -0.2723, -0.2723,  0.3454,  0.3454])
# Base value centered mean: 2.2010803490957187e-07
# Gamma init for k=12 (first 5): tensor([-0.0067,  0.0030, -0.0134,  0.0127,  0.0048])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -12.9170, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2809, -0.2809,  0.6176, -0.2809, -0.2809])
# Base value centered mean: -1.080703782463388e-06
# Gamma init for k=13 (first 5): tensor([-0.0083,  0.0191, -0.0084,  0.0010, -0.0163])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0915, -0.0915, -0.0915, -0.0915, -0.0915])
# Base value centered mean: -9.2916491212236e-07
# Gamma init for k=14 (first 5): tensor([-0.0061,  0.0039,  0.0040,  0.0053,  0.0041])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0897, -0.0897, -0.0897, -0.0897, -0.0897])
# Base value centered mean: -6.519794624182396e-07
# Gamma init for k=15 (first 5): tensor([-0.0030,  0.0009,  0.0076,  0.0145,  0.0051])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1759, -0.1759, -0.1759, -0.1759, -0.1759])
# Base value centered mean: -6.105423153712763e-07
# Gamma init for k=16 (first 5): tensor([-0.0001,  0.0030,  0.0027,  0.0054,  0.0068])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.1978, -13.1978, -12.5800, -11.3446, -13.8155])
# Base value centered (first 5): tensor([ 0.1701,  0.1701,  0.7879,  2.0233, -0.4476])
# Base value centered mean: -1.1844634855151526e-06
# Gamma init for k=17 (first 5): tensor([-0.0038,  0.0090, -0.0029, -0.0063,  0.0135])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 22
# Base value (first 5): tensor([-13.3663, -13.3663, -13.3663, -12.9170, -13.3663])
# Base value centered (first 5): tensor([-0.1135, -0.1135, -0.1135,  0.3358, -0.1135])
# Base value centered mean: 6.504058660539158e-07
# Gamma init for k=18 (first 5): tensor([-0.0046,  0.0096, -0.0099,  0.0200,  0.0012])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.1978, -13.8155])
# Base value centered (first 5): tensor([-0.1494, -0.1494, -0.1494,  0.4684, -0.1494])
# Base value centered mean: -2.2361755327438004e-06
# Gamma init for k=19 (first 5): tensor([ 0.0138, -0.0006,  0.0039,  0.0002,  0.0027])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.9623])
# Base value centered (first 5): tensor([-0.1871, -0.1871, -0.1871, -0.1871,  1.6661])
# Base value centered mean: -6.058692747501482e-07
# Gamma init for k=0 (first 5): tensor([-0.0019,  0.0010, -0.0044, -0.0018,  0.0304])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 0.1585, -0.3122, -0.3122, -0.3122, -0.3122])
# Base value centered mean: 6.502151563836378e-07
# Gamma init for k=1 (first 5): tensor([-0.0020,  0.0073, -0.0074,  0.0131,  0.0025])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -11.8388, -10.5209, -13.8155])
# Base value centered (first 5): tensor([-0.3785, -0.3785,  1.5982,  2.9160, -0.3785])
# Base value centered mean: 5.493163968139925e-08
# Gamma init for k=2 (first 5): tensor([ 0.0079, -0.0051,  0.0011,  0.0071,  0.0031])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.5744, -13.6950, -13.8155, -13.5744, -13.8155])
# Base value centered (first 5): tensor([ 0.1365,  0.0159, -0.1046,  0.1365, -0.1046])
# Base value centered mean: -3.633499261468387e-07
# Gamma init for k=3 (first 5): tensor([ 0.0002,  0.0004,  0.0004, -0.0005,  0.0017])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1101, -0.1101, -0.1101, -0.1101, -0.1101])
# Base value centered mean: -3.237629016439314e-06
# Gamma init for k=4 (first 5): tensor([-0.0028, -0.0021,  0.0082,  0.0178,  0.0076])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -10.9916, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7101, -0.7101,  2.1138, -0.7101, -0.7101])
# Base value centered mean: -9.76181013356836e-07
# Gamma init for k=5 (first 5): tensor([-0.0026, -0.0134, -0.0256,  0.0107,  0.0261])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1599, -0.1599, -0.1599, -0.1599, -0.1599])
# Base value centered mean: -1.6735076542317984e-06
# Gamma init for k=6 (first 5): tensor([ 0.0080,  0.0083,  0.0044,  0.0091, -0.0020])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.8155, -12.9170, -12.9170, -12.0185, -13.3663])
# Base value centered (first 5): tensor([-0.5616,  0.3369,  0.3369,  1.2355, -0.1123])
# Base value centered mean: -1.0938643981717178e-06
# Gamma init for k=7 (first 5): tensor([-0.0061,  0.0077, -0.0027,  0.0276,  0.0085])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.4625, -13.8155])
# Base value centered (first 5): tensor([-0.1220, -0.1220, -0.1220,  0.2310, -0.1220])
# Base value centered mean: -1.5850066859002254e-07
# Gamma init for k=8 (first 5): tensor([ 0.0099, -0.0020,  0.0040, -0.0001,  0.0027])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1977, -0.1977, -0.1977, -0.1977, -0.1977])
# Base value centered mean: 6.660461622232106e-07
# Gamma init for k=9 (first 5): tensor([ 0.0021,  0.0036, -0.0056,  0.0024, -0.0043])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -12.9170, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2809, -0.2809,  0.6176, -0.2809, -0.2809])
# Base value centered mean: -1.080703782463388e-06
# Gamma init for k=10 (first 5): tensor([-0.0083,  0.0191, -0.0084,  0.0010, -0.0163])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1150, -0.1150, -0.1150, -0.1150, -0.1150])
# Base value centered mean: -2.318954557267716e-06
# Gamma init for k=11 (first 5): tensor([ 0.0038,  0.0085,  0.0110, -0.0038,  0.0126])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# ...
# Base value centered mean: 1.753807055138168e-07
# Gamma init for k=8 (first 5): tensor([ 0.0060, -0.0011, -0.0011, -0.0009,  0.0014])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.2068, -0.2068, -0.2068, -0.2068,  0.6168])
# Base value centered mean: -7.566451927232265e-07
# Gamma init for k=9 (first 5): tensor([-0.0004, -0.0078, -0.0034,  0.0076,  0.0033])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2663, -0.2663, -0.2663, -0.2663, -0.2663])
# Base value centered mean: -1.115417489927495e-06
# Gamma init for k=10 (first 5): tensor([-0.0041,  0.0153,  0.0086,  0.0102, -0.0016])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1109, -0.1109, -0.1109, -0.1109, -0.1109])
# Base value centered mean: -1.4264106766859186e-06
# Gamma init for k=11 (first 5): tensor([-0.0016, -0.0023, -0.0018, -0.0025,  0.0148])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -12.4036, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0998, -0.0998,  1.3121, -0.0998, -0.0998])
# Base value centered mean: -1.7006874486469314e-06
# Gamma init for k=12 (first 5): tensor([ 0.0005, -0.0005, -0.0056, -0.0004,  0.0101])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -11.5347, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1716, -0.1716,  2.1093, -0.1716, -0.1716])
# Base value centered mean: 2.187728824765145e-07
# Gamma init for k=13 (first 5): tensor([ 0.0055,  0.0017,  0.0070, -0.0034, -0.0028])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-12.8271, -13.8155, -12.8271, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 0.7084, -0.2800,  0.7084, -0.2800, -0.2800])
# Base value centered mean: 1.4724732011472952e-07
# Gamma init for k=14 (first 5): tensor([-0.0063,  0.0009, -0.0137,  0.0181,  0.0098])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([ -7.8853, -11.8388, -11.8388, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 5.6386,  1.6852,  1.6852, -0.2916, -0.2916])
# Base value centered mean: -1.1932372672163183e-06
# Gamma init for k=15 (first 5): tensor([-0.0180, -0.0068,  0.0047,  0.0275, -0.0032])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1339, -13.4747, -13.8155])
# Base value centered (first 5): tensor([-0.2561, -0.2561,  0.4255,  0.0847, -0.2561])
# Base value centered mean: -5.432128773463774e-07
# Gamma init for k=16 (first 5): tensor([-0.0109, -0.0037,  0.0114,  0.0130,  0.0150])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.2341])
# Base value centered (first 5): tensor([-0.4213, -0.4213, -0.4213, -0.4213,  0.1601])
# Base value centered mean: -1.363754222438729e-06
# Gamma init for k=17 (first 5): tensor([-0.0078,  0.0099, -0.0066,  0.0085,  0.0133])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1679, -0.1679, -0.1679, -0.1679, -0.1679])
# Base value centered mean: -1.7017364370985888e-06
# Gamma init for k=18 (first 5): tensor([ 0.0027,  0.0135,  0.0061,  0.0057, -0.0064])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-12.9561, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([ 0.7026, -0.1568, -0.1568, -0.1568,  0.2729])
# Base value centered mean: -1.2242317097843625e-06
# Gamma init for k=19 (first 5): tensor([ 0.0023, -0.0011, -0.0026,  0.0028,  0.0067])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.727 (0.707-0.734) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 853 (8.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.703, Events = 318/5560
#    Male: AUC = 0.710, Events = 535/4440
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.759, Events = 8/52
#    Breast_Cancer: AUC = 0.525, Events = 8/155
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.655 (0.633-0.679) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 591 (5.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.654, Events = 233/5560
#    Male: AUC = 0.643, Events = 358/4440
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.682 (0.662-0.702) (calculated on 9885 individuals)
# Events (10-Year in Eval Cohort): 368 (3.7%) (from 10000 individuals)
# Excluded 115 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.690, Events = 207/5519
#    Male: AUC = 0.684, Events = 158/4366
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.724 (0.697-0.763) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 213 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.714, Events = 113/5560
#    Male: AUC = 0.735, Events = 100/4440
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.661 (0.646-0.680) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 491 (4.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.616, Events = 151/5560
#    Male: AUC = 0.665, Events = 340/4440
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.677 (0.650-0.724) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 136 (1.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.679, Events = 58/5560
#    Male: AUC = 0.668, Events = 78/4440
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.693 (0.655-0.723) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 222 (2.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.684, Events = 84/5560
#    Male: AUC = 0.687, Events = 138/4440
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.667 (0.643-0.692) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 390 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.651, Events = 163/5560
#    Male: AUC = 0.669, Events = 227/4440
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.636 (0.610-0.652) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 433 (4.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.649, Events = 185/5560
#    Male: AUC = 0.616, Events = 248/4440
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.667 (0.632-0.685) (calculated on 9968 individuals)
# Events (10-Year in Eval Cohort): 255 (2.5%) (from 10000 individuals)
# Excluded 32 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.658, Events = 139/5531
#    Male: AUC = 0.682, Events = 115/4437
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.576 (0.565-0.589) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 587 (5.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.558, Events = 337/5560
#    Male: AUC = 0.602, Events = 250/4440
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.590 (0.550-0.637) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 111 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.563, Events = 42/5560
#    Male: AUC = 0.596, Events = 69/4440
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5560 individuals in cohort
# AUC: 0.584 (0.562-0.626) (calculated on 5560 individuals)
# Events (10-Year in Eval Cohort): 228 (4.1%) (from 5560 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4440 individuals in cohort
# AUC: 0.691 (0.657-0.715) (calculated on 4402 individuals)
# Events (10-Year in Eval Cohort): 184 (4.1%) (from 4440 individuals)
# Excluded 38 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.612 (0.546-0.662) (calculated on 9996 individuals)
# Events (10-Year in Eval Cohort): 79 (0.8%) (from 10000 individuals)
# Excluded 4 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.597, Events = 43/5557
#    Male: AUC = 0.632, Events = 36/4439
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.764 (0.714-0.817) (calculated on 9973 individuals)
# Events (10-Year in Eval Cohort): 56 (0.6%) (from 10000 individuals)
# Excluded 27 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.748, Events = 31/5555
#    Male: AUC = 0.787, Events = 25/4418
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.601 (0.560-0.624) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 307 (3.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.588, Events = 180/5560
#    Male: AUC = 0.621, Events = 127/4440
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.488 (0.471-0.514) (calculated on 9893 individuals)
# Events (10-Year in Eval Cohort): 425 (4.2%) (from 10000 individuals)
# Excluded 107 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.491, Events = 237/5500
#    Male: AUC = 0.493, Events = 179/4393
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.493 (0.463-0.519) (calculated on 9968 individuals)
# Events (10-Year in Eval Cohort): 271 (2.7%) (from 10000 individuals)
# Excluded 32 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.501, Events = 138/5545
#    Male: AUC = 0.484, Events = 131/4423
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.535 (0.427-0.639) (calculated on 9986 individuals)
# Events (10-Year in Eval Cohort): 24 (0.2%) (from 10000 individuals)
# Excluded 14 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.436, Events = 10/5553
#    Male: AUC = 0.606, Events = 14/4433
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.599 (0.567-0.645) (calculated on 9948 individuals)
# Events (10-Year in Eval Cohort): 121 (1.2%) (from 10000 individuals)
# Excluded 52 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.597, Events = 74/5525
#    Male: AUC = 0.613, Events = 46/4423
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.529 (0.479-0.608) (calculated on 9980 individuals)
# Events (10-Year in Eval Cohort): 44 (0.4%) (from 10000 individuals)
# Excluded 20 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.509, Events = 28/5553
#    Male: AUC = 0.568, Events = 16/4427
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.608 (0.510-0.665) (calculated on 9957 individuals)
# Events (10-Year in Eval Cohort): 52 (0.5%) (from 10000 individuals)
# Excluded 43 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.600, Events = 32/5537
#    Male: AUC = 0.625, Events = 20/4420
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.559 (0.417-0.703) (calculated on 9965 individuals)
# Events (10-Year in Eval Cohort): 29 (0.3%) (from 10000 individuals)
# Excluded 35 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.544, Events = 16/5545
#    Male: AUC = 0.581, Events = 13/4420
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.515 (0.499-0.533) (calculated on 9672 individuals)
# Events (10-Year in Eval Cohort): 624 (6.2%) (from 10000 individuals)
# Excluded 328 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.528, Events = 337/5339
#    Male: AUC = 0.534, Events = 269/4333
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.726 (0.706-0.770) (calculated on 9998 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 2 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.732, Events = 21/5559
#    Male: AUC = 0.719, Events = 28/4439
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.543 (0.427-0.591) (calculated on 9982 individuals)
# Events (10-Year in Eval Cohort): 29 (0.3%) (from 10000 individuals)
# Excluded 18 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.616, Events = 11/5547
#    Male: AUC = 0.498, Events = 18/4435
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.589 (0.562-0.603) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 434 (4.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.582, Events = 344/5560
#    Male: AUC = 0.600, Events = 90/4440
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.727 (0.707-0.734)       853        8.5
# Diabetes             0.655 (0.633-0.679)       591        5.9
# Atrial_Fib           0.682 (0.662-0.702)       368        3.7
# CKD                  0.724 (0.697-0.763)       213        2.1
# All_Cancers          0.661 (0.646-0.680)       491        4.9
# Stroke               0.677 (0.650-0.724)       136        1.4
# Heart_Failure        0.693 (0.655-0.723)       222        2.2
# Pneumonia            0.667 (0.643-0.692)       390        3.9
# COPD                 0.636 (0.610-0.652)       433        4.3
# Osteoporosis         0.667 (0.632-0.685)       255        2.5
# Anemia               0.576 (0.565-0.589)       587        5.9
# Colorectal_Cancer    0.590 (0.550-0.637)       111        1.1
# Breast_Cancer        0.584 (0.562-0.626)       228        4.1
# Prostate_Cancer      0.691 (0.657-0.715)       184        4.1
# Lung_Cancer          0.612 (0.546-0.662)       79         0.8
# Bladder_Cancer       0.764 (0.714-0.817)       56         0.6
# Secondary_Cancer     0.601 (0.560-0.624)       307        3.1
# Depression           0.488 (0.471-0.514)       425        4.2
# Anxiety              0.493 (0.463-0.519)       271        2.7
# Bipolar_Disorder     0.535 (0.427-0.639)       24         0.2
# Rheumatoid_Arthritis 0.599 (0.567-0.645)       121        1.2
# Psoriasis            0.529 (0.479-0.608)       44         0.4
# Ulcerative_Colitis   0.608 (0.510-0.665)       52         0.5
# Crohns_Disease       0.559 (0.417-0.703)       29         0.3
# Asthma               0.515 (0.499-0.533)       624        6.2
# Parkinsons           0.726 (0.706-0.770)       49         0.5
# Multiple_Sclerosis   0.543 (0.427-0.591)       29         0.3
# Thyroid_Disorders    0.589 (0.562-0.603)       434        4.3
# --------------------------------------------------------------------------------
# Finished 90000-100000

# %%
import pickle
from pathlib import Path

out_dir = Path("/Users/sarahurbut/aladynoulli2/claudefile/output")
out_dir.mkdir(parents=True, exist_ok=True)

# Save joint run (e.g., 10‑year evaluation)
with (out_dir / "batch_results_joint_10yr.pkl").open("wb") as f:
    pickle.dump(batch_results, f)
print("Saved:", out_dir / "batch_results_joint_10yr.pkl")
# Out:
# Saved: /Users/sarahurbut/aladynoulli2/claudefile/output/batch_results_joint_10yr.pkl

# %%
# Collect per-disease AUC lists
disease_aucs = {}
for batch_res in batch_results.values():
    for disease, metrics in batch_res.items():
        disease_aucs.setdefault(disease, []).append(metrics["auc"])

# Median AUC and optional IQR
median_auc_df = (
    pd.Series({d: np.nanmedian(vals) for d, vals in disease_aucs.items()}, name="MedianAUC")
      .reset_index()
      .rename(columns={"index": "Disease"})
      .sort_values("MedianAUC", ascending=False)
)
median_auc_df["IQR"] = [
    (np.nanpercentile(disease_aucs[d], 25), np.nanpercentile(disease_aucs[d], 75))
    for d in median_auc_df["Disease"]
]

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=median_auc_df,
    x="MedianAUC",
    y="Disease",
    color="#4c72b0"
)
plt.xlim(0.5, 1.0)
plt.xlabel("Median AUC (across PCS batches)")
plt.ylabel("")
plt.title("Enrollment 10-year predictions (PCS joint runs)")
plt.tight_layout()
plt.show()

# %%
median_auc_df.to_csv("/Users/sarahurbut/aladynoulli2/claudefile/output/median_auc_results_10yearjointphi.csv", index=False)

# %%
median_auc_df
# Out:
#                  Disease  MedianAUC  \
# 25            Parkinsons   0.725859
# 0                  ASCVD   0.720972
# 3                    CKD   0.707039
# 15        Bladder_Cancer   0.699543
# 6          Heart_Failure   0.698028
# 2             Atrial_Fib   0.685074
# 13       Prostate_Cancer   0.684887
# 5                 Stroke   0.680301
# 9           Osteoporosis   0.676395
# 4            All_Cancers   0.670563
# 14           Lung_Cancer   0.665383
# 8                   COPD   0.655750
# 11     Colorectal_Cancer   0.654174
# 7              Pneumonia   0.644121
# 1               Diabetes   0.631094
# 16      Secondary_Cancer   0.609764
# 20  Rheumatoid_Arthritis   0.603083
# 27     Thyroid_Disorders   0.588635
# 10                Anemia   0.585011
# 22    Ulcerative_Colitis   0.584830
# 23        Crohns_Disease   0.583469
# 26    Multiple_Sclerosis   0.553681
# 12         Breast_Cancer   0.549627
# 21             Psoriasis   0.546502
# 24                Asthma   0.527031
# 18               Anxiety   0.512678
# 19      Bipolar_Disorder   0.503134
# 17            Depression   0.485063
#
#                                            IQR
# 25    (0.7051851779360048, 0.7404188779738213)
# 0     (0.7169762522835295, 0.7282278846282333)
# 3     (0.6939694480838121, 0.7196922361307282)
# 15    (0.6871965122392619, 0.7303162174666177)
# 6     (0.6848233245547349, 0.7102008721673144)
# 2     (0.6793683558637993, 0.6944408770508036)
# 13     (0.675269843727718, 0.6937566082272619)
# 5     (0.6688904438759516, 0.6951842606397092)
# 9     (0.6709313493902282, 0.6848704070191798)
# 4     (0.6606732523129755, 0.6796050544777492)
# 14     (0.644474928708474, 0.6895975814521749)
# 8     (0.6447499702586863, 0.6647278178641165)
# 11    (0.6256928325139925, 0.6650361359281403)
# 7     (0.6348672291512448, 0.6533577315201482)
# 1     (0.6249795920654493, 0.6373069136751719)
# 16     (0.600164316417671, 0.6214354515646031)
# 20     (0.5904813382272442, 0.617294995337488)
# 27    (0.5784726821004407, 0.5936993834222227)
# 10    (0.5781024979749534, 0.5935022843126472)
# 22    (0.5529536886649618, 0.6109344069969447)
# 23    (0.5566560150857647, 0.6287529782901796)
# 26    (0.5149379344330591, 0.6002550816159113)
# 12     (0.533641301447533, 0.5621874421880312)
# 21    (0.5271508000077643, 0.5640533282192957)
# 24    (0.5159665339334302, 0.5350021654176305)
# 18    (0.5038867693538035, 0.5241505332443938)
# 19    (0.4575080757054647, 0.5330144625077933)
# 17  (0.47644550717781753, 0.49413481220457245)

# %% [markdown]
# # now with fixed phi

# %%
    # --- loop through all checkpoints --------------------------------------------
ckpt_dir = "/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs"
ckpt_paths = sorted(glob.glob(os.path.join(ckpt_dir, "enrollment_model_W0.0001_batch_*_*.pt")))

ckpt = torch.load(ckpt_path, map_location="cpu")
ckpt = torch.load(ckpt_paths[0], map_location="cpu")
G_batch_dummy=ckpt["G"]
G_batch_dummy.shape
del ckpt
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/2760979252.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/2760979252.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_paths[0], map_location="cpu")

# %%
# %load_ext autoreload
# %autoreload 2
import glob
import os
import sys
sys.path.append('/Users/sarahurbut/aladynoulli2/pyScripts/')
from clust_huge_amp import *
import torch
import numpy as np
import pandas as pd
from fig5utils import evaluate_major_diseases_wsex_with_bootstrap
import os
import sys
import torch



pce_df = pd.read_csv("/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/pce_prevent_full.csv")
disease_names=pd.read_csv("/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/disease_names.csv")


# --- Fixed resources ---------------------------------------------------------
initial_psi = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt")
initial_clusters = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt")
signature_refs = torch.load(
    "/Users/sarahurbut/Library/Cloudstorage/Dropbox-Personal/data_for_running/reference_trajectories.pt"
)["signature_refs"]




# master tensors; adjust paths if they live elsewhere
Y_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/Y_tensor.pt")
E_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_matrix.pt")
G_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/G_matrix.pt")

# helper to build model & evaluate one batch

# helper to build model & evaluate one batch
def eval_batch(ckpt_path):
    ckpt = torch.load(ckpt_path, map_location="cpu")
    start, stop = ckpt["start_index"], ckpt["end_index"]  # indices saved in each checkpoint

  
    Y_batch = Y_full[start:stop]
    E_batch = E_full[start:stop]
# master tensors; adjust paths if 
    cov_batch = pce_df.iloc[start:stop].reset_index(drop=True)
    if "Sex" not in cov_batch.columns and "sex" in cov_batch.columns:
        cov_batch = cov_batch.rename(columns={"sex": "Sex"})
    cov_batch = cov_batch.assign(Sex=cov_batch["Sex"], age=cov_batch["age"])  # keep original naming, but ensure present

  

    model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
        N=Y_batch.shape[0],
        D=Y_batch.shape[1],
        T=Y_batch.shape[2],
        K=20,
        P=G_batch_dummy.shape[1],
        init_sd_scaler=1e-1,
        G=G_batch_dummy,
        Y=Y_batch.numpy(),
        genetic_scale=1,
        W=0.0001,
        R=0,
        prevalence_t=ckpt["prevalence_t"],
        signature_references=signature_refs,
        healthy_reference=True,
        disease_names=disease_names['x'],
    )
    model.initialize_params(true_psi=initial_psi)
    model.clusters =  initial_clusters
    model.load_state_dict(ckpt["model_state_dict"])
    model.eval()

    results = evaluate_major_diseases_wsex_with_bootstrap(
        model=model,
        Y_100k=Y_batch,
        E_100k=E_batch,
        disease_names=disease_names['x'],
        pce_df=cov_batch,
        n_bootstraps=20,
        follow_up_duration_years=10,
    )
    return (start, stop), results

# --- loop through all checkpoints --------------------------------------------
ckpt_dir = "/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs_fromclaudeoutput/"
ckpt_paths = sorted(glob.glob(os.path.join(ckpt_dir, "model_enroll_fixedphi_sex_*_*pt")))

batch_results_fixed = {}
for ckpt_path in ckpt_paths:
    (start, stop), res = eval_batch(ckpt_path)
    batch_results_fixed[(start, stop)] = res
    print(f"Finished {start}-{stop}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/3406750175.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/3406750175.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/3406750175.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   signature_refs = torch.load(
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/3406750175.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/Y_tensor.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/3406750175.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_matrix.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/3406750175.py:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G_full = torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/G_matrix.pt")
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/3406750175.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0026,  0.0050,  0.0103,  0.0132, -0.0116])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0011, -0.0023,  0.0073,  0.0020, -0.0051])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0014, -0.0038,  0.0025,  0.0024, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0088, -0.0010, -0.0120,  0.0372, -0.0093])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0051,  0.0055, -0.0040,  0.0058,  0.0238])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0018,  0.0010, -0.0011, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0075,  0.0045, -0.0065,  0.0055, -0.0043])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0032, -0.0005,  0.0003,  0.0114, -0.0019])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([-0.0003,  0.0084,  0.0164, -0.0027,  0.0004])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0123, -0.0048,  0.0016, -0.0047,  0.0018])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0068,  0.0008, -0.0014,  0.0007,  0.0027])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 0.0086,  0.0104, -0.0006,  0.0071, -0.0017])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([-0.0015,  0.0126,  0.0149, -0.0003,  0.0101])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0162, -0.0025,  0.0116,  0.0191, -0.0034])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0008, -0.0014,  0.0007,  0.0034,  0.0015])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.9623, -13.8155])
# Base value centered (first 5): tensor([-0.1879, -0.1879, -0.1879,  1.6653, -0.1879])
# Base value centered mean: -3.345489574257954e-07
# Gamma init for k=0 (first 5): tensor([ 0.0074,  0.0061, -0.0054,  0.0060,  0.0235])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.3449, -13.3449, -12.4036])
# Base value centered (first 5): tensor([ 0.1505, -0.3201,  0.1505,  0.1505,  1.0918])
# Base value centered mean: -1.8495559288567165e-06
# Gamma init for k=1 (first 5): tensor([0.0042, 0.0009, 0.0009, 0.0018, 0.0015])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1566, -11.8388, -12.4977])
# Base value centered (first 5): tensor([-0.3849, -0.3849,  0.2740,  1.5918,  0.9329])
# Base value centered mean: 9.290695288655115e-07
# Gamma init for k=2 (first 5): tensor([ 0.0016,  0.0073,  0.0100,  0.0140, -0.0118])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.6950, -13.5744])
# Base value centered (first 5): tensor([-0.1026, -0.1026, -0.1026,  0.0179,  0.1384])
# Base value centered mean: 4.7445297468584613e-07
# Gamma init for k=3 (first 5): tensor([ 0.0012,  0.0003,  0.0016,  0.0018, -0.0006])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155,  -9.8620, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1133,  3.8402, -0.1133, -0.1133, -0.1133])
# Base value centered mean: -2.841758714566822e-06
# Gamma init for k=4 (first 5): tensor([-0.0172, -0.0033,  0.0143,  0.0225, -0.0033])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=5 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1523, -0.1523, -0.1523, -0.1523, -0.1523])
# Base value centered mean: -1.0890006478803116e-06
# Gamma init for k=6 (first 5): tensor([ 0.0090,  0.0121, -0.0006,  0.0042, -0.0027])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.3663, -13.8155, -13.3663, -13.8155, -11.1200])
# Base value centered (first 5): tensor([-0.1005, -0.5497, -0.1005, -0.5497,  2.1458])
# Base value centered mean: 1.2460708376238472e-06
# Gamma init for k=7 (first 5): tensor([ 0.0003, -0.0038, -0.0111,  0.0251, -0.0016])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1159, -0.1159, -0.1159, -0.1159, -0.1159])
# Base value centered mean: -1.4129639112070436e-06
# Gamma init for k=8 (first 5): tensor([ 0.0066, -0.0055,  0.0011, -0.0020, -0.0005])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=9 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=10 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=11 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0860, -0.0860, -0.0860, -0.0860, -0.0860])
# Base value centered mean: -1.034450519910024e-06
# Gamma init for k=12 (first 5): tensor([ 0.0080, -0.0074,  0.0002, -0.0001, -0.0076])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.7744, -12.2949])
# Base value centered (first 5): tensor([-0.1777, -0.1777, -0.1777,  2.8635,  1.3429])
# Base value centered mean: -1.0064125035569305e-06
# Gamma init for k=13 (first 5): tensor([-0.0002,  0.0060,  0.0127, -0.0051,  0.0007])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.8388, -12.8271])
# Base value centered (first 5): tensor([-0.2562, -0.2562, -0.2562,  1.7205,  0.7322])
# Base value centered mean: -1.5125274330785032e-06
# Gamma init for k=14 (first 5): tensor([ 0.0038, -0.0052, -0.0089,  0.0162,  0.0005])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.8388])
# Base value centered (first 5): tensor([-0.2850, -0.2850, -0.2850, -0.2850,  1.6917])
# Base value centered mean: -1.2931823221151717e-06
# Gamma init for k=15 (first 5): tensor([-0.0039,  0.0064,  0.0118, -0.0049,  0.0086])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.7706, -13.1339])
# Base value centered (first 5): tensor([-0.2428, -0.2428, -0.2428,  1.8021,  0.4388])
# Base value centered mean: -1.9989013253507437e-06
# Gamma init for k=16 (first 5): tensor([ 0.0009,  0.0001,  0.0093,  0.0055, -0.0031])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.3272, -12.0713])
# Base value centered (first 5): tensor([-0.4228, -0.4228, -0.4228,  3.0656,  1.3214])
# Base value centered mean: -2.227592403869494e-06
# Gamma init for k=17 (first 5): tensor([ 0.0081,  0.0052, -0.0070,  0.0058, -0.0042])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=18 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([-0.1519, -0.1519, -0.1519, -0.1519,  0.2779])
# Base value centered mean: -1.1179923831150518e-06
# Gamma init for k=19 (first 5): tensor([-0.0027,  0.0053,  0.0013, -0.0016, -0.0018])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.683 (0.668-0.701) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.669, Events = 273/5409
#    Male: AUC = 0.685, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.707, Events = 8/37
#    Breast_Cancer: AUC = 0.549, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.613 (0.593-0.626) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.604, Events = 264/5409
#    Male: AUC = 0.617, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.701 (0.687-0.722) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.707, Events = 197/5372
#    Male: AUC = 0.706, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.710 (0.688-0.737) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.733, Events = 101/5409
#    Male: AUC = 0.687, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.676 (0.645-0.697) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.671, Events = 134/5409
#    Male: AUC = 0.672, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.652 (0.617-0.687) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.626, Events = 64/5409
#    Male: AUC = 0.678, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.699 (0.670-0.729) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.716, Events = 83/5409
#    Male: AUC = 0.683, Events = 122/4591
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.681 (0.661-0.703) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.682, Events = 135/5409
#    Male: AUC = 0.676, Events = 200/4591
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.647 (0.613-0.662) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.674, Events = 176/5409
#    Male: AUC = 0.622, Events = 218/4591
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.665 (0.644-0.697) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.674, Events = 128/5379
#    Male: AUC = 0.660, Events = 90/4582
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.592 (0.563-0.621) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.549, Events = 280/5409
#    Male: AUC = 0.640, Events = 243/4591
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.661 (0.630-0.702) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.635, Events = 56/5409
#    Male: AUC = 0.689, Events = 49/4591
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.580 (0.558-0.607) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.677 (0.649-0.714) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.4%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.689 (0.630-0.732) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.693, Events = 48/5406
#    Male: AUC = 0.681, Events = 27/4586
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.726 (0.683-0.776) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.609, Events = 24/5399
#    Male: AUC = 0.841, Events = 25/4577
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.604 (0.585-0.619) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.611, Events = 147/5409
#    Male: AUC = 0.595, Events = 129/4591
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.470 (0.440-0.487) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.0%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.469, Events = 210/5351
#    Male: AUC = 0.482, Events = 191/4561
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.507 (0.466-0.541) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.517, Events = 130/5391
#    Male: AUC = 0.499, Events = 110/4584
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.406 (0.265-0.493) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.443, Events = 14/5399
#    Male: AUC = 0.378, Events = 19/4585
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.596 (0.534-0.628) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.592, Events = 62/5381
#    Male: AUC = 0.595, Events = 60/4582
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.416 (0.338-0.499) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.386, Events = 15/5405
#    Male: AUC = 0.435, Events = 25/4576
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.591 (0.516-0.683) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.575, Events = 31/5378
#    Male: AUC = 0.624, Events = 19/4569
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.510 (0.408-0.590) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.532, Events = 20/5388
#    Male: AUC = 0.471, Events = 11/4579
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.497 (0.477-0.521) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.1%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.499, Events = 321/5214
#    Male: AUC = 0.531, Events = 264/4473
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.747 (0.665-0.802) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.800, Events = 21/5407
#    Male: AUC = 0.701, Events = 25/4590
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.533 (0.435-0.598) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.514, Events = 13/5394
#    Male: AUC = 0.566, Events = 8/4585
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.563 (0.537-0.574) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.567, Events = 385/5409
#    Male: AUC = 0.561, Events = 94/4591
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.683 (0.668-0.701)       831        8.3
# Diabetes             0.613 (0.593-0.626)       581        5.8
# Atrial_Fib           0.701 (0.687-0.722)       376        3.8
# CKD                  0.710 (0.688-0.737)       207        2.1
# All_Cancers          0.676 (0.645-0.697)       480        4.8
# Stroke               0.652 (0.617-0.687)       129        1.3
# Heart_Failure        0.699 (0.670-0.729)       205        2.1
# Pneumonia            0.681 (0.661-0.703)       335        3.4
# COPD                 0.647 (0.613-0.662)       394        3.9
# Osteoporosis         0.665 (0.644-0.697)       219        2.2
# Anemia               0.592 (0.563-0.621)       523        5.2
# Colorectal_Cancer    0.661 (0.630-0.702)       105        1.1
# Breast_Cancer        0.580 (0.558-0.607)       214        4.0
# Prostate_Cancer      0.677 (0.649-0.714)       204        4.4
# Lung_Cancer          0.689 (0.630-0.732)       75         0.8
# Bladder_Cancer       0.726 (0.683-0.776)       49         0.5
# Secondary_Cancer     0.604 (0.585-0.619)       276        2.8
# Depression           0.470 (0.440-0.487)       405        4.0
# Anxiety              0.507 (0.466-0.541)       241        2.4
# Bipolar_Disorder     0.406 (0.265-0.493)       34         0.3
# Rheumatoid_Arthritis 0.596 (0.534-0.628)       123        1.2
# Psoriasis            0.416 (0.338-0.499)       40         0.4
# Ulcerative_Colitis   0.591 (0.516-0.683)       50         0.5
# Crohns_Disease       0.510 (0.408-0.590)       31         0.3
# Asthma               0.497 (0.477-0.521)       606        6.1
# Parkinsons           0.747 (0.665-0.802)       46         0.5
# Multiple_Sclerosis   0.533 (0.435-0.598)       21         0.2
# Thyroid_Disorders    0.563 (0.537-0.574)       479        4.8
# --------------------------------------------------------------------------------
# Finished 0-10000
#
# Cluster Sizes:
# Cluster 0: 42 diseases
# Cluster 1: 24 diseases
# Cluster 2: 8 diseases
# Cluster 3: 5 diseases
# Cluster 4: 8 diseases
# Cluster 5: 13 diseases
# Cluster 6: 60 diseases
# Cluster 7: 30 diseases
# Cluster 8: 7 diseases
# Cluster 9: 19 diseases
# Cluster 10: 10 diseases
# Cluster 11: 15 diseases
# Cluster 12: 16 diseases
# Cluster 13: 11 diseases
# Cluster 14: 7 diseases
# Cluster 15: 7 diseases
# Cluster 16: 12 diseases
# Cluster 17: 16 diseases
# Cluster 18: 22 diseases
# Cluster 19: 16 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 42
# Base value (first 5): tensor([-13.5802, -13.8155, -13.8155, -13.8155, -13.5802])
# Base value centered (first 5): tensor([ 0.1123, -0.1230, -0.1230, -0.1230,  0.1123])
# Base value centered mean: -4.872322278970387e-07
# Gamma init for k=0 (first 5): tensor([-0.0032, -0.0004,  0.0024,  0.0001,  0.0007])
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/3406750175.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location="cpu")
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Calculating gamma for k=1:
# Number of diseases in cluster: 24
# Base value (first 5): tensor([-13.8155, -13.4037, -13.8155, -12.9919, -13.8155])
# Base value centered (first 5): tensor([-0.2507,  0.1611, -0.2507,  0.5729, -0.2507])
# Base value centered mean: -3.0660628453915706e-06
# Gamma init for k=1 (first 5): tensor([-0.0034,  0.0084, -0.0081, -0.0016, -0.0014])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1150, -0.1150, -0.1150, -0.1150, -0.1150])
# Base value centered mean: -2.318954557267716e-06
# Gamma init for k=2 (first 5): tensor([-0.0023,  0.0033, -0.0088, -0.0063,  0.0050])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 5
# Base value (first 5): tensor([-13.8155, -11.8388, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2868,  1.6899, -0.2868, -0.2868, -0.2868])
# Base value centered mean: -1.7898559008244774e-06
# Gamma init for k=3 (first 5): tensor([ 0.0034,  0.0165,  0.0034, -0.0020, -0.0095])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1599, -0.1599, -0.1599, -0.1599, -0.1599])
# Base value centered mean: -1.6735076542317984e-06
# Gamma init for k=4 (first 5): tensor([-0.0093,  0.0117, -0.0036, -0.0108,  0.0038])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1988, -0.1988, -0.1988, -0.1988, -0.1988])
# Base value centered mean: 5.046844648859405e-07
# Gamma init for k=5 (first 5): tensor([ 0.0065,  0.0022, -0.0043, -0.0101,  0.0047])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 60
# Base value (first 5): tensor([-13.6508, -13.6508, -13.6508, -13.6508, -13.8155])
# Base value centered (first 5): tensor([ 0.0040,  0.0040,  0.0040,  0.0040, -0.1608])
# Base value centered mean: -3.2844542374732555e-07
# Gamma init for k=6 (first 5): tensor([ 1.8497e-03,  2.5832e-03, -1.0756e-03, -1.0755e-03,  8.9680e-05])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 30
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1529, -0.1529, -0.1529, -0.1529, -0.1529])
# Base value centered mean: -1.6108513136714464e-06
# Gamma init for k=7 (first 5): tensor([-0.0010,  0.0059, -0.0056, -0.0012, -0.0012])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -10.9916, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7101, -0.7101,  2.1138, -0.7101, -0.7101])
# Base value centered mean: -9.76181013356836e-07
# Gamma init for k=8 (first 5): tensor([ 0.0049,  0.0437, -0.0107, -0.0139, -0.0172])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 19
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.2549])
# Base value centered (first 5): tensor([-0.1634, -0.1634, -0.1634, -0.1634,  1.3971])
# Base value centered mean: -1.4804840020588017e-06
# Gamma init for k=9 (first 5): tensor([-0.0005,  0.0104, -0.0036,  0.0014, -0.0039])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 10
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.8271, -13.8155])
# Base value centered (first 5): tensor([-0.1655, -0.1655, -0.1655,  0.8229, -0.1655])
# Base value centered mean: -1.396179243329243e-07
# Gamma init for k=10 (first 5): tensor([0.0101, 0.0041, 0.0024, 0.0018, 0.0010])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -11.8388, -11.1799, -13.8155])
# Base value centered (first 5): tensor([-0.3435, -0.3435,  1.6332,  2.2922, -0.3435])
# Base value centered mean: -8.144378398355911e-07
# Gamma init for k=11 (first 5): tensor([ 0.0134,  0.0033, -0.0101,  0.0023,  0.0059])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.1978, -13.1978])
# Base value centered (first 5): tensor([-0.2723, -0.2723, -0.2723,  0.3454,  0.3454])
# Base value centered mean: 2.2010803490957187e-07
# Gamma init for k=12 (first 5): tensor([-0.0013,  0.0207, -0.0107,  0.0131,  0.0003])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -12.9170, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2809, -0.2809,  0.6176, -0.2809, -0.2809])
# Base value centered mean: -1.080703782463388e-06
# Gamma init for k=13 (first 5): tensor([-0.0210, -0.0059, -0.0088, -0.0006,  0.0081])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0915, -0.0915, -0.0915, -0.0915, -0.0915])
# Base value centered mean: -9.2916491212236e-07
# Gamma init for k=14 (first 5): tensor([-0.0005,  0.0033, -0.0031, -0.0045,  0.0123])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0897, -0.0897, -0.0897, -0.0897, -0.0897])
# Base value centered mean: -6.519794624182396e-07
# Gamma init for k=15 (first 5): tensor([-0.0030,  0.0084, -0.0033,  0.0004, -0.0037])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1759, -0.1759, -0.1759, -0.1759, -0.1759])
# Base value centered mean: -6.105423153712763e-07
# Gamma init for k=16 (first 5): tensor([ 5.1392e-03, -2.6544e-03,  4.4172e-03, -1.0849e-02,  5.0559e-06])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.1978, -13.1978, -12.5800, -11.3446, -13.8155])
# Base value centered (first 5): tensor([ 0.1701,  0.1701,  0.7879,  2.0233, -0.4476])
# Base value centered mean: -1.1844634855151526e-06
# Gamma init for k=17 (first 5): tensor([-0.0015,  0.0075, -0.0135,  0.0090, -0.0066])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 22
# Base value (first 5): tensor([-13.3663, -13.3663, -13.3663, -12.9170, -13.3663])
# Base value centered (first 5): tensor([-0.1135, -0.1135, -0.1135,  0.3358, -0.1135])
# Base value centered mean: 6.504058660539158e-07
# Gamma init for k=18 (first 5): tensor([-0.0097,  0.0089, -0.0178, -0.0072, -0.0061])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.1978, -13.8155])
# Base value centered (first 5): tensor([-0.1494, -0.1494, -0.1494,  0.4684, -0.1494])
# Base value centered mean: -2.2361755327438004e-06
# Gamma init for k=19 (first 5): tensor([ 0.0026, -0.0092, -0.0104,  0.0035,  0.0010])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.9623])
# Base value centered (first 5): tensor([-0.1871, -0.1871, -0.1871, -0.1871,  1.6661])
# Base value centered mean: -6.058692747501482e-07
# Gamma init for k=0 (first 5): tensor([-0.0033,  0.0132, -0.0078,  0.0028, -0.0062])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 0.1585, -0.3122, -0.3122, -0.3122, -0.3122])
# Base value centered mean: 6.502151563836378e-07
# Gamma init for k=1 (first 5): tensor([-0.0111,  0.0010, -0.0117, -0.0079,  0.0042])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -11.8388, -10.5209, -13.8155])
# Base value centered (first 5): tensor([-0.3785, -0.3785,  1.5982,  2.9160, -0.3785])
# Base value centered mean: 5.493163968139925e-08
# Gamma init for k=2 (first 5): tensor([ 0.0102,  0.0033, -0.0083,  0.0054,  0.0065])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.5744, -13.6950, -13.8155, -13.5744, -13.8155])
# Base value centered (first 5): tensor([ 0.1365,  0.0159, -0.1046,  0.1365, -0.1046])
# Base value centered mean: -3.633499261468387e-07
# Gamma init for k=3 (first 5): tensor([-0.0010,  0.0030, -0.0004, -0.0004, -0.0015])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1101, -0.1101, -0.1101, -0.1101, -0.1101])
# Base value centered mean: -3.237629016439314e-06
# Gamma init for k=4 (first 5): tensor([-0.0032,  0.0123, -0.0048,  0.0003, -0.0067])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -10.9916, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7101, -0.7101,  2.1138, -0.7101, -0.7101])
# Base value centered mean: -9.76181013356836e-07
# Gamma init for k=5 (first 5): tensor([ 0.0049,  0.0437, -0.0107, -0.0139, -0.0172])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# ...
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2663, -0.2663, -0.2663, -0.2663, -0.2663])
# Base value centered mean: -1.115417489927495e-06
# Gamma init for k=10 (first 5): tensor([ 0.0089, -0.0068, -0.0078, -0.0064, -0.0124])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1109, -0.1109, -0.1109, -0.1109, -0.1109])
# Base value centered mean: -1.4264106766859186e-06
# Gamma init for k=11 (first 5): tensor([-6.3167e-04, -5.2316e-05,  2.1208e-03, -4.4305e-03,  2.1411e-03])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -12.4036, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0998, -0.0998,  1.3121, -0.0998, -0.0998])
# Base value centered mean: -1.7006874486469314e-06
# Gamma init for k=12 (first 5): tensor([-0.0015, -0.0011, -0.0045, -0.0050,  0.0026])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -11.5347, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1716, -0.1716,  2.1093, -0.1716, -0.1716])
# Base value centered mean: 2.187728824765145e-07
# Gamma init for k=13 (first 5): tensor([ 0.0050, -0.0047, -0.0048, -0.0038, -0.0003])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-12.8271, -13.8155, -12.8271, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 0.7084, -0.2800,  0.7084, -0.2800, -0.2800])
# Base value centered mean: 1.4724732011472952e-07
# Gamma init for k=14 (first 5): tensor([ 0.0124, -0.0042,  0.0063,  0.0072,  0.0029])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([ -7.8853, -11.8388, -11.8388, -13.8155, -13.8155])
# Base value centered (first 5): tensor([ 5.6386,  1.6852,  1.6852, -0.2916, -0.2916])
# Base value centered mean: -1.1932372672163183e-06
# Gamma init for k=15 (first 5): tensor([ 0.0106,  0.0268, -0.0023,  0.0092, -0.0190])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1339, -13.4747, -13.8155])
# Base value centered (first 5): tensor([-0.2561, -0.2561,  0.4255,  0.0847, -0.2561])
# Base value centered mean: -5.432128773463774e-07
# Gamma init for k=16 (first 5): tensor([-0.0029,  0.0013, -0.0044,  0.0045, -0.0052])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.2341])
# Base value centered (first 5): tensor([-0.4213, -0.4213, -0.4213, -0.4213,  0.1601])
# Base value centered mean: -1.363754222438729e-06
# Gamma init for k=17 (first 5): tensor([ 0.0015,  0.0083, -0.0007,  0.0017,  0.0133])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1679, -0.1679, -0.1679, -0.1679, -0.1679])
# Base value centered mean: -1.7017364370985888e-06
# Gamma init for k=18 (first 5): tensor([-0.0032,  0.0039,  0.0033,  0.0010, -0.0008])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-12.9561, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([ 0.7026, -0.1568, -0.1568, -0.1568,  0.2729])
# Base value centered mean: -1.2242317097843625e-06
# Gamma init for k=19 (first 5): tensor([-0.0005, -0.0045, -0.0011, -0.0031, -0.0021])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.686 (0.672-0.700) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 853 (8.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.676, Events = 318/5560
#    Male: AUC = 0.683, Events = 535/4440
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.756, Events = 8/52
#    Breast_Cancer: AUC = 0.486, Events = 8/155
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.621 (0.606-0.640) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 591 (5.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.626, Events = 233/5560
#    Male: AUC = 0.610, Events = 358/4440
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.692 (0.657-0.713) (calculated on 9885 individuals)
# Events (10-Year in Eval Cohort): 368 (3.7%) (from 10000 individuals)
# Excluded 115 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.701, Events = 207/5519
#    Male: AUC = 0.691, Events = 158/4366
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.727 (0.693-0.760) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 213 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.718, Events = 113/5560
#    Male: AUC = 0.735, Events = 100/4440
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.658 (0.642-0.679) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 491 (4.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.618, Events = 151/5560
#    Male: AUC = 0.664, Events = 340/4440
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.676 (0.604-0.710) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 136 (1.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.678, Events = 58/5560
#    Male: AUC = 0.668, Events = 78/4440
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.692 (0.671-0.731) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 222 (2.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.682, Events = 84/5560
#    Male: AUC = 0.688, Events = 138/4440
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.667 (0.652-0.694) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 390 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.652, Events = 163/5560
#    Male: AUC = 0.671, Events = 227/4440
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.636 (0.621-0.656) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 433 (4.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.650, Events = 185/5560
#    Male: AUC = 0.617, Events = 248/4440
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.656 (0.628-0.687) (calculated on 9968 individuals)
# Events (10-Year in Eval Cohort): 255 (2.5%) (from 10000 individuals)
# Excluded 32 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.644, Events = 139/5531
#    Male: AUC = 0.674, Events = 115/4437
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.575 (0.554-0.595) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 587 (5.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.556, Events = 337/5560
#    Male: AUC = 0.600, Events = 250/4440
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.582 (0.553-0.613) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 111 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.568, Events = 42/5560
#    Male: AUC = 0.583, Events = 69/4440
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5560 individuals in cohort
# AUC: 0.570 (0.533-0.596) (calculated on 5560 individuals)
# Events (10-Year in Eval Cohort): 228 (4.1%) (from 5560 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4440 individuals in cohort
# AUC: 0.689 (0.654-0.704) (calculated on 4402 individuals)
# Events (10-Year in Eval Cohort): 184 (4.1%) (from 4440 individuals)
# Excluded 38 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.612 (0.572-0.651) (calculated on 9996 individuals)
# Events (10-Year in Eval Cohort): 79 (0.8%) (from 10000 individuals)
# Excluded 4 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.596, Events = 43/5557
#    Male: AUC = 0.634, Events = 36/4439
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.741 (0.704-0.780) (calculated on 9973 individuals)
# Events (10-Year in Eval Cohort): 56 (0.6%) (from 10000 individuals)
# Excluded 27 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.715, Events = 31/5555
#    Male: AUC = 0.776, Events = 25/4418
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.601 (0.571-0.628) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 307 (3.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.590, Events = 180/5560
#    Male: AUC = 0.618, Events = 127/4440
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.486 (0.456-0.512) (calculated on 9893 individuals)
# Events (10-Year in Eval Cohort): 425 (4.2%) (from 10000 individuals)
# Excluded 107 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.493, Events = 237/5500
#    Male: AUC = 0.487, Events = 179/4393
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.478 (0.450-0.509) (calculated on 9968 individuals)
# Events (10-Year in Eval Cohort): 271 (2.7%) (from 10000 individuals)
# Excluded 32 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.490, Events = 138/5545
#    Male: AUC = 0.464, Events = 131/4423
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.557 (0.486-0.618) (calculated on 9986 individuals)
# Events (10-Year in Eval Cohort): 24 (0.2%) (from 10000 individuals)
# Excluded 14 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.477, Events = 10/5553
#    Male: AUC = 0.616, Events = 14/4433
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.602 (0.567-0.635) (calculated on 9948 individuals)
# Events (10-Year in Eval Cohort): 121 (1.2%) (from 10000 individuals)
# Excluded 52 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.592, Events = 74/5525
#    Male: AUC = 0.631, Events = 46/4423
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.544 (0.467-0.613) (calculated on 9980 individuals)
# Events (10-Year in Eval Cohort): 44 (0.4%) (from 10000 individuals)
# Excluded 20 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.516, Events = 28/5553
#    Male: AUC = 0.596, Events = 16/4427
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.578 (0.502-0.637) (calculated on 9957 individuals)
# Events (10-Year in Eval Cohort): 52 (0.5%) (from 10000 individuals)
# Excluded 43 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.573, Events = 32/5537
#    Male: AUC = 0.588, Events = 20/4420
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.572 (0.452-0.729) (calculated on 9965 individuals)
# Events (10-Year in Eval Cohort): 29 (0.3%) (from 10000 individuals)
# Excluded 35 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.557, Events = 16/5545
#    Male: AUC = 0.595, Events = 13/4420
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.507 (0.484-0.529) (calculated on 9672 individuals)
# Events (10-Year in Eval Cohort): 624 (6.2%) (from 10000 individuals)
# Excluded 328 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.522, Events = 337/5339
#    Male: AUC = 0.525, Events = 269/4333
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.721 (0.690-0.789) (calculated on 9998 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 2 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.735, Events = 21/5559
#    Male: AUC = 0.708, Events = 28/4439
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.542 (0.449-0.634) (calculated on 9982 individuals)
# Events (10-Year in Eval Cohort): 29 (0.3%) (from 10000 individuals)
# Excluded 18 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.641, Events = 11/5547
#    Male: AUC = 0.480, Events = 18/4435
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.578 (0.551-0.589) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 434 (4.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.582, Events = 344/5560
#    Male: AUC = 0.583, Events = 90/4440
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.686 (0.672-0.700)       853        8.5
# Diabetes             0.621 (0.606-0.640)       591        5.9
# Atrial_Fib           0.692 (0.657-0.713)       368        3.7
# CKD                  0.727 (0.693-0.760)       213        2.1
# All_Cancers          0.658 (0.642-0.679)       491        4.9
# Stroke               0.676 (0.604-0.710)       136        1.4
# Heart_Failure        0.692 (0.671-0.731)       222        2.2
# Pneumonia            0.667 (0.652-0.694)       390        3.9
# COPD                 0.636 (0.621-0.656)       433        4.3
# Osteoporosis         0.656 (0.628-0.687)       255        2.5
# Anemia               0.575 (0.554-0.595)       587        5.9
# Colorectal_Cancer    0.582 (0.553-0.613)       111        1.1
# Breast_Cancer        0.570 (0.533-0.596)       228        4.1
# Prostate_Cancer      0.689 (0.654-0.704)       184        4.1
# Lung_Cancer          0.612 (0.572-0.651)       79         0.8
# Bladder_Cancer       0.741 (0.704-0.780)       56         0.6
# Secondary_Cancer     0.601 (0.571-0.628)       307        3.1
# Depression           0.486 (0.456-0.512)       425        4.2
# Anxiety              0.478 (0.450-0.509)       271        2.7
# Bipolar_Disorder     0.557 (0.486-0.618)       24         0.2
# Rheumatoid_Arthritis 0.602 (0.567-0.635)       121        1.2
# Psoriasis            0.544 (0.467-0.613)       44         0.4
# Ulcerative_Colitis   0.578 (0.502-0.637)       52         0.5
# Crohns_Disease       0.572 (0.452-0.729)       29         0.3
# Asthma               0.507 (0.484-0.529)       624        6.2
# Parkinsons           0.721 (0.690-0.789)       49         0.5
# Multiple_Sclerosis   0.542 (0.449-0.634)       29         0.3
# Thyroid_Disorders    0.578 (0.551-0.589)       434        4.3
# --------------------------------------------------------------------------------
# Finished 90000-100000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 100
#      96     print(f"Finished {start}-{stop}")
#      99 # Save fixed-φ run (10‑year evaluation)
# --> 100 with (out_dir / "batch_results_fixed_10yr.pkl").open("wb") as f:
#     101     pickle.dump(batch_results_fixed, f)
#     102 print("Saved:", out_dir / "batch_results_fixed_10yr.pkl")
#
# NameError: name 'out_dir' is not defined

# %%
import pickle
from pathlib import Path

out_dir = Path("/Users/sarahurbut/aladynoulli2/claudefile/output")
out_dir.mkdir(parents=True, exist_ok=True)

# Save joint run (e.g., 10‑year evaluation)
with (out_dir / "batch_results_fixed_10yr.pkl").open("wb") as f:
    pickle.dump(batch_results_fixed, f)
print("Saved:", out_dir / "batch_results_fixed_10yr.pkl")
# Out:
# Saved: /Users/sarahurbut/aladynoulli2/claudefile/output/batch_results_fixed_10yr.pkl

# %%
# Collect per-disease AUC lists
# Collect per-disease AUC lists
disease_aucs = {}
for batch_res in batch_results_fixed.values():
    for disease, metrics in batch_res.items():
        disease_aucs.setdefault(disease, []).append(metrics["auc"])
# Median AUC and optional IQR
median_auc_df = (
    pd.Series({d: np.nanmedian(vals) for d, vals in disease_aucs.items()}, name="MedianAUC")
      .reset_index()
      .rename(columns={"index": "Disease"})
      .sort_values("MedianAUC", ascending=False)
)
median_auc_df["IQR"] = [
    (np.nanpercentile(disease_aucs[d], 25), np.nanpercentile(disease_aucs[d], 75))
    for d in median_auc_df["Disease"]
]

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=median_auc_df,
    x="MedianAUC",
    y="Disease",
    color="#4c72b0"
)
plt.xlim(0.5, 1.0)
plt.xlabel("Median AUC (across PCS batches)")
plt.ylabel("")
plt.title("Enrollment 10-year predictions (PCS fixed phi runs)")
plt.tight_layout()
plt.show()

# %%
median_auc_df.to_csv("/Users/sarahurbut/aladynoulli2/claudefile/output/median_auc_results_10yearfixedphi.csv", index=False)

# %%
tl=torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs_fromclaudeoutput/model_enroll_fixedphi_sex_10000_20000.pt")
tl.keys()
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_21266/708949983.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   tl=torch.load("/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs_fromclaudeoutput/model_enroll_fixedphi_sex_10000_20000.pt")
# dict_keys(['model_state_dict', 'E', 'prevalence_t', 'logit_prevalence_t', 'start_index', 'end_index'])
