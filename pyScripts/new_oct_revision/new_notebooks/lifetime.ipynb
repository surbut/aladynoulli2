# %%
import os
import sys
import torch
# %load_ext autoreload
# %autoreload 2
sys.path.append('/Users/sarahurbut/aladynoulli2/pyScripts/')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_retrospective_full/enrollment_model_W0.0001_batch_0_10000.pt')
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/1252489767.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_retrospective_full/enrollment_model_W0.0001_batch_0_10000.pt')

# %%
# %load_ext autoreload
# %autoreload 2

# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()

def load_model_essentials(base_path='/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
from clust_huge_amp import *
# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, start_index=0, end_index=10000)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data

del Y

# Load references (signatures only, no healthy)
refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/reference_trajectories.pt')
signature_refs = refs['signature_refs']
# When initializing the model:

readRDS = robjects.r['readRDS']
pce_data = readRDS('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_df_prevent.rds')
pce_df = pandas2ri.rpy2py(pce_data)  # Convert to pandas DataFrame
sex=pce_df['Sex'].values

# Convert to numeric: Female=0, Male=1

pce_df['sex_numeric'] = pce_df['Sex'].map({'Female': 0, 'Male': 1}).astype(int)

sex=pce_df['sex_numeric'].values
G_with_sex = ckpt['G']  # sex should be numeric (e.g., 0/1)
# N


model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_with_sex.shape[1],
    init_sd_scaler=1e-1,
    G=G_with_sex, 
    Y=Y_100k,
    genetic_scale=1,
    W=0,
    R=0,
    prevalence_t=essentials['prevalence_t'],
    signature_references=signature_refs,  # Only pass signature refs
    healthy_reference=True,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

torch.manual_seed(0)
np.random.seed(0)
# Initialize with psi and clusters


import cProfile
import pstats
from pstats import SortKey

# Now in your batch run, load and verify:
initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')

model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/3330217842.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/3330217842.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/3330217842.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/3330217842.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/3330217842.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/reference_trajectories.pt')
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0026,  0.0050,  0.0103,  0.0132, -0.0116])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0011, -0.0023,  0.0073,  0.0020, -0.0051])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0014, -0.0038,  0.0025,  0.0024, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0088, -0.0010, -0.0120,  0.0372, -0.0093])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0051,  0.0055, -0.0040,  0.0058,  0.0238])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0018,  0.0010, -0.0011, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0075,  0.0045, -0.0065,  0.0055, -0.0043])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0032, -0.0005,  0.0003,  0.0114, -0.0019])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([-0.0003,  0.0084,  0.0164, -0.0027,  0.0004])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0123, -0.0048,  0.0016, -0.0047,  0.0018])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0068,  0.0008, -0.0014,  0.0007,  0.0027])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 0.0086,  0.0104, -0.0006,  0.0071, -0.0017])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([-0.0015,  0.0126,  0.0149, -0.0003,  0.0101])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0162, -0.0025,  0.0116,  0.0191, -0.0034])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0008, -0.0014,  0.0007,  0.0034,  0.0015])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 16.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.9623, -13.8155])
# Base value centered (first 5): tensor([-0.1879, -0.1879, -0.1879,  1.6653, -0.1879])
# Base value centered mean: -3.345489574257954e-07
# Gamma init for k=0 (first 5): tensor([ 0.0074,  0.0061, -0.0054,  0.0060,  0.0235])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 21.0
# Base value (first 5): tensor([-13.3449, -13.8155, -13.3449, -13.3449, -12.4036])
# Base value centered (first 5): tensor([ 0.1505, -0.3201,  0.1505,  0.1505,  1.0918])
# Base value centered mean: -1.8495559288567165e-06
# Gamma init for k=1 (first 5): tensor([0.0042, 0.0009, 0.0009, 0.0018, 0.0015])
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/3330217842.py:99: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_psi_400k.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/3330217842.py:100: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/initial_clusters_400k.pt')
# Calculating gamma for k=2:
# Number of diseases in cluster: 15.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1566, -11.8388, -12.4977])
# Base value centered (first 5): tensor([-0.3849, -0.3849,  0.2740,  1.5918,  0.9329])
# Base value centered mean: 9.290695288655115e-07
# Gamma init for k=2 (first 5): tensor([ 0.0016,  0.0073,  0.0100,  0.0140, -0.0118])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 82.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.6950, -13.5744])
# Base value centered (first 5): tensor([-0.1026, -0.1026, -0.1026,  0.0179,  0.1384])
# Base value centered mean: 4.7445297468584613e-07
# Gamma init for k=3 (first 5): tensor([ 0.0012,  0.0003,  0.0016,  0.0018, -0.0006])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155,  -9.8620, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1133,  3.8402, -0.1133, -0.1133, -0.1133])
# Base value centered mean: -2.841758714566822e-06
# Gamma init for k=4 (first 5): tensor([-0.0172, -0.0033,  0.0143,  0.0225, -0.0033])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=5 (first 5): tensor([ 0.0200,  0.0102,  0.0029, -0.0021, -0.0044])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1523, -0.1523, -0.1523, -0.1523, -0.1523])
# Base value centered mean: -1.0890006478803116e-06
# Gamma init for k=6 (first 5): tensor([ 0.0090,  0.0121, -0.0006,  0.0042, -0.0027])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 22.0
# Base value (first 5): tensor([-13.3663, -13.8155, -13.3663, -13.8155, -11.1200])
# Base value centered (first 5): tensor([-0.1005, -0.5497, -0.1005, -0.5497,  2.1458])
# Base value centered mean: 1.2460708376238472e-06
# Gamma init for k=7 (first 5): tensor([ 0.0003, -0.0038, -0.0111,  0.0251, -0.0016])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 28.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1159, -0.1159, -0.1159, -0.1159, -0.1159])
# Base value centered mean: -1.4129639112070436e-06
# Gamma init for k=8 (first 5): tensor([ 0.0066, -0.0055,  0.0011, -0.0020, -0.0005])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 12.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=9 (first 5): tensor([ 0.0037,  0.0055, -0.0066,  0.0036,  0.0014])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 11.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=10 (first 5): tensor([-0.0084,  0.0188,  0.0010, -0.0041, -0.0089])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 8.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=11 (first 5): tensor([0.0026, 0.0020, 0.0032, 0.0007, 0.0098])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 7.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.0860, -0.0860, -0.0860, -0.0860, -0.0860])
# Base value centered mean: -1.034450519910024e-06
# Gamma init for k=12 (first 5): tensor([ 0.0080, -0.0074,  0.0002, -0.0001, -0.0076])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 13.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.7744, -12.2949])
# Base value centered (first 5): tensor([-0.1777, -0.1777, -0.1777,  2.8635,  1.3429])
# Base value centered mean: -1.0064125035569305e-06
# Gamma init for k=13 (first 5): tensor([-0.0002,  0.0060,  0.0127, -0.0051,  0.0007])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 10.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.8388, -12.8271])
# Base value centered (first 5): tensor([-0.2562, -0.2562, -0.2562,  1.7205,  0.7322])
# Base value centered mean: -1.5125274330785032e-06
# Gamma init for k=14 (first 5): tensor([ 0.0038, -0.0052, -0.0089,  0.0162,  0.0005])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 5.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -11.8388])
# Base value centered (first 5): tensor([-0.2850, -0.2850, -0.2850, -0.2850,  1.6917])
# Base value centered mean: -1.2931823221151717e-06
# Gamma init for k=15 (first 5): tensor([-0.0039,  0.0064,  0.0118, -0.0049,  0.0086])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 29.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.7706, -13.1339])
# Base value centered (first 5): tensor([-0.2428, -0.2428, -0.2428,  1.8021,  0.4388])
# Base value centered mean: -1.9989013253507437e-06
# Gamma init for k=16 (first 5): tensor([ 0.0009,  0.0001,  0.0093,  0.0055, -0.0031])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 17.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.3272, -12.0713])
# Base value centered (first 5): tensor([-0.4228, -0.4228, -0.4228,  3.0656,  1.3214])
# Base value centered mean: -2.227592403869494e-06
# Gamma init for k=17 (first 5): tensor([ 0.0081,  0.0052, -0.0070,  0.0058, -0.0042])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 9.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=18 (first 5): tensor([-0.0111, -0.0044, -0.0045,  0.0119,  0.0053])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 23.0
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.3858])
# Base value centered (first 5): tensor([-0.1519, -0.1519, -0.1519, -0.1519,  0.2779])
# Base value centered mean: -1.1179923831150518e-06
# Gamma init for k=19 (first 5): tensor([-0.0027,  0.0053,  0.0013, -0.0016, -0.0018])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Clusters match exactly: True

# %% [markdown]
# # Gold standard

# %%
from fig5utils import *
disease_names=essentials['disease_names']
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_retrospective_full/enrollment_model_W0.0001_batch_0_10000.pt')
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, Y_100k, E_100k, disease_names, pce_df, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/419753689.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_retrospective_full/enrollment_model_W0.0001_batch_0_10000.pt')
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.863 (0.827-0.897) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.711 (0.669-0.752) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.708 (0.589-0.813) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.569 (0.462-0.667) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.668 (0.608-0.732) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.516 (0.419-0.629) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.692 (0.595-0.788) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.612 (0.514-0.699) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.718 (0.662-0.759) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.618 (0.534-0.719) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.666 (0.604-0.712) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.742 (0.633-0.847) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.805 (0.766-0.849) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.801 (0.718-0.873) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.747 (0.575-0.888) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.627 (0.376-0.857) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.565 (0.493-0.638) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.757 (0.720-0.789) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.699 (0.655-0.746) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.695 (0.544-0.796) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.719 (0.626-0.792) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.615 (0.465-0.742) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.902 (0.854-0.951) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.736 (0.605-0.867) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.756 (0.730-0.788) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.632 (0.455-0.813) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.667 (0.493-0.808) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.757 (0.715-0.799) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.863 (0.827-0.897)       136        5.4
# Diabetes             0.711 (0.669-0.752)       137        5.4
# Atrial_Fib           0.708 (0.589-0.813)       29         1.1
# CKD                  0.569 (0.462-0.667)       33         1.3
# All_Cancers          0.668 (0.608-0.732)       94         3.7
# Stroke               0.516 (0.419-0.629)       30         1.2
# Heart_Failure        0.692 (0.595-0.788)       32         1.3
# Pneumonia            0.612 (0.514-0.699)       70         2.8
# COPD                 0.718 (0.662-0.759)       81         3.2
# Osteoporosis         0.618 (0.534-0.719)       41         1.6
# Anemia               0.666 (0.604-0.712)       154        6.1
# Colorectal_Cancer    0.742 (0.633-0.847)       25         1.0
# Breast_Cancer        0.805 (0.766-0.849)       65         4.6
# Prostate_Cancer      0.801 (0.718-0.873)       35         3.1
# Lung_Cancer          0.747 (0.575-0.888)       9          0.4
# Bladder_Cancer       0.627 (0.376-0.857)       9          0.4
# Secondary_Cancer     0.565 (0.493-0.638)       71         2.8
# Depression           0.757 (0.720-0.789)       192        7.6
# Anxiety              0.699 (0.655-0.746)       136        5.4
# Bipolar_Disorder     0.695 (0.544-0.796)       17         0.7
# Rheumatoid_Arthritis 0.719 (0.626-0.792)       36         1.4
# Psoriasis            0.615 (0.465-0.742)       24         0.9
# Ulcerative_Colitis   0.902 (0.854-0.951)       22         0.9
# Crohns_Disease       0.736 (0.605-0.867)       20         0.8
# Asthma               0.756 (0.730-0.788)       218        8.8
# Parkinsons           0.632 (0.455-0.813)       2          0.1
# Multiple_Sclerosis   0.667 (0.493-0.808)       11         0.4
# Thyroid_Disorders    0.757 (0.715-0.799)       145        5.7
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.8629968203497616,
#   'n_events': 136,
#   'event_rate': 5.352223534041716,
#   'ci_lower': 0.82711792821039,
#   'ci_upper': 0.8972171076423406},
#  'Diabetes': {'auc': 0.7110503175971921,
#   'n_events': 137,
#   'event_rate': 5.3915781188508465,
#   'ci_lower': 0.6686920009741962,
#   'ci_upper': 0.752473153708459},
#  'Atrial_Fib': {'auc': 0.7078815765908496,
#   'n_events': 29,
#   'event_rate': 1.1453396524486572,
#   'ci_lower': 0.5888396699054479,
#   'ci_upper': 0.8130167874025415},
#  'CKD': {'auc': 0.5687496979363008,
#   'n_events': 33,
#   'event_rate': 1.2987012987012987,
#   'ci_lower': 0.46240219454795806,
#   'ci_upper': 0.6672354811645976},
#  'All_Cancers': {'auc': 0.6684998565329671,
#   'n_events': 94,
#   'event_rate': 3.699330972058245,
#   'ci_lower': 0.6075515125374636,
#   'ci_upper': 0.7324619478085796},
#  'Stroke': {'auc': 0.5155847603876278,
#   'n_events': 30,
#   'event_rate': 1.1806375442739079,
#   'ci_lower': 0.41902427383886715,
#   'ci_upper': 0.629165494061507},
#  'Heart_Failure': {'auc': 0.6918094858509366,
#   'n_events': 32,
#   'event_rate': 1.2593467138921683,
#   'ci_lower': 0.5950207357396111,
#   'ci_upper': 0.7875320110093467},
#  'Pneumonia': {'auc': 0.6119962999364051,
#   'n_events': 70,
#   'event_rate': 2.7548209366391188,
#   'ci_lower': 0.5135907319639428,
#   'ci_upper': 0.6989835017835989},
#  'COPD': {'auc': 0.717745658938071,
#   'n_events': 81,
#   'event_rate': 3.187721369539551,
#   'ci_lower': 0.6619620470813589,
#   'ci_upper': 0.7593275132975758},
#  'Osteoporosis': {'auc': 0.6177397788383646,
#   'n_events': 41,
#   'event_rate': 1.6141732283464567,
#   'ci_lower': 0.5344942716077624,
#   'ci_upper': 0.7191023673460191},
#  'Anemia': {'auc': 0.6663637995854167,
#   'n_events': 154,
#   'event_rate': 6.0606060606060606,
#   'ci_lower': 0.6041683344277203,
#   'ci_upper': 0.712068954043021},
#  'Colorectal_Cancer': {'auc': 0.7419713831478537,
#   'n_events': 25,
#   'event_rate': 0.9838646202282565,
#   'ci_lower': 0.6327114597737762,
#   'ci_upper': 0.8466549280372808},
#  'Breast_Cancer': {'auc': 0.8052701225476095,
#   'n_events': 65,
#   'event_rate': 4.636233951497861,
#   'ci_lower': 0.7663418394125964,
#   'ci_upper': 0.8487851627025423},
#  'Prostate_Cancer': {'auc': 0.8014492753623188,
#   'n_events': 35,
#   'event_rate': 3.0728709394205445,
#   'ci_lower': 0.7182996750920174,
#   'ci_upper': 0.872983727458821},
#  'Lung_Cancer': {'auc': 0.7473670352817272,
#   'n_events': 9,
#   'event_rate': 0.3541912632821724,
#   'ci_lower': 0.5748432995794899,
#   'ci_upper': 0.8884715924047987},
#  'Bladder_Cancer': {'auc': 0.6266297905966022,
#   'n_events': 9,
#   'event_rate': 0.3543307086614173,
#   'ci_lower': 0.3756276043795859,
#   'ci_upper': 0.8573904378840432},
#  'Secondary_Cancer': {'auc': 0.564891372526658,
#   'n_events': 71,
#   'event_rate': 2.7941755214482487,
#   'ci_lower': 0.4933222490931077,
#   'ci_upper': 0.6377770166259801},
#  'Depression': {'auc': 0.7573105325571368,
#   'n_events': 192,
#   'event_rate': 7.646356033452808,
#   'ci_lower': 0.7195104174318905,
#   'ci_upper': 0.7890458022476431},
#  'Anxiety': {'auc': 0.6992493872549019,
#   'n_events': 136,
#   'event_rate': 5.3627760252365935,
#   'ci_lower': 0.6551417859376392,
#   'ci_upper': 0.7456638597607267},
#  'Bipolar_Disorder': {'auc': 0.6953506293347033,
#   'n_events': 17,
#   'event_rate': 0.6703470031545742,
#   'ci_lower': 0.543635462118207,
#   'ci_upper': 0.7956671329669386},
#  'Rheumatoid_Arthritis': {'auc': 0.718591793232081,
#   'n_events': 36,
#   'event_rate': 1.4184397163120568,
#   'ci_lower': 0.6259145628029203,
#   'ci_upper': 0.7921850346389554},
#  'Psoriasis': {'auc': 0.6148277004638835,
#   'n_events': 24,
#   'event_rate': 0.9452540370224497,
#   'ci_lower': 0.4650486136396648,
#   'ci_upper': 0.7415158441269706},
#  'Ulcerative_Colitis': {'auc': 0.9024160197344555,
#   'n_events': 22,
#   'event_rate': 0.870253164556962,
#   'ci_lower': 0.8540267295047042,
#   'ci_upper': 0.950960479771359},
#  'Crohns_Disease': {'auc': 0.7360525268603262,
#   'n_events': 20,
#   'event_rate': 0.7895775759968418,
#   'ci_lower': 0.6048630660832046,
#   'ci_upper': 0.8670757763701951},
#  'Asthma': {'auc': 0.756361778855938,
#   'n_events': 218,
#   'event_rate': 8.818770226537216,
#   'ci_lower': 0.7297473913589954,
#   'ci_upper': 0.7882446403328591},
#  'Parkinsons': {'auc': 0.6317447814100039,
#   'n_events': 2,
#   'event_rate': 0.07870916961826052,
#   'ci_lower': 0.45499654213172147,
#   'ci_upper': 0.8133070866141732},
#  'Multiple_Sclerosis': {'auc': 0.6673627362736274,
#   'n_events': 11,
#   'event_rate': 0.4337539432176656,
#   'ci_lower': 0.4930630324868623,
#   'ci_upper': 0.808429333216602},
#  'Thyroid_Disorders': {'auc': 0.7574232916930518,
#   'n_events': 145,
#   'event_rate': 5.706414797323888,
#   'ci_lower': 0.7146342624712206,
#   'ci_upper': 0.7985407209310552}}

# %% [markdown]
# # fixed phi from enrollment

# %%
from fig5utils import *
disease_names=essentials['disease_names']
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs/output/model_enroll_fixedphi_sex_0_10000.pt')
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, Y_100k, E_100k, disease_names, pce_df, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/1696711840.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs/output/model_enroll_fixedphi_sex_0_10000.pt')
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.517-0.625) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.547 (0.502-0.591) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.531 (0.445-0.627) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.585 (0.492-0.694) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.575 (0.514-0.621) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.516 (0.391-0.616) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.592 (0.484-0.709) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.531 (0.469-0.602) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.619 (0.561-0.673) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.485 (0.396-0.587) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.520 (0.478-0.564) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.482 (0.381-0.598) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.543 (0.480-0.590) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.611 (0.528-0.695) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.682 (0.542-0.796) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.476 (0.324-0.628) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.521 (0.468-0.589) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.499 (0.459-0.538) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.507 (0.451-0.557) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.437 (0.291-0.568) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.535 (0.447-0.622) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.453 (0.352-0.591) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.410 (0.271-0.515) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.457 (0.309-0.593) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.499 (0.457-0.535) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.545 (0.502-0.595) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.407 (0.242-0.530) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.472-0.578) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.579 (0.517-0.625)       136        5.4
# Diabetes             0.547 (0.502-0.591)       137        5.4
# Atrial_Fib           0.531 (0.445-0.627)       29         1.1
# CKD                  0.585 (0.492-0.694)       33         1.3
# All_Cancers          0.575 (0.514-0.621)       94         3.7
# Stroke               0.516 (0.391-0.616)       30         1.2
# Heart_Failure        0.592 (0.484-0.709)       32         1.3
# Pneumonia            0.531 (0.469-0.602)       70         2.8
# COPD                 0.619 (0.561-0.673)       81         3.2
# Osteoporosis         0.485 (0.396-0.587)       41         1.6
# Anemia               0.520 (0.478-0.564)       154        6.1
# Colorectal_Cancer    0.482 (0.381-0.598)       25         1.0
# Breast_Cancer        0.543 (0.480-0.590)       65         4.6
# Prostate_Cancer      0.611 (0.528-0.695)       35         3.1
# Lung_Cancer          0.682 (0.542-0.796)       9          0.4
# Bladder_Cancer       0.476 (0.324-0.628)       9          0.4
# Secondary_Cancer     0.521 (0.468-0.589)       71         2.8
# Depression           0.499 (0.459-0.538)       192        7.6
# Anxiety              0.507 (0.451-0.557)       136        5.4
# Bipolar_Disorder     0.437 (0.291-0.568)       17         0.7
# Rheumatoid_Arthritis 0.535 (0.447-0.622)       36         1.4
# Psoriasis            0.453 (0.352-0.591)       24         0.9
# Ulcerative_Colitis   0.410 (0.271-0.515)       22         0.9
# Crohns_Disease       0.457 (0.309-0.593)       20         0.8
# Asthma               0.499 (0.457-0.535)       218        8.8
# Parkinsons           0.545 (0.502-0.595)       2          0.1
# Multiple_Sclerosis   0.407 (0.242-0.530)       11         0.4
# Thyroid_Disorders    0.526 (0.472-0.578)       145        5.7
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.5793873058578941,
#   'n_events': 136,
#   'event_rate': 5.352223534041716,
#   'ci_lower': 0.5166386911472844,
#   'ci_upper': 0.6248502541121312},
#  'Diabetes': {'auc': 0.5468410313710725,
#   'n_events': 137,
#   'event_rate': 5.3915781188508465,
#   'ci_lower': 0.5017127233711027,
#   'ci_upper': 0.5905136959868277},
#  'Atrial_Fib': {'auc': 0.5310317274443082,
#   'n_events': 29,
#   'event_rate': 1.1453396524486572,
#   'ci_lower': 0.4448442792993816,
#   'ci_upper': 0.6273670890723894},
#  'CKD': {'auc': 0.5852907061041033,
#   'n_events': 33,
#   'event_rate': 1.2987012987012987,
#   'ci_lower': 0.49246689710073993,
#   'ci_upper': 0.6936970406569458},
#  'All_Cancers': {'auc': 0.5753506247337166,
#   'n_events': 94,
#   'event_rate': 3.699330972058245,
#   'ci_lower': 0.514313517156167,
#   'ci_upper': 0.6212059367174722},
#  'Stroke': {'auc': 0.5163414310367715,
#   'n_events': 30,
#   'event_rate': 1.1806375442739079,
#   'ci_lower': 0.3910944088711865,
#   'ci_upper': 0.6155426367230397},
#  'Heart_Failure': {'auc': 0.5917073535273017,
#   'n_events': 32,
#   'event_rate': 1.2593467138921683,
#   'ci_lower': 0.4835675743145695,
#   'ci_upper': 0.7093197591662824},
#  'Pneumonia': {'auc': 0.5311614730878187,
#   'n_events': 70,
#   'event_rate': 2.7548209366391188,
#   'ci_lower': 0.4694648290472488,
#   'ci_upper': 0.6021827225505008},
#  'COPD': {'auc': 0.61850848138111,
#   'n_events': 81,
#   'event_rate': 3.187721369539551,
#   'ci_lower': 0.5606462340027646,
#   'ci_upper': 0.6734197707776577},
#  'Osteoporosis': {'auc': 0.48482807757249247,
#   'n_events': 41,
#   'event_rate': 1.6141732283464567,
#   'ci_lower': 0.39620398118546446,
#   'ci_upper': 0.5867171147422938},
#  'Anemia': {'auc': 0.519850488849232,
#   'n_events': 154,
#   'event_rate': 6.0606060606060606,
#   'ci_lower': 0.4780340746121741,
#   'ci_upper': 0.5643642319674305},
#  'Colorectal_Cancer': {'auc': 0.48240063593004767,
#   'n_events': 25,
#   'event_rate': 0.9838646202282565,
#   'ci_lower': 0.38135135135135134,
#   'ci_upper': 0.5975971918184071},
#  'Breast_Cancer': {'auc': 0.5425004315056671,
#   'n_events': 65,
#   'event_rate': 4.636233951497861,
#   'ci_lower': 0.4800552852752456,
#   'ci_upper': 0.5899074034360501},
#  'Prostate_Cancer': {'auc': 0.6113354037267081,
#   'n_events': 35,
#   'event_rate': 3.0728709394205445,
#   'ci_lower': 0.5277275959313864,
#   'ci_upper': 0.6950800506772365},
#  'Lung_Cancer': {'auc': 0.6823766894856942,
#   'n_events': 9,
#   'event_rate': 0.3541912632821724,
#   'ci_lower': 0.5420658166062627,
#   'ci_upper': 0.7960619825247617},
#  'Bladder_Cancer': {'auc': 0.4759208042495281,
#   'n_events': 9,
#   'event_rate': 0.3543307086614173,
#   'ci_lower': 0.3240817628047371,
#   'ci_upper': 0.628135117225168},
#  'Secondary_Cancer': {'auc': 0.5213320408279637,
#   'n_events': 71,
#   'event_rate': 2.7941755214482487,
#   'ci_lower': 0.46827744411718725,
#   'ci_upper': 0.5889877051136437},
#  'Depression': {'auc': 0.49873104427195625,
#   'n_events': 192,
#   'event_rate': 7.646356033452808,
#   'ci_lower': 0.4585920349046526,
#   'ci_upper': 0.5377725134457627},
#  'Anxiety': {'auc': 0.5067616421568627,
#   'n_events': 136,
#   'event_rate': 5.3627760252365935,
#   'ci_lower': 0.4509536348514138,
#   'ci_upper': 0.5566037532497272},
#  'Bipolar_Disorder': {'auc': 0.43677463045559634,
#   'n_events': 17,
#   'event_rate': 0.6703470031545742,
#   'ci_lower': 0.29075728833787423,
#   'ci_upper': 0.5677059863366545},
#  'Rheumatoid_Arthritis': {'auc': 0.5354494182431832,
#   'n_events': 36,
#   'event_rate': 1.4184397163120568,
#   'ci_lower': 0.44657263358989163,
#   'ci_upper': 0.6224262861882273},
#  'Psoriasis': {'auc': 0.4534625579854208,
#   'n_events': 24,
#   'event_rate': 0.9452540370224497,
#   'ci_lower': 0.3515868393275061,
#   'ci_upper': 0.5911534024514276},
#  'Ulcerative_Colitis': {'auc': 0.40990713197417106,
#   'n_events': 22,
#   'event_rate': 0.870253164556962,
#   'ci_lower': 0.2705979446627136,
#   'ci_upper': 0.515459234049121},
#  'Crohns_Disease': {'auc': 0.4568643056108237,
#   'n_events': 20,
#   'event_rate': 0.7895775759968418,
#   'ci_lower': 0.30937550771840383,
#   'ci_upper': 0.5931098620614749},
#  'Asthma': {'auc': 0.4985794876386933,
#   'n_events': 218,
#   'event_rate': 8.818770226537216,
#   'ci_lower': 0.45704065079564987,
#   'ci_upper': 0.5353575392083202},
#  'Parkinsons': {'auc': 0.5452934226073258,
#   'n_events': 2,
#   'event_rate': 0.07870916961826052,
#   'ci_lower': 0.501988188976378,
#   'ci_upper': 0.5948326771653544},
#  'Multiple_Sclerosis': {'auc': 0.4069126912691269,
#   'n_events': 11,
#   'event_rate': 0.4337539432176656,
#   'ci_lower': 0.24212944642307527,
#   'ci_upper': 0.5301948865840337},
#  'Thyroid_Disorders': {'auc': 0.5255022739047839,
#   'n_events': 145,
#   'event_rate': 5.706414797323888,
#   'ci_lower': 0.47181956405590375,
#   'ci_upper': 0.5778472033306071}}

# %%
from utils import *
results = evaluate_major_diseases_wsex_with_bootstrap(
    model=model,
    Y_100k=Y_100k,
    E_100k=E_100k,
    disease_names=disease_names,
    pce_df=pce_df,
    n_bootstraps=20,
    follow_up_duration_years=10,
)
# Out:
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.683 (0.667-0.692) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.669, Events = 273/5409
#    Male: AUC = 0.685, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.707, Events = 8/37
#    Breast_Cancer: AUC = 0.549, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.613 (0.583-0.631) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.604, Events = 264/5409
#    Male: AUC = 0.617, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.701 (0.671-0.719) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.707, Events = 197/5372
#    Male: AUC = 0.706, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.710 (0.689-0.737) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.733, Events = 101/5409
#    Male: AUC = 0.687, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.676 (0.659-0.691) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.671, Events = 134/5409
#    Male: AUC = 0.672, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.652 (0.612-0.690) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.626, Events = 64/5409
#    Male: AUC = 0.678, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.699 (0.670-0.728) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.716, Events = 83/5409
#    Male: AUC = 0.683, Events = 122/4591
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.681 (0.659-0.704) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.682, Events = 135/5409
#    Male: AUC = 0.676, Events = 200/4591
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.647 (0.628-0.662) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.674, Events = 176/5409
#    Male: AUC = 0.622, Events = 218/4591
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.665 (0.633-0.679) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.674, Events = 128/5379
#    Male: AUC = 0.660, Events = 90/4582
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.592 (0.578-0.612) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.549, Events = 280/5409
#    Male: AUC = 0.640, Events = 243/4591
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.661 (0.610-0.704) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.635, Events = 56/5409
#    Male: AUC = 0.689, Events = 49/4591
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.580 (0.546-0.616) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.677 (0.643-0.696) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.4%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.689 (0.642-0.737) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.693, Events = 48/5406
#    Male: AUC = 0.681, Events = 27/4586
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.726 (0.688-0.779) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.609, Events = 24/5399
#    Male: AUC = 0.841, Events = 25/4577
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.604 (0.589-0.635) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.611, Events = 147/5409
#    Male: AUC = 0.595, Events = 129/4591
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.470 (0.446-0.483) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.0%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.469, Events = 210/5351
#    Male: AUC = 0.482, Events = 191/4561
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.507 (0.464-0.536) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.517, Events = 130/5391
#    Male: AUC = 0.499, Events = 110/4584
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.406 (0.327-0.489) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.443, Events = 14/5399
#    Male: AUC = 0.378, Events = 19/4585
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.596 (0.547-0.632) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.592, Events = 62/5381
#    Male: AUC = 0.595, Events = 60/4582
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.416 (0.366-0.459) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.386, Events = 15/5405
#    Male: AUC = 0.435, Events = 25/4576
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.591 (0.533-0.680) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.575, Events = 31/5378
#    Male: AUC = 0.624, Events = 19/4569
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.510 (0.404-0.615) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.532, Events = 20/5388
#    Male: AUC = 0.471, Events = 11/4579
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.497 (0.477-0.528) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.1%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.499, Events = 321/5214
#    Male: AUC = 0.531, Events = 264/4473
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.747 (0.670-0.826) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.800, Events = 21/5407
#    Male: AUC = 0.701, Events = 25/4590
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.533 (0.423-0.659) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.514, Events = 13/5394
#    Male: AUC = 0.566, Events = 8/4585
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.563 (0.544-0.592) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.567, Events = 385/5409
#    Male: AUC = 0.561, Events = 94/4591
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.683 (0.667-0.692)       831        8.3
# Diabetes             0.613 (0.583-0.631)       581        5.8
# Atrial_Fib           0.701 (0.671-0.719)       376        3.8
# CKD                  0.710 (0.689-0.737)       207        2.1
# All_Cancers          0.676 (0.659-0.691)       480        4.8
# Stroke               0.652 (0.612-0.690)       129        1.3
# Heart_Failure        0.699 (0.670-0.728)       205        2.1
# Pneumonia            0.681 (0.659-0.704)       335        3.4
# COPD                 0.647 (0.628-0.662)       394        3.9
# Osteoporosis         0.665 (0.633-0.679)       219        2.2
# Anemia               0.592 (0.578-0.612)       523        5.2
# Colorectal_Cancer    0.661 (0.610-0.704)       105        1.1
# Breast_Cancer        0.580 (0.546-0.616)       214        4.0
# Prostate_Cancer      0.677 (0.643-0.696)       204        4.4
# Lung_Cancer          0.689 (0.642-0.737)       75         0.8
# Bladder_Cancer       0.726 (0.688-0.779)       49         0.5
# Secondary_Cancer     0.604 (0.589-0.635)       276        2.8
# Depression           0.470 (0.446-0.483)       405        4.0
# Anxiety              0.507 (0.464-0.536)       241        2.4
# Bipolar_Disorder     0.406 (0.327-0.489)       34         0.3
# Rheumatoid_Arthritis 0.596 (0.547-0.632)       123        1.2
# Psoriasis            0.416 (0.366-0.459)       40         0.4
# Ulcerative_Colitis   0.591 (0.533-0.680)       50         0.5
# Crohns_Disease       0.510 (0.404-0.615)       31         0.3
# Asthma               0.497 (0.477-0.528)       606        6.1
# Parkinsons           0.747 (0.670-0.826)       46         0.5
# Multiple_Sclerosis   0.533 (0.423-0.659)       21         0.2
# Thyroid_Disorders    0.563 (0.544-0.592)       479        4.8
# --------------------------------------------------------------------------------

# %% [markdown]
# # joint 10 year

# %%
from fig5utils import *
disease_names=essentials['disease_names']
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_0_10000.pt')
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, Y_100k, E_100k, disease_names, pce_df, n_bootstraps=100, follow_up_duration_years=20, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/4141852495.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_0_10000.pt')
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.717 (0.697-0.738) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 578 (9.0%) (from 6424 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.641 (0.617-0.665) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 464 (7.2%) (from 6424 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.577 (0.532-0.618) (calculated on 6371 individuals)
# Events (10-Year in Eval Cohort): 137 (2.2%) (from 6371 individuals)
# Excluded 53 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.654 (0.620-0.693) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 173 (2.7%) (from 6424 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.647 (0.625-0.677) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 396 (6.2%) (from 6424 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.610 (0.559-0.661) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 119 (1.9%) (from 6424 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.642 (0.596-0.676) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 153 (2.4%) (from 6424 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.598 (0.565-0.635) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 263 (4.1%) (from 6424 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.622 (0.603-0.648) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 325 (5.1%) (from 6424 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.654 (0.619-0.688) (calculated on 6405 individuals)
# Events (10-Year in Eval Cohort): 208 (3.2%) (from 6405 individuals)
# Excluded 19 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.556 (0.532-0.582) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 471 (7.3%) (from 6424 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.563 (0.504-0.627) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 96 (1.5%) (from 6424 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.491 (0.447-0.536) (calculated on 3573 individuals)
# Events (10-Year in Eval Cohort): 195 (5.5%) (from 3573 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.679 (0.644-0.724) (calculated on 2840 individuals)
# Events (10-Year in Eval Cohort): 169 (6.0%) (from 2840 individuals)
# Excluded 11 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.670 (0.626-0.711) (calculated on 6420 individuals)
# Events (10-Year in Eval Cohort): 61 (1.0%) (from 6420 individuals)
# Excluded 4 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.617 (0.517-0.696) (calculated on 6415 individuals)
# Events (10-Year in Eval Cohort): 33 (0.5%) (from 6415 individuals)
# Excluded 9 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.602 (0.565-0.639) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 256 (4.0%) (from 6424 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.493 (0.466-0.521) (calculated on 6358 individuals)
# Events (10-Year in Eval Cohort): 439 (6.9%) (from 6358 individuals)
# Excluded 66 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.516 (0.486-0.553) (calculated on 6409 individuals)
# Events (10-Year in Eval Cohort): 342 (5.3%) (from 6409 individuals)
# Excluded 15 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.565 (0.481-0.625) (calculated on 6414 individuals)
# Events (10-Year in Eval Cohort): 30 (0.5%) (from 6414 individuals)
# Excluded 10 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.584 (0.530-0.631) (calculated on 6401 individuals)
# Events (10-Year in Eval Cohort): 112 (1.7%) (from 6401 individuals)
# Excluded 23 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.474 (0.400-0.539) (calculated on 6413 individuals)
# Events (10-Year in Eval Cohort): 59 (0.9%) (from 6413 individuals)
# Excluded 11 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.568 (0.484-0.640) (calculated on 6395 individuals)
# Events (10-Year in Eval Cohort): 52 (0.8%) (from 6395 individuals)
# Excluded 29 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.581 (0.471-0.666) (calculated on 6405 individuals)
# Events (10-Year in Eval Cohort): 33 (0.5%) (from 6405 individuals)
# Excluded 19 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.533 (0.506-0.558) (calculated on 6239 individuals)
# Events (10-Year in Eval Cohort): 538 (8.6%) (from 6239 individuals)
# Excluded 185 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.741 (0.646-0.832) (calculated on 6422 individuals)
# Events (10-Year in Eval Cohort): 25 (0.4%) (from 6422 individuals)
# Excluded 2 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.611 (0.433-0.779) (calculated on 6409 individuals)
# Events (10-Year in Eval Cohort): 17 (0.3%) (from 6409 individuals)
# Excluded 15 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.602 (0.575-0.634) (calculated on 6424 individuals)
# Events (10-Year in Eval Cohort): 407 (6.3%) (from 6424 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.717 (0.697-0.738)       578        9.0
# Diabetes             0.641 (0.617-0.665)       464        7.2
# Atrial_Fib           0.577 (0.532-0.618)       137        2.2
# CKD                  0.654 (0.620-0.693)       173        2.7
# All_Cancers          0.647 (0.625-0.677)       396        6.2
# Stroke               0.610 (0.559-0.661)       119        1.9
# Heart_Failure        0.642 (0.596-0.676)       153        2.4
# Pneumonia            0.598 (0.565-0.635)       263        4.1
# COPD                 0.622 (0.603-0.648)       325        5.1
# Osteoporosis         0.654 (0.619-0.688)       208        3.2
# Anemia               0.556 (0.532-0.582)       471        7.3
# Colorectal_Cancer    0.563 (0.504-0.627)       96         1.5
# Breast_Cancer        0.491 (0.447-0.536)       195        5.5
# Prostate_Cancer      0.679 (0.644-0.724)       169        6.0
# Lung_Cancer          0.670 (0.626-0.711)       61         1.0
# Bladder_Cancer       0.617 (0.517-0.696)       33         0.5
# Secondary_Cancer     0.602 (0.565-0.639)       256        4.0
# Depression           0.493 (0.466-0.521)       439        6.9
# Anxiety              0.516 (0.486-0.553)       342        5.3
# Bipolar_Disorder     0.565 (0.481-0.625)       30         0.5
# Rheumatoid_Arthritis 0.584 (0.530-0.631)       112        1.7
# Psoriasis            0.474 (0.400-0.539)       59         0.9
# Ulcerative_Colitis   0.568 (0.484-0.640)       52         0.8
# Crohns_Disease       0.581 (0.471-0.666)       33         0.5
# Asthma               0.533 (0.506-0.558)       538        8.6
# Parkinsons           0.741 (0.646-0.832)       25         0.4
# Multiple_Sclerosis   0.611 (0.433-0.779)       17         0.3
# Thyroid_Disorders    0.602 (0.575-0.634)       407        6.3
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.7168187634877661,
#   'n_events': 578,
#   'event_rate': 8.997509339975093,
#   'ci_lower': 0.6971406970520175,
#   'ci_upper': 0.7383857218331997},
#  'Diabetes': {'auc': 0.6413323015505671,
#   'n_events': 464,
#   'event_rate': 7.22291407222914,
#   'ci_lower': 0.6171004831653426,
#   'ci_upper': 0.6653732160826513},
#  'Atrial_Fib': {'auc': 0.5767114177257282,
#   'n_events': 137,
#   'event_rate': 2.1503688588918535,
#   'ci_lower': 0.531748768462853,
#   'ci_upper': 0.6182185069180305},
#  'CKD': {'auc': 0.6536924034351035,
#   'n_events': 173,
#   'event_rate': 2.6930261519302614,
#   'ci_lower': 0.6199344402579027,
#   'ci_upper': 0.6934320493373844},
#  'All_Cancers': {'auc': 0.6465882279999731,
#   'n_events': 396,
#   'event_rate': 6.164383561643835,
#   'ci_lower': 0.6249466566810339,
#   'ci_upper': 0.6765189587212519},
#  'Stroke': {'auc': 0.6098654529218508,
#   'n_events': 119,
#   'event_rate': 1.852428393524284,
#   'ci_lower': 0.5586284446405901,
#   'ci_upper': 0.6608779495477444},
#  'Heart_Failure': {'auc': 0.641948673372501,
#   'n_events': 153,
#   'event_rate': 2.3816936488169365,
#   'ci_lower': 0.5956727870018179,
#   'ci_upper': 0.6755955176773186},
#  'Pneumonia': {'auc': 0.5976857986241184,
#   'n_events': 263,
#   'event_rate': 4.094022415940223,
#   'ci_lower': 0.5652257541537142,
#   'ci_upper': 0.6350974755004323},
#  'COPD': {'auc': 0.6223345567369178,
#   'n_events': 325,
#   'event_rate': 5.059153175591532,
#   'ci_lower': 0.6028722072858365,
#   'ci_upper': 0.6475507282926413},
#  'Osteoporosis': {'auc': 0.6544598192673874,
#   'n_events': 208,
#   'event_rate': 3.247462919594067,
#   'ci_lower': 0.6189964625868913,
#   'ci_upper': 0.6879334720934951},
#  'Anemia': {'auc': 0.5556533967601127,
#   'n_events': 471,
#   'event_rate': 7.331880448318804,
#   'ci_lower': 0.5322978964437485,
#   'ci_upper': 0.5821384268701243},
#  'Colorectal_Cancer': {'auc': 0.5634201827855035,
#   'n_events': 96,
#   'event_rate': 1.4943960149439601,
#   'ci_lower': 0.5040009311428466,
#   'ci_upper': 0.6270017986253},
#  'Breast_Cancer': {'auc': 0.4910203276100256,
#   'n_events': 195,
#   'event_rate': 5.4575986565911,
#   'ci_lower': 0.4470520518404732,
#   'ci_upper': 0.5358383465481097},
#  'Prostate_Cancer': {'auc': 0.678543816003137,
#   'n_events': 169,
#   'event_rate': 5.950704225352112,
#   'ci_lower': 0.6441873974795163,
#   'ci_upper': 0.723938196383794},
#  'Lung_Cancer': {'auc': 0.6697465061781547,
#   'n_events': 61,
#   'event_rate': 0.9501557632398754,
#   'ci_lower': 0.626068832078362,
#   'ci_upper': 0.7111352354539581},
#  'Bladder_Cancer': {'auc': 0.6165161486377406,
#   'n_events': 33,
#   'event_rate': 0.514419329696025,
#   'ci_lower': 0.5167305436036458,
#   'ci_upper': 0.6961615449718819},
#  'Secondary_Cancer': {'auc': 0.6020691472114138,
#   'n_events': 256,
#   'event_rate': 3.9850560398505603,
#   'ci_lower': 0.5652063454174023,
#   'ci_upper': 0.6389604516806792},
#  'Depression': {'auc': 0.49251570460903293,
#   'n_events': 439,
#   'event_rate': 6.904687008493236,
#   'ci_lower': 0.46646331537768887,
#   'ci_upper': 0.5207942068328443},
#  'Anxiety': {'auc': 0.515726916874627,
#   'n_events': 342,
#   'event_rate': 5.336245904197223,
#   'ci_lower': 0.4864122712732343,
#   'ci_upper': 0.5529111508709751},
#  'Bipolar_Disorder': {'auc': 0.5646668755221387,
#   'n_events': 30,
#   'event_rate': 0.4677268475210477,
#   'ci_lower': 0.4806981997500338,
#   'ci_upper': 0.6245834434267644},
#  'Rheumatoid_Arthritis': {'auc': 0.5838382777184653,
#   'n_events': 112,
#   'event_rate': 1.7497266052179348,
#   'ci_lower': 0.5295947366253901,
#   'ci_upper': 0.6309889780812885},
#  'Psoriasis': {'auc': 0.4743708754127922,
#   'n_events': 59,
#   'event_rate': 0.9200062373304226,
#   'ci_lower': 0.4001269196220814,
#   'ci_upper': 0.5389508949350944},
#  'Ulcerative_Colitis': {'auc': 0.5683430553365916,
#   'n_events': 52,
#   'event_rate': 0.8131352619233777,
#   'ci_lower': 0.4840608900882637,
#   'ci_upper': 0.6395094108563817},
#  'Crohns_Disease': {'auc': 0.5805798093933687,
#   'n_events': 33,
#   'event_rate': 0.5152224824355972,
#   'ci_lower': 0.47068229451468213,
#   'ci_upper': 0.665946013326305},
#  'Asthma': {'auc': 0.5333917156645707,
#   'n_events': 538,
#   'event_rate': 8.623176791152428,
#   'ci_lower': 0.505789304509233,
#   'ci_upper': 0.5580779279983723},
#  'Parkinsons': {'auc': 0.7406784430201657,
#   'n_events': 25,
#   'event_rate': 0.3892868265337901,
#   'ci_lower': 0.645564821485484,
#   'ci_upper': 0.8322396646715207},
#  'Multiple_Sclerosis': {'auc': 0.6113984392255024,
#   'n_events': 17,
#   'event_rate': 0.2652519893899204,
#   'ci_lower': 0.4325627194881416,
#   'ci_upper': 0.7789601093800657},
#  'Thyroid_Disorders': {'auc': 0.6021366978654664,
#   'n_events': 407,
#   'event_rate': 6.335616438356165,
#   'ci_lower': 0.5750012885961463,
#   'ci_upper': 0.6341103426757558}}

# %%
results = evaluate_major_diseases_wsex_with_bootstrap(
    model=model,
    Y_100k=Y_100k,
    E_100k=E_100k,
    disease_names=disease_names,
    pce_df=pce_df,
    n_bootstraps=20,
    follow_up_duration_years=10,
)
# Out:
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.712 (0.701-0.730) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.666, Events = 273/5409
#    Male: AUC = 0.702, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.677, Events = 8/37
#    Breast_Cancer: AUC = 0.631, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.628 (0.606-0.642) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.618, Events = 264/5409
#    Male: AUC = 0.628, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.684 (0.665-0.707) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.697, Events = 197/5372
#    Male: AUC = 0.683, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.708 (0.675-0.738) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.732, Events = 101/5409
#    Male: AUC = 0.684, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.680 (0.657-0.701) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.672, Events = 134/5409
#    Male: AUC = 0.669, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.654 (0.628-0.705) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.624, Events = 64/5409
#    Male: AUC = 0.683, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.698 (0.673-0.720) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.717, Events = 83/5409
#    Male: AUC = 0.678, Events = 122/4591
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.683 (0.659-0.709) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.684, Events = 135/5409
#    Male: AUC = 0.676, Events = 200/4591
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.646 (0.635-0.672) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.672, Events = 176/5409
#    Male: AUC = 0.620, Events = 218/4591
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.676 (0.642-0.704) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.681, Events = 128/5379
#    Male: AUC = 0.677, Events = 90/4582
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.593 (0.564-0.612) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.549, Events = 280/5409
#    Male: AUC = 0.643, Events = 243/4591
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.654 (0.612-0.692) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.625, Events = 56/5409
#    Male: AUC = 0.688, Events = 49/4591
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.575 (0.557-0.613) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.672 (0.645-0.691) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.4%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.691 (0.641-0.744) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.696, Events = 48/5406
#    Male: AUC = 0.680, Events = 27/4586
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.740 (0.692-0.803) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.628, Events = 24/5399
#    Male: AUC = 0.847, Events = 25/4577
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.607 (0.579-0.636) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.613, Events = 147/5409
#    Male: AUC = 0.600, Events = 129/4591
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.470 (0.441-0.484) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.0%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.474, Events = 210/5351
#    Male: AUC = 0.476, Events = 191/4561
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.506 (0.482-0.541) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.512, Events = 130/5391
#    Male: AUC = 0.504, Events = 110/4584
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.373 (0.302-0.454) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.392, Events = 14/5399
#    Male: AUC = 0.359, Events = 19/4585
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.598 (0.584-0.668) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.597, Events = 62/5381
#    Male: AUC = 0.595, Events = 60/4582
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.432 (0.352-0.513) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.416, Events = 15/5405
#    Male: AUC = 0.443, Events = 25/4576
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.587 (0.518-0.646) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.599, Events = 31/5378
#    Male: AUC = 0.573, Events = 19/4569
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.503 (0.409-0.602) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.548, Events = 20/5388
#    Male: AUC = 0.423, Events = 11/4579
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.511 (0.487-0.530) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.1%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.505, Events = 321/5214
#    Male: AUC = 0.555, Events = 264/4473
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.741 (0.696-0.804) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.787, Events = 21/5407
#    Male: AUC = 0.700, Events = 25/4590
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.524 (0.403-0.593) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.533, Events = 13/5394
#    Male: AUC = 0.515, Events = 8/4585
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.579 (0.554-0.601) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.573, Events = 385/5409
#    Male: AUC = 0.573, Events = 94/4591
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.712 (0.701-0.730)       831        8.3
# Diabetes             0.628 (0.606-0.642)       581        5.8
# Atrial_Fib           0.684 (0.665-0.707)       376        3.8
# CKD                  0.708 (0.675-0.738)       207        2.1
# All_Cancers          0.680 (0.657-0.701)       480        4.8
# Stroke               0.654 (0.628-0.705)       129        1.3
# Heart_Failure        0.698 (0.673-0.720)       205        2.1
# Pneumonia            0.683 (0.659-0.709)       335        3.4
# COPD                 0.646 (0.635-0.672)       394        3.9
# Osteoporosis         0.676 (0.642-0.704)       219        2.2
# Anemia               0.593 (0.564-0.612)       523        5.2
# Colorectal_Cancer    0.654 (0.612-0.692)       105        1.1
# Breast_Cancer        0.575 (0.557-0.613)       214        4.0
# Prostate_Cancer      0.672 (0.645-0.691)       204        4.4
# Lung_Cancer          0.691 (0.641-0.744)       75         0.8
# Bladder_Cancer       0.740 (0.692-0.803)       49         0.5
# Secondary_Cancer     0.607 (0.579-0.636)       276        2.8
# Depression           0.470 (0.441-0.484)       405        4.0
# Anxiety              0.506 (0.482-0.541)       241        2.4
# Bipolar_Disorder     0.373 (0.302-0.454)       34         0.3
# Rheumatoid_Arthritis 0.598 (0.584-0.668)       123        1.2
# Psoriasis            0.432 (0.352-0.513)       40         0.4
# Ulcerative_Colitis   0.587 (0.518-0.646)       50         0.5
# Crohns_Disease       0.503 (0.409-0.602)       31         0.3
# Asthma               0.511 (0.487-0.530)       606        6.1
# Parkinsons           0.741 (0.696-0.804)       46         0.5
# Multiple_Sclerosis   0.524 (0.403-0.593)       21         0.2
# Thyroid_Disorders    0.579 (0.554-0.601)       479        4.8
# --------------------------------------------------------------------------------

# %%
from fig5utils import *
disease_names=essentials['disease_names']
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_0_10000.pt')
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, Y_100k, E_100k, disease_names, pce_df, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/1198762482.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_0_10000.pt')
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.757 (0.720-0.800) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.658 (0.612-0.691) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.611 (0.519-0.714) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.475-0.684) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.605 (0.551-0.655) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.513 (0.429-0.601) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.632 (0.544-0.706) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.544 (0.488-0.610) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.630 (0.577-0.683) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.555 (0.456-0.650) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.537 (0.489-0.572) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.511 (0.409-0.610) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.584 (0.511-0.634) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.719 (0.652-0.795) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.717 (0.534-0.833) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.519 (0.302-0.689) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.532 (0.467-0.608) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.541 (0.495-0.576) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.500 (0.448-0.538) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.381 (0.276-0.490) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.492-0.654) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.453 (0.353-0.577) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.379-0.643) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.412 (0.318-0.522) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.490-0.562) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.617 (0.482-0.754) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.498 (0.359-0.624) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.636 (0.583-0.678) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.757 (0.720-0.800)       136        5.4
# Diabetes             0.658 (0.612-0.691)       137        5.4
# Atrial_Fib           0.611 (0.519-0.714)       29         1.1
# CKD                  0.579 (0.475-0.684)       33         1.3
# All_Cancers          0.605 (0.551-0.655)       94         3.7
# Stroke               0.513 (0.429-0.601)       30         1.2
# Heart_Failure        0.632 (0.544-0.706)       32         1.3
# Pneumonia            0.544 (0.488-0.610)       70         2.8
# COPD                 0.630 (0.577-0.683)       81         3.2
# Osteoporosis         0.555 (0.456-0.650)       41         1.6
# Anemia               0.537 (0.489-0.572)       154        6.1
# Colorectal_Cancer    0.511 (0.409-0.610)       25         1.0
# Breast_Cancer        0.584 (0.511-0.634)       65         4.6
# Prostate_Cancer      0.719 (0.652-0.795)       35         3.1
# Lung_Cancer          0.717 (0.534-0.833)       9          0.4
# Bladder_Cancer       0.519 (0.302-0.689)       9          0.4
# Secondary_Cancer     0.532 (0.467-0.608)       71         2.8
# Depression           0.541 (0.495-0.576)       192        7.6
# Anxiety              0.500 (0.448-0.538)       136        5.4
# Bipolar_Disorder     0.381 (0.276-0.490)       17         0.7
# Rheumatoid_Arthritis 0.579 (0.492-0.654)       36         1.4
# Psoriasis            0.453 (0.353-0.577)       24         0.9
# Ulcerative_Colitis   0.526 (0.379-0.643)       22         0.9
# Crohns_Disease       0.412 (0.318-0.522)       20         0.8
# Asthma               0.526 (0.490-0.562)       218        8.8
# Parkinsons           0.617 (0.482-0.754)       2          0.1
# Multiple_Sclerosis   0.498 (0.359-0.624)       11         0.4
# Thyroid_Disorders    0.636 (0.583-0.678)       145        5.7
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.7571909013085484,
#   'n_events': 136,
#   'event_rate': 5.352223534041716,
#   'ci_lower': 0.7196164322704525,
#   'ci_upper': 0.7998098617765688},
#  'Diabetes': {'auc': 0.6577358903044803,
#   'n_events': 137,
#   'event_rate': 5.3915781188508465,
#   'ci_lower': 0.6123458384182642,
#   'ci_upper': 0.6913152968579725},
#  'Atrial_Fib': {'auc': 0.6105087687877995,
#   'n_events': 29,
#   'event_rate': 1.1453396524486572,
#   'ci_lower': 0.5187187812187812,
#   'ci_upper': 0.7139761218304131},
#  'CKD': {'auc': 0.5791406891885361,
#   'n_events': 33,
#   'event_rate': 1.2987012987012987,
#   'ci_lower': 0.4751873972532305,
#   'ci_upper': 0.6840220317703328},
#  'All_Cancers': {'auc': 0.6049178759923136,
#   'n_events': 94,
#   'event_rate': 3.699330972058245,
#   'ci_lower': 0.5511648593714323,
#   'ci_upper': 0.6551751341489507},
#  'Stroke': {'auc': 0.5132218239745122,
#   'n_events': 30,
#   'event_rate': 1.1806375442739079,
#   'ci_lower': 0.42933241580915205,
#   'ci_upper': 0.601101468305172},
#  'Heart_Failure': {'auc': 0.631925069748904,
#   'n_events': 32,
#   'event_rate': 1.2593467138921683,
#   'ci_lower': 0.5439125711984258,
#   'ci_upper': 0.7059756085315307},
#  'Pneumonia': {'auc': 0.5441001329710354,
#   'n_events': 70,
#   'event_rate': 2.7548209366391188,
#   'ci_lower': 0.4878451733030035,
#   'ci_upper': 0.6103527924664565},
#  'COPD': {'auc': 0.6296898524540799,
#   'n_events': 81,
#   'event_rate': 3.187721369539551,
#   'ci_lower': 0.5772602378801566,
#   'ci_upper': 0.6831250165966297},
#  'Osteoporosis': {'auc': 0.5550512888082061,
#   'n_events': 41,
#   'event_rate': 1.6141732283464567,
#   'ci_lower': 0.45560705201484275,
#   'ci_upper': 0.6502962246352225},
#  'Anemia': {'auc': 0.5365725602424387,
#   'n_events': 154,
#   'event_rate': 6.0606060606060606,
#   'ci_lower': 0.48905685100066615,
#   'ci_upper': 0.5723650923646466},
#  'Colorectal_Cancer': {'auc': 0.5113513513513512,
#   'n_events': 25,
#   'event_rate': 0.9838646202282565,
#   'ci_lower': 0.4094382878466027,
#   'ci_upper': 0.6103016772764482},
#  'Breast_Cancer': {'auc': 0.5837523732811691,
#   'n_events': 65,
#   'event_rate': 4.636233951497861,
#   'ci_lower': 0.5114907271375011,
#   'ci_upper': 0.6337586606512919},
#  'Prostate_Cancer': {'auc': 0.7187888198757765,
#   'n_events': 35,
#   'event_rate': 3.0728709394205445,
#   'ci_lower': 0.6517371055806049,
#   'ci_upper': 0.7953028032330093},
#  'Lung_Cancer': {'auc': 0.717307354748113,
#   'n_events': 9,
#   'event_rate': 0.3541912632821724,
#   'ci_lower': 0.5338825485327803,
#   'ci_upper': 0.8333400268656235},
#  'Bladder_Cancer': {'auc': 0.5192940866587646,
#   'n_events': 9,
#   'event_rate': 0.3543307086614173,
#   'ci_lower': 0.30158950462453105,
#   'ci_upper': 0.6885754549050631},
#  'Secondary_Cancer': {'auc': 0.5324627929520442,
#   'n_events': 71,
#   'event_rate': 2.7941755214482487,
#   'ci_lower': 0.4671808976138426,
#   'ci_upper': 0.6082031651521855},
#  'Depression': {'auc': 0.5406851911743568,
#   'n_events': 192,
#   'event_rate': 7.646356033452808,
#   'ci_lower': 0.4948706468434851,
#   'ci_upper': 0.5757906007686903},
#  'Anxiety': {'auc': 0.4997089460784313,
#   'n_events': 136,
#   'event_rate': 5.3627760252365935,
#   'ci_lower': 0.44823421004872593,
#   'ci_upper': 0.5375172714526006},
#  'Bipolar_Disorder': {'auc': 0.3805198141185811,
#   'n_events': 17,
#   'event_rate': 0.6703470031545742,
#   'ci_lower': 0.27618516000491905,
#   'ci_upper': 0.4900412087912087},
#  'Rheumatoid_Arthritis': {'auc': 0.5790256683542054,
#   'n_events': 36,
#   'event_rate': 1.4184397163120568,
#   'ci_lower': 0.4918552289275704,
#   'ci_upper': 0.6536532702599349},
#  'Psoriasis': {'auc': 0.45278330019880714,
#   'n_events': 24,
#   'event_rate': 0.9452540370224497,
#   'ci_lower': 0.3530242272347536,
#   'ci_upper': 0.5765618185501553},
#  'Ulcerative_Colitis': {'auc': 0.5255205688166582,
#   'n_events': 22,
#   'event_rate': 0.870253164556962,
#   'ci_lower': 0.37947637188409056,
#   'ci_upper': 0.6432574823171363},
#  'Crohns_Disease': {'auc': 0.4121567847194588,
#   'n_events': 20,
#   'event_rate': 0.7895775759968418,
#   'ci_lower': 0.31828126918770544,
#   'ci_upper': 0.5222700469033129},
#  'Asthma': {'auc': 0.5257869801291079,
#   'n_events': 218,
#   'event_rate': 8.818770226537216,
#   'ci_lower': 0.4897048758287963,
#   'ci_upper': 0.561756860602507},
#  'Parkinsons': {'auc': 0.6167782591571485,
#   'n_events': 2,
#   'event_rate': 0.07870916961826052,
#   'ci_lower': 0.482498883558224,
#   'ci_upper': 0.7544574049254481},
#  'Multiple_Sclerosis': {'auc': 0.4977137713771377,
#   'n_events': 11,
#   'event_rate': 0.4337539432176656,
#   'ci_lower': 0.3591448475013772,
#   'ci_upper': 0.624443147839333},
#  'Thyroid_Disorders': {'auc': 0.6363479362155317,
#   'n_events': 145,
#   'event_rate': 5.706414797323888,
#   'ci_lower': 0.5830391562436114,
#   'ci_upper': 0.6783044731817693}}

# %% [markdown]
# ## check joint (we know this was run with enrollment)

# %%
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/DB_backup_5132025941p/enrollment_model_W0.0001_jointphi_sexspecific.pt')
ckpt['G'].shape
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/4135310562.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/DB_backup_5132025941p/enrollment_model_W0.0001_jointphi_sexspecific.pt')
# torch.Size([10000, 37])

# %%
G_with_sex = ckpt['G']  # sex should be numeric (e.g., 0/1)
# N


model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_with_sex.shape[1],
    init_sd_scaler=1e-1,
    G=G_with_sex, 
    Y=Y_100k,
    genetic_scale=1,
    W=0,
    R=0,
    prevalence_t=essentials['prevalence_t'],
    signature_references=signature_refs,  # Only pass signature refs
    healthy_reference=True,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, Y_100k, E_100k, disease_names, pce_df, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/clust_huge_amp.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Cluster Sizes:
# Cluster 0: 14 diseases
# Cluster 1: 7 diseases
# Cluster 2: 21 diseases
# Cluster 3: 15 diseases
# Cluster 4: 17 diseases
# Cluster 5: 16 diseases
# Cluster 6: 57 diseases
# Cluster 7: 18 diseases
# Cluster 8: 13 diseases
# Cluster 9: 11 diseases
# Cluster 10: 18 diseases
# Cluster 11: 12 diseases
# Cluster 12: 26 diseases
# Cluster 13: 7 diseases
# Cluster 14: 9 diseases
# Cluster 15: 8 diseases
# Cluster 16: 7 diseases
# Cluster 17: 11 diseases
# Cluster 18: 6 diseases
# Cluster 19: 55 diseases
#
# Calculating gamma for k=0:
# Number of diseases in cluster: 14
# Base value (first 5): tensor([-13.8155, -13.8155, -13.1095, -12.4036, -12.4036])
# Base value centered (first 5): tensor([-0.3723, -0.3723,  0.3336,  1.0396,  1.0396])
# Base value centered mean: 6.57081614008348e-07
# Gamma init for k=0 (first 5): tensor([ 0.0008,  0.0071,  0.0117,  0.0152, -0.0106])
#
# Calculating gamma for k=1:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.7043, -0.7043, -0.7043, -0.7043, -0.7043])
# Base value centered mean: -2.2621155437718699e-07
# Gamma init for k=1 (first 5): tensor([ 0.0219,  0.0117,  0.0025, -0.0018, -0.0047])
#
# Calculating gamma for k=2:
# Number of diseases in cluster: 21
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.9916, -13.3449])
# Base value centered (first 5): tensor([-0.2393, -0.2393, -0.2393,  2.5846,  0.2313])
# Base value centered mean: -3.040313742985745e-07
# Gamma init for k=2 (first 5): tensor([ 0.0018, -0.0023,  0.0065,  0.0024, -0.0054])
#
# Calculating gamma for k=3:
# Number of diseases in cluster: 15
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1155, -0.1155, -0.1155, -0.1155, -0.1155])
# Base value centered mean: 1.0881424117314964e-07
# Gamma init for k=3 (first 5): tensor([ 0.0020, -0.0039,  0.0022,  0.0021, -0.0058])
#
# Calculating gamma for k=4:
# Number of diseases in cluster: 17
# Base value (first 5): tensor([-13.2341, -13.8155, -13.2341, -13.2341, -11.4899])
# Base value centered (first 5): tensor([-0.0441, -0.6255, -0.0441, -0.0441,  1.7001])
# Base value centered mean: 1.0607719787003589e-06
# Gamma init for k=4 (first 5): tensor([-0.0060, -0.0015, -0.0132,  0.0367, -0.0098])
#
# Calculating gamma for k=5:
# Number of diseases in cluster: 16
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.5800, -13.8155])
# Base value centered (first 5): tensor([-0.1663, -0.1663, -0.1663,  1.0692, -0.1663])
# Base value centered mean: -1.2866020142610068e-06
# Gamma init for k=5 (first 5): tensor([ 0.0048,  0.0060, -0.0042,  0.0057,  0.0247])
#
# Calculating gamma for k=6:
# Number of diseases in cluster: 57
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.4687])
# Base value centered (first 5): tensor([-0.1119, -0.1119, -0.1119, -0.1119,  0.2349])
# Base value centered mean: -2.3013114969216986e-06
# Gamma init for k=6 (first 5): tensor([ 0.0017,  0.0017,  0.0011, -0.0008, -0.0017])
#
# Calculating gamma for k=7:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -10.5209, -12.1682])
# Base value centered (first 5): tensor([-0.4014, -0.4014, -0.4014,  2.8931,  1.2458])
# Base value centered mean: -5.4836272056491e-07
# Gamma init for k=7 (first 5): tensor([ 0.0073,  0.0049, -0.0054,  0.0056, -0.0040])
#
# Calculating gamma for k=8:
# Number of diseases in cluster: 13
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -11.5347, -13.0552])
# Base value centered (first 5): tensor([-0.2446, -0.2446, -0.2446,  2.0363,  0.5157])
# Base value centered mean: -1.083374030486084e-07
# Gamma init for k=8 (first 5): tensor([ 0.0013,  0.0009,  0.0006,  0.0133, -0.0011])
#
# Calculating gamma for k=9:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -12.0185, -11.1200])
# Base value centered (first 5): tensor([-0.2584, -0.2584, -0.2584,  1.5386,  2.4371])
# Base value centered mean: -2.26306909212326e-07
# Gamma init for k=9 (first 5): tensor([ 9.8623e-06,  9.0591e-03,  1.5899e-02, -3.2696e-03,  5.4497e-04])
#
# Calculating gamma for k=10:
# Number of diseases in cluster: 18
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1341, -0.1341, -0.1341, -0.1341, -0.1341])
# Base value centered mean: -3.9024354236971703e-07
# Gamma init for k=10 (first 5): tensor([ 0.0122, -0.0048,  0.0013, -0.0042,  0.0020])
#
# Calculating gamma for k=11:
# Number of diseases in cluster: 12
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.9919])
# Base value centered (first 5): tensor([-0.1911, -0.1911, -0.1911, -0.1911,  0.6326])
# Base value centered mean: -4.671096860420221e-07
# Gamma init for k=11 (first 5): tensor([ 0.0062,  0.0047, -0.0075,  0.0032,  0.0006])
#
# Calculating gamma for k=12:
# Number of diseases in cluster: 26
# Base value (first 5): tensor([-13.4354, -13.8155, -13.4354, -13.4354, -12.2949])
# Base value centered (first 5): tensor([ 0.0574, -0.3228,  0.0574,  0.0574,  1.1978])
# Base value centered mean: -1.0808944352902472e-06
# Gamma init for k=12 (first 5): tensor([ 0.0072,  0.0011, -0.0018,  0.0015,  0.0025])
#
# Calculating gamma for k=13:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1511, -0.1511, -0.1511, -0.1511, -0.1511])
# Base value centered mean: -1.0584831215965096e-06
# Gamma init for k=13 (first 5): tensor([ 7.6971e-03,  1.0931e-02,  8.1500e-05,  7.9379e-03, -1.5938e-03])
#
# Calculating gamma for k=14:
# Number of diseases in cluster: 9
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1618, -0.1618, -0.1618, -0.1618, -0.1618])
# Base value centered mean: -1.2922287169203628e-06
# Gamma init for k=14 (first 5): tensor([-0.0121, -0.0034, -0.0035,  0.0132,  0.0054])
#
# Calculating gamma for k=15:
# Number of diseases in cluster: 8
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1184, -0.1184, -0.1184, -0.1184, -0.1184])
# Base value centered mean: -6.237029879230249e-07
# Gamma init for k=15 (first 5): tensor([0.0026, 0.0024, 0.0029, 0.0010, 0.0098])
#
# Calculating gamma for k=16:
# Number of diseases in cluster: 7
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -12.4036])
# Base value centered (first 5): tensor([-0.2306, -0.2306, -0.2306, -0.2306,  1.1814])
# Base value centered mean: -1.5748977375551476e-06
# Gamma init for k=16 (first 5): tensor([ 0.0023,  0.0108,  0.0118, -0.0026,  0.0093])
#
# Calculating gamma for k=17:
# Number of diseases in cluster: 11
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.2706, -0.2706, -0.2706, -0.2706, -0.2706])
# Base value centered mean: -7.493972589145415e-07
# Gamma init for k=17 (first 5): tensor([-0.0068,  0.0176,  0.0005, -0.0053, -0.0091])
#
# Calculating gamma for k=18:
# Number of diseases in cluster: 6
# Base value (first 5): tensor([-13.8155, -10.5209, -13.8155, -13.8155, -13.8155])
# Base value centered (first 5): tensor([-0.1006,  3.1939, -0.1006, -0.1006, -0.1006])
# Base value centered mean: -1.0191916999247042e-06
# Gamma init for k=18 (first 5): tensor([-0.0158, -0.0017,  0.0114,  0.0180, -0.0033])
#
# Calculating gamma for k=19:
# Number of diseases in cluster: 55
# Base value (first 5): tensor([-13.8155, -13.8155, -13.8155, -13.2764, -13.4561])
# Base value centered (first 5): tensor([-0.1217, -0.1217, -0.1217,  0.4174,  0.2377])
# Base value centered mean: -3.7849426917091478e-06
# Gamma init for k=19 (first 5): tensor([ 0.0006, -0.0010,  0.0008,  0.0037,  0.0014])
# Initializing with 20 disease states + 1 healthy state
# Initialization complete!
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.753 (0.712-0.800) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.622 (0.564-0.671) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.609 (0.507-0.714) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.580 (0.494-0.694) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.604 (0.552-0.664) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.513 (0.408-0.624) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.626 (0.525-0.757) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.541 (0.477-0.601) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.627 (0.579-0.685) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.552 (0.471-0.616) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.537 (0.494-0.582) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.491 (0.401-0.594) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.588 (0.525-0.663) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.720 (0.644-0.788) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.718 (0.570-0.856) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.524 (0.325-0.760) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.531 (0.466-0.589) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.544 (0.503-0.587) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.499 (0.450-0.545) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.364 (0.255-0.486) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.578 (0.481-0.657) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.449 (0.319-0.580) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.515 (0.378-0.649) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.413 (0.315-0.550) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.527 (0.482-0.560) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.613 (0.481-0.744) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.510 (0.357-0.663) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.638 (0.596-0.683) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.753 (0.712-0.800)       136        5.4
# Diabetes             0.622 (0.564-0.671)       137        5.4
# Atrial_Fib           0.609 (0.507-0.714)       29         1.1
# CKD                  0.580 (0.494-0.694)       33         1.3
# All_Cancers          0.604 (0.552-0.664)       94         3.7
# Stroke               0.513 (0.408-0.624)       30         1.2
# Heart_Failure        0.626 (0.525-0.757)       32         1.3
# Pneumonia            0.541 (0.477-0.601)       70         2.8
# COPD                 0.627 (0.579-0.685)       81         3.2
# Osteoporosis         0.552 (0.471-0.616)       41         1.6
# Anemia               0.537 (0.494-0.582)       154        6.1
# Colorectal_Cancer    0.491 (0.401-0.594)       25         1.0
# Breast_Cancer        0.588 (0.525-0.663)       65         4.6
# Prostate_Cancer      0.720 (0.644-0.788)       35         3.1
# Lung_Cancer          0.718 (0.570-0.856)       9          0.4
# Bladder_Cancer       0.524 (0.325-0.760)       9          0.4
# Secondary_Cancer     0.531 (0.466-0.589)       71         2.8
# Depression           0.544 (0.503-0.587)       192        7.6
# Anxiety              0.499 (0.450-0.545)       136        5.4
# Bipolar_Disorder     0.364 (0.255-0.486)       17         0.7
# Rheumatoid_Arthritis 0.578 (0.481-0.657)       36         1.4
# Psoriasis            0.449 (0.319-0.580)       24         0.9
# Ulcerative_Colitis   0.515 (0.378-0.649)       22         0.9
# Crohns_Disease       0.413 (0.315-0.550)       20         0.8
# Asthma               0.527 (0.482-0.560)       218        8.8
# Parkinsons           0.613 (0.481-0.744)       2          0.1
# Multiple_Sclerosis   0.510 (0.357-0.663)       11         0.4
# Thyroid_Disorders    0.638 (0.596-0.683)       145        5.7
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.7532988871224164,
#   'n_events': 136,
#   'event_rate': 5.352223534041716,
#   'ci_lower': 0.7116539386338724,
#   'ci_upper': 0.8004184426747034},
#  'Diabetes': {'auc': 0.6219955791442486,
#   'n_events': 137,
#   'event_rate': 5.3915781188508465,
#   'ci_lower': 0.5644707291331775,
#   'ci_upper': 0.6705135730675604},
#  'Atrial_Fib': {'auc': 0.6089520162012482,
#   'n_events': 29,
#   'event_rate': 1.1453396524486572,
#   'ci_lower': 0.5070816213147761,
#   'ci_upper': 0.7141575415994241},
#  'CKD': {'auc': 0.5802764486975013,
#   'n_events': 33,
#   'event_rate': 1.2987012987012987,
#   'ci_lower': 0.4942235278556403,
#   'ci_upper': 0.6936778422873241},
#  'All_Cancers': {'auc': 0.6035005956055614,
#   'n_events': 94,
#   'event_rate': 3.699330972058245,
#   'ci_lower': 0.552498107718909,
#   'ci_upper': 0.6638416804572402},
#  'Stroke': {'auc': 0.5130227001194743,
#   'n_events': 30,
#   'event_rate': 1.1806375442739079,
#   'ci_lower': 0.40827787487122774,
#   'ci_upper': 0.6241064309256734},
#  'Heart_Failure': {'auc': 0.6262455161418892,
#   'n_events': 32,
#   'event_rate': 1.2593467138921683,
#   'ci_lower': 0.5252191171636946,
#   'ci_upper': 0.7565782565463649},
#  'Pneumonia': {'auc': 0.5408567959761809,
#   'n_events': 70,
#   'event_rate': 2.7548209366391188,
#   'ci_lower': 0.4771209487406683,
#   'ci_upper': 0.6014818690032758},
#  'COPD': {'auc': 0.6265231356017263,
#   'n_events': 81,
#   'event_rate': 3.187721369539551,
#   'ci_lower': 0.5786848392203162,
#   'ci_upper': 0.6846032770400291},
#  'Osteoporosis': {'auc': 0.5518402482944397,
#   'n_events': 41,
#   'event_rate': 1.6141732283464567,
#   'ci_lower': 0.47069144758942055,
#   'ci_upper': 0.6155534608543165},
#  'Anemia': {'auc': 0.5366432896805751,
#   'n_events': 154,
#   'event_rate': 6.0606060606060606,
#   'ci_lower': 0.4943342359322264,
#   'ci_upper': 0.5821479375541995},
#  'Colorectal_Cancer': {'auc': 0.4908267090620032,
#   'n_events': 25,
#   'event_rate': 0.9838646202282565,
#   'ci_lower': 0.40059040632635085,
#   'ci_upper': 0.594113827805838},
#  'Breast_Cancer': {'auc': 0.5876646913296127,
#   'n_events': 65,
#   'event_rate': 4.636233951497861,
#   'ci_lower': 0.5252250549996451,
#   'ci_upper': 0.6626938408694172},
#  'Prostate_Cancer': {'auc': 0.7197722567287785,
#   'n_events': 35,
#   'event_rate': 3.0728709394205445,
#   'ci_lower': 0.6441361299310986,
#   'ci_upper': 0.7875367132867134},
#  'Lung_Cancer': {'auc': 0.7184483061260312,
#   'n_events': 9,
#   'event_rate': 0.3541912632821724,
#   'ci_lower': 0.5701693527212249,
#   'ci_upper': 0.8563921452451944},
#  'Bladder_Cancer': {'auc': 0.5244742965011633,
#   'n_events': 9,
#   'event_rate': 0.3543307086614173,
#   'ci_lower': 0.3247912756499937,
#   'ci_upper': 0.7596031474710561},
#  'Secondary_Cancer': {'auc': 0.5313052403489764,
#   'n_events': 71,
#   'event_rate': 2.7941755214482487,
#   'ci_lower': 0.4659725073204558,
#   'ci_upper': 0.5889733508270412},
#  'Depression': {'auc': 0.5437059795889032,
#   'n_events': 192,
#   'event_rate': 7.646356033452808,
#   'ci_lower': 0.5033206155992369,
#   'ci_upper': 0.5866431608489657},
#  'Anxiety': {'auc': 0.49885110294117646,
#   'n_events': 136,
#   'event_rate': 5.3627760252365935,
#   'ci_lower': 0.45013904790452364,
#   'ci_upper': 0.5451058524296369},
#  'Bipolar_Disorder': {'auc': 0.36408005044018404,
#   'n_events': 17,
#   'event_rate': 0.6703470031545742,
#   'ci_lower': 0.2545275238473768,
#   'ci_upper': 0.4861346373056558},
#  'Rheumatoid_Arthritis': {'auc': 0.5784372501998402,
#   'n_events': 36,
#   'event_rate': 1.4184397163120568,
#   'ci_lower': 0.4812824155567312,
#   'ci_upper': 0.6571339480564433},
#  'Psoriasis': {'auc': 0.44895626242544734,
#   'n_events': 24,
#   'event_rate': 0.9452540370224497,
#   'ci_lower': 0.3186550327876847,
#   'ci_upper': 0.5804076144421499},
#  'Ulcerative_Colitis': {'auc': 0.5145469056083581,
#   'n_events': 22,
#   'event_rate': 0.870253164556962,
#   'ci_lower': 0.3781416865869854,
#   'ci_upper': 0.6486278087393644},
#  'Crohns_Disease': {'auc': 0.41285316354954243,
#   'n_events': 20,
#   'event_rate': 0.7895775759968418,
#   'ci_lower': 0.31538477784640423,
#   'ci_upper': 0.5501293566712727},
#  'Asthma': {'auc': 0.5268940843190087,
#   'n_events': 218,
#   'event_rate': 8.818770226537216,
#   'ci_lower': 0.4820946168200351,
#   'ci_upper': 0.5599749058465358},
#  'Parkinsons': {'auc': 0.612839700669555,
#   'n_events': 2,
#   'event_rate': 0.07870916961826052,
#   'ci_lower': 0.4807086614173228,
#   'ci_upper': 0.7440944881889764},
#  'Multiple_Sclerosis': {'auc': 0.5095589558955895,
#   'n_events': 11,
#   'event_rate': 0.4337539432176656,
#   'ci_lower': 0.35738162838840276,
#   'ci_upper': 0.6630803440997417},
#  'Thyroid_Disorders': {'auc': 0.6384577744516723,
#   'n_events': 145,
#   'event_rate': 5.706414797323888,
#   'ci_lower': 0.5957318881290844,
#   'ci_upper': 0.6825984929856975}}

# %% [markdown]
# ## joint fun

# %%
from fig5utils import *
pce_df_full=pd.read_csv('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_prevent_full.csv')
pce_df_subset=pce_df_full[0:10000]
disease_names=essentials['disease_names']
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_0_10000.pt')
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, ckpt['Y'], E_100k, disease_names, pce_df_subset, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/2486174665.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_0_10000.pt')
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.757 (0.716-0.800) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.658 (0.616-0.695) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.611 (0.517-0.721) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.475-0.688) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.605 (0.540-0.658) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.513 (0.411-0.607) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.632 (0.545-0.735) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.544 (0.473-0.628) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.630 (0.582-0.686) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.555 (0.466-0.641) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.537 (0.490-0.589) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.511 (0.414-0.630) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.584 (0.517-0.646) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.719 (0.624-0.792) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.717 (0.552-0.846) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.519 (0.290-0.755) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.532 (0.470-0.612) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.541 (0.504-0.572) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.500 (0.457-0.553) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.381 (0.259-0.495) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.498-0.666) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.453 (0.349-0.574) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.405-0.634) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.412 (0.302-0.496) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.495-0.561) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.617 (0.485-0.753) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.498 (0.377-0.618) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.636 (0.594-0.680) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.757 (0.716-0.800)       136        5.4
# Diabetes             0.658 (0.616-0.695)       137        5.4
# Atrial_Fib           0.611 (0.517-0.721)       29         1.1
# CKD                  0.579 (0.475-0.688)       33         1.3
# All_Cancers          0.605 (0.540-0.658)       94         3.7
# Stroke               0.513 (0.411-0.607)       30         1.2
# Heart_Failure        0.632 (0.545-0.735)       32         1.3
# Pneumonia            0.544 (0.473-0.628)       70         2.8
# COPD                 0.630 (0.582-0.686)       81         3.2
# Osteoporosis         0.555 (0.466-0.641)       41         1.6
# Anemia               0.537 (0.490-0.589)       154        6.1
# Colorectal_Cancer    0.511 (0.414-0.630)       25         1.0
# Breast_Cancer        0.584 (0.517-0.646)       65         4.6
# Prostate_Cancer      0.719 (0.624-0.792)       35         3.1
# Lung_Cancer          0.717 (0.552-0.846)       9          0.4
# Bladder_Cancer       0.519 (0.290-0.755)       9          0.4
# Secondary_Cancer     0.532 (0.470-0.612)       71         2.8
# Depression           0.541 (0.504-0.572)       192        7.6
# Anxiety              0.500 (0.457-0.553)       136        5.4
# Bipolar_Disorder     0.381 (0.259-0.495)       17         0.7
# Rheumatoid_Arthritis 0.579 (0.498-0.666)       36         1.4
# Psoriasis            0.453 (0.349-0.574)       24         0.9
# Ulcerative_Colitis   0.526 (0.405-0.634)       22         0.9
# Crohns_Disease       0.412 (0.302-0.496)       20         0.8
# Asthma               0.526 (0.495-0.561)       218        8.8
# Parkinsons           0.617 (0.485-0.753)       2          0.1
# Multiple_Sclerosis   0.498 (0.377-0.618)       11         0.4
# Thyroid_Disorders    0.636 (0.594-0.680)       145        5.7
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.7571909013085484,
#   'n_events': 136,
#   'event_rate': 5.352223534041716,
#   'ci_lower': 0.7162736593401398,
#   'ci_upper': 0.7996759094788214},
#  'Diabetes': {'auc': 0.6577358903044803,
#   'n_events': 137,
#   'event_rate': 5.3915781188508465,
#   'ci_lower': 0.6157588508726881,
#   'ci_upper': 0.6953519024959631},
#  'Atrial_Fib': {'auc': 0.6105087687877995,
#   'n_events': 29,
#   'event_rate': 1.1453396524486572,
#   'ci_lower': 0.5168071313827604,
#   'ci_upper': 0.7208575656673831},
#  'CKD': {'auc': 0.5791406891885361,
#   'n_events': 33,
#   'event_rate': 1.2987012987012987,
#   'ci_lower': 0.47517277686016224,
#   'ci_upper': 0.6882456490166603},
#  'All_Cancers': {'auc': 0.6049178759923136,
#   'n_events': 94,
#   'event_rate': 3.699330972058245,
#   'ci_lower': 0.5401905412145855,
#   'ci_upper': 0.6578950343016632},
#  'Stroke': {'auc': 0.5132218239745122,
#   'n_events': 30,
#   'event_rate': 1.1806375442739079,
#   'ci_lower': 0.4113602215301302,
#   'ci_upper': 0.6065410183110185},
#  'Heart_Failure': {'auc': 0.631925069748904,
#   'n_events': 32,
#   'event_rate': 1.2593467138921683,
#   'ci_lower': 0.5446163836282821,
#   'ci_upper': 0.7348430877823668},
#  'Pneumonia': {'auc': 0.5441001329710354,
#   'n_events': 70,
#   'event_rate': 2.7548209366391188,
#   'ci_lower': 0.47271218874643356,
#   'ci_upper': 0.6281708492426792},
#  'COPD': {'auc': 0.6296898524540799,
#   'n_events': 81,
#   'event_rate': 3.187721369539551,
#   'ci_lower': 0.5820428999716061,
#   'ci_upper': 0.6861849782816988},
#  'Osteoporosis': {'auc': 0.5550512888082061,
#   'n_events': 41,
#   'event_rate': 1.6141732283464567,
#   'ci_lower': 0.465711838485687,
#   'ci_upper': 0.6405831085181313},
#  'Anemia': {'auc': 0.5365725602424387,
#   'n_events': 154,
#   'event_rate': 6.0606060606060606,
#   'ci_lower': 0.4903314834705812,
#   'ci_upper': 0.5886832781271018},
#  'Colorectal_Cancer': {'auc': 0.5113513513513512,
#   'n_events': 25,
#   'event_rate': 0.9838646202282565,
#   'ci_lower': 0.41418686403624405,
#   'ci_upper': 0.6302814570634527},
#  'Breast_Cancer': {'auc': 0.5837523732811691,
#   'n_events': 65,
#   'event_rate': 4.636233951497861,
#   'ci_lower': 0.5168161687814593,
#   'ci_upper': 0.6463005546091747},
#  'Prostate_Cancer': {'auc': 0.7187888198757765,
#   'n_events': 35,
#   'event_rate': 3.0728709394205445,
#   'ci_lower': 0.6236509785647717,
#   'ci_upper': 0.7919407069574231},
#  'Lung_Cancer': {'auc': 0.717307354748113,
#   'n_events': 9,
#   'event_rate': 0.3541912632821724,
#   'ci_lower': 0.5524267621922091,
#   'ci_upper': 0.8464458459586841},
#  'Bladder_Cancer': {'auc': 0.5192940866587646,
#   'n_events': 9,
#   'event_rate': 0.3543307086614173,
#   'ci_lower': 0.2901244345034709,
#   'ci_upper': 0.7549784767694814},
#  'Secondary_Cancer': {'auc': 0.5324627929520442,
#   'n_events': 71,
#   'event_rate': 2.7941755214482487,
#   'ci_lower': 0.4697923678913449,
#   'ci_upper': 0.6123355068458011},
#  'Depression': {'auc': 0.5406851911743568,
#   'n_events': 192,
#   'event_rate': 7.646356033452808,
#   'ci_lower': 0.5044494010868479,
#   'ci_upper': 0.5721636417032121},
#  'Anxiety': {'auc': 0.4997089460784313,
#   'n_events': 136,
#   'event_rate': 5.3627760252365935,
#   'ci_lower': 0.45655663778728806,
#   'ci_upper': 0.5533118447000699},
#  'Bipolar_Disorder': {'auc': 0.3805198141185811,
#   'n_events': 17,
#   'event_rate': 0.6703470031545742,
#   'ci_lower': 0.2591626725112385,
#   'ci_upper': 0.4946279595942494},
#  'Rheumatoid_Arthritis': {'auc': 0.5790256683542054,
#   'n_events': 36,
#   'event_rate': 1.4184397163120568,
#   'ci_lower': 0.498077535969623,
#   'ci_upper': 0.6663491360474754},
#  'Psoriasis': {'auc': 0.45278330019880714,
#   'n_events': 24,
#   'event_rate': 0.9452540370224497,
#   'ci_lower': 0.349466651052038,
#   'ci_upper': 0.574127589880621},
#  'Ulcerative_Colitis': {'auc': 0.5255205688166582,
#   'n_events': 22,
#   'event_rate': 0.870253164556962,
#   'ci_lower': 0.4049870266833823,
#   'ci_upper': 0.6335855059753522},
#  'Crohns_Disease': {'auc': 0.4121567847194588,
#   'n_events': 20,
#   'event_rate': 0.7895775759968418,
#   'ci_lower': 0.30173524242763444,
#   'ci_upper': 0.496006974557376},
#  'Asthma': {'auc': 0.5257869801291079,
#   'n_events': 218,
#   'event_rate': 8.818770226537216,
#   'ci_lower': 0.4945631643404353,
#   'ci_upper': 0.5605300994720771},
#  'Parkinsons': {'auc': 0.6167782591571485,
#   'n_events': 2,
#   'event_rate': 0.07870916961826052,
#   'ci_lower': 0.4850393700787402,
#   'ci_upper': 0.7530413618510452},
#  'Multiple_Sclerosis': {'auc': 0.4977137713771377,
#   'n_events': 11,
#   'event_rate': 0.4337539432176656,
#   'ci_lower': 0.3768692647558627,
#   'ci_upper': 0.6178874399906467},
#  'Thyroid_Disorders': {'auc': 0.6363479362155317,
#   'n_events': 145,
#   'event_rate': 5.706414797323888,
#   'ci_lower': 0.5940107984098288,
#   'ci_upper': 0.6795077053555904}}

# %%
from fig5utils import *
pce_df_full=pd.read_csv('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_prevent_full.csv')
pce_df_subset=pce_df_full[10000:20000]
disease_names=essentials['disease_names']
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_10000_20000.pt')
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, ckpt['Y'], E_100k, disease_names, pce_df_subset, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/1476358432.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_10000_20000.pt')
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.679 (0.640-0.725) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 143 (5.7%) (from 2503 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.708 (0.656-0.750) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 118 (4.7%) (from 2503 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.750 (0.678-0.833) (calculated on 2492 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2492 individuals)
# Excluded 11 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.533 (0.432-0.585) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 27 (1.1%) (from 2503 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.616 (0.563-0.669) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 77 (3.1%) (from 2503 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.554 (0.434-0.690) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 21 (0.8%) (from 2503 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.621 (0.544-0.716) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 34 (1.4%) (from 2503 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.576 (0.512-0.658) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 67 (2.7%) (from 2503 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.563 (0.499-0.627) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 64 (2.6%) (from 2503 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.604 (0.521-0.698) (calculated on 2502 individuals)
# Events (10-Year in Eval Cohort): 40 (1.6%) (from 2502 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.508 (0.464-0.554) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 146 (5.8%) (from 2503 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.617 (0.499-0.717) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2503 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5401 individuals in cohort
# AUC: 0.545 (0.485-0.605) (calculated on 1416 individuals)
# Events (10-Year in Eval Cohort): 84 (5.9%) (from 1416 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4599 individuals in cohort
# AUC: 0.645 (0.533-0.747) (calculated on 1086 individuals)
# Events (10-Year in Eval Cohort): 25 (2.3%) (from 1086 individuals)
# Excluded 1 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.735 (0.467-0.904) (calculated on 2502 individuals)
# Events (10-Year in Eval Cohort): 5 (0.2%) (from 2502 individuals)
# Excluded 1 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.444 (0.287-0.612) (calculated on 2502 individuals)
# Events (10-Year in Eval Cohort): 6 (0.2%) (from 2502 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.575 (0.502-0.643) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 65 (2.6%) (from 2503 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.524 (0.488-0.565) (calculated on 2463 individuals)
# Events (10-Year in Eval Cohort): 176 (7.1%) (from 2463 individuals)
# Excluded 40 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.521 (0.480-0.582) (calculated on 2493 individuals)
# Events (10-Year in Eval Cohort): 128 (5.1%) (from 2493 individuals)
# Excluded 10 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.386 (0.287-0.523) (calculated on 2493 individuals)
# Events (10-Year in Eval Cohort): 13 (0.5%) (from 2493 individuals)
# Excluded 10 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.554 (0.447-0.639) (calculated on 2500 individuals)
# Events (10-Year in Eval Cohort): 29 (1.2%) (from 2500 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.493 (0.342-0.666) (calculated on 2498 individuals)
# Events (10-Year in Eval Cohort): 13 (0.5%) (from 2498 individuals)
# Excluded 5 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.469 (0.275-0.630) (calculated on 2492 individuals)
# Events (10-Year in Eval Cohort): 15 (0.6%) (from 2492 individuals)
# Excluded 11 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.442 (0.261-0.632) (calculated on 2494 individuals)
# Events (10-Year in Eval Cohort): 10 (0.4%) (from 2494 individuals)
# Excluded 9 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.570 (0.535-0.622) (calculated on 2406 individuals)
# Events (10-Year in Eval Cohort): 205 (8.5%) (from 2406 individuals)
# Excluded 97 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.573 (0.249-0.929) (calculated on 2502 individuals)
# Events (10-Year in Eval Cohort): 4 (0.2%) (from 2502 individuals)
# Excluded 1 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.575 (0.424-0.741) (calculated on 2498 individuals)
# Events (10-Year in Eval Cohort): 13 (0.5%) (from 2498 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.588 (0.532-0.637) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 112 (4.5%) (from 2503 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.679 (0.640-0.725)       143        5.7
# Diabetes             0.708 (0.656-0.750)       118        4.7
# Atrial_Fib           0.750 (0.678-0.833)       30         1.2
# CKD                  0.533 (0.432-0.585)       27         1.1
# All_Cancers          0.616 (0.563-0.669)       77         3.1
# Stroke               0.554 (0.434-0.690)       21         0.8
# Heart_Failure        0.621 (0.544-0.716)       34         1.4
# Pneumonia            0.576 (0.512-0.658)       67         2.7
# COPD                 0.563 (0.499-0.627)       64         2.6
# Osteoporosis         0.604 (0.521-0.698)       40         1.6
# Anemia               0.508 (0.464-0.554)       146        5.8
# Colorectal_Cancer    0.617 (0.499-0.717)       22         0.9
# Breast_Cancer        0.545 (0.485-0.605)       84         5.9
# Prostate_Cancer      0.645 (0.533-0.747)       25         2.3
# Lung_Cancer          0.735 (0.467-0.904)       5          0.2
# Bladder_Cancer       0.444 (0.287-0.612)       6          0.2
# Secondary_Cancer     0.575 (0.502-0.643)       65         2.6
# Depression           0.524 (0.488-0.565)       176        7.1
# Anxiety              0.521 (0.480-0.582)       128        5.1
# Bipolar_Disorder     0.386 (0.287-0.523)       13         0.5
# Rheumatoid_Arthritis 0.554 (0.447-0.639)       29         1.2
# Psoriasis            0.493 (0.342-0.666)       13         0.5
# Ulcerative_Colitis   0.469 (0.275-0.630)       15         0.6
# Crohns_Disease       0.442 (0.261-0.632)       10         0.4
# Asthma               0.570 (0.535-0.622)       205        8.5
# Parkinsons           0.573 (0.249-0.929)       4          0.2
# Multiple_Sclerosis   0.575 (0.424-0.741)       13         0.5
# Thyroid_Disorders    0.588 (0.532-0.637)       112        4.5
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.6791958041958043,
#   'n_events': 143,
#   'event_rate': 5.713144226927687,
#   'ci_lower': 0.6396737797737561,
#   'ci_upper': 0.7249290061207281},
#  'Diabetes': {'auc': 0.707799452794656,
#   'n_events': 118,
#   'event_rate': 4.714342788653616,
#   'ci_lower': 0.6564537185995166,
#   'ci_upper': 0.7495627656114395},
#  'Atrial_Fib': {'auc': 0.7498375304630382,
#   'n_events': 30,
#   'event_rate': 1.2038523274478332,
#   'ci_lower': 0.6780413780817799,
#   'ci_upper': 0.8332437048990318},
#  'CKD': {'auc': 0.5333423083826961,
#   'n_events': 27,
#   'event_rate': 1.0787055533359968,
#   'ci_lower': 0.4323761015044704,
#   'ci_upper': 0.5851480341504525},
#  'All_Cancers': {'auc': 0.6156786329910815,
#   'n_events': 77,
#   'event_rate': 3.076308429884139,
#   'ci_lower': 0.5626293450837618,
#   'ci_upper': 0.6686342668863261},
#  'Stroke': {'auc': 0.5544491769310465,
#   'n_events': 21,
#   'event_rate': 0.8389932081502196,
#   'ci_lower': 0.43437827617937297,
#   'ci_upper': 0.6897797324307383},
#  'Heart_Failure': {'auc': 0.620851499773664,
#   'n_events': 34,
#   'event_rate': 1.3583699560527367,
#   'ci_lower': 0.5440204615032928,
#   'ci_upper': 0.715749255310573},
#  'Pneumonia': {'auc': 0.5762198857927112,
#   'n_events': 67,
#   'event_rate': 2.6767878545745107,
#   'ci_lower': 0.5124513206221487,
#   'ci_upper': 0.6582087381933417},
#  'COPD': {'auc': 0.5631534440344403,
#   'n_events': 64,
#   'event_rate': 2.556931681981622,
#   'ci_lower': 0.49926093905073265,
#   'ci_upper': 0.6270214135316691},
#  'Osteoporosis': {'auc': 0.6038992688870837,
#   'n_events': 40,
#   'event_rate': 1.5987210231814548,
#   'ci_lower': 0.5213634907907856,
#   'ci_upper': 0.697810494440744},
#  'Anemia': {'auc': 0.508235451380615,
#   'n_events': 146,
#   'event_rate': 5.833000399520576,
#   'ci_lower': 0.46377581591979106,
#   'ci_upper': 0.5541001708368377},
#  'Colorectal_Cancer': {'auc': 0.617346377926789,
#   'n_events': 22,
#   'event_rate': 0.8789452656811825,
#   'ci_lower': 0.499349190367023,
#   'ci_upper': 0.7170275094922405},
#  'Breast_Cancer': {'auc': 0.5452595452595453,
#   'n_events': 84,
#   'event_rate': 5.932203389830509,
#   'ci_lower': 0.4852313204673721,
#   'ci_upper': 0.6053805899763015},
#  'Prostate_Cancer': {'auc': 0.6450895381715362,
#   'n_events': 25,
#   'event_rate': 2.3020257826887662,
#   'ci_lower': 0.5334550417157281,
#   'ci_upper': 0.7470647520313425},
#  'Lung_Cancer': {'auc': 0.7352823388065679,
#   'n_events': 5,
#   'event_rate': 0.19984012789768185,
#   'ci_lower': 0.4673036694677871,
#   'ci_upper': 0.9041854963971176},
#  'Bladder_Cancer': {'auc': 0.44411057692307687,
#   'n_events': 6,
#   'event_rate': 0.2398081534772182,
#   'ci_lower': 0.287493838553749,
#   'ci_upper': 0.6122060478176051},
#  'Secondary_Cancer': {'auc': 0.5750741465261564,
#   'n_events': 65,
#   'event_rate': 2.596883739512585,
#   'ci_lower': 0.5018562559431068,
#   'ci_upper': 0.6431403941486012},
#  'Depression': {'auc': 0.5243893349763484,
#   'n_events': 176,
#   'event_rate': 7.145757206658547,
#   'ci_lower': 0.4879303106933017,
#   'ci_upper': 0.5654384155280455},
#  'Anxiety': {'auc': 0.5205767706131078,
#   'n_events': 128,
#   'event_rate': 5.134376253509827,
#   'ci_lower': 0.4799573532463251,
#   'ci_upper': 0.5823746336514228},
#  'Bipolar_Disorder': {'auc': 0.385514888337469,
#   'n_events': 13,
#   'event_rate': 0.5214600882470918,
#   'ci_lower': 0.28684721535551244,
#   'ci_upper': 0.5230431079407554},
#  'Rheumatoid_Arthritis': {'auc': 0.554222079571303,
#   'n_events': 29,
#   'event_rate': 1.16,
#   'ci_lower': 0.44682420732579486,
#   'ci_upper': 0.6391757313215259},
#  'Psoriasis': {'auc': 0.4928339266367435,
#   'n_events': 13,
#   'event_rate': 0.5204163330664532,
#   'ci_lower': 0.34216269508611996,
#   'ci_upper': 0.6661237223802653},
#  'Ulcerative_Colitis': {'auc': 0.46892746602072405,
#   'n_events': 15,
#   'event_rate': 0.6019261637239166,
#   'ci_lower': 0.2752293318549036,
#   'ci_upper': 0.630164045322607},
#  'Crohns_Disease': {'auc': 0.442109500805153,
#   'n_events': 10,
#   'event_rate': 0.40096230954290296,
#   'ci_lower': 0.26131980715146647,
#   'ci_upper': 0.6321752498432717},
#  'Asthma': {'auc': 0.5703505058676211,
#   'n_events': 205,
#   'event_rate': 8.520365752285953,
#   'ci_lower': 0.5349723701826959,
#   'ci_upper': 0.6219776897050203},
#  'Parkinsons': {'auc': 0.5732586068855083,
#   'n_events': 4,
#   'event_rate': 0.15987210231814547,
#   'ci_lower': 0.249100064192323,
#   'ci_upper': 0.9289115646258503},
#  'Multiple_Sclerosis': {'auc': 0.5745550224423464,
#   'n_events': 13,
#   'event_rate': 0.5204163330664532,
#   'ci_lower': 0.4238648429553804,
#   'ci_upper': 0.741223469038194},
#  'Thyroid_Disorders': {'auc': 0.5880310091414231,
#   'n_events': 112,
#   'event_rate': 4.474630443467839,
#   'ci_lower': 0.5322278894385928,
#   'ci_upper': 0.6372078452342814}}

# %%
from fig5utils import *
pce_df_full=pd.read_csv('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_prevent_full.csv')
pce_df_subset=pce_df_full[20000:30000]
disease_names=essentials['disease_names']
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_20000_30000.pt')
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, ckpt['Y'], E_100k, disease_names, pce_df_subset, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/1205554614.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_20000_30000.pt')
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.703 (0.664-0.746) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 143 (5.6%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.696 (0.652-0.734) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 167 (6.6%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.660 (0.573-0.758) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2536 individuals)
# Excluded 5 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.506 (0.433-0.590) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 42 (1.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.606 (0.541-0.665) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 80 (3.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.621 (0.545-0.704) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.669 (0.559-0.765) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.553 (0.484-0.634) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 82 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.600 (0.552-0.663) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 78 (3.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.697 (0.618-0.782) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 34 (1.3%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.571 (0.526-0.609) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 131 (5.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.660 (0.560-0.749) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5395 individuals in cohort
# AUC: 0.562 (0.494-0.627) (calculated on 1435 individuals)
# Events (10-Year in Eval Cohort): 86 (6.0%) (from 1435 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4605 individuals in cohort
# AUC: 0.590 (0.484-0.690) (calculated on 1105 individuals)
# Events (10-Year in Eval Cohort): 28 (2.5%) (from 1105 individuals)
# Excluded 1 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.619 (0.455-0.788) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 8 (0.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.606 (0.369-0.895) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 7 (0.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.601 (0.541-0.680) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 63 (2.5%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.547 (0.497-0.586) (calculated on 2515 individuals)
# Events (10-Year in Eval Cohort): 191 (7.6%) (from 2515 individuals)
# Excluded 26 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.515 (0.453-0.573) (calculated on 2537 individuals)
# Events (10-Year in Eval Cohort): 139 (5.5%) (from 2537 individuals)
# Excluded 4 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.589 (0.461-0.704) (calculated on 2535 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2535 individuals)
# Excluded 6 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.614 (0.483-0.737) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2536 individuals)
# Excluded 5 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.453 (0.341-0.583) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 21 (0.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.626 (0.503-0.704) (calculated on 2530 individuals)
# Events (10-Year in Eval Cohort): 19 (0.8%) (from 2530 individuals)
# Excluded 11 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.476 (0.294-0.712) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.540 (0.502-0.577) (calculated on 2460 individuals)
# Events (10-Year in Eval Cohort): 219 (8.9%) (from 2460 individuals)
# Excluded 81 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.702 (0.410-0.889) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 5 (0.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.487 (0.338-0.617) (calculated on 2534 individuals)
# Events (10-Year in Eval Cohort): 8 (0.3%) (from 2534 individuals)
# Excluded 7 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.624 (0.579-0.660) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 138 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.703 (0.664-0.746)       143        5.6
# Diabetes             0.696 (0.652-0.734)       167        6.6
# Atrial_Fib           0.660 (0.573-0.758)       30         1.2
# CKD                  0.506 (0.433-0.590)       42         1.7
# All_Cancers          0.606 (0.541-0.665)       80         3.1
# Stroke               0.621 (0.545-0.704)       29         1.1
# Heart_Failure        0.669 (0.559-0.765)       29         1.1
# Pneumonia            0.553 (0.484-0.634)       82         3.2
# COPD                 0.600 (0.552-0.663)       78         3.1
# Osteoporosis         0.697 (0.618-0.782)       34         1.3
# Anemia               0.571 (0.526-0.609)       131        5.2
# Colorectal_Cancer    0.660 (0.560-0.749)       24         0.9
# Breast_Cancer        0.562 (0.494-0.627)       86         6.0
# Prostate_Cancer      0.590 (0.484-0.690)       28         2.5
# Lung_Cancer          0.619 (0.455-0.788)       8          0.3
# Bladder_Cancer       0.606 (0.369-0.895)       7          0.3
# Secondary_Cancer     0.601 (0.541-0.680)       63         2.5
# Depression           0.547 (0.497-0.586)       191        7.6
# Anxiety              0.515 (0.453-0.573)       139        5.5
# Bipolar_Disorder     0.589 (0.461-0.704)       11         0.4
# Rheumatoid_Arthritis 0.614 (0.483-0.737)       25         1.0
# Psoriasis            0.453 (0.341-0.583)       21         0.8
# Ulcerative_Colitis   0.626 (0.503-0.704)       19         0.8
# Crohns_Disease       0.476 (0.294-0.712)       11         0.4
# Asthma               0.540 (0.502-0.577)       219        8.9
# Parkinsons           0.702 (0.410-0.889)       5          0.2
# Multiple_Sclerosis   0.487 (0.338-0.617)       8          0.3
# Thyroid_Disorders    0.624 (0.579-0.660)       138        5.4
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.702703884939081,
#   'n_events': 143,
#   'event_rate': 5.627705627705628,
#   'ci_lower': 0.6639360357402131,
#   'ci_upper': 0.7457842727039136},
#  'Diabetes': {'auc': 0.696328488768041,
#   'n_events': 167,
#   'event_rate': 6.572215663124754,
#   'ci_lower': 0.6521787933323038,
#   'ci_upper': 0.7340838427096437},
#  'Atrial_Fib': {'auc': 0.6600425645118382,
#   'n_events': 30,
#   'event_rate': 1.1829652996845426,
#   'ci_lower': 0.5733488476927109,
#   'ci_upper': 0.7577966330387702},
#  'CKD': {'auc': 0.5060881495455325,
#   'n_events': 42,
#   'event_rate': 1.6528925619834711,
#   'ci_lower': 0.43313142691818596,
#   'ci_upper': 0.5897366248250617},
#  'All_Cancers': {'auc': 0.6062677773262901,
#   'n_events': 80,
#   'event_rate': 3.1483667847304213,
#   'ci_lower': 0.5414213750606394,
#   'ci_upper': 0.6651409677305284},
#  'Stroke': {'auc': 0.6214721063035361,
#   'n_events': 29,
#   'event_rate': 1.1412829594647778,
#   'ci_lower': 0.5452880118318795,
#   'ci_upper': 0.7040282353836513},
#  'Heart_Failure': {'auc': 0.6687349000658906,
#   'n_events': 29,
#   'event_rate': 1.1412829594647778,
#   'ci_lower': 0.5593802424337005,
#   'ci_upper': 0.7654898666278446},
#  'Pneumonia': {'auc': 0.552991003679862,
#   'n_events': 82,
#   'event_rate': 3.2270759543486816,
#   'ci_lower': 0.48356556043464,
#   'ci_upper': 0.6342500916743199},
#  'COPD': {'auc': 0.5997168347960065,
#   'n_events': 78,
#   'event_rate': 3.0696576151121606,
#   'ci_lower': 0.5520905762616732,
#   'ci_upper': 0.6632822616482567},
#  'Osteoporosis': {'auc': 0.6966222243087179,
#   'n_events': 34,
#   'event_rate': 1.3385826771653544,
#   'ci_lower': 0.6181611336779325,
#   'ci_upper': 0.7824848876258093},
#  'Anemia': {'auc': 0.5708815051788033,
#   'n_events': 131,
#   'event_rate': 5.155450609996064,
#   'ci_lower': 0.5259454631639656,
#   'ci_upper': 0.6087504490208238},
#  'Colorectal_Cancer': {'auc': 0.6600119189511323,
#   'n_events': 24,
#   'event_rate': 0.9445100354191263,
#   'ci_lower': 0.5599643423137876,
#   'ci_upper': 0.7490390576893599},
#  'Breast_Cancer': {'auc': 0.5618201251573086,
#   'n_events': 86,
#   'event_rate': 5.993031358885018,
#   'ci_lower': 0.49393981236194423,
#   'ci_upper': 0.6269576392178919},
#  'Prostate_Cancer': {'auc': 0.5897665472874386,
#   'n_events': 28,
#   'event_rate': 2.5339366515837103,
#   'ci_lower': 0.4841158545314031,
#   'ci_upper': 0.6896780484635366},
#  'Lung_Cancer': {'auc': 0.6189794709830241,
#   'n_events': 8,
#   'event_rate': 0.3148366784730421,
#   'ci_lower': 0.4550200919295063,
#   'ci_upper': 0.7883211412731945},
#  'Bladder_Cancer': {'auc': 0.6062690269477957,
#   'n_events': 7,
#   'event_rate': 0.27548209366391185,
#   'ci_lower': 0.36878278366149947,
#   'ci_upper': 0.8949777466597726},
#  'Secondary_Cancer': {'auc': 0.600670023188183,
#   'n_events': 63,
#   'event_rate': 2.479338842975207,
#   'ci_lower': 0.541139058943997,
#   'ci_upper': 0.6800127731808384},
#  'Depression': {'auc': 0.5472510836164403,
#   'n_events': 191,
#   'event_rate': 7.594433399602386,
#   'ci_lower': 0.49727548942533684,
#   'ci_upper': 0.5855113768817134},
#  'Anxiety': {'auc': 0.5147575017550596,
#   'n_events': 139,
#   'event_rate': 5.478912100906583,
#   'ci_lower': 0.45275449360425973,
#   'ci_upper': 0.5733045503503166},
#  'Bipolar_Disorder': {'auc': 0.5894683763146521,
#   'n_events': 11,
#   'event_rate': 0.4339250493096647,
#   'ci_lower': 0.4605471909628514,
#   'ci_upper': 0.7037076453361383},
#  'Rheumatoid_Arthritis': {'auc': 0.6142254082039028,
#   'n_events': 25,
#   'event_rate': 0.9858044164037855,
#   'ci_lower': 0.48339534053073996,
#   'ci_upper': 0.737224596821505},
#  'Psoriasis': {'auc': 0.45311791383219957,
#   'n_events': 21,
#   'event_rate': 0.8264462809917356,
#   'ci_lower': 0.3407590372424061,
#   'ci_upper': 0.5826855240340696},
#  'Ulcerative_Colitis': {'auc': 0.6261921230795029,
#   'n_events': 19,
#   'event_rate': 0.7509881422924901,
#   'ci_lower': 0.5026008484954375,
#   'ci_upper': 0.704437749003984},
#  'Crohns_Disease': {'auc': 0.47574075409126954,
#   'n_events': 11,
#   'event_rate': 0.43426766679826295,
#   'ci_lower': 0.2935031201241755,
#   'ci_upper': 0.7116870263544841},
#  'Asthma': {'auc': 0.5398560248095375,
#   'n_events': 219,
#   'event_rate': 8.902439024390244,
#   'ci_lower': 0.5020008908996493,
#   'ci_upper': 0.5771518636230987},
#  'Parkinsons': {'auc': 0.701813880126183,
#   'n_events': 5,
#   'event_rate': 0.19677292404565133,
#   'ci_lower': 0.41005812243776335,
#   'ci_upper': 0.8893033109972407},
#  'Multiple_Sclerosis': {'auc': 0.4869853523357086,
#   'n_events': 8,
#   'event_rate': 0.31570639305445936,
#   'ci_lower': 0.3375852082249073,
#   'ci_upper': 0.6166275448730164},
#  'Thyroid_Disorders': {'auc': 0.623830718847817,
#   'n_events': 138,
#   'event_rate': 5.430932703659976,
#   'ci_lower': 0.5794324567259783,
#   'ci_upper': 0.6603529634328732}}

# %%
from fig5utils import *
pce_df_subset=pce_df_full[330000:340000]
disease_names=essentials['disease_names']
ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_330000_340000.pt')
model.load_state_dict(ckpt['model_state_dict'])

evaluate_major_diseases_wsex_with_bootstrap_dynamic(model, ckpt['Y'], E_100k, disease_names, pce_df_subset, n_bootstraps=100, follow_up_duration_years=30, patient_indices=None)
# Out:
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/1180716549.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt=torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_330000_340000.pt')
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.686 (0.641-0.733) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 151 (5.9%) (from 2562 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.695 (0.647-0.746) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 140 (5.5%) (from 2562 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.458 (0.377-0.550) (calculated on 2554 individuals)
# Events (10-Year in Eval Cohort): 26 (1.0%) (from 2554 individuals)
# Excluded 8 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.619 (0.531-0.720) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 31 (1.2%) (from 2562 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.568 (0.512-0.635) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 80 (3.1%) (from 2562 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.523 (0.425-0.642) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2562 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.484 (0.400-0.583) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2562 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.521 (0.445-0.587) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2562 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.580 (0.504-0.639) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 86 (3.4%) (from 2562 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.654 (0.575-0.725) (calculated on 2559 individuals)
# Events (10-Year in Eval Cohort): 37 (1.4%) (from 2559 individuals)
# Excluded 3 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.519 (0.474-0.562) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 152 (5.9%) (from 2562 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.554 (0.457-0.647) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 32 (1.2%) (from 2562 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5314 individuals in cohort
# AUC: 0.546 (0.490-0.605) (calculated on 1444 individuals)
# Events (10-Year in Eval Cohort): 79 (5.5%) (from 1444 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4686 individuals in cohort
# AUC: 0.619 (0.491-0.735) (calculated on 1116 individuals)
# Events (10-Year in Eval Cohort): 20 (1.8%) (from 1116 individuals)
# Excluded 2 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.575 (0.399-0.779) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2562 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.696 (0.536-0.890) (calculated on 2559 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2559 individuals)
# Excluded 3 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.523 (0.456-0.593) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 64 (2.5%) (from 2562 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.514 (0.477-0.549) (calculated on 2531 individuals)
# Events (10-Year in Eval Cohort): 189 (7.5%) (from 2531 individuals)
# Excluded 31 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.473 (0.419-0.512) (calculated on 2555 individuals)
# Events (10-Year in Eval Cohort): 131 (5.1%) (from 2555 individuals)
# Excluded 7 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.482 (0.314-0.648) (calculated on 2556 individuals)
# Events (10-Year in Eval Cohort): 13 (0.5%) (from 2556 individuals)
# Excluded 6 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.517 (0.373-0.600) (calculated on 2556 individuals)
# Events (10-Year in Eval Cohort): 42 (1.6%) (from 2556 individuals)
# Excluded 6 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.458 (0.323-0.589) (calculated on 2556 individuals)
# Events (10-Year in Eval Cohort): 23 (0.9%) (from 2556 individuals)
# Excluded 6 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.534 (0.349-0.676) (calculated on 2548 individuals)
# Events (10-Year in Eval Cohort): 18 (0.7%) (from 2548 individuals)
# Excluded 14 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.516 (0.340-0.738) (calculated on 2550 individuals)
# Events (10-Year in Eval Cohort): 10 (0.4%) (from 2550 individuals)
# Excluded 12 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.551 (0.514-0.588) (calculated on 2471 individuals)
# Events (10-Year in Eval Cohort): 243 (9.8%) (from 2471 individuals)
# Excluded 91 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.860 (0.791-0.963) (calculated on 2561 individuals)
# Events (10-Year in Eval Cohort): 3 (0.1%) (from 2561 individuals)
# Excluded 1 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.702 (0.569-0.804) (calculated on 2551 individuals)
# Events (10-Year in Eval Cohort): 14 (0.5%) (from 2551 individuals)
# Excluded 11 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.624 (0.575-0.675) (calculated on 2562 individuals)
# Events (10-Year in Eval Cohort): 127 (5.0%) (from 2562 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.686 (0.641-0.733)       151        5.9
# Diabetes             0.695 (0.647-0.746)       140        5.5
# Atrial_Fib           0.458 (0.377-0.550)       26         1.0
# CKD                  0.619 (0.531-0.720)       31         1.2
# All_Cancers          0.568 (0.512-0.635)       80         3.1
# Stroke               0.523 (0.425-0.642)       24         0.9
# Heart_Failure        0.484 (0.400-0.583)       41         1.6
# Pneumonia            0.521 (0.445-0.587)       81         3.2
# COPD                 0.580 (0.504-0.639)       86         3.4
# Osteoporosis         0.654 (0.575-0.725)       37         1.4
# Anemia               0.519 (0.474-0.562)       152        5.9
# Colorectal_Cancer    0.554 (0.457-0.647)       32         1.2
# Breast_Cancer        0.546 (0.490-0.605)       79         5.5
# Prostate_Cancer      0.619 (0.491-0.735)       20         1.8
# Lung_Cancer          0.575 (0.399-0.779)       9          0.4
# Bladder_Cancer       0.696 (0.536-0.890)       9          0.4
# Secondary_Cancer     0.523 (0.456-0.593)       64         2.5
# Depression           0.514 (0.477-0.549)       189        7.5
# Anxiety              0.473 (0.419-0.512)       131        5.1
# Bipolar_Disorder     0.482 (0.314-0.648)       13         0.5
# Rheumatoid_Arthritis 0.517 (0.373-0.600)       42         1.6
# Psoriasis            0.458 (0.323-0.589)       23         0.9
# Ulcerative_Colitis   0.534 (0.349-0.676)       18         0.7
# Crohns_Disease       0.516 (0.340-0.738)       10         0.4
# Asthma               0.551 (0.514-0.588)       243        9.8
# Parkinsons           0.860 (0.791-0.963)       3          0.1
# Multiple_Sclerosis   0.702 (0.569-0.804)       14         0.5
# Thyroid_Disorders    0.624 (0.575-0.675)       127        5.0
# --------------------------------------------------------------------------------
# {'ASCVD': {'auc': 0.6864536437575022,
#   'n_events': 151,
#   'event_rate': 5.893832943013271,
#   'ci_lower': 0.6408218399773111,
#   'ci_upper': 0.7333201768648648},
#  'Diabetes': {'auc': 0.6948478235224727,
#   'n_events': 140,
#   'event_rate': 5.46448087431694,
#   'ci_lower': 0.6473089499538704,
#   'ci_upper': 0.7462902778905613},
#  'Atrial_Fib': {'auc': 0.45752190847127555,
#   'n_events': 26,
#   'event_rate': 1.0180109631949883,
#   'ci_lower': 0.3765504663397537,
#   'ci_upper': 0.549752759702033},
#  'CKD': {'auc': 0.6191483667044775,
#   'n_events': 31,
#   'event_rate': 1.209992193598751,
#   'ci_lower': 0.5314332651789754,
#   'ci_upper': 0.7200861253930616},
#  'All_Cancers': {'auc': 0.5682514101531023,
#   'n_events': 80,
#   'event_rate': 3.12256049960968,
#   'ci_lower': 0.5120910812711724,
#   'ci_upper': 0.6353951505902593},
#  'Stroke': {'auc': 0.5228362227475702,
#   'n_events': 24,
#   'event_rate': 0.936768149882904,
#   'ci_lower': 0.4250125110311483,
#   'ci_upper': 0.6421851140802983},
#  'Heart_Failure': {'auc': 0.48437031375470435,
#   'n_events': 41,
#   'event_rate': 1.600312256049961,
#   'ci_lower': 0.4000569772444062,
#   'ci_upper': 0.5829878943835558},
#  'Pneumonia': {'auc': 0.5213897223839451,
#   'n_events': 81,
#   'event_rate': 3.161592505854801,
#   'ci_lower': 0.44526085549502514,
#   'ci_upper': 0.5873347672542176},
#  'COPD': {'auc': 0.5795685088477289,
#   'n_events': 86,
#   'event_rate': 3.356752537080406,
#   'ci_lower': 0.5037951438074005,
#   'ci_upper': 0.6386620279801463},
#  'Osteoporosis': {'auc': 0.6537282722849733,
#   'n_events': 37,
#   'event_rate': 1.4458772958186792,
#   'ci_lower': 0.57519468889381,
#   'ci_upper': 0.7250996227780337},
#  'Anemia': {'auc': 0.5188523695129941,
#   'n_events': 152,
#   'event_rate': 5.932864949258392,
#   'ci_lower': 0.47449421489647803,
#   'ci_upper': 0.5622513449920058},
#  'Colorectal_Cancer': {'auc': 0.5539649209486166,
#   'n_events': 32,
#   'event_rate': 1.249024199843872,
#   'ci_lower': 0.4570752612294831,
#   'ci_upper': 0.6471858726846023},
#  'Breast_Cancer': {'auc': 0.5455464366856773,
#   'n_events': 79,
#   'event_rate': 5.470914127423822,
#   'ci_lower': 0.4899387778175406,
#   'ci_upper': 0.6053895013631032},
#  'Prostate_Cancer': {'auc': 0.6192062043795621,
#   'n_events': 20,
#   'event_rate': 1.7921146953405016,
#   'ci_lower': 0.49126920776618593,
#   'ci_upper': 0.7352722095230612},
#  'Lung_Cancer': {'auc': 0.5747486617051834,
#   'n_events': 9,
#   'event_rate': 0.351288056206089,
#   'ci_lower': 0.3993441660140955,
#   'ci_upper': 0.779266812523582},
#  'Bladder_Cancer': {'auc': 0.695599128540305,
#   'n_events': 9,
#   'event_rate': 0.3516998827667058,
#   'ci_lower': 0.5359305469016429,
#   'ci_upper': 0.8901399537215107},
#  'Secondary_Cancer': {'auc': 0.522943354683747,
#   'n_events': 64,
#   'event_rate': 2.498048399687744,
#   'ci_lower': 0.4557666913500571,
#   'ci_upper': 0.5930892312113815},
#  'Depression': {'auc': 0.5144836186680763,
#   'n_events': 189,
#   'event_rate': 7.467404188067957,
#   'ci_lower': 0.4770597014925373,
#   'ci_upper': 0.5486546698419872},
#  'Anxiety': {'auc': 0.47254238782656893,
#   'n_events': 131,
#   'event_rate': 5.12720156555773,
#   'ci_lower': 0.41854095433452193,
#   'ci_upper': 0.511523279657422},
#  'Bipolar_Disorder': {'auc': 0.48165401252306483,
#   'n_events': 13,
#   'event_rate': 0.5086071987480438,
#   'ci_lower': 0.3143777843291405,
#   'ci_upper': 0.648258048457046},
#  'Rheumatoid_Arthritis': {'auc': 0.5168200931924082,
#   'n_events': 42,
#   'event_rate': 1.643192488262911,
#   'ci_lower': 0.3730777776374252,
#   'ci_upper': 0.6004145208620846},
#  'Psoriasis': {'auc': 0.4578005115089514,
#   'n_events': 23,
#   'event_rate': 0.8998435054773083,
#   'ci_lower': 0.32347140039447736,
#   'ci_upper': 0.5890542636928001},
#  'Ulcerative_Colitis': {'auc': 0.5342336407553798,
#   'n_events': 18,
#   'event_rate': 0.7064364207221351,
#   'ci_lower': 0.349486928761063,
#   'ci_upper': 0.6764636065220482},
#  'Crohns_Disease': {'auc': 0.516259842519685,
#   'n_events': 10,
#   'event_rate': 0.39215686274509803,
#   'ci_lower': 0.3398843273399837,
#   'ci_upper': 0.7380539849407121},
#  'Asthma': {'auc': 0.5506036157841464,
#   'n_events': 243,
#   'event_rate': 9.834075273168757,
#   'ci_lower': 0.5138270655513247,
#   'ci_upper': 0.5875962359957226},
#  'Parkinsons': {'auc': 0.8599166015115975,
#   'n_events': 3,
#   'event_rate': 0.11714174150722373,
#   'ci_lower': 0.7913247362250879,
#   'ci_upper': 0.96337890625},
#  'Multiple_Sclerosis': {'auc': 0.7021791767554479,
#   'n_events': 14,
#   'event_rate': 0.5488043904351235,
#   'ci_lower': 0.5691688358170105,
#   'ci_upper': 0.8042605309122367},
#  'Thyroid_Disorders': {'auc': 0.6242687836505036,
#   'n_events': 127,
#   'event_rate': 4.957064793130367,
#   'ci_lower': 0.5749249572780553,
#   'ci_upper': 0.6750406451475871}}

# %%
from fig5utils import *
import pandas as pd
import numpy as np
import torch

# Load full pce_df
pce_df_full = pd.read_csv('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/pce_prevent_full.csv')
disease_names = essentials['disease_names']

# Storage for results - Dynamic predictions
joint_10yr_results = []
joint_30yr_results = []
fixed_10yr_results = []
fixed_30yr_results = []

# Storage for results - Static predictions (1-year score for 10-year outcome)
joint_static_10yr_results = []
fixed_static_10yr_results = []

# Loop through checkpoints 0-40 (batch_0_10000 to batch_390000_400000)
for batch_idx in range(41):
    start_idx = batch_idx * 10000
    end_idx = (batch_idx + 1) * 10000
    
    print(f"\n{'='*80}")
    print(f"Processing batch {batch_idx}: {start_idx} to {end_idx}")
    print(f"{'='*80}")
    
    # Get pce_df subset for this batch
    pce_df_subset = pce_df_full[start_idx:end_idx].copy().reset_index(drop=True)
    
    # === JOINT PHI CHECKPOINTS ===
    joint_ckpt_path = f'/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_{start_idx}_{end_idx}.pt'
    
    try:
        joint_ckpt = torch.load(joint_ckpt_path, weights_only=False)
        model.load_state_dict(joint_ckpt['model_state_dict'])
        
        # Use Y from checkpoint and update model.Y so forward() uses correct patients
        Y_batch = joint_ckpt['Y']
        model.Y = torch.tensor(Y_batch, dtype=torch.float32)
        model.N = Y_batch.shape[0]  # Update N to match new Y size
        
        # 10-year predictions
        print(f"\nJoint Phi - 10 year predictions...")
        joint_10yr = evaluate_major_diseases_wsex_with_bootstrap_dynamic(
            model, Y_batch, E_100k, disease_names, pce_df_subset, 
            n_bootstraps=100, follow_up_duration_years=10, patient_indices=None
        )
        joint_10yr['batch_idx'] = batch_idx
        joint_10yr_results.append(joint_10yr)
        
        # 30-year predictions
        print(f"\nJoint Phi - 30 year predictions...")
        joint_30yr = evaluate_major_diseases_wsex_with_bootstrap_dynamic(
            model, Y_batch, E_100k, disease_names, pce_df_subset, 
            n_bootstraps=100, follow_up_duration_years=30, patient_indices=None
        )
        joint_30yr['batch_idx'] = batch_idx
        joint_30yr_results.append(joint_30yr)
        
        # Static 10-year predictions (using 1-year score)
        print(f"\nJoint Phi - Static 10 year predictions (1-year score)...")
        joint_static_10yr = evaluate_major_diseases_wsex_with_bootstrap(
            model=model,
            Y_100k=Y_batch,
            E_100k=E_100k,
            disease_names=disease_names,
            pce_df=pce_df_subset,
            n_bootstraps=100,
            follow_up_duration_years=10,
        )
        joint_static_10yr['batch_idx'] = batch_idx
        joint_static_10yr_results.append(joint_static_10yr)
        
    except FileNotFoundError:
        print(f"Joint phi checkpoint not found: {joint_ckpt_path}")
        continue
    except Exception as e:
        print(f"Error processing joint phi checkpoint {batch_idx}: {e}")
        continue
    
    # === FIXED PHI CHECKPOINTS ===
    fixed_ckpt_path = f'/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs_fromclaudeoutput/model_enroll_fixedphi_sex_{start_idx}_{end_idx}.pt'
    
    try:
        fixed_ckpt = torch.load(fixed_ckpt_path, weights_only=False)
        model.load_state_dict(fixed_ckpt['model_state_dict'])
        
        # For fixed phi, Y is not saved in checkpoint, so extract from full Y tensor
        # Load full Y tensor if not already available
        if 'Y_full' not in globals():
            Y_full = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/Y_tensor.pt')
        if 'E_full' not in globals():
            E_full = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_enrollment_full.pt')
        
        # Extract batch from full tensors
        Y_batch = Y_full[start_idx:end_idx]
        E_batch = E_full[start_idx:end_idx]
        
        # Update model.Y and model.N so forward() uses correct patients
        model.Y = torch.tensor(Y_batch, dtype=torch.float32)
        model.N = Y_batch.shape[0]  # Update N to match new Y size
       
        # 10-year predictions
        print(f"\nFixed Phi - 10 year predictions...")
        fixed_10yr = evaluate_major_diseases_wsex_with_bootstrap_dynamic(
            model, Y_batch, E_batch, disease_names, pce_df_subset, 
            n_bootstraps=100, follow_up_duration_years=10, patient_indices=None
        )
        fixed_10yr['batch_idx'] = batch_idx
        fixed_10yr_results.append(fixed_10yr)
        
        # 30-year predictions
        print(f"\nFixed Phi - 30 year predictions...")
        fixed_30yr = evaluate_major_diseases_wsex_with_bootstrap_dynamic(
            model, Y_batch, E_batch, disease_names, pce_df_subset, 
            n_bootstraps=100, follow_up_duration_years=30, patient_indices=None
        )
        fixed_30yr['batch_idx'] = batch_idx
        fixed_30yr_results.append(fixed_30yr)
        
        # Static 10-year predictions (using 1-year score)
        print(f"\nFixed Phi - Static 10 year predictions (1-year score)...")
        fixed_static_10yr = evaluate_major_diseases_wsex_with_bootstrap(
            model=model,
            Y_100k=Y_batch,
            E_100k=E_batch,
            disease_names=disease_names,
            pce_df=pce_df_subset,
            n_bootstraps=100,
            follow_up_duration_years=10,
        )
        fixed_static_10yr['batch_idx'] = batch_idx
        fixed_static_10yr_results.append(fixed_static_10yr)
        
    except FileNotFoundError:
        print(f"Fixed phi checkpoint not found: {fixed_ckpt_path}")
        continue
    except Exception as e:
        print(f"Error processing fixed phi checkpoint {batch_idx}: {e}")
        continue

print(f"\n{'='*80}")
print("Completed processing all checkpoints!")
print(f"{'='*80}")
# Out:
# ================================================================================
# Processing batch 0: 0 to 10000
# ================================================================================
#
# Joint Phi - 10 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.655 (0.637-0.674) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.578 (0.558-0.606) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.525 (0.504-0.545) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 9864 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.710 (0.679-0.738) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.660 (0.636-0.681) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.654 (0.608-0.698) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.691 (0.656-0.723) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.683 (0.661-0.712) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.641 (0.621-0.667) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.683 (0.644-0.721) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 9961 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.587 (0.560-0.616) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.588 (0.540-0.635) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.515 (0.485-0.549) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.652 (0.618-0.687) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.5%) (from 4547 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.679 (0.625-0.726) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 9992 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.729 (0.659-0.785) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 9976 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.602 (0.579-0.629) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.476 (0.443-0.502) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.1%) (from 9912 individuals)
# Excluded 88 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.510 (0.475-0.552) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 9975 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.539 (0.443-0.633) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 9984 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.559 (0.524-0.603) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 9963 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.444 (0.342-0.550) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 9981 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.524 (0.407-0.603) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 9947 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.574 (0.475-0.658) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 9967 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.507 (0.488-0.531) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.3%) (from 9687 individuals)
# Excluded 313 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.742 (0.685-0.795) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 9997 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.507 (0.401-0.626) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 9979 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.593 (0.571-0.620) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.655 (0.637-0.674)       831        8.3
# Diabetes             0.578 (0.558-0.606)       581        5.8
# Atrial_Fib           0.525 (0.504-0.545)       376        3.8
# CKD                  0.710 (0.679-0.738)       207        2.1
# All_Cancers          0.660 (0.636-0.681)       480        4.8
# Stroke               0.654 (0.608-0.698)       129        1.3
# Heart_Failure        0.691 (0.656-0.723)       205        2.1
# Pneumonia            0.683 (0.661-0.712)       335        3.4
# COPD                 0.641 (0.621-0.667)       394        3.9
# Osteoporosis         0.683 (0.644-0.721)       219        2.2
# Anemia               0.587 (0.560-0.616)       523        5.2
# Colorectal_Cancer    0.588 (0.540-0.635)       105        1.1
# Breast_Cancer        0.515 (0.485-0.549)       214        4.0
# Prostate_Cancer      0.652 (0.618-0.687)       204        4.5
# Lung_Cancer          0.679 (0.625-0.726)       75         0.8
# Bladder_Cancer       0.729 (0.659-0.785)       49         0.5
# Secondary_Cancer     0.602 (0.579-0.629)       276        2.8
# Depression           0.476 (0.443-0.502)       405        4.1
# Anxiety              0.510 (0.475-0.552)       241        2.4
# Bipolar_Disorder     0.539 (0.443-0.633)       34         0.3
# Rheumatoid_Arthritis 0.559 (0.524-0.603)       123        1.2
# Psoriasis            0.444 (0.342-0.550)       40         0.4
# Ulcerative_Colitis   0.524 (0.407-0.603)       50         0.5
# Crohns_Disease       0.574 (0.475-0.658)       31         0.3
# Asthma               0.507 (0.488-0.531)       606        6.3
# Parkinsons           0.742 (0.685-0.795)       46         0.5
# Multiple_Sclerosis   0.507 (0.401-0.626)       21         0.2
# Thyroid_Disorders    0.593 (0.571-0.620)       479        4.8
# --------------------------------------------------------------------------------
#
# Joint Phi - 30 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.757 (0.712-0.797) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.658 (0.616-0.700) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.611 (0.507-0.702) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.484-0.702) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.605 (0.548-0.663) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.513 (0.396-0.588) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.632 (0.511-0.727) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.544 (0.489-0.615) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.630 (0.571-0.685) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.555 (0.451-0.639) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.537 (0.489-0.582) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.511 (0.384-0.646) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.584 (0.525-0.652) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.719 (0.620-0.805) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.717 (0.585-0.871) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.519 (0.298-0.763) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.532 (0.479-0.579) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.541 (0.505-0.586) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.500 (0.455-0.540) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.381 (0.261-0.500) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.484-0.667) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.453 (0.340-0.583) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.367-0.654) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.412 (0.295-0.507) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.492-0.559) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.617 (0.476-0.749) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.498 (0.328-0.616) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.636 (0.586-0.679) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.757 (0.712-0.797)       136        5.4
# Diabetes             0.658 (0.616-0.700)       137        5.4
# Atrial_Fib           0.611 (0.507-0.702)       29         1.1
# CKD                  0.579 (0.484-0.702)       33         1.3
# All_Cancers          0.605 (0.548-0.663)       94         3.7
# Stroke               0.513 (0.396-0.588)       30         1.2
# Heart_Failure        0.632 (0.511-0.727)       32         1.3
# Pneumonia            0.544 (0.489-0.615)       70         2.8
# COPD                 0.630 (0.571-0.685)       81         3.2
# Osteoporosis         0.555 (0.451-0.639)       41         1.6
# Anemia               0.537 (0.489-0.582)       154        6.1
# Colorectal_Cancer    0.511 (0.384-0.646)       25         1.0
# Breast_Cancer        0.584 (0.525-0.652)       65         4.6
# Prostate_Cancer      0.719 (0.620-0.805)       35         3.1
# Lung_Cancer          0.717 (0.585-0.871)       9          0.4
# Bladder_Cancer       0.519 (0.298-0.763)       9          0.4
# Secondary_Cancer     0.532 (0.479-0.579)       71         2.8
# Depression           0.541 (0.505-0.586)       192        7.6
# Anxiety              0.500 (0.455-0.540)       136        5.4
# Bipolar_Disorder     0.381 (0.261-0.500)       17         0.7
# Rheumatoid_Arthritis 0.579 (0.484-0.667)       36         1.4
# Psoriasis            0.453 (0.340-0.583)       24         0.9
# Ulcerative_Colitis   0.526 (0.367-0.654)       22         0.9
# Crohns_Disease       0.412 (0.295-0.507)       20         0.8
# Asthma               0.526 (0.492-0.559)       218        8.8
# Parkinsons           0.617 (0.476-0.749)       2          0.1
# Multiple_Sclerosis   0.498 (0.328-0.616)       11         0.4
# Thyroid_Disorders    0.636 (0.586-0.679)       145        5.7
# --------------------------------------------------------------------------------
#
# Joint Phi - Static 10 year predictions (1-year score)...
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.712 (0.690-0.732) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.666, Events = 273/5409
#    Male: AUC = 0.702, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.677, Events = 8/37
#    Breast_Cancer: AUC = 0.631, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.628 (0.609-0.648) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.618, Events = 264/5409
#    Male: AUC = 0.628, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.684 (0.661-0.711) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.697, Events = 197/5372
#    Male: AUC = 0.683, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.708 (0.675-0.738) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.732, Events = 101/5409
#    Male: AUC = 0.684, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.680 (0.655-0.705) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.672, Events = 134/5409
#    Male: AUC = 0.669, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.654 (0.608-0.706) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.624, Events = 64/5409
#    Male: AUC = 0.683, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.698 (0.657-0.729) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.717, Events = 83/5409
#    Male: AUC = 0.678, Events = 122/4591
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.683 (0.655-0.716) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.684, Events = 135/5409
#    Male: AUC = 0.676, Events = 200/4591
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.646 (0.622-0.674) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.672, Events = 176/5409
#    Male: AUC = 0.620, Events = 218/4591
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.676 (0.648-0.712) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.681, Events = 128/5379
#    Male: AUC = 0.677, Events = 90/4582
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.593 (0.569-0.621) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.549, Events = 280/5409
#    Male: AUC = 0.643, Events = 243/4591
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.654 (0.614-0.700) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.625, Events = 56/5409
#    Male: AUC = 0.688, Events = 49/4591
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.575 (0.534-0.618) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.672 (0.641-0.707) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.4%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.691 (0.635-0.737) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.696, Events = 48/5406
#    Male: AUC = 0.680, Events = 27/4586
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.740 (0.681-0.796) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.628, Events = 24/5399
#    Male: AUC = 0.847, Events = 25/4577
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.607 (0.570-0.640) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.613, Events = 147/5409
#    Male: AUC = 0.600, Events = 129/4591
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.470 (0.443-0.499) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.0%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.474, Events = 210/5351
#    Male: AUC = 0.476, Events = 191/4561
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.506 (0.472-0.539) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.512, Events = 130/5391
#    Male: AUC = 0.504, Events = 110/4584
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.373 (0.275-0.490) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.392, Events = 14/5399
#    Male: AUC = 0.359, Events = 19/4585
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.598 (0.548-0.651) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.597, Events = 62/5381
#    Male: AUC = 0.595, Events = 60/4582
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.432 (0.351-0.513) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.416, Events = 15/5405
#    Male: AUC = 0.443, Events = 25/4576
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.587 (0.496-0.664) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.599, Events = 31/5378
#    Male: AUC = 0.573, Events = 19/4569
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.503 (0.387-0.609) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.548, Events = 20/5388
#    Male: AUC = 0.423, Events = 11/4579
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.511 (0.486-0.529) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.1%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.505, Events = 321/5214
#    Male: AUC = 0.555, Events = 264/4473
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.741 (0.665-0.793) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.787, Events = 21/5407
#    Male: AUC = 0.700, Events = 25/4590
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.524 (0.403-0.664) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.533, Events = 13/5394
#    Male: AUC = 0.515, Events = 8/4585
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.579 (0.554-0.603) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.573, Events = 385/5409
#    Male: AUC = 0.573, Events = 94/4591
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.712 (0.690-0.732)       831        8.3
# Diabetes             0.628 (0.609-0.648)       581        5.8
# Atrial_Fib           0.684 (0.661-0.711)       376        3.8
# CKD                  0.708 (0.675-0.738)       207        2.1
# All_Cancers          0.680 (0.655-0.705)       480        4.8
# Stroke               0.654 (0.608-0.706)       129        1.3
# Heart_Failure        0.698 (0.657-0.729)       205        2.1
# Pneumonia            0.683 (0.655-0.716)       335        3.4
# COPD                 0.646 (0.622-0.674)       394        3.9
# Osteoporosis         0.676 (0.648-0.712)       219        2.2
# Anemia               0.593 (0.569-0.621)       523        5.2
# Colorectal_Cancer    0.654 (0.614-0.700)       105        1.1
# Breast_Cancer        0.575 (0.534-0.618)       214        4.0
# Prostate_Cancer      0.672 (0.641-0.707)       204        4.4
# Lung_Cancer          0.691 (0.635-0.737)       75         0.8
# Bladder_Cancer       0.740 (0.681-0.796)       49         0.5
# Secondary_Cancer     0.607 (0.570-0.640)       276        2.8
# Depression           0.470 (0.443-0.499)       405        4.0
# Anxiety              0.506 (0.472-0.539)       241        2.4
# Bipolar_Disorder     0.373 (0.275-0.490)       34         0.3
# Rheumatoid_Arthritis 0.598 (0.548-0.651)       123        1.2
# Psoriasis            0.432 (0.351-0.513)       40         0.4
# Ulcerative_Colitis   0.587 (0.496-0.664)       50         0.5
# Crohns_Disease       0.503 (0.387-0.609)       31         0.3
# Asthma               0.511 (0.486-0.529)       606        6.1
# Parkinsons           0.741 (0.665-0.793)       46         0.5
# Multiple_Sclerosis   0.524 (0.403-0.664)       21         0.2
# Thyroid_Disorders    0.579 (0.554-0.603)       479        4.8
# --------------------------------------------------------------------------------
#
# Fixed Phi - 10 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.608 (0.587-0.625) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.574 (0.548-0.595) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.599 (0.574-0.621) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 9864 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.713 (0.675-0.744) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.651 (0.632-0.674) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.651 (0.608-0.693) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.692 (0.651-0.729) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.675 (0.644-0.699) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.643 (0.613-0.669) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.654 (0.612-0.678) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 9961 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.585 (0.555-0.608) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.607 (0.555-0.665) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.531 (0.499-0.565) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.665 (0.632-0.694) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.5%) (from 4547 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.678 (0.614-0.725) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 9992 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.702 (0.648-0.776) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 9976 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.594 (0.565-0.618) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.486 (0.460-0.520) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.1%) (from 9912 individuals)
# Excluded 88 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.494 (0.465-0.528) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 9975 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.586 (0.509-0.698) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 9984 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.572 (0.531-0.626) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 9963 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.434 (0.348-0.508) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 9981 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.433-0.623) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 9947 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.563 (0.467-0.661) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 9967 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.508 (0.483-0.534) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.3%) (from 9687 individuals)
# Excluded 313 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.754 (0.696-0.816) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 9997 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.507 (0.378-0.630) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 9979 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.542 (0.520-0.566) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.608 (0.587-0.625)       831        8.3
# Diabetes             0.574 (0.548-0.595)       581        5.8
# Atrial_Fib           0.599 (0.574-0.621)       376        3.8
# CKD                  0.713 (0.675-0.744)       207        2.1
# All_Cancers          0.651 (0.632-0.674)       480        4.8
# Stroke               0.651 (0.608-0.693)       129        1.3
# Heart_Failure        0.692 (0.651-0.729)       205        2.1
# Pneumonia            0.675 (0.644-0.699)       335        3.4
# COPD                 0.643 (0.613-0.669)       394        3.9
# Osteoporosis         0.654 (0.612-0.678)       219        2.2
# Anemia               0.585 (0.555-0.608)       523        5.2
# Colorectal_Cancer    0.607 (0.555-0.665)       105        1.1
# Breast_Cancer        0.531 (0.499-0.565)       214        4.0
# Prostate_Cancer      0.665 (0.632-0.694)       204        4.5
# Lung_Cancer          0.678 (0.614-0.725)       75         0.8
# Bladder_Cancer       0.702 (0.648-0.776)       49         0.5
# Secondary_Cancer     0.594 (0.565-0.618)       276        2.8
# Depression           0.486 (0.460-0.520)       405        4.1
# Anxiety              0.494 (0.465-0.528)       241        2.4
# Bipolar_Disorder     0.586 (0.509-0.698)       34         0.3
# Rheumatoid_Arthritis 0.572 (0.531-0.626)       123        1.2
# Psoriasis            0.434 (0.348-0.508)       40         0.4
# Ulcerative_Colitis   0.526 (0.433-0.623)       50         0.5
# Crohns_Disease       0.563 (0.467-0.661)       31         0.3
# Asthma               0.508 (0.483-0.534)       606        6.3
# Parkinsons           0.754 (0.696-0.816)       46         0.5
# Multiple_Sclerosis   0.507 (0.378-0.630)       21         0.2
# Thyroid_Disorders    0.542 (0.520-0.566)       479        4.8
# --------------------------------------------------------------------------------
#
# Fixed Phi - 30 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.528-0.624) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.547 (0.498-0.597) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.531 (0.452-0.620) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.585 (0.490-0.678) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.575 (0.529-0.621) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.516 (0.406-0.629) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.592 (0.492-0.687) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.531 (0.464-0.598) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.619 (0.562-0.687) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.485 (0.405-0.566) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.520 (0.468-0.562) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.482 (0.399-0.616) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.543 (0.474-0.600) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.611 (0.525-0.713) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.682 (0.552-0.794) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.476 (0.347-0.624) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.521 (0.455-0.593) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.499 (0.452-0.544) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.507 (0.462-0.553) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.437 (0.313-0.561) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.535 (0.440-0.620) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.453 (0.343-0.583) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.410 (0.286-0.526) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.457 (0.323-0.597) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.499 (0.470-0.536) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.545 (0.509-0.586) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.407 (0.258-0.584) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.489-0.565) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.579 (0.528-0.624)       136        5.4
# Diabetes             0.547 (0.498-0.597)       137        5.4
# Atrial_Fib           0.531 (0.452-0.620)       29         1.1
# CKD                  0.585 (0.490-0.678)       33         1.3
# All_Cancers          0.575 (0.529-0.621)       94         3.7
# Stroke               0.516 (0.406-0.629)       30         1.2
# Heart_Failure        0.592 (0.492-0.687)       32         1.3
# Pneumonia            0.531 (0.464-0.598)       70         2.8
# COPD                 0.619 (0.562-0.687)       81         3.2
# Osteoporosis         0.485 (0.405-0.566)       41         1.6
# Anemia               0.520 (0.468-0.562)       154        6.1
# Colorectal_Cancer    0.482 (0.399-0.616)       25         1.0
# Breast_Cancer        0.543 (0.474-0.600)       65         4.6
# Prostate_Cancer      0.611 (0.525-0.713)       35         3.1
# Lung_Cancer          0.682 (0.552-0.794)       9          0.4
# Bladder_Cancer       0.476 (0.347-0.624)       9          0.4
# Secondary_Cancer     0.521 (0.455-0.593)       71         2.8
# Depression           0.499 (0.452-0.544)       192        7.6
# Anxiety              0.507 (0.462-0.553)       136        5.4
# Bipolar_Disorder     0.437 (0.313-0.561)       17         0.7
# Rheumatoid_Arthritis 0.535 (0.440-0.620)       36         1.4
# Psoriasis            0.453 (0.343-0.583)       24         0.9
# Ulcerative_Colitis   0.410 (0.286-0.526)       22         0.9
# Crohns_Disease       0.457 (0.323-0.597)       20         0.8
# Asthma               0.499 (0.470-0.536)       218        8.8
# Parkinsons           0.545 (0.509-0.586)       2          0.1
# Multiple_Sclerosis   0.407 (0.258-0.584)       11         0.4
# Thyroid_Disorders    0.526 (0.489-0.565)       145        5.7
# --------------------------------------------------------------------------------
#
# Fixed Phi - Static 10 year predictions (1-year score)...
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.683 (0.665-0.701) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.669, Events = 273/5409
#    Male: AUC = 0.685, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.707, Events = 8/37
#    Breast_Cancer: AUC = 0.549, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.613 (0.589-0.634) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.604, Events = 264/5409
#    Male: AUC = 0.617, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.701 (0.680-0.726) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.707, Events = 197/5372
#    Male: AUC = 0.706, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.710 (0.674-0.741) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.733, Events = 101/5409
#    Male: AUC = 0.687, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.676 (0.654-0.703) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.671, Events = 134/5409
#    Male: AUC = 0.672, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.652 (0.609-0.701) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.626, Events = 64/5409
#    Male: AUC = 0.678, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# ...
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.513 (0.393-0.631) (calculated on 2522 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2522 individuals)
# Excluded 16 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.545 (0.410-0.715) (calculated on 2529 individuals)
# Events (10-Year in Eval Cohort): 13 (0.5%) (from 2529 individuals)
# Excluded 9 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.570 (0.535-0.606) (calculated on 2484 individuals)
# Events (10-Year in Eval Cohort): 241 (9.7%) (from 2484 individuals)
# Excluded 54 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.574 (0.219-0.925) (calculated on 2537 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2537 individuals)
# Excluded 1 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.762 (0.513-0.964) (calculated on 2534 individuals)
# Events (10-Year in Eval Cohort): 6 (0.2%) (from 2534 individuals)
# Excluded 4 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.612 (0.564-0.660) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 125 (4.9%) (from 2538 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.712 (0.670-0.753)       160        6.3
# Diabetes             0.681 (0.644-0.733)       159        6.3
# Atrial_Fib           0.432 (0.341-0.551)       26         1.0
# CKD                  0.613 (0.523-0.719)       26         1.0
# All_Cancers          0.608 (0.554-0.677)       92         3.6
# Stroke               0.500 (0.407-0.580)       33         1.3
# Heart_Failure        0.645 (0.574-0.715)       30         1.2
# Pneumonia            0.571 (0.499-0.644)       51         2.0
# COPD                 0.607 (0.543-0.672)       79         3.1
# Osteoporosis         0.550 (0.395-0.671)       22         0.9
# Anemia               0.526 (0.479-0.585)       152        6.0
# Colorectal_Cancer    0.437 (0.330-0.534)       23         0.9
# Breast_Cancer        0.580 (0.494-0.645)       88         6.0
# Prostate_Cancer      0.640 (0.538-0.742)       37         3.5
# Lung_Cancer          0.544 (0.332-0.682)       8          0.3
# Bladder_Cancer       0.590 (0.396-0.820)       9          0.4
# Secondary_Cancer     0.562 (0.485-0.625)       73         2.9
# Depression           0.522 (0.483-0.578)       196        7.9
# Anxiety              0.561 (0.514-0.609)       144        5.7
# Bipolar_Disorder     0.587 (0.465-0.717)       14         0.6
# Rheumatoid_Arthritis 0.607 (0.536-0.713)       35         1.4
# Psoriasis            0.503 (0.367-0.648)       21         0.8
# Ulcerative_Colitis   0.513 (0.393-0.631)       22         0.9
# Crohns_Disease       0.545 (0.410-0.715)       13         0.5
# Asthma               0.570 (0.535-0.606)       241        9.7
# Parkinsons           0.574 (0.219-0.925)       2          0.1
# Multiple_Sclerosis   0.762 (0.513-0.964)       6          0.2
# Thyroid_Disorders    0.612 (0.564-0.660)       125        4.9
# --------------------------------------------------------------------------------
#
# Joint Phi - Static 10 year predictions (1-year score)...
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.717 (0.697-0.731) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 901 (9.0%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.713, Events = 319/5564
#    Male: AUC = 0.683, Events = 582/4436
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.891, Events = 8/48
#    Breast_Cancer: AUC = 0.731, Events = 17/174
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.615 (0.594-0.640) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 613 (6.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.618, Events = 259/5564
#    Male: AUC = 0.604, Events = 354/4436
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.680 (0.649-0.703) (calculated on 9860 individuals)
# Events (10-Year in Eval Cohort): 379 (3.8%) (from 10000 individuals)
# Excluded 140 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.677, Events = 202/5523
#    Male: AUC = 0.692, Events = 170/4337
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.718 (0.678-0.757) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 184 (1.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.689, Events = 88/5564
#    Male: AUC = 0.745, Events = 96/4436
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.664 (0.636-0.683) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 499 (5.0%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.584, Events = 152/5564
#    Male: AUC = 0.685, Events = 347/4436
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.645 (0.605-0.696) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 142 (1.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.723, Events = 58/5564
#    Male: AUC = 0.583, Events = 84/4436
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.708 (0.678-0.746) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 210 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.760, Events = 82/5564
#    Male: AUC = 0.664, Events = 128/4436
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.660 (0.636-0.688) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 351 (3.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.649, Events = 150/5564
#    Male: AUC = 0.662, Events = 201/4436
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.639 (0.617-0.661) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 429 (4.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.652, Events = 207/5564
#    Male: AUC = 0.622, Events = 222/4436
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.696 (0.666-0.727) (calculated on 9970 individuals)
# Events (10-Year in Eval Cohort): 223 (2.2%) (from 10000 individuals)
# Excluded 30 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.699, Events = 117/5537
#    Male: AUC = 0.696, Events = 106/4433
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.585 (0.560-0.612) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 552 (5.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.573, Events = 311/5564
#    Male: AUC = 0.601, Events = 241/4436
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.618 (0.574-0.672) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 118 (1.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.574, Events = 50/5564
#    Male: AUC = 0.646, Events = 68/4436
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5564 individuals in cohort
# AUC: 0.523 (0.486-0.568) (calculated on 5564 individuals)
# Events (10-Year in Eval Cohort): 225 (4.0%) (from 5564 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4436 individuals in cohort
# AUC: 0.685 (0.650-0.726) (calculated on 4386 individuals)
# Events (10-Year in Eval Cohort): 178 (4.0%) (from 4436 individuals)
# Excluded 50 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.671 (0.622-0.718) (calculated on 9995 individuals)
# Events (10-Year in Eval Cohort): 90 (0.9%) (from 10000 individuals)
# Excluded 5 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.644, Events = 49/5564
#    Male: AUC = 0.702, Events = 41/4431
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.697 (0.635-0.766) (calculated on 9977 individuals)
# Events (10-Year in Eval Cohort): 58 (0.6%) (from 10000 individuals)
# Excluded 23 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.697, Events = 35/5558
#    Male: AUC = 0.699, Events = 23/4419
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.608 (0.584-0.639) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 307 (3.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.568, Events = 163/5564
#    Male: AUC = 0.653, Events = 144/4436
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.489 (0.458-0.515) (calculated on 9894 individuals)
# Events (10-Year in Eval Cohort): 410 (4.1%) (from 10000 individuals)
# Excluded 106 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.512, Events = 228/5501
#    Male: AUC = 0.469, Events = 176/4393
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.525 (0.484-0.557) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 260 (2.6%) (from 10000 individuals)
# Excluded 19 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.539, Events = 144/5554
#    Male: AUC = 0.510, Events = 116/4427
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.485 (0.384-0.611) (calculated on 9985 individuals)
# Events (10-Year in Eval Cohort): 23 (0.2%) (from 10000 individuals)
# Excluded 15 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.521, Events = 16/5555
#    Male: AUC = 0.411, Events = 7/4430
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.602 (0.555-0.651) (calculated on 9952 individuals)
# Events (10-Year in Eval Cohort): 116 (1.2%) (from 10000 individuals)
# Excluded 48 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.641, Events = 62/5528
#    Male: AUC = 0.553, Events = 52/4424
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.595 (0.510-0.674) (calculated on 9985 individuals)
# Events (10-Year in Eval Cohort): 54 (0.5%) (from 10000 individuals)
# Excluded 15 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.622, Events = 27/5558
#    Male: AUC = 0.571, Events = 27/4427
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.598 (0.518-0.682) (calculated on 9940 individuals)
# Events (10-Year in Eval Cohort): 52 (0.5%) (from 10000 individuals)
# Excluded 60 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.705, Events = 25/5538
#    Male: AUC = 0.503, Events = 27/4402
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.634 (0.495-0.734) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 30 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.615, Events = 17/5546
#    Male: AUC = 0.661, Events = 13/4421
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.510 (0.485-0.536) (calculated on 9704 individuals)
# Events (10-Year in Eval Cohort): 635 (6.3%) (from 10000 individuals)
# Excluded 296 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.506, Events = 321/5373
#    Male: AUC = 0.549, Events = 288/4331
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.746 (0.672-0.808) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 53 (0.5%) (from 10000 individuals)
# Excluded 8 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.750, Events = 33/5559
#    Male: AUC = 0.740, Events = 20/4433
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.571 (0.455-0.705) (calculated on 9987 individuals)
# Events (10-Year in Eval Cohort): 18 (0.2%) (from 10000 individuals)
# Excluded 13 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.536, Events = 7/5555
#    Male: AUC = 0.595, Events = 11/4432
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.579 (0.554-0.605) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 458 (4.6%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.575, Events = 378/5564
#    Male: AUC = 0.570, Events = 80/4436
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.717 (0.697-0.731)       901        9.0
# Diabetes             0.615 (0.594-0.640)       613        6.1
# Atrial_Fib           0.680 (0.649-0.703)       379        3.8
# CKD                  0.718 (0.678-0.757)       184        1.8
# All_Cancers          0.664 (0.636-0.683)       499        5.0
# Stroke               0.645 (0.605-0.696)       142        1.4
# Heart_Failure        0.708 (0.678-0.746)       210        2.1
# Pneumonia            0.660 (0.636-0.688)       351        3.5
# COPD                 0.639 (0.617-0.661)       429        4.3
# Osteoporosis         0.696 (0.666-0.727)       223        2.2
# Anemia               0.585 (0.560-0.612)       552        5.5
# Colorectal_Cancer    0.618 (0.574-0.672)       118        1.2
# Breast_Cancer        0.523 (0.486-0.568)       225        4.0
# Prostate_Cancer      0.685 (0.650-0.726)       178        4.0
# Lung_Cancer          0.671 (0.622-0.718)       90         0.9
# Bladder_Cancer       0.697 (0.635-0.766)       58         0.6
# Secondary_Cancer     0.608 (0.584-0.639)       307        3.1
# Depression           0.489 (0.458-0.515)       410        4.1
# Anxiety              0.525 (0.484-0.557)       260        2.6
# Bipolar_Disorder     0.485 (0.384-0.611)       23         0.2
# Rheumatoid_Arthritis 0.602 (0.555-0.651)       116        1.2
# Psoriasis            0.595 (0.510-0.674)       54         0.5
# Ulcerative_Colitis   0.598 (0.518-0.682)       52         0.5
# Crohns_Disease       0.634 (0.495-0.734)       30         0.3
# Asthma               0.510 (0.485-0.536)       635        6.3
# Parkinsons           0.746 (0.672-0.808)       53         0.5
# Multiple_Sclerosis   0.571 (0.455-0.705)       18         0.2
# Thyroid_Disorders    0.579 (0.554-0.605)       458        4.6
# --------------------------------------------------------------------------------
# Fixed phi checkpoint not found: /Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs/output/model_enroll_fixedphi_sex_390000_400000.pt
#
# ================================================================================
# Processing batch 40: 400000 to 410000
# ================================================================================
# Joint phi checkpoint not found: /Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_prediction_jointphi_sex_pcs/enrollment_model_W0.0001_batch_400000_410000.pt
#
# ================================================================================
# Completed processing all checkpoints!
# ================================================================================

# %%
# Rerun only Fixed Phi evaluations with proper Y batch extraction
# (Joint phi results should already be in joint_*_results variables)

# Clear only fixed phi results to rerun them
fixed_10yr_results = []
fixed_30yr_results = []
fixed_static_10yr_results = []

# Load full Y and E tensors once
print("Loading full Y and E tensors...")
Y_full = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/Y_tensor.pt')
E_full = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_enrollment_full.pt')
print("Loaded full tensors!")

# Loop through checkpoints 0-40 (batch_0_10000 to batch_390000_400000)
for batch_idx in range(41):
    start_idx = batch_idx * 10000
    end_idx = (batch_idx + 1) * 10000
    
    print(f"\n{'='*80}")
    print(f"Processing FIXED PHI batch {batch_idx}: {start_idx} to {end_idx}")
    print(f"{'='*80}")
    
    # Get pce_df subset for this batch
    pce_df_subset = pce_df_full[start_idx:end_idx].copy().reset_index(drop=True)
    
    # === FIXED PHI CHECKPOINTS ===
    fixed_ckpt_path = f'/Users/sarahurbut/Library/CloudStorage/Dropbox/enrollment_predictions_fixedphi_withpcs_fromclaudeoutput/model_enroll_fixedphi_sex_{start_idx}_{end_idx}.pt'
    
    try:
        fixed_ckpt = torch.load(fixed_ckpt_path, weights_only=False)
        model.load_state_dict(fixed_ckpt['model_state_dict'])
        
        # For fixed phi, Y is not saved in checkpoint, so extract from full Y tensor
        # Extract batch from full tensors
        Y_batch = Y_full[start_idx:end_idx]
        E_batch = E_full[start_idx:end_idx]
        
        # Update model.Y and model.N so forward() uses correct patients
        model.Y = torch.tensor(Y_batch, dtype=torch.float32)
        model.N = Y_batch.shape[0]  # Update N to match new Y size
       
        # 10-year predictions
        print(f"\nFixed Phi - 10 year predictions...")
        fixed_10yr = evaluate_major_diseases_wsex_with_bootstrap_dynamic(
            model, Y_batch, E_batch, disease_names, pce_df_subset, 
            n_bootstraps=100, follow_up_duration_years=10, patient_indices=None
        )
        fixed_10yr['batch_idx'] = batch_idx
        fixed_10yr_results.append(fixed_10yr)
        
        # 30-year predictions
        print(f"\nFixed Phi - 30 year predictions...")
        fixed_30yr = evaluate_major_diseases_wsex_with_bootstrap_dynamic(
            model, Y_batch, E_batch, disease_names, pce_df_subset, 
            n_bootstraps=100, follow_up_duration_years=30, patient_indices=None
        )
        fixed_30yr['batch_idx'] = batch_idx
        fixed_30yr_results.append(fixed_30yr)
        
        # Static 10-year predictions (using 1-year score)
        print(f"\nFixed Phi - Static 10 year predictions (1-year score)...")
        fixed_static_10yr = evaluate_major_diseases_wsex_with_bootstrap(
            model=model,
            Y_100k=Y_batch,
            E_100k=E_batch,
            disease_names=disease_names,
            pce_df=pce_df_subset,
            n_bootstraps=100,
            follow_up_duration_years=10,
        )
        fixed_static_10yr['batch_idx'] = batch_idx
        fixed_static_10yr_results.append(fixed_static_10yr)
        
    except FileNotFoundError:
        print(f"Fixed phi checkpoint not found: {fixed_ckpt_path}")
        continue
    except Exception as e:
        print(f"Error processing fixed phi checkpoint {batch_idx}: {e}")
        continue

print(f"\n{'='*80}")
print("Completed processing all FIXED PHI checkpoints!")
print(f"{'='*80}")
# Out:
# Loading full Y and E tensors...
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/2217820238.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y_full = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/Y_tensor.pt')
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/2217820238.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E_full = torch.load('/Users/sarahurbut/Library/CloudStorage/Dropbox-Personal/data_for_running/E_enrollment_full.pt')
# Loaded full tensors!
#
# ================================================================================
# Processing FIXED PHI batch 0: 0 to 10000
# ================================================================================
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/2217820238.py:40: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   model.Y = torch.tensor(Y_batch, dtype=torch.float32)
# Fixed Phi - 10 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.608 (0.585-0.622) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.574 (0.553-0.594) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.599 (0.576-0.626) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 9864 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.713 (0.679-0.748) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.651 (0.632-0.668) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.651 (0.601-0.703) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.692 (0.654-0.723) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.675 (0.653-0.704) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.643 (0.617-0.670) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.654 (0.623-0.686) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 9961 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.585 (0.563-0.608) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.607 (0.559-0.655) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.531 (0.494-0.565) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.665 (0.636-0.703) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.5%) (from 4547 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.678 (0.625-0.727) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 9992 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.702 (0.655-0.773) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 9976 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.594 (0.566-0.623) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.486 (0.460-0.518) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.1%) (from 9912 individuals)
# Excluded 88 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.494 (0.466-0.530) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 9975 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.586 (0.495-0.700) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 9984 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.572 (0.530-0.621) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 9963 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.434 (0.347-0.530) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 9981 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.431-0.609) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 9947 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.563 (0.478-0.673) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 9967 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.508 (0.482-0.532) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.3%) (from 9687 individuals)
# Excluded 313 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.754 (0.691-0.809) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 9997 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.507 (0.413-0.619) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 9979 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.542 (0.518-0.570) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.608 (0.585-0.622)       831        8.3
# Diabetes             0.574 (0.553-0.594)       581        5.8
# Atrial_Fib           0.599 (0.576-0.626)       376        3.8
# CKD                  0.713 (0.679-0.748)       207        2.1
# All_Cancers          0.651 (0.632-0.668)       480        4.8
# Stroke               0.651 (0.601-0.703)       129        1.3
# Heart_Failure        0.692 (0.654-0.723)       205        2.1
# Pneumonia            0.675 (0.653-0.704)       335        3.4
# COPD                 0.643 (0.617-0.670)       394        3.9
# Osteoporosis         0.654 (0.623-0.686)       219        2.2
# Anemia               0.585 (0.563-0.608)       523        5.2
# Colorectal_Cancer    0.607 (0.559-0.655)       105        1.1
# Breast_Cancer        0.531 (0.494-0.565)       214        4.0
# Prostate_Cancer      0.665 (0.636-0.703)       204        4.5
# Lung_Cancer          0.678 (0.625-0.727)       75         0.8
# Bladder_Cancer       0.702 (0.655-0.773)       49         0.5
# Secondary_Cancer     0.594 (0.566-0.623)       276        2.8
# Depression           0.486 (0.460-0.518)       405        4.1
# Anxiety              0.494 (0.466-0.530)       241        2.4
# Bipolar_Disorder     0.586 (0.495-0.700)       34         0.3
# Rheumatoid_Arthritis 0.572 (0.530-0.621)       123        1.2
# Psoriasis            0.434 (0.347-0.530)       40         0.4
# Ulcerative_Colitis   0.526 (0.431-0.609)       50         0.5
# Crohns_Disease       0.563 (0.478-0.673)       31         0.3
# Asthma               0.508 (0.482-0.532)       606        6.3
# Parkinsons           0.754 (0.691-0.809)       46         0.5
# Multiple_Sclerosis   0.507 (0.413-0.619)       21         0.2
# Thyroid_Disorders    0.542 (0.518-0.570)       479        4.8
# --------------------------------------------------------------------------------
#
# Fixed Phi - 30 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.579 (0.533-0.626) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.547 (0.498-0.590) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 137 (5.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.531 (0.452-0.629) (calculated on 2532 individuals)
# Events (10-Year in Eval Cohort): 29 (1.1%) (from 2532 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.585 (0.499-0.667) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 33 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.575 (0.512-0.627) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 94 (3.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.516 (0.425-0.637) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.592 (0.511-0.691) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 32 (1.3%) (from 2541 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.531 (0.482-0.603) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 70 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.619 (0.562-0.679) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 81 (3.2%) (from 2541 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.485 (0.394-0.571) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2540 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.520 (0.470-0.565) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 154 (6.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.482 (0.354-0.565) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 25 (1.0%) (from 2541 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.543 (0.480-0.609) (calculated on 1402 individuals)
# Events (10-Year in Eval Cohort): 65 (4.6%) (from 1402 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.611 (0.532-0.691) (calculated on 1139 individuals)
# Events (10-Year in Eval Cohort): 35 (3.1%) (from 1139 individuals)
# Excluded 0 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.682 (0.551-0.822) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2541 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.476 (0.334-0.673) (calculated on 2540 individuals)
# Events (10-Year in Eval Cohort): 9 (0.4%) (from 2540 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.521 (0.461-0.581) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 71 (2.8%) (from 2541 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.499 (0.459-0.527) (calculated on 2511 individuals)
# Events (10-Year in Eval Cohort): 192 (7.6%) (from 2511 individuals)
# Excluded 30 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.507 (0.441-0.563) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 136 (5.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.437 (0.317-0.551) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 17 (0.7%) (from 2536 individuals)
# Excluded 5 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.535 (0.444-0.637) (calculated on 2538 individuals)
# Events (10-Year in Eval Cohort): 36 (1.4%) (from 2538 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.453 (0.307-0.584) (calculated on 2539 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2539 individuals)
# Excluded 2 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.410 (0.310-0.501) (calculated on 2528 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2528 individuals)
# Excluded 13 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.457 (0.311-0.585) (calculated on 2533 individuals)
# Events (10-Year in Eval Cohort): 20 (0.8%) (from 2533 individuals)
# Excluded 8 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.499 (0.455-0.530) (calculated on 2472 individuals)
# Events (10-Year in Eval Cohort): 218 (8.8%) (from 2472 individuals)
# Excluded 69 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.545 (0.503-0.593) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 2 (0.1%) (from 2541 individuals)
# Excluded 0 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.407 (0.255-0.560) (calculated on 2536 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2536 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.489-0.578) (calculated on 2541 individuals)
# Events (10-Year in Eval Cohort): 145 (5.7%) (from 2541 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.579 (0.533-0.626)       136        5.4
# Diabetes             0.547 (0.498-0.590)       137        5.4
# Atrial_Fib           0.531 (0.452-0.629)       29         1.1
# CKD                  0.585 (0.499-0.667)       33         1.3
# All_Cancers          0.575 (0.512-0.627)       94         3.7
# Stroke               0.516 (0.425-0.637)       30         1.2
# Heart_Failure        0.592 (0.511-0.691)       32         1.3
# Pneumonia            0.531 (0.482-0.603)       70         2.8
# COPD                 0.619 (0.562-0.679)       81         3.2
# Osteoporosis         0.485 (0.394-0.571)       41         1.6
# Anemia               0.520 (0.470-0.565)       154        6.1
# Colorectal_Cancer    0.482 (0.354-0.565)       25         1.0
# Breast_Cancer        0.543 (0.480-0.609)       65         4.6
# Prostate_Cancer      0.611 (0.532-0.691)       35         3.1
# Lung_Cancer          0.682 (0.551-0.822)       9          0.4
# Bladder_Cancer       0.476 (0.334-0.673)       9          0.4
# Secondary_Cancer     0.521 (0.461-0.581)       71         2.8
# Depression           0.499 (0.459-0.527)       192        7.6
# Anxiety              0.507 (0.441-0.563)       136        5.4
# Bipolar_Disorder     0.437 (0.317-0.551)       17         0.7
# Rheumatoid_Arthritis 0.535 (0.444-0.637)       36         1.4
# Psoriasis            0.453 (0.307-0.584)       24         0.9
# Ulcerative_Colitis   0.410 (0.310-0.501)       22         0.9
# Crohns_Disease       0.457 (0.311-0.585)       20         0.8
# Asthma               0.499 (0.455-0.530)       218        8.8
# Parkinsons           0.545 (0.503-0.593)       2          0.1
# Multiple_Sclerosis   0.407 (0.255-0.560)       11         0.4
# Thyroid_Disorders    0.526 (0.489-0.578)       145        5.7
# --------------------------------------------------------------------------------
#
# Fixed Phi - Static 10 year predictions (1-year score)...
#
# Evaluating ASCVD (10-Year Outcome, 1-Year Score)...
# AUC: 0.683 (0.664-0.704) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 831 (8.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.669, Events = 273/5409
#    Male: AUC = 0.685, Events = 558/4591
#
#    ASCVD risk in patients with pre-existing conditions:
#    RA: AUC = 0.707, Events = 8/37
#    Breast_Cancer: AUC = 0.549, Events = 13/170
#
# Evaluating Diabetes (10-Year Outcome, 1-Year Score)...
# AUC: 0.613 (0.595-0.641) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 581 (5.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.604, Events = 264/5409
#    Male: AUC = 0.617, Events = 317/4591
#
# Evaluating Atrial_Fib (10-Year Outcome, 1-Year Score)...
# AUC: 0.701 (0.676-0.720) (calculated on 9864 individuals)
# Events (10-Year in Eval Cohort): 376 (3.8%) (from 10000 individuals)
# Excluded 136 prevalent cases for Atrial_Fib.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.707, Events = 197/5372
#    Male: AUC = 0.706, Events = 174/4492
#
# Evaluating CKD (10-Year Outcome, 1-Year Score)...
# AUC: 0.710 (0.677-0.740) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 207 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.733, Events = 101/5409
#    Male: AUC = 0.687, Events = 106/4591
#
# Evaluating All_Cancers (10-Year Outcome, 1-Year Score)...
# AUC: 0.676 (0.659-0.700) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 480 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.671, Events = 134/5409
#    Male: AUC = 0.672, Events = 346/4591
#
# Evaluating Stroke (10-Year Outcome, 1-Year Score)...
# AUC: 0.652 (0.589-0.709) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 129 (1.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.626, Events = 64/5409
#    Male: AUC = 0.678, Events = 65/4591
#
# Evaluating Heart_Failure (10-Year Outcome, 1-Year Score)...
# AUC: 0.699 (0.670-0.732) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 205 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.716, Events = 83/5409
#    Male: AUC = 0.683, Events = 122/4591
#
# Evaluating Pneumonia (10-Year Outcome, 1-Year Score)...
# AUC: 0.681 (0.658-0.705) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 335 (3.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.682, Events = 135/5409
#    Male: AUC = 0.676, Events = 200/4591
#
# Evaluating COPD (10-Year Outcome, 1-Year Score)...
# AUC: 0.647 (0.620-0.679) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 394 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.674, Events = 176/5409
#    Male: AUC = 0.622, Events = 218/4591
#
# Evaluating Osteoporosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.665 (0.628-0.695) (calculated on 9961 individuals)
# Events (10-Year in Eval Cohort): 219 (2.2%) (from 10000 individuals)
# Excluded 39 prevalent cases for Osteoporosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.674, Events = 128/5379
#    Male: AUC = 0.660, Events = 90/4582
#
# Evaluating Anemia (10-Year Outcome, 1-Year Score)...
# AUC: 0.592 (0.570-0.614) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 523 (5.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.549, Events = 280/5409
#    Male: AUC = 0.640, Events = 243/4591
#
# Evaluating Colorectal_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.661 (0.617-0.707) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 105 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.635, Events = 56/5409
#    Male: AUC = 0.689, Events = 49/4591
#
# Evaluating Breast_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Female: Found 5409 individuals in cohort
# AUC: 0.580 (0.543-0.616) (calculated on 5409 individuals)
# Events (10-Year in Eval Cohort): 214 (4.0%) (from 5409 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (10-Year Outcome, 1-Year Score)...
# Filtering for Male: Found 4591 individuals in cohort
# AUC: 0.677 (0.651-0.713) (calculated on 4547 individuals)
# Events (10-Year in Eval Cohort): 204 (4.4%) (from 4591 individuals)
# Excluded 44 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.689 (0.626-0.743) (calculated on 9992 individuals)
# Events (10-Year in Eval Cohort): 75 (0.8%) (from 10000 individuals)
# Excluded 8 prevalent cases for Lung_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.693, Events = 48/5406
#    Male: AUC = 0.681, Events = 27/4586
#
# Evaluating Bladder_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.726 (0.651-0.775) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 10000 individuals)
# Excluded 24 prevalent cases for Bladder_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.609, Events = 24/5399
#    Male: AUC = 0.841, Events = 25/4577
#
# Evaluating Secondary_Cancer (10-Year Outcome, 1-Year Score)...
# AUC: 0.604 (0.570-0.639) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 276 (2.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.611, Events = 147/5409
#    Male: AUC = 0.595, Events = 129/4591
#
# Evaluating Depression (10-Year Outcome, 1-Year Score)...
# AUC: 0.470 (0.439-0.499) (calculated on 9912 individuals)
# Events (10-Year in Eval Cohort): 405 (4.0%) (from 10000 individuals)
# Excluded 88 prevalent cases for Depression.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.469, Events = 210/5351
#    Male: AUC = 0.482, Events = 191/4561
#
# Evaluating Anxiety (10-Year Outcome, 1-Year Score)...
# AUC: 0.507 (0.469-0.543) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 241 (2.4%) (from 10000 individuals)
# Excluded 25 prevalent cases for Anxiety.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.517, Events = 130/5391
#    Male: AUC = 0.499, Events = 110/4584
#
# Evaluating Bipolar_Disorder (10-Year Outcome, 1-Year Score)...
# AUC: 0.406 (0.308-0.512) (calculated on 9984 individuals)
# Events (10-Year in Eval Cohort): 34 (0.3%) (from 10000 individuals)
# Excluded 16 prevalent cases for Bipolar_Disorder.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.443, Events = 14/5399
#    Male: AUC = 0.378, Events = 19/4585
#
# Evaluating Rheumatoid_Arthritis (10-Year Outcome, 1-Year Score)...
# AUC: 0.596 (0.548-0.646) (calculated on 9963 individuals)
# Events (10-Year in Eval Cohort): 123 (1.2%) (from 10000 individuals)
# Excluded 37 prevalent cases for Rheumatoid_Arthritis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.592, Events = 62/5381
#    Male: AUC = 0.595, Events = 60/4582
#
# Evaluating Psoriasis (10-Year Outcome, 1-Year Score)...
# AUC: 0.416 (0.328-0.502) (calculated on 9981 individuals)
# Events (10-Year in Eval Cohort): 40 (0.4%) (from 10000 individuals)
# Excluded 19 prevalent cases for Psoriasis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.386, Events = 15/5405
#    Male: AUC = 0.435, Events = 25/4576
#
# Evaluating Ulcerative_Colitis (10-Year Outcome, 1-Year Score)...
# AUC: 0.591 (0.524-0.681) (calculated on 9947 individuals)
# Events (10-Year in Eval Cohort): 50 (0.5%) (from 10000 individuals)
# Excluded 53 prevalent cases for Ulcerative_Colitis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.575, Events = 31/5378
#    Male: AUC = 0.624, Events = 19/4569
#
# Evaluating Crohns_Disease (10-Year Outcome, 1-Year Score)...
# AUC: 0.510 (0.400-0.598) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 31 (0.3%) (from 10000 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.532, Events = 20/5388
#    Male: AUC = 0.471, Events = 11/4579
#
# Evaluating Asthma (10-Year Outcome, 1-Year Score)...
# AUC: 0.497 (0.476-0.520) (calculated on 9687 individuals)
# Events (10-Year in Eval Cohort): 606 (6.1%) (from 10000 individuals)
# Excluded 313 prevalent cases for Asthma.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.499, Events = 321/5214
#    Male: AUC = 0.531, Events = 264/4473
#
# Evaluating Parkinsons (10-Year Outcome, 1-Year Score)...
# AUC: 0.747 (0.679-0.807) (calculated on 9997 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 10000 individuals)
# Excluded 3 prevalent cases for Parkinsons.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.800, Events = 21/5407
#    Male: AUC = 0.701, Events = 25/4590
#
# Evaluating Multiple_Sclerosis (10-Year Outcome, 1-Year Score)...
# AUC: 0.533 (0.401-0.664) (calculated on 9979 individuals)
# Events (10-Year in Eval Cohort): 21 (0.2%) (from 10000 individuals)
# Excluded 21 prevalent cases for Multiple_Sclerosis.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.514, Events = 13/5394
#    Male: AUC = 0.566, Events = 8/4585
#
# Evaluating Thyroid_Disorders (10-Year Outcome, 1-Year Score)...
# AUC: 0.563 (0.535-0.592) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 479 (4.8%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
#    Sex-stratified analysis:
#    Female: AUC = 0.567, Events = 385/5409
#    Male: AUC = 0.561, Events = 94/4591
#
# Summary of Results (Prospective 10-Year Outcome, 1-Year Score, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.683 (0.664-0.704)       831        8.3
# Diabetes             0.613 (0.595-0.641)       581        5.8
# Atrial_Fib           0.701 (0.676-0.720)       376        3.8
# CKD                  0.710 (0.677-0.740)       207        2.1
# All_Cancers          0.676 (0.659-0.700)       480        4.8
# Stroke               0.652 (0.589-0.709)       129        1.3
# Heart_Failure        0.699 (0.670-0.732)       205        2.1
# Pneumonia            0.681 (0.658-0.705)       335        3.4
# COPD                 0.647 (0.620-0.679)       394        3.9
# Osteoporosis         0.665 (0.628-0.695)       219        2.2
# Anemia               0.592 (0.570-0.614)       523        5.2
# Colorectal_Cancer    0.661 (0.617-0.707)       105        1.1
# Breast_Cancer        0.580 (0.543-0.616)       214        4.0
# Prostate_Cancer      0.677 (0.651-0.713)       204        4.4
# Lung_Cancer          0.689 (0.626-0.743)       75         0.8
# Bladder_Cancer       0.726 (0.651-0.775)       49         0.5
# Secondary_Cancer     0.604 (0.570-0.639)       276        2.8
# Depression           0.470 (0.439-0.499)       405        4.0
# Anxiety              0.507 (0.469-0.543)       241        2.4
# Bipolar_Disorder     0.406 (0.308-0.512)       34         0.3
# Rheumatoid_Arthritis 0.596 (0.548-0.646)       123        1.2
# Psoriasis            0.416 (0.328-0.502)       40         0.4
# Ulcerative_Colitis   0.591 (0.524-0.681)       50         0.5
# Crohns_Disease       0.510 (0.400-0.598)       31         0.3
# Asthma               0.497 (0.476-0.520)       606        6.1
# Parkinsons           0.747 (0.679-0.807)       46         0.5
# Multiple_Sclerosis   0.533 (0.401-0.664)       21         0.2
# Thyroid_Disorders    0.563 (0.535-0.592)       479        4.8
# --------------------------------------------------------------------------------
#
# ================================================================================
# Processing FIXED PHI batch 1: 10000 to 20000
# ================================================================================
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/2217820238.py:40: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   model.Y = torch.tensor(Y_batch, dtype=torch.float32)
# Fixed Phi - 10 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.618 (0.596-0.636) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 857 (8.6%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.572 (0.556-0.594) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 588 (5.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.588 (0.561-0.616) (calculated on 9857 individuals)
# Events (10-Year in Eval Cohort): 380 (3.9%) (from 9857 individuals)
# Excluded 143 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.700 (0.667-0.733) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 202 (2.0%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.644 (0.618-0.662) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 531 (5.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.674 (0.626-0.714) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 156 (1.6%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.687 (0.654-0.731) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 197 (2.0%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.639 (0.614-0.677) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 333 (3.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.668 (0.645-0.691) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 404 (4.0%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.680 (0.640-0.704) (calculated on 9972 individuals)
# Events (10-Year in Eval Cohort): 228 (2.3%) (from 9972 individuals)
# Excluded 28 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.599 (0.574-0.619) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 568 (5.7%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.555 (0.517-0.595) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 139 (1.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5401 individuals in cohort
# AUC: 0.514 (0.472-0.555) (calculated on 5401 individuals)
# Events (10-Year in Eval Cohort): 220 (4.1%) (from 5401 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4599 individuals in cohort
# AUC: 0.656 (0.629-0.692) (calculated on 4556 individuals)
# Events (10-Year in Eval Cohort): 193 (4.2%) (from 4556 individuals)
# Excluded 43 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.681 (0.650-0.738) (calculated on 9990 individuals)
# Events (10-Year in Eval Cohort): 89 (0.9%) (from 9990 individuals)
# Excluded 10 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.631 (0.581-0.694) (calculated on 9975 individuals)
# Events (10-Year in Eval Cohort): 61 (0.6%) (from 9975 individuals)
# Excluded 25 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.596 (0.562-0.623) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 298 (3.0%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.485 (0.458-0.515) (calculated on 9900 individuals)
# Events (10-Year in Eval Cohort): 390 (3.9%) (from 9900 individuals)
# Excluded 100 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.534 (0.507-0.573) (calculated on 9964 individuals)
# Events (10-Year in Eval Cohort): 246 (2.5%) (from 9964 individuals)
# Excluded 36 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.530 (0.433-0.651) (calculated on 9982 individuals)
# Events (10-Year in Eval Cohort): 24 (0.2%) (from 9982 individuals)
# Excluded 18 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.587 (0.528-0.639) (calculated on 9939 individuals)
# Events (10-Year in Eval Cohort): 116 (1.2%) (from 9939 individuals)
# Excluded 61 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.561 (0.481-0.629) (calculated on 9976 individuals)
# Events (10-Year in Eval Cohort): 45 (0.5%) (from 9976 individuals)
# Excluded 24 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.551 (0.486-0.630) (calculated on 9949 individuals)
# Events (10-Year in Eval Cohort): 56 (0.6%) (from 9949 individuals)
# Excluded 51 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.419 (0.326-0.539) (calculated on 9967 individuals)
# Events (10-Year in Eval Cohort): 22 (0.2%) (from 9967 individuals)
# Excluded 33 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.510 (0.489-0.528) (calculated on 9680 individuals)
# Events (10-Year in Eval Cohort): 630 (6.5%) (from 9680 individuals)
# Excluded 320 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.734 (0.694-0.782) (calculated on 9995 individuals)
# Events (10-Year in Eval Cohort): 46 (0.5%) (from 9995 individuals)
# Excluded 5 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.647 (0.544-0.743) (calculated on 9978 individuals)
# Events (10-Year in Eval Cohort): 26 (0.3%) (from 9978 individuals)
# Excluded 22 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.540 (0.512-0.562) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 431 (4.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.618 (0.596-0.636)       857        8.6
# Diabetes             0.572 (0.556-0.594)       588        5.9
# Atrial_Fib           0.588 (0.561-0.616)       380        3.9
# CKD                  0.700 (0.667-0.733)       202        2.0
# All_Cancers          0.644 (0.618-0.662)       531        5.3
# Stroke               0.674 (0.626-0.714)       156        1.6
# Heart_Failure        0.687 (0.654-0.731)       197        2.0
# Pneumonia            0.639 (0.614-0.677)       333        3.3
# COPD                 0.668 (0.645-0.691)       404        4.0
# Osteoporosis         0.680 (0.640-0.704)       228        2.3
# Anemia               0.599 (0.574-0.619)       568        5.7
# Colorectal_Cancer    0.555 (0.517-0.595)       139        1.4
# Breast_Cancer        0.514 (0.472-0.555)       220        4.1
# Prostate_Cancer      0.656 (0.629-0.692)       193        4.2
# Lung_Cancer          0.681 (0.650-0.738)       89         0.9
# Bladder_Cancer       0.631 (0.581-0.694)       61         0.6
# Secondary_Cancer     0.596 (0.562-0.623)       298        3.0
# Depression           0.485 (0.458-0.515)       390        3.9
# Anxiety              0.534 (0.507-0.573)       246        2.5
# Bipolar_Disorder     0.530 (0.433-0.651)       24         0.2
# Rheumatoid_Arthritis 0.587 (0.528-0.639)       116        1.2
# Psoriasis            0.561 (0.481-0.629)       45         0.5
# Ulcerative_Colitis   0.551 (0.486-0.630)       56         0.6
# Crohns_Disease       0.419 (0.326-0.539)       22         0.2
# Asthma               0.510 (0.489-0.528)       630        6.5
# Parkinsons           0.734 (0.694-0.782)       46         0.5
# Multiple_Sclerosis   0.647 (0.544-0.743)       26         0.3
# Thyroid_Disorders    0.540 (0.512-0.562)       431        4.3
# --------------------------------------------------------------------------------
#
# Fixed Phi - 30 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.527 (0.485-0.579) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 143 (5.7%) (from 2503 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.512 (0.464-0.561) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 118 (4.7%) (from 2503 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.491 (0.385-0.589) (calculated on 2492 individuals)
# Events (10-Year in Eval Cohort): 30 (1.2%) (from 2492 individuals)
# Excluded 11 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.546 (0.433-0.640) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 27 (1.1%) (from 2503 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.595 (0.541-0.651) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 77 (3.1%) (from 2503 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.565 (0.429-0.684) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 21 (0.8%) (from 2503 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.605 (0.501-0.702) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 34 (1.4%) (from 2503 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.584 (0.505-0.651) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 67 (2.7%) (from 2503 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.568 (0.495-0.635) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 64 (2.6%) (from 2503 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.594 (0.508-0.662) (calculated on 2502 individuals)
# Events (10-Year in Eval Cohort): 40 (1.6%) (from 2502 individuals)
# Excluded 1 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.495 (0.440-0.545) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 146 (5.8%) (from 2503 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.615 (0.508-0.705) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 22 (0.9%) (from 2503 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5401 individuals in cohort
# AUC: 0.515 (0.460-0.583) (calculated on 1416 individuals)
# Events (10-Year in Eval Cohort): 84 (5.9%) (from 1416 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4599 individuals in cohort
# AUC: 0.589 (0.492-0.701) (calculated on 1086 individuals)
# Events (10-Year in Eval Cohort): 25 (2.3%) (from 1086 individuals)
# Excluded 1 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.729 (0.482-0.987) (calculated on 2502 individuals)
# Events (10-Year in Eval Cohort): 5 (0.2%) (from 2502 individuals)
# Excluded 1 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.509 (0.311-0.773) (calculated on 2502 individuals)
# Events (10-Year in Eval Cohort): 6 (0.2%) (from 2502 individuals)
# Excluded 1 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.565 (0.474-0.641) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 65 (2.6%) (from 2503 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.491 (0.447-0.534) (calculated on 2463 individuals)
# Events (10-Year in Eval Cohort): 176 (7.1%) (from 2463 individuals)
# Excluded 40 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.480-0.572) (calculated on 2493 individuals)
# Events (10-Year in Eval Cohort): 128 (5.1%) (from 2493 individuals)
# Excluded 10 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.466 (0.314-0.734) (calculated on 2493 individuals)
# Events (10-Year in Eval Cohort): 13 (0.5%) (from 2493 individuals)
# Excluded 10 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.482 (0.371-0.584) (calculated on 2500 individuals)
# Events (10-Year in Eval Cohort): 29 (1.2%) (from 2500 individuals)
# Excluded 3 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.607 (0.449-0.790) (calculated on 2498 individuals)
# Events (10-Year in Eval Cohort): 13 (0.5%) (from 2498 individuals)
# Excluded 5 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.670 (0.539-0.802) (calculated on 2492 individuals)
# Events (10-Year in Eval Cohort): 15 (0.6%) (from 2492 individuals)
# Excluded 11 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.383 (0.231-0.548) (calculated on 2494 individuals)
# Events (10-Year in Eval Cohort): 10 (0.4%) (from 2494 individuals)
# Excluded 9 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.520 (0.483-0.560) (calculated on 2406 individuals)
# Events (10-Year in Eval Cohort): 205 (8.5%) (from 2406 individuals)
# Excluded 97 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.576 (0.097-0.953) (calculated on 2502 individuals)
# Events (10-Year in Eval Cohort): 4 (0.2%) (from 2502 individuals)
# Excluded 1 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.627 (0.517-0.747) (calculated on 2498 individuals)
# Events (10-Year in Eval Cohort): 13 (0.5%) (from 2498 individuals)
# Excluded 5 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.520 (0.480-0.571) (calculated on 2503 individuals)
# Events (10-Year in Eval Cohort): 112 (4.5%) (from 2503 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.527 (0.485-0.579)       143        5.7
# Diabetes             0.512 (0.464-0.561)       118        4.7
# Atrial_Fib           0.491 (0.385-0.589)       30         1.2
# CKD                  0.546 (0.433-0.640)       27         1.1
# All_Cancers          0.595 (0.541-0.651)       77         3.1
# Stroke               0.565 (0.429-0.684)       21         0.8
# Heart_Failure        0.605 (0.501-0.702)       34         1.4
# Pneumonia            0.584 (0.505-0.651)       67         2.7
# COPD                 0.568 (0.495-0.635)       64         2.6
# Osteoporosis         0.594 (0.508-0.662)       40         1.6
# Anemia               0.495 (0.440-0.545)       146        5.8
# Colorectal_Cancer    0.615 (0.508-0.705)       22         0.9
# Breast_Cancer        0.515 (0.460-0.583)       84         5.9
# Prostate_Cancer      0.589 (0.492-0.701)       25         2.3
# Lung_Cancer          0.729 (0.482-0.987)       5          0.2
# Bladder_Cancer       0.509 (0.311-0.773)       6          0.2
# ...
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.701 (0.680-0.718)       883        8.8
# Diabetes             0.611 (0.590-0.633)       603        6.0
# Atrial_Fib           0.692 (0.664-0.711)       350        3.5
# CKD                  0.678 (0.644-0.704)       221        2.2
# All_Cancers          0.674 (0.655-0.697)       510        5.1
# Stroke               0.715 (0.667-0.755)       152        1.5
# Heart_Failure        0.718 (0.688-0.747)       188        1.9
# Pneumonia            0.657 (0.622-0.685)       364        3.6
# COPD                 0.656 (0.633-0.679)       433        4.3
# Osteoporosis         0.683 (0.652-0.717)       231        2.3
# Anemia               0.578 (0.558-0.602)       534        5.3
# Colorectal_Cancer    0.601 (0.552-0.647)       127        1.3
# Breast_Cancer        0.522 (0.491-0.568)       242        4.5
# Prostate_Cancer      0.682 (0.653-0.721)       187        4.1
# Lung_Cancer          0.717 (0.658-0.771)       85         0.9
# Bladder_Cancer       0.683 (0.640-0.734)       60         0.6
# Secondary_Cancer     0.589 (0.554-0.614)       305        3.0
# Depression           0.479 (0.447-0.508)       387        3.9
# Anxiety              0.515 (0.473-0.549)       250        2.5
# Bipolar_Disorder     0.503 (0.399-0.594)       30         0.3
# Rheumatoid_Arthritis 0.599 (0.550-0.646)       129        1.3
# Psoriasis            0.532 (0.480-0.593)       54         0.5
# Ulcerative_Colitis   0.614 (0.526-0.709)       56         0.6
# Crohns_Disease       0.517 (0.399-0.633)       23         0.2
# Asthma               0.513 (0.493-0.533)       604        6.0
# Parkinsons           0.764 (0.699-0.823)       45         0.4
# Multiple_Sclerosis   0.506 (0.321-0.629)       11         0.1
# Thyroid_Disorders    0.555 (0.538-0.581)       469        4.7
# --------------------------------------------------------------------------------
#
# ================================================================================
# Processing FIXED PHI batch 9: 90000 to 100000
# ================================================================================
# /var/folders/fl/ng5crz0x0fnb6c6x8dk7tfth0000gn/T/ipykernel_5551/2217820238.py:40: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   model.Y = torch.tensor(Y_batch, dtype=torch.float32)
# Fixed Phi - 10 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.637 (0.622-0.656) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 853 (8.5%) (from 10000 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.603 (0.582-0.624) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 591 (5.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.588 (0.564-0.611) (calculated on 9885 individuals)
# Events (10-Year in Eval Cohort): 368 (3.7%) (from 9885 individuals)
# Excluded 115 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.729 (0.695-0.763) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 213 (2.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.643 (0.619-0.665) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 491 (4.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.678 (0.630-0.721) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 136 (1.4%) (from 10000 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.685 (0.650-0.713) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 222 (2.2%) (from 10000 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.662 (0.634-0.687) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 390 (3.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.624 (0.598-0.650) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 433 (4.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.651 (0.625-0.674) (calculated on 9968 individuals)
# Events (10-Year in Eval Cohort): 255 (2.6%) (from 9968 individuals)
# Excluded 32 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.575 (0.549-0.596) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 587 (5.9%) (from 10000 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.572 (0.531-0.612) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 111 (1.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5560 individuals in cohort
# AUC: 0.567 (0.536-0.607) (calculated on 5560 individuals)
# Events (10-Year in Eval Cohort): 228 (4.1%) (from 5560 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4440 individuals in cohort
# AUC: 0.681 (0.647-0.716) (calculated on 4402 individuals)
# Events (10-Year in Eval Cohort): 184 (4.2%) (from 4402 individuals)
# Excluded 38 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.598 (0.539-0.647) (calculated on 9996 individuals)
# Events (10-Year in Eval Cohort): 79 (0.8%) (from 9996 individuals)
# Excluded 4 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.707 (0.644-0.767) (calculated on 9973 individuals)
# Events (10-Year in Eval Cohort): 56 (0.6%) (from 9973 individuals)
# Excluded 27 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.589 (0.555-0.615) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 307 (3.1%) (from 10000 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.486 (0.461-0.515) (calculated on 9893 individuals)
# Events (10-Year in Eval Cohort): 425 (4.3%) (from 9893 individuals)
# Excluded 107 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.469 (0.439-0.500) (calculated on 9968 individuals)
# Events (10-Year in Eval Cohort): 271 (2.7%) (from 9968 individuals)
# Excluded 32 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.582 (0.437-0.702) (calculated on 9986 individuals)
# Events (10-Year in Eval Cohort): 24 (0.2%) (from 9986 individuals)
# Excluded 14 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.584 (0.530-0.626) (calculated on 9948 individuals)
# Events (10-Year in Eval Cohort): 121 (1.2%) (from 9948 individuals)
# Excluded 52 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.560 (0.485-0.636) (calculated on 9980 individuals)
# Events (10-Year in Eval Cohort): 44 (0.4%) (from 9980 individuals)
# Excluded 20 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...
# AUC: 0.565 (0.507-0.658) (calculated on 9957 individuals)
# Events (10-Year in Eval Cohort): 52 (0.5%) (from 9957 individuals)
# Excluded 43 prevalent cases for Ulcerative_Colitis.
#
# Evaluating Crohns_Disease (Dynamic 10-Year Risk)...
# AUC: 0.599 (0.507-0.681) (calculated on 9965 individuals)
# Events (10-Year in Eval Cohort): 29 (0.3%) (from 9965 individuals)
# Excluded 35 prevalent cases for Crohns_Disease.
#
# Evaluating Asthma (Dynamic 10-Year Risk)...
# AUC: 0.518 (0.500-0.542) (calculated on 9672 individuals)
# Events (10-Year in Eval Cohort): 624 (6.5%) (from 9672 individuals)
# Excluded 328 prevalent cases for Asthma.
#
# Evaluating Parkinsons (Dynamic 10-Year Risk)...
# AUC: 0.715 (0.649-0.760) (calculated on 9998 individuals)
# Events (10-Year in Eval Cohort): 49 (0.5%) (from 9998 individuals)
# Excluded 2 prevalent cases for Parkinsons.
#
# Evaluating Multiple_Sclerosis (Dynamic 10-Year Risk)...
# AUC: 0.596 (0.491-0.680) (calculated on 9982 individuals)
# Events (10-Year in Eval Cohort): 29 (0.3%) (from 9982 individuals)
# Excluded 18 prevalent cases for Multiple_Sclerosis.
#
# Evaluating Thyroid_Disorders (Dynamic 10-Year Risk)...
# AUC: 0.558 (0.535-0.586) (calculated on 10000 individuals)
# Events (10-Year in Eval Cohort): 434 (4.3%) (from 10000 individuals)
# Excluded 0 prevalent cases for Thyroid_Disorders.
#
# Summary of Results (Dynamic 10-Year Risk, Sex-Adjusted):
# --------------------------------------------------------------------------------
# Disease Group        AUC                       Events     Rate (%)
# --------------------------------------------------------------------------------
# ASCVD                0.637 (0.622-0.656)       853        8.5
# Diabetes             0.603 (0.582-0.624)       591        5.9
# Atrial_Fib           0.588 (0.564-0.611)       368        3.7
# CKD                  0.729 (0.695-0.763)       213        2.1
# All_Cancers          0.643 (0.619-0.665)       491        4.9
# Stroke               0.678 (0.630-0.721)       136        1.4
# Heart_Failure        0.685 (0.650-0.713)       222        2.2
# Pneumonia            0.662 (0.634-0.687)       390        3.9
# COPD                 0.624 (0.598-0.650)       433        4.3
# Osteoporosis         0.651 (0.625-0.674)       255        2.6
# Anemia               0.575 (0.549-0.596)       587        5.9
# Colorectal_Cancer    0.572 (0.531-0.612)       111        1.1
# Breast_Cancer        0.567 (0.536-0.607)       228        4.1
# Prostate_Cancer      0.681 (0.647-0.716)       184        4.2
# Lung_Cancer          0.598 (0.539-0.647)       79         0.8
# Bladder_Cancer       0.707 (0.644-0.767)       56         0.6
# Secondary_Cancer     0.589 (0.555-0.615)       307        3.1
# Depression           0.486 (0.461-0.515)       425        4.3
# Anxiety              0.469 (0.439-0.500)       271        2.7
# Bipolar_Disorder     0.582 (0.437-0.702)       24         0.2
# Rheumatoid_Arthritis 0.584 (0.530-0.626)       121        1.2
# Psoriasis            0.560 (0.485-0.636)       44         0.4
# Ulcerative_Colitis   0.565 (0.507-0.658)       52         0.5
# Crohns_Disease       0.599 (0.507-0.681)       29         0.3
# Asthma               0.518 (0.500-0.542)       624        6.5
# Parkinsons           0.715 (0.649-0.760)       49         0.5
# Multiple_Sclerosis   0.596 (0.491-0.680)       29         0.3
# Thyroid_Disorders    0.558 (0.535-0.586)       434        4.3
# --------------------------------------------------------------------------------
#
# Fixed Phi - 30 year predictions...
#
# Evaluating ASCVD (Dynamic 10-Year Risk)...
# AUC: 0.566 (0.518-0.613) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 130 (5.0%) (from 2583 individuals)
# Excluded 0 prevalent cases for ASCVD.
#
# Evaluating Diabetes (Dynamic 10-Year Risk)...
# AUC: 0.592 (0.527-0.632) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 132 (5.1%) (from 2583 individuals)
# Excluded 0 prevalent cases for Diabetes.
#
# Evaluating Atrial_Fib (Dynamic 10-Year Risk)...
# AUC: 0.534 (0.427-0.618) (calculated on 2574 individuals)
# Events (10-Year in Eval Cohort): 26 (1.0%) (from 2574 individuals)
# Excluded 9 prevalent cases for Atrial_Fib.
#
# Evaluating CKD (Dynamic 10-Year Risk)...
# AUC: 0.635 (0.525-0.714) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 28 (1.1%) (from 2583 individuals)
# Excluded 0 prevalent cases for CKD.
#
# Evaluating All_Cancers (Dynamic 10-Year Risk)...
# AUC: 0.588 (0.517-0.653) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 86 (3.3%) (from 2583 individuals)
# Excluded 0 prevalent cases for All_Cancers.
#
# Evaluating Stroke (Dynamic 10-Year Risk)...
# AUC: 0.594 (0.486-0.680) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 21 (0.8%) (from 2583 individuals)
# Excluded 0 prevalent cases for Stroke.
#
# Evaluating Heart_Failure (Dynamic 10-Year Risk)...
# AUC: 0.563 (0.459-0.665) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 28 (1.1%) (from 2583 individuals)
# Excluded 0 prevalent cases for Heart_Failure.
#
# Evaluating Pneumonia (Dynamic 10-Year Risk)...
# AUC: 0.523 (0.462-0.597) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 82 (3.2%) (from 2583 individuals)
# Excluded 0 prevalent cases for Pneumonia.
#
# Evaluating COPD (Dynamic 10-Year Risk)...
# AUC: 0.578 (0.526-0.628) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 87 (3.4%) (from 2583 individuals)
# Excluded 0 prevalent cases for COPD.
#
# Evaluating Osteoporosis (Dynamic 10-Year Risk)...
# AUC: 0.526 (0.446-0.623) (calculated on 2581 individuals)
# Events (10-Year in Eval Cohort): 41 (1.6%) (from 2581 individuals)
# Excluded 2 prevalent cases for Osteoporosis.
#
# Evaluating Anemia (Dynamic 10-Year Risk)...
# AUC: 0.522 (0.484-0.568) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 188 (7.3%) (from 2583 individuals)
# Excluded 0 prevalent cases for Anemia.
#
# Evaluating Colorectal_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.499 (0.376-0.637) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 23 (0.9%) (from 2583 individuals)
# Excluded 0 prevalent cases for Colorectal_Cancer.
#
# Evaluating Breast_Cancer (Dynamic 10-Year Risk)...
# Filtering for Female: Found 5560 individuals in cohort
# AUC: 0.504 (0.437-0.572) (calculated on 1515 individuals)
# Events (10-Year in Eval Cohort): 55 (3.6%) (from 1515 individuals)
# Excluded 0 prevalent cases for Breast_Cancer.
#
# Evaluating Prostate_Cancer (Dynamic 10-Year Risk)...
# Filtering for Male: Found 4440 individuals in cohort
# AUC: 0.615 (0.484-0.742) (calculated on 1067 individuals)
# Events (10-Year in Eval Cohort): 20 (1.9%) (from 1067 individuals)
# Excluded 1 prevalent cases for Prostate_Cancer.
#
# Evaluating Lung_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.684 (0.515-0.847) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 14 (0.5%) (from 2583 individuals)
# Excluded 0 prevalent cases for Lung_Cancer.
#
# Evaluating Bladder_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.846 (0.794-0.917) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 5 (0.2%) (from 2583 individuals)
# Excluded 0 prevalent cases for Bladder_Cancer.
#
# Evaluating Secondary_Cancer (Dynamic 10-Year Risk)...
# AUC: 0.553 (0.490-0.617) (calculated on 2583 individuals)
# Events (10-Year in Eval Cohort): 70 (2.7%) (from 2583 individuals)
# Excluded 0 prevalent cases for Secondary_Cancer.
#
# Evaluating Depression (Dynamic 10-Year Risk)...
# AUC: 0.510 (0.473-0.545) (calculated on 2560 individuals)
# Events (10-Year in Eval Cohort): 211 (8.2%) (from 2560 individuals)
# Excluded 23 prevalent cases for Depression.
#
# Evaluating Anxiety (Dynamic 10-Year Risk)...
# AUC: 0.489 (0.442-0.530) (calculated on 2573 individuals)
# Events (10-Year in Eval Cohort): 162 (6.3%) (from 2573 individuals)
# Excluded 10 prevalent cases for Anxiety.
#
# Evaluating Bipolar_Disorder (Dynamic 10-Year Risk)...
# AUC: 0.307 (0.146-0.468) (calculated on 2577 individuals)
# Events (10-Year in Eval Cohort): 11 (0.4%) (from 2577 individuals)
# Excluded 6 prevalent cases for Bipolar_Disorder.
#
# Evaluating Rheumatoid_Arthritis (Dynamic 10-Year Risk)...
# AUC: 0.485 (0.347-0.597) (calculated on 2577 individuals)
# Events (10-Year in Eval Cohort): 24 (0.9%) (from 2577 individuals)
# Excluded 6 prevalent cases for Rheumatoid_Arthritis.
#
# Evaluating Psoriasis (Dynamic 10-Year Risk)...
# AUC: 0.683 (0.560-0.809) (calculated on 2579 individuals)
# Events (10-Year in Eval Cohort): 18 (0.7%) (from 2579 individuals)
# Excluded 4 prevalent cases for Psoriasis.
#
# Evaluating Ulcerative_Colitis (Dynamic 10-Year Risk)...

# %%
# Compute median AUC across all batches
def compute_median_aucs(results_list):
    """Extract AUC values and compute medians for each disease"""
    if not results_list:
        return pd.DataFrame()
    
    # Get all disease names from first result (excluding batch_idx)
    disease_names_list = [k for k in results_list[0].keys() if k != 'batch_idx']
    
    auc_data = {disease: [] for disease in disease_names_list}
    
    for result in results_list:
        for disease in disease_names_list:
            if disease in result and 'auc' in result[disease]:
                auc_val = result[disease]['auc']
                if not np.isnan(auc_val):
                    auc_data[disease].append(auc_val)
    
    # Compute medians
    median_aucs = {}
    for disease, aucs in auc_data.items():
        if aucs:
            median_aucs[disease] = np.median(aucs)
        else:
            median_aucs[disease] = np.nan
    
    # Create DataFrame
    df = pd.DataFrame([median_aucs]).T
    df.columns = ['median_auc']
    df = df.sort_values('median_auc', ascending=False)
    
    return df

# Compute median AUC DataFrames
print("Computing median AUCs...")
joint_10yr_median_df = compute_median_aucs(joint_10yr_results)
joint_30yr_median_df = compute_median_aucs(joint_30yr_results)
fixed_10yr_median_df = compute_median_aucs(fixed_10yr_results)
fixed_30yr_median_df = compute_median_aucs(fixed_30yr_results)
joint_static_10yr_median_df = compute_median_aucs(joint_static_10yr_results)
fixed_static_10yr_median_df = compute_median_aucs(fixed_static_10yr_results)

print("\n" + "="*80)
print("JOINT PHI - 10 YEAR PREDICTIONS - Median AUC")
print("="*80)
print(joint_10yr_median_df)

print("\n" + "="*80)
print("JOINT PHI - 30 YEAR PREDICTIONS - Median AUC")
print("="*80)
print(joint_30yr_median_df)

print("\n" + "="*80)
print("FIXED PHI - 10 YEAR PREDICTIONS - Median AUC")
print("="*80)
print(fixed_10yr_median_df)

print("\n" + "="*80)
print("FIXED PHI - 30 YEAR PREDICTIONS - Median AUC")
print("="*80)
print(fixed_30yr_median_df)

print("\n" + "="*80)
print("JOINT PHI - STATIC 10 YEAR PREDICTIONS (1-year score) - Median AUC")
print("="*80)
print(joint_static_10yr_median_df)

print("\n" + "="*80)
print("FIXED PHI - STATIC 10 YEAR PREDICTIONS (1-year score) - Median AUC")
print("="*80)
print(fixed_static_10yr_median_df)

# Save to CSV files
joint_10yr_median_df.to_csv('joint_phi_10yr_median_auc.csv')
joint_30yr_median_df.to_csv('joint_phi_30yr_median_auc.csv')
fixed_10yr_median_df.to_csv('fixed_phi_10yr_median_auc.csv')
fixed_30yr_median_df.to_csv('fixed_phi_30yr_median_auc.csv')
joint_static_10yr_median_df.to_csv('joint_phi_static_10yr_median_auc.csv')
fixed_static_10yr_median_df.to_csv('fixed_phi_static_10yr_median_auc.csv')

print("\nMedian AUC DataFrames saved to CSV files.")
# Out:
# Computing median AUCs...
#
# ================================================================================
# JOINT PHI - 10 YEAR PREDICTIONS - Median AUC
# ================================================================================
#                       median_auc
# Parkinsons              0.724464
# CKD                     0.708086
# Heart_Failure           0.697602
# Osteoporosis            0.690270
# Bladder_Cancer          0.683268
# Stroke                  0.681467
# Prostate_Cancer         0.662691
# Lung_Cancer             0.660430
# COPD                    0.656907
# ASCVD                   0.653996
# All_Cancers             0.653568
# Pneumonia               0.644770
# Colorectal_Cancer       0.607017
# Secondary_Cancer        0.605406
# Diabetes                0.599016
# Multiple_Sclerosis      0.594623
# Thyroid_Disorders       0.588120
# Anemia                  0.581611
# Rheumatoid_Arthritis    0.573449
# Crohns_Disease          0.542644
# Ulcerative_Colitis      0.541622
# Bipolar_Disorder        0.539409
# Psoriasis               0.533948
# Atrial_Fib              0.528289
# Asthma                  0.521254
# Anxiety                 0.514116
# Breast_Cancer           0.513429
# Depression              0.485529
#
# ================================================================================
# JOINT PHI - 30 YEAR PREDICTIONS - Median AUC
# ================================================================================
#                       median_auc
# ASCVD                   0.703092
# Diabetes                0.702863
# Prostate_Cancer         0.665030
# Osteoporosis            0.651358
# Bladder_Cancer          0.634129
# Lung_Cancer             0.619478
# Parkinsons              0.616778
# All_Cancers             0.613983
# Thyroid_Disorders       0.604051
# Atrial_Fib              0.601109
# Colorectal_Cancer       0.591821
# CKD                     0.582414
# Crohns_Disease          0.582003
# Stroke                  0.575577
# Rheumatoid_Arthritis    0.574285
# Heart_Failure           0.570321
# COPD                    0.567239
# Secondary_Cancer        0.565985
# Breast_Cancer           0.561933
# Ulcerative_Colitis      0.558571
# Pneumonia               0.540897
# Asthma                  0.540286
# Depression              0.534213
# Anemia                  0.518763
# Anxiety                 0.512036
# Multiple_Sclerosis      0.508731
# Bipolar_Disorder        0.500518
# Psoriasis               0.483871
#
# ================================================================================
# FIXED PHI - 10 YEAR PREDICTIONS - Median AUC
# ================================================================================
#                       median_auc
# Parkinsons              0.737768
# CKD                     0.713424
# Lung_Cancer             0.688475
# Heart_Failure           0.671057
# COPD                    0.658174
# Osteoporosis            0.653816
# Pneumonia               0.650745
# Stroke                  0.649463
# Prostate_Cancer         0.644277
# All_Cancers             0.643707
# Secondary_Cancer        0.631679
# Bladder_Cancer          0.626456
# Atrial_Fib              0.624863
# Crohns_Disease          0.606895
# Diabetes                0.595302
# Anemia                  0.594181
# Colorectal_Cancer       0.590064
# Bipolar_Disorder        0.589032
# Multiple_Sclerosis      0.588808
# ASCVD                   0.587606
# Rheumatoid_Arthritis    0.584234
# Anxiety                 0.582696
# Thyroid_Disorders       0.572921
# Breast_Cancer           0.569913
# Ulcerative_Colitis      0.561302
# Depression              0.559525
# Psoriasis               0.557580
# Asthma                  0.555469
#
# ================================================================================
# FIXED PHI - 30 YEAR PREDICTIONS - Median AUC
# ================================================================================
#                       median_auc
# CKD                     0.575101
# Parkinsons              0.574576
# Stroke                  0.569194
# Heart_Failure           0.566851
# COPD                    0.555568
# Lung_Cancer             0.548713
# Pneumonia               0.547804
# Osteoporosis            0.543000
# All_Cancers             0.541604
# Colorectal_Cancer       0.540208
# Bladder_Cancer          0.536807
# Anemia                  0.535084
# Multiple_Sclerosis      0.534538
# Secondary_Cancer        0.532385
# Atrial_Fib              0.531942
# Prostate_Cancer         0.530130
# Diabetes                0.528056
# Psoriasis               0.523929
# Anxiety                 0.521149
# ASCVD                   0.519724
# Thyroid_Disorders       0.517247
# Crohns_Disease          0.513382
# Depression              0.502825
# Asthma                  0.501859
# Breast_Cancer           0.500159
# Rheumatoid_Arthritis    0.496807
# Bipolar_Disorder        0.490730
# Ulcerative_Colitis      0.490075
#
# ================================================================================
# JOINT PHI - STATIC 10 YEAR PREDICTIONS (1-year score) - Median AUC
# ================================================================================
#                       median_auc
# Parkinsons              0.725859
# ASCVD                   0.720972
# CKD                     0.707039
# Bladder_Cancer          0.699543
# Heart_Failure           0.698028
# Atrial_Fib              0.685074
# Prostate_Cancer         0.684887
# Stroke                  0.680301
# Osteoporosis            0.676395
# All_Cancers             0.670563
# Lung_Cancer             0.665383
# COPD                    0.655750
# Colorectal_Cancer       0.654174
# Pneumonia               0.644121
# Diabetes                0.631094
# Secondary_Cancer        0.609764
# Rheumatoid_Arthritis    0.603083
# Thyroid_Disorders       0.588635
# Anemia                  0.585011
# Ulcerative_Colitis      0.584830
# Crohns_Disease          0.583469
# Multiple_Sclerosis      0.553681
# Breast_Cancer           0.549627
# Psoriasis               0.546502
# Asthma                  0.527031
# Anxiety                 0.512678
# Bipolar_Disorder        0.503134
# Depression              0.485063
#
# ================================================================================
# FIXED PHI - STATIC 10 YEAR PREDICTIONS (1-year score) - Median AUC
# ================================================================================
#                       median_auc
# Parkinsons              0.743758
# CKD                     0.714343
# Lung_Cancer             0.692791
# Heart_Failure           0.671482
# COPD                    0.658558
# Osteoporosis            0.654127
# Pneumonia               0.653905
# Stroke                  0.650603
# All_Cancers             0.644929
# Prostate_Cancer         0.640473
# Bladder_Cancer          0.635477
# Secondary_Cancer        0.629069
# Atrial_Fib              0.614643
# Diabetes                0.599960
# Anemia                  0.592781
# Rheumatoid_Arthritis    0.591270
# Colorectal_Cancer       0.588983
# ASCVD                   0.586010
# Anxiety                 0.585931
# Thyroid_Disorders       0.569521
# Multiple_Sclerosis      0.569391
# Psoriasis               0.563558
# Depression              0.556303
# Breast_Cancer           0.552664
# Bipolar_Disorder        0.550765
# Asthma                  0.541613
# Ulcerative_Colitis      0.538167
# Crohns_Disease          0.533258
#
# Median AUC DataFrames saved to CSV files.

# %%
# Compute median AUC across all batches
def compute_mean_aucs(results_list):
    """Extract AUC values and compute medians for each disease"""
    if not results_list:
        return pd.DataFrame()
    
    # Get all disease names from first result (excluding batch_idx)
    disease_names_list = [k for k in results_list[0].keys() if k != 'batch_idx']
    
    auc_data = {disease: [] for disease in disease_names_list}
    
    for result in results_list:
        for disease in disease_names_list:
            if disease in result and 'auc' in result[disease]:
                auc_val = result[disease]['auc']
                if not np.isnan(auc_val):
                    auc_data[disease].append(auc_val)
    
    # Compute medians
    mean_aucs = {}
    for disease, aucs in auc_data.items():
        if aucs:
            mean_aucs[disease] = np.mean(aucs)
        else:
            mean_aucs[disease] = np.nan
    
    # Create DataFrame
    df = pd.DataFrame([mean_aucs]).T
    df.columns = ['mean_auc']
    df = df.sort_values('mean_auc', ascending=False)
    
    return df

# Compute median AUC DataFrames
print("Computing mean AUCs...")
joint_10yr_mean_df = compute_mean_aucs(joint_10yr_results)
joint_30yr_mean_df = compute_mean_aucs(joint_30yr_results)
fixed_10yr_mean_df = compute_mean_aucs(fixed_10yr_results)
fixed_30yr_mean_df = compute_mean_aucs(fixed_30yr_results)
joint_static_10yr_mean_df = compute_mean_aucs(joint_static_10yr_results)
fixed_static_10yr_mean_df = compute_mean_aucs(fixed_static_10yr_results)

print("\n" + "="*80)
print("JOINT PHI - 10 YEAR PREDICTIONS - Mean AUC")
print("="*80)
print(joint_10yr_mean_df)

print("\n" + "="*80)
print("JOINT PHI - 30 YEAR PREDICTIONS - Mean AUC")
print("="*80)
print(joint_30yr_mean_df)

print("\n" + "="*80)
print("FIXED PHI - 10 YEAR PREDICTIONS - Mean AUC")
print("="*80)
print(fixed_10yr_mean_df)

print("\n" + "="*80)
print("FIXED PHI - 30 YEAR PREDICTIONS - Mean AUC")
print("="*80)
print(fixed_30yr_mean_df)

print("\n" + "="*80)
print("JOINT PHI - STATIC 10 YEAR PREDICTIONS (1-year score) - Mean AUC")
print("="*80)
print(joint_static_10yr_mean_df)

print("\n" + "="*80)
print("FIXED PHI - STATIC 10 YEAR PREDICTIONS (1-year score) - Mean AUC")
print("="*80)
print(fixed_static_10yr_mean_df)

# Save to CSV files
joint_10yr_median_df.to_csv('joint_phi_10yr_mean_auc.csv')
joint_30yr_median_df.to_csv('joint_phi_30yr_mean_auc.csv')
fixed_10yr_median_df.to_csv('fixed_phi_10yr_mean_auc.csv')
fixed_30yr_median_df.to_csv('fixed_phi_30yr_mean_auc.csv')
joint_static_10yr_median_df.to_csv('joint_phi_static_10yr_mean_auc.csv')
fixed_static_10yr_median_df.to_csv('fixed_phi_static_10yr_mean_auc.csv')

print("\nMean AUC DataFrames saved to CSV files.")
# Out:
# Computing mean AUCs...
#
# ================================================================================
# JOINT PHI - 10 YEAR PREDICTIONS - Mean AUC
# ================================================================================
#                       mean_auc
# Parkinsons            0.721116
# CKD                   0.706205
# Heart_Failure         0.699092
# Osteoporosis          0.689301
# Bladder_Cancer        0.685003
# Stroke                0.682043
# Lung_Cancer           0.664386
# Prostate_Cancer       0.661342
# COPD                  0.656095
# All_Cancers           0.653230
# ASCVD                 0.652882
# Pneumonia             0.643167
# Secondary_Cancer      0.605142
# Colorectal_Cancer     0.602444
# Multiple_Sclerosis    0.599871
# Diabetes              0.598152
# Thyroid_Disorders     0.586794
# Anemia                0.580701
# Rheumatoid_Arthritis  0.574710
# Ulcerative_Colitis    0.542664
# Crohns_Disease        0.540576
# Bipolar_Disorder      0.533674
# Atrial_Fib            0.529457
# Psoriasis             0.526381
# Asthma                0.523253
# Breast_Cancer         0.515143
# Anxiety               0.513754
# Depression            0.485151
#
# ================================================================================
# JOINT PHI - 30 YEAR PREDICTIONS - Mean AUC
# ================================================================================
#                       mean_auc
# ASCVD                 0.703365
# Diabetes              0.696332
# Prostate_Cancer       0.672435
# Osteoporosis          0.639826
# Bladder_Cancer        0.628550
# Lung_Cancer           0.623859
# All_Cancers           0.614744
# Thyroid_Disorders     0.606476
# Parkinsons            0.606325
# Atrial_Fib            0.596618
# Colorectal_Cancer     0.588756
# Crohns_Disease        0.579967
# Heart_Failure         0.579501
# Rheumatoid_Arthritis  0.573866
# CKD                   0.573490
# Stroke                0.572550
# COPD                  0.569477
# Secondary_Cancer      0.564597
# Breast_Cancer         0.560701
# Ulcerative_Colitis    0.556244
# Asthma                0.542578
# Pneumonia             0.542174
# Depression            0.533278
# Anemia                0.517863
# Anxiety               0.514200
# Multiple_Sclerosis    0.507602
# Bipolar_Disorder      0.500857
# Psoriasis             0.489158
#
# ================================================================================
# FIXED PHI - 10 YEAR PREDICTIONS - Mean AUC
# ================================================================================
#                       mean_auc
# Parkinsons            0.739363
# CKD                   0.715460
# Lung_Cancer           0.692194
# Heart_Failure         0.673144
# COPD                  0.657967
# Osteoporosis          0.657262
# Pneumonia             0.653364
# Stroke                0.645637
# Prostate_Cancer       0.642298
# All_Cancers           0.641837
# Secondary_Cancer      0.630118
# Bladder_Cancer        0.627813
# Atrial_Fib            0.623347
# Crohns_Disease        0.611737
# Anemia                0.596487
# Diabetes              0.594572
# Bipolar_Disorder      0.591305
# Colorectal_Cancer     0.587596
# ASCVD                 0.587301
# Rheumatoid_Arthritis  0.583031
# Anxiety               0.581187
# Thyroid_Disorders     0.572303
# Breast_Cancer         0.571250
# Multiple_Sclerosis    0.564590
# Ulcerative_Colitis    0.562681
# Asthma                0.554991
# Depression            0.554586
# Psoriasis             0.546828
#
# ================================================================================
# FIXED PHI - 30 YEAR PREDICTIONS - Mean AUC
# ================================================================================
#                       mean_auc
# CKD                   0.578008
# Parkinsons            0.571755
# Heart_Failure         0.568797
# Stroke                0.561772
# COPD                  0.559472
# Lung_Cancer           0.551298
# Pneumonia             0.547067
# Osteoporosis          0.543552
# All_Cancers           0.543066
# Bladder_Cancer        0.541967
# Colorectal_Cancer     0.535862
# Anemia                0.534462
# Atrial_Fib            0.530305
# Secondary_Cancer      0.530202
# Diabetes              0.528453
# Psoriasis             0.527065
# Anxiety               0.525495
# Prostate_Cancer       0.524709
# Crohns_Disease        0.519898
# ASCVD                 0.519457
# Thyroid_Disorders     0.515507
# Multiple_Sclerosis    0.514462
# Depression            0.504150
# Asthma                0.504021
# Rheumatoid_Arthritis  0.503648
# Breast_Cancer         0.503350
# Bipolar_Disorder      0.498164
# Ulcerative_Colitis    0.489922
#
# ================================================================================
# JOINT PHI - STATIC 10 YEAR PREDICTIONS (1-year score) - Mean AUC
# ================================================================================
#                       mean_auc
# ASCVD                 0.722932
# Parkinsons            0.720981
# Bladder_Cancer        0.706558
# CKD                   0.704750
# Heart_Failure         0.699902
# Atrial_Fib            0.685920
# Prostate_Cancer       0.684700
# Stroke                0.681243
# Osteoporosis          0.676236
# All_Cancers           0.670238
# Lung_Cancer           0.667647
# COPD                  0.655607
# Colorectal_Cancer     0.643825
# Pneumonia             0.643501
# Diabetes              0.631386
# Secondary_Cancer      0.610432
# Rheumatoid_Arthritis  0.606947
# Crohns_Disease        0.593632
# Thyroid_Disorders     0.586774
# Anemia                0.585709
# Ulcerative_Colitis    0.584446
# Multiple_Sclerosis    0.557238
# Breast_Cancer         0.546738
# Psoriasis             0.540873
# Asthma                0.525583
# Anxiety               0.513166
# Bipolar_Disorder      0.498378
# Depression            0.484919
#
# ================================================================================
# FIXED PHI - STATIC 10 YEAR PREDICTIONS (1-year score) - Mean AUC
# ================================================================================
#                       mean_auc
# Parkinsons            0.737058
# CKD                   0.717195
# Lung_Cancer           0.690455
# Heart_Failure         0.671777
# COPD                  0.658240
# Osteoporosis          0.656997
# Pneumonia             0.654923
# Stroke                0.645936
# All_Cancers           0.642774
# Bladder_Cancer        0.637864
# Prostate_Cancer       0.635811
# Secondary_Cancer      0.630949
# Atrial_Fib            0.616870
# Diabetes              0.599660
# Anemia                0.594243
# Rheumatoid_Arthritis  0.588251
# Colorectal_Cancer     0.587175
# Anxiety               0.586588
# ASCVD                 0.586543
# Thyroid_Disorders     0.569950
# Depression            0.555680
# Psoriasis             0.555454
# Breast_Cancer         0.553550
# Multiple_Sclerosis    0.551236
# Bipolar_Disorder      0.547019
# Asthma                0.540036
# Ulcerative_Colitis    0.539850
# Crohns_Disease        0.535911
#
# Mean AUC DataFrames saved to CSV files.
