# %%
# %load_ext autoreload
# %autoreload 2
from optimize_psi import *
from cluster_g_logit_init_acceptpsi import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import rpy2.robjects as robjects
import numpy as np
import os as os
from rpy2.robjects import numpy2ri
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt



# Specify the path to your data files
data_path = "/Users/sarahurbut/tensornoulli_ehr_new/data"

# Activate automatic conversion between R and NumPy arrays
numpy2ri.activate()# Load data saved as .rds files
Y = np.array(robjects.r['readRDS'](os.path.join(data_path, 'Y.rds')))
E = np.array(robjects.r['readRDS'](os.path.join(data_path, 'event_for_aladynoulli.rds')))
G = np.array(robjects.r['readRDS'](os.path.join(data_path, 'prs.rds')))

E = E.astype(int)

# G should be float64
G = G.astype(float)
G.shape
G = G.T
print("G shape after transposition:", G.shape)

# Convert to PyTorch tensors
Y_tensor = torch.FloatTensor(Y)
E_tensor = torch.FloatTensor(E)
G_tensor = torch.FloatTensor(G)

# Get dimensions
N, D, T = Y_tensor.shape
P = G_tensor.shape[1]
T = int(E_tensor.max() + 1)  # 0-indexed time
K = 10  # number of topics

# Print shapes to verify
print("Tensor shapes:")
print(f"Y: {Y_tensor.shape}")  # [N, D]
print(f"E: {E_tensor.shape}")  # [N, D]
print(f"G: {G_tensor.shape}")  # [N, P]
print(f"Time range: 0 to {T-1}")
print(T)
print(K)


import rpy2.robjects as robjects
import pandas as pd
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the metadata from R
disease_names = pd.DataFrame(robjects.r['readRDS']('/Users/sarahurbut/Dropbox (Personal)/disease_names.rds'))
prs_names = pd.DataFrame(robjects.r['readRDS']('/Users/sarahurbut/Dropbox (Personal)/prs_names.rds'))
disease_names_list = disease_names[0].tolist()
# Out:
# G shape after transposition: (9661, 36)
# Tensor shapes:
# Y: torch.Size([9661, 348, 51])
# E: torch.Size([9661, 348])
# G: torch.Size([9661, 36])
# Time range: 0 to 50
# 51
# 10

# %%
prevalence_t=compute_smoothed_prevalence(Y=Y,window_size=5)
K=20

# %%
        # Convert Y to tensor if it's not already
Y_tensor = torch.tensor(Y) if isinstance(Y, np.ndarray) else Y

# %%
psi_config = {'in_cluster': 1, 'out_cluster': -2, 'noise_in': 0.1, 'noise_out': 0.01}

# %%
# choosing the best

model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(N,D,T,K,P,G_tensor,Y=Y, prevalence_t=prevalence_t,disease_names=disease_names_list)
model.initialize_params(psi_config=psi_config)
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# Lambda kernel condition number: 45200668.00
# Phi kernel condition number: 89734320.00
#
# Cluster Sizes:
# Cluster 0: 27 diseases
# Cluster 1: 32 diseases
# Cluster 2: 12 diseases
# Cluster 3: 9 diseases
# Cluster 4: 19 diseases
# Cluster 5: 74 diseases
# Cluster 6: 31 diseases
# Cluster 7: 12 diseases
# Cluster 8: 10 diseases
# Cluster 9: 8 diseases
# Cluster 10: 5 diseases
# Cluster 11: 10 diseases
# Cluster 12: 6 diseases
# Cluster 13: 12 diseases
# Cluster 14: 14 diseases
# Cluster 15: 9 diseases
# Cluster 16: 23 diseases
# Cluster 17: 5 diseases
# Cluster 18: 18 diseases
# Cluster 19: 12 diseases
# Initialization complete!
#
# Using psi configuration
# Initialization complete!

# %%
model.plot_initial_params()
model.visualize_initialization()
model.psi
# Out:
# Cluster membership for sampled diseases:
# Disease 12: Cluster 4
# Disease 39: Cluster 18
# Disease 8: Cluster 4
# Disease 117: Cluster 18
# Disease 46: Cluster 5
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:617: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()
# Parameter containing:
# tensor([[-2.0074, -1.9777, -2.0048,  ..., -1.9961, -1.9919,  0.8714],
#         [-2.0099, -1.9968,  0.8835,  ..., -1.9951, -1.9993, -1.9978],
#         [-1.9840, -1.9771, -1.9949,  ..., -1.9969, -2.0018, -2.0130],
#         ...,
#         [-1.9867, -2.0025, -2.0107,  ..., -1.9795, -2.0111, -1.9796],
#         [-1.9946,  1.0720, -1.9859,  ..., -1.9973, -2.0100, -2.0079],
#         [ 1.1249, -1.9933, -2.0008,  ..., -1.9870, -1.9937, -2.0204]],
#        requires_grad=True)

# %%
history = model.fit(E_tensor, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:196: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 0
# Loss: 1108.1832
# Psi gradient stats:
# Mean: -2.4690e-05
# Std:  4.6851e-03
# Max:  1.9393e-02
# Min:  -2.1046e-02
# Average psi change: 9.9959e-05
# Epoch 0, Loss: 1108.1832, Gradients - Lambda: 5.540e-01, Phi: 1.330e+01, Gamma: 6.024e-02, Psi: 2.105e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 1
# Loss: 843.5457
# Psi gradient stats:
# Mean: -2.3464e-05
# Std:  4.6708e-03
# Max:  1.9204e-02
# Min:  -2.1102e-02
# Average psi change: 9.9289e-05
# Epoch 1, Loss: 843.5457, Gradients - Lambda: 5.052e-01, Phi: 1.258e+01, Gamma: 6.054e-02, Psi: 2.110e-02
#
# Estimated total training time: 917.7 minutes
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 2
# Loss: 654.6707
# Psi gradient stats:
# Mean: -2.3000e-05
# Std:  4.6572e-03
# Max:  1.8976e-02
# Min:  -2.1126e-02
# Average psi change: 9.8872e-05
# Epoch 2, Loss: 654.6707, Gradients - Lambda: 4.659e-01, Phi: 1.196e+01, Gamma: 6.100e-02, Psi: 2.113e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 3
# Loss: 525.6383
# Psi gradient stats:
# Mean: -2.3054e-05
# Std:  4.6435e-03
# Max:  1.8746e-02
# Min:  -2.1127e-02
# Average psi change: 9.8480e-05
# Epoch 3, Loss: 525.6383, Gradients - Lambda: 4.260e-01, Phi: 1.134e+01, Gamma: 6.135e-02, Psi: 2.113e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 4
# Loss: 440.2949
# Psi gradient stats:
# Mean: -2.3532e-05
# Std:  4.6293e-03
# Max:  1.8535e-02
# Min:  -2.1106e-02
# Average psi change: 9.8162e-05
# Epoch 4, Loss: 440.2949, Gradients - Lambda: 3.864e-01, Phi: 1.068e+01, Gamma: 6.144e-02, Psi: 2.111e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 5
# Loss: 385.4010
# Psi gradient stats:
# Mean: -2.4406e-05
# Std:  4.6144e-03
# Max:  1.8339e-02
# Min:  -2.1062e-02
# Average psi change: 9.7815e-05
# Epoch 5, Loss: 385.4010, Gradients - Lambda: 3.542e-01, Phi: 9.964e+00, Gamma: 6.131e-02, Psi: 2.106e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 6
# Loss: 351.1485
# Psi gradient stats:
# Mean: -2.5554e-05
# Std:  4.5992e-03
# Max:  1.8149e-02
# Min:  -2.0996e-02
# Average psi change: 9.7530e-05
# Epoch 6, Loss: 351.1485, Gradients - Lambda: 3.288e-01, Phi: 9.236e+00, Gamma: 6.101e-02, Psi: 2.100e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 7
# Loss: 330.3488
# Psi gradient stats:
# Mean: -2.7033e-05
# Std:  4.5837e-03
# Max:  1.7964e-02
# Min:  -2.0908e-02
# Average psi change: 9.7222e-05
# Epoch 7, Loss: 330.3488, Gradients - Lambda: 3.035e-01, Phi: 8.509e+00, Gamma: 6.062e-02, Psi: 2.091e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 8
# Loss: 317.7695
# Psi gradient stats:
# Mean: -2.8843e-05
# Std:  4.5683e-03
# Max:  1.7779e-02
# Min:  -2.0807e-02
# Average psi change: 9.6881e-05
# Epoch 8, Loss: 317.7695, Gradients - Lambda: 2.771e-01, Phi: 7.808e+00, Gamma: 6.014e-02, Psi: 2.081e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 9
# Loss: 309.8046
# Psi gradient stats:
# Mean: -3.1006e-05
# Std:  4.5534e-03
# Max:  1.7598e-02
# Min:  -2.0692e-02
# Average psi change: 9.6603e-05
# Epoch 9, Loss: 309.8046, Gradients - Lambda: 2.492e-01, Phi: 7.156e+00, Gamma: 5.958e-02, Psi: 2.069e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 10
# Loss: 304.2035
# Psi gradient stats:
# Mean: -3.3388e-05
# Std:  4.5392e-03
# Max:  1.7423e-02
# Min:  -2.0567e-02
# Average psi change: 9.6360e-05
# Epoch 10, Loss: 304.2035, Gradients - Lambda: 2.206e-01, Phi: 6.541e+00, Gamma: 5.891e-02, Psi: 2.057e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 11
# Loss: 299.6763
# Psi gradient stats:
# Mean: -3.5786e-05
# Std:  4.5260e-03
# Max:  1.7257e-02
# Min:  -2.0432e-02
# Average psi change: 9.6134e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 12
# Loss: 295.5410
# Psi gradient stats:
# Mean: -3.7987e-05
# Std:  4.5139e-03
# Max:  1.7103e-02
# Min:  -2.0291e-02
# Average psi change: 9.5925e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 13
# Loss: 291.4909
# Psi gradient stats:
# Mean: -3.9876e-05
# Std:  4.5030e-03
# Max:  1.6960e-02
# Min:  -2.0147e-02
# Average psi change: 9.5707e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 14
# Loss: 287.4642
# Psi gradient stats:
# Mean: -4.1456e-05
# Std:  4.4934e-03
# Max:  1.6997e-02
# Min:  -2.0006e-02
# Average psi change: 9.5510e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 15
# Loss: 283.5309
# Psi gradient stats:
# Mean: -4.2820e-05
# Std:  4.4850e-03
# Max:  1.7103e-02
# Min:  -1.9868e-02
# Average psi change: 9.5331e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 16
# Loss: 279.8030
# Psi gradient stats:
# Mean: -4.4098e-05
# Std:  4.4777e-03
# Max:  1.7202e-02
# Min:  -1.9735e-02
# Average psi change: 9.5153e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 17
# Loss: 276.3742
# Psi gradient stats:
# Mean: -4.5333e-05
# Std:  4.4716e-03
# Max:  1.7287e-02
# Min:  -1.9607e-02
# Average psi change: 9.4978e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 18
# Loss: 273.3068
# Psi gradient stats:
# Mean: -4.6522e-05
# Std:  4.4664e-03
# Max:  1.7352e-02
# Min:  -1.9486e-02
# Average psi change: 9.4844e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 19
# Loss: 270.6279
# Psi gradient stats:
# Mean: -4.7620e-05
# Std:  4.4622e-03
# Max:  1.7400e-02
# Min:  -1.9374e-02
# Average psi change: 9.4732e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 20
# Loss: 268.3338
# Psi gradient stats:
# Mean: -4.8631e-05
# Std:  4.4587e-03
# Max:  1.7439e-02
# Min:  -1.9272e-02
# Average psi change: 9.4633e-05
# Epoch 20, Loss: 268.3338, Gradients - Lambda: 7.415e-02, Phi: 1.720e+00, Gamma: 5.184e-02, Psi: 1.927e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 21
# Loss: 266.3916
# Psi gradient stats:
# Mean: -4.9576e-05
# Std:  4.4559e-03
# Max:  1.7478e-02
# Min:  -1.9180e-02
# Average psi change: 9.4604e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 22
# Loss: 264.7523
# Psi gradient stats:
# Mean: -5.0495e-05
# Std:  4.4536e-03
# Max:  1.7520e-02
# Min:  -1.9099e-02
# Average psi change: 9.4632e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 23
# Loss: 263.3569
# Psi gradient stats:
# Mean: -5.1355e-05
# Std:  4.4518e-03
# Max:  1.7563e-02
# Min:  -1.9024e-02
# Average psi change: 9.4667e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 24
# Loss: 262.1520
# Psi gradient stats:
# Mean: -5.2130e-05
# Std:  4.4503e-03
# Max:  1.7603e-02
# Min:  -1.8956e-02
# Average psi change: 9.4692e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 25
# Loss: 261.0899
# Psi gradient stats:
# Mean: -5.2774e-05
# Std:  4.4488e-03
# Max:  1.7635e-02
# Min:  -1.8892e-02
# Average psi change: 9.4723e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 26
# Loss: 260.1357
# Psi gradient stats:
# Mean: -5.3310e-05
# Std:  4.4473e-03
# Max:  1.7661e-02
# Min:  -1.8833e-02
# Average psi change: 9.4748e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 27
# Loss: 259.2698
# Psi gradient stats:
# Mean: -5.3779e-05
# Std:  4.4458e-03
# Max:  1.7686e-02
# Min:  -1.8780e-02
# Average psi change: 9.4763e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 28
# Loss: 258.4769
# Psi gradient stats:
# Mean: -5.4198e-05
# Std:  4.4444e-03
# Max:  1.7709e-02
# Min:  -1.8734e-02
# Average psi change: 9.4758e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 29
# Loss: 257.7409
# Psi gradient stats:
# Mean: -5.4549e-05
# Std:  4.4429e-03
# Max:  1.7726e-02
# Min:  -1.8698e-02
# Average psi change: 9.4742e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 30
# Loss: 257.0592
# Psi gradient stats:
# Mean: -5.4808e-05
# Std:  4.4414e-03
# Max:  1.7736e-02
# Min:  -1.8668e-02
# Average psi change: 9.4710e-05
# Epoch 30, Loss: 257.0592, Gradients - Lambda: 3.908e-02, Phi: 8.224e-01, Gamma: 4.607e-02, Psi: 1.867e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 31
# Loss: 256.4233
# Psi gradient stats:
# Mean: -5.4957e-05
# Std:  4.4398e-03
# Max:  1.7738e-02
# Min:  -1.8646e-02
# Average psi change: 9.4667e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 32
# Loss: 255.8274
# Psi gradient stats:
# Mean: -5.5003e-05
# Std:  4.4382e-03
# Max:  1.7735e-02
# Min:  -1.8630e-02
# Average psi change: 9.4611e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 33
# Loss: 255.2675
# Psi gradient stats:
# Mean: -5.4983e-05
# Std:  4.4364e-03
# Max:  1.7733e-02
# Min:  -1.8620e-02
# Average psi change: 9.4540e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 34
# Loss: 254.7418
# Psi gradient stats:
# Mean: -5.4906e-05
# Std:  4.4346e-03
# Max:  1.7733e-02
# Min:  -1.8613e-02
# Average psi change: 9.4455e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 35
# Loss: 254.2491
# Psi gradient stats:
# Mean: -5.4802e-05
# Std:  4.4328e-03
# Max:  1.7733e-02
# Min:  -1.8611e-02
# Average psi change: 9.4362e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 36
# Loss: 253.7839
# Psi gradient stats:
# Mean: -5.4654e-05
# Std:  4.4311e-03
# Max:  1.7727e-02
# Min:  -1.8614e-02
# Average psi change: 9.4261e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 37
# Loss: 253.3402
# Psi gradient stats:
# Mean: -5.4475e-05
# Std:  4.4294e-03
# Max:  1.7711e-02
# Min:  -1.8620e-02
# Average psi change: 9.4152e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 38
# Loss: 252.9191
# Psi gradient stats:
# Mean: -5.4253e-05
# Std:  4.4277e-03
# Max:  1.7688e-02
# Min:  -1.8625e-02
# Average psi change: 9.4037e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 39
# Loss: 252.5190
# Psi gradient stats:
# Mean: -5.4002e-05
# Std:  4.4261e-03
# Max:  1.7666e-02
# Min:  -1.8630e-02
# Average psi change: 9.3921e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 40
# Loss: 252.1337
# Psi gradient stats:
# Mean: -5.3780e-05
# Std:  4.4245e-03
# Max:  1.7651e-02
# Min:  -1.8631e-02
# Average psi change: 9.3804e-05
# Epoch 40, Loss: 252.1337, Gradients - Lambda: 3.016e-02, Phi: 6.424e-01, Gamma: 4.078e-02, Psi: 1.863e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 41
# Loss: 251.7634
# Psi gradient stats:
# Mean: -5.3620e-05
# Std:  4.4230e-03
# Max:  1.7643e-02
# Min:  -1.8631e-02
# Average psi change: 9.3690e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 42
# Loss: 251.4095
# Psi gradient stats:
# Mean: -5.3502e-05
# Std:  4.4214e-03
# Max:  1.7639e-02
# Min:  -1.8632e-02
# Average psi change: 9.3580e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 43
# Loss: 251.0688
# Psi gradient stats:
# Mean: -5.3400e-05
# Std:  4.4198e-03
# Max:  1.7632e-02
# Min:  -1.8637e-02
# Average psi change: 9.3474e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 44
# Loss: 250.7404
# Psi gradient stats:
# Mean: -5.3247e-05
# Std:  4.4181e-03
# Max:  1.7622e-02
# Min:  -1.8642e-02
# Average psi change: 9.3376e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 45
# Loss: 250.4222
# Psi gradient stats:
# Mean: -5.3067e-05
# Std:  4.4164e-03
# Max:  1.7614e-02
# Min:  -1.8647e-02
# Average psi change: 9.3283e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 46
# Loss: 250.1152
# Psi gradient stats:
# Mean: -5.2920e-05
# Std:  4.4148e-03
# Max:  1.7610e-02
# Min:  -1.8650e-02
# Average psi change: 9.3199e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 47
# Loss: 249.8175
# Psi gradient stats:
# Mean: -5.2841e-05
# Std:  4.4132e-03
# Max:  1.7613e-02
# Min:  -1.8651e-02
# Average psi change: 9.3123e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 48
# Loss: 249.5293
# Psi gradient stats:
# Mean: -5.2823e-05
# Std:  4.4116e-03
# Max:  1.7617e-02
# Min:  -1.8652e-02
# Average psi change: 9.3052e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 49
# Loss: 249.2486
# Psi gradient stats:
# Mean: -5.2796e-05
# Std:  4.4100e-03
# Max:  1.7618e-02
# Min:  -1.8653e-02
# Average psi change: 9.2987e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 50
# Loss: 248.9747
# Psi gradient stats:
# Mean: -5.2739e-05
# Std:  4.4084e-03
# Max:  1.7614e-02
# Min:  -1.8656e-02
# Average psi change: 9.2927e-05
# Epoch 50, Loss: 248.9747, Gradients - Lambda: 2.849e-02, Phi: 5.153e-01, Gamma: 3.569e-02, Psi: 1.866e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 51
# Loss: 248.7088
# Psi gradient stats:
# Mean: -5.2644e-05
# Std:  4.4067e-03
# Max:  1.7606e-02
# Min:  -1.8659e-02
# Average psi change: 9.2873e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 52
# Loss: 248.4513
# Psi gradient stats:
# Mean: -5.2569e-05
# Std:  4.4051e-03
# Max:  1.7601e-02
# Min:  -1.8659e-02
# Average psi change: 9.2826e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 53
# Loss: 248.1967
# Psi gradient stats:
# Mean: -5.2530e-05
# Std:  4.4034e-03
# Max:  1.7603e-02
# Min:  -1.8657e-02
# Average psi change: 9.2783e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 54
# Loss: 247.9501
# Psi gradient stats:
# Mean: -5.2527e-05
# Std:  4.4018e-03
# Max:  1.7610e-02
# Min:  -1.8654e-02
# Average psi change: 9.2740e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 55
# Loss: 247.7097
# Psi gradient stats:
# Mean: -5.2543e-05
# Std:  4.4001e-03
# Max:  1.7617e-02
# Min:  -1.8654e-02
# Average psi change: 9.2700e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 56
# Loss: 247.4732
# Psi gradient stats:
# Mean: -5.2562e-05
# Std:  4.3985e-03
# Max:  1.7618e-02
# Min:  -1.8653e-02
# Average psi change: 9.2662e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 57
# Loss: 247.2416
# Psi gradient stats:
# Mean: -5.2607e-05
# Std:  4.3968e-03
# Max:  1.7611e-02
# Min:  -1.8651e-02
# Average psi change: 9.2626e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 58
# Loss: 247.0165
# Psi gradient stats:
# Mean: -5.2650e-05
# Std:  4.3951e-03
# Max:  1.7602e-02
# Min:  -1.8645e-02
# Average psi change: 9.2596e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 59
# Loss: 246.7943
# Psi gradient stats:
# Mean: -5.2657e-05
# Std:  4.3935e-03
# Max:  1.7599e-02
# Min:  -1.8638e-02
# Average psi change: 9.2566e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 60
# Loss: 246.5766
# Psi gradient stats:
# Mean: -5.2618e-05
# Std:  4.3919e-03
# Max:  1.7602e-02
# Min:  -1.8631e-02
# Average psi change: 9.2539e-05
# Epoch 60, Loss: 246.5766, Gradients - Lambda: 3.095e-02, Phi: 5.457e-01, Gamma: 3.100e-02, Psi: 1.863e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 61
# Loss: 246.3664
# Psi gradient stats:
# Mean: -5.2568e-05
# Std:  4.3901e-03
# Max:  1.7608e-02
# Min:  -1.8626e-02
# Average psi change: 9.2513e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 62
# Loss: 246.1572
# Psi gradient stats:
# Mean: -5.2555e-05
# Std:  4.3884e-03
# Max:  1.7611e-02
# Min:  -1.8624e-02
# Average psi change: 9.2484e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 63
# Loss: 245.9526
# Psi gradient stats:
# Mean: -5.2601e-05
# Std:  4.3867e-03
# Max:  1.7607e-02
# Min:  -1.8622e-02
# Average psi change: 9.2454e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 64
# Loss: 245.7531
# Psi gradient stats:
# Mean: -5.2672e-05
# Std:  4.3851e-03
# Max:  1.7601e-02
# Min:  -1.8616e-02
# Average psi change: 9.2428e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 65
# Loss: 245.5547
# Psi gradient stats:
# Mean: -5.2678e-05
# Std:  4.3834e-03
# Max:  1.7596e-02
# Min:  -1.8608e-02
# Average psi change: 9.2400e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 66
# Loss: 245.3603
# Psi gradient stats:
# Mean: -5.2622e-05
# Std:  4.3817e-03
# Max:  1.7597e-02
# Min:  -1.8598e-02
# Average psi change: 9.2375e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 67
# Loss: 245.1726
# Psi gradient stats:
# Mean: -5.2537e-05
# Std:  4.3800e-03
# Max:  1.7601e-02
# Min:  -1.8592e-02
# Average psi change: 9.2350e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 68
# Loss: 244.9862
# Psi gradient stats:
# Mean: -5.2508e-05
# Std:  4.3782e-03
# Max:  1.7605e-02
# Min:  -1.8590e-02
# Average psi change: 9.2327e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 69
# Loss: 244.8008
# Psi gradient stats:
# Mean: -5.2541e-05
# Std:  4.3765e-03
# Max:  1.7603e-02
# Min:  -1.8587e-02
# Average psi change: 9.2299e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 70
# Loss: 244.6234
# Psi gradient stats:
# Mean: -5.2607e-05
# Std:  4.3748e-03
# Max:  1.7596e-02
# Min:  -1.8582e-02
# Average psi change: 9.2271e-05
# Epoch 70, Loss: 244.6234, Gradients - Lambda: 3.673e-02, Phi: 5.475e-01, Gamma: 2.647e-02, Psi: 1.858e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 71
# Loss: 244.4476
# Psi gradient stats:
# Mean: -5.2636e-05
# Std:  4.3731e-03
# Max:  1.7591e-02
# Min:  -1.8574e-02
# Average psi change: 9.2243e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 72
# Loss: 244.2704
# Psi gradient stats:
# Mean: -5.2585e-05
# Std:  4.3714e-03
# Max:  1.7592e-02
# Min:  -1.8567e-02
# Average psi change: 9.2219e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 73
# Loss: 244.1016
# Psi gradient stats:
# Mean: -5.2495e-05
# Std:  4.3697e-03
# Max:  1.7599e-02
# Min:  -1.8562e-02
# Average psi change: 9.2195e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 74
# Loss: 243.9361
# Psi gradient stats:
# Mean: -5.2454e-05
# Std:  4.3680e-03
# Max:  1.7605e-02
# Min:  -1.8561e-02
# Average psi change: 9.2168e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 75
# Loss: 243.7699
# Psi gradient stats:
# Mean: -5.2472e-05
# Std:  4.3662e-03
# Max:  1.7604e-02
# Min:  -1.8559e-02
# Average psi change: 9.2141e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 76
# Loss: 243.6081
# Psi gradient stats:
# Mean: -5.2530e-05
# Std:  4.3645e-03
# Max:  1.7599e-02
# Min:  -1.8553e-02
# Average psi change: 9.2112e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 77
# Loss: 243.4507
# Psi gradient stats:
# Mean: -5.2544e-05
# Std:  4.3628e-03
# Max:  1.7591e-02
# Min:  -1.8544e-02
# Average psi change: 9.2088e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 78
# Loss: 243.2926
# Psi gradient stats:
# Mean: -5.2494e-05
# Std:  4.3611e-03
# Max:  1.7588e-02
# Min:  -1.8535e-02
# Average psi change: 9.2066e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 79
# Loss: 243.1396
# Psi gradient stats:
# Mean: -5.2423e-05
# Std:  4.3594e-03
# Max:  1.7590e-02
# Min:  -1.8531e-02
# Average psi change: 9.2045e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 80
# Loss: 242.9898
# Psi gradient stats:
# Mean: -5.2396e-05
# Std:  4.3577e-03
# Max:  1.7595e-02
# Min:  -1.8530e-02
# Average psi change: 9.2023e-05
# Epoch 80, Loss: 242.9898, Gradients - Lambda: 3.959e-02, Phi: 5.874e-01, Gamma: 2.252e-02, Psi: 1.853e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 81
# Loss: 242.8420
# Psi gradient stats:
# Mean: -5.2455e-05
# Std:  4.3560e-03
# Max:  1.7596e-02
# Min:  -1.8529e-02
# Average psi change: 9.1993e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 82
# Loss: 242.6956
# Psi gradient stats:
# Mean: -5.2524e-05
# Std:  4.3542e-03
# Max:  1.7593e-02
# Min:  -1.8524e-02
# Average psi change: 9.1964e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 83
# Loss: 242.5533
# Psi gradient stats:
# Mean: -5.2504e-05
# Std:  4.3525e-03
# Max:  1.7587e-02
# Min:  -1.8516e-02
# Average psi change: 9.1939e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 84
# Loss: 242.4128
# Psi gradient stats:
# Mean: -5.2401e-05
# Std:  4.3508e-03
# Max:  1.7584e-02
# Min:  -1.8505e-02
# Average psi change: 9.1919e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 85
# Loss: 242.2747
# Psi gradient stats:
# Mean: -5.2282e-05
# Std:  4.3491e-03
# Max:  1.7584e-02
# Min:  -1.8499e-02
# Average psi change: 9.1900e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 86
# Loss: 242.1400
# Psi gradient stats:
# Mean: -5.2254e-05
# Std:  4.3474e-03
# Max:  1.7587e-02
# Min:  -1.8497e-02
# Average psi change: 9.1879e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 87
# Loss: 242.0070
# Psi gradient stats:
# Mean: -5.2347e-05
# Std:  4.3456e-03
# Max:  1.7588e-02
# Min:  -1.8498e-02
# Average psi change: 9.1853e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 88
# Loss: 241.8773
# Psi gradient stats:
# Mean: -5.2459e-05
# Std:  4.3438e-03
# Max:  1.7587e-02
# Min:  -1.8497e-02
# Average psi change: 9.1824e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 89
# Loss: 241.7483
# Psi gradient stats:
# Mean: -5.2486e-05
# Std:  4.3421e-03
# Max:  1.7585e-02
# Min:  -1.8489e-02
# Average psi change: 9.1797e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 90
# Loss: 241.6227
# Psi gradient stats:
# Mean: -5.2378e-05
# Std:  4.3404e-03
# Max:  1.7583e-02
# Min:  -1.8477e-02
# Average psi change: 9.1775e-05
# Epoch 90, Loss: 241.6227, Gradients - Lambda: 4.365e-02, Phi: 6.429e-01, Gamma: 1.877e-02, Psi: 1.848e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 91
# Loss: 241.5008
# Psi gradient stats:
# Mean: -5.2220e-05
# Std:  4.3387e-03
# Max:  1.7581e-02
# Min:  -1.8468e-02
# Average psi change: 9.1753e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 92
# Loss: 241.3784
# Psi gradient stats:
# Mean: -5.2147e-05
# Std:  4.3369e-03
# Max:  1.7580e-02
# Min:  -1.8466e-02
# Average psi change: 9.1733e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 93
# Loss: 241.2598
# Psi gradient stats:
# Mean: -5.2230e-05
# Std:  4.3351e-03
# Max:  1.7580e-02
# Min:  -1.8469e-02
# Average psi change: 9.1709e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 94
# Loss: 241.1438
# Psi gradient stats:
# Mean: -5.2389e-05
# Std:  4.3334e-03
# Max:  1.7581e-02
# Min:  -1.8470e-02
# Average psi change: 9.1682e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 95
# Loss: 241.0269
# Psi gradient stats:
# Mean: -5.2476e-05
# Std:  4.3317e-03
# Max:  1.7583e-02
# Min:  -1.8462e-02
# Average psi change: 9.1654e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 96
# Loss: 240.9142
# Psi gradient stats:
# Mean: -5.2396e-05
# Std:  4.3300e-03
# Max:  1.7584e-02
# Min:  -1.8448e-02
# Average psi change: 9.1631e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 97
# Loss: 240.8056
# Psi gradient stats:
# Mean: -5.2212e-05
# Std:  4.3283e-03
# Max:  1.7580e-02
# Min:  -1.8437e-02
# Average psi change: 9.1609e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 98
# Loss: 240.6950
# Psi gradient stats:
# Mean: -5.2069e-05
# Std:  4.3265e-03
# Max:  1.7575e-02
# Min:  -1.8435e-02
# Average psi change: 9.1592e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 99
# Loss: 240.5881
# Psi gradient stats:
# Mean: -5.2086e-05
# Std:  4.3247e-03
# Max:  1.7574e-02
# Min:  -1.8439e-02
# Average psi change: 9.1570e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 100
# Loss: 240.4848
# Psi gradient stats:
# Mean: -5.2256e-05
# Std:  4.3229e-03
# Max:  1.7579e-02
# Min:  -1.8439e-02
# Average psi change: 9.1545e-05
# Epoch 100, Loss: 240.4848, Gradients - Lambda: 4.643e-02, Phi: 6.607e-01, Gamma: 1.550e-02, Psi: 1.844e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 101
# Loss: 240.3815
# Psi gradient stats:
# Mean: -5.2401e-05
# Std:  4.3212e-03
# Max:  1.7584e-02
# Min:  -1.8430e-02
# Average psi change: 9.1518e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 102
# Loss: 240.2798
# Psi gradient stats:
# Mean: -5.2395e-05
# Std:  4.3195e-03
# Max:  1.7583e-02
# Min:  -1.8416e-02
# Average psi change: 9.1492e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 103
# Loss: 240.1817
# Psi gradient stats:
# Mean: -5.2222e-05
# Std:  4.3178e-03
# Max:  1.7576e-02
# Min:  -1.8404e-02
# Average psi change: 9.1469e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 104
# Loss: 240.0850
# Psi gradient stats:
# Mean: -5.2018e-05
# Std:  4.3160e-03
# Max:  1.7567e-02
# Min:  -1.8400e-02
# Average psi change: 9.1449e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 105
# Loss: 239.9865
# Psi gradient stats:
# Mean: -5.1980e-05
# Std:  4.3142e-03
# Max:  1.7566e-02
# Min:  -1.8403e-02
# Average psi change: 9.1430e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 106
# Loss: 239.8945
# Psi gradient stats:
# Mean: -5.2125e-05
# Std:  4.3124e-03
# Max:  1.7573e-02
# Min:  -1.8407e-02
# Average psi change: 9.1409e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 107
# Loss: 239.8029
# Psi gradient stats:
# Mean: -5.2307e-05
# Std:  4.3108e-03
# Max:  1.7580e-02
# Min:  -1.8404e-02
# Average psi change: 9.1385e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 108
# Loss: 239.7104
# Psi gradient stats:
# Mean: -5.2344e-05
# Std:  4.3092e-03
# Max:  1.7580e-02
# Min:  -1.8393e-02
# Average psi change: 9.1360e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 109
# Loss: 239.6203
# Psi gradient stats:
# Mean: -5.2180e-05
# Std:  4.3074e-03
# Max:  1.7568e-02
# Min:  -1.8380e-02
# Average psi change: 9.1336e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 110
# Loss: 239.5342
# Psi gradient stats:
# Mean: -5.1960e-05
# Std:  4.3056e-03
# Max:  1.7557e-02
# Min:  -1.8370e-02
# Average psi change: 9.1316e-05
# Epoch 110, Loss: 239.5342, Gradients - Lambda: 4.577e-02, Phi: 7.888e-01, Gamma: 1.251e-02, Psi: 1.837e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 111
# Loss: 239.4487
# Psi gradient stats:
# Mean: -5.1896e-05
# Std:  4.3037e-03
# Max:  1.7559e-02
# Min:  -1.8367e-02
# Average psi change: 9.1297e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 112
# Loss: 239.3609
# Psi gradient stats:
# Mean: -5.2053e-05
# Std:  4.3019e-03
# Max:  1.7571e-02
# Min:  -1.8371e-02
# Average psi change: 9.1276e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 113
# Loss: 239.2784
# Psi gradient stats:
# Mean: -5.2277e-05
# Std:  4.3003e-03
# Max:  1.7581e-02
# Min:  -1.8372e-02
# Average psi change: 9.1255e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 114
# Loss: 239.1979
# Psi gradient stats:
# Mean: -5.2354e-05
# Std:  4.2987e-03
# Max:  1.7575e-02
# Min:  -1.8365e-02
# Average psi change: 9.1234e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 115
# Loss: 239.1125
# Psi gradient stats:
# Mean: -5.2181e-05
# Std:  4.2970e-03
# Max:  1.7559e-02
# Min:  -1.8350e-02
# Average psi change: 9.1209e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 116
# Loss: 239.0342
# Psi gradient stats:
# Mean: -5.1921e-05
# Std:  4.2951e-03
# Max:  1.7549e-02
# Min:  -1.8336e-02
# Average psi change: 9.1187e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 117
# Loss: 238.9586
# Psi gradient stats:
# Mean: -5.1808e-05
# Std:  4.2932e-03
# Max:  1.7555e-02
# Min:  -1.8328e-02
# Average psi change: 9.1167e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 118
# Loss: 238.8757
# Psi gradient stats:
# Mean: -5.1961e-05
# Std:  4.2915e-03
# Max:  1.7573e-02
# Min:  -1.8330e-02
# Average psi change: 9.1145e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 119
# Loss: 238.7993
# Psi gradient stats:
# Mean: -5.2220e-05
# Std:  4.2899e-03
# Max:  1.7584e-02
# Min:  -1.8334e-02
# Average psi change: 9.1120e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 120
# Loss: 238.7283
# Psi gradient stats:
# Mean: -5.2341e-05
# Std:  4.2883e-03
# Max:  1.7574e-02
# Min:  -1.8333e-02
# Average psi change: 9.1100e-05
# Epoch 120, Loss: 238.7283, Gradients - Lambda: 4.889e-02, Phi: 7.679e-01, Gamma: 1.003e-02, Psi: 1.833e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 121
# Loss: 238.6502
# Psi gradient stats:
# Mean: -5.2196e-05
# Std:  4.2866e-03
# Max:  1.7552e-02
# Min:  -1.8322e-02
# Average psi change: 9.1078e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 122
# Loss: 238.5750
# Psi gradient stats:
# Mean: -5.1916e-05
# Std:  4.2846e-03
# Max:  1.7540e-02
# Min:  -1.8306e-02
# Average psi change: 9.1057e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 123
# Loss: 238.5057
# Psi gradient stats:
# Mean: -5.1745e-05
# Std:  4.2827e-03
# Max:  1.7551e-02
# Min:  -1.8294e-02
# Average psi change: 9.1033e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 124
# Loss: 238.4293
# Psi gradient stats:
# Mean: -5.1833e-05
# Std:  4.2810e-03
# Max:  1.7576e-02
# Min:  -1.8291e-02
# Average psi change: 9.1008e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 125
# Loss: 238.3571
# Psi gradient stats:
# Mean: -5.2084e-05
# Std:  4.2795e-03
# Max:  1.7587e-02
# Min:  -1.8297e-02
# Average psi change: 9.0982e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 126
# Loss: 238.2881
# Psi gradient stats:
# Mean: -5.2252e-05
# Std:  4.2780e-03
# Max:  1.7572e-02
# Min:  -1.8300e-02
# Average psi change: 9.0958e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 127
# Loss: 238.2182
# Psi gradient stats:
# Mean: -5.2186e-05
# Std:  4.2762e-03
# Max:  1.7543e-02
# Min:  -1.8295e-02
# Average psi change: 9.0937e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 128
# Loss: 238.1466
# Psi gradient stats:
# Mean: -5.1949e-05
# Std:  4.2742e-03
# Max:  1.7529e-02
# Min:  -1.8280e-02
# Average psi change: 9.0918e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 129
# Loss: 238.0790
# Psi gradient stats:
# Mean: -5.1745e-05
# Std:  4.2723e-03
# Max:  1.7543e-02
# Min:  -1.8265e-02
# Average psi change: 9.0894e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 130
# Loss: 238.0088
# Psi gradient stats:
# Mean: -5.1738e-05
# Std:  4.2706e-03
# Max:  1.7572e-02
# Min:  -1.8257e-02
# Average psi change: 9.0864e-05
# Epoch 130, Loss: 238.0088, Gradients - Lambda: 5.150e-02, Phi: 7.456e-01, Gamma: 7.889e-03, Psi: 1.826e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 131
# Loss: 237.9409
# Psi gradient stats:
# Mean: -5.1921e-05
# Std:  4.2691e-03
# Max:  1.7588e-02
# Min:  -1.8257e-02
# Average psi change: 9.0832e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 132
# Loss: 237.8727
# Psi gradient stats:
# Mean: -5.2112e-05
# Std:  4.2676e-03
# Max:  1.7573e-02
# Min:  -1.8264e-02
# Average psi change: 9.0807e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 133
# Loss: 237.8050
# Psi gradient stats:
# Mean: -5.2161e-05
# Std:  4.2659e-03
# Max:  1.7538e-02
# Min:  -1.8264e-02
# Average psi change: 9.0788e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 134
# Loss: 237.7384
# Psi gradient stats:
# Mean: -5.2033e-05
# Std:  4.2639e-03
# Max:  1.7519e-02
# Min:  -1.8257e-02
# Average psi change: 9.0771e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 135
# Loss: 237.6738
# Psi gradient stats:
# Mean: -5.1831e-05
# Std:  4.2620e-03
# Max:  1.7533e-02
# Min:  -1.8242e-02
# Average psi change: 9.0753e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 136
# Loss: 237.6045
# Psi gradient stats:
# Mean: -5.1721e-05
# Std:  4.2603e-03
# Max:  1.7568e-02
# Min:  -1.8228e-02
# Average psi change: 9.0726e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 137
# Loss: 237.5385
# Psi gradient stats:
# Mean: -5.1776e-05
# Std:  4.2587e-03
# Max:  1.7590e-02
# Min:  -1.8220e-02
# Average psi change: 9.0694e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 138
# Loss: 237.4742
# Psi gradient stats:
# Mean: -5.1939e-05
# Std:  4.2572e-03
# Max:  1.7578e-02
# Min:  -1.8220e-02
# Average psi change: 9.0664e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 139
# Loss: 237.4059
# Psi gradient stats:
# Mean: -5.2054e-05
# Std:  4.2556e-03
# Max:  1.7539e-02
# Min:  -1.8224e-02
# Average psi change: 9.0641e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 140
# Loss: 237.3393
# Psi gradient stats:
# Mean: -5.2045e-05
# Std:  4.2537e-03
# Max:  1.7510e-02
# Min:  -1.8226e-02
# Average psi change: 9.0623e-05
# Epoch 140, Loss: 237.3393, Gradients - Lambda: 5.175e-02, Phi: 9.369e-01, Gamma: 7.880e-03, Psi: 1.823e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 141
# Loss: 237.2763
# Psi gradient stats:
# Mean: -5.1893e-05
# Std:  4.2518e-03
# Max:  1.7517e-02
# Min:  -1.8220e-02
# Average psi change: 9.0608e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 142
# Loss: 237.2105
# Psi gradient stats:
# Mean: -5.1724e-05
# Std:  4.2500e-03
# Max:  1.7555e-02
# Min:  -1.8208e-02
# Average psi change: 9.0585e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 143
# Loss: 237.1431
# Psi gradient stats:
# Mean: -5.1659e-05
# Std:  4.2483e-03
# Max:  1.7590e-02
# Min:  -1.8194e-02
# Average psi change: 9.0556e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 144
# Loss: 237.0754
# Psi gradient stats:
# Mean: -5.1749e-05
# Std:  4.2468e-03
# Max:  1.7587e-02
# Min:  -1.8184e-02
# Average psi change: 9.0523e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 145
# Loss: 237.0146
# Psi gradient stats:
# Mean: -5.1928e-05
# Std:  4.2452e-03
# Max:  1.7549e-02
# Min:  -1.8180e-02
# Average psi change: 9.0497e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 146
# Loss: 236.9488
# Psi gradient stats:
# Mean: -5.2032e-05
# Std:  4.2435e-03
# Max:  1.7507e-02
# Min:  -1.8181e-02
# Average psi change: 9.0482e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 147
# Loss: 236.8780
# Psi gradient stats:
# Mean: -5.1981e-05
# Std:  4.2417e-03
# Max:  1.7500e-02
# Min:  -1.8182e-02
# Average psi change: 9.0470e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 148
# Loss: 236.8148
# Psi gradient stats:
# Mean: -5.1791e-05
# Std:  4.2398e-03
# Max:  1.7534e-02
# Min:  -1.8179e-02
# Average psi change: 9.0451e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 149
# Loss: 236.7536
# Psi gradient stats:
# Mean: -5.1620e-05
# Std:  4.2380e-03
# Max:  1.7580e-02
# Min:  -1.8171e-02
# Average psi change: 9.0421e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 150
# Loss: 236.6819
# Psi gradient stats:
# Mean: -5.1607e-05
# Std:  4.2364e-03
# Max:  1.7595e-02
# Min:  -1.8159e-02
# Average psi change: 9.0388e-05
# Epoch 150, Loss: 236.6819, Gradients - Lambda: 5.345e-02, Phi: 8.210e-01, Gamma: 7.697e-03, Psi: 1.816e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 151
# Loss: 236.6161
# Psi gradient stats:
# Mean: -5.1764e-05
# Std:  4.2350e-03
# Max:  1.7565e-02
# Min:  -1.8148e-02
# Average psi change: 9.0364e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 152
# Loss: 236.5549
# Psi gradient stats:
# Mean: -5.1950e-05
# Std:  4.2334e-03
# Max:  1.7515e-02
# Min:  -1.8141e-02
# Average psi change: 9.0349e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 153
# Loss: 236.4856
# Psi gradient stats:
# Mean: -5.1978e-05
# Std:  4.2317e-03
# Max:  1.7490e-02
# Min:  -1.8139e-02
# Average psi change: 9.0341e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 154
# Loss: 236.4161
# Psi gradient stats:
# Mean: -5.1823e-05
# Std:  4.2297e-03
# Max:  1.7511e-02
# Min:  -1.8138e-02
# Average psi change: 9.0324e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 155
# Loss: 236.3545
# Psi gradient stats:
# Mean: -5.1605e-05
# Std:  4.2278e-03
# Max:  1.7560e-02
# Min:  -1.8135e-02
# Average psi change: 9.0294e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 156
# Loss: 236.2892
# Psi gradient stats:
# Mean: -5.1519e-05
# Std:  4.2261e-03
# Max:  1.7594e-02
# Min:  -1.8130e-02
# Average psi change: 9.0261e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 157
# Loss: 236.2196
# Psi gradient stats:
# Mean: -5.1653e-05
# Std:  4.2247e-03
# Max:  1.7582e-02
# Min:  -1.8121e-02
# Average psi change: 9.0231e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 158
# Loss: 236.1530
# Psi gradient stats:
# Mean: -5.1877e-05
# Std:  4.2232e-03
# Max:  1.7534e-02
# Min:  -1.8112e-02
# Average psi change: 9.0215e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 159
# Loss: 236.0880
# Psi gradient stats:
# Mean: -5.2010e-05
# Std:  4.2216e-03
# Max:  1.7493e-02
# Min:  -1.8104e-02
# Average psi change: 9.0208e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 160
# Loss: 236.0206
# Psi gradient stats:
# Mean: -5.1888e-05
# Std:  4.2197e-03
# Max:  1.7493e-02
# Min:  -1.8098e-02
# Average psi change: 9.0193e-05
# Epoch 160, Loss: 236.0206, Gradients - Lambda: 5.300e-02, Phi: 8.061e-01, Gamma: 7.932e-03, Psi: 1.810e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 161
# Loss: 235.9513
# Psi gradient stats:
# Mean: -5.1609e-05
# Std:  4.2177e-03
# Max:  1.7534e-02
# Min:  -1.8096e-02
# Average psi change: 9.0165e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 162
# Loss: 235.8840
# Psi gradient stats:
# Mean: -5.1403e-05
# Std:  4.2160e-03
# Max:  1.7578e-02
# Min:  -1.8096e-02
# Average psi change: 9.0125e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 163
# Loss: 235.8199
# Psi gradient stats:
# Mean: -5.1474e-05
# Std:  4.2145e-03
# Max:  1.7587e-02
# Min:  -1.8092e-02
# Average psi change: 9.0095e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 164
# Loss: 235.7490
# Psi gradient stats:
# Mean: -5.1760e-05
# Std:  4.2131e-03
# Max:  1.7551e-02
# Min:  -1.8085e-02
# Average psi change: 9.0075e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 165
# Loss: 235.6791
# Psi gradient stats:
# Mean: -5.2021e-05
# Std:  4.2115e-03
# Max:  1.7504e-02
# Min:  -1.8074e-02
# Average psi change: 9.0073e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 166
# Loss: 235.6148
# Psi gradient stats:
# Mean: -5.1987e-05
# Std:  4.2097e-03
# Max:  1.7487e-02
# Min:  -1.8064e-02
# Average psi change: 9.0064e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 167
# Loss: 235.5484
# Psi gradient stats:
# Mean: -5.1675e-05
# Std:  4.2078e-03
# Max:  1.7513e-02
# Min:  -1.8057e-02
# Average psi change: 9.0042e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 168
# Loss: 235.4759
# Psi gradient stats:
# Mean: -5.1316e-05
# Std:  4.2060e-03
# Max:  1.7560e-02
# Min:  -1.8057e-02
# Average psi change: 9.0001e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 169
# Loss: 235.4069
# Psi gradient stats:
# Mean: -5.1251e-05
# Std:  4.2044e-03
# Max:  1.7584e-02
# Min:  -1.8059e-02
# Average psi change: 8.9958e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 170
# Loss: 235.3444
# Psi gradient stats:
# Mean: -5.1538e-05
# Std:  4.2030e-03
# Max:  1.7563e-02
# Min:  -1.8056e-02
# Average psi change: 8.9935e-05
# Epoch 170, Loss: 235.3444, Gradients - Lambda: 5.416e-02, Phi: 8.580e-01, Gamma: 7.761e-03, Psi: 1.806e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 171
# Loss: 235.2736
# Psi gradient stats:
# Mean: -5.1957e-05
# Std:  4.2015e-03
# Max:  1.7518e-02
# Min:  -1.8047e-02
# Average psi change: 8.9930e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 172
# Loss: 235.2004
# Psi gradient stats:
# Mean: -5.2125e-05
# Std:  4.1998e-03
# Max:  1.7486e-02
# Min:  -1.8032e-02
# Average psi change: 8.9930e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 173
# Loss: 235.1352
# Psi gradient stats:
# Mean: -5.1858e-05
# Std:  4.1978e-03
# Max:  1.7497e-02
# Min:  -1.8021e-02
# Average psi change: 8.9915e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 174
# Loss: 235.0684
# Psi gradient stats:
# Mean: -5.1365e-05
# Std:  4.1960e-03
# Max:  1.7540e-02
# Min:  -1.8016e-02
# Average psi change: 8.9879e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 175
# Loss: 234.9952
# Psi gradient stats:
# Mean: -5.1067e-05
# Std:  4.1944e-03
# Max:  1.7575e-02
# Min:  -1.8019e-02
# Average psi change: 8.9838e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 176
# Loss: 234.9246
# Psi gradient stats:
# Mean: -5.1224e-05
# Std:  4.1930e-03
# Max:  1.7572e-02
# Min:  -1.8023e-02
# Average psi change: 8.9803e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 177
# Loss: 234.8607
# Psi gradient stats:
# Mean: -5.1717e-05
# Std:  4.1916e-03
# Max:  1.7531e-02
# Min:  -1.8018e-02
# Average psi change: 8.9786e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 178
# Loss: 234.7914
# Psi gradient stats:
# Mean: -5.2111e-05
# Std:  4.1899e-03
# Max:  1.7489e-02
# Min:  -1.8004e-02
# Average psi change: 8.9782e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 179
# Loss: 234.7166
# Psi gradient stats:
# Mean: -5.2056e-05
# Std:  4.1880e-03
# Max:  1.7481e-02
# Min:  -1.7987e-02
# Average psi change: 8.9777e-05
# ...
# Psi gradient stats:
# Mean: -5.0534e-05
# Std:  3.8161e-03
# Max:  1.7373e-02
# Min:  -1.6649e-02
# Average psi change: 8.3681e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 448
# Loss: 223.5329
# Psi gradient stats:
# Mean: -4.9953e-05
# Std:  3.8146e-03
# Max:  1.7409e-02
# Min:  -1.6655e-02
# Average psi change: 8.3659e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 449
# Loss: 223.4907
# Psi gradient stats:
# Mean: -4.9499e-05
# Std:  3.8133e-03
# Max:  1.7412e-02
# Min:  -1.6628e-02
# Average psi change: 8.3632e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 450
# Loss: 223.4408
# Psi gradient stats:
# Mean: -4.9543e-05
# Std:  3.8122e-03
# Max:  1.7378e-02
# Min:  -1.6585e-02
# Average psi change: 8.3603e-05
# Epoch 450, Loss: 223.4408, Gradients - Lambda: 6.822e-02, Phi: 9.246e-01, Gamma: 7.916e-03, Psi: 1.738e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 451
# Loss: 223.4297
# Psi gradient stats:
# Mean: -5.0065e-05
# Std:  3.8113e-03
# Max:  1.7335e-02
# Min:  -1.6559e-02
# Average psi change: 8.3575e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 452
# Loss: 223.4017
# Psi gradient stats:
# Mean: -5.0627e-05
# Std:  3.8105e-03
# Max:  1.7319e-02
# Min:  -1.6568e-02
# Average psi change: 8.3553e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 453
# Loss: 223.3460
# Psi gradient stats:
# Mean: -5.0750e-05
# Std:  3.8093e-03
# Max:  1.7343e-02
# Min:  -1.6602e-02
# Average psi change: 8.3532e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 454
# Loss: 223.3255
# Psi gradient stats:
# Mean: -5.0340e-05
# Std:  3.8079e-03
# Max:  1.7388e-02
# Min:  -1.6631e-02
# Average psi change: 8.3515e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 455
# Loss: 223.3097
# Psi gradient stats:
# Mean: -4.9719e-05
# Std:  3.8063e-03
# Max:  1.7413e-02
# Min:  -1.6626e-02
# Average psi change: 8.3488e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 456
# Loss: 223.2551
# Psi gradient stats:
# Mean: -4.9407e-05
# Std:  3.8050e-03
# Max:  1.7397e-02
# Min:  -1.6587e-02
# Average psi change: 8.3456e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 457
# Loss: 223.2228
# Psi gradient stats:
# Mean: -4.9671e-05
# Std:  3.8041e-03
# Max:  1.7352e-02
# Min:  -1.6544e-02
# Average psi change: 8.3430e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 458
# Loss: 223.2130
# Psi gradient stats:
# Mean: -5.0270e-05
# Std:  3.8035e-03
# Max:  1.7315e-02
# Min:  -1.6527e-02
# Average psi change: 8.3404e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 459
# Loss: 223.1679
# Psi gradient stats:
# Mean: -5.0722e-05
# Std:  3.8026e-03
# Max:  1.7318e-02
# Min:  -1.6547e-02
# Average psi change: 8.3387e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 460
# Loss: 223.1230
# Psi gradient stats:
# Mean: -5.0632e-05
# Std:  3.8013e-03
# Max:  1.7356e-02
# Min:  -1.6584e-02
# Average psi change: 8.3369e-05
# Epoch 460, Loss: 223.1230, Gradients - Lambda: 5.787e-02, Phi: 9.302e-01, Gamma: 7.660e-03, Psi: 1.736e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 461
# Loss: 223.1118
# Psi gradient stats:
# Mean: -5.0078e-05
# Std:  3.7997e-03
# Max:  1.7399e-02
# Min:  -1.6604e-02
# Average psi change: 8.3348e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 462
# Loss: 223.0802
# Psi gradient stats:
# Mean: -4.9520e-05
# Std:  3.7981e-03
# Max:  1.7409e-02
# Min:  -1.6588e-02
# Average psi change: 8.3314e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 463
# Loss: 223.0280
# Psi gradient stats:
# Mean: -4.9407e-05
# Std:  3.7970e-03
# Max:  1.7375e-02
# Min:  -1.6544e-02
# Average psi change: 8.3283e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 464
# Loss: 223.0079
# Psi gradient stats:
# Mean: -4.9827e-05
# Std:  3.7963e-03
# Max:  1.7327e-02
# Min:  -1.6506e-02
# Average psi change: 8.3256e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 465
# Loss: 222.9892
# Psi gradient stats:
# Mean: -5.0434e-05
# Std:  3.7958e-03
# Max:  1.7304e-02
# Min:  -1.6502e-02
# Average psi change: 8.3237e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 466
# Loss: 222.9379
# Psi gradient stats:
# Mean: -5.0715e-05
# Std:  3.7948e-03
# Max:  1.7325e-02
# Min:  -1.6531e-02
# Average psi change: 8.3224e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 467
# Loss: 222.9060
# Psi gradient stats:
# Mean: -5.0449e-05
# Std:  3.7933e-03
# Max:  1.7373e-02
# Min:  -1.6564e-02
# Average psi change: 8.3207e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 468
# Loss: 222.8925
# Psi gradient stats:
# Mean: -4.9848e-05
# Std:  3.7915e-03
# Max:  1.7406e-02
# Min:  -1.6572e-02
# Average psi change: 8.3178e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 469
# Loss: 222.8515
# Psi gradient stats:
# Mean: -4.9415e-05
# Std:  3.7900e-03
# Max:  1.7397e-02
# Min:  -1.6547e-02
# Average psi change: 8.3140e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 470
# Loss: 222.8094
# Psi gradient stats:
# Mean: -4.9504e-05
# Std:  3.7891e-03
# Max:  1.7351e-02
# Min:  -1.6505e-02
# Average psi change: 8.3111e-05
# Epoch 470, Loss: 222.8094, Gradients - Lambda: 5.702e-02, Phi: 9.245e-01, Gamma: 7.608e-03, Psi: 1.735e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 471
# Loss: 222.7917
# Psi gradient stats:
# Mean: -5.0016e-05
# Std:  3.7886e-03
# Max:  1.7307e-02
# Min:  -1.6476e-02
# Average psi change: 8.3088e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 472
# Loss: 222.7620
# Psi gradient stats:
# Mean: -5.0524e-05
# Std:  3.7880e-03
# Max:  1.7301e-02
# Min:  -1.6481e-02
# Average psi change: 8.3072e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 473
# Loss: 222.7168
# Psi gradient stats:
# Mean: -5.0607e-05
# Std:  3.7869e-03
# Max:  1.7336e-02
# Min:  -1.6510e-02
# Average psi change: 8.3060e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 474
# Loss: 222.6929
# Psi gradient stats:
# Mean: -5.0195e-05
# Std:  3.7853e-03
# Max:  1.7385e-02
# Min:  -1.6536e-02
# Average psi change: 8.3041e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 475
# Loss: 222.6683
# Psi gradient stats:
# Mean: -4.9650e-05
# Std:  3.7835e-03
# Max:  1.7406e-02
# Min:  -1.6534e-02
# Average psi change: 8.3003e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 476
# Loss: 222.6293
# Psi gradient stats:
# Mean: -4.9410e-05
# Std:  3.7821e-03
# Max:  1.7380e-02
# Min:  -1.6505e-02
# Average psi change: 8.2967e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 477
# Loss: 222.5953
# Psi gradient stats:
# Mean: -4.9658e-05
# Std:  3.7813e-03
# Max:  1.7328e-02
# Min:  -1.6469e-02
# Average psi change: 8.2938e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 478
# Loss: 222.5739
# Psi gradient stats:
# Mean: -5.0168e-05
# Std:  3.7809e-03
# Max:  1.7294e-02
# Min:  -1.6452e-02
# Average psi change: 8.2920e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 479
# Loss: 222.5398
# Psi gradient stats:
# Mean: -5.0513e-05
# Std:  3.7802e-03
# Max:  1.7303e-02
# Min:  -1.6464e-02
# Average psi change: 8.2910e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 480
# Loss: 222.5024
# Psi gradient stats:
# Mean: -5.0416e-05
# Std:  3.7790e-03
# Max:  1.7348e-02
# Min:  -1.6490e-02
# Average psi change: 8.2893e-05
# Epoch 480, Loss: 222.5024, Gradients - Lambda: 6.384e-02, Phi: 1.112e+00, Gamma: 7.889e-03, Psi: 1.735e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 481
# Loss: 222.4773
# Psi gradient stats:
# Mean: -4.9978e-05
# Std:  3.7773e-03
# Max:  1.7389e-02
# Min:  -1.6505e-02
# Average psi change: 8.2869e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 482
# Loss: 222.4501
# Psi gradient stats:
# Mean: -4.9573e-05
# Std:  3.7756e-03
# Max:  1.7393e-02
# Min:  -1.6496e-02
# Average psi change: 8.2828e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 483
# Loss: 222.4118
# Psi gradient stats:
# Mean: -4.9538e-05
# Std:  3.7744e-03
# Max:  1.7355e-02
# Min:  -1.6468e-02
# Average psi change: 8.2793e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 484
# Loss: 222.3843
# Psi gradient stats:
# Mean: -4.9873e-05
# Std:  3.7737e-03
# Max:  1.7307e-02
# Min:  -1.6442e-02
# Average psi change: 8.2764e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 485
# Loss: 222.3560
# Psi gradient stats:
# Mean: -5.0266e-05
# Std:  3.7732e-03
# Max:  1.7289e-02
# Min:  -1.6435e-02
# Average psi change: 8.2753e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 486
# Loss: 222.3235
# Psi gradient stats:
# Mean: -5.0398e-05
# Std:  3.7724e-03
# Max:  1.7313e-02
# Min:  -1.6446e-02
# Average psi change: 8.2744e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 487
# Loss: 222.2911
# Psi gradient stats:
# Mean: -5.0156e-05
# Std:  3.7710e-03
# Max:  1.7359e-02
# Min:  -1.6462e-02
# Average psi change: 8.2725e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 488
# Loss: 222.2651
# Psi gradient stats:
# Mean: -4.9776e-05
# Std:  3.7693e-03
# Max:  1.7388e-02
# Min:  -1.6468e-02
# Average psi change: 8.2692e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 489
# Loss: 222.2349
# Psi gradient stats:
# Mean: -4.9573e-05
# Std:  3.7678e-03
# Max:  1.7375e-02
# Min:  -1.6457e-02
# Average psi change: 8.2650e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 490
# Loss: 222.1998
# Psi gradient stats:
# Mean: -4.9709e-05
# Std:  3.7668e-03
# Max:  1.7330e-02
# Min:  -1.6438e-02
# Average psi change: 8.2616e-05
# Epoch 490, Loss: 222.1998, Gradients - Lambda: 6.415e-02, Phi: 9.767e-01, Gamma: 7.516e-03, Psi: 1.733e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 491
# Loss: 222.1735
# Psi gradient stats:
# Mean: -5.0038e-05
# Std:  3.7661e-03
# Max:  1.7293e-02
# Min:  -1.6422e-02
# Average psi change: 8.2593e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 492
# Loss: 222.1481
# Psi gradient stats:
# Mean: -5.0265e-05
# Std:  3.7655e-03
# Max:  1.7291e-02
# Min:  -1.6419e-02
# Average psi change: 8.2586e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 493
# Loss: 222.1109
# Psi gradient stats:
# Mean: -5.0194e-05
# Std:  3.7645e-03
# Max:  1.7326e-02
# Min:  -1.6424e-02
# Average psi change: 8.2578e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 494
# Loss: 222.0812
# Psi gradient stats:
# Mean: -4.9913e-05
# Std:  3.7631e-03
# Max:  1.7366e-02
# Min:  -1.6428e-02
# Average psi change: 8.2555e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 495
# Loss: 222.0602
# Psi gradient stats:
# Mean: -4.9659e-05
# Std:  3.7615e-03
# Max:  1.7377e-02
# Min:  -1.6426e-02
# Average psi change: 8.2515e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 496
# Loss: 222.0227
# Psi gradient stats:
# Mean: -4.9659e-05
# Std:  3.7602e-03
# Max:  1.7350e-02
# Min:  -1.6418e-02
# Average psi change: 8.2475e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 497
# Loss: 221.9880
# Psi gradient stats:
# Mean: -4.9893e-05
# Std:  3.7592e-03
# Max:  1.7306e-02
# Min:  -1.6410e-02
# Average psi change: 8.2442e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 498
# Loss: 221.9728
# Psi gradient stats:
# Mean: -5.0133e-05
# Std:  3.7586e-03
# Max:  1.7283e-02
# Min:  -1.6404e-02
# Average psi change: 8.2427e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 499
# Loss: 221.9390
# Psi gradient stats:
# Mean: -5.0163e-05
# Std:  3.7578e-03
# Max:  1.7298e-02
# Min:  -1.6399e-02
# Average psi change: 8.2425e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 500
# Loss: 221.8963
# Psi gradient stats:
# Mean: -4.9970e-05
# Std:  3.7567e-03
# Max:  1.7338e-02
# Min:  -1.6395e-02
# Average psi change: 8.2411e-05
# Epoch 500, Loss: 221.8963, Gradients - Lambda: 6.385e-02, Phi: 9.056e-01, Gamma: 7.799e-03, Psi: 1.734e-02
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 501
# Loss: 221.8818
# Psi gradient stats:
# Mean: -4.9745e-05
# Std:  3.7552e-03
# Max:  1.7368e-02
# Min:  -1.6391e-02
# Average psi change: 8.2381e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 502
# Loss: 221.8591
# Psi gradient stats:
# Mean: -4.9681e-05
# Std:  3.7538e-03
# Max:  1.7363e-02
# Min:  -1.6388e-02
# Average psi change: 8.2337e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 503
# Loss: 221.8098
# Psi gradient stats:
# Mean: -4.9834e-05
# Std:  3.7526e-03
# Max:  1.7326e-02
# Min:  -1.6389e-02
# Average psi change: 8.2300e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 504
# Loss: 221.7856
# Psi gradient stats:
# Mean: -5.0059e-05
# Std:  3.7518e-03
# Max:  1.7287e-02
# Min:  -1.6390e-02
# Average psi change: 8.2271e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 505
# Loss: 221.7774
# Psi gradient stats:
# Mean: -5.0133e-05
# Std:  3.7511e-03
# Max:  1.7279e-02
# Min:  -1.6386e-02
# Average psi change: 8.2266e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 506
# Loss: 221.7296
# Psi gradient stats:
# Mean: -4.9995e-05
# Std:  3.7501e-03
# Max:  1.7307e-02
# Min:  -1.6376e-02
# Average psi change: 8.2261e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 507
# Loss: 221.6917
# Psi gradient stats:
# Mean: -4.9769e-05
# Std:  3.7489e-03
# Max:  1.7348e-02
# Min:  -1.6361e-02
# Average psi change: 8.2245e-05
# mask_before_event shape: torch.Size([9661, 348, 51])
# mask_at_event shape: torch.Size([9661, 348, 51])
#
# Epoch 508
# Loss: 221.6915
# Psi gradient stats:
# Mean: -4.9659e-05
# Std:  3.7475e-03
# Max:  1.7368e-02
# Min:  -1.6353e-02
# Average psi change: 8.2206e-05
#
# Converged at epoch 508. Loss change: 0.0002

# %%
import torch

# Save complete state for R
# Save components as .rds files
save_path = '/Users/sarahurbut/Dropbox (Personal)/aladynoulli/model_complete_for_R_125_1_neg2_logitinit_nobg.pt'

torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'psi': model.psi,
    'Y': Y,
    'prevalence_t':prevalence_t,
    'G': G,
    'E': E,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': N,
        'D': D,
        'T': T,
        'P': P,
        'K': K
    }
}, save_path)

# %%
import numpy as np
import pandas as pd
import rpy2.robjects as robjects
from rpy2.robjects import numpy2ri
numpy2ri.activate()

# Extract key components from model
with torch.no_grad():
    pi_pred, theta, phi = model.forward()
    
# Convert tensors to numpy arrays - check type first
pi_pred = pi_pred.cpu().detach().numpy()
theta = theta.cpu().detach().numpy()
phi = model.phi.cpu().detach().numpy()
psi = model.psi.cpu().detach().numpy()
lambda_vals = model.lambda_.cpu().detach().numpy()

# These are already numpy arrays
clusters = model.clusters  # Already numpy


save_path = '/Users/sarahurbut/Dropbox (Personal)/aladynoulli/Rdata/1neg2/'
# Main parameters
robjects.r.saveRDS(phi, f"{save_path}phi.rds")
robjects.r.saveRDS(psi, f"{save_path}psi.rds")
robjects.r.saveRDS(lambda_vals, f"{save_path}lambda.rds")
robjects.r.saveRDS(theta, f"{save_path}theta.rds")
robjects.r.saveRDS(pi_pred, f"{save_path}pi_pred.rds")
robjects.r.saveRDS(clusters, f"{save_path}clusters.rds")
# Out:
# R[write to console]: Error in gzfile(file, mode) : cannot open the connection
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In gzfile(file, mode) :
# R[write to console]:
#
# R[write to console]:  cannot open compressed file '/Users/sarahurbut/Dropbox (Personal)/aladynoulli/Rdata/1neg2/phi.rds', probable reason 'No such file or directory'
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[27], line 24
#      22 save_path = '/Users/sarahurbut/Dropbox (Personal)/aladynoulli/Rdata/1neg2/'
#      23 # Main parameters
# ---> 24 robjects.r.saveRDS(phi, f"{save_path}phi.rds")
#      25 robjects.r.saveRDS(psi, f"{save_path}psi.rds")
#      26 robjects.r.saveRDS(lambda_vals, f"{save_path}lambda.rds")
#
# File /opt/miniconda3/envs/pyro_env/lib/python3.9/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     206         v = kwargs.pop(k)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File /opt/miniconda3/envs/pyro_env/lib/python3.9/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     129     else:
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#     133 return res
#
# File /opt/miniconda3/envs/pyro_env/lib/python3.9/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File /opt/miniconda3/envs/pyro_env/lib/python3.9/site-packages/rpy2/rinterface.py:869, in SexpClosure.__call__(self, *args, **kwargs)
#     862     res = rmemory.protect(
#     863         openrlib.rlib.R_tryEval(
#     864             call_r,
#     865             call_context.__sexp__._cdata,
#     866             error_occured)
#     867     )
#     868     if error_occured[0]:
# --> 869         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     870 return res
#
# RRuntimeError: Error in gzfile(file, mode) : cannot open the connection

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history['max_grad_lambda'], label='Lambda')
ax2.plot(history['max_grad_phi'], label='Phi')
ax2.plot(history['max_grad_gamma'], label='Gamma')
ax2.plot(history['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, disease_names_list)
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Prolapse of vaginal walls: effect=2.679 (OR=14.57), std=0.439
# Hypertrophy of female genital organs: effect=2.345 (OR=10.44), std=0.451
# Irregular menstrual bleeding: effect=2.288 (OR=9.85), std=0.733
# Uterine leiomyoma: effect=1.974 (OR=7.20), std=0.688
# Endometriosis: effect=1.941 (OR=6.97), std=0.498
# Irregular menstrual cycle: effect=1.858 (OR=6.41), std=0.422
# Excessive or frequent menstruation: effect=1.790 (OR=5.99), std=1.145
# Disorders of uterus, NEC: effect=1.656 (OR=5.24), std=0.413
# Disorders of menstruation and other abnormal bleeding from female genital tract: effect=1.582 (OR=4.86), std=1.353
# Noninflammatory disorders of cervix: effect=1.489 (OR=4.43), std=0.687
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Synovitis and tenosynovitis: effect=2.560 (OR=12.94), std=0.256
# Other inflammatory spondylopathies: effect=2.549 (OR=12.79), std=0.628
# Obesity: effect=2.448 (OR=11.57), std=0.895
# Malunion and nonunion of fracture: effect=2.383 (OR=10.83), std=0.793
# Hammer toe (acquired): effect=2.351 (OR=10.50), std=0.558
# Major depressive disorder: effect=2.318 (OR=10.15), std=0.675
# Other disorders of synovium, tendon, and bursa: effect=2.130 (OR=8.41), std=0.872
# Osteoarthrosis NOS: effect=1.985 (OR=7.28), std=1.215
# Spondylosis and allied disorders: effect=1.890 (OR=6.62), std=0.566
# Hallux valgus (Bunion): effect=1.782 (OR=5.94), std=0.501
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Other and unspecified disc disorder: effect=2.147 (OR=8.56), std=0.193
# Displacement of intervertebral disc: effect=1.200 (OR=3.32), std=0.742
# Spondylosis without myelopathy: effect=1.041 (OR=2.83), std=0.614
# Acquired spondylolisthesis: effect=1.031 (OR=2.81), std=0.326
# Kyphoscoliosis and scoliosis: effect=1.013 (OR=2.75), std=0.700
# Degenerative disease of the spinal cord: effect=0.767 (OR=2.15), std=0.580
# Sciatica: effect=0.730 (OR=2.08), std=0.708
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=0.500 (OR=1.65), std=0.628
# Degeneration of intervertebral disc: effect=0.491 (OR=1.63), std=0.616
# Ganglion and cyst of synovium, tendon, and bursa: effect=0.398 (OR=1.49), std=0.489
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Cholecystitis without cholelithiasis: effect=2.423 (OR=11.28), std=0.737
# Cholelithiasis with acute cholecystitis: effect=0.977 (OR=2.66), std=0.488
# Cholelithiasis: effect=0.685 (OR=1.98), std=1.013
# Other disorders of biliary tract: effect=0.441 (OR=1.55), std=0.189
# Cholelithiasis with other cholecystitis: effect=0.323 (OR=1.38), std=0.130
# Calculus of bile duct: effect=0.284 (OR=1.33), std=0.415
# Other disorders of gallbladder: effect=0.091 (OR=1.10), std=1.108
# Peritoneal adhesions (postoperative) (postinfection): effect=0.037 (OR=1.04), std=0.285
# Dyspareunia: effect=-0.042 (OR=0.96), std=0.308
# Acute pancreatitis: effect=-0.118 (OR=0.89), std=0.355
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Mitral valve disease: effect=2.782 (OR=16.16), std=0.572
# Paroxysmal supraventricular tachycardia: effect=2.402 (OR=11.05), std=0.746
# Left bundle branch block: effect=2.352 (OR=10.51), std=0.248
# Cardiac arrest: effect=2.198 (OR=9.01), std=0.842
# Right bundle branch block: effect=2.127 (OR=8.39), std=0.312
# Disease of tricuspid valve: effect=1.772 (OR=5.89), std=0.409
# Primary/intrinsic cardiomyopathies: effect=1.740 (OR=5.70), std=1.000
# Paroxysmal ventricular tachycardia: effect=1.637 (OR=5.14), std=1.086
# Pleurisy; pleural effusion: effect=1.504 (OR=4.50), std=0.155
# Pericarditis: effect=1.146 (OR=3.15), std=0.332
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Other diseases of the teeth and supporting structures: effect=2.980 (OR=19.68), std=0.500
# Diseases and other conditions of the tongue: effect=2.961 (OR=19.32), std=0.654
# Hearing loss: effect=2.723 (OR=15.22), std=1.004
# Acute gastritis: effect=2.404 (OR=11.07), std=0.696
# Allergic rhinitis: effect=2.361 (OR=10.60), std=0.213
# Arrhythmia (cardiac) NOS: effect=2.352 (OR=10.51), std=0.660
# Other benign neoplasm of connective and other soft tissue: effect=2.108 (OR=8.23), std=0.737
# Hemangioma and lymphangioma, any site: effect=1.987 (OR=7.30), std=0.590
# Polymyalgia Rheumatica: effect=1.966 (OR=7.14), std=0.700
# Benign neoplasm of breast: effect=1.943 (OR=6.98), std=0.699
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Gout: effect=3.622 (OR=37.40), std=0.752
# Peritonitis and retroperitoneal infections: effect=2.895 (OR=18.08), std=0.464
# Other disorders of male genital organs: effect=2.777 (OR=16.07), std=1.059
# Psoriasis vulgaris: effect=2.178 (OR=8.83), std=0.508
# Alcoholic liver damage: effect=2.158 (OR=8.65), std=0.317
# Inguinal hernia: effect=2.072 (OR=7.94), std=0.411
# Bursitis: effect=1.947 (OR=7.01), std=0.706
# Atopic/contact dermatitis due to other or unspecified: effect=1.746 (OR=5.73), std=0.372
# Alcohol-related disorders: effect=1.592 (OR=4.91), std=0.205
# Pulmonary heart disease: effect=1.545 (OR=4.69), std=0.557
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Asthma: effect=2.542 (OR=12.70), std=0.512
# Respiratory failure: effect=2.429 (OR=11.35), std=0.707
# Bronchiectasis: effect=2.161 (OR=8.68), std=0.187
# Chronic airway obstruction: effect=1.623 (OR=5.07), std=1.176
# Pulmonary collapse; interstitial and compensatory emphysema: effect=1.225 (OR=3.41), std=0.374
# Tobacco use disorder: effect=1.187 (OR=3.28), std=0.234
# Empyema and pneumothorax: effect=1.112 (OR=3.04), std=0.375
# Pneumococcal pneumonia: effect=0.640 (OR=1.90), std=0.985
# Obstructive chronic bronchitis: effect=0.477 (OR=1.61), std=0.192
# Bacterial pneumonia: effect=0.280 (OR=1.32), std=0.511
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Myopia: effect=2.487 (OR=12.02), std=0.375
# Cataract: effect=0.952 (OR=2.59), std=0.530
# Retinal detachment with retinal defect: effect=0.919 (OR=2.51), std=0.667
# Senile cataract: effect=0.913 (OR=2.49), std=0.491
# Glaucoma: effect=0.710 (OR=2.03), std=0.261
# Urinary tract infection: effect=0.697 (OR=2.01), std=0.608
# Other retinal disorders: effect=0.671 (OR=1.96), std=0.484
# Retinal detachments and defects: effect=0.670 (OR=1.95), std=0.708
# Macular degeneration (senile) of retina NOS: effect=0.600 (OR=1.82), std=0.915
# Disorders of vitreous body: effect=0.501 (OR=1.65), std=0.978
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Cerebrovascular disease: effect=1.587 (OR=4.89), std=0.751
# Late effects of cerebrovascular disease: effect=1.460 (OR=4.30), std=0.840
# Cerebral ischemia: effect=1.056 (OR=2.87), std=0.438
# Occlusion of cerebral arteries: effect=0.759 (OR=2.14), std=0.505
# Transient cerebral ischemia: effect=0.720 (OR=2.05), std=0.186
# Occlusion and stenosis of precerebral arteries: effect=-0.021 (OR=0.98), std=0.323
# Cerebral artery occlusion, with cerebral infarction: effect=-0.054 (OR=0.95), std=0.625
# Acquired spondylolisthesis: effect=-0.226 (OR=0.80), std=0.190
# Emphysema: effect=-0.232 (OR=0.79), std=0.742
# Malignant neoplasm of kidney, except pelvis: effect=-0.324 (OR=0.72), std=0.793
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Type 1 diabetes: effect=1.174 (OR=3.24), std=0.679
# Diabetic retinopathy: effect=0.482 (OR=1.62), std=0.551
# Hypoglycemia: effect=0.250 (OR=1.28), std=0.320
# Type 2 diabetes: effect=0.147 (OR=1.16), std=0.571
# Ectropion or entropion: effect=-0.122 (OR=0.89), std=0.492
# Parkinson's disease: effect=-0.127 (OR=0.88), std=0.261
# Asthma: effect=-0.331 (OR=0.72), std=0.516
# Coronary atherosclerosis: effect=-0.438 (OR=0.65), std=0.156
# Type 2 diabetes with ophthalmic manifestations: effect=-0.480 (OR=0.62), std=0.324
# Chronic sinusitis: effect=-0.533 (OR=0.59), std=0.671
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Secondary malignant neoplasm of liver: effect=1.390 (OR=4.01), std=0.663
# Cancer of bronchus; lung: effect=1.344 (OR=3.83), std=0.446
# Malignant neoplasm of ovary: effect=0.983 (OR=2.67), std=0.268
# Secondary malignant neoplasm of digestive systems: effect=0.892 (OR=2.44), std=0.441
# Malignant neoplasm, other: effect=0.843 (OR=2.32), std=0.093
# Secondary malignant neoplasm: effect=0.626 (OR=1.87), std=0.624
# Malignant neoplasm of female breast: effect=0.360 (OR=1.43), std=0.659
# Secondary malignancy of bone: effect=0.289 (OR=1.34), std=0.916
# Mucous polyp of cervix: effect=0.107 (OR=1.11), std=0.418
# Cellulitis and abscess of arm/hand: effect=-0.015 (OR=0.99), std=0.468
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Nasal polyps: effect=1.937 (OR=6.94), std=0.406
# Otitis media: effect=1.587 (OR=4.89), std=1.530
# Other upper respiratory disease: effect=1.492 (OR=4.45), std=0.613
# Septal Deviations/Turbinate Hypertrophy: effect=1.453 (OR=4.28), std=0.373
# Chronic sinusitis: effect=1.186 (OR=3.28), std=0.447
# Chronic pharyngitis and nasopharyngitis: effect=1.015 (OR=2.76), std=0.778
# Other tests: effect=-0.032 (OR=0.97), std=0.461
# Dysmenorrhea: effect=-0.214 (OR=0.81), std=0.986
# Pleurisy; pleural effusion: effect=-0.216 (OR=0.81), std=1.050
# Hypovolemia: effect=-0.391 (OR=0.68), std=0.813
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Carbuncle and furuncle: effect=2.135 (OR=8.46), std=0.510
# Decubitus ulcer: effect=1.996 (OR=7.36), std=0.516
# Peripheral vascular disease, unspecified: effect=1.773 (OR=5.89), std=0.733
# Other local infections of skin and subcutaneous tissue: effect=1.526 (OR=4.60), std=0.519
# Chronic ulcer of skin: effect=1.469 (OR=4.34), std=1.114
# Phlebitis and thrombophlebitis of lower extremities: effect=1.289 (OR=3.63), std=0.607
# Cellulitis and abscess of arm/hand: effect=0.778 (OR=2.18), std=0.612
# Streptococcus infection: effect=0.575 (OR=1.78), std=0.062
# Staphylococcus infections: effect=0.366 (OR=1.44), std=0.519
# Joint effusions: effect=0.284 (OR=1.33), std=0.500
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Barrett's esophagus: effect=2.687 (OR=14.69), std=0.655
# Other specified gastritis: effect=1.823 (OR=6.19), std=0.796
# GERD: effect=1.628 (OR=5.09), std=0.666
# Ulcer of esophagus: effect=1.266 (OR=3.55), std=1.026
# Other disorders of stomach and duodenum: effect=1.264 (OR=3.54), std=0.471
# Benign neoplasm of other parts of digestive system: effect=1.192 (OR=3.29), std=0.298
# Reflux esophagitis: effect=1.169 (OR=3.22), std=0.268
# Gastritis and duodenitis: effect=0.881 (OR=2.41), std=0.441
# Stricture and stenosis of esophagus: effect=0.465 (OR=1.59), std=0.244
# Osteoporosis NOS: effect=0.322 (OR=1.38), std=0.470
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Other chronic ischemic heart disease, unspecified: effect=2.698 (OR=14.84), std=0.650
# Coronary atherosclerosis: effect=2.102 (OR=8.19), std=0.282
# Unstable angina (intermediate coronary syndrome): effect=1.921 (OR=6.83), std=0.503
# Other acute and subacute forms of ischemic heart disease: effect=1.826 (OR=6.21), std=0.716
# Hyperlipidemia: effect=1.406 (OR=4.08), std=0.077
# Hypercholesterolemia: effect=1.023 (OR=2.78), std=0.344
# Streptococcus infection: effect=0.794 (OR=2.21), std=1.326
# Essential hypertension: effect=0.692 (OR=2.00), std=0.205
# Myocardial infarction: effect=0.541 (OR=1.72), std=0.667
# Decubitus ulcer: effect=0.137 (OR=1.15), std=0.526
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Acidosis: effect=2.340 (OR=10.38), std=0.451
# Hypopotassemia: effect=1.902 (OR=6.70), std=0.260
# Hypotension NOS: effect=1.781 (OR=5.94), std=0.716
# Acute renal failure: effect=1.608 (OR=4.99), std=0.323
# Other diseases of respiratory system, NEC: effect=1.588 (OR=4.89), std=0.693
# Constipation: effect=1.392 (OR=4.02), std=0.259
# Disorders of calcium/phosphorus metabolism: effect=1.323 (OR=3.75), std=0.329
# Neutropenia: effect=1.303 (OR=3.68), std=0.881
# Orthostatic hypotension: effect=1.300 (OR=3.67), std=0.801
# E. coli: effect=1.263 (OR=3.54), std=0.797
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Calculus of ureter: effect=0.871 (OR=2.39), std=0.486
# Renal colic: effect=0.709 (OR=2.03), std=1.464
# Calculus of kidney: effect=0.418 (OR=1.52), std=1.386
# Barrett's esophagus: effect=0.220 (OR=1.25), std=0.899
# Scar conditions and fibrosis of skin: effect=0.186 (OR=1.20), std=1.283
# Peritoneal adhesions (postoperative) (postinfection): effect=-0.157 (OR=0.85), std=0.672
# Reflux esophagitis: effect=-0.213 (OR=0.81), std=0.326
# Arrhythmia (cardiac) NOS: effect=-0.390 (OR=0.68), std=1.778
# Malignant neoplasm, other: effect=-0.426 (OR=0.65), std=0.119
# Peripheral enthesopathies and allied syndromes: effect=-0.459 (OR=0.63), std=0.450
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Malignant neoplasm of rectum, rectosigmoid junction, and anus: effect=3.234 (OR=25.39), std=0.558
# Noninfectious gastroenteritis: effect=2.173 (OR=8.78), std=0.355
# Other intestinal obstruction: effect=2.013 (OR=7.49), std=0.172
# Ulcerative colitis: effect=1.659 (OR=5.25), std=0.223
# Neoplasm of unspecified nature of digestive system: effect=1.366 (OR=3.92), std=0.601
# Hemorrhage of rectum and anus: effect=1.274 (OR=3.57), std=0.754
# Anal and rectal conditions: effect=1.206 (OR=3.34), std=0.577
# Other disorders of intestine: effect=1.168 (OR=3.22), std=0.384
# Diverticulosis: effect=1.124 (OR=3.08), std=0.162
# Hemorrhoids: effect=1.008 (OR=2.74), std=0.162
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Hyperplasia of prostate: effect=2.379 (OR=10.79), std=0.365
# Malignant neoplasm of bladder: effect=1.861 (OR=6.43), std=0.271
# Other disorders of bladder: effect=1.787 (OR=5.97), std=0.423
# Chronic prostatitis: effect=1.572 (OR=4.82), std=0.558
# Cystitis: effect=1.411 (OR=4.10), std=0.190
# Bladder neck obstruction: effect=1.213 (OR=3.36), std=1.233
# Chronic cystitis: effect=1.029 (OR=2.80), std=0.969
# Urethral stricture (not specified as infectious): effect=0.973 (OR=2.64), std=1.007
# Cancer of prostate: effect=0.852 (OR=2.34), std=0.613
# Urinary incontinence: effect=0.711 (OR=2.04), std=0.378

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, disease_names_list)
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Irregular menstrual cycle: 1.282
# 2. Prolapse of vaginal walls: 1.169
# 3. Uterine leiomyoma: 1.166
# 4. Disorders of uterus, NEC: 1.129
# 5. Noninflammatory disorders of vagina: 1.091
# 6. Irregular menstrual bleeding: 1.085
# 7. Uterine/Uterovaginal prolapse: 1.079
# 8. Hypertrophy of female genital organs: 1.075
# 9. Postmenopausal atrophic vaginitis: 1.045
# 10. Noninflammatory disorders of cervix: 1.032
#
# Final top diseases:
# 1. Prolapse of vaginal walls: 2.679
# 2. Hypertrophy of female genital organs: 2.345
# 3. Irregular menstrual bleeding: 2.288
# 4. Uterine leiomyoma: 1.974
# 5. Endometriosis: 1.941
# 6. Irregular menstrual cycle: 1.858
# 7. Excessive or frequent menstruation: 1.790
# 8. Disorders of uterus, NEC: 1.656
# 9. Disorders of menstruation and other abnormal bleeding from female genital tract: 1.582
# 10. Noninflammatory disorders of cervix: 1.489
#
# Irregular menstrual cycle changed from rank 1 to 6
#
# Postmenopausal atrophic vaginitis changed from rank 9 to 12
#
# Endometriosis changed from rank 12 to 5
#
# Noninflammatory disorders of vagina changed from rank 5 to 12
#
# Irregular menstrual bleeding changed from rank 6 to 3
#
# Disorders of uterus, NEC changed from rank 4 to 8
#
# Excessive or frequent menstruation changed from rank 12 to 7
#
# Disorders of menstruation and other abnormal bleeding from female genital tract changed from rank 12 to 9
#
# Hypertrophy of female genital organs changed from rank 8 to 2
#
# Uterine/Uterovaginal prolapse changed from rank 7 to 12
#
# Signature 1:
#
# Initial top diseases:
# 1. Other derangement of joint: 1.344
# 2. Myalgia and myositis unspecified: 1.341
# 3. Obesity: 1.331
# 4. Other acquired deformities of limbs: 1.297
# 5. Other disorders of synovium, tendon, and bursa: 1.258
# 6. Enthesopathy: 1.240
# 7. Osteoarthrosis NOS: 1.234
# 8. Synovitis and tenosynovitis: 1.223
# 9. Hammer toe (acquired): 1.201
# 10. Pain in limb: 1.195
#
# Final top diseases:
# 1. Synovitis and tenosynovitis: 2.560
# 2. Other inflammatory spondylopathies: 2.549
# 3. Obesity: 2.448
# 4. Malunion and nonunion of fracture: 2.383
# 5. Hammer toe (acquired): 2.351
# 6. Major depressive disorder: 2.318
# 7. Other disorders of synovium, tendon, and bursa: 2.130
# 8. Osteoarthrosis NOS: 1.985
# 9. Spondylosis and allied disorders: 1.890
# 10. Hallux valgus (Bunion): 1.782
#
# Spondylosis and allied disorders changed from rank 12 to 9
#
# Other derangement of joint changed from rank 1 to 12
#
# Enthesopathy changed from rank 6 to 12
#
# Other acquired deformities of limbs changed from rank 4 to 12
#
# Myalgia and myositis unspecified changed from rank 2 to 12
#
# Hammer toe (acquired) changed from rank 9 to 5
#
# Major depressive disorder changed from rank 12 to 6
#
# Other inflammatory spondylopathies changed from rank 12 to 2
#
# Synovitis and tenosynovitis changed from rank 8 to 1
#
# Malunion and nonunion of fracture changed from rank 12 to 4
#
# Signature 2:
#
# Initial top diseases:
# 1. Kyphoscoliosis and scoliosis: 1.222
# 2. Acquired spondylolisthesis: 1.181
# 3. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.164
# 4. Other and unspecified disc disorder: 1.108
# 5. Degeneration of intervertebral disc: 0.974
# 6. Spondylosis without myelopathy: 0.913
# 7. Displacement of intervertebral disc: 0.887
# 8. Sciatica: 0.880
# 9. Spinal stenosis: 0.843
# 10. Neuralgia, neuritis, and radiculitis NOS: 0.835
#
# Final top diseases:
# 1. Other and unspecified disc disorder: 2.147
# 2. Displacement of intervertebral disc: 1.200
# 3. Spondylosis without myelopathy: 1.041
# 4. Acquired spondylolisthesis: 1.031
# 5. Kyphoscoliosis and scoliosis: 1.013
# 6. Degenerative disease of the spinal cord: 0.767
# 7. Sciatica: 0.730
# 8. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 0.500
# 9. Degeneration of intervertebral disc: 0.491
# 10. Ganglion and cyst of synovium, tendon, and bursa: 0.398
#
# Spinal stenosis changed from rank 9 to 12
#
# Thoracic or lumbosacral neuritis or radiculitis, unspecified changed from rank 3 to 8
#
# Degeneration of intervertebral disc changed from rank 5 to 9
#
# Other and unspecified disc disorder changed from rank 4 to 1
#
# Degenerative disease of the spinal cord changed from rank 12 to 6
#
# Kyphoscoliosis and scoliosis changed from rank 1 to 5
#
# Spondylosis without myelopathy changed from rank 6 to 3
#
# Displacement of intervertebral disc changed from rank 7 to 2
#
# Signature 3:
#
# Initial top diseases:
# 1. Cholecystitis without cholelithiasis: 1.167
# 2. Cholelithiasis: 1.103
# 3. Cholelithiasis with other cholecystitis: 0.988
# 4. Peritoneal adhesions (postoperative) (postinfection): 0.987
# 5. Other disorders of biliary tract: 0.924
# 6. Acute pancreatitis: 0.899
# 7. Cholelithiasis with acute cholecystitis: 0.871
# 8. Calculus of bile duct: 0.841
# 9. Other disorders of gallbladder: 0.799
# 10. Primary open angle glaucoma: -1.866
#
# Final top diseases:
# 1. Cholecystitis without cholelithiasis: 2.423
# 2. Cholelithiasis with acute cholecystitis: 0.977
# 3. Cholelithiasis: 0.685
# 4. Other disorders of biliary tract: 0.441
# 5. Cholelithiasis with other cholecystitis: 0.323
# 6. Calculus of bile duct: 0.284
# 7. Other disorders of gallbladder: 0.091
# 8. Peritoneal adhesions (postoperative) (postinfection): 0.037
# 9. Dyspareunia: -0.042
# 10. Acute pancreatitis: -0.118
#
# Dyspareunia changed from rank 12 to 9
#
# Peritoneal adhesions (postoperative) (postinfection) changed from rank 4 to 8
#
# Acute pancreatitis changed from rank 6 to 10
#
# Cholelithiasis with acute cholecystitis changed from rank 7 to 2
#
# Signature 4:
#
# Initial top diseases:
# 1. Other forms of chronic heart disease: 1.275
# 2. Paroxysmal supraventricular tachycardia: 1.247
# 3. Mitral valve disease: 1.244
# 4. Left bundle branch block: 1.149
# 5. Congestive heart failure (CHF) NOS: 1.090
# 6. Pericarditis: 1.081
# 7. Paroxysmal ventricular tachycardia: 1.051
# 8. Disease of tricuspid valve: 1.009
# 9. Cardiac arrest: 0.975
# 10. Heart failure NOS: 0.972
#
# Final top diseases:
# 1. Mitral valve disease: 2.782
# 2. Paroxysmal supraventricular tachycardia: 2.402
# 3. Left bundle branch block: 2.352
# 4. Cardiac arrest: 2.198
# 5. Right bundle branch block: 2.127
# 6. Disease of tricuspid valve: 1.772
# 7. Primary/intrinsic cardiomyopathies: 1.740
# 8. Paroxysmal ventricular tachycardia: 1.637
# 9. Pleurisy; pleural effusion: 1.504
# 10. Pericarditis: 1.146
#
# Pericarditis changed from rank 6 to 10
#
# Pleurisy; pleural effusion changed from rank 12 to 9
#
# Cardiac arrest changed from rank 9 to 4
#
# Congestive heart failure (CHF) NOS changed from rank 5 to 12
#
# Primary/intrinsic cardiomyopathies changed from rank 12 to 7
#
# Other forms of chronic heart disease changed from rank 1 to 12
#
# Right bundle branch block changed from rank 12 to 5
#
# Signature 5:
#
# Initial top diseases:
# 1. Benign neoplasm of breast: 1.277
# 2. Seborrheic keratosis: 1.274
# 3. Other diseases of the teeth and supporting structures: 1.214
# 4. Hearing loss: 1.200
# 5. Malignant neoplasm of kidney, except pelvis: 1.191
# 6. Benign neoplasm of skin: 1.186
# 7. Viral Enteritis: 1.185
# 8. Visual disturbances: 1.182
# 9. Other benign neoplasm of connective and other soft tissue: 1.174
# 10. Inflammation of eyelids: 1.156
#
# Final top diseases:
# 1. Other diseases of the teeth and supporting structures: 2.980
# 2. Diseases and other conditions of the tongue: 2.961
# 3. Hearing loss: 2.723
# 4. Acute gastritis: 2.404
# 5. Allergic rhinitis: 2.361
# 6. Arrhythmia (cardiac) NOS: 2.352
# 7. Other benign neoplasm of connective and other soft tissue: 2.108
# 8. Hemangioma and lymphangioma, any site: 1.987
# 9. Polymyalgia Rheumatica: 1.966
# 10. Benign neoplasm of breast: 1.943
#
# Polymyalgia Rheumatica changed from rank 12 to 9
#
# Acute gastritis changed from rank 12 to 4
#
# Hemangioma and lymphangioma, any site changed from rank 12 to 8
#
# Seborrheic keratosis changed from rank 2 to 12
#
# Diseases and other conditions of the tongue changed from rank 12 to 2
#
# Benign neoplasm of skin changed from rank 6 to 12
#
# Malignant neoplasm of kidney, except pelvis changed from rank 5 to 12
#
# Allergic rhinitis changed from rank 12 to 5
#
# Viral Enteritis changed from rank 7 to 12
#
# Benign neoplasm of breast changed from rank 1 to 10
#
# Visual disturbances changed from rank 8 to 12
#
# Arrhythmia (cardiac) NOS changed from rank 12 to 6
#
# Signature 6:
#
# Initial top diseases:
# 1. Pulmonary heart disease: 1.203
# 2. Other disorders of male genital organs: 1.191
# 3. Gout: 1.177
# 4. Peritonitis and retroperitoneal infections: 1.176
# 5. Sleep apnea: 1.161
# 6. Duodenal ulcer: 1.142
# 7. Inguinal hernia: 1.127
# 8. Psoriasis vulgaris: 1.118
# 9. Bursitis: 1.117
# 10. Blood in stool: 1.113
#
# Final top diseases:
# 1. Gout: 3.622
# 2. Peritonitis and retroperitoneal infections: 2.895
# 3. Other disorders of male genital organs: 2.777
# 4. Psoriasis vulgaris: 2.178
# 5. Alcoholic liver damage: 2.158
# 6. Inguinal hernia: 2.072
# 7. Bursitis: 1.947
# 8. Atopic/contact dermatitis due to other or unspecified: 1.746
# 9. Alcohol-related disorders: 1.592
# 10. Pulmonary heart disease: 1.545
#
# Alcohol-related disorders changed from rank 12 to 9
#
# Alcoholic liver damage changed from rank 12 to 5
#
# Duodenal ulcer changed from rank 6 to 12
#
# Sleep apnea changed from rank 5 to 12
#
# Pulmonary heart disease changed from rank 1 to 10
#
# Psoriasis vulgaris changed from rank 8 to 4
#
# Atopic/contact dermatitis due to other or unspecified changed from rank 12 to 8
#
# Signature 7:
#
# Initial top diseases:
# 1. Respiratory failure: 1.220
# 2. Pulmonary collapse; interstitial and compensatory emphysema: 1.197
# 3. Asthma: 1.155
# 4. Pneumococcal pneumonia: 1.115
# 5. Postinflammatory pulmonary fibrosis: 1.104
# 6. Chronic airway obstruction: 1.100
# 7. Tobacco use disorder: 1.027
# 8. Pneumonia: 0.975
# 9. Empyema and pneumothorax: 0.959
# 10. Bronchiectasis: 0.891
#
# Final top diseases:
# 1. Asthma: 2.542
# 2. Respiratory failure: 2.429
# 3. Bronchiectasis: 2.161
# 4. Chronic airway obstruction: 1.623
# 5. Pulmonary collapse; interstitial and compensatory emphysema: 1.225
# 6. Tobacco use disorder: 1.187
# 7. Empyema and pneumothorax: 1.112
# 8. Pneumococcal pneumonia: 0.640
# 9. Obstructive chronic bronchitis: 0.477
# 10. Bacterial pneumonia: 0.280
#
# Postinflammatory pulmonary fibrosis changed from rank 5 to 12
#
# Pneumonia changed from rank 8 to 12
#
# Pneumococcal pneumonia changed from rank 4 to 8
#
# Bronchiectasis changed from rank 10 to 3
#
# Obstructive chronic bronchitis changed from rank 12 to 9
#
# Pulmonary collapse; interstitial and compensatory emphysema changed from rank 2 to 5
#
# Signature 8:
#
# Initial top diseases:
# 1. Myopia: 1.087
# 2. Retinal detachment with retinal defect: 1.075
# 3. Disorders of vitreous body: 1.031
# 4. Senile cataract: 1.009
# 5. Cataract: 1.005
# 6. Macular degeneration (senile) of retina NOS: 0.930
# 7. Glaucoma: 0.881
# 8. Other retinal disorders: 0.871
# 9. Primary open angle glaucoma: 0.851
# 10. Retinal detachments and defects: 0.780
#
# Final top diseases:
# 1. Myopia: 2.487
# 2. Cataract: 0.952
# 3. Retinal detachment with retinal defect: 0.919
# 4. Senile cataract: 0.913
# 5. Glaucoma: 0.710
# 6. Urinary tract infection: 0.697
# 7. Other retinal disorders: 0.671
# 8. Retinal detachments and defects: 0.670
# 9. Macular degeneration (senile) of retina NOS: 0.600
# 10. Disorders of vitreous body: 0.501
#
# Cataract changed from rank 5 to 2
#
# Disorders of vitreous body changed from rank 3 to 10
#
# Macular degeneration (senile) of retina NOS changed from rank 6 to 9
#
# Primary open angle glaucoma changed from rank 9 to 12
#
# Urinary tract infection changed from rank 12 to 6
#
# Signature 9:
#
# Initial top diseases:
# 1. Cerebrovascular disease: 1.102
# 2. Late effects of cerebrovascular disease: 1.089
# 3. Transient cerebral ischemia: 1.016
# 4. Cerebral ischemia: 0.992
# 5. Occlusion and stenosis of precerebral arteries: 0.984
# 6. Cerebral artery occlusion, with cerebral infarction: 0.919
# 7. Occlusion of cerebral arteries: 0.819
# 8. Hemiplegia: 0.687
# 9. Disorders of vitreous body: -1.876
# 10. Atopic/contact dermatitis due to other or unspecified: -1.881
#
# Final top diseases:
# 1. Cerebrovascular disease: 1.587
# 2. Late effects of cerebrovascular disease: 1.460
# 3. Cerebral ischemia: 1.056
# 4. Occlusion of cerebral arteries: 0.759
# 5. Transient cerebral ischemia: 0.720
# 6. Occlusion and stenosis of precerebral arteries: -0.021
# 7. Cerebral artery occlusion, with cerebral infarction: -0.054
# 8. Acquired spondylolisthesis: -0.226
# 9. Emphysema: -0.232
# 10. Malignant neoplasm of kidney, except pelvis: -0.324
#
# Acquired spondylolisthesis changed from rank 12 to 8
#
# Emphysema changed from rank 12 to 9
#
# Hemiplegia changed from rank 8 to 12
#
# Disorders of vitreous body changed from rank 9 to 12
#
# Occlusion of cerebral arteries changed from rank 7 to 4
#
# Signature 10:
#
# Initial top diseases:
# 1. Type 2 diabetes: 1.068
# 2. Type 1 diabetes: 1.045
# 3. Hypoglycemia: 0.946
# 4. Diabetic retinopathy: 0.844
# 5. Type 2 diabetes with ophthalmic manifestations: 0.781
# 6. Umbilical hernia: -1.870
# 7. Otitis media: -1.872
# 8. Back pain: -1.876
# 9. Celiac disease: -1.877
# 10. Secondary malignancy of respiratory organs: -1.878
#
# Final top diseases:
# 1. Type 1 diabetes: 1.174
# 2. Diabetic retinopathy: 0.482
# 3. Hypoglycemia: 0.250
# 4. Type 2 diabetes: 0.147
# 5. Ectropion or entropion: -0.122
# 6. Parkinson's disease: -0.127
# 7. Asthma: -0.331
# 8. Coronary atherosclerosis: -0.438
# 9. Type 2 diabetes with ophthalmic manifestations: -0.480
# 10. Chronic sinusitis: -0.533
#
# Type 2 diabetes changed from rank 1 to 4
#
# Umbilical hernia changed from rank 6 to 12
#
# Otitis media changed from rank 7 to 12
#
# Celiac disease changed from rank 9 to 12
#
# Type 2 diabetes with ophthalmic manifestations changed from rank 5 to 9
#
# Asthma changed from rank 12 to 7
#
# Coronary atherosclerosis changed from rank 12 to 8
#
# Ectropion or entropion changed from rank 12 to 5
#
# Parkinson's disease changed from rank 12 to 6
#
# Back pain changed from rank 8 to 12
#
# Signature 11:
#
# Initial top diseases:
# 1. Secondary malignant neoplasm: 1.041
# 2. Cancer of bronchus; lung: 1.021
# 3. Secondary malignant neoplasm of liver: 0.995
# 4. Malignant neoplasm of ovary: 0.935
# 5. Secondary malignancy of respiratory organs: 0.904
# 6. Secondary malignant neoplasm of digestive systems: 0.877
# 7. Secondary malignancy of lymph nodes: 0.866
# 8. Malignant neoplasm of female breast: 0.853
# 9. Malignant neoplasm, other: 0.849
# 10. Secondary malignancy of bone: 0.779
#
# Final top diseases:
# 1. Secondary malignant neoplasm of liver: 1.390
# 2. Cancer of bronchus; lung: 1.344
# 3. Malignant neoplasm of ovary: 0.983
# 4. Secondary malignant neoplasm of digestive systems: 0.892
# 5. Malignant neoplasm, other: 0.843
# 6. Secondary malignant neoplasm: 0.626
# 7. Malignant neoplasm of female breast: 0.360
# 8. Secondary malignancy of bone: 0.289
# 9. Mucous polyp of cervix: 0.107
# 10. Cellulitis and abscess of arm/hand: -0.015
#
# Malignant neoplasm, other changed from rank 9 to 5
#
# Secondary malignancy of respiratory organs changed from rank 5 to 12
#
# Secondary malignant neoplasm changed from rank 1 to 6
#
# Secondary malignancy of lymph nodes changed from rank 7 to 12
#
# Mucous polyp of cervix changed from rank 12 to 9
#
# Signature 12:
#
# Initial top diseases:
# 1. Otitis media: 1.246
# 2. Nasal polyps: 1.139
# 3. Other upper respiratory disease: 1.127
# 4. Chronic pharyngitis and nasopharyngitis: 1.098
# 5. Chronic sinusitis: 1.058
# 6. Septal Deviations/Turbinate Hypertrophy: 0.973
# 7. Rheumatism, unspecified and fibrositis: -1.873
# 8. Scar conditions and fibrosis of skin: -1.878
# 9. Other disorders of testis: -1.878
# 10. Hemorrhage of gastrointestinal tract: -1.878
#
# Final top diseases:
# 1. Nasal polyps: 1.937
# 2. Otitis media: 1.587
# 3. Other upper respiratory disease: 1.492
# 4. Septal Deviations/Turbinate Hypertrophy: 1.453
# 5. Chronic sinusitis: 1.186
# 6. Chronic pharyngitis and nasopharyngitis: 1.015
# 7. Other tests: -0.032
# 8. Dysmenorrhea: -0.214
# 9. Pleurisy; pleural effusion: -0.216
# 10. Hypovolemia: -0.391
#
# Other disorders of testis changed from rank 9 to 12
#
# Pleurisy; pleural effusion changed from rank 12 to 9
#
# Rheumatism, unspecified and fibrositis changed from rank 7 to 12
#
# Other tests changed from rank 12 to 7
#
# Scar conditions and fibrosis of skin changed from rank 8 to 12
#
# Dysmenorrhea changed from rank 12 to 8
#
# Signature 13:
#
# Initial top diseases:
# 1. Chronic ulcer of skin: 1.180
# 2. Staphylococcus infections: 1.134
# 3. Decubitus ulcer: 1.132
# 4. Phlebitis and thrombophlebitis of lower extremities: 1.122
# 5. Peripheral vascular disease, unspecified: 1.078
# 6. Other local infections of skin and subcutaneous tissue: 1.074
# 7. Carbuncle and furuncle: 1.065
# 8. Joint effusions: 0.935
# 9. Other disorders of soft tissues: 0.841
# 10. Stricture of artery: 0.814
#
# Final top diseases:
# 1. Carbuncle and furuncle: 2.135
# 2. Decubitus ulcer: 1.996
# 3. Peripheral vascular disease, unspecified: 1.773
# 4. Other local infections of skin and subcutaneous tissue: 1.526
# 5. Chronic ulcer of skin: 1.469
# 6. Phlebitis and thrombophlebitis of lower extremities: 1.289
# 7. Cellulitis and abscess of arm/hand: 0.778
# 8. Streptococcus infection: 0.575
# 9. Staphylococcus infections: 0.366
# 10. Joint effusions: 0.284
#
# Staphylococcus infections changed from rank 2 to 9
#
# Cellulitis and abscess of arm/hand changed from rank 12 to 7
#
# Chronic ulcer of skin changed from rank 1 to 5
#
# Carbuncle and furuncle changed from rank 7 to 1
#
# Other disorders of soft tissues changed from rank 9 to 12
#
# Streptococcus infection changed from rank 12 to 8
#
# Signature 14:
#
# Initial top diseases:
# 1. Stricture and stenosis of esophagus: 1.127
# 2. Other disorders of stomach and duodenum: 1.121
# 3. Benign neoplasm of other parts of digestive system: 1.076
# 4. Other specified gastritis: 1.064
# 5. Gastric ulcer: 1.043
# 6. Barrett's esophagus: 1.042
# 7. GERD: 1.005
# 8. Gastritis and duodenitis: 0.996
# 9. Duodenitis: 0.993
# 10. Ulcer of esophagus: 0.831
#
# Final top diseases:
# 1. Barrett's esophagus: 2.687
# 2. Other specified gastritis: 1.823
# 3. GERD: 1.628
# 4. Ulcer of esophagus: 1.266
# 5. Other disorders of stomach and duodenum: 1.264
# 6. Benign neoplasm of other parts of digestive system: 1.192
# 7. Reflux esophagitis: 1.169
# 8. Gastritis and duodenitis: 0.881
# 9. Stricture and stenosis of esophagus: 0.465
# 10. Osteoporosis NOS: 0.322
#
# Gastric ulcer changed from rank 5 to 12
#
# Benign neoplasm of other parts of digestive system changed from rank 3 to 6
#
# Barrett's esophagus changed from rank 6 to 1
#
# Ulcer of esophagus changed from rank 10 to 4
#
# Reflux esophagitis changed from rank 12 to 7
#
# Other disorders of stomach and duodenum changed from rank 2 to 5
#
# Stricture and stenosis of esophagus changed from rank 1 to 9
#
# Duodenitis changed from rank 9 to 12
#
# GERD changed from rank 7 to 3
#
# Signature 15:
#
# Initial top diseases:
# 1. Coronary atherosclerosis: 1.258
# 2. Other acute and subacute forms of ischemic heart disease: 1.199
# 3. Hypercholesterolemia: 1.187
# 4. Hyperlipidemia: 1.074
# 5. Other chronic ischemic heart disease, unspecified: 1.006
# 6. Angina pectoris: 0.995
# 7. Unstable angina (intermediate coronary syndrome): 0.894
# 8. Essential hypertension: 0.892
# 9. Myocardial infarction: 0.847
# 10. Retinal detachment with retinal defect: -1.869
#
# Final top diseases:
# 1. Other chronic ischemic heart disease, unspecified: 2.698
# 2. Coronary atherosclerosis: 2.102
# 3. Unstable angina (intermediate coronary syndrome): 1.921
# 4. Other acute and subacute forms of ischemic heart disease: 1.826
# 5. Hyperlipidemia: 1.406
# 6. Hypercholesterolemia: 1.023
# 7. Streptococcus infection: 0.794
# 8. Essential hypertension: 0.692
# 9. Myocardial infarction: 0.541
# 10. Decubitus ulcer: 0.137
#
# Hypercholesterolemia changed from rank 3 to 6
#
# Streptococcus infection changed from rank 12 to 7
#
# Other chronic ischemic heart disease, unspecified changed from rank 5 to 1
#
# Angina pectoris changed from rank 6 to 12
#
# Unstable angina (intermediate coronary syndrome) changed from rank 7 to 3
#
# Signature 16:
#
# Initial top diseases:
# 1. Hypotension NOS: 1.268
# 2. E. coli: 1.257
# 3. Neutropenia: 1.235
# 4. Constipation: 1.143
# 5. Acidosis: 1.133
# 6. Other diseases of respiratory system, NEC: 1.124
# 7. Disorders of calcium/phosphorus metabolism: 1.089
# 8. Gram negative septicemia: 1.076
# 9. Acute renal failure: 1.048
# 10. Hypovolemia: 1.044
#
# Final top diseases:
# 1. Acidosis: 2.340
# 2. Hypopotassemia: 1.902
# 3. Hypotension NOS: 1.781
# 4. Acute renal failure: 1.608
# 5. Other diseases of respiratory system, NEC: 1.588
# 6. Constipation: 1.392
# 7. Disorders of calcium/phosphorus metabolism: 1.323
# 8. Neutropenia: 1.303
# 9. Orthostatic hypotension: 1.300
# 10. E. coli: 1.263
#
# Acidosis changed from rank 5 to 1
#
# Acute renal failure changed from rank 9 to 4
#
# Orthostatic hypotension changed from rank 12 to 9
#
# Hypopotassemia changed from rank 12 to 2
#
# Gram negative septicemia changed from rank 8 to 12
#
# Neutropenia changed from rank 3 to 8
#
# E. coli changed from rank 2 to 10
#
# Signature 17:
#
# Initial top diseases:
# 1. Renal colic: 0.974
# 2. Calculus of kidney: 0.920
# 3. Stricture/obstruction of ureter: 0.896
# 4. Calculus of ureter: 0.783
# 5. Hydronephrosis: 0.746
# 6. Displacement of intervertebral disc: -1.851
# 7. Reflux esophagitis: -1.876
# 8. Other disorders of soft tissues: -1.876
# 9. Chronic periodontitis: -1.879
# 10. Paroxysmal supraventricular tachycardia: -1.880
#
# Final top diseases:
# 1. Calculus of ureter: 0.871
# 2. Renal colic: 0.709
# 3. Calculus of kidney: 0.418
# 4. Barrett's esophagus: 0.220
# 5. Scar conditions and fibrosis of skin: 0.186
# 6. Peritoneal adhesions (postoperative) (postinfection): -0.157
# 7. Reflux esophagitis: -0.213
# 8. Arrhythmia (cardiac) NOS: -0.390
# 9. Malignant neoplasm, other: -0.426
# 10. Peripheral enthesopathies and allied syndromes: -0.459
#
# Malignant neoplasm, other changed from rank 12 to 9
#
# Stricture/obstruction of ureter changed from rank 3 to 12
#
# Barrett's esophagus changed from rank 12 to 4
#
# Calculus of ureter changed from rank 4 to 1
#
# Chronic periodontitis changed from rank 9 to 12
#
# Peritoneal adhesions (postoperative) (postinfection) changed from rank 12 to 6
#
# Other disorders of soft tissues changed from rank 8 to 12
#
# Scar conditions and fibrosis of skin changed from rank 12 to 5
#
# Displacement of intervertebral disc changed from rank 6 to 12
#
# Arrhythmia (cardiac) NOS changed from rank 12 to 8
#
# Hydronephrosis changed from rank 5 to 12
#
# Signature 18:
#
# Initial top diseases:
# 1. Ulcerative colitis: 1.318
# 2. Hemorrhage of rectum and anus: 1.287
# 3. Noninfectious gastroenteritis: 1.251
# 4. Other disorders of intestine: 1.159
# 5. Malignant neoplasm of rectum, rectosigmoid junction, and anus: 1.125
# 6. Hemorrhoids: 1.109
# 7. Anal and rectal polyp: 1.065
# 8. Other intestinal obstruction: 1.034
# 9. Benign neoplasm of colon: 1.009
# 10. Gastrointestinal complications: 0.974
#
# Final top diseases:
# 1. Malignant neoplasm of rectum, rectosigmoid junction, and anus: 3.234
# 2. Noninfectious gastroenteritis: 2.173
# 3. Other intestinal obstruction: 2.013
# 4. Ulcerative colitis: 1.659
# 5. Neoplasm of unspecified nature of digestive system: 1.366
# 6. Hemorrhage of rectum and anus: 1.274
# 7. Anal and rectal conditions: 1.206
# 8. Other disorders of intestine: 1.168
# 9. Diverticulosis: 1.124
# 10. Hemorrhoids: 1.008
#
# Diverticulosis changed from rank 12 to 9
#
# Other intestinal obstruction changed from rank 8 to 3
#
# Benign neoplasm of colon changed from rank 9 to 12
#
# Neoplasm of unspecified nature of digestive system changed from rank 12 to 5
#
# Malignant neoplasm of rectum, rectosigmoid junction, and anus changed from rank 5 to 1
#
# Hemorrhage of rectum and anus changed from rank 2 to 6
#
# Other disorders of intestine changed from rank 4 to 8
#
# Hemorrhoids changed from rank 6 to 10
#
# Anal and rectal conditions changed from rank 12 to 7
#
# Ulcerative colitis changed from rank 1 to 4
#
# Anal and rectal polyp changed from rank 7 to 12
#
# Signature 19:
#
# Initial top diseases:
# 1. Chronic prostatitis: 1.226
# 2. Cancer of prostate: 1.121
# 3. Hyperplasia of prostate: 1.114
# 4. Chronic cystitis: 1.110
# 5. Urinary incontinence: 1.075
# 6. Malignant neoplasm of bladder: 1.065
# 7. Cystitis: 1.053
# 8. Urethral stricture (not specified as infectious): 0.993
# 9. Bladder neck obstruction: 0.985
# 10. Other disorders of bladder: 0.934
#
# Final top diseases:
# 1. Hyperplasia of prostate: 2.379
# 2. Malignant neoplasm of bladder: 1.861
# 3. Other disorders of bladder: 1.787
# 4. Chronic prostatitis: 1.572
# 5. Cystitis: 1.411
# 6. Bladder neck obstruction: 1.213
# 7. Chronic cystitis: 1.029
# 8. Urethral stricture (not specified as infectious): 0.973
# 9. Cancer of prostate: 0.852
# 10. Urinary incontinence: 0.711
#
# Chronic prostatitis changed from rank 1 to 4
#
# Malignant neoplasm of bladder changed from rank 6 to 2
#
# Bladder neck obstruction changed from rank 9 to 6
#
# Cancer of prostate changed from rank 2 to 9
#
# Other disorders of bladder changed from rank 10 to 3
#
# Urinary incontinence changed from rank 5 to 10
#
# Chronic cystitis changed from rank 4 to 7

# %%
def visualize_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    plt.figure(figsize=(15, 5))
    
    # 1. Density plot of predictions
    plt.subplot(131)
    plt.hist(event_probs, bins=50, density=True, alpha=0.5, label='Events', color='red')
    plt.hist(nonevent_probs, bins=50, density=True, alpha=0.5, label='Non-events', color='blue')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Density')
    plt.title('Distribution of Predictions')
    plt.legend()
    
    # 2. ROC curve
    from sklearn.metrics import roc_curve, auc
    y_true = np.concatenate([np.ones_like(event_probs), np.zeros_like(nonevent_probs)])
    y_pred = np.concatenate([event_probs, nonevent_probs])
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    
    plt.subplot(132)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    
    # 3. Calibration plot
    from sklearn.calibration import calibration_curve
    prob_true, prob_pred = calibration_curve(y_true, y_pred, n_bins=10)
    
    plt.subplot(133)
    plt.plot(prob_pred, prob_true, marker='o', label='Model')
    plt.plot([0, 1], [0, 1], linestyle='--', label='Perfect calibration')
    plt.xlabel('Mean predicted probability')
    plt.ylabel('Empirical probability')
    plt.title('Calibration Plot')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    print(f"AUC: {roc_auc:.4f}")
    
    return event_probs, nonevent_probs, roc_auc

# %%
visualize_predictions(model, Y, E)
# Out:
# Average pi for events: 0.0010 (std: 0.0017)
# Average pi for non-events: 0.0004 (std: 0.0009)
# AUC: 0.6917
# (array([5.6849360e-05, 5.1999676e-05, 4.6067595e-05, ..., 1.1411139e-06,
#         1.8293485e-07, 9.9999999e-09], dtype=float32),
#  array([1.e-08, 1.e-08, 1.e-08, ..., 1.e-08, 1.e-08, 1.e-08], dtype=float32),
#  0.6917139378216937)

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
plot_signature_temporal_patterns(model, disease_names_list, selected_signatures=[0,1,14,15,16,13,17])

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000613
# Mean predicted risk (original): 0.000203
# Mean predicted risk (calibrated): 0.000613
# Calibration scale factor: 3.019

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.508
