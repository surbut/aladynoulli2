# %%
import rpy2.robjects as robjects
import numpy as np
import os as os
from rpy2.robjects import numpy2ri
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt


# %load_ext autoreload
# %autoreload 2
# Specify the path to your data files
data_path = "/"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
# Activate automatic conversion between R and NumPy arrays
numpy2ri.activate()# Load data saved as .rds files
Y = np.array(robjects.r['readRDS'](os.path.join(data_path, 'Y.rds')))
E = np.array(robjects.r['readRDS'](os.path.join(data_path, 'event_for_aladynoulli.rds')))
G = np.array(robjects.r['readRDS'](os.path.join(data_path, 'prs.rds')))

E = E.astype(int)

# G should be float64
G = G.astype(float)
G.shape
G = G.T
print("G shape after transposition:", G.shape)

# Convert to PyTorch tensors
Y_tensor = torch.FloatTensor(Y)
E_tensor = torch.FloatTensor(E)
G_tensor = torch.FloatTensor(G)

# Get dimensions
N, D, T = Y_tensor.shape
P = G_tensor.shape[1]
T = int(E_tensor.max() + 1)  # 0-indexed time
K = 10  # number of topics

# Print shapes to verify
print("Tensor shapes:")
print(f"Y: {Y_tensor.shape}")  # [N, D]
print(f"E: {E_tensor.shape}")  # [N, D]
print(f"G: {G_tensor.shape}")  # [N, P]
print(f"Time range: 0 to {T-1}")
print(T)
print(K)


import rpy2.robjects as robjects
import pandas as pd
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the metadata from R
disease_names = pd.DataFrame(robjects.r['readRDS']('/Users/sarahurbut/Dropbox (Personal)/disease_names.rds'))
prs_names = pd.DataFrame(robjects.r['readRDS']('/Users/sarahurbut/Dropbox (Personal)/prs_names.rds'))
disease_names_list = disease_names[0].tolist()
# Out:
# G shape after transposition: (9661, 36)
# Tensor shapes:
# Y: torch.Size([9661, 348, 51])
# E: torch.Size([9661, 348])
# G: torch.Size([9661, 36])
# Time range: 0 to 50
# 51
# 10

# %%
disease_names_list
# Out:
# ['Chronic prostatitis',
#  'Gastrointestinal complications',
#  'Other peripheral nerve disorders',
#  'Peritonitis and retroperitoneal infections',
#  'Hyperplasia of prostate',
#  'Diverticulosis',
#  'Thrombocytopenia',
#  'Other anemias',
#  'Cardiomegaly',
#  'Colon cancer',
#  'Hypovolemia',
#  'Pericarditis',
#  'Pleurisy; pleural effusion',
#  'Hypotension NOS',
#  'Other diseases of the teeth and supporting structures',
#  'Benign neoplasm of colon',
#  'Pneumonia',
#  'Hyposmolality and/or hyponatremia',
#  'Iron deficiency anemias, unspecified or not due to blood loss',
#  'Pneumococcal pneumonia',
#  'Other specified gastritis',
#  'Malignant neoplasm of rectum, rectosigmoid junction, and anus',
#  'Esophagitis, GERD and related diseases',
#  'Cancer of prostate',
#  'Hemorrhage of gastrointestinal tract',
#  'Other disorders of prostate',
#  'Essential hypertension',
#  'Malignant neoplasm of kidney, except pelvis',
#  'Peritoneal adhesions (postoperative) (postinfection)',
#  'Acute renal failure',
#  'Hypercholesterolemia',
#  'Pulmonary heart disease',
#  'Obesity',
#  'Secondary malignancy of lymph nodes',
#  'Sebaceous cyst',
#  'Cerebral artery occlusion, with cerebral infarction',
#  'Secondary malignant neoplasm of liver',
#  'Other disorders of liver',
#  'Hemiplegia',
#  'Other disorders of intestine',
#  'Cyst of kidney, acquired',
#  'Cholelithiasis',
#  'Secondary malignancy of bone',
#  'Irritable Bowel Syndrome',
#  'Asthma',
#  'Major depressive disorder',
#  'Visual disturbances',
#  'Cataract',
#  'Macular degeneration (senile) of retina NOS',
#  'Myopia',
#  'Hemorrhoids',
#  'Dental caries',
#  'Anal and rectal conditions',
#  'Acute pancreatitis',
#  'Gastritis and duodenitis',
#  'Duodenitis',
#  'GERD',
#  'Arthropathy NOS',
#  'Candidiasis',
#  'Back pain',
#  'Constipation',
#  'Bacterial infection NOS',
#  'Other disorders of bone and cartilage',
#  'Urinary tract infection',
#  'Osteoarthrosis, generalized',
#  'Polymyalgia Rheumatica',
#  'Decubitus ulcer',
#  'Other disorders of testis',
#  'Osteoporosis NOS',
#  'Bladder neck obstruction',
#  'Other intestinal obstruction',
#  'Benign neoplasm of other parts of digestive system',
#  'Malignant neoplasm of female breast',
#  'Secondary malignancy of respiratory organs',
#  'Other diseases of respiratory system, NEC',
#  'Spondylosis and allied disorders',
#  'Osteoarthritis; localized',
#  'Breast cancer [female]',
#  'Kyphoscoliosis and scoliosis',
#  'Enthesopathy',
#  'Osteoarthrosis, localized, primary',
#  'Chronic renal failure [CKD]',
#  'Type 2 diabetes',
#  'Umbilical hernia',
#  'Polyp of corpus uteri',
#  'Senile cataract',
#  'Postmenopausal bleeding',
#  'Ovarian cyst',
#  'Epilepsy, recurrent seizures, convulsions',
#  'Functional digestive disorders',
#  'Diaphragmatic hernia',
#  'Benign neoplasm of ovary',
#  'Pelvic peritoneal adhesions, female (postoperative) (postinfection)',
#  'Malignant neoplasm of uterus',
#  'Other disorders of bladder',
#  'Cholelithiasis with other cholecystitis',
#  'Prolapse of vaginal walls',
#  'Orthostatic hypotension',
#  'Stricture and stenosis of esophagus',
#  'Hypopotassemia',
#  'Mucous polyp of cervix',
#  'Secondary hypothyroidism',
#  'Aortic valve disease',
#  'Noninflammatory disorders of cervix',
#  'Gram negative septicemia',
#  'Neutropenia',
#  'Streptococcus infection',
#  'Congenital anomalies of great vessels',
#  'Hypothyroidism NOS',
#  'Sepsis',
#  'Coronary atherosclerosis',
#  'Other chronic ischemic heart disease, unspecified',
#  'Disorders of vitreous body',
#  'Myocardial infarction',
#  'Angina pectoris',
#  'Synovitis and tenosynovitis',
#  'Unstable angina (intermediate coronary syndrome)',
#  'Ulcerative colitis',
#  'Inguinal hernia',
#  'Respiratory failure',
#  'Hydrocele',
#  'Anal and rectal polyp',
#  'Pulmonary collapse; interstitial and compensatory emphysema',
#  'Viral infection',
#  'Rheumatoid arthritis',
#  'Blood in stool',
#  'Ventral hernia',
#  'Hypoglycemia',
#  'Chronic Kidney Disease, Stage III',
#  'Malignant neoplasm, other',
#  'Acidosis',
#  'Stricture/obstruction of ureter',
#  'Esophageal bleeding (varices/hemorrhage)',
#  'Other disorders of biliary tract',
#  'Alcohol-related disorders',
#  'Bipolar',
#  'Cellulitis and abscess of arm/hand',
#  'Lipoma of skin and subcutaneous tissue',
#  'Postinflammatory pulmonary fibrosis',
#  "Barrett's esophagus",
#  'Sleep apnea',
#  'Degenerative disease of the spinal cord',
#  'Non-Hodgkins lymphoma',
#  'Epiphora',
#  'Melanomas of skin',
#  'Anxiety disorder',
#  'Benign neoplasm of skin',
#  'Actinic keratosis',
#  'Other disorders of eyelids',
#  'Gout',
#  'Chronic ulcer of skin',
#  'Disorder of skin and subcutaneous tissue NOS',
#  'Congestive heart failure (CHF) NOS',
#  'Uterine leiomyoma',
#  'Other disorders of the kidney and ureters',
#  'Acute upper respiratory infections of multiple or unspecified sites',
#  'Postmenopausal atrophic vaginitis',
#  'Other disorders of soft tissues',
#  'Acute appendicitis',
#  'Tobacco use disorder',
#  'Abdominal pain',
#  'Disorders of conjunctiva',
#  'Other disorders of stomach and duodenum',
#  'Noninflammatory disorders of vagina',
#  'Cystitis',
#  'Urinary incontinence',
#  'Chronic tonsillitis and adenoiditis',
#  'Other upper respiratory disease',
#  'Pain in limb',
#  'Other tests',
#  'Disorders of uterus, NEC',
#  'Myalgia and myositis unspecified',
#  'Other hypertrophic and atrophic conditions of skin',
#  'Hammer toe (acquired)',
#  'Chronic airway obstruction',
#  'Late effects of cerebrovascular disease',
#  'E. coli',
#  'Occlusion of cerebral arteries',
#  'Cerebral ischemia',
#  'Cerebrovascular disease',
#  'Other chronic nonalcoholic liver disease',
#  'Atrial fibrillation and flutter',
#  'Primary open angle glaucoma',
#  'Osteopenia or other disorder of bone and cartilage',
#  "Parkinson's disease",
#  "Contracture of palmar fascia [Dupuytren's disease]",
#  'Internal derangement of knee',
#  'Calculus of bile duct',
#  'Peripheral enthesopathies and allied syndromes',
#  'Hydronephrosis',
#  'Hypertensive chronic kidney disease',
#  'Atopic/contact dermatitis due to other or unspecified',
#  'Urethral stricture (not specified as infectious)',
#  'Malignant neoplasm of bladder',
#  'Hyperlipidemia',
#  'Staphylococcus infections',
#  'Other disorders of male genital organs',
#  'Hyperpotassemia',
#  'Spinal stenosis',
#  'Gastric ulcer',
#  'Acquired spondylolisthesis',
#  'Retinal vascular changes and abnomalities',
#  'Other non-epithelial cancer of skin',
#  'Duodenal ulcer',
#  'Other derangement of joint',
#  'Seborrheic keratosis',
#  'Regional enteritis',
#  'Pyelonephritis',
#  'Calculus of ureter',
#  'Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]',
#  'Ulcer of esophagus',
#  'Migraine',
#  'Celiac disease',
#  'Type 1 diabetes',
#  'Carbuncle and furuncle',
#  "Raynaud's syndrome",
#  'Hearing loss',
#  'Hemorrhage of rectum and anus',
#  'Chronic pharyngitis and nasopharyngitis',
#  'Septal Deviations/Turbinate Hypertrophy',
#  'Other benign neoplasm of connective and other soft tissue',
#  'Inflammatory and toxic neuropathy',
#  'Bronchiectasis',
#  'Acquired toe deformities',
#  'Reflux esophagitis',
#  'Hallux valgus (Bunion)',
#  'Thyrotoxicosis with or without goiter',
#  'Neoplasm of uncertain behavior',
#  'Viral Enteritis',
#  'Diabetic retinopathy',
#  'Endometrial hyperplasia',
#  'Type 2 diabetes with ophthalmic manifestations',
#  'Cervicitis and endocervicitis',
#  'Disorders of calcium/phosphorus metabolism',
#  'Sleep disorders',
#  'Other retinal disorders',
#  'Ptosis of eyelid',
#  'Facial nerve disorders [CN7]',
#  'Diseases of the larynx and vocal cords',
#  'Other inflammatory spondylopathies',
#  'Ectropion or entropion',
#  'Disorders of lacrimal system',
#  'Other forms of chronic heart disease',
#  'Left bundle branch block',
#  'Cancer of bronchus; lung',
#  'Peripheral vascular disease, unspecified',
#  'Chronic sinusitis',
#  'Dysmenorrhea',
#  'Excessive or frequent menstruation',
#  'Glaucoma',
#  'Noninfectious gastroenteritis',
#  'Heart failure NOS',
#  'Perforation of tympanic membrane',
#  'Malunion and nonunion of fracture',
#  'Uterine/Uterovaginal prolapse',
#  'Functional disorders of bladder',
#  'Rheumatic disease of the heart valves',
#  'Pain in joint',
#  'Retinal detachment with retinal defect',
#  'Bacterial enteritis',
#  'Varicose veins of lower extremity',
#  'First degree AV block',
#  'Phlebitis and thrombophlebitis of lower extremities',
#  'Disturbances in tooth eruption',
#  'Other and unspecified disc disorder',
#  'Thoracic or lumbosacral neuritis or radiculitis, unspecified',
#  'Degeneration of intervertebral disc',
#  'Hemangioma and lymphangioma, any site',
#  'Renal colic',
#  'Renal failure NOS',
#  'Transient cerebral ischemia',
#  'Noninflammatory disorders of vulva and perineum',
#  'Emphysema',
#  'Secondary malignant neoplasm',
#  'Retinal detachments and defects',
#  'Mitral valve disease',
#  'Cardiac arrest',
#  'Paroxysmal ventricular tachycardia',
#  'Other acquired deformities of limbs',
#  'Symptoms and disorders of the joints',
#  'Spondylosis without myelopathy',
#  'Rheumatism, unspecified and fibrositis',
#  'Cervicalgia',
#  'Multiple sclerosis',
#  'Ingrowing nail',
#  'Endometriosis',
#  'Primary/intrinsic cardiomyopathies',
#  'Allergic rhinitis',
#  'Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue',
#  'Calculus of kidney',
#  'Disease of tricuspid valve',
#  'Lipoma',
#  'Abdominal aortic aneurysm',
#  'Irregular menstrual cycle/bleeding',
#  'Chronic cystitis',
#  'Benign neoplasm of breast',
#  'Paroxysmal supraventricular tachycardia',
#  'Irregular menstrual bleeding',
#  'Ganglion and cyst of synovium, tendon, and bursa',
#  'Strabismus (not specified as paralytic)',
#  'Scar conditions and fibrosis of skin',
#  'Displacement of intervertebral disc',
#  'Other acute and subacute forms of ischemic heart disease',
#  'Obstructive chronic bronchitis',
#  'Empyema and pneumothorax',
#  'Bursitis',
#  'Right bundle branch block',
#  'Psoriasis vulgaris',
#  'Neuralgia, neuritis, and radiculitis NOS',
#  'Joint effusions',
#  'Bacterial pneumonia',
#  'Arrhythmia (cardiac) NOS',
#  'Hallux rigidus',
#  'Cholecystitis without cholelithiasis',
#  'Disorders of menstruation and other abnormal bleeding from female genital tract',
#  'Sciatica',
#  'Hypertrophy of female genital organs',
#  'Pain and other symptoms associated with female genital organs',
#  'Cholelithiasis with acute cholecystitis',
#  'Other local infections of skin and subcutaneous tissue',
#  'Nasal polyps',
#  'Inflammation of eyelids',
#  'Other disorders of gallbladder',
#  'Stricture of artery',
#  'Occlusion and stenosis of precerebral arteries',
#  'Chronic glomerulonephritis, NOS',
#  'Acute gastritis',
#  'Alcoholic liver damage',
#  'Hematemesis',
#  'Other disorders of synovium, tendon, and bursa',
#  'Irregular menstrual cycle',
#  'Periapical abscess',
#  'Redundant prepuce and phimosis/BXO',
#  'Benign neoplasm of lip, oral cavity, and pharynx',
#  'Diseases and other conditions of the tongue',
#  'Osteoarthrosis NOS',
#  'Hypertrophy of breast (Gynecomastia)',
#  'Neoplasm of unspecified nature of digestive system',
#  'Otitis media',
#  'Chronic periodontitis',
#  'Malignant neoplasm of ovary',
#  'Secondary malignant neoplasm of digestive systems',
#  'Other symptoms/disorders or the urinary system',
#  'Acute pharyngitis',
#  'Infertility, female',
#  'Lump or mass in breast',
#  'Viral warts & HPV',
#  'Dyspareunia']

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from seaborn) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from cluster_g_logit_init import *
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

# %%
prevalence_t=compute_smoothed_prevalence(Y=Y,window_size=5)
K=20
# Create model
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(N, D, T, K, P, G, Y, prevalence_t)
# Visualize the clusters
model.visualize_clusters(disease_names_list)
# Out:
# Lambda kernel condition number: 45200668.00
# Phi kernel condition number: 89734320.00
#
# Cluster Sizes:
# Cluster 0: 27 diseases
# Cluster 1: 32 diseases
# Cluster 2: 12 diseases
# Cluster 3: 9 diseases
# Cluster 4: 19 diseases
# Cluster 5: 74 diseases
# Cluster 6: 31 diseases
# Cluster 7: 12 diseases
# Cluster 8: 10 diseases
# Cluster 9: 8 diseases
# Cluster 10: 5 diseases
# Cluster 11: 10 diseases
# Cluster 12: 6 diseases
# Cluster 13: 12 diseases
# Cluster 14: 14 diseases
# Cluster 15: 9 diseases
# Cluster 16: 23 diseases
# Cluster 17: 5 diseases
# Cluster 18: 18 diseases
# Cluster 19: 12 diseases
# Initialization complete!
#
# Cluster Assignments:
#
# Cluster 0:
#   - Polyp of corpus uteri (prevalence: 0.0007)
#   - Postmenopausal bleeding (prevalence: 0.0008)
#   - Ovarian cyst (prevalence: 0.0004)
#   - Benign neoplasm of ovary (prevalence: 0.0001)
#   - Pelvic peritoneal adhesions, female (postoperative) (postinfection) (prevalence: 0.0003)
#   - Malignant neoplasm of uterus (prevalence: 0.0002)
#   - Prolapse of vaginal walls (prevalence: 0.0007)
#   - Mucous polyp of cervix (prevalence: 0.0002)
#   - Noninflammatory disorders of cervix (prevalence: 0.0003)
#   - Uterine leiomyoma (prevalence: 0.0009)
#   - Postmenopausal atrophic vaginitis (prevalence: 0.0001)
#   - Noninflammatory disorders of vagina (prevalence: 0.0001)
#   - Disorders of uterus, NEC (prevalence: 0.0003)
#   - Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] (prevalence: 0.0001)
#   - Endometrial hyperplasia (prevalence: 0.0001)
#   - Cervicitis and endocervicitis (prevalence: 0.0001)
#   - Dysmenorrhea (prevalence: 0.0001)
#   - Excessive or frequent menstruation (prevalence: 0.0007)
#   - Uterine/Uterovaginal prolapse (prevalence: 0.0005)
#   - Endometriosis (prevalence: 0.0003)
#   - Irregular menstrual cycle/bleeding (prevalence: 0.0001)
#   - Irregular menstrual bleeding (prevalence: 0.0002)
#   - Disorders of menstruation and other abnormal bleeding from female genital tract (prevalence: 0.0001)
#   - Hypertrophy of female genital organs (prevalence: 0.0001)
#   - Pain and other symptoms associated with female genital organs (prevalence: 0.0001)
#   - Irregular menstrual cycle (prevalence: 0.0001)
#   - Dyspareunia (prevalence: 0.0001)
#
# Cluster 1:
#   - Other peripheral nerve disorders (prevalence: 0.0013)
#   - Obesity (prevalence: 0.0025)
#   - Major depressive disorder (prevalence: 0.0021)
#   - Arthropathy NOS (prevalence: 0.0057)
#   - Other disorders of bone and cartilage (prevalence: 0.0005)
#   - Osteoarthrosis, generalized (prevalence: 0.0008)
#   - Spondylosis and allied disorders (prevalence: 0.0006)
#   - Osteoarthritis; localized (prevalence: 0.0014)
#   - Enthesopathy (prevalence: 0.0012)
#   - Osteoarthrosis, localized, primary (prevalence: 0.0008)
#   - Synovitis and tenosynovitis (prevalence: 0.0004)
#   - Rheumatoid arthritis (prevalence: 0.0007)
#   - Anxiety disorder (prevalence: 0.0015)
#   - Pain in limb (prevalence: 0.0009)
#   - Myalgia and myositis unspecified (prevalence: 0.0003)
#   - Hammer toe (acquired) (prevalence: 0.0002)
#   - Internal derangement of knee (prevalence: 0.0013)
#   - Peripheral enthesopathies and allied syndromes (prevalence: 0.0007)
#   - Other derangement of joint (prevalence: 0.0003)
#   - Acquired toe deformities (prevalence: 0.0002)
#   - Hallux valgus (Bunion) (prevalence: 0.0005)
#   - Other inflammatory spondylopathies (prevalence: 0.0002)
#   - Malunion and nonunion of fracture (prevalence: 0.0001)
#   - Pain in joint (prevalence: 0.0011)
#   - Other acquired deformities of limbs (prevalence: 0.0002)
#   - Symptoms and disorders of the joints (prevalence: 0.0001)
#   - Rheumatism, unspecified and fibrositis (prevalence: 0.0001)
#   - Cervicalgia (prevalence: 0.0003)
#   - Ingrowing nail (prevalence: 0.0001)
#   - Hallux rigidus (prevalence: 0.0001)
#   - Other disorders of synovium, tendon, and bursa (prevalence: 0.0001)
#   - Osteoarthrosis NOS (prevalence: 0.0001)
#
# Cluster 2:
#   - Back pain (prevalence: 0.0017)
#   - Kyphoscoliosis and scoliosis (prevalence: 0.0002)
#   - Degenerative disease of the spinal cord (prevalence: 0.0002)
#   - Spinal stenosis (prevalence: 0.0007)
#   - Acquired spondylolisthesis (prevalence: 0.0003)
#   - Other and unspecified disc disorder (prevalence: 0.0006)
#   - Thoracic or lumbosacral neuritis or radiculitis, unspecified (prevalence: 0.0005)
#   - Degeneration of intervertebral disc (prevalence: 0.0005)
#   - Spondylosis without myelopathy (prevalence: 0.0010)
#   - Displacement of intervertebral disc (prevalence: 0.0004)
#   - Neuralgia, neuritis, and radiculitis NOS (prevalence: 0.0002)
#   - Sciatica (prevalence: 0.0004)
#
# Cluster 3:
#   - Peritoneal adhesions (postoperative) (postinfection) (prevalence: 0.0006)
#   - Cholelithiasis (prevalence: 0.0011)
#   - Acute pancreatitis (prevalence: 0.0003)
#   - Cholelithiasis with other cholecystitis (prevalence: 0.0006)
#   - Other disorders of biliary tract (prevalence: 0.0002)
#   - Calculus of bile duct (prevalence: 0.0003)
#   - Cholecystitis without cholelithiasis (prevalence: 0.0003)
#   - Cholelithiasis with acute cholecystitis (prevalence: 0.0002)
#   - Other disorders of gallbladder (prevalence: 0.0002)
#
# Cluster 4:
#   - Cardiomegaly (prevalence: 0.0007)
#   - Pericarditis (prevalence: 0.0002)
#   - Pleurisy; pleural effusion (prevalence: 0.0013)
#   - Aortic valve disease (prevalence: 0.0002)
#   - Congenital anomalies of great vessels (prevalence: 0.0004)
#   - Congestive heart failure (CHF) NOS (prevalence: 0.0006)
#   - Atrial fibrillation and flutter (prevalence: 0.0014)
#   - Other forms of chronic heart disease (prevalence: 0.0006)
#   - Left bundle branch block (prevalence: 0.0004)
#   - Heart failure NOS (prevalence: 0.0009)
#   - Rheumatic disease of the heart valves (prevalence: 0.0004)
#   - First degree AV block (prevalence: 0.0003)
#   - Mitral valve disease (prevalence: 0.0005)
#   - Cardiac arrest (prevalence: 0.0002)
#   - Paroxysmal ventricular tachycardia (prevalence: 0.0002)
#   - Primary/intrinsic cardiomyopathies (prevalence: 0.0002)
#   - Disease of tricuspid valve (prevalence: 0.0003)
#   - Paroxysmal supraventricular tachycardia (prevalence: 0.0004)
#   - Right bundle branch block (prevalence: 0.0004)
#
# Cluster 5:
#   - Other diseases of the teeth and supporting structures (prevalence: 0.0003)
#   - Malignant neoplasm of kidney, except pelvis (prevalence: 0.0002)
#   - Irritable Bowel Syndrome (prevalence: 0.0010)
#   - Visual disturbances (prevalence: 0.0002)
#   - Dental caries (prevalence: 0.0003)
#   - Polymyalgia Rheumatica (prevalence: 0.0003)
#   - Osteoporosis NOS (prevalence: 0.0013)
#   - Breast cancer [female] (prevalence: 0.0002)
#   - Functional digestive disorders (prevalence: 0.0001)
#   - Secondary hypothyroidism (prevalence: 0.0002)
#   - Hypothyroidism NOS (prevalence: 0.0019)
#   - Viral infection (prevalence: 0.0005)
#   - Chronic Kidney Disease, Stage III (prevalence: 0.0010)
#   - Lipoma of skin and subcutaneous tissue (prevalence: 0.0004)
#   - Non-Hodgkins lymphoma (prevalence: 0.0002)
#   - Epiphora (prevalence: 0.0001)
#   - Melanomas of skin (prevalence: 0.0003)
#   - Benign neoplasm of skin (prevalence: 0.0007)
#   - Actinic keratosis (prevalence: 0.0004)
#   - Other disorders of eyelids (prevalence: 0.0004)
#   - Other disorders of the kidney and ureters (prevalence: 0.0002)
#   - Acute upper respiratory infections of multiple or unspecified sites (prevalence: 0.0002)
#   - Acute appendicitis (prevalence: 0.0003)
#   - Abdominal pain (prevalence: 0.0012)
#   - Disorders of conjunctiva (prevalence: 0.0001)
#   - Chronic tonsillitis and adenoiditis (prevalence: 0.0001)
#   - Other tests (prevalence: 0.0003)
#   - Other hypertrophic and atrophic conditions of skin (prevalence: 0.0002)
#   - Osteopenia or other disorder of bone and cartilage (prevalence: 0.0001)
#   - Parkinson's disease (prevalence: 0.0002)
#   - Hypertensive chronic kidney disease (prevalence: 0.0002)
#   - Other non-epithelial cancer of skin (prevalence: 0.0013)
#   - Seborrheic keratosis (prevalence: 0.0004)
#   - Migraine (prevalence: 0.0004)
#   - Celiac disease (prevalence: 0.0002)
#   - Raynaud's syndrome (prevalence: 0.0002)
#   - Hearing loss (prevalence: 0.0007)
#   - Other benign neoplasm of connective and other soft tissue (prevalence: 0.0001)
#   - Inflammatory and toxic neuropathy (prevalence: 0.0003)
#   - Thyrotoxicosis with or without goiter (prevalence: 0.0002)
#   - Neoplasm of uncertain behavior (prevalence: 0.0002)
#   - Viral Enteritis (prevalence: 0.0001)
#   - Ptosis of eyelid (prevalence: 0.0002)
#   - Facial nerve disorders [CN7] (prevalence: 0.0001)
#   - Diseases of the larynx and vocal cords (prevalence: 0.0002)
#   - Ectropion or entropion (prevalence: 0.0002)
#   - Disorders of lacrimal system (prevalence: 0.0003)
#   - Perforation of tympanic membrane (prevalence: 0.0001)
#   - Bacterial enteritis (prevalence: 0.0003)
#   - Varicose veins of lower extremity (prevalence: 0.0008)
#   - Disturbances in tooth eruption (prevalence: 0.0001)
#   - Hemangioma and lymphangioma, any site (prevalence: 0.0002)
#   - Renal failure NOS (prevalence: 0.0002)
#   - Noninflammatory disorders of vulva and perineum (prevalence: 0.0001)
#   - Multiple sclerosis (prevalence: 0.0001)
#   - Allergic rhinitis (prevalence: 0.0003)
#   - Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue (prevalence: 0.0002)
#   - Benign neoplasm of breast (prevalence: 0.0001)
#   - Ganglion and cyst of synovium, tendon, and bursa (prevalence: 0.0003)
#   - Strabismus (not specified as paralytic) (prevalence: 0.0001)
#   - Scar conditions and fibrosis of skin (prevalence: 0.0002)
#   - Arrhythmia (cardiac) NOS (prevalence: 0.0002)
#   - Inflammation of eyelids (prevalence: 0.0002)
#   - Chronic glomerulonephritis, NOS (prevalence: 0.0001)
#   - Acute gastritis (prevalence: 0.0001)
#   - Periapical abscess (prevalence: 0.0001)
#   - Diseases and other conditions of the tongue (prevalence: 0.0001)
#   - Hypertrophy of breast (Gynecomastia) (prevalence: 0.0001)
#   - Chronic periodontitis (prevalence: 0.0001)
#   - Other symptoms/disorders or the urinary system (prevalence: 0.0001)
#   - Acute pharyngitis (prevalence: 0.0001)
#   - Infertility, female (prevalence: 0.0000)
#   - Lump or mass in breast (prevalence: 0.0001)
#   - Viral warts & HPV (prevalence: 0.0001)
#
# Cluster 6:
#   - Peritonitis and retroperitoneal infections (prevalence: 0.0001)
#   - Pulmonary heart disease (prevalence: 0.0006)
#   - Sebaceous cyst (prevalence: 0.0007)
#   - Other disorders of liver (prevalence: 0.0004)
#   - Cyst of kidney, acquired (prevalence: 0.0004)
#   - Other disorders of testis (prevalence: 0.0001)
#   - Umbilical hernia (prevalence: 0.0004)
#   - Epilepsy, recurrent seizures, convulsions (prevalence: 0.0004)
#   - Inguinal hernia (prevalence: 0.0015)
#   - Hydrocele (prevalence: 0.0001)
#   - Blood in stool (prevalence: 0.0003)
#   - Alcohol-related disorders (prevalence: 0.0007)
#   - Bipolar (prevalence: 0.0001)
#   - Sleep apnea (prevalence: 0.0007)
#   - Gout (prevalence: 0.0007)
#   - Disorder of skin and subcutaneous tissue NOS (prevalence: 0.0007)
#   - Other chronic nonalcoholic liver disease (prevalence: 0.0005)
#   - Contracture of palmar fascia [Dupuytren's disease] (prevalence: 0.0004)
#   - Atopic/contact dermatitis due to other or unspecified (prevalence: 0.0004)
#   - Other disorders of male genital organs (prevalence: 0.0003)
#   - Retinal vascular changes and abnomalities (prevalence: 0.0002)
#   - Duodenal ulcer (prevalence: 0.0003)
#   - Sleep disorders (prevalence: 0.0001)
#   - Lipoma (prevalence: 0.0002)
#   - Abdominal aortic aneurysm (prevalence: 0.0002)
#   - Bursitis (prevalence: 0.0001)
#   - Psoriasis vulgaris (prevalence: 0.0003)
#   - Alcoholic liver damage (prevalence: 0.0002)
#   - Hematemesis (prevalence: 0.0003)
#   - Redundant prepuce and phimosis/BXO (prevalence: 0.0003)
#   - Benign neoplasm of lip, oral cavity, and pharynx (prevalence: 0.0001)
#
# Cluster 7:
#   - Pneumonia (prevalence: 0.0008)
#   - Pneumococcal pneumonia (prevalence: 0.0012)
#   - Asthma (prevalence: 0.0031)
#   - Respiratory failure (prevalence: 0.0007)
#   - Pulmonary collapse; interstitial and compensatory emphysema (prevalence: 0.0007)
#   - Postinflammatory pulmonary fibrosis (prevalence: 0.0002)
#   - Tobacco use disorder (prevalence: 0.0016)
#   - Chronic airway obstruction (prevalence: 0.0013)
#   - Bronchiectasis (prevalence: 0.0004)
#   - Emphysema (prevalence: 0.0003)
#   - Obstructive chronic bronchitis (prevalence: 0.0005)
#   - Empyema and pneumothorax (prevalence: 0.0002)
#
# Cluster 8:
#   - Cataract (prevalence: 0.0025)
#   - Macular degeneration (senile) of retina NOS (prevalence: 0.0006)
#   - Myopia (prevalence: 0.0003)
#   - Senile cataract (prevalence: 0.0021)
#   - Disorders of vitreous body (prevalence: 0.0003)
#   - Primary open angle glaucoma (prevalence: 0.0002)
#   - Other retinal disorders (prevalence: 0.0002)
#   - Glaucoma (prevalence: 0.0008)
#   - Retinal detachment with retinal defect (prevalence: 0.0002)
#   - Retinal detachments and defects (prevalence: 0.0002)
#
# Cluster 9:
#   - Cerebral artery occlusion, with cerebral infarction (prevalence: 0.0004)
#   - Hemiplegia (prevalence: 0.0003)
#   - Late effects of cerebrovascular disease (prevalence: 0.0002)
#   - Occlusion of cerebral arteries (prevalence: 0.0003)
#   - Cerebral ischemia (prevalence: 0.0004)
#   - Cerebrovascular disease (prevalence: 0.0003)
#   - Transient cerebral ischemia (prevalence: 0.0003)
#   - Occlusion and stenosis of precerebral arteries (prevalence: 0.0002)
#
# Cluster 10:
#   - Type 2 diabetes (prevalence: 0.0029)
#   - Hypoglycemia (prevalence: 0.0002)
#   - Type 1 diabetes (prevalence: 0.0003)
#   - Diabetic retinopathy (prevalence: 0.0002)
#   - Type 2 diabetes with ophthalmic manifestations (prevalence: 0.0003)
#
# Cluster 11:
#   - Secondary malignancy of lymph nodes (prevalence: 0.0008)
#   - Secondary malignant neoplasm of liver (prevalence: 0.0005)
#   - Secondary malignancy of bone (prevalence: 0.0005)
#   - Malignant neoplasm of female breast (prevalence: 0.0010)
#   - Secondary malignancy of respiratory organs (prevalence: 0.0004)
#   - Malignant neoplasm, other (prevalence: 0.0003)
#   - Cancer of bronchus; lung (prevalence: 0.0004)
#   - Secondary malignant neoplasm (prevalence: 0.0003)
#   - Malignant neoplasm of ovary (prevalence: 0.0001)
#   - Secondary malignant neoplasm of digestive systems (prevalence: 0.0003)
#
# Cluster 12:
#   - Other upper respiratory disease (prevalence: 0.0004)
#   - Chronic pharyngitis and nasopharyngitis (prevalence: 0.0001)
#   - Septal Deviations/Turbinate Hypertrophy (prevalence: 0.0004)
#   - Chronic sinusitis (prevalence: 0.0003)
#   - Nasal polyps (prevalence: 0.0003)
#   - Otitis media (prevalence: 0.0001)
#
# Cluster 13:
#   - Decubitus ulcer (prevalence: 0.0004)
#   - Streptococcus infection (prevalence: 0.0003)
#   - Cellulitis and abscess of arm/hand (prevalence: 0.0008)
#   - Chronic ulcer of skin (prevalence: 0.0003)
#   - Other disorders of soft tissues (prevalence: 0.0008)
#   - Staphylococcus infections (prevalence: 0.0005)
#   - Carbuncle and furuncle (prevalence: 0.0003)
#   - Peripheral vascular disease, unspecified (prevalence: 0.0004)
#   - Phlebitis and thrombophlebitis of lower extremities (prevalence: 0.0005)
#   - Joint effusions (prevalence: 0.0002)
#   - Other local infections of skin and subcutaneous tissue (prevalence: 0.0002)
#   - Stricture of artery (prevalence: 0.0001)
#
# Cluster 14:
#   - Other specified gastritis (prevalence: 0.0014)
#   - Esophagitis, GERD and related diseases (prevalence: 0.0011)
#   - Gastritis and duodenitis (prevalence: 0.0022)
#   - Duodenitis (prevalence: 0.0010)
#   - GERD (prevalence: 0.0030)
#   - Benign neoplasm of other parts of digestive system (prevalence: 0.0010)
#   - Diaphragmatic hernia (prevalence: 0.0036)
#   - Stricture and stenosis of esophagus (prevalence: 0.0003)
#   - Esophageal bleeding (varices/hemorrhage) (prevalence: 0.0003)
#   - Barrett's esophagus (prevalence: 0.0005)
#   - Other disorders of stomach and duodenum (prevalence: 0.0006)
#   - Gastric ulcer (prevalence: 0.0006)
#   - Ulcer of esophagus (prevalence: 0.0006)
#   - Reflux esophagitis (prevalence: 0.0013)
#
# Cluster 15:
#   - Essential hypertension (prevalence: 0.0100)
#   - Hypercholesterolemia (prevalence: 0.0049)
#   - Coronary atherosclerosis (prevalence: 0.0025)
#   - Other chronic ischemic heart disease, unspecified (prevalence: 0.0022)
#   - Myocardial infarction (prevalence: 0.0017)
#   - Angina pectoris (prevalence: 0.0021)
#   - Unstable angina (intermediate coronary syndrome) (prevalence: 0.0006)
#   - Hyperlipidemia (prevalence: 0.0009)
#   - Other acute and subacute forms of ischemic heart disease (prevalence: 0.0003)
#
# Cluster 16:
#   - Thrombocytopenia (prevalence: 0.0002)
#   - Other anemias (prevalence: 0.0020)
#   - Hypovolemia (prevalence: 0.0008)
#   - Hypotension NOS (prevalence: 0.0008)
#   - Hyposmolality and/or hyponatremia (prevalence: 0.0007)
#   - Acute renal failure (prevalence: 0.0016)
#   - Candidiasis (prevalence: 0.0004)
#   - Constipation (prevalence: 0.0021)
#   - Bacterial infection NOS (prevalence: 0.0009)
#   - Urinary tract infection (prevalence: 0.0019)
#   - Other diseases of respiratory system, NEC (prevalence: 0.0011)
#   - Chronic renal failure [CKD] (prevalence: 0.0007)
#   - Orthostatic hypotension (prevalence: 0.0004)
#   - Hypopotassemia (prevalence: 0.0005)
#   - Gram negative septicemia (prevalence: 0.0002)
#   - Neutropenia (prevalence: 0.0005)
#   - Sepsis (prevalence: 0.0008)
#   - Acidosis (prevalence: 0.0003)
#   - E. coli (prevalence: 0.0005)
#   - Hyperpotassemia (prevalence: 0.0003)
#   - Pyelonephritis (prevalence: 0.0002)
#   - Disorders of calcium/phosphorus metabolism (prevalence: 0.0003)
#   - Bacterial pneumonia (prevalence: 0.0002)
#
# Cluster 17:
#   - Stricture/obstruction of ureter (prevalence: 0.0002)
#   - Hydronephrosis (prevalence: 0.0004)
#   - Calculus of ureter (prevalence: 0.0003)
#   - Renal colic (prevalence: 0.0001)
#   - Calculus of kidney (prevalence: 0.0004)
#
# Cluster 18:
#   - Gastrointestinal complications (prevalence: 0.0001)
#   - Diverticulosis (prevalence: 0.0042)
#   - Colon cancer (prevalence: 0.0005)
#   - Benign neoplasm of colon (prevalence: 0.0030)
#   - Iron deficiency anemias, unspecified or not due to blood loss (prevalence: 0.0015)
#   - Malignant neoplasm of rectum, rectosigmoid junction, and anus (prevalence: 0.0003)
#   - Hemorrhage of gastrointestinal tract (prevalence: 0.0009)
#   - Other disorders of intestine (prevalence: 0.0006)
#   - Hemorrhoids (prevalence: 0.0030)
#   - Anal and rectal conditions (prevalence: 0.0010)
#   - Other intestinal obstruction (prevalence: 0.0005)
#   - Ulcerative colitis (prevalence: 0.0004)
#   - Anal and rectal polyp (prevalence: 0.0011)
#   - Ventral hernia (prevalence: 0.0004)
#   - Regional enteritis (prevalence: 0.0002)
#   - Hemorrhage of rectum and anus (prevalence: 0.0012)
#   - Noninfectious gastroenteritis (prevalence: 0.0014)
#   - Neoplasm of unspecified nature of digestive system (prevalence: 0.0002)
#
# Cluster 19:
#   - Chronic prostatitis (prevalence: 0.0001)
#   - Hyperplasia of prostate (prevalence: 0.0017)
#   - Cancer of prostate (prevalence: 0.0009)
#   - Other disorders of prostate (prevalence: 0.0002)
#   - Bladder neck obstruction (prevalence: 0.0002)
#   - Other disorders of bladder (prevalence: 0.0011)
#   - Cystitis (prevalence: 0.0003)
#   - Urinary incontinence (prevalence: 0.0007)
#   - Urethral stricture (not specified as infectious) (prevalence: 0.0004)
#   - Malignant neoplasm of bladder (prevalence: 0.0003)
#   - Functional disorders of bladder (prevalence: 0.0002)
#   - Chronic cystitis (prevalence: 0.0001)

# %%
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(N, D, T, K, P, G, Y, prevalence_t,disease_names_list)
model.print_cluster_memberships()
model.plot_initial_params()

# %%
model.visualize_initialization()
model.psi

# %%
Y_tensor.shape

# %%
# Initialize model
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(N, D, T, K, P, G, Y, prevalence_t, disease_names_list)

# Store initial psi values
initial_psi = model.psi.detach().clone()
initial_phi=model.phi.detach().clone()
initial_lambda=model.lambda_.detach().clone()

history = model.fit(E_tensor, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2)

# Compare final vs initial psi
print("\nOverall psi changes:")

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history['max_grad_lambda'], label='Lambda')
ax2.plot(history['max_grad_phi'], label='Phi')
ax2.plot(history['max_grad_gamma'], label='Gamma')
ax2.plot(history['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
# Get the posterior phi values
phi_posterior = model.phi.detach().cpu().numpy()  # Shape should be [K, D, T]

# Create visualization
plt.figure(figsize=(15, 10))

# Plot phi trajectories for each cluster
for k in range(model.K):
    # Get diseases in this cluster
    cluster_mask = (model.clusters == k)
    cluster_phis = phi_posterior[k, cluster_mask, :]
    
    plt.subplot(4, 5, k+1)  # Adjust grid size based on number of clusters
    plt.plot(cluster_phis.T, alpha=0.3)  # Plot each disease trajectory
    plt.title(f'Cluster {k}\n({np.sum(cluster_mask)} diseases)')
    plt.grid(True)
    
plt.tight_layout()
plt.show()

# You might also want to see cluster means
plt.figure(figsize=(12, 6))
cluster_means = np.array([phi_posterior[k, model.clusters == k, :].mean(axis=0) 
                         for k in range(model.K)])
plt.plot(cluster_means.T)
plt.title('Mean Phi Trajectories by Cluster')
plt.xlabel('Time')
plt.ylabel('Phi Value')
plt.legend([f'Cluster {k}' for k in range(model.K)])
plt.grid(True)
plt.show()

# %%
import torch

# Save complete state for R
save_path = '/Users/sarahurbut/aladynoulli/pyScripts/model_complete_for_R_121_logitinit_nobg.pt'

torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'psi': model.psi,
    'Y': Y,
    'prevalence_t':prevalence_t,
    'G': G,
    'E': E,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': N,
        'D': D,
        'T': T,
        'P': P,
        'K': K
    }
}, save_path)

# %%
import numpy as np
import pandas as pd
import rpy2.robjects as robjects
from rpy2.robjects import numpy2ri
numpy2ri.activate()

# Extract key components from model
with torch.no_grad():
    pi_pred, theta, phi = model.forward()
    
# Convert tensors to numpy arrays - check type first
pi_pred = pi_pred.cpu().detach().numpy()
theta = theta.cpu().detach().numpy()
phi = model.phi.cpu().detach().numpy()
psi = model.psi.cpu().detach().numpy()
lambda_vals = model.lambda_.cpu().detach().numpy()

# These are already numpy arrays
clusters = model.clusters  # Already numpy


# Save components as .rds files
save_path = '/Users/sarahurbut/Dropbox (Personal)/aladynoulli/Rdata/'
# Main parameters
robjects.r.saveRDS(phi, f"{save_path}phi.rds")
robjects.r.saveRDS(psi, f"{save_path}psi.rds")
robjects.r.saveRDS(lambda_vals, f"{save_path}lambda.rds")
robjects.r.saveRDS(theta, f"{save_path}theta.rds")
robjects.r.saveRDS(pi_pred, f"{save_path}pi_pred.rds")
robjects.r.saveRDS(clusters, f"{save_path}clusters.rds")

# %%
robjects.r.saveRDS(Y, f"{save_path}Y.rds")
robjects.r.saveRDS(E, f"{save_path}E.rds")
robjects.r.saveRDS(G, f"{save_path}G.rds")

# %%
prevalence_t = checkpoint['prevalence_t']  # Get from checkpoint instead


robjects.r.saveRDS(prevalence_t, f"{save_path}prevalence_t.rds")

# %%
# Save disease names
robjects.r.saveRDS(checkpoint['disease_names'], f"{save_path}disease_names.rds")

# %%
# First load the saved state
#checkpoint = torch.load('/Users/sarahurbut/Dropbox (Personal)/model_complete_for_R_121_logitinit_nobg.pt')
checkpoint = torch.load('/Users/sarahurbut/Dropbox (Personal)/for10kanalysis/12model_complete_for_R_129_12.pt')
#checkpoint = torch.load('/Users/sarahurbut/Downloads/model_20241211_1749_in1_out-2_nIn0.1_nOut0.01.pt')
prevalence_t=checkpoint['prevalence_t']
disease_names=checkpoint['disease_names']
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_45390/1754967850.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/Users/sarahurbut/Dropbox (Personal)/for10kanalysis/12model_complete_for_R_129_12.pt')

# %%
#checkpoint = torch.load('/Users/sarahurbut/Downloads/model_complete.pt')
from cluster_g_logit_init_acceptpsi import *
# Create a new model instance with the same parameters
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=checkpoint['hyperparameters']['N'],
    D=checkpoint['hyperparameters']['D'],
    T=checkpoint['hyperparameters']['T'],
    K=checkpoint['hyperparameters']['K'],
    P=checkpoint['hyperparameters']['P'],
    G=checkpoint['G'],
    Y=checkpoint['Y'],
    prevalence_t=prevalence_t,
    disease_names=disease_names
)

# Load the saved state into the model
model.load_state_dict(checkpoint['model_state_dict'])
model.clusters = checkpoint['clusters']


# Generate predictions
with torch.no_grad():
    pi_pred, theta, phi = model.forward()
    pi_pred = pi_pred.cpu().numpy()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
#
# Cluster Sizes:
# Cluster 0: 11 diseases
# Cluster 1: 74 diseases
# Cluster 2: 30 diseases
# Cluster 3: 7 diseases
# Cluster 4: 23 diseases
# Cluster 5: 10 diseases
# Cluster 6: 17 diseases
# Cluster 7: 14 diseases
# Cluster 8: 21 diseases
# Cluster 9: 5 diseases
# Cluster 10: 8 diseases
# Cluster 11: 9 diseases
# Cluster 12: 12 diseases
# Cluster 13: 31 diseases
# Cluster 14: 25 diseases
# Cluster 15: 5 diseases
# Cluster 16: 9 diseases
# Cluster 17: 17 diseases
# Cluster 18: 11 diseases
# Cluster 19: 9 diseases
# Initialization complete!

# %%
model.disease_names
# Out:
# [np.str_('Bacterial enteritis'),
#  np.str_('Viral Enteritis'),
#  np.str_('Gram negative septicemia'),
#  np.str_('Bacterial infection NOS'),
#  np.str_('Staphylococcus infections'),
#  np.str_('Streptococcus infection'),
#  np.str_('E. coli'),
#  np.str_('Viral warts & HPV'),
#  np.str_('Viral infection'),
#  np.str_('Candidiasis'),
#  np.str_('Colon cancer'),
#  np.str_('Malignant neoplasm of rectum, rectosigmoid junction, and anus'),
#  np.str_('Neoplasm of unspecified nature of digestive system'),
#  np.str_('Cancer of bronchus; lung'),
#  np.str_('Melanomas of skin'),
#  np.str_('Other non-epithelial cancer of skin'),
#  np.str_('Breast cancer [female]'),
#  np.str_('Malignant neoplasm of female breast'),
#  np.str_('Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]'),
#  np.str_('Malignant neoplasm of uterus'),
#  np.str_('Malignant neoplasm of ovary'),
#  np.str_('Cancer of prostate'),
#  np.str_('Malignant neoplasm of kidney, except pelvis'),
#  np.str_('Malignant neoplasm of bladder'),
#  np.str_('Malignant neoplasm, other'),
#  np.str_('Secondary malignant neoplasm'),
#  np.str_('Secondary malignancy of lymph nodes'),
#  np.str_('Secondary malignancy of respiratory organs'),
#  np.str_('Secondary malignant neoplasm of digestive systems'),
#  np.str_('Secondary malignant neoplasm of liver'),
#  np.str_('Secondary malignancy of bone'),
#  np.str_('Neoplasm of uncertain behavior'),
#  np.str_('Non-Hodgkins lymphoma'),
#  np.str_('Benign neoplasm of colon'),
#  np.str_('Benign neoplasm of lip, oral cavity, and pharynx'),
#  np.str_('Benign neoplasm of other parts of digestive system'),
#  np.str_('Lipoma'),
#  np.str_('Lipoma of skin and subcutaneous tissue'),
#  np.str_('Other benign neoplasm of connective and other soft tissue'),
#  np.str_('Benign neoplasm of skin'),
#  np.str_('Uterine leiomyoma'),
#  np.str_('Benign neoplasm of ovary'),
#  np.str_('Hemangioma and lymphangioma, any site'),
#  np.str_('Thyrotoxicosis with or without goiter'),
#  np.str_('Secondary hypothyroidism'),
#  np.str_('Hypothyroidism NOS'),
#  np.str_('Type 1 diabetes'),
#  np.str_('Type 2 diabetes'),
#  np.str_('Type 2 diabetes with ophthalmic manifestations'),
#  np.str_('Diabetic retinopathy'),
#  np.str_('Hypoglycemia'),
#  np.str_('Hyperlipidemia'),
#  np.str_('Hypercholesterolemia'),
#  np.str_('Gout'),
#  np.str_('Disorders of calcium/phosphorus metabolism'),
#  np.str_('Hyposmolality and/or hyponatremia'),
#  np.str_('Hyperpotassemia'),
#  np.str_('Hypopotassemia'),
#  np.str_('Acidosis'),
#  np.str_('Hypovolemia'),
#  np.str_('Obesity'),
#  np.str_('Iron deficiency anemias, unspecified or not due to blood loss'),
#  np.str_('Other anemias'),
#  np.str_('Thrombocytopenia'),
#  np.str_('Neutropenia'),
#  np.str_('Bipolar'),
#  np.str_('Major depressive disorder'),
#  np.str_('Anxiety disorder'),
#  np.str_('Alcohol-related disorders'),
#  np.str_('Alcoholic liver damage'),
#  np.str_('Tobacco use disorder'),
#  np.str_('Sleep disorders'),
#  np.str_('Sleep apnea'),
#  np.str_("Parkinson's disease"),
#  np.str_('Degenerative disease of the spinal cord'),
#  np.str_('Multiple sclerosis'),
#  np.str_('Migraine'),
#  np.str_('Hemiplegia'),
#  np.str_('Epilepsy, recurrent seizures, convulsions'),
#  np.str_('Other peripheral nerve disorders'),
#  np.str_('Facial nerve disorders [CN7]'),
#  np.str_('Inflammatory and toxic neuropathy'),
#  np.str_('Retinal detachments and defects'),
#  np.str_('Retinal detachment with retinal defect'),
#  np.str_('Other retinal disorders'),
#  np.str_('Macular degeneration (senile) of retina NOS'),
#  np.str_('Retinal vascular changes and abnomalities'),
#  np.str_('Glaucoma'),
#  np.str_('Primary open angle glaucoma'),
#  np.str_('Cataract'),
#  np.str_('Senile cataract'),
#  np.str_('Myopia'),
#  np.str_('Visual disturbances'),
#  np.str_('Inflammation of eyelids'),
#  np.str_('Disorders of conjunctiva'),
#  np.str_('Other disorders of eyelids'),
#  np.str_('Ectropion or entropion'),
#  np.str_('Ptosis of eyelid'),
#  np.str_('Disorders of lacrimal system'),
#  np.str_('Epiphora'),
#  np.str_('Strabismus (not specified as paralytic)'),
#  np.str_('Disorders of vitreous body'),
#  np.str_('Otitis media'),
#  np.str_('Perforation of tympanic membrane'),
#  np.str_('Hearing loss'),
#  np.str_('Rheumatic disease of the heart valves'),
#  np.str_('Mitral valve disease'),
#  np.str_('Aortic valve disease'),
#  np.str_('Disease of tricuspid valve'),
#  np.str_('Essential hypertension'),
#  np.str_('Hypertensive chronic kidney disease'),
#  np.str_('Unstable angina (intermediate coronary syndrome)'),
#  np.str_('Myocardial infarction'),
#  np.str_('Angina pectoris'),
#  np.str_('Coronary atherosclerosis'),
#  np.str_('Other chronic ischemic heart disease, unspecified'),
#  np.str_('Other acute and subacute forms of ischemic heart disease'),
#  np.str_('Other forms of chronic heart disease'),
#  np.str_('Pulmonary heart disease'),
#  np.str_('Cardiomegaly'),
#  np.str_('Pericarditis'),
#  np.str_('Primary/intrinsic cardiomyopathies'),
#  np.str_('First degree AV block'),
#  np.str_('Right bundle branch block'),
#  np.str_('Left bundle branch block'),
#  np.str_('Paroxysmal supraventricular tachycardia'),
#  np.str_('Paroxysmal ventricular tachycardia'),
#  np.str_('Atrial fibrillation and flutter'),
#  np.str_('Cardiac arrest'),
#  np.str_('Arrhythmia (cardiac) NOS'),
#  np.str_('Congestive heart failure (CHF) NOS'),
#  np.str_('Heart failure NOS'),
#  np.str_('Cerebrovascular disease'),
#  np.str_('Occlusion and stenosis of precerebral arteries'),
#  np.str_('Occlusion of cerebral arteries'),
#  np.str_('Cerebral artery occlusion, with cerebral infarction'),
#  np.str_('Cerebral ischemia'),
#  np.str_('Transient cerebral ischemia'),
#  np.str_('Late effects of cerebrovascular disease'),
#  np.str_('Abdominal aortic aneurysm'),
#  np.str_("Raynaud's syndrome"),
#  np.str_('Peripheral vascular disease, unspecified'),
#  np.str_('Stricture of artery'),
#  np.str_('Phlebitis and thrombophlebitis of lower extremities'),
#  np.str_('Varicose veins of lower extremity'),
#  np.str_('Hemorrhoids'),
#  np.str_('Orthostatic hypotension'),
#  np.str_('Hypotension NOS'),
#  np.str_('Acute upper respiratory infections of multiple or unspecified sites'),
#  np.str_('Acute pharyngitis'),
#  np.str_('Septal Deviations/Turbinate Hypertrophy'),
#  np.str_('Nasal polyps'),
#  np.str_('Chronic pharyngitis and nasopharyngitis'),
#  np.str_('Diseases of the larynx and vocal cords'),
#  np.str_('Chronic tonsillitis and adenoiditis'),
#  np.str_('Chronic sinusitis'),
#  np.str_('Allergic rhinitis'),
#  np.str_('Other upper respiratory disease'),
#  np.str_('Pneumonia'),
#  np.str_('Bacterial pneumonia'),
#  np.str_('Pneumococcal pneumonia'),
#  np.str_('Asthma'),
#  np.str_('Chronic airway obstruction'),
#  np.str_('Emphysema'),
#  np.str_('Obstructive chronic bronchitis'),
#  np.str_('Bronchiectasis'),
#  np.str_('Postinflammatory pulmonary fibrosis'),
#  np.str_('Empyema and pneumothorax'),
#  np.str_('Pleurisy; pleural effusion'),
#  np.str_('Pulmonary collapse; interstitial and compensatory emphysema'),
#  np.str_('Respiratory failure'),
#  np.str_('Other diseases of respiratory system, NEC'),
#  np.str_('Disturbances in tooth eruption'),
#  np.str_('Dental caries'),
#  np.str_('Periapical abscess'),
#  np.str_('Chronic periodontitis'),
#  np.str_('Other diseases of the teeth and supporting structures'),
#  np.str_('Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue'),
#  np.str_('Diseases and other conditions of the tongue'),
#  np.str_('Esophagitis, GERD and related diseases'),
#  np.str_('GERD'),
#  np.str_('Ulcer of esophagus'),
#  np.str_("Barrett's esophagus"),
#  np.str_('Reflux esophagitis'),
#  np.str_('Esophageal bleeding (varices/hemorrhage)'),
#  np.str_('Stricture and stenosis of esophagus'),
#  np.str_('Gastric ulcer'),
#  np.str_('Duodenal ulcer'),
#  np.str_('Gastritis and duodenitis'),
#  np.str_('Acute gastritis'),
#  np.str_('Duodenitis'),
#  np.str_('Other specified gastritis'),
#  np.str_('Other disorders of stomach and duodenum'),
#  np.str_('Acute appendicitis'),
#  np.str_('Inguinal hernia'),
#  np.str_('Diaphragmatic hernia'),
#  np.str_('Umbilical hernia'),
#  np.str_('Ventral hernia'),
#  np.str_('Regional enteritis'),
#  np.str_('Ulcerative colitis'),
#  np.str_('Celiac disease'),
#  np.str_('Noninfectious gastroenteritis'),
#  np.str_('Other intestinal obstruction'),
#  np.str_('Diverticulosis'),
#  np.str_('Constipation'),
#  np.str_('Functional digestive disorders'),
#  np.str_('Irritable Bowel Syndrome'),
#  np.str_('Anal and rectal conditions'),
#  np.str_('Anal and rectal polyp'),
#  np.str_('Peritonitis and retroperitoneal infections'),
#  np.str_('Peritoneal adhesions (postoperative) (postinfection)'),
#  np.str_('Other disorders of intestine'),
#  np.str_('Gastrointestinal complications'),
#  np.str_('Other chronic nonalcoholic liver disease'),
#  np.str_('Other disorders of liver'),
#  np.str_('Cholelithiasis'),
#  np.str_('Cholelithiasis with acute cholecystitis'),
#  np.str_('Cholelithiasis with other cholecystitis'),
#  np.str_('Calculus of bile duct'),
#  np.str_('Cholecystitis without cholelithiasis'),
#  np.str_('Other disorders of gallbladder'),
#  np.str_('Other disorders of biliary tract'),
#  np.str_('Acute pancreatitis'),
#  np.str_('Hematemesis'),
#  np.str_('Blood in stool'),
#  np.str_('Hemorrhage of rectum and anus'),
#  np.str_('Hemorrhage of gastrointestinal tract'),
#  np.str_('Chronic glomerulonephritis, NOS'),
#  np.str_('Acute renal failure'),
#  np.str_('Renal failure NOS'),
#  np.str_('Chronic renal failure [CKD]'),
#  np.str_('Chronic Kidney Disease, Stage III'),
#  np.str_('Other disorders of the kidney and ureters'),
#  np.str_('Cyst of kidney, acquired'),
#  np.str_('Stricture/obstruction of ureter'),
#  np.str_('Pyelonephritis'),
#  np.str_('Urinary tract infection'),
#  np.str_('Cystitis'),
#  np.str_('Chronic cystitis'),
#  np.str_('Calculus of kidney'),
#  np.str_('Calculus of ureter'),
#  np.str_('Renal colic'),
#  np.str_('Hydronephrosis'),
#  np.str_('Other disorders of bladder'),
#  np.str_('Bladder neck obstruction'),
#  np.str_('Functional disorders of bladder'),
#  np.str_('Urethral stricture (not specified as infectious)'),
#  np.str_('Other symptoms/disorders or the urinary system'),
#  np.str_('Urinary incontinence'),
#  np.str_('Hyperplasia of prostate'),
#  np.str_('Chronic prostatitis'),
#  np.str_('Other disorders of prostate'),
#  np.str_('Other disorders of testis'),
#  np.str_('Hydrocele'),
#  np.str_('Redundant prepuce and phimosis/BXO'),
#  np.str_('Other disorders of male genital organs'),
#  np.str_('Benign neoplasm of breast'),
#  np.str_('Lump or mass in breast'),
#  np.str_('Hypertrophy of breast (Gynecomastia)'),
#  np.str_('Pelvic peritoneal adhesions, female (postoperative) (postinfection)'),
#  np.str_('Cervicitis and endocervicitis'),
#  np.str_('Endometriosis'),
#  np.str_('Prolapse of vaginal walls'),
#  np.str_('Uterine/Uterovaginal prolapse'),
#  np.str_('Disorders of uterus, NEC'),
#  np.str_('Noninflammatory disorders of cervix'),
#  np.str_('Noninflammatory disorders of vagina'),
#  np.str_('Noninflammatory disorders of vulva and perineum'),
#  np.str_('Endometrial hyperplasia'),
#  np.str_('Polyp of corpus uteri'),
#  np.str_('Mucous polyp of cervix'),
#  np.str_('Hypertrophy of female genital organs'),
#  np.str_('Pain and other symptoms associated with female genital organs'),
#  np.str_('Dyspareunia'),
#  np.str_('Disorders of menstruation and other abnormal bleeding from female genital tract'),
#  np.str_('Irregular menstrual cycle/bleeding'),
#  np.str_('Excessive or frequent menstruation'),
#  np.str_('Irregular menstrual cycle'),
#  np.str_('Irregular menstrual bleeding'),
#  np.str_('Dysmenorrhea'),
#  np.str_('Infertility, female'),
#  np.str_('Postmenopausal bleeding'),
#  np.str_('Postmenopausal atrophic vaginitis'),
#  np.str_('Ovarian cyst'),
#  np.str_('Cellulitis and abscess of arm/hand'),
#  np.str_('Other local infections of skin and subcutaneous tissue'),
#  np.str_('Carbuncle and furuncle'),
#  np.str_('Disorder of skin and subcutaneous tissue NOS'),
#  np.str_('Psoriasis vulgaris'),
#  np.str_('Other hypertrophic and atrophic conditions of skin'),
#  np.str_('Scar conditions and fibrosis of skin'),
#  np.str_('Actinic keratosis'),
#  np.str_('Seborrheic keratosis'),
#  np.str_('Ingrowing nail'),
#  np.str_('Sebaceous cyst'),
#  np.str_('Chronic ulcer of skin'),
#  np.str_('Decubitus ulcer'),
#  np.str_('Rheumatoid arthritis'),
#  np.str_('Other inflammatory spondylopathies'),
#  np.str_('Arthropathy NOS'),
#  np.str_('Polymyalgia Rheumatica'),
#  np.str_('Spinal stenosis'),
#  np.str_('Spondylosis and allied disorders'),
#  np.str_('Spondylosis without myelopathy'),
#  np.str_('Displacement of intervertebral disc'),
#  np.str_('Degeneration of intervertebral disc'),
#  np.str_('Other and unspecified disc disorder'),
#  np.str_('Peripheral enthesopathies and allied syndromes'),
#  np.str_('Enthesopathy'),
#  np.str_('Bursitis'),
#  np.str_('Other disorders of synovium, tendon, and bursa'),
#  np.str_('Synovitis and tenosynovitis'),
#  np.str_('Ganglion and cyst of synovium, tendon, and bursa'),
#  np.str_("Contracture of palmar fascia [Dupuytren's disease]"),
#  np.str_('Other disorders of soft tissues'),
#  np.str_('Rheumatism, unspecified and fibrositis'),
#  np.str_('Other disorders of bone and cartilage'),
#  np.str_('Malunion and nonunion of fracture'),
#  np.str_('Acquired toe deformities'),
#  np.str_('Hammer toe (acquired)'),
#  np.str_('Hallux rigidus'),
#  np.str_('Hallux valgus (Bunion)'),
#  np.str_('Other acquired deformities of limbs'),
#  np.str_('Kyphoscoliosis and scoliosis'),
#  np.str_('Acquired spondylolisthesis'),
#  np.str_('Osteoarthritis; localized'),
#  np.str_('Osteoarthrosis, localized, primary'),
#  np.str_('Osteoarthrosis, generalized'),
#  np.str_('Osteoarthrosis NOS'),
#  np.str_('Symptoms and disorders of the joints'),
#  np.str_('Joint effusions'),
#  np.str_('Other derangement of joint'),
#  np.str_('Osteoporosis NOS'),
#  np.str_('Osteopenia or other disorder of bone and cartilage'),
#  np.str_('Pain in joint'),
#  np.str_('Congenital anomalies of great vessels'),
#  np.str_('Back pain'),
#  np.str_('Cervicalgia'),
#  np.str_('Thoracic or lumbosacral neuritis or radiculitis, unspecified'),
#  np.str_('Sciatica'),
#  np.str_('Neuralgia, neuritis, and radiculitis NOS'),
#  np.str_('Myalgia and myositis unspecified'),
#  np.str_('Pain in limb'),
#  np.str_('Abdominal pain'),
#  np.str_('Internal derangement of knee'),
#  np.str_('Atopic/contact dermatitis due to other or unspecified'),
#  np.str_('Sepsis'),
#  np.str_('Other tests')]

# %%
model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:617: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Plot training loss history
plt.figure(figsize=(10, 5))
plt.plot(history['loss'])
plt.yscale('log')
plt.title('Training Loss Over Time')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.grid(True)
plt.show()

# Visualize psi map
plt.figure(figsize=(15, 8))
psi_np = model.psi.detach().numpy()
plt.imshow(psi_np, aspect='auto', cmap='RdBu_r')
plt.colorbar(label='ψ value')
plt.xlabel('Disease')
plt.ylabel('State/Cluster')
plt.title('Disease-State Deviations (ψ) After Mean Removal')

# If you have disease names, add them as x-axis labels
if disease_names_list:
    plt.xticks(range(len(disease_names_list)), disease_names_list, rotation=90)

plt.tight_layout()
plt.show()

# Print some summary statistics about psi
print("\nPsi Statistics:")
print(f"Mean: {psi_np.mean():.3f}")
print(f"Std: {psi_np.std():.3f}")
print(f"Min: {psi_np.min():.3f}")
print(f"Max: {psi_np.max():.3f}")

# Optionally, identify the strongest associations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 3
#       1 # Plot training loss history
#       2 plt.figure(figsize=(10, 5))
# ----> 3 plt.plot(history['loss'])
#       4 plt.yscale('log')
#       5 plt.title('Training Loss Over Time')
#
# NameError: name 'history' is not defined

# %%
model.Y.shape
# Out:
# torch.Size([10000, 348, 52])

# %%
psi_np = model.psi.detach().numpy()

# Print basic info about psi matrix
print("Psi matrix shape:", psi_np.shape)
print("\nPsi value ranges:")
print(f"Min: {psi_np.min():.3f}")
print(f"Max: {psi_np.max():.3f}")
print(f"Mean: {psi_np.mean():.3f}")
print(f"Std: {psi_np.std():.3f}")

# Look at a small sample of values
print("\nSample of psi values (first 5 states, first 5 diseases):")
print(psi_np[:5, :5])
# Out:
# Psi matrix shape: (20, 348)
#
# Psi value ranges:
# Min: -2.154
# Max: 1.318
# Mean: -1.849
# Std: 0.657
#
# Sample of psi values (first 5 states, first 5 diseases):
# [[-1.9065527 -1.9947097 -1.9564654 -2.1044474 -1.8967073]
#  [ 1.2052684  0.9746962 -2.0837352 -1.89868   -2.0929937]
#  [-1.9087886 -1.8967938  1.0590605  1.1446278 -1.9673743]
#  [-1.8997021 -2.1090684 -2.0979004 -1.8843557 -1.9062583]
#  [-1.9076873 -1.9720979 -1.8846953 -2.0660088 -2.1108828]]

# %%
model.lambda_.shape
# Out:
# torch.Size([50000, 20, 52])

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, model.disease_names)
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Retinal vascular changes and abnomalities: effect=1.869 (OR=6.48), std=0.418
# Other retinal disorders: effect=1.448 (OR=4.26), std=0.267
# Myopia: effect=1.313 (OR=3.72), std=0.643
# Retinal detachment with retinal defect: effect=1.310 (OR=3.71), std=0.200
# Glaucoma: effect=1.263 (OR=3.54), std=0.589
# Cataract: effect=1.161 (OR=3.19), std=0.349
# Disorders of vitreous body: effect=0.593 (OR=1.81), std=0.663
# Primary open angle glaucoma: effect=0.591 (OR=1.81), std=0.380
# Abdominal pain: effect=0.175 (OR=1.19), std=1.009
# Ptosis of eyelid: effect=0.170 (OR=1.19), std=0.557
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Bacterial enteritis: effect=3.062 (OR=21.37), std=0.438
# Facial nerve disorders [CN7]: effect=2.765 (OR=15.89), std=0.216
# Seborrheic keratosis: effect=2.109 (OR=8.24), std=0.299
# Other disorders of bone and cartilage: effect=2.052 (OR=7.78), std=0.506
# Acute upper respiratory infections of multiple or unspecified sites: effect=1.970 (OR=7.17), std=0.304
# Breast cancer [female]: effect=1.924 (OR=6.85), std=0.305
# Neoplasm of uncertain behavior: effect=1.846 (OR=6.33), std=0.452
# Sleep disorders: effect=1.753 (OR=5.77), std=0.403
# Acute appendicitis: effect=1.746 (OR=5.73), std=0.381
# Viral Enteritis: effect=1.655 (OR=5.23), std=0.692
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Chronic renal failure [CKD]: effect=2.585 (OR=13.26), std=1.000
# Malignant neoplasm of kidney, except pelvis: effect=2.060 (OR=7.85), std=0.486
# Cyst of kidney, acquired: effect=1.794 (OR=6.01), std=0.333
# Stricture/obstruction of ureter: effect=1.785 (OR=5.96), std=0.884
# Pyelonephritis: effect=1.589 (OR=4.90), std=0.585
# Chronic Kidney Disease, Stage III: effect=1.556 (OR=4.74), std=0.402
# Gram negative septicemia: effect=1.547 (OR=4.70), std=0.327
# Pulmonary collapse; interstitial and compensatory emphysema: effect=1.407 (OR=4.08), std=0.267
# Hypovolemia: effect=1.322 (OR=3.75), std=0.528
# Bacterial infection NOS: effect=1.215 (OR=3.37), std=0.855
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Other chronic ischemic heart disease, unspecified: effect=1.936 (OR=6.93), std=0.310
# Angina pectoris: effect=1.868 (OR=6.48), std=0.559
# Myocardial infarction: effect=1.386 (OR=4.00), std=0.622
# Other acute and subacute forms of ischemic heart disease: effect=1.278 (OR=3.59), std=0.184
# Unstable angina (intermediate coronary syndrome): effect=1.027 (OR=2.79), std=0.538
# Other forms of chronic heart disease: effect=0.819 (OR=2.27), std=0.802
# Hypercholesterolemia: effect=0.700 (OR=2.01), std=0.129
# Ulcerative colitis: effect=0.407 (OR=1.50), std=0.479
# Constipation: effect=0.376 (OR=1.46), std=0.902
# Occlusion of cerebral arteries: effect=0.107 (OR=1.11), std=0.443
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Cervicalgia: effect=2.842 (OR=17.14), std=0.400
# Other diseases of respiratory system, NEC: effect=2.350 (OR=10.48), std=1.017
# Urinary incontinence: effect=2.349 (OR=10.47), std=0.432
# Rheumatism, unspecified and fibrositis: effect=1.848 (OR=6.35), std=0.277
# Asthma: effect=1.783 (OR=5.95), std=0.265
# Other chronic nonalcoholic liver disease: effect=1.641 (OR=5.16), std=0.336
# Parkinson's disease: effect=1.619 (OR=5.05), std=0.390
# Hypothyroidism NOS: effect=1.454 (OR=4.28), std=0.880
# Viral infection: effect=1.449 (OR=4.26), std=0.397
# Irritable Bowel Syndrome: effect=1.375 (OR=3.96), std=0.553
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Urethral stricture (not specified as infectious): effect=2.005 (OR=7.43), std=0.831
# Other disorders of prostate: effect=1.926 (OR=6.86), std=0.272
# Functional disorders of bladder: effect=1.816 (OR=6.14), std=1.005
# Chronic cystitis: effect=0.969 (OR=2.63), std=0.459
# Cystitis: effect=0.497 (OR=1.64), std=0.838
# Hyperplasia of prostate: effect=0.113 (OR=1.12), std=0.726
# Bladder neck obstruction: effect=0.078 (OR=1.08), std=0.341
# Decubitus ulcer: effect=0.064 (OR=1.07), std=0.455
# Allergic rhinitis: effect=-0.001 (OR=1.00), std=1.039
# Malignant neoplasm of ovary: effect=-0.065 (OR=0.94), std=0.158
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Hemorrhage of gastrointestinal tract: effect=2.162 (OR=8.69), std=0.273
# Malignant neoplasm of rectum, rectosigmoid junction, and anus: effect=2.134 (OR=8.45), std=0.958
# Anal and rectal conditions: effect=1.565 (OR=4.78), std=0.235
# Other disorders of intestine: effect=1.209 (OR=3.35), std=0.819
# Benign neoplasm of colon: effect=0.707 (OR=2.03), std=0.492
# Diverticulosis: effect=0.684 (OR=1.98), std=0.789
# Anal and rectal polyp: effect=0.656 (OR=1.93), std=1.310
# Hemorrhoids: effect=0.646 (OR=1.91), std=0.273
# Noninfectious gastroenteritis: effect=0.477 (OR=1.61), std=0.271
# Ulcerative colitis: effect=0.442 (OR=1.56), std=0.509
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Gastric ulcer: effect=2.241 (OR=9.40), std=0.243
# Iron deficiency anemias, unspecified or not due to blood loss: effect=1.607 (OR=4.99), std=0.762
# Ulcer of esophagus: effect=1.580 (OR=4.85), std=0.206
# GERD: effect=1.505 (OR=4.50), std=0.141
# Duodenitis: effect=1.336 (OR=3.80), std=0.465
# Benign neoplasm of other parts of digestive system: effect=1.303 (OR=3.68), std=0.848
# Esophagitis, GERD and related diseases: effect=1.194 (OR=3.30), std=0.455
# Gastritis and duodenitis: effect=1.118 (OR=3.06), std=1.112
# Reflux esophagitis: effect=1.077 (OR=2.94), std=0.380
# Diaphragmatic hernia: effect=1.069 (OR=2.91), std=0.724
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Rheumatoid arthritis: effect=2.175 (OR=8.81), std=1.152
# Enthesopathy: effect=1.668 (OR=5.30), std=1.462
# Other disorders of synovium, tendon, and bursa: effect=1.655 (OR=5.23), std=0.038
# Other peripheral nerve disorders: effect=1.357 (OR=3.88), std=0.196
# Osteoarthrosis, localized, primary: effect=1.122 (OR=3.07), std=0.201
# Acquired toe deformities: effect=0.998 (OR=2.71), std=0.844
# Other derangement of joint: effect=0.982 (OR=2.67), std=0.684
# Transient cerebral ischemia: effect=0.980 (OR=2.66), std=0.761
# Obesity: effect=0.847 (OR=2.33), std=0.428
# Breast cancer [female]: effect=0.780 (OR=2.18), std=0.874
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Chronic sinusitis: effect=2.261 (OR=9.60), std=0.243
# Nasal polyps: effect=1.787 (OR=5.97), std=0.433
# Chronic pharyngitis and nasopharyngitis: effect=1.497 (OR=4.47), std=0.138
# Septal Deviations/Turbinate Hypertrophy: effect=1.262 (OR=3.53), std=0.470
# Other upper respiratory disease: effect=1.057 (OR=2.88), std=0.350
# Myocardial infarction: effect=0.599 (OR=1.82), std=0.640
# Other disorders of bladder: effect=0.256 (OR=1.29), std=1.054
# Bacterial infection NOS: effect=0.083 (OR=1.09), std=0.320
# Sleep disorders: effect=0.047 (OR=1.05), std=0.735
# Bronchiectasis: effect=-0.053 (OR=0.95), std=0.610
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Transient cerebral ischemia: effect=2.846 (OR=17.22), std=1.081
# Occlusion of cerebral arteries: effect=1.724 (OR=5.60), std=0.560
# Cerebral ischemia: effect=1.630 (OR=5.11), std=0.980
# Hemiplegia: effect=1.479 (OR=4.39), std=0.300
# Occlusion and stenosis of precerebral arteries: effect=1.340 (OR=3.82), std=0.383
# Late effects of cerebrovascular disease: effect=1.277 (OR=3.59), std=0.370
# Cerebral artery occlusion, with cerebral infarction: effect=0.796 (OR=2.22), std=0.274
# Cerebrovascular disease: effect=0.281 (OR=1.33), std=0.476
# Acute upper respiratory infections of multiple or unspecified sites: effect=0.211 (OR=1.23), std=0.658
# Melanomas of skin: effect=0.114 (OR=1.12), std=0.397
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Cholelithiasis with acute cholecystitis: effect=1.808 (OR=6.10), std=0.562
# Calculus of bile duct: effect=1.202 (OR=3.33), std=0.519
# Peritoneal adhesions (postoperative) (postinfection): effect=0.841 (OR=2.32), std=0.253
# Other disorders of biliary tract: effect=0.637 (OR=1.89), std=0.385
# Cholecystitis without cholelithiasis: effect=0.582 (OR=1.79), std=0.096
# Acute pancreatitis: effect=0.530 (OR=1.70), std=0.690
# Carbuncle and furuncle: effect=0.298 (OR=1.35), std=0.182
# Abdominal pain: effect=0.127 (OR=1.14), std=0.929
# Cholelithiasis with other cholecystitis: effect=0.096 (OR=1.10), std=0.810
# Epilepsy, recurrent seizures, convulsions: effect=-0.059 (OR=0.94), std=0.758
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Neuralgia, neuritis, and radiculitis NOS: effect=1.932 (OR=6.90), std=0.872
# Other and unspecified disc disorder: effect=1.313 (OR=3.72), std=0.487
# Back pain: effect=1.234 (OR=3.43), std=0.148
# Spinal stenosis: effect=1.184 (OR=3.27), std=0.430
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=1.095 (OR=2.99), std=0.955
# Spondylosis without myelopathy: effect=0.975 (OR=2.65), std=0.916
# Degenerative disease of the spinal cord: effect=0.792 (OR=2.21), std=0.714
# Displacement of intervertebral disc: effect=0.708 (OR=2.03), std=0.349
# Degeneration of intervertebral disc: effect=0.638 (OR=1.89), std=0.916
# Other inflammatory spondylopathies: effect=0.214 (OR=1.24), std=0.578
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Candidiasis: effect=2.051 (OR=7.78), std=0.233
# Sleep apnea: effect=1.921 (OR=6.83), std=0.171
# Gout: effect=1.844 (OR=6.32), std=0.687
# Ingrowing nail: effect=1.732 (OR=5.65), std=0.249
# Cellulitis and abscess of arm/hand: effect=1.723 (OR=5.60), std=0.462
# Inflammatory and toxic neuropathy: effect=1.579 (OR=4.85), std=1.093
# Cancer of prostate: effect=1.571 (OR=4.81), std=0.287
# Other local infections of skin and subcutaneous tissue: effect=1.533 (OR=4.63), std=0.388
# Other disorders of male genital organs: effect=1.512 (OR=4.54), std=0.325
# Varicose veins of lower extremity: effect=1.502 (OR=4.49), std=0.773
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Irregular menstrual cycle/bleeding: effect=2.771 (OR=15.98), std=0.302
# Pelvic peritoneal adhesions, female (postoperative) (postinfection): effect=2.609 (OR=13.59), std=0.310
# Disorders of uterus, NEC: effect=2.225 (OR=9.25), std=0.240
# Disorders of menstruation and other abnormal bleeding from female genital tract: effect=1.607 (OR=4.99), std=1.153
# Postmenopausal bleeding: effect=1.545 (OR=4.69), std=0.325
# Endometriosis: effect=1.339 (OR=3.81), std=0.841
# Prolapse of vaginal walls: effect=1.249 (OR=3.49), std=0.779
# Hypertrophy of female genital organs: effect=1.169 (OR=3.22), std=0.306
# Cervicitis and endocervicitis: effect=1.106 (OR=3.02), std=0.853
# Pain and other symptoms associated with female genital organs: effect=1.094 (OR=2.99), std=0.482
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Type 2 diabetes with ophthalmic manifestations: effect=1.847 (OR=6.34), std=0.251
# Type 2 diabetes: effect=1.519 (OR=4.57), std=0.404
# Type 1 diabetes: effect=1.450 (OR=4.26), std=0.427
# Diabetic retinopathy: effect=0.739 (OR=2.09), std=0.436
# Hypoglycemia: effect=0.548 (OR=1.73), std=0.354
# Viral warts & HPV: effect=-0.129 (OR=0.88), std=0.586
# Cerebrovascular disease: effect=-0.136 (OR=0.87), std=0.521
# Other forms of chronic heart disease: effect=-0.156 (OR=0.86), std=0.747
# Secondary malignancy of respiratory organs: effect=-0.156 (OR=0.86), std=0.938
# Retinal detachment with retinal defect: effect=-0.248 (OR=0.78), std=0.458
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Alcoholic liver damage: effect=2.345 (OR=10.43), std=0.331
# Other disorders of liver: effect=2.061 (OR=7.86), std=0.406
# Esophageal bleeding (varices/hemorrhage): effect=1.674 (OR=5.34), std=0.906
# Hematemesis: effect=1.442 (OR=4.23), std=0.187
# Blood in stool: effect=1.370 (OR=3.93), std=0.261
# Alcohol-related disorders: effect=0.845 (OR=2.33), std=0.154
# Hypopotassemia: effect=0.788 (OR=2.20), std=0.156
# Thrombocytopenia: effect=0.387 (OR=1.47), std=0.342
# Renal failure NOS: effect=0.353 (OR=1.42), std=1.276
# First degree AV block: effect=0.350 (OR=1.42), std=0.490
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Paroxysmal supraventricular tachycardia: effect=2.777 (OR=16.07), std=0.420
# Rheumatic disease of the heart valves: effect=2.460 (OR=11.71), std=0.707
# Congenital anomalies of great vessels: effect=1.835 (OR=6.26), std=0.324
# Atrial fibrillation and flutter: effect=1.366 (OR=3.92), std=0.260
# Paroxysmal ventricular tachycardia: effect=1.348 (OR=3.85), std=1.179
# Heart failure NOS: effect=1.328 (OR=3.78), std=0.484
# Aortic valve disease: effect=1.016 (OR=2.76), std=0.384
# Cardiomegaly: effect=0.965 (OR=2.63), std=0.533
# Pleurisy; pleural effusion: effect=0.938 (OR=2.55), std=0.290
# Other forms of chronic heart disease: effect=0.867 (OR=2.38), std=0.768
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Pneumonia: effect=3.101 (OR=22.22), std=0.337
# Cancer of bronchus; lung: effect=2.239 (OR=9.38), std=0.242
# Respiratory failure: effect=1.545 (OR=4.69), std=0.079
# Obstructive chronic bronchitis: effect=1.390 (OR=4.02), std=0.736
# Postinflammatory pulmonary fibrosis: effect=1.382 (OR=3.98), std=0.912
# Empyema and pneumothorax: effect=1.192 (OR=3.29), std=0.351
# Bronchiectasis: effect=1.070 (OR=2.92), std=0.352
# Emphysema: effect=0.790 (OR=2.20), std=0.845
# Chronic airway obstruction: effect=0.662 (OR=1.94), std=0.464
# Sepsis: effect=0.425 (OR=1.53), std=0.384
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Neutropenia: effect=1.964 (OR=7.12), std=0.266
# Malignant neoplasm of ovary: effect=1.150 (OR=3.16), std=0.365
# Secondary malignancy of lymph nodes: effect=0.874 (OR=2.40), std=0.732
# Secondary malignancy of bone: effect=0.780 (OR=2.18), std=0.177
# Malignant neoplasm, other: effect=0.446 (OR=1.56), std=0.459
# Secondary malignancy of respiratory organs: effect=0.302 (OR=1.35), std=0.496
# Hemangioma and lymphangioma, any site: effect=0.241 (OR=1.27), std=0.749
# Secondary malignant neoplasm: effect=0.213 (OR=1.24), std=1.028
# Secondary malignant neoplasm of liver: effect=-0.005 (OR=1.00), std=0.480
# Non-Hodgkins lymphoma: effect=-0.066 (OR=0.94), std=0.048

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, disease_names_list)
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Other acute and subacute forms of ischemic heart disease: 1.126
# 2. Stricture of artery: 1.116
# 3. Malignant neoplasm of ovary: 1.109
# 4. Obstructive chronic bronchitis: 1.074
# 5. Occlusion and stenosis of precerebral arteries: 1.069
# 6. Hypertrophy of breast (Gynecomastia): 1.044
# 7. Chronic periodontitis: 1.015
# 8. Empyema and pneumothorax: 0.978
# 9. Right bundle branch block: 0.971
# 10. Other diseases of respiratory system, NEC: 0.964
#
# Final top diseases:
# 1. Stricture of artery: 2.299
# 2. Chronic periodontitis: 1.662
# 3. Obstructive chronic bronchitis: 1.278
# 4. Right bundle branch block: 1.194
# 5. Otitis media: 0.975
# 6. Bursitis: 0.943
# 7. Displacement of intervertebral disc: 0.725
# 8. Other diseases of respiratory system, NEC: 0.606
# 9. Malignant neoplasm of ovary: 0.490
# 10. Occlusion and stenosis of precerebral arteries: 0.324
#
# Occlusion and stenosis of precerebral arteries changed from rank 5 to 10
#
# Hypertrophy of breast (Gynecomastia) changed from rank 6 to 12
#
# Otitis media changed from rank 12 to 5
#
# Chronic periodontitis changed from rank 7 to 2
#
# Malignant neoplasm of ovary changed from rank 3 to 9
#
# Displacement of intervertebral disc changed from rank 12 to 7
#
# Other acute and subacute forms of ischemic heart disease changed from rank 1 to 12
#
# Empyema and pneumothorax changed from rank 8 to 12
#
# Bursitis changed from rank 12 to 6
#
# Right bundle branch block changed from rank 9 to 4
#
# Signature 1:
#
# Initial top diseases:
# 1. Other acquired deformities of limbs: 1.153
# 2. Degeneration of intervertebral disc: 1.111
# 3. Retinal detachments and defects: 1.098
# 4. Pneumococcal pneumonia: 1.097
# 5. Renal failure NOS: 1.047
# 6. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.040
# 7. Other and unspecified disc disorder: 1.034
# 8. Phlebitis and thrombophlebitis of lower extremities: 1.030
# 9. Bacterial enteritis: 1.029
# 10. Paroxysmal ventricular tachycardia: 1.024
#
# Final top diseases:
# 1. Bacterial enteritis: 2.873
# 2. Cervicalgia: 2.527
# 3. Cardiac arrest: 2.105
# 4. Cholelithiasis: 1.917
# 5. Renal colic: 1.773
# 6. Pneumococcal pneumonia: 1.593
# 7. Paroxysmal ventricular tachycardia: 1.554
# 8. Renal failure NOS: 1.438
# 9. Retinal detachments and defects: 1.403
# 10. Noninflammatory disorders of vulva and perineum: 1.374
#
# Bacterial enteritis changed from rank 9 to 1
#
# Phlebitis and thrombophlebitis of lower extremities changed from rank 8 to 12
#
# Other and unspecified disc disorder changed from rank 7 to 12
#
# Thoracic or lumbosacral neuritis or radiculitis, unspecified changed from rank 6 to 12
#
# Degeneration of intervertebral disc changed from rank 2 to 12
#
# Renal colic changed from rank 12 to 5
#
# Renal failure NOS changed from rank 5 to 8
#
# Retinal detachments and defects changed from rank 3 to 9
#
# Cardiac arrest changed from rank 12 to 3
#
# Paroxysmal ventricular tachycardia changed from rank 10 to 7
#
# Other acquired deformities of limbs changed from rank 1 to 12
#
# Cervicalgia changed from rank 12 to 2
#
# Cholelithiasis changed from rank 12 to 4
#
# Signature 2:
#
# Initial top diseases:
# 1. Disorders of calcium/phosphorus metabolism: 1.211
# 2. Coronary atherosclerosis: 1.050
# 3. GERD: 1.026
# 4. Endometrial hyperplasia: 1.022
# 5. Type 2 diabetes with ophthalmic manifestations: 1.014
# 6. Acute pancreatitis: 1.005
# 7. Other retinal disorders: 0.962
# 8. Neoplasm of uncertain behavior: 0.956
# 9. Diabetic retinopathy: 0.903
# 10. Cervicitis and endocervicitis: 0.886
#
# Final top diseases:
# 1. Disorders of calcium/phosphorus metabolism: 2.907
# 2. Other retinal disorders: 2.861
# 3. Coronary atherosclerosis: 2.356
# 4. Endometrial hyperplasia: 1.804
# 5. Sepsis: 1.714
# 6. Type 2 diabetes with ophthalmic manifestations: 1.490
# 7. Neoplasm of uncertain behavior: 1.373
# 8. Diabetic retinopathy: 1.042
# 9. Acute pancreatitis: 1.040
# 10. GERD: 0.884
#
# Other retinal disorders changed from rank 7 to 2
#
# Sepsis changed from rank 12 to 5
#
# Acute pancreatitis changed from rank 6 to 9
#
# GERD changed from rank 3 to 10
#
# Signature 3:
#
# Initial top diseases:
# 1. Myocardial infarction: 1.097
# 2. Disorders of vitreous body: 1.087
# 3. Other chronic ischemic heart disease, unspecified: 1.051
# 4. Synovitis and tenosynovitis: 1.041
# 5. Anal and rectal conditions: 1.020
# 6. Unstable angina (intermediate coronary syndrome): 1.000
# 7. Angina pectoris: 0.883
# 8. Endometrial hyperplasia: -1.975
# 9. Osteoarthrosis NOS: -1.975
# 10. Dyspareunia: -1.975
#
# Final top diseases:
# 1. Anal and rectal conditions: 2.188
# 2. Synovitis and tenosynovitis: 2.085
# 3. Disorders of vitreous body: 1.922
# 4. Angina pectoris: 1.151
# 5. Other chronic ischemic heart disease, unspecified: 1.029
# 6. Disorder of skin and subcutaneous tissue NOS: 0.767
# 7. Urinary incontinence: 0.474
# 8. Unstable angina (intermediate coronary syndrome): 0.347
# 9. Myocardial infarction: 0.047
# 10. Bronchiectasis: -0.202
#
# Osteoarthrosis NOS changed from rank 9 to 12
#
# Disorder of skin and subcutaneous tissue NOS changed from rank 12 to 6
#
# Urinary incontinence changed from rank 12 to 7
#
# Endometrial hyperplasia changed from rank 8 to 12
#
# Myocardial infarction changed from rank 1 to 9
#
# Angina pectoris changed from rank 7 to 4
#
# Anal and rectal conditions changed from rank 5 to 1
#
# Signature 4:
#
# Initial top diseases:
# 1. Acidosis: 1.181
# 2. Hypothyroidism NOS: 1.092
# 3. Respiratory failure: 1.084
# 4. Ulcerative colitis: 1.082
# 5. Blood in stool: 1.047
# 6. Stricture/obstruction of ureter: 1.029
# 7. Streptococcus infection: 0.993
# 8. Anal and rectal polyp: 0.991
# 9. Pulmonary collapse; interstitial and compensatory emphysema: 0.947
# 10. Congenital anomalies of great vessels: 0.933
#
# Final top diseases:
# 1. Neutropenia: 2.566
# 2. Congenital anomalies of great vessels: 2.126
# 3. Streptococcus infection: 1.787
# 4. Respiratory failure: 1.342
# 5. Blood in stool: 1.114
# 6. Osteoarthrosis NOS: 0.966
# 7. Ulcerative colitis: 0.891
# 8. Rheumatoid arthritis: 0.804
# 9. Viral infection: 0.735
# 10. Hypothyroidism NOS: 0.664
#
# Acidosis changed from rank 1 to 12
#
# Stricture/obstruction of ureter changed from rank 6 to 12
#
# Osteoarthrosis NOS changed from rank 12 to 6
#
# Neutropenia changed from rank 12 to 1
#
# Streptococcus infection changed from rank 7 to 3
#
# Congenital anomalies of great vessels changed from rank 10 to 2
#
# Hypothyroidism NOS changed from rank 2 to 10
#
# Ulcerative colitis changed from rank 4 to 7
#
# Anal and rectal polyp changed from rank 8 to 12
#
# Pulmonary collapse; interstitial and compensatory emphysema changed from rank 9 to 12
#
# Viral infection changed from rank 12 to 9
#
# Rheumatoid arthritis changed from rank 12 to 8
#
# Signature 5:
#
# Initial top diseases:
# 1. Scar conditions and fibrosis of skin: 1.208
# 2. Cholecystitis without cholelithiasis: 1.200
# 3. Malunion and nonunion of fracture: 1.176
# 4. Benign neoplasm of colon: 1.152
# 5. Chronic cystitis: 1.144
# 6. Hypertrophy of female genital organs: 1.140
# 7. Orthostatic hypotension: 1.138
# 8. Secondary malignancy of respiratory organs: 1.135
# 9. Gastrointestinal complications: 1.132
# 10. Uterine/Uterovaginal prolapse: 1.129
#
# Final top diseases:
# 1. Other disorders of bladder: 2.760
# 2. Dysmenorrhea: 2.520
# 3. Uterine leiomyoma: 2.384
# 4. Rheumatic disease of the heart valves: 2.255
# 5. Benign neoplasm of colon: 2.020
# 6. Pelvic peritoneal adhesions, female (postoperative) (postinfection): 2.016
# 7. Other diseases of the teeth and supporting structures: 1.932
# 8. Late effects of cerebrovascular disease: 1.901
# 9. Chronic Kidney Disease, Stage III: 1.896
# 10. Malignant neoplasm of uterus: 1.887
#
# Rheumatic disease of the heart valves changed from rank 12 to 4
#
# Gastrointestinal complications changed from rank 9 to 12
#
# Chronic Kidney Disease, Stage III changed from rank 12 to 9
#
# Secondary malignancy of respiratory organs changed from rank 8 to 12
#
# Other diseases of the teeth and supporting structures changed from rank 12 to 7
#
# Uterine leiomyoma changed from rank 12 to 3
#
# Pelvic peritoneal adhesions, female (postoperative) (postinfection) changed from rank 12 to 6
#
# Other disorders of bladder changed from rank 12 to 1
#
# Orthostatic hypotension changed from rank 7 to 12
#
# Chronic cystitis changed from rank 5 to 12
#
# Scar conditions and fibrosis of skin changed from rank 1 to 12
#
# Late effects of cerebrovascular disease changed from rank 12 to 8
#
# Dysmenorrhea changed from rank 12 to 2
#
# Cholecystitis without cholelithiasis changed from rank 2 to 12
#
# Hypertrophy of female genital organs changed from rank 6 to 12
#
# Malunion and nonunion of fracture changed from rank 3 to 12
#
# Signature 6:
#
# Initial top diseases:
# 1. Chronic ulcer of skin: 1.179
# 2. Disorder of skin and subcutaneous tissue NOS: 1.042
# 3. Congestive heart failure (CHF) NOS: 0.983
# 4. Other disorders of soft tissues: 0.905
# 5. Acute upper respiratory infections of multiple or unspecified sites: 0.854
# 6. Type 1 diabetes: -1.972
# 7. Alcoholic liver damage: -1.972
# 8. Other anemias: -1.975
# 9. Rheumatism, unspecified and fibrositis: -1.976
# 10. Infertility, female: -1.978
#
# Final top diseases:
# 1. Acute upper respiratory infections of multiple or unspecified sites: 2.376
# 2. Other disorders of soft tissues: 1.582
# 3. Chronic ulcer of skin: 0.767
# 4. Disorder of skin and subcutaneous tissue NOS: 0.728
# 5. Gastritis and duodenitis: 0.221
# 6. Hypopotassemia: 0.186
# 7. Osteopenia or other disorder of bone and cartilage: 0.174
# 8. Congestive heart failure (CHF) NOS: 0.007
# 9. Benign neoplasm of other parts of digestive system: -0.129
# 10. Urethral stricture (not specified as infectious): -0.245
#
# Alcoholic liver damage changed from rank 7 to 12
#
# Other anemias changed from rank 8 to 12
#
# Benign neoplasm of other parts of digestive system changed from rank 12 to 9
#
# Type 1 diabetes changed from rank 6 to 12
#
# Congestive heart failure (CHF) NOS changed from rank 3 to 8
#
# Rheumatism, unspecified and fibrositis changed from rank 9 to 12
#
# Acute upper respiratory infections of multiple or unspecified sites changed from rank 5 to 1
#
# Hypopotassemia changed from rank 12 to 6
#
# Gastritis and duodenitis changed from rank 12 to 5
#
# Osteopenia or other disorder of bone and cartilage changed from rank 12 to 7
#
# Signature 7:
#
# Initial top diseases:
# 1. Neuralgia, neuritis, and radiculitis NOS: 1.156
# 2. Acute gastritis: 1.103
# 3. Periapical abscess: 1.098
# 4. Hematemesis: 1.096
# 5. Other disorders of gallbladder: 1.090
# 6. Arrhythmia (cardiac) NOS: 1.083
# 7. Other symptoms/disorders or the urinary system: 1.066
# 8. Irregular menstrual bleeding: 1.044
# 9. Nasal polyps: 1.041
# 10. Enthesopathy: 1.024
#
# Final top diseases:
# 1. Disorders of menstruation and other abnormal bleeding from female genital tract: 3.712
# 2. Strabismus (not specified as paralytic): 2.715
# 3. Cholelithiasis with acute cholecystitis: 2.329
# 4. Diseases and other conditions of the tongue: 2.308
# 5. Neuralgia, neuritis, and radiculitis NOS: 2.276
# 6. Nasal polyps: 1.764
# 7. Other symptoms/disorders or the urinary system: 1.613
# 8. Irregular menstrual bleeding: 1.453
# 9. Enthesopathy: 1.452
# 10. Other disorders of gallbladder: 1.252
#
# Nasal polyps changed from rank 9 to 6
#
# Other disorders of gallbladder changed from rank 5 to 10
#
# Acute gastritis changed from rank 2 to 12
#
# Hematemesis changed from rank 4 to 12
#
# Periapical abscess changed from rank 3 to 12
#
# Diseases and other conditions of the tongue changed from rank 12 to 4
#
# Strabismus (not specified as paralytic) changed from rank 12 to 2
#
# Neuralgia, neuritis, and radiculitis NOS changed from rank 1 to 5
#
# Arrhythmia (cardiac) NOS changed from rank 6 to 12
#
# Disorders of menstruation and other abnormal bleeding from female genital tract changed from rank 12 to 1
#
# Cholelithiasis with acute cholecystitis changed from rank 12 to 3
#
# Signature 8:
#
# Initial top diseases:
# 1. Redundant prepuce and phimosis/BXO: 1.224
# 2. Regional enteritis: 1.163
# 3. Osteoporosis NOS: 1.126
# 4. Decubitus ulcer: 1.100
# 5. Acquired toe deformities: 1.075
# 6. Type 1 diabetes: 1.066
# 7. Other disorders of testis: 1.055
# 8. Neoplasm of unspecified nature of digestive system: 0.990
# 9. Sciatica: 0.980
# 10. Osteoarthritis; localized: 0.930
#
# Final top diseases:
# 1. Hammer toe (acquired): 2.313
# 2. Decubitus ulcer: 1.989
# 3. Major depressive disorder: 1.427
# 4. Neoplasm of unspecified nature of digestive system: 1.342
# 5. Polymyalgia Rheumatica: 1.340
# 6. Acquired toe deformities: 1.155
# 7. Other disorders of testis: 0.997
# 8. Osteoporosis NOS: 0.868
# 9. Bladder neck obstruction: 0.833
# 10. Redundant prepuce and phimosis/BXO: 0.792
#
# Polymyalgia Rheumatica changed from rank 12 to 5
#
# Osteoporosis NOS changed from rank 3 to 8
#
# Bladder neck obstruction changed from rank 12 to 9
#
# Redundant prepuce and phimosis/BXO changed from rank 1 to 10
#
# Regional enteritis changed from rank 2 to 12
#
# Neoplasm of unspecified nature of digestive system changed from rank 8 to 4
#
# Type 1 diabetes changed from rank 6 to 12
#
# Major depressive disorder changed from rank 12 to 3
#
# Hammer toe (acquired) changed from rank 12 to 1
#
# Sciatica changed from rank 9 to 12
#
# Signature 9:
#
# Initial top diseases:
# 1. Postinflammatory pulmonary fibrosis: 1.226
# 2. Lipoma of skin and subcutaneous tissue: 1.090
# 3. Breast cancer [female]: 1.081
# 4. Other disorders of biliary tract: 1.062
# 5. Cellulitis and abscess of arm/hand: 1.025
# 6. Esophageal bleeding (varices/hemorrhage): 1.015
# 7. Bipolar: 0.986
# 8. Alcohol-related disorders: 0.855
# 9. Postmenopausal bleeding: -1.975
# 10. Orthostatic hypotension: -1.976
#
# Final top diseases:
# 1. Alcohol-related disorders: 1.530
# 2. Esophageal bleeding (varices/hemorrhage): 1.262
# 3. Cellulitis and abscess of arm/hand: 1.259
# 4. Bipolar: 0.825
# 5. Other disorders of biliary tract: 0.738
# 6. Breast cancer [female]: 0.702
# 7. Postinflammatory pulmonary fibrosis: 0.688
# 8. Lipoma of skin and subcutaneous tissue: 0.560
# 9. Ulcerative colitis: -0.097
# 10. Other disorders of liver: -0.145
#
# Esophageal bleeding (varices/hemorrhage) changed from rank 6 to 2
#
# Alcohol-related disorders changed from rank 8 to 1
#
# Bipolar changed from rank 7 to 4
#
# Lipoma of skin and subcutaneous tissue changed from rank 2 to 8
#
# Postinflammatory pulmonary fibrosis changed from rank 1 to 7
#
# Breast cancer [female] changed from rank 3 to 6
#
# Postmenopausal bleeding changed from rank 9 to 12
#
# Ulcerative colitis changed from rank 12 to 9
#
# Signature 10:
#
# Initial top diseases:
# 1. Disorders of uterus, NEC: 1.243
# 2. Pain in limb: 1.215
# 3. Cystitis: 1.054
# 4. Acute appendicitis: 1.008
# 5. Other tests: 0.993
# 6. Other upper respiratory disease: 0.969
# 7. Urinary incontinence: 0.966
# 8. Abdominal pain: 0.947
# 9. Chronic tonsillitis and adenoiditis: 0.943
# 10. Other disorders of stomach and duodenum: 0.886
#
# Final top diseases:
# 1. Other upper respiratory disease: 2.405
# 2. Hypotension NOS: 1.958
# 3. Other disorders of stomach and duodenum: 1.678
# 4. Disorders of uterus, NEC: 1.417
# 5. Abdominal pain: 1.218
# 6. Urinary incontinence: 1.137
# 7. Noninflammatory disorders of vagina: 1.092
# 8. Pain in limb: 0.963
# 9. Other tests: 0.822
# 10. Right bundle branch block: 0.374
#
# Hypotension NOS changed from rank 12 to 2
#
# Acute appendicitis changed from rank 4 to 12
#
# Abdominal pain changed from rank 8 to 5
#
# Other disorders of stomach and duodenum changed from rank 10 to 3
#
# Noninflammatory disorders of vagina changed from rank 12 to 7
#
# Cystitis changed from rank 3 to 12
#
# Chronic tonsillitis and adenoiditis changed from rank 9 to 12
#
# Other upper respiratory disease changed from rank 6 to 1
#
# Pain in limb changed from rank 2 to 8
#
# Other tests changed from rank 5 to 9
#
# Disorders of uterus, NEC changed from rank 1 to 4
#
# Signature 11:
#
# Initial top diseases:
# 1. Spinal stenosis: 1.155
# 2. Migraine: 1.125
# 3. Calculus of ureter: 1.092
# 4. Duodenal ulcer: 1.064
# 5. Hyperpotassemia: 1.061
# 6. Celiac disease: 1.014
# 7. Pleurisy; pleural effusion: 1.012
# 8. Hypovolemia: 1.002
# 9. Thyrotoxicosis with or without goiter: 0.996
# 10. Other non-epithelial cancer of skin: 0.996
#
# Final top diseases:
# 1. Migraine: 2.757
# 2. Hypovolemia: 1.798
# 3. Celiac disease: 1.793
# 4. Anxiety disorder: 1.625
# 5. Gastric ulcer: 1.260
# 6. Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: 1.232
# 7. Other non-epithelial cancer of skin: 1.147
# 8. Spinal stenosis: 1.096
# 9. Duodenal ulcer: 0.970
# 10. Retinal vascular changes and abnomalities: 0.593
#
# Hyperpotassemia changed from rank 5 to 12
#
# Spinal stenosis changed from rank 1 to 8
#
# Gastric ulcer changed from rank 12 to 5
#
# Hypovolemia changed from rank 8 to 2
#
# Duodenal ulcer changed from rank 4 to 9
#
# Pleurisy; pleural effusion changed from rank 7 to 12
#
# Other non-epithelial cancer of skin changed from rank 10 to 7
#
# Calculus of ureter changed from rank 3 to 12
#
# Anxiety disorder changed from rank 12 to 4
#
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] changed from rank 12 to 6
#
# Celiac disease changed from rank 6 to 3
#
# Thyrotoxicosis with or without goiter changed from rank 9 to 12
#
# Signature 12:
#
# Initial top diseases:
# 1. Hypertensive chronic kidney disease: 1.115
# 2. Atopic/contact dermatitis due to other or unspecified: 1.115
# 3. Bacterial infection NOS: 1.074
# 4. Osteopenia or other disorder of bone and cartilage: 1.069
# 5. Calculus of bile duct: 1.063
# 6. Cerebral artery occlusion, with cerebral infarction: 1.056
# 7. Urethral stricture (not specified as infectious): 1.053
# 8. Internal derangement of knee: 1.041
# 9. Staphylococcus infections: 1.027
# 10. Peripheral enthesopathies and allied syndromes: 1.019
#
# Final top diseases:
# 1. Atrial fibrillation and flutter: 2.169
# 2. Cerebral artery occlusion, with cerebral infarction: 1.665
# 3. Atopic/contact dermatitis due to other or unspecified: 1.653
# 4. Peripheral enthesopathies and allied syndromes: 1.512
# 5. Osteopenia or other disorder of bone and cartilage: 1.358
# 6. Other chronic nonalcoholic liver disease: 1.210
# 7. Hypertensive chronic kidney disease: 1.040
# 8. Bacterial infection NOS: 1.019
# 9. Contracture of palmar fascia [Dupuytren's disease]: 0.781
# 10. Urethral stricture (not specified as infectious): 0.617
#
# Urethral stricture (not specified as infectious) changed from rank 7 to 10
#
# Staphylococcus infections changed from rank 9 to 12
#
# Cerebral artery occlusion, with cerebral infarction changed from rank 6 to 2
#
# Other chronic nonalcoholic liver disease changed from rank 12 to 6
#
# Atrial fibrillation and flutter changed from rank 12 to 1
#
# Contracture of palmar fascia [Dupuytren's disease] changed from rank 12 to 9
#
# Internal derangement of knee changed from rank 8 to 12
#
# Calculus of bile duct changed from rank 5 to 12
#
# Peripheral enthesopathies and allied syndromes changed from rank 10 to 4
#
# Bacterial infection NOS changed from rank 3 to 8
#
# Hypertensive chronic kidney disease changed from rank 1 to 7
#
# Signature 13:
#
# Initial top diseases:
# 1. Heart failure NOS: 1.075
# 2. Cancer of bronchus; lung: 1.073
# 3. Excessive or frequent menstruation: 1.069
# 4. Cancer of prostate: 1.063
# 5. Noninfectious gastroenteritis: 1.063
# 6. Malignant neoplasm of rectum, rectosigmoid junction, and anus: 1.010
# 7. Glaucoma: 0.997
# 8. Chronic sinusitis: 0.979
# 9. Diseases of the larynx and vocal cords: 0.963
# 10. Facial nerve disorders [CN7]: 0.921
#
# Final top diseases:
# 1. Peripheral vascular disease, unspecified: 1.908
# 2. Malignant neoplasm of rectum, rectosigmoid junction, and anus: 1.809
# 3. Glaucoma: 1.709
# 4. Noninfectious gastroenteritis: 1.446
# 5. Excessive or frequent menstruation: 1.197
# 6. Cancer of prostate: 0.990
# 7. Diseases of the larynx and vocal cords: 0.654
# 8. Facial nerve disorders [CN7]: 0.513
# 9. Cancer of bronchus; lung: 0.288
# 10. Varicose veins of lower extremity: 0.257
#
# Malignant neoplasm of rectum, rectosigmoid junction, and anus changed from rank 6 to 2
#
# Cancer of bronchus; lung changed from rank 2 to 9
#
# Peripheral vascular disease, unspecified changed from rank 12 to 1
#
# Chronic sinusitis changed from rank 8 to 12
#
# Glaucoma changed from rank 7 to 3
#
# Heart failure NOS changed from rank 1 to 12
#
# Signature 14:
#
# Initial top diseases:
# 1. Myopia: 1.122
# 2. Cataract: 1.079
# 3. Hemorrhoids: 0.985
# 4. Visual disturbances: 0.969
# 5. Macular degeneration (senile) of retina NOS: 0.909
# 6. Hearing loss: -1.969
# 7. Noninflammatory disorders of cervix: -1.970
# 8. Barrett's esophagus: -1.978
# 9. Acute upper respiratory infections of multiple or unspecified sites: -1.980
# 10. Infertility, female: -1.982
#
# Final top diseases:
# 1. Visual disturbances: 2.271
# 2. Hemorrhoids: 2.179
# 3. Cataract: 2.134
# 4. Myopia: 0.990
# 5. Uterine leiomyoma: 0.419
# 6. Congenital anomalies of great vessels: 0.130
# 7. Macular degeneration (senile) of retina NOS: 0.044
# 8. Chronic glomerulonephritis, NOS: -0.166
# 9. Abdominal pain: -0.210
# 10. Scar conditions and fibrosis of skin: -0.234
#
# Chronic glomerulonephritis, NOS changed from rank 12 to 8
#
# Barrett's esophagus changed from rank 8 to 12
#
# Hearing loss changed from rank 6 to 12
#
# Uterine leiomyoma changed from rank 12 to 5
#
# Acute upper respiratory infections of multiple or unspecified sites changed from rank 9 to 12
#
# Abdominal pain changed from rank 12 to 9
#
# Noninflammatory disorders of cervix changed from rank 7 to 12
#
# Congenital anomalies of great vessels changed from rank 12 to 6
#
# Visual disturbances changed from rank 4 to 1
#
# Myopia changed from rank 1 to 4
#
# Signature 15:
#
# Initial top diseases:
# 1. Viral warts & HPV: 1.122
# 2. Diverticulosis: 1.102
# 3. Back pain: 1.081
# 4. Endometriosis: 1.067
# 5. Colon cancer: 1.059
# 6. Tobacco use disorder: 1.054
# 7. Myalgia and myositis unspecified: 1.053
# 8. Other peripheral nerve disorders: 1.039
# 9. Urinary tract infection: 1.019
# 10. Peritonitis and retroperitoneal infections: 1.009
#
# Final top diseases:
# 1. Osteoarthrosis, generalized: 2.557
# 2. Diverticulosis: 2.531
# 3. Ingrowing nail: 2.181
# 4. Paroxysmal supraventricular tachycardia: 2.065
# 5. Peritonitis and retroperitoneal infections: 1.927
# 6. Colon cancer: 1.895
# 7. Urinary tract infection: 1.720
# 8. Gastritis and duodenitis: 1.619
# 9. Duodenitis: 1.590
# 10. Hyperplasia of prostate: 1.367
#
# Osteoarthrosis, generalized changed from rank 12 to 1
#
# Other peripheral nerve disorders changed from rank 8 to 12
#
# Peritonitis and retroperitoneal infections changed from rank 10 to 5
#
# Viral warts & HPV changed from rank 1 to 12
#
# Ingrowing nail changed from rank 12 to 3
#
# Endometriosis changed from rank 4 to 12
#
# Tobacco use disorder changed from rank 6 to 12
#
# Paroxysmal supraventricular tachycardia changed from rank 12 to 4
#
# Myalgia and myositis unspecified changed from rank 7 to 12
#
# Gastritis and duodenitis changed from rank 12 to 8
#
# Duodenitis changed from rank 12 to 9
#
# Back pain changed from rank 3 to 12
#
# Signature 16:
#
# Initial top diseases:
# 1. Postmenopausal bleeding: 1.104
# 2. Secondary hypothyroidism: 1.103
# 3. Epilepsy, recurrent seizures, convulsions: 1.069
# 4. Type 2 diabetes: 1.067
# 5. Diaphragmatic hernia: 1.044
# 6. Functional digestive disorders: 0.984
# 7. Benign neoplasm of ovary: 0.967
# 8. Ovarian cyst: 0.964
# 9. Polyp of corpus uteri: 0.890
# 10. Senile cataract: 0.869
#
# Final top diseases:
# 1. Umbilical hernia: 2.200
# 2. Postmenopausal bleeding: 1.704
# 3. Ovarian cyst: 1.651
# 4. Epilepsy, recurrent seizures, convulsions: 1.395
# 5. Benign neoplasm of ovary: 1.253
# 6. Senile cataract: 1.136
# 7. Secondary hypothyroidism: 0.989
# 8. Functional digestive disorders: 0.836
# 9. Type 2 diabetes: 0.602
# 10. Polyp of corpus uteri: 0.423
#
# Type 2 diabetes changed from rank 4 to 9
#
# Umbilical hernia changed from rank 12 to 1
#
# Senile cataract changed from rank 10 to 6
#
# Ovarian cyst changed from rank 8 to 3
#
# Diaphragmatic hernia changed from rank 5 to 12
#
# Secondary hypothyroidism changed from rank 2 to 7
#
# Signature 17:
#
# Initial top diseases:
# 1. Disorders of lacrimal system: 1.151
# 2. Ectropion or entropion: 1.038
# 3. Sleep disorders: 0.916
# 4. Other inflammatory spondylopathies: 0.904
# 5. Other forms of chronic heart disease: 0.885
# 6. Other chronic nonalcoholic liver disease: -1.974
# 7. Thyrotoxicosis with or without goiter: -1.978
# 8. Migraine: -1.979
# 9. Esophageal bleeding (varices/hemorrhage): -1.981
# 10. Epiphora: -1.981
#
# Final top diseases:
# 1. Disorders of lacrimal system: 3.056
# 2. Other forms of chronic heart disease: 1.592
# 3. Other inflammatory spondylopathies: 0.800
# 4. Sleep disorders: 0.759
# 5. Cystitis: 0.347
# 6. Ectropion or entropion: 0.159
# 7. Hallux rigidus: -0.090
# 8. Postmenopausal atrophic vaginitis: -0.121
# 9. Mucous polyp of cervix: -0.230
# 10. Disease of tricuspid valve: -0.333
#
# Esophageal bleeding (varices/hemorrhage) changed from rank 9 to 12
#
# Migraine changed from rank 8 to 12
#
# Postmenopausal atrophic vaginitis changed from rank 12 to 8
#
# Thyrotoxicosis with or without goiter changed from rank 7 to 12
#
# Cystitis changed from rank 12 to 5
#
# Mucous polyp of cervix changed from rank 12 to 9
#
# Ectropion or entropion changed from rank 2 to 6
#
# Other forms of chronic heart disease changed from rank 5 to 2
#
# Other chronic nonalcoholic liver disease changed from rank 6 to 12
#
# Hallux rigidus changed from rank 12 to 7
#
# Signature 18:
#
# Initial top diseases:
# 1. Hemorrhage of rectum and anus: 1.128
# 2. Raynaud's syndrome: 1.120
# 3. Hearing loss: 1.107
# 4. Other benign neoplasm of connective and other soft tissue: 1.054
# 5. Chronic pharyngitis and nasopharyngitis: 1.048
# 6. Septal Deviations/Turbinate Hypertrophy: 1.028
# 7. Ulcer of esophagus: 0.890
# 8. Inflammatory and toxic neuropathy: 0.862
# 9. Bronchiectasis: 0.791
# 10. Infertility, female: -1.969
#
# Final top diseases:
# 1. Other benign neoplasm of connective and other soft tissue: 2.888
# 2. Septal Deviations/Turbinate Hypertrophy: 2.487
# 3. Inflammatory and toxic neuropathy: 2.047
# 4. Hearing loss: 1.868
# 5. Raynaud's syndrome: 1.706
# 6. Chronic pharyngitis and nasopharyngitis: 1.114
# 7. Hemorrhage of rectum and anus: 0.716
# 8. Bronchiectasis: 0.551
# 9. Ingrowing nail: 0.226
# 10. Other local infections of skin and subcutaneous tissue: 0.100
#
# Ulcer of esophagus changed from rank 7 to 12
#
# Raynaud's syndrome changed from rank 2 to 5
#
# Hemorrhage of rectum and anus changed from rank 1 to 7
#
# Septal Deviations/Turbinate Hypertrophy changed from rank 6 to 2
#
# Other benign neoplasm of connective and other soft tissue changed from rank 4 to 1
#
# Inflammatory and toxic neuropathy changed from rank 8 to 3
#
# Ingrowing nail changed from rank 12 to 9
#
# Signature 19:
#
# Initial top diseases:
# 1. Hemorrhage of gastrointestinal tract: 1.120
# 2. Malignant neoplasm of kidney, except pelvis: 1.106
# 3. Other disorders of prostate: 0.999
# 4. Peritoneal adhesions (postoperative) (postinfection): 0.985
# 5. Acute renal failure: 0.975
# 6. Essential hypertension: 0.959
# 7. Hypercholesterolemia: 0.937
# 8. Abdominal pain: -1.975
# 9. Other derangement of joint: -1.975
# 10. Gram negative septicemia: -1.977
#
# Final top diseases:
# 1. Acute renal failure: 2.271
# 2. Malignant neoplasm of kidney, except pelvis: 2.141
# 3. Hemorrhage of gastrointestinal tract: 1.580
# 4. Essential hypertension: 1.574
# 5. Hypercholesterolemia: 0.498
# 6. Chronic ulcer of skin: 0.050
# 7. Postmenopausal atrophic vaginitis: 0.002
# 8. Pneumococcal pneumonia: -0.025
# 9. Peritoneal adhesions (postoperative) (postinfection): -0.054
# 10. Coronary atherosclerosis: -0.261
#
# Other derangement of joint changed from rank 9 to 12
#
# Pneumococcal pneumonia changed from rank 12 to 8
#
# Chronic ulcer of skin changed from rank 12 to 6
#
# Other disorders of prostate changed from rank 3 to 12
#
# Peritoneal adhesions (postoperative) (postinfection) changed from rank 4 to 9
#
# Acute renal failure changed from rank 5 to 1
#
# Postmenopausal atrophic vaginitis changed from rank 12 to 7
#
# Abdominal pain changed from rank 8 to 12

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, disease_names)
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Spondylosis and allied disorders: 1.126
# 2. Kyphoscoliosis and scoliosis: 1.116
# 3. Neuralgia, neuritis, and radiculitis NOS: 1.109
# 4. Spondylosis without myelopathy: 1.074
# 5. Acquired spondylolisthesis: 1.069
# 6. Back pain: 1.044
# 7. Sciatica: 1.015
# 8. Displacement of intervertebral disc: 0.978
# 9. Other and unspecified disc disorder: 0.971
# 10. Degenerative disease of the spinal cord: 0.964
#
# Final top diseases:
# 1. Kyphoscoliosis and scoliosis: 2.299
# 2. Sciatica: 1.662
# 3. Spondylosis without myelopathy: 1.278
# 4. Other and unspecified disc disorder: 1.194
# 5. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 0.975
# 6. Degeneration of intervertebral disc: 0.943
# 7. Spinal stenosis: 0.725
# 8. Degenerative disease of the spinal cord: 0.606
# 9. Neuralgia, neuritis, and radiculitis NOS: 0.490
# 10. Acquired spondylolisthesis: 0.324
#
# Acquired spondylolisthesis changed from rank 5 to 10
#
# Back pain changed from rank 6 to 12
#
# Thoracic or lumbosacral neuritis or radiculitis, unspecified changed from rank 12 to 5
#
# Sciatica changed from rank 7 to 2
#
# Neuralgia, neuritis, and radiculitis NOS changed from rank 3 to 9
#
# Spinal stenosis changed from rank 12 to 7
#
# Spondylosis and allied disorders changed from rank 1 to 12
#
# Displacement of intervertebral disc changed from rank 8 to 12
#
# Degeneration of intervertebral disc changed from rank 12 to 6
#
# Other and unspecified disc disorder changed from rank 9 to 4
#
# Signature 1:
#
# Initial top diseases:
# 1. Irregular menstrual bleeding: 1.153
# 2. Noninflammatory disorders of vagina: 1.111
# 3. Disorders of menstruation and other abnormal bleeding from female genital tract: 1.098
# 4. Malignant neoplasm of uterus: 1.097
# 5. Polyp of corpus uteri: 1.047
# 6. Noninflammatory disorders of cervix: 1.040
# 7. Disorders of uterus, NEC: 1.034
# 8. Prolapse of vaginal walls: 1.030
# 9. Pelvic peritoneal adhesions, female (postoperative) (postinfection): 1.029
# 10. Irregular menstrual cycle: 1.024
#
# Final top diseases:
# 1. Pelvic peritoneal adhesions, female (postoperative) (postinfection): 2.873
# 2. Postmenopausal atrophic vaginitis: 2.527
# 3. Excessive or frequent menstruation: 2.105
# 4. Benign neoplasm of ovary: 1.917
# 5. Endometrial hyperplasia: 1.773
# 6. Malignant neoplasm of uterus: 1.593
# 7. Irregular menstrual cycle: 1.554
# 8. Polyp of corpus uteri: 1.438
# 9. Disorders of menstruation and other abnormal bleeding from female genital tract: 1.403
# 10. Hypertrophy of female genital organs: 1.374
#
# Pelvic peritoneal adhesions, female (postoperative) (postinfection) changed from rank 9 to 1
#
# Prolapse of vaginal walls changed from rank 8 to 12
#
# Disorders of uterus, NEC changed from rank 7 to 12
#
# Noninflammatory disorders of cervix changed from rank 6 to 12
#
# Noninflammatory disorders of vagina changed from rank 2 to 12
#
# Endometrial hyperplasia changed from rank 12 to 5
#
# Polyp of corpus uteri changed from rank 5 to 8
#
# Disorders of menstruation and other abnormal bleeding from female genital tract changed from rank 3 to 9
#
# Excessive or frequent menstruation changed from rank 12 to 3
#
# Irregular menstrual cycle changed from rank 10 to 7
#
# Irregular menstrual bleeding changed from rank 1 to 12
#
# Postmenopausal atrophic vaginitis changed from rank 12 to 2
#
# Benign neoplasm of ovary changed from rank 12 to 4
#
# Signature 2:
#
# Initial top diseases:
# 1. Cyst of kidney, acquired: 1.211
# 2. Hypertensive chronic kidney disease: 1.050
# 3. Hyperpotassemia: 1.026
# 4. Chronic renal failure [CKD]: 1.022
# 5. Chronic Kidney Disease, Stage III: 1.014
# 6. Gout: 1.005
# 7. Pyelonephritis: 0.962
# 8. Chronic glomerulonephritis, NOS: 0.956
# 9. Renal failure NOS: 0.903
# 10. Other disorders of the kidney and ureters: 0.886
#
# Final top diseases:
# 1. Cyst of kidney, acquired: 2.907
# 2. Pyelonephritis: 2.861
# 3. Hypertensive chronic kidney disease: 2.356
# 4. Chronic renal failure [CKD]: 1.804
# 5. Essential hypertension: 1.714
# 6. Chronic Kidney Disease, Stage III: 1.490
# 7. Chronic glomerulonephritis, NOS: 1.373
# 8. Renal failure NOS: 1.042
# 9. Gout: 1.040
# 10. Hyperpotassemia: 0.884
#
# Pyelonephritis changed from rank 7 to 2
#
# Essential hypertension changed from rank 12 to 5
#
# Gout changed from rank 6 to 9
#
# Hyperpotassemia changed from rank 3 to 10
#
# Signature 3:
#
# Initial top diseases:
# 1. Angina pectoris: 1.097
# 2. Myocardial infarction: 1.087
# 3. Unstable angina (intermediate coronary syndrome): 1.051
# 4. Other chronic ischemic heart disease, unspecified: 1.041
# 5. Hypercholesterolemia: 1.020
# 6. Other acute and subacute forms of ischemic heart disease: 1.000
# 7. Coronary atherosclerosis: 0.883
# 8. Chronic renal failure [CKD]: -1.975
# 9. Congenital anomalies of great vessels: -1.975
# 10. Other tests: -1.975
#
# Final top diseases:
# 1. Hypercholesterolemia: 2.188
# 2. Other chronic ischemic heart disease, unspecified: 2.085
# 3. Myocardial infarction: 1.922
# 4. Coronary atherosclerosis: 1.151
# 5. Unstable angina (intermediate coronary syndrome): 1.029
# 6. Nasal polyps: 0.767
# 7. Bronchiectasis: 0.474
# 8. Other acute and subacute forms of ischemic heart disease: 0.347
# 9. Angina pectoris: 0.047
# 10. Acute pancreatitis: -0.202
#
# Congenital anomalies of great vessels changed from rank 9 to 12
#
# Nasal polyps changed from rank 12 to 6
#
# Bronchiectasis changed from rank 12 to 7
#
# Chronic renal failure [CKD] changed from rank 8 to 12
#
# Angina pectoris changed from rank 1 to 9
#
# Coronary atherosclerosis changed from rank 7 to 4
#
# Hypercholesterolemia changed from rank 5 to 1
#
# Signature 4:
#
# Initial top diseases:
# 1. Congestive heart failure (CHF) NOS: 1.181
# 2. Disease of tricuspid valve: 1.092
# 3. Cardiomegaly: 1.084
# 4. Other forms of chronic heart disease: 1.082
# 5. Paroxysmal supraventricular tachycardia: 1.047
# 6. Heart failure NOS: 1.029
# 7. Mitral valve disease: 0.993
# 8. Primary/intrinsic cardiomyopathies: 0.991
# 9. First degree AV block: 0.947
# 10. Aortic valve disease: 0.933
#
# Final top diseases:
# 1. Rheumatic disease of the heart valves: 2.566
# 2. Aortic valve disease: 2.126
# 3. Mitral valve disease: 1.787
# 4. Cardiomegaly: 1.342
# 5. Paroxysmal supraventricular tachycardia: 1.114
# 6. Congenital anomalies of great vessels: 0.966
# 7. Other forms of chronic heart disease: 0.891
# 8. Left bundle branch block: 0.804
# 9. Right bundle branch block: 0.735
# 10. Disease of tricuspid valve: 0.664
#
# Congestive heart failure (CHF) NOS changed from rank 1 to 12
#
# Heart failure NOS changed from rank 6 to 12
#
# Congenital anomalies of great vessels changed from rank 12 to 6
#
# Rheumatic disease of the heart valves changed from rank 12 to 1
#
# Mitral valve disease changed from rank 7 to 3
#
# Aortic valve disease changed from rank 10 to 2
#
# Disease of tricuspid valve changed from rank 2 to 10
#
# Other forms of chronic heart disease changed from rank 4 to 7
#
# Primary/intrinsic cardiomyopathies changed from rank 8 to 12
#
# First degree AV block changed from rank 9 to 12
#
# Right bundle branch block changed from rank 12 to 9
#
# Left bundle branch block changed from rank 12 to 8
#
# Signature 5:
#
# Initial top diseases:
# 1. Polymyalgia Rheumatica: 1.208
# 2. Contracture of palmar fascia [Dupuytren's disease]: 1.200
# 3. Hydrocele: 1.176
# 4. Other non-epithelial cancer of skin: 1.152
# 5. Sebaceous cyst: 1.144
# 6. Other disorders of bone and cartilage: 1.140
# 7. Ptosis of eyelid: 1.138
# 8. Parkinson's disease: 1.135
# 9. Viral Enteritis: 1.132
# 10. Redundant prepuce and phimosis/BXO: 1.129
#
# Final top diseases:
# 1. Disorders of conjunctiva: 2.760
# 2. Other symptoms/disorders or the urinary system: 2.520
# 3. Diseases of the larynx and vocal cords: 2.384
# 4. Benign neoplasm of breast: 2.255
# 5. Other non-epithelial cancer of skin: 2.020
# 6. Visual disturbances: 2.016
# 7. Melanomas of skin: 1.932
# 8. Chronic periodontitis: 1.901
# 9. Cardiac arrest: 1.896
# 10. Inflammation of eyelids: 1.887
#
# Benign neoplasm of breast changed from rank 12 to 4
#
# Viral Enteritis changed from rank 9 to 12
#
# Cardiac arrest changed from rank 12 to 9
#
# Parkinson's disease changed from rank 8 to 12
#
# Melanomas of skin changed from rank 12 to 7
#
# Diseases of the larynx and vocal cords changed from rank 12 to 3
#
# Visual disturbances changed from rank 12 to 6
#
# Disorders of conjunctiva changed from rank 12 to 1
#
# Ptosis of eyelid changed from rank 7 to 12
#
# Sebaceous cyst changed from rank 5 to 12
#
# Polymyalgia Rheumatica changed from rank 1 to 12
#
# Chronic periodontitis changed from rank 12 to 8
#
# Other symptoms/disorders or the urinary system changed from rank 12 to 2
#
# Contracture of palmar fascia [Dupuytren's disease] changed from rank 2 to 12
#
# Other disorders of bone and cartilage changed from rank 6 to 12
#
# Hydrocele changed from rank 3 to 12
#
# Signature 6:
#
# Initial top diseases:
# 1. Septal Deviations/Turbinate Hypertrophy: 1.179
# 2. Nasal polyps: 1.042
# 3. Chronic pharyngitis and nasopharyngitis: 0.983
# 4. Other upper respiratory disease: 0.905
# 5. Chronic sinusitis: 0.854
# 6. Other chronic nonalcoholic liver disease: -1.972
# 7. Osteoarthrosis, generalized: -1.972
# 8. Viral warts & HPV: -1.975
# 9. Postmenopausal bleeding: -1.976
# 10. Internal derangement of knee: -1.978
#
# Final top diseases:
# 1. Chronic sinusitis: 2.376
# 2. Other upper respiratory disease: 1.582
# 3. Septal Deviations/Turbinate Hypertrophy: 0.767
# 4. Nasal polyps: 0.728
# 5. Disorders of calcium/phosphorus metabolism: 0.221
# 6. Epiphora: 0.186
# 7. Reflux esophagitis: 0.174
# 8. Chronic pharyngitis and nasopharyngitis: 0.007
# 9. Sleep disorders: -0.129
# 10. Other disorders of stomach and duodenum: -0.245
#
# Osteoarthrosis, generalized changed from rank 7 to 12
#
# Viral warts & HPV changed from rank 8 to 12
#
# Sleep disorders changed from rank 12 to 9
#
# Other chronic nonalcoholic liver disease changed from rank 6 to 12
#
# Chronic pharyngitis and nasopharyngitis changed from rank 3 to 8
#
# Postmenopausal bleeding changed from rank 9 to 12
#
# Chronic sinusitis changed from rank 5 to 1
#
# Epiphora changed from rank 12 to 6
#
# Disorders of calcium/phosphorus metabolism changed from rank 12 to 5
#
# Reflux esophagitis changed from rank 12 to 7
#
# Signature 7:
#
# Initial top diseases:
# 1. Enthesopathy: 1.156
# 2. Osteoarthrosis, localized, primary: 1.103
# 3. Other derangement of joint: 1.098
# 4. Osteoarthrosis NOS: 1.096
# 5. Other acquired deformities of limbs: 1.090
# 6. Synovitis and tenosynovitis: 1.083
# 7. Pain in limb: 1.066
# 8. Rheumatoid arthritis: 1.044
# 9. Hallux rigidus: 1.041
# 10. Other peripheral nerve disorders: 1.024
#
# Final top diseases:
# 1. Other disorders of soft tissues: 3.712
# 2. Arthropathy NOS: 2.715
# 3. Acquired toe deformities: 2.329
# 4. Pain in joint: 2.308
# 5. Enthesopathy: 2.276
# 6. Hallux rigidus: 1.764
# 7. Pain in limb: 1.613
# 8. Rheumatoid arthritis: 1.453
# 9. Other peripheral nerve disorders: 1.452
# 10. Other acquired deformities of limbs: 1.252
#
# Hallux rigidus changed from rank 9 to 6
#
# Other acquired deformities of limbs changed from rank 5 to 10
#
# Osteoarthrosis, localized, primary changed from rank 2 to 12
#
# Osteoarthrosis NOS changed from rank 4 to 12
#
# Other derangement of joint changed from rank 3 to 12
#
# Pain in joint changed from rank 12 to 4
#
# Arthropathy NOS changed from rank 12 to 2
#
# Enthesopathy changed from rank 1 to 5
#
# Synovitis and tenosynovitis changed from rank 6 to 12
#
# Other disorders of soft tissues changed from rank 12 to 1
#
# Acquired toe deformities changed from rank 12 to 3
#
# Signature 8:
#
# Initial top diseases:
# 1. Osteoporosis NOS: 1.224
# 2. Irritable Bowel Syndrome: 1.163
# 3. Alcohol-related disorders: 1.126
# 4. Major depressive disorder: 1.100
# 5. Hematemesis: 1.075
# 6. Other chronic nonalcoholic liver disease: 1.066
# 7. Anxiety disorder: 1.055
# 8. Cervicalgia: 0.990
# 9. Rheumatism, unspecified and fibrositis: 0.980
# 10. Migraine: 0.930
#
# Final top diseases:
# 1. Dental caries: 2.313
# 2. Major depressive disorder: 1.989
# 3. Hypothyroidism NOS: 1.427
# 4. Cervicalgia: 1.342
# 5. Bipolar: 1.340
# 6. Hematemesis: 1.155
# 7. Anxiety disorder: 0.997
# 8. Alcohol-related disorders: 0.868
# 9. Alcoholic liver damage: 0.833
# 10. Osteoporosis NOS: 0.792
#
# Bipolar changed from rank 12 to 5
#
# Alcohol-related disorders changed from rank 3 to 8
#
# Alcoholic liver damage changed from rank 12 to 9
#
# Osteoporosis NOS changed from rank 1 to 10
#
# Irritable Bowel Syndrome changed from rank 2 to 12
#
# Cervicalgia changed from rank 8 to 4
#
# Other chronic nonalcoholic liver disease changed from rank 6 to 12
#
# Hypothyroidism NOS changed from rank 12 to 3
#
# Dental caries changed from rank 12 to 1
#
# Rheumatism, unspecified and fibrositis changed from rank 9 to 12
#
# Signature 9:
#
# Initial top diseases:
# 1. Late effects of cerebrovascular disease: 1.226
# 2. Transient cerebral ischemia: 1.090
# 3. Hemiplegia: 1.081
# 4. Occlusion and stenosis of precerebral arteries: 1.062
# 5. Cerebral ischemia: 1.025
# 6. Cerebrovascular disease: 1.015
# 7. Cerebral artery occlusion, with cerebral infarction: 0.986
# 8. Occlusion of cerebral arteries: 0.855
# 9. Retinal vascular changes and abnomalities: -1.975
# 10. Ptosis of eyelid: -1.976
#
# Final top diseases:
# 1. Occlusion of cerebral arteries: 1.530
# 2. Cerebrovascular disease: 1.262
# 3. Cerebral ischemia: 1.259
# 4. Cerebral artery occlusion, with cerebral infarction: 0.825
# 5. Occlusion and stenosis of precerebral arteries: 0.738
# 6. Hemiplegia: 0.702
# 7. Late effects of cerebrovascular disease: 0.688
# 8. Transient cerebral ischemia: 0.560
# 9. Other forms of chronic heart disease: -0.097
# 10. Lipoma of skin and subcutaneous tissue: -0.145
#
# Cerebrovascular disease changed from rank 6 to 2
#
# Occlusion of cerebral arteries changed from rank 8 to 1
#
# Cerebral artery occlusion, with cerebral infarction changed from rank 7 to 4
#
# Transient cerebral ischemia changed from rank 2 to 8
#
# Late effects of cerebrovascular disease changed from rank 1 to 7
#
# Hemiplegia changed from rank 3 to 6
#
# Retinal vascular changes and abnomalities changed from rank 9 to 12
#
# Other forms of chronic heart disease changed from rank 12 to 9
#
# Signature 10:
#
# Initial top diseases:
# 1. Respiratory failure: 1.243
# 2. Pleurisy; pleural effusion: 1.215
# 3. Obstructive chronic bronchitis: 1.054
# 4. Pneumonia: 1.008
# 5. Pulmonary collapse; interstitial and compensatory emphysema: 0.993
# 6. Empyema and pneumothorax: 0.969
# 7. Bronchiectasis: 0.966
# 8. Pneumococcal pneumonia: 0.947
# 9. Postinflammatory pulmonary fibrosis: 0.943
# 10. Chronic airway obstruction: 0.886
#
# Final top diseases:
# 1. Empyema and pneumothorax: 2.405
# 2. Cancer of bronchus; lung: 1.958
# 3. Chronic airway obstruction: 1.678
# 4. Respiratory failure: 1.417
# 5. Pneumococcal pneumonia: 1.218
# 6. Bronchiectasis: 1.137
# 7. Emphysema: 1.092
# 8. Pleurisy; pleural effusion: 0.963
# 9. Pulmonary collapse; interstitial and compensatory emphysema: 0.822
# 10. Other and unspecified disc disorder: 0.374
#
# Cancer of bronchus; lung changed from rank 12 to 2
#
# Pneumonia changed from rank 4 to 12
#
# Pneumococcal pneumonia changed from rank 8 to 5
#
# Chronic airway obstruction changed from rank 10 to 3
#
# Emphysema changed from rank 12 to 7
#
# Obstructive chronic bronchitis changed from rank 3 to 12
#
# Postinflammatory pulmonary fibrosis changed from rank 9 to 12
#
# Empyema and pneumothorax changed from rank 6 to 1
#
# Pleurisy; pleural effusion changed from rank 2 to 8
#
# Pulmonary collapse; interstitial and compensatory emphysema changed from rank 5 to 9
#
# Respiratory failure changed from rank 1 to 4
#
# Signature 11:
#
# Initial top diseases:
# 1. Regional enteritis: 1.155
# 2. Other disorders of intestine: 1.125
# 3. Anal and rectal polyp: 1.092
# 4. Diverticulosis: 1.064
# 5. Ventral hernia: 1.061
# 6. Gastrointestinal complications: 1.014
# 7. Neoplasm of unspecified nature of digestive system: 1.012
# 8. Colon cancer: 1.002
# 9. Hemorrhage of gastrointestinal tract: 0.996
# 10. Other intestinal obstruction: 0.996
#
# Final top diseases:
# 1. Other disorders of intestine: 2.757
# 2. Colon cancer: 1.798
# 3. Gastrointestinal complications: 1.793
# 4. Hemorrhoids: 1.625
# 5. Ulcerative colitis: 1.260
# 6. Peritonitis and retroperitoneal infections: 1.232
# 7. Other intestinal obstruction: 1.147
# 8. Regional enteritis: 1.096
# 9. Diverticulosis: 0.970
# 10. Noninfectious gastroenteritis: 0.593
#
# Ventral hernia changed from rank 5 to 12
#
# Regional enteritis changed from rank 1 to 8
#
# Ulcerative colitis changed from rank 12 to 5
#
# Colon cancer changed from rank 8 to 2
#
# Diverticulosis changed from rank 4 to 9
#
# Neoplasm of unspecified nature of digestive system changed from rank 7 to 12
#
# Other intestinal obstruction changed from rank 10 to 7
#
# Anal and rectal polyp changed from rank 3 to 12
#
# Hemorrhoids changed from rank 12 to 4
#
# Peritonitis and retroperitoneal infections changed from rank 12 to 6
#
# Gastrointestinal complications changed from rank 6 to 3
#
# Hemorrhage of gastrointestinal tract changed from rank 9 to 12
#
# Signature 12:
#
# Initial top diseases:
# 1. Duodenitis: 1.115
# 2. Other specified gastritis: 1.115
# 3. Iron deficiency anemias, unspecified or not due to blood loss: 1.074
# 4. Reflux esophagitis: 1.069
# 5. Duodenal ulcer: 1.063
# 6. Benign neoplasm of other parts of digestive system: 1.056
# 7. Other disorders of stomach and duodenum: 1.053
# 8. Gastric ulcer: 1.041
# 9. Diaphragmatic hernia: 1.027
# 10. Gastritis and duodenitis: 1.019
#
# Final top diseases:
# 1. Ulcer of esophagus: 2.169
# 2. Benign neoplasm of other parts of digestive system: 1.665
# 3. Other specified gastritis: 1.653
# 4. Gastritis and duodenitis: 1.512
# 5. Reflux esophagitis: 1.358
# 6. GERD: 1.210
# 7. Duodenitis: 1.040
# 8. Iron deficiency anemias, unspecified or not due to blood loss: 1.019
# 9. Stricture and stenosis of esophagus: 0.781
# 10. Other disorders of stomach and duodenum: 0.617
#
# Other disorders of stomach and duodenum changed from rank 7 to 10
#
# Diaphragmatic hernia changed from rank 9 to 12
#
# Benign neoplasm of other parts of digestive system changed from rank 6 to 2
#
# GERD changed from rank 12 to 6
#
# Ulcer of esophagus changed from rank 12 to 1
#
# Stricture and stenosis of esophagus changed from rank 12 to 9
#
# Gastric ulcer changed from rank 8 to 12
#
# Duodenal ulcer changed from rank 5 to 12
#
# Gastritis and duodenitis changed from rank 10 to 4
#
# Iron deficiency anemias, unspecified or not due to blood loss changed from rank 3 to 8
#
# Duodenitis changed from rank 1 to 7
#
# Signature 13:
#
# Initial top diseases:
# 1. Other disorders of prostate: 1.075
# 2. Bladder neck obstruction: 1.073
# 3. Urinary incontinence: 1.069
# 4. Malignant neoplasm of bladder: 1.063
# 5. Chronic prostatitis: 1.063
# 6. Cancer of prostate: 1.010
# 7. Hyperplasia of prostate: 0.997
# 8. Urethral stricture (not specified as infectious): 0.979
# 9. Chronic cystitis: 0.963
# 10. Cystitis: 0.921
#
# Final top diseases:
# 1. Functional disorders of bladder: 1.908
# 2. Cancer of prostate: 1.809
# 3. Hyperplasia of prostate: 1.709
# 4. Chronic prostatitis: 1.446
# 5. Urinary incontinence: 1.197
# 6. Malignant neoplasm of bladder: 0.990
# 7. Chronic cystitis: 0.654
# 8. Cystitis: 0.513
# 9. Bladder neck obstruction: 0.288
# 10. Cervicitis and endocervicitis: 0.257
#
# Cancer of prostate changed from rank 6 to 2
#
# Bladder neck obstruction changed from rank 2 to 9
#
# Functional disorders of bladder changed from rank 12 to 1
#
# Urethral stricture (not specified as infectious) changed from rank 8 to 12
#
# Hyperplasia of prostate changed from rank 7 to 3
#
# Other disorders of prostate changed from rank 1 to 12
#
# Signature 14:
#
# Initial top diseases:
# 1. Diabetic retinopathy: 1.122
# 2. Type 2 diabetes: 1.079
# 3. Hypoglycemia: 0.985
# 4. Type 1 diabetes: 0.969
# 5. Type 2 diabetes with ophthalmic manifestations: 0.909
# 6. Cholelithiasis with acute cholecystitis: -1.969
# 7. Perforation of tympanic membrane: -1.970
# 8. Abdominal aortic aneurysm: -1.978
# 9. Chronic sinusitis: -1.980
# 10. Internal derangement of knee: -1.982
#
# Final top diseases:
# 1. Type 1 diabetes: 2.271
# 2. Hypoglycemia: 2.179
# 3. Type 2 diabetes: 2.134
# 4. Diabetic retinopathy: 0.990
# 5. Diseases of the larynx and vocal cords: 0.419
# 6. Aortic valve disease: 0.130
# 7. Type 2 diabetes with ophthalmic manifestations: 0.044
# 8. Osteoarthritis; localized: -0.166
# 9. Pneumococcal pneumonia: -0.210
# 10. Polymyalgia Rheumatica: -0.234
#
# Osteoarthritis; localized changed from rank 12 to 8
#
# Abdominal aortic aneurysm changed from rank 8 to 12
#
# Cholelithiasis with acute cholecystitis changed from rank 6 to 12
#
# Diseases of the larynx and vocal cords changed from rank 12 to 5
#
# Chronic sinusitis changed from rank 9 to 12
#
# Pneumococcal pneumonia changed from rank 12 to 9
#
# Perforation of tympanic membrane changed from rank 7 to 12
#
# Aortic valve disease changed from rank 12 to 6
#
# Type 1 diabetes changed from rank 4 to 1
#
# Diabetic retinopathy changed from rank 1 to 4
#
# Signature 15:
#
# Initial top diseases:
# 1. Sepsis: 1.122
# 2. Streptococcus infection: 1.102
# 3. Hypovolemia: 1.081
# 4. Other local infections of skin and subcutaneous tissue: 1.067
# 5. Candidiasis: 1.059
# 6. Bacterial pneumonia: 1.054
# 7. Other diseases of respiratory system, NEC: 1.053
# 8. Gram negative septicemia: 1.039
# 9. Thrombocytopenia: 1.019
# 10. Bacterial infection NOS: 1.009
#
# Final top diseases:
# 1. Neutropenia: 2.557
# 2. Streptococcus infection: 2.531
# 3. Cellulitis and abscess of arm/hand: 2.181
# 4. Decubitus ulcer: 2.065
# 5. Bacterial infection NOS: 1.927
# 6. Candidiasis: 1.895
# 7. Thrombocytopenia: 1.720
# 8. Disorders of calcium/phosphorus metabolism: 1.619
# 9. Hyposmolality and/or hyponatremia: 1.590
# 10. Staphylococcus infections: 1.367
#
# Neutropenia changed from rank 12 to 1
#
# Gram negative septicemia changed from rank 8 to 12
#
# Bacterial infection NOS changed from rank 10 to 5
#
# Sepsis changed from rank 1 to 12
#
# Cellulitis and abscess of arm/hand changed from rank 12 to 3
#
# Other local infections of skin and subcutaneous tissue changed from rank 4 to 12
#
# Bacterial pneumonia changed from rank 6 to 12
#
# Decubitus ulcer changed from rank 12 to 4
#
# Other diseases of respiratory system, NEC changed from rank 7 to 12
#
# Disorders of calcium/phosphorus metabolism changed from rank 12 to 8
#
# Hyposmolality and/or hyponatremia changed from rank 12 to 9
#
# Hypovolemia changed from rank 3 to 12
#
# Signature 16:
#
# Initial top diseases:
# 1. Retinal vascular changes and abnomalities: 1.104
# 2. Disorders of vitreous body: 1.103
# 3. Primary open angle glaucoma: 1.069
# 4. Retinal detachments and defects: 1.067
# 5. Senile cataract: 1.044
# 6. Cataract: 0.984
# 7. Myopia: 0.967
# 8. Glaucoma: 0.964
# 9. Other retinal disorders: 0.890
# 10. Macular degeneration (senile) of retina NOS: 0.869
#
# Final top diseases:
# 1. Retinal detachment with retinal defect: 2.200
# 2. Retinal vascular changes and abnomalities: 1.704
# 3. Glaucoma: 1.651
# 4. Primary open angle glaucoma: 1.395
# 5. Myopia: 1.253
# 6. Macular degeneration (senile) of retina NOS: 1.136
# 7. Disorders of vitreous body: 0.989
# 8. Cataract: 0.836
# 9. Retinal detachments and defects: 0.602
# 10. Other retinal disorders: 0.423
#
# Retinal detachments and defects changed from rank 4 to 9
#
# Retinal detachment with retinal defect changed from rank 12 to 1
#
# Macular degeneration (senile) of retina NOS changed from rank 10 to 6
#
# Glaucoma changed from rank 8 to 3
#
# Senile cataract changed from rank 5 to 12
#
# Disorders of vitreous body changed from rank 2 to 7
#
# Signature 17:
#
# Initial top diseases:
# 1. Renal colic: 1.151
# 2. Calculus of ureter: 1.038
# 3. Stricture/obstruction of ureter: 0.916
# 4. Calculus of kidney: 0.904
# 5. Hydronephrosis: 0.885
# 6. GERD: -1.974
# 7. Hemorrhage of gastrointestinal tract: -1.978
# 8. Other disorders of intestine: -1.979
# 9. Cerebrovascular disease: -1.981
# 10. Phlebitis and thrombophlebitis of lower extremities: -1.981
#
# Final top diseases:
# 1. Renal colic: 3.056
# 2. Hydronephrosis: 1.592
# 3. Calculus of kidney: 0.800
# 4. Stricture/obstruction of ureter: 0.759
# 5. Obstructive chronic bronchitis: 0.347
# 6. Calculus of ureter: 0.159
# 7. Ganglion and cyst of synovium, tendon, and bursa: -0.090
# 8. Allergic rhinitis: -0.121
# 9. Strabismus (not specified as paralytic): -0.230
# 10. Scar conditions and fibrosis of skin: -0.333
#
# Cerebrovascular disease changed from rank 9 to 12
#
# Other disorders of intestine changed from rank 8 to 12
#
# Allergic rhinitis changed from rank 12 to 8
#
# Hemorrhage of gastrointestinal tract changed from rank 7 to 12
#
# Obstructive chronic bronchitis changed from rank 12 to 5
#
# Strabismus (not specified as paralytic) changed from rank 12 to 9
#
# Calculus of ureter changed from rank 2 to 6
#
# Hydronephrosis changed from rank 5 to 2
#
# GERD changed from rank 6 to 12
#
# Ganglion and cyst of synovium, tendon, and bursa changed from rank 12 to 7
#
# Signature 18:
#
# Initial top diseases:
# 1. Cholelithiasis with other cholecystitis: 1.128
# 2. Cholelithiasis: 1.120
# 3. Cholelithiasis with acute cholecystitis: 1.107
# 4. Other disorders of gallbladder: 1.054
# 5. Calculus of bile duct: 1.048
# 6. Cholecystitis without cholelithiasis: 1.028
# 7. Peritoneal adhesions (postoperative) (postinfection): 0.890
# 8. Other disorders of biliary tract: 0.862
# 9. Acute pancreatitis: 0.791
# 10. Internal derangement of knee: -1.969
#
# Final top diseases:
# 1. Other disorders of gallbladder: 2.888
# 2. Cholecystitis without cholelithiasis: 2.487
# 3. Other disorders of biliary tract: 2.047
# 4. Cholelithiasis with acute cholecystitis: 1.868
# 5. Cholelithiasis: 1.706
# 6. Calculus of bile duct: 1.114
# 7. Cholelithiasis with other cholecystitis: 0.716
# 8. Acute pancreatitis: 0.551
# 9. Cellulitis and abscess of arm/hand: 0.226
# 10. Hammer toe (acquired): 0.100
#
# Peritoneal adhesions (postoperative) (postinfection) changed from rank 7 to 12
#
# Cholelithiasis changed from rank 2 to 5
#
# Cholelithiasis with other cholecystitis changed from rank 1 to 7
#
# Cholecystitis without cholelithiasis changed from rank 6 to 2
#
# Other disorders of gallbladder changed from rank 4 to 1
#
# Other disorders of biliary tract changed from rank 8 to 3
#
# Cellulitis and abscess of arm/hand changed from rank 12 to 9
#
# Signature 19:
#
# Initial top diseases:
# 1. Malignant neoplasm, other: 1.120
# 2. Secondary malignancy of respiratory organs: 1.106
# 3. Secondary malignant neoplasm: 0.999
# 4. Secondary malignant neoplasm of digestive systems: 0.985
# 5. Secondary malignant neoplasm of liver: 0.975
# 6. Secondary malignancy of lymph nodes: 0.959
# 7. Secondary malignancy of bone: 0.937
# 8. Pneumococcal pneumonia: -1.975
# 9. Constipation: -1.975
# 10. Hearing loss: -1.977
#
# Final top diseases:
# 1. Secondary malignant neoplasm of liver: 2.271
# 2. Secondary malignancy of respiratory organs: 2.141
# 3. Malignant neoplasm, other: 1.580
# 4. Secondary malignancy of lymph nodes: 1.574
# 5. Secondary malignancy of bone: 0.498
# 6. Septal Deviations/Turbinate Hypertrophy: 0.050
# 7. Allergic rhinitis: 0.002
# 8. Malignant neoplasm of uterus: -0.025
# 9. Secondary malignant neoplasm of digestive systems: -0.054
# 10. Hypertensive chronic kidney disease: -0.261
#
# Constipation changed from rank 9 to 12
#
# Malignant neoplasm of uterus changed from rank 12 to 8
#
# Septal Deviations/Turbinate Hypertrophy changed from rank 12 to 6
#
# Secondary malignant neoplasm changed from rank 3 to 12
#
# Secondary malignant neoplasm of digestive systems changed from rank 4 to 9
#
# Secondary malignant neoplasm of liver changed from rank 5 to 1
#
# Allergic rhinitis changed from rank 12 to 7
#
# Pneumococcal pneumonia changed from rank 8 to 12

# %%
def evaluate_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    # Create at-risk mask
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions for events vs non-events
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    
    # Could also add:
    # 1. ROC curve
    # 2. Disease-specific metrics
    # 3. Time-stratified evaluation
    
    return event_probs, nonevent_probs

# %%
def evaluate_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    # Create at-risk mask
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions for events vs non-events
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    
    # Could also add:
    # 1. ROC curve
    # 2. Disease-specific metrics
    # 3. Time-stratified evaluation
    
    return event_probs, nonevent_probs

evaluate_predictions(model, Y, E)

# %%
def visualize_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    plt.figure(figsize=(15, 5))
    
    # 1. Density plot of predictions
    plt.subplot(131)
    plt.hist(event_probs, bins=50, density=True, alpha=0.5, label='Events', color='red')
    plt.hist(nonevent_probs, bins=50, density=True, alpha=0.5, label='Non-events', color='blue')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Density')
    plt.title('Distribution of Predictions')
    plt.legend()
    
    # 2. ROC curve
    from sklearn.metrics import roc_curve, auc
    y_true = np.concatenate([np.ones_like(event_probs), np.zeros_like(nonevent_probs)])
    y_pred = np.concatenate([event_probs, nonevent_probs])
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    
    plt.subplot(132)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    
    # 3. Calibration plot
    from sklearn.calibration import calibration_curve
    prob_true, prob_pred = calibration_curve(y_true, y_pred, n_bins=10)
    
    plt.subplot(133)
    plt.plot(prob_pred, prob_true, marker='o', label='Model')
    plt.plot([0, 1], [0, 1], linestyle='--', label='Perfect calibration')
    plt.xlabel('Mean predicted probability')
    plt.ylabel('Empirical probability')
    plt.title('Calibration Plot')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    print(f"AUC: {roc_auc:.4f}")
    
    return event_probs, nonevent_probs, roc_auc

# %%
visualize_predictions(model, checkpoint['Y'], checkpoint['E'])
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_45390/3429516181.py:54: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /opt/miniconda3/envs/new_env_pyro2/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Average pi for events: 0.0003 (std: 0.0007)
# Average pi for non-events: 0.0002 (std: 0.0004)
# AUC: 0.6482
# (array([4.0490305e-04, 4.3596894e-05, 4.4185057e-05, ..., 2.9213037e-04,
#         2.2159352e-04, 3.0411309e-05], dtype=float32),
#  array([1.0436116e-05, 1.0434311e-05, 1.0887879e-05, ..., 3.2318268e-05,
#         3.0832874e-05, 3.0411309e-05], dtype=float32),
#  np.float64(0.6482404667187506))

# %%
def plot_event_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    # Get predictions for events and non-events
    events_mask = (Y == 1)
    nonevents_mask = (Y == 0)
    
    # Sample for speed (optional)
    n_samples = 10000
    event_probs = np.random.choice(pi_pred[events_mask], n_samples)
    nonevent_probs = np.random.choice(pi_pred[nonevents_mask], n_samples)
    
    plt.figure(figsize=(8, 5))
    plt.hist(event_probs, bins=50, density=True, alpha=0.5, 
             label=f'Events (mean={event_probs.mean():.4f})', color='red')
    plt.hist(nonevent_probs, bins=50, density=True, alpha=0.5, 
             label=f'Non-events (mean={nonevent_probs.mean():.4f})', color='blue')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Density')
    plt.title('Distribution of Predictions')
    plt.legend()
    plt.show()
    
    return event_probs, nonevent_probs
 
plot_event_predictions(model,checkpoint['Y'], checkpoint['E'])
# Out:
# (array([0.00082142, 0.00073744, 0.0007169 , ..., 0.00020729, 0.00044533,
#         0.00095262], dtype=float32),
#  array([3.9281924e-05, 1.3101171e-04, 8.4629073e-06, ..., 3.1404929e-07,
#         5.6211231e-04, 4.0696636e-05], dtype=float32))

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,3,4,15,16,18,19])

# %%
model.visualize_clusters(disease_names)
# Out:
# Cluster Assignments:
#
# Cluster 0:
#   - Degenerative disease of the spinal cord (prevalence: 0.0002)
#   - Spinal stenosis (prevalence: 0.0005)
#   - Spondylosis and allied disorders (prevalence: 0.0004)
#   - Spondylosis without myelopathy (prevalence: 0.0007)
#   - Displacement of intervertebral disc (prevalence: 0.0003)
#   - Degeneration of intervertebral disc (prevalence: 0.0003)
#   - Other and unspecified disc disorder (prevalence: 0.0004)
#   - Kyphoscoliosis and scoliosis (prevalence: 0.0002)
#   - Acquired spondylolisthesis (prevalence: 0.0002)
#   - Back pain (prevalence: 0.0012)
#   - Thoracic or lumbosacral neuritis or radiculitis, unspecified (prevalence: 0.0003)
#   - Sciatica (prevalence: 0.0003)
#   - Neuralgia, neuritis, and radiculitis NOS (prevalence: 0.0001)
#
# Cluster 1:
#   - Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] (prevalence: 0.0001)
#   - Malignant neoplasm of uterus (prevalence: 0.0001)
#   - Malignant neoplasm of ovary (prevalence: 0.0001)
#   - Uterine leiomyoma (prevalence: 0.0007)
#   - Benign neoplasm of ovary (prevalence: 0.0001)
#   - Pelvic peritoneal adhesions, female (postoperative) (postinfection) (prevalence: 0.0002)
#   - Cervicitis and endocervicitis (prevalence: 0.0001)
#   - Endometriosis (prevalence: 0.0003)
#   - Prolapse of vaginal walls (prevalence: 0.0005)
#   - Uterine/Uterovaginal prolapse (prevalence: 0.0004)
#   - Disorders of uterus, NEC (prevalence: 0.0002)
#   - Noninflammatory disorders of cervix (prevalence: 0.0002)
#   - Noninflammatory disorders of vagina (prevalence: 0.0001)
#   - Endometrial hyperplasia (prevalence: 0.0001)
#   - Polyp of corpus uteri (prevalence: 0.0006)
#   - Mucous polyp of cervix (prevalence: 0.0002)
#   - Hypertrophy of female genital organs (prevalence: 0.0001)
#   - Pain and other symptoms associated with female genital organs (prevalence: 0.0001)
#   - Disorders of menstruation and other abnormal bleeding from female genital tract (prevalence: 0.0001)
#   - Irregular menstrual cycle/bleeding (prevalence: 0.0001)
#   - Excessive or frequent menstruation (prevalence: 0.0005)
#   - Irregular menstrual cycle (prevalence: 0.0001)
#   - Irregular menstrual bleeding (prevalence: 0.0002)
#   - Dysmenorrhea (prevalence: 0.0001)
#   - Postmenopausal bleeding (prevalence: 0.0006)
#   - Postmenopausal atrophic vaginitis (prevalence: 0.0001)
#   - Ovarian cyst (prevalence: 0.0003)
#
# Cluster 2:
#   - Gout (prevalence: 0.0005)
#   - Hyperpotassemia (prevalence: 0.0002)
#   - Essential hypertension (prevalence: 0.0072)
#   - Hypertensive chronic kidney disease (prevalence: 0.0001)
#   - Chronic glomerulonephritis, NOS (prevalence: 0.0001)
#   - Renal failure NOS (prevalence: 0.0001)
#   - Chronic renal failure [CKD] (prevalence: 0.0005)
#   - Chronic Kidney Disease, Stage III (prevalence: 0.0006)
#   - Other disorders of the kidney and ureters (prevalence: 0.0001)
#   - Cyst of kidney, acquired (prevalence: 0.0003)
#   - Pyelonephritis (prevalence: 0.0002)
#
# Cluster 3:
#   - Hypercholesterolemia (prevalence: 0.0035)
#   - Unstable angina (intermediate coronary syndrome) (prevalence: 0.0004)
#   - Myocardial infarction (prevalence: 0.0012)
#   - Angina pectoris (prevalence: 0.0014)
#   - Coronary atherosclerosis (prevalence: 0.0017)
#   - Other chronic ischemic heart disease, unspecified (prevalence: 0.0015)
#   - Other acute and subacute forms of ischemic heart disease (prevalence: 0.0002)
#
# Cluster 4:
#   - Rheumatic disease of the heart valves (prevalence: 0.0002)
#   - Mitral valve disease (prevalence: 0.0003)
#   - Aortic valve disease (prevalence: 0.0002)
#   - Disease of tricuspid valve (prevalence: 0.0002)
#   - Other forms of chronic heart disease (prevalence: 0.0004)
#   - Cardiomegaly (prevalence: 0.0005)
#   - Pericarditis (prevalence: 0.0001)
#   - Primary/intrinsic cardiomyopathies (prevalence: 0.0001)
#   - First degree AV block (prevalence: 0.0002)
#   - Right bundle branch block (prevalence: 0.0003)
#   - Left bundle branch block (prevalence: 0.0003)
#   - Paroxysmal supraventricular tachycardia (prevalence: 0.0002)
#   - Paroxysmal ventricular tachycardia (prevalence: 0.0001)
#   - Atrial fibrillation and flutter (prevalence: 0.0010)
#   - Congestive heart failure (CHF) NOS (prevalence: 0.0004)
#   - Heart failure NOS (prevalence: 0.0007)
#   - Congenital anomalies of great vessels (prevalence: 0.0003)
#
# Cluster 5:
#   - Bacterial enteritis (prevalence: 0.0002)
#   - Viral Enteritis (prevalence: 0.0001)
#   - Viral warts & HPV (prevalence: 0.0001)
#   - Viral infection (prevalence: 0.0004)
#   - Melanomas of skin (prevalence: 0.0003)
#   - Other non-epithelial cancer of skin (prevalence: 0.0012)
#   - Breast cancer [female] (prevalence: 0.0002)
#   - Malignant neoplasm of female breast (prevalence: 0.0008)
#   - Malignant neoplasm of kidney, except pelvis (prevalence: 0.0001)
#   - Neoplasm of uncertain behavior (prevalence: 0.0002)
#   - Non-Hodgkins lymphoma (prevalence: 0.0001)
#   - Benign neoplasm of lip, oral cavity, and pharynx (prevalence: 0.0001)
#   - Lipoma (prevalence: 0.0002)
#   - Lipoma of skin and subcutaneous tissue (prevalence: 0.0003)
#   - Other benign neoplasm of connective and other soft tissue (prevalence: 0.0001)
#   - Benign neoplasm of skin (prevalence: 0.0006)
#   - Hemangioma and lymphangioma, any site (prevalence: 0.0001)
#   - Thyrotoxicosis with or without goiter (prevalence: 0.0002)
#   - Secondary hypothyroidism (prevalence: 0.0001)
#   - Hyperlipidemia (prevalence: 0.0006)
#   - Sleep disorders (prevalence: 0.0001)
#   - Sleep apnea (prevalence: 0.0005)
#   - Parkinson's disease (prevalence: 0.0002)
#   - Multiple sclerosis (prevalence: 0.0001)
#   - Epilepsy, recurrent seizures, convulsions (prevalence: 0.0003)
#   - Facial nerve disorders [CN7] (prevalence: 0.0001)
#   - Visual disturbances (prevalence: 0.0001)
#   - Inflammation of eyelids (prevalence: 0.0002)
#   - Disorders of conjunctiva (prevalence: 0.0001)
#   - Other disorders of eyelids (prevalence: 0.0002)
#   - Ectropion or entropion (prevalence: 0.0001)
#   - Ptosis of eyelid (prevalence: 0.0002)
#   - Disorders of lacrimal system (prevalence: 0.0002)
#   - Epiphora (prevalence: 0.0001)
#   - Strabismus (not specified as paralytic) (prevalence: 0.0001)
#   - Otitis media (prevalence: 0.0001)
#   - Perforation of tympanic membrane (prevalence: 0.0001)
#   - Hearing loss (prevalence: 0.0006)
#   - Pulmonary heart disease (prevalence: 0.0004)
#   - Cardiac arrest (prevalence: 0.0001)
#   - Arrhythmia (cardiac) NOS (prevalence: 0.0001)
#   - Abdominal aortic aneurysm (prevalence: 0.0001)
#   - Raynaud's syndrome (prevalence: 0.0002)
#   - Peripheral vascular disease, unspecified (prevalence: 0.0003)
#   - Stricture of artery (prevalence: 0.0001)
#   - Phlebitis and thrombophlebitis of lower extremities (prevalence: 0.0004)
#   - Varicose veins of lower extremity (prevalence: 0.0007)
#   - Acute upper respiratory infections of multiple or unspecified sites (prevalence: 0.0001)
#   - Acute pharyngitis (prevalence: 0.0001)
#   - Diseases of the larynx and vocal cords (prevalence: 0.0001)
#   - Chronic tonsillitis and adenoiditis (prevalence: 0.0001)
#   - Allergic rhinitis (prevalence: 0.0002)
#   - Asthma (prevalence: 0.0022)
#   - Disturbances in tooth eruption (prevalence: 0.0001)
#   - Periapical abscess (prevalence: 0.0001)
#   - Chronic periodontitis (prevalence: 0.0001)
#   - Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue (prevalence: 0.0002)
#   - Diseases and other conditions of the tongue (prevalence: 0.0001)
#   - Acute gastritis (prevalence: 0.0001)
#   - Acute appendicitis (prevalence: 0.0002)
#   - Inguinal hernia (prevalence: 0.0012)
#   - Umbilical hernia (prevalence: 0.0003)
#   - Celiac disease (prevalence: 0.0002)
#   - Functional digestive disorders (prevalence: 0.0001)
#   - Other disorders of liver (prevalence: 0.0003)
#   - Blood in stool (prevalence: 0.0002)
#   - Other symptoms/disorders or the urinary system (prevalence: 0.0001)
#   - Other disorders of testis (prevalence: 0.0001)
#   - Hydrocele (prevalence: 0.0001)
#   - Redundant prepuce and phimosis/BXO (prevalence: 0.0002)
#   - Other disorders of male genital organs (prevalence: 0.0002)
#   - Benign neoplasm of breast (prevalence: 0.0001)
#   - Lump or mass in breast (prevalence: 0.0001)
#   - Hypertrophy of breast (Gynecomastia) (prevalence: 0.0001)
#   - Noninflammatory disorders of vulva and perineum (prevalence: 0.0001)
#   - Dyspareunia (prevalence: 0.0001)
#   - Infertility, female (prevalence: 0.0001)
#   - Carbuncle and furuncle (prevalence: 0.0002)
#   - Disorder of skin and subcutaneous tissue NOS (prevalence: 0.0005)
#   - Psoriasis vulgaris (prevalence: 0.0002)
#   - Other hypertrophic and atrophic conditions of skin (prevalence: 0.0001)
#   - Scar conditions and fibrosis of skin (prevalence: 0.0002)
#   - Actinic keratosis (prevalence: 0.0003)
#   - Seborrheic keratosis (prevalence: 0.0003)
#   - Ingrowing nail (prevalence: 0.0001)
#   - Sebaceous cyst (prevalence: 0.0006)
#   - Other inflammatory spondylopathies (prevalence: 0.0001)
#   - Polymyalgia Rheumatica (prevalence: 0.0002)
#   - Bursitis (prevalence: 0.0001)
#   - Ganglion and cyst of synovium, tendon, and bursa (prevalence: 0.0002)
#   - Contracture of palmar fascia [Dupuytren's disease] (prevalence: 0.0003)
#   - Other disorders of bone and cartilage (prevalence: 0.0004)
#   - Malunion and nonunion of fracture (prevalence: 0.0001)
#   - Osteopenia or other disorder of bone and cartilage (prevalence: 0.0001)
#   - Abdominal pain (prevalence: 0.0008)
#   - Atopic/contact dermatitis due to other or unspecified (prevalence: 0.0003)
#   - Other tests (prevalence: 0.0003)
#
# Cluster 6:
#   - Septal Deviations/Turbinate Hypertrophy (prevalence: 0.0003)
#   - Nasal polyps (prevalence: 0.0002)
#   - Chronic pharyngitis and nasopharyngitis (prevalence: 0.0001)
#   - Chronic sinusitis (prevalence: 0.0002)
#   - Other upper respiratory disease (prevalence: 0.0003)
#
# Cluster 7:
#   - Obesity (prevalence: 0.0018)
#   - Other peripheral nerve disorders (prevalence: 0.0010)
#   - Rheumatoid arthritis (prevalence: 0.0005)
#   - Arthropathy NOS (prevalence: 0.0041)
#   - Peripheral enthesopathies and allied syndromes (prevalence: 0.0005)
#   - Enthesopathy (prevalence: 0.0009)
#   - Other disorders of synovium, tendon, and bursa (prevalence: 0.0001)
#   - Synovitis and tenosynovitis (prevalence: 0.0002)
#   - Other disorders of soft tissues (prevalence: 0.0005)
#   - Acquired toe deformities (prevalence: 0.0002)
#   - Hammer toe (acquired) (prevalence: 0.0002)
#   - Hallux rigidus (prevalence: 0.0001)
#   - Hallux valgus (Bunion) (prevalence: 0.0005)
#   - Other acquired deformities of limbs (prevalence: 0.0002)
#   - Osteoarthritis; localized (prevalence: 0.0011)
#   - Osteoarthrosis, localized, primary (prevalence: 0.0006)
#   - Osteoarthrosis, generalized (prevalence: 0.0005)
#   - Osteoarthrosis NOS (prevalence: 0.0001)
#   - Symptoms and disorders of the joints (prevalence: 0.0001)
#   - Joint effusions (prevalence: 0.0002)
#   - Other derangement of joint (prevalence: 0.0002)
#   - Pain in joint (prevalence: 0.0008)
#   - Pain in limb (prevalence: 0.0006)
#   - Internal derangement of knee (prevalence: 0.0010)
#
# Cluster 8:
#   - Hypothyroidism NOS (prevalence: 0.0014)
#   - Bipolar (prevalence: 0.0001)
#   - Major depressive disorder (prevalence: 0.0014)
#   - Anxiety disorder (prevalence: 0.0011)
#   - Alcohol-related disorders (prevalence: 0.0005)
#   - Alcoholic liver damage (prevalence: 0.0001)
#   - Migraine (prevalence: 0.0003)
#   - Dental caries (prevalence: 0.0003)
#   - Other diseases of the teeth and supporting structures (prevalence: 0.0002)
#   - Irritable Bowel Syndrome (prevalence: 0.0006)
#   - Other chronic nonalcoholic liver disease (prevalence: 0.0003)
#   - Hematemesis (prevalence: 0.0002)
#   - Rheumatism, unspecified and fibrositis (prevalence: 0.0001)
#   - Osteoporosis NOS (prevalence: 0.0009)
#   - Cervicalgia (prevalence: 0.0002)
#   - Myalgia and myositis unspecified (prevalence: 0.0002)
#
# Cluster 9:
#   - Hemiplegia (prevalence: 0.0002)
#   - Cerebrovascular disease (prevalence: 0.0002)
#   - Occlusion and stenosis of precerebral arteries (prevalence: 0.0001)
#   - Occlusion of cerebral arteries (prevalence: 0.0003)
#   - Cerebral artery occlusion, with cerebral infarction (prevalence: 0.0003)
#   - Cerebral ischemia (prevalence: 0.0003)
#   - Transient cerebral ischemia (prevalence: 0.0002)
#   - Late effects of cerebrovascular disease (prevalence: 0.0002)
#
# Cluster 10:
#   - Cancer of bronchus; lung (prevalence: 0.0003)
#   - Tobacco use disorder (prevalence: 0.0012)
#   - Pneumonia (prevalence: 0.0006)
#   - Pneumococcal pneumonia (prevalence: 0.0009)
#   - Chronic airway obstruction (prevalence: 0.0009)
#   - Emphysema (prevalence: 0.0002)
#   - Obstructive chronic bronchitis (prevalence: 0.0004)
#   - Bronchiectasis (prevalence: 0.0003)
#   - Postinflammatory pulmonary fibrosis (prevalence: 0.0002)
#   - Empyema and pneumothorax (prevalence: 0.0001)
#   - Pleurisy; pleural effusion (prevalence: 0.0009)
#   - Pulmonary collapse; interstitial and compensatory emphysema (prevalence: 0.0005)
#   - Respiratory failure (prevalence: 0.0004)
#
# Cluster 11:
#   - Colon cancer (prevalence: 0.0003)
#   - Malignant neoplasm of rectum, rectosigmoid junction, and anus (prevalence: 0.0002)
#   - Neoplasm of unspecified nature of digestive system (prevalence: 0.0001)
#   - Benign neoplasm of colon (prevalence: 0.0023)
#   - Hemorrhoids (prevalence: 0.0023)
#   - Ventral hernia (prevalence: 0.0003)
#   - Regional enteritis (prevalence: 0.0001)
#   - Ulcerative colitis (prevalence: 0.0002)
#   - Noninfectious gastroenteritis (prevalence: 0.0011)
#   - Other intestinal obstruction (prevalence: 0.0004)
#   - Diverticulosis (prevalence: 0.0031)
#   - Anal and rectal conditions (prevalence: 0.0007)
#   - Anal and rectal polyp (prevalence: 0.0008)
#   - Peritonitis and retroperitoneal infections (prevalence: 0.0001)
#   - Other disorders of intestine (prevalence: 0.0004)
#   - Gastrointestinal complications (prevalence: 0.0001)
#   - Hemorrhage of rectum and anus (prevalence: 0.0009)
#   - Hemorrhage of gastrointestinal tract (prevalence: 0.0007)
#
# Cluster 12:
#   - Benign neoplasm of other parts of digestive system (prevalence: 0.0006)
#   - Iron deficiency anemias, unspecified or not due to blood loss (prevalence: 0.0010)
#   - Esophagitis, GERD and related diseases (prevalence: 0.0008)
#   - GERD (prevalence: 0.0020)
#   - Ulcer of esophagus (prevalence: 0.0004)
#   - Barrett's esophagus (prevalence: 0.0004)
#   - Reflux esophagitis (prevalence: 0.0009)
#   - Esophageal bleeding (varices/hemorrhage) (prevalence: 0.0002)
#   - Stricture and stenosis of esophagus (prevalence: 0.0002)
#   - Gastric ulcer (prevalence: 0.0004)
#   - Duodenal ulcer (prevalence: 0.0002)
#   - Gastritis and duodenitis (prevalence: 0.0015)
#   - Duodenitis (prevalence: 0.0007)
#   - Other specified gastritis (prevalence: 0.0009)
#   - Other disorders of stomach and duodenum (prevalence: 0.0004)
#   - Diaphragmatic hernia (prevalence: 0.0025)
#
# Cluster 13:
#   - Cancer of prostate (prevalence: 0.0007)
#   - Malignant neoplasm of bladder (prevalence: 0.0002)
#   - Cystitis (prevalence: 0.0002)
#   - Chronic cystitis (prevalence: 0.0001)
#   - Other disorders of bladder (prevalence: 0.0007)
#   - Bladder neck obstruction (prevalence: 0.0002)
#   - Functional disorders of bladder (prevalence: 0.0001)
#   - Urethral stricture (not specified as infectious) (prevalence: 0.0003)
#   - Urinary incontinence (prevalence: 0.0005)
#   - Hyperplasia of prostate (prevalence: 0.0013)
#   - Chronic prostatitis (prevalence: 0.0001)
#   - Other disorders of prostate (prevalence: 0.0001)
#
# Cluster 14:
#   - Type 1 diabetes (prevalence: 0.0002)
#   - Type 2 diabetes (prevalence: 0.0020)
#   - Type 2 diabetes with ophthalmic manifestations (prevalence: 0.0002)
#   - Diabetic retinopathy (prevalence: 0.0002)
#   - Hypoglycemia (prevalence: 0.0002)
#
# Cluster 15:
#   - Gram negative septicemia (prevalence: 0.0002)
#   - Bacterial infection NOS (prevalence: 0.0006)
#   - Staphylococcus infections (prevalence: 0.0003)
#   - Streptococcus infection (prevalence: 0.0002)
#   - E. coli (prevalence: 0.0004)
#   - Candidiasis (prevalence: 0.0003)
#   - Disorders of calcium/phosphorus metabolism (prevalence: 0.0002)
#   - Hyposmolality and/or hyponatremia (prevalence: 0.0005)
#   - Hypopotassemia (prevalence: 0.0004)
#   - Acidosis (prevalence: 0.0002)
#   - Hypovolemia (prevalence: 0.0006)
#   - Other anemias (prevalence: 0.0014)
#   - Thrombocytopenia (prevalence: 0.0002)
#   - Neutropenia (prevalence: 0.0003)
#   - Inflammatory and toxic neuropathy (prevalence: 0.0002)
#   - Orthostatic hypotension (prevalence: 0.0003)
#   - Hypotension NOS (prevalence: 0.0006)
#   - Bacterial pneumonia (prevalence: 0.0001)
#   - Other diseases of respiratory system, NEC (prevalence: 0.0008)
#   - Constipation (prevalence: 0.0015)
#   - Acute renal failure (prevalence: 0.0011)
#   - Urinary tract infection (prevalence: 0.0014)
#   - Cellulitis and abscess of arm/hand (prevalence: 0.0006)
#   - Other local infections of skin and subcutaneous tissue (prevalence: 0.0002)
#   - Chronic ulcer of skin (prevalence: 0.0002)
#   - Decubitus ulcer (prevalence: 0.0003)
#   - Sepsis (prevalence: 0.0006)
#
# Cluster 16:
#   - Retinal detachments and defects (prevalence: 0.0002)
#   - Retinal detachment with retinal defect (prevalence: 0.0001)
#   - Other retinal disorders (prevalence: 0.0001)
#   - Macular degeneration (senile) of retina NOS (prevalence: 0.0005)
#   - Retinal vascular changes and abnomalities (prevalence: 0.0001)
#   - Glaucoma (prevalence: 0.0006)
#   - Primary open angle glaucoma (prevalence: 0.0002)
#   - Cataract (prevalence: 0.0021)
#   - Senile cataract (prevalence: 0.0016)
#   - Myopia (prevalence: 0.0002)
#   - Disorders of vitreous body (prevalence: 0.0002)
#
# Cluster 17:
#   - Stricture/obstruction of ureter (prevalence: 0.0001)
#   - Calculus of kidney (prevalence: 0.0003)
#   - Calculus of ureter (prevalence: 0.0002)
#   - Renal colic (prevalence: 0.0001)
#   - Hydronephrosis (prevalence: 0.0003)
#
# Cluster 18:
#   - Peritoneal adhesions (postoperative) (postinfection) (prevalence: 0.0004)
#   - Cholelithiasis (prevalence: 0.0008)
#   - Cholelithiasis with acute cholecystitis (prevalence: 0.0002)
#   - Cholelithiasis with other cholecystitis (prevalence: 0.0005)
#   - Calculus of bile duct (prevalence: 0.0002)
#   - Cholecystitis without cholelithiasis (prevalence: 0.0002)
#   - Other disorders of gallbladder (prevalence: 0.0002)
#   - Other disorders of biliary tract (prevalence: 0.0001)
#   - Acute pancreatitis (prevalence: 0.0002)
#
# Cluster 19:
#   - Malignant neoplasm, other (prevalence: 0.0002)
#   - Secondary malignant neoplasm (prevalence: 0.0002)
#   - Secondary malignancy of lymph nodes (prevalence: 0.0006)
#   - Secondary malignancy of respiratory organs (prevalence: 0.0003)
#   - Secondary malignant neoplasm of digestive systems (prevalence: 0.0002)
#   - Secondary malignant neoplasm of liver (prevalence: 0.0004)
#   - Secondary malignancy of bone (prevalence: 0.0003)

# %%
def evaluate_survival_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred = model.forward()[0].cpu().numpy()
    
    remaining_risks = []
    true_outcomes = []
    
    # First, let's check what events we actually have
    print("Total events in Y:", np.sum(Y))
    print("Distribution of event_times:", np.bincount(event_times.flatten()))
    
    N, D, T = Y.shape
    n_samples = 0
    n_events = 0
    
    # Look at a single example first
    n, d = 0, 0
    print(f"\nExample for patient {n}, disease {d}:")
    print(f"Event time: {event_times[n,d]}")
    print(f"Y sequence: {Y[n,d,:]}")
    print(f"Has any event: {np.any(Y[n,d,:] == 1)}")
    
    # Modified evaluation
    for n in range(N):
        for d in range(D):
            event_t = event_times[n,d]
            for t in range(event_t):  # Only look until event time
                n_samples += 1
                # Did event occur after time t?
                if np.any(Y[n,d,t:event_t] == 1):
                    n_events += 1
                    true_outcomes.append(1)
                else:
                    true_outcomes.append(0)
                # Compute remaining risk
                remaining_risks.append(1 - np.prod(1 - pi_pred[n,d,t:event_t]))
    
    print(f"\nTotal samples evaluated: {n_samples}")
    print(f"Number of positive events: {n_events}")
    
    if n_events > 0:
        auc = roc_auc_score(true_outcomes, remaining_risks)
        return auc
    else:
        print("No events found!")
        return None

# %%
evaluate_survival_predictions(model, Y, E)

# %%
def compare_clustering_evolution(model, checkpoint):
    # Get initial cluster assignments from spectral clustering
    initial_clusters = checkpoint['clusters']
    
    # Get final learned parameters
    final_psi = model.psi.detach().numpy()
    final_phi = model.phi.detach().numpy()
    prevalence_logit = model.logit_prev_t.detach().numpy()
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(final_phi)
    for k in range(final_phi.shape[0]):
        for d in range(final_phi.shape[1]):
            phi_centered[k, d, :] = final_phi[k, d, :] - prevalence_logit[d, :]
    
    # Compare initial vs final clustering
    plt.figure(figsize=(15, 5))
    
    # 1. Plot initial psi values
    plt.subplot(131)
    initial_psi = np.zeros((model.K, model.D))
    for k in range(model.K):
        cluster_mask = (initial_clusters == k)
        initial_psi[k, cluster_mask] = 1.0
        initial_psi[k, ~cluster_mask] = -3.0
    plt.imshow(initial_psi, aspect='auto', cmap='RdBu_r')
    plt.title('Initial Psi (from spectral clustering)')
    plt.colorbar()
    
    # 2. Plot final psi values
    plt.subplot(132)
    plt.imshow(final_psi, aspect='auto', cmap='RdBu_r')
    plt.title('Final Learned Psi')
    plt.colorbar()
    
    # 3. Plot average phi_centered
    plt.subplot(133)
    mean_phi_centered = phi_centered.mean(axis=2)  # Average over time
    plt.imshow(mean_phi_centered, aspect='auto', cmap='RdBu_r')
    plt.title('Time-averaged Centered Phi')
    plt.colorbar()
    
    plt.tight_layout()
    plt.show()
    
    # Print some statistics
    print("\nChanges in cluster assignments:")
    for k in range(model.K):
        initial_mask = (initial_clusters == k)
        final_strong = (final_psi[k] > 0)
        
        print(f"\nCluster {k}:")
        print(f"Initially assigned: {initial_mask.sum()} diseases")
        print(f"Final strong membership: {final_strong.sum()} diseases")
        print(f"Overlap: {(initial_mask & final_strong).sum()} diseases")
        
    return initial_psi, final_psi, mean_phi_centered

compare_clustering_evolution(model,checkpoint)

# %%
from sklearn.metrics import roc_auc_score

def evaluate_survival_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred = model.forward()[0].cpu().numpy()
    
    N, D, T = Y.shape
    results = []
    
    # Evaluate every 5 years
    evaluation_times = range(0, T, 5)  # Every 5 years
    print(f"Evaluating at times: {list(evaluation_times)}")
    
    for t in evaluation_times:
        print(f"\nEvaluating from time {t} (age {t+30}):")
        
        for d in range(D):
            remaining_risks = []
            true_outcomes = []
            
            for n in range(N):
                # Check if still at risk (no events before time t)
                if np.sum(Y[n,d,:t]) == 0:
                    # Calculate remaining lifetime risk from t onwards
                    future_pi = pi_pred[n,d,t:]
                    remaining_risk = 1 - np.prod(1 - future_pi)
                    
                    # Check if event occurs in remaining lifetime
                    future_event = np.any(Y[n,d,t:] == 1)
                    
                    remaining_risks.append(remaining_risk)
                    true_outcomes.append(future_event)
            
            if len(true_outcomes) > 0:
                n_events = sum(true_outcomes)
                n_total = len(true_outcomes)
                
                if n_events > 0 and n_events < n_total:
                    auc = roc_auc_score(true_outcomes, remaining_risks)
                    results.append({
                        'time': t,
                        'age': t + 30,
                        'disease': d,
                        'auc': auc,
                        'n_at_risk': n_total,
                        'n_events': n_events,
                        'event_rate': n_events/n_total
                    })
                    print(f"Disease {d}: AUC={auc:.3f}, Events={n_events}/{n_total}")
    
    return pd.DataFrame(results)

# %%
evaluate_survival_predictions(model,Y,E)

# %%
import seaborn as sns
def plot_survival_results(results_df):
    plt.figure(figsize=(15, 10))
    
    # 1. AUC distribution over time
    plt.subplot(221)
    sns.boxplot(data=results_df, x='age', y='auc')
    plt.title('AUC Distribution by Age')
    plt.xticks(rotation=45)
    plt.axhline(y=0.5, color='r', linestyle='--', alpha=0.5)
    
    # 2. Mean AUC by disease ID
    plt.subplot(222)
    disease_aucs = (results_df.groupby('disease')['auc']
                   .mean()
                   .sort_values(ascending=False))
    sns.barplot(x=range(len(disease_aucs)), y=disease_aucs.values)
    plt.title('Diseases Ranked by Mean AUC')
    plt.xlabel('Disease Rank')
    plt.ylabel('Mean AUC')
    
    # 3. Event rates over time
    plt.subplot(223)
    sns.boxplot(data=results_df, x='age', y='event_rate')
    plt.title('Event Rate Distribution by Age')
    plt.xticks(rotation=45)
    
    # 4. Population at risk over time
    plt.subplot(224)
    sns.boxplot(data=results_df, x='age', y='n_at_risk')
    plt.title('Population at Risk by Age')
    plt.xticks(rotation=45)
    
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print("\nOverall AUC Summary:")
    print(results_df.groupby('age')['auc'].describe())
    
    return results_df



results = evaluate_survival_predictions(model, Y, E)
# Use with previous results
plot_survival_results(results)

# %%
print("Real data summary:")
print(f"Event rates per disease:")
Y_real = Y # Your real data tensor
print(Y_real.sum(axis=(0,2))/Y_real.shape[0])  # Per person rate

print("\nTime distribution of events:")
print(Y_real.sum(axis=(0,1))/Y_real.shape[0])

# %%
# Plot smoothed prevalence for each disease
epsilon=1e-8
logit_prev_t = torch.log(
            (model.prevalence_t + epsilon) / (1 - model.prevalence_t + epsilon)
        )  # D 
for d in range(Y.shape[1]):
    plt.plot(logit_prev_t[d,:], alpha=0.5, label=f'Disease {d}' if d < 5 else '')

# %%
checkpoint['Y'].shape
# Out:
# torch.Size([10000, 348, 52])

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# %%
predicted_risk.shape
# Out:
# (18096,)

# %%
# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000451
# Mean predicted risk (original): 0.000158
# Mean predicted risk (calibrated): 0.000451
# Calibration scale factor: 2.862

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.776

# %%
def analyze_phi_evolution(model):
    """Analyze how phi changes while psi remains stable"""
    # 1. Look at deviation from mean function
    phi_deviation = model.phi -(model.logit_prev_t + model.psi.unsqueeze(-1))
    
    # 2. Check temporal patterns
    phi_temporal = torch.mean(phi_deviation, dim=1)  # Average across diseases
    
    # 3. Compare cluster-specific patterns
    for k in range(model.K):
        cluster_mask = (model.clusters == k)
        phi_k = model.phi[k, cluster_mask, :]
        
        print(f"\nCluster {k} phi statistics:")
        print(f"Mean deviation: {phi_deviation[k].mean():.3f}")
        print(f"Temporal variance: {phi_temporal[k].var():.3f}")

# %%
analyze_phi_evolution(model)

# %%
initial_phi

# %%
model.phi

# %%
def visualize_phi_changes(initial_phi, final_phi):
    """Visualize changes in phi from initial to final values"""
    
    plt.figure(figsize=(15, 5))
    K,D,T=final_phi.shape
    # Plot initial phi
    plt.subplot(131)
    for k in range(K):
        for d in range(min(3, D)):  # Plot first 3 diseases for clarity
            plt.plot(initial_phi[k, d, :].cpu().numpy(), 
                     label=f'Cluster {k}, Disease {d}')
    plt.title('Initial φ')
    plt.xlabel('Time')
    plt.ylabel('φ Value')
    plt.legend()
    
    # Plot final phi
    plt.subplot(132)
    for k in range(K):
        for d in range(min(3, D)):
            plt.plot(final_phi[k, d, :].cpu().numpy(), 
                     label=f'Cluster {k}, Disease {d}')
    plt.title('Final φ')
    plt.xlabel('Time')
    plt.ylabel('φ Value')
    plt.legend()
    
    # Plot change in phi
    plt.subplot(133)
    phi_diff = final_phi - initial_phi
    for k in range(K):
        for d in range(min(3, D)):
            plt.plot(phi_diff[k, d, :].cpu().numpy(), 
                     label=f'Cluster {k}, Disease {d}')
    plt.title('Change in φ')
    plt.xlabel('Time')
    plt.ylabel('Δφ')
    plt.legend()
    
    plt.suptitle('φ Evolution')
    plt.tight_layout()
    plt.show()

# %%
final_phi = model.phi.detach()
final_phi.shape

# %%
# Visualize changes
visualize_phi_changes(initial_phi, final_phi)

# %%
final_lambda = model.lambda_.detach()
final_lambda.shape

# %%
def visualize_lambda_changes(initial_lambda, final_lambda):
    """Visualize changes in phi from initial to final values"""
    
    plt.figure(figsize=(15, 5))
    N,K,T=final_lambda.shape
    # Plot initial phi
    plt.subplot(131)
    for k in range(K):
        for n in range(min(3, N)):  # Plot first 3 diseases for clarity
            plt.plot(initial_lambda[n, k, :].cpu().numpy(), 
                     label=f'Cluster {k}, Person {n}')
    plt.title('Initial lambda')
    plt.xlabel('Time')
    plt.ylabel('lambda Value')
    plt.legend()
    
    # Plot final phi
    plt.subplot(132)
    for k in range(K):
        for n in range(min(3, N)):  # Plot first 3 diseases for clarity
            plt.plot(final_lambda[n, k, :].cpu().numpy(), 
                     label=f'Cluster {k}, Person {n}')
    plt.title('Final lambda')
    plt.xlabel('Time')
    plt.ylabel('lambda Value')
    plt.legend()
    
    # Plot change in phi
    plt.subplot(133)
    phi_diff = final_lambda- initial_lambda
    for k in range(K):
        for n in range(min(3, N)):
            plt.plot(phi_diff[n, k, :].cpu().numpy(), 
                     label=f'Cluster {k}, Person {n}')
    plt.title('Change in lambda')
    plt.xlabel('Time')
    plt.ylabel('ΔLambda')
    plt.legend()
    
    plt.suptitle('Lambda Evolution')
    plt.tight_layout()
    plt.show()

visualize_lambda_changes(initial_lambda,final_lambda)

# %%
# Instead of model.fit(), use:
# Initialize model
model_efficient = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(N, D, T, K, P, G, Y, prevalence_t, disease_names_list)

# Store initial psi values
initial_psi = model.psi.detach().clone()
initial_phi=model.phi.detach().clone()
initial_lambda=model.lambda_.detach().clone()

history = model_efficient.fit_efficient(
    E_tensor,
    learning_rate=1e-4,
    param_change_threshold=1e-3,  # Adjust based on your needs
    consecutive_threshold=3  # Stop after 3 consecutive small changes
)
