# %%
import rpy2.robjects as robjects
import numpy as np
import os as os
from rpy2.robjects import numpy2ri
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
# Out:
# /opt/miniconda3/envs/pyro_env/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 2.0.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 9
#       7 import torch.optim as optim
#       8 import numpy as np
# ----> 9 from scipy.spatial.distance import pdist, squareform
#      10 from scipy.special import expit
#      11 from scipy.stats import multivariate_normal
#
# File /opt/miniconda3/envs/pyro_env/lib/python3.9/site-packages/scipy/spatial/__init__.py:96
#       1 """
#       2 =============================================================
#       3 Spatial algorithms and data structures (:mod:`scipy.spatial`)
#    (...)
#      93
#      94 """
# ---> 96 from .kdtree import *
#      97 from .ckdtree import *
#      98 from .qhull import *
#
# File /opt/miniconda3/envs/pyro_env/lib/python3.9/site-packages/scipy/spatial/kdtree.py:5
#       3 import numpy as np
#       4 import warnings
# ----> 5 from .ckdtree import cKDTree, cKDTreeNode
#       7 __all__ = ['minkowski_distance_p', 'minkowski_distance',
#       8            'distance_matrix',
#       9            'Rectangle', 'KDTree']
#      12 def minkowski_distance_p(x, y, p=2):
#
# File ckdtree.pyx:1, in init scipy.spatial.ckdtree()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# %load_ext autoreload
# %autoreload 2
# Specify the path to your data files
data_path = "/Users/sarahurbut/tensornoulli_ehr_new/data"

# Activate automatic conversion between R and NumPy arrays
numpy2ri.activate()# Load data saved as .rds files
Y = np.array(robjects.r['readRDS'](os.path.join(data_path, 'Y.rds')))
E = np.array(robjects.r['readRDS'](os.path.join(data_path, 'event_for_aladynoulli.rds')))
G = np.array(robjects.r['readRDS'](os.path.join(data_path, 'prs.rds')))

E = E.astype(int)

# G should be float64
G = G.astype(float)
G.shape
G = G.T
print("G shape after transposition:", G.shape)

# Convert to PyTorch tensors
Y_tensor = torch.FloatTensor(Y)
E_tensor = torch.FloatTensor(E)
G_tensor = torch.FloatTensor(G)

# Get dimensions
N, D, T = Y_tensor.shape
P = G_tensor.shape[1]
T = int(E_tensor.max() + 1)  # 0-indexed time
K = 10  # number of topics

# Print shapes to verify
print("Tensor shapes:")
print(f"Y: {Y_tensor.shape}")  # [N, D]
print(f"E: {E_tensor.shape}")  # [N, D]
print(f"G: {G_tensor.shape}")  # [N, P]
print(f"Time range: 0 to {T-1}")
print(T)
print(K)


import rpy2.robjects as robjects
import pandas as pd
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the metadata from R
disease_names = pd.DataFrame(robjects.r['readRDS']('/Users/sarahurbut/Dropbox (Personal)/disease_names.rds'))
prs_names = pd.DataFrame(robjects.r['readRDS']('/Users/sarahurbut/Dropbox (Personal)/prs_names.rds'))
disease_names_list = disease_names[0].tolist()

# %%
from cluster_g_logit_init import *
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

# %%
prevalence_t=compute_smoothed_prevalence(Y=Y,window_size=5)
K=20
# Create model
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(N, D, T, K, P, G, Y, prevalence_t)
# Visualize the clusters
model.visualize_clusters(disease_names_list)
# Out:
# Lambda kernel condition number: 45200668.00
# Phi kernel condition number: 89734320.00
#
# Cluster Sizes:
# Cluster 0: 27 diseases
# Cluster 1: 32 diseases
# Cluster 2: 12 diseases
# Cluster 3: 9 diseases
# Cluster 4: 19 diseases
# Cluster 5: 74 diseases
# Cluster 6: 31 diseases
# Cluster 7: 12 diseases
# Cluster 8: 10 diseases
# Cluster 9: 8 diseases
# Cluster 10: 5 diseases
# Cluster 11: 10 diseases
# Cluster 12: 6 diseases
# Cluster 13: 12 diseases
# Cluster 14: 14 diseases
# Cluster 15: 9 diseases
# Cluster 16: 23 diseases
# Cluster 17: 5 diseases
# Cluster 18: 18 diseases
# Cluster 19: 12 diseases
# Initialization complete!
#
# Cluster Assignments:
#
# Cluster 0:
#   - Polyp of corpus uteri (prevalence: 0.0007)
#   - Postmenopausal bleeding (prevalence: 0.0008)
#   - Ovarian cyst (prevalence: 0.0004)
#   - Benign neoplasm of ovary (prevalence: 0.0001)
#   - Pelvic peritoneal adhesions, female (postoperative) (postinfection) (prevalence: 0.0003)
#   - Malignant neoplasm of uterus (prevalence: 0.0002)
#   - Prolapse of vaginal walls (prevalence: 0.0007)
#   - Mucous polyp of cervix (prevalence: 0.0002)
#   - Noninflammatory disorders of cervix (prevalence: 0.0003)
#   - Uterine leiomyoma (prevalence: 0.0009)
#   - Postmenopausal atrophic vaginitis (prevalence: 0.0001)
#   - Noninflammatory disorders of vagina (prevalence: 0.0001)
#   - Disorders of uterus, NEC (prevalence: 0.0003)
#   - Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] (prevalence: 0.0001)
#   - Endometrial hyperplasia (prevalence: 0.0001)
#   - Cervicitis and endocervicitis (prevalence: 0.0001)
#   - Dysmenorrhea (prevalence: 0.0001)
#   - Excessive or frequent menstruation (prevalence: 0.0007)
#   - Uterine/Uterovaginal prolapse (prevalence: 0.0005)
#   - Endometriosis (prevalence: 0.0003)
#   - Irregular menstrual cycle/bleeding (prevalence: 0.0001)
#   - Irregular menstrual bleeding (prevalence: 0.0002)
#   - Disorders of menstruation and other abnormal bleeding from female genital tract (prevalence: 0.0001)
#   - Hypertrophy of female genital organs (prevalence: 0.0001)
#   - Pain and other symptoms associated with female genital organs (prevalence: 0.0001)
#   - Irregular menstrual cycle (prevalence: 0.0001)
#   - Dyspareunia (prevalence: 0.0001)
#
# Cluster 1:
#   - Other peripheral nerve disorders (prevalence: 0.0013)
#   - Obesity (prevalence: 0.0025)
#   - Major depressive disorder (prevalence: 0.0021)
#   - Arthropathy NOS (prevalence: 0.0057)
#   - Other disorders of bone and cartilage (prevalence: 0.0005)
#   - Osteoarthrosis, generalized (prevalence: 0.0008)
#   - Spondylosis and allied disorders (prevalence: 0.0006)
#   - Osteoarthritis; localized (prevalence: 0.0014)
#   - Enthesopathy (prevalence: 0.0012)
#   - Osteoarthrosis, localized, primary (prevalence: 0.0008)
#   - Synovitis and tenosynovitis (prevalence: 0.0004)
#   - Rheumatoid arthritis (prevalence: 0.0007)
#   - Anxiety disorder (prevalence: 0.0015)
#   - Pain in limb (prevalence: 0.0009)
#   - Myalgia and myositis unspecified (prevalence: 0.0003)
#   - Hammer toe (acquired) (prevalence: 0.0002)
#   - Internal derangement of knee (prevalence: 0.0013)
#   - Peripheral enthesopathies and allied syndromes (prevalence: 0.0007)
#   - Other derangement of joint (prevalence: 0.0003)
#   - Acquired toe deformities (prevalence: 0.0002)
#   - Hallux valgus (Bunion) (prevalence: 0.0005)
#   - Other inflammatory spondylopathies (prevalence: 0.0002)
#   - Malunion and nonunion of fracture (prevalence: 0.0001)
#   - Pain in joint (prevalence: 0.0011)
#   - Other acquired deformities of limbs (prevalence: 0.0002)
#   - Symptoms and disorders of the joints (prevalence: 0.0001)
#   - Rheumatism, unspecified and fibrositis (prevalence: 0.0001)
#   - Cervicalgia (prevalence: 0.0003)
#   - Ingrowing nail (prevalence: 0.0001)
#   - Hallux rigidus (prevalence: 0.0001)
#   - Other disorders of synovium, tendon, and bursa (prevalence: 0.0001)
#   - Osteoarthrosis NOS (prevalence: 0.0001)
#
# Cluster 2:
#   - Back pain (prevalence: 0.0017)
#   - Kyphoscoliosis and scoliosis (prevalence: 0.0002)
#   - Degenerative disease of the spinal cord (prevalence: 0.0002)
#   - Spinal stenosis (prevalence: 0.0007)
#   - Acquired spondylolisthesis (prevalence: 0.0003)
#   - Other and unspecified disc disorder (prevalence: 0.0006)
#   - Thoracic or lumbosacral neuritis or radiculitis, unspecified (prevalence: 0.0005)
#   - Degeneration of intervertebral disc (prevalence: 0.0005)
#   - Spondylosis without myelopathy (prevalence: 0.0010)
#   - Displacement of intervertebral disc (prevalence: 0.0004)
#   - Neuralgia, neuritis, and radiculitis NOS (prevalence: 0.0002)
#   - Sciatica (prevalence: 0.0004)
#
# Cluster 3:
#   - Peritoneal adhesions (postoperative) (postinfection) (prevalence: 0.0006)
#   - Cholelithiasis (prevalence: 0.0011)
#   - Acute pancreatitis (prevalence: 0.0003)
#   - Cholelithiasis with other cholecystitis (prevalence: 0.0006)
#   - Other disorders of biliary tract (prevalence: 0.0002)
#   - Calculus of bile duct (prevalence: 0.0003)
#   - Cholecystitis without cholelithiasis (prevalence: 0.0003)
#   - Cholelithiasis with acute cholecystitis (prevalence: 0.0002)
#   - Other disorders of gallbladder (prevalence: 0.0002)
#
# Cluster 4:
#   - Cardiomegaly (prevalence: 0.0007)
#   - Pericarditis (prevalence: 0.0002)
#   - Pleurisy; pleural effusion (prevalence: 0.0013)
#   - Aortic valve disease (prevalence: 0.0002)
#   - Congenital anomalies of great vessels (prevalence: 0.0004)
#   - Congestive heart failure (CHF) NOS (prevalence: 0.0006)
#   - Atrial fibrillation and flutter (prevalence: 0.0014)
#   - Other forms of chronic heart disease (prevalence: 0.0006)
#   - Left bundle branch block (prevalence: 0.0004)
#   - Heart failure NOS (prevalence: 0.0009)
#   - Rheumatic disease of the heart valves (prevalence: 0.0004)
#   - First degree AV block (prevalence: 0.0003)
#   - Mitral valve disease (prevalence: 0.0005)
#   - Cardiac arrest (prevalence: 0.0002)
#   - Paroxysmal ventricular tachycardia (prevalence: 0.0002)
#   - Primary/intrinsic cardiomyopathies (prevalence: 0.0002)
#   - Disease of tricuspid valve (prevalence: 0.0003)
#   - Paroxysmal supraventricular tachycardia (prevalence: 0.0004)
#   - Right bundle branch block (prevalence: 0.0004)
#
# Cluster 5:
#   - Other diseases of the teeth and supporting structures (prevalence: 0.0003)
#   - Malignant neoplasm of kidney, except pelvis (prevalence: 0.0002)
#   - Irritable Bowel Syndrome (prevalence: 0.0010)
#   - Visual disturbances (prevalence: 0.0002)
#   - Dental caries (prevalence: 0.0003)
#   - Polymyalgia Rheumatica (prevalence: 0.0003)
#   - Osteoporosis NOS (prevalence: 0.0013)
#   - Breast cancer [female] (prevalence: 0.0002)
#   - Functional digestive disorders (prevalence: 0.0001)
#   - Secondary hypothyroidism (prevalence: 0.0002)
#   - Hypothyroidism NOS (prevalence: 0.0019)
#   - Viral infection (prevalence: 0.0005)
#   - Chronic Kidney Disease, Stage III (prevalence: 0.0010)
#   - Lipoma of skin and subcutaneous tissue (prevalence: 0.0004)
#   - Non-Hodgkins lymphoma (prevalence: 0.0002)
#   - Epiphora (prevalence: 0.0001)
#   - Melanomas of skin (prevalence: 0.0003)
#   - Benign neoplasm of skin (prevalence: 0.0007)
#   - Actinic keratosis (prevalence: 0.0004)
#   - Other disorders of eyelids (prevalence: 0.0004)
#   - Other disorders of the kidney and ureters (prevalence: 0.0002)
#   - Acute upper respiratory infections of multiple or unspecified sites (prevalence: 0.0002)
#   - Acute appendicitis (prevalence: 0.0003)
#   - Abdominal pain (prevalence: 0.0012)
#   - Disorders of conjunctiva (prevalence: 0.0001)
#   - Chronic tonsillitis and adenoiditis (prevalence: 0.0001)
#   - Other tests (prevalence: 0.0003)
#   - Other hypertrophic and atrophic conditions of skin (prevalence: 0.0002)
#   - Osteopenia or other disorder of bone and cartilage (prevalence: 0.0001)
#   - Parkinson's disease (prevalence: 0.0002)
#   - Hypertensive chronic kidney disease (prevalence: 0.0002)
#   - Other non-epithelial cancer of skin (prevalence: 0.0013)
#   - Seborrheic keratosis (prevalence: 0.0004)
#   - Migraine (prevalence: 0.0004)
#   - Celiac disease (prevalence: 0.0002)
#   - Raynaud's syndrome (prevalence: 0.0002)
#   - Hearing loss (prevalence: 0.0007)
#   - Other benign neoplasm of connective and other soft tissue (prevalence: 0.0001)
#   - Inflammatory and toxic neuropathy (prevalence: 0.0003)
#   - Thyrotoxicosis with or without goiter (prevalence: 0.0002)
#   - Neoplasm of uncertain behavior (prevalence: 0.0002)
#   - Viral Enteritis (prevalence: 0.0001)
#   - Ptosis of eyelid (prevalence: 0.0002)
#   - Facial nerve disorders [CN7] (prevalence: 0.0001)
#   - Diseases of the larynx and vocal cords (prevalence: 0.0002)
#   - Ectropion or entropion (prevalence: 0.0002)
#   - Disorders of lacrimal system (prevalence: 0.0003)
#   - Perforation of tympanic membrane (prevalence: 0.0001)
#   - Bacterial enteritis (prevalence: 0.0003)
#   - Varicose veins of lower extremity (prevalence: 0.0008)
#   - Disturbances in tooth eruption (prevalence: 0.0001)
#   - Hemangioma and lymphangioma, any site (prevalence: 0.0002)
#   - Renal failure NOS (prevalence: 0.0002)
#   - Noninflammatory disorders of vulva and perineum (prevalence: 0.0001)
#   - Multiple sclerosis (prevalence: 0.0001)
#   - Allergic rhinitis (prevalence: 0.0003)
#   - Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue (prevalence: 0.0002)
#   - Benign neoplasm of breast (prevalence: 0.0001)
#   - Ganglion and cyst of synovium, tendon, and bursa (prevalence: 0.0003)
#   - Strabismus (not specified as paralytic) (prevalence: 0.0001)
#   - Scar conditions and fibrosis of skin (prevalence: 0.0002)
#   - Arrhythmia (cardiac) NOS (prevalence: 0.0002)
#   - Inflammation of eyelids (prevalence: 0.0002)
#   - Chronic glomerulonephritis, NOS (prevalence: 0.0001)
#   - Acute gastritis (prevalence: 0.0001)
#   - Periapical abscess (prevalence: 0.0001)
#   - Diseases and other conditions of the tongue (prevalence: 0.0001)
#   - Hypertrophy of breast (Gynecomastia) (prevalence: 0.0001)
#   - Chronic periodontitis (prevalence: 0.0001)
#   - Other symptoms/disorders or the urinary system (prevalence: 0.0001)
#   - Acute pharyngitis (prevalence: 0.0001)
#   - Infertility, female (prevalence: 0.0000)
#   - Lump or mass in breast (prevalence: 0.0001)
#   - Viral warts & HPV (prevalence: 0.0001)
#
# Cluster 6:
#   - Peritonitis and retroperitoneal infections (prevalence: 0.0001)
#   - Pulmonary heart disease (prevalence: 0.0006)
#   - Sebaceous cyst (prevalence: 0.0007)
#   - Other disorders of liver (prevalence: 0.0004)
#   - Cyst of kidney, acquired (prevalence: 0.0004)
#   - Other disorders of testis (prevalence: 0.0001)
#   - Umbilical hernia (prevalence: 0.0004)
#   - Epilepsy, recurrent seizures, convulsions (prevalence: 0.0004)
#   - Inguinal hernia (prevalence: 0.0015)
#   - Hydrocele (prevalence: 0.0001)
#   - Blood in stool (prevalence: 0.0003)
#   - Alcohol-related disorders (prevalence: 0.0007)
#   - Bipolar (prevalence: 0.0001)
#   - Sleep apnea (prevalence: 0.0007)
#   - Gout (prevalence: 0.0007)
#   - Disorder of skin and subcutaneous tissue NOS (prevalence: 0.0007)
#   - Other chronic nonalcoholic liver disease (prevalence: 0.0005)
#   - Contracture of palmar fascia [Dupuytren's disease] (prevalence: 0.0004)
#   - Atopic/contact dermatitis due to other or unspecified (prevalence: 0.0004)
#   - Other disorders of male genital organs (prevalence: 0.0003)
#   - Retinal vascular changes and abnomalities (prevalence: 0.0002)
#   - Duodenal ulcer (prevalence: 0.0003)
#   - Sleep disorders (prevalence: 0.0001)
#   - Lipoma (prevalence: 0.0002)
#   - Abdominal aortic aneurysm (prevalence: 0.0002)
#   - Bursitis (prevalence: 0.0001)
#   - Psoriasis vulgaris (prevalence: 0.0003)
#   - Alcoholic liver damage (prevalence: 0.0002)
#   - Hematemesis (prevalence: 0.0003)
#   - Redundant prepuce and phimosis/BXO (prevalence: 0.0003)
#   - Benign neoplasm of lip, oral cavity, and pharynx (prevalence: 0.0001)
#
# Cluster 7:
#   - Pneumonia (prevalence: 0.0008)
#   - Pneumococcal pneumonia (prevalence: 0.0012)
#   - Asthma (prevalence: 0.0031)
#   - Respiratory failure (prevalence: 0.0007)
#   - Pulmonary collapse; interstitial and compensatory emphysema (prevalence: 0.0007)
#   - Postinflammatory pulmonary fibrosis (prevalence: 0.0002)
#   - Tobacco use disorder (prevalence: 0.0016)
#   - Chronic airway obstruction (prevalence: 0.0013)
#   - Bronchiectasis (prevalence: 0.0004)
#   - Emphysema (prevalence: 0.0003)
#   - Obstructive chronic bronchitis (prevalence: 0.0005)
#   - Empyema and pneumothorax (prevalence: 0.0002)
#
# Cluster 8:
#   - Cataract (prevalence: 0.0025)
#   - Macular degeneration (senile) of retina NOS (prevalence: 0.0006)
#   - Myopia (prevalence: 0.0003)
#   - Senile cataract (prevalence: 0.0021)
#   - Disorders of vitreous body (prevalence: 0.0003)
#   - Primary open angle glaucoma (prevalence: 0.0002)
#   - Other retinal disorders (prevalence: 0.0002)
#   - Glaucoma (prevalence: 0.0008)
#   - Retinal detachment with retinal defect (prevalence: 0.0002)
#   - Retinal detachments and defects (prevalence: 0.0002)
#
# Cluster 9:
#   - Cerebral artery occlusion, with cerebral infarction (prevalence: 0.0004)
#   - Hemiplegia (prevalence: 0.0003)
#   - Late effects of cerebrovascular disease (prevalence: 0.0002)
#   - Occlusion of cerebral arteries (prevalence: 0.0003)
#   - Cerebral ischemia (prevalence: 0.0004)
#   - Cerebrovascular disease (prevalence: 0.0003)
#   - Transient cerebral ischemia (prevalence: 0.0003)
#   - Occlusion and stenosis of precerebral arteries (prevalence: 0.0002)
#
# Cluster 10:
#   - Type 2 diabetes (prevalence: 0.0029)
#   - Hypoglycemia (prevalence: 0.0002)
#   - Type 1 diabetes (prevalence: 0.0003)
#   - Diabetic retinopathy (prevalence: 0.0002)
#   - Type 2 diabetes with ophthalmic manifestations (prevalence: 0.0003)
#
# Cluster 11:
#   - Secondary malignancy of lymph nodes (prevalence: 0.0008)
#   - Secondary malignant neoplasm of liver (prevalence: 0.0005)
#   - Secondary malignancy of bone (prevalence: 0.0005)
#   - Malignant neoplasm of female breast (prevalence: 0.0010)
#   - Secondary malignancy of respiratory organs (prevalence: 0.0004)
#   - Malignant neoplasm, other (prevalence: 0.0003)
#   - Cancer of bronchus; lung (prevalence: 0.0004)
#   - Secondary malignant neoplasm (prevalence: 0.0003)
#   - Malignant neoplasm of ovary (prevalence: 0.0001)
#   - Secondary malignant neoplasm of digestive systems (prevalence: 0.0003)
#
# Cluster 12:
#   - Other upper respiratory disease (prevalence: 0.0004)
#   - Chronic pharyngitis and nasopharyngitis (prevalence: 0.0001)
#   - Septal Deviations/Turbinate Hypertrophy (prevalence: 0.0004)
#   - Chronic sinusitis (prevalence: 0.0003)
#   - Nasal polyps (prevalence: 0.0003)
#   - Otitis media (prevalence: 0.0001)
#
# Cluster 13:
#   - Decubitus ulcer (prevalence: 0.0004)
#   - Streptococcus infection (prevalence: 0.0003)
#   - Cellulitis and abscess of arm/hand (prevalence: 0.0008)
#   - Chronic ulcer of skin (prevalence: 0.0003)
#   - Other disorders of soft tissues (prevalence: 0.0008)
#   - Staphylococcus infections (prevalence: 0.0005)
#   - Carbuncle and furuncle (prevalence: 0.0003)
#   - Peripheral vascular disease, unspecified (prevalence: 0.0004)
#   - Phlebitis and thrombophlebitis of lower extremities (prevalence: 0.0005)
#   - Joint effusions (prevalence: 0.0002)
#   - Other local infections of skin and subcutaneous tissue (prevalence: 0.0002)
#   - Stricture of artery (prevalence: 0.0001)
#
# Cluster 14:
#   - Other specified gastritis (prevalence: 0.0014)
#   - Esophagitis, GERD and related diseases (prevalence: 0.0011)
#   - Gastritis and duodenitis (prevalence: 0.0022)
#   - Duodenitis (prevalence: 0.0010)
#   - GERD (prevalence: 0.0030)
#   - Benign neoplasm of other parts of digestive system (prevalence: 0.0010)
#   - Diaphragmatic hernia (prevalence: 0.0036)
#   - Stricture and stenosis of esophagus (prevalence: 0.0003)
#   - Esophageal bleeding (varices/hemorrhage) (prevalence: 0.0003)
#   - Barrett's esophagus (prevalence: 0.0005)
#   - Other disorders of stomach and duodenum (prevalence: 0.0006)
#   - Gastric ulcer (prevalence: 0.0006)
#   - Ulcer of esophagus (prevalence: 0.0006)
#   - Reflux esophagitis (prevalence: 0.0013)
#
# Cluster 15:
#   - Essential hypertension (prevalence: 0.0100)
#   - Hypercholesterolemia (prevalence: 0.0049)
#   - Coronary atherosclerosis (prevalence: 0.0025)
#   - Other chronic ischemic heart disease, unspecified (prevalence: 0.0022)
#   - Myocardial infarction (prevalence: 0.0017)
#   - Angina pectoris (prevalence: 0.0021)
#   - Unstable angina (intermediate coronary syndrome) (prevalence: 0.0006)
#   - Hyperlipidemia (prevalence: 0.0009)
#   - Other acute and subacute forms of ischemic heart disease (prevalence: 0.0003)
#
# Cluster 16:
#   - Thrombocytopenia (prevalence: 0.0002)
#   - Other anemias (prevalence: 0.0020)
#   - Hypovolemia (prevalence: 0.0008)
#   - Hypotension NOS (prevalence: 0.0008)
#   - Hyposmolality and/or hyponatremia (prevalence: 0.0007)
#   - Acute renal failure (prevalence: 0.0016)
#   - Candidiasis (prevalence: 0.0004)
#   - Constipation (prevalence: 0.0021)
#   - Bacterial infection NOS (prevalence: 0.0009)
#   - Urinary tract infection (prevalence: 0.0019)
#   - Other diseases of respiratory system, NEC (prevalence: 0.0011)
#   - Chronic renal failure [CKD] (prevalence: 0.0007)
#   - Orthostatic hypotension (prevalence: 0.0004)
#   - Hypopotassemia (prevalence: 0.0005)
#   - Gram negative septicemia (prevalence: 0.0002)
#   - Neutropenia (prevalence: 0.0005)
#   - Sepsis (prevalence: 0.0008)
#   - Acidosis (prevalence: 0.0003)
#   - E. coli (prevalence: 0.0005)
#   - Hyperpotassemia (prevalence: 0.0003)
#   - Pyelonephritis (prevalence: 0.0002)
#   - Disorders of calcium/phosphorus metabolism (prevalence: 0.0003)
#   - Bacterial pneumonia (prevalence: 0.0002)
#
# Cluster 17:
#   - Stricture/obstruction of ureter (prevalence: 0.0002)
#   - Hydronephrosis (prevalence: 0.0004)
#   - Calculus of ureter (prevalence: 0.0003)
#   - Renal colic (prevalence: 0.0001)
#   - Calculus of kidney (prevalence: 0.0004)
#
# Cluster 18:
#   - Gastrointestinal complications (prevalence: 0.0001)
#   - Diverticulosis (prevalence: 0.0042)
#   - Colon cancer (prevalence: 0.0005)
#   - Benign neoplasm of colon (prevalence: 0.0030)
#   - Iron deficiency anemias, unspecified or not due to blood loss (prevalence: 0.0015)
#   - Malignant neoplasm of rectum, rectosigmoid junction, and anus (prevalence: 0.0003)
#   - Hemorrhage of gastrointestinal tract (prevalence: 0.0009)
#   - Other disorders of intestine (prevalence: 0.0006)
#   - Hemorrhoids (prevalence: 0.0030)
#   - Anal and rectal conditions (prevalence: 0.0010)
#   - Other intestinal obstruction (prevalence: 0.0005)
#   - Ulcerative colitis (prevalence: 0.0004)
#   - Anal and rectal polyp (prevalence: 0.0011)
#   - Ventral hernia (prevalence: 0.0004)
#   - Regional enteritis (prevalence: 0.0002)
#   - Hemorrhage of rectum and anus (prevalence: 0.0012)
#   - Noninfectious gastroenteritis (prevalence: 0.0014)
#   - Neoplasm of unspecified nature of digestive system (prevalence: 0.0002)
#
# Cluster 19:
#   - Chronic prostatitis (prevalence: 0.0001)
#   - Hyperplasia of prostate (prevalence: 0.0017)
#   - Cancer of prostate (prevalence: 0.0009)
#   - Other disorders of prostate (prevalence: 0.0002)
#   - Bladder neck obstruction (prevalence: 0.0002)
#   - Other disorders of bladder (prevalence: 0.0011)
#   - Cystitis (prevalence: 0.0003)
#   - Urinary incontinence (prevalence: 0.0007)
#   - Urethral stricture (not specified as infectious) (prevalence: 0.0004)
#   - Malignant neoplasm of bladder (prevalence: 0.0003)
#   - Functional disorders of bladder (prevalence: 0.0002)
#   - Chronic cystitis (prevalence: 0.0001)

# %%
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(N, D, T, K, P, G, Y, prevalence_t,disease_names_list)
model.print_cluster_memberships()
model.plot_initial_params()
# Out:
# Lambda kernel condition number: 45200668.00
# Phi kernel condition number: 89734320.00
#
# Cluster Sizes:
# Cluster 0: 27 diseases
# Cluster 1: 32 diseases
# Cluster 2: 12 diseases
# Cluster 3: 9 diseases
# Cluster 4: 19 diseases
# Cluster 5: 74 diseases
# Cluster 6: 31 diseases
# Cluster 7: 12 diseases
# Cluster 8: 10 diseases
# Cluster 9: 8 diseases
# Cluster 10: 5 diseases
# Cluster 11: 10 diseases
# Cluster 12: 6 diseases
# Cluster 13: 12 diseases
# Cluster 14: 14 diseases
# Cluster 15: 9 diseases
# Cluster 16: 23 diseases
# Cluster 17: 5 diseases
# Cluster 18: 18 diseases
# Cluster 19: 12 diseases
# Initialization complete!
#
# Cluster Memberships:
#
# Cluster 0 (Size: 27)
# Diseases:
#   84: Polyp of corpus uteri
#   86: Postmenopausal bleeding
#   87: Ovarian cyst
#   91: Benign neoplasm of ovary
#   92: Pelvic peritoneal adhesions, female (postoperative) (postinfection)
#   93: Malignant neoplasm of uterus
#   96: Prolapse of vaginal walls
#   100: Mucous polyp of cervix
#   103: Noninflammatory disorders of cervix
#   153: Uterine leiomyoma
#   156: Postmenopausal atrophic vaginitis
#   163: Noninflammatory disorders of vagina
#   170: Disorders of uterus, NEC
#   209: Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]
#   230: Endometrial hyperplasia
#   232: Cervicitis and endocervicitis
#   247: Dysmenorrhea
#   248: Excessive or frequent menstruation
#   254: Uterine/Uterovaginal prolapse
#   285: Endometriosis
#   293: Irregular menstrual cycle/bleeding
#   297: Irregular menstrual bleeding
#   314: Disorders of menstruation and other abnormal bleeding from female genital tract
#   316: Hypertrophy of female genital organs
#   317: Pain and other symptoms associated with female genital organs
#   330: Irregular menstrual cycle
#   347: Dyspareunia
# Average prevalence in cluster: 0.000
#
# Cluster 1 (Size: 32)
# Diseases:
#   2: Other peripheral nerve disorders
#   32: Obesity
#   45: Major depressive disorder
#   57: Arthropathy NOS
#   62: Other disorders of bone and cartilage
#   64: Osteoarthrosis, generalized
#   75: Spondylosis and allied disorders
#   76: Osteoarthritis; localized
#   79: Enthesopathy
#   80: Osteoarthrosis, localized, primary
#   115: Synovitis and tenosynovitis
#   124: Rheumatoid arthritis
#   145: Anxiety disorder
#   168: Pain in limb
#   171: Myalgia and myositis unspecified
#   173: Hammer toe (acquired)
#   186: Internal derangement of knee
#   188: Peripheral enthesopathies and allied syndromes
#   204: Other derangement of joint
#   223: Acquired toe deformities
#   225: Hallux valgus (Bunion)
#   239: Other inflammatory spondylopathies
#   253: Malunion and nonunion of fracture
#   257: Pain in joint
#   278: Other acquired deformities of limbs
#   279: Symptoms and disorders of the joints
#   281: Rheumatism, unspecified and fibrositis
#   282: Cervicalgia
#   284: Ingrowing nail
#   312: Hallux rigidus
#   329: Other disorders of synovium, tendon, and bursa
#   335: Osteoarthrosis NOS
# Average prevalence in cluster: 0.001
#
# Cluster 2 (Size: 12)
# Diseases:
#   59: Back pain
#   78: Kyphoscoliosis and scoliosis
#   141: Degenerative disease of the spinal cord
#   198: Spinal stenosis
#   200: Acquired spondylolisthesis
#   264: Other and unspecified disc disorder
#   265: Thoracic or lumbosacral neuritis or radiculitis, unspecified
#   266: Degeneration of intervertebral disc
#   280: Spondylosis without myelopathy
#   301: Displacement of intervertebral disc
#   308: Neuralgia, neuritis, and radiculitis NOS
#   315: Sciatica
# Average prevalence in cluster: 0.001
#
# Cluster 3 (Size: 9)
# Diseases:
#   28: Peritoneal adhesions (postoperative) (postinfection)
#   41: Cholelithiasis
#   53: Acute pancreatitis
#   95: Cholelithiasis with other cholecystitis
#   133: Other disorders of biliary tract
#   187: Calculus of bile duct
#   313: Cholecystitis without cholelithiasis
#   318: Cholelithiasis with acute cholecystitis
#   322: Other disorders of gallbladder
# Average prevalence in cluster: 0.000
#
# Cluster 4 (Size: 19)
# Diseases:
#   8: Cardiomegaly
#   11: Pericarditis
#   12: Pleurisy; pleural effusion
#   102: Aortic valve disease
#   107: Congenital anomalies of great vessels
#   152: Congestive heart failure (CHF) NOS
#   181: Atrial fibrillation and flutter
#   242: Other forms of chronic heart disease
#   243: Left bundle branch block
#   251: Heart failure NOS
#   256: Rheumatic disease of the heart valves
#   261: First degree AV block
#   275: Mitral valve disease
#   276: Cardiac arrest
#   277: Paroxysmal ventricular tachycardia
#   286: Primary/intrinsic cardiomyopathies
#   290: Disease of tricuspid valve
#   296: Paroxysmal supraventricular tachycardia
#   306: Right bundle branch block
# Average prevalence in cluster: 0.001
#
# Cluster 5 (Size: 74)
# Diseases:
#   14: Other diseases of the teeth and supporting structures
#   27: Malignant neoplasm of kidney, except pelvis
#   43: Irritable Bowel Syndrome
#   46: Visual disturbances
#   51: Dental caries
#   65: Polymyalgia Rheumatica
#   68: Osteoporosis NOS
#   77: Breast cancer [female]
#   89: Functional digestive disorders
#   101: Secondary hypothyroidism
#   108: Hypothyroidism NOS
#   123: Viral infection
#   128: Chronic Kidney Disease, Stage III
#   137: Lipoma of skin and subcutaneous tissue
#   142: Non-Hodgkins lymphoma
#   143: Epiphora
#   144: Melanomas of skin
#   146: Benign neoplasm of skin
#   147: Actinic keratosis
#   148: Other disorders of eyelids
#   154: Other disorders of the kidney and ureters
#   155: Acute upper respiratory infections of multiple or unspecified sites
#   158: Acute appendicitis
#   160: Abdominal pain
#   161: Disorders of conjunctiva
#   166: Chronic tonsillitis and adenoiditis
#   169: Other tests
#   172: Other hypertrophic and atrophic conditions of skin
#   183: Osteopenia or other disorder of bone and cartilage
#   184: Parkinson's disease
#   190: Hypertensive chronic kidney disease
#   202: Other non-epithelial cancer of skin
#   205: Seborrheic keratosis
#   211: Migraine
#   212: Celiac disease
#   215: Raynaud's syndrome
#   216: Hearing loss
#   220: Other benign neoplasm of connective and other soft tissue
#   221: Inflammatory and toxic neuropathy
#   226: Thyrotoxicosis with or without goiter
#   227: Neoplasm of uncertain behavior
#   228: Viral Enteritis
#   236: Ptosis of eyelid
#   237: Facial nerve disorders [CN7]
#   238: Diseases of the larynx and vocal cords
#   240: Ectropion or entropion
#   241: Disorders of lacrimal system
#   252: Perforation of tympanic membrane
#   259: Bacterial enteritis
#   260: Varicose veins of lower extremity
#   263: Disturbances in tooth eruption
#   267: Hemangioma and lymphangioma, any site
#   269: Renal failure NOS
#   271: Noninflammatory disorders of vulva and perineum
#   283: Multiple sclerosis
#   287: Allergic rhinitis
#   288: Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue
#   295: Benign neoplasm of breast
#   298: Ganglion and cyst of synovium, tendon, and bursa
#   299: Strabismus (not specified as paralytic)
#   300: Scar conditions and fibrosis of skin
#   311: Arrhythmia (cardiac) NOS
#   321: Inflammation of eyelids
#   325: Chronic glomerulonephritis, NOS
#   326: Acute gastritis
#   331: Periapical abscess
#   334: Diseases and other conditions of the tongue
#   336: Hypertrophy of breast (Gynecomastia)
#   339: Chronic periodontitis
#   342: Other symptoms/disorders or the urinary system
#   343: Acute pharyngitis
#   344: Infertility, female
#   345: Lump or mass in breast
#   346: Viral warts & HPV
# Average prevalence in cluster: 0.000
#
# Cluster 6 (Size: 31)
# Diseases:
#   3: Peritonitis and retroperitoneal infections
#   31: Pulmonary heart disease
#   34: Sebaceous cyst
#   37: Other disorders of liver
#   40: Cyst of kidney, acquired
#   67: Other disorders of testis
#   83: Umbilical hernia
#   88: Epilepsy, recurrent seizures, convulsions
#   118: Inguinal hernia
#   120: Hydrocele
#   125: Blood in stool
#   134: Alcohol-related disorders
#   135: Bipolar
#   140: Sleep apnea
#   149: Gout
#   151: Disorder of skin and subcutaneous tissue NOS
#   180: Other chronic nonalcoholic liver disease
#   185: Contracture of palmar fascia [Dupuytren's disease]
#   191: Atopic/contact dermatitis due to other or unspecified
#   196: Other disorders of male genital organs
#   201: Retinal vascular changes and abnomalities
#   203: Duodenal ulcer
#   234: Sleep disorders
#   291: Lipoma
#   292: Abdominal aortic aneurysm
#   305: Bursitis
#   307: Psoriasis vulgaris
#   327: Alcoholic liver damage
#   328: Hematemesis
#   332: Redundant prepuce and phimosis/BXO
#   333: Benign neoplasm of lip, oral cavity, and pharynx
# Average prevalence in cluster: 0.000
#
# Cluster 7 (Size: 12)
# Diseases:
#   16: Pneumonia
#   19: Pneumococcal pneumonia
#   44: Asthma
#   119: Respiratory failure
#   122: Pulmonary collapse; interstitial and compensatory emphysema
#   138: Postinflammatory pulmonary fibrosis
#   159: Tobacco use disorder
#   174: Chronic airway obstruction
#   222: Bronchiectasis
#   272: Emphysema
#   303: Obstructive chronic bronchitis
#   304: Empyema and pneumothorax
# Average prevalence in cluster: 0.001
#
# Cluster 8 (Size: 10)
# Diseases:
#   47: Cataract
#   48: Macular degeneration (senile) of retina NOS
#   49: Myopia
#   85: Senile cataract
#   112: Disorders of vitreous body
#   182: Primary open angle glaucoma
#   235: Other retinal disorders
#   249: Glaucoma
#   258: Retinal detachment with retinal defect
#   274: Retinal detachments and defects
# Average prevalence in cluster: 0.001
#
# Cluster 9 (Size: 8)
# Diseases:
#   35: Cerebral artery occlusion, with cerebral infarction
#   38: Hemiplegia
#   175: Late effects of cerebrovascular disease
#   177: Occlusion of cerebral arteries
#   178: Cerebral ischemia
#   179: Cerebrovascular disease
#   270: Transient cerebral ischemia
#   324: Occlusion and stenosis of precerebral arteries
# Average prevalence in cluster: 0.000
#
# Cluster 10 (Size: 5)
# Diseases:
#   82: Type 2 diabetes
#   127: Hypoglycemia
#   213: Type 1 diabetes
#   229: Diabetic retinopathy
#   231: Type 2 diabetes with ophthalmic manifestations
# Average prevalence in cluster: 0.001
#
# Cluster 11 (Size: 10)
# Diseases:
#   33: Secondary malignancy of lymph nodes
#   36: Secondary malignant neoplasm of liver
#   42: Secondary malignancy of bone
#   72: Malignant neoplasm of female breast
#   73: Secondary malignancy of respiratory organs
#   129: Malignant neoplasm, other
#   244: Cancer of bronchus; lung
#   273: Secondary malignant neoplasm
#   340: Malignant neoplasm of ovary
#   341: Secondary malignant neoplasm of digestive systems
# Average prevalence in cluster: 0.000
#
# Cluster 12 (Size: 6)
# Diseases:
#   167: Other upper respiratory disease
#   218: Chronic pharyngitis and nasopharyngitis
#   219: Septal Deviations/Turbinate Hypertrophy
#   246: Chronic sinusitis
#   320: Nasal polyps
#   338: Otitis media
# Average prevalence in cluster: 0.000
#
# Cluster 13 (Size: 12)
# Diseases:
#   66: Decubitus ulcer
#   106: Streptococcus infection
#   136: Cellulitis and abscess of arm/hand
#   150: Chronic ulcer of skin
#   157: Other disorders of soft tissues
#   195: Staphylococcus infections
#   214: Carbuncle and furuncle
#   245: Peripheral vascular disease, unspecified
#   262: Phlebitis and thrombophlebitis of lower extremities
#   309: Joint effusions
#   319: Other local infections of skin and subcutaneous tissue
#   323: Stricture of artery
# Average prevalence in cluster: 0.000
#
# Cluster 14 (Size: 14)
# Diseases:
#   20: Other specified gastritis
#   22: Esophagitis, GERD and related diseases
#   54: Gastritis and duodenitis
#   55: Duodenitis
#   56: GERD
#   71: Benign neoplasm of other parts of digestive system
#   90: Diaphragmatic hernia
#   98: Stricture and stenosis of esophagus
#   132: Esophageal bleeding (varices/hemorrhage)
#   139: Barrett's esophagus
#   162: Other disorders of stomach and duodenum
#   199: Gastric ulcer
#   210: Ulcer of esophagus
#   224: Reflux esophagitis
# Average prevalence in cluster: 0.001
#
# Cluster 15 (Size: 9)
# Diseases:
#   26: Essential hypertension
#   30: Hypercholesterolemia
#   110: Coronary atherosclerosis
#   111: Other chronic ischemic heart disease, unspecified
#   113: Myocardial infarction
#   114: Angina pectoris
#   116: Unstable angina (intermediate coronary syndrome)
#   194: Hyperlipidemia
#   302: Other acute and subacute forms of ischemic heart disease
# Average prevalence in cluster: 0.003
#
# Cluster 16 (Size: 23)
# Diseases:
#   6: Thrombocytopenia
#   7: Other anemias
#   10: Hypovolemia
#   13: Hypotension NOS
#   17: Hyposmolality and/or hyponatremia
#   29: Acute renal failure
#   58: Candidiasis
#   60: Constipation
#   61: Bacterial infection NOS
#   63: Urinary tract infection
#   74: Other diseases of respiratory system, NEC
#   81: Chronic renal failure [CKD]
#   97: Orthostatic hypotension
#   99: Hypopotassemia
#   104: Gram negative septicemia
#   105: Neutropenia
#   109: Sepsis
#   130: Acidosis
#   176: E. coli
#   197: Hyperpotassemia
#   207: Pyelonephritis
#   233: Disorders of calcium/phosphorus metabolism
#   310: Bacterial pneumonia
# Average prevalence in cluster: 0.001
#
# Cluster 17 (Size: 5)
# Diseases:
#   131: Stricture/obstruction of ureter
#   189: Hydronephrosis
#   208: Calculus of ureter
#   268: Renal colic
#   289: Calculus of kidney
# Average prevalence in cluster: 0.000
#
# Cluster 18 (Size: 18)
# Diseases:
#   1: Gastrointestinal complications
#   5: Diverticulosis
#   9: Colon cancer
#   15: Benign neoplasm of colon
#   18: Iron deficiency anemias, unspecified or not due to blood loss
#   21: Malignant neoplasm of rectum, rectosigmoid junction, and anus
#   24: Hemorrhage of gastrointestinal tract
#   39: Other disorders of intestine
#   50: Hemorrhoids
#   52: Anal and rectal conditions
#   70: Other intestinal obstruction
#   117: Ulcerative colitis
#   121: Anal and rectal polyp
#   126: Ventral hernia
#   206: Regional enteritis
#   217: Hemorrhage of rectum and anus
#   250: Noninfectious gastroenteritis
#   337: Neoplasm of unspecified nature of digestive system
# Average prevalence in cluster: 0.001
#
# Cluster 19 (Size: 12)
# Diseases:
#   0: Chronic prostatitis
#   4: Hyperplasia of prostate
#   23: Cancer of prostate
#   25: Other disorders of prostate
#   69: Bladder neck obstruction
#   94: Other disorders of bladder
#   164: Cystitis
#   165: Urinary incontinence
#   192: Urethral stricture (not specified as infectious)
#   193: Malignant neoplasm of bladder
#   255: Functional disorders of bladder
#   294: Chronic cystitis
# Average prevalence in cluster: 0.001
# Cluster membership for sampled diseases:
# Disease 153: Cluster 0
# Disease 160: Cluster 5
# Disease 342: Cluster 5
# Disease 156: Cluster 0
# Disease 281: Cluster 1

# %%
model.visualize_initialization()
model.psi
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init.py:803: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()
# Parameter containing:
# tensor([[-3.0085, -2.9869, -2.9931,  ..., -3.0128, -2.9955,  0.9120],
#         [-3.0271, -3.0061,  1.0490,  ..., -3.0082, -3.0147, -3.0035],
#         [-2.9966, -3.0310, -3.0146,  ..., -3.0146, -2.9810, -3.0004],
#         ...,
#         [-3.0076, -2.9820, -2.9933,  ..., -3.0036, -3.0034, -3.0108],
#         [-2.9896,  0.9241, -3.0030,  ..., -3.0058, -3.0034, -3.0022],
#         [ 0.9714, -2.9871, -2.9939,  ..., -2.9911, -2.9901, -2.9893]],
#        requires_grad=True)

# %%
Y_tensor.shape
# Out:
# torch.Size([9661, 348, 51])

# %%
# Initialize model
torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(N, D, T, K, P, G, Y, prevalence_t, disease_names_list)

# Store initial psi values
initial_psi = model.psi.detach().clone()
initial_phi=model.phi.detach().clone()
initial_lambda=model.lambda_.detach().clone()

history = model.fit(E_tensor, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2)

# Compare final vs initial psi
print("\nOverall psi changes:")
# Out:
# Lambda kernel condition number: 45200668.00
# Phi kernel condition number: 89734320.00
#
# Cluster Sizes:
# Cluster 0: 27 diseases
# Cluster 1: 32 diseases
# Cluster 2: 12 diseases
# Cluster 3: 9 diseases
# Cluster 4: 19 diseases
# Cluster 5: 74 diseases
# Cluster 6: 31 diseases
# Cluster 7: 12 diseases
# Cluster 8: 10 diseases
# Cluster 9: 8 diseases
# Cluster 10: 5 diseases
# Cluster 11: 10 diseases
# Cluster 12: 6 diseases
# Cluster 13: 12 diseases
# Cluster 14: 14 diseases
# Cluster 15: 9 diseases
# Cluster 16: 23 diseases
# Cluster 17: 5 diseases
# Cluster 18: 18 diseases
# Cluster 19: 12 diseases
# Initialization complete!
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init.py:290: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 1113.0669
# Psi gradient stats:
# Mean: -3.4540e-05
# Std:  4.6873e-03
# Max:  1.7338e-02
# Min:  -1.8840e-02
# Average psi change: 9.9903e-05
# Epoch 0, Loss: 1113.0669, Gradients - Lambda: 5.615e-01, Phi: 1.303e+01, Gamma: 5.300e-02, Psi: 1.884e-02
#
# Epoch 1
# Loss: 848.2545
# Psi gradient stats:
# Mean: -3.4483e-05
# Std:  4.6754e-03
# Max:  1.7263e-02
# Min:  -1.8705e-02
# Average psi change: 9.9334e-05
# Epoch 1, Loss: 848.2545, Gradients - Lambda: 4.977e-01, Phi: 1.208e+01, Gamma: 5.210e-02, Psi: 1.870e-02
#
# Estimated total training time: 914.7 minutes
#
# Epoch 2
# Loss: 659.2227
# Psi gradient stats:
# Mean: -3.4779e-05
# Std:  4.6625e-03
# Max:  1.7160e-02
# Min:  -1.8597e-02
# Average psi change: 9.8977e-05
# Epoch 2, Loss: 659.2227, Gradients - Lambda: 4.587e-01, Phi: 1.130e+01, Gamma: 5.107e-02, Psi: 1.860e-02
#
# Epoch 3
# Loss: 530.0841
# Psi gradient stats:
# Mean: -3.4596e-05
# Std:  4.6493e-03
# Max:  1.7015e-02
# Min:  -1.8506e-02
# Average psi change: 9.8635e-05
# Epoch 3, Loss: 530.0841, Gradients - Lambda: 4.218e-01, Phi: 1.087e+01, Gamma: 4.994e-02, Psi: 1.851e-02
#
# Epoch 4
# Loss: 444.6720
# Psi gradient stats:
# Mean: -3.3966e-05
# Std:  4.6358e-03
# Max:  1.6836e-02
# Min:  -1.8430e-02
# Average psi change: 9.8381e-05
# Epoch 4, Loss: 444.6720, Gradients - Lambda: 3.936e-01, Phi: 1.039e+01, Gamma: 4.884e-02, Psi: 1.843e-02
#
# Epoch 5
# Loss: 389.7273
# Psi gradient stats:
# Mean: -3.3032e-05
# Std:  4.6220e-03
# Max:  1.6638e-02
# Min:  -1.8378e-02
# Average psi change: 9.8144e-05
# Epoch 5, Loss: 389.7273, Gradients - Lambda: 3.652e-01, Phi: 9.873e+00, Gamma: 4.782e-02, Psi: 1.838e-02
#
# Epoch 6
# Loss: 355.4305
# Psi gradient stats:
# Mean: -3.1948e-05
# Std:  4.6080e-03
# Max:  1.6431e-02
# Min:  -1.8357e-02
# Average psi change: 9.7911e-05
# Epoch 6, Loss: 355.4305, Gradients - Lambda: 3.372e-01, Phi: 9.318e+00, Gamma: 4.695e-02, Psi: 1.836e-02
#
# Epoch 7
# Loss: 334.5994
# Psi gradient stats:
# Mean: -3.0886e-05
# Std:  4.5939e-03
# Max:  1.6223e-02
# Min:  -1.8362e-02
# Average psi change: 9.7632e-05
# Epoch 7, Loss: 334.5994, Gradients - Lambda: 3.104e-01, Phi: 8.717e+00, Gamma: 4.625e-02, Psi: 1.836e-02
#
# Epoch 8
# Loss: 322.0127
# Psi gradient stats:
# Mean: -2.9787e-05
# Std:  4.5797e-03
# Max:  1.6019e-02
# Min:  -1.8384e-02
# Average psi change: 9.7296e-05
# Epoch 8, Loss: 322.0127, Gradients - Lambda: 2.849e-01, Phi: 8.067e+00, Gamma: 4.573e-02, Psi: 1.838e-02
#
# Epoch 9
# Loss: 314.0732
# Psi gradient stats:
# Mean: -2.8642e-05
# Std:  4.5657e-03
# Max:  1.5818e-02
# Min:  -1.8422e-02
# Average psi change: 9.7006e-05
# Epoch 9, Loss: 314.0732, Gradients - Lambda: 2.645e-01, Phi: 7.373e+00, Gamma: 4.599e-02, Psi: 1.842e-02
#
# Epoch 10
# Loss: 308.5138
# Psi gradient stats:
# Mean: -2.7536e-05
# Std:  4.5523e-03
# Max:  1.5620e-02
# Min:  -1.8467e-02
# Average psi change: 9.6776e-05
# Epoch 10, Loss: 308.5138, Gradients - Lambda: 2.440e-01, Phi: 6.637e+00, Gamma: 4.656e-02, Psi: 1.847e-02
#
# Epoch 11
# Loss: 304.0230
# Psi gradient stats:
# Mean: -2.6550e-05
# Std:  4.5395e-03
# Max:  1.5424e-02
# Min:  -1.8513e-02
# Average psi change: 9.6551e-05
#
# Epoch 12
# Loss: 299.9091
# Psi gradient stats:
# Mean: -2.5800e-05
# Std:  4.5276e-03
# Max:  1.5237e-02
# Min:  -1.8556e-02
# Average psi change: 9.6327e-05
#
# Epoch 13
# Loss: 295.8695
# Psi gradient stats:
# Mean: -2.5356e-05
# Std:  4.5166e-03
# Max:  1.5151e-02
# Min:  -1.8594e-02
# Average psi change: 9.6099e-05
#
# Epoch 14
# Loss: 291.8367
# Psi gradient stats:
# Mean: -2.5219e-05
# Std:  4.5066e-03
# Max:  1.5083e-02
# Min:  -1.8627e-02
# Average psi change: 9.5918e-05
#
# Epoch 15
# Loss: 287.8888
# Psi gradient stats:
# Mean: -2.5336e-05
# Std:  4.4978e-03
# Max:  1.5034e-02
# Min:  -1.8658e-02
# Average psi change: 9.5751e-05
#
# Epoch 16
# Loss: 284.1390
# Psi gradient stats:
# Mean: -2.5664e-05
# Std:  4.4901e-03
# Max:  1.4995e-02
# Min:  -1.8692e-02
# Average psi change: 9.5580e-05
#
# Epoch 17
# Loss: 280.6911
# Psi gradient stats:
# Mean: -2.6091e-05
# Std:  4.4835e-03
# Max:  1.4962e-02
# Min:  -1.8733e-02
# Average psi change: 9.5405e-05
#
# Epoch 18
# Loss: 277.6122
# Psi gradient stats:
# Mean: -2.6545e-05
# Std:  4.4781e-03
# Max:  1.4942e-02
# Min:  -1.8780e-02
# Average psi change: 9.5248e-05
#
# Epoch 19
# Loss: 274.9278
# Psi gradient stats:
# Mean: -2.7009e-05
# Std:  4.4736e-03
# Max:  1.4999e-02
# Min:  -1.8832e-02
# Average psi change: 9.5110e-05
#
# Epoch 20
# Loss: 272.6326
# Psi gradient stats:
# Mean: -2.7465e-05
# Std:  4.4698e-03
# Max:  1.5044e-02
# Min:  -1.8889e-02
# Average psi change: 9.4993e-05
# Epoch 20, Loss: 272.6326, Gradients - Lambda: 7.179e-02, Phi: 1.633e+00, Gamma: 4.541e-02, Psi: 1.889e-02
#
# Epoch 21
# Loss: 270.6886
# Psi gradient stats:
# Mean: -2.7951e-05
# Std:  4.4667e-03
# Max:  1.5079e-02
# Min:  -1.8944e-02
# Average psi change: 9.4908e-05
#
# Epoch 22
# Loss: 269.0488
# Psi gradient stats:
# Mean: -2.8482e-05
# Std:  4.4641e-03
# Max:  1.5102e-02
# Min:  -1.8995e-02
# Average psi change: 9.4873e-05
#
# Epoch 23
# Loss: 267.6528
# Psi gradient stats:
# Mean: -2.9010e-05
# Std:  4.4619e-03
# Max:  1.5116e-02
# Min:  -1.9042e-02
# Average psi change: 9.4865e-05
#
# Epoch 24
# Loss: 266.4490
# Psi gradient stats:
# Mean: -2.9501e-05
# Std:  4.4601e-03
# Max:  1.5124e-02
# Min:  -1.9084e-02
# Average psi change: 9.4866e-05
#
# Epoch 25
# Loss: 265.3858
# Psi gradient stats:
# Mean: -2.9899e-05
# Std:  4.4585e-03
# Max:  1.5129e-02
# Min:  -1.9120e-02
# Average psi change: 9.4865e-05
#
# Epoch 26
# Loss: 264.4382
# Psi gradient stats:
# Mean: -3.0231e-05
# Std:  4.4570e-03
# Max:  1.5159e-02
# Min:  -1.9152e-02
# Average psi change: 9.4853e-05
#
# Epoch 27
# Loss: 263.5774
# Psi gradient stats:
# Mean: -3.0535e-05
# Std:  4.4555e-03
# Max:  1.5182e-02
# Min:  -1.9179e-02
# Average psi change: 9.4817e-05
#
# Epoch 28
# Loss: 262.7824
# Psi gradient stats:
# Mean: -3.0835e-05
# Std:  4.4540e-03
# Max:  1.5201e-02
# Min:  -1.9197e-02
# Average psi change: 9.4760e-05
#
# Epoch 29
# Loss: 262.0513
# Psi gradient stats:
# Mean: -3.1067e-05
# Std:  4.4525e-03
# Max:  1.5216e-02
# Min:  -1.9209e-02
# Average psi change: 9.4695e-05
#
# Epoch 30
# Loss: 261.3685
# Psi gradient stats:
# Mean: -3.1204e-05
# Std:  4.4510e-03
# Max:  1.5225e-02
# Min:  -1.9213e-02
# Average psi change: 9.4620e-05
# Epoch 30, Loss: 261.3685, Gradients - Lambda: 3.997e-02, Phi: 9.407e-01, Gamma: 3.948e-02, Psi: 1.921e-02
#
# Epoch 31
# Loss: 260.7310
# Psi gradient stats:
# Mean: -3.1200e-05
# Std:  4.4495e-03
# Max:  1.5226e-02
# Min:  -1.9213e-02
# Average psi change: 9.4536e-05
#
# Epoch 32
# Loss: 260.1336
# Psi gradient stats:
# Mean: -3.1042e-05
# Std:  4.4480e-03
# Max:  1.5219e-02
# Min:  -1.9208e-02
# Average psi change: 9.4448e-05
#
# Epoch 33
# Loss: 259.5744
# Psi gradient stats:
# Mean: -3.0823e-05
# Std:  4.4465e-03
# Max:  1.5205e-02
# Min:  -1.9198e-02
# Average psi change: 9.4357e-05
#
# Epoch 34
# Loss: 259.0519
# Psi gradient stats:
# Mean: -3.0625e-05
# Std:  4.4448e-03
# Max:  1.5189e-02
# Min:  -1.9187e-02
# Average psi change: 9.4262e-05
#
# Epoch 35
# Loss: 258.5595
# Psi gradient stats:
# Mean: -3.0532e-05
# Std:  4.4432e-03
# Max:  1.5170e-02
# Min:  -1.9174e-02
# Average psi change: 9.4164e-05
#
# Epoch 36
# Loss: 258.0938
# Psi gradient stats:
# Mean: -3.0514e-05
# Std:  4.4415e-03
# Max:  1.5155e-02
# Min:  -1.9161e-02
# Average psi change: 9.4065e-05
#
# Epoch 37
# Loss: 257.6513
# Psi gradient stats:
# Mean: -3.0507e-05
# Std:  4.4399e-03
# Max:  1.5145e-02
# Min:  -1.9149e-02
# Average psi change: 9.3962e-05
#
# Epoch 38
# Loss: 257.2300
# Psi gradient stats:
# Mean: -3.0453e-05
# Std:  4.4383e-03
# Max:  1.5138e-02
# Min:  -1.9138e-02
# Average psi change: 9.3861e-05
#
# Epoch 39
# Loss: 256.8304
# Psi gradient stats:
# Mean: -3.0347e-05
# Std:  4.4367e-03
# Max:  1.5131e-02
# Min:  -1.9127e-02
# Average psi change: 9.3761e-05
#
# Epoch 40
# Loss: 256.4458
# Psi gradient stats:
# Mean: -3.0226e-05
# Std:  4.4351e-03
# Max:  1.5121e-02
# Min:  -1.9116e-02
# Average psi change: 9.3663e-05
# Epoch 40, Loss: 256.4458, Gradients - Lambda: 2.963e-02, Phi: 6.396e-01, Gamma: 3.416e-02, Psi: 1.912e-02
#
# Epoch 41
# Loss: 256.0771
# Psi gradient stats:
# Mean: -3.0155e-05
# Std:  4.4335e-03
# Max:  1.5105e-02
# Min:  -1.9105e-02
# Average psi change: 9.3570e-05
#
# Epoch 42
# Loss: 255.7249
# Psi gradient stats:
# Mean: -3.0149e-05
# Std:  4.4319e-03
# Max:  1.5089e-02
# Min:  -1.9096e-02
# Average psi change: 9.3482e-05
#
# Epoch 43
# Loss: 255.3849
# Psi gradient stats:
# Mean: -3.0169e-05
# Std:  4.4303e-03
# Max:  1.5079e-02
# Min:  -1.9089e-02
# Average psi change: 9.3399e-05
#
# Epoch 44
# Loss: 255.0569
# Psi gradient stats:
# Mean: -3.0156e-05
# Std:  4.4287e-03
# Max:  1.5079e-02
# Min:  -1.9081e-02
# Average psi change: 9.3317e-05
#
# Epoch 45
# Loss: 254.7401
# Psi gradient stats:
# Mean: -3.0092e-05
# Std:  4.4270e-03
# Max:  1.5083e-02
# Min:  -1.9075e-02
# Average psi change: 9.3240e-05
#
# Epoch 46
# Loss: 254.4334
# Psi gradient stats:
# Mean: -3.0012e-05
# Std:  4.4253e-03
# Max:  1.5080e-02
# Min:  -1.9068e-02
# Average psi change: 9.3166e-05
#
# Epoch 47
# Loss: 254.1359
# Psi gradient stats:
# Mean: -2.9971e-05
# Std:  4.4237e-03
# Max:  1.5071e-02
# Min:  -1.9060e-02
# Average psi change: 9.3101e-05
#
# Epoch 48
# Loss: 253.8466
# Psi gradient stats:
# Mean: -3.0003e-05
# Std:  4.4220e-03
# Max:  1.5060e-02
# Min:  -1.9052e-02
# Average psi change: 9.3043e-05
#
# Epoch 49
# Loss: 253.5676
# Psi gradient stats:
# Mean: -3.0098e-05
# Std:  4.4204e-03
# Max:  1.5055e-02
# Min:  -1.9047e-02
# Average psi change: 9.2992e-05
#
# Epoch 50
# Loss: 253.2957
# Psi gradient stats:
# Mean: -3.0182e-05
# Std:  4.4188e-03
# Max:  1.5057e-02
# Min:  -1.9040e-02
# Average psi change: 9.2948e-05
# Epoch 50, Loss: 253.2957, Gradients - Lambda: 2.700e-02, Phi: 4.299e-01, Gamma: 3.002e-02, Psi: 1.904e-02
#
# Epoch 51
# Loss: 253.0302
# Psi gradient stats:
# Mean: -3.0204e-05
# Std:  4.4171e-03
# Max:  1.5057e-02
# Min:  -1.9032e-02
# Average psi change: 9.2904e-05
#
# Epoch 52
# Loss: 252.7724
# Psi gradient stats:
# Mean: -3.0188e-05
# Std:  4.4154e-03
# Max:  1.5050e-02
# Min:  -1.9025e-02
# Average psi change: 9.2865e-05
#
# Epoch 53
# Loss: 252.5204
# Psi gradient stats:
# Mean: -3.0210e-05
# Std:  4.4138e-03
# Max:  1.5036e-02
# Min:  -1.9021e-02
# Average psi change: 9.2826e-05
#
# Epoch 54
# Loss: 252.2733
# Psi gradient stats:
# Mean: -3.0291e-05
# Std:  4.4121e-03
# Max:  1.5026e-02
# Min:  -1.9019e-02
# Average psi change: 9.2794e-05
#
# Epoch 55
# Loss: 252.0333
# Psi gradient stats:
# Mean: -3.0392e-05
# Std:  4.4105e-03
# Max:  1.5027e-02
# Min:  -1.9021e-02
# Average psi change: 9.2765e-05
#
# Epoch 56
# Loss: 251.7980
# Psi gradient stats:
# Mean: -3.0439e-05
# Std:  4.4089e-03
# Max:  1.5035e-02
# Min:  -1.9021e-02
# Average psi change: 9.2737e-05
#
# Epoch 57
# Loss: 251.5667
# Psi gradient stats:
# Mean: -3.0380e-05
# Std:  4.4072e-03
# Max:  1.5041e-02
# Min:  -1.9019e-02
# Average psi change: 9.2711e-05
#
# Epoch 58
# Loss: 251.3414
# Psi gradient stats:
# Mean: -3.0263e-05
# Std:  4.4055e-03
# Max:  1.5036e-02
# Min:  -1.9013e-02
# Average psi change: 9.2688e-05
#
# Epoch 59
# Loss: 251.1203
# Psi gradient stats:
# Mean: -3.0172e-05
# Std:  4.4038e-03
# Max:  1.5025e-02
# Min:  -1.9005e-02
# Average psi change: 9.2662e-05
#
# Epoch 60
# Loss: 250.9043
# Psi gradient stats:
# Mean: -3.0190e-05
# Std:  4.4022e-03
# Max:  1.5016e-02
# Min:  -1.8999e-02
# Average psi change: 9.2639e-05
# Epoch 60, Loss: 250.9043, Gradients - Lambda: 3.255e-02, Phi: 4.585e-01, Gamma: 2.598e-02, Psi: 1.900e-02
#
# Epoch 61
# Loss: 250.6914
# Psi gradient stats:
# Mean: -3.0290e-05
# Std:  4.4005e-03
# Max:  1.5019e-02
# Min:  -1.8996e-02
# Average psi change: 9.2617e-05
#
# Epoch 62
# Loss: 250.4855
# Psi gradient stats:
# Mean: -3.0400e-05
# Std:  4.3989e-03
# Max:  1.5029e-02
# Min:  -1.8995e-02
# Average psi change: 9.2594e-05
#
# Epoch 63
# Loss: 250.2803
# Psi gradient stats:
# Mean: -3.0422e-05
# Std:  4.3972e-03
# Max:  1.5034e-02
# Min:  -1.8994e-02
# Average psi change: 9.2574e-05
#
# Epoch 64
# Loss: 250.0791
# Psi gradient stats:
# Mean: -3.0382e-05
# Std:  4.3955e-03
# Max:  1.5028e-02
# Min:  -1.8991e-02
# Average psi change: 9.2550e-05
#
# Epoch 65
# Loss: 249.8843
# Psi gradient stats:
# Mean: -3.0332e-05
# Std:  4.3938e-03
# Max:  1.5013e-02
# Min:  -1.8988e-02
# Average psi change: 9.2527e-05
#
# Epoch 66
# Loss: 249.6912
# Psi gradient stats:
# Mean: -3.0344e-05
# Std:  4.3921e-03
# Max:  1.5000e-02
# Min:  -1.8985e-02
# Average psi change: 9.2509e-05
#
# Epoch 67
# Loss: 249.5000
# Psi gradient stats:
# Mean: -3.0413e-05
# Std:  4.3904e-03
# Max:  1.4997e-02
# Min:  -1.8979e-02
# Average psi change: 9.2484e-05
#
# Epoch 68
# Loss: 249.3147
# Psi gradient stats:
# Mean: -3.0464e-05
# Std:  4.3887e-03
# Max:  1.5003e-02
# Min:  -1.8972e-02
# Average psi change: 9.2462e-05
#
# Epoch 69
# Loss: 249.1336
# Psi gradient stats:
# Mean: -3.0462e-05
# Std:  4.3871e-03
# Max:  1.5008e-02
# Min:  -1.8964e-02
# Average psi change: 9.2437e-05
#
# Epoch 70
# Loss: 248.9512
# Psi gradient stats:
# Mean: -3.0423e-05
# Std:  4.3854e-03
# Max:  1.5006e-02
# Min:  -1.8960e-02
# Average psi change: 9.2418e-05
# Epoch 70, Loss: 248.9512, Gradients - Lambda: 3.467e-02, Phi: 5.408e-01, Gamma: 2.244e-02, Psi: 1.896e-02
#
# Epoch 71
# Loss: 248.7758
# Psi gradient stats:
# Mean: -3.0410e-05
# Std:  4.3837e-03
# Max:  1.4994e-02
# Min:  -1.8960e-02
# Average psi change: 9.2397e-05
#
# Epoch 72
# Loss: 248.6053
# Psi gradient stats:
# Mean: -3.0452e-05
# Std:  4.3820e-03
# Max:  1.4982e-02
# Min:  -1.8960e-02
# Average psi change: 9.2376e-05
#
# Epoch 73
# Loss: 248.4314
# Psi gradient stats:
# Mean: -3.0536e-05
# Std:  4.3802e-03
# Max:  1.4978e-02
# Min:  -1.8959e-02
# Average psi change: 9.2354e-05
#
# Epoch 74
# Loss: 248.2649
# Psi gradient stats:
# Mean: -3.0580e-05
# Std:  4.3785e-03
# Max:  1.4985e-02
# Min:  -1.8952e-02
# Average psi change: 9.2330e-05
#
# Epoch 75
# Loss: 248.1034
# Psi gradient stats:
# Mean: -3.0550e-05
# Std:  4.3768e-03
# Max:  1.4994e-02
# Min:  -1.8941e-02
# Average psi change: 9.2305e-05
#
# Epoch 76
# Loss: 247.9393
# Psi gradient stats:
# Mean: -3.0499e-05
# Std:  4.3752e-03
# Max:  1.4992e-02
# Min:  -1.8929e-02
# Average psi change: 9.2282e-05
#
# Epoch 77
# Loss: 247.7810
# Psi gradient stats:
# Mean: -3.0510e-05
# Std:  4.3735e-03
# Max:  1.4978e-02
# Min:  -1.8923e-02
# Average psi change: 9.2262e-05
#
# Epoch 78
# Loss: 247.6274
# Psi gradient stats:
# Mean: -3.0607e-05
# Std:  4.3717e-03
# Max:  1.4961e-02
# Min:  -1.8921e-02
# Average psi change: 9.2240e-05
#
# Epoch 79
# Loss: 247.4716
# Psi gradient stats:
# Mean: -3.0699e-05
# Std:  4.3699e-03
# Max:  1.4953e-02
# Min:  -1.8924e-02
# Average psi change: 9.2216e-05
#
# Epoch 80
# Loss: 247.3214
# Psi gradient stats:
# Mean: -3.0693e-05
# Std:  4.3682e-03
# Max:  1.4958e-02
# Min:  -1.8923e-02
# Average psi change: 9.2192e-05
# Epoch 80, Loss: 247.3214, Gradients - Lambda: 3.849e-02, Phi: 5.954e-01, Gamma: 1.932e-02, Psi: 1.892e-02
#
# Epoch 81
# Loss: 247.1761
# Psi gradient stats:
# Mean: -3.0611e-05
# Std:  4.3665e-03
# Max:  1.4970e-02
# Min:  -1.8917e-02
# Average psi change: 9.2171e-05
#
# Epoch 82
# Loss: 247.0280
# Psi gradient stats:
# Mean: -3.0531e-05
# Std:  4.3649e-03
# Max:  1.4976e-02
# Min:  -1.8907e-02
# Average psi change: 9.2151e-05
#
# Epoch 83
# Loss: 246.8865
# Psi gradient stats:
# Mean: -3.0560e-05
# Std:  4.3632e-03
# Max:  1.4966e-02
# Min:  -1.8897e-02
# Average psi change: 9.2129e-05
#
# Epoch 84
# Loss: 246.7481
# Psi gradient stats:
# Mean: -3.0701e-05
# Std:  4.3615e-03
# Max:  1.4945e-02
# Min:  -1.8892e-02
# Average psi change: 9.2108e-05
#
# Epoch 85
# Loss: 246.6092
# Psi gradient stats:
# Mean: -3.0845e-05
# Std:  4.3596e-03
# Max:  1.4928e-02
# Min:  -1.8891e-02
# Average psi change: 9.2086e-05
#
# Epoch 86
# Loss: 246.4728
# Psi gradient stats:
# Mean: -3.0866e-05
# Std:  4.3579e-03
# Max:  1.4926e-02
# Min:  -1.8893e-02
# Average psi change: 9.2062e-05
#
# Epoch 87
# Loss: 246.3409
# Psi gradient stats:
# Mean: -3.0756e-05
# Std:  4.3561e-03
# Max:  1.4939e-02
# Min:  -1.8891e-02
# Average psi change: 9.2041e-05
#
# Epoch 88
# Loss: 246.2095
# Psi gradient stats:
# Mean: -3.0615e-05
# Std:  4.3545e-03
# Max:  1.4952e-02
# Min:  -1.8884e-02
# Average psi change: 9.2018e-05
#
# Epoch 89
# Loss: 246.0818
# Psi gradient stats:
# Mean: -3.0577e-05
# Std:  4.3528e-03
# Max:  1.4952e-02
# Min:  -1.8874e-02
# Average psi change: 9.2002e-05
#
# Epoch 90
# Loss: 245.9572
# Psi gradient stats:
# Mean: -3.0703e-05
# Std:  4.3511e-03
# Max:  1.4933e-02
# Min:  -1.8865e-02
# Average psi change: 9.1979e-05
# Epoch 90, Loss: 245.9572, Gradients - Lambda: 4.160e-02, Phi: 5.820e-01, Gamma: 1.647e-02, Psi: 1.887e-02
#
# Epoch 91
# Loss: 245.8334
# Psi gradient stats:
# Mean: -3.0888e-05
# Std:  4.3494e-03
# Max:  1.4910e-02
# Min:  -1.8860e-02
# Average psi change: 9.1957e-05
#
# Epoch 92
# Loss: 245.7126
# Psi gradient stats:
# Mean: -3.0984e-05
# Std:  4.3475e-03
# Max:  1.4898e-02
# Min:  -1.8860e-02
# Average psi change: 9.1933e-05
#
# Epoch 93
# Loss: 245.5928
# Psi gradient stats:
# Mean: -3.0934e-05
# Std:  4.3457e-03
# Max:  1.4906e-02
# Min:  -1.8862e-02
# Average psi change: 9.1913e-05
#
# Epoch 94
# Loss: 245.4760
# Psi gradient stats:
# Mean: -3.0771e-05
# Std:  4.3440e-03
# Max:  1.4924e-02
# Min:  -1.8860e-02
# Average psi change: 9.1891e-05
#
# Epoch 95
# Loss: 245.3623
# Psi gradient stats:
# Mean: -3.0664e-05
# Std:  4.3424e-03
# Max:  1.4936e-02
# Min:  -1.8853e-02
# Average psi change: 9.1869e-05
#
# Epoch 96
# Loss: 245.2475
# Psi gradient stats:
# Mean: -3.0699e-05
# Std:  4.3408e-03
# Max:  1.4926e-02
# Min:  -1.8841e-02
# Average psi change: 9.1848e-05
#
# Epoch 97
# Loss: 245.1362
# Psi gradient stats:
# Mean: -3.0873e-05
# Std:  4.3391e-03
# Max:  1.4902e-02
# Min:  -1.8831e-02
# Average psi change: 9.1826e-05
#
# Epoch 98
# Loss: 245.0303
# Psi gradient stats:
# Mean: -3.1039e-05
# Std:  4.3372e-03
# Max:  1.4880e-02
# Min:  -1.8826e-02
# Average psi change: 9.1803e-05
#
# Epoch 99
# Loss: 244.9218
# Psi gradient stats:
# Mean: -3.1057e-05
# Std:  4.3354e-03
# Max:  1.4877e-02
# Min:  -1.8829e-02
# Average psi change: 9.1781e-05
#
# Epoch 100
# Loss: 244.8180
# Psi gradient stats:
# Mean: -3.0920e-05
# Std:  4.3336e-03
# Max:  1.4891e-02
# Min:  -1.8831e-02
# Average psi change: 9.1757e-05
# Epoch 100, Loss: 244.8180, Gradients - Lambda: 4.972e-02, Phi: 6.436e-01, Gamma: 1.412e-02, Psi: 1.883e-02
#
# Epoch 101
# Loss: 244.7173
# Psi gradient stats:
# Mean: -3.0757e-05
# Std:  4.3319e-03
# Max:  1.4909e-02
# Min:  -1.8829e-02
# Average psi change: 9.1734e-05
#
# Epoch 102
# Loss: 244.6147
# Psi gradient stats:
# Mean: -3.0727e-05
# Std:  4.3303e-03
# Max:  1.4913e-02
# Min:  -1.8817e-02
# Average psi change: 9.1709e-05
#
# Epoch 103
# Loss: 244.5149
# Psi gradient stats:
# Mean: -3.0890e-05
# Std:  4.3287e-03
# Max:  1.4896e-02
# Min:  -1.8803e-02
# Average psi change: 9.1688e-05
#
# Epoch 104
# Loss: 244.4195
# Psi gradient stats:
# Mean: -3.1104e-05
# Std:  4.3269e-03
# Max:  1.4870e-02
# Min:  -1.8794e-02
# Average psi change: 9.1666e-05
#
# Epoch 105
# Loss: 244.3228
# Psi gradient stats:
# Mean: -3.1188e-05
# Std:  4.3250e-03
# Max:  1.4856e-02
# Min:  -1.8794e-02
# Average psi change: 9.1641e-05
#
# Epoch 106
# Loss: 244.2260
# Psi gradient stats:
# Mean: -3.1076e-05
# Std:  4.3232e-03
# Max:  1.4861e-02
# Min:  -1.8799e-02
# Average psi change: 9.1617e-05
#
# Epoch 107
# Loss: 244.1366
# Psi gradient stats:
# Mean: -3.0874e-05
# Std:  4.3214e-03
# Max:  1.4877e-02
# Min:  -1.8800e-02
# Average psi change: 9.1592e-05
#
# Epoch 108
# Loss: 244.0471
# Psi gradient stats:
# Mean: -3.0776e-05
# Std:  4.3198e-03
# Max:  1.4886e-02
# Min:  -1.8790e-02
# Average psi change: 9.1568e-05
#
# Epoch 109
# Loss: 243.9531
# Psi gradient stats:
# Mean: -3.0903e-05
# Std:  4.3183e-03
# Max:  1.4879e-02
# Min:  -1.8775e-02
# Average psi change: 9.1544e-05
#
# Epoch 110
# Loss: 243.8672
# Psi gradient stats:
# Mean: -3.1152e-05
# Std:  4.3166e-03
# Max:  1.4858e-02
# Min:  -1.8762e-02
# Average psi change: 9.1521e-05
# Epoch 110, Loss: 243.8672, Gradients - Lambda: 5.080e-02, Phi: 8.251e-01, Gamma: 1.191e-02, Psi: 1.876e-02
#
# Epoch 111
# Loss: 243.7861
# Psi gradient stats:
# Mean: -3.1318e-05
# Std:  4.3147e-03
# Max:  1.4841e-02
# Min:  -1.8759e-02
# Average psi change: 9.1497e-05
#
# Epoch 112
# Loss: 243.6935
# Psi gradient stats:
# Mean: -3.1235e-05
# Std:  4.3128e-03
# Max:  1.4837e-02
# Min:  -1.8765e-02
# Average psi change: 9.1476e-05
#
# Epoch 113
# Loss: 243.6101
# Psi gradient stats:
# Mean: -3.0989e-05
# Std:  4.3110e-03
# Max:  1.4844e-02
# Min:  -1.8772e-02
# Average psi change: 9.1450e-05
#
# Epoch 114
# Loss: 243.5362
# Psi gradient stats:
# Mean: -3.0824e-05
# Std:  4.3094e-03
# Max:  1.4854e-02
# Min:  -1.8768e-02
# Average psi change: 9.1420e-05
#
# Epoch 115
# Loss: 243.4472
# Psi gradient stats:
# Mean: -3.0931e-05
# Std:  4.3078e-03
# Max:  1.4853e-02
# Min:  -1.8752e-02
# Average psi change: 9.1394e-05
#
# Epoch 116
# Loss: 243.3646
# Psi gradient stats:
# Mean: -3.1222e-05
# Std:  4.3062e-03
# Max:  1.4842e-02
# Min:  -1.8733e-02
# Average psi change: 9.1371e-05
#
# Epoch 117
# Loss: 243.2957
# Psi gradient stats:
# Mean: -3.1435e-05
# Std:  4.3044e-03
# Max:  1.4825e-02
# Min:  -1.8724e-02
# Average psi change: 9.1352e-05
#
# Epoch 118
# Loss: 243.2119
# Psi gradient stats:
# Mean: -3.1380e-05
# Std:  4.3024e-03
# Max:  1.4816e-02
# Min:  -1.8728e-02
# Average psi change: 9.1328e-05
#
# Epoch 119
# Loss: 243.1293
# Psi gradient stats:
# Mean: -3.1107e-05
# Std:  4.3005e-03
# Max:  1.4818e-02
# Min:  -1.8738e-02
# Average psi change: 9.1301e-05
#
# Epoch 120
# Loss: 243.0636
# Psi gradient stats:
# Mean: -3.0897e-05
# Std:  4.2989e-03
# Max:  1.4826e-02
# Min:  -1.8741e-02
# Average psi change: 9.1272e-05
# Epoch 120, Loss: 243.0636, Gradients - Lambda: 4.944e-02, Phi: 9.002e-01, Gamma: 1.004e-02, Psi: 1.874e-02
#
# Epoch 121
# Loss: 242.9866
# Psi gradient stats:
# Mean: -3.0969e-05
# Std:  4.2974e-03
# Max:  1.4829e-02
# Min:  -1.8731e-02
# Average psi change: 9.1246e-05
#
# Epoch 122
# Loss: 242.9039
# Psi gradient stats:
# Mean: -3.1279e-05
# Std:  4.2958e-03
# Max:  1.4823e-02
# Min:  -1.8711e-02
# Average psi change: 9.1221e-05
#
# Epoch 123
# Loss: 242.8414
# Psi gradient stats:
# Mean: -3.1571e-05
# Std:  4.2941e-03
# Max:  1.4809e-02
# Min:  -1.8695e-02
# Average psi change: 9.1199e-05
#
# Epoch 124
# Loss: 242.7699
# Psi gradient stats:
# Mean: -3.1566e-05
# Std:  4.2921e-03
# Max:  1.4798e-02
# Min:  -1.8692e-02
# Average psi change: 9.1178e-05
#
# Epoch 125
# Loss: 242.6857
# Psi gradient stats:
# Mean: -3.1282e-05
# Std:  4.2902e-03
# Max:  1.4795e-02
# Min:  -1.8701e-02
# Average psi change: 9.1156e-05
#
# Epoch 126
# Loss: 242.6234
# Psi gradient stats:
# Mean: -3.0968e-05
# Std:  4.2885e-03
# Max:  1.4799e-02
# Min:  -1.8708e-02
# Average psi change: 9.1128e-05
#
# Epoch 127
# Loss: 242.5595
# Psi gradient stats:
# Mean: -3.0946e-05
# Std:  4.2869e-03
# Max:  1.4804e-02
# Min:  -1.8704e-02
# Average psi change: 9.1096e-05
#
# Epoch 128
# Loss: 242.4771
# Psi gradient stats:
# Mean: -3.1233e-05
# Std:  4.2854e-03
# Max:  1.4801e-02
# Min:  -1.8685e-02
# Average psi change: 9.1064e-05
#
# Epoch 129
# Loss: 242.4112
# Psi gradient stats:
# Mean: -3.1603e-05
# Std:  4.2838e-03
# Max:  1.4790e-02
# Min:  -1.8667e-02
# Average psi change: 9.1040e-05
#
# Epoch 130
# Loss: 242.3517
# Psi gradient stats:
# Mean: -3.1728e-05
# Std:  4.2819e-03
# Max:  1.4777e-02
# Min:  -1.8660e-02
# Average psi change: 9.1019e-05
# Epoch 130, Loss: 242.3517, Gradients - Lambda: 4.819e-02, Phi: 7.728e-01, Gamma: 8.509e-03, Psi: 1.866e-02
#
# Epoch 131
# Loss: 242.2748
# Psi gradient stats:
# Mean: -3.1529e-05
# Std:  4.2799e-03
# Max:  1.4770e-02
# Min:  -1.8666e-02
# Average psi change: 9.0998e-05
#
# Epoch 132
# Loss: 242.2067
# Psi gradient stats:
# Mean: -3.1181e-05
# Std:  4.2780e-03
# Max:  1.4771e-02
# Min:  -1.8675e-02
# Average psi change: 9.0973e-05
#
# Epoch 133
# Loss: 242.1469
# Psi gradient stats:
# Mean: -3.1023e-05
# Std:  4.2764e-03
# Max:  1.4776e-02
# Min:  -1.8673e-02
# Average psi change: 9.0944e-05
#
# Epoch 134
# Loss: 242.0761
# Psi gradient stats:
# Mean: -3.1198e-05
# Std:  4.2750e-03
# Max:  1.4777e-02
# Min:  -1.8658e-02
# Average psi change: 9.0909e-05
#
# Epoch 135
# Loss: 242.0062
# Psi gradient stats:
# Mean: -3.1555e-05
# Std:  4.2735e-03
# Max:  1.4770e-02
# Min:  -1.8637e-02
# Average psi change: 9.0874e-05
#
# Epoch 136
# Loss: 241.9438
# Psi gradient stats:
# Mean: -3.1806e-05
# Std:  4.2718e-03
# Max:  1.4760e-02
# Min:  -1.8626e-02
# Average psi change: 9.0851e-05
#
# Epoch 137
# Loss: 241.8788
# Psi gradient stats:
# Mean: -3.1749e-05
# Std:  4.2698e-03
# Max:  1.4753e-02
# Min:  -1.8631e-02
# Average psi change: 9.0833e-05
#
# Epoch 138
# Loss: 241.8099
# Psi gradient stats:
# Mean: -3.1474e-05
# Std:  4.2678e-03
# Max:  1.4752e-02
# Min:  -1.8642e-02
# Average psi change: 9.0816e-05
#
# Epoch 139
# Loss: 241.7432
# Psi gradient stats:
# Mean: -3.1233e-05
# Std:  4.2660e-03
# Max:  1.4756e-02
# Min:  -1.8644e-02
# Average psi change: 9.0792e-05
#
# Epoch 140
# Loss: 241.6816
# Psi gradient stats:
# Mean: -3.1248e-05
# Std:  4.2645e-03
# Max:  1.4756e-02
# Min:  -1.8631e-02
# Average psi change: 9.0757e-05
# Epoch 140, Loss: 241.6816, Gradients - Lambda: 5.085e-02, Phi: 8.140e-01, Gamma: 7.430e-03, Psi: 1.863e-02
#
# Epoch 141
# Loss: 241.6160
# Psi gradient stats:
# Mean: -3.1517e-05
# Std:  4.2631e-03
# Max:  1.4749e-02
# Min:  -1.8608e-02
# Average psi change: 9.0718e-05
#
# Epoch 142
# Loss: 241.5466
# Psi gradient stats:
# Mean: -3.1814e-05
# Std:  4.2616e-03
# Max:  1.4739e-02
# Min:  -1.8593e-02
# Average psi change: 9.0684e-05
#
# Epoch 143
# Loss: 241.4851
# Psi gradient stats:
# Mean: -3.1901e-05
# Std:  4.2598e-03
# Max:  1.4731e-02
# Min:  -1.8595e-02
# Average psi change: 9.0664e-05
#
# Epoch 144
# Loss: 241.4210
# Psi gradient stats:
# Mean: -3.1715e-05
# Std:  4.2578e-03
# Max:  1.4732e-02
# Min:  -1.8609e-02
# Average psi change: 9.0649e-05
#
# Epoch 145
# Loss: 241.3517
# Psi gradient stats:
# Mean: -3.1441e-05
# Std:  4.2558e-03
# Max:  1.4739e-02
# Min:  -1.8617e-02
# Average psi change: 9.0630e-05
#
# Epoch 146
# Loss: 241.2878
# Psi gradient stats:
# Mean: -3.1330e-05
# Std:  4.2541e-03
# Max:  1.4740e-02
# Min:  -1.8607e-02
# Average psi change: 9.0602e-05
#
# Epoch 147
# Loss: 241.2256
# Psi gradient stats:
# Mean: -3.1486e-05
# Std:  4.2527e-03
# Max:  1.4726e-02
# Min:  -1.8584e-02
# Average psi change: 9.0563e-05
#
# Epoch 148
# Loss: 241.1581
# Psi gradient stats:
# Mean: -3.1806e-05
# Std:  4.2513e-03
# Max:  1.4706e-02
# Min:  -1.8562e-02
# Average psi change: 9.0523e-05
#
# Epoch 149
# Loss: 241.0907
# Psi gradient stats:
# Mean: -3.2005e-05
# Std:  4.2497e-03
# Max:  1.4694e-02
# Min:  -1.8559e-02
# Average psi change: 9.0491e-05
#
# Epoch 150
# Loss: 241.0296
# Psi gradient stats:
# Mean: -3.1937e-05
# Std:  4.2478e-03
# Max:  1.4701e-02
# Min:  -1.8570e-02
# Average psi change: 9.0471e-05
# Epoch 150, Loss: 241.0296, Gradients - Lambda: 5.118e-02, Phi: 8.148e-01, Gamma: 7.480e-03, Psi: 1.857e-02
#
# Epoch 151
# Loss: 240.9632
# Psi gradient stats:
# Mean: -3.1660e-05
# Std:  4.2458e-03
# Max:  1.4717e-02
# Min:  -1.8582e-02
# Average psi change: 9.0456e-05
#
# Epoch 152
# Loss: 240.8953
# Psi gradient stats:
# Mean: -3.1461e-05
# Std:  4.2439e-03
# Max:  1.4728e-02
# Min:  -1.8579e-02
# Average psi change: 9.0434e-05
#
# Epoch 153
# Loss: 240.8317
# Psi gradient stats:
# Mean: -3.1516e-05
# Std:  4.2423e-03
# Max:  1.4720e-02
# Min:  -1.8559e-02
# Average psi change: 9.0402e-05
#
# Epoch 154
# Loss: 240.7660
# Psi gradient stats:
# Mean: -3.1821e-05
# Std:  4.2410e-03
# Max:  1.4696e-02
# Min:  -1.8537e-02
# Average psi change: 9.0361e-05
#
# Epoch 155
# Loss: 240.7001
# Psi gradient stats:
# Mean: -3.2098e-05
# Std:  4.2396e-03
# Max:  1.4671e-02
# Min:  -1.8528e-02
# Average psi change: 9.0325e-05
#
# Epoch 156
# Loss: 240.6334
# Psi gradient stats:
# Mean: -3.2106e-05
# Std:  4.2379e-03
# Max:  1.4664e-02
# Min:  -1.8534e-02
# Average psi change: 9.0302e-05
#
# Epoch 157
# Loss: 240.5658
# Psi gradient stats:
# Mean: -3.1840e-05
# Std:  4.2359e-03
# Max:  1.4679e-02
# Min:  -1.8545e-02
# Average psi change: 9.0285e-05
#
# Epoch 158
# Loss: 240.5030
# Psi gradient stats:
# Mean: -3.1550e-05
# Std:  4.2339e-03
# Max:  1.4700e-02
# Min:  -1.8544e-02
# Average psi change: 9.0268e-05
#
# Epoch 159
# Loss: 240.4347
# Psi gradient stats:
# Mean: -3.1549e-05
# Std:  4.2321e-03
# Max:  1.4707e-02
# Min:  -1.8530e-02
# Average psi change: 9.0239e-05
#
# Epoch 160
# Loss: 240.3668
# Psi gradient stats:
# Mean: -3.1860e-05
# Std:  4.2306e-03
# Max:  1.4690e-02
# Min:  -1.8510e-02
# Average psi change: 9.0204e-05
# Epoch 160, Loss: 240.3668, Gradients - Lambda: 5.148e-02, Phi: 9.011e-01, Gamma: 7.386e-03, Psi: 1.851e-02
#
# Epoch 161
# Loss: 240.3028
# Psi gradient stats:
# Mean: -3.2223e-05
# Std:  4.2293e-03
# Max:  1.4660e-02
# Min:  -1.8501e-02
# Average psi change: 9.0168e-05
#
# Epoch 162
# Loss: 240.2354
# Psi gradient stats:
# Mean: -3.2287e-05
# Std:  4.2278e-03
# Max:  1.4641e-02
# Min:  -1.8504e-02
# Average psi change: 9.0139e-05
#
# Epoch 163
# Loss: 240.1644
# Psi gradient stats:
# Mean: -3.2017e-05
# Std:  4.2261e-03
# Max:  1.4644e-02
# Min:  -1.8512e-02
# Average psi change: 9.0115e-05
#
# Epoch 164
# Loss: 240.1021
# Psi gradient stats:
# Mean: -3.1656e-05
# Std:  4.2241e-03
# Max:  1.4662e-02
# Min:  -1.8509e-02
# Average psi change: 9.0097e-05
#
# Epoch 165
# Loss: 240.0357
# Psi gradient stats:
# Mean: -3.1568e-05
# Std:  4.2221e-03
# Max:  1.4680e-02
# Min:  -1.8495e-02
# Average psi change: 9.0075e-05
#
# Epoch 166
# Loss: 239.9610
# Psi gradient stats:
# Mean: -3.1865e-05
# Std:  4.2205e-03
# Max:  1.4678e-02
# Min:  -1.8478e-02
# Average psi change: 9.0049e-05
#
# Epoch 167
# Loss: 239.8977
# Psi gradient stats:
# Mean: -3.2327e-05
# Std:  4.2191e-03
# Max:  1.4657e-02
# Min:  -1.8471e-02
# Average psi change: 9.0016e-05
#
# Epoch 168
# Loss: 239.8329
# Psi gradient stats:
# Mean: -3.2540e-05
# Std:  4.2177e-03
# Max:  1.4631e-02
# Min:  -1.8475e-02
# Average psi change: 8.9986e-05
#
# Epoch 169
# Loss: 239.7580
# Psi gradient stats:
# Mean: -3.2293e-05
# Std:  4.2162e-03
# Max:  1.4618e-02
# Min:  -1.8484e-02
# Average psi change: 8.9954e-05
#
# Epoch 170
# Loss: 239.6905
# Psi gradient stats:
# Mean: -3.1829e-05
# Std:  4.2144e-03
# Max:  1.4625e-02
# Min:  -1.8483e-02
# Average psi change: 8.9931e-05
# Epoch 170, Loss: 239.6905, Gradients - Lambda: 5.172e-02, Phi: 8.471e-01, Gamma: 7.510e-03, Psi: 1.848e-02
#
# Epoch 171
# Loss: 239.6311
# Psi gradient stats:
# Mean: -3.1565e-05
# Std:  4.2123e-03
# Max:  1.4641e-02
# Min:  -1.8470e-02
# Average psi change: 8.9914e-05
#
# Epoch 172
# Loss: 239.5559
# Psi gradient stats:
# Mean: -3.1758e-05
# Std:  4.2104e-03
# Max:  1.4651e-02
# Min:  -1.8451e-02
# Average psi change: 8.9890e-05
#
# Epoch 173
# Loss: 239.4839
# Psi gradient stats:
# Mean: -3.2264e-05
# Std:  4.2089e-03
# Max:  1.4643e-02
# Min:  -1.8438e-02
# Average psi change: 8.9865e-05
#
# Epoch 174
# Loss: 239.4233
# Psi gradient stats:
# Mean: -3.2679e-05
# Std:  4.2076e-03
# Max:  1.4622e-02
# Min:  -1.8439e-02
# Average psi change: 8.9836e-05
#
# Epoch 175
# Loss: 239.3534
# Psi gradient stats:
# Mean: -3.2638e-05
# Std:  4.2064e-03
# Max:  1.4604e-02
# Min:  -1.8449e-02
# Average psi change: 8.9803e-05
#
# Epoch 176
# Loss: 239.2772
# Psi gradient stats:
# Mean: -3.2185e-05
# Std:  4.2047e-03
# Max:  1.4600e-02
# Min:  -1.8455e-02
# Average psi change: 8.9773e-05
#
# Epoch 177
# Loss: 239.2135
# Psi gradient stats:
# Mean: -3.1719e-05
# Std:  4.2027e-03
# Max:  1.4611e-02
# Min:  -1.8447e-02
# Average psi change: 8.9753e-05
#
# Epoch 178
# Loss: 239.1488
# Psi gradient stats:
# Mean: -3.1635e-05
# Std:  4.2006e-03
# Max:  1.4624e-02
# Min:  -1.8429e-02
# Average psi change: 8.9733e-05
#
# Epoch 179
# Loss: 239.0729
# Psi gradient stats:
# Mean: -3.2015e-05
# Std:  4.1989e-03
# Max:  1.4625e-02
# Min:  -1.8410e-02
# Average psi change: 8.9712e-05
#
# Epoch 180
# Loss: 239.0032
# Psi gradient stats:
# Mean: -3.2522e-05
# Std:  4.1975e-03
# Max:  1.4612e-02
# Min:  -1.8401e-02
# Average psi change: 8.9683e-05
# Epoch 180, Loss: 239.0032, Gradients - Lambda: 5.224e-02, Phi: 8.444e-01, Gamma: 7.587e-03, Psi: 1.840e-02
#
# Epoch 181
# Loss: 238.9407
# Psi gradient stats:
# Mean: -3.2747e-05
# Std:  4.1964e-03
# Max:  1.4590e-02
# Min:  -1.8405e-02
# Average psi change: 8.9652e-05
#
# Epoch 182
# Loss: 238.8688
# Psi gradient stats:
# Mean: -3.2525e-05
# Std:  4.1949e-03
# Max:  1.4576e-02
# Min:  -1.8414e-02
# Average psi change: 8.9620e-05
#
# Epoch 183
# Loss: 238.7950
# Psi gradient stats:
# Mean: -3.2106e-05
# Std:  4.1931e-03
# Max:  1.4579e-02
# Min:  -1.8418e-02
# Average psi change: 8.9592e-05
#
# Epoch 184
# Loss: 238.7321
# Psi gradient stats:
# Mean: -3.1865e-05
# Std:  4.1910e-03
# Max:  1.4593e-02
# Min:  -1.8410e-02
# Average psi change: 8.9571e-05
#
# Epoch 185
# Loss: 238.6630
# Psi gradient stats:
# Mean: -3.2011e-05
# Std:  4.1891e-03
# Max:  1.4603e-02
# Min:  -1.8392e-02
# Average psi change: 8.9554e-05
#
# Epoch 186
# Loss: 238.5895
# Psi gradient stats:
# Mean: -3.2415e-05
# Std:  4.1876e-03
# Max:  1.4599e-02
# Min:  -1.8375e-02
# Average psi change: 8.9531e-05
#
# Epoch 187
# Loss: 238.5222
# Psi gradient stats:
# Mean: -3.2723e-05
# Std:  4.1864e-03
# Max:  1.4582e-02
# Min:  -1.8367e-02
# Average psi change: 8.9502e-05
#
# Epoch 188
# Loss: 238.4559
# Psi gradient stats:
# Mean: -3.2700e-05
# Std:  4.1851e-03
# Max:  1.4563e-02
# Min:  -1.8368e-02
# Average psi change: 8.9471e-05
#
# Epoch 189
# Loss: 238.3847
# Psi gradient stats:
# Mean: -3.2407e-05
# Std:  4.1834e-03
# Max:  1.4559e-02
# Min:  -1.8376e-02
# Average psi change: 8.9440e-05
#
# Epoch 190
# Loss: 238.3160
# Psi gradient stats:
# Mean: -3.2134e-05
# Std:  4.1814e-03
# Max:  1.4562e-02
# Min:  -1.8380e-02
# Average psi change: 8.9414e-05
# Epoch 190, Loss: 238.3160, Gradients - Lambda: 5.279e-02, Phi: 9.296e-01, Gamma: 7.541e-03, Psi: 1.838e-02
#
# Epoch 191
# Loss: 238.2482
# Psi gradient stats:
# Mean: -3.2142e-05
# Std:  4.1795e-03
# Max:  1.4576e-02
# Min:  -1.8375e-02
# Average psi change: 8.9394e-05
#
# Epoch 192
# Loss: 238.1796
# Psi gradient stats:
# Mean: -3.2411e-05
# Std:  4.1779e-03
# Max:  1.4582e-02
# Min:  -1.8361e-02
# Average psi change: 8.9375e-05
#
# Epoch 193
# Loss: 238.1108
# Psi gradient stats:
# Mean: -3.2699e-05
# Std:  4.1765e-03
# Max:  1.4572e-02
# Min:  -1.8344e-02
# Average psi change: 8.9354e-05
#
# Epoch 194
# Loss: 238.0414
# Psi gradient stats:
# Mean: -3.2739e-05
# Std:  4.1752e-03
# Max:  1.4555e-02
# Min:  -1.8332e-02
# Average psi change: 8.9331e-05
#
# Epoch 195
# Loss: 237.9723
# Psi gradient stats:
# Mean: -3.2537e-05
# Std:  4.1737e-03
# Max:  1.4553e-02
# Min:  -1.8327e-02
# Average psi change: 8.9297e-05
#
# Epoch 196
# Loss: 237.9069
# Psi gradient stats:
# Mean: -3.2302e-05
# Std:  4.1718e-03
# Max:  1.4546e-02
# Min:  -1.8331e-02
# Average psi change: 8.9268e-05
#
# Epoch 197
# Loss: 237.8377
# Psi gradient stats:
# Mean: -3.2278e-05
# Std:  4.1699e-03
# Max:  1.4545e-02
# Min:  -1.8337e-02
# Average psi change: 8.9241e-05
#
# Epoch 198
# Loss: 237.7671
# Psi gradient stats:
# Mean: -3.2528e-05
# Std:  4.1683e-03
# Max:  1.4558e-02
# Min:  -1.8339e-02
# Average psi change: 8.9219e-05
#
# Epoch 199
# Loss: 237.7035
# Psi gradient stats:
# Mean: -3.2807e-05
# Std:  4.1669e-03
# Max:  1.4558e-02
# Min:  -1.8332e-02
# Average psi change: 8.9202e-05
#
# Epoch 200
# Loss: 237.6373
# Psi gradient stats:
# Mean: -3.2883e-05
# Std:  4.1656e-03
# Max:  1.4547e-02
# Min:  -1.8317e-02
# Average psi change: 8.9187e-05
# Epoch 200, Loss: 237.6373, Gradients - Lambda: 5.586e-02, Phi: 8.296e-01, Gamma: 7.511e-03, Psi: 1.832e-02
#
# Epoch 201
# Loss: 237.5641
# Psi gradient stats:
# Mean: -3.2678e-05
# Std:  4.1641e-03
# Max:  1.4546e-02
# Min:  -1.8298e-02
# Average psi change: 8.9164e-05
#
# Epoch 202
# Loss: 237.5006
# Psi gradient stats:
# Mean: -3.2390e-05
# Std:  4.1622e-03
# Max:  1.4537e-02
# Min:  -1.8287e-02
# Average psi change: 8.9134e-05
#
# Epoch 203
# Loss: 237.4375
# Psi gradient stats:
# Mean: -3.2312e-05
# Std:  4.1603e-03
# Max:  1.4529e-02
# Min:  -1.8288e-02
# Average psi change: 8.9097e-05
#
# Epoch 204
# Loss: 237.3642
# Psi gradient stats:
# Mean: -3.2535e-05
# Std:  4.1587e-03
# Max:  1.4526e-02
# Min:  -1.8298e-02
# Average psi change: 8.9069e-05
#
# Epoch 205
# Loss: 237.2994
# Psi gradient stats:
# Mean: -3.2919e-05
# Std:  4.1573e-03
# Max:  1.4537e-02
# Min:  -1.8308e-02
# Average psi change: 8.9049e-05
#
# Epoch 206
# Loss: 237.2372
# Psi gradient stats:
# Mean: -3.3113e-05
# Std:  4.1561e-03
# Max:  1.4535e-02
# Min:  -1.8307e-02
# Average psi change: 8.9037e-05
#
# Epoch 207
# Loss: 237.1660
# Psi gradient stats:
# Mean: -3.2957e-05
# Std:  4.1546e-03
# Max:  1.4535e-02
# Min:  -1.8288e-02
# Average psi change: 8.9022e-05
#
# Epoch 208
# Loss: 237.0990
# Psi gradient stats:
# Mean: -3.2604e-05
# Std:  4.1528e-03
# Max:  1.4528e-02
# Min:  -1.8262e-02
# Average psi change: 8.8998e-05
#
# Epoch 209
# Loss: 237.0400
# Psi gradient stats:
# Mean: -3.2362e-05
# Std:  4.1508e-03
# Max:  1.4519e-02
# Min:  -1.8243e-02
# Average psi change: 8.8965e-05
#
# Epoch 210
# Loss: 236.9715
# Psi gradient stats:
# Mean: -3.2477e-05
# Std:  4.1491e-03
# Max:  1.4514e-02
# Min:  -1.8245e-02
# Average psi change: 8.8930e-05
# Epoch 210, Loss: 236.9715, Gradients - Lambda: 5.543e-02, Phi: 9.121e-01, Gamma: 7.429e-03, Psi: 1.824e-02
#
# Epoch 211
# Loss: 236.9029
# Psi gradient stats:
# Mean: -3.2847e-05
# Std:  4.1476e-03
# Max:  1.4516e-02
# Min:  -1.8261e-02
# Average psi change: 8.8903e-05
#
# Epoch 212
# Loss: 236.8443
# Psi gradient stats:
# Mean: -3.3183e-05
# Std:  4.1464e-03
# Max:  1.4524e-02
# Min:  -1.8278e-02
# Average psi change: 8.8887e-05
#
# Epoch 213
# Loss: 236.7779
# Psi gradient stats:
# Mean: -3.3206e-05
# Std:  4.1452e-03
# Max:  1.4528e-02
# Min:  -1.8278e-02
# Average psi change: 8.8874e-05
#
# Epoch 214
# Loss: 236.7083
# Psi gradient stats:
# Mean: -3.2910e-05
# Std:  4.1436e-03
# Max:  1.4525e-02
# Min:  -1.8256e-02
# Average psi change: 8.8862e-05
#
# Epoch 215
# Loss: 236.6515
# Psi gradient stats:
# Mean: -3.2582e-05
# Std:  4.1417e-03
# Max:  1.4516e-02
# Min:  -1.8224e-02
# Average psi change: 8.8840e-05
#
# Epoch 216
# Loss: 236.5893
# Psi gradient stats:
# Mean: -3.2520e-05
# Std:  4.1397e-03
# Max:  1.4504e-02
# Min:  -1.8203e-02
# Average psi change: 8.8805e-05
#
# Epoch 217
# Loss: 236.5171
# Psi gradient stats:
# Mean: -3.2777e-05
# Std:  4.1381e-03
# Max:  1.4499e-02
# Min:  -1.8206e-02
# Average psi change: 8.8769e-05
#
# Epoch 218
# Loss: 236.4579
# Psi gradient stats:
# Mean: -3.3137e-05
# Std:  4.1367e-03
# Max:  1.4506e-02
# Min:  -1.8229e-02
# Average psi change: 8.8744e-05
#
# Epoch 219
# Loss: 236.4016
# Psi gradient stats:
# Mean: -3.3291e-05
# Std:  4.1356e-03
# Max:  1.4519e-02
# Min:  -1.8249e-02
# Average psi change: 8.8730e-05
#
# Epoch 220
# Loss: 236.3326
# Psi gradient stats:
# Mean: -3.3144e-05
# Std:  4.1343e-03
# Max:  1.4527e-02
# Min:  -1.8246e-02
# Average psi change: 8.8720e-05
# Epoch 220, Loss: 236.3326, Gradients - Lambda: 5.399e-02, Phi: 8.120e-01, Gamma: 7.475e-03, Psi: 1.825e-02
#
# Epoch 221
# Loss: 236.2686
# Psi gradient stats:
# Mean: -3.2847e-05
# Std:  4.1326e-03
# Max:  1.4522e-02
# Min:  -1.8218e-02
# Average psi change: 8.8705e-05
#
# Epoch 222
# Loss: 236.2142
# Psi gradient stats:
# Mean: -3.2690e-05
# Std:  4.1307e-03
# Max:  1.4504e-02
# Min:  -1.8183e-02
# Average psi change: 8.8678e-05
#
# Epoch 223
# Loss: 236.1510
# Psi gradient stats:
# Mean: -3.2808e-05
# Std:  4.1288e-03
# Max:  1.4486e-02
# Min:  -1.8163e-02
# Average psi change: 8.8642e-05
#
# Epoch 224
# Loss: 236.0848
# Psi gradient stats:
# Mean: -3.3101e-05
# Std:  4.1272e-03
# Max:  1.4482e-02
# Min:  -1.8171e-02
# Average psi change: 8.8606e-05
#
# Epoch 225
# Loss: 236.0297
# Psi gradient stats:
# Mean: -3.3297e-05
# Std:  4.1259e-03
# Max:  1.4495e-02
# Min:  -1.8197e-02
# Average psi change: 8.8586e-05
#
# Epoch 226
# Loss: 235.9703
# Psi gradient stats:
# Mean: -3.3272e-05
# Std:  4.1247e-03
# Max:  1.4514e-02
# Min:  -1.8217e-02
# Average psi change: 8.8573e-05
#
# Epoch 227
# Loss: 235.9051
# Psi gradient stats:
# Mean: -3.3061e-05
# Std:  4.1234e-03
# Max:  1.4522e-02
# Min:  -1.8212e-02
# Average psi change: 8.8563e-05
#
# Epoch 228
# Loss: 235.8467
# Psi gradient stats:
# Mean: -3.2896e-05
# Std:  4.1217e-03
# Max:  1.4512e-02
# Min:  -1.8183e-02
# Average psi change: 8.8545e-05
#
# Epoch 229
# Loss: 235.7916
# Psi gradient stats:
# Mean: -3.2917e-05
# Std:  4.1199e-03
# Max:  1.4488e-02
# Min:  -1.8148e-02
# Average psi change: 8.8515e-05
#
# Epoch 230
# Loss: 235.7297
# Psi gradient stats:
# Mean: -3.3117e-05
# Std:  4.1180e-03
# Max:  1.4469e-02
# Min:  -1.8132e-02
# Average psi change: 8.8479e-05
# Epoch 230, Loss: 235.7297, Gradients - Lambda: 5.582e-02, Phi: 8.398e-01, Gamma: 7.458e-03, Psi: 1.813e-02
#
# Epoch 231
# Loss: 235.6673
# Psi gradient stats:
# Mean: -3.3295e-05
# Std:  4.1165e-03
# Max:  1.4470e-02
# Min:  -1.8142e-02
# Average psi change: 8.8450e-05
#
# Epoch 232
# Loss: 235.6147
# Psi gradient stats:
# Mean: -3.3329e-05
# Std:  4.1152e-03
# Max:  1.4488e-02
# Min:  -1.8167e-02
# Average psi change: 8.8428e-05
#
# Epoch 233
# Loss: 235.5561
# Psi gradient stats:
# Mean: -3.3211e-05
# Std:  4.1139e-03
# Max:  1.4506e-02
# Min:  -1.8182e-02
# Average psi change: 8.8415e-05
#
# Epoch 234
# Loss: 235.4955
# Psi gradient stats:
# Mean: -3.3083e-05
# Std:  4.1126e-03
# Max:  1.4509e-02
# Min:  -1.8172e-02
# Average psi change: 8.8406e-05
#
# Epoch 235
# Loss: 235.4401
# Psi gradient stats:
# Mean: -3.3090e-05
# Std:  4.1109e-03
# Max:  1.4494e-02
# Min:  -1.8143e-02
# Average psi change: 8.8387e-05
#
# Epoch 236
# Loss: 235.3863
# Psi gradient stats:
# Mean: -3.3202e-05
# Std:  4.1091e-03
# Max:  1.4473e-02
# Min:  -1.8114e-02
# Average psi change: 8.8353e-05
#
# Epoch 237
# Loss: 235.3270
# Psi gradient stats:
# Mean: -3.3309e-05
# Std:  4.1073e-03
# Max:  1.4460e-02
# Min:  -1.8105e-02
# Average psi change: 8.8314e-05
#
# Epoch 238
# Loss: 235.2697
# Psi gradient stats:
# Mean: -3.3330e-05
# Std:  4.1058e-03
# Max:  1.4465e-02
# Min:  -1.8117e-02
# Average psi change: 8.8286e-05
#
# Epoch 239
# Loss: 235.2174
# Psi gradient stats:
# Mean: -3.3242e-05
# Std:  4.1045e-03
# Max:  1.4482e-02
# Min:  -1.8137e-02
# Average psi change: 8.8269e-05
#
# Epoch 240
# Loss: 235.1602
# Psi gradient stats:
# Mean: -3.3197e-05
# Std:  4.1033e-03
# Max:  1.4495e-02
# Min:  -1.8146e-02
# Average psi change: 8.8257e-05
# Epoch 240, Loss: 235.1602, Gradients - Lambda: 5.380e-02, Phi: 8.961e-01, Gamma: 7.584e-03, Psi: 1.815e-02
#
# Epoch 241
# Loss: 235.1016
# Psi gradient stats:
# Mean: -3.3270e-05
# Std:  4.1019e-03
# Max:  1.4494e-02
# Min:  -1.8133e-02
# Average psi change: 8.8248e-05
#
# Epoch 242
# Loss: 235.0500
# Psi gradient stats:
# Mean: -3.3419e-05
# Std:  4.1002e-03
# Max:  1.4479e-02
# Min:  -1.8107e-02
# Average psi change: 8.8224e-05
#
# Epoch 243
# Loss: 234.9983
# Psi gradient stats:
# Mean: -3.3501e-05
# Std:  4.0984e-03
# Max:  1.4461e-02
# Min:  -1.8084e-02
# Average psi change: 8.8186e-05
#
# Epoch 244
# Loss: 234.9412
# Psi gradient stats:
# Mean: -3.3430e-05
# Std:  4.0967e-03
# Max:  1.4455e-02
# Min:  -1.8077e-02
# Average psi change: 8.8149e-05
#
# Epoch 245
# Loss: 234.8852
# Psi gradient stats:
# Mean: -3.3276e-05
# Std:  4.0953e-03
# Max:  1.4461e-02
# Min:  -1.8086e-02
# Average psi change: 8.8122e-05
#
# Epoch 246
# Loss: 234.8387
# Psi gradient stats:
# Mean: -3.3190e-05
# Std:  4.0941e-03
# Max:  1.4475e-02
# Min:  -1.8101e-02
# Average psi change: 8.8102e-05
#
# Epoch 247
# Loss: 234.7849
# Psi gradient stats:
# Mean: -3.3292e-05
# Std:  4.0927e-03
# Max:  1.4483e-02
# Min:  -1.8106e-02
# Average psi change: 8.8092e-05
#
# Epoch 248
# Loss: 234.7263
# Psi gradient stats:
# Mean: -3.3566e-05
# Std:  4.0912e-03
# Max:  1.4477e-02
# Min:  -1.8094e-02
# Average psi change: 8.8081e-05
#
# Epoch 249
# Loss: 234.6774
# Psi gradient stats:
# Mean: -3.3776e-05
# Std:  4.0895e-03
# Max:  1.4462e-02
# Min:  -1.8072e-02
# Average psi change: 8.8058e-05
#
# Epoch 250
# Loss: 234.6310
# Psi gradient stats:
# Mean: -3.3727e-05
# Std:  4.0878e-03
# Max:  1.4450e-02
# Min:  -1.8054e-02
# Average psi change: 8.8021e-05
# Epoch 250, Loss: 234.6310, Gradients - Lambda: 5.287e-02, Phi: 8.634e-01, Gamma: 7.528e-03, Psi: 1.805e-02
#
# Epoch 251
# Loss: 234.5723
# Psi gradient stats:
# Mean: -3.3444e-05
# Std:  4.0863e-03
# Max:  1.4446e-02
# Min:  -1.8049e-02
# Average psi change: 8.7986e-05
#
# Epoch 252
# Loss: 234.5216
# Psi gradient stats:
# Mean: -3.3149e-05
# Std:  4.0850e-03
# Max:  1.4454e-02
# Min:  -1.8056e-02
# Average psi change: 8.7959e-05
#
# Epoch 253
# Loss: 234.4782
# Psi gradient stats:
# Mean: -3.3140e-05
# Std:  4.0837e-03
# Max:  1.4465e-02
# Min:  -1.8064e-02
# Average psi change: 8.7943e-05
#
# Epoch 254
# Loss: 234.4242
# Psi gradient stats:
# Mean: -3.3470e-05
# Std:  4.0822e-03
# Max:  1.4469e-02
# Min:  -1.8066e-02
# Average psi change: 8.7930e-05
#
# Epoch 255
# Loss: 234.3678
# Psi gradient stats:
# Mean: -3.3890e-05
# Std:  4.0806e-03
# Max:  1.4463e-02
# Min:  -1.8056e-02
# Average psi change: 8.7917e-05
#
# Epoch 256
# Loss: 234.3253
# Psi gradient stats:
# Mean: -3.4066e-05
# Std:  4.0789e-03
# Max:  1.4451e-02
# Min:  -1.8039e-02
# Average psi change: 8.7893e-05
#
# Epoch 257
# Loss: 234.2782
# Psi gradient stats:
# Mean: -3.3824e-05
# Std:  4.0773e-03
# Max:  1.4442e-02
# Min:  -1.8025e-02
# Average psi change: 8.7861e-05
#
# Epoch 258
# Loss: 234.2225
# Psi gradient stats:
# Mean: -3.3370e-05
# Std:  4.0759e-03
# Max:  1.4440e-02
# Min:  -1.8021e-02
# Average psi change: 8.7829e-05
#
# Epoch 259
# Loss: 234.1754
# Psi gradient stats:
# Mean: -3.3090e-05
# Std:  4.0747e-03
# Max:  1.4445e-02
# Min:  -1.8023e-02
# Average psi change: 8.7804e-05
#
# Epoch 260
# Loss: 234.1343
# Psi gradient stats:
# Mean: -3.3238e-05
# Std:  4.0734e-03
# Max:  1.4451e-02
# Min:  -1.8027e-02
# Average psi change: 8.7784e-05
# Epoch 260, Loss: 234.1343, Gradients - Lambda: 5.247e-02, Phi: 8.800e-01, Gamma: 7.489e-03, Psi: 1.803e-02
#
# Epoch 261
# Loss: 234.0800
# Psi gradient stats:
# Mean: -3.3716e-05
# Std:  4.0718e-03
# Max:  1.4453e-02
# Min:  -1.8025e-02
# Average psi change: 8.7770e-05
#
# Epoch 262
# Loss: 234.0296
# Psi gradient stats:
# Mean: -3.4162e-05
# Std:  4.0702e-03
# Max:  1.4449e-02
# Min:  -1.8016e-02
# Average psi change: 8.7756e-05
#
# Epoch 263
# Loss: 233.9896
# Psi gradient stats:
# Mean: -3.4194e-05
# Std:  4.0685e-03
# Max:  1.4442e-02
# Min:  -1.8005e-02
# Average psi change: 8.7732e-05
#
# Epoch 264
# Loss: 233.9420
# Psi gradient stats:
# Mean: -3.3804e-05
# Std:  4.0670e-03
# Max:  1.4437e-02
# Min:  -1.7996e-02
# Average psi change: 8.7706e-05
#
# Epoch 265
# Loss: 233.8896
# Psi gradient stats:
# Mean: -3.3323e-05
# Std:  4.0657e-03
# Max:  1.4436e-02
# Min:  -1.7993e-02
# Average psi change: 8.7676e-05
#
# Epoch 266
# Loss: 233.8482
# Psi gradient stats:
# Mean: -3.3170e-05
# Std:  4.0644e-03
# Max:  1.4436e-02
# Min:  -1.7992e-02
# Average psi change: 8.7646e-05
#
# Epoch 267
# Loss: 233.8051
# Psi gradient stats:
# Mean: -3.3482e-05
# Std:  4.0630e-03
# Max:  1.4435e-02
# Min:  -1.7992e-02
# Average psi change: 8.7623e-05
#
# Epoch 268
# Loss: 233.7531
# Psi gradient stats:
# Mean: -3.4010e-05
# Std:  4.0614e-03
# Max:  1.4433e-02
# Min:  -1.7987e-02
# Average psi change: 8.7608e-05
#
# Epoch 269
# Loss: 233.7090
# Psi gradient stats:
# Mean: -3.4327e-05
# Std:  4.0598e-03
# Max:  1.4432e-02
# Min:  -1.7980e-02
# Average psi change: 8.7591e-05
#
# Epoch 270
# Loss: 233.6700
# Psi gradient stats:
# Mean: -3.4180e-05
# Std:  4.0583e-03
# Max:  1.4433e-02
# Min:  -1.7973e-02
# Average psi change: 8.7568e-05
# Epoch 270, Loss: 233.6700, Gradients - Lambda: 5.468e-02, Phi: 8.518e-01, Gamma: 7.575e-03, Psi: 1.797e-02
#
# Epoch 271
# Loss: 233.6216
# Psi gradient stats:
# Mean: -3.3718e-05
# Std:  4.0569e-03
# Max:  1.4434e-02
# Min:  -1.7967e-02
# Average psi change: 8.7543e-05
#
# Epoch 272
# Loss: 233.5752
# Psi gradient stats:
# Mean: -3.3356e-05
# Std:  4.0556e-03
# Max:  1.4433e-02
# Min:  -1.7963e-02
# Average psi change: 8.7512e-05
#
# Epoch 273
# Loss: 233.5373
# Psi gradient stats:
# Mean: -3.3400e-05
# Std:  4.0542e-03
# Max:  1.4426e-02
# Min:  -1.7960e-02
# Average psi change: 8.7482e-05
#
# Epoch 274
# Loss: 233.4920
# Psi gradient stats:
# Mean: -3.3820e-05
# Std:  4.0527e-03
# Max:  1.4417e-02
# Min:  -1.7957e-02
# Average psi change: 8.7464e-05
#
# Epoch 275
# Loss: 233.4457
# Psi gradient stats:
# Mean: -3.4256e-05
# Std:  4.0511e-03
# Max:  1.4412e-02
# Min:  -1.7951e-02
# Average psi change: 8.7450e-05
#
# Epoch 276
# Loss: 233.4053
# Psi gradient stats:
# Mean: -3.4354e-05
# Std:  4.0496e-03
# Max:  1.4415e-02
# Min:  -1.7943e-02
# Average psi change: 8.7428e-05
#
# Epoch 277
# Loss: 233.3646
# Psi gradient stats:
# Mean: -3.4058e-05
# Std:  4.0482e-03
# Max:  1.4426e-02
# Min:  -1.7939e-02
# Average psi change: 8.7407e-05
#
# Epoch 278
# Loss: 233.3188
# Psi gradient stats:
# Mean: -3.3655e-05
# Std:  4.0470e-03
# Max:  1.4434e-02
# Min:  -1.7936e-02
# Average psi change: 8.7378e-05
#
# Epoch 279
# Loss: 233.2779
# Psi gradient stats:
# Mean: -3.3509e-05
# Std:  4.0456e-03
# Max:  1.4430e-02
# Min:  -1.7934e-02
# Average psi change: 8.7348e-05
#
# Epoch 280
# Loss: 233.2369
# Psi gradient stats:
# Mean: -3.3732e-05
# Std:  4.0441e-03
# Max:  1.4415e-02
# Min:  -1.7932e-02
# Average psi change: 8.7324e-05
# Epoch 280, Loss: 233.2369, Gradients - Lambda: 5.352e-02, Phi: 8.359e-01, Gamma: 7.403e-03, Psi: 1.793e-02
#
# Epoch 281
# Loss: 233.1941
# Psi gradient stats:
# Mean: -3.4146e-05
# Std:  4.0424e-03
# Max:  1.4398e-02
# Min:  -1.7926e-02
# Average psi change: 8.7312e-05
#
# Epoch 282
# Loss: 233.1543
# Psi gradient stats:
# Mean: -3.4378e-05
# Std:  4.0408e-03
# Max:  1.4392e-02
# Min:  -1.7917e-02
# Average psi change: 8.7293e-05
#
# Epoch 283
# Loss: 233.1150
# Psi gradient stats:
# Mean: -3.4253e-05
# Std:  4.0395e-03
# Max:  1.4403e-02
# Min:  -1.7909e-02
# Average psi change: 8.7269e-05
#
# Epoch 284
# Loss: 233.0718
# Psi gradient stats:
# Mean: -3.3935e-05
# Std:  4.0383e-03
# Max:  1.4422e-02
# Min:  -1.7903e-02
# Average psi change: 8.7241e-05
#
# Epoch 285
# Loss: 233.0324
# Psi gradient stats:
# Mean: -3.3699e-05
# Std:  4.0371e-03
# Max:  1.4433e-02
# Min:  -1.7901e-02
# Average psi change: 8.7209e-05
#
# Epoch 286
# Loss: 232.9948
# Psi gradient stats:
# Mean: -3.3776e-05
# Std:  4.0357e-03
# Max:  1.4424e-02
# Min:  -1.7901e-02
# Average psi change: 8.7188e-05
#
# Epoch 287
# Loss: 232.9532
# Psi gradient stats:
# Mean: -3.4077e-05
# Std:  4.0339e-03
# Max:  1.4401e-02
# Min:  -1.7900e-02
# Average psi change: 8.7170e-05
#
# Epoch 288
# Loss: 232.9131
# Psi gradient stats:
# Mean: -3.4346e-05
# Std:  4.0322e-03
# Max:  1.4379e-02
# Min:  -1.7893e-02
# Average psi change: 8.7156e-05
#
# Epoch 289
# Loss: 232.8757
# Psi gradient stats:
# Mean: -3.4356e-05
# Std:  4.0307e-03
# Max:  1.4377e-02
# Min:  -1.7883e-02
# Average psi change: 8.7135e-05
#
# Epoch 290
# Loss: 232.8366
# Psi gradient stats:
# Mean: -3.4141e-05
# Std:  4.0296e-03
# Max:  1.4396e-02
# Min:  -1.7874e-02
# Average psi change: 8.7106e-05
# Epoch 290, Loss: 232.8366, Gradients - Lambda: 5.461e-02, Phi: 8.319e-01, Gamma: 7.643e-03, Psi: 1.787e-02
#
# Epoch 291
# Loss: 232.7964
# Psi gradient stats:
# Mean: -3.3911e-05
# Std:  4.0286e-03
# Max:  1.4418e-02
# Min:  -1.7869e-02
# Average psi change: 8.7074e-05
#
# Epoch 292
# Loss: 232.7579
# Psi gradient stats:
# ...
#
# Epoch 593
# Loss: 224.0599
# Psi gradient stats:
# Mean: -3.6617e-05
# Std:  3.6730e-03
# Max:  1.3967e-02
# Min:  -1.6725e-02
# Average psi change: 7.9838e-05
#
# Epoch 594
# Loss: 224.0454
# Psi gradient stats:
# Mean: -3.6449e-05
# Std:  3.6717e-03
# Max:  1.3967e-02
# Min:  -1.6710e-02
# Average psi change: 7.9804e-05
#
# Epoch 595
# Loss: 224.0345
# Psi gradient stats:
# Mean: -3.6625e-05
# Std:  3.6708e-03
# Max:  1.3948e-02
# Min:  -1.6690e-02
# Average psi change: 7.9765e-05
#
# Epoch 596
# Loss: 224.0059
# Psi gradient stats:
# Mean: -3.7027e-05
# Std:  3.6702e-03
# Max:  1.3927e-02
# Min:  -1.6682e-02
# Average psi change: 7.9744e-05
#
# Epoch 597
# Loss: 223.9842
# Psi gradient stats:
# Mean: -3.7311e-05
# Std:  3.6697e-03
# Max:  1.3923e-02
# Min:  -1.6694e-02
# Average psi change: 7.9735e-05
#
# Epoch 598
# Loss: 223.9749
# Psi gradient stats:
# Mean: -3.7274e-05
# Std:  3.6687e-03
# Max:  1.3936e-02
# Min:  -1.6714e-02
# Average psi change: 7.9716e-05
#
# Epoch 599
# Loss: 223.9548
# Psi gradient stats:
# Mean: -3.6934e-05
# Std:  3.6675e-03
# Max:  1.3954e-02
# Min:  -1.6722e-02
# Average psi change: 7.9691e-05
#
# Epoch 600
# Loss: 223.9243
# Psi gradient stats:
# Mean: -3.6571e-05
# Std:  3.6660e-03
# Max:  1.3956e-02
# Min:  -1.6707e-02
# Average psi change: 7.9654e-05
# Epoch 600, Loss: 223.9243, Gradients - Lambda: 5.889e-02, Phi: 1.013e+00, Gamma: 7.674e-03, Psi: 1.671e-02
#
# Epoch 601
# Loss: 223.9122
# Psi gradient stats:
# Mean: -3.6480e-05
# Std:  3.6647e-03
# Max:  1.3940e-02
# Min:  -1.6675e-02
# Average psi change: 7.9623e-05
#
# Epoch 602
# Loss: 223.9028
# Psi gradient stats:
# Mean: -3.6751e-05
# Std:  3.6639e-03
# Max:  1.3922e-02
# Min:  -1.6653e-02
# Average psi change: 7.9588e-05
#
# Epoch 603
# Loss: 223.8708
# Psi gradient stats:
# Mean: -3.7160e-05
# Std:  3.6633e-03
# Max:  1.3916e-02
# Min:  -1.6657e-02
# Average psi change: 7.9572e-05
#
# Epoch 604
# Loss: 223.8502
# Psi gradient stats:
# Mean: -3.7387e-05
# Std:  3.6627e-03
# Max:  1.3928e-02
# Min:  -1.6684e-02
# Average psi change: 7.9561e-05
#
# Epoch 605
# Loss: 223.8462
# Psi gradient stats:
# Mean: -3.7239e-05
# Std:  3.6618e-03
# Max:  1.3945e-02
# Min:  -1.6708e-02
# Average psi change: 7.9540e-05
#
# Epoch 606
# Loss: 223.8223
# Psi gradient stats:
# Mean: -3.6832e-05
# Std:  3.6604e-03
# Max:  1.3948e-02
# Min:  -1.6707e-02
# Average psi change: 7.9513e-05
#
# Epoch 607
# Loss: 223.7922
# Psi gradient stats:
# Mean: -3.6498e-05
# Std:  3.6589e-03
# Max:  1.3932e-02
# Min:  -1.6677e-02
# Average psi change: 7.9476e-05
#
# Epoch 608
# Loss: 223.7859
# Psi gradient stats:
# Mean: -3.6515e-05
# Std:  3.6577e-03
# Max:  1.3909e-02
# Min:  -1.6641e-02
# Average psi change: 7.9441e-05
#
# Epoch 609
# Loss: 223.7700
# Psi gradient stats:
# Mean: -3.6867e-05
# Std:  3.6570e-03
# Max:  1.3902e-02
# Min:  -1.6626e-02
# Average psi change: 7.9412e-05
#
# Epoch 610
# Loss: 223.7374
# Psi gradient stats:
# Mean: -3.7273e-05
# Std:  3.6565e-03
# Max:  1.3917e-02
# Min:  -1.6644e-02
# Average psi change: 7.9398e-05
# Epoch 610, Loss: 223.7374, Gradients - Lambda: 6.657e-02, Phi: 1.062e+00, Gamma: 7.553e-03, Psi: 1.664e-02
#
# Epoch 611
# Loss: 223.7234
# Psi gradient stats:
# Mean: -3.7414e-05
# Std:  3.6558e-03
# Max:  1.3939e-02
# Min:  -1.6676e-02
# Average psi change: 7.9384e-05
#
# Epoch 612
# Loss: 223.7183
# Psi gradient stats:
# Mean: -3.7180e-05
# Std:  3.6548e-03
# Max:  1.3946e-02
# Min:  -1.6695e-02
# Average psi change: 7.9359e-05
#
# Epoch 613
# Loss: 223.6874
# Psi gradient stats:
# Mean: -3.6761e-05
# Std:  3.6534e-03
# Max:  1.3928e-02
# Min:  -1.6681e-02
# Average psi change: 7.9330e-05
#
# Epoch 614
# Loss: 223.6656
# Psi gradient stats:
# Mean: -3.6505e-05
# Std:  3.6520e-03
# Max:  1.3900e-02
# Min:  -1.6645e-02
# Average psi change: 7.9297e-05
#
# Epoch 615
# Loss: 223.6625
# Psi gradient stats:
# Mean: -3.6607e-05
# Std:  3.6509e-03
# Max:  1.3887e-02
# Min:  -1.6615e-02
# Average psi change: 7.9263e-05
#
# Epoch 616
# Loss: 223.6386
# Psi gradient stats:
# Mean: -3.6995e-05
# Std:  3.6502e-03
# Max:  1.3901e-02
# Min:  -1.6613e-02
# Average psi change: 7.9240e-05
#
# Epoch 617
# Loss: 223.6082
# Psi gradient stats:
# Mean: -3.7346e-05
# Std:  3.6497e-03
# Max:  1.3929e-02
# Min:  -1.6637e-02
# Average psi change: 7.9223e-05
#
# Epoch 618
# Loss: 223.6053
# Psi gradient stats:
# Mean: -3.7384e-05
# Std:  3.6489e-03
# Max:  1.3944e-02
# Min:  -1.6662e-02
# Average psi change: 7.9207e-05
#
# Epoch 619
# Loss: 223.5904
# Psi gradient stats:
# Mean: -3.7084e-05
# Std:  3.6478e-03
# Max:  1.3930e-02
# Min:  -1.6665e-02
# Average psi change: 7.9181e-05
#
# Epoch 620
# Loss: 223.5554
# Psi gradient stats:
# Mean: -3.6678e-05
# Std:  3.6464e-03
# Max:  1.3897e-02
# Min:  -1.6642e-02
# Average psi change: 7.9148e-05
# Epoch 620, Loss: 223.5554, Gradients - Lambda: 5.663e-02, Phi: 1.134e+00, Gamma: 7.583e-03, Psi: 1.664e-02
#
# Epoch 621
# Loss: 223.5460
# Psi gradient stats:
# Mean: -3.6500e-05
# Std:  3.6450e-03
# Max:  1.3873e-02
# Min:  -1.6612e-02
# Average psi change: 7.9117e-05
#
# Epoch 622
# Loss: 223.5397
# Psi gradient stats:
# Mean: -3.6703e-05
# Std:  3.6440e-03
# Max:  1.3880e-02
# Min:  -1.6599e-02
# Average psi change: 7.9089e-05
#
# Epoch 623
# Loss: 223.5047
# Psi gradient stats:
# Mean: -3.7096e-05
# Std:  3.6434e-03
# Max:  1.3911e-02
# Min:  -1.6611e-02
# Average psi change: 7.9070e-05
#
# Epoch 624
# Loss: 223.4877
# Psi gradient stats:
# Mean: -3.7390e-05
# Std:  3.6428e-03
# Max:  1.3937e-02
# Min:  -1.6631e-02
# Average psi change: 7.9049e-05
#
# Epoch 625
# Loss: 223.4859
# Psi gradient stats:
# Mean: -3.7326e-05
# Std:  3.6420e-03
# Max:  1.3932e-02
# Min:  -1.6638e-02
# Average psi change: 7.9025e-05
#
# Epoch 626
# Loss: 223.4587
# Psi gradient stats:
# Mean: -3.6974e-05
# Std:  3.6408e-03
# Max:  1.3899e-02
# Min:  -1.6625e-02
# Average psi change: 7.8997e-05
#
# Epoch 627
# Loss: 223.4304
# Psi gradient stats:
# Mean: -3.6630e-05
# Std:  3.6394e-03
# Max:  1.3865e-02
# Min:  -1.6603e-02
# Average psi change: 7.8967e-05
#
# Epoch 628
# Loss: 223.4293
# Psi gradient stats:
# Mean: -3.6569e-05
# Std:  3.6382e-03
# Max:  1.3860e-02
# Min:  -1.6591e-02
# Average psi change: 7.8935e-05
#
# Epoch 629
# Loss: 223.4125
# Psi gradient stats:
# Mean: -3.6851e-05
# Std:  3.6373e-03
# Max:  1.3889e-02
# Min:  -1.6597e-02
# Average psi change: 7.8917e-05
#
# Epoch 630
# Loss: 223.3775
# Psi gradient stats:
# Mean: -3.7239e-05
# Std:  3.6367e-03
# Max:  1.3925e-02
# Min:  -1.6612e-02
# Average psi change: 7.8898e-05
# Epoch 630, Loss: 223.3775, Gradients - Lambda: 5.808e-02, Phi: 1.078e+00, Gamma: 7.627e-03, Psi: 1.661e-02
#
# Epoch 631
# Loss: 223.3701
# Psi gradient stats:
# Mean: -3.7414e-05
# Std:  3.6361e-03
# Max:  1.3933e-02
# Min:  -1.6618e-02
# Average psi change: 7.8870e-05
#
# Epoch 632
# Loss: 223.3627
# Psi gradient stats:
# Mean: -3.7236e-05
# Std:  3.6352e-03
# Max:  1.3905e-02
# Min:  -1.6606e-02
# Average psi change: 7.8847e-05
#
# Epoch 633
# Loss: 223.3295
# Psi gradient stats:
# Mean: -3.6859e-05
# Std:  3.6339e-03
# Max:  1.3865e-02
# Min:  -1.6586e-02
# Average psi change: 7.8817e-05
#
# Epoch 634
# Loss: 223.3122
# Psi gradient stats:
# Mean: -3.6578e-05
# Std:  3.6325e-03
# Max:  1.3847e-02
# Min:  -1.6574e-02
# Average psi change: 7.8786e-05
#
# Epoch 635
# Loss: 223.3089
# Psi gradient stats:
# Mean: -3.6623e-05
# Std:  3.6314e-03
# Max:  1.3867e-02
# Min:  -1.6581e-02
# Average psi change: 7.8760e-05
#
# Epoch 636
# Loss: 223.2835
# Psi gradient stats:
# Mean: -3.6978e-05
# Std:  3.6306e-03
# Max:  1.3906e-02
# Min:  -1.6598e-02
# Average psi change: 7.8750e-05
#
# Epoch 637
# Loss: 223.2578
# Psi gradient stats:
# Mean: -3.7344e-05
# Std:  3.6300e-03
# Max:  1.3927e-02
# Min:  -1.6605e-02
# Average psi change: 7.8726e-05
#
# Epoch 638
# Loss: 223.2532
# Psi gradient stats:
# Mean: -3.7447e-05
# Std:  3.6293e-03
# Max:  1.3909e-02
# Min:  -1.6593e-02
# Average psi change: 7.8693e-05
#
# Epoch 639
# Loss: 223.2373
# Psi gradient stats:
# Mean: -3.7184e-05
# Std:  3.6283e-03
# Max:  1.3868e-02
# Min:  -1.6568e-02
# Average psi change: 7.8665e-05
#
# Epoch 640
# Loss: 223.2058
# Psi gradient stats:
# Mean: -3.6770e-05
# Std:  3.6270e-03
# Max:  1.3839e-02
# Min:  -1.6552e-02
# Average psi change: 7.8638e-05
# Epoch 640, Loss: 223.2058, Gradients - Lambda: 6.110e-02, Phi: 1.008e+00, Gamma: 7.516e-03, Psi: 1.655e-02
#
# Epoch 641
# Loss: 223.1947
# Psi gradient stats:
# Mean: -3.6524e-05
# Std:  3.6256e-03
# Max:  1.3848e-02
# Min:  -1.6557e-02
# Average psi change: 7.8606e-05
#
# Epoch 642
# Loss: 223.1880
# Psi gradient stats:
# Mean: -3.6658e-05
# Std:  3.6246e-03
# Max:  1.3886e-02
# Min:  -1.6578e-02
# Average psi change: 7.8588e-05
#
# Epoch 643
# Loss: 223.1595
# Psi gradient stats:
# Mean: -3.7074e-05
# Std:  3.6239e-03
# Max:  1.3916e-02
# Min:  -1.6595e-02
# Average psi change: 7.8578e-05
#
# Epoch 644
# Loss: 223.1379
# Psi gradient stats:
# Mean: -3.7460e-05
# Std:  3.6233e-03
# Max:  1.3911e-02
# Min:  -1.6590e-02
# Average psi change: 7.8549e-05
#
# Epoch 645
# Loss: 223.1339
# Psi gradient stats:
# Mean: -3.7496e-05
# Std:  3.6226e-03
# Max:  1.3872e-02
# Min:  -1.6563e-02
# Average psi change: 7.8515e-05
#
# Epoch 646
# Loss: 223.1130
# Psi gradient stats:
# Mean: -3.7148e-05
# Std:  3.6214e-03
# Max:  1.3834e-02
# Min:  -1.6535e-02
# Average psi change: 7.8486e-05
#
# Epoch 647
# Loss: 223.0844
# Psi gradient stats:
# Mean: -3.6669e-05
# Std:  3.6200e-03
# Max:  1.3829e-02
# Min:  -1.6527e-02
# Average psi change: 7.8456e-05
#
# Epoch 648
# Loss: 223.0778
# Psi gradient stats:
# Mean: -3.6445e-05
# Std:  3.6188e-03
# Max:  1.3861e-02
# Min:  -1.6545e-02
# Average psi change: 7.8428e-05
#
# Epoch 649
# Loss: 223.0667
# Psi gradient stats:
# Mean: -3.6658e-05
# Std:  3.6179e-03
# Max:  1.3901e-02
# Min:  -1.6572e-02
# Average psi change: 7.8416e-05
#
# Epoch 650
# Loss: 223.0349
# Psi gradient stats:
# Mean: -3.7167e-05
# Std:  3.6173e-03
# Max:  1.3910e-02
# Min:  -1.6582e-02
# Average psi change: 7.8404e-05
# Epoch 650, Loss: 223.0349, Gradients - Lambda: 6.024e-02, Phi: 9.404e-01, Gamma: 7.720e-03, Psi: 1.658e-02
#
# Epoch 651
# Loss: 223.0197
# Psi gradient stats:
# Mean: -3.7563e-05
# Std:  3.6167e-03
# Max:  1.3879e-02
# Min:  -1.6563e-02
# Average psi change: 7.8371e-05
#
# Epoch 652
# Loss: 223.0154
# Psi gradient stats:
# Mean: -3.7546e-05
# Std:  3.6159e-03
# Max:  1.3834e-02
# Min:  -1.6529e-02
# Average psi change: 7.8338e-05
#
# Epoch 653
# Loss: 222.9900
# Psi gradient stats:
# Mean: -3.7087e-05
# Std:  3.6146e-03
# Max:  1.3815e-02
# Min:  -1.6505e-02
# Average psi change: 7.8306e-05
#
# Epoch 654
# Loss: 222.9625
# Psi gradient stats:
# Mean: -3.6546e-05
# Std:  3.6132e-03
# Max:  1.3837e-02
# Min:  -1.6511e-02
# Average psi change: 7.8275e-05
#
# Epoch 655
# Loss: 222.9601
# Psi gradient stats:
# Mean: -3.6369e-05
# Std:  3.6120e-03
# Max:  1.3881e-02
# Min:  -1.6538e-02
# Average psi change: 7.8254e-05
#
# Epoch 656
# Loss: 222.9449
# Psi gradient stats:
# Mean: -3.6710e-05
# Std:  3.6112e-03
# Max:  1.3906e-02
# Min:  -1.6563e-02
# Average psi change: 7.8248e-05
#
# Epoch 657
# Loss: 222.9122
# Psi gradient stats:
# Mean: -3.7310e-05
# Std:  3.6107e-03
# Max:  1.3889e-02
# Min:  -1.6561e-02
# Average psi change: 7.8232e-05
#
# Epoch 658
# Loss: 222.9006
# Psi gradient stats:
# Mean: -3.7705e-05
# Std:  3.6101e-03
# Max:  1.3844e-02
# Min:  -1.6532e-02
# Average psi change: 7.8196e-05
#
# Epoch 659
# Loss: 222.8956
# Psi gradient stats:
# Mean: -3.7571e-05
# Std:  3.6091e-03
# Max:  1.3809e-02
# Min:  -1.6498e-02
# Average psi change: 7.8158e-05
#
# Epoch 660
# Loss: 222.8654
# Psi gradient stats:
# Mean: -3.6994e-05
# Std:  3.6077e-03
# Max:  1.3815e-02
# Min:  -1.6487e-02
# Average psi change: 7.8128e-05
# Epoch 660, Loss: 222.8654, Gradients - Lambda: 5.984e-02, Phi: 9.503e-01, Gamma: 7.763e-03, Psi: 1.649e-02
#
# Epoch 661
# Loss: 222.8437
# Psi gradient stats:
# Mean: -3.6421e-05
# Std:  3.6063e-03
# Max:  1.3854e-02
# Min:  -1.6504e-02
# Average psi change: 7.8096e-05
#
# Epoch 662
# Loss: 222.8421
# Psi gradient stats:
# Mean: -3.6336e-05
# Std:  3.6053e-03
# Max:  1.3890e-02
# Min:  -1.6533e-02
# Average psi change: 7.8080e-05
#
# Epoch 663
# Loss: 222.8203
# Psi gradient stats:
# Mean: -3.6811e-05
# Std:  3.6047e-03
# Max:  1.3891e-02
# Min:  -1.6547e-02
# Average psi change: 7.8081e-05
#
# Epoch 664
# Loss: 222.7905
# Psi gradient stats:
# Mean: -3.7472e-05
# Std:  3.6042e-03
# Max:  1.3854e-02
# Min:  -1.6531e-02
# Average psi change: 7.8064e-05
#
# Epoch 665
# Loss: 222.7841
# Psi gradient stats:
# Mean: -3.7783e-05
# Std:  3.6035e-03
# Max:  1.3810e-02
# Min:  -1.6498e-02
# Average psi change: 7.8018e-05
#
# Epoch 666
# Loss: 222.7739
# Psi gradient stats:
# Mean: -3.7493e-05
# Std:  3.6023e-03
# Max:  1.3798e-02
# Min:  -1.6473e-02
# Average psi change: 7.7978e-05
#
# Epoch 667
# Loss: 222.7438
# Psi gradient stats:
# Mean: -3.6811e-05
# Std:  3.6009e-03
# Max:  1.3825e-02
# Min:  -1.6477e-02
# Average psi change: 7.7945e-05
#
# Epoch 668
# Loss: 222.7250
# Psi gradient stats:
# Mean: -3.6318e-05
# Std:  3.5996e-03
# Max:  1.3866e-02
# Min:  -1.6501e-02
# Average psi change: 7.7922e-05
#
# Epoch 669
# Loss: 222.7210
# Psi gradient stats:
# Mean: -3.6400e-05
# Std:  3.5988e-03
# Max:  1.3884e-02
# Min:  -1.6524e-02
# Average psi change: 7.7908e-05
#
# Epoch 670
# Loss: 222.6985
# Psi gradient stats:
# Mean: -3.7003e-05
# Std:  3.5982e-03
# Max:  1.3861e-02
# Min:  -1.6522e-02
# Average psi change: 7.7911e-05
# Epoch 670, Loss: 222.6985, Gradients - Lambda: 5.886e-02, Phi: 1.020e+00, Gamma: 7.796e-03, Psi: 1.652e-02
#
# Epoch 671
# Loss: 222.6704
# Psi gradient stats:
# Mean: -3.7631e-05
# Std:  3.5977e-03
# Max:  1.3818e-02
# Min:  -1.6495e-02
# Average psi change: 7.7886e-05
#
# Epoch 672
# Loss: 222.6635
# Psi gradient stats:
# Mean: -3.7772e-05
# Std:  3.5967e-03
# Max:  1.3791e-02
# Min:  -1.6466e-02
# Average psi change: 7.7835e-05
#
# Epoch 673
# Loss: 222.6513
# Psi gradient stats:
# Mean: -3.7320e-05
# Std:  3.5954e-03
# Max:  1.3802e-02
# Min:  -1.6457e-02
# Average psi change: 7.7796e-05
#
# Epoch 674
# Loss: 222.6212
# Psi gradient stats:
# Mean: -3.6642e-05
# Std:  3.5941e-03
# Max:  1.3841e-02
# Min:  -1.6474e-02
# Average psi change: 7.7765e-05
#
# Epoch 675
# Loss: 222.6042
# Psi gradient stats:
# Mean: -3.6297e-05
# Std:  3.5930e-03
# Max:  1.3871e-02
# Min:  -1.6499e-02
# Average psi change: 7.7744e-05
#
# Epoch 676
# Loss: 222.5988
# Psi gradient stats:
# Mean: -3.6560e-05
# Std:  3.5923e-03
# Max:  1.3866e-02
# Min:  -1.6506e-02
# Average psi change: 7.7741e-05
#
# Epoch 677
# Loss: 222.5759
# Psi gradient stats:
# Mean: -3.7204e-05
# Std:  3.5918e-03
# Max:  1.3830e-02
# Min:  -1.6488e-02
# Average psi change: 7.7738e-05
#
# Epoch 678
# Loss: 222.5480
# Psi gradient stats:
# Mean: -3.7695e-05
# Std:  3.5911e-03
# Max:  1.3794e-02
# Min:  -1.6458e-02
# Average psi change: 7.7705e-05
#
# Epoch 679
# Loss: 222.5419
# Psi gradient stats:
# Mean: -3.7630e-05
# Std:  3.5900e-03
# Max:  1.3789e-02
# Min:  -1.6440e-02
# Average psi change: 7.7655e-05
#
# Epoch 680
# Loss: 222.5300
# Psi gradient stats:
# Mean: -3.7083e-05
# Std:  3.5886e-03
# Max:  1.3817e-02
# Min:  -1.6448e-02
# Average psi change: 7.7618e-05
# Epoch 680, Loss: 222.5300, Gradients - Lambda: 6.196e-02, Phi: 1.029e+00, Gamma: 7.718e-03, Psi: 1.645e-02
#
# Epoch 681
# Loss: 222.4973
# Psi gradient stats:
# Mean: -3.6517e-05
# Std:  3.5874e-03
# Max:  1.3852e-02
# Min:  -1.6473e-02
# Average psi change: 7.7588e-05
#
# Epoch 682
# Loss: 222.4821
# Psi gradient stats:
# Mean: -3.6406e-05
# Std:  3.5865e-03
# Max:  1.3862e-02
# Min:  -1.6490e-02
# Average psi change: 7.7570e-05
#
# Epoch 683
# Loss: 222.4794
# Psi gradient stats:
# Mean: -3.6823e-05
# Std:  3.5859e-03
# Max:  1.3837e-02
# Min:  -1.6482e-02
# Average psi change: 7.7573e-05
#
# Epoch 684
# Loss: 222.4509
# Psi gradient stats:
# Mean: -3.7392e-05
# Std:  3.5853e-03
# Max:  1.3798e-02
# Min:  -1.6453e-02
# Average psi change: 7.7567e-05
#
# Epoch 685
# Loss: 222.4247
# Psi gradient stats:
# Mean: -3.7652e-05
# Std:  3.5845e-03
# Max:  1.3779e-02
# Min:  -1.6427e-02
# Average psi change: 7.7526e-05
#
# Epoch 686
# Loss: 222.4230
# Psi gradient stats:
# Mean: -3.7387e-05
# Std:  3.5832e-03
# Max:  1.3795e-02
# Min:  -1.6424e-02
# Average psi change: 7.7476e-05
#
# Epoch 687
# Loss: 222.4048
# Psi gradient stats:
# Mean: -3.6849e-05
# Std:  3.5819e-03
# Max:  1.3830e-02
# Min:  -1.6446e-02
# Average psi change: 7.7448e-05
#
# Epoch 688
# Loss: 222.3706
# Psi gradient stats:
# Mean: -3.6484e-05
# Std:  3.5808e-03
# Max:  1.3851e-02
# Min:  -1.6470e-02
# Average psi change: 7.7420e-05
#
# Epoch 689
# Loss: 222.3632
# Psi gradient stats:
# Mean: -3.6589e-05
# Std:  3.5800e-03
# Max:  1.3838e-02
# Min:  -1.6473e-02
# Average psi change: 7.7406e-05
#
# Epoch 690
# Loss: 222.3566
# Psi gradient stats:
# Mean: -3.7045e-05
# Std:  3.5795e-03
# Max:  1.3801e-02
# Min:  -1.6449e-02
# Average psi change: 7.7409e-05
# Epoch 690, Loss: 222.3566, Gradients - Lambda: 5.864e-02, Phi: 9.595e-01, Gamma: 7.626e-03, Psi: 1.645e-02
#
# Epoch 691
# Loss: 222.3212
# Psi gradient stats:
# Mean: -3.7464e-05
# Std:  3.5788e-03
# Max:  1.3772e-02
# Min:  -1.6417e-02
# Average psi change: 7.7391e-05
#
# Epoch 692
# Loss: 222.3038
# Psi gradient stats:
# Mean: -3.7490e-05
# Std:  3.5778e-03
# Max:  1.3775e-02
# Min:  -1.6404e-02
# Average psi change: 7.7339e-05
#
# Epoch 693
# Loss: 222.3037
# Psi gradient stats:
# Mean: -3.7135e-05
# Std:  3.5765e-03
# Max:  1.3806e-02
# Min:  -1.6419e-02
# Average psi change: 7.7292e-05
#
# Converged at epoch 693. Loss change: 0.0001
#
# Overall psi changes:

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history['max_grad_lambda'], label='Lambda')
ax2.plot(history['max_grad_phi'], label='Phi')
ax2.plot(history['max_grad_gamma'], label='Gamma')
ax2.plot(history['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
# Get the posterior phi values
phi_posterior = model.phi.detach().cpu().numpy()  # Shape should be [K, D, T]

# Create visualization
plt.figure(figsize=(15, 10))

# Plot phi trajectories for each cluster
for k in range(model.K):
    # Get diseases in this cluster
    cluster_mask = (model.clusters == k)
    cluster_phis = phi_posterior[k, cluster_mask, :]
    
    plt.subplot(4, 5, k+1)  # Adjust grid size based on number of clusters
    plt.plot(cluster_phis.T, alpha=0.3)  # Plot each disease trajectory
    plt.title(f'Cluster {k}\n({np.sum(cluster_mask)} diseases)')
    plt.grid(True)
    
plt.tight_layout()
plt.show()

# You might also want to see cluster means
plt.figure(figsize=(12, 6))
cluster_means = np.array([phi_posterior[k, model.clusters == k, :].mean(axis=0) 
                         for k in range(model.K)])
plt.plot(cluster_means.T)
plt.title('Mean Phi Trajectories by Cluster')
plt.xlabel('Time')
plt.ylabel('Phi Value')
plt.legend([f'Cluster {k}' for k in range(model.K)])
plt.grid(True)
plt.show()

# %%
import torch

# Save complete state for R
save_path = '/Users/sarahurbut/aladynoulli/pyScripts/model_complete_for_R_121_logitinit_nobg.pt'

torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'psi': model.psi,
    'Y': Y,
    'prevalence_t':prevalence_t,
    'G': G,
    'E': E,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': N,
        'D': D,
        'T': T,
        'P': P,
        'K': K
    }
}, save_path)

# %%
import numpy as np
import pandas as pd
import rpy2.robjects as robjects
from rpy2.robjects import numpy2ri
numpy2ri.activate()

# Extract key components from model
with torch.no_grad():
    pi_pred, theta, phi = model.forward()
    
# Convert tensors to numpy arrays - check type first
pi_pred = pi_pred.cpu().detach().numpy()
theta = theta.cpu().detach().numpy()
phi = model.phi.cpu().detach().numpy()
psi = model.psi.cpu().detach().numpy()
lambda_vals = model.lambda_.cpu().detach().numpy()

# These are already numpy arrays
clusters = model.clusters  # Already numpy


# Save components as .rds files
save_path = '/Users/sarahurbut/Dropbox (Personal)/aladynoulli/Rdata/'
# Main parameters
robjects.r.saveRDS(phi, f"{save_path}phi.rds")
robjects.r.saveRDS(psi, f"{save_path}psi.rds")
robjects.r.saveRDS(lambda_vals, f"{save_path}lambda.rds")
robjects.r.saveRDS(theta, f"{save_path}theta.rds")
robjects.r.saveRDS(pi_pred, f"{save_path}pi_pred.rds")
robjects.r.saveRDS(clusters, f"{save_path}clusters.rds")

# %%
robjects.r.saveRDS(Y, f"{save_path}Y.rds")
robjects.r.saveRDS(E, f"{save_path}E.rds")
robjects.r.saveRDS(G, f"{save_path}G.rds")

# %%
prevalence_t = checkpoint['prevalence_t']  # Get from checkpoint instead


robjects.r.saveRDS(prevalence_t, f"{save_path}prevalence_t.rds")

# %%
# Save disease names
robjects.r.saveRDS(checkpoint['disease_names'], f"{save_path}disease_names.rds")

# %%
# First load the saved state
checkpoint = torch.load('/Users/sarahurbut/Dropbox (Personal)/model_complete_for_R_121_logitinit_nobg.pt')

# Create a new model instance with the same parameters
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(
    N=checkpoint['hyperparameters']['N'],
    D=checkpoint['hyperparameters']['D'],
    T=checkpoint['hyperparameters']['T'],
    K=checkpoint['hyperparameters']['K'],
    P=checkpoint['hyperparameters']['P'],
    G=checkpoint['G'],
    Y=checkpoint['Y'],
    prevalence_t=checkpoint['prevalence_t'],
    disease_names=checkpoint['disease_names']
)

# Load the saved state into the model
model.load_state_dict(checkpoint['model_state_dict'])
model.clusters = checkpoint['clusters']


# Generate predictions
with torch.no_grad():
    pi_pred, theta, phi = model.forward()
    pi_pred = pi_pred.cpu().numpy()

# %%
model.visualize_initialization()

# %%
# Plot training loss history
plt.figure(figsize=(10, 5))
plt.plot(history['loss'])
plt.yscale('log')
plt.title('Training Loss Over Time')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.grid(True)
plt.show()

# Visualize psi map
plt.figure(figsize=(15, 8))
psi_np = model.psi.detach().numpy()
plt.imshow(psi_np, aspect='auto', cmap='RdBu_r')
plt.colorbar(label='ψ value')
plt.xlabel('Disease')
plt.ylabel('State/Cluster')
plt.title('Disease-State Deviations (ψ) After Mean Removal')

# If you have disease names, add them as x-axis labels
if disease_names_list:
    plt.xticks(range(len(disease_names_list)), disease_names_list, rotation=90)

plt.tight_layout()
plt.show()

# Print some summary statistics about psi
print("\nPsi Statistics:")
print(f"Mean: {psi_np.mean():.3f}")
print(f"Std: {psi_np.std():.3f}")
print(f"Min: {psi_np.min():.3f}")
print(f"Max: {psi_np.max():.3f}")

# Optionally, identify the strongest associations

# %%
psi_np = model.psi.detach().numpy()

# Print basic info about psi matrix
print("Psi matrix shape:", psi_np.shape)
print("\nPsi value ranges:")
print(f"Min: {psi_np.min():.3f}")
print(f"Max: {psi_np.max():.3f}")
print(f"Mean: {psi_np.mean():.3f}")
print(f"Std: {psi_np.std():.3f}")

# Look at a small sample of values
print("\nSample of psi values (first 5 states, first 5 diseases):")
print(psi_np[:5, :5])

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, disease_names_list)

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, disease_names_list)

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, disease_names_list)

# %%
def evaluate_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    # Create at-risk mask
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions for events vs non-events
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    
    # Could also add:
    # 1. ROC curve
    # 2. Disease-specific metrics
    # 3. Time-stratified evaluation
    
    return event_probs, nonevent_probs

# %%
def evaluate_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    # Create at-risk mask
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions for events vs non-events
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    
    # Could also add:
    # 1. ROC curve
    # 2. Disease-specific metrics
    # 3. Time-stratified evaluation
    
    return event_probs, nonevent_probs

evaluate_predictions(model, Y, E)

# %%
def visualize_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    plt.figure(figsize=(15, 5))
    
    # 1. Density plot of predictions
    plt.subplot(131)
    plt.hist(event_probs, bins=50, density=True, alpha=0.5, label='Events', color='red')
    plt.hist(nonevent_probs, bins=50, density=True, alpha=0.5, label='Non-events', color='blue')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Density')
    plt.title('Distribution of Predictions')
    plt.legend()
    
    # 2. ROC curve
    from sklearn.metrics import roc_curve, auc
    y_true = np.concatenate([np.ones_like(event_probs), np.zeros_like(nonevent_probs)])
    y_pred = np.concatenate([event_probs, nonevent_probs])
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    
    plt.subplot(132)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    
    # 3. Calibration plot
    from sklearn.calibration import calibration_curve
    prob_true, prob_pred = calibration_curve(y_true, y_pred, n_bins=10)
    
    plt.subplot(133)
    plt.plot(prob_pred, prob_true, marker='o', label='Model')
    plt.plot([0, 1], [0, 1], linestyle='--', label='Perfect calibration')
    plt.xlabel('Mean predicted probability')
    plt.ylabel('Empirical probability')
    plt.title('Calibration Plot')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    print(f"AUC: {roc_auc:.4f}")
    
    return event_probs, nonevent_probs, roc_auc

# %%
visualize_predictions(model, Y, E)

# %%
def plot_event_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    # Get predictions for events and non-events
    events_mask = (Y == 1)
    nonevents_mask = (Y == 0)
    
    # Sample for speed (optional)
    n_samples = 10000
    event_probs = np.random.choice(pi_pred[events_mask], n_samples)
    nonevent_probs = np.random.choice(pi_pred[nonevents_mask], n_samples)
    
    plt.figure(figsize=(8, 5))
    plt.hist(event_probs, bins=50, density=True, alpha=0.5, 
             label=f'Events (mean={event_probs.mean():.4f})', color='red')
    plt.hist(nonevent_probs, bins=50, density=True, alpha=0.5, 
             label=f'Non-events (mean={nonevent_probs.mean():.4f})', color='blue')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Density')
    plt.title('Distribution of Predictions')
    plt.legend()
    plt.show()
    
    return event_probs, nonevent_probs
 
plot_event_predictions(model,Y,E)

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
plot_signature_temporal_patterns(model, disease_names_list, selected_signatures=[0,1,14,15,16,13,17])

# %%
def evaluate_survival_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred = model.forward()[0].cpu().numpy()
    
    remaining_risks = []
    true_outcomes = []
    
    # First, let's check what events we actually have
    print("Total events in Y:", np.sum(Y))
    print("Distribution of event_times:", np.bincount(event_times.flatten()))
    
    N, D, T = Y.shape
    n_samples = 0
    n_events = 0
    
    # Look at a single example first
    n, d = 0, 0
    print(f"\nExample for patient {n}, disease {d}:")
    print(f"Event time: {event_times[n,d]}")
    print(f"Y sequence: {Y[n,d,:]}")
    print(f"Has any event: {np.any(Y[n,d,:] == 1)}")
    
    # Modified evaluation
    for n in range(N):
        for d in range(D):
            event_t = event_times[n,d]
            for t in range(event_t):  # Only look until event time
                n_samples += 1
                # Did event occur after time t?
                if np.any(Y[n,d,t:event_t] == 1):
                    n_events += 1
                    true_outcomes.append(1)
                else:
                    true_outcomes.append(0)
                # Compute remaining risk
                remaining_risks.append(1 - np.prod(1 - pi_pred[n,d,t:event_t]))
    
    print(f"\nTotal samples evaluated: {n_samples}")
    print(f"Number of positive events: {n_events}")
    
    if n_events > 0:
        auc = roc_auc_score(true_outcomes, remaining_risks)
        return auc
    else:
        print("No events found!")
        return None

# %%
evaluate_survival_predictions(model, Y, E)

# %%
def compare_clustering_evolution(model, checkpoint):
    # Get initial cluster assignments from spectral clustering
    initial_clusters = checkpoint['clusters']
    
    # Get final learned parameters
    final_psi = model.psi.detach().numpy()
    final_phi = model.phi.detach().numpy()
    prevalence_logit = model.logit_prev_t.detach().numpy()
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(final_phi)
    for k in range(final_phi.shape[0]):
        for d in range(final_phi.shape[1]):
            phi_centered[k, d, :] = final_phi[k, d, :] - prevalence_logit[d, :]
    
    # Compare initial vs final clustering
    plt.figure(figsize=(15, 5))
    
    # 1. Plot initial psi values
    plt.subplot(131)
    initial_psi = np.zeros((model.K, model.D))
    for k in range(model.K):
        cluster_mask = (initial_clusters == k)
        initial_psi[k, cluster_mask] = 1.0
        initial_psi[k, ~cluster_mask] = -3.0
    plt.imshow(initial_psi, aspect='auto', cmap='RdBu_r')
    plt.title('Initial Psi (from spectral clustering)')
    plt.colorbar()
    
    # 2. Plot final psi values
    plt.subplot(132)
    plt.imshow(final_psi, aspect='auto', cmap='RdBu_r')
    plt.title('Final Learned Psi')
    plt.colorbar()
    
    # 3. Plot average phi_centered
    plt.subplot(133)
    mean_phi_centered = phi_centered.mean(axis=2)  # Average over time
    plt.imshow(mean_phi_centered, aspect='auto', cmap='RdBu_r')
    plt.title('Time-averaged Centered Phi')
    plt.colorbar()
    
    plt.tight_layout()
    plt.show()
    
    # Print some statistics
    print("\nChanges in cluster assignments:")
    for k in range(model.K):
        initial_mask = (initial_clusters == k)
        final_strong = (final_psi[k] > 0)
        
        print(f"\nCluster {k}:")
        print(f"Initially assigned: {initial_mask.sum()} diseases")
        print(f"Final strong membership: {final_strong.sum()} diseases")
        print(f"Overlap: {(initial_mask & final_strong).sum()} diseases")
        
    return initial_psi, final_psi, mean_phi_centered

compare_clustering_evolution(model,checkpoint)

# %%
from sklearn.metrics import roc_auc_score

def evaluate_survival_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred = model.forward()[0].cpu().numpy()
    
    N, D, T = Y.shape
    results = []
    
    # Evaluate every 5 years
    evaluation_times = range(0, T, 5)  # Every 5 years
    print(f"Evaluating at times: {list(evaluation_times)}")
    
    for t in evaluation_times:
        print(f"\nEvaluating from time {t} (age {t+30}):")
        
        for d in range(D):
            remaining_risks = []
            true_outcomes = []
            
            for n in range(N):
                # Check if still at risk (no events before time t)
                if np.sum(Y[n,d,:t]) == 0:
                    # Calculate remaining lifetime risk from t onwards
                    future_pi = pi_pred[n,d,t:]
                    remaining_risk = 1 - np.prod(1 - future_pi)
                    
                    # Check if event occurs in remaining lifetime
                    future_event = np.any(Y[n,d,t:] == 1)
                    
                    remaining_risks.append(remaining_risk)
                    true_outcomes.append(future_event)
            
            if len(true_outcomes) > 0:
                n_events = sum(true_outcomes)
                n_total = len(true_outcomes)
                
                if n_events > 0 and n_events < n_total:
                    auc = roc_auc_score(true_outcomes, remaining_risks)
                    results.append({
                        'time': t,
                        'age': t + 30,
                        'disease': d,
                        'auc': auc,
                        'n_at_risk': n_total,
                        'n_events': n_events,
                        'event_rate': n_events/n_total
                    })
                    print(f"Disease {d}: AUC={auc:.3f}, Events={n_events}/{n_total}")
    
    return pd.DataFrame(results)

# %%
evaluate_survival_predictions(model,Y,E)

# %%
import seaborn as sns
def plot_survival_results(results_df):
    plt.figure(figsize=(15, 10))
    
    # 1. AUC distribution over time
    plt.subplot(221)
    sns.boxplot(data=results_df, x='age', y='auc')
    plt.title('AUC Distribution by Age')
    plt.xticks(rotation=45)
    plt.axhline(y=0.5, color='r', linestyle='--', alpha=0.5)
    
    # 2. Mean AUC by disease ID
    plt.subplot(222)
    disease_aucs = (results_df.groupby('disease')['auc']
                   .mean()
                   .sort_values(ascending=False))
    sns.barplot(x=range(len(disease_aucs)), y=disease_aucs.values)
    plt.title('Diseases Ranked by Mean AUC')
    plt.xlabel('Disease Rank')
    plt.ylabel('Mean AUC')
    
    # 3. Event rates over time
    plt.subplot(223)
    sns.boxplot(data=results_df, x='age', y='event_rate')
    plt.title('Event Rate Distribution by Age')
    plt.xticks(rotation=45)
    
    # 4. Population at risk over time
    plt.subplot(224)
    sns.boxplot(data=results_df, x='age', y='n_at_risk')
    plt.title('Population at Risk by Age')
    plt.xticks(rotation=45)
    
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print("\nOverall AUC Summary:")
    print(results_df.groupby('age')['auc'].describe())
    
    return results_df



results = evaluate_survival_predictions(model, Y, E)
# Use with previous results
plot_survival_results(results)

# %%
print("Real data summary:")
print(f"Event rates per disease:")
Y_real = Y # Your real data tensor
print(Y_real.sum(axis=(0,2))/Y_real.shape[0])  # Per person rate

print("\nTime distribution of events:")
print(Y_real.sum(axis=(0,1))/Y_real.shape[0])

# %%
# Plot smoothed prevalence for each disease
epsilon=1e-8
logit_prev_t = torch.log(
            (model.prevalence_t + epsilon) / (1 - model.prevalence_t + epsilon)
        )  # D 
for d in range(Y.shape[1]):
    plt.plot(logit_prev_t[d,:], alpha=0.5, label=f'Disease {d}' if d < 5 else '')

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")

# %%
def analyze_phi_evolution(model):
    """Analyze how phi changes while psi remains stable"""
    # 1. Look at deviation from mean function
    phi_deviation = model.phi -(model.logit_prev_t + model.psi.unsqueeze(-1))
    
    # 2. Check temporal patterns
    phi_temporal = torch.mean(phi_deviation, dim=1)  # Average across diseases
    
    # 3. Compare cluster-specific patterns
    for k in range(model.K):
        cluster_mask = (model.clusters == k)
        phi_k = model.phi[k, cluster_mask, :]
        
        print(f"\nCluster {k} phi statistics:")
        print(f"Mean deviation: {phi_deviation[k].mean():.3f}")
        print(f"Temporal variance: {phi_temporal[k].var():.3f}")

# %%
analyze_phi_evolution(model)

# %%
initial_phi

# %%
model.phi

# %%
def visualize_phi_changes(initial_phi, final_phi):
    """Visualize changes in phi from initial to final values"""
    
    plt.figure(figsize=(15, 5))
    K,D,T=final_phi.shape
    # Plot initial phi
    plt.subplot(131)
    for k in range(K):
        for d in range(min(3, D)):  # Plot first 3 diseases for clarity
            plt.plot(initial_phi[k, d, :].cpu().numpy(), 
                     label=f'Cluster {k}, Disease {d}')
    plt.title('Initial φ')
    plt.xlabel('Time')
    plt.ylabel('φ Value')
    plt.legend()
    
    # Plot final phi
    plt.subplot(132)
    for k in range(K):
        for d in range(min(3, D)):
            plt.plot(final_phi[k, d, :].cpu().numpy(), 
                     label=f'Cluster {k}, Disease {d}')
    plt.title('Final φ')
    plt.xlabel('Time')
    plt.ylabel('φ Value')
    plt.legend()
    
    # Plot change in phi
    plt.subplot(133)
    phi_diff = final_phi - initial_phi
    for k in range(K):
        for d in range(min(3, D)):
            plt.plot(phi_diff[k, d, :].cpu().numpy(), 
                     label=f'Cluster {k}, Disease {d}')
    plt.title('Change in φ')
    plt.xlabel('Time')
    plt.ylabel('Δφ')
    plt.legend()
    
    plt.suptitle('φ Evolution')
    plt.tight_layout()
    plt.show()

# %%
final_phi = model.phi.detach()
final_phi.shape

# %%
# Visualize changes
visualize_phi_changes(initial_phi, final_phi)

# %%
final_lambda = model.lambda_.detach()
final_lambda.shape

# %%
def visualize_lambda_changes(initial_lambda, final_lambda):
    """Visualize changes in phi from initial to final values"""
    
    plt.figure(figsize=(15, 5))
    N,K,T=final_lambda.shape
    # Plot initial phi
    plt.subplot(131)
    for k in range(K):
        for n in range(min(3, N)):  # Plot first 3 diseases for clarity
            plt.plot(initial_lambda[n, k, :].cpu().numpy(), 
                     label=f'Cluster {k}, Person {n}')
    plt.title('Initial lambda')
    plt.xlabel('Time')
    plt.ylabel('lambda Value')
    plt.legend()
    
    # Plot final phi
    plt.subplot(132)
    for k in range(K):
        for n in range(min(3, N)):  # Plot first 3 diseases for clarity
            plt.plot(final_lambda[n, k, :].cpu().numpy(), 
                     label=f'Cluster {k}, Person {n}')
    plt.title('Final lambda')
    plt.xlabel('Time')
    plt.ylabel('lambda Value')
    plt.legend()
    
    # Plot change in phi
    plt.subplot(133)
    phi_diff = final_lambda- initial_lambda
    for k in range(K):
        for n in range(min(3, N)):
            plt.plot(phi_diff[n, k, :].cpu().numpy(), 
                     label=f'Cluster {k}, Person {n}')
    plt.title('Change in lambda')
    plt.xlabel('Time')
    plt.ylabel('ΔLambda')
    plt.legend()
    
    plt.suptitle('Lambda Evolution')
    plt.tight_layout()
    plt.show()

visualize_lambda_changes(initial_lambda,final_lambda)

# %%
# Instead of model.fit(), use:
# Initialize model
model_efficient = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(N, D, T, K, P, G, Y, prevalence_t, disease_names_list)

# Store initial psi values
initial_psi = model.psi.detach().clone()
initial_phi=model.phi.detach().clone()
initial_lambda=model.lambda_.detach().clone()

history = model_efficient.fit_efficient(
    E_tensor,
    learning_rate=1e-4,
    param_change_threshold=1e-3,  # Adjust based on your needs
    consecutive_threshold=3  # Stop after 3 consecutive small changes
)
