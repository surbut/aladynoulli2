# %%
import sys
import os

# Get the parent directory of current directory
parent_dir = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(parent_dir)

# Now you can import from pyScripts
from pyScripts.cluster_g_logit_init_acceptpsi import *

# %load_ext autoreload
# %autoreload 2
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

# %%
# Generate and plot
np.random.seed(42)
data = generate_clustered_survival_data(N=10000, D=20, T=50, K=5, P=5)
plot_synthetic_components(data)

# %%
Y_tensor = torch.tensor(data['Y'], dtype=torch.float32)
Y_avg = torch.mean(Y_tensor, dim=2)
Y_corr = torch.corrcoef(Y_avg.T)
Y_avg
# Out:
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0200, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0200,  ..., 0.0200, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0200, 0.0000, 0.0000],
#         ...,
#         [0.0000, 0.0000, 0.0200,  ..., 0.0200, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0200, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0200,  ..., 0.0200, 0.0000, 0.0000]])

# %%
K=5
similarity = (Y_corr + 1) / 2
spectral = SpectralClustering(
            n_clusters=K,  # One less for background state
            assign_labels='kmeans',
            affinity='precomputed',
            n_init=10,
            random_state=42
        ).fit(similarity.numpy())
        
clusters = spectral.labels_

# %%
print("Number of events per disease:")
print(data['Y'].sum(axis=(0,2)))  # Sum over individuals and time
print(data['Y'].mean(axis=(0,2)))  # Sum over individuals and time

print("\nNumber of events per time point:")
print(data['Y'].sum(axis=(0,1)))  # Sum over individuals and diseases
# Out:
# Number of events per disease:
# [1.000e+00 1.300e+02 1.355e+03 3.637e+03 2.800e+01 7.646e+03 4.710e+02
#  1.000e+04 3.637e+03 6.663e+03 8.242e+03 2.370e+02 9.986e+03 1.247e+03
#  8.220e+02 9.059e+03 9.957e+03 9.801e+03 6.000e+00 2.830e+02]
# [2.0000e-06 2.6000e-04 2.7100e-03 7.2740e-03 5.6000e-05 1.5292e-02
#  9.4200e-04 2.0000e-02 7.2740e-03 1.3326e-02 1.6484e-02 4.7400e-04
#  1.9972e-02 2.4940e-03 1.6440e-03 1.8118e-02 1.9914e-02 1.9602e-02
#  1.2000e-05 5.6600e-04]
#
# Number of events per time point:
# [  12.   22.   27.   57.  103.  145.  236.  303.  413.  486.  540.  611.
#   623.  695.  701.  736.  821.  922. 1043. 1090. 1178. 1237. 1245. 1252.
#  1235. 1282. 1378. 1541. 1748. 2033. 2208. 2551. 2865. 2939. 3117. 3191.
#  3224. 3270. 3361. 3302. 3448. 3398. 3492. 3229. 3095. 3024. 2774. 2574.
#  2284. 2147.]

# %%
# First generate synthetic data
np.random.seed(42)

# Convert data to tensors for the model
Y_tensor = torch.tensor(data['Y'], dtype=torch.float32)
G_tensor = torch.tensor(data['G'], dtype=torch.float32)
E_tensor = torch.tensor(data['event_times'], dtype=torch.float32)
true_psi = torch.tensor(data['psi'], dtype=torch.float32)

# %%
true_psi
# Out:
# tensor([[ 1.,  1.,  1.,  1., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3.,  1.,  1.,  1.,  1., -3., -3., -3., -3., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3.,  1.,  1.,  1.,  1., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,  1.,  1.,
#           1.,  1., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,
#          -3., -3.,  1.,  1.,  1.,  1.]])

# %%
# Calculate prevalence_t from synthetic data
prevalence_t = compute_smoothed_prevalence(Y_tensor)  # Average over individuals

# Initialize model with synthetic data
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=data['Y'].shape[0], 
    D=data['Y'].shape[1], 
    T=data['Y'].shape[2], 
    K=data['phi'].shape[0],  # number of clusters
    P=data['G'].shape[1],    # number of genetic features
    G=G_tensor,
    Y=Y_tensor,              # Added Y_tensor
    prevalence_t=prevalence_t
)

# Initialize with true psi
model.initialize_params(true_psi=true_psi)
model.clusters = data['clusters'] 

model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli2/pyScripts/cluster_g_logit_init_acceptpsi.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/cluster_g_logit_init_acceptpsi.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli2/pyScripts/cluster_g_logit_init_acceptpsi.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 45214952.00
# Phi kernel condition number: 104912536.00
#
# Cluster Sizes:
# Cluster 0: 3 diseases
# Cluster 1: 8 diseases
# Cluster 2: 4 diseases
# Cluster 3: 3 diseases
# Cluster 4: 2 diseases
# Initialization complete!
#
# Using true psi from simulation
# Initialization complete!

# %%
K=5
# Store initial psi values
initial_psi = model.psi.detach().clone()

# Fit the model
history = model.fit(E_tensor, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
# /Users/sarahurbut/aladynoulli2/pyScripts/cluster_g_logit_init_acceptpsi.py:209: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 289.4095
# Psi gradient stats:
# Mean: -1.1189e-02
# Std:  8.0605e-02
# Max:  2.2239e-01
# Min:  -1.9923e-01
# Epoch 0, Loss: 289.4095, Gradients - Lambda: 5.063e-01, Phi: 1.930e+02, Gamma: 5.742e-02, Psi: 2.224e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 1
# Loss: 254.6492
# Psi gradient stats:
# Mean: -1.1212e-02
# Std:  8.0487e-02
# Max:  2.2255e-01
# Min:  -1.9913e-01
# Epoch 1, Loss: 254.6492, Gradients - Lambda: 4.696e-01, Phi: 1.853e+02, Gamma: 5.717e-02, Psi: 2.226e-01
#
# Estimated total training time: 109.1 minutes
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 2
# Loss: 224.9493
# Psi gradient stats:
# Mean: -1.1227e-02
# Std:  8.0362e-02
# Max:  2.2268e-01
# Min:  -1.9848e-01
# Epoch 2, Loss: 224.9493, Gradients - Lambda: 4.413e-01, Phi: 1.779e+02, Gamma: 5.690e-02, Psi: 2.227e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 3
# Loss: 199.8485
# Psi gradient stats:
# Mean: -1.1227e-02
# Std:  8.0228e-02
# Max:  2.2268e-01
# Min:  -1.9755e-01
# Epoch 3, Loss: 199.8485, Gradients - Lambda: 4.265e-01, Phi: 1.709e+02, Gamma: 5.663e-02, Psi: 2.227e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 4
# Loss: 178.8027
# Psi gradient stats:
# Mean: -1.1211e-02
# Std:  8.0100e-02
# Max:  2.2268e-01
# Min:  -1.9648e-01
# Epoch 4, Loss: 178.8027, Gradients - Lambda: 4.115e-01, Phi: 1.642e+02, Gamma: 5.635e-02, Psi: 2.227e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 5
# Loss: 161.2952
# Psi gradient stats:
# Mean: -1.1174e-02
# Std:  7.9973e-02
# Max:  2.2260e-01
# Min:  -1.9542e-01
# Epoch 5, Loss: 161.2952, Gradients - Lambda: 3.963e-01, Phi: 1.579e+02, Gamma: 5.607e-02, Psi: 2.226e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 6
# Loss: 146.8478
# Psi gradient stats:
# Mean: -1.1127e-02
# Std:  7.9860e-02
# Max:  2.2255e-01
# Min:  -1.9453e-01
# Epoch 6, Loss: 146.8478, Gradients - Lambda: 3.809e-01, Phi: 1.515e+02, Gamma: 5.581e-02, Psi: 2.225e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 7
# Loss: 135.0214
# Psi gradient stats:
# Mean: -1.1077e-02
# Std:  7.9747e-02
# Max:  2.2250e-01
# Min:  -1.9382e-01
# Epoch 7, Loss: 135.0214, Gradients - Lambda: 3.653e-01, Phi: 1.454e+02, Gamma: 5.556e-02, Psi: 2.225e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 8
# Loss: 125.4170
# Psi gradient stats:
# Mean: -1.1026e-02
# Std:  7.9643e-02
# Max:  2.2240e-01
# Min:  -1.9394e-01
# Epoch 8, Loss: 125.4170, Gradients - Lambda: 3.497e-01, Phi: 1.394e+02, Gamma: 5.529e-02, Psi: 2.224e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 9
# Loss: 117.6758
# Psi gradient stats:
# Mean: -1.0983e-02
# Std:  7.9536e-02
# Max:  2.2223e-01
# Min:  -1.9446e-01
# Epoch 9, Loss: 117.6758, Gradients - Lambda: 3.341e-01, Phi: 1.336e+02, Gamma: 5.504e-02, Psi: 2.222e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 10
# Loss: 111.4808
# Psi gradient stats:
# Mean: -1.0940e-02
# Std:  7.9429e-02
# Max:  2.2199e-01
# Min:  -1.9495e-01
# Epoch 10, Loss: 111.4808, Gradients - Lambda: 3.185e-01, Phi: 1.280e+02, Gamma: 5.479e-02, Psi: 2.220e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 11
# Loss: 106.5565
# Psi gradient stats:
# Mean: -1.0900e-02
# Std:  7.9318e-02
# Max:  2.2168e-01
# Min:  -1.9537e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 12
# Loss: 102.6703
# Psi gradient stats:
# Mean: -1.0860e-02
# Std:  7.9205e-02
# Max:  2.2131e-01
# Min:  -1.9569e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 13
# Loss: 99.6173
# Psi gradient stats:
# Mean: -1.0820e-02
# Std:  7.9082e-02
# Max:  2.2086e-01
# Min:  -1.9593e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 14
# Loss: 97.2298
# Psi gradient stats:
# Mean: -1.0785e-02
# Std:  7.8955e-02
# Max:  2.2040e-01
# Min:  -1.9605e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 15
# Loss: 95.3652
# Psi gradient stats:
# Mean: -1.0751e-02
# Std:  7.8819e-02
# Max:  2.1986e-01
# Min:  -1.9609e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 16
# Loss: 93.9052
# Psi gradient stats:
# Mean: -1.0722e-02
# Std:  7.8678e-02
# Max:  2.1930e-01
# Min:  -1.9609e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 17
# Loss: 92.7502
# Psi gradient stats:
# Mean: -1.0695e-02
# Std:  7.8525e-02
# Max:  2.1867e-01
# Min:  -1.9604e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 18
# Loss: 91.8202
# Psi gradient stats:
# Mean: -1.0672e-02
# Std:  7.8369e-02
# Max:  2.1801e-01
# Min:  -1.9595e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 19
# Loss: 91.0529
# Psi gradient stats:
# Mean: -1.0651e-02
# Std:  7.8210e-02
# Max:  2.1731e-01
# Min:  -1.9619e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 20
# Loss: 90.3999
# Psi gradient stats:
# Mean: -1.0632e-02
# Std:  7.8047e-02
# Max:  2.1660e-01
# Min:  -1.9690e-01
# Epoch 20, Loss: 90.3999, Gradients - Lambda: 1.809e-01, Phi: 7.841e+01, Gamma: 5.219e-02, Psi: 2.166e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 21
# Loss: 89.8244
# Psi gradient stats:
# Mean: -1.0616e-02
# Std:  7.7884e-02
# Max:  2.1587e-01
# Min:  -1.9766e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 22
# Loss: 89.3009
# Psi gradient stats:
# Mean: -1.0601e-02
# Std:  7.7723e-02
# Max:  2.1511e-01
# Min:  -1.9845e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 23
# Loss: 88.8095
# Psi gradient stats:
# Mean: -1.0588e-02
# Std:  7.7565e-02
# Max:  2.1433e-01
# Min:  -1.9925e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 24
# Loss: 88.3366
# Psi gradient stats:
# Mean: -1.0573e-02
# Std:  7.7412e-02
# Max:  2.1352e-01
# Min:  -2.0005e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 25
# Loss: 87.8754
# Psi gradient stats:
# Mean: -1.0554e-02
# Std:  7.7261e-02
# Max:  2.1272e-01
# Min:  -2.0084e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 26
# Loss: 87.4200
# Psi gradient stats:
# Mean: -1.0534e-02
# Std:  7.7117e-02
# Max:  2.1189e-01
# Min:  -2.0160e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 27
# Loss: 86.9699
# Psi gradient stats:
# Mean: -1.0509e-02
# Std:  7.6977e-02
# Max:  2.1104e-01
# Min:  -2.0232e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 28
# Loss: 86.5261
# Psi gradient stats:
# Mean: -1.0478e-02
# Std:  7.6845e-02
# Max:  2.1019e-01
# Min:  -2.0304e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 29
# Loss: 86.0907
# Psi gradient stats:
# Mean: -1.0445e-02
# Std:  7.6721e-02
# Max:  2.0934e-01
# Min:  -2.0373e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 30
# Loss: 85.6671
# Psi gradient stats:
# Mean: -1.0406e-02
# Std:  7.6607e-02
# Max:  2.0849e-01
# Min:  -2.0437e-01
# Epoch 30, Loss: 85.6671, Gradients - Lambda: 9.063e-02, Phi: 3.429e+01, Gamma: 4.959e-02, Psi: 2.085e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 31
# Loss: 85.2566
# Psi gradient stats:
# Mean: -1.0362e-02
# Std:  7.6501e-02
# Max:  2.0765e-01
# Min:  -2.0501e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 32
# Loss: 84.8635
# Psi gradient stats:
# Mean: -1.0311e-02
# Std:  7.6404e-02
# Max:  2.0684e-01
# Min:  -2.0558e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 33
# Loss: 84.4892
# Psi gradient stats:
# Mean: -1.0253e-02
# Std:  7.6315e-02
# Max:  2.0606e-01
# Min:  -2.0613e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 34
# Loss: 84.1354
# Psi gradient stats:
# Mean: -1.0187e-02
# Std:  7.6235e-02
# Max:  2.0529e-01
# Min:  -2.0661e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 35
# Loss: 83.8027
# Psi gradient stats:
# Mean: -1.0115e-02
# Std:  7.6160e-02
# Max:  2.0456e-01
# Min:  -2.0703e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 36
# Loss: 83.4923
# Psi gradient stats:
# Mean: -1.0038e-02
# Std:  7.6093e-02
# Max:  2.0389e-01
# Min:  -2.0738e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 37
# Loss: 83.2035
# Psi gradient stats:
# Mean: -9.9593e-03
# Std:  7.6030e-02
# Max:  2.0325e-01
# Min:  -2.0766e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 38
# Loss: 82.9363
# Psi gradient stats:
# Mean: -9.8798e-03
# Std:  7.5973e-02
# Max:  2.0265e-01
# Min:  -2.0787e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 39
# Loss: 82.6895
# Psi gradient stats:
# Mean: -9.7999e-03
# Std:  7.5921e-02
# Max:  2.0212e-01
# Min:  -2.0800e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 40
# Loss: 82.4623
# Psi gradient stats:
# Mean: -9.7237e-03
# Std:  7.5873e-02
# Max:  2.0162e-01
# Min:  -2.0808e-01
# Epoch 40, Loss: 82.4623, Gradients - Lambda: 5.951e-02, Phi: 2.438e+01, Gamma: 4.723e-02, Psi: 2.081e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 41
# Loss: 82.2529
# Psi gradient stats:
# Mean: -9.6490e-03
# Std:  7.5826e-02
# Max:  2.0119e-01
# Min:  -2.0810e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 42
# Loss: 82.0602
# Psi gradient stats:
# Mean: -9.5758e-03
# Std:  7.5781e-02
# Max:  2.0080e-01
# Min:  -2.0808e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 43
# Loss: 81.8821
# Psi gradient stats:
# Mean: -9.5042e-03
# Std:  7.5737e-02
# Max:  2.0045e-01
# Min:  -2.0800e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 44
# Loss: 81.7172
# Psi gradient stats:
# Mean: -9.4343e-03
# Std:  7.5696e-02
# Max:  2.0017e-01
# Min:  -2.0792e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 45
# Loss: 81.5641
# Psi gradient stats:
# Mean: -9.3648e-03
# Std:  7.5658e-02
# Max:  1.9994e-01
# Min:  -2.0780e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 46
# Loss: 81.4211
# Psi gradient stats:
# Mean: -9.2976e-03
# Std:  7.5622e-02
# Max:  1.9974e-01
# Min:  -2.0770e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 47
# Loss: 81.2873
# Psi gradient stats:
# Mean: -9.2334e-03
# Std:  7.5588e-02
# Max:  1.9957e-01
# Min:  -2.0757e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 48
# Loss: 81.1619
# Psi gradient stats:
# Mean: -9.1707e-03
# Std:  7.5558e-02
# Max:  1.9946e-01
# Min:  -2.0744e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 49
# Loss: 81.0433
# Psi gradient stats:
# Mean: -9.1112e-03
# Std:  7.5529e-02
# Max:  1.9937e-01
# Min:  -2.0733e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 50
# Loss: 80.9309
# Psi gradient stats:
# Mean: -9.0570e-03
# Std:  7.5504e-02
# Max:  1.9931e-01
# Min:  -2.0722e-01
# Epoch 50, Loss: 80.9309, Gradients - Lambda: 5.049e-02, Phi: 1.634e+01, Gamma: 4.473e-02, Psi: 2.072e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 51
# Loss: 80.8239
# Psi gradient stats:
# Mean: -9.0056e-03
# Std:  7.5479e-02
# Max:  1.9927e-01
# Min:  -2.0711e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 52
# Loss: 80.7217
# Psi gradient stats:
# Mean: -8.9586e-03
# Std:  7.5457e-02
# Max:  1.9925e-01
# Min:  -2.0700e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 53
# Loss: 80.6237
# Psi gradient stats:
# Mean: -8.9175e-03
# Std:  7.5437e-02
# Max:  1.9924e-01
# Min:  -2.0688e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 54
# Loss: 80.5296
# Psi gradient stats:
# Mean: -8.8817e-03
# Std:  7.5418e-02
# Max:  1.9926e-01
# Min:  -2.0677e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 55
# Loss: 80.4393
# Psi gradient stats:
# Mean: -8.8522e-03
# Std:  7.5400e-02
# Max:  1.9928e-01
# Min:  -2.0665e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 56
# Loss: 80.3522
# Psi gradient stats:
# Mean: -8.8274e-03
# Std:  7.5384e-02
# Max:  1.9931e-01
# Min:  -2.0654e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 57
# Loss: 80.2681
# Psi gradient stats:
# Mean: -8.8073e-03
# Std:  7.5369e-02
# Max:  1.9936e-01
# Min:  -2.0641e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 58
# Loss: 80.1866
# Psi gradient stats:
# Mean: -8.7917e-03
# Std:  7.5353e-02
# Max:  1.9941e-01
# Min:  -2.0627e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 59
# Loss: 80.1073
# Psi gradient stats:
# Mean: -8.7795e-03
# Std:  7.5337e-02
# Max:  1.9946e-01
# Min:  -2.0613e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 60
# Loss: 80.0305
# Psi gradient stats:
# Mean: -8.7708e-03
# Std:  7.5322e-02
# Max:  1.9952e-01
# Min:  -2.0600e-01
# Epoch 60, Loss: 80.0305, Gradients - Lambda: 3.138e-02, Phi: 1.101e+01, Gamma: 4.180e-02, Psi: 2.060e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 61
# Loss: 79.9555
# Psi gradient stats:
# Mean: -8.7658e-03
# Std:  7.5309e-02
# Max:  1.9958e-01
# Min:  -2.0587e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 62
# Loss: 79.8824
# Psi gradient stats:
# Mean: -8.7623e-03
# Std:  7.5294e-02
# Max:  1.9964e-01
# Min:  -2.0573e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 63
# Loss: 79.8114
# Psi gradient stats:
# Mean: -8.7617e-03
# Std:  7.5283e-02
# Max:  1.9971e-01
# Min:  -2.0559e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 64
# Loss: 79.7421
# Psi gradient stats:
# Mean: -8.7624e-03
# Std:  7.5272e-02
# Max:  1.9976e-01
# Min:  -2.0546e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 65
# Loss: 79.6746
# Psi gradient stats:
# Mean: -8.7657e-03
# Std:  7.5262e-02
# Max:  1.9982e-01
# Min:  -2.0534e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 66
# Loss: 79.6088
# Psi gradient stats:
# Mean: -8.7703e-03
# Std:  7.5254e-02
# Max:  1.9987e-01
# Min:  -2.0522e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 67
# Loss: 79.5444
# Psi gradient stats:
# Mean: -8.7758e-03
# Std:  7.5245e-02
# Max:  1.9992e-01
# Min:  -2.0511e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 68
# Loss: 79.4820
# Psi gradient stats:
# Mean: -8.7818e-03
# Std:  7.5237e-02
# Max:  1.9997e-01
# Min:  -2.0501e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 69
# Loss: 79.4210
# Psi gradient stats:
# Mean: -8.7875e-03
# Std:  7.5230e-02
# Max:  2.0000e-01
# Min:  -2.0492e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 70
# Loss: 79.3612
# Psi gradient stats:
# Mean: -8.7934e-03
# Std:  7.5224e-02
# Max:  2.0003e-01
# Min:  -2.0483e-01
# Epoch 70, Loss: 79.3612, Gradients - Lambda: 2.459e-02, Phi: 7.932e+00, Gamma: 3.897e-02, Psi: 2.048e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 71
# Loss: 79.3031
# Psi gradient stats:
# Mean: -8.8006e-03
# Std:  7.5218e-02
# Max:  2.0006e-01
# Min:  -2.0476e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 72
# Loss: 79.2465
# Psi gradient stats:
# Mean: -8.8078e-03
# Std:  7.5211e-02
# Max:  2.0008e-01
# Min:  -2.0470e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 73
# Loss: 79.1910
# Psi gradient stats:
# Mean: -8.8154e-03
# Std:  7.5203e-02
# Max:  2.0011e-01
# Min:  -2.0464e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 74
# Loss: 79.1369
# Psi gradient stats:
# Mean: -8.8231e-03
# Std:  7.5195e-02
# Max:  2.0014e-01
# Min:  -2.0459e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 75
# Loss: 79.0838
# Psi gradient stats:
# Mean: -8.8328e-03
# Std:  7.5186e-02
# Max:  2.0015e-01
# Min:  -2.0456e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 76
# Loss: 79.0321
# Psi gradient stats:
# Mean: -8.8406e-03
# Std:  7.5176e-02
# Max:  2.0015e-01
# Min:  -2.0452e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 77
# Loss: 78.9813
# Psi gradient stats:
# Mean: -8.8504e-03
# Std:  7.5165e-02
# Max:  2.0017e-01
# Min:  -2.0448e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 78
# Loss: 78.9315
# Psi gradient stats:
# Mean: -8.8612e-03
# Std:  7.5154e-02
# Max:  2.0018e-01
# Min:  -2.0445e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 79
# Loss: 78.8827
# Psi gradient stats:
# Mean: -8.8726e-03
# Std:  7.5142e-02
# Max:  2.0019e-01
# Min:  -2.0442e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 80
# Loss: 78.8349
# Psi gradient stats:
# Mean: -8.8850e-03
# Std:  7.5131e-02
# Max:  2.0020e-01
# Min:  -2.0439e-01
# Epoch 80, Loss: 78.8349, Gradients - Lambda: 1.973e-02, Phi: 6.843e+00, Gamma: 3.647e-02, Psi: 2.044e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 81
# Loss: 78.7876
# Psi gradient stats:
# Mean: -8.8982e-03
# Std:  7.5118e-02
# Max:  2.0021e-01
# Min:  -2.0436e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 82
# Loss: 78.7412
# Psi gradient stats:
# Mean: -8.9107e-03
# Std:  7.5105e-02
# Max:  2.0023e-01
# Min:  -2.0433e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 83
# Loss: 78.6955
# Psi gradient stats:
# Mean: -8.9233e-03
# Std:  7.5092e-02
# Max:  2.0024e-01
# Min:  -2.0431e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 84
# Loss: 78.6505
# Psi gradient stats:
# Mean: -8.9345e-03
# Std:  7.5077e-02
# Max:  2.0025e-01
# Min:  -2.0428e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 85
# Loss: 78.6061
# Psi gradient stats:
# Mean: -8.9450e-03
# Std:  7.5062e-02
# Max:  2.0026e-01
# Min:  -2.0426e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 86
# Loss: 78.5625
# Psi gradient stats:
# Mean: -8.9555e-03
# Std:  7.5046e-02
# Max:  2.0026e-01
# Min:  -2.0424e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 87
# Loss: 78.5195
# Psi gradient stats:
# Mean: -8.9645e-03
# Std:  7.5030e-02
# Max:  2.0026e-01
# Min:  -2.0423e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 88
# Loss: 78.4773
# Psi gradient stats:
# Mean: -8.9734e-03
# Std:  7.5013e-02
# Max:  2.0025e-01
# Min:  -2.0421e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 89
# Loss: 78.4355
# Psi gradient stats:
# Mean: -8.9818e-03
# Std:  7.4997e-02
# Max:  2.0025e-01
# Min:  -2.0420e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 90
# Loss: 78.3944
# Psi gradient stats:
# Mean: -8.9879e-03
# Std:  7.4980e-02
# Max:  2.0026e-01
# Min:  -2.0421e-01
# Epoch 90, Loss: 78.3944, Gradients - Lambda: 1.656e-02, Phi: 6.675e+00, Gamma: 3.401e-02, Psi: 2.042e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 91
# Loss: 78.3539
# Psi gradient stats:
# Mean: -8.9939e-03
# Std:  7.4962e-02
# Max:  2.0026e-01
# Min:  -2.0419e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 92
# Loss: 78.3140
# Psi gradient stats:
# Mean: -8.9992e-03
# Std:  7.4943e-02
# Max:  2.0026e-01
# Min:  -2.0419e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 93
# Loss: 78.2745
# Psi gradient stats:
# Mean: -9.0033e-03
# Std:  7.4926e-02
# Max:  2.0026e-01
# Min:  -2.0419e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 94
# Loss: 78.2356
# Psi gradient stats:
# Mean: -9.0065e-03
# Std:  7.4908e-02
# Max:  2.0027e-01
# Min:  -2.0417e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 95
# Loss: 78.1969
# Psi gradient stats:
# Mean: -9.0092e-03
# Std:  7.4889e-02
# Max:  2.0026e-01
# Min:  -2.0416e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 96
# Loss: 78.1590
# Psi gradient stats:
# Mean: -9.0119e-03
# Std:  7.4870e-02
# Max:  2.0025e-01
# Min:  -2.0414e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 97
# Loss: 78.1217
# Psi gradient stats:
# Mean: -9.0136e-03
# Std:  7.4850e-02
# Max:  2.0025e-01
# Min:  -2.0412e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 98
# Loss: 78.0845
# Psi gradient stats:
# Mean: -9.0145e-03
# Std:  7.4832e-02
# Max:  2.0024e-01
# Min:  -2.0410e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 99
# Loss: 78.0479
# Psi gradient stats:
# Mean: -9.0146e-03
# Std:  7.4812e-02
# Max:  2.0023e-01
# Min:  -2.0407e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 100
# Loss: 78.0116
# Psi gradient stats:
# Mean: -9.0137e-03
# Std:  7.4791e-02
# Max:  2.0021e-01
# Min:  -2.0405e-01
# Epoch 100, Loss: 78.0116, Gradients - Lambda: 1.389e-02, Phi: 5.362e+00, Gamma: 3.163e-02, Psi: 2.041e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 101
# Loss: 77.9758
# Psi gradient stats:
# Mean: -9.0138e-03
# Std:  7.4771e-02
# Max:  2.0019e-01
# Min:  -2.0403e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 102
# Loss: 77.9403
# Psi gradient stats:
# Mean: -9.0146e-03
# Std:  7.4751e-02
# Max:  2.0016e-01
# Min:  -2.0400e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 103
# Loss: 77.9053
# Psi gradient stats:
# Mean: -9.0139e-03
# Std:  7.4733e-02
# Max:  2.0014e-01
# Min:  -2.0398e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 104
# Loss: 77.8708
# Psi gradient stats:
# Mean: -9.0133e-03
# Std:  7.4715e-02
# Max:  2.0012e-01
# Min:  -2.0395e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 105
# Loss: 77.8364
# Psi gradient stats:
# Mean: -9.0136e-03
# Std:  7.4695e-02
# Max:  2.0008e-01
# Min:  -2.0391e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 106
# Loss: 77.8025
# Psi gradient stats:
# Mean: -9.0136e-03
# Std:  7.4677e-02
# Max:  2.0005e-01
# Min:  -2.0389e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 107
# Loss: 77.7690
# Psi gradient stats:
# Mean: -9.0126e-03
# Std:  7.4657e-02
# Max:  2.0002e-01
# Min:  -2.0386e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 108
# Loss: 77.7358
# Psi gradient stats:
# Mean: -9.0122e-03
# Std:  7.4639e-02
# Max:  1.9999e-01
# Min:  -2.0384e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 109
# Loss: 77.7029
# Psi gradient stats:
# Mean: -9.0113e-03
# Std:  7.4620e-02
# Max:  1.9997e-01
# Min:  -2.0382e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 110
# Loss: 77.6705
# Psi gradient stats:
# Mean: -9.0111e-03
# Std:  7.4600e-02
# Max:  1.9993e-01
# Min:  -2.0379e-01
# Epoch 110, Loss: 77.6705, Gradients - Lambda: 1.264e-02, Phi: 5.088e+00, Gamma: 2.932e-02, Psi: 2.038e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 111
# Loss: 77.6382
# Psi gradient stats:
# Mean: -9.0102e-03
# Std:  7.4580e-02
# Max:  1.9989e-01
# Min:  -2.0376e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 112
# Loss: 77.6064
# Psi gradient stats:
# Mean: -9.0080e-03
# Std:  7.4561e-02
# Max:  1.9987e-01
# Min:  -2.0372e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 113
# Loss: 77.5749
# Psi gradient stats:
# Mean: -9.0074e-03
# Std:  7.4541e-02
# Max:  1.9984e-01
# Min:  -2.0369e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 114
# Loss: 77.5436
# Psi gradient stats:
# Mean: -9.0062e-03
# Std:  7.4522e-02
# Max:  1.9980e-01
# Min:  -2.0365e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 115
# Loss: 77.5127
# Psi gradient stats:
# Mean: -9.0043e-03
# Std:  7.4503e-02
# Max:  1.9977e-01
# Min:  -2.0360e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 116
# Loss: 77.4820
# Psi gradient stats:
# Mean: -9.0029e-03
# Std:  7.4484e-02
# Max:  1.9975e-01
# Min:  -2.0357e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 117
# Loss: 77.4517
# Psi gradient stats:
# Mean: -9.0011e-03
# Std:  7.4466e-02
# Max:  1.9972e-01
# Min:  -2.0354e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 118
# Loss: 77.4215
# Psi gradient stats:
# Mean: -9.0002e-03
# Std:  7.4447e-02
# Max:  1.9969e-01
# Min:  -2.0351e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 119
# Loss: 77.3916
# Psi gradient stats:
# Mean: -8.9982e-03
# Std:  7.4428e-02
# Max:  1.9964e-01
# Min:  -2.0348e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 120
# Loss: 77.3621
# Psi gradient stats:
# Mean: -8.9956e-03
# Std:  7.4409e-02
# Max:  1.9962e-01
# Min:  -2.0343e-01
# Epoch 120, Loss: 77.3621, Gradients - Lambda: 1.248e-02, Phi: 4.496e+00, Gamma: 2.709e-02, Psi: 2.034e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 121
# Loss: 77.3329
# Psi gradient stats:
# Mean: -8.9933e-03
# Std:  7.4392e-02
# Max:  1.9959e-01
# Min:  -2.0337e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 122
# Loss: 77.3039
# Psi gradient stats:
# Mean: -8.9910e-03
# Std:  7.4373e-02
# Max:  1.9956e-01
# Min:  -2.0332e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 123
# Loss: 77.2752
# Psi gradient stats:
# Mean: -8.9893e-03
# Std:  7.4356e-02
# Max:  1.9954e-01
# Min:  -2.0327e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 124
# Loss: 77.2467
# Psi gradient stats:
# Mean: -8.9875e-03
# Std:  7.4338e-02
# Max:  1.9952e-01
# Min:  -2.0322e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 125
# Loss: 77.2186
# Psi gradient stats:
# Mean: -8.9872e-03
# Std:  7.4320e-02
# Max:  1.9950e-01
# Min:  -2.0318e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 126
# Loss: 77.1904
# Psi gradient stats:
# Mean: -8.9860e-03
# Std:  7.4301e-02
# Max:  1.9947e-01
# Min:  -2.0312e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 127
# Loss: 77.1628
# Psi gradient stats:
# Mean: -8.9845e-03
# Std:  7.4284e-02
# Max:  1.9944e-01
# Min:  -2.0307e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 128
# Loss: 77.1352
# Psi gradient stats:
# Mean: -8.9848e-03
# Std:  7.4267e-02
# Max:  1.9942e-01
# Min:  -2.0303e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 129
# Loss: 77.1079
# Psi gradient stats:
# Mean: -8.9829e-03
# Std:  7.4250e-02
# Max:  1.9940e-01
# Min:  -2.0299e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 130
# Loss: 77.0809
# Psi gradient stats:
# Mean: -8.9820e-03
# Std:  7.4233e-02
# Max:  1.9937e-01
# Min:  -2.0295e-01
# Epoch 130, Loss: 77.0809, Gradients - Lambda: 1.191e-02, Phi: 4.260e+00, Gamma: 2.495e-02, Psi: 2.029e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 131
# Loss: 77.0540
# Psi gradient stats:
# Mean: -8.9811e-03
# Std:  7.4216e-02
# Max:  1.9935e-01
# Min:  -2.0291e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 132
# Loss: 77.0274
# Psi gradient stats:
# Mean: -8.9781e-03
# Std:  7.4198e-02
# Max:  1.9933e-01
# Min:  -2.0288e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 133
# Loss: 77.0010
# Psi gradient stats:
# Mean: -8.9768e-03
# Std:  7.4181e-02
# Max:  1.9931e-01
# Min:  -2.0284e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 134
# Loss: 76.9747
# Psi gradient stats:
# Mean: -8.9768e-03
# Std:  7.4164e-02
# Max:  1.9928e-01
# Min:  -2.0280e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 135
# Loss: 76.9489
# Psi gradient stats:
# Mean: -8.9766e-03
# Std:  7.4146e-02
# Max:  1.9926e-01
# Min:  -2.0276e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 136
# Loss: 76.9231
# Psi gradient stats:
# Mean: -8.9770e-03
# Std:  7.4129e-02
# Max:  1.9923e-01
# Min:  -2.0272e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 137
# Loss: 76.8975
# Psi gradient stats:
# Mean: -8.9769e-03
# Std:  7.4112e-02
# Max:  1.9921e-01
# Min:  -2.0268e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 138
# Loss: 76.8723
# Psi gradient stats:
# Mean: -8.9765e-03
# Std:  7.4095e-02
# Max:  1.9919e-01
# Min:  -2.0263e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 139
# Loss: 76.8469
# Psi gradient stats:
# Mean: -8.9749e-03
# Std:  7.4078e-02
# Max:  1.9917e-01
# Min:  -2.0260e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 140
# Loss: 76.8220
# Psi gradient stats:
# Mean: -8.9744e-03
# Std:  7.4061e-02
# Max:  1.9914e-01
# Min:  -2.0257e-01
# Epoch 140, Loss: 76.8220, Gradients - Lambda: 1.111e-02, Phi: 3.851e+00, Gamma: 2.289e-02, Psi: 2.026e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 141
# Loss: 76.7972
# Psi gradient stats:
# Mean: -8.9744e-03
# Std:  7.4045e-02
# Max:  1.9912e-01
# Min:  -2.0254e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 142
# Loss: 76.7726
# Psi gradient stats:
# Mean: -8.9727e-03
# Std:  7.4027e-02
# Max:  1.9910e-01
# Min:  -2.0250e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 143
# Loss: 76.7482
# Psi gradient stats:
# Mean: -8.9723e-03
# Std:  7.4009e-02
# Max:  1.9907e-01
# Min:  -2.0245e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 144
# Loss: 76.7241
# Psi gradient stats:
# Mean: -8.9729e-03
# Std:  7.3990e-02
# Max:  1.9905e-01
# Min:  -2.0241e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 145
# Loss: 76.6998
# Psi gradient stats:
# Mean: -8.9735e-03
# Std:  7.3972e-02
# Max:  1.9904e-01
# Min:  -2.0235e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 146
# Loss: 76.6760
# Psi gradient stats:
# Mean: -8.9741e-03
# Std:  7.3954e-02
# Max:  1.9901e-01
# Min:  -2.0231e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 147
# Loss: 76.6523
# Psi gradient stats:
# Mean: -8.9740e-03
# Std:  7.3935e-02
# Max:  1.9898e-01
# Min:  -2.0227e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 148
# Loss: 76.6288
# Psi gradient stats:
# Mean: -8.9745e-03
# Std:  7.3918e-02
# Max:  1.9895e-01
# Min:  -2.0224e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 149
# Loss: 76.6054
# Psi gradient stats:
# Mean: -8.9747e-03
# Std:  7.3900e-02
# Max:  1.9894e-01
# Min:  -2.0221e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 150
# Loss: 76.5823
# Psi gradient stats:
# Mean: -8.9759e-03
# Std:  7.3883e-02
# Max:  1.9892e-01
# Min:  -2.0216e-01
# Epoch 150, Loss: 76.5823, Gradients - Lambda: 1.060e-02, Phi: 3.452e+00, Gamma: 2.093e-02, Psi: 2.022e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 151
# Loss: 76.5594
# Psi gradient stats:
# Mean: -8.9759e-03
# Std:  7.3863e-02
# Max:  1.9889e-01
# Min:  -2.0212e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 152
# Loss: 76.5365
# Psi gradient stats:
# Mean: -8.9764e-03
# Std:  7.3844e-02
# Max:  1.9887e-01
# Min:  -2.0207e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 153
# Loss: 76.5139
# Psi gradient stats:
# Mean: -8.9770e-03
# Std:  7.3824e-02
# Max:  1.9885e-01
# Min:  -2.0202e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 154
# Loss: 76.4915
# Psi gradient stats:
# Mean: -8.9768e-03
# Std:  7.3805e-02
# Max:  1.9883e-01
# Min:  -2.0198e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 155
# Loss: 76.4692
# Psi gradient stats:
# Mean: -8.9774e-03
# Std:  7.3786e-02
# Max:  1.9879e-01
# Min:  -2.0195e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 156
# Loss: 76.4469
# Psi gradient stats:
# Mean: -8.9778e-03
# Std:  7.3768e-02
# Max:  1.9875e-01
# Min:  -2.0192e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 157
# Loss: 76.4249
# Psi gradient stats:
# Mean: -8.9795e-03
# Std:  7.3751e-02
# Max:  1.9872e-01
# Min:  -2.0189e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 158
# Loss: 76.4030
# Psi gradient stats:
# Mean: -8.9806e-03
# Std:  7.3732e-02
# Max:  1.9869e-01
# Min:  -2.0184e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 159
# Loss: 76.3813
# Psi gradient stats:
# Mean: -8.9809e-03
# Std:  7.3713e-02
# Max:  1.9865e-01
# Min:  -2.0181e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 160
# Loss: 76.3598
# Psi gradient stats:
# Mean: -8.9821e-03
# Std:  7.3695e-02
# Max:  1.9862e-01
# Min:  -2.0177e-01
# Epoch 160, Loss: 76.3598, Gradients - Lambda: 1.030e-02, Phi: 3.082e+00, Gamma: 2.077e-02, Psi: 2.018e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 161
# Loss: 76.3383
# Psi gradient stats:
# Mean: -8.9830e-03
# Std:  7.3676e-02
# Max:  1.9859e-01
# Min:  -2.0173e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 162
# Loss: 76.3170
# Psi gradient stats:
# Mean: -8.9826e-03
# Std:  7.3656e-02
# Max:  1.9858e-01
# Min:  -2.0168e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 163
# Loss: 76.2961
# Psi gradient stats:
# Mean: -8.9823e-03
# Std:  7.3637e-02
# Max:  1.9855e-01
# Min:  -2.0166e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 164
# Loss: 76.2750
# Psi gradient stats:
# Mean: -8.9829e-03
# Std:  7.3618e-02
# Max:  1.9852e-01
# Min:  -2.0163e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 165
# Loss: 76.2542
# Psi gradient stats:
# Mean: -8.9822e-03
# Std:  7.3599e-02
# Max:  1.9849e-01
# Min:  -2.0158e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 166
# Loss: 76.2335
# Psi gradient stats:
# Mean: -8.9807e-03
# Std:  7.3580e-02
# Max:  1.9847e-01
# Min:  -2.0154e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 167
# Loss: 76.2128
# Psi gradient stats:
# Mean: -8.9788e-03
# Std:  7.3561e-02
# Max:  1.9844e-01
# Min:  -2.0149e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 168
# Loss: 76.1923
# Psi gradient stats:
# Mean: -8.9796e-03
# Std:  7.3543e-02
# Max:  1.9840e-01
# Min:  -2.0145e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 169
# Loss: 76.1720
# Psi gradient stats:
# Mean: -8.9798e-03
# Std:  7.3524e-02
# Max:  1.9838e-01
# Min:  -2.0139e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 170
# Loss: 76.1517
# Psi gradient stats:
# Mean: -8.9788e-03
# Std:  7.3505e-02
# Max:  1.9836e-01
# Min:  -2.0134e-01
# Epoch 170, Loss: 76.1517, Gradients - Lambda: 1.005e-02, Phi: 2.875e+00, Gamma: 2.132e-02, Psi: 2.013e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 171
# Loss: 76.1317
# Psi gradient stats:
# Mean: -8.9782e-03
# Std:  7.3484e-02
# Max:  1.9834e-01
# Min:  -2.0128e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 172
# Loss: 76.1118
# Psi gradient stats:
# Mean: -8.9775e-03
# Std:  7.3465e-02
# Max:  1.9831e-01
# Min:  -2.0124e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 173
# Loss: 76.0919
# Psi gradient stats:
# Mean: -8.9768e-03
# Std:  7.3446e-02
# Max:  1.9829e-01
# Min:  -2.0120e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 174
# Loss: 76.0722
# Psi gradient stats:
# Mean: -8.9763e-03
# Std:  7.3427e-02
# Max:  1.9827e-01
# Min:  -2.0117e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 175
# Loss: 76.0528
# Psi gradient stats:
# Mean: -8.9757e-03
# Std:  7.3408e-02
# Max:  1.9823e-01
# Min:  -2.0113e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 176
# Loss: 76.0334
# Psi gradient stats:
# Mean: -8.9750e-03
# Std:  7.3389e-02
# Max:  1.9820e-01
# Min:  -2.0108e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 177
# Loss: 76.0141
# Psi gradient stats:
# Mean: -8.9741e-03
# Std:  7.3368e-02
# Max:  1.9818e-01
# Min:  -2.0102e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 178
# Loss: 75.9949
# Psi gradient stats:
# Mean: -8.9747e-03
# Std:  7.3349e-02
# Max:  1.9816e-01
# Min:  -2.0097e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 179
# Loss: 75.9757
# Psi gradient stats:
# Mean: -8.9752e-03
# Std:  7.3329e-02
# Max:  1.9814e-01
# Min:  -2.0093e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 180
# Loss: 75.9569
# Psi gradient stats:
# Mean: -8.9755e-03
# Std:  7.3309e-02
# Max:  1.9811e-01
# Min:  -2.0087e-01
# Epoch 180, Loss: 75.9569, Gradients - Lambda: 9.728e-03, Phi: 2.790e+00, Gamma: 2.177e-02, Psi: 2.009e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 181
# Loss: 75.9380
# Psi gradient stats:
# Mean: -8.9752e-03
# Std:  7.3290e-02
# Max:  1.9809e-01
# Min:  -2.0082e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 182
# Loss: 75.9191
# Psi gradient stats:
# Mean: -8.9747e-03
# Std:  7.3273e-02
# Max:  1.9807e-01
# Min:  -2.0077e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 183
# Loss: 75.9006
# Psi gradient stats:
# Mean: -8.9755e-03
# Std:  7.3254e-02
# Max:  1.9804e-01
# Min:  -2.0072e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 184
# Loss: 75.8820
# Psi gradient stats:
# Mean: -8.9748e-03
# Std:  7.3235e-02
# Max:  1.9801e-01
# Min:  -2.0066e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 185
# Loss: 75.8638
# Psi gradient stats:
# Mean: -8.9739e-03
# Std:  7.3216e-02
# Max:  1.9799e-01
# Min:  -2.0059e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 186
# Loss: 75.8454
# Psi gradient stats:
# Mean: -8.9732e-03
# Std:  7.3196e-02
# Max:  1.9797e-01
# Min:  -2.0053e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 187
# Loss: 75.8273
# Psi gradient stats:
# Mean: -8.9730e-03
# Std:  7.3176e-02
# Max:  1.9793e-01
# Min:  -2.0049e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 188
# Loss: 75.8092
# Psi gradient stats:
# Mean: -8.9738e-03
# Std:  7.3158e-02
# Max:  1.9790e-01
# Min:  -2.0045e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 189
# Loss: 75.7913
# Psi gradient stats:
# Mean: -8.9723e-03
# Std:  7.3138e-02
# Max:  1.9787e-01
# Min:  -2.0041e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 190
# Loss: 75.7733
# Psi gradient stats:
# Mean: -8.9723e-03
# Std:  7.3120e-02
# Max:  1.9786e-01
# Min:  -2.0037e-01
# Epoch 190, Loss: 75.7733, Gradients - Lambda: 9.424e-03, Phi: 2.709e+00, Gamma: 2.214e-02, Psi: 2.004e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 191
# Loss: 75.7556
# Psi gradient stats:
# Mean: -8.9707e-03
# Std:  7.3099e-02
# Max:  1.9783e-01
# Min:  -2.0031e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 192
# Loss: 75.7379
# Psi gradient stats:
# Mean: -8.9702e-03
# Std:  7.3080e-02
# Max:  1.9780e-01
# Min:  -2.0026e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 193
# Loss: 75.7203
# Psi gradient stats:
# Mean: -8.9705e-03
# Std:  7.3060e-02
# Max:  1.9778e-01
# Min:  -2.0020e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 194
# Loss: 75.7029
# Psi gradient stats:
# Mean: -8.9709e-03
# Std:  7.3041e-02
# Max:  1.9776e-01
# Min:  -2.0015e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 195
# Loss: 75.6854
# Psi gradient stats:
# Mean: -8.9716e-03
# Std:  7.3022e-02
# Max:  1.9772e-01
# Min:  -2.0012e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 196
# Loss: 75.6682
# Psi gradient stats:
# Mean: -8.9704e-03
# Std:  7.3003e-02
# Max:  1.9769e-01
# Min:  -2.0006e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 197
# Loss: 75.6510
# Psi gradient stats:
# Mean: -8.9711e-03
# Std:  7.2986e-02
# Max:  1.9768e-01
# Min:  -2.0002e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 198
# Loss: 75.6339
# Psi gradient stats:
# Mean: -8.9708e-03
# Std:  7.2968e-02
# Max:  1.9767e-01
# Min:  -1.9998e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 199
# Loss: 75.6168
# Psi gradient stats:
# Mean: -8.9724e-03
# Std:  7.2948e-02
# Max:  1.9765e-01
# Min:  -1.9993e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 200
# Loss: 75.6000
# Psi gradient stats:
# Mean: -8.9732e-03
# Std:  7.2929e-02
# Max:  1.9762e-01
# Min:  -1.9988e-01
# Epoch 200, Loss: 75.6000, Gradients - Lambda: 9.146e-03, Phi: 2.416e+00, Gamma: 2.243e-02, Psi: 1.999e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 201
# Loss: 75.5831
# Psi gradient stats:
# Mean: -8.9728e-03
# Std:  7.2910e-02
# Max:  1.9759e-01
# Min:  -1.9982e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 202
# Loss: 75.5664
# Psi gradient stats:
# Mean: -8.9739e-03
# Std:  7.2891e-02
# Max:  1.9756e-01
# Min:  -1.9979e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 203
# Loss: 75.5498
# Psi gradient stats:
# Mean: -8.9739e-03
# Std:  7.2871e-02
# Max:  1.9753e-01
# Min:  -1.9974e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 204
# Loss: 75.5333
# Psi gradient stats:
# Mean: -8.9743e-03
# Std:  7.2852e-02
# Max:  1.9749e-01
# Min:  -1.9971e-01
# ...
# Std:  6.1745e-02
# Max:  1.7797e-01
# Min:  -1.6887e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 930
# Loss: 69.8222
# Psi gradient stats:
# Mean: -8.6145e-03
# Std:  6.1735e-02
# Max:  1.7794e-01
# Min:  -1.6885e-01
# Epoch 930, Loss: 69.8222, Gradients - Lambda: 3.752e-03, Phi: 6.969e-01, Gamma: 2.337e-02, Psi: 1.779e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 931
# Loss: 69.8177
# Psi gradient stats:
# Mean: -8.6125e-03
# Std:  6.1725e-02
# Max:  1.7791e-01
# Min:  -1.6883e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 932
# Loss: 69.8131
# Psi gradient stats:
# Mean: -8.6123e-03
# Std:  6.1715e-02
# Max:  1.7789e-01
# Min:  -1.6879e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 933
# Loss: 69.8086
# Psi gradient stats:
# Mean: -8.6114e-03
# Std:  6.1705e-02
# Max:  1.7787e-01
# Min:  -1.6876e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 934
# Loss: 69.8040
# Psi gradient stats:
# Mean: -8.6085e-03
# Std:  6.1693e-02
# Max:  1.7785e-01
# Min:  -1.6874e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 935
# Loss: 69.7994
# Psi gradient stats:
# Mean: -8.6079e-03
# Std:  6.1682e-02
# Max:  1.7782e-01
# Min:  -1.6872e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 936
# Loss: 69.7949
# Psi gradient stats:
# Mean: -8.6080e-03
# Std:  6.1672e-02
# Max:  1.7778e-01
# Min:  -1.6869e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 937
# Loss: 69.7904
# Psi gradient stats:
# Mean: -8.6067e-03
# Std:  6.1663e-02
# Max:  1.7776e-01
# Min:  -1.6868e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 938
# Loss: 69.7859
# Psi gradient stats:
# Mean: -8.6056e-03
# Std:  6.1653e-02
# Max:  1.7773e-01
# Min:  -1.6865e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 939
# Loss: 69.7814
# Psi gradient stats:
# Mean: -8.6035e-03
# Std:  6.1640e-02
# Max:  1.7769e-01
# Min:  -1.6863e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 940
# Loss: 69.7769
# Psi gradient stats:
# Mean: -8.6029e-03
# Std:  6.1629e-02
# Max:  1.7767e-01
# Min:  -1.6861e-01
# Epoch 940, Loss: 69.7769, Gradients - Lambda: 3.764e-03, Phi: 7.734e-01, Gamma: 2.337e-02, Psi: 1.777e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 941
# Loss: 69.7724
# Psi gradient stats:
# Mean: -8.6021e-03
# Std:  6.1620e-02
# Max:  1.7767e-01
# Min:  -1.6856e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 942
# Loss: 69.7679
# Psi gradient stats:
# Mean: -8.5995e-03
# Std:  6.1610e-02
# Max:  1.7766e-01
# Min:  -1.6854e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 943
# Loss: 69.7633
# Psi gradient stats:
# Mean: -8.5982e-03
# Std:  6.1600e-02
# Max:  1.7763e-01
# Min:  -1.6853e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 944
# Loss: 69.7589
# Psi gradient stats:
# Mean: -8.5983e-03
# Std:  6.1592e-02
# Max:  1.7760e-01
# Min:  -1.6853e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 945
# Loss: 69.7543
# Psi gradient stats:
# Mean: -8.5967e-03
# Std:  6.1582e-02
# Max:  1.7759e-01
# Min:  -1.6850e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 946
# Loss: 69.7499
# Psi gradient stats:
# Mean: -8.5953e-03
# Std:  6.1568e-02
# Max:  1.7758e-01
# Min:  -1.6845e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 947
# Loss: 69.7455
# Psi gradient stats:
# Mean: -8.5953e-03
# Std:  6.1557e-02
# Max:  1.7755e-01
# Min:  -1.6841e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 948
# Loss: 69.7410
# Psi gradient stats:
# Mean: -8.5958e-03
# Std:  6.1547e-02
# Max:  1.7752e-01
# Min:  -1.6841e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 949
# Loss: 69.7366
# Psi gradient stats:
# Mean: -8.5945e-03
# Std:  6.1537e-02
# Max:  1.7751e-01
# Min:  -1.6840e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 950
# Loss: 69.7322
# Psi gradient stats:
# Mean: -8.5918e-03
# Std:  6.1526e-02
# Max:  1.7749e-01
# Min:  -1.6836e-01
# Epoch 950, Loss: 69.7322, Gradients - Lambda: 3.679e-03, Phi: 7.720e-01, Gamma: 2.337e-02, Psi: 1.775e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 951
# Loss: 69.7277
# Psi gradient stats:
# Mean: -8.5901e-03
# Std:  6.1516e-02
# Max:  1.7745e-01
# Min:  -1.6832e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 952
# Loss: 69.7233
# Psi gradient stats:
# Mean: -8.5895e-03
# Std:  6.1504e-02
# Max:  1.7742e-01
# Min:  -1.6830e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 953
# Loss: 69.7188
# Psi gradient stats:
# Mean: -8.5916e-03
# Std:  6.1496e-02
# Max:  1.7740e-01
# Min:  -1.6830e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 954
# Loss: 69.7144
# Psi gradient stats:
# Mean: -8.5910e-03
# Std:  6.1486e-02
# Max:  1.7738e-01
# Min:  -1.6826e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 955
# Loss: 69.7100
# Psi gradient stats:
# Mean: -8.5879e-03
# Std:  6.1475e-02
# Max:  1.7734e-01
# Min:  -1.6820e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 956
# Loss: 69.7055
# Psi gradient stats:
# Mean: -8.5877e-03
# Std:  6.1466e-02
# Max:  1.7732e-01
# Min:  -1.6819e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 957
# Loss: 69.7011
# Psi gradient stats:
# Mean: -8.5858e-03
# Std:  6.1456e-02
# Max:  1.7731e-01
# Min:  -1.6820e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 958
# Loss: 69.6967
# Psi gradient stats:
# Mean: -8.5835e-03
# Std:  6.1445e-02
# Max:  1.7729e-01
# Min:  -1.6817e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 959
# Loss: 69.6923
# Psi gradient stats:
# Mean: -8.5809e-03
# Std:  6.1435e-02
# Max:  1.7725e-01
# Min:  -1.6812e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 960
# Loss: 69.6879
# Psi gradient stats:
# Mean: -8.5797e-03
# Std:  6.1428e-02
# Max:  1.7724e-01
# Min:  -1.6812e-01
# Epoch 960, Loss: 69.6879, Gradients - Lambda: 3.647e-03, Phi: 6.486e-01, Gamma: 2.337e-02, Psi: 1.772e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 961
# Loss: 69.6836
# Psi gradient stats:
# Mean: -8.5799e-03
# Std:  6.1419e-02
# Max:  1.7724e-01
# Min:  -1.6810e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 962
# Loss: 69.6791
# Psi gradient stats:
# Mean: -8.5793e-03
# Std:  6.1407e-02
# Max:  1.7721e-01
# Min:  -1.6807e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 963
# Loss: 69.6747
# Psi gradient stats:
# Mean: -8.5775e-03
# Std:  6.1397e-02
# Max:  1.7718e-01
# Min:  -1.6805e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 964
# Loss: 69.6703
# Psi gradient stats:
# Mean: -8.5754e-03
# Std:  6.1386e-02
# Max:  1.7716e-01
# Min:  -1.6802e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 965
# Loss: 69.6660
# Psi gradient stats:
# Mean: -8.5761e-03
# Std:  6.1375e-02
# Max:  1.7714e-01
# Min:  -1.6800e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 966
# Loss: 69.6616
# Psi gradient stats:
# Mean: -8.5750e-03
# Std:  6.1366e-02
# Max:  1.7712e-01
# Min:  -1.6798e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 967
# Loss: 69.6573
# Psi gradient stats:
# Mean: -8.5741e-03
# Std:  6.1355e-02
# Max:  1.7709e-01
# Min:  -1.6796e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 968
# Loss: 69.6529
# Psi gradient stats:
# Mean: -8.5725e-03
# Std:  6.1345e-02
# Max:  1.7707e-01
# Min:  -1.6793e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 969
# Loss: 69.6486
# Psi gradient stats:
# Mean: -8.5716e-03
# Std:  6.1337e-02
# Max:  1.7706e-01
# Min:  -1.6790e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 970
# Loss: 69.6442
# Psi gradient stats:
# Mean: -8.5691e-03
# Std:  6.1326e-02
# Max:  1.7706e-01
# Min:  -1.6787e-01
# Epoch 970, Loss: 69.6442, Gradients - Lambda: 3.612e-03, Phi: 6.627e-01, Gamma: 2.337e-02, Psi: 1.771e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 971
# Loss: 69.6399
# Psi gradient stats:
# Mean: -8.5685e-03
# Std:  6.1316e-02
# Max:  1.7703e-01
# Min:  -1.6784e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 972
# Loss: 69.6354
# Psi gradient stats:
# Mean: -8.5674e-03
# Std:  6.1307e-02
# Max:  1.7699e-01
# Min:  -1.6782e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 973
# Loss: 69.6311
# Psi gradient stats:
# Mean: -8.5666e-03
# Std:  6.1297e-02
# Max:  1.7697e-01
# Min:  -1.6779e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 974
# Loss: 69.6268
# Psi gradient stats:
# Mean: -8.5649e-03
# Std:  6.1284e-02
# Max:  1.7694e-01
# Min:  -1.6776e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 975
# Loss: 69.6225
# Psi gradient stats:
# Mean: -8.5635e-03
# Std:  6.1276e-02
# Max:  1.7691e-01
# Min:  -1.6774e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 976
# Loss: 69.6181
# Psi gradient stats:
# Mean: -8.5641e-03
# Std:  6.1266e-02
# Max:  1.7689e-01
# Min:  -1.6774e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 977
# Loss: 69.6138
# Psi gradient stats:
# Mean: -8.5614e-03
# Std:  6.1256e-02
# Max:  1.7687e-01
# Min:  -1.6770e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 978
# Loss: 69.6095
# Psi gradient stats:
# Mean: -8.5600e-03
# Std:  6.1244e-02
# Max:  1.7683e-01
# Min:  -1.6767e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 979
# Loss: 69.6051
# Psi gradient stats:
# Mean: -8.5590e-03
# Std:  6.1233e-02
# Max:  1.7680e-01
# Min:  -1.6767e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 980
# Loss: 69.6008
# Psi gradient stats:
# Mean: -8.5581e-03
# Std:  6.1223e-02
# Max:  1.7678e-01
# Min:  -1.6765e-01
# Epoch 980, Loss: 69.6008, Gradients - Lambda: 3.582e-03, Phi: 8.385e-01, Gamma: 2.337e-02, Psi: 1.768e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 981
# Loss: 69.5966
# Psi gradient stats:
# Mean: -8.5582e-03
# Std:  6.1213e-02
# Max:  1.7676e-01
# Min:  -1.6762e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 982
# Loss: 69.5923
# Psi gradient stats:
# Mean: -8.5567e-03
# Std:  6.1204e-02
# Max:  1.7675e-01
# Min:  -1.6761e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 983
# Loss: 69.5879
# Psi gradient stats:
# Mean: -8.5559e-03
# Std:  6.1195e-02
# Max:  1.7672e-01
# Min:  -1.6759e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 984
# Loss: 69.5837
# Psi gradient stats:
# Mean: -8.5557e-03
# Std:  6.1185e-02
# Max:  1.7670e-01
# Min:  -1.6756e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 985
# Loss: 69.5794
# Psi gradient stats:
# Mean: -8.5536e-03
# Std:  6.1176e-02
# Max:  1.7669e-01
# Min:  -1.6754e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 986
# Loss: 69.5751
# Psi gradient stats:
# Mean: -8.5506e-03
# Std:  6.1165e-02
# Max:  1.7668e-01
# Min:  -1.6750e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 987
# Loss: 69.5707
# Psi gradient stats:
# Mean: -8.5485e-03
# Std:  6.1156e-02
# Max:  1.7667e-01
# Min:  -1.6747e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 988
# Loss: 69.5664
# Psi gradient stats:
# Mean: -8.5472e-03
# Std:  6.1147e-02
# Max:  1.7666e-01
# Min:  -1.6745e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 989
# Loss: 69.5622
# Psi gradient stats:
# Mean: -8.5473e-03
# Std:  6.1137e-02
# Max:  1.7665e-01
# Min:  -1.6744e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 990
# Loss: 69.5579
# Psi gradient stats:
# Mean: -8.5455e-03
# Std:  6.1127e-02
# Max:  1.7662e-01
# Min:  -1.6741e-01
# Epoch 990, Loss: 69.5579, Gradients - Lambda: 3.547e-03, Phi: 6.375e-01, Gamma: 2.336e-02, Psi: 1.766e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 991
# Loss: 69.5537
# Psi gradient stats:
# Mean: -8.5449e-03
# Std:  6.1118e-02
# Max:  1.7659e-01
# Min:  -1.6736e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 992
# Loss: 69.5494
# Psi gradient stats:
# Mean: -8.5459e-03
# Std:  6.1108e-02
# Max:  1.7658e-01
# Min:  -1.6736e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 993
# Loss: 69.5451
# Psi gradient stats:
# Mean: -8.5449e-03
# Std:  6.1096e-02
# Max:  1.7655e-01
# Min:  -1.6734e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 994
# Loss: 69.5409
# Psi gradient stats:
# Mean: -8.5436e-03
# Std:  6.1086e-02
# Max:  1.7652e-01
# Min:  -1.6732e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 995
# Loss: 69.5366
# Psi gradient stats:
# Mean: -8.5422e-03
# Std:  6.1078e-02
# Max:  1.7649e-01
# Min:  -1.6728e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 996
# Loss: 69.5324
# Psi gradient stats:
# Mean: -8.5381e-03
# Std:  6.1068e-02
# Max:  1.7647e-01
# Min:  -1.6726e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 997
# Loss: 69.5281
# Psi gradient stats:
# Mean: -8.5385e-03
# Std:  6.1060e-02
# Max:  1.7646e-01
# Min:  -1.6726e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 998
# Loss: 69.5239
# Psi gradient stats:
# Mean: -8.5384e-03
# Std:  6.1051e-02
# Max:  1.7643e-01
# Min:  -1.6725e-01
# mask_before_event shape: torch.Size([10000, 20, 50])
# mask_at_event shape: torch.Size([10000, 20, 50])
#
# Epoch 999
# Loss: 69.5197
# Psi gradient stats:
# Mean: -8.5361e-03
# Std:  6.1040e-02
# Max:  1.7640e-01
# Min:  -1.6721e-01

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history['max_grad_lambda'], label='Lambda')
ax2.plot(history['max_grad_phi'], label='Phi')
ax2.plot(history['max_grad_gamma'], label='Gamma')
ax2.plot(history['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
initial_psi
# Out:
# tensor([[ 1.,  1.,  1.,  1., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3.,  1.,  1.,  1.,  1., -3., -3., -3., -3., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3.,  1.,  1.,  1.,  1., -3., -3.,
#          -3., -3., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,  1.,  1.,
#           1.,  1., -3., -3., -3., -3.],
#         [-3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3., -3.,
#          -3., -3.,  1.,  1.,  1.,  1.]])

# %%
model.psi
# Out:
# Parameter containing:
# tensor([[ 1.0741,  1.0673,  1.1107,  0.8929, -2.8715, -2.9099, -2.9099, -3.0969,
#          -3.0756, -3.0994, -3.0942, -2.9389, -2.9384, -3.0924, -3.0845, -3.0916,
#          -3.0937, -2.8955, -2.9056, -3.0857],
#         [-2.9151, -3.0728, -2.9071, -2.9078,  0.9221,  0.9091,  0.9773,  1.0905,
#          -2.9633, -2.9089, -3.0809, -2.9212, -3.1004, -3.1029, -2.9032, -3.0105,
#          -2.8979, -2.9055, -3.0947, -2.9071],
#         [-2.9031, -2.9028, -3.0573, -2.9115, -3.0832, -2.8935, -2.9126, -2.9944,
#           1.1040,  1.0884,  1.0903,  1.0847, -3.1009, -2.9463, -2.9890, -3.0839,
#          -2.9172, -3.0941, -3.1018, -3.0963],
#         [-2.9028, -2.9032, -3.0906, -2.9530, -2.8981, -2.8960, -3.0499, -2.8754,
#          -2.9920, -3.0866, -2.9063, -2.9109,  1.1452,  1.0569,  1.0959,  1.0939,
#          -3.0998, -3.1039, -2.8994, -2.8965],
#         [-3.0400, -2.9097, -2.8992, -2.9840, -3.0965, -3.1322, -3.0906, -2.9101,
#          -2.8915, -2.9046, -3.0877, -2.8991, -3.0917, -2.9643, -2.8968, -3.0966,
#           1.1169,  0.9150,  0.9019,  1.0988]], requires_grad=True)

# %%
# Compare recovered vs true parameters
def compare_parameters(model, true_data):
    plt.figure(figsize=(15, 10))
    
    # 1. Compare psi values
    plt.subplot(221)
    sns.heatmap(model.psi.detach().numpy(), 
                cmap='RdBu_r', center=0)
    plt.title('Recovered - True ψ Values')
    
    # 2. Compare phi trajectories
    plt.subplot(222)
    recovered_phi = model.phi.detach().numpy()
    for k in range(K):
        #plt.plot(true_data['phi'][k,0,:], 'b-', alpha=0.5, label='True' if k==0 else '')
        plt.plot(recovered_phi[k,0,:], 'r--', alpha=0.5, label='Recovered' if k==0 else '')
    plt.title('φ Trajectories (First Disease)')
    plt.legend()
    
    # 3. Training history
    plt.subplot(223)
    plt.plot(history['loss'])
    plt.yscale('log')
    plt.title('Training Loss')
    plt.xlabel('Epoch')
    
    plt.tight_layout()
    plt.show()

# Compare results
compare_parameters(model, data)

print("\nOverall psi changes:")
print(torch.abs(model.psi - initial_psi).mean().item())
# Out:
# Overall psi changes:
# 0.08588773757219315

# %%
epsilon=1e-8
logit_prev_t = torch.log(
            (model.prevalence_t + epsilon) / (1 - model.prevalence_t + epsilon)
        )  # D 

for d in range(data['Y'].shape[1]):
    plt.plot(logit_prev_t[d,:], alpha=0.5, label=f'Disease {d}' if d < 5 else '')

for d in range(data['Y'].shape[1]):
    plt.plot(model.prevalence_t[d,:], alpha=0.5, label=f'Disease {d}' if d < 5 else '')

# %%
# For plotting smoothed prevalences
def plot_smoothed_prevalences(model, data):
    # Data smoothed prevalence
    data_prev = data['Y'].mean(axis=0)  # Average across individuals
    
    # Model smoothed prevalence (using mu_d/logit_prev_t)
    model_prev = torch.sigmoid(model.logit_prev_t)  # Convert logits to probabilities
    
    plt.figure(figsize=(10, 6))
    
    # Plot for each disease
    for d in range(data_prev.shape[0]):
        plt.plot(data_prev[d], 'b-', alpha=0.3, label='Data' if d==0 else '')
        plt.plot(model_prev[:, d].detach().numpy(), 'r--', alpha=0.3, 
                label='Model' if d==0 else '')
    
    plt.xlabel('Time')
    plt.ylabel('Prevalence')
    plt.title('Smoothed Prevalences: Data vs Model')
    plt.legend()
    plt.yscale('log')  # Optional: use log scale if prevalences vary widely
    plt.grid(True)
    plt.show()

# %%
print("Number of events per disease:")
print(data['Y'].sum(axis=(0,2)))  # Sum over individuals and time

print("\nNumber of events per time point:")
print(data['Y'].sum(axis=(0,1)))  # Sum over individuals and diseases
# Out:
# Number of events per disease:
# [1.000e+00 1.300e+02 1.355e+03 3.637e+03 2.800e+01 7.646e+03 4.710e+02
#  1.000e+04 3.637e+03 6.663e+03 8.242e+03 2.370e+02 9.986e+03 1.247e+03
#  8.220e+02 9.059e+03 9.957e+03 9.801e+03 6.000e+00 2.830e+02]
#
# Number of events per time point:
# [  12.   22.   27.   57.  103.  145.  236.  303.  413.  486.  540.  611.
#   623.  695.  701.  736.  821.  922. 1043. 1090. 1178. 1237. 1245. 1252.
#  1235. 1282. 1378. 1541. 1748. 2033. 2208. 2551. 2865. 2939. 3117. 3191.
#  3224. 3270. 3361. 3302. 3448. 3398. 3492. 3229. 3095. 3024. 2774. 2574.
#  2284. 2147.]

# %%
model.logit_prev_t
# Out:
# tensor([[-17.7275, -17.7274, -17.7273, -17.7270, -17.7264, -17.7253, -17.7234,
#          -17.7202, -17.7149, -17.7067, -17.6943, -17.6766, -17.6522, -17.6202,
#          -17.5801, -17.5328, -17.4800, -17.4255, -17.3742, -17.3319, -17.3038,
#          -17.2940, -17.3038, -17.3319, -17.3742, -17.4255, -17.4800, -17.5328,
#          -17.5801, -17.6202, -17.6522, -17.6766, -17.6943, -17.7067, -17.7149,
#          -17.7202, -17.7234, -17.7253, -17.7264, -17.7270, -17.7273, -17.7274,
#          -17.7275, -17.7275, -17.7275, -17.7275, -17.7275, -17.7275, -17.7275,
#          -17.7275],
#         [-17.7245, -17.7228, -17.7189, -17.7117, -17.6988, -17.6773, -17.6425,
#          -17.5876, -17.5033, -17.3768, -17.1924, -16.9321, -16.5805, -16.1304,
#          -15.5873, -14.9697, -14.3047, -13.6223, -12.9506, -12.3129, -11.7252,
#          -11.1961, -10.7267, -10.3133,  -9.9487,  -9.6254,  -9.3371,  -9.0791,
#           -8.8492,  -8.6459,  -8.4684,  -8.3158,  -8.1860,  -8.0766,  -7.9846,
#           -7.9069,  -7.8409,  -7.7846,  -7.7366,  -7.6958,  -7.6617,  -7.6337,
#           -7.6114,  -7.5942,  -7.5812,  -7.5721,  -7.5659,  -7.5618,  -7.5595,
#           -7.5584],
#         [-17.5409, -17.5083, -17.4395, -17.3271, -17.1603, -16.9251, -16.6068,
#          -16.1935, -15.6798, -15.0689, -14.3725, -13.6085, -12.7986, -11.9673,
#          -11.1393, -10.3378,  -9.5830,  -8.8901,  -8.2684,  -7.7215,  -7.2482,
#           -6.8436,  -6.5004,  -6.2109,  -5.9674,  -5.7635,  -5.5939,  -5.4546,
#           -5.3426,  -5.2559,  -5.1929,  -5.1522,  -5.1328,  -5.1338,  -5.1541,
#           -5.1924,  -5.2474,  -5.3176,  -5.4010,  -5.4955,  -5.5985,  -5.7069,
#           -5.8173,  -5.9258,  -6.0286,  -6.1218,  -6.2015,  -6.2646,  -6.3082,
#           -6.3305],
#         [-17.7257, -17.7248, -17.7226, -17.7186, -17.7116, -17.7001, -17.6817,
#          -17.6534, -17.6107, -17.5480, -17.4577, -17.3305, -17.1550, -16.9187,
#          -16.6102, -16.2214, -15.7497, -15.1991, -14.5788, -13.9014, -13.1817,
#          -12.4353, -11.6783, -10.9262, -10.1936,  -9.4930,  -8.8346,  -8.2252,
#           -7.6688,  -7.1663,  -6.7160,  -6.3145,  -5.9574,  -5.6395,  -5.3560,
#           -5.1022,  -4.8742,  -4.6688,  -4.4838,  -4.3171,  -4.1675,  -4.0344,
#           -3.9169,  -3.8149,  -3.7279,  -3.6558,  -3.5984,  -3.5556,  -3.5271,
#           -3.5129],
#         [-17.7271, -17.7268, -17.7260, -17.7245, -17.7217, -17.7165, -17.7078,
#          -17.6933, -17.6702, -17.6345, -17.5807, -17.5018, -17.3894, -17.2337,
#          -17.0255, -16.7579, -16.4299, -16.0480, -15.6260, -15.1825, -14.7379,
#          -14.3110, -13.9183, -13.5726, -13.2834, -13.0585, -12.9042, -12.8260,
#          -12.8290, -12.9163, -13.0879, -13.3388, -13.6574, -14.0257, -14.4202,
#          -14.8148, -15.1855, -15.5132, -15.7877, -16.0083, -16.1820, -16.3203,
#          -16.4365, -16.5410, -16.6404, -16.7359, -16.8243, -16.8992, -16.9539,
#          -16.9826],
#         [-17.7275, -17.7275, -17.7275, -17.7275, -17.7275, -17.7275, -17.7275,
#          -17.7275, -17.7275, -17.7275, -17.7274, -17.7273, -17.7268, -17.7259,
#          -17.7242, -17.7210, -17.7151, -17.7048, -17.6873, -17.6586, -17.6126,
#          -17.5406, -17.4299, -17.2633, -17.0184, -16.6702, -16.1965, -15.5862,
#          -14.8430, -13.9838, -13.0337, -12.0225, -10.9814,  -9.9417,  -8.9321,
#           -7.9768,  -7.0944,  -6.2969,  -5.5905,  -4.9757,  -4.4495,  -4.0058,
#           -3.6376,  -3.3369,  -3.0962,  -2.9081,  -2.7662,  -2.6649,  -2.6000,
#           -2.5683],
#         [-17.7274, -17.7273, -17.7270, -17.7263, -17.7249, -17.7226, -17.7185,
#          -17.7116, -17.7001, -17.6821, -17.6545, -17.6136, -17.5548, -17.4723,
#          -17.3598, -17.2109, -17.0197, -16.7828, -16.4992, -16.1714, -15.8035,
#          -15.3998, -14.9632, -14.4946, -13.9936, -13.4597, -12.8944, -12.3022,
#          -11.6922, -11.0765, -10.4700,  -9.8876,  -9.3423,  -8.8436,  -8.3965,
#           -8.0012,  -7.6543,  -7.3497,  -7.0801,  -6.8385,  -6.6189,  -6.4171,
#           -6.2306,  -6.0593,  -5.9043,  -5.7680,  -5.6534,  -5.5638,  -5.5023,
#           -5.4710],
#         [ -5.1031,  -5.0476,  -4.9406,  -4.7899,  -4.6060,  -4.4009,  -4.1869,
#           -3.9754,  -3.7761,  -3.5965,  -3.4414,  -3.3136,  -3.2138,  -3.1411,
#           -3.0941,  -3.0707,  -3.0691,  -3.0878,  -3.1257,  -3.1828,  -3.2590,
#           -3.3548,  -3.4716,  -3.6108,  -3.7744,  -3.9652,  -4.1867,  -4.4436,
#           -4.7415,  -5.0868,  -5.4863,  -5.9466,  -6.4731,  -7.0693,  -7.7358,
#           -8.4695,  -9.2633, -10.1061, -10.9824, -11.8737, -12.7587, -13.6140,
#          -14.4156, -15.1396, -15.7646, -16.2752, -16.6658, -16.9415, -17.1145,
#          -17.1972],
#         [-17.7156, -17.7108, -17.7001, -17.6812, -17.6501, -17.6011, -17.5263,
#          -17.4151, -17.2541, -17.0281, -16.7225, -16.3284, -15.8463, -15.2871,
#          -14.6699, -14.0167, -13.3488, -12.6838, -12.0342, -11.4071, -10.8052,
#          -10.2278,  -9.6726,  -9.1378,  -8.6225,  -8.1278,  -7.6563,  -7.2114,
#           -6.7964,  -6.4138,  -6.0647,  -5.7488,  -5.4646,  -5.2096,  -4.9811,
#           -4.7765,  -4.5936,  -4.4305,  -4.2863,  -4.1600,  -4.0515,  -3.9602,
#           -3.8855,  -3.8261,  -3.7811,  -3.7484,  -3.7258,  -3.7112,  -3.7028,
#           -3.6989],
#         [-17.7261, -17.7252, -17.7230, -17.7185, -17.7105, -17.6966, -17.6730,
#          -17.6343, -17.5725, -17.4758, -17.3276, -17.1060, -16.7850, -16.3404,
#          -15.7577, -15.0388, -14.2011, -13.2721, -12.2844, -11.2723, -10.2691,
#           -9.3043,  -8.4019,  -7.5787,  -6.8441,  -6.2009,  -5.6466,  -5.1754,
#           -4.7797,  -4.4513,  -4.1825,  -3.9664,  -3.7969,  -3.6687,  -3.5765,
#           -3.5158,  -3.4819,  -3.4701,  -3.4760,  -3.4954,  -3.5245,  -3.5596,
#           -3.5978,  -3.6365,  -3.6736,  -3.7073,  -3.7361,  -3.7588,  -3.7745,
#           -3.7825],
#         [-13.7845, -13.5616, -13.1318, -12.5260, -11.7866, -10.9616, -10.0984,
#           -9.2396,  -8.4185,  -7.6584,  -6.9728,  -6.3662,  -5.8370,  -5.3800,
#           -4.9880,  -4.6540,  -4.3717,  -4.1360,  -3.9430,  -3.7895,  -3.6724,
#           -3.5887,  -3.5351,  -3.5078,  -3.5029,  -3.5162,  -3.5435,  -3.5809,
#           -3.6252,  -3.6733,  -3.7233,  -3.7733,  -3.8224,  -3.8699,  -3.9157,
#           -3.9597,  -4.0023,  -4.0437,  -4.0841,  -4.1237,  -4.1624,  -4.2001,
#           -4.2363,  -4.2705,  -4.3019,  -4.3297,  -4.3532,  -4.3715,  -4.3841,
#           -4.3905],
#         [-17.7275, -17.7275, -17.7275, -17.7275, -17.7275, -17.7275, -17.7274,
#          -17.7271, -17.7267, -17.7258, -17.7241, -17.7209, -17.7154, -17.7060,
#          -17.6907, -17.6666, -17.6299, -17.5754, -17.4969, -17.3866, -17.2355,
#          -17.0345, -16.7754, -16.4528, -16.0655, -15.6161, -15.1101, -14.5548,
#          -13.9580, -13.3285, -12.6761, -12.0123, -11.3501, -10.7035, -10.0859,
#           -9.5091,  -8.9819,  -8.5094,  -8.0929,  -7.7303,  -7.4176,  -7.1495,
#           -6.9205,  -6.7261,  -6.5626,  -6.4277,  -6.3202,  -6.2396,  -6.1856,
#           -6.1585],
#         [-17.7275, -17.7274, -17.7271, -17.7266, -17.7254, -17.7231, -17.7187,
#          -17.7109, -17.6973, -17.6742, -17.6363, -17.5757, -17.4809, -17.3356,
#          -17.1180, -16.8023, -16.3636, -15.7864, -15.0712, -14.2337, -13.3000,
#          -12.3015, -11.2713, -10.2417,  -9.2423,  -8.2972,  -7.4242,  -6.6344,
#           -5.9326,  -5.3188,  -4.7893,  -4.3390,  -3.9619,  -3.6524,  -3.4055,
#           -3.2177,  -3.0859,  -3.0083,  -2.9829,  -3.0078,  -3.0801,  -3.1954,
#           -3.3472,  -3.5260,  -3.7200,  -3.9154,  -4.0968,  -4.2491,  -4.3591,
#           -4.4167],
#         [-14.1775, -13.9894, -13.6281, -13.1225, -12.5122, -11.8414, -11.1539,
#          -10.4873,  -9.8704,  -9.3213,  -8.8484,  -8.4513,  -8.1235,  -7.8551,
#           -7.6341,  -7.4489,  -7.2892,  -7.1462,  -7.0136,  -6.8866,  -6.7626,
#           -6.6406,  -6.5207,  -6.4040,  -6.2919,  -6.1860,  -6.0873,  -5.9965,
#           -5.9137,  -5.8383,  -5.7695,  -5.7064,  -5.6482,  -5.5941,  -5.5438,
#           -5.4973,  -5.4549,  -5.4169,  -5.3838,  -5.3559,  -5.3334,  -5.3160,
#           -5.3035,  -5.2953,  -5.2906,  -5.2886,  -5.2884,  -5.2891,  -5.2900,
#           -5.2906],
#         [-17.7006, -17.6923, -17.6741, -17.6431, -17.5940, -17.5197, -17.4100,
#          -17.2518, -17.0289, -16.7247, -16.3257, -15.8262, -15.2310, -14.5545,
#          -13.8179, -13.0458, -12.2635, -11.4956, -10.7639, -10.0858,  -9.4733,
#           -8.9325,  -8.4640,  -8.0635,  -7.7239,  -7.4358,  -7.1899,  -6.9774,
#           -6.7907,  -6.6242,  -6.4737,  -6.3364,  -6.2107,  -6.0956,  -5.9908,
#           -5.8961,  -5.8116,  -5.7376,  -5.6741,  -5.6211,  -5.5786,  -5.5460,
#           -5.5229,  -5.5080,  -5.5001,  -5.4974,  -5.4981,  -5.5006,  -5.5032,
#           -5.5048],
#         [-16.9177, -16.8379, -16.6760, -16.4295, -16.0979, -15.6854, -15.2011,
#          -14.6569, -14.0658, -13.4403, -12.7913, -12.1284, -11.4600, -10.7926,
#          -10.1327,  -9.4856,  -8.8569,  -8.2517,  -7.6750,  -7.1310,  -6.6237,
#           -6.1553,  -5.7270,  -5.3386,  -4.9888,  -4.6753,  -4.3956,  -4.1474,
#           -3.9283,  -3.7372,  -3.5729,  -3.4349,  -3.3231,  -3.2371,  -3.1766,
#           -3.1409,  -3.1287,  -3.1390,  -3.1694,  -3.2174,  -3.2800,  -3.3537,
#           -3.4348,  -3.5191,  -3.6023,  -3.6800,  -3.7483,  -3.8032,  -3.8416,
#           -3.8614],
#         [-15.6706, -15.4829, -15.1117, -14.5694, -13.8800, -13.0773, -12.1998,
#          -11.2864, -10.3731,  -9.4902,  -8.6614,  -7.9026,  -7.2226,  -6.6235,
#           -6.1024,  -5.6537,  -5.2693,  -4.9409,  -4.6605,  -4.4208,  -4.2151,
#           -4.0381,  -3.8851,  -3.7521,  -3.6360,  -3.5342,  -3.4450,  -3.3669,
#           -3.2997,  -3.2433,  -3.1986,  -3.1666,  -3.1490,  -3.1475,  -3.1639,
#           -3.1997,  -3.2561,  -3.3335,  -3.4318,  -3.5496,  -3.6846,  -3.8331,
#           -3.9905,  -4.1509,  -4.3077,  -4.4537,  -4.5815,  -4.6844,  -4.7565,
#           -4.7937],
#         [-17.6432, -17.6200, -17.5695, -17.4834, -17.3488, -17.1473, -16.8576,
#          -16.4594, -15.9409, -15.3038, -14.5645, -13.7481, -12.8837, -12.0008,
#          -11.1261, -10.2819,  -9.4844,  -8.7437,  -8.0638,  -7.4441,  -6.8809,
#           -6.3691,  -5.9037,  -5.4804,  -5.0962,  -4.7494,  -4.4393,  -4.1654,
#           -3.9275,  -3.7251,  -3.5567,  -3.4204,  -3.3135,  -3.2328,  -3.1748,
#           -3.1361,  -3.1138,  -3.1057,  -3.1103,  -3.1265,  -3.1537,  -3.1913,
#           -3.2381,  -3.2921,  -3.3506,  -3.4098,  -3.4651,  -3.5119,  -3.5459,
#           -3.5637],
#         [-17.7275, -17.7275, -17.7275, -17.7275, -17.7275, -17.7274, -17.7273,
#          -17.7270, -17.7264, -17.7252, -17.7232, -17.7196, -17.7138, -17.7045,
#          -17.6901, -17.6689, -17.6387, -17.5971, -17.5422, -17.4723, -17.3874,
#          -17.2888, -17.1805, -17.0688, -16.9616, -16.8667, -16.7905, -16.7364,
#          -16.7035, -16.6869, -16.6787, -16.6697, -16.6503, -16.6133, -16.5548,
#          -16.4746, -16.3773, -16.2704, -16.1643, -16.0694, -15.9938, -15.9421,
#          -15.9143, -15.9072, -15.9146, -15.9298, -15.9470, -15.9619, -15.9725,
#          -15.9780],
#         [-17.7270, -17.7265, -17.7254, -17.7231, -17.7188, -17.7111, -17.6976,
#          -17.6751, -17.6383, -17.5798, -17.4892, -17.3518, -17.1488, -16.8584,
#          -16.4606, -15.9448, -15.3148, -14.5890, -13.7957, -12.9675, -12.1374,
#          -11.3355, -10.5868,  -9.9092,  -9.3129,  -8.8008,  -8.3698,  -8.0125,
#           -7.7191,  -7.4796,  -7.2846,  -7.1261,  -6.9979,  -6.8956,  -6.8160,
#           -6.7573,  -6.7183,  -6.6984,  -6.6972,  -6.7142,  -6.7487,  -6.7990,
#           -6.8629,  -6.9370,  -7.0168,  -7.0969,  -7.1714,  -7.2340,  -7.2792,
#           -7.3030]])

# %%
plt.plot(data['pi'][1,3,:])

# %%
print("Number of events per disease:")
print(data['Y'].sum(axis=(0,2)))  # Sum over individuals and time

print("\nNumber of events per time point:")
print(data['Y'].sum(axis=(0,1)))  # Sum over individuals and diseases
# Out:
# Number of events per disease:
# [1.000e+00 1.300e+02 1.355e+03 3.637e+03 2.800e+01 7.646e+03 4.710e+02
#  1.000e+04 3.637e+03 6.663e+03 8.242e+03 2.370e+02 9.986e+03 1.247e+03
#  8.220e+02 9.059e+03 9.957e+03 9.801e+03 6.000e+00 2.830e+02]
#
# Number of events per time point:
# [  12.   22.   27.   57.  103.  145.  236.  303.  413.  486.  540.  611.
#   623.  695.  701.  736.  821.  922. 1043. 1090. 1178. 1237. 1245. 1252.
#  1235. 1282. 1378. 1541. 1748. 2033. 2208. 2551. 2865. 2939. 3117. 3191.
#  3224. 3270. 3361. 3302. 3448. 3398. 3492. 3229. 3095. 3024. 2774. 2574.
#  2284. 2147.]

# %%
with torch.no_grad():
    pi_pred, theta, phi = model.forward()
    pi_pred = pi_pred.cpu().numpy()

# %%
plt.plot(pi_pred[1,3,:])
E_tensor[1,3]
# Out:
# tensor(41.)

# %%
model_prev = torch.sigmoid(model.logit_prev_t)  
print(model_prev.shape)

data_prev = data['Y'].mean(axis=0) 
print(data_prev.shape)
# Out:
# torch.Size([20, 50])
# (20, 50)

# %%
# For plotting smoothed prevalences
def plot_smoothed_prevalences(model, data):
    # Data smoothed prevalence
    data_prev = compute_smoothed_prevalence(data['Y'])  # Average across individuals
    
    # Model smoothed prevalence (using mu_d/logit_prev_t)
    model_prev = torch.sigmoid(model.logit_prev_t)  # Convert logits to probabilities
    
    plt.figure(figsize=(10, 6))
    
    # Plot for each disease
    for d in range(data_prev.shape[0]):
        plt.plot(data_prev[d], 'b-', alpha=0.3, label='Data' if d==0 else '')
        plt.plot(model_prev[d, :].detach().numpy(), 'r--', alpha=0.3, 
                label='Model' if d==0 else '')
    
    plt.xlabel('Time')
    plt.ylabel('Prevalence')
    plt.title('Smoothed Prevalences: Data vs Model')
    plt.legend()
    plt.yscale('log')  # Optional: use log scale if prevalences vary widely
    plt.grid(True)
    plt.show()

plot_smoothed_prevalences(model, data)

# %%
# Mean predicted probability for disease 3 over time
mean_pred_d3 = pi_pred[:, 3, :].mean(axis=0)  # Average across people

# Actual prevalence for disease 3 over time
real_prev_pi = data['pi'][:, 3, :].mean(axis=0)  # Average across people

#real_prev_d3 = data['Y'][:, 3, :].mean(axis=0)  # Average across people

real_prev_d3 = model.prevalence_t[3,:]  # Average across people

# Plot comparison
plt.figure(figsize=(10,6))
plt.plot(mean_pred_d3, label='Model Predicted average pi for disease 3')
plt.plot(real_prev_pi, label='Actual Average Pi for disease 3 ')
plt.plot(real_prev_d3, label='Actual Incidence for disease 3')
plt.title('Disease 3: Predicted vs Actual Prevalence')
plt.legend()
plt.show()

# %%
# Mean predicted probability for disease 3 over time
mean_pred_d3 = pi_pred[1, 3, :]  # Average across people

# Actual prevalence for disease 3 over time
real_prev_pi = data['pi'][1, 3, :]  # Average across people

#real_prev_d3 = data['Y'][:, 3, :].mean(axis=0)  # Average across people

#real_prev_d3 = model.prevalence_t[3,:]  # Average across people

# Plot comparison
plt.figure(figsize=(10,6))
plt.plot(mean_pred_d3, label='Model Predicted person 1 pi for disease 3')
plt.plot(real_prev_pi, label='Actual person 1  for disease 3 ')
#plt.plot(real_prev_d3, label='Actual Incidence for disease 3')
plt.title('Disease 3: Predicted vs Actual Prevalence')
plt.legend()
plt.show()

# %%
# Average over all diseases and all individuals
mean_pred_all = pi_pred.mean(axis=(0,1))  # Average across people and diseases
real_incidence_all = model.prevalence_t.mean(axis=0)  # Average across diseases
real_pi_all = data['pi'].mean(axis=(0,1)) # Average across diseases

plt.figure(figsize=(10,6))
plt.plot(mean_pred_all, 'b-', label='Model Predicted')
plt.plot(real_incidence_all, 'r-', label='Actual Prevalence') 
plt.plot(real_pi_all, 'g-', label='Simulated pi') 


plt.title('Average Disease Prevalence: Predicted vs Actual')
plt.xlabel('Time')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %%
plot_best_matches(data['pi'], model.forward()[0],n_samples=6)

# %%
# Calculate prevalence_t from synthetic data
prevalence_t = compute_smoothed_prevalence(Y_tensor)  # Average over individuals

# Initialize model with synthetic data
model_est = AladynSurvivalFixedKernelsAvgLoss_clust(
    N=data['Y'].shape[0], 
    D=data['Y'].shape[1], 
    T=data['Y'].shape[2], 
    K=data['phi'].shape[0],  # number of clusters
    P=data['G'].shape[1],    # number of genetic features
    G=G_tensor,
    Y=Y_tensor,              # Added Y_tensor
    prevalence_t=prevalence_t
)

# Initialize with true psi


model_est.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 45214952.00
# Phi kernel condition number: 104912536.00
#
# Cluster Sizes:
# Cluster 0: 3 diseases
# Cluster 1: 8 diseases
# Cluster 2: 4 diseases
# Cluster 3: 3 diseases
# Cluster 4: 2 diseases
# Initialization complete!

# %%
history = model_est.fit(E_tensor, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g.py:278: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 290.4394
# Psi gradient stats:
# Mean: -5.9831e-03
# Std:  8.9669e-02
# Max:  1.8442e-01
# Min:  -2.6258e-01
# Average psi change: 9.9921e-05
# Epoch 0, Loss: 290.4394, Gradients - Lambda: 5.107e-01, Phi: 1.936e+02, Gamma: 3.312e-02, Psi: 2.626e-01
#
# Epoch 1
# Loss: 226.5218
# Psi gradient stats:
# Mean: -5.8570e-03
# Std:  8.9540e-02
# Max:  1.8490e-01
# Min:  -2.6246e-01
# Average psi change: 9.9389e-05
# Epoch 1, Loss: 226.5218, Gradients - Lambda: 4.510e-01, Phi: 1.787e+02, Gamma: 3.263e-02, Psi: 2.625e-01
#
# Estimated total training time: 268.9 minutes
#
# Epoch 2
# Loss: 180.8995
# Psi gradient stats:
# Mean: -5.7330e-03
# Std:  8.9427e-02
# Max:  1.8411e-01
# Min:  -2.6229e-01
# Average psi change: 9.8624e-05
# Epoch 2, Loss: 180.8995, Gradients - Lambda: 3.934e-01, Phi: 1.659e+02, Gamma: 3.200e-02, Psi: 2.623e-01
#
# Epoch 3
# Loss: 149.6907
# Psi gradient stats:
# Mean: -5.6219e-03
# Std:  8.9291e-02
# Max:  1.8313e-01
# Min:  -2.6217e-01
# Average psi change: 9.7601e-05
# Epoch 3, Loss: 149.6907, Gradients - Lambda: 3.559e-01, Phi: 1.533e+02, Gamma: 3.144e-02, Psi: 2.622e-01
#
# Epoch 4
# Loss: 128.9671
# Psi gradient stats:
# Mean: -5.5439e-03
# Std:  8.9115e-02
# Max:  1.8222e-01
# Min:  -2.6212e-01
# Average psi change: 9.6633e-05
# Epoch 4, Loss: 128.9671, Gradients - Lambda: 3.310e-01, Phi: 1.406e+02, Gamma: 3.086e-02, Psi: 2.621e-01
#
# Epoch 5
# Loss: 115.5578
# Psi gradient stats:
# Mean: -5.4748e-03
# Std:  8.8905e-02
# Max:  1.8143e-01
# Min:  -2.6225e-01
# Average psi change: 9.6012e-05
# Epoch 5, Loss: 115.5578, Gradients - Lambda: 3.061e-01, Phi: 1.277e+02, Gamma: 3.028e-02, Psi: 2.622e-01
#
# Epoch 6
# Loss: 107.1600
# Psi gradient stats:
# Mean: -5.4073e-03
# Std:  8.8658e-02
# Max:  1.8085e-01
# Min:  -2.6251e-01
# Average psi change: 9.6194e-05
# Epoch 6, Loss: 107.1600, Gradients - Lambda: 2.820e-01, Phi: 1.144e+02, Gamma: 2.972e-02, Psi: 2.625e-01
#
# Epoch 7
# Loss: 102.0650
# Psi gradient stats:
# Mean: -5.3318e-03
# Std:  8.8371e-02
# Max:  1.8048e-01
# Min:  -2.6284e-01
# Average psi change: 9.6806e-05
# Epoch 7, Loss: 102.0650, Gradients - Lambda: 2.587e-01, Phi: 1.006e+02, Gamma: 2.920e-02, Psi: 2.628e-01
#
# Epoch 8
# Loss: 98.9811
# Psi gradient stats:
# Mean: -5.2454e-03
# Std:  8.8045e-02
# Max:  1.8016e-01
# Min:  -2.6327e-01
# Average psi change: 9.7317e-05
# Epoch 8, Loss: 98.9811, Gradients - Lambda: 2.358e-01, Phi: 8.662e+01, Gamma: 2.879e-02, Psi: 2.633e-01
#
# Epoch 9
# Loss: 97.0148
# Psi gradient stats:
# Mean: -5.1590e-03
# Std:  8.7678e-02
# Max:  1.7975e-01
# Min:  -2.6377e-01
# Average psi change: 9.7530e-05
# Epoch 9, Loss: 97.0148, Gradients - Lambda: 2.131e-01, Phi: 7.520e+01, Gamma: 2.851e-02, Psi: 2.638e-01
#
# Epoch 10
# Loss: 95.6265
# Psi gradient stats:
# Mean: -5.0932e-03
# Std:  8.7275e-02
# Max:  1.7909e-01
# Min:  -2.6432e-01
# Average psi change: 9.7544e-05
# Epoch 10, Loss: 95.6265, Gradients - Lambda: 1.932e-01, Phi: 6.431e+01, Gamma: 2.833e-02, Psi: 2.643e-01
#
# Epoch 11
# Loss: 94.5036
# Psi gradient stats:
# Mean: -5.0588e-03
# Std:  8.6842e-02
# Max:  1.7817e-01
# Min:  -2.6486e-01
# Average psi change: 9.7437e-05
#
# Epoch 12
# Loss: 93.4731
# Psi gradient stats:
# Mean: -5.0599e-03
# Std:  8.6399e-02
# Max:  1.7713e-01
# Min:  -2.6534e-01
# Average psi change: 9.7253e-05
#
# Epoch 13
# Loss: 92.4597
# Psi gradient stats:
# Mean: -5.0875e-03
# Std:  8.5956e-02
# Max:  1.7608e-01
# Min:  -2.6574e-01
# Average psi change: 9.6946e-05
#
# Epoch 14
# Loss: 91.4533
# Psi gradient stats:
# Mean: -5.1304e-03
# Std:  8.5517e-02
# Max:  1.7515e-01
# Min:  -2.6602e-01
# Average psi change: 9.6546e-05
#
# Epoch 15
# Loss: 90.4772
# Psi gradient stats:
# Mean: -5.1757e-03
# Std:  8.5095e-02
# Max:  1.7441e-01
# Min:  -2.6617e-01
# Average psi change: 9.5987e-05
#
# Epoch 16
# Loss: 89.5562
# Psi gradient stats:
# Mean: -5.2126e-03
# Std:  8.4702e-02
# Max:  1.7385e-01
# Min:  -2.6624e-01
# Average psi change: 9.5781e-05
#
# Epoch 17
# Loss: 88.7106
# Psi gradient stats:
# Mean: -5.2389e-03
# Std:  8.4350e-02
# Max:  1.7339e-01
# Min:  -2.6622e-01
# Average psi change: 9.6042e-05
#
# Epoch 18
# Loss: 87.9621
# Psi gradient stats:
# Mean: -5.2508e-03
# Std:  8.4052e-02
# Max:  1.7296e-01
# Min:  -2.6609e-01
# Average psi change: 9.6187e-05
#
# Epoch 19
# Loss: 87.3217
# Psi gradient stats:
# Mean: -5.2535e-03
# Std:  8.3804e-02
# Max:  1.7249e-01
# Min:  -2.6588e-01
# Average psi change: 9.6421e-05
#
# Epoch 20
# Loss: 86.7818
# Psi gradient stats:
# Mean: -5.2498e-03
# Std:  8.3597e-02
# Max:  1.7188e-01
# Min:  -2.6558e-01
# Average psi change: 9.6579e-05
# Epoch 20, Loss: 86.7818, Gradients - Lambda: 6.638e-02, Phi: 2.206e+01, Gamma: 2.479e-02, Psi: 2.656e-01
#
# Epoch 21
# Loss: 86.3240
# Psi gradient stats:
# Mean: -5.2442e-03
# Std:  8.3419e-02
# Max:  1.7117e-01
# Min:  -2.6521e-01
# Average psi change: 9.6766e-05
#
# Epoch 22
# Loss: 85.9358
# Psi gradient stats:
# Mean: -5.2367e-03
# Std:  8.3270e-02
# Max:  1.7038e-01
# Min:  -2.6481e-01
# Average psi change: 9.7035e-05
#
# Epoch 23
# Loss: 85.6033
# Psi gradient stats:
# Mean: -5.2253e-03
# Std:  8.3148e-02
# Max:  1.6956e-01
# Min:  -2.6442e-01
# Average psi change: 9.7407e-05
#
# Epoch 24
# Loss: 85.3096
# Psi gradient stats:
# Mean: -5.2057e-03
# Std:  8.3048e-02
# Max:  1.6878e-01
# Min:  -2.6407e-01
# Average psi change: 9.7793e-05
#
# Epoch 25
# Loss: 85.0453
# Psi gradient stats:
# Mean: -5.1807e-03
# Std:  8.2960e-02
# Max:  1.6809e-01
# Min:  -2.6376e-01
# Average psi change: 9.8114e-05
#
# Epoch 26
# Loss: 84.8102
# Psi gradient stats:
# Mean: -5.1539e-03
# Std:  8.2879e-02
# Max:  1.6772e-01
# Min:  -2.6348e-01
# Average psi change: 9.8351e-05
#
# Epoch 27
# Loss: 84.5973
# Psi gradient stats:
# Mean: -5.1375e-03
# Std:  8.2807e-02
# Max:  1.6761e-01
# Min:  -2.6320e-01
# Average psi change: 9.8503e-05
#
# Epoch 28
# Loss: 84.3991
# Psi gradient stats:
# Mean: -5.1431e-03
# Std:  8.2746e-02
# Max:  1.6753e-01
# Min:  -2.6296e-01
# Average psi change: 9.8588e-05
#
# Epoch 29
# Loss: 84.2157
# Psi gradient stats:
# Mean: -5.1706e-03
# Std:  8.2695e-02
# Max:  1.6756e-01
# Min:  -2.6278e-01
# Average psi change: 9.8615e-05
#
# Epoch 30
# Loss: 84.0462
# Psi gradient stats:
# Mean: -5.2148e-03
# Std:  8.2652e-02
# Max:  1.6766e-01
# Min:  -2.6269e-01
# Average psi change: 9.8581e-05
# Epoch 30, Loss: 84.0462, Gradients - Lambda: 3.212e-02, Phi: 1.274e+01, Gamma: 1.848e-02, Psi: 2.627e-01
#
# Epoch 31
# Loss: 83.8893
# Psi gradient stats:
# Mean: -5.2653e-03
# Std:  8.2617e-02
# Max:  1.6770e-01
# Min:  -2.6267e-01
# Average psi change: 9.8516e-05
#
# Epoch 32
# Loss: 83.7432
# Psi gradient stats:
# Mean: -5.3131e-03
# Std:  8.2595e-02
# Max:  1.6760e-01
# Min:  -2.6270e-01
# Average psi change: 9.8435e-05
#
# Epoch 33
# Loss: 83.6063
# Psi gradient stats:
# Mean: -5.3555e-03
# Std:  8.2586e-02
# Max:  1.6733e-01
# Min:  -2.6274e-01
# Average psi change: 9.8366e-05
#
# Epoch 34
# Loss: 83.4771
# Psi gradient stats:
# Mean: -5.3859e-03
# Std:  8.2587e-02
# Max:  1.6698e-01
# Min:  -2.6278e-01
# Average psi change: 9.8282e-05
#
# Epoch 35
# Loss: 83.3566
# Psi gradient stats:
# Mean: -5.4065e-03
# Std:  8.2592e-02
# Max:  1.6667e-01
# Min:  -2.6286e-01
# Average psi change: 9.8200e-05
#
# Epoch 36
# Loss: 83.2436
# Psi gradient stats:
# Mean: -5.4184e-03
# Std:  8.2591e-02
# Max:  1.6651e-01
# Min:  -2.6302e-01
# Average psi change: 9.8125e-05
#
# Epoch 37
# Loss: 83.1343
# Psi gradient stats:
# Mean: -5.4264e-03
# Std:  8.2592e-02
# Max:  1.6652e-01
# Min:  -2.6321e-01
# Average psi change: 9.8026e-05
#
# Epoch 38
# Loss: 83.0293
# Psi gradient stats:
# Mean: -5.4282e-03
# Std:  8.2600e-02
# Max:  1.6664e-01
# Min:  -2.6338e-01
# Average psi change: 9.7911e-05
#
# Epoch 39
# Loss: 82.9314
# Psi gradient stats:
# Mean: -5.4237e-03
# Std:  8.2608e-02
# Max:  1.6676e-01
# Min:  -2.6342e-01
# Average psi change: 9.7797e-05
#
# Epoch 40
# Loss: 82.8368
# Psi gradient stats:
# Mean: -5.4093e-03
# Std:  8.2607e-02
# Max:  1.6685e-01
# Min:  -2.6335e-01
# Average psi change: 9.7660e-05
# Epoch 40, Loss: 82.8368, Gradients - Lambda: 2.795e-02, Phi: 7.433e+00, Gamma: 1.380e-02, Psi: 2.633e-01
#
# Epoch 41
# Loss: 82.7457
# Psi gradient stats:
# Mean: -5.3879e-03
# Std:  8.2590e-02
# Max:  1.6692e-01
# Min:  -2.6324e-01
# Average psi change: 9.7520e-05
#
# Epoch 42
# Loss: 82.6605
# Psi gradient stats:
# Mean: -5.3716e-03
# Std:  8.2567e-02
# Max:  1.6692e-01
# Min:  -2.6320e-01
# Average psi change: 9.7409e-05
#
# Epoch 43
# Loss: 82.5782
# Psi gradient stats:
# Mean: -5.3653e-03
# Std:  8.2547e-02
# Max:  1.6685e-01
# Min:  -2.6324e-01
# Average psi change: 9.7314e-05
#
# Epoch 44
# Loss: 82.4980
# Psi gradient stats:
# Mean: -5.3658e-03
# Std:  8.2533e-02
# Max:  1.6674e-01
# Min:  -2.6326e-01
# Average psi change: 9.7218e-05
#
# Epoch 45
# Loss: 82.4213
# Psi gradient stats:
# Mean: -5.3620e-03
# Std:  8.2522e-02
# Max:  1.6663e-01
# Min:  -2.6319e-01
# Average psi change: 9.7151e-05
#
# Epoch 46
# Loss: 82.3475
# Psi gradient stats:
# Mean: -5.3491e-03
# Std:  8.2507e-02
# Max:  1.6657e-01
# Min:  -2.6300e-01
# Average psi change: 9.7081e-05
#
# Epoch 47
# Loss: 82.2751
# Psi gradient stats:
# Mean: -5.3296e-03
# Std:  8.2485e-02
# Max:  1.6658e-01
# Min:  -2.6281e-01
# Average psi change: 9.7003e-05
#
# Epoch 48
# Loss: 82.2048
# Psi gradient stats:
# Mean: -5.3168e-03
# Std:  8.2458e-02
# Max:  1.6663e-01
# Min:  -2.6273e-01
# Average psi change: 9.6956e-05
#
# Epoch 49
# Loss: 82.1374
# Psi gradient stats:
# Mean: -5.3118e-03
# Std:  8.2419e-02
# Max:  1.6661e-01
# Min:  -2.6279e-01
# Average psi change: 9.6892e-05
#
# Epoch 50
# Loss: 82.0718
# Psi gradient stats:
# Mean: -5.3098e-03
# Std:  8.2373e-02
# Max:  1.6644e-01
# Min:  -2.6288e-01
# Average psi change: 9.6835e-05
# Epoch 50, Loss: 82.0718, Gradients - Lambda: 2.973e-02, Phi: 6.662e+00, Gamma: 9.792e-03, Psi: 2.629e-01
#
# Epoch 51
# Loss: 82.0075
# Psi gradient stats:
# Mean: -5.3040e-03
# Std:  8.2327e-02
# Max:  1.6616e-01
# Min:  -2.6287e-01
# Average psi change: 9.6756e-05
#
# Epoch 52
# Loss: 81.9454
# Psi gradient stats:
# Mean: -5.2931e-03
# Std:  8.2286e-02
# Max:  1.6591e-01
# Min:  -2.6273e-01
# Average psi change: 9.6712e-05
#
# Epoch 53
# Loss: 81.8854
# Psi gradient stats:
# Mean: -5.2794e-03
# Std:  8.2252e-02
# Max:  1.6582e-01
# Min:  -2.6255e-01
# Average psi change: 9.6658e-05
#
# Epoch 54
# Loss: 81.8258
# Psi gradient stats:
# Mean: -5.2688e-03
# Std:  8.2215e-02
# Max:  1.6587e-01
# Min:  -2.6246e-01
# Average psi change: 9.6598e-05
#
# Epoch 55
# Loss: 81.7669
# Psi gradient stats:
# Mean: -5.2643e-03
# Std:  8.2170e-02
# Max:  1.6599e-01
# Min:  -2.6247e-01
# Average psi change: 9.6564e-05
#
# Epoch 56
# Loss: 81.7126
# Psi gradient stats:
# Mean: -5.2636e-03
# Std:  8.2120e-02
# Max:  1.6598e-01
# Min:  -2.6247e-01
# Average psi change: 9.6523e-05
#
# Epoch 57
# Loss: 81.6572
# Psi gradient stats:
# Mean: -5.2608e-03
# Std:  8.2077e-02
# Max:  1.6583e-01
# Min:  -2.6236e-01
# Average psi change: 9.6505e-05
#
# Epoch 58
# Loss: 81.6003
# Psi gradient stats:
# Mean: -5.2515e-03
# Std:  8.2045e-02
# Max:  1.6565e-01
# Min:  -2.6221e-01
# Average psi change: 9.6466e-05
#
# Epoch 59
# Loss: 81.5512
# Psi gradient stats:
# Mean: -5.2384e-03
# Std:  8.2020e-02
# Max:  1.6557e-01
# Min:  -2.6212e-01
# Average psi change: 9.6456e-05
#
# Epoch 60
# Loss: 81.5000
# Psi gradient stats:
# Mean: -5.2251e-03
# Std:  8.1990e-02
# Max:  1.6562e-01
# Min:  -2.6219e-01
# Average psi change: 9.6436e-05
# Epoch 60, Loss: 81.5000, Gradients - Lambda: 3.460e-02, Phi: 9.034e+00, Gamma: 6.619e-03, Psi: 2.622e-01
#
# Epoch 61
# Loss: 81.4448
# Psi gradient stats:
# Mean: -5.2202e-03
# Std:  8.1949e-02
# Max:  1.6571e-01
# Min:  -2.6229e-01
# Average psi change: 9.6426e-05
#
# Epoch 62
# Loss: 81.3991
# Psi gradient stats:
# Mean: -5.2269e-03
# Std:  8.1902e-02
# Max:  1.6571e-01
# Min:  -2.6225e-01
# Average psi change: 9.6415e-05
#
# Epoch 63
# Loss: 81.3525
# Psi gradient stats:
# Mean: -5.2384e-03
# Std:  8.1865e-02
# Max:  1.6554e-01
# Min:  -2.6205e-01
# Average psi change: 9.6410e-05
#
# Epoch 64
# Loss: 81.2993
# Psi gradient stats:
# Mean: -5.2393e-03
# Std:  8.1843e-02
# Max:  1.6530e-01
# Min:  -2.6187e-01
# Average psi change: 9.6402e-05
#
# Epoch 65
# Loss: 81.2558
# Psi gradient stats:
# Mean: -5.2268e-03
# Std:  8.1829e-02
# Max:  1.6517e-01
# Min:  -2.6186e-01
# Average psi change: 9.6408e-05
#
# Epoch 66
# Loss: 81.2138
# Psi gradient stats:
# Mean: -5.2016e-03
# Std:  8.1803e-02
# Max:  1.6521e-01
# Min:  -2.6202e-01
# Average psi change: 9.6414e-05
#
# Epoch 67
# Loss: 81.1621
# Psi gradient stats:
# Mean: -5.1845e-03
# Std:  8.1755e-02
# Max:  1.6531e-01
# Min:  -2.6212e-01
# Average psi change: 9.6393e-05
#
# Epoch 68
# Loss: 81.1199
# Psi gradient stats:
# Mean: -5.1848e-03
# Std:  8.1695e-02
# Max:  1.6531e-01
# Min:  -2.6199e-01
# Average psi change: 9.6371e-05
#
# Epoch 69
# Loss: 81.0833
# Psi gradient stats:
# Mean: -5.2014e-03
# Std:  8.1647e-02
# Max:  1.6513e-01
# Min:  -2.6171e-01
# Average psi change: 9.6363e-05
#
# Epoch 70
# Loss: 81.0327
# Psi gradient stats:
# Mean: -5.2149e-03
# Std:  8.1622e-02
# Max:  1.6487e-01
# Min:  -2.6155e-01
# Average psi change: 9.6340e-05
# Epoch 70, Loss: 81.0327, Gradients - Lambda: 3.902e-02, Phi: 8.677e+00, Gamma: 4.251e-03, Psi: 2.616e-01
#
# Epoch 71
# Loss: 80.9915
# Psi gradient stats:
# Mean: -5.2110e-03
# Std:  8.1613e-02
# Max:  1.6475e-01
# Min:  -2.6165e-01
# Average psi change: 9.6327e-05
#
# Epoch 72
# Loss: 80.9602
# Psi gradient stats:
# Mean: -5.1868e-03
# Std:  8.1594e-02
# Max:  1.6484e-01
# Min:  -2.6186e-01
# Average psi change: 9.6298e-05
#
# Epoch 73
# Loss: 80.9109
# Psi gradient stats:
# Mean: -5.1599e-03
# Std:  8.1551e-02
# Max:  1.6505e-01
# Min:  -2.6193e-01
# Average psi change: 9.6275e-05
#
# Epoch 74
# Loss: 80.8696
# Psi gradient stats:
# Mean: -5.1499e-03
# Std:  8.1490e-02
# Max:  1.6513e-01
# Min:  -2.6172e-01
# Average psi change: 9.6281e-05
#
# Epoch 75
# Loss: 80.8433
# Psi gradient stats:
# Mean: -5.1628e-03
# Std:  8.1438e-02
# Max:  1.6493e-01
# Min:  -2.6138e-01
# Average psi change: 9.6245e-05
#
# Epoch 76
# Loss: 80.7957
# Psi gradient stats:
# Mean: -5.1830e-03
# Std:  8.1413e-02
# Max:  1.6454e-01
# Min:  -2.6126e-01
# Average psi change: 9.6216e-05
#
# Epoch 77
# Loss: 80.7552
# Psi gradient stats:
# Mean: -5.1868e-03
# Std:  8.1404e-02
# Max:  1.6425e-01
# Min:  -2.6139e-01
# Average psi change: 9.6195e-05
#
# Epoch 78
# Loss: 80.7324
# Psi gradient stats:
# Mean: -5.1660e-03
# Std:  8.1387e-02
# Max:  1.6428e-01
# Min:  -2.6158e-01
# Average psi change: 9.6170e-05
#
# Epoch 79
# Loss: 80.6866
# Psi gradient stats:
# Mean: -5.1316e-03
# Std:  8.1343e-02
# Max:  1.6455e-01
# Min:  -2.6158e-01
# Average psi change: 9.6158e-05
#
# Epoch 80
# Loss: 80.6481
# Psi gradient stats:
# Mean: -5.1121e-03
# Std:  8.1281e-02
# Max:  1.6477e-01
# Min:  -2.6133e-01
# Average psi change: 9.6141e-05
# Epoch 80, Loss: 80.6481, Gradients - Lambda: 4.298e-02, Phi: 7.643e+00, Gamma: 2.359e-03, Psi: 2.613e-01
#
# Epoch 81
# Loss: 80.6277
# Psi gradient stats:
# Mean: -5.1188e-03
# Std:  8.1224e-02
# Max:  1.6464e-01
# Min:  -2.6107e-01
# Average psi change: 9.6126e-05
#
# Epoch 82
# Loss: 80.5819
# Psi gradient stats:
# Mean: -5.1443e-03
# Std:  8.1193e-02
# Max:  1.6420e-01
# Min:  -2.6105e-01
# Average psi change: 9.6087e-05
#
# Epoch 83
# Loss: 80.5478
# Psi gradient stats:
# Mean: -5.1580e-03
# Std:  8.1178e-02
# Max:  1.6372e-01
# Min:  -2.6121e-01
# Average psi change: 9.6062e-05
#
# Epoch 84
# Loss: 80.5297
# Psi gradient stats:
# Mean: -5.1419e-03
# Std:  8.1160e-02
# Max:  1.6358e-01
# Min:  -2.6131e-01
# Average psi change: 9.6048e-05
#
# Epoch 85
# Loss: 80.4816
# Psi gradient stats:
# Mean: -5.1057e-03
# Std:  8.1120e-02
# Max:  1.6385e-01
# Min:  -2.6115e-01
# Average psi change: 9.6029e-05
#
# Epoch 86
# Loss: 80.4530
# Psi gradient stats:
# Mean: -5.0759e-03
# Std:  8.1067e-02
# Max:  1.6427e-01
# Min:  -2.6085e-01
# Average psi change: 9.6018e-05
#
# Epoch 87
# Loss: 80.4387
# Psi gradient stats:
# Mean: -5.0753e-03
# Std:  8.1023e-02
# Max:  1.6441e-01
# Min:  -2.6072e-01
# Average psi change: 9.5994e-05
#
# Epoch 88
# Loss: 80.3869
# Psi gradient stats:
# Mean: -5.0988e-03
# Std:  8.0993e-02
# Max:  1.6407e-01
# Min:  -2.6087e-01
# Average psi change: 9.5970e-05
#
# Epoch 89
# Loss: 80.3628
# Psi gradient stats:
# Mean: -5.1189e-03
# Std:  8.0968e-02
# Max:  1.6348e-01
# Min:  -2.6111e-01
# Average psi change: 9.5941e-05
#
# Epoch 90
# Loss: 80.3528
# Psi gradient stats:
# Mean: -5.1129e-03
# Std:  8.0933e-02
# Max:  1.6309e-01
# Min:  -2.6110e-01
# Average psi change: 9.5900e-05
# Epoch 90, Loss: 80.3528, Gradients - Lambda: 4.646e-02, Phi: 1.165e+01, Gamma: 1.194e-03, Psi: 2.611e-01
#
# Epoch 91
# Loss: 80.2985
# Psi gradient stats:
# Mean: -5.0802e-03
# Std:  8.0885e-02
# Max:  1.6318e-01
# Min:  -2.6076e-01
# Average psi change: 9.5886e-05
#
# Epoch 92
# Loss: 80.2769
# Psi gradient stats:
# Mean: -5.0497e-03
# Std:  8.0841e-02
# Max:  1.6360e-01
# Min:  -2.6038e-01
# Average psi change: 9.5869e-05
#
# Epoch 93
# Loss: 80.2712
# Psi gradient stats:
# Mean: -5.0431e-03
# Std:  8.0812e-02
# Max:  1.6394e-01
# Min:  -2.6034e-01
# Average psi change: 9.5862e-05
#
# Epoch 94
# Loss: 80.2163
# Psi gradient stats:
# Mean: -5.0616e-03
# Std:  8.0793e-02
# Max:  1.6386e-01
# Min:  -2.6065e-01
# Average psi change: 9.5828e-05
#
# Epoch 95
# Loss: 80.1952
# Psi gradient stats:
# Mean: -5.0829e-03
# Std:  8.0765e-02
# Max:  1.6337e-01
# Min:  -2.6098e-01
# Average psi change: 9.5780e-05
#
# Epoch 96
# Loss: 80.1936
# Psi gradient stats:
# Mean: -5.0833e-03
# Std:  8.0716e-02
# Max:  1.6284e-01
# Min:  -2.6094e-01
# Average psi change: 9.5738e-05
#
# Epoch 97
# Loss: 80.1399
# Psi gradient stats:
# Mean: -5.0610e-03
# Std:  8.0655e-02
# Max:  1.6265e-01
# Min:  -2.6049e-01
# Average psi change: 9.5735e-05
#
# Epoch 98
# Loss: 80.1182
# Psi gradient stats:
# Mean: -5.0325e-03
# Std:  8.0609e-02
# Max:  1.6292e-01
# Min:  -2.6001e-01
# Average psi change: 9.5721e-05
#
# Epoch 99
# Loss: 80.1199
# Psi gradient stats:
# Mean: -5.0192e-03
# Std:  8.0590e-02
# Max:  1.6336e-01
# Min:  -2.5993e-01
# Average psi change: 9.5705e-05
#
# Epoch 100
# Loss: 80.0686
# Psi gradient stats:
# Mean: -5.0250e-03
# Std:  8.0583e-02
# Max:  1.6354e-01
# Min:  -2.6029e-01
# Average psi change: 9.5667e-05
# Epoch 100, Loss: 80.0686, Gradients - Lambda: 4.588e-02, Phi: 1.210e+01, Gamma: 6.950e-04, Psi: 2.603e-01
#
# Epoch 101
# Loss: 80.0450
# Psi gradient stats:
# Mean: -5.0379e-03
# Std:  8.0559e-02
# Max:  1.6326e-01
# Min:  -2.6071e-01
# Average psi change: 9.5611e-05
#
# Epoch 102
# Loss: 80.0499
# Psi gradient stats:
# Mean: -5.0408e-03
# Std:  8.0504e-02
# Max:  1.6271e-01
# Min:  -2.6076e-01
# Average psi change: 9.5568e-05
#
# Epoch 103
# Loss: 80.0016
# Psi gradient stats:
# Mean: -5.0298e-03
# Std:  8.0435e-02
# Max:  1.6228e-01
# Min:  -2.6034e-01
# Average psi change: 9.5563e-05
#
# Epoch 104
# Loss: 79.9759
# Psi gradient stats:
# Mean: -5.0108e-03
# Std:  8.0382e-02
# Max:  1.6226e-01
# Min:  -2.5981e-01
# Average psi change: 9.5569e-05
#
# Epoch 105
# Loss: 79.9838
# Psi gradient stats:
# Mean: -4.9962e-03
# Std:  8.0362e-02
# Max:  1.6258e-01
# Min:  -2.5964e-01
# Average psi change: 9.5562e-05
#
# Epoch 106
# Loss: 79.9390
# Psi gradient stats:
# Mean: -4.9915e-03
# Std:  8.0359e-02
# Max:  1.6290e-01
# Min:  -2.5991e-01
# Average psi change: 9.5512e-05
#
# Epoch 107
# Loss: 79.9108
# Psi gradient stats:
# Mean: -4.9921e-03
# Std:  8.0342e-02
# Max:  1.6290e-01
# Min:  -2.6032e-01
# Average psi change: 9.5441e-05
#
# Epoch 108
# Loss: 79.9202
# Psi gradient stats:
# Mean: -4.9947e-03
# Std:  8.0294e-02
# Max:  1.6255e-01
# Min:  -2.6046e-01
# Average psi change: 9.5393e-05
#
# Epoch 109
# Loss: 79.8794
# Psi gradient stats:
# Mean: -4.9929e-03
# Std:  8.0224e-02
# Max:  1.6210e-01
# Min:  -2.6017e-01
# Average psi change: 9.5380e-05
#
# Epoch 110
# Loss: 79.8494
# Psi gradient stats:
# Mean: -4.9877e-03
# Std:  8.0165e-02
# Max:  1.6188e-01
# Min:  -2.5968e-01
# Average psi change: 9.5369e-05
# Epoch 110, Loss: 79.8494, Gradients - Lambda: 4.645e-02, Phi: 1.355e+01, Gamma: 7.942e-04, Psi: 2.597e-01
#
# Epoch 111
# Loss: 79.8602
# Psi gradient stats:
# Mean: -4.9782e-03
# Std:  8.0140e-02
# Max:  1.6200e-01
# Min:  -2.5941e-01
# Average psi change: 9.5380e-05
#
# Epoch 112
# Loss: 79.8230
# Psi gradient stats:
# Mean: -4.9643e-03
# Std:  8.0137e-02
# Max:  1.6228e-01
# Min:  -2.5954e-01
# Average psi change: 9.5356e-05
#
# Epoch 113
# Loss: 79.7911
# Psi gradient stats:
# Mean: -4.9545e-03
# Std:  8.0128e-02
# Max:  1.6240e-01
# Min:  -2.5989e-01
# Average psi change: 9.5288e-05
#
# Epoch 114
# Loss: 79.8023
# Psi gradient stats:
# Mean: -4.9505e-03
# Std:  8.0084e-02
# Max:  1.6222e-01
# Min:  -2.6009e-01
# Average psi change: 9.5232e-05
#
# Epoch 115
# Loss: 79.7688
# Psi gradient stats:
# Mean: -4.9557e-03
# Std:  8.0013e-02
# Max:  1.6186e-01
# Min:  -2.5993e-01
# Average psi change: 9.5204e-05
#
# Epoch 116
# Loss: 79.7351
# Psi gradient stats:
# Mean: -4.9645e-03
# Std:  7.9945e-02
# Max:  1.6158e-01
# Min:  -2.5951e-01
# Average psi change: 9.5198e-05
#
# Epoch 117
# Loss: 79.7471
# Psi gradient stats:
# Mean: -4.9613e-03
# Std:  7.9910e-02
# Max:  1.6154e-01
# Min:  -2.5917e-01
# Average psi change: 9.5195e-05
#
# Epoch 118
# Loss: 79.7177
# Psi gradient stats:
# Mean: -4.9448e-03
# Std:  7.9907e-02
# Max:  1.6172e-01
# Min:  -2.5916e-01
# Average psi change: 9.5181e-05
#
# Epoch 119
# Loss: 79.6808
# Psi gradient stats:
# Mean: -4.9221e-03
# Std:  7.9907e-02
# Max:  1.6183e-01
# Min:  -2.5944e-01
# Average psi change: 9.5128e-05
#
# Epoch 120
# Loss: 79.6940
# Psi gradient stats:
# Mean: -4.9095e-03
# Std:  7.9877e-02
# Max:  1.6171e-01
# Min:  -2.5970e-01
# Average psi change: 9.5073e-05
# Epoch 120, Loss: 79.6940, Gradients - Lambda: 5.226e-02, Phi: 1.329e+01, Gamma: 7.582e-04, Psi: 2.597e-01
#
# Epoch 121
# Loss: 79.6696
# Psi gradient stats:
# Mean: -4.9148e-03
# Std:  7.9812e-02
# Max:  1.6139e-01
# Min:  -2.5970e-01
# Average psi change: 9.5020e-05
#
# Epoch 122
# Loss: 79.6271
# Psi gradient stats:
# Mean: -4.9308e-03
# Std:  7.9736e-02
# Max:  1.6112e-01
# Min:  -2.5941e-01
# Average psi change: 9.5004e-05
#
# Epoch 123
# Loss: 79.6415
# Psi gradient stats:
# Mean: -4.9375e-03
# Std:  7.9685e-02
# Max:  1.6109e-01
# Min:  -2.5904e-01
# Average psi change: 9.5007e-05
#
# Epoch 124
# Loss: 79.6242
# Psi gradient stats:
# Mean: -4.9252e-03
# Std:  7.9672e-02
# Max:  1.6128e-01
# Min:  -2.5884e-01
# Average psi change: 9.4984e-05
#
# Epoch 125
# Loss: 79.5760
# Psi gradient stats:
# Mean: -4.8997e-03
# Std:  7.9677e-02
# Max:  1.6148e-01
# Min:  -2.5895e-01
# Average psi change: 9.4944e-05
#
# Epoch 126
# Loss: 79.5886
# Psi gradient stats:
# Mean: -4.8787e-03
# Std:  7.9664e-02
# Max:  1.6144e-01
# Min:  -2.5921e-01
# Average psi change: 9.4892e-05
#
# Epoch 127
# Loss: 79.5800
# Psi gradient stats:
# Mean: -4.8728e-03
# Std:  7.9617e-02
# Max:  1.6113e-01
# Min:  -2.5935e-01
# Average psi change: 9.4839e-05
#
# Epoch 128
# Loss: 79.5271
# Psi gradient stats:
# Mean: -4.8857e-03
# Std:  7.9545e-02
# Max:  1.6075e-01
# Min:  -2.5923e-01
# Average psi change: 9.4813e-05
#
# Epoch 129
# Loss: 79.5358
# Psi gradient stats:
# Mean: -4.8997e-03
# Std:  7.9478e-02
# Max:  1.6057e-01
# Min:  -2.5890e-01
# Average psi change: 9.4799e-05
#
# Epoch 130
# Loss: 79.5364
# Psi gradient stats:
# Mean: -4.9023e-03
# Std:  7.9440e-02
# Max:  1.6070e-01
# Min:  -2.5864e-01
# Average psi change: 9.4789e-05
# Epoch 130, Loss: 79.5364, Gradients - Lambda: 5.084e-02, Phi: 1.344e+01, Gamma: 8.383e-04, Psi: 2.586e-01
#
# Converged at epoch 130. Loss change: 0.0006

# %%
plot_best_matches(data['pi'], model_est.forward()[0],n_samples=6)

# %%
def verify_marginal_probabilities(Y, pi_pred, age_start=10, age_window=10):
    """
    Compare predicted marginal probabilities with observed rates
    """
    N, D, T = Y.shape
    verification = []
    
    for d in range(D):
        # Get people at risk
        at_risk = ~np.any(Y[:, d, :age_start], axis=1)
        n_at_risk = np.sum(at_risk)
        
        if n_at_risk >= 100:  # Minimum sample size
            # Predicted probability
            yearly_pi = pi_pred[at_risk, d, age_start:age_start+age_window]
            pred_risk = 1 - np.prod(1 - yearly_pi, axis=1).mean()
            
            # Observed probability
            observed = np.any(Y[at_risk, d, age_start:age_start+age_window], axis=1).mean()
            
            verification.append({
                #'disease': disease_name_list[d],
                'predicted_risk': pred_risk,
                'observed_risk': observed,
                'ratio_pred_obs': pred_risk/observed if observed > 0 else np.nan,
                'n_at_risk': n_at_risk,
                'n_events': np.sum(np.any(Y[at_risk, d, age_start:age_start+age_window], axis=1))
            })
    
    verify_df = pd.DataFrame(verification)
    
    # Sort by absolute difference between predicted and observed
    verify_df['abs_diff'] = np.abs(verify_df.predicted_risk - verify_df.observed_risk)
    verify_df = verify_df.sort_values('abs_diff', ascending=False)
    
    print("\nTop 10 largest discrepancies between predicted and observed risks:")
    print(verify_df.head(10)[['predicted_risk', 'observed_risk', 'ratio_pred_obs', 'n_events', 'n_at_risk']])
    
    print("\nSummary statistics of prediction/observation ratios:")
    print(verify_df.ratio_pred_obs.describe())
    
    # Plot predicted vs observed
    plt.figure(figsize=(10, 10))
    plt.scatter(verify_df.observed_risk, verify_df.predicted_risk, alpha=0.5)
    plt.plot([0, max(verify_df.observed_risk.max(), verify_df.predicted_risk.max())], 
             [0, max(verify_df.observed_risk.max(), verify_df.predicted_risk.max())], 
             'r--')
    plt.xlabel('Observed Risk')
    plt.ylabel('Predicted Risk')
    plt.title('Predicted vs Observed Marginal Risks')
    plt.show()
    
    return verify_df
data['Y'].shape
with torch.no_grad():  
    pi_pred =model_est.forward()[0].cpu().numpy()
# Run verification
verify_df = verify_marginal_probabilities(Y=data['Y'],pi_pred=pi_pred)
# Out:
# Top 10 largest discrepancies between predicted and observed risks:
#     predicted_risk  observed_risk  ratio_pred_obs  n_events  n_at_risk
# 7         0.097953       0.627039        0.156216      5190       8277
# 10        0.057590       0.164323        0.350466      1636       9956
# 16        0.008129       0.072438        0.112225       723       9981
# 15        0.000842       0.007201        0.116959        72       9998
# 13        0.001173       0.007111        0.164966        71       9985
# 2         0.000980       0.004000        0.244921        40       9999
# 17        0.000919       0.002500        0.367689        25      10000
# 14        0.000030       0.000900        0.032981         9      10000
# 8         0.000008       0.000500        0.015259         5      10000
# 1         0.000003       0.000400        0.006557         4      10000
#
# Summary statistics of prediction/observation ratios:
# count    14.000000
# mean      0.119915
# std       0.125224
# min       0.005960
# 25%       0.010520
# 50%       0.100071
# 75%       0.162779
# max       0.367689
# Name: ratio_pred_obs, dtype: float64

# %%
model.psi
# Out:
# Parameter containing:
# tensor([[ 1.0406,  0.9608,  0.9595,  0.9605, -2.9613, -3.0083, -2.9598, -2.9622,
#          -2.9598, -2.9596, -3.0337, -2.9622, -3.0370, -3.0344, -2.9635, -3.0433,
#          -2.9614, -2.9582, -2.9593, -3.0270],
#         [-3.0394, -2.9629, -3.0348, -2.9607,  1.0368,  0.9624,  0.9591,  1.0374,
#          -2.9639, -2.9584, -2.9593, -2.9575, -3.0382, -3.0350, -2.9568, -2.9633,
#          -2.9608, -3.0398, -3.0395, -3.0365],
#         [-2.9794, -3.0411, -3.0286, -3.0141, -3.0259, -2.9592, -2.9591, -3.0373,
#           1.0396,  1.0397,  1.0400,  1.0381, -3.0430, -3.0334, -3.0395, -3.0412,
#          -3.0426, -3.0307, -3.0395, -2.9590],
#         [-3.0395, -3.0393, -3.0418, -2.9635, -3.0389, -3.0425, -2.9619, -3.0359,
#          -3.0298, -3.0408, -2.9779, -2.9586,  1.0390,  1.0416,  1.0404,  1.0288,
#          -3.0374, -2.9593, -3.0043, -3.0398],
#         [-2.9699, -2.9592, -3.0268, -3.0436, -3.0117, -2.9630, -2.9579, -3.0397,
#          -3.0425, -2.9595, -3.0415, -2.9596, -3.0397, -2.9626, -2.9590, -3.0296,
#           1.0194,  1.0354,  1.0402,  1.0420]], requires_grad=True)

# %%
from cluster_g_logit_init import *
# Calculate prevalence_t from synthetic data
prevalence_t = compute_smoothed_prevalence(data['Y'])  # Average over individuals

# Initialize model with synthetic data
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit(
    N=data['Y'].shape[0], 
    D=data['Y'].shape[1], 
    T=data['Y'].shape[2], 
    K=data['phi'].shape[0],  # number of clusters
    P=data['G'].shape[1],    # number of genetic features
    G=G_tensor,
    Y=Y_tensor,              # Added Y_tensor
    prevalence_t=prevalence_t
)

# Initialize with true psi
#model.initialize_params(true_psi=true_psi)


model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 45214952.00
# Phi kernel condition number: 104912536.00
#
# Cluster Sizes:
# Cluster 0: 3 diseases
# Cluster 1: 8 diseases
# Cluster 2: 4 diseases
# Cluster 3: 3 diseases
# Cluster 4: 2 diseases
# Initialization complete!

# %%
history = model.fit(E_tensor, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init.py:289: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# Epoch 0
# Loss: 288.1469
# Psi gradient stats:
# Mean: 2.2599e-04
# Std:  9.4874e-02
# Max:  1.6939e-01
# Min:  -2.4428e-01
# Average psi change: 9.9921e-05
# Epoch 0, Loss: 288.1469, Gradients - Lambda: 5.128e-01, Phi: 1.962e+02, Gamma: 3.999e-02, Psi: 2.443e-01
#
# Epoch 1
# Loss: 224.1898
# Psi gradient stats:
# Mean: 1.1910e-04
# Std:  9.4740e-02
# Max:  1.7001e-01
# Min:  -2.4502e-01
# Average psi change: 9.8457e-05
# Epoch 1, Loss: 224.1898, Gradients - Lambda: 4.468e-01, Phi: 1.701e+02, Gamma: 3.964e-02, Psi: 2.450e-01
#
# Estimated total training time: 276.4 minutes
#
# Epoch 2
# Loss: 178.5336
# Psi gradient stats:
# Mean: 8.6280e-05
# Std:  9.4566e-02
# Max:  1.6985e-01
# Min:  -2.4446e-01
# Average psi change: 9.8127e-05
# Epoch 2, Loss: 178.5336, Gradients - Lambda: 4.263e-01, Phi: 1.461e+02, Gamma: 3.925e-02, Psi: 2.445e-01
#
# Epoch 3
# Loss: 147.3645
# Psi gradient stats:
# Mean: 1.2820e-04
# Std:  9.4320e-02
# Max:  1.6980e-01
# Min:  -2.4336e-01
# Average psi change: 9.7992e-05
# Epoch 3, Loss: 147.3645, Gradients - Lambda: 4.061e-01, Phi: 1.263e+02, Gamma: 3.862e-02, Psi: 2.434e-01
#
# Epoch 4
# Loss: 126.7958
# Psi gradient stats:
# Mean: 1.9975e-04
# Std:  9.4031e-02
# Max:  1.7006e-01
# Min:  -2.4212e-01
# Average psi change: 9.8398e-05
# Epoch 4, Loss: 126.7958, Gradients - Lambda: 3.848e-01, Phi: 1.123e+02, Gamma: 3.772e-02, Psi: 2.421e-01
#
# Epoch 5
# Loss: 113.6115
# Psi gradient stats:
# Mean: 2.6032e-04
# Std:  9.3708e-02
# Max:  1.7024e-01
# Min:  -2.4082e-01
# Average psi change: 9.8240e-05
# Epoch 5, Loss: 113.6115, Gradients - Lambda: 3.629e-01, Phi: 1.011e+02, Gamma: 3.661e-02, Psi: 2.408e-01
#
# Epoch 6
# Loss: 105.4120
# Psi gradient stats:
# Mean: 2.9730e-04
# Std:  9.3361e-02
# Max:  1.7015e-01
# Min:  -2.3951e-01
# Average psi change: 9.7625e-05
# Epoch 6, Loss: 105.4120, Gradients - Lambda: 3.407e-01, Phi: 8.921e+01, Gamma: 3.542e-02, Psi: 2.395e-01
#
# Epoch 7
# Loss: 100.4460
# Psi gradient stats:
# Mean: 2.9682e-04
# Std:  9.2987e-02
# Max:  1.6966e-01
# Min:  -2.3817e-01
# Average psi change: 9.7284e-05
# Epoch 7, Loss: 100.4460, Gradients - Lambda: 3.180e-01, Phi: 7.666e+01, Gamma: 3.423e-02, Psi: 2.382e-01
#
# Epoch 8
# Loss: 97.4350
# Psi gradient stats:
# Mean: 2.7230e-04
# Std:  9.2587e-02
# Max:  1.6889e-01
# Min:  -2.3680e-01
# Average psi change: 9.7592e-05
# Epoch 8, Loss: 97.4350, Gradients - Lambda: 2.943e-01, Phi: 6.358e+01, Gamma: 3.313e-02, Psi: 2.368e-01
#
# Epoch 9
# Loss: 95.4972
# Psi gradient stats:
# Mean: 2.4016e-04
# Std:  9.2167e-02
# Max:  1.6860e-01
# Min:  -2.3542e-01
# Average psi change: 9.7703e-05
# Epoch 9, Loss: 95.4972, Gradients - Lambda: 2.696e-01, Phi: 5.070e+01, Gamma: 3.214e-02, Psi: 2.354e-01
#
# Epoch 10
# Loss: 94.1117
# Psi gradient stats:
# Mean: 2.0621e-04
# Std:  9.1742e-02
# Max:  1.6812e-01
# Min:  -2.3406e-01
# Average psi change: 9.7573e-05
# Epoch 10, Loss: 94.1117, Gradients - Lambda: 2.443e-01, Phi: 3.849e+01, Gamma: 3.126e-02, Psi: 2.341e-01
#
# Epoch 11
# Loss: 92.9954
# Psi gradient stats:
# Mean: 1.7647e-04
# Std:  9.1325e-02
# Max:  1.6747e-01
# Min:  -2.3277e-01
# Average psi change: 9.7252e-05
#
# Epoch 12
# Loss: 91.9901
# Psi gradient stats:
# Mean: 1.4801e-04
# Std:  9.0919e-02
# Max:  1.6653e-01
# Min:  -2.3147e-01
# Average psi change: 9.6766e-05
#
# Epoch 13
# Loss: 91.0096
# Psi gradient stats:
# Mean: 1.1926e-04
# Std:  9.0534e-02
# Max:  1.6541e-01
# Min:  -2.3021e-01
# Average psi change: 9.6161e-05
#
# Epoch 14
# Loss: 90.0324
# Psi gradient stats:
# Mean: 8.9209e-05
# Std:  9.0177e-02
# Max:  1.6416e-01
# Min:  -2.2901e-01
# Average psi change: 9.5431e-05
#
# Epoch 15
# Loss: 89.0759
# Psi gradient stats:
# Mean: 5.6733e-05
# Std:  8.9850e-02
# Max:  1.6418e-01
# Min:  -2.2793e-01
# Average psi change: 9.4952e-05
#
# Epoch 16
# Loss: 88.1717
# Psi gradient stats:
# Mean: 2.4736e-05
# Std:  8.9562e-02
# Max:  1.6431e-01
# Min:  -2.2706e-01
# Average psi change: 9.4717e-05
#
# Epoch 17
# Loss: 87.3405
# Psi gradient stats:
# Mean: -2.8634e-06
# Std:  8.9310e-02
# Max:  1.6449e-01
# Min:  -2.2683e-01
# Average psi change: 9.4568e-05
#
# Epoch 18
# Loss: 86.5937
# Psi gradient stats:
# Mean: -2.6668e-05
# Std:  8.9092e-02
# Max:  1.6495e-01
# Min:  -2.2861e-01
# Average psi change: 9.4467e-05
#
# Epoch 19
# Loss: 85.9435
# Psi gradient stats:
# Mean: -4.7760e-05
# Std:  8.8898e-02
# Max:  1.6519e-01
# Min:  -2.3032e-01
# Average psi change: 9.4274e-05
#
# Epoch 20
# Loss: 85.3892
# Psi gradient stats:
# Mean: -6.2981e-05
# Std:  8.8723e-02
# Max:  1.6523e-01
# Min:  -2.3190e-01
# Average psi change: 9.4031e-05
# Epoch 20, Loss: 85.3892, Gradients - Lambda: 6.915e-02, Phi: 2.496e+01, Gamma: 2.797e-02, Psi: 2.319e-01
#
# Epoch 21
# Loss: 84.9221
# Psi gradient stats:
# Mean: -7.4301e-05
# Std:  8.8573e-02
# Max:  1.6516e-01
# Min:  -2.3339e-01
# Average psi change: 9.3715e-05
#
# Epoch 22
# Loss: 84.5264
# Psi gradient stats:
# Mean: -8.3806e-05
# Std:  8.8452e-02
# Max:  1.6512e-01
# Min:  -2.3473e-01
# Average psi change: 9.3438e-05
#
# Epoch 23
# Loss: 84.1886
# Psi gradient stats:
# Mean: -9.2809e-05
# Std:  8.8369e-02
# Max:  1.6532e-01
# Min:  -2.3588e-01
# Average psi change: 9.3356e-05
#
# Epoch 24
# Loss: 83.9006
# Psi gradient stats:
# Mean: -9.8449e-05
# Std:  8.8318e-02
# Max:  1.6552e-01
# Min:  -2.3681e-01
# Average psi change: 9.3271e-05
#
# Epoch 25
# Loss: 83.6507
# Psi gradient stats:
# Mean: -1.0133e-04
# Std:  8.8286e-02
# Max:  1.6568e-01
# Min:  -2.3749e-01
# Average psi change: 9.3153e-05
#
# Epoch 26
# Loss: 83.4251
# Psi gradient stats:
# Mean: -1.0088e-04
# Std:  8.8264e-02
# Max:  1.6579e-01
# Min:  -2.3800e-01
# Average psi change: 9.3057e-05
#
# Epoch 27
# Loss: 83.2187
# Psi gradient stats:
# Mean: -1.0371e-04
# Std:  8.8244e-02
# Max:  1.6584e-01
# Min:  -2.3843e-01
# Average psi change: 9.2958e-05
#
# Epoch 28
# Loss: 83.0303
# Psi gradient stats:
# Mean: -1.1573e-04
# Std:  8.8219e-02
# Max:  1.6581e-01
# Min:  -2.3874e-01
# Average psi change: 9.2874e-05
#
# Epoch 29
# Loss: 82.8537
# Psi gradient stats:
# Mean: -1.4305e-04
# Std:  8.8195e-02
# Max:  1.6576e-01
# Min:  -2.3885e-01
# Average psi change: 9.2768e-05
#
# Epoch 30
# Loss: 82.6858
# Psi gradient stats:
# Mean: -1.7957e-04
# Std:  8.8168e-02
# Max:  1.6570e-01
# Min:  -2.3869e-01
# Average psi change: 9.2697e-05
# Epoch 30, Loss: 82.6858, Gradients - Lambda: 3.199e-02, Phi: 9.717e+00, Gamma: 2.201e-02, Psi: 2.387e-01
#
# Epoch 31
# Loss: 82.5293
# Psi gradient stats:
# Mean: -2.1063e-04
# Std:  8.8139e-02
# Max:  1.6565e-01
# Min:  -2.3836e-01
# Average psi change: 9.2646e-05
#
# Epoch 32
# Loss: 82.3834
# Psi gradient stats:
# Mean: -2.2559e-04
# Std:  8.8102e-02
# Max:  1.6557e-01
# Min:  -2.3796e-01
# Average psi change: 9.2592e-05
#
# Epoch 33
# Loss: 82.2471
# Psi gradient stats:
# Mean: -2.2037e-04
# Std:  8.8061e-02
# Max:  1.6545e-01
# Min:  -2.3765e-01
# Average psi change: 9.2555e-05
#
# Epoch 34
# Loss: 82.1210
# Psi gradient stats:
# Mean: -2.0398e-04
# Std:  8.8024e-02
# Max:  1.6528e-01
# Min:  -2.3740e-01
# Average psi change: 9.2513e-05
#
# Epoch 35
# Loss: 82.0030
# Psi gradient stats:
# Mean: -1.8758e-04
# Std:  8.7994e-02
# Max:  1.6514e-01
# Min:  -2.3711e-01
# Average psi change: 9.2461e-05
#
# Epoch 36
# Loss: 81.8884
# Psi gradient stats:
# Mean: -1.7664e-04
# Std:  8.7977e-02
# Max:  1.6508e-01
# Min:  -2.3673e-01
# Average psi change: 9.2406e-05
#
# Epoch 37
# Loss: 81.7811
# Psi gradient stats:
# Mean: -1.6575e-04
# Std:  8.7971e-02
# Max:  1.6511e-01
# Min:  -2.3628e-01
# Average psi change: 9.2360e-05
#
# Epoch 38
# Loss: 81.6813
# Psi gradient stats:
# Mean: -1.4989e-04
# Std:  8.7967e-02
# Max:  1.6516e-01
# Min:  -2.3587e-01
# Average psi change: 9.2314e-05
#
# Epoch 39
# Loss: 81.5844
# Psi gradient stats:
# Mean: -1.3282e-04
# Std:  8.7957e-02
# Max:  1.6516e-01
# Min:  -2.3555e-01
# Average psi change: 9.2284e-05
#
# Epoch 40
# Loss: 81.4914
# Psi gradient stats:
# Mean: -1.2009e-04
# Std:  8.7935e-02
# Max:  1.6501e-01
# Min:  -2.3533e-01
# Average psi change: 9.2254e-05
# Epoch 40, Loss: 81.4914, Gradients - Lambda: 2.561e-02, Phi: 6.270e+00, Gamma: 1.570e-02, Psi: 2.353e-01
#
# Epoch 41
# Loss: 81.4031
# Psi gradient stats:
# Mean: -1.1685e-04
# Std:  8.7906e-02
# Max:  1.6476e-01
# Min:  -2.3515e-01
# Average psi change: 9.2258e-05
#
# Epoch 42
# Loss: 81.3180
# Psi gradient stats:
# Mean: -1.2216e-04
# Std:  8.7877e-02
# Max:  1.6448e-01
# Min:  -2.3495e-01
# Average psi change: 9.2239e-05
#
# Epoch 43
# Loss: 81.2358
# Psi gradient stats:
# Mean: -1.2929e-04
# Std:  8.7852e-02
# Max:  1.6432e-01
# Min:  -2.3475e-01
# Average psi change: 9.2243e-05
#
# Epoch 44
# Loss: 81.1567
# Psi gradient stats:
# Mean: -1.3135e-04
# Std:  8.7832e-02
# Max:  1.6431e-01
# Min:  -2.3460e-01
# Average psi change: 9.2227e-05
#
# Epoch 45
# Loss: 81.0799
# Psi gradient stats:
# Mean: -1.2697e-04
# Std:  8.7811e-02
# Max:  1.6438e-01
# Min:  -2.3453e-01
# Average psi change: 9.2231e-05
#
# Epoch 46
# Loss: 81.0061
# Psi gradient stats:
# Mean: -1.2000e-04
# Std:  8.7790e-02
# Max:  1.6442e-01
# Min:  -2.3456e-01
# Average psi change: 9.2244e-05
#
# Epoch 47
# Loss: 80.9351
# Psi gradient stats:
# Mean: -1.1940e-04
# Std:  8.7766e-02
# Max:  1.6438e-01
# Min:  -2.3465e-01
# Average psi change: 9.2236e-05
#
# Epoch 48
# Loss: 80.8656
# Psi gradient stats:
# Mean: -1.2922e-04
# Std:  8.7743e-02
# Max:  1.6424e-01
# Min:  -2.3473e-01
# Average psi change: 9.2233e-05
#
# Epoch 49
# Loss: 80.7982
# Psi gradient stats:
# Mean: -1.4317e-04
# Std:  8.7722e-02
# Max:  1.6411e-01
# Min:  -2.3474e-01
# Average psi change: 9.2231e-05
#
# Epoch 50
# Loss: 80.7323
# Psi gradient stats:
# Mean: -1.5669e-04
# Std:  8.7699e-02
# Max:  1.6400e-01
# Min:  -2.3468e-01
# Average psi change: 9.2238e-05
# Epoch 50, Loss: 80.7323, Gradients - Lambda: 3.149e-02, Phi: 6.333e+00, Gamma: 1.183e-02, Psi: 2.347e-01
#
# Epoch 51
# Loss: 80.6682
# Psi gradient stats:
# Mean: -1.6377e-04
# Std:  8.7671e-02
# Max:  1.6390e-01
# Min:  -2.3456e-01
# Average psi change: 9.2248e-05
#
# Epoch 52
# Loss: 80.6067
# Psi gradient stats:
# Mean: -1.6432e-04
# Std:  8.7638e-02
# Max:  1.6378e-01
# Min:  -2.3447e-01
# Average psi change: 9.2248e-05
#
# Epoch 53
# Loss: 80.5446
# Psi gradient stats:
# Mean: -1.6245e-04
# Std:  8.7599e-02
# Max:  1.6364e-01
# Min:  -2.3444e-01
# Average psi change: 9.2248e-05
#
# Epoch 54
# Loss: 80.4853
# Psi gradient stats:
# Mean: -1.6137e-04
# Std:  8.7567e-02
# Max:  1.6354e-01
# Min:  -2.3452e-01
# Average psi change: 9.2233e-05
#
# Epoch 55
# Loss: 80.4292
# Psi gradient stats:
# Mean: -1.6131e-04
# Std:  8.7547e-02
# Max:  1.6352e-01
# Min:  -2.3464e-01
# Average psi change: 9.2239e-05
#
# Epoch 56
# Loss: 80.3698
# Psi gradient stats:
# Mean: -1.6563e-04
# Std:  8.7533e-02
# Max:  1.6352e-01
# Min:  -2.3476e-01
# Average psi change: 9.2250e-05
#
# Epoch 57
# Loss: 80.3146
# Psi gradient stats:
# Mean: -1.7551e-04
# Std:  8.7519e-02
# Max:  1.6347e-01
# Min:  -2.3480e-01
# Average psi change: 9.2275e-05
#
# Epoch 58
# Loss: 80.2638
# Psi gradient stats:
# Mean: -1.9232e-04
# Std:  8.7493e-02
# Max:  1.6326e-01
# Min:  -2.3477e-01
# Average psi change: 9.2297e-05
#
# Epoch 59
# Loss: 80.2062
# Psi gradient stats:
# Mean: -2.0819e-04
# Std:  8.7453e-02
# Max:  1.6304e-01
# Min:  -2.3471e-01
# Average psi change: 9.2300e-05
#
# Epoch 60
# Loss: 80.1541
# Psi gradient stats:
# Mean: -2.1964e-04
# Std:  8.7410e-02
# Max:  1.6294e-01
# Min:  -2.3468e-01
# Average psi change: 9.2283e-05
# Epoch 60, Loss: 80.1541, Gradients - Lambda: 3.463e-02, Phi: 6.566e+00, Gamma: 8.527e-03, Psi: 2.347e-01
#
# Epoch 61
# Loss: 80.1083
# Psi gradient stats:
# Mean: -2.2091e-04
# Std:  8.7376e-02
# Max:  1.6300e-01
# Min:  -2.3473e-01
# Average psi change: 9.2282e-05
#
# Epoch 62
# Loss: 80.0523
# Psi gradient stats:
# Mean: -2.1590e-04
# Std:  8.7355e-02
# Max:  1.6309e-01
# Min:  -2.3483e-01
# Average psi change: 9.2281e-05
#
# Epoch 63
# Loss: 80.0031
# Psi gradient stats:
# Mean: -2.1338e-04
# Std:  8.7339e-02
# Max:  1.6303e-01
# Min:  -2.3490e-01
# Average psi change: 9.2315e-05
#
# Epoch 64
# Loss: 79.9611
# Psi gradient stats:
# Mean: -2.2140e-04
# Std:  8.7316e-02
# Max:  1.6282e-01
# Min:  -2.3491e-01
# Average psi change: 9.2334e-05
#
# Epoch 65
# Loss: 79.9067
# Psi gradient stats:
# Mean: -2.3870e-04
# Std:  8.7279e-02
# Max:  1.6258e-01
# Min:  -2.3487e-01
# Average psi change: 9.2343e-05
#
# Epoch 66
# Loss: 79.8612
# Psi gradient stats:
# Mean: -2.5511e-04
# Std:  8.7239e-02
# Max:  1.6252e-01
# Min:  -2.3483e-01
# Average psi change: 9.2337e-05
#
# Epoch 67
# Loss: 79.8215
# Psi gradient stats:
# Mean: -2.6123e-04
# Std:  8.7203e-02
# Max:  1.6262e-01
# Min:  -2.3482e-01
# Average psi change: 9.2328e-05
#
# Epoch 68
# Loss: 79.7690
# Psi gradient stats:
# Mean: -2.5603e-04
# Std:  8.7175e-02
# Max:  1.6272e-01
# Min:  -2.3485e-01
# Average psi change: 9.2338e-05
#
# Epoch 69
# Loss: 79.7271
# Psi gradient stats:
# Mean: -2.4916e-04
# Std:  8.7153e-02
# Max:  1.6259e-01
# Min:  -2.3488e-01
# Average psi change: 9.2324e-05
#
# Epoch 70
# Loss: 79.6898
# Psi gradient stats:
# Mean: -2.5435e-04
# Std:  8.7128e-02
# Max:  1.6236e-01
# Min:  -2.3489e-01
# Average psi change: 9.2346e-05
# Epoch 70, Loss: 79.6898, Gradients - Lambda: 4.079e-02, Phi: 1.037e+01, Gamma: 6.095e-03, Psi: 2.349e-01
#
# Epoch 71
# Loss: 79.6383
# Psi gradient stats:
# Mean: -2.7035e-04
# Std:  8.7097e-02
# Max:  1.6218e-01
# Min:  -2.3487e-01
# Average psi change: 9.2378e-05
#
# Epoch 72
# Loss: 79.5996
# Psi gradient stats:
# Mean: -2.8696e-04
# Std:  8.7063e-02
# Max:  1.6211e-01
# Min:  -2.3484e-01
# Average psi change: 9.2375e-05
#
# Epoch 73
# Loss: 79.5652
# Psi gradient stats:
# Mean: -2.9140e-04
# Std:  8.7030e-02
# Max:  1.6221e-01
# Min:  -2.3485e-01
# Average psi change: 9.2371e-05
#
# Epoch 74
# Loss: 79.5144
# Psi gradient stats:
# Mean: -2.8442e-04
# Std:  8.7000e-02
# Max:  1.6218e-01
# Min:  -2.3487e-01
# Average psi change: 9.2347e-05
#
# Epoch 75
# Loss: 79.4774
# Psi gradient stats:
# Mean: -2.7699e-04
# Std:  8.6972e-02
# Max:  1.6217e-01
# Min:  -2.3487e-01
# Average psi change: 9.2344e-05
#
# Epoch 76
# Loss: 79.4481
# Psi gradient stats:
# Mean: -2.8140e-04
# Std:  8.6944e-02
# Max:  1.6215e-01
# Min:  -2.3482e-01
# Average psi change: 9.2355e-05
#
# Epoch 77
# Loss: 79.3983
# Psi gradient stats:
# Mean: -2.9650e-04
# Std:  8.6919e-02
# Max:  1.6196e-01
# Min:  -2.3475e-01
# Average psi change: 9.2357e-05
#
# Epoch 78
# Loss: 79.3606
# Psi gradient stats:
# Mean: -3.0866e-04
# Std:  8.6895e-02
# Max:  1.6178e-01
# Min:  -2.3469e-01
# Average psi change: 9.2359e-05
#
# Epoch 79
# Loss: 79.3364
# Psi gradient stats:
# Mean: -3.1053e-04
# Std:  8.6868e-02
# Max:  1.6189e-01
# Min:  -2.3470e-01
# Average psi change: 9.2353e-05
#
# Epoch 80
# Loss: 79.2891
# Psi gradient stats:
# Mean: -3.0422e-04
# Std:  8.6833e-02
# Max:  1.6191e-01
# Min:  -2.3476e-01
# Average psi change: 9.2334e-05
# Epoch 80, Loss: 79.2891, Gradients - Lambda: 3.983e-02, Phi: 8.267e+00, Gamma: 4.241e-03, Psi: 2.348e-01
#
# Epoch 81
# Loss: 79.2500
# Psi gradient stats:
# Mean: -3.0207e-04
# Std:  8.6796e-02
# Max:  1.6200e-01
# Min:  -2.3483e-01
# Average psi change: 9.2328e-05
#
# Epoch 82
# Loss: 79.2296
# Psi gradient stats:
# Mean: -3.1289e-04
# Std:  8.6760e-02
# Max:  1.6191e-01
# Min:  -2.3483e-01
# Average psi change: 9.2326e-05
#
# Epoch 83
# Loss: 79.1859
# Psi gradient stats:
# Mean: -3.3171e-04
# Std:  8.6736e-02
# Max:  1.6168e-01
# Min:  -2.3476e-01
# Average psi change: 9.2309e-05
#
# Epoch 84
# Loss: 79.1466
# Psi gradient stats:
# Mean: -3.4531e-04
# Std:  8.6719e-02
# Max:  1.6150e-01
# Min:  -2.3468e-01
# Average psi change: 9.2319e-05
#
# Epoch 85
# Loss: 79.1278
# Psi gradient stats:
# Mean: -3.4540e-04
# Std:  8.6702e-02
# Max:  1.6156e-01
# Min:  -2.3465e-01
# Average psi change: 9.2304e-05
#
# Epoch 86
# Loss: 79.0874
# Psi gradient stats:
# Mean: -3.3756e-04
# Std:  8.6670e-02
# Max:  1.6173e-01
# Min:  -2.3470e-01
# Average psi change: 9.2302e-05
#
# Epoch 87
# Loss: 79.0505
# Psi gradient stats:
# Mean: -3.3720e-04
# Std:  8.6625e-02
# Max:  1.6179e-01
# Min:  -2.3479e-01
# Average psi change: 9.2289e-05
#
# Epoch 88
# Loss: 79.0317
# Psi gradient stats:
# Mean: -3.4939e-04
# Std:  8.6577e-02
# Max:  1.6160e-01
# Min:  -2.3485e-01
# Average psi change: 9.2287e-05
#
# Epoch 89
# Loss: 78.9925
# Psi gradient stats:
# Mean: -3.6758e-04
# Std:  8.6543e-02
# Max:  1.6132e-01
# Min:  -2.3483e-01
# Average psi change: 9.2271e-05
#
# Epoch 90
# Loss: 78.9608
# Psi gradient stats:
# Mean: -3.8018e-04
# Std:  8.6527e-02
# Max:  1.6120e-01
# Min:  -2.3475e-01
# Average psi change: 9.2258e-05
# Epoch 90, Loss: 78.9608, Gradients - Lambda: 4.465e-02, Phi: 1.125e+01, Gamma: 3.637e-03, Psi: 2.348e-01
#
# Epoch 91
# Loss: 78.9420
# Psi gradient stats:
# Mean: -3.7784e-04
# Std:  8.6521e-02
# Max:  1.6138e-01
# Min:  -2.3469e-01
# Average psi change: 9.2246e-05
#
# Epoch 92
# Loss: 78.9017
# Psi gradient stats:
# Mean: -3.7257e-04
# Std:  8.6503e-02
# Max:  1.6163e-01
# Min:  -2.3469e-01
# Average psi change: 9.2249e-05
#
# Epoch 93
# Loss: 78.8753
# Psi gradient stats:
# Mean: -3.7223e-04
# Std:  8.6462e-02
# Max:  1.6166e-01
# Min:  -2.3475e-01
# Average psi change: 9.2223e-05
#
# Epoch 94
# Loss: 78.8585
# Psi gradient stats:
# Mean: -3.8461e-04
# Std:  8.6407e-02
# Max:  1.6139e-01
# Min:  -2.3481e-01
# Average psi change: 9.2224e-05
#
# Epoch 95
# Loss: 78.8160
# Psi gradient stats:
# Mean: -4.0132e-04
# Std:  8.6362e-02
# Max:  1.6102e-01
# Min:  -2.3481e-01
# Average psi change: 9.2208e-05
#
# Epoch 96
# Loss: 78.7933
# Psi gradient stats:
# Mean: -4.1139e-04
# Std:  8.6339e-02
# Max:  1.6091e-01
# Min:  -2.3477e-01
# Average psi change: 9.2186e-05
#
# Epoch 97
# Loss: 78.7807
# Psi gradient stats:
# Mean: -4.1520e-04
# Std:  8.6338e-02
# Max:  1.6114e-01
# Min:  -2.3475e-01
# Average psi change: 9.2180e-05
#
# Epoch 98
# Loss: 78.7372
# Psi gradient stats:
# Mean: -4.1365e-04
# Std:  8.6330e-02
# Max:  1.6146e-01
# Min:  -2.3476e-01
# Average psi change: 9.2166e-05
#
# Epoch 99
# Loss: 78.7135
# Psi gradient stats:
# Mean: -4.1471e-04
# Std:  8.6294e-02
# Max:  1.6149e-01
# Min:  -2.3479e-01
# Average psi change: 9.2140e-05
#
# Epoch 100
# Loss: 78.7067
# Psi gradient stats:
# Mean: -4.2061e-04
# Std:  8.6237e-02
# Max:  1.6116e-01
# Min:  -2.3480e-01
# Average psi change: 9.2131e-05
# Epoch 100, Loss: 78.7067, Gradients - Lambda: 4.789e-02, Phi: 1.676e+01, Gamma: 3.614e-03, Psi: 2.348e-01
#
# Epoch 101
# Loss: 78.6655
# Psi gradient stats:
# Mean: -4.3111e-04
# Std:  8.6185e-02
# Max:  1.6073e-01
# Min:  -2.3479e-01
# Average psi change: 9.2129e-05
#
# Epoch 102
# Loss: 78.6370
# Psi gradient stats:
# Mean: -4.4018e-04
# Std:  8.6157e-02
# Max:  1.6062e-01
# Min:  -2.3475e-01
# Average psi change: 9.2125e-05
#
# Epoch 103
# Loss: 78.6344
# Psi gradient stats:
# Mean: -4.4754e-04
# Std:  8.6151e-02
# Max:  1.6089e-01
# Min:  -2.3474e-01
# Average psi change: 9.2103e-05
#
# Epoch 104
# Loss: 78.6009
# Psi gradient stats:
# Mean: -4.5320e-04
# Std:  8.6145e-02
# Max:  1.6128e-01
# Min:  -2.3478e-01
# Average psi change: 9.2079e-05
#
# Epoch 105
# Loss: 78.5653
# Psi gradient stats:
# Mean: -4.5560e-04
# Std:  8.6117e-02
# Max:  1.6136e-01
# Min:  -2.3486e-01
# Average psi change: 9.2062e-05
#
# Epoch 106
# Loss: 78.5627
# Psi gradient stats:
# Mean: -4.5715e-04
# Std:  8.6065e-02
# Max:  1.6102e-01
# Min:  -2.3489e-01
# Average psi change: 9.2021e-05
#
# Epoch 107
# Loss: 78.5410
# Psi gradient stats:
# Mean: -4.6101e-04
# Std:  8.6013e-02
# Max:  1.6054e-01
# Min:  -2.3481e-01
# Average psi change: 9.2017e-05
#
# Epoch 108
# Loss: 78.5011
# Psi gradient stats:
# Mean: -4.7165e-04
# Std:  8.5981e-02
# Max:  1.6035e-01
# Min:  -2.3470e-01
# Average psi change: 9.2011e-05
#
# Epoch 109
# Loss: 78.4932
# Psi gradient stats:
# Mean: -4.8270e-04
# Std:  8.5973e-02
# Max:  1.6059e-01
# Min:  -2.3469e-01
# Average psi change: 9.2012e-05
#
# Epoch 110
# Loss: 78.4820
# Psi gradient stats:
# Mean: -4.9160e-04
# Std:  8.5966e-02
# Max:  1.6100e-01
# Min:  -2.3478e-01
# Average psi change: 9.1988e-05
# Epoch 110, Loss: 78.4820, Gradients - Lambda: 4.884e-02, Phi: 1.309e+01, Gamma: 3.687e-03, Psi: 2.348e-01
#
# Epoch 111
# Loss: 78.4435
# Psi gradient stats:
# Mean: -4.9306e-04
# Std:  8.5942e-02
# Max:  1.6116e-01
# Min:  -2.3491e-01
# Average psi change: 9.1947e-05
#
# Epoch 112
# Loss: 78.4280
# Psi gradient stats:
# Mean: -4.9110e-04
# Std:  8.5898e-02
# Max:  1.6089e-01
# Min:  -2.3496e-01
# Average psi change: 9.1916e-05
#
# Epoch 113
# Loss: 78.4224
# Psi gradient stats:
# Mean: -4.9302e-04
# Std:  8.5847e-02
# Max:  1.6041e-01
# Min:  -2.3487e-01
# Average psi change: 9.1893e-05
#
# Epoch 114
# Loss: 78.3905
# Psi gradient stats:
# Mean: -4.9935e-04
# Std:  8.5813e-02
# Max:  1.6012e-01
# Min:  -2.3471e-01
# Average psi change: 9.1879e-05
#
# Epoch 115
# Loss: 78.3693
# Psi gradient stats:
# Mean: -5.1222e-04
# Std:  8.5794e-02
# Max:  1.6025e-01
# Min:  -2.3464e-01
# Average psi change: 9.1892e-05
#
# Epoch 116
# Loss: 78.3624
# Psi gradient stats:
# Mean: -5.2181e-04
# Std:  8.5781e-02
# Max:  1.6065e-01
# Min:  -2.3473e-01
# Average psi change: 9.1872e-05
#
# Epoch 117
# Loss: 78.3378
# Psi gradient stats:
# Mean: -5.2691e-04
# Std:  8.5761e-02
# Max:  1.6092e-01
# Min:  -2.3490e-01
# Average psi change: 9.1831e-05
#
# Epoch 118
# Loss: 78.3169
# Psi gradient stats:
# Mean: -5.2674e-04
# Std:  8.5728e-02
# Max:  1.6079e-01
# Min:  -2.3500e-01
# Average psi change: 9.1780e-05
#
# Epoch 119
# Loss: 78.3054
# Psi gradient stats:
# Mean: -5.2602e-04
# Std:  8.5686e-02
# Max:  1.6038e-01
# Min:  -2.3494e-01
# Average psi change: 9.1762e-05
#
# Epoch 120
# Loss: 78.2843
# Psi gradient stats:
# Mean: -5.3190e-04
# Std:  8.5648e-02
# Max:  1.6001e-01
# Min:  -2.3477e-01
# Average psi change: 9.1745e-05
# Epoch 120, Loss: 78.2843, Gradients - Lambda: 4.997e-02, Phi: 1.394e+01, Gamma: 3.705e-03, Psi: 2.348e-01
#
# Epoch 121
# Loss: 78.2686
# Psi gradient stats:
# Mean: -5.4410e-04
# Std:  8.5619e-02
# Max:  1.5999e-01
# Min:  -2.3465e-01
# Average psi change: 9.1748e-05
#
# Epoch 122
# Loss: 78.2530
# Psi gradient stats:
# Mean: -5.5513e-04
# Std:  8.5595e-02
# Max:  1.6027e-01
# Min:  -2.3468e-01
# Average psi change: 9.1739e-05
#
# Epoch 123
# Loss: 78.2305
# Psi gradient stats:
# Mean: -5.6143e-04
# Std:  8.5573e-02
# Max:  1.6056e-01
# Min:  -2.3486e-01
# Average psi change: 9.1707e-05
#
# Epoch 124
# Loss: 78.2205
# Psi gradient stats:
# Mean: -5.6226e-04
# Std:  8.5547e-02
# Max:  1.6057e-01
# Min:  -2.3502e-01
# Average psi change: 9.1653e-05
#
# Epoch 125
# Loss: 78.2055
# Psi gradient stats:
# Mean: -5.6151e-04
# Std:  8.5517e-02
# Max:  1.6027e-01
# Min:  -2.3504e-01
# Average psi change: 9.1615e-05
#
# Epoch 126
# Loss: 78.1787
# Psi gradient stats:
# Mean: -5.6624e-04
# Std:  8.5485e-02
# Max:  1.5992e-01
# Min:  -2.3490e-01
# Average psi change: 9.1606e-05
#
# Epoch 127
# Loss: 78.1706
# Psi gradient stats:
# Mean: -5.7852e-04
# Std:  8.5451e-02
# Max:  1.5978e-01
# Min:  -2.3473e-01
# Average psi change: 9.1606e-05
#
# Epoch 128
# Loss: 78.1600
# Psi gradient stats:
# Mean: -5.9574e-04
# Std:  8.5416e-02
# Max:  1.5994e-01
# Min:  -2.3468e-01
# Average psi change: 9.1586e-05
#
# Epoch 129
# Loss: 78.1321
# Psi gradient stats:
# Mean: -6.0348e-04
# Std:  8.5387e-02
# Max:  1.6021e-01
# Min:  -2.3480e-01
# Average psi change: 9.1554e-05
#
# Epoch 130
# Loss: 78.1212
# Psi gradient stats:
# Mean: -6.0214e-04
# Std:  8.5364e-02
# Max:  1.6029e-01
# Min:  -2.3498e-01
# Average psi change: 9.1510e-05
# Epoch 130, Loss: 78.1212, Gradients - Lambda: 4.960e-02, Phi: 1.444e+01, Gamma: 3.607e-03, Psi: 2.350e-01
#
# Epoch 131
# Loss: 78.1110
# Psi gradient stats:
# Mean: -5.9508e-04
# Std:  8.5345e-02
# Max:  1.6014e-01
# Min:  -2.3508e-01
# Average psi change: 9.1459e-05
#
# Epoch 132
# Loss: 78.0895
# Psi gradient stats:
# Mean: -5.9110e-04
# Std:  8.5320e-02
# Max:  1.5984e-01
# Min:  -2.3502e-01
# Average psi change: 9.1429e-05
#
# Epoch 133
# Loss: 78.0758
# Psi gradient stats:
# Mean: -6.0159e-04
# Std:  8.5284e-02
# Max:  1.5966e-01
# Min:  -2.3485e-01
# Average psi change: 9.1434e-05
#
# Epoch 134
# Loss: 78.0591
# Psi gradient stats:
# Mean: -6.2367e-04
# Std:  8.5239e-02
# Max:  1.5970e-01
# Min:  -2.3473e-01
# Average psi change: 9.1431e-05
#
# Epoch 135
# Loss: 78.0439
# Psi gradient stats:
# Mean: -6.4472e-04
# Std:  8.5204e-02
# Max:  1.5986e-01
# Min:  -2.3475e-01
# Average psi change: 9.1408e-05
#
# Epoch 136
# Loss: 78.0362
# Psi gradient stats:
# Mean: -6.4867e-04
# Std:  8.5185e-02
# Max:  1.5997e-01
# Min:  -2.3492e-01
# Average psi change: 9.1347e-05
#
# Epoch 137
# Loss: 78.0094
# Psi gradient stats:
# Mean: -6.3119e-04
# Std:  8.5175e-02
# Max:  1.5988e-01
# Min:  -2.3507e-01
# Average psi change: 9.1288e-05
#
# Epoch 138
# Loss: 77.9928
# Psi gradient stats:
# Mean: -6.1433e-04
# Std:  8.5159e-02
# Max:  1.5969e-01
# Min:  -2.3510e-01
# Average psi change: 9.1249e-05
#
# Epoch 139
# Loss: 77.9976
# Psi gradient stats:
# Mean: -6.1478e-04
# Std:  8.5122e-02
# Max:  1.5954e-01
# Min:  -2.3498e-01
# Average psi change: 9.1240e-05
#
# Epoch 140
# Loss: 77.9664
# Psi gradient stats:
# Mean: -6.4067e-04
# Std:  8.5067e-02
# Max:  1.5954e-01
# Min:  -2.3482e-01
# Average psi change: 9.1255e-05
# Epoch 140, Loss: 77.9664, Gradients - Lambda: 5.185e-02, Phi: 1.617e+01, Gamma: 3.812e-03, Psi: 2.348e-01
#
# Epoch 141
# Loss: 77.9372
# Psi gradient stats:
# Mean: -6.7734e-04
# Std:  8.5019e-02
# Max:  1.5963e-01
# Min:  -2.3475e-01
# Average psi change: 9.1250e-05
#
# Epoch 142
# Loss: 77.9540
# Psi gradient stats:
# Mean: -6.9592e-04
# Std:  8.4997e-02
# Max:  1.5970e-01
# Min:  -2.3485e-01
# Average psi change: 9.1199e-05
#
# Epoch 143
# Loss: 77.9315
# Psi gradient stats:
# Mean: -6.8670e-04
# Std:  8.5001e-02
# Max:  1.5964e-01
# Min:  -2.3502e-01
# Average psi change: 9.1167e-05
#
# Epoch 144
# Loss: 77.8819
# Psi gradient stats:
# Mean: -6.5948e-04
# Std:  8.5002e-02
# Max:  1.5949e-01
# Min:  -2.3512e-01
# Average psi change: 9.1121e-05
#
# Epoch 145
# Loss: 77.9007
# Psi gradient stats:
# Mean: -6.4127e-04
# Std:  8.4973e-02
# Max:  1.5934e-01
# Min:  -2.3508e-01
# Average psi change: 9.1093e-05
#
# Epoch 146
# Loss: 77.9019
# Psi gradient stats:
# Mean: -6.5102e-04
# Std:  8.4911e-02
# Max:  1.5934e-01
# Min:  -2.3494e-01
# Average psi change: 9.1114e-05
#
# Epoch 147
# Loss: 77.8334
# Psi gradient stats:
# Mean: -6.8733e-04
# Std:  8.4844e-02
# Max:  1.5944e-01
# Min:  -2.3484e-01
# Average psi change: 9.1133e-05
#
# Epoch 148
# Loss: 77.8371
# Psi gradient stats:
# Mean: -7.2240e-04
# Std:  8.4806e-02
# Max:  1.5951e-01
# Min:  -2.3486e-01
# Average psi change: 9.1118e-05
#
# Epoch 149
# Loss: 77.8695
# Psi gradient stats:
# Mean: -7.3415e-04
# Std:  8.4810e-02
# Max:  1.5947e-01
# Min:  -2.3499e-01
# Average psi change: 9.1099e-05
#
# Epoch 150
# Loss: 77.7966
# Psi gradient stats:
# Mean: -7.1697e-04
# Std:  8.4829e-02
# Max:  1.5930e-01
# Min:  -2.3511e-01
# Average psi change: 9.1038e-05
# Epoch 150, Loss: 77.7966, Gradients - Lambda: 5.446e-02, Phi: 1.661e+01, Gamma: 3.554e-03, Psi: 2.351e-01
#
# Epoch 151
# Loss: 77.7690
# Psi gradient stats:
# Mean: -6.9410e-04
# Std:  8.4823e-02
# Max:  1.5914e-01
# Min:  -2.3513e-01
# Average psi change: 9.1005e-05
#
# Epoch 152
# Loss: 77.8250
# Psi gradient stats:
# Mean: -6.8696e-04
# Std:  8.4771e-02
# Max:  1.5909e-01
# Min:  -2.3505e-01
# Average psi change: 9.0997e-05
#
# Epoch 153
# Loss: 77.7705
# Psi gradient stats:
# Mean: -7.0730e-04
# Std:  8.4691e-02
# Max:  1.5917e-01
# Min:  -2.3495e-01
# Average psi change: 9.0993e-05
#
# Epoch 154
# Loss: 77.7071
# Psi gradient stats:
# Mean: -7.3751e-04
# Std:  8.4626e-02
# Max:  1.5927e-01
# Min:  -2.3494e-01
# Average psi change: 9.1015e-05
#
# Epoch 155
# Loss: 77.7646
# Psi gradient stats:
# Mean: -7.5700e-04
# Std:  8.4605e-02
# Max:  1.5929e-01
# Min:  -2.3500e-01
# Average psi change: 9.1014e-05
#
# Epoch 156
# Loss: 77.7446
# Psi gradient stats:
# Mean: -7.5238e-04
# Std:  8.4624e-02
# Max:  1.5917e-01
# Min:  -2.3508e-01
# Average psi change: 9.0972e-05
#
# Epoch 157
# Loss: 77.6611
# Psi gradient stats:
# Mean: -7.3738e-04
# Std:  8.4643e-02
# Max:  1.5901e-01
# Min:  -2.3511e-01
# Average psi change: 9.0935e-05
#
# Epoch 158
# Loss: 77.6944
# Psi gradient stats:
# Mean: -7.3029e-04
# Std:  8.4627e-02
# Max:  1.5890e-01
# Min:  -2.3510e-01
# Average psi change: 9.0904e-05
#
# Epoch 159
# Loss: 77.7075
# Psi gradient stats:
# Mean: -7.4326e-04
# Std:  8.4564e-02
# Max:  1.5891e-01
# Min:  -2.3510e-01
# Average psi change: 9.0885e-05
#
# Epoch 160
# Loss: 77.6292
# Psi gradient stats:
# Mean: -7.6542e-04
# Std:  8.4484e-02
# Max:  1.5900e-01
# Min:  -2.3510e-01
# Average psi change: 9.0869e-05
# Epoch 160, Loss: 77.6292, Gradients - Lambda: 5.808e-02, Phi: 1.483e+01, Gamma: 3.774e-03, Psi: 2.351e-01
#
# Epoch 161
# Loss: 77.6267
# Psi gradient stats:
# Mean: -7.8102e-04
# Std:  8.4424e-02
# Max:  1.5904e-01
# Min:  -2.3509e-01
# Average psi change: 9.0874e-05
#
# Epoch 162
# Loss: 77.6539
# Psi gradient stats:
# Mean: -7.7905e-04
# Std:  8.4409e-02
# Max:  1.5897e-01
# Min:  -2.3508e-01
# Average psi change: 9.0877e-05
#
# Epoch 163
# Loss: 77.6022
# Psi gradient stats:
# Mean: -7.6551e-04
# Std:  8.4432e-02
# Max:  1.5884e-01
# Min:  -2.3506e-01
# Average psi change: 9.0854e-05
#
# Epoch 164
# Loss: 77.5707
# Psi gradient stats:
# Mean: -7.6197e-04
# Std:  8.4454e-02
# Max:  1.5873e-01
# Min:  -2.3507e-01
# Average psi change: 9.0829e-05
#
# Epoch 165
# Loss: 77.5888
# Psi gradient stats:
# Mean: -7.7717e-04
# Std:  8.4436e-02
# Max:  1.5873e-01
# Min:  -2.3514e-01
# Average psi change: 9.0796e-05
#
# Epoch 166
# Loss: 77.5686
# Psi gradient stats:
# Mean: -8.0309e-04
# Std:  8.4370e-02
# Max:  1.5880e-01
# Min:  -2.3521e-01
# Average psi change: 9.0769e-05
#
# Epoch 167
# Loss: 77.5275
# Psi gradient stats:
# Mean: -8.2147e-04
# Std:  8.4284e-02
# Max:  1.5886e-01
# Min:  -2.3523e-01
# Average psi change: 9.0739e-05
#
# Epoch 168
# Loss: 77.5211
# Psi gradient stats:
# Mean: -8.1680e-04
# Std:  8.4223e-02
# Max:  1.5879e-01
# Min:  -2.3514e-01
# Average psi change: 9.0748e-05
#
# Epoch 169
# Loss: 77.5232
# Psi gradient stats:
# Mean: -7.9777e-04
# Std:  8.4216e-02
# Max:  1.5862e-01
# Min:  -2.3503e-01
# Average psi change: 9.0752e-05
#
# Epoch 170
# Loss: 77.4927
# Psi gradient stats:
# Mean: -7.8333e-04
# Std:  8.4250e-02
# Max:  1.5844e-01
# Min:  -2.3502e-01
# Average psi change: 9.0763e-05
# Epoch 170, Loss: 77.4927, Gradients - Lambda: 5.490e-02, Phi: 1.503e+01, Gamma: 3.556e-03, Psi: 2.350e-01
#
# Epoch 171
# Loss: 77.4595
# Psi gradient stats:
# Mean: -7.9168e-04
# Std:  8.4276e-02
# Max:  1.5842e-01
# Min:  -2.3512e-01
# Average psi change: 9.0710e-05
#
# Epoch 172
# Loss: 77.4638
# Psi gradient stats:
# Mean: -8.2237e-04
# Std:  8.4254e-02
# Max:  1.5855e-01
# Min:  -2.3531e-01
# Average psi change: 9.0670e-05
#
# Epoch 173
# Loss: 77.4580
# Psi gradient stats:
# Mean: -8.5479e-04
# Std:  8.4176e-02
# Max:  1.5873e-01
# Min:  -2.3541e-01
# Average psi change: 9.0628e-05
#
# Epoch 174
# Loss: 77.4104
# Psi gradient stats:
# Mean: -8.6934e-04
# Std:  8.4082e-02
# Max:  1.5877e-01
# Min:  -2.3532e-01
# Average psi change: 9.0605e-05
#
# Epoch 175
# Loss: 77.3962
# Psi gradient stats:
# Mean: -8.5498e-04
# Std:  8.4025e-02
# Max:  1.5861e-01
# Min:  -2.3510e-01
# Average psi change: 9.0594e-05
#
# Epoch 176
# Loss: 77.4143
# Psi gradient stats:
# Mean: -8.2776e-04
# Std:  8.4031e-02
# Max:  1.5831e-01
# Min:  -2.3496e-01
# Average psi change: 9.0616e-05
#
# Epoch 177
# Loss: 77.3737
# Psi gradient stats:
# Mean: -8.0970e-04
# Std:  8.4073e-02
# Max:  1.5806e-01
# Min:  -2.3503e-01
# Average psi change: 9.0613e-05
#
# Epoch 178
# Loss: 77.3304
# Psi gradient stats:
# Mean: -8.2244e-04
# Std:  8.4094e-02
# Max:  1.5806e-01
# Min:  -2.3529e-01
# Average psi change: 9.0579e-05
#
# Epoch 179
# Loss: 77.3562
# Psi gradient stats:
# Mean: -8.5756e-04
# Std:  8.4055e-02
# Max:  1.5828e-01
# Min:  -2.3551e-01
# Average psi change: 9.0533e-05
#
# Epoch 180
# Loss: 77.3422
# Psi gradient stats:
# Mean: -8.9447e-04
# Std:  8.3965e-02
# Max:  1.5857e-01
# Min:  -2.3550e-01
# Average psi change: 9.0477e-05
# Epoch 180, Loss: 77.3422, Gradients - Lambda: 5.766e-02, Phi: 1.514e+01, Gamma: 3.744e-03, Psi: 2.355e-01
#
# Epoch 181
# Loss: 77.2760
# Psi gradient stats:
# Mean: -9.0767e-04
# Std:  8.3875e-02
# Max:  1.5867e-01
# Min:  -2.3526e-01
# Average psi change: 9.0447e-05
#
# Epoch 182
# Loss: 77.2857
# Psi gradient stats:
# Mean: -8.8996e-04
# Std:  8.3837e-02
# Max:  1.5847e-01
# Min:  -2.3501e-01
# Average psi change: 9.0456e-05
#
# Epoch 183
# Loss: 77.3049
# Psi gradient stats:
# Mean: -8.6009e-04
# Std:  8.3861e-02
# Max:  1.5808e-01
# Min:  -2.3498e-01
# Average psi change: 9.0450e-05
#
# Epoch 184
# Loss: 77.2373
# Psi gradient stats:
# Mean: -8.4624e-04
# Std:  8.3901e-02
# Max:  1.5776e-01
# Min:  -2.3522e-01
# Average psi change: 9.0441e-05
#
# Epoch 185
# Loss: 77.2124
# Psi gradient stats:
# Mean: -8.6390e-04
# Std:  8.3903e-02
# Max:  1.5773e-01
# Min:  -2.3554e-01
# Average psi change: 9.0410e-05
#
# Epoch 186
# Loss: 77.2513
# Psi gradient stats:
# Mean: -9.0253e-04
# Std:  8.3843e-02
# Max:  1.5801e-01
# Min:  -2.3565e-01
# Average psi change: 9.0371e-05
#
# Epoch 187
# Loss: 77.2099
# Psi gradient stats:
# Mean: -9.3460e-04
# Std:  8.3748e-02
# Max:  1.5839e-01
# Min:  -2.3545e-01
# Average psi change: 9.0318e-05
#
# Epoch 188
# Loss: 77.1502
# Psi gradient stats:
# Mean: -9.3637e-04
# Std:  8.3678e-02
# Max:  1.5856e-01
# Min:  -2.3512e-01
# Average psi change: 9.0296e-05
#
# Epoch 189
# Loss: 77.1802
# Psi gradient stats:
# Mean: -9.1045e-04
# Std:  8.3666e-02
# Max:  1.5838e-01
# Min:  -2.3498e-01
# Average psi change: 9.0290e-05
#
# Epoch 190
# Loss: 77.1779
# Psi gradient stats:
# Mean: -8.8410e-04
# Std:  8.3699e-02
# Max:  1.5792e-01
# Min:  -2.3515e-01
# Average psi change: 9.0279e-05
# Epoch 190, Loss: 77.1779, Gradients - Lambda: 5.504e-02, Phi: 1.477e+01, Gamma: 3.711e-03, Psi: 2.351e-01
#
# Epoch 191
# Loss: 77.1083
# Psi gradient stats:
# Mean: -8.8451e-04
# Std:  8.3723e-02
# Max:  1.5750e-01
# Min:  -2.3549e-01
# Average psi change: 9.0262e-05
#
# Epoch 192
# Loss: 77.1043
# Psi gradient stats:
# Mean: -9.1531e-04
# Std:  8.3699e-02
# Max:  1.5740e-01
# Min:  -2.3570e-01
# Average psi change: 9.0222e-05
#
# Epoch 193
# Loss: 77.1276
# Psi gradient stats:
# Mean: -9.5850e-04
# Std:  8.3623e-02
# Max:  1.5770e-01
# Min:  -2.3560e-01
# Average psi change: 9.0175e-05
#
# Epoch 194
# Loss: 77.0784
# Psi gradient stats:
# Mean: -9.8141e-04
# Std:  8.3539e-02
# Max:  1.5813e-01
# Min:  -2.3529e-01
# Average psi change: 9.0168e-05
#
# Epoch 195
# Loss: 77.0421
# Psi gradient stats:
# Mean: -9.6461e-04
# Std:  8.3493e-02
# Max:  1.5836e-01
# Min:  -2.3506e-01
# Average psi change: 9.0158e-05
#
# Epoch 196
# Loss: 77.0610
# Psi gradient stats:
# Mean: -9.2738e-04
# Std:  8.3500e-02
# Max:  1.5820e-01
# Min:  -2.3513e-01
# Average psi change: 9.0155e-05
#
# Epoch 197
# Loss: 77.0426
# Psi gradient stats:
# Mean: -9.0230e-04
# Std:  8.3529e-02
# Max:  1.5774e-01
# Min:  -2.3545e-01
# Average psi change: 9.0130e-05
#
# Epoch 198
# Loss: 76.9982
# Psi gradient stats:
# Mean: -9.1820e-04
# Std:  8.3533e-02
# Max:  1.5728e-01
# Min:  -2.3573e-01
# Average psi change: 9.0073e-05
#
# Epoch 199
# Loss: 76.9931
# Psi gradient stats:
# Mean: -9.6609e-04
# Std:  8.3488e-02
# Max:  1.5713e-01
# Min:  -2.3571e-01
# Average psi change: 9.0005e-05
#
# Epoch 200
# Loss: 76.9907
# Psi gradient stats:
# Mean: -1.0121e-03
# Std:  8.3414e-02
# Max:  1.5739e-01
# Min:  -2.3543e-01
# Average psi change: 8.9986e-05
# Epoch 200, Loss: 76.9907, Gradients - Lambda: 5.467e-02, Phi: 1.428e+01, Gamma: 3.620e-03, Psi: 2.354e-01
#
# Epoch 201
# Loss: 76.9621
# Psi gradient stats:
# Mean: -1.0228e-03
# Std:  8.3349e-02
# Max:  1.5785e-01
# Min:  -2.3513e-01
# Average psi change: 8.9989e-05
#
# Epoch 202
# Loss: 76.9381
# Psi gradient stats:
# Mean: -9.9087e-04
# Std:  8.3323e-02
# Max:  1.5812e-01
# Min:  -2.3513e-01
# Average psi change: 9.0002e-05
#
# Epoch 203
# Loss: 76.9282
# Psi gradient stats:
# Mean: -9.4511e-04
# Std:  8.3333e-02
# Max:  1.5800e-01
# Min:  -2.3541e-01
# Average psi change: 9.0006e-05
#
# Epoch 204
# Loss: 76.9185
# Psi gradient stats:
# Mean: -9.2602e-04
# Std:  8.3346e-02
# Max:  1.5754e-01
# Min:  -2.3574e-01
# Average psi change: 8.9952e-05
#
# Epoch 205
# Loss: 76.8967
# Psi gradient stats:
# Mean: -9.5536e-04
# Std:  8.3332e-02
# Max:  1.5709e-01
# Min:  -2.3583e-01
# Average psi change: 8.9872e-05
#
# Epoch 206
# Loss: 76.8684
# Psi gradient stats:
# Mean: -1.0136e-03
# Std:  8.3286e-02
# Max:  1.5694e-01
# Min:  -2.3562e-01
# Average psi change: 8.9794e-05
#
# Epoch 207
# Loss: 76.8620
# Psi gradient stats:
# Mean: -1.0585e-03
# Std:  8.3224e-02
# Max:  1.5719e-01
# Min:  -2.3526e-01
# Average psi change: 8.9786e-05
#
# Epoch 208
# Loss: 76.8580
# Psi gradient stats:
# Mean: -1.0588e-03
# Std:  8.3175e-02
# Max:  1.5761e-01
# Min:  -2.3511e-01
# Average psi change: 8.9799e-05
#
# Epoch 209
# Loss: 76.8206
# Psi gradient stats:
# Mean: -1.0145e-03
# Std:  8.3151e-02
# Max:  1.5787e-01
# Min:  -2.3529e-01
# Average psi change: 8.9834e-05
#
# Epoch 210
# Loss: 76.8003
# Psi gradient stats:
# Mean: -9.6722e-04
# Std:  8.3150e-02
# Max:  1.5777e-01
# Min:  -2.3567e-01
# Average psi change: 8.9813e-05
# Epoch 210, Loss: 76.8003, Gradients - Lambda: 5.732e-02, Phi: 1.475e+01, Gamma: 3.727e-03, Psi: 2.357e-01
#
# Epoch 211
# Loss: 76.8115
# Psi gradient stats:
# Mean: -9.5519e-04
# Std:  8.3149e-02
# Max:  1.5734e-01
# Min:  -2.3592e-01
# Average psi change: 8.9743e-05
#
# Epoch 212
# Loss: 76.7831
# Psi gradient stats:
# Mean: -9.9292e-04
# Std:  8.3132e-02
# Max:  1.5691e-01
# Min:  -2.3584e-01
# Average psi change: 8.9650e-05
#
# Epoch 213
# Loss: 76.7428
# Psi gradient stats:
# Mean: -1.0544e-03
# Std:  8.3092e-02
# Max:  1.5677e-01
# Min:  -2.3549e-01
# Average psi change: 8.9575e-05
#
# Epoch 214
# Loss: 76.7544
# Psi gradient stats:
# Mean: -1.0930e-03
# Std:  8.3043e-02
# Max:  1.5699e-01
# Min:  -2.3518e-01
# Average psi change: 8.9578e-05
#
# Epoch 215
# Loss: 76.7469
# Psi gradient stats:
# Mean: -1.0831e-03
# Std:  8.2998e-02
# Max:  1.5736e-01
# Min:  -2.3516e-01
# Average psi change: 8.9608e-05
#
# Epoch 216
# Loss: 76.6963
# Psi gradient stats:
# Mean: -1.0367e-03
# Std:  8.2971e-02
# Max:  1.5758e-01
# Min:  -2.3547e-01
# Average psi change: 8.9642e-05
#
# Epoch 217
# Loss: 76.6929
# Psi gradient stats:
# Mean: -9.9808e-04
# Std:  8.2958e-02
# Max:  1.5746e-01
# Min:  -2.3586e-01
# Average psi change: 8.9614e-05
#
# Epoch 218
# Loss: 76.7040
# Psi gradient stats:
# Mean: -9.9884e-04
# Std:  8.2952e-02
# Max:  1.5707e-01
# Min:  -2.3602e-01
# Average psi change: 8.9518e-05
#
# Epoch 219
# Loss: 76.6588
# Psi gradient stats:
# Mean: -1.0418e-03
# Std:  8.2937e-02
# Max:  1.5671e-01
# Min:  -2.3582e-01
# Average psi change: 8.9439e-05
#
# Epoch 220
# Loss: 76.6345
# Psi gradient stats:
# Mean: -1.0939e-03
# Std:  8.2907e-02
# Max:  1.5661e-01
# Min:  -2.3543e-01
# Average psi change: 8.9394e-05
# Epoch 220, Loss: 76.6345, Gradients - Lambda: 6.315e-02, Phi: 1.339e+01, Gamma: 3.662e-03, Psi: 2.354e-01
#
# Epoch 221
# Loss: 76.6513
# Psi gradient stats:
# Mean: -1.1195e-03
# Std:  8.2865e-02
# Max:  1.5681e-01
# Min:  -2.3517e-01
# Average psi change: 8.9420e-05
#
# Epoch 222
# Loss: 76.6244
# Psi gradient stats:
# Mean: -1.1024e-03
# Std:  8.2822e-02
# Max:  1.5714e-01
# Min:  -2.3524e-01
# Average psi change: 8.9478e-05
#
# Epoch 223
# Loss: 76.5853
# Psi gradient stats:
# Mean: -1.0632e-03
# Std:  8.2788e-02
# Max:  1.5731e-01
# Min:  -2.3560e-01
# Average psi change: 8.9502e-05
#
# Epoch 224
# Loss: 76.5933
# Psi gradient stats:
# Mean: -1.0370e-03
# Std:  8.2773e-02
# Max:  1.5716e-01
# Min:  -2.3597e-01
# Average psi change: 8.9479e-05
#
# Epoch 225
# Loss: 76.5855
# Psi gradient stats:
# Mean: -1.0474e-03
# Std:  8.2766e-02
# Max:  1.5681e-01
# Min:  -2.3607e-01
# Average psi change: 8.9422e-05
#
# Epoch 226
# Loss: 76.5458
# Psi gradient stats:
# Mean: -1.0892e-03
# Std:  8.2757e-02
# Max:  1.5651e-01
# Min:  -2.3584e-01
# Average psi change: 8.9363e-05
#
# Epoch 227
# Loss: 76.5372
# Psi gradient stats:
# Mean: -1.1288e-03
# Std:  8.2731e-02
# Max:  1.5647e-01
# Min:  -2.3545e-01
# Average psi change: 8.9343e-05
#
# Epoch 228
# Loss: 76.5389
# Psi gradient stats:
# Mean: -1.1412e-03
# Std:  8.2687e-02
# Max:  1.5669e-01
# Min:  -2.3520e-01
# Average psi change: 8.9372e-05
#
# Epoch 229
# Loss: 76.5098
# Psi gradient stats:
# Mean: -1.1245e-03
# Std:  8.2639e-02
# Max:  1.5697e-01
# Min:  -2.3528e-01
# Average psi change: 8.9410e-05
#
# Epoch 230
# Loss: 76.4877
# Psi gradient stats:
# Mean: -1.0968e-03
# Std:  8.2602e-02
# Max:  1.5705e-01
# Min:  -2.3564e-01
# Average psi change: 8.9450e-05
# Epoch 230, Loss: 76.4877, Gradients - Lambda: 5.565e-02, Phi: 1.302e+01, Gamma: 3.655e-03, Psi: 2.356e-01
#
# Epoch 231
# Loss: 76.4880
# Psi gradient stats:
# Mean: -1.0850e-03
# Std:  8.2588e-02
# Max:  1.5688e-01
# Min:  -2.3602e-01
# Average psi change: 8.9415e-05
#
# Converged at epoch 231. Loss change: 0.0003

# %%
plot_best_matches(data['pi'], model.forward()[0],n_samples=6)

# %%
def verify_marginal_probabilities(Y, pi_pred, age_start=10, age_window=10):
    """
    Compare predicted marginal probabilities with observed rates
    """
    N, D, T = Y.shape
    verification = []
    
    for d in range(D):
        # Get people at risk
        at_risk = ~np.any(Y[:, d, :age_start], axis=1)
        n_at_risk = np.sum(at_risk)
        
        if n_at_risk >= 100:  # Minimum sample size
            # Predicted probability
            yearly_pi = pi_pred[at_risk, d, age_start:age_start+age_window]
            pred_risk = 1 - np.prod(1 - yearly_pi, axis=1).mean()
            
            # Observed probability
            observed = np.any(Y[at_risk, d, age_start:age_start+age_window], axis=1).mean()
            
            verification.append({
                #'disease': disease_name_list[d],
                'predicted_risk': pred_risk,
                'observed_risk': observed,
                'ratio_pred_obs': pred_risk/observed if observed > 0 else np.nan,
                'n_at_risk': n_at_risk,
                'n_events': np.sum(np.any(Y[at_risk, d, age_start:age_start+age_window], axis=1))
            })
    
    verify_df = pd.DataFrame(verification)
    
    # Sort by absolute difference between predicted and observed
    verify_df['abs_diff'] = np.abs(verify_df.predicted_risk - verify_df.observed_risk)
    verify_df = verify_df.sort_values('abs_diff', ascending=False)
    
    print("\nTop 10 largest discrepancies between predicted and observed risks:")
    print(verify_df.head(10)[['predicted_risk', 'observed_risk', 'ratio_pred_obs', 'n_events', 'n_at_risk']])
    
    print("\nSummary statistics of prediction/observation ratios:")
    print(verify_df.ratio_pred_obs.describe())
    
    # Plot predicted vs observed
    plt.figure(figsize=(10, 10))
    plt.scatter(verify_df.observed_risk, verify_df.predicted_risk, alpha=0.5)
    plt.plot([0, max(verify_df.observed_risk.max(), verify_df.predicted_risk.max())], 
             [0, max(verify_df.observed_risk.max(), verify_df.predicted_risk.max())], 
             'r--')
    plt.xlabel('Observed Risk')
    plt.ylabel('Predicted Risk')
    plt.title('Predicted vs Observed Marginal Risks')
    plt.show()
    
    return verify_df
data['Y'].shape
with torch.no_grad():  
    pi_pred =model.forward()[0].cpu().numpy()
# Run verification
verify_df = verify_marginal_probabilities(Y=data['Y'],pi_pred=pi_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 58
#      56     pi_pred =model.forward()[0].cpu().numpy()
#      57 # Run verification
# ---> 58 verify_df = verify_marginal_probabilities(Y=data['Y'],pi_pred=pi_pred)
#
# Cell In[17], line 30, in verify_marginal_probabilities(Y, pi_pred, age_start, age_window)
#      19         observed = np.any(Y[at_risk, d, age_start:age_start+age_window], axis=1).mean()
#      21         verification.append({
#      22             #'disease': disease_name_list[d],
#      23             'predicted_risk': pred_risk,
#    (...)
#      27             'n_events': np.sum(np.any(Y[at_risk, d, age_start:age_start+age_window], axis=1))
#      28         })
# ---> 30 verify_df = pd.DataFrame(verification)
#      32 # Sort by absolute difference between predicted and observed
#      33 verify_df['abs_diff'] = np.abs(verify_df.predicted_risk - verify_df.observed_risk)
#
# NameError: name 'pd' is not defined

# %%
model.lambda_
# Out:
# Parameter containing:
# tensor([[[ 2.3960,  2.3283,  2.2400,  ..., -0.8835, -0.9286, -0.9477],
#          [-0.8531, -0.7937, -0.7355,  ..., -0.1721, -0.1772, -0.2035],
#          [ 1.1227,  1.2680,  1.4255,  ...,  2.2607,  2.1604,  2.0649],
#          [ 0.6984,  0.7193,  0.7262,  ..., -0.0773, -0.0117,  0.0405],
#          [ 2.6412,  2.5785,  2.4982,  ...,  0.8859,  0.8524,  0.8273]],
#
#         [[-0.3149, -0.3857, -0.4549,  ..., -0.4895, -0.4195, -0.3524],
#          [-0.2688, -0.3005, -0.3285,  ...,  0.4233,  0.4468,  0.4632],
#          [-2.9171, -2.9109, -2.8936,  ..., -1.3157, -1.1843, -1.0833],
#          [ 0.6433,  0.6969,  0.7426,  ...,  1.3817,  1.4358,  1.4878],
#          [ 2.8252,  2.8384,  2.8326,  ...,  2.0400,  2.0984,  2.1497]],
#
#         [[-2.4628, -2.4141, -2.3589,  ..., -1.5852, -1.5284, -1.4801],
#          [-0.0681, -0.0965, -0.1114,  ...,  0.4842,  0.3878,  0.2783],
#          [ 3.9457,  3.9132,  3.8745,  ...,  3.4637,  3.5192,  3.5776],
#          [ 0.2650,  0.3884,  0.5071,  ..., -0.4119, -0.5509, -0.6947],
#          [ 1.8075,  1.7985,  1.7914,  ...,  1.2819,  1.3122,  1.3435]],
#
#         ...,
#
#         [[ 0.4416,  0.4034,  0.3618,  ..., -0.8285, -0.8595, -0.8820],
#          [-0.8828, -0.8188, -0.7412,  ..., -0.8968, -0.8824, -0.8809],
#          [-0.9352, -1.0575, -1.1651,  ..., -3.2838, -3.1319, -2.9802],
#          [ 1.6583,  1.6930,  1.7289,  ...,  0.4098,  0.4478,  0.4864],
#          [-0.7528, -0.6953, -0.6348,  ..., -0.4168, -0.4133, -0.4085]],
#
#         [[-0.7635, -0.7763, -0.8027,  ..., -0.1156, -0.0511,  0.0111],
#          [-1.4247, -1.4009, -1.3725,  ..., -0.4852, -0.4797, -0.4830],
#          [-5.6611, -5.5376, -5.3977,  ..., -2.1668, -2.2559, -2.3484],
#          [ 0.2521,  0.1634,  0.0904,  ...,  2.5035,  2.7049,  2.9124],
#          [-2.3952, -2.3568, -2.2907,  ..., -0.1174, -0.0665, -0.0228]],
#
#         [[ 0.0257,  0.1121,  0.1972,  ...,  1.0036,  0.8297,  0.6704],
#          [-0.4452, -0.5143, -0.5917,  ..., -1.2460, -1.3271, -1.3922],
#          [-2.9555, -2.9519, -2.9502,  ..., -2.7839, -2.7886, -2.7952],
#          [ 0.3744,  0.4730,  0.5857,  ...,  0.5027,  0.4256,  0.3512],
#          [-0.1919, -0.0355,  0.1047,  ..., -0.9167, -0.7969, -0.6673]]],
#        requires_grad=True)

# %%
# Average over all diseases and all individuals
mean_pred_all = pi_pred.mean(axis=(0,1))  # Average across people and diseases
real_incidence_all = model.prevalence_t.mean(axis=0)  # Average across diseases
real_pi_all = data['pi'].mean(axis=(0,1)) # Average across diseases

plt.figure(figsize=(10,6))
plt.plot(mean_pred_all, 'b-', label='Model Predicted')
plt.plot(real_incidence_all, 'r-', label='Actual Prevalence') 
plt.plot(real_pi_all, 'g-', label='Simulated pi') 


plt.title('Average Disease Prevalence: Predicted vs Actual')
plt.xlabel('Time')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %%
def visualize_predictions(model, Y, event_times):
    with torch.no_grad():
        pi_pred, _, _ = model.forward()
        pi_pred = pi_pred.cpu().numpy()
    
    N, D, T = Y.shape
    at_risk = np.zeros_like(Y, dtype=bool)
    for n in range(N):
        for d in range(D):
            at_risk[n,d,:event_times[n,d]] = True
    
    # Get predictions
    event_probs = pi_pred[Y == 1 & at_risk]
    nonevent_probs = pi_pred[Y == 0 & at_risk]
    
    plt.figure(figsize=(15, 5))
    
    # 1. Density plot of predictions
    plt.subplot(131)
    plt.hist(event_probs, bins=50, density=True, alpha=0.5, label='Events', color='red')
    plt.hist(nonevent_probs, bins=50, density=True, alpha=0.5, label='Non-events', color='blue')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Density')
    plt.title('Distribution of Predictions')
    plt.legend()
    
    # 2. ROC curve
    from sklearn.metrics import roc_curve, auc
    y_true = np.concatenate([np.ones_like(event_probs), np.zeros_like(nonevent_probs)])
    y_pred = np.concatenate([event_probs, nonevent_probs])
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    
    plt.subplot(132)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    
    # 3. Calibration plot
    from sklearn.calibration import calibration_curve
    prob_true, prob_pred = calibration_curve(y_true, y_pred, n_bins=10)
    
    plt.subplot(133)
    plt.plot(prob_pred, prob_true, marker='o', label='Model')
    plt.plot([0, 1], [0, 1], linestyle='--', label='Perfect calibration')
    plt.xlabel('Mean predicted probability')
    plt.ylabel('Empirical probability')
    plt.title('Calibration Plot')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print(f"Average pi for events: {event_probs.mean():.4f} (std: {event_probs.std():.4f})")
    print(f"Average pi for non-events: {nonevent_probs.mean():.4f} (std: {nonevent_probs.std():.4f})")
    print(f"AUC: {roc_auc:.4f}")
    
    return event_probs, nonevent_probs, roc_auc

visualize_predictions(model, data['Y'], data['event_times'])
# Out:
# Average pi for events: 0.0162 (std: 0.0221)
# Average pi for non-events: 0.0044 (std: 0.0123)
# AUC: 0.7990
# (array([0.01497232, 0.01426951, 0.01319611, ..., 0.01560148, 0.01300061,
#         0.01097673], dtype=float32),
#  array([1.9097472e-08, 1.8283405e-08, 1.7716552e-08, ..., 1.8849341e-03,
#         1.6119609e-03, 1.3967906e-03], dtype=float32),
#  0.7989957413054178)
