# %%
# %load_ext autoreload
# %autoreload 2

#from pis_copy import *
from cluster_g_2 import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_78541/3642553306.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_78541/3642553306.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_78541/3642553306.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_78541/3642553306.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
def subset_data(Y, E, G, n_samples=50000, seed=42):
    """
    Subset the data to n_samples individuals while maintaining consistency
    
    Args:
        Y: tensor of shape [N, D, T]
        E: tensor of shape [N, D]
        G: tensor of shape [N, P]
        n_samples: number of individuals to keep
        seed: random seed for reproducibility
    
    Returns:
        Y_sub, E_sub, G_sub: subsetted tensors
    """
    torch.manual_seed(seed)
    
    # Get total number of individuals
    N = Y.shape[0]
    
    # Randomly select n_samples indices
    indices = torch.randperm(N)[:n_samples]
    
    # Subset all matrices using the same indices
    Y_sub = Y[indices]
    E_sub = E[indices]
    G_sub = G[indices]
    
    print(f"Original shapes: Y={Y.shape}, E={E.shape}, G={G.shape}")
    print(f"New shapes: Y={Y_sub.shape}, E={E_sub.shape}, G={G_sub.shape}")
    
    return Y_sub, E_sub, G_sub, indices

# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([407878, 348, 52]), E=torch.Size([407878, 348]), G=torch.Size([407878, 36])
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=torch.Size([10000, 36])

# %%
del model
psi_config = {'in_cluster': 1, 'out_cluster': -2, 'noise_in': 0.1, 'noise_out': 0.01}
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0],
    D=Y_100k.shape[1],
    T=Y_100k.shape[2],
    K=essentials['K'],
    P=essentials['P'],
    G=G_100k,
    Y=Y_100k,
    prevalence_t=essentials['prevalence_t']
)

# %%
model.fit??
# Out:
# Signature:
# model.fit(
#     event_times,
#     num_epochs=1000,
#     learning_rate=0.0001,
#     lambda_reg=0.01,
#     convergence_threshold=0.001,
#     patience=10,
# )
# Source:
#     def fit(self, event_times, num_epochs=1000, learning_rate=1e-4, lambda_reg=1e-2,
#         convergence_threshold=1e-3, patience=10):
#         """
#         Fit model with early stopping and parameter monitoring
#
#         """
#
#
#         optimizer = optim.Adam([
#             {'params': [self.lambda_], 'lr': learning_rate * 3},  # Larger updates for mixing weights
#             {'params': [self.phi], 'lr': learning_rate},
#             {'params': [self.psi], 'lr': learning_rate * 3},  # Much larger updates for cluster structure
#             {'params': [self.gamma], 'weight_decay': lambda_reg, 'lr': learning_rate*2}
#         ])
#
#
#
#         history = {
#             'loss': [],
#             'max_grad_lambda': [],
#             'max_grad_phi': [],
#             'max_grad_gamma': [],
#             'max_grad_psi': []
#         }
#
#         best_loss = float('inf')
#         patience_counter = 0
#         prev_loss = float('inf')
#
#         print("Starting training...")
#
#         for epoch in range(num_epochs):
#             optimizer.zero_grad()
#
#             # Compute loss and backprop
#             loss = self.compute_loss(event_times)
#             loss_val = loss.item()
#             history['loss'].append(loss_val)
#             loss.backward()
#
#
#             # Get and track gradients
#             grad_lambda = self.lambda_.grad.abs().max().item() if self.lambda_.grad is not None else 0
#             grad_phi = self.phi.grad.abs().max().item() if self.phi.grad is not None else 0
#             grad_gamma = self.gamma.grad.abs().max().item() if self.gamma.grad is not None else 0
#             grad_psi = self.psi.grad.abs().max().item() if self.psi.grad is not None else 0
#
#             history['max_grad_lambda'].append(grad_lambda)
#             history['max_grad_phi'].append(grad_phi)
#             history['max_grad_gamma'].append(grad_gamma)
#             history['max_grad_psi'].append(grad_psi)
#
#                 # Monitor psi gradients
#             print(f"\nEpoch {epoch}")
#             print(f"Loss: {loss.item():.4f}")
#             print("Psi gradient stats:")
#             print(f"Mean: {self.psi.grad.mean().item():.4e}")
#             print(f"Std:  {self.psi.grad.std().item():.4e}")
#             print(f"Max:  {self.psi.grad.max().item():.4e}")
#             print(f"Min:  {self.psi.grad.min().item():.4e}")
#
#             # Check if psi is actually changing
#             ## old_psi = self.psi.detach().clone()
#             ## optimizer.step()
#             ## psi_change = (self.psi - old_psi).abs().mean().item()
#             ### print(f"Average psi change: {psi_change:.4e}")
#
#
#             if epoch < 10 or epoch % 10 == 0:
#                 print(f"Epoch {epoch}, Loss: {loss_val:.4f}, "
#                     f"Gradients - Lambda: {grad_lambda:.3e}, Phi: {grad_phi:.3e}, "
#                     f"Gamma: {grad_gamma:.3e}, Psi: {grad_psi:.3e}")
#
#             # Check convergence
#             loss_change = abs(prev_loss - loss_val)
#             if loss_change < convergence_threshold:
#                 print(f"\nConverged at epoch {epoch}. Loss change: {loss_change:.4f}")
#                 break
#
#             # Early stopping check
#             if loss_val < best_loss:
#                 patience_counter = 0
#                 best_loss = loss_val
#             else:
#                 patience_counter += 1
#                 if patience_counter >= patience:
#                     print(f"\nEarly stopping triggered at epoch {epoch}")
#                     break
#
#
#
#             optimizer.step()
#             prev_loss = loss_val
#
#             # Time estimate on first epoch
#             if epoch == 0:
#                 import time
#                 start_time = time.time()
#             elif epoch == 1:
#                 time_per_epoch = time.time() - start_time
#                 estimated_total_time = time_per_epoch * num_epochs
#                 print(f"\nEstimated total training time: {estimated_total_time/60:.1f} minutes")
#
#         return history
# File:      ~/aladynoulli/pyScripts/cluster_g_2.py
# Type:      method

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

history = model.fit(E_100k, num_epochs=200, learning_rate=1e-3, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_2.py:198: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 0
# Loss: 1109.1042
# Psi gradient stats:
# Mean: -4.1142e-05
# Std:  4.7490e-03
# Max:  1.7403e-02
# Min:  -1.9418e-02
# Epoch 0, Loss: 1109.1042, Gradients - Lambda: 5.413e-01, Phi: 1.365e+01, Gamma: 6.317e-02, Psi: 1.942e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 1
# Loss: 3761.6733
# Psi gradient stats:
# Mean: -3.4084e-05
# Std:  4.6846e-03
# Max:  1.7178e-02
# Min:  -1.9526e-02
# Epoch 1, Loss: 3761.6733, Gradients - Lambda: 1.196e+00, Phi: 1.009e+01, Gamma: 4.851e-02, Psi: 1.953e-02
#
# Estimated total training time: 106.8 minutes
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 2
# Loss: 1097.9304
# Psi gradient stats:
# Mean: -3.4338e-05
# Std:  4.6170e-03
# Max:  1.7179e-02
# Min:  -1.9241e-02
# Epoch 2, Loss: 1097.9304, Gradients - Lambda: 7.603e-01, Phi: 6.448e+00, Gamma: 4.090e-02, Psi: 1.924e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 3
# Loss: 1153.6936
# Psi gradient stats:
# Mean: -3.8318e-05
# Std:  4.5585e-03
# Max:  1.7262e-02
# Min:  -1.8652e-02
# Epoch 3, Loss: 1153.6936, Gradients - Lambda: 7.751e-01, Phi: 5.784e+00, Gamma: 3.737e-02, Psi: 1.865e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 4
# Loss: 1928.1608
# Psi gradient stats:
# Mean: -4.4126e-05
# Std:  4.5114e-03
# Max:  1.7323e-02
# Min:  -1.8079e-02
# Epoch 4, Loss: 1928.1608, Gradients - Lambda: 8.191e-01, Phi: 6.105e+00, Gamma: 3.321e-02, Psi: 1.808e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 5
# Loss: 1549.6316
# Psi gradient stats:
# Mean: -5.0275e-05
# Std:  4.4750e-03
# Max:  1.7345e-02
# Min:  -1.7597e-02
# Epoch 5, Loss: 1549.6316, Gradients - Lambda: 7.185e-01, Phi: 6.119e+00, Gamma: 2.631e-02, Psi: 1.760e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 6
# Loss: 855.2739
# Psi gradient stats:
# Mean: -5.6118e-05
# Std:  4.4484e-03
# Max:  1.7328e-02
# Min:  -1.7249e-02
# Epoch 6, Loss: 855.2739, Gradients - Lambda: 6.435e-01, Phi: 6.653e+00, Gamma: 2.179e-02, Psi: 1.733e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 7
# Loss: 665.3096
# Psi gradient stats:
# Mean: -6.0199e-05
# Std:  4.4307e-03
# Max:  1.7296e-02
# Min:  -1.7005e-02
# Epoch 7, Loss: 665.3096, Gradients - Lambda: 6.906e-01, Phi: 6.965e+00, Gamma: 2.540e-02, Psi: 1.730e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 8
# Loss: 896.7359
# Psi gradient stats:
# Mean: -6.2084e-05
# Std:  4.4197e-03
# Max:  1.7289e-02
# Min:  -1.6799e-02
# Epoch 8, Loss: 896.7359, Gradients - Lambda: 6.743e-01, Phi: 6.626e+00, Gamma: 2.681e-02, Psi: 1.729e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 9
# Loss: 1012.6392
# Psi gradient stats:
# Mean: -6.2452e-05
# Std:  4.4122e-03
# Max:  1.7328e-02
# Min:  -1.6713e-02
# Epoch 9, Loss: 1012.6392, Gradients - Lambda: 6.213e-01, Phi: 5.692e+00, Gamma: 2.432e-02, Psi: 1.733e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 10
# Loss: 837.2026
# Psi gradient stats:
# Mean: -6.2207e-05
# Std:  4.4053e-03
# Max:  1.7403e-02
# Min:  -1.6783e-02
# Epoch 10, Loss: 837.2026, Gradients - Lambda: 5.242e-01, Phi: 4.946e+00, Gamma: 2.056e-02, Psi: 1.740e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 11
# Loss: 601.1044
# Psi gradient stats:
# Mean: -6.2163e-05
# Std:  4.3968e-03
# Max:  1.7482e-02
# Min:  -1.6800e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 12
# Loss: 523.2307
# Psi gradient stats:
# Mean: -6.2761e-05
# Std:  4.3852e-03
# Max:  1.7533e-02
# Min:  -1.6794e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 13
# Loss: 586.1771
# Psi gradient stats:
# Mean: -6.3817e-05
# Std:  4.3699e-03
# Max:  1.7539e-02
# Min:  -1.6778e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 14
# Loss: 634.1814
# Psi gradient stats:
# Mean: -6.4790e-05
# Std:  4.3511e-03
# Max:  1.7503e-02
# Min:  -1.6755e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 15
# Loss: 582.7231
# Psi gradient stats:
# Mean: -6.5209e-05
# Std:  4.3295e-03
# Max:  1.7447e-02
# Min:  -1.6708e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 16
# Loss: 481.8381
# Psi gradient stats:
# Mean: -6.4681e-05
# Std:  4.3062e-03
# Max:  1.7381e-02
# Min:  -1.6635e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 17
# Loss: 418.8641
# Psi gradient stats:
# Mean: -6.3177e-05
# Std:  4.2819e-03
# Max:  1.7318e-02
# Min:  -1.6539e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 18
# Loss: 417.6964
# Psi gradient stats:
# Mean: -6.0927e-05
# Std:  4.2576e-03
# Max:  1.7253e-02
# Min:  -1.6429e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 19
# Loss: 435.4152
# Psi gradient stats:
# Mean: -5.8391e-05
# Std:  4.2341e-03
# Max:  1.7177e-02
# Min:  -1.6316e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 20
# Loss: 427.1532
# Psi gradient stats:
# Mean: -5.5954e-05
# Std:  4.2120e-03
# Max:  1.7084e-02
# Min:  -1.6381e-02
# Epoch 20, Loss: 427.1532, Gradients - Lambda: 3.322e-01, Phi: 2.947e+00, Gamma: 1.393e-02, Psi: 1.708e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 21
# Loss: 391.4311
# Psi gradient stats:
# Mean: -5.3818e-05
# Std:  4.1920e-03
# Max:  1.6984e-02
# Min:  -1.6515e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 22
# Loss: 356.6577
# Psi gradient stats:
# Mean: -5.2037e-05
# Std:  4.1743e-03
# Max:  1.6897e-02
# Min:  -1.6648e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 23
# Loss: 342.0798
# Psi gradient stats:
# Mean: -5.0627e-05
# Std:  4.1583e-03
# Max:  1.6839e-02
# Min:  -1.6770e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 24
# Loss: 341.1642
# Psi gradient stats:
# Mean: -4.9599e-05
# Std:  4.1433e-03
# Max:  1.6819e-02
# Min:  -1.6868e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 25
# Loss: 336.8791
# Psi gradient stats:
# Mean: -4.8920e-05
# Std:  4.1284e-03
# Max:  1.6829e-02
# Min:  -1.6933e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 26
# Loss: 322.7778
# Psi gradient stats:
# Mean: -4.8571e-05
# Std:  4.1131e-03
# Max:  1.6855e-02
# Min:  -1.6962e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 27
# Loss: 306.1960
# Psi gradient stats:
# Mean: -4.8511e-05
# Std:  4.0968e-03
# Max:  1.6886e-02
# Min:  -1.6958e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 28
# Loss: 295.8362
# Psi gradient stats:
# Mean: -4.8661e-05
# Std:  4.0798e-03
# Max:  1.6912e-02
# Min:  -1.6933e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 29
# Loss: 291.8833
# Psi gradient stats:
# Mean: -4.8905e-05
# Std:  4.0623e-03
# Max:  1.6931e-02
# Min:  -1.6897e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 30
# Loss: 288.3116
# Psi gradient stats:
# Mean: -4.9173e-05
# Std:  4.0445e-03
# Max:  1.6938e-02
# Min:  -1.6855e-02
# Epoch 30, Loss: 288.3116, Gradients - Lambda: 1.933e-01, Phi: 2.057e+00, Gamma: 1.098e-02, Psi: 1.694e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 31
# Loss: 281.2222
# Psi gradient stats:
# Mean: -4.9479e-05
# Std:  4.0267e-03
# Max:  1.6930e-02
# Min:  -1.6807e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 32
# Loss: 272.3374
# Psi gradient stats:
# Mean: -4.9857e-05
# Std:  4.0090e-03
# Max:  1.6900e-02
# Min:  -1.6750e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 33
# Loss: 265.3851
# Psi gradient stats:
# Mean: -5.0345e-05
# Std:  3.9915e-03
# Max:  1.6846e-02
# Min:  -1.6679e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 34
# Loss: 261.3975
# Psi gradient stats:
# Mean: -5.0921e-05
# Std:  3.9743e-03
# Max:  1.6776e-02
# Min:  -1.6591e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch
-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 53
# Loss: 219.1601
# Psi gradient stats:
# Mean: -4.7342e-05
# Std:  3.6755e-03
# Max:  1.6346e-02
# Min:  -1.5943e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 54
# Loss: 218.3114
# Psi gradient stats:
# Mean: -4.7219e-05
# Std:  3.6603e-03
# Max:  1.6335e-02
# Min:  -1.5947e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 55
# Loss: 217.4997
# Psi gradient stats:
# Mean: -4.7144e-05
# Std:  3.6452e-03
# Max:  1.6323e-02
# Min:  -1.5937e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 56
# Loss: 216.7202
# Psi gradient stats:
# Mean: -4.7109e-05
# Std:  3.6302e-03
# Max:  1.6308e-02
# Min:  -1.5913e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 57
# Loss: 216.0032
# Psi gradient stats:
# Mean: -4.7118e-05
# Std:  3.6152e-03
# Max:  1.6291e-02
# Min:  -1.5875e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 58
# Loss: 215.3497
# Psi gradient stats:
# Mean: -4.7159e-05
# Std:  3.6003e-03
# Max:  1.6271e-02
# Min:  -1.5830e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 59
# Loss: 214.7361
# Psi gradient stats:
# Mean: -4.7203e-05
# Std:  3.5854e-03
# Max:  1.6248e-02
# Min:  -1.5781e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 60
# Loss: 214.1480
# Psi gradient stats:
# Mean: -4.7208e-05
# Std:  3.5706e-03
# Max:  1.6220e-02
# Min:  -1.5734e-02
# Epoch 60, Loss: 214.1480, Gradients - Lambda: 5.009e-02, Phi: 5.198e-01, Gamma: 6.753e-03, Psi: 1.622e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 61
# Loss: 213.5925
# Psi gradient stats:
# Mean: -4.7153e-05
# Std:  3.5559e-03
# Max:  1.6191e-02
# Min:  -1.5690e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 62
# Loss: 213.0812
# Psi gradient stats:
# Mean: -4.7009e-05
# Std:  3.5412e-03
# Max:  1.6163e-02
# Min:  -1.5649e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 63
# Loss: 212.6047
# Psi gradient stats:
# Mean: -4.6788e-05
# Std:  3.5268e-03
# Max:  1.6142e-02
# Min:  -1.5610e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 64
# Loss: 212.1488
# Psi gradient stats:
# Mean: -4.6533e-05
# Std:  3.5125e-03
# Max:  1.6127e-02
# Min:  -1.5569e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 65
# Loss: 211.7130
# Psi gradient stats:
# Mean: -4.6304e-05
# Std:  3.4983e-03
# Max:  1.6114e-02
# Min:  -1.5527e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 66
# Loss: 211.3042
# Psi gradient stats:
# Mean: -4.6097e-05
# Std:  3.4842e-03
# Max:  1.6099e-02
# Min:  -1.5484e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 67
# Loss: 210.9155
# Psi gradient stats:
# Mean: -4.5890e-05
# Std:  3.4700e-03
# Max:  1.6078e-02
# Min:  -1.5442e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 68
# Loss: 210.5460
# Psi gradient stats:
# Mean: -4.5636e-05
# Std:  3.4558e-03
# Max:  1.6054e-02
# Min:  -1.5404e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 69
# Loss: 210.1912
# Psi gradient stats:
# Mean: -4.5337e-05
# Std:  3.4416e-03
# Max:  1.6030e-02
# Min:  -1.5373e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 70
# Loss: 209.8522
# Psi gradient stats:
# Mean: -4.5031e-05
# Std:  3.4275e-03
# Max:  1.6007e-02
# Min:  -1.5350e-02
# Epoch 70, Loss: 209.8522, Gradients - Lambda: 4.585e-02, Phi: 3.046e-01, Gamma: 6.515e-03, Psi: 1.601e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch
-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 108
# Loss: 202.0112
# Psi gradient stats:
# Mean: -3.8648e-05
# Std:  2.9410e-03
# Max:  1.5187e-02
# Min:  -1.4451e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 109
# Loss: 201.8598
# Psi gradient stats:
# Mean: -3.8450e-05
# Std:  2.9294e-03
# Max:  1.5166e-02
# Min:  -1.4422e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 110
# Loss: 201.7098
# Psi gradient stats:
# Mean: -3.8267e-05
# Std:  2.9179e-03
# Max:  1.5144e-02
# Min:  -1.4395e-02
# Epoch 110, Loss: 201.7098, Gradients - Lambda: 7.718e-02, Phi: 2.228e-01, Gamma: 5.391e-03, Psi: 1.514e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 111
# Loss: 201.5597
# Psi gradient stats:
# Mean: -3.8116e-05
# Std:  2.9064e-03
# Max:  1.5124e-02
# Min:  -1.4368e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 112
# Loss: 201.4113
# Psi gradient stats:
# Mean: -3.7960e-05
# Std:  2.8950e-03
# Max:  1.5104e-02
# Min:  -1.4342e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 113
# Loss: 201.2645
# Psi gradient stats:
# Mean: -3.7783e-05
# Std:  2.8837e-03
# Max:  1.5083e-02
# Min:  -1.4316e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 114
# Loss: 201.1186
# Psi gradient stats:
# Mean: -3.7644e-05
# Std:  2.8723e-03
# Max:  1.5061e-02
# Min:  -1.4291e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 115
# Loss: 200.9740
# Psi gradient stats:
# Mean: -3.7459e-05
# Std:  2.8611e-03
# Max:  1.5040e-02
# Min:  -1.4267e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 116
# Loss: 200.8302
# Psi gradient stats:
# Mean: -3.7341e-05
# Std:  2.8499e-03
# Max:  1.5019e-02
# Min:  -1.4243e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 117
# Loss: 200.6869
# Psi gradient stats:
# Mean: -3.7186e-05
# Std:  2.8388e-03
# Max:  1.4999e-02
# Min:  -1.4220e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 118
# Loss: 200.5450
# Psi gradient stats:
# Mean: -3.7033e-05
# Std:  2.8277e-03
# Max:  1.4978e-02
# Min:  -1.4197e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 119
# Loss: 200.4044
# Psi gradient stats:
# Mean: -3.6903e-05
# Std:  2.8167e-03
# Max:  1.4957e-02
# Min:  -1.4173e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 120
# Loss: 200.2639
# Psi gradient stats:
# Mean: -3.6754e-05
# Std:  2.8057e-03
# Max:  1.4936e-02
# Min:  -1.4149e-02
# Epoch 120, Loss: 200.2639, Gradients - Lambda: 7.127e-02, Phi: 3.494e-01, Gamma: 5.499e-03, Psi: 1.494e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 121
# Loss: 200.1253
# Psi gradient stats:
# Mean: -3.6622e-05
# Std:  2.7948e-03
# Max:  1.4916e-02
# Min:  -1.4125e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 122
# Loss: 199.9868
# Psi gradient stats:
# Mean: -3.6468e-05
# Std:  2.7839e-03
# Max:  1.4895e-02
# Min:  -1.4102e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 123
# Loss: 199.8493
# Psi gradient stats:
# Mean: -3.6329e-05
# Std:  2.7731e-03
# Max:  1.4875e-02
# Min:  -1.4078e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 124
# Loss: 199.7125
# Psi gradient stats:
# Mean: -3.6188e-05
# Std:  2.7623e-03
# Max:  1.4856e-02
# Min:  -1.4054e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 125
# Loss: 199.5766
# Psi gradient stats:
# Mean: -3.6032e-05
# Std:  2.7516e-03
# Max:  1.4836e-02
# Min:  -1.4030e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch
-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 163
# Loss: 194.9428
# Psi gradient stats:
# Mean: -3.0850e-05
# Std:  2.3824e-03
# Max:  1.4083e-02
# Min:  -1.3128e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 164
# Loss: 194.8335
# Psi gradient stats:
# Mean: -3.0712e-05
# Std:  2.3736e-03
# Max:  1.4064e-02
# Min:  -1.3105e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 165
# Loss: 194.7240
# Psi gradient stats:
# Mean: -3.0593e-05
# Std:  2.3649e-03
# Max:  1.4044e-02
# Min:  -1.3082e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 166
# Loss: 194.6154
# Psi gradient stats:
# Mean: -3.0469e-05
# Std:  2.3561e-03
# Max:  1.4025e-02
# Min:  -1.3060e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 167
# Loss: 194.5082
# Psi gradient stats:
# Mean: -3.0350e-05
# Std:  2.3475e-03
# Max:  1.4005e-02
# Min:  -1.3038e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 168
# Loss: 194.4009
# Psi gradient stats:
# Mean: -3.0238e-05
# Std:  2.3388e-03
# Max:  1.3986e-02
# Min:  -1.3015e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 169
# Loss: 194.2945
# Psi gradient stats:
# Mean: -3.0094e-05
# Std:  2.3302e-03
# Max:  1.3967e-02
# Min:  -1.2992e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 170
# Loss: 194.1891
# Psi gradient stats:
# Mean: -3.0006e-05
# Std:  2.3216e-03
# Max:  1.3948e-02
# Min:  -1.2969e-02
# Epoch 170, Loss: 194.1891, Gradients - Lambda: 9.337e-02, Phi: 3.761e-01, Gamma: 5.496e-03, Psi: 1.395e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 171
# Loss: 194.0829
# Psi gradient stats:
# Mean: -2.9878e-05
# Std:  2.3132e-03
# Max:  1.3929e-02
# Min:  -1.2947e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 172
# Loss: 193.9774
# Psi gradient stats:
# Mean: -2.9772e-05
# Std:  2.3047e-03
# Max:  1.3910e-02
# Min:  -1.2924e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 173
# Loss: 193.8727
# Psi gradient stats:
# Mean: -2.9630e-05
# Std:  2.2963e-03
# Max:  1.3892e-02
# Min:  -1.2902e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 174
# Loss: 193.7690
# Psi gradient stats:
# Mean: -2.9530e-05
# Std:  2.2879e-03
# Max:  1.3872e-02
# Min:  -1.2879e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 175
# Loss: 193.6664
# Psi gradient stats:
# Mean: -2.9429e-05
# Std:  2.2795e-03
# Max:  1.3852e-02
# Min:  -1.2857e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 176
# Loss: 193.5629
# Psi gradient stats:
# Mean: -2.9284e-05
# Std:  2.2712e-03
# Max:  1.3834e-02
# Min:  -1.2835e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 177
# Loss: 193.4612
# Psi gradient stats:
# Mean: -2.9206e-05
# Std:  2.2630e-03
# Max:  1.3816e-02
# Min:  -1.2813e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 178
# Loss: 193.3602
# Psi gradient stats:
# Mean: -2.9040e-05
# Std:  2.2547e-03
# Max:  1.3797e-02
# Min:  -1.2791e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 179
# Loss: 193.2595
# Psi gradient stats:
# Mean: -2.8990e-05
# Std:  2.2466e-03
# Max:  1.3778e-02
# Min:  -1.2768e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 180
# Loss: 193.1597
# Psi gradient stats:
# Mean: -2.8810e-05
# Std:  2.2384e-03
# Max:  1.3759e-02
# Min:  -1.2747e-02
# Epoch 180, Loss: 193.1597, Gradients - Lambda: 1.007e-01, Phi: 3.786e-01, Gamma: 5.439e-03, Psi: 1.376e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch
# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history['max_grad_lambda'], label='Lambda')
ax2.plot(history['max_grad_phi'], label='Phi')
ax2.plot(history['max_grad_gamma'], label='Gamma')
ax2.plot(history['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
disease_names=essentials['disease_names']

# %%
import torch

# Save complete state for R
save_path = '12model_complete_for_R_1218_withnewlrs.pt'

torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t':essentials['prevalence_t'],
    'loit_prevalence_t': model.logit_prev_t,
    'G': G_100k,
    'E': E,
    'indices' : indices,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T':Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, save_path)

# %%
initial_gamma
# Out:
# tensor([[-1.2960e-02,  4.6540e-03,  1.6287e-03, -1.5053e-02, -4.2092e-04,
#           1.6932e-02,  2.1446e-02,  3.5832e-03, -6.8771e-04, -8.6195e-03,
#           1.6670e-04, -1.4271e-02, -2.2448e-03,  6.2877e-04,  2.3186e-02,
#           1.2095e-02,  1.2525e-03,  7.6934e-03, -1.1566e-02,  9.7693e-03],
#         [-2.2430e-01, -2.3607e-01, -2.4155e-01, -2.2063e-01, -2.4280e-01,
#          -2.3736e-01, -2.4573e-01, -2.4156e-01, -2.5045e-01, -2.3748e-01,
#          -2.3757e-01, -2.4017e-01, -2.2834e-01, -2.3261e-01, -2.4629e-01,
#          -2.3860e-01, -2.2975e-01, -2.3232e-01, -2.2934e-01, -2.5411e-01],
#         [-2.0552e-01, -1.9808e-01, -2.0495e-01, -2.1587e-01, -1.9699e-01,
#          -1.9227e-01, -1.9559e-01, -1.8863e-01, -2.0427e-01, -1.9873e-01,
#          -1.9626e-01, -2.0276e-01, -2.0458e-01, -1.9808e-01, -1.9945e-01,
#          -2.1663e-01, -1.9191e-01, -2.1188e-01, -2.0572e-01, -2.0577e-01],
#         [-1.2554e-01, -1.1734e-01, -1.1372e-01, -1.2022e-01, -6.5344e-02,
#          -1.1676e-01, -9.9148e-02, -7.2112e-02, -1.0069e-01, -7.7837e-02,
#          -1.0576e-01, -1.1094e-01, -9.5025e-02, -1.1343e-01, -1.1495e-01,
#          -1.3729e-01, -9.5367e-02, -1.1418e-01, -7.5103e-02, -1.1834e-01],
#         [ 2.1639e-01,  2.1930e-01,  2.1139e-01,  1.7884e-01,  2.1677e-01,
#           2.1967e-01,  2.1070e-01,  2.0863e-01,  2.2605e-01,  2.1828e-01,
#           2.2578e-01,  2.0867e-01,  2.1531e-01,  2.1788e-01,  2.1772e-01,
#           1.6513e-01,  2.2023e-01,  2.7037e-01,  2.1636e-01,  2.1791e-01],
#         [-2.2139e-01, -2.3327e-01, -2.2213e-01, -2.3423e-01, -2.1491e-01,
#          -2.3544e-01, -2.2160e-01, -2.3254e-01, -2.3041e-01, -2.4340e-01,
#          -2.3477e-01, -2.2991e-01, -2.2727e-01, -2.3348e-01, -2.1881e-01,
#          -2.5363e-01, -2.2802e-01, -2.2882e-01, -2.3446e-01, -2.3011e-01],
#         [-5.1803e-01, -5.3559e-01, -5.1570e-01, -4.5795e-01, -4.9339e-01,
#          -5.2780e-01, -5.2004e-01, -5.1305e-01, -4.7981e-01, -5.4933e-01,
#          -5.3635e-01, -5.0884e-01, -5.1230e-01, -5.1325e-01, -5.2484e-01,
#          [ 9.8867e-03,  3.0050e-03, -2.4357e-03,  ...,  3.7537e-03,
#            9.9926e-03,  1.7099e-02],
#          [ 3.8662e-03,  1.3885e-03,  1.8673e-03,  ..., -9.9850e-04,
#            2.2221e-03,  9.1200e-03],
#          ...,
#          [ 7.1182e-03,  2.3565e-03,  3.0718e-03,  ...,  4.3869e-04,
#           -1.3924e-03, -2.4195e-03],
#          [-2.0142e-03, -6.2943e-04,  3.6793e-03,  ..., -2.2974e-03,
#           -5.5647e-03, -5.5637e-03],
#          [-1.6737e-02, -7.2126e-03, -1.8625e-03,  ..., -2.1667e-03,
#           -2.6503e-03, -9.6989e-04]]], grad_fn=<SubBackward0>)

# %%
initial_gamma[0,0]
# Out:
# tensor(-0.0130)

# %%
model.lambda_-initial_lambda
# Out:
# tensor([[[ 4.7292e-03,  3.8226e-03,  1.9118e-03,  ..., -2.1653e-03,
#           -8.7838e-03, -1.9597e-02],
#          [-1.3325e-02, -6.0864e-03, -2.0397e-03,  ...,  2.6888e-03,
#            1.3168e-03, -1.5677e-03],
#          [ 1.5714e-02,  2.4363e-03, -6.2866e-03,  ..., -1.3458e-03,
#           -3.4087e-03,  3.8071e-03],
#          ...,
#          [-1.3016e-02, -4.4819e-03,  5.8222e-04,  ..., -5.6393e-03,
#            1.4034e-03,  1.8050e-02],
#          [ 1.0292e-02,  3.6301e-03, -1.1894e-03,  ...,  3.3200e-04,
#            2.6370e-03,  9.8770e-03],
#          [ 1.5309e-02,  4.5115e-03, -9.4992e-04,  ..., -2.3278e-03,
#            7.6807e-04,  8.6949e-03]],
#
#         [[ 3.1228e-03, -1.8498e-04, -2.9705e-03,  ...,  2.3921e-03,
#           -1.2389e-03, -1.1370e-02],
#          [ 2.2221e-02,  1.1653e-02,  2.7895e-05,  ..., -1.5939e-03,
#           -5.4160e-03, -1.2708e-02],
#          [ 2.0985e-02,  3.6491e-03, -5.1112e-03,  ...,  1.0481e-03,
#           -4.6635e-04, -8.3961e-03],
#          ...,
#          [-7.8024e-03, -2.6433e-03, -5.6446e-05,  ...,  1.1815e-03,
#            2.0671e-03,  3.4466e-03],
#          [ 1.3055e-02,  1.5844e-03, -1.0224e-03,  ...,  2.7245e-03,
#           -2.6596e-04, -8.8201e-03],
#          [ 2.1242e-02,  9.0056e-03, -1.4532e-03,  ...,  1.5785e-03,
#           -6.7045e-03, -1.9135e-02]],
#
#         [[ 9.2194e-03,  5.0005e-03,  1.5104e-04,  ..., -9.6357e-04,
#           -1.1207e-02, -2.4765e-02],
#          [ 1.7190e-02,  8.0072e-03,  9.2787e-04,  ..., -1.8646e-03,
#            5.4171e-03,  9.9245e-03],
#          [-1.3565e-02, -5.8408e-03,  7.5805e-04,  ...,  9.4661e-04,
#            6.3607e-04, -1.8159e-03],
#          ...,
#          [ 5.6460e-03,  9.6025e-03,  6.1421e-03,  ...,  1.6746e-03,
#           -4.0631e-03, -1.1165e-02],
#          [ 1.5754e-02,  2.2956e-03, -2.9839e-03,  ...,  2.0418e-03,
#           -7.9405e-04, -4.4286e-03],
#          [-4.0738e-03, -3.4899e-04,  7.6070e-04,  ...,  2.6807e-03,
#            4.6862e-03,  6.6214e-03]],
#
#         ...,
#
#         [[ 1.2134e-02,  6.8716e-03, -9.9063e-04,  ...,  7.7131e-04,
#            5.5766e-03,  1.6765e-02],
#          [ 6.7251e-03,  2.8682e-03,  2.7031e-03,  ..., -1.3610e-03,
#           -2.7537e-05,  7.4804e-05],
#          [ 7.3473e-03,  3.6882e-03,  1.3003e-03,  ..., -8.1760e-04,
#            1.1729e-03,  1.0558e-02],
#          ...,
#          [-2.6906e-02, -6.7207e-03,  5.7617e-03,  ...,  7.9293e-03,
#           -3.6033e-03, -1.7403e-02],
#          [-1.3640e-02, -4.6218e-03,  3.7133e-03,  ...,  3.1664e-03,
#           -6.1022e-03, -2.2897e-02],
#          [-3.4291e-03,  3.3078e-03,  5.8275e-03,  ...,  1.0405e-03,
#           -6.1396e-03, -2.1187e-02]],
#
#         [[ 6.4634e-03,  2.1873e-03, -1.6876e-03,  ...,  3.8949e-03,
#            5.1959e-03,  1.1537e-02],
#          [ 2.5577e-02,  8.7005e-03, -6.6888e-04,  ...,  1.4384e-03,
#           -2.6903e-03, -5.6248e-03],
#          [-1.5197e-02, -2.8878e-03,  2.7007e-03,  ...,  3.4950e-03,
#            1.2289e-02,  2.2047e-02],
#          ...,
#          [-1.1900e-02, -2.6771e-03,  4.2787e-04,  ..., -1.6962e-03,
#           -6.4182e-04, -7.4255e-04],
#          [-6.0713e-04, -7.3504e-04, -2.1642e-03,  ...,  7.5877e-05,
#           -1.3925e-02, -3.0875e-02],
#          [-6.2749e-03,  1.3085e-03,  4.4049e-03,  ...,  1.7782e-03,
#           -1.1355e-05, -3.2115e-03]],
#
#         [[ 7.5799e-03,  6.9584e-04, -5.0615e-03,  ..., -1.5972e-03,
#           -7.9036e-04, -1.2875e-03],
#          [-1.6603e-02, -5.0294e-03,  2.3227e-03,  ...,  6.5994e-04,
#            3.6943e-03,  9.8546e-03],
#          [ 8.1613e-03,  4.8633e-03,  6.7377e-04,  ..., -1.6551e-03,
#           -8.2016e-05, -2.2588e-03],
#          ...,
#          [ 1.7179e-03,  2.9047e-03,  2.2001e-03,  ...,  2.3890e-04,
#           -7.6777e-03, -2.3316e-02],
#          [ 9.8097e-03,  2.2538e-03, -1.0305e-03,  ..., -4.2508e-03,
#            6.2299e-04,  1.0872e-02],
#          [ 1.7547e-02,  5.7559e-03, -4.8816e-04,  ...,  1.7834e-04,
#            3.3095e-03,  3.4318e-03]]], grad_fn=<SubBackward0>)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert gamma tensors to numpy arrays
initial_gamma_np = initial_gamma.detach().numpy()
final_gamma_np = model.gamma.detach().numpy()

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial gamma
sns.heatmap(initial_gamma_np, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Gamma')

# Plot final gamma
sns.heatmap(final_gamma_np, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Gamma')

# Add a title to the figure
plt.suptitle('Comparison of Initial vs Final Gamma Values', fontsize=16)

# You can also add a colorbar
plt.tight_layout()

# To see the actual difference, you can also create a difference heatmap
plt.figure(figsize=(10, 8))
diff = final_gamma_np - initial_gamma_np
sns.heatmap(diff, cmap='RdBu_r', center=0)
plt.title('Difference (Final - Initial Gamma)')
plt.show()

# Print some summary statistics
print(f"Mean absolute difference: {np.abs(diff).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff):.4f}")
# Out:
# Mean absolute difference: 0.0054
# Max absolute difference: 0.0226
# Standard deviation of differences: 0.0069

# %%
def compare_base_and_gamma_values(Y, G, clusters, K, n_sample=1000,P=36):
    """
    Compare base values with gamma predictions for sampled individuals across signatures
    """
    # Take random sample of people
    N = Y.shape[0]
    sample_idx = torch.randperm(N)[:n_sample]
    Y_sampled = Y[sample_idx]
    G_sampled = G[sample_idx]
    
    # Compute base values (same as before)
    Y_avg = torch.mean(Y_sampled, dim=2)
    epsilon = 1e-8
    Y_avg = torch.log((Y_avg + epsilon)/(1-Y_avg+epsilon))
    
    base_values = torch.zeros(n_sample, K)
    gamma_predictions = torch.zeros(n_sample, K)
    gamma_values = torch.zeros(P, K)
    
    for k in range(K):
        # Get base values
        cluster_diseases = (clusters == k)
        base_values[:, k] = Y_avg[:, cluster_diseases].mean(dim=1)
        
        # Compute gamma and predictions for this signature
        # Fixed: Use G_sampled instead of G
        gamma_k = torch.linalg.lstsq(G_sampled, base_values[:, k].unsqueeze(1)).solution.squeeze()
        gamma_values[:, k] = G_sampled @ gamma_k
        gamma_predictions[:, k] = G_sampled @ gamma_k
    
    # Rest of visualization code remains the same
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
    
    sns.heatmap(base_values.numpy(), 
                cmap='RdBu_r',
                center=0,
                xticklabels=[f'Sig {i}' for i in range(K)],
                yticklabels=False,
                ax=ax1)
    ax1.set_title('Base Values\n(Y logit avg time cluster-specific diseases)')
    ax1.set_xlabel('Signature')
    ax1.set_ylabel('Individual (sampled)')
    
    sns.heatmap(gamma_predictions.numpy(), 
                cmap='RdBu_r',
                center=0,
                xticklabels=[f'Sig {i}' for i in range(K)],
                yticklabels=False,
                ax=ax2)
    ax2.set_title('Gamma Predictions\n(G @ gamma)')
    ax2.set_xlabel('Signature')
    ax2.set_ylabel('Individual (sampled)')
    
    print("\nBase Value Statistics:")
    print(f"Base Values - Overall Mean: {base_values.mean():.2e}")
    print(f"Base Values - Overall Std: {base_values.std():.2e}")
    print(f"Base Values - Std across signatures: {base_values.std(dim=1).mean():.2e}")
    
    print("\nGamma Prediction Statistics:")
    print(f"Predictions - Overall Mean: {gamma_predictions.mean():.2e}")
    print(f"Predictions - Overall Std: {gamma_predictions.std():.2e}")
    print(f"Predictions - Std across signatures: {gamma_predictions.std(dim=1).mean():.2e}")
    
    corr = torch.corrcoef(torch.stack([base_values.flatten(), gamma_predictions.flatten()]))
    print(f"\nCorrelation between base values and predictions: {corr[0,1]:.3f}")
    
    plt.tight_layout()
    plt.show()
    
    return base_values, gamma_predictions, gamma_

# Usage:
base_values, gamma_predictions = compare_base_and_gamma_values(Y, G, clusters, K, n_sample=100,P=36)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 73
#      70     return base_values, gamma_predictions, gamma_
#      72 # Usage:
# ---> 73 base_values, gamma_predictions = compare_base_and_gamma_values(Y, G, clusters, K, n_sample=100,P=36)
#
# NameError: name 'clusters' is not defined

# %%
base_values[1,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 base_values[1,:]
#
# NameError: name 'base_values' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Convert phi tensors to numpy arrays
initial_phi_np = initial_phi.detach().numpy()  # Shape: (K, D, T)
final_phi_np = model.phi.detach().numpy()

# Take mean over time dimension
initial_phi_mean = initial_phi_np.mean(axis=2)  # Shape: (K, D)
final_phi_mean = final_phi_np.mean(axis=2)

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial phi (averaged over time)
sns.heatmap(initial_phi_mean, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Phi (Mean over Time)')
ax1.set_xlabel('Disease')
ax1.set_ylabel('Signature')

# Plot final phi (averaged over time)
sns.heatmap(final_phi_mean, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Phi (Mean over Time)')
ax2.set_xlabel('Disease')
ax2.set_ylabel('Signature')

plt.suptitle('Comparison of Initial vs Final Phi Values (Averaged over Time)', fontsize=16)
plt.tight_layout()

# Plot difference
plt.figure(figsize=(10, 8))
diff_mean = final_phi_mean - initial_phi_mean
sns.heatmap(diff_mean, cmap='RdBu_r', center=0)
plt.title('Difference in Phi (Final - Initial), Mean over Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# Print summary statistics for both full tensor and time-averaged differences
print("Full tensor statistics:")
diff_full = final_phi_np - initial_phi_np
print(f"Mean absolute difference: {np.abs(diff_full).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_full).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_full):.4f}")

print("\nTime-averaged statistics:")
print(f"Mean absolute difference: {np.abs(diff_mean).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_mean).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_mean):.4f}")

# Optionally, look at temporal variation
temporal_std = np.std(diff_full, axis=2)
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_std, cmap='viridis')
plt.title('Standard Deviation of Changes Across Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()
# Out:
# Full tensor statistics:
# Mean absolute difference: 0.0028
# Max absolute difference: 0.0552
# Standard deviation of differences: 0.0039
#
# Time-averaged statistics:
# Mean absolute difference: 0.0002
# Max absolute difference: 0.0016
# Standard deviation of differences: 0.0003

# %%
def track_gamma_changes(initial_gamma, current_gamma):
    diff = (current_gamma - initial_gamma).abs()
    print(f"Gamma changes:")
    print(f"Mean change: {diff.mean():.8f}")
    print(f"Max change: {diff.max():.8f}")
    print(f"Std of changes: {diff.std():.8f}")

# %%
diff = (model.gamma - initial_gamma).abs()
diff
# Out:
# tensor([[6.1180e-03, 8.0931e-03, 1.0433e-02, 4.7477e-03, 1.9343e-03, 5.7579e-03,
#          2.9092e-04, 4.4703e-03, 5.1871e-04, 6.7833e-04, 9.3931e-03, 6.9020e-03,
#          1.4366e-03, 1.1436e-02, 2.7065e-03, 1.1598e-02, 4.8579e-03, 1.5731e-03,
#          3.1053e-03, 3.4991e-03],
#         [2.7525e-03, 2.6716e-04, 1.1738e-02, 2.3328e-03, 4.7472e-04, 6.9842e-05,
#          1.3485e-03, 9.2457e-03, 7.8354e-03, 1.0688e-03, 8.8559e-04, 4.9032e-03,
#          6.7990e-03, 9.1165e-03, 4.1914e-03, 1.5826e-03, 5.9832e-03, 1.0157e-03,
#          4.7536e-03, 5.1955e-03],
#         [2.1708e-03, 2.9404e-03, 4.6144e-03, 4.1030e-03, 2.2396e-03, 2.9502e-03,
#          1.4908e-02, 1.8134e-02, 3.2762e-03, 5.0025e-03, 4.2141e-03, 4.5218e-03,
# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000451
# Mean predicted risk (original): 0.000158
# Mean predicted risk (calibrated): 0.000451
# Calibration scale factor: 2.862

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.775

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, disease_names)
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Retinal vascular changes and abnomalities: effect=1.869 (OR=6.48), std=0.422
# Other retinal disorders: effect=1.432 (OR=4.19), std=0.281
# Myopia: effect=1.326 (OR=3.77), std=0.654
# Retinal detachment with retinal defect: effect=1.322 (OR=3.75), std=0.210
# Glaucoma: effect=1.272 (OR=3.57), std=0.581
# Cataract: effect=1.164 (OR=3.20), std=0.351
# Primary open angle glaucoma: effect=0.600 (OR=1.82), std=0.383
# Disorders of vitreous body: effect=0.593 (OR=1.81), std=0.663
# Ptosis of eyelid: effect=0.185 (OR=1.20), std=0.563
# Abdominal pain: effect=0.171 (OR=1.19), std=1.010
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Bacterial enteritis: effect=3.050 (OR=21.11), std=0.429
# Facial nerve disorders [CN7]: effect=2.766 (OR=15.90), std=0.212
# Seborrheic keratosis: effect=2.119 (OR=8.32), std=0.308
# Other disorders of bone and cartilage: effect=2.057 (OR=7.82), std=0.503
# Acute upper respiratory infections of multiple or unspecified sites: effect=1.966 (OR=7.14), std=0.298
# Breast cancer [female]: effect=1.939 (OR=6.95), std=0.323
# Neoplasm of uncertain behavior: effect=1.840 (OR=6.30), std=0.446
# Acute appendicitis: effect=1.756 (OR=5.79), std=0.369
# Sleep disorders: effect=1.751 (OR=5.76), std=0.403
# Viral Enteritis: effect=1.637 (OR=5.14), std=0.703
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Chronic renal failure [CKD]: effect=2.570 (OR=13.06), std=1.015
# Malignant neoplasm of kidney, except pelvis: effect=2.043 (OR=7.71), std=0.504
# Cyst of kidney, acquired: effect=1.794 (OR=6.01), std=0.332
# Stricture/obstruction of ureter: effect=1.783 (OR=5.95), std=0.887
# Pyelonephritis: effect=1.587 (OR=4.89), std=0.586
# Chronic Kidney Disease, Stage III: effect=1.544 (OR=4.68), std=0.395
# Gram negative septicemia: effect=1.526 (OR=4.60), std=0.339
# Pulmonary collapse; interstitial and compensatory emphysema: effect=1.396 (OR=4.04), std=0.276
# Hypovolemia: effect=1.320 (OR=3.74), std=0.528
# Bacterial infection NOS: effect=1.217 (OR=3.38), std=0.857
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Other chronic ischemic heart disease, unspecified: effect=1.931 (OR=6.90), std=0.314
# Angina pectoris: effect=1.888 (OR=6.60), std=0.572
# Myocardial infarction: effect=1.373 (OR=3.95), std=0.634
# Other acute and subacute forms of ischemic heart disease: effect=1.293 (OR=3.64), std=0.191
# Unstable angina (intermediate coronary syndrome): effect=1.038 (OR=2.82), std=0.543
# Other forms of chronic heart disease: effect=0.818 (OR=2.27), std=0.802
# Hypercholesterolemia: effect=0.699 (OR=2.01), std=0.132
# Ulcerative colitis: effect=0.400 (OR=1.49), std=0.486
# Constipation: effect=0.391 (OR=1.48), std=0.917
# Occlusion of cerebral arteries: effect=0.118 (OR=1.13), std=0.453
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Cervicalgia: effect=2.850 (OR=17.29), std=0.402
# Urinary incontinence: effect=2.348 (OR=10.46), std=0.432
# Other diseases of respiratory system, NEC: effect=2.336 (OR=10.34), std=1.030
# Rheumatism, unspecified and fibrositis: effect=1.840 (OR=6.29), std=0.284
# Asthma: effect=1.779 (OR=5.92), std=0.273
# Other chronic nonalcoholic liver disease: effect=1.632 (OR=5.11), std=0.343
# Parkinson's disease: effect=1.629 (OR=5.10), std=0.388
# Hypothyroidism NOS: effect=1.463 (OR=4.32), std=0.887
# Viral infection: effect=1.438 (OR=4.21), std=0.406
# Irritable Bowel Syndrome: effect=1.389 (OR=4.01), std=0.537
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Urethral stricture (not specified as infectious): effect=2.006 (OR=7.44), std=0.829
# Other disorders of prostate: effect=1.914 (OR=6.78), std=0.284
# Functional disorders of bladder: effect=1.807 (OR=6.09), std=0.999
# Chronic cystitis: effect=0.981 (OR=2.67), std=0.460
# Cystitis: effect=0.502 (OR=1.65), std=0.835
# Hyperplasia of prostate: effect=0.111 (OR=1.12), std=0.720
# Decubitus ulcer: effect=0.064 (OR=1.07), std=0.455
# Bladder neck obstruction: effect=0.060 (OR=1.06), std=0.333
# Allergic rhinitis: effect=-0.003 (OR=1.00), std=1.042
# Malignant neoplasm of ovary: effect=-0.063 (OR=0.94), std=0.160
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Hemorrhage of gastrointestinal tract: effect=2.168 (OR=8.74), std=0.278
# Malignant neoplasm of rectum, rectosigmoid junction, and anus: effect=2.133 (OR=8.44), std=0.960
# Anal and rectal conditions: effect=1.561 (OR=4.76), std=0.231
# Other disorders of intestine: effect=1.187 (OR=3.28), std=0.835
# Benign neoplasm of colon: effect=0.700 (OR=2.01), std=0.486
# Diverticulosis: effect=0.696 (OR=2.01), std=0.783
# Hemorrhoids: effect=0.651 (OR=1.92), std=0.270
# Anal and rectal polyp: effect=0.650 (OR=1.92), std=1.315
# Noninfectious gastroenteritis: effect=0.492 (OR=1.64), std=0.267
# Ulcerative colitis: effect=0.446 (OR=1.56), std=0.507
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Gastric ulcer: effect=2.238 (OR=9.37), std=0.242
# Iron deficiency anemias, unspecified or not due to blood loss: effect=1.611 (OR=5.01), std=0.761
# Ulcer of esophagus: effect=1.554 (OR=4.73), std=0.221
# GERD: effect=1.494 (OR=4.46), std=0.150
# Duodenitis: effect=1.330 (OR=3.78), std=0.462
# Benign neoplasm of other parts of digestive system: effect=1.306 (OR=3.69), std=0.846
# Esophagitis, GERD and related diseases: effect=1.194 (OR=3.30), std=0.459
# Gastritis and duodenitis: effect=1.118 (OR=3.06), std=1.112
# Diaphragmatic hernia: effect=1.075 (OR=2.93), std=0.719
# Reflux esophagitis: effect=1.065 (OR=2.90), std=0.392
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Rheumatoid arthritis: effect=2.174 (OR=8.79), std=1.153
# Enthesopathy: effect=1.657 (OR=5.24), std=1.451
# Other disorders of synovium, tendon, and bursa: effect=1.650 (OR=5.21), std=0.037
# Other peripheral nerve disorders: effect=1.349 (OR=3.85), std=0.201
# Osteoarthrosis, localized, primary: effect=1.124 (OR=3.08), std=0.201
# Acquired toe deformities: effect=1.012 (OR=2.75), std=0.856
# Other derangement of joint: effect=0.991 (OR=2.70), std=0.674
# Transient cerebral ischemia: effect=0.980 (OR=2.66), std=0.762
# Obesity: effect=0.836 (OR=2.31), std=0.420
# Breast cancer [female]: effect=0.784 (OR=2.19), std=0.870
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Chronic sinusitis: effect=2.253 (OR=9.51), std=0.244
# Nasal polyps: effect=1.810 (OR=6.11), std=0.456
# Chronic pharyngitis and nasopharyngitis: effect=1.490 (OR=4.44), std=0.141
# Septal Deviations/Turbinate Hypertrophy: effect=1.256 (OR=3.51), std=0.471
# Other upper respiratory disease: effect=1.058 (OR=2.88), std=0.351
# Myocardial infarction: effect=0.612 (OR=1.84), std=0.626
# Other disorders of bladder: effect=0.238 (OR=1.27), std=1.077
# Bacterial infection NOS: effect=0.074 (OR=1.08), std=0.322
# Sleep disorders: effect=0.050 (OR=1.05), std=0.729
# Bronchiectasis: effect=-0.068 (OR=0.93), std=0.623
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Transient cerebral ischemia: effect=2.837 (OR=17.07), std=1.089
# Occlusion of cerebral arteries: effect=1.726 (OR=5.62), std=0.562
# Cerebral ischemia: effect=1.637 (OR=5.14), std=0.986
# Hemiplegia: effect=1.480 (OR=4.39), std=0.300
# Occlusion and stenosis of precerebral arteries: effect=1.346 (OR=3.84), std=0.385
# Late effects of cerebrovascular disease: effect=1.258 (OR=3.52), std=0.376
# Cerebral artery occlusion, with cerebral infarction: effect=0.787 (OR=2.20), std=0.269
# Cerebrovascular disease: effect=0.277 (OR=1.32), std=0.472
# Acute upper respiratory infections of multiple or unspecified sites: effect=0.213 (OR=1.24), std=0.660
# Melanomas of skin: effect=0.111 (OR=1.12), std=0.404
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Cholelithiasis with acute cholecystitis: effect=1.803 (OR=6.07), std=0.562
# Calculus of bile duct: effect=1.197 (OR=3.31), std=0.517
# Peritoneal adhesions (postoperative) (postinfection): effect=0.848 (OR=2.33), std=0.257
# Other disorders of biliary tract: effect=0.630 (OR=1.88), std=0.391
# Cholecystitis without cholelithiasis: effect=0.583 (OR=1.79), std=0.098
# Acute pancreatitis: effect=0.535 (OR=1.71), std=0.694
# Carbuncle and furuncle: effect=0.306 (OR=1.36), std=0.190
# Abdominal pain: effect=0.126 (OR=1.13), std=0.928
# Cholelithiasis with other cholecystitis: effect=0.108 (OR=1.11), std=0.801
# Epilepsy, recurrent seizures, convulsions: effect=-0.059 (OR=0.94), std=0.757
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Neuralgia, neuritis, and radiculitis NOS: effect=1.925 (OR=6.85), std=0.878
# Other and unspecified disc disorder: effect=1.312 (OR=3.71), std=0.487
# Back pain: effect=1.229 (OR=3.42), std=0.144
# Spinal stenosis: effect=1.177 (OR=3.25), std=0.423
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=1.102 (OR=3.01), std=0.961
# Spondylosis without myelopathy: effect=0.957 (OR=2.60), std=0.935
# Degenerative disease of the spinal cord: effect=0.801 (OR=2.23), std=0.724
# Displacement of intervertebral disc: effect=0.722 (OR=2.06), std=0.339
# Degeneration of intervertebral disc: effect=0.633 (OR=1.88), std=0.910
# Other inflammatory spondylopathies: effect=0.216 (OR=1.24), std=0.572
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Candidiasis: effect=2.040 (OR=7.69), std=0.228
# Sleep apnea: effect=1.936 (OR=6.93), std=0.162
# Gout: effect=1.855 (OR=6.39), std=0.696
# Ingrowing nail: effect=1.729 (OR=5.63), std=0.255
# Cellulitis and abscess of arm/hand: effect=1.727 (OR=5.63), std=0.458
# Inflammatory and toxic neuropathy: effect=1.592 (OR=4.91), std=1.104
# Cancer of prostate: effect=1.567 (OR=4.79), std=0.282
# Other local infections of skin and subcutaneous tissue: effect=1.534 (OR=4.64), std=0.388
# Other disorders of male genital organs: effect=1.524 (OR=4.59), std=0.337
# Varicose veins of lower extremity: effect=1.511 (OR=4.53), std=0.782
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Irregular menstrual cycle/bleeding: effect=2.786 (OR=16.22), std=0.317
# Pelvic peritoneal adhesions, female (postoperative) (postinfection): effect=2.612 (OR=13.63), std=0.309
# Disorders of uterus, NEC: effect=2.224 (OR=9.25), std=0.238
# Disorders of menstruation and other abnormal bleeding from female genital tract: effect=1.605 (OR=4.98), std=1.152
# Postmenopausal bleeding: effect=1.524 (OR=4.59), std=0.348
# Endometriosis: effect=1.330 (OR=3.78), std=0.850
# Prolapse of vaginal walls: effect=1.250 (OR=3.49), std=0.779
# Hypertrophy of female genital organs: effect=1.182 (OR=3.26), std=0.319
# Cervicitis and endocervicitis: effect=1.109 (OR=3.03), std=0.851
# Pain and other symptoms associated with female genital organs: effect=1.095 (OR=2.99), std=0.483
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Type 2 diabetes with ophthalmic manifestations: effect=1.862 (OR=6.44), std=0.265
# Type 2 diabetes: effect=1.521 (OR=4.58), std=0.404
# Type 1 diabetes: effect=1.464 (OR=4.32), std=0.423
# Diabetic retinopathy: effect=0.737 (OR=2.09), std=0.434
# Hypoglycemia: effect=0.541 (OR=1.72), std=0.353
# Viral warts & HPV: effect=-0.137 (OR=0.87), std=0.590
# Cerebrovascular disease: effect=-0.143 (OR=0.87), std=0.517
# Other forms of chronic heart disease: effect=-0.150 (OR=0.86), std=0.751
# Secondary malignancy of respiratory organs: effect=-0.167 (OR=0.85), std=0.931
# Retinal detachment with retinal defect: effect=-0.247 (OR=0.78), std=0.457
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Alcoholic liver damage: effect=2.342 (OR=10.40), std=0.331
# Other disorders of liver: effect=2.061 (OR=7.85), std=0.405
# Esophageal bleeding (varices/hemorrhage): effect=1.663 (OR=5.28), std=0.918
# Hematemesis: effect=1.430 (OR=4.18), std=0.187
# Blood in stool: effect=1.373 (OR=3.95), std=0.257
# Alcohol-related disorders: effect=0.848 (OR=2.33), std=0.156
# Hypopotassemia: effect=0.796 (OR=2.22), std=0.154
# Thrombocytopenia: effect=0.371 (OR=1.45), std=0.338
# First degree AV block: effect=0.353 (OR=1.42), std=0.491
# Renal failure NOS: effect=0.347 (OR=1.41), std=1.276
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Paroxysmal supraventricular tachycardia: effect=2.777 (OR=16.07), std=0.418
# Rheumatic disease of the heart valves: effect=2.452 (OR=11.61), std=0.700
# Congenital anomalies of great vessels: effect=1.821 (OR=6.18), std=0.320
# Paroxysmal ventricular tachycardia: effect=1.355 (OR=3.88), std=1.175
# Atrial fibrillation and flutter: effect=1.353 (OR=3.87), std=0.246
# Heart failure NOS: effect=1.330 (OR=3.78), std=0.487
# Aortic valve disease: effect=1.022 (OR=2.78), std=0.377
# Cardiomegaly: effect=0.968 (OR=2.63), std=0.535
# Pleurisy; pleural effusion: effect=0.937 (OR=2.55), std=0.293
# Other forms of chronic heart disease: effect=0.863 (OR=2.37), std=0.777
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Pneumonia: effect=3.094 (OR=22.07), std=0.342
# Cancer of bronchus; lung: effect=2.255 (OR=9.53), std=0.251
# Respiratory failure: effect=1.554 (OR=4.73), std=0.075
# Obstructive chronic bronchitis: effect=1.388 (OR=4.01), std=0.734
# Postinflammatory pulmonary fibrosis: effect=1.375 (OR=3.96), std=0.907
# Empyema and pneumothorax: effect=1.194 (OR=3.30), std=0.353
# Bronchiectasis: effect=1.070 (OR=2.91), std=0.350
# Emphysema: effect=0.796 (OR=2.22), std=0.837
# Chronic airway obstruction: effect=0.668 (OR=1.95), std=0.465
# Sepsis: effect=0.430 (OR=1.54), std=0.388
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Neutropenia: effect=1.949 (OR=7.02), std=0.254
# Malignant neoplasm of ovary: effect=1.134 (OR=3.11), std=0.381
# Secondary malignancy of lymph nodes: effect=0.877 (OR=2.40), std=0.729
# Secondary malignancy of bone: effect=0.784 (OR=2.19), std=0.178
# Malignant neoplasm, other: effect=0.449 (OR=1.57), std=0.459
# Secondary malignancy of respiratory organs: effect=0.300 (OR=1.35), std=0.498
# Hemangioma and lymphangioma, any site: effect=0.260 (OR=1.30), std=0.733
# Secondary malignant neoplasm: effect=0.202 (OR=1.22), std=1.037
# Secondary malignant neoplasm of liver: effect=0.017 (OR=1.02), std=0.481
# Non-Hodgkins lymphoma: effect=-0.055 (OR=0.95), std=0.041

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, disease_names)

# %%
model.visualize_clusters(disease_names)
model.visualize_initialization()

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,1,14,15,16,13,17])
