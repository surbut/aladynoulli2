# %%
# %load_ext autoreload
# %autoreload 2

from cluster_g_logit_init_acceptpsi_flatlam import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2



# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/1184199116.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/1184199116.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/1184199116.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/1184199116.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/filesforupload/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'filtered_3plus/Y_tensor_filtered.pt')
    E = torch.load(base_path + 'filtered_3plus/E_matrix_filtered.pt')
    G = torch.load(base_path + 'filtered_3plus/G_matrix_filtered.pt')
    
    # Load other components
    essentials = torch.load('/Users/sarahurbut/Dropbox (Personal)/data_for_running/model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/511890075.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'filtered_3plus/Y_tensor_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/511890075.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'filtered_3plus/E_matrix_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/511890075.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'filtered_3plus/G_matrix_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/511890075.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load('/Users/sarahurbut/Dropbox (Personal)/data_for_running/model_essentials.pt')
# Loaded all components successfully!

# %%
# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000,seed=1)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([314976, 348, 52]), E=torch.Size([314976, 348]), G=(314976, 36)
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=(10000, 36)

# %%
# When initializing the model:
original_G = G_100k # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/1949801412.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/1949801412.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
# Load references (signatures only, no healthy)
refs = torch.load('reference_trajectories.pt')
signature_refs = refs['signature_refs']

torch.manual_seed(7)
np.random.seed(4)
# Create model without healthy reference
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_100k.shape[1],
    G=G_100k, 
    Y=Y_100k,
    prevalence_t=essentials['prevalence_t'],
     disease_names=essentials['disease_names']
)

torch.manual_seed(4)
np.random.seed(4)
# Initialize with psi and clusters
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_83988/2118269527.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('reference_trajectories.pt')
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
#
# Cluster Sizes:
# Cluster 0: 18 diseases
# Cluster 1: 28 diseases
# Cluster 2: 99 diseases
# Cluster 3: 13 diseases
# Cluster 4: 18 diseases
# Cluster 5: 28 diseases
# Cluster 6: 5 diseases
# Cluster 7: 11 diseases
# Cluster 8: 9 diseases
# Cluster 9: 17 diseases
# Cluster 10: 7 diseases
# Cluster 11: 13 diseases
# Cluster 12: 9 diseases
# Cluster 13: 5 diseases
# Cluster 14: 9 diseases
# Cluster 15: 21 diseases
# Cluster 16: 10 diseases
# Cluster 17: 6 diseases
# Cluster 18: 15 diseases
# Cluster 19: 7 diseases
# Initialization complete!
#
# Using true psi from simulation
# Initialization complete!
#
# Clusters match exactly: True

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Initial Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Initial Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
model.plot_initial_params()
# Convert disease names to list if it's not already
disease_names_list = list(essentials['disease_names'])

# Now visualize clusters
model.visualize_clusters(disease_names=disease_names_list)
# Out:
# Cluster membership for sampled diseases:
# Disease 63: Cluster 16
# Disease 34: Cluster 3
# Disease 146: Cluster 16
# Disease 223: Cluster 3
# Disease 134: Cluster 11
#
# Cluster Assignments:
#
# Cluster 0:
#   - Rheumatic disease of the heart valves (prevalence: 0.0003)
#   - Mitral valve disease (prevalence: 0.0004)
#   - Aortic valve disease (prevalence: 0.0002)
#   - Disease of tricuspid valve (prevalence: 0.0003)
#   - Other forms of chronic heart disease (prevalence: 0.0006)
#   - Cardiomegaly (prevalence: 0.0006)
#   - Pericarditis (prevalence: 0.0002)
#   - Primary/intrinsic cardiomyopathies (prevalence: 0.0001)
#   - Left bundle branch block (prevalence: 0.0004)
#   - Paroxysmal supraventricular tachycardia (prevalence: 0.0003)
#   - Paroxysmal ventricular tachycardia (prevalence: 0.0001)
#   - Atrial fibrillation and flutter (prevalence: 0.0012)
#   - Congestive heart failure (CHF) NOS (prevalence: 0.0005)
#   - Heart failure NOS (prevalence: 0.0009)
#   - Pleurisy; pleural effusion (prevalence: 0.0012)
#   - Congenital anomalies of great vessels (prevalence: 0.0003)
#
# Cluster 1:
#   - Other peripheral nerve disorders (prevalence: 0.0011)
#   - Rheumatoid arthritis (prevalence: 0.0006)
#   - Arthropathy NOS (prevalence: 0.0051)
#   - Peripheral enthesopathies and allied syndromes (prevalence: 0.0006)
#   - Enthesopathy (prevalence: 0.0010)
#   - Other disorders of synovium, tendon, and bursa (prevalence: 0.0001)
#   - Synovitis and tenosynovitis (prevalence: 0.0003)
#   - Acquired toe deformities (prevalence: 0.0002)
#   - Hammer toe (acquired) (prevalence: 0.0002)
#   - Hallux rigidus (prevalence: 0.0001)
#   - Hallux valgus (Bunion) (prevalence: 0.0006)
#   - Other acquired deformities of limbs (prevalence: 0.0002)
#   - Osteoarthritis; localized (prevalence: 0.0012)
#   - Osteoarthrosis, localized, primary (prevalence: 0.0008)
#   - Osteoarthrosis, generalized (prevalence: 0.0007)
#   - Osteoarthrosis NOS (prevalence: 0.0001)
#   - Symptoms and disorders of the joints (prevalence: 0.0001)
#   - Joint effusions (prevalence: 0.0002)
#   - Other derangement of joint (prevalence: 0.0003)
#   - Pain in joint (prevalence: 0.0010)
#   - Internal derangement of knee (prevalence: 0.0012)
#
# Cluster 2:
#   - Benign neoplasm of other parts of digestive system (prevalence: 0.0009)
#   - Iron deficiency anemias, unspecified or not due to blood loss (prevalence: 0.0013)
#   - Esophagitis, GERD and related diseases (prevalence: 0.0009)
#   - Ulcer of esophagus (prevalence: 0.0005)
#   - Barrett's esophagus (prevalence: 0.0004)
#   - Reflux esophagitis (prevalence: 0.0012)
#   - Esophageal bleeding (varices/hemorrhage) (prevalence: 0.0003)
#   - Stricture and stenosis of esophagus (prevalence: 0.0003)
#   - Gastric ulcer (prevalence: 0.0006)
#   - Duodenal ulcer (prevalence: 0.0003)
#   - Gastritis and duodenitis (prevalence: 0.0019)
#   - Duodenitis (prevalence: 0.0008)
#   - Other specified gastritis (prevalence: 0.0012)
#   - Other disorders of stomach and duodenum (prevalence: 0.0005)
#   - Diaphragmatic hernia (prevalence: 0.0031)
#
# Cluster 3:
#   - Bacterial enteritis (prevalence: 0.0002)
#   - Viral Enteritis (prevalence: 0.0001)
#   - Viral infection (prevalence: 0.0005)
#   - Malignant neoplasm of kidney, except pelvis (prevalence: 0.0001)
#   - Neoplasm of uncertain behavior (prevalence: 0.0002)
#   - Non-Hodgkins lymphoma (prevalence: 0.0002)
#   - Benign neoplasm of lip, oral cavity, and pharynx (prevalence: 0.0001)
#   - Lipoma (prevalence: 0.0002)
#   - Lipoma of skin and subcutaneous tissue (prevalence: 0.0004)
#   - Other benign neoplasm of connective and other soft tissue (prevalence: 0.0001)
#   - Hemangioma and lymphangioma, any site (prevalence: 0.0002)
#   - Gout (prevalence: 0.0006)
#   - Bipolar (prevalence: 0.0001)
#   - Alcohol-related disorders (prevalence: 0.0006)
#   - Alcoholic liver damage (prevalence: 0.0001)
#   - Sleep disorders (prevalence: 0.0001)
#   - Parkinson's disease (prevalence: 0.0002)
#   - Multiple sclerosis (prevalence: 0.0001)
#   - Epilepsy, recurrent seizures, convulsions (prevalence: 0.0004)
#   - Facial nerve disorders [CN7] (prevalence: 0.0001)
#   - Inflammatory and toxic neuropathy (prevalence: 0.0003)
#   - Visual disturbances (prevalence: 0.0002)
#   - Inflammation of eyelids (prevalence: 0.0002)
#   - Disorders of conjunctiva (prevalence: 0.0001)
#   - Ptosis of eyelid (prevalence: 0.0002)
#   - Strabismus (not specified as paralytic) (prevalence: 0.0001)
#   - Otitis media (prevalence: 0.0001)
#   - Perforation of tympanic membrane (prevalence: 0.0001)
#   - Hearing loss (prevalence: 0.0007)
#   - Pulmonary heart disease (prevalence: 0.0006)
#   - First degree AV block (prevalence: 0.0003)
#   - Right bundle branch block (prevalence: 0.0004)
#   - Cardiac arrest (prevalence: 0.0002)
#   - Arrhythmia (cardiac) NOS (prevalence: 0.0002)
#   - Abdominal aortic aneurysm (prevalence: 0.0001)
#   - Raynaud's syndrome (prevalence: 0.0002)
#   - Peripheral vascular disease, unspecified (prevalence: 0.0004)
#   - Stricture of artery (prevalence: 0.0001)
#   - Phlebitis and thrombophlebitis of lower extremities (prevalence: 0.0005)
#   - Varicose veins of lower extremity (prevalence: 0.0008)
#   - Acute upper respiratory infections of multiple or unspecified sites (prevalence: 0.0002)
#   - Acute pharyngitis (prevalence: 0.0001)
#   - Diseases of the larynx and vocal cords (prevalence: 0.0001)
#   - Chronic tonsillitis and adenoiditis (prevalence: 0.0001)
#   - Allergic rhinitis (prevalence: 0.0003)
#   - Disturbances in tooth eruption (prevalence: 0.0001)
#   - Dental caries (prevalence: 0.0003)
#   - Periapical abscess (prevalence: 0.0001)
#   - Chronic periodontitis (prevalence: 0.0001)
#   - Other diseases of the teeth and supporting structures (prevalence: 0.0003)
#   - Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue (prevalence: 0.0002)
#   - Diseases and other conditions of the tongue (prevalence: 0.0001)
#   - Acute gastritis (prevalence: 0.0001)
#   - Acute appendicitis (prevalence: 0.0002)
#   - Inguinal hernia (prevalence: 0.0014)
#   - Umbilical hernia (prevalence: 0.0004)
#   - Celiac disease (prevalence: 0.0002)
#   - Functional digestive disorders (prevalence: 0.0001)
#   - Other disorders of liver (prevalence: 0.0003)
#   - Hematemesis (prevalence: 0.0002)
#   - Blood in stool (prevalence: 0.0003)
#   - Cyst of kidney, acquired (prevalence: 0.0004)
#   - Other disorders of testis (prevalence: 0.0001)
#   - Hydrocele (prevalence: 0.0001)
#   - Redundant prepuce and phimosis/BXO (prevalence: 0.0002)
#   - Other disorders of male genital organs (prevalence: 0.0003)
#   - Benign neoplasm of breast (prevalence: 0.0001)
#   - Hypertrophy of breast (Gynecomastia) (prevalence: 0.0001)
#   - Noninflammatory disorders of vulva and perineum (prevalence: 0.0001)
#   - Infertility, female (prevalence: 0.0000)
#   - Carbuncle and furuncle (prevalence: 0.0003)
#   - Psoriasis vulgaris (prevalence: 0.0003)
#   - Ingrowing nail (prevalence: 0.0001)
#   - Sebaceous cyst (prevalence: 0.0007)
#   - Polymyalgia Rheumatica (prevalence: 0.0003)
#   - Bursitis (prevalence: 0.0001)
#   - Ganglion and cyst of synovium, tendon, and bursa (prevalence: 0.0003)
#   - Contracture of palmar fascia [Dupuytren's disease] (prevalence: 0.0003)
#   - Malunion and nonunion of fracture (prevalence: 0.0001)
#   - Osteopenia or other disorder of bone and cartilage (prevalence: 0.0001)
#   - Atopic/contact dermatitis due to other or unspecified (prevalence: 0.0004)
#   - Other tests (prevalence: 0.0003)
#
# Cluster 4:
#   - Septal Deviations/Turbinate Hypertrophy (prevalence: 0.0003)
#   - Nasal polyps (prevalence: 0.0003)
#   - Chronic pharyngitis and nasopharyngitis (prevalence: 0.0001)
#   - Chronic sinusitis (prevalence: 0.0002)
#   - Other upper respiratory disease (prevalence: 0.0004)
#
# Cluster 5:
#   - Hypercholesterolemia (prevalence: 0.0043)
#   - Unstable angina (intermediate coronary syndrome) (prevalence: 0.0004)
#   - Myocardial infarction (prevalence: 0.0015)
#   - Angina pectoris (prevalence: 0.0019)
#   - Coronary atherosclerosis (prevalence: 0.0022)
#   - Other chronic ischemic heart disease, unspecified (prevalence: 0.0019)
#   - Other acute and subacute forms of ischemic heart disease (prevalence: 0.0002)
#
# Cluster 6:
#   - Cancer of bronchus; lung (prevalence: 0.0004)
#   - Malignant neoplasm, other (prevalence: 0.0003)
#   - Secondary malignant neoplasm (prevalence: 0.0003)
#   - Secondary malignancy of lymph nodes (prevalence: 0.0008)
#   - Secondary malignancy of respiratory organs (prevalence: 0.0004)
#   - Secondary malignant neoplasm of digestive systems (prevalence: 0.0003)
#   - Secondary malignant neoplasm of liver (prevalence: 0.0005)
#   - Secondary malignancy of bone (prevalence: 0.0004)
#
# Cluster 7:
#   - Hypothyroidism NOS (prevalence: 0.0017)
#   - Hyperlipidemia (prevalence: 0.0009)
#   - Obesity (prevalence: 0.0024)
#   - Major depressive disorder (prevalence: 0.0019)
#   - Anxiety disorder (prevalence: 0.0014)
#   - Sleep apnea (prevalence: 0.0005)
#   - Migraine (prevalence: 0.0004)
#   - Essential hypertension (prevalence: 0.0091)
#   - Asthma (prevalence: 0.0027)
#   - GERD (prevalence: 0.0026)
#   - Irritable Bowel Syndrome (prevalence: 0.0008)
#   - Other chronic nonalcoholic liver disease (prevalence: 0.0004)
#   - Other inflammatory spondylopathies (prevalence: 0.0002)
#   - Spondylosis and allied disorders (prevalence: 0.0006)
#   - Other disorders of soft tissues (prevalence: 0.0008)
#   - Rheumatism, unspecified and fibrositis (prevalence: 0.0001)
#   - Other disorders of bone and cartilage (prevalence: 0.0005)
#   - Osteoporosis NOS (prevalence: 0.0011)
#   - Cervicalgia (prevalence: 0.0002)
#   - Myalgia and myositis unspecified (prevalence: 0.0003)
#   - Pain in limb (prevalence: 0.0008)
#   - Abdominal pain (prevalence: 0.0010)
#
# Cluster 8:
#   - Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] (prevalence: 0.0001)
#   - Malignant neoplasm of uterus (prevalence: 0.0002)
#   - Malignant neoplasm of ovary (prevalence: 0.0001)
#   - Uterine leiomyoma (prevalence: 0.0008)
#   - Benign neoplasm of ovary (prevalence: 0.0002)
#   - Pelvic peritoneal adhesions, female (postoperative) (postinfection) (prevalence: 0.0003)
#   - Cervicitis and endocervicitis (prevalence: 0.0001)
#   - Endometriosis (prevalence: 0.0003)
#   - Prolapse of vaginal walls (prevalence: 0.0006)
#   - Uterine/Uterovaginal prolapse (prevalence: 0.0004)
#   - Disorders of uterus, NEC (prevalence: 0.0003)
#   - Noninflammatory disorders of cervix (prevalence: 0.0002)
#   - Noninflammatory disorders of vagina (prevalence: 0.0001)
#   - Endometrial hyperplasia (prevalence: 0.0001)
#   - Polyp of corpus uteri (prevalence: 0.0006)
#   - Mucous polyp of cervix (prevalence: 0.0002)
#   - Hypertrophy of female genital organs (prevalence: 0.0001)
#   - Pain and other symptoms associated with female genital organs (prevalence: 0.0001)
#   - Dyspareunia (prevalence: 0.0001)
#   - Disorders of menstruation and other abnormal bleeding from female genital tract (prevalence: 0.0001)
#   - Irregular menstrual cycle/bleeding (prevalence: 0.0001)
#   - Excessive or frequent menstruation (prevalence: 0.0006)
#   - Irregular menstrual cycle (prevalence: 0.0001)
#   - Irregular menstrual bleeding (prevalence: 0.0002)
#   - Dysmenorrhea (prevalence: 0.0001)
#   - Postmenopausal bleeding (prevalence: 0.0008)
#   - Postmenopausal atrophic vaginitis (prevalence: 0.0001)
#   - Ovarian cyst (prevalence: 0.0004)
#
# Cluster 9:
#   - Degenerative disease of the spinal cord (prevalence: 0.0002)
#   - Spinal stenosis (prevalence: 0.0007)
#   - Spondylosis without myelopathy (prevalence: 0.0010)
#   - Displacement of intervertebral disc (prevalence: 0.0003)
#   - Degeneration of intervertebral disc (prevalence: 0.0005)
#   - Other and unspecified disc disorder (prevalence: 0.0006)
#   - Kyphoscoliosis and scoliosis (prevalence: 0.0002)
#   - Acquired spondylolisthesis (prevalence: 0.0002)
#   - Back pain (prevalence: 0.0016)
#   - Thoracic or lumbosacral neuritis or radiculitis, unspecified (prevalence: 0.0005)
#   - Sciatica (prevalence: 0.0004)
#   - Neuralgia, neuritis, and radiculitis NOS (prevalence: 0.0002)
#
# Cluster 10:
#   - Retinal detachments and defects (prevalence: 0.0002)
#   - Retinal detachment with retinal defect (prevalence: 0.0001)
#   - Other retinal disorders (prevalence: 0.0002)
#   - Macular degeneration (senile) of retina NOS (prevalence: 0.0006)
#   - Retinal vascular changes and abnomalities (prevalence: 0.0001)
#   - Glaucoma (prevalence: 0.0007)
#   - Primary open angle glaucoma (prevalence: 0.0002)
#   - Cataract (prevalence: 0.0024)
#   - Senile cataract (prevalence: 0.0020)
#   - Myopia (prevalence: 0.0002)
#   - Disorders of vitreous body (prevalence: 0.0003)
#
# Cluster 11:
#   - Hemiplegia (prevalence: 0.0003)
#   - Cerebrovascular disease (prevalence: 0.0003)
#   - Occlusion and stenosis of precerebral arteries (prevalence: 0.0002)
#   - Occlusion of cerebral arteries (prevalence: 0.0004)
#   - Cerebral artery occlusion, with cerebral infarction (prevalence: 0.0003)
#   - Cerebral ischemia (prevalence: 0.0003)
#   - Transient cerebral ischemia (prevalence: 0.0003)
#   - Late effects of cerebrovascular disease (prevalence: 0.0002)
#
# Cluster 12:
#   - Other disorders of the kidney and ureters (prevalence: 0.0002)
#   - Stricture/obstruction of ureter (prevalence: 0.0001)
#   - Pyelonephritis (prevalence: 0.0002)
#   - Calculus of kidney (prevalence: 0.0004)
#   - Calculus of ureter (prevalence: 0.0002)
#   - Renal colic (prevalence: 0.0001)
#   - Hydronephrosis (prevalence: 0.0004)
#
# Cluster 13:
#   - Cancer of prostate (prevalence: 0.0008)
#   - Malignant neoplasm of bladder (prevalence: 0.0003)
#   - Cystitis (prevalence: 0.0002)
#   - Chronic cystitis (prevalence: 0.0001)
#   - Other disorders of bladder (prevalence: 0.0009)
#   - Bladder neck obstruction (prevalence: 0.0002)
#   - Functional disorders of bladder (prevalence: 0.0002)
#   - Urethral stricture (not specified as infectious) (prevalence: 0.0003)
#   - Other symptoms/disorders or the urinary system (prevalence: 0.0001)
#   - Urinary incontinence (prevalence: 0.0006)
#   - Hyperplasia of prostate (prevalence: 0.0016)
#   - Chronic prostatitis (prevalence: 0.0001)
#   - Other disorders of prostate (prevalence: 0.0002)
#
# Cluster 14:
#   - Tobacco use disorder (prevalence: 0.0015)
#   - Pneumonia (prevalence: 0.0008)
#   - Pneumococcal pneumonia (prevalence: 0.0012)
#   - Chronic airway obstruction (prevalence: 0.0013)
#   - Emphysema (prevalence: 0.0004)
#   - Obstructive chronic bronchitis (prevalence: 0.0005)
#   - Bronchiectasis (prevalence: 0.0004)
#   - Postinflammatory pulmonary fibrosis (prevalence: 0.0002)
#   - Empyema and pneumothorax (prevalence: 0.0002)
#   - Respiratory failure (prevalence: 0.0005)
#
# Cluster 15:
#   - Type 1 diabetes (prevalence: 0.0003)
#   - Type 2 diabetes (prevalence: 0.0026)
#   - Type 2 diabetes with ophthalmic manifestations (prevalence: 0.0002)
#   - Diabetic retinopathy (prevalence: 0.0003)
#   - Hypoglycemia (prevalence: 0.0002)
#
# Cluster 16:
#   - Gram negative septicemia (prevalence: 0.0002)
#   - Bacterial infection NOS (prevalence: 0.0008)
#   - Staphylococcus infections (prevalence: 0.0004)
#   - Streptococcus infection (prevalence: 0.0002)
#   - E. coli (prevalence: 0.0005)
#   - Candidiasis (prevalence: 0.0004)
#   - Disorders of calcium/phosphorus metabolism (prevalence: 0.0003)
#   - Hyposmolality and/or hyponatremia (prevalence: 0.0006)
#   - Hyperpotassemia (prevalence: 0.0002)
#   - Hypopotassemia (prevalence: 0.0005)
#   - Acidosis (prevalence: 0.0003)
#   - Hypovolemia (prevalence: 0.0008)
#   - Other anemias (prevalence: 0.0018)
#   - Thrombocytopenia (prevalence: 0.0003)
#   - Neutropenia (prevalence: 0.0004)
#   - Orthostatic hypotension (prevalence: 0.0004)
#   - Hypotension NOS (prevalence: 0.0009)
#   - Bacterial pneumonia (prevalence: 0.0002)
#   - Pulmonary collapse; interstitial and compensatory emphysema (prevalence: 0.0006)
#   - Other diseases of respiratory system, NEC (prevalence: 0.0012)
#   - Constipation (prevalence: 0.0019)
#   - Peritonitis and retroperitoneal infections (prevalence: 0.0001)
#   - Acute renal failure (prevalence: 0.0016)
#   - Urinary tract infection (prevalence: 0.0019)
#   - Cellulitis and abscess of arm/hand (prevalence: 0.0007)
#   - Other local infections of skin and subcutaneous tissue (prevalence: 0.0002)
#   - Chronic ulcer of skin (prevalence: 0.0002)
#   - Decubitus ulcer (prevalence: 0.0003)
#   - Sepsis (prevalence: 0.0008)
#
# Cluster 17:
#   - Colon cancer (prevalence: 0.0004)
#   - Malignant neoplasm of rectum, rectosigmoid junction, and anus (prevalence: 0.0002)
#   - Neoplasm of unspecified nature of digestive system (prevalence: 0.0001)
#   - Benign neoplasm of colon (prevalence: 0.0028)
#   - Hemorrhoids (prevalence: 0.0027)
#   - Ventral hernia (prevalence: 0.0004)
#   - Regional enteritis (prevalence: 0.0002)
#   - Ulcerative colitis (prevalence: 0.0003)
#   - Noninfectious gastroenteritis (prevalence: 0.0014)
#   - Other intestinal obstruction (prevalence: 0.0005)
#   - Diverticulosis (prevalence: 0.0038)
#   - Anal and rectal conditions (prevalence: 0.0009)
#   - Anal and rectal polyp (prevalence: 0.0010)
#   - Other disorders of intestine (prevalence: 0.0005)
#   - Gastrointestinal complications (prevalence: 0.0001)
#   - Hemorrhage of rectum and anus (prevalence: 0.0011)
#   - Hemorrhage of gastrointestinal tract (prevalence: 0.0010)
#
# Cluster 18:
#   - Peritoneal adhesions (postoperative) (postinfection) (prevalence: 0.0005)
#   - Cholelithiasis (prevalence: 0.0009)
#   - Cholelithiasis with acute cholecystitis (prevalence: 0.0002)
#   - Cholelithiasis with other cholecystitis (prevalence: 0.0006)
#   - Calculus of bile duct (prevalence: 0.0003)
#   - Cholecystitis without cholelithiasis (prevalence: 0.0003)
#   - Other disorders of gallbladder (prevalence: 0.0002)
#   - Other disorders of biliary tract (prevalence: 0.0002)
#   - Acute pancreatitis (prevalence: 0.0003)
#
# Cluster 19:
#   - Viral warts & HPV (prevalence: 0.0001)
#   - Melanomas of skin (prevalence: 0.0003)
#   - Other non-epithelial cancer of skin (prevalence: 0.0014)
#   - Breast cancer [female] (prevalence: 0.0002)
#   - Malignant neoplasm of female breast (prevalence: 0.0009)
#   - Benign neoplasm of skin (prevalence: 0.0007)
#   - Thyrotoxicosis with or without goiter (prevalence: 0.0002)
#   - Secondary hypothyroidism (prevalence: 0.0002)
#   - Other disorders of eyelids (prevalence: 0.0003)
#   - Ectropion or entropion (prevalence: 0.0001)
#   - Disorders of lacrimal system (prevalence: 0.0002)
#   - Epiphora (prevalence: 0.0001)
#   - Hypertensive chronic kidney disease (prevalence: 0.0001)
#   - Chronic glomerulonephritis, NOS (prevalence: 0.0001)
#   - Renal failure NOS (prevalence: 0.0002)
#   - Chronic renal failure [CKD] (prevalence: 0.0007)
#   - Chronic Kidney Disease, Stage III (prevalence: 0.0009)
#   - Lump or mass in breast (prevalence: 0.0001)
#   - Disorder of skin and subcutaneous tissue NOS (prevalence: 0.0006)
#   - Other hypertrophic and atrophic conditions of skin (prevalence: 0.0002)
#   - Scar conditions and fibrosis of skin (prevalence: 0.0002)
#   - Actinic keratosis (prevalence: 0.0004)
#   - Seborrheic keratosis (prevalence: 0.0004)

# %%
model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam.py:719: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000560
# Mean predicted risk (original): 0.000176
# Mean predicted risk (calibrated): 0.000560
# Calibration scale factor: 3.185

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.623

# %%
history_new = model.fit(E_100k, num_epochs=100, learning_rate=1e-3, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam.py:209: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=1e-4:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Lambda changes with lr=1e-4:
# Mean absolute change: 5.088e-05
# Max absolute change: 3.626e-03
# Std of changes: 4.792e-05

# %%
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# Clusters match exactly: True

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history_new['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history_new['max_grad_lambda'], label='Lambda')
ax2.plot(history_new['max_grad_phi'], label='Phi')
ax2.plot(history_new['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert gamma tensors to numpy arrays
initial_gamma_np = initial_gamma.detach().numpy()
final_gamma_np = model.gamma.detach().numpy()

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial gamma
sns.heatmap(initial_gamma_np, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Gamma')

# Plot final gamma
sns.heatmap(final_gamma_np, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Gamma')

# Add a title to the figure
plt.suptitle('Comparison of Initial vs Final Gamma Values', fontsize=16)

# You can also add a colorbar
plt.tight_layout()

# To see the actual difference, you can also create a difference heatmap
plt.figure(figsize=(10, 8))
diff = final_gamma_np - initial_gamma_np
sns.heatmap(diff, cmap='RdBu_r', center=0)
plt.title('Difference (Final - Initial Gamma)')
plt.show()

# Print some summary statistics
print(f"Mean absolute difference: {np.abs(diff).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff):.4f}")
# Out:
# Mean absolute difference: 0.0001
# Max absolute difference: 0.0020
# Standard deviation of differences: 0.0002

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Convert phi tensors to numpy arrays
initial_phi_np = initial_phi.detach().numpy()  # Shape: (K, D, T)
final_phi_np = model.phi.detach().numpy()

# Take mean over time dimension
initial_phi_mean = initial_phi_np.mean(axis=2)  # Shape: (K, D)
final_phi_mean = final_phi_np.mean(axis=2)

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial phi (averaged over time)
sns.heatmap(initial_phi_mean, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Phi (Mean over Time)')
ax1.set_xlabel('Disease')
ax1.set_ylabel('Signature')

# Plot final phi (averaged over time)
sns.heatmap(final_phi_mean, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Phi (Mean over Time)')
ax2.set_xlabel('Disease')
ax2.set_ylabel('Signature')

plt.suptitle('Comparison of Initial vs Final Phi Values (Averaged over Time)', fontsize=16)
plt.tight_layout()

# Plot difference
plt.figure(figsize=(10, 8))
diff_mean = final_phi_mean - initial_phi_mean
sns.heatmap(diff_mean, cmap='RdBu_r', center=0)
plt.title('Difference in Phi (Final - Initial), Mean over Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# Print summary statistics for both full tensor and time-averaged differences
print("Full tensor statistics:")
diff_full = final_phi_np - initial_phi_np
print(f"Mean absolute difference: {np.abs(diff_full).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_full).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_full):.4f}")

print("\nTime-averaged statistics:")
print(f"Mean absolute difference: {np.abs(diff_mean).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_mean).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_mean):.4f}")

# Optionally, look at temporal variation
temporal_std = np.std(diff_full, axis=2)
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_std, cmap='viridis')
plt.title('Standard Deviation of Changes Across Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()
# Out:
# Full tensor statistics:
# Mean absolute difference: 0.0016
# Max absolute difference: 0.0298
# Standard deviation of differences: 0.0022
#
# Time-averaged statistics:
# Mean absolute difference: 0.0002
# Max absolute difference: 0.0012
# Standard deviation of differences: 0.0002

# %%
model_save_path='/Users/sarahurbut/Dropbox (Personal)/model_with_flattrajectory_lr1e-3.pt'
torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'initial_phi': initial_phi, 
    'initial_lambda': initial_lambda, 
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t': essentials['prevalence_t'],
    'logit_prevalence_t': model.logit_prev_t,
    'G': G_100k,
    'E': E_100k,
    'indices': indices,
    'disease_names': essentials['disease_names'],
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T': Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, model_save_path)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000560
# Mean predicted risk (original): 0.000176
# Mean predicted risk (calibrated): 0.000560
# Calibration scale factor: 3.185

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.623

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Mitral valve disease: effect=2.744 (OR=15.54), std=0.378
# Primary/intrinsic cardiomyopathies: effect=2.358 (OR=10.57), std=0.632
# Cardiomegaly: effect=2.132 (OR=8.43), std=0.695
# Heart failure NOS: effect=1.533 (OR=4.63), std=0.504
# Aortic valve disease: effect=1.519 (OR=4.57), std=0.566
# Left bundle branch block: effect=1.445 (OR=4.24), std=0.628
# Rheumatic disease of the heart valves: effect=1.421 (OR=4.14), std=0.579
# Paroxysmal ventricular tachycardia: effect=1.311 (OR=3.71), std=0.445
# Pericarditis: effect=0.923 (OR=2.52), std=0.488
# Paroxysmal supraventricular tachycardia: effect=0.793 (OR=2.21), std=0.463
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Other peripheral nerve disorders: effect=2.378 (OR=10.79), std=0.956
# Hallux rigidus: effect=2.246 (OR=9.45), std=0.935
# Internal derangement of knee: effect=2.199 (OR=9.01), std=0.599
# Peripheral enthesopathies and allied syndromes: effect=2.075 (OR=7.97), std=0.918
# Other acquired deformities of limbs: effect=1.951 (OR=7.04), std=0.375
# Arthropathy NOS: effect=1.855 (OR=6.39), std=1.089
# Enthesopathy: effect=1.748 (OR=5.74), std=0.880
# Synovitis and tenosynovitis: effect=1.660 (OR=5.26), std=0.418
# Acquired toe deformities: effect=1.514 (OR=4.55), std=1.232
# Pain in joint: effect=1.279 (OR=3.59), std=1.078
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Benign neoplasm of other parts of digestive system: effect=1.782 (OR=5.94), std=1.739
# Gastritis and duodenitis: effect=1.777 (OR=5.91), std=0.381
# Barrett's esophagus: effect=1.485 (OR=4.41), std=0.385
# Diaphragmatic hernia: effect=1.456 (OR=4.29), std=0.295
# Iron deficiency anemias, unspecified or not due to blood loss: effect=1.455 (OR=4.28), std=0.623
# Esophagitis, GERD and related diseases: effect=1.454 (OR=4.28), std=0.526
# Other specified gastritis: effect=1.150 (OR=3.16), std=0.392
# Stricture and stenosis of esophagus: effect=1.119 (OR=3.06), std=0.509
# Esophageal bleeding (varices/hemorrhage): effect=0.963 (OR=2.62), std=0.807
# Duodenitis: effect=0.762 (OR=2.14), std=0.204
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Celiac disease: effect=2.803 (OR=16.49), std=1.321
# Sleep disorders: effect=2.640 (OR=14.01), std=0.262
# Cyst of kidney, acquired: effect=2.593 (OR=13.37), std=0.630
# Multiple sclerosis: effect=2.524 (OR=12.48), std=0.267
# Acute gastritis: effect=2.511 (OR=12.31), std=0.293
# Dental caries: effect=2.374 (OR=10.74), std=0.467
# Lipoma: effect=2.331 (OR=10.29), std=0.492
# Viral Enteritis: effect=2.200 (OR=9.02), std=0.205
# Other diseases of the teeth and supporting structures: effect=2.081 (OR=8.01), std=1.116
# Varicose veins of lower extremity: effect=1.930 (OR=6.89), std=0.258
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Other upper respiratory disease: effect=1.406 (OR=4.08), std=0.664
# Septal Deviations/Turbinate Hypertrophy: effect=1.090 (OR=2.98), std=0.504
# Nasal polyps: effect=0.407 (OR=1.50), std=0.317
# Irregular menstrual bleeding: effect=0.389 (OR=1.48), std=0.556
# Chronic sinusitis: effect=0.286 (OR=1.33), std=0.083
# Malignant neoplasm of uterus: effect=0.179 (OR=1.20), std=0.811
# Chronic pharyngitis and nasopharyngitis: effect=0.172 (OR=1.19), std=0.539
# Diseases and other conditions of the tongue: effect=0.161 (OR=1.17), std=0.335
# Other disorders of male genital organs: effect=-0.013 (OR=0.99), std=0.512
# Spondylosis without myelopathy: effect=-0.345 (OR=0.71), std=0.755
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Hypercholesterolemia: effect=1.894 (OR=6.65), std=0.611
# Coronary atherosclerosis: effect=1.400 (OR=4.06), std=0.764
# Myocardial infarction: effect=1.297 (OR=3.66), std=0.086
# Other chronic ischemic heart disease, unspecified: effect=1.138 (OR=3.12), std=0.248
# Hyperlipidemia: effect=0.338 (OR=1.40), std=0.350
# Ptosis of eyelid: effect=0.137 (OR=1.15), std=0.656
# Other acute and subacute forms of ischemic heart disease: effect=0.063 (OR=1.06), std=0.681
# Hearing loss: effect=-0.019 (OR=0.98), std=0.197
# Unstable angina (intermediate coronary syndrome): effect=-0.103 (OR=0.90), std=0.461
# Other disorders of bone and cartilage: effect=-0.297 (OR=0.74), std=0.729
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Secondary malignant neoplasm of digestive systems: effect=2.421 (OR=11.25), std=0.155
# Secondary malignant neoplasm of liver: effect=2.412 (OR=11.16), std=0.637
# Secondary malignancy of lymph nodes: effect=1.767 (OR=5.85), std=0.934
# Malignant neoplasm, other: effect=1.404 (OR=4.07), std=0.454
# Secondary malignancy of respiratory organs: effect=1.353 (OR=3.87), std=0.166
# Cancer of bronchus; lung: effect=1.322 (OR=3.75), std=0.313
# Secondary malignant neoplasm: effect=1.258 (OR=3.52), std=0.424
# Secondary malignancy of bone: effect=1.025 (OR=2.79), std=0.150
# Disorders of lacrimal system: effect=0.640 (OR=1.90), std=0.594
# Endometriosis: effect=0.262 (OR=1.30), std=0.983
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Hyperlipidemia: effect=3.236 (OR=25.43), std=0.465
# Obesity: effect=1.946 (OR=7.00), std=0.360
# Migraine: effect=1.788 (OR=5.98), std=0.222
# Other disorders of bone and cartilage: effect=1.666 (OR=5.29), std=0.773
# Asthma: effect=1.429 (OR=4.18), std=0.459
# Other disorders of soft tissues: effect=1.337 (OR=3.81), std=0.953
# Abdominal pain: effect=1.321 (OR=3.75), std=0.315
# Osteoporosis NOS: effect=0.647 (OR=1.91), std=0.679
# Rheumatism, unspecified and fibrositis: effect=0.641 (OR=1.90), std=0.325
# Spondylosis and allied disorders: effect=0.617 (OR=1.85), std=0.379
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Irregular menstrual cycle: effect=2.030 (OR=7.62), std=0.124
# Ovarian cyst: effect=1.934 (OR=6.92), std=0.348
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: effect=1.802 (OR=6.06), std=0.473
# Disorders of menstruation and other abnormal bleeding from female genital tract: effect=1.782 (OR=5.94), std=1.195
# Postmenopausal bleeding: effect=1.778 (OR=5.92), std=0.353
# Irregular menstrual cycle/bleeding: effect=1.674 (OR=5.33), std=0.576
# Pelvic peritoneal adhesions, female (postoperative) (postinfection): effect=1.396 (OR=4.04), std=0.439
# Excessive or frequent menstruation: effect=1.383 (OR=3.98), std=0.437
# Malignant neoplasm of ovary: effect=1.380 (OR=3.97), std=0.781
# Malignant neoplasm of uterus: effect=1.293 (OR=3.64), std=0.997
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Spinal stenosis: effect=2.462 (OR=11.72), std=0.874
# Degeneration of intervertebral disc: effect=1.806 (OR=6.08), std=0.938
# Spondylosis without myelopathy: effect=1.763 (OR=5.83), std=0.457
# Thoracic or lumbosacral neuritis or radiculitis, unspecified: effect=1.540 (OR=4.67), std=0.528
# Other and unspecified disc disorder: effect=1.452 (OR=4.27), std=0.672
# Sciatica: effect=1.374 (OR=3.95), std=0.364
# Displacement of intervertebral disc: effect=1.109 (OR=3.03), std=0.587
# Secondary malignant neoplasm of liver: effect=1.013 (OR=2.75), std=0.577
# Degenerative disease of the spinal cord: effect=0.873 (OR=2.39), std=0.152
# Back pain: effect=0.823 (OR=2.28), std=0.659
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Primary open angle glaucoma: effect=2.410 (OR=11.14), std=0.897
# Myopia: effect=1.891 (OR=6.62), std=0.843
# Disorders of vitreous body: effect=1.523 (OR=4.59), std=0.379
# Glaucoma: effect=1.362 (OR=3.90), std=0.141
# Retinal detachment with retinal defect: effect=1.286 (OR=3.62), std=0.389
# Cataract: effect=1.262 (OR=3.53), std=0.180
# Senile cataract: effect=1.249 (OR=3.49), std=0.425
# Macular degeneration (senile) of retina NOS: effect=0.946 (OR=2.57), std=0.770
# Retinal vascular changes and abnomalities: effect=0.925 (OR=2.52), std=0.555
# Bacterial enteritis: effect=0.922 (OR=2.51), std=0.756
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Cerebrovascular disease: effect=1.991 (OR=7.32), std=0.718
# Late effects of cerebrovascular disease: effect=1.776 (OR=5.90), std=0.946
# Cerebral ischemia: effect=1.434 (OR=4.20), std=0.785
# Hemiplegia: effect=1.303 (OR=3.68), std=0.218
# Occlusion and stenosis of precerebral arteries: effect=0.995 (OR=2.70), std=0.380
# Chronic prostatitis: effect=0.532 (OR=1.70), std=0.609
# Occlusion of cerebral arteries: effect=0.457 (OR=1.58), std=0.242
# Other derangement of joint: effect=0.355 (OR=1.43), std=0.542
# Transient cerebral ischemia: effect=0.350 (OR=1.42), std=0.659
# Cerebral artery occlusion, with cerebral infarction: effect=0.087 (OR=1.09), std=0.417
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Hydronephrosis: effect=1.733 (OR=5.66), std=0.759
# Renal colic: effect=1.719 (OR=5.58), std=0.872
# Calculus of ureter: effect=1.233 (OR=3.43), std=0.386
# Other disorders of the kidney and ureters: effect=0.760 (OR=2.14), std=0.553
# Anal and rectal polyp: effect=0.688 (OR=1.99), std=1.033
# Pyelonephritis: effect=0.318 (OR=1.37), std=0.534
# Calculus of kidney: effect=0.107 (OR=1.11), std=0.869
# Seborrheic keratosis: effect=-0.016 (OR=0.98), std=0.371
# Stricture/obstruction of ureter: effect=-0.086 (OR=0.92), std=0.195
# Malunion and nonunion of fracture: effect=-0.127 (OR=0.88), std=0.349
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Other disorders of bladder: effect=1.937 (OR=6.94), std=0.263
# Cystitis: effect=1.745 (OR=5.72), std=0.136
# Chronic cystitis: effect=1.669 (OR=5.31), std=0.836
# Bladder neck obstruction: effect=1.480 (OR=4.39), std=0.418
# Chronic prostatitis: effect=1.384 (OR=3.99), std=0.553
# Cancer of prostate: effect=1.144 (OR=3.14), std=0.856
# Hyperplasia of prostate: effect=0.986 (OR=2.68), std=1.048
# Urinary incontinence: effect=0.785 (OR=2.19), std=0.519
# Other disorders of prostate: effect=0.697 (OR=2.01), std=0.757
# Functional disorders of bladder: effect=0.491 (OR=1.63), std=0.309
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Empyema and pneumothorax: effect=2.200 (OR=9.02), std=0.388
# Postinflammatory pulmonary fibrosis: effect=1.716 (OR=5.56), std=0.331
# Tobacco use disorder: effect=1.193 (OR=3.30), std=0.741
# Pneumonia: effect=0.793 (OR=2.21), std=0.243
# Obstructive chronic bronchitis: effect=0.418 (OR=1.52), std=0.753
# Internal derangement of knee: effect=0.338 (OR=1.40), std=1.069
# Bronchiectasis: effect=0.307 (OR=1.36), std=0.189
# Benign neoplasm of breast: effect=0.175 (OR=1.19), std=0.616
# Septal Deviations/Turbinate Hypertrophy: effect=0.119 (OR=1.13), std=0.287
# Emphysema: effect=0.104 (OR=1.11), std=0.318
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Type 2 diabetes with ophthalmic manifestations: effect=1.635 (OR=5.13), std=0.662
# Type 1 diabetes: effect=1.562 (OR=4.77), std=0.253
# Type 2 diabetes: effect=0.955 (OR=2.60), std=0.873
# Hypoglycemia: effect=0.284 (OR=1.33), std=0.362
# Benign neoplasm of ovary: effect=0.154 (OR=1.17), std=0.504
# Blood in stool: effect=0.011 (OR=1.01), std=0.676
# Visual disturbances: effect=-0.081 (OR=0.92), std=0.675
# Chronic periodontitis: effect=-0.081 (OR=0.92), std=0.609
# Pulmonary collapse; interstitial and compensatory emphysema: effect=-0.086 (OR=0.92), std=0.995
# Congestive heart failure (CHF) NOS: effect=-0.121 (OR=0.89), std=1.044
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Orthostatic hypotension: effect=2.967 (OR=19.43), std=0.746
# Other anemias: effect=2.382 (OR=10.83), std=0.558
# Urinary tract infection: effect=1.975 (OR=7.21), std=0.828
# Thrombocytopenia: effect=1.796 (OR=6.03), std=1.047
# Disorders of calcium/phosphorus metabolism: effect=1.778 (OR=5.92), std=0.235
# Bacterial infection NOS: effect=1.741 (OR=5.70), std=0.531
# Sepsis: effect=1.681 (OR=5.37), std=0.505
# Decubitus ulcer: effect=1.297 (OR=3.66), std=0.357
# Gram negative septicemia: effect=1.265 (OR=3.54), std=0.382
# Hypopotassemia: effect=1.209 (OR=3.35), std=0.813
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Hemorrhage of rectum and anus: effect=2.582 (OR=13.23), std=0.515
# Diverticulosis: effect=2.359 (OR=10.58), std=1.000
# Anal and rectal polyp: effect=2.105 (OR=8.21), std=0.587
# Other disorders of intestine: effect=1.673 (OR=5.33), std=0.086
# Malignant neoplasm of rectum, rectosigmoid junction, and anus: effect=1.602 (OR=4.97), std=0.478
# Anal and rectal conditions: effect=1.039 (OR=2.83), std=0.785
# Other intestinal obstruction: effect=0.736 (OR=2.09), std=0.356
# Noninfectious gastroenteritis: effect=0.731 (OR=2.08), std=0.879
# Gastrointestinal complications: effect=0.623 (OR=1.87), std=0.520
# Ventral hernia: effect=0.546 (OR=1.73), std=0.532
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Cholelithiasis with acute cholecystitis: effect=3.532 (OR=34.20), std=1.290
# Cholelithiasis: effect=2.035 (OR=7.65), std=0.703
# Peritoneal adhesions (postoperative) (postinfection): effect=1.993 (OR=7.34), std=1.063
# Calculus of bile duct: effect=1.293 (OR=3.64), std=0.643
# Other disorders of gallbladder: effect=1.074 (OR=2.93), std=0.692
# Other disorders of biliary tract: effect=1.066 (OR=2.90), std=0.743
# Cholelithiasis with other cholecystitis: effect=0.690 (OR=1.99), std=0.560
# Acute upper respiratory infections of multiple or unspecified sites: effect=0.165 (OR=1.18), std=1.268
# Peripheral vascular disease, unspecified: effect=-0.153 (OR=0.86), std=0.629
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: effect=-0.298 (OR=0.74), std=0.744
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Seborrheic keratosis: effect=2.730 (OR=15.33), std=1.209
# Actinic keratosis: effect=2.483 (OR=11.98), std=0.686
# Disorder of skin and subcutaneous tissue NOS: effect=2.226 (OR=9.26), std=0.370
# Other disorders of eyelids: effect=1.936 (OR=6.93), std=0.979
# Scar conditions and fibrosis of skin: effect=1.722 (OR=5.59), std=0.120
# Epiphora: effect=1.669 (OR=5.31), std=0.963
# Thyrotoxicosis with or without goiter: effect=1.374 (OR=3.95), std=0.999
# Other non-epithelial cancer of skin: effect=1.344 (OR=3.83), std=0.497
# Ectropion or entropion: effect=1.242 (OR=3.46), std=0.509
# Hypertensive chronic kidney disease: effect=1.221 (OR=3.39), std=0.587

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Aortic valve disease: 1.258
# 2. Left bundle branch block: 1.155
# 3. Cardiomegaly: 1.081
# 4. Mitral valve disease: 1.069
# 5. Heart failure NOS: 1.069
# 6. Paroxysmal ventricular tachycardia: 1.045
# 7. Congestive heart failure (CHF) NOS: 0.956
# 8. Rheumatic disease of the heart valves: 0.947
# 9. Congenital anomalies of great vessels: 0.945
# 10. Atrial fibrillation and flutter: 0.939
#
# Final top diseases:
# 1. Mitral valve disease: 2.744
# 2. Primary/intrinsic cardiomyopathies: 2.358
# 3. Cardiomegaly: 2.132
# 4. Heart failure NOS: 1.533
# 5. Aortic valve disease: 1.519
# 6. Left bundle branch block: 1.445
# 7. Rheumatic disease of the heart valves: 1.421
# 8. Paroxysmal ventricular tachycardia: 1.311
# 9. Pericarditis: 0.923
# 10. Paroxysmal supraventricular tachycardia: 0.793
#
# Congestive heart failure (CHF) NOS changed from rank 7 to 12
#
# Congenital anomalies of great vessels changed from rank 9 to 12
#
# Mitral valve disease changed from rank 4 to 1
#
# Aortic valve disease changed from rank 1 to 5
#
# Pericarditis changed from rank 12 to 9
#
# Primary/intrinsic cardiomyopathies changed from rank 12 to 2
#
# Left bundle branch block changed from rank 2 to 6
#
# Signature 1:
#
# Initial top diseases:
# 1. Hallux valgus (Bunion): 1.261
# 2. Enthesopathy: 1.212
# 3. Other disorders of synovium, tendon, and bursa: 1.212
# 4. Peripheral enthesopathies and allied syndromes: 1.154
# 5. Hallux rigidus: 1.119
# 6. Other peripheral nerve disorders: 1.117
# 7. Internal derangement of knee: 1.059
# 8. Acquired toe deformities: 1.058
# 9. Synovitis and tenosynovitis: 1.047
# 10. Arthropathy NOS: 1.031
#
# Final top diseases:
# 1. Other peripheral nerve disorders: 2.378
# 2. Hallux rigidus: 2.246
# 3. Internal derangement of knee: 2.199
# 4. Peripheral enthesopathies and allied syndromes: 2.075
# 5. Other acquired deformities of limbs: 1.951
# 6. Arthropathy NOS: 1.855
# 7. Enthesopathy: 1.748
# 8. Synovitis and tenosynovitis: 1.660
# 9. Acquired toe deformities: 1.514
# 10. Pain in joint: 1.279
#
# Hallux rigidus changed from rank 5 to 2
#
# Hallux valgus (Bunion) changed from rank 1 to 12
#
# Other acquired deformities of limbs changed from rank 12 to 5
#
# Other peripheral nerve disorders changed from rank 6 to 1
#
# Internal derangement of knee changed from rank 7 to 3
#
# Arthropathy NOS changed from rank 10 to 6
#
# Enthesopathy changed from rank 2 to 7
#
# Other disorders of synovium, tendon, and bursa changed from rank 3 to 12
#
# Signature 2:
#
# Initial top diseases:
# 1. Gastritis and duodenitis: 1.244
# 2. Gastric ulcer: 1.095
# 3. Stricture and stenosis of esophagus: 1.060
# 4. Barrett's esophagus: 1.058
# 5. Duodenitis: 1.054
# 6. Benign neoplasm of other parts of digestive system: 1.019
# 7. Diaphragmatic hernia: 0.984
# 8. Esophagitis, GERD and related diseases: 0.956
# 9. Other disorders of stomach and duodenum: 0.948
# 10. Reflux esophagitis: 0.940
#
# Final top diseases:
# 1. Benign neoplasm of other parts of digestive system: 1.782
# 2. Gastritis and duodenitis: 1.777
# 3. Barrett's esophagus: 1.485
# 4. Diaphragmatic hernia: 1.456
# 5. Iron deficiency anemias, unspecified or not due to blood loss: 1.455
# 6. Esophagitis, GERD and related diseases: 1.454
# 7. Other specified gastritis: 1.150
# 8. Stricture and stenosis of esophagus: 1.119
# 9. Esophageal bleeding (varices/hemorrhage): 0.963
# 10. Duodenitis: 0.762
#
# Other disorders of stomach and duodenum changed from rank 9 to 12
#
# Diaphragmatic hernia changed from rank 7 to 4
#
# Benign neoplasm of other parts of digestive system changed from rank 6 to 1
#
# Esophageal bleeding (varices/hemorrhage) changed from rank 12 to 9
#
# Stricture and stenosis of esophagus changed from rank 3 to 8
#
# Gastric ulcer changed from rank 2 to 12
#
# Iron deficiency anemias, unspecified or not due to blood loss changed from rank 12 to 5
#
# Duodenitis changed from rank 5 to 10
#
# Other specified gastritis changed from rank 12 to 7
#
# Signature 3:
#
# Initial top diseases:
# 1. Celiac disease: 1.302
# 2. Atopic/contact dermatitis due to other or unspecified: 1.247
# 3. Blood in stool: 1.242
# 4. Inflammation of eyelids: 1.209
# 5. Diseases of the larynx and vocal cords: 1.197
# 6. Alcohol-related disorders: 1.184
# 7. Viral infection: 1.172
# 8. Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: 1.161
# 9. Right bundle branch block: 1.153
# 10. Acute pharyngitis: 1.141
#
# Final top diseases:
# 1. Celiac disease: 2.803
# 2. Sleep disorders: 2.640
# 3. Cyst of kidney, acquired: 2.593
# 4. Multiple sclerosis: 2.524
# 5. Acute gastritis: 2.511
# 6. Dental caries: 2.374
# 7. Lipoma: 2.331
# 8. Viral Enteritis: 2.200
# 9. Other diseases of the teeth and supporting structures: 2.081
# 10. Varicose veins of lower extremity: 1.930
#
# Viral Enteritis changed from rank 12 to 8
#
# Alcohol-related disorders changed from rank 6 to 12
#
# Sleep disorders changed from rank 12 to 2
#
# Viral infection changed from rank 7 to 12
#
# Multiple sclerosis changed from rank 12 to 4
#
# Diseases of the larynx and vocal cords changed from rank 5 to 12
#
# Atopic/contact dermatitis due to other or unspecified changed from rank 2 to 12
#
# Inflammation of eyelids changed from rank 4 to 12
#
# Blood in stool changed from rank 3 to 12
#
# Lipoma changed from rank 12 to 7
#
# Cyst of kidney, acquired changed from rank 12 to 3
#
# Dental caries changed from rank 12 to 6
#
# Other diseases of the teeth and supporting structures changed from rank 12 to 9
#
# Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue changed from rank 8 to 12
#
# Right bundle branch block changed from rank 9 to 12
#
# Acute gastritis changed from rank 12 to 5
#
# Signature 4:
#
# Initial top diseases:
# 1. Other upper respiratory disease: 0.931
# 2. Nasal polyps: 0.910
# 3. Septal Deviations/Turbinate Hypertrophy: 0.846
# 4. Chronic sinusitis: 0.822
# 5. Chronic pharyngitis and nasopharyngitis: 0.775
# 6. Arrhythmia (cardiac) NOS: -1.888
# 7. Visual disturbances: -1.890
# 8. Raynaud's syndrome: -1.893
# 9. Decubitus ulcer: -1.899
# 10. Chronic cystitis: -1.899
#
# Final top diseases:
# 1. Other upper respiratory disease: 1.406
# 2. Septal Deviations/Turbinate Hypertrophy: 1.090
# 3. Nasal polyps: 0.407
# 4. Irregular menstrual bleeding: 0.389
# 5. Chronic sinusitis: 0.286
# 6. Malignant neoplasm of uterus: 0.179
# 7. Chronic pharyngitis and nasopharyngitis: 0.172
# 8. Diseases and other conditions of the tongue: 0.161
# 9. Other disorders of male genital organs: -0.013
# 10. Spondylosis without myelopathy: -0.345
#
# Arrhythmia (cardiac) NOS changed from rank 6 to 12
#
# Raynaud's syndrome changed from rank 8 to 12
#
# Malignant neoplasm of uterus changed from rank 12 to 6
#
# Irregular menstrual bleeding changed from rank 12 to 4
#
# Visual disturbances changed from rank 7 to 12
#
# Decubitus ulcer changed from rank 9 to 12
#
# Diseases and other conditions of the tongue changed from rank 12 to 8
#
# Other disorders of male genital organs changed from rank 12 to 9
#
# Signature 5:
#
# Initial top diseases:
# 1. Coronary atherosclerosis: 1.260
# 2. Hypercholesterolemia: 1.149
# 3. Other acute and subacute forms of ischemic heart disease: 1.023
# 4. Myocardial infarction: 0.950
# 5. Other chronic ischemic heart disease, unspecified: 0.858
# 6. Angina pectoris: 0.756
# 7. Unstable angina (intermediate coronary syndrome): 0.740
# 8. Renal colic: -1.899
# 9. Neuralgia, neuritis, and radiculitis NOS: -1.900
# 10. First degree AV block: -1.900
#
# Final top diseases:
# 1. Hypercholesterolemia: 1.894
# 2. Coronary atherosclerosis: 1.400
# 3. Myocardial infarction: 1.297
# 4. Other chronic ischemic heart disease, unspecified: 1.138
# 5. Hyperlipidemia: 0.338
# 6. Ptosis of eyelid: 0.137
# 7. Other acute and subacute forms of ischemic heart disease: 0.063
# 8. Hearing loss: -0.019
# 9. Unstable angina (intermediate coronary syndrome): -0.103
# 10. Other disorders of bone and cartilage: -0.297
#
# Neuralgia, neuritis, and radiculitis NOS changed from rank 9 to 12
#
# Ptosis of eyelid changed from rank 12 to 6
#
# Hearing loss changed from rank 12 to 8
#
# Angina pectoris changed from rank 6 to 12
#
# Other acute and subacute forms of ischemic heart disease changed from rank 3 to 7
#
# Renal colic changed from rank 8 to 12
#
# Hyperlipidemia changed from rank 12 to 5
#
# Signature 6:
#
# Initial top diseases:
# 1. Secondary malignant neoplasm of digestive systems: 1.169
# 2. Secondary malignancy of lymph nodes: 1.116
# 3. Secondary malignant neoplasm of liver: 1.089
# 4. Malignant neoplasm, other: 1.089
# 5. Cancer of bronchus; lung: 1.048
# 6. Secondary malignant neoplasm: 1.008
# 7. Secondary malignancy of bone: 0.996
# 8. Secondary malignancy of respiratory organs: 0.885
# 9. Arrhythmia (cardiac) NOS: -1.889
# 10. Emphysema: -1.893
#
# Final top diseases:
# 1. Secondary malignant neoplasm of digestive systems: 2.421
# 2. Secondary malignant neoplasm of liver: 2.412
# 3. Secondary malignancy of lymph nodes: 1.767
# 4. Malignant neoplasm, other: 1.404
# 5. Secondary malignancy of respiratory organs: 1.353
# 6. Cancer of bronchus; lung: 1.322
# 7. Secondary malignant neoplasm: 1.258
# 8. Secondary malignancy of bone: 1.025
# 9. Disorders of lacrimal system: 0.640
# 10. Endometriosis: 0.262
#
# Arrhythmia (cardiac) NOS changed from rank 9 to 12
#
# Secondary malignancy of respiratory organs changed from rank 8 to 5
#
# Disorders of lacrimal system changed from rank 12 to 9
#
# Signature 7:
#
# Initial top diseases:
# 1. Migraine: 1.337
# 2. Asthma: 1.244
# 3. Hyperlipidemia: 1.180
# 4. Abdominal pain: 1.176
# 5. Other disorders of bone and cartilage: 1.174
# 6. Obesity: 1.166
# 7. Myalgia and myositis unspecified: 1.104
# 8. Osteoporosis NOS: 1.078
# 9. Cervicalgia: 1.074
# 10. Other disorders of soft tissues: 1.072
#
# Final top diseases:
# 1. Hyperlipidemia: 3.236
# 2. Obesity: 1.946
# 3. Migraine: 1.788
# 4. Other disorders of bone and cartilage: 1.666
# 5. Asthma: 1.429
# 6. Other disorders of soft tissues: 1.337
# 7. Abdominal pain: 1.321
# 8. Osteoporosis NOS: 0.647
# 9. Rheumatism, unspecified and fibrositis: 0.641
# 10. Spondylosis and allied disorders: 0.617
#
# Cervicalgia changed from rank 9 to 12
#
# Myalgia and myositis unspecified changed from rank 7 to 12
#
# Abdominal pain changed from rank 4 to 7
#
# Asthma changed from rank 2 to 5
#
# Other disorders of soft tissues changed from rank 10 to 6
#
# Rheumatism, unspecified and fibrositis changed from rank 12 to 9
#
# Obesity changed from rank 6 to 2
#
# Signature 8:
#
# Initial top diseases:
# 1. Ovarian cyst: 1.294
# 2. Endometrial hyperplasia: 1.092
# 3. Irregular menstrual cycle: 1.074
# 4. Malignant neoplasm of uterus: 1.064
# 5. Dyspareunia: 1.063
# 6. Noninflammatory disorders of cervix: 1.031
# 7. Disorders of uterus, NEC: 1.026
# 8. Postmenopausal atrophic vaginitis: 1.021
# 9. Polyp of corpus uteri: 1.019
# 10. Pelvic peritoneal adhesions, female (postoperative) (postinfection): 1.013
#
# Final top diseases:
# 1. Irregular menstrual cycle: 2.030
# 2. Ovarian cyst: 1.934
# 3. Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: 1.802
# 4. Disorders of menstruation and other abnormal bleeding from female genital tract: 1.782
# 5. Postmenopausal bleeding: 1.778
# 6. Irregular menstrual cycle/bleeding: 1.674
# 7. Pelvic peritoneal adhesions, female (postoperative) (postinfection): 1.396
# 8. Excessive or frequent menstruation: 1.383
# 9. Malignant neoplasm of ovary: 1.380
# 10. Malignant neoplasm of uterus: 1.293
#
# Pelvic peritoneal adhesions, female (postoperative) (postinfection) changed from rank 10 to 7
#
# Disorders of uterus, NEC changed from rank 7 to 12
#
# Noninflammatory disorders of cervix changed from rank 6 to 12
#
# Endometrial hyperplasia changed from rank 2 to 12
#
# Polyp of corpus uteri changed from rank 9 to 12
#
# Dyspareunia changed from rank 5 to 12
#
# Disorders of menstruation and other abnormal bleeding from female genital tract changed from rank 12 to 4
#
# Malignant neoplasm of uterus changed from rank 4 to 10
#
# Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] changed from rank 12 to 3
#
# Irregular menstrual cycle/bleeding changed from rank 12 to 6
#
# Excessive or frequent menstruation changed from rank 12 to 8
#
# Malignant neoplasm of ovary changed from rank 12 to 9
#
# Postmenopausal bleeding changed from rank 12 to 5
#
# Postmenopausal atrophic vaginitis changed from rank 8 to 12
#
# Signature 9:
#
# Initial top diseases:
# 1. Back pain: 1.187
# 2. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.143
# 3. Spondylosis without myelopathy: 1.079
# 4. Degenerative disease of the spinal cord: 1.039
# 5. Other and unspecified disc disorder: 1.016
# 6. Sciatica: 1.004
# 7. Neuralgia, neuritis, and radiculitis NOS: 0.971
# 8. Displacement of intervertebral disc: 0.935
# 9. Spinal stenosis: 0.932
# 10. Degeneration of intervertebral disc: 0.908
#
# Final top diseases:
# 1. Spinal stenosis: 2.462
# 2. Degeneration of intervertebral disc: 1.806
# 3. Spondylosis without myelopathy: 1.763
# 4. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.540
# 5. Other and unspecified disc disorder: 1.452
# 6. Sciatica: 1.374
# 7. Displacement of intervertebral disc: 1.109
# 8. Secondary malignant neoplasm of liver: 1.013
# 9. Degenerative disease of the spinal cord: 0.873
# 10. Back pain: 0.823
#
# Degenerative disease of the spinal cord changed from rank 4 to 9
#
# Back pain changed from rank 1 to 10
#
# Neuralgia, neuritis, and radiculitis NOS changed from rank 7 to 12
#
# Secondary malignant neoplasm of liver changed from rank 12 to 8
#
# Spinal stenosis changed from rank 9 to 1
#
# Degeneration of intervertebral disc changed from rank 10 to 2
#
# Signature 10:
#
# Initial top diseases:
# 1. Macular degeneration (senile) of retina NOS: 1.233
# 2. Primary open angle glaucoma: 1.163
# 3. Glaucoma: 1.102
# 4. Retinal vascular changes and abnomalities: 1.085
# 5. Myopia: 1.082
# 6. Disorders of vitreous body: 1.072
# 7. Cataract: 1.043
# 8. Senile cataract: 1.023
# 9. Other retinal disorders: 1.022
# 10. Retinal detachment with retinal defect: 0.867
#
# Final top diseases:
# 1. Primary open angle glaucoma: 2.410
# 2. Myopia: 1.891
# 3. Disorders of vitreous body: 1.523
# 4. Glaucoma: 1.362
# 5. Retinal detachment with retinal defect: 1.286
# 6. Cataract: 1.262
# 7. Senile cataract: 1.249
# 8. Macular degeneration (senile) of retina NOS: 0.946
# 9. Retinal vascular changes and abnomalities: 0.925
# 10. Bacterial enteritis: 0.922
#
# Retinal detachment with retinal defect changed from rank 10 to 5
#
# Other retinal disorders changed from rank 9 to 12
#
# Macular degeneration (senile) of retina NOS changed from rank 1 to 8
#
# Retinal vascular changes and abnomalities changed from rank 4 to 9
#
# Myopia changed from rank 5 to 2
#
# Disorders of vitreous body changed from rank 6 to 3
#
# Signature 11:
#
# Initial top diseases:
# 1. Cerebral ischemia: 1.133
# 2. Hemiplegia: 1.094
# 3. Cerebrovascular disease: 1.048
# 4. Transient cerebral ischemia: 0.960
# 5. Late effects of cerebrovascular disease: 0.955
# 6. Occlusion of cerebral arteries: 0.946
# 7. Cerebral artery occlusion, with cerebral infarction: 0.857
# 8. Occlusion and stenosis of precerebral arteries: 0.719
# 9. Other derangement of joint: -1.890
# 10. Osteoarthrosis, generalized: -1.891
#
# Final top diseases:
# 1. Cerebrovascular disease: 1.991
# 2. Late effects of cerebrovascular disease: 1.776
# 3. Cerebral ischemia: 1.434
# 4. Hemiplegia: 1.303
# 5. Occlusion and stenosis of precerebral arteries: 0.995
# 6. Chronic prostatitis: 0.532
# 7. Occlusion of cerebral arteries: 0.457
# 8. Other derangement of joint: 0.355
# 9. Transient cerebral ischemia: 0.350
# 10. Cerebral artery occlusion, with cerebral infarction: 0.087
#
# Occlusion and stenosis of precerebral arteries changed from rank 8 to 5
#
# Cerebral artery occlusion, with cerebral infarction changed from rank 7 to 10
#
# Transient cerebral ischemia changed from rank 4 to 9
#
# Late effects of cerebrovascular disease changed from rank 5 to 2
#
# Chronic prostatitis changed from rank 12 to 6
#
# Signature 12:
#
# Initial top diseases:
# 1. Renal colic: 1.301
# 2. Calculus of ureter: 1.173
# 3. Hydronephrosis: 1.088
# 4. Other disorders of the kidney and ureters: 1.074
# 5. Stricture/obstruction of ureter: 0.981
# 6. Pyelonephritis: 0.822
# 7. Calculus of kidney: 0.776
# 8. Streptococcus infection: -1.872
# 9. Emphysema: -1.891
# 10. Left bundle branch block: -1.891
#
# Final top diseases:
# 1. Hydronephrosis: 1.733
# 2. Renal colic: 1.719
# 3. Calculus of ureter: 1.233
# 4. Other disorders of the kidney and ureters: 0.760
# 5. Anal and rectal polyp: 0.688
# 6. Pyelonephritis: 0.318
# 7. Calculus of kidney: 0.107
# 8. Seborrheic keratosis: -0.016
# 9. Stricture/obstruction of ureter: -0.086
# 10. Malunion and nonunion of fracture: -0.127
#
# Streptococcus infection changed from rank 8 to 12
#
# Anal and rectal polyp changed from rank 12 to 5
#
# Emphysema changed from rank 9 to 12
#
# Seborrheic keratosis changed from rank 12 to 8
#
# Stricture/obstruction of ureter changed from rank 5 to 9
#
# Signature 13:
#
# Initial top diseases:
# 1. Cystitis: 1.237
# 2. Other disorders of bladder: 1.087
# 3. Urethral stricture (not specified as infectious): 1.072
# 4. Cancer of prostate: 0.996
# 5. Chronic cystitis: 0.974
# 6. Chronic prostatitis: 0.971
# 7. Bladder neck obstruction: 0.959
# 8. Hyperplasia of prostate: 0.941
# 9. Malignant neoplasm of bladder: 0.927
# 10. Urinary incontinence: 0.913
#
# Final top diseases:
# 1. Other disorders of bladder: 1.937
# 2. Cystitis: 1.745
# 3. Chronic cystitis: 1.669
# 4. Bladder neck obstruction: 1.480
# 5. Chronic prostatitis: 1.384
# 6. Cancer of prostate: 1.144
# 7. Hyperplasia of prostate: 0.986
# 8. Urinary incontinence: 0.785
# 9. Other disorders of prostate: 0.697
# 10. Functional disorders of bladder: 0.491
#
# Malignant neoplasm of bladder changed from rank 9 to 12
#
# Bladder neck obstruction changed from rank 7 to 4
#
# Urethral stricture (not specified as infectious) changed from rank 3 to 12
#
# Other disorders of prostate changed from rank 12 to 9
#
# Signature 14:
#
# Initial top diseases:
# 1. Empyema and pneumothorax: 1.113
# 2. Emphysema: 1.061
# 3. Tobacco use disorder: 0.997
# 4. Bronchiectasis: 0.973
# 5. Pneumonia: 0.961
# 6. Postinflammatory pulmonary fibrosis: 0.959
# 7. Pneumococcal pneumonia: 0.842
# 8. Chronic airway obstruction: 0.787
# 9. Obstructive chronic bronchitis: 0.785
# 10. Respiratory failure: 0.733
#
# Final top diseases:
# 1. Empyema and pneumothorax: 2.200
# 2. Postinflammatory pulmonary fibrosis: 1.716
# 3. Tobacco use disorder: 1.193
# 4. Pneumonia: 0.793
# 5. Obstructive chronic bronchitis: 0.418
# 6. Internal derangement of knee: 0.338
# 7. Bronchiectasis: 0.307
# 8. Benign neoplasm of breast: 0.175
# 9. Septal Deviations/Turbinate Hypertrophy: 0.119
# 10. Emphysema: 0.104
#
# Benign neoplasm of breast changed from rank 12 to 8
#
# Septal Deviations/Turbinate Hypertrophy changed from rank 12 to 9
#
# Internal derangement of knee changed from rank 12 to 6
#
# Pneumococcal pneumonia changed from rank 7 to 12
#
# Chronic airway obstruction changed from rank 8 to 12
#
# Emphysema changed from rank 2 to 10
#
# Obstructive chronic bronchitis changed from rank 9 to 5
#
# Bronchiectasis changed from rank 4 to 7
#
# Postinflammatory pulmonary fibrosis changed from rank 6 to 2
#
# Signature 15:
#
# Initial top diseases:
# 1. Hypoglycemia: 1.083
# 2. Type 1 diabetes: 1.043
# 3. Type 2 diabetes with ophthalmic manifestations: 0.975
# 4. Type 2 diabetes: 0.925
# 5. Diabetic retinopathy: 0.823
# 6. Disorders of calcium/phosphorus metabolism: -1.889
# 7. Varicose veins of lower extremity: -1.895
# 8. Acute pharyngitis: -1.896
# 9. Pulmonary collapse; interstitial and compensatory emphysema: -1.896
# 10. Peritonitis and retroperitoneal infections: -1.896
#
# Final top diseases:
# 1. Type 2 diabetes with ophthalmic manifestations: 1.635
# 2. Type 1 diabetes: 1.562
# 3. Type 2 diabetes: 0.955
# 4. Hypoglycemia: 0.284
# 5. Benign neoplasm of ovary: 0.154
# 6. Blood in stool: 0.011
# 7. Visual disturbances: -0.081
# 8. Chronic periodontitis: -0.081
# 9. Pulmonary collapse; interstitial and compensatory emphysema: -0.086
# 10. Congestive heart failure (CHF) NOS: -0.121
#
# Varicose veins of lower extremity changed from rank 7 to 12
#
# Acute pharyngitis changed from rank 8 to 12
#
# Visual disturbances changed from rank 12 to 7
#
# Blood in stool changed from rank 12 to 6
#
# Benign neoplasm of ovary changed from rank 12 to 5
#
# Diabetic retinopathy changed from rank 5 to 12
#
# Hypoglycemia changed from rank 1 to 4
#
# Chronic periodontitis changed from rank 12 to 8
#
# Disorders of calcium/phosphorus metabolism changed from rank 6 to 12
#
# Signature 16:
#
# Initial top diseases:
# 1. Hypopotassemia: 1.160
# 2. Acute renal failure: 1.126
# 3. Gram negative septicemia: 1.105
# 4. Chronic ulcer of skin: 1.086
# 5. Urinary tract infection: 1.083
# 6. Orthostatic hypotension: 1.083
# 7. Disorders of calcium/phosphorus metabolism: 1.076
# 8. Other anemias: 1.064
# 9. Other local infections of skin and subcutaneous tissue: 1.049
# 10. Sepsis: 1.043
#
# Final top diseases:
# 1. Orthostatic hypotension: 2.967
# 2. Other anemias: 2.382
# 3. Urinary tract infection: 1.975
# 4. Thrombocytopenia: 1.796
# 5. Disorders of calcium/phosphorus metabolism: 1.778
# 6. Bacterial infection NOS: 1.741
# 7. Sepsis: 1.681
# 8. Decubitus ulcer: 1.297
# 9. Gram negative septicemia: 1.265
# 10. Hypopotassemia: 1.209
#
# Gram negative septicemia changed from rank 3 to 9
#
# Bacterial infection NOS changed from rank 12 to 6
#
# Orthostatic hypotension changed from rank 6 to 1
#
# Sepsis changed from rank 10 to 7
#
# Other local infections of skin and subcutaneous tissue changed from rank 9 to 12
#
# Acute renal failure changed from rank 2 to 12
#
# Chronic ulcer of skin changed from rank 4 to 12
#
# Decubitus ulcer changed from rank 12 to 8
#
# Hypopotassemia changed from rank 1 to 10
#
# Other anemias changed from rank 8 to 2
#
# Thrombocytopenia changed from rank 12 to 4
#
# Signature 17:
#
# Initial top diseases:
# 1. Hemorrhage of rectum and anus: 1.180
# 2. Diverticulosis: 1.136
# 3. Noninfectious gastroenteritis: 1.105
# 4. Regional enteritis: 1.105
# 5. Ventral hernia: 1.092
# 6. Hemorrhoids: 1.032
# 7. Other disorders of intestine: 1.031
# 8. Hemorrhage of gastrointestinal tract: 1.029
# 9. Anal and rectal conditions: 1.024
# 10. Neoplasm of unspecified nature of digestive system: 1.014
#
# Final top diseases:
# 1. Hemorrhage of rectum and anus: 2.582
# 2. Diverticulosis: 2.359
# 3. Anal and rectal polyp: 2.105
# 4. Other disorders of intestine: 1.673
# 5. Malignant neoplasm of rectum, rectosigmoid junction, and anus: 1.602
# 6. Anal and rectal conditions: 1.039
# 7. Other intestinal obstruction: 0.736
# 8. Noninfectious gastroenteritis: 0.731
# 9. Gastrointestinal complications: 0.623
# 10. Ventral hernia: 0.546
#
# Ventral hernia changed from rank 5 to 10
#
# Regional enteritis changed from rank 4 to 12
#
# Noninfectious gastroenteritis changed from rank 3 to 8
#
# Other intestinal obstruction changed from rank 12 to 7
#
# Malignant neoplasm of rectum, rectosigmoid junction, and anus changed from rank 12 to 5
#
# Anal and rectal conditions changed from rank 9 to 6
#
# Anal and rectal polyp changed from rank 12 to 3
#
# Hemorrhoids changed from rank 6 to 12
#
# Other disorders of intestine changed from rank 7 to 4
#
# Gastrointestinal complications changed from rank 12 to 9
#
# Hemorrhage of gastrointestinal tract changed from rank 8 to 12
#
# Signature 18:
#
# Initial top diseases:
# 1. Other disorders of gallbladder: 1.257
# 2. Cholelithiasis with acute cholecystitis: 1.139
# 3. Peritoneal adhesions (postoperative) (postinfection): 1.130
# 4. Cholelithiasis: 1.069
# 5. Acute pancreatitis: 0.964
# 6. Calculus of bile duct: 0.936
# 7. Other disorders of biliary tract: 0.922
# 8. Cholelithiasis with other cholecystitis: 0.831
# 9. Cholecystitis without cholelithiasis: 0.790
# 10. Myopia: -1.892
#
# Final top diseases:
# 1. Cholelithiasis with acute cholecystitis: 3.532
# 2. Cholelithiasis: 2.035
# 3. Peritoneal adhesions (postoperative) (postinfection): 1.993
# 4. Calculus of bile duct: 1.293
# 5. Other disorders of gallbladder: 1.074
# 6. Other disorders of biliary tract: 1.066
# 7. Cholelithiasis with other cholecystitis: 0.690
# 8. Acute upper respiratory infections of multiple or unspecified sites: 0.165
# 9. Peripheral vascular disease, unspecified: -0.153
# 10. Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia]: -0.298
#
# Peripheral vascular disease, unspecified changed from rank 12 to 9
#
# Acute upper respiratory infections of multiple or unspecified sites changed from rank 12 to 8
#
# Cholecystitis without cholelithiasis changed from rank 9 to 12
#
# Other disorders of gallbladder changed from rank 1 to 5
#
# Acute pancreatitis changed from rank 5 to 12
#
# Signature 19:
#
# Initial top diseases:
# 1. Seborrheic keratosis: 1.234
# 2. Chronic glomerulonephritis, NOS: 1.227
# 3. Hypertensive chronic kidney disease: 1.162
# 4. Ectropion or entropion: 1.144
# 5. Other disorders of eyelids: 1.092
# 6. Thyrotoxicosis with or without goiter: 1.056
# 7. Actinic keratosis: 1.052
# 8. Scar conditions and fibrosis of skin: 1.045
# 9. Disorders of lacrimal system: 1.040
# 10. Other non-epithelial cancer of skin: 1.019
#
# Final top diseases:
# 1. Seborrheic keratosis: 2.730
# 2. Actinic keratosis: 2.483
# 3. Disorder of skin and subcutaneous tissue NOS: 2.226
# 4. Other disorders of eyelids: 1.936
# 5. Scar conditions and fibrosis of skin: 1.722
# 6. Epiphora: 1.669
# 7. Thyrotoxicosis with or without goiter: 1.374
# 8. Other non-epithelial cancer of skin: 1.344
# 9. Ectropion or entropion: 1.242
# 10. Hypertensive chronic kidney disease: 1.221
#
# Ectropion or entropion changed from rank 4 to 9
#
# Disorder of skin and subcutaneous tissue NOS changed from rank 12 to 3
#
# Scar conditions and fibrosis of skin changed from rank 8 to 5
#
# Chronic glomerulonephritis, NOS changed from rank 2 to 12
#
# Actinic keratosis changed from rank 7 to 2
#
# Disorders of lacrimal system changed from rank 9 to 12
#
# Epiphora changed from rank 12 to 6
#
# Hypertensive chronic kidney disease changed from rank 3 to 10

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
disease_names=essentials['disease_names']
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,1,14,15,16,13,17])

# %%
Y_avg_global = torch.mean(torch.tensor(Y) if isinstance(Y,np.ndarray) else Y, dim=2)
Y_avg_batch = torch.mean(torch.tensor(Y_100k) if isinstance(Y_100k, np.ndarray) else Y_100k, dim=2)

# %%
def compare_disease_patterns(k, true_psi, Y_avg_global, Y_avg_batch):
    """Compare disease patterns between global and batch data"""
    strong_diseases = (true_psi[k] > 0)
    
    # Get mean pattern for each dataset (average across patients)
    pattern_large = Y_avg_global[:, strong_diseases].mean(dim=0)  # Average across all patients
    pattern_small = Y_avg_batch[:, strong_diseases].mean(dim=0)  # Average across batch patients
    
    # Now both patterns are just length of strong_diseases
    correlation = torch.corrcoef(
        torch.stack([pattern_large, pattern_small])
    )[0,1]
    
    print(f"Signature {k} pattern correlation: {correlation:.3f}")
    print(f"Mean pattern difference: {(pattern_large - pattern_small).abs().mean():.3f}")

# Now use it
print("Comparing disease sharing patterns between global and batch data:")
for k in range(model.K):
    print(f"\nSignature {k}:")
    compare_disease_patterns(k, model.psi, Y_avg_global, Y_avg_batch)

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Final Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Final Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects for these patients
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]  # Already computed above
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
