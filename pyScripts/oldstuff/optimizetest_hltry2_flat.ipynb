# %%
# %load_ext autoreload
# %autoreload 2

from cluster_g_logit_init_acceptpsi_flatlam_healthtoo import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/filesforupload/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'filtered_3plus/Y_tensor_filtered.pt')
    E = torch.load(base_path + 'filtered_3plus/E_matrix_filtered.pt')
    G = torch.load(base_path + 'filtered_3plus/G_matrix_filtered.pt')
    
    # Load other components
    essentials = torch.load('/Users/sarahurbut/Dropbox (Personal)/data_for_running/model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_63792/2518768727.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'filtered_3plus/Y_tensor_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_63792/2518768727.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'filtered_3plus/E_matrix_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_63792/2518768727.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'filtered_3plus/G_matrix_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_63792/2518768727.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load('/Users/sarahurbut/Dropbox (Personal)/data_for_running/model_essentials.pt')
# Loaded all components successfully!

# %%
def subset_data(Y, E, G, n_samples=50000, seed=42):
    """
    Subset the data to n_samples individuals while maintaining consistency
    
    Args:
        Y: tensor of shape [N, D, T]
        E: tensor of shape [N, D]
        G: tensor of shape [N, P]
        n_samples: number of individuals to keep
        seed: random seed for reproducibility
    
    Returns:
        Y_sub, E_sub, G_sub: subsetted tensors
    """
    torch.manual_seed(seed)
    
    # Get total number of individuals
    N = Y.shape[0]
    
    # Randomly select n_samples indices
    indices = torch.randperm(N)[:n_samples]
    
    # Subset all matrices using the same indices
    Y_sub = Y[indices]
    E_sub = E[indices]
    G_sub = G[indices]
    
    print(f"Original shapes: Y={Y.shape}, E={E.shape}, G={G.shape}")
    print(f"New shapes: Y={Y_sub.shape}, E={E_sub.shape}, G={G_sub.shape}")
    
    return Y_sub, E_sub, G_sub, indices

# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000,seed=1)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([314976, 348, 52]), E=torch.Size([314976, 348]), G=(314976, 36)
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=(10000, 36)

# %%
# When initializing the model:
original_G = G_100k # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_63792/1949801412.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_63792/1949801412.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
# Create model without healthy reference
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_100k.shape[1],
    G=G_100k, 
    Y=Y_100k,
    prevalence_t=essentials['prevalence_t'],
   
    healthy_reference=None,  # Explicitly set to None
    disease_names=essentials['disease_names'],
    flat_lambda=True
)

# Initialize with psi and clusters
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters

# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.prevalence_t = torch.tensor(prevalence_t, dtype=torch.float32)
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
#
# Cluster Sizes:
# Cluster 0: 18 diseases
# Cluster 1: 28 diseases
# Cluster 2: 99 diseases
# Cluster 3: 13 diseases
# Cluster 4: 18 diseases
# Cluster 5: 28 diseases
# Cluster 6: 5 diseases
# Cluster 7: 11 diseases
# Cluster 8: 9 diseases
# Cluster 9: 17 diseases
# Cluster 10: 7 diseases
# Cluster 11: 13 diseases
# Cluster 12: 9 diseases
# Cluster 13: 5 diseases
# Cluster 14: 9 diseases
# Cluster 15: 21 diseases
# Cluster 16: 10 diseases
# Cluster 17: 6 diseases
# Cluster 18: 15 diseases
# Cluster 19: 7 diseases
# Initializing with 20 disease states only
# Initialization complete!
# Initializing with 20 disease states only
# Initialization complete!
#
# Clusters match exactly: True

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Initial Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Initial Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects for these patients
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]  # Already computed above
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
# Out:
# Genetic Effect Statistics for Sample Patients:
#
# Patient 4376:
# Mean shift: -0.189
# Std of shifts: 0.556
# Range of shifts: [-2.365, 0.233]
#
# Top states and average proportions:
# State 3: 0.070
# State 7: 0.069
# State 19: 0.067
# State 18: 0.063
# State 8: 0.062
#
# Patient 6640:
# Mean shift: 0.019
# Std of shifts: 0.333
# Range of shifts: [-0.455, 1.046]
#
# Top states and average proportions:
# State 13: 0.130
# State 7: 0.064
# State 11: 0.062
# State 6: 0.060
# State 14: 0.056

# %%
model.genetic_scale
# Out:
# 3.0

# %%
model.plot_initial_params()
# Convert disease names to list if it's not already
disease_names_list = list(essentials['disease_names'])

# Now visualize clusters
model.visualize_clusters(disease_names=disease_names_list)
# Out:
# Cluster membership for sampled diseases:
# Disease 255: Cluster 3
# Disease 114: Cluster 5
# Disease 314: Cluster 7
# Disease 268: Cluster 8
# Disease 167: Cluster 14
#
# Cluster Assignments:
#
# Cluster 0:
#   - Rheumatic disease of the heart valves (prevalence: 0.0003)
#   - Mitral valve disease (prevalence: 0.0004)
#   - Aortic valve disease (prevalence: 0.0002)
#   - Disease of tricuspid valve (prevalence: 0.0003)
#   - Other forms of chronic heart disease (prevalence: 0.0006)
#   - Cardiomegaly (prevalence: 0.0006)
#   - Pericarditis (prevalence: 0.0002)
#   - Primary/intrinsic cardiomyopathies (prevalence: 0.0001)
#   - Left bundle branch block (prevalence: 0.0004)
#   - Paroxysmal supraventricular tachycardia (prevalence: 0.0003)
#   - Paroxysmal ventricular tachycardia (prevalence: 0.0001)
#   - Atrial fibrillation and flutter (prevalence: 0.0012)
#   - Congestive heart failure (CHF) NOS (prevalence: 0.0005)
#   - Heart failure NOS (prevalence: 0.0009)
#   - Pleurisy; pleural effusion (prevalence: 0.0012)
#   - Congenital anomalies of great vessels (prevalence: 0.0003)
#
# Cluster 1:
#   - Other peripheral nerve disorders (prevalence: 0.0011)
#   - Rheumatoid arthritis (prevalence: 0.0006)
#   - Arthropathy NOS (prevalence: 0.0051)
#   - Peripheral enthesopathies and allied syndromes (prevalence: 0.0006)
#   - Enthesopathy (prevalence: 0.0010)
#   - Other disorders of synovium, tendon, and bursa (prevalence: 0.0001)
#   - Synovitis and tenosynovitis (prevalence: 0.0003)
#   - Acquired toe deformities (prevalence: 0.0002)
#   - Hammer toe (acquired) (prevalence: 0.0002)
#   - Hallux rigidus (prevalence: 0.0001)
#   - Hallux valgus (Bunion) (prevalence: 0.0006)
#   - Other acquired deformities of limbs (prevalence: 0.0002)
#   - Osteoarthritis; localized (prevalence: 0.0012)
#   - Osteoarthrosis, localized, primary (prevalence: 0.0008)
#   - Osteoarthrosis, generalized (prevalence: 0.0007)
#   - Osteoarthrosis NOS (prevalence: 0.0001)
#   - Symptoms and disorders of the joints (prevalence: 0.0001)
#   - Joint effusions (prevalence: 0.0002)
#   - Other derangement of joint (prevalence: 0.0003)
#   - Pain in joint (prevalence: 0.0010)
#   - Internal derangement of knee (prevalence: 0.0012)
#
# Cluster 2:
#   - Benign neoplasm of other parts of digestive system (prevalence: 0.0009)
#   - Iron deficiency anemias, unspecified or not due to blood loss (prevalence: 0.0013)
#   - Esophagitis, GERD and related diseases (prevalence: 0.0009)
#   - Ulcer of esophagus (prevalence: 0.0005)
#   - Barrett's esophagus (prevalence: 0.0004)
#   - Reflux esophagitis (prevalence: 0.0012)
#   - Esophageal bleeding (varices/hemorrhage) (prevalence: 0.0003)
#   - Stricture and stenosis of esophagus (prevalence: 0.0003)
#   - Gastric ulcer (prevalence: 0.0006)
#   - Duodenal ulcer (prevalence: 0.0003)
#   - Gastritis and duodenitis (prevalence: 0.0019)
#   - Duodenitis (prevalence: 0.0008)
#   - Other specified gastritis (prevalence: 0.0012)
#   - Other disorders of stomach and duodenum (prevalence: 0.0005)
#   - Diaphragmatic hernia (prevalence: 0.0031)
#
# Cluster 3:
#   - Bacterial enteritis (prevalence: 0.0002)
#   - Viral Enteritis (prevalence: 0.0001)
#   - Viral infection (prevalence: 0.0005)
#   - Malignant neoplasm of kidney, except pelvis (prevalence: 0.0001)
#   - Neoplasm of uncertain behavior (prevalence: 0.0002)
#   - Non-Hodgkins lymphoma (prevalence: 0.0002)
#   - Benign neoplasm of lip, oral cavity, and pharynx (prevalence: 0.0001)
#   - Lipoma (prevalence: 0.0002)
#   - Lipoma of skin and subcutaneous tissue (prevalence: 0.0004)
#   - Other benign neoplasm of connective and other soft tissue (prevalence: 0.0001)
#   - Hemangioma and lymphangioma, any site (prevalence: 0.0002)
#   - Gout (prevalence: 0.0006)
#   - Bipolar (prevalence: 0.0001)
#   - Alcohol-related disorders (prevalence: 0.0006)
#   - Alcoholic liver damage (prevalence: 0.0001)
#   - Sleep disorders (prevalence: 0.0001)
#   - Parkinson's disease (prevalence: 0.0002)
#   - Multiple sclerosis (prevalence: 0.0001)
#   - Epilepsy, recurrent seizures, convulsions (prevalence: 0.0004)
#   - Facial nerve disorders [CN7] (prevalence: 0.0001)
#   - Inflammatory and toxic neuropathy (prevalence: 0.0003)
#   - Visual disturbances (prevalence: 0.0002)
#   - Inflammation of eyelids (prevalence: 0.0002)
#   - Disorders of conjunctiva (prevalence: 0.0001)
#   - Ptosis of eyelid (prevalence: 0.0002)
#   - Strabismus (not specified as paralytic) (prevalence: 0.0001)
#   - Otitis media (prevalence: 0.0001)
#   - Perforation of tympanic membrane (prevalence: 0.0001)
#   - Hearing loss (prevalence: 0.0007)
#   - Pulmonary heart disease (prevalence: 0.0006)
#   - First degree AV block (prevalence: 0.0003)
#   - Right bundle branch block (prevalence: 0.0004)
#   - Cardiac arrest (prevalence: 0.0002)
#   - Arrhythmia (cardiac) NOS (prevalence: 0.0002)
#   - Abdominal aortic aneurysm (prevalence: 0.0001)
#   - Raynaud's syndrome (prevalence: 0.0002)
#   - Peripheral vascular disease, unspecified (prevalence: 0.0004)
#   - Stricture of artery (prevalence: 0.0001)
#   - Phlebitis and thrombophlebitis of lower extremities (prevalence: 0.0005)
#   - Varicose veins of lower extremity (prevalence: 0.0008)
#   - Acute upper respiratory infections of multiple or unspecified sites (prevalence: 0.0002)
#   - Acute pharyngitis (prevalence: 0.0001)
#   - Diseases of the larynx and vocal cords (prevalence: 0.0001)
#   - Chronic tonsillitis and adenoiditis (prevalence: 0.0001)
#   - Allergic rhinitis (prevalence: 0.0003)
#   - Disturbances in tooth eruption (prevalence: 0.0001)
#   - Dental caries (prevalence: 0.0003)
#   - Periapical abscess (prevalence: 0.0001)
#   - Chronic periodontitis (prevalence: 0.0001)
#   - Other diseases of the teeth and supporting structures (prevalence: 0.0003)
#   - Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue (prevalence: 0.0002)
#   - Diseases and other conditions of the tongue (prevalence: 0.0001)
#   - Acute gastritis (prevalence: 0.0001)
#   - Acute appendicitis (prevalence: 0.0002)
#   - Inguinal hernia (prevalence: 0.0014)
#   - Umbilical hernia (prevalence: 0.0004)
#   - Celiac disease (prevalence: 0.0002)
#   - Functional digestive disorders (prevalence: 0.0001)
#   - Other disorders of liver (prevalence: 0.0003)
#   - Hematemesis (prevalence: 0.0002)
#   - Blood in stool (prevalence: 0.0003)
#   - Cyst of kidney, acquired (prevalence: 0.0004)
#   - Other disorders of testis (prevalence: 0.0001)
#   - Hydrocele (prevalence: 0.0001)
#   - Redundant prepuce and phimosis/BXO (prevalence: 0.0002)
#   - Other disorders of male genital organs (prevalence: 0.0003)
#   - Benign neoplasm of breast (prevalence: 0.0001)
#   - Hypertrophy of breast (Gynecomastia) (prevalence: 0.0001)
#   - Noninflammatory disorders of vulva and perineum (prevalence: 0.0001)
#   - Infertility, female (prevalence: 0.0000)
#   - Carbuncle and furuncle (prevalence: 0.0003)
#   - Psoriasis vulgaris (prevalence: 0.0003)
#   - Ingrowing nail (prevalence: 0.0001)
#   - Sebaceous cyst (prevalence: 0.0007)
#   - Polymyalgia Rheumatica (prevalence: 0.0003)
#   - Bursitis (prevalence: 0.0001)
#   - Ganglion and cyst of synovium, tendon, and bursa (prevalence: 0.0003)
#   - Contracture of palmar fascia [Dupuytren's disease] (prevalence: 0.0003)
#   - Malunion and nonunion of fracture (prevalence: 0.0001)
#   - Osteopenia or other disorder of bone and cartilage (prevalence: 0.0001)
#   - Atopic/contact dermatitis due to other or unspecified (prevalence: 0.0004)
#   - Other tests (prevalence: 0.0003)
#
# Cluster 4:
#   - Septal Deviations/Turbinate Hypertrophy (prevalence: 0.0003)
#   - Nasal polyps (prevalence: 0.0003)
#   - Chronic pharyngitis and nasopharyngitis (prevalence: 0.0001)
#   - Chronic sinusitis (prevalence: 0.0002)
#   - Other upper respiratory disease (prevalence: 0.0004)
#
# Cluster 5:
#   - Hypercholesterolemia (prevalence: 0.0043)
#   - Unstable angina (intermediate coronary syndrome) (prevalence: 0.0004)
#   - Myocardial infarction (prevalence: 0.0015)
#   - Angina pectoris (prevalence: 0.0019)
#   - Coronary atherosclerosis (prevalence: 0.0022)
#   - Other chronic ischemic heart disease, unspecified (prevalence: 0.0019)
#   - Other acute and subacute forms of ischemic heart disease (prevalence: 0.0002)
#
# Cluster 6:
#   - Cancer of bronchus; lung (prevalence: 0.0004)
#   - Malignant neoplasm, other (prevalence: 0.0003)
#   - Secondary malignant neoplasm (prevalence: 0.0003)
#   - Secondary malignancy of lymph nodes (prevalence: 0.0008)
#   - Secondary malignancy of respiratory organs (prevalence: 0.0004)
#   - Secondary malignant neoplasm of digestive systems (prevalence: 0.0003)
#   - Secondary malignant neoplasm of liver (prevalence: 0.0005)
#   - Secondary malignancy of bone (prevalence: 0.0004)
#
# Cluster 7:
#   - Hypothyroidism NOS (prevalence: 0.0017)
#   - Hyperlipidemia (prevalence: 0.0009)
#   - Obesity (prevalence: 0.0024)
#   - Major depressive disorder (prevalence: 0.0019)
#   - Anxiety disorder (prevalence: 0.0014)
#   - Sleep apnea (prevalence: 0.0005)
#   - Migraine (prevalence: 0.0004)
#   - Essential hypertension (prevalence: 0.0091)
#   - Asthma (prevalence: 0.0027)
#   - GERD (prevalence: 0.0026)
#   - Irritable Bowel Syndrome (prevalence: 0.0008)
#   - Other chronic nonalcoholic liver disease (prevalence: 0.0004)
#   - Other inflammatory spondylopathies (prevalence: 0.0002)
#   - Spondylosis and allied disorders (prevalence: 0.0006)
#   - Other disorders of soft tissues (prevalence: 0.0008)
#   - Rheumatism, unspecified and fibrositis (prevalence: 0.0001)
#   - Other disorders of bone and cartilage (prevalence: 0.0005)
#   - Osteoporosis NOS (prevalence: 0.0011)
#   - Cervicalgia (prevalence: 0.0002)
#   - Myalgia and myositis unspecified (prevalence: 0.0003)
#   - Pain in limb (prevalence: 0.0008)
#   - Abdominal pain (prevalence: 0.0010)
#
# Cluster 8:
#   - Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] (prevalence: 0.0001)
#   - Malignant neoplasm of uterus (prevalence: 0.0002)
#   - Malignant neoplasm of ovary (prevalence: 0.0001)
#   - Uterine leiomyoma (prevalence: 0.0008)
#   - Benign neoplasm of ovary (prevalence: 0.0002)
#   - Pelvic peritoneal adhesions, female (postoperative) (postinfection) (prevalence: 0.0003)
#   - Cervicitis and endocervicitis (prevalence: 0.0001)
#   - Endometriosis (prevalence: 0.0003)
#   - Prolapse of vaginal walls (prevalence: 0.0006)
#   - Uterine/Uterovaginal prolapse (prevalence: 0.0004)
#   - Disorders of uterus, NEC (prevalence: 0.0003)
#   - Noninflammatory disorders of cervix (prevalence: 0.0002)
#   - Noninflammatory disorders of vagina (prevalence: 0.0001)
#   - Endometrial hyperplasia (prevalence: 0.0001)
#   - Polyp of corpus uteri (prevalence: 0.0006)
#   - Mucous polyp of cervix (prevalence: 0.0002)
#   - Hypertrophy of female genital organs (prevalence: 0.0001)
#   - Pain and other symptoms associated with female genital organs (prevalence: 0.0001)
#   - Dyspareunia (prevalence: 0.0001)
#   - Disorders of menstruation and other abnormal bleeding from female genital tract (prevalence: 0.0001)
#   - Irregular menstrual cycle/bleeding (prevalence: 0.0001)
#   - Excessive or frequent menstruation (prevalence: 0.0006)
#   - Irregular menstrual cycle (prevalence: 0.0001)
#   - Irregular menstrual bleeding (prevalence: 0.0002)
#   - Dysmenorrhea (prevalence: 0.0001)
#   - Postmenopausal bleeding (prevalence: 0.0008)
#   - Postmenopausal atrophic vaginitis (prevalence: 0.0001)
#   - Ovarian cyst (prevalence: 0.0004)
#
# Cluster 9:
#   - Degenerative disease of the spinal cord (prevalence: 0.0002)
#   - Spinal stenosis (prevalence: 0.0007)
#   - Spondylosis without myelopathy (prevalence: 0.0010)
#   - Displacement of intervertebral disc (prevalence: 0.0003)
#   - Degeneration of intervertebral disc (prevalence: 0.0005)
#   - Other and unspecified disc disorder (prevalence: 0.0006)
#   - Kyphoscoliosis and scoliosis (prevalence: 0.0002)
#   - Acquired spondylolisthesis (prevalence: 0.0002)
#   - Back pain (prevalence: 0.0016)
#   - Thoracic or lumbosacral neuritis or radiculitis, unspecified (prevalence: 0.0005)
#   - Sciatica (prevalence: 0.0004)
#   - Neuralgia, neuritis, and radiculitis NOS (prevalence: 0.0002)
#
# Cluster 10:
#   - Retinal detachments and defects (prevalence: 0.0002)
#   - Retinal detachment with retinal defect (prevalence: 0.0001)
#   - Other retinal disorders (prevalence: 0.0002)
#   - Macular degeneration (senile) of retina NOS (prevalence: 0.0006)
#   - Retinal vascular changes and abnomalities (prevalence: 0.0001)
#   - Glaucoma (prevalence: 0.0007)
#   - Primary open angle glaucoma (prevalence: 0.0002)
#   - Cataract (prevalence: 0.0024)
#   - Senile cataract (prevalence: 0.0020)
#   - Myopia (prevalence: 0.0002)
#   - Disorders of vitreous body (prevalence: 0.0003)
#
# Cluster 11:
#   - Hemiplegia (prevalence: 0.0003)
#   - Cerebrovascular disease (prevalence: 0.0003)
#   - Occlusion and stenosis of precerebral arteries (prevalence: 0.0002)
#   - Occlusion of cerebral arteries (prevalence: 0.0004)
#   - Cerebral artery occlusion, with cerebral infarction (prevalence: 0.0003)
#   - Cerebral ischemia (prevalence: 0.0003)
#   - Transient cerebral ischemia (prevalence: 0.0003)
#   - Late effects of cerebrovascular disease (prevalence: 0.0002)
#
# Cluster 12:
#   - Other disorders of the kidney and ureters (prevalence: 0.0002)
#   - Stricture/obstruction of ureter (prevalence: 0.0001)
#   - Pyelonephritis (prevalence: 0.0002)
#   - Calculus of kidney (prevalence: 0.0004)
#   - Calculus of ureter (prevalence: 0.0002)
#   - Renal colic (prevalence: 0.0001)
#   - Hydronephrosis (prevalence: 0.0004)
#
# Cluster 13:
#   - Cancer of prostate (prevalence: 0.0008)
#   - Malignant neoplasm of bladder (prevalence: 0.0003)
#   - Cystitis (prevalence: 0.0002)
#   - Chronic cystitis (prevalence: 0.0001)
#   - Other disorders of bladder (prevalence: 0.0009)
#   - Bladder neck obstruction (prevalence: 0.0002)
#   - Functional disorders of bladder (prevalence: 0.0002)
#   - Urethral stricture (not specified as infectious) (prevalence: 0.0003)
#   - Other symptoms/disorders or the urinary system (prevalence: 0.0001)
#   - Urinary incontinence (prevalence: 0.0006)
#   - Hyperplasia of prostate (prevalence: 0.0016)
#   - Chronic prostatitis (prevalence: 0.0001)
#   - Other disorders of prostate (prevalence: 0.0002)
#
# Cluster 14:
#   - Tobacco use disorder (prevalence: 0.0015)
#   - Pneumonia (prevalence: 0.0008)
#   - Pneumococcal pneumonia (prevalence: 0.0012)
#   - Chronic airway obstruction (prevalence: 0.0013)
#   - Emphysema (prevalence: 0.0004)
#   - Obstructive chronic bronchitis (prevalence: 0.0005)
#   - Bronchiectasis (prevalence: 0.0004)
#   - Postinflammatory pulmonary fibrosis (prevalence: 0.0002)
#   - Empyema and pneumothorax (prevalence: 0.0002)
#   - Respiratory failure (prevalence: 0.0005)
#
# Cluster 15:
#   - Type 1 diabetes (prevalence: 0.0003)
#   - Type 2 diabetes (prevalence: 0.0026)
#   - Type 2 diabetes with ophthalmic manifestations (prevalence: 0.0002)
#   - Diabetic retinopathy (prevalence: 0.0003)
#   - Hypoglycemia (prevalence: 0.0002)
#
# Cluster 16:
#   - Gram negative septicemia (prevalence: 0.0002)
#   - Bacterial infection NOS (prevalence: 0.0008)
#   - Staphylococcus infections (prevalence: 0.0004)
#   - Streptococcus infection (prevalence: 0.0002)
#   - E. coli (prevalence: 0.0005)
#   - Candidiasis (prevalence: 0.0004)
#   - Disorders of calcium/phosphorus metabolism (prevalence: 0.0003)
#   - Hyposmolality and/or hyponatremia (prevalence: 0.0006)
#   - Hyperpotassemia (prevalence: 0.0002)
#   - Hypopotassemia (prevalence: 0.0005)
#   - Acidosis (prevalence: 0.0003)
#   - Hypovolemia (prevalence: 0.0008)
#   - Other anemias (prevalence: 0.0018)
#   - Thrombocytopenia (prevalence: 0.0003)
#   - Neutropenia (prevalence: 0.0004)
#   - Orthostatic hypotension (prevalence: 0.0004)
#   - Hypotension NOS (prevalence: 0.0009)
#   - Bacterial pneumonia (prevalence: 0.0002)
#   - Pulmonary collapse; interstitial and compensatory emphysema (prevalence: 0.0006)
#   - Other diseases of respiratory system, NEC (prevalence: 0.0012)
#   - Constipation (prevalence: 0.0019)
#   - Peritonitis and retroperitoneal infections (prevalence: 0.0001)
#   - Acute renal failure (prevalence: 0.0016)
#   - Urinary tract infection (prevalence: 0.0019)
#   - Cellulitis and abscess of arm/hand (prevalence: 0.0007)
#   - Other local infections of skin and subcutaneous tissue (prevalence: 0.0002)
#   - Chronic ulcer of skin (prevalence: 0.0002)
#   - Decubitus ulcer (prevalence: 0.0003)
#   - Sepsis (prevalence: 0.0008)
#
# Cluster 17:
#   - Colon cancer (prevalence: 0.0004)
#   - Malignant neoplasm of rectum, rectosigmoid junction, and anus (prevalence: 0.0002)
#   - Neoplasm of unspecified nature of digestive system (prevalence: 0.0001)
#   - Benign neoplasm of colon (prevalence: 0.0028)
#   - Hemorrhoids (prevalence: 0.0027)
#   - Ventral hernia (prevalence: 0.0004)
#   - Regional enteritis (prevalence: 0.0002)
#   - Ulcerative colitis (prevalence: 0.0003)
#   - Noninfectious gastroenteritis (prevalence: 0.0014)
#   - Other intestinal obstruction (prevalence: 0.0005)
#   - Diverticulosis (prevalence: 0.0038)
#   - Anal and rectal conditions (prevalence: 0.0009)
#   - Anal and rectal polyp (prevalence: 0.0010)
#   - Other disorders of intestine (prevalence: 0.0005)
#   - Gastrointestinal complications (prevalence: 0.0001)
#   - Hemorrhage of rectum and anus (prevalence: 0.0011)
#   - Hemorrhage of gastrointestinal tract (prevalence: 0.0010)
#
# Cluster 18:
#   - Peritoneal adhesions (postoperative) (postinfection) (prevalence: 0.0005)
#   - Cholelithiasis (prevalence: 0.0009)
#   - Cholelithiasis with acute cholecystitis (prevalence: 0.0002)
#   - Cholelithiasis with other cholecystitis (prevalence: 0.0006)
#   - Calculus of bile duct (prevalence: 0.0003)
#   - Cholecystitis without cholelithiasis (prevalence: 0.0003)
#   - Other disorders of gallbladder (prevalence: 0.0002)
#   - Other disorders of biliary tract (prevalence: 0.0002)
#   - Acute pancreatitis (prevalence: 0.0003)
#
# Cluster 19:
#   - Viral warts & HPV (prevalence: 0.0001)
#   - Melanomas of skin (prevalence: 0.0003)
#   - Other non-epithelial cancer of skin (prevalence: 0.0014)
#   - Breast cancer [female] (prevalence: 0.0002)
#   - Malignant neoplasm of female breast (prevalence: 0.0009)
#   - Benign neoplasm of skin (prevalence: 0.0007)
#   - Thyrotoxicosis with or without goiter (prevalence: 0.0002)
#   - Secondary hypothyroidism (prevalence: 0.0002)
#   - Other disorders of eyelids (prevalence: 0.0003)
#   - Ectropion or entropion (prevalence: 0.0001)
#   - Disorders of lacrimal system (prevalence: 0.0002)
#   - Epiphora (prevalence: 0.0001)
#   - Hypertensive chronic kidney disease (prevalence: 0.0001)
#   - Chronic glomerulonephritis, NOS (prevalence: 0.0001)
#   - Renal failure NOS (prevalence: 0.0002)
#   - Chronic renal failure [CKD] (prevalence: 0.0007)
#   - Chronic Kidney Disease, Stage III (prevalence: 0.0009)
#   - Lump or mass in breast (prevalence: 0.0001)
#   - Disorder of skin and subcutaneous tissue NOS (prevalence: 0.0006)
#   - Other hypertrophic and atrophic conditions of skin (prevalence: 0.0002)
#   - Scar conditions and fibrosis of skin (prevalence: 0.0002)
#   - Actinic keratosis (prevalence: 0.0004)
#   - Seborrheic keratosis (prevalence: 0.0004)

# %%
model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:808: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   def check_gp_kernels(self):

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
model.genetic_scale
# Out:
# 3.0

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000560
# Mean predicted risk (original): 0.000188
# Mean predicted risk (calibrated): 0.000560
# Calibration scale factor: 2.983

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.503

# %%
history_new = model.fit(E_100k, num_epochs=300, learning_rate=1e-3, lambda_reg=1e-2)

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=1e-4:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history_new['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history_new['max_grad_lambda'], label='Lambda')
ax2.plot(history_new['max_grad_phi'], label='Phi')
ax2.plot(history_new['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert gamma tensors to numpy arrays
initial_gamma_np = initial_gamma.detach().numpy()
final_gamma_np = model.gamma.detach().numpy()

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial gamma
sns.heatmap(initial_gamma_np, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Gamma')

# Plot final gamma
sns.heatmap(final_gamma_np, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Gamma')

# Add a title to the figure
plt.suptitle('Comparison of Initial vs Final Gamma Values', fontsize=16)

# You can also add a colorbar
plt.tight_layout()

# To see the actual difference, you can also create a difference heatmap
plt.figure(figsize=(10, 8))
diff = final_gamma_np - initial_gamma_np
sns.heatmap(diff, cmap='RdBu_r', center=0)
plt.title('Difference (Final - Initial Gamma)')
plt.show()

# Print some summary statistics
print(f"Mean absolute difference: {np.abs(diff).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff):.4f}")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Convert phi tensors to numpy arrays
initial_phi_np = initial_phi.detach().numpy()  # Shape: (K, D, T)
final_phi_np = model.phi.detach().numpy()

# Take mean over time dimension
initial_phi_mean = initial_phi_np.mean(axis=2)  # Shape: (K, D)
final_phi_mean = final_phi_np.mean(axis=2)

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial phi (averaged over time)
sns.heatmap(initial_phi_mean, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Phi (Mean over Time)')
ax1.set_xlabel('Disease')
ax1.set_ylabel('Signature')

# Plot final phi (averaged over time)
sns.heatmap(final_phi_mean, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Phi (Mean over Time)')
ax2.set_xlabel('Disease')
ax2.set_ylabel('Signature')

plt.suptitle('Comparison of Initial vs Final Phi Values (Averaged over Time)', fontsize=16)
plt.tight_layout()

# Plot difference
plt.figure(figsize=(10, 8))
diff_mean = final_phi_mean - initial_phi_mean
sns.heatmap(diff_mean, cmap='RdBu_r', center=0)
plt.title('Difference in Phi (Final - Initial), Mean over Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# Print summary statistics for both full tensor and time-averaged differences
print("Full tensor statistics:")
diff_full = final_phi_np - initial_phi_np
print(f"Mean absolute difference: {np.abs(diff_full).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_full).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_full):.4f}")

print("\nTime-averaged statistics:")
print(f"Mean absolute difference: {np.abs(diff_mean).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_mean).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_mean):.4f}")

# Optionally, look at temporal variation
temporal_std = np.std(diff_full, axis=2)
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_std, cmap='viridis')
plt.title('Standard Deviation of Changes Across Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# %%
model_save_path='/Users/sarahurbut/Dropbox (Personal)/model_with_poptrajectory_lr1e-3.pt'
torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'initial_phi': initial_phi, 
    'initial_lambda': initial_lambda, 
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t': essentials['prevalence_t'],
    'logit_prevalence_t': model.logit_prev_t,
    'G': G_100k,
    'E': E_100k,
    'indices': indices,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T': Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, model_save_path)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")

# %%
ss_res = np.sum((observed_risk - predicted_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
disease_names=essentials['disease_names']
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,1,14,15,16,13,17])

# %%
Y_avg_global = torch.mean(torch.tensor(Y) if isinstance(Y,np.ndarray) else Y, dim=2)
Y_avg_batch = torch.mean(torch.tensor(Y_100k) if isinstance(Y_100k, np.ndarray) else Y_100k, dim=2)

# %%
def compare_disease_patterns(k, true_psi, Y_avg_global, Y_avg_batch):
    """Compare disease patterns between global and batch data"""
    strong_diseases = (true_psi[k] > 0)
    
    # Get mean pattern for each dataset (average across patients)
    pattern_large = Y_avg_global[:, strong_diseases].mean(dim=0)  # Average across all patients
    pattern_small = Y_avg_batch[:, strong_diseases].mean(dim=0)  # Average across batch patients
    
    # Now both patterns are just length of strong_diseases
    correlation = torch.corrcoef(
        torch.stack([pattern_large, pattern_small])
    )[0,1]
    
    print(f"Signature {k} pattern correlation: {correlation:.3f}")
    print(f"Mean pattern difference: {(pattern_large - pattern_small).abs().mean():.3f}")

# Now use it
print("Comparing disease sharing patterns between global and batch data:")
for k in range(model.K):
    print(f"\nSignature {k}:")
    compare_disease_patterns(k, model.psi, Y_avg_global, Y_avg_batch)
