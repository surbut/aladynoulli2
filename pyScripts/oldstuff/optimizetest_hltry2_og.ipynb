# %%
# %load_ext autoreload
# %autoreload 2

from cluster_g_logit_init_acceptpsi_flatlam_healthtoo import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/filesforupload/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'filtered_3plus/Y_tensor_filtered.pt')
    E = torch.load(base_path + 'filtered_3plus/E_matrix_filtered.pt')
    G = torch.load(base_path + 'filtered_3plus/G_matrix_filtered.pt')
    
    # Load other components
    essentials = torch.load('/Users/sarahurbut/Dropbox (Personal)/data_for_running/model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_43544/2518768727.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'filtered_3plus/Y_tensor_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_43544/2518768727.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'filtered_3plus/E_matrix_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_43544/2518768727.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'filtered_3plus/G_matrix_filtered.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_43544/2518768727.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load('/Users/sarahurbut/Dropbox (Personal)/data_for_running/model_essentials.pt')
# Loaded all components successfully!

# %%
def subset_data(Y, E, G, n_samples=50000, seed=42):
    """
    Subset the data to n_samples individuals while maintaining consistency
    
    Args:
        Y: tensor of shape [N, D, T]
        E: tensor of shape [N, D]
        G: tensor of shape [N, P]
        n_samples: number of individuals to keep
        seed: random seed for reproducibility
    
    Returns:
        Y_sub, E_sub, G_sub: subsetted tensors
    """
    torch.manual_seed(seed)
    
    # Get total number of individuals
    N = Y.shape[0]
    
    # Randomly select n_samples indices
    indices = torch.randperm(N)[:n_samples]
    
    # Subset all matrices using the same indices
    Y_sub = Y[indices]
    E_sub = E[indices]
    G_sub = G[indices]
    
    print(f"Original shapes: Y={Y.shape}, E={E.shape}, G={G.shape}")
    print(f"New shapes: Y={Y_sub.shape}, E={E_sub.shape}, G={G_sub.shape}")
    
    return Y_sub, E_sub, G_sub, indices

# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000,seed=1)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([314976, 348, 52]), E=torch.Size([314976, 348]), G=(314976, 36)
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=(10000, 36)

# %%
# When initializing the model:
original_G = G_100k # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_43544/1949801412.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_43544/1949801412.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
# Load the saved references
refs = torch.load('reference_trajectories.pt')
signature_refs = refs['signature_refs']
healthy_ref = refs['healthy_ref']

# Verify the shapes
print("Signature references shape:", signature_refs.shape)  # Should be [K, T]
print("Healthy reference shape:", healthy_ref.shape)       # Should be [T]

# Optional: Quick plot to verify they loaded correctly
plt.figure(figsize=(15, 8))
props = torch.softmax(torch.vstack([signature_refs, healthy_ref]), dim=0)
for k in range(signature_refs.shape[0]):
    plt.plot(range(len(healthy_ref)), props[k], label=f'Signature {k}', alpha=0.7)
plt.plot(range(len(healthy_ref)), props[-1], label='Healthy', color='black', linestyle='--')
plt.xlabel('Time (years)')
plt.ylabel('Reference Proportions')
plt.title('Loaded Reference Trajectories')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Signature references shape: torch.Size([20, 52])
# Healthy reference shape: torch.Size([52])
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_43544/823062432.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('reference_trajectories.pt')

# %%
# Load references (signatures only, no healthy)
refs = torch.load('reference_trajectories.pt')
signature_refs = refs['signature_refs']


# Create model without healthy reference
model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0], 
    D=Y_100k.shape[1], 
    T=Y_100k.shape[2], 
    K=20,
    P=G_100k.shape[1],
    G=G_100k, 
    Y=Y_100k,
    prevalence_t=essentials['prevalence_t'],
    signature_references=signature_refs,  # Only pass signature refs
    healthy_reference=None,  # Explicitly set to None
    disease_names=essentials['disease_names']
)

# Initialize with psi and clusters
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters

# Verify clusters match
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_43544/2422801962.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   refs = torch.load('reference_trajectories.pt')
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.signature_refs = torch.tensor(signature_references, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
#
# Cluster Sizes:
# Cluster 0: 18 diseases
# Cluster 1: 28 diseases
# Cluster 2: 99 diseases
# Cluster 3: 13 diseases
# Cluster 4: 18 diseases
# Cluster 5: 28 diseases
# Cluster 6: 5 diseases
# Cluster 7: 11 diseases
# Cluster 8: 9 diseases
# Cluster 9: 17 diseases
# Cluster 10: 7 diseases
# Cluster 11: 13 diseases
# Cluster 12: 9 diseases
# Cluster 13: 5 diseases
# Cluster 14: 9 diseases
# Cluster 15: 21 diseases
# Cluster 16: 10 diseases
# Cluster 17: 6 diseases
# Cluster 18: 15 diseases
# Cluster 19: 7 diseases
# Initializing with 20 disease states only
# Initialization complete!
# Initializing with 20 disease states only
# Initialization complete!
#
# Clusters match exactly: True

# %%
# Sample patients and set parameters
n_samples = 2
sample_patients = [4376, 6640]  # Use specific patients
n_top_states = 5  # Show only top 5 states per patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
time_points = np.arange(model.T)

# Get dominant states for these patients
lambda_patients = model.lambda_[sample_patients]  # [2, K, T]
patient_props = torch.softmax(lambda_patients, dim=1)  # [2, K, T]
mean_props = patient_props.mean(dim=-1)  # Average over time, now [2, K]
top_states = mean_props.topk(n_top_states, dim=-1).indices  # Get top states for each patient

# Color map for consistent colors across patients
colors = plt.cm.tab20(np.linspace(0, 1, model.K))

# Plot for each patient
for i, patient in enumerate(sample_patients):
    for j, k in enumerate(top_states[i]):
        k = k.item()  # Convert tensor to int
        color = colors[k]
        
        # Plot lambda values
        ax1.plot(time_points, signature_refs[k], '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax1.plot(time_points, model.lambda_[patient, k].detach(), '-', color=color,
                label=f'Patient {patient} - State {k}')
        
        # Plot proportions
        ref_props = torch.softmax(signature_refs, dim=0)[k]
        patient_props = torch.softmax(model.lambda_[patient].detach(), dim=0)[k]
        ax2.plot(time_points, ref_props, '--', color=color, alpha=0.3, 
                label=f'Ref {k}')
        ax2.plot(time_points, patient_props, '-', color=color,
                label=f'Patient {patient} - State {k}')

# Customize plots
ax1.set_title('Initial Lambda Values\n(dashed=reference, solid=patient-specific)')
ax1.set_xlabel('Time')
ax1.set_ylabel('Lambda (logit scale)')
ax1.grid(True, alpha=0.3)
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2.set_title('Initial Proportions\n(dashed=reference, solid=patient-specific)')
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion')
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# Print genetic effects for these patients
print("\nGenetic Effect Statistics for Sample Patients:")
for i, patient in enumerate(sample_patients):
    genetic_effects = model.genetic_scale * (model.G[patient] @ model.gamma).detach()
    print(f"\nPatient {patient}:")
    print(f"Mean shift: {genetic_effects.mean():.3f}")
    print(f"Std of shifts: {genetic_effects.std():.3f}")
    print(f"Range of shifts: [{genetic_effects.min():.3f}, {genetic_effects.max():.3f}]")
    
    # Print top states and their proportions
    patient_mean_props = mean_props[i]  # Already computed above
    top_props, top_indices = patient_mean_props.topk(n_top_states)
    print("\nTop states and average proportions:")
    for state, prop in zip(top_indices, top_props):
        print(f"State {state.item()}: {prop:.3f}")
# Out:
# Genetic Effect Statistics for Sample Patients:
#
# Patient 4376:
# Mean shift: -0.189
# Std of shifts: 0.556
# Range of shifts: [-2.365, 0.233]
#
# Top states and average proportions:
# State 7: 0.186
# State 3: 0.186
# State 8: 0.095
# State 17: 0.078
# State 1: 0.076
#
# Patient 6640:
# Mean shift: 0.019
# Std of shifts: 0.333
# Range of shifts: [-0.455, 1.046]
#
# Top states and average proportions:
# State 7: 0.194
# State 3: 0.173
# State 1: 0.086
# State 17: 0.070
# State 13: 0.061

# %%
model.genetic_scale
# Out:
# 3.0

# %%
model.plot_initial_params()
# Convert disease names to list if it's not already
disease_names_list = list(essentials['disease_names'])

# Now visualize clusters
model.visualize_clusters(disease_names=disease_names_list)
# Out:
# Cluster membership for sampled diseases:
# Disease 255: Cluster 3
# Disease 114: Cluster 5
# Disease 314: Cluster 7
# Disease 268: Cluster 8
# Disease 167: Cluster 14
#
# Cluster Assignments:
#
# Cluster 0:
#   - Rheumatic disease of the heart valves (prevalence: 0.0003)
#   - Mitral valve disease (prevalence: 0.0004)
#   - Aortic valve disease (prevalence: 0.0002)
#   - Disease of tricuspid valve (prevalence: 0.0003)
#   - Other forms of chronic heart disease (prevalence: 0.0006)
#   - Cardiomegaly (prevalence: 0.0006)
#   - Pericarditis (prevalence: 0.0002)
#   - Primary/intrinsic cardiomyopathies (prevalence: 0.0001)
#   - Left bundle branch block (prevalence: 0.0004)
#   - Paroxysmal supraventricular tachycardia (prevalence: 0.0003)
#   - Paroxysmal ventricular tachycardia (prevalence: 0.0001)
#   - Atrial fibrillation and flutter (prevalence: 0.0012)
#   - Congestive heart failure (CHF) NOS (prevalence: 0.0005)
#   - Heart failure NOS (prevalence: 0.0009)
#   - Pleurisy; pleural effusion (prevalence: 0.0012)
#   - Congenital anomalies of great vessels (prevalence: 0.0003)
#
# Cluster 1:
#   - Other peripheral nerve disorders (prevalence: 0.0011)
#   - Rheumatoid arthritis (prevalence: 0.0006)
#   - Arthropathy NOS (prevalence: 0.0051)
#   - Peripheral enthesopathies and allied syndromes (prevalence: 0.0006)
#   - Enthesopathy (prevalence: 0.0010)
#   - Other disorders of synovium, tendon, and bursa (prevalence: 0.0001)
#   - Synovitis and tenosynovitis (prevalence: 0.0003)
#   - Acquired toe deformities (prevalence: 0.0002)
#   - Hammer toe (acquired) (prevalence: 0.0002)
#   - Hallux rigidus (prevalence: 0.0001)
#   - Hallux valgus (Bunion) (prevalence: 0.0006)
#   - Other acquired deformities of limbs (prevalence: 0.0002)
#   - Osteoarthritis; localized (prevalence: 0.0012)
#   - Osteoarthrosis, localized, primary (prevalence: 0.0008)
#   - Osteoarthrosis, generalized (prevalence: 0.0007)
#   - Osteoarthrosis NOS (prevalence: 0.0001)
#   - Symptoms and disorders of the joints (prevalence: 0.0001)
#   - Joint effusions (prevalence: 0.0002)
#   - Other derangement of joint (prevalence: 0.0003)
#   - Pain in joint (prevalence: 0.0010)
#   - Internal derangement of knee (prevalence: 0.0012)
#
# Cluster 2:
#   - Benign neoplasm of other parts of digestive system (prevalence: 0.0009)
#   - Iron deficiency anemias, unspecified or not due to blood loss (prevalence: 0.0013)
#   - Esophagitis, GERD and related diseases (prevalence: 0.0009)
#   - Ulcer of esophagus (prevalence: 0.0005)
#   - Barrett's esophagus (prevalence: 0.0004)
#   - Reflux esophagitis (prevalence: 0.0012)
#   - Esophageal bleeding (varices/hemorrhage) (prevalence: 0.0003)
#   - Stricture and stenosis of esophagus (prevalence: 0.0003)
#   - Gastric ulcer (prevalence: 0.0006)
#   - Duodenal ulcer (prevalence: 0.0003)
#   - Gastritis and duodenitis (prevalence: 0.0019)
#   - Duodenitis (prevalence: 0.0008)
#   - Other specified gastritis (prevalence: 0.0012)
#   - Other disorders of stomach and duodenum (prevalence: 0.0005)
#   - Diaphragmatic hernia (prevalence: 0.0031)
#
# Cluster 3:
#   - Bacterial enteritis (prevalence: 0.0002)
#   - Viral Enteritis (prevalence: 0.0001)
#   - Viral infection (prevalence: 0.0005)
#   - Malignant neoplasm of kidney, except pelvis (prevalence: 0.0001)
#   - Neoplasm of uncertain behavior (prevalence: 0.0002)
#   - Non-Hodgkins lymphoma (prevalence: 0.0002)
#   - Benign neoplasm of lip, oral cavity, and pharynx (prevalence: 0.0001)
#   - Lipoma (prevalence: 0.0002)
#   - Lipoma of skin and subcutaneous tissue (prevalence: 0.0004)
#   - Other benign neoplasm of connective and other soft tissue (prevalence: 0.0001)
#   - Hemangioma and lymphangioma, any site (prevalence: 0.0002)
#   - Gout (prevalence: 0.0006)
#   - Bipolar (prevalence: 0.0001)
#   - Alcohol-related disorders (prevalence: 0.0006)
#   - Alcoholic liver damage (prevalence: 0.0001)
#   - Sleep disorders (prevalence: 0.0001)
#   - Parkinson's disease (prevalence: 0.0002)
#   - Multiple sclerosis (prevalence: 0.0001)
#   - Epilepsy, recurrent seizures, convulsions (prevalence: 0.0004)
#   - Facial nerve disorders [CN7] (prevalence: 0.0001)
#   - Inflammatory and toxic neuropathy (prevalence: 0.0003)
#   - Visual disturbances (prevalence: 0.0002)
#   - Inflammation of eyelids (prevalence: 0.0002)
#   - Disorders of conjunctiva (prevalence: 0.0001)
#   - Ptosis of eyelid (prevalence: 0.0002)
#   - Strabismus (not specified as paralytic) (prevalence: 0.0001)
#   - Otitis media (prevalence: 0.0001)
#   - Perforation of tympanic membrane (prevalence: 0.0001)
#   - Hearing loss (prevalence: 0.0007)
#   - Pulmonary heart disease (prevalence: 0.0006)
#   - First degree AV block (prevalence: 0.0003)
#   - Right bundle branch block (prevalence: 0.0004)
#   - Cardiac arrest (prevalence: 0.0002)
#   - Arrhythmia (cardiac) NOS (prevalence: 0.0002)
#   - Abdominal aortic aneurysm (prevalence: 0.0001)
#   - Raynaud's syndrome (prevalence: 0.0002)
#   - Peripheral vascular disease, unspecified (prevalence: 0.0004)
#   - Stricture of artery (prevalence: 0.0001)
#   - Phlebitis and thrombophlebitis of lower extremities (prevalence: 0.0005)
#   - Varicose veins of lower extremity (prevalence: 0.0008)
#   - Acute upper respiratory infections of multiple or unspecified sites (prevalence: 0.0002)
#   - Acute pharyngitis (prevalence: 0.0001)
#   - Diseases of the larynx and vocal cords (prevalence: 0.0001)
#   - Chronic tonsillitis and adenoiditis (prevalence: 0.0001)
#   - Allergic rhinitis (prevalence: 0.0003)
#   - Disturbances in tooth eruption (prevalence: 0.0001)
#   - Dental caries (prevalence: 0.0003)
#   - Periapical abscess (prevalence: 0.0001)
#   - Chronic periodontitis (prevalence: 0.0001)
#   - Other diseases of the teeth and supporting structures (prevalence: 0.0003)
#   - Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue (prevalence: 0.0002)
#   - Diseases and other conditions of the tongue (prevalence: 0.0001)
#   - Acute gastritis (prevalence: 0.0001)
#   - Acute appendicitis (prevalence: 0.0002)
#   - Inguinal hernia (prevalence: 0.0014)
#   - Umbilical hernia (prevalence: 0.0004)
#   - Celiac disease (prevalence: 0.0002)
#   - Functional digestive disorders (prevalence: 0.0001)
#   - Other disorders of liver (prevalence: 0.0003)
#   - Hematemesis (prevalence: 0.0002)
#   - Blood in stool (prevalence: 0.0003)
#   - Cyst of kidney, acquired (prevalence: 0.0004)
#   - Other disorders of testis (prevalence: 0.0001)
#   - Hydrocele (prevalence: 0.0001)
#   - Redundant prepuce and phimosis/BXO (prevalence: 0.0002)
#   - Other disorders of male genital organs (prevalence: 0.0003)
#   - Benign neoplasm of breast (prevalence: 0.0001)
#   - Hypertrophy of breast (Gynecomastia) (prevalence: 0.0001)
#   - Noninflammatory disorders of vulva and perineum (prevalence: 0.0001)
#   - Infertility, female (prevalence: 0.0000)
#   - Carbuncle and furuncle (prevalence: 0.0003)
#   - Psoriasis vulgaris (prevalence: 0.0003)
#   - Ingrowing nail (prevalence: 0.0001)
#   - Sebaceous cyst (prevalence: 0.0007)
#   - Polymyalgia Rheumatica (prevalence: 0.0003)
#   - Bursitis (prevalence: 0.0001)
#   - Ganglion and cyst of synovium, tendon, and bursa (prevalence: 0.0003)
#   - Contracture of palmar fascia [Dupuytren's disease] (prevalence: 0.0003)
#   - Malunion and nonunion of fracture (prevalence: 0.0001)
#   - Osteopenia or other disorder of bone and cartilage (prevalence: 0.0001)
#   - Atopic/contact dermatitis due to other or unspecified (prevalence: 0.0004)
#   - Other tests (prevalence: 0.0003)
#
# Cluster 4:
#   - Septal Deviations/Turbinate Hypertrophy (prevalence: 0.0003)
#   - Nasal polyps (prevalence: 0.0003)
#   - Chronic pharyngitis and nasopharyngitis (prevalence: 0.0001)
#   - Chronic sinusitis (prevalence: 0.0002)
#   - Other upper respiratory disease (prevalence: 0.0004)
#
# Cluster 5:
#   - Hypercholesterolemia (prevalence: 0.0043)
#   - Unstable angina (intermediate coronary syndrome) (prevalence: 0.0004)
#   - Myocardial infarction (prevalence: 0.0015)
#   - Angina pectoris (prevalence: 0.0019)
#   - Coronary atherosclerosis (prevalence: 0.0022)
#   - Other chronic ischemic heart disease, unspecified (prevalence: 0.0019)
#   - Other acute and subacute forms of ischemic heart disease (prevalence: 0.0002)
#
# Cluster 6:
#   - Cancer of bronchus; lung (prevalence: 0.0004)
#   - Malignant neoplasm, other (prevalence: 0.0003)
#   - Secondary malignant neoplasm (prevalence: 0.0003)
#   - Secondary malignancy of lymph nodes (prevalence: 0.0008)
#   - Secondary malignancy of respiratory organs (prevalence: 0.0004)
#   - Secondary malignant neoplasm of digestive systems (prevalence: 0.0003)
#   - Secondary malignant neoplasm of liver (prevalence: 0.0005)
#   - Secondary malignancy of bone (prevalence: 0.0004)
#
# Cluster 7:
#   - Hypothyroidism NOS (prevalence: 0.0017)
#   - Hyperlipidemia (prevalence: 0.0009)
#   - Obesity (prevalence: 0.0024)
#   - Major depressive disorder (prevalence: 0.0019)
#   - Anxiety disorder (prevalence: 0.0014)
#   - Sleep apnea (prevalence: 0.0005)
#   - Migraine (prevalence: 0.0004)
#   - Essential hypertension (prevalence: 0.0091)
#   - Asthma (prevalence: 0.0027)
#   - GERD (prevalence: 0.0026)
#   - Irritable Bowel Syndrome (prevalence: 0.0008)
#   - Other chronic nonalcoholic liver disease (prevalence: 0.0004)
#   - Other inflammatory spondylopathies (prevalence: 0.0002)
#   - Spondylosis and allied disorders (prevalence: 0.0006)
#   - Other disorders of soft tissues (prevalence: 0.0008)
#   - Rheumatism, unspecified and fibrositis (prevalence: 0.0001)
#   - Other disorders of bone and cartilage (prevalence: 0.0005)
#   - Osteoporosis NOS (prevalence: 0.0011)
#   - Cervicalgia (prevalence: 0.0002)
#   - Myalgia and myositis unspecified (prevalence: 0.0003)
#   - Pain in limb (prevalence: 0.0008)
#   - Abdominal pain (prevalence: 0.0010)
#
# Cluster 8:
#   - Cervical intraepithelial neoplasia [CIN] [Cervical dysplasia] (prevalence: 0.0001)
#   - Malignant neoplasm of uterus (prevalence: 0.0002)
#   - Malignant neoplasm of ovary (prevalence: 0.0001)
#   - Uterine leiomyoma (prevalence: 0.0008)
#   - Benign neoplasm of ovary (prevalence: 0.0002)
#   - Pelvic peritoneal adhesions, female (postoperative) (postinfection) (prevalence: 0.0003)
#   - Cervicitis and endocervicitis (prevalence: 0.0001)
#   - Endometriosis (prevalence: 0.0003)
#   - Prolapse of vaginal walls (prevalence: 0.0006)
#   - Uterine/Uterovaginal prolapse (prevalence: 0.0004)
#   - Disorders of uterus, NEC (prevalence: 0.0003)
#   - Noninflammatory disorders of cervix (prevalence: 0.0002)
#   - Noninflammatory disorders of vagina (prevalence: 0.0001)
#   - Endometrial hyperplasia (prevalence: 0.0001)
#   - Polyp of corpus uteri (prevalence: 0.0006)
#   - Mucous polyp of cervix (prevalence: 0.0002)
#   - Hypertrophy of female genital organs (prevalence: 0.0001)
#   - Pain and other symptoms associated with female genital organs (prevalence: 0.0001)
#   - Dyspareunia (prevalence: 0.0001)
#   - Disorders of menstruation and other abnormal bleeding from female genital tract (prevalence: 0.0001)
#   - Irregular menstrual cycle/bleeding (prevalence: 0.0001)
#   - Excessive or frequent menstruation (prevalence: 0.0006)
#   - Irregular menstrual cycle (prevalence: 0.0001)
#   - Irregular menstrual bleeding (prevalence: 0.0002)
#   - Dysmenorrhea (prevalence: 0.0001)
#   - Postmenopausal bleeding (prevalence: 0.0008)
#   - Postmenopausal atrophic vaginitis (prevalence: 0.0001)
#   - Ovarian cyst (prevalence: 0.0004)
#
# Cluster 9:
#   - Degenerative disease of the spinal cord (prevalence: 0.0002)
#   - Spinal stenosis (prevalence: 0.0007)
#   - Spondylosis without myelopathy (prevalence: 0.0010)
#   - Displacement of intervertebral disc (prevalence: 0.0003)
#   - Degeneration of intervertebral disc (prevalence: 0.0005)
#   - Other and unspecified disc disorder (prevalence: 0.0006)
#   - Kyphoscoliosis and scoliosis (prevalence: 0.0002)
#   - Acquired spondylolisthesis (prevalence: 0.0002)
#   - Back pain (prevalence: 0.0016)
#   - Thoracic or lumbosacral neuritis or radiculitis, unspecified (prevalence: 0.0005)
#   - Sciatica (prevalence: 0.0004)
#   - Neuralgia, neuritis, and radiculitis NOS (prevalence: 0.0002)
#
# Cluster 10:
#   - Retinal detachments and defects (prevalence: 0.0002)
#   - Retinal detachment with retinal defect (prevalence: 0.0001)
#   - Other retinal disorders (prevalence: 0.0002)
#   - Macular degeneration (senile) of retina NOS (prevalence: 0.0006)
#   - Retinal vascular changes and abnomalities (prevalence: 0.0001)
#   - Glaucoma (prevalence: 0.0007)
#   - Primary open angle glaucoma (prevalence: 0.0002)
#   - Cataract (prevalence: 0.0024)
#   - Senile cataract (prevalence: 0.0020)
#   - Myopia (prevalence: 0.0002)
#   - Disorders of vitreous body (prevalence: 0.0003)
#
# Cluster 11:
#   - Hemiplegia (prevalence: 0.0003)
#   - Cerebrovascular disease (prevalence: 0.0003)
#   - Occlusion and stenosis of precerebral arteries (prevalence: 0.0002)
#   - Occlusion of cerebral arteries (prevalence: 0.0004)
#   - Cerebral artery occlusion, with cerebral infarction (prevalence: 0.0003)
#   - Cerebral ischemia (prevalence: 0.0003)
#   - Transient cerebral ischemia (prevalence: 0.0003)
#   - Late effects of cerebrovascular disease (prevalence: 0.0002)
#
# Cluster 12:
#   - Other disorders of the kidney and ureters (prevalence: 0.0002)
#   - Stricture/obstruction of ureter (prevalence: 0.0001)
#   - Pyelonephritis (prevalence: 0.0002)
#   - Calculus of kidney (prevalence: 0.0004)
#   - Calculus of ureter (prevalence: 0.0002)
#   - Renal colic (prevalence: 0.0001)
#   - Hydronephrosis (prevalence: 0.0004)
#
# Cluster 13:
#   - Cancer of prostate (prevalence: 0.0008)
#   - Malignant neoplasm of bladder (prevalence: 0.0003)
#   - Cystitis (prevalence: 0.0002)
#   - Chronic cystitis (prevalence: 0.0001)
#   - Other disorders of bladder (prevalence: 0.0009)
#   - Bladder neck obstruction (prevalence: 0.0002)
#   - Functional disorders of bladder (prevalence: 0.0002)
#   - Urethral stricture (not specified as infectious) (prevalence: 0.0003)
#   - Other symptoms/disorders or the urinary system (prevalence: 0.0001)
#   - Urinary incontinence (prevalence: 0.0006)
#   - Hyperplasia of prostate (prevalence: 0.0016)
#   - Chronic prostatitis (prevalence: 0.0001)
#   - Other disorders of prostate (prevalence: 0.0002)
#
# Cluster 14:
#   - Tobacco use disorder (prevalence: 0.0015)
#   - Pneumonia (prevalence: 0.0008)
#   - Pneumococcal pneumonia (prevalence: 0.0012)
#   - Chronic airway obstruction (prevalence: 0.0013)
#   - Emphysema (prevalence: 0.0004)
#   - Obstructive chronic bronchitis (prevalence: 0.0005)
#   - Bronchiectasis (prevalence: 0.0004)
#   - Postinflammatory pulmonary fibrosis (prevalence: 0.0002)
#   - Empyema and pneumothorax (prevalence: 0.0002)
#   - Respiratory failure (prevalence: 0.0005)
#
# Cluster 15:
#   - Type 1 diabetes (prevalence: 0.0003)
#   - Type 2 diabetes (prevalence: 0.0026)
#   - Type 2 diabetes with ophthalmic manifestations (prevalence: 0.0002)
#   - Diabetic retinopathy (prevalence: 0.0003)
#   - Hypoglycemia (prevalence: 0.0002)
#
# Cluster 16:
#   - Gram negative septicemia (prevalence: 0.0002)
#   - Bacterial infection NOS (prevalence: 0.0008)
#   - Staphylococcus infections (prevalence: 0.0004)
#   - Streptococcus infection (prevalence: 0.0002)
#   - E. coli (prevalence: 0.0005)
#   - Candidiasis (prevalence: 0.0004)
#   - Disorders of calcium/phosphorus metabolism (prevalence: 0.0003)
#   - Hyposmolality and/or hyponatremia (prevalence: 0.0006)
#   - Hyperpotassemia (prevalence: 0.0002)
#   - Hypopotassemia (prevalence: 0.0005)
#   - Acidosis (prevalence: 0.0003)
#   - Hypovolemia (prevalence: 0.0008)
#   - Other anemias (prevalence: 0.0018)
#   - Thrombocytopenia (prevalence: 0.0003)
#   - Neutropenia (prevalence: 0.0004)
#   - Orthostatic hypotension (prevalence: 0.0004)
#   - Hypotension NOS (prevalence: 0.0009)
#   - Bacterial pneumonia (prevalence: 0.0002)
#   - Pulmonary collapse; interstitial and compensatory emphysema (prevalence: 0.0006)
#   - Other diseases of respiratory system, NEC (prevalence: 0.0012)
#   - Constipation (prevalence: 0.0019)
#   - Peritonitis and retroperitoneal infections (prevalence: 0.0001)
#   - Acute renal failure (prevalence: 0.0016)
#   - Urinary tract infection (prevalence: 0.0019)
#   - Cellulitis and abscess of arm/hand (prevalence: 0.0007)
#   - Other local infections of skin and subcutaneous tissue (prevalence: 0.0002)
#   - Chronic ulcer of skin (prevalence: 0.0002)
#   - Decubitus ulcer (prevalence: 0.0003)
#   - Sepsis (prevalence: 0.0008)
#
# Cluster 17:
#   - Colon cancer (prevalence: 0.0004)
#   - Malignant neoplasm of rectum, rectosigmoid junction, and anus (prevalence: 0.0002)
#   - Neoplasm of unspecified nature of digestive system (prevalence: 0.0001)
#   - Benign neoplasm of colon (prevalence: 0.0028)
#   - Hemorrhoids (prevalence: 0.0027)
#   - Ventral hernia (prevalence: 0.0004)
#   - Regional enteritis (prevalence: 0.0002)
#   - Ulcerative colitis (prevalence: 0.0003)
#   - Noninfectious gastroenteritis (prevalence: 0.0014)
#   - Other intestinal obstruction (prevalence: 0.0005)
#   - Diverticulosis (prevalence: 0.0038)
#   - Anal and rectal conditions (prevalence: 0.0009)
#   - Anal and rectal polyp (prevalence: 0.0010)
#   - Other disorders of intestine (prevalence: 0.0005)
#   - Gastrointestinal complications (prevalence: 0.0001)
#   - Hemorrhage of rectum and anus (prevalence: 0.0011)
#   - Hemorrhage of gastrointestinal tract (prevalence: 0.0010)
#
# Cluster 18:
#   - Peritoneal adhesions (postoperative) (postinfection) (prevalence: 0.0005)
#   - Cholelithiasis (prevalence: 0.0009)
#   - Cholelithiasis with acute cholecystitis (prevalence: 0.0002)
#   - Cholelithiasis with other cholecystitis (prevalence: 0.0006)
#   - Calculus of bile duct (prevalence: 0.0003)
#   - Cholecystitis without cholelithiasis (prevalence: 0.0003)
#   - Other disorders of gallbladder (prevalence: 0.0002)
#   - Other disorders of biliary tract (prevalence: 0.0002)
#   - Acute pancreatitis (prevalence: 0.0003)
#
# Cluster 19:
#   - Viral warts & HPV (prevalence: 0.0001)
#   - Melanomas of skin (prevalence: 0.0003)
#   - Other non-epithelial cancer of skin (prevalence: 0.0014)
#   - Breast cancer [female] (prevalence: 0.0002)
#   - Malignant neoplasm of female breast (prevalence: 0.0009)
#   - Benign neoplasm of skin (prevalence: 0.0007)
#   - Thyrotoxicosis with or without goiter (prevalence: 0.0002)
#   - Secondary hypothyroidism (prevalence: 0.0002)
#   - Other disorders of eyelids (prevalence: 0.0003)
#   - Ectropion or entropion (prevalence: 0.0001)
#   - Disorders of lacrimal system (prevalence: 0.0002)
#   - Epiphora (prevalence: 0.0001)
#   - Hypertensive chronic kidney disease (prevalence: 0.0001)
#   - Chronic glomerulonephritis, NOS (prevalence: 0.0001)
#   - Renal failure NOS (prevalence: 0.0002)
#   - Chronic renal failure [CKD] (prevalence: 0.0007)
#   - Chronic Kidney Disease, Stage III (prevalence: 0.0009)
#   - Lump or mass in breast (prevalence: 0.0001)
#   - Disorder of skin and subcutaneous tissue NOS (prevalence: 0.0006)
#   - Other hypertrophic and atrophic conditions of skin (prevalence: 0.0002)
#   - Scar conditions and fibrosis of skin (prevalence: 0.0002)
#   - Actinic keratosis (prevalence: 0.0004)
#   - Seborrheic keratosis (prevalence: 0.0004)

# %%
model.visualize_initialization()
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:797: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
model.genetic_scale
# Out:
# 3.0

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000560
# Mean predicted risk (original): 0.000263
# Mean predicted risk (calibrated): 0.000560
# Calibration scale factor: 2.129

# %%
ss_res = np.sum((observed_risk - predicted_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.613

# %%
history_new = model.fit(E_100k, num_epochs=300, learning_rate=1e-3, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi_flatlam_healthtoo.py:198: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 0
# Loss: 600.5139
# Psi gradient stats:
# Mean: 3.7819e-05
# Std:  4.7422e-03
# Max:  1.7553e-02
# Min:  -1.8102e-02
# Epoch 0, Loss: 600.5139, Gradients - Lambda: 5.323e-03, Phi: 1.531e+01, Gamma: 1.371e-03, Psi: 1.810e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 1
# Loss: 946.2457
# Psi gradient stats:
# Mean: 3.6071e-05
# Std:  4.6957e-03
# Max:  1.6897e-02
# Min:  -1.7437e-02
# Epoch 1, Loss: 946.2457, Gradients - Lambda: 4.464e-01, Phi: 9.154e+00, Gamma: 8.813e-02, Psi: 1.744e-02
#
# Estimated total training time: 182.7 minutes
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 2
# Loss: 351.8164
# Psi gradient stats:
# Mean: 3.8363e-05
# Std:  4.6423e-03
# Max:  1.6986e-02
# Min:  -1.7147e-02
# Epoch 2, Loss: 351.8164, Gradients - Lambda: 2.582e-01, Phi: 7.035e+00, Gamma: 5.676e-02, Psi: 1.715e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 3
# Loss: 443.8999
# Psi gradient stats:
# Mean: 3.9364e-05
# Std:  4.5938e-03
# Max:  1.7302e-02
# Min:  -1.6877e-02
# Epoch 3, Loss: 443.8999, Gradients - Lambda: 2.924e-01, Phi: 5.940e+00, Gamma: 6.016e-02, Psi: 1.730e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 4
# Loss: 641.3326
# Psi gradient stats:
# Mean: 3.8724e-05
# Std:  4.5526e-03
# Max:  1.7552e-02
# Min:  -1.6627e-02
# Epoch 4, Loss: 641.3326, Gradients - Lambda: 3.191e-01, Phi: 6.154e+00, Gamma: 6.534e-02, Psi: 1.755e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch
-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 56
# Loss: 147.5029
# Psi gradient stats:
# Mean: 3.2689e-05
# Std:  4.1633e-03
# Max:  1.6746e-02
# Min:  -1.5743e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 57
# Loss: 147.3235
# Psi gradient stats:
# Mean: 3.2690e-05
# Std:  4.1567e-03
# Max:  1.6725e-02
# Min:  -1.5708e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 58
# Loss: 147.5112
# Psi gradient stats:
# Mean: 3.2730e-05
# Std:  4.1500e-03
# Max:  1.6710e-02
# Min:  -1.5670e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 59
# Loss: 147.4852
# Psi gradient stats:
# Mean: 3.2771e-05
# Std:  4.1432e-03
# Max:  1.6700e-02
# Min:  -1.5635e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 60
# Loss: 147.0638
# Psi gradient stats:
# Mean: 3.2817e-05
# Std:  4.1362e-03
# Max:  1.6690e-02
# Min:  -1.5603e-02
# Epoch 60, Loss: 147.0638, Gradients - Lambda: 1.912e-02, Phi: 5.174e-01, Gamma: 4.742e-03, Psi: 1.669e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 61
# Loss: 146.6310
# Psi gradient stats:
# Mean: 3.2820e-05
# Std:  4.1293e-03
# Max:  1.6676e-02
# Min:  -1.5577e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 62
# Loss: 146.5293
# Psi gradient stats:
# Mean: 3.2745e-05
# Std:  4.1224e-03
# Max:  1.6657e-02
# Min:  -1.5566e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 63
# Loss: 146.6098
# Psi gradient stats:
# Mean: 3.2592e-05
# Std:  4.1155e-03
# Max:  1.6637e-02
# Min:  -1.5552e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 64
# Loss: 146.5172
# Psi gradient stats:
# Mean: 3.2412e-05
# Std:  4.1087e-03
# Max:  1.6620e-02
# Min:  -1.5537e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 65
# Loss: 146.2028
# Psi gradient stats:
# Mean: 3.2270e-05
# Std:  4.1020e-03
# Max:  1.6603e-02
# Min:  -1.5523e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 66
# Loss: 145.9377
# Psi gradient stats:
# Mean: 3.2186e-05
# Std:  4.0954e-03
# Max:  1.6588e-02
# Min:  -1.5509e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 67
# Loss: 145.8840
# Psi gradient stats:
# Mean: 3.2165e-05
# Std:  4.0888e-03
# Max:  1.6571e-02
# Min:  -1.5490e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 68
# Loss: 145.8899
# Psi gradient stats:
# Mean: 3.2202e-05
# Std:  4.0822e-03
# Max:  1.6551e-02
# Min:  -1.5467e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 69
# Loss: 145.7541
# Psi gradient stats:
# Mean: 3.2197e-05
# Std:  4.0756e-03
# Max:  1.6530e-02
# Min:  -1.5442e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 70
# Loss: 145.5150
# Psi gradient stats:
# Mean: 3.2130e-05
# Std:  4.0691e-03
# Max:  1.6509e-02
# Min:  -1.5415e-02
# Epoch 70, Loss: 145.5150, Gradients - Lambda: 1.404e-02, Phi: 3.411e-01, Gamma: 3.775e-03, Psi: 1.651e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 71
# Loss: 145.3541
# Psi gradient stats:
# Mean: 3.1955e-05
# Std:  4.0626e-03
# Max:  1.6488e-02
# Min:  -1.5396e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 72
# Loss: 145.3140
# Psi gradient stats:
# Mean: 3.1731e-05
# Std:  4.0561e-03
# Max:  1.6467e-02
# Min:  -1.5376e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 73
# Loss: 145.2620
# Psi gradient stats:
# Mean: 3.1537e-05
# Std:  4.0498e-03
# Max:  1.6445e-02
# Min:  -1.5354e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch
-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 283
# Loss: 133.0516
# Psi gradient stats:
# Mean: 1.4812e-05
# Std:  3.0279e-03
# Max:  1.3735e-02
# Min:  -1.3994e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 284
# Loss: 133.0203
# Psi gradient stats:
# Mean: 1.4817e-05
# Std:  3.0241e-03
# Max:  1.3732e-02
# Min:  -1.3990e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 285
# Loss: 132.9888
# Psi gradient stats:
# Mean: 1.4740e-05
# Std:  3.0206e-03
# Max:  1.3723e-02
# Min:  -1.3984e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 286
# Loss: 132.9577
# Psi gradient stats:
# Mean: 1.4739e-05
# Std:  3.0169e-03
# Max:  1.3718e-02
# Min:  -1.3979e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 287
# Loss: 132.9262
# Psi gradient stats:
# Mean: 1.4672e-05
# Std:  3.0134e-03
# Max:  1.3711e-02
# Min:  -1.3974e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 288
# Loss: 132.8951
# Psi gradient stats:
# Mean: 1.4641e-05
# Std:  3.0098e-03
# Max:  1.3705e-02
# Min:  -1.3968e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 289
# Loss: 132.8638
# Psi gradient stats:
# Mean: 1.4593e-05
# Std:  3.0062e-03
# Max:  1.3701e-02
# Min:  -1.3963e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 290
# Loss: 132.8332
# Psi gradient stats:
# Mean: 1.4532e-05
# Std:  3.0027e-03
# Max:  1.3692e-02
# Min:  -1.3957e-02
# Epoch 290, Loss: 132.8332, Gradients - Lambda: 3.477e-02, Phi: 4.804e-01, Gamma: 3.085e-03, Psi: 1.396e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 291
# Loss: 132.8025
# Psi gradient stats:
# Mean: 1.4531e-05
# Std:  2.9990e-03
# Max:  1.3688e-02
# Min:  -1.3952e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 292
# Loss: 132.7721
# Psi gradient stats:
# Mean: 1.4437e-05
# Std:  2.9955e-03
# Max:  1.3680e-02
# Min:  -1.3949e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 293
# Loss: 132.7417
# Psi gradient stats:
# Mean: 1.4455e-05
# Std:  2.9919e-03
# Max:  1.3676e-02
# Min:  -1.3943e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 294
# Loss: 132.7109
# Psi gradient stats:
# Mean: 1.4350e-05
# Std:  2.9884e-03
# Max:  1.3668e-02
# Min:  -1.3939e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 295
# Loss: 132.6803
# Psi gradient stats:
# Mean: 1.4348e-05
# Std:  2.9849e-03
# Max:  1.3663e-02
# Min:  -1.3933e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 296
# Loss: 132.6499
# Psi gradient stats:
# Mean: 1.4281e-05
# Std:  2.9813e-03
# Max:  1.3656e-02
# Min:  -1.3928e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 297
# Loss: 132.6196
# Psi gradient stats:
# Mean: 1.4235e-05
# Std:  2.9779e-03
# Max:  1.3651e-02
# Min:  -1.3923e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 298
# Loss: 132.5894
# Psi gradient stats:
# Mean: 1.4221e-05
# Std:  2.9742e-03
# Max:  1.3644e-02
# Min:  -1.3918e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 299
# Loss: 132.5596
# Psi gradient stats:
# Mean: 1.4127e-05
# Std:  2.9708e-03
# Max:  1.3635e-02
# Min:  -1.3910e-02

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=1e-4:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Lambda changes with lr=1e-4:
# Mean absolute change: 6.584e-05
# Max absolute change: 6.874e-03
# Std of changes: 8.390e-05

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history_new['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history_new['max_grad_lambda'], label='Lambda')
ax2.plot(history_new['max_grad_phi'], label='Phi')
ax2.plot(history_new['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert gamma tensors to numpy arrays
initial_gamma_np = initial_gamma.detach().numpy()
final_gamma_np = model.gamma.detach().numpy()

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial gamma
sns.heatmap(initial_gamma_np, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Gamma')

# Plot final gamma
sns.heatmap(final_gamma_np, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Gamma')

# Add a title to the figure
plt.suptitle('Comparison of Initial vs Final Gamma Values', fontsize=16)

# You can also add a colorbar
plt.tight_layout()

# To see the actual difference, you can also create a difference heatmap
plt.figure(figsize=(10, 8))
diff = final_gamma_np - initial_gamma_np
sns.heatmap(diff, cmap='RdBu_r', center=0)
plt.title('Difference (Final - Initial Gamma)')
plt.show()

# Print some summary statistics
print(f"Mean absolute difference: {np.abs(diff).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff):.4f}")
# Out:
# Mean absolute difference: 0.0000
# Max absolute difference: 0.0002
# Standard deviation of differences: 0.0000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Convert phi tensors to numpy arrays
initial_phi_np = initial_phi.detach().numpy()  # Shape: (K, D, T)
final_phi_np = model.phi.detach().numpy()

# Take mean over time dimension
initial_phi_mean = initial_phi_np.mean(axis=2)  # Shape: (K, D)
final_phi_mean = final_phi_np.mean(axis=2)

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial phi (averaged over time)
sns.heatmap(initial_phi_mean, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Phi (Mean over Time)')
ax1.set_xlabel('Disease')
ax1.set_ylabel('Signature')

# Plot final phi (averaged over time)
sns.heatmap(final_phi_mean, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Phi (Mean over Time)')
ax2.set_xlabel('Disease')
ax2.set_ylabel('Signature')

plt.suptitle('Comparison of Initial vs Final Phi Values (Averaged over Time)', fontsize=16)
plt.tight_layout()

# Plot difference
plt.figure(figsize=(10, 8))
diff_mean = final_phi_mean - initial_phi_mean
sns.heatmap(diff_mean, cmap='RdBu_r', center=0)
plt.title('Difference in Phi (Final - Initial), Mean over Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# Print summary statistics for both full tensor and time-averaged differences
print("Full tensor statistics:")
diff_full = final_phi_np - initial_phi_np
print(f"Mean absolute difference: {np.abs(diff_full).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_full).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_full):.4f}")

print("\nTime-averaged statistics:")
print(f"Mean absolute difference: {np.abs(diff_mean).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_mean).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_mean):.4f}")

# Optionally, look at temporal variation
temporal_std = np.std(diff_full, axis=2)
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_std, cmap='viridis')
plt.title('Standard Deviation of Changes Across Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()
# Out:
# Full tensor statistics:
# Mean absolute difference: 0.0037
# Max absolute difference: 0.0872
# Standard deviation of differences: 0.0052
#
# Time-averaged statistics:
# Mean absolute difference: 0.0003
# Max absolute difference: 0.0030
# Standard deviation of differences: 0.0004

# %%
model_save_path='/Users/sarahurbut/Dropbox (Personal)/model_with_poptrajectory_lr1e-3.pt'
torch.save({
    'model_state_dict': model.state_dict(),
    'clusters': model.clusters,
    'initial_phi': initial_phi, 
    'initial_lambda': initial_lambda, 
    'psi': model.psi,
    'Y': Y_100k,
    'prevalence_t': essentials['prevalence_t'],
    'logit_prevalence_t': model.logit_prev_t,
    'G': G_100k,
    'E': E_100k,
    'indices': indices,
    'disease_names': disease_names,
    'hyperparameters': {
        'N': Y_100k.shape[0],
        'D': Y_100k.shape[1],
        'T': Y_100k.shape[2],
        'P': G_100k.shape[1],
        'K': model.phi.shape[0]
    }
}, model_save_path)

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000560
# Mean predicted risk (original): 0.000263
# Mean predicted risk (calibrated): 0.000560
# Calibration scale factor: 2.129

# %%
ss_res = np.sum((observed_risk - predicted_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.613

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Pleurisy; pleural effusion: effect=3.301 (OR=27.14), std=0.233
# Congenital anomalies of great vessels: effect=2.311 (OR=10.08), std=0.667
# Mitral valve disease: effect=1.812 (OR=6.12), std=0.147
# Other forms of chronic heart disease: effect=1.247 (OR=3.48), std=0.550
# Aortic valve disease: effect=1.223 (OR=3.40), std=0.482
# Cardiomegaly: effect=1.187 (OR=3.28), std=0.307
# Paroxysmal ventricular tachycardia: effect=1.158 (OR=3.18), std=0.712
# Left bundle branch block: effect=1.090 (OR=2.98), std=0.682
# Paroxysmal supraventricular tachycardia: effect=1.076 (OR=2.93), std=0.269
# Atrial fibrillation and flutter: effect=0.902 (OR=2.46), std=0.879
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Arthropathy NOS: effect=2.563 (OR=12.98), std=0.559
# Other peripheral nerve disorders: effect=2.421 (OR=11.26), std=0.465
# Hallux valgus (Bunion): effect=2.301 (OR=9.99), std=0.604
# Acquired toe deformities: effect=2.077 (OR=7.98), std=0.317
# Symptoms and disorders of the joints: effect=2.070 (OR=7.93), std=1.029
# Rheumatoid arthritis: effect=1.992 (OR=7.33), std=0.359
# Enthesopathy: effect=1.772 (OR=5.88), std=0.129
# Internal derangement of knee: effect=1.766 (OR=5.85), std=0.183
# Other disorders of synovium, tendon, and bursa: effect=1.327 (OR=3.77), std=0.325
# Peripheral enthesopathies and allied syndromes: effect=1.212 (OR=3.36), std=0.434
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Duodenal ulcer: effect=2.175 (OR=8.80), std=0.235
# Esophageal bleeding (varices/hemorrhage): effect=1.474 (OR=4.36), std=0.422
# Other specified gastritis: effect=1.374 (OR=3.95), std=0.053
# Stricture and stenosis of esophagus: effect=1.285 (OR=3.61), std=1.169
# Other disorders of stomach and duodenum: effect=1.215 (OR=3.37), std=0.516
# Barrett's esophagus: effect=1.137 (OR=3.12), std=0.245
# Ulcer of esophagus: effect=1.022 (OR=2.78), std=0.547
# Duodenitis: effect=1.015 (OR=2.76), std=0.561
# Esophagitis, GERD and related diseases: effect=0.968 (OR=2.63), std=0.369
# Gastric ulcer: effect=0.676 (OR=1.97), std=0.370
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Right bundle branch block: effect=2.784 (OR=16.19), std=0.469
# Other disorders of testis: effect=2.698 (OR=14.85), std=0.228
# Bipolar: effect=2.660 (OR=14.30), std=0.394
# Other benign neoplasm of connective and other soft tissue: effect=2.399 (OR=11.01), std=0.129
# Carbuncle and furuncle: effect=2.312 (OR=10.09), std=0.479
# Acute upper respiratory infections of multiple or unspecified sites: effect=2.164 (OR=8.70), std=0.880
# Arrhythmia (cardiac) NOS: effect=2.009 (OR=7.46), std=0.419
# Stricture of artery: effect=2.003 (OR=7.41), std=0.630
# Ptosis of eyelid: effect=1.857 (OR=6.41), std=0.289
# Other disorders of male genital organs: effect=1.794 (OR=6.01), std=0.385
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Other upper respiratory disease: effect=1.331 (OR=3.78), std=0.072
# Chronic sinusitis: effect=1.223 (OR=3.40), std=0.341
# Septal Deviations/Turbinate Hypertrophy: effect=1.169 (OR=3.22), std=1.242
# Nasal polyps: effect=0.890 (OR=2.43), std=0.322
# Chronic pharyngitis and nasopharyngitis: effect=0.859 (OR=2.36), std=0.555
# Other hypertrophic and atrophic conditions of skin: effect=0.421 (OR=1.52), std=0.307
# Congestive heart failure (CHF) NOS: effect=-0.165 (OR=0.85), std=0.667
# Joint effusions: effect=-0.385 (OR=0.68), std=0.383
# Acidosis: effect=-0.508 (OR=0.60), std=0.279
# Internal derangement of knee: effect=-0.563 (OR=0.57), std=0.540
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Unstable angina (intermediate coronary syndrome): effect=2.215 (OR=9.16), std=0.953
# Hypercholesterolemia: effect=1.813 (OR=6.13), std=1.135
# Myocardial infarction: effect=1.680 (OR=5.36), std=0.989
# Other acute and subacute forms of ischemic heart disease: effect=1.646 (OR=5.19), std=0.243
# Angina pectoris: effect=0.970 (OR=2.64), std=0.982
# Other forms of chronic heart disease: effect=0.790 (OR=2.20), std=0.392
# Other chronic ischemic heart disease, unspecified: effect=0.639 (OR=1.89), std=0.381
# Secondary malignancy of respiratory organs: effect=0.531 (OR=1.70), std=0.969
# Diseases of the larynx and vocal cords: effect=0.035 (OR=1.04), std=1.051
# Other hypertrophic and atrophic conditions of skin: effect=-0.045 (OR=0.96), std=0.852
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Cancer of bronchus; lung: effect=2.170 (OR=8.76), std=0.785
# Secondary malignant neoplasm of liver: effect=1.654 (OR=5.23), std=0.201
# Secondary malignancy of lymph nodes: effect=1.587 (OR=4.89), std=0.311
# Secondary malignancy of bone: effect=1.030 (OR=2.80), std=0.167
# Acquired spondylolisthesis: effect=0.692 (OR=2.00), std=0.614
# Secondary malignant neoplasm of digestive systems: effect=0.508 (OR=1.66), std=0.694
# Secondary malignancy of respiratory organs: effect=0.440 (OR=1.55), std=0.322
# Hemiplegia: effect=0.254 (OR=1.29), std=0.458
# Malignant neoplasm of ovary: effect=0.207 (OR=1.23), std=0.911
# Hammer toe (acquired): effect=0.040 (OR=1.04), std=0.207
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Migraine: effect=2.803 (OR=16.50), std=0.390
# Pain in limb: effect=2.270 (OR=9.68), std=0.672
# Other disorders of soft tissues: effect=2.003 (OR=7.41), std=0.328
# Major depressive disorder: effect=1.808 (OR=6.10), std=0.685
# Myalgia and myositis unspecified: effect=1.751 (OR=5.76), std=0.425
# Rheumatism, unspecified and fibrositis: effect=1.607 (OR=4.99), std=0.926
# Osteoporosis NOS: effect=1.397 (OR=4.04), std=0.515
# Other disorders of bone and cartilage: effect=1.241 (OR=3.46), std=0.544
# Anxiety disorder: effect=1.237 (OR=3.45), std=0.444
# GERD: effect=1.219 (OR=3.38), std=0.614
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Malignant neoplasm of uterus: effect=2.401 (OR=11.04), std=0.542
# Prolapse of vaginal walls: effect=2.098 (OR=8.15), std=0.536
# Benign neoplasm of ovary: effect=1.841 (OR=6.30), std=1.001
# Postmenopausal atrophic vaginitis: effect=1.825 (OR=6.20), std=0.179
# Dyspareunia: effect=1.664 (OR=5.28), std=0.421
# Irregular menstrual cycle: effect=1.624 (OR=5.07), std=0.317
# Endometrial hyperplasia: effect=1.509 (OR=4.52), std=1.110
# Uterine/Uterovaginal prolapse: effect=1.390 (OR=4.01), std=0.314
# Excessive or frequent menstruation: effect=1.378 (OR=3.97), std=0.796
# Noninflammatory disorders of vagina: effect=1.335 (OR=3.80), std=0.265
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Neuralgia, neuritis, and radiculitis NOS: effect=2.941 (OR=18.94), std=0.684
# Acquired spondylolisthesis: effect=1.548 (OR=4.70), std=0.530
# Back pain: effect=1.248 (OR=3.48), std=0.223
# Spondylosis without myelopathy: effect=1.173 (OR=3.23), std=0.446
# Degeneration of intervertebral disc: effect=1.086 (OR=2.96), std=0.668
# Degenerative disease of the spinal cord: effect=0.808 (OR=2.24), std=0.738
# Sciatica: effect=0.693 (OR=2.00), std=0.433
# Other and unspecified disc disorder: effect=0.539 (OR=1.71), std=0.161
# Kyphoscoliosis and scoliosis: effect=0.436 (OR=1.55), std=0.043
# Raynaud's syndrome: effect=0.284 (OR=1.33), std=0.335
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Macular degeneration (senile) of retina NOS: effect=2.355 (OR=10.54), std=0.520
# Primary open angle glaucoma: effect=2.354 (OR=10.53), std=0.410
# Retinal detachment with retinal defect: effect=2.148 (OR=8.56), std=0.232
# Retinal detachments and defects: effect=2.134 (OR=8.45), std=0.799
# Retinal vascular changes and abnomalities: effect=1.955 (OR=7.06), std=0.590
# Other retinal disorders: effect=1.880 (OR=6.55), std=0.296
# Myopia: effect=1.101 (OR=3.01), std=0.463
# Cataract: effect=1.065 (OR=2.90), std=0.364
# Glaucoma: effect=0.708 (OR=2.03), std=0.407
# Other disorders of intestine: effect=0.224 (OR=1.25), std=0.408
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Hemiplegia: effect=3.790 (OR=44.26), std=0.813
# Late effects of cerebrovascular disease: effect=1.868 (OR=6.48), std=0.278
# Cerebrovascular disease: effect=1.738 (OR=5.68), std=0.938
# Occlusion of cerebral arteries: effect=1.627 (OR=5.09), std=0.555
# Cerebral ischemia: effect=1.586 (OR=4.88), std=0.383
# Cerebral artery occlusion, with cerebral infarction: effect=1.243 (OR=3.47), std=0.471
# Transient cerebral ischemia: effect=0.977 (OR=2.66), std=0.537
# Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: effect=0.691 (OR=1.99), std=0.458
# Occlusion and stenosis of precerebral arteries: effect=0.624 (OR=1.87), std=0.718
# Pulmonary heart disease: effect=0.167 (OR=1.18), std=0.222
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Renal colic: effect=1.795 (OR=6.02), std=0.479
# Other disorders of the kidney and ureters: effect=1.499 (OR=4.48), std=1.082
# Pyelonephritis: effect=0.543 (OR=1.72), std=1.116
# Hydronephrosis: effect=0.143 (OR=1.15), std=0.826
# Viral Enteritis: effect=0.064 (OR=1.07), std=0.190
# Calculus of ureter: effect=0.052 (OR=1.05), std=0.569
# Retinal detachment with retinal defect: effect=-0.070 (OR=0.93), std=0.796
# Stricture/obstruction of ureter: effect=-0.080 (OR=0.92), std=0.919
# Calculus of kidney: effect=-0.165 (OR=0.85), std=0.330
# Tobacco use disorder: effect=-0.363 (OR=0.70), std=0.736
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Urethral stricture (not specified as infectious): effect=2.267 (OR=9.65), std=0.612
# Bladder neck obstruction: effect=1.523 (OR=4.58), std=0.635
# Other symptoms/disorders or the urinary system: effect=1.330 (OR=3.78), std=0.431
# Hyperplasia of prostate: effect=1.262 (OR=3.53), std=0.385
# Functional disorders of bladder: effect=1.223 (OR=3.40), std=0.200
# Cystitis: effect=0.735 (OR=2.08), std=0.342
# Other disorders of bladder: effect=0.657 (OR=1.93), std=0.126
# Urinary incontinence: effect=0.475 (OR=1.61), std=0.431
# Malignant neoplasm of bladder: effect=0.356 (OR=1.43), std=0.901
# Chronic prostatitis: effect=0.328 (OR=1.39), std=0.652
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Empyema and pneumothorax: effect=2.369 (OR=10.69), std=0.512
# Bronchiectasis: effect=2.217 (OR=9.18), std=0.612
# Pneumococcal pneumonia: effect=1.649 (OR=5.20), std=0.698
# Respiratory failure: effect=1.482 (OR=4.40), std=0.884
# Chronic airway obstruction: effect=1.284 (OR=3.61), std=0.337
# Pneumonia: effect=0.903 (OR=2.47), std=1.005
# Emphysema: effect=0.765 (OR=2.15), std=0.764
# Diabetic retinopathy: effect=0.629 (OR=1.87), std=0.453
# Postinflammatory pulmonary fibrosis: effect=0.567 (OR=1.76), std=0.248
# Tobacco use disorder: effect=0.406 (OR=1.50), std=0.785
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Type 2 diabetes: effect=1.640 (OR=5.15), std=0.435
# Type 2 diabetes with ophthalmic manifestations: effect=1.584 (OR=4.88), std=0.736
# Hypoglycemia: effect=1.253 (OR=3.50), std=0.847
# Diabetic retinopathy: effect=0.801 (OR=2.23), std=0.172
# Type 1 diabetes: effect=0.734 (OR=2.08), std=0.656
# Inguinal hernia: effect=0.363 (OR=1.44), std=0.769
# Other acute and subacute forms of ischemic heart disease: effect=0.266 (OR=1.30), std=0.258
# Other symptoms/disorders or the urinary system: effect=0.098 (OR=1.10), std=0.571
# Diseases and other conditions of the tongue: effect=-0.197 (OR=0.82), std=0.163
# Inflammation of eyelids: effect=-0.202 (OR=0.82), std=0.823
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Other anemias: effect=2.459 (OR=11.69), std=0.648
# Peritonitis and retroperitoneal infections: effect=2.358 (OR=10.57), std=0.537
# Other local infections of skin and subcutaneous tissue: effect=2.200 (OR=9.03), std=0.349
# Pulmonary collapse; interstitial and compensatory emphysema: effect=1.668 (OR=5.30), std=0.379
# Cellulitis and abscess of arm/hand: effect=1.636 (OR=5.13), std=0.593
# Thrombocytopenia: effect=1.543 (OR=4.68), std=0.939
# Other diseases of respiratory system, NEC: effect=1.522 (OR=4.58), std=0.124
# Hypotension NOS: effect=1.470 (OR=4.35), std=0.381
# Bacterial infection NOS: effect=1.349 (OR=3.85), std=0.634
# Sepsis: effect=1.273 (OR=3.57), std=0.549
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Diverticulosis: effect=2.646 (OR=14.10), std=1.010
# Noninfectious gastroenteritis: effect=1.685 (OR=5.39), std=0.632
# Hemorrhoids: effect=1.647 (OR=5.19), std=0.424
# Hemorrhage of rectum and anus: effect=1.448 (OR=4.25), std=0.433
# Gastrointestinal complications: effect=1.436 (OR=4.21), std=1.418
# Anal and rectal polyp: effect=1.387 (OR=4.00), std=0.664
# Benign neoplasm of colon: effect=1.338 (OR=3.81), std=1.485
# Ulcerative colitis: effect=1.298 (OR=3.66), std=0.755
# Anal and rectal conditions: effect=1.285 (OR=3.62), std=0.153
# Malignant neoplasm of rectum, rectosigmoid junction, and anus: effect=1.192 (OR=3.29), std=1.021
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Peritoneal adhesions (postoperative) (postinfection): effect=2.602 (OR=13.49), std=1.168
# Cholelithiasis: effect=1.484 (OR=4.41), std=0.593
# Calculus of bile duct: effect=1.251 (OR=3.49), std=0.291
# Other disorders of gallbladder: effect=0.937 (OR=2.55), std=0.191
# Cholelithiasis with acute cholecystitis: effect=0.903 (OR=2.47), std=0.777
# Acute pancreatitis: effect=0.857 (OR=2.36), std=0.517
# Cholecystitis without cholelithiasis: effect=0.621 (OR=1.86), std=0.509
# Primary/intrinsic cardiomyopathies: effect=0.241 (OR=1.27), std=0.939
# Hypertrophy of breast (Gynecomastia): effect=0.148 (OR=1.16), std=0.905
# Cholelithiasis with other cholecystitis: effect=0.066 (OR=1.07), std=0.390
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Renal failure NOS: effect=2.528 (OR=12.53), std=0.355
# Secondary hypothyroidism: effect=2.462 (OR=11.73), std=0.468
# Viral warts & HPV: effect=2.412 (OR=11.16), std=0.433
# Other hypertrophic and atrophic conditions of skin: effect=1.896 (OR=6.66), std=0.520
# Seborrheic keratosis: effect=1.748 (OR=5.74), std=0.635
# Hypertensive chronic kidney disease: effect=1.730 (OR=5.64), std=0.133
# Other non-epithelial cancer of skin: effect=1.603 (OR=4.97), std=0.326
# Chronic renal failure [CKD]: effect=1.525 (OR=4.59), std=0.264
# Breast cancer [female]: effect=1.483 (OR=4.40), std=0.157
# Malignant neoplasm of female breast: effect=1.482 (OR=4.40), std=0.113

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Congenital anomalies of great vessels: 1.319
# 2. Left bundle branch block: 1.290
# 3. Mitral valve disease: 1.220
# 4. Pleurisy; pleural effusion: 1.169
# 5. Paroxysmal supraventricular tachycardia: 1.109
# 6. Atrial fibrillation and flutter: 1.057
# 7. Cardiomegaly: 1.037
# 8. Other forms of chronic heart disease: 1.019
# 9. Aortic valve disease: 0.992
# 10. Paroxysmal ventricular tachycardia: 0.925
#
# Final top diseases:
# 1. Pleurisy; pleural effusion: 3.301
# 2. Congenital anomalies of great vessels: 2.311
# 3. Mitral valve disease: 1.812
# 4. Other forms of chronic heart disease: 1.247
# 5. Aortic valve disease: 1.223
# 6. Cardiomegaly: 1.187
# 7. Paroxysmal ventricular tachycardia: 1.158
# 8. Left bundle branch block: 1.090
# 9. Paroxysmal supraventricular tachycardia: 1.076
# 10. Atrial fibrillation and flutter: 0.902
#
# Pleurisy; pleural effusion changed from rank 4 to 1
#
# Aortic valve disease changed from rank 9 to 5
#
# Other forms of chronic heart disease changed from rank 8 to 4
#
# Left bundle branch block changed from rank 2 to 8
#
# Paroxysmal supraventricular tachycardia changed from rank 5 to 9
#
# Paroxysmal ventricular tachycardia changed from rank 10 to 7
#
# Atrial fibrillation and flutter changed from rank 6 to 10
#
# Signature 1:
#
# Initial top diseases:
# 1. Hallux valgus (Bunion): 1.422
# 2. Enthesopathy: 1.401
# 3. Rheumatoid arthritis: 1.361
# 4. Acquired toe deformities: 1.352
# 5. Other peripheral nerve disorders: 1.286
# 6. Arthropathy NOS: 1.217
# 7. Internal derangement of knee: 1.204
# 8. Other disorders of synovium, tendon, and bursa: 1.187
# 9. Symptoms and disorders of the joints: 1.051
# 10. Pain in joint: 1.028
#
# Final top diseases:
# 1. Arthropathy NOS: 2.563
# 2. Other peripheral nerve disorders: 2.421
# 3. Hallux valgus (Bunion): 2.301
# 4. Acquired toe deformities: 2.077
# 5. Symptoms and disorders of the joints: 2.070
# 6. Rheumatoid arthritis: 1.992
# 7. Enthesopathy: 1.772
# 8. Internal derangement of knee: 1.766
# 9. Other disorders of synovium, tendon, and bursa: 1.327
# 10. Peripheral enthesopathies and allied syndromes: 1.212
#
# Symptoms and disorders of the joints changed from rank 9 to 5
#
# Other peripheral nerve disorders changed from rank 5 to 2
#
# Rheumatoid arthritis changed from rank 3 to 6
#
# Arthropathy NOS changed from rank 6 to 1
#
# Enthesopathy changed from rank 2 to 7
#
# Signature 2:
#
# Initial top diseases:
# 1. Other disorders of stomach and duodenum: 1.283
# 2. Other specified gastritis: 1.212
# 3. Duodenal ulcer: 1.192
# 4. Stricture and stenosis of esophagus: 1.192
# 5. Barrett's esophagus: 1.182
# 6. Gastric ulcer: 0.966
# 7. Gastritis and duodenitis: 0.948
# 8. Duodenitis: 0.916
# 9. Esophageal bleeding (varices/hemorrhage): 0.822
# 10. Reflux esophagitis: 0.748
#
# Final top diseases:
# 1. Duodenal ulcer: 2.175
# 2. Esophageal bleeding (varices/hemorrhage): 1.474
# 3. Other specified gastritis: 1.374
# 4. Stricture and stenosis of esophagus: 1.285
# 5. Other disorders of stomach and duodenum: 1.215
# 6. Barrett's esophagus: 1.137
# 7. Ulcer of esophagus: 1.022
# 8. Duodenitis: 1.015
# 9. Esophagitis, GERD and related diseases: 0.968
# 10. Gastric ulcer: 0.676
#
# Other disorders of stomach and duodenum changed from rank 1 to 5
#
# Esophagitis, GERD and related diseases changed from rank 12 to 9
#
# Ulcer of esophagus changed from rank 12 to 7
#
# Esophageal bleeding (varices/hemorrhage) changed from rank 9 to 2
#
# Gastric ulcer changed from rank 6 to 10
#
# Gastritis and duodenitis changed from rank 7 to 12
#
# Signature 3:
#
# Initial top diseases:
# 1. Celiac disease: 1.462
# 2. Acute upper respiratory infections of multiple or unspecified sites: 1.372
# 3. Diseases of the larynx and vocal cords: 1.365
# 4. Redundant prepuce and phimosis/BXO: 1.343
# 5. Other disorders of testis: 1.337
# 6. Right bundle branch block: 1.335
# 7. Malunion and nonunion of fracture: 1.326
# 8. Stricture of artery: 1.293
# 9. Carbuncle and furuncle: 1.277
# 10. Arrhythmia (cardiac) NOS: 1.270
#
# Final top diseases:
# 1. Right bundle branch block: 2.784
# 2. Other disorders of testis: 2.698
# 3. Bipolar: 2.660
# 4. Other benign neoplasm of connective and other soft tissue: 2.399
# 5. Carbuncle and furuncle: 2.312
# 6. Acute upper respiratory infections of multiple or unspecified sites: 2.164
# 7. Arrhythmia (cardiac) NOS: 2.009
# 8. Stricture of artery: 2.003
# 9. Ptosis of eyelid: 1.857
# 10. Other disorders of male genital organs: 1.794
#
# Arrhythmia (cardiac) NOS changed from rank 10 to 7
#
# Bipolar changed from rank 12 to 3
#
# Celiac disease changed from rank 1 to 12
#
# Acute upper respiratory infections of multiple or unspecified sites changed from rank 2 to 6
#
# Diseases of the larynx and vocal cords changed from rank 3 to 12
#
# Carbuncle and furuncle changed from rank 9 to 5
#
# Ptosis of eyelid changed from rank 12 to 9
#
# Other benign neoplasm of connective and other soft tissue changed from rank 12 to 4
#
# Right bundle branch block changed from rank 6 to 1
#
# Other disorders of testis changed from rank 5 to 2
#
# Malunion and nonunion of fracture changed from rank 7 to 12
#
# Redundant prepuce and phimosis/BXO changed from rank 4 to 12
#
# Signature 4:
#
# Initial top diseases:
# 1. Other upper respiratory disease: 1.200
# 2. Chronic sinusitis: 0.830
# 3. Chronic pharyngitis and nasopharyngitis: 0.806
# 4. Nasal polyps: 0.776
# 5. Septal Deviations/Turbinate Hypertrophy: 0.686
# 6. Other local infections of skin and subcutaneous tissue: -1.654
# 7. Anal and rectal conditions: -1.675
# 8. Chronic glomerulonephritis, NOS: -1.684
# 9. Congestive heart failure (CHF) NOS: -1.689
# 10. Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: -1.689
#
# Final top diseases:
# 1. Other upper respiratory disease: 1.331
# 2. Chronic sinusitis: 1.223
# 3. Septal Deviations/Turbinate Hypertrophy: 1.169
# 4. Nasal polyps: 0.890
# 5. Chronic pharyngitis and nasopharyngitis: 0.859
# 6. Other hypertrophic and atrophic conditions of skin: 0.421
# 7. Congestive heart failure (CHF) NOS: -0.165
# 8. Joint effusions: -0.385
# 9. Acidosis: -0.508
# 10. Internal derangement of knee: -0.563
#
# Joint effusions changed from rank 12 to 8
#
# Anal and rectal conditions changed from rank 7 to 12
#
# Other local infections of skin and subcutaneous tissue changed from rank 6 to 12
#
# Other hypertrophic and atrophic conditions of skin changed from rank 12 to 6
#
# Chronic glomerulonephritis, NOS changed from rank 8 to 12
#
# Acidosis changed from rank 12 to 9
#
# Signature 5:
#
# Initial top diseases:
# 1. Hypercholesterolemia: 1.373
# 2. Other acute and subacute forms of ischemic heart disease: 1.199
# 3. Unstable angina (intermediate coronary syndrome): 1.109
# 4. Myocardial infarction: 1.081
# 5. Other chronic ischemic heart disease, unspecified: 0.980
# 6. Coronary atherosclerosis: 0.901
# 7. Angina pectoris: 0.855
# 8. Viral Enteritis: -1.664
# 9. Sleep disorders: -1.676
# 10. Celiac disease: -1.686
#
# Final top diseases:
# 1. Unstable angina (intermediate coronary syndrome): 2.215
# 2. Hypercholesterolemia: 1.813
# 3. Myocardial infarction: 1.680
# 4. Other acute and subacute forms of ischemic heart disease: 1.646
# 5. Angina pectoris: 0.970
# 6. Other forms of chronic heart disease: 0.790
# 7. Other chronic ischemic heart disease, unspecified: 0.639
# 8. Secondary malignancy of respiratory organs: 0.531
# 9. Diseases of the larynx and vocal cords: 0.035
# 10. Other hypertrophic and atrophic conditions of skin: -0.045
#
# Viral Enteritis changed from rank 8 to 12
#
# Sleep disorders changed from rank 9 to 12
#
# Diseases of the larynx and vocal cords changed from rank 12 to 9
#
# Secondary malignancy of respiratory organs changed from rank 12 to 8
#
# Coronary atherosclerosis changed from rank 6 to 12
#
# Other forms of chronic heart disease changed from rank 12 to 6
#
# Signature 6:
#
# Initial top diseases:
# 1. Secondary malignancy of bone: 1.315
# 2. Secondary malignancy of lymph nodes: 1.284
# 3. Secondary malignant neoplasm of liver: 1.258
# 4. Cancer of bronchus; lung: 1.234
# 5. Secondary malignant neoplasm of digestive systems: 0.806
# 6. Malignant neoplasm, other: 0.737
# 7. Secondary malignant neoplasm: 0.685
# 8. Secondary malignancy of respiratory organs: 0.656
# 9. Paroxysmal ventricular tachycardia: -1.676
# 10. Excessive or frequent menstruation: -1.682
#
# Final top diseases:
# 1. Cancer of bronchus; lung: 2.170
# 2. Secondary malignant neoplasm of liver: 1.654
# 3. Secondary malignancy of lymph nodes: 1.587
# 4. Secondary malignancy of bone: 1.030
# 5. Acquired spondylolisthesis: 0.692
# 6. Secondary malignant neoplasm of digestive systems: 0.508
# 7. Secondary malignancy of respiratory organs: 0.440
# 8. Hemiplegia: 0.254
# 9. Malignant neoplasm of ovary: 0.207
# 10. Hammer toe (acquired): 0.040
#
# Acquired spondylolisthesis changed from rank 12 to 5
#
# Cancer of bronchus; lung changed from rank 4 to 1
#
# Hemiplegia changed from rank 12 to 8
#
# Malignant neoplasm of ovary changed from rank 12 to 9
#
# Malignant neoplasm, other changed from rank 6 to 12
#
# Secondary malignant neoplasm changed from rank 7 to 12
#
# Secondary malignancy of bone changed from rank 1 to 4
#
# Paroxysmal ventricular tachycardia changed from rank 9 to 12
#
# Signature 7:
#
# Initial top diseases:
# 1. Migraine: 1.542
# 2. Major depressive disorder: 1.423
# 3. Myalgia and myositis unspecified: 1.358
# 4. Abdominal pain: 1.316
# 5. Other disorders of soft tissues: 1.271
# 6. Pain in limb: 1.263
# 7. GERD: 1.261
# 8. Rheumatism, unspecified and fibrositis: 1.216
# 9. Osteoporosis NOS: 1.216
# 10. Asthma: 1.119
#
# Final top diseases:
# 1. Migraine: 2.803
# 2. Pain in limb: 2.270
# 3. Other disorders of soft tissues: 2.003
# 4. Major depressive disorder: 1.808
# 5. Myalgia and myositis unspecified: 1.751
# 6. Rheumatism, unspecified and fibrositis: 1.607
# 7. Osteoporosis NOS: 1.397
# 8. Other disorders of bone and cartilage: 1.241
# 9. Anxiety disorder: 1.237
# 10. GERD: 1.219
#
# Anxiety disorder changed from rank 12 to 9
#
# Pain in limb changed from rank 6 to 2
#
# Abdominal pain changed from rank 4 to 12
#
# GERD changed from rank 7 to 10
#
# Other disorders of bone and cartilage changed from rank 12 to 8
#
# Signature 8:
#
# Initial top diseases:
# 1. Malignant neoplasm of uterus: 1.413
# 2. Noninflammatory disorders of cervix: 1.356
# 3. Ovarian cyst: 1.324
# 4. Prolapse of vaginal walls: 1.284
# 5. Noninflammatory disorders of vagina: 1.273
# 6. Excessive or frequent menstruation: 1.249
# 7. Endometrial hyperplasia: 1.227
# 8. Postmenopausal atrophic vaginitis: 1.221
# 9. Dyspareunia: 1.214
# 10. Mucous polyp of cervix: 1.194
#
# Final top diseases:
# 1. Malignant neoplasm of uterus: 2.401
# 2. Prolapse of vaginal walls: 2.098
# 3. Benign neoplasm of ovary: 1.841
# 4. Postmenopausal atrophic vaginitis: 1.825
# 5. Dyspareunia: 1.664
# 6. Irregular menstrual cycle: 1.624
# 7. Endometrial hyperplasia: 1.509
# 8. Uterine/Uterovaginal prolapse: 1.390
# 9. Excessive or frequent menstruation: 1.378
# 10. Noninflammatory disorders of vagina: 1.335
#
# Uterine/Uterovaginal prolapse changed from rank 12 to 8
#
# Noninflammatory disorders of cervix changed from rank 2 to 12
#
# Noninflammatory disorders of vagina changed from rank 5 to 10
#
# Dyspareunia changed from rank 9 to 5
#
# Excessive or frequent menstruation changed from rank 6 to 9
#
# Irregular menstrual cycle changed from rank 12 to 6
#
# Postmenopausal atrophic vaginitis changed from rank 8 to 4
#
# Ovarian cyst changed from rank 3 to 12
#
# Benign neoplasm of ovary changed from rank 12 to 3
#
# Signature 9:
#
# Initial top diseases:
# 1. Back pain: 1.415
# 2. Neuralgia, neuritis, and radiculitis NOS: 1.333
# 3. Acquired spondylolisthesis: 1.189
# 4. Degeneration of intervertebral disc: 1.122
# 5. Sciatica: 1.043
# 6. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 0.802
# 7. Spondylosis without myelopathy: 0.799
# 8. Degenerative disease of the spinal cord: 0.770
# 9. Displacement of intervertebral disc: 0.737
# 10. Other and unspecified disc disorder: 0.724
#
# Final top diseases:
# 1. Neuralgia, neuritis, and radiculitis NOS: 2.941
# 2. Acquired spondylolisthesis: 1.548
# 3. Back pain: 1.248
# 4. Spondylosis without myelopathy: 1.173
# 5. Degeneration of intervertebral disc: 1.086
# 6. Degenerative disease of the spinal cord: 0.808
# 7. Sciatica: 0.693
# 8. Other and unspecified disc disorder: 0.539
# 9. Kyphoscoliosis and scoliosis: 0.436
# 10. Raynaud's syndrome: 0.284
#
# Kyphoscoliosis and scoliosis changed from rank 12 to 9
#
# Thoracic or lumbosacral neuritis or radiculitis, unspecified changed from rank 6 to 12
#
# Spondylosis without myelopathy changed from rank 7 to 4
#
# Displacement of intervertebral disc changed from rank 9 to 12
#
# Signature 10:
#
# Initial top diseases:
# 1. Macular degeneration (senile) of retina NOS: 1.450
# 2. Other retinal disorders: 1.414
# 3. Retinal vascular changes and abnomalities: 1.337
# 4. Primary open angle glaucoma: 1.336
# 5. Retinal detachments and defects: 1.134
# 6. Cataract: 1.100
# 7. Retinal detachment with retinal defect: 1.091
# 8. Glaucoma: 0.779
# 9. Myopia: 0.753
# 10. Disorders of vitreous body: 0.713
#
# Final top diseases:
# 1. Macular degeneration (senile) of retina NOS: 2.355
# 2. Primary open angle glaucoma: 2.354
# 3. Retinal detachment with retinal defect: 2.148
# 4. Retinal detachments and defects: 2.134
# 5. Retinal vascular changes and abnomalities: 1.955
# 6. Other retinal disorders: 1.880
# 7. Myopia: 1.101
# 8. Cataract: 1.065
# 9. Glaucoma: 0.708
# 10. Other disorders of intestine: 0.224
#
# Retinal detachment with retinal defect changed from rank 7 to 3
#
# Other retinal disorders changed from rank 2 to 6
#
# Signature 11:
#
# Initial top diseases:
# 1. Hemiplegia: 1.397
# 2. Occlusion of cerebral arteries: 1.306
# 3. Late effects of cerebrovascular disease: 1.292
# 4. Cerebrovascular disease: 1.249
# 5. Cerebral artery occlusion, with cerebral infarction: 1.201
# 6. Transient cerebral ischemia: 1.073
# 7. Cerebral ischemia: 0.862
# 8. Occlusion and stenosis of precerebral arteries: 0.538
# 9. Degenerative disease of the spinal cord: -1.680
# 10. Iron deficiency anemias, unspecified or not due to blood loss: -1.682
#
# Final top diseases:
# 1. Hemiplegia: 3.790
# 2. Late effects of cerebrovascular disease: 1.868
# 3. Cerebrovascular disease: 1.738
# 4. Occlusion of cerebral arteries: 1.627
# 5. Cerebral ischemia: 1.586
# 6. Cerebral artery occlusion, with cerebral infarction: 1.243
# 7. Transient cerebral ischemia: 0.977
# 8. Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue: 0.691
# 9. Occlusion and stenosis of precerebral arteries: 0.624
# 10. Pulmonary heart disease: 0.167
#
# Degenerative disease of the spinal cord changed from rank 9 to 12
#
# Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue changed from rank 12 to 8
#
# Signature 12:
#
# Initial top diseases:
# 1. Renal colic: 1.436
# 2. Other disorders of the kidney and ureters: 1.249
# 3. Calculus of ureter: 0.855
# 4. Stricture/obstruction of ureter: 0.787
# 5. Hydronephrosis: 0.753
# 6. Pyelonephritis: 0.667
# 7. Calculus of kidney: 0.576
# 8. Pain in limb: -1.623
# 9. Bronchiectasis: -1.638
# 10. Streptococcus infection: -1.659
#
# Final top diseases:
# 1. Renal colic: 1.795
# 2. Other disorders of the kidney and ureters: 1.499
# 3. Pyelonephritis: 0.543
# 4. Hydronephrosis: 0.143
# 5. Viral Enteritis: 0.064
# 6. Calculus of ureter: 0.052
# 7. Retinal detachment with retinal defect: -0.070
# 8. Stricture/obstruction of ureter: -0.080
# 9. Calculus of kidney: -0.165
# 10. Tobacco use disorder: -0.363
#
# Viral Enteritis changed from rank 12 to 5
#
# Retinal detachment with retinal defect changed from rank 12 to 7
#
# Pain in limb changed from rank 8 to 12
#
# Bronchiectasis changed from rank 9 to 12
#
# Stricture/obstruction of ureter changed from rank 4 to 8
#
# Pyelonephritis changed from rank 6 to 3
#
# Calculus of ureter changed from rank 3 to 6
#
# Signature 13:
#
# Initial top diseases:
# 1. Urethral stricture (not specified as infectious): 1.393
# 2. Functional disorders of bladder: 1.257
# 3. Other symptoms/disorders or the urinary system: 1.050
# 4. Hyperplasia of prostate: 0.976
# 5. Bladder neck obstruction: 0.938
# 6. Cystitis: 0.893
# 7. Malignant neoplasm of bladder: 0.853
# 8. Cancer of prostate: 0.820
# 9. Other disorders of bladder: 0.790
# 10. Urinary incontinence: 0.722
#
# Final top diseases:
# 1. Urethral stricture (not specified as infectious): 2.267
# 2. Bladder neck obstruction: 1.523
# 3. Other symptoms/disorders or the urinary system: 1.330
# 4. Hyperplasia of prostate: 1.262
# 5. Functional disorders of bladder: 1.223
# 6. Cystitis: 0.735
# 7. Other disorders of bladder: 0.657
# 8. Urinary incontinence: 0.475
# 9. Malignant neoplasm of bladder: 0.356
# 10. Chronic prostatitis: 0.328
#
# Cancer of prostate changed from rank 8 to 12
#
# Bladder neck obstruction changed from rank 5 to 2
#
# Functional disorders of bladder changed from rank 2 to 5
#
# Signature 14:
#
# Initial top diseases:
# 1. Bronchiectasis: 1.329
# 2. Empyema and pneumothorax: 1.297
# 3. Pneumococcal pneumonia: 1.185
# 4. Postinflammatory pulmonary fibrosis: 1.060
# 5. Emphysema: 0.870
# 6. Pneumonia: 0.841
# 7. Tobacco use disorder: 0.805
# 8. Chronic airway obstruction: 0.800
# 9. Respiratory failure: 0.622
# 10. Obstructive chronic bronchitis: 0.529
#
# Final top diseases:
# 1. Empyema and pneumothorax: 2.369
# 2. Bronchiectasis: 2.217
# 3. Pneumococcal pneumonia: 1.649
# 4. Respiratory failure: 1.482
# 5. Chronic airway obstruction: 1.284
# 6. Pneumonia: 0.903
# 7. Emphysema: 0.765
# 8. Diabetic retinopathy: 0.629
# 9. Postinflammatory pulmonary fibrosis: 0.567
# 10. Tobacco use disorder: 0.406
#
# Tobacco use disorder changed from rank 7 to 10
#
# Chronic airway obstruction changed from rank 8 to 5
#
# Postinflammatory pulmonary fibrosis changed from rank 4 to 9
#
# Respiratory failure changed from rank 9 to 4
#
# Diabetic retinopathy changed from rank 12 to 8
#
# Signature 15:
#
# Initial top diseases:
# 1. Hypoglycemia: 1.407
# 2. Type 2 diabetes: 1.221
# 3. Type 2 diabetes with ophthalmic manifestations: 1.088
# 4. Diabetic retinopathy: 1.049
# 5. Type 1 diabetes: 0.840
# 6. Dental caries: -1.616
# 7. Hydronephrosis: -1.621
# 8. Neuralgia, neuritis, and radiculitis NOS: -1.671
# 9. Esophageal bleeding (varices/hemorrhage): -1.672
# 10. Bipolar: -1.681
#
# Final top diseases:
# 1. Type 2 diabetes: 1.640
# 2. Type 2 diabetes with ophthalmic manifestations: 1.584
# 3. Hypoglycemia: 1.253
# 4. Diabetic retinopathy: 0.801
# 5. Type 1 diabetes: 0.734
# 6. Inguinal hernia: 0.363
# 7. Other acute and subacute forms of ischemic heart disease: 0.266
# 8. Other symptoms/disorders or the urinary system: 0.098
# 9. Diseases and other conditions of the tongue: -0.197
# 10. Inflammation of eyelids: -0.202
#
# Inguinal hernia changed from rank 12 to 6
#
# Neuralgia, neuritis, and radiculitis NOS changed from rank 8 to 12
#
# Dental caries changed from rank 6 to 12
#
# Hydronephrosis changed from rank 7 to 12
#
# Diseases and other conditions of the tongue changed from rank 12 to 9
#
# Other acute and subacute forms of ischemic heart disease changed from rank 12 to 7
#
# Other symptoms/disorders or the urinary system changed from rank 12 to 8
#
# Esophageal bleeding (varices/hemorrhage) changed from rank 9 to 12
#
# Signature 16:
#
# Initial top diseases:
# 1. Peritonitis and retroperitoneal infections: 1.387
# 2. Other diseases of respiratory system, NEC: 1.341
# 3. Other anemias: 1.261
# 4. Gram negative septicemia: 1.231
# 5. Chronic ulcer of skin: 1.221
# 6. Sepsis: 1.220
# 7. Other local infections of skin and subcutaneous tissue: 1.214
# 8. Thrombocytopenia: 1.209
# 9. Bacterial infection NOS: 1.206
# 10. Acute renal failure: 1.172
#
# Final top diseases:
# 1. Other anemias: 2.459
# 2. Peritonitis and retroperitoneal infections: 2.358
# 3. Other local infections of skin and subcutaneous tissue: 2.200
# 4. Pulmonary collapse; interstitial and compensatory emphysema: 1.668
# 5. Cellulitis and abscess of arm/hand: 1.636
# 6. Thrombocytopenia: 1.543
# 7. Other diseases of respiratory system, NEC: 1.522
# 8. Hypotension NOS: 1.470
# 9. Bacterial infection NOS: 1.349
# 10. Sepsis: 1.273
#
# Gram negative septicemia changed from rank 4 to 12
#
# Hypotension NOS changed from rank 12 to 8
#
# Sepsis changed from rank 6 to 10
#
# Cellulitis and abscess of arm/hand changed from rank 12 to 5
#
# Other local infections of skin and subcutaneous tissue changed from rank 7 to 3
#
# Chronic ulcer of skin changed from rank 5 to 12
#
# Pulmonary collapse; interstitial and compensatory emphysema changed from rank 12 to 4
#
# Other diseases of respiratory system, NEC changed from rank 2 to 7
#
# Signature 17:
#
# Initial top diseases:
# 1. Diverticulosis: 1.342
# 2. Hemorrhoids: 1.324
# 3. Colon cancer: 1.209
# 4. Hemorrhage of rectum and anus: 1.190
# 5. Anal and rectal conditions: 1.189
# 6. Gastrointestinal complications: 1.158
# 7. Anal and rectal polyp: 1.151
# 8. Noninfectious gastroenteritis: 1.051
# 9. Ventral hernia: 0.958
# 10. Benign neoplasm of colon: 0.956
#
# Final top diseases:
# 1. Diverticulosis: 2.646
# 2. Noninfectious gastroenteritis: 1.685
# 3. Hemorrhoids: 1.647
# 4. Hemorrhage of rectum and anus: 1.448
# 5. Gastrointestinal complications: 1.436
# 6. Anal and rectal polyp: 1.387
# 7. Benign neoplasm of colon: 1.338
# 8. Ulcerative colitis: 1.298
# 9. Anal and rectal conditions: 1.285
# 10. Malignant neoplasm of rectum, rectosigmoid junction, and anus: 1.192
#
# Ventral hernia changed from rank 9 to 12
#
# Ulcerative colitis changed from rank 12 to 8
#
# Noninfectious gastroenteritis changed from rank 8 to 2
#
# Colon cancer changed from rank 3 to 12
#
# Anal and rectal conditions changed from rank 5 to 9
#
# Benign neoplasm of colon changed from rank 10 to 7
#
# Signature 18:
#
# Initial top diseases:
# 1. Peritoneal adhesions (postoperative) (postinfection): 1.334
# 2. Other disorders of gallbladder: 1.211
# 3. Cholelithiasis with acute cholecystitis: 1.176
# 4. Cholelithiasis: 0.878
# 5. Acute pancreatitis: 0.814
# 6. Calculus of bile duct: 0.740
# 7. Other disorders of biliary tract: 0.715
# 8. Cholecystitis without cholelithiasis: 0.676
# 9. Cholelithiasis with other cholecystitis: 0.658
# 10. Esophageal bleeding (varices/hemorrhage): -1.645
#
# Final top diseases:
# 1. Peritoneal adhesions (postoperative) (postinfection): 2.602
# 2. Cholelithiasis: 1.484
# 3. Calculus of bile duct: 1.251
# 4. Other disorders of gallbladder: 0.937
# 5. Cholelithiasis with acute cholecystitis: 0.903
# 6. Acute pancreatitis: 0.857
# 7. Cholecystitis without cholelithiasis: 0.621
# 8. Primary/intrinsic cardiomyopathies: 0.241
# 9. Hypertrophy of breast (Gynecomastia): 0.148
# 10. Cholelithiasis with other cholecystitis: 0.066
#
# Hypertrophy of breast (Gynecomastia) changed from rank 12 to 9
#
# Calculus of bile duct changed from rank 6 to 3
#
# Other disorders of biliary tract changed from rank 7 to 12
#
# Primary/intrinsic cardiomyopathies changed from rank 12 to 8
#
# Signature 19:
#
# Initial top diseases:
# 1. Seborrheic keratosis: 1.413
# 2. Ectropion or entropion: 1.350
# 3. Hypertensive chronic kidney disease: 1.331
# 4. Breast cancer [female]: 1.319
# 5. Viral warts & HPV: 1.313
# 6. Renal failure NOS: 1.250
# 7. Secondary hypothyroidism: 1.246
# 8. Other non-epithelial cancer of skin: 1.210
# 9. Malignant neoplasm of female breast: 1.207
# 10. Epiphora: 1.200
#
# Final top diseases:
# 1. Renal failure NOS: 2.528
# 2. Secondary hypothyroidism: 2.462
# 3. Viral warts & HPV: 2.412
# 4. Other hypertrophic and atrophic conditions of skin: 1.896
# 5. Seborrheic keratosis: 1.748
# 6. Hypertensive chronic kidney disease: 1.730
# 7. Other non-epithelial cancer of skin: 1.603
# 8. Chronic renal failure [CKD]: 1.525
# 9. Breast cancer [female]: 1.483
# 10. Malignant neoplasm of female breast: 1.482
#
# Breast cancer [female] changed from rank 4 to 9
#
# Ectropion or entropion changed from rank 2 to 12
#
# Other hypertrophic and atrophic conditions of skin changed from rank 12 to 4
#
# Seborrheic keratosis changed from rank 1 to 5
#
# Renal failure NOS changed from rank 6 to 1
#
# Chronic renal failure [CKD] changed from rank 12 to 8
#
# Secondary hypothyroidism changed from rank 7 to 2
#
# Hypertensive chronic kidney disease changed from rank 3 to 6

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
disease_names=essentials['disease_names']
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,1,14,15,16,13,17])

# %%
Y_avg_global = torch.mean(torch.tensor(Y) if isinstance(Y,np.ndarray) else Y, dim=2)
Y_avg_batch = torch.mean(torch.tensor(Y_100k) if isinstance(Y_100k, np.ndarray) else Y_100k, dim=2)

# %%
def compare_disease_patterns(k, true_psi, Y_avg_global, Y_avg_batch):
    """Compare disease patterns between global and batch data"""
    strong_diseases = (true_psi[k] > 0)
    
    # Get mean pattern for each dataset (average across patients)
    pattern_large = Y_avg_global[:, strong_diseases].mean(dim=0)  # Average across all patients
    pattern_small = Y_avg_batch[:, strong_diseases].mean(dim=0)  # Average across batch patients
    
    # Now both patterns are just length of strong_diseases
    correlation = torch.corrcoef(
        torch.stack([pattern_large, pattern_small])
    )[0,1]
    
    print(f"Signature {k} pattern correlation: {correlation:.3f}")
    print(f"Mean pattern difference: {(pattern_large - pattern_small).abs().mean():.3f}")

# Now use it
print("Comparing disease sharing patterns between global and batch data:")
for k in range(model.K):
    print(f"\nSignature {k}:")
    compare_disease_patterns(k, model.psi, Y_avg_global, Y_avg_batch)
