# %%
# %load_ext autoreload
# %autoreload 2

from cluster_g_logit_init_acceptpsi import *


# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_74318/1069408875.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_74318/1069408875.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_74318/1069408875.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_74318/1069408875.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
def subset_data(Y, E, G, n_samples=50000, seed=42):
    """
    Subset the data to n_samples individuals while maintaining consistency
    
    Args:
        Y: tensor of shape [N, D, T]
        E: tensor of shape [N, D]
        G: tensor of shape [N, P]
        n_samples: number of individuals to keep
        seed: random seed for reproducibility
    
    Returns:
        Y_sub, E_sub, G_sub: subsetted tensors
    """
    torch.manual_seed(seed)
    
    # Get total number of individuals
    N = Y.shape[0]
    
    # Randomly select n_samples indices
    indices = torch.randperm(N)[:n_samples]
    
    # Subset all matrices using the same indices
    Y_sub = Y[indices]
    E_sub = E[indices]
    G_sub = G[indices]
    
    print(f"Original shapes: Y={Y.shape}, E={E.shape}, G={G.shape}")
    print(f"New shapes: Y={Y_sub.shape}, E={E_sub.shape}, G={G_sub.shape}")
    
    return Y_sub, E_sub, G_sub, indices

# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000,seed=1)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([407878, 348, 52]), E=torch.Size([407878, 348]), G=torch.Size([407878, 36])
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=torch.Size([10000, 36])

# %%
# When initializing the model:
original_G = G_100k.clone().detach()  # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_74318/685643090.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_74318/685643090.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0],
    D=Y_100k.shape[1],
    T=Y_100k.shape[2],
    K=essentials['K'],
    P=essentials['P'],
    G=G_100k,
    Y=Y_100k,
    prevalence_t=essentials['prevalence_t']
)

# Initialize and train
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
#
# Cluster Sizes:
# Cluster 0: 11 diseases
# Cluster 1: 6 diseases
# Cluster 2: 13 diseases
# Cluster 3: 97 diseases
# Cluster 4: 22 diseases
# Cluster 5: 22 diseases
# Cluster 6: 15 diseases
# Cluster 7: 17 diseases
# Cluster 8: 35 diseases
# Cluster 9: 6 diseases
# Cluster 10: 13 diseases
# Cluster 11: 9 diseases
# Cluster 12: 11 diseases
# Cluster 13: 6 diseases
# Cluster 14: 17 diseases
# Cluster 15: 5 diseases
# Cluster 16: 15 diseases
# Cluster 17: 8 diseases
# Cluster 18: 17 diseases
# Cluster 19: 3 diseases
# Initialization complete!
#
# Using true psi from simulation
# Initialization complete!
#
# Clusters match exactly: True

# %%
model.phi[1,1,:]
# Out:
# tensor([-13.3536, -13.3847, -13.3609, -13.2947, -13.1985, -13.0819, -12.9570,
#         -12.8368, -12.7224, -12.6231, -12.5360, -12.4614, -12.3976, -12.3397,
#         -12.2819, -12.2289, -12.1717, -12.1157, -12.0542, -11.9904, -11.9242,
#         -11.8547, -11.7801, -11.7081, -11.6286, -11.5523, -11.4756, -11.3966,
#         -11.3185, -11.2424, -11.1665, -11.0922, -11.0137, -10.9377, -10.8639,
#         -10.7871, -10.7146, -10.6440, -10.5761, -10.5175, -10.4630, -10.4224,
#         -10.3956, -10.3801, -10.3754, -10.3802, -10.3969, -10.4189, -10.4377,
#         -10.4556, -10.4664, -10.4657], grad_fn=<SliceBackward0>)

# %%
# Plot both versions:
model.plot_genetic_scores(original_G)
print(model.G[:,3].mean())

print(original_G[:,3].mean())


# Check G matrix scaling
G_mean = model.G.mean(dim=0)
G_std = model.G.std(dim=0)
print("\nG matrix scaling check:")
print(f"Mean should be ~0: {G_mean.abs().max().item():.6f}")
print(f"Std should be ~1: {(G_std - 1).abs().max().item():.6f}")
# Out:
# Genetic Components Summary Statistics:
# Component  Original Mean Original Std  Trans. Mean  Trans. Std
# ------------------------------------------------------------
# 1                 -0.007        1.004       -0.000       1.000
# 2                 -0.001        1.011       -0.000       1.000
# 3                  0.018        1.005       -0.000       1.000
# 4                  0.009        0.977       -0.000       1.000
# 5                  0.000        1.005        0.000       1.000
# 6                 -0.013        1.007        0.000       1.000
# 7                  0.012        1.001       -0.000       1.000
# 8                  0.012        1.001       -0.000       1.000
# 9                  0.017        1.006        0.000       1.000
# 10                 0.010        1.001        0.000       1.000
# 11                 0.013        1.002       -0.000       1.000
# 12                 0.005        0.998        0.000       1.000
# 13                -0.001        0.998        0.000       1.000
# 14                -0.018        0.999        0.000       1.000
# 15                -0.009        1.002       -0.000       1.000
# 16                 0.001        1.013        0.000       1.000
# 17                -0.002        1.000       -0.000       1.000
# 18                -0.009        0.995        0.000       1.000
# 19                 0.026        0.997        0.000       1.000
# 20                -0.010        1.009       -0.000       1.000
# 21                 0.012        0.992       -0.000       1.000
# 22                 0.018        1.000       -0.000       1.000
# 23                 0.002        1.005       -0.000       1.000
# 24                 0.012        1.012       -0.000       1.000
# 25                -0.002        0.997        0.000       1.000
# 26                -0.011        1.001        0.000       1.000
# 27                 0.012        0.990        0.000       1.000
# 28                 0.015        0.997       -0.000       1.000
# 29                -0.005        0.994       -0.000       1.000
# 30                 0.010        1.006        0.000       1.000
# 31                 0.013        1.003        0.000       1.000
# 32                 0.006        0.996       -0.000       1.000
# 33                 0.010        1.004       -0.000       1.000
# 34                 0.029        0.998        0.000       1.000
# 35                -0.003        1.013       -0.000       1.000
# 36                 0.026        1.000        0.000       1.000
# tensor(-3.8147e-09)
# tensor(0.0093)
#
# G matrix scaling check:
# Mean should be ~0: 0.000000
# Std should be ~1: 0.000000

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
history_new = model.fit(E_100k, num_epochs=300, learning_rate=1e-4, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:209: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 0
# Loss: 1107.0975
# Psi gradient stats:
# Mean: 6.3960e-05
# Std:  4.7301e-03
# Max:  1.6373e-02
# Min:  -2.1012e-02
# Epoch 0, Loss: 1107.0975, Gradients - Lambda: 5.410e-01, Phi: 1.418e+01, Gamma: 5.045e-02, Psi: 2.101e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 1
# Loss: 960.4070
# Psi gradient stats:
# Mean: 6.4122e-05
# Std:  4.7237e-03
# Max:  1.6343e-02
# Min:  -2.0992e-02
# Epoch 1, Loss: 960.4070, Gradients - Lambda: 5.185e-01, Phi: 1.358e+01, Gamma: 5.030e-02, Psi: 2.099e-02
#
# Estimated total training time: 150.4 minutes
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 2
# Loss: 835.1179
# Psi gradient stats:
# Mean: 6.4477e-05
# Std:  4.7172e-03
# Max:  1.6314e-02
# Min:  -2.0968e-02
# Epoch 2, Loss: 835.1179, Gradients - Lambda: 4.913e-01, Phi: 1.297e+01, Gamma: 5.016e-02, Psi: 2.097e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 3
# Loss: 729.3547
# Psi gradient stats:
# Mean: 6.4839e-05
# Std:  4.7109e-03
# Max:  1.6274e-02
# Min:  -2.0955e-02
# Epoch 3, Loss: 729.3547, Gradients - Lambda: 4.630e-01, Phi: 1.235e+01, Gamma: 5.000e-02, Psi: 2.096e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 4
# Loss: 640.7534
# Psi gradient stats:
# Mean: 6.5041e-05
# Std:  4.7046e-03
# Max:  1.6245e-02
# Min:  -2.0943e-02
# Epoch 4, Loss: 640.7534, Gradients - Lambda: 4.447e-01, Phi: 1.172e+01, Gamma: 4.978e-02, Psi: 2.094e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 5
# Loss: 567.1570
# Psi gradient stats:
# Mean: 6.5132e-05
# Std:  4.6983e-03
# Max:  1.6217e-02
# Min:  -2.0932e-02
# Epoch 5, Loss: 567.1570, Gradients - Lambda: 4.271e-01, Phi: 1.108e+01, Gamma: 4.950e-02, Psi: 2.093e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 6
# Loss: 506.5248
# Psi gradient stats:
# Mean: 6.5129e-05
# Std:  4.6918e-03
# Max:  1.6197e-02
# Min:  -2.0927e-02
# Epoch 6, Loss: 506.5248, Gradients - Lambda: 4.099e-01, Phi: 1.055e+01, Gamma: 4.916e-02, Psi: 2.093e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 7
# Loss: 456.9893
# Psi gradient stats:
# Mean: 6.5098e-05
# Std:  4.6853e-03
# Max:  1.6174e-02
# Min:  -2.0923e-02
# Epoch 7, Loss: 456.9893, Gradients - Lambda: 3.932e-01, Phi: 1.016e+01, Gamma: 4.876e-02, Psi: 2.092e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 8
# Loss: 416.8410
# Psi gradient stats:
# Mean: 6.5062e-05
# Std:  4.6786e-03
# Max:  1.6155e-02
# Min:  -2.0916e-02
# Epoch 8, Loss: 416.8410, Gradients - Lambda: 3.766e-01, Phi: 9.785e+00, Gamma: 4.833e-02, Psi: 2.092e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 9
# Loss: 384.5543
# Psi gradient stats:
# Mean: 6.5046e-05
# Std:  4.6718e-03
# Max:  1.6133e-02
# Min:  -2.0905e-02
# Epoch 9, Loss: 384.5543, Gradients - Lambda: 3.650e-01, Phi: 9.415e+00, Gamma: 4.788e-02, Psi: 2.091e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 10
# Loss: 358.7972
# Psi gradient stats:
# Mean: 6.5109e-05
# Std:  4.6649e-03
# Max:  1.6108e-02
# Min:  -2.0889e-02
# Epoch 10, Loss: 358.7972, Gradients - Lambda: 3.542e-01, Phi: 9.055e+00, Gamma: 4.742e-02, Psi: 2.089e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 11
# Loss: 338.4050
# Psi gradient stats:
# Mean: 6.5239e-05
# Std:  4.6579e-03
# Max:  1.6075e-02
# Min:  -2.0870e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 12
# Loss: 322.3782
# Psi gradient stats:
# Mean: 6.5431e-05
# Std:  4.6508e-03
# Max:  1.6052e-02
# Min:  -2.0850e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch
-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 295
# Loss: 210.1048
# Psi gradient stats:
# Mean: 7.1374e-05
# Std:  4.2738e-03
# Max:  1.5249e-02
# Min:  -1.9968e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 296
# Loss: 210.0575
# Psi gradient stats:
# Mean: 7.1370e-05
# Std:  4.2729e-03
# Max:  1.5249e-02
# Min:  -1.9965e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 297
# Loss: 210.0105
# Psi gradient stats:
# Mean: 7.1367e-05
# Std:  4.2719e-03
# Max:  1.5250e-02
# Min:  -1.9961e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 298
# Loss: 209.9641
# Psi gradient stats:
# Mean: 7.1354e-05
# Std:  4.2710e-03
# Max:  1.5250e-02
# Min:  -1.9959e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 299
# Loss: 209.9179
# Psi gradient stats:
# Mean: 7.1341e-05
# Std:  4.2701e-03
# Max:  1.5250e-02
# Min:  -1.9955e-02

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=1e-4:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Lambda changes with lr=1e-4:
# Mean absolute change: 1.652e-03
# Max absolute change: 2.983e-02
# Std of changes: 1.556e-03

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history_new['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history_new['max_grad_lambda'], label='Lambda')
ax2.plot(history_new['max_grad_phi'], label='Phi')
ax2.plot(history_new['max_grad_psi'], label='Psi')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
# First get the trained parameters from your existing model
pretrained_phi = model.phi.detach().clone()
pretrained_gamma = model.gamma.detach().clone()
pretrained_psi = model.psi.detach().clone()

# Get a new batch of 10k individuals
Y_new, E_new, G_new, new_indices = subset_data(Y, E, G, n_samples=10000, seed=43)  # Using different seed
# Out:
# Original shapes: Y=torch.Size([407878, 348, 52]), E=torch.Size([407878, 348]), G=torch.Size([407878, 36])
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=torch.Size([10000, 36])

# %%
from gp_clust_pretrained import *
# %load_ext autoreload
# %autoreload 2


# Create pretrained model for new data
pretrained_model = AladynSurvivalPretrainedModel(
    N=Y_new.shape[0],  # 10000
    D=Y_new.shape[1],  # same number of diseases
    T=Y_new.shape[2],  # same time points
    K=essentials['K'],  # same number of clusters
    P=essentials['P'],  # same number of genetic components
    G=G_new,           # genetic data for new individuals
    Y=Y_new,           # outcome data for new individuals
    prevalence_t=essentials['prevalence_t'],  # same prevalence
    pretrained_phi=pretrained_phi,
    pretrained_gamma=pretrained_gamma,
    pretrained_psi=pretrained_psi
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
# /Users/sarahurbut/aladynoulli/pyScripts/gp_clust_pretrained.py:60: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/gp_clust_pretrained.py:63: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/gp_clust_pretrained.py:65: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/gp_clust_pretrained.py:89: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.phi = nn.Parameter(torch.tensor(self.pretrained_phi), requires_grad=False)
# /Users/sarahurbut/aladynoulli/pyScripts/gp_clust_pretrained.py:90: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.gamma = nn.Parameter(torch.tensor(self.pretrained_gamma), requires_grad=False)
# /Users/sarahurbut/aladynoulli/pyScripts/gp_clust_pretrained.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.psi = nn.Parameter(torch.tensor(self.pretrained_psi), requires_grad=False)
# Pretrained model stats:
# G stats: mean=0.000, std=1.000
# gamma stats: mean=0.003, std=0.020
# Initial lambda stats: mean=-0.003, std=1.010
# phi stats: mean=-11.049, std=2.518
# Initialization complete! Only lambda parameters will be updated.

# %%
# Fit only lambda parameters for new individuals
history_new = pretrained_model.fit(E_new, num_epochs=100, learning_rate=1e-3)
# Out:
# Starting training (lambda parameters only)...
# /Users/sarahurbut/aladynoulli/pyScripts/gp_clust_pretrained.py:178: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 0, Loss: 587.1111, Lambda gradient: 5.442e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 1, Loss: 384.6211, Lambda gradient: 4.008e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 2, Loss: 308.7187, Lambda gradient: 2.863e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 3, Loss: 311.3310, Lambda gradient: 2.849e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 4, Loss: 318.6316, Lambda gradient: 2.646e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 5, Loss: 296.9107, Lambda gradient: 2.494e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 6, Loss: 262.0410, Lambda gradient: 2.501e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 7, Loss: 236.2537, Lambda gradient: 2.434e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 8, Loss: 225.1852, Lambda gradient: 2.443e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 9, Loss: 222.1314, Lambda gradient: 2.317e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 10, Loss: 219.4619, Lambda gradient: 1.894e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 11, Loss: 214.3521, Lambda gradient: 1.732e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 12, Loss: 207.5498, Lambda gradient: 1.633e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 13, Loss: 200.4782, Lambda gradient: 1.594e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 14, Loss: 194.0231, Lambda gradient: 1.602e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 15, Loss: 188.6039, Lambda gradient: 1.574e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 16, Loss: 184.4246, Lambda gradient: 1.662e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 17, Loss: 181.4317, Lambda gradient: 1.606e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 18, Loss: 179.2513, Lambda gradient: 1.540e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 19, Loss: 177.3593, Lambda gradient: 1.348e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 20, Loss: 175.3528, Lambda gradient: 1.195e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 21, Loss: 173.1107, Lambda gradient: 1.140e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 22, Loss: 170.7611, Lambda gradient: 1.082e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 23, Loss: 168.5202, Lambda gradient: 1.084e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 24, Loss: 166.5636, Lambda gradient: 1.037e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 25, Loss: 164.9635, Lambda gradient: 9.924e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 26, Loss: 163.6909, Lambda gradient: 1.050e-01
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 27, Loss: 162.6493, Lambda gradient: 9.811e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 28, Loss: 161.7205, Lambda gradient: 8.452e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 29, Loss: 160.8222, Lambda gradient: 7.575e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 30, Loss: 159.9039, Lambda gradient: 7.579e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 31, Loss: 158.9674, Lambda gradient: 8.355e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 32, Loss: 158.0468, Lambda gradient: 7.716e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 33, Loss: 157.1820, Lambda gradient: 7.321e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 34, Loss: 156.4061, Lambda gradient: 6.741e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 35, Loss: 155.7254, Lambda gradient: 6.870e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 36, Loss: 155.1217, Lambda gradient: 6.405e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 37, Loss: 154.5670, Lambda gradient: 5.567e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 38, Loss: 154.0410, Lambda gradient: 5.288e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch
-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 97, Loss: 143.7349, Lambda gradient: 1.737e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 98, Loss: 143.6693, Lambda gradient: 2.180e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
# Epoch 99, Loss: 143.6036, Lambda gradient: 2.326e-02

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history_new['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history_new['max_grad_lambda'], label='Lambda')

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
disease_names=essentials['disease_names']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert gamma tensors to numpy arrays
initial_gamma_np = initial_gamma.detach().numpy()
final_gamma_np = model.gamma.detach().numpy()

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial gamma
sns.heatmap(initial_gamma_np, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Gamma')

# Plot final gamma
sns.heatmap(final_gamma_np, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Gamma')

# Add a title to the figure
plt.suptitle('Comparison of Initial vs Final Gamma Values', fontsize=16)

# You can also add a colorbar
plt.tight_layout()

# To see the actual difference, you can also create a difference heatmap
plt.figure(figsize=(10, 8))
diff = final_gamma_np - initial_gamma_np
sns.heatmap(diff, cmap='RdBu_r', center=0)
plt.title('Difference (Final - Initial Gamma)')
plt.show()

# Print some summary statistics
print(f"Mean absolute difference: {np.abs(diff).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff):.4f}")
# Out:
# Mean absolute difference: 0.0052
# Max absolute difference: 0.0187
# Standard deviation of differences: 0.0065

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Convert phi tensors to numpy arrays
initial_phi_np = initial_phi.detach().numpy()  # Shape: (K, D, T)
final_phi_np = model.phi.detach().numpy()

# Take mean over time dimension
initial_phi_mean = initial_phi_np.mean(axis=2)  # Shape: (K, D)
final_phi_mean = final_phi_np.mean(axis=2)

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial phi (averaged over time)
sns.heatmap(initial_phi_mean, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Phi (Mean over Time)')
ax1.set_xlabel('Disease')
ax1.set_ylabel('Signature')

# Plot final phi (averaged over time)
sns.heatmap(final_phi_mean, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Phi (Mean over Time)')
ax2.set_xlabel('Disease')
ax2.set_ylabel('Signature')

plt.suptitle('Comparison of Initial vs Final Phi Values (Averaged over Time)', fontsize=16)
plt.tight_layout()

# Plot difference
plt.figure(figsize=(10, 8))
diff_mean = final_phi_mean - initial_phi_mean
sns.heatmap(diff_mean, cmap='RdBu_r', center=0)
plt.title('Difference in Phi (Final - Initial), Mean over Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# Print summary statistics for both full tensor and time-averaged differences
print("Full tensor statistics:")
diff_full = final_phi_np - initial_phi_np
print(f"Mean absolute difference: {np.abs(diff_full).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_full).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_full):.4f}")

print("\nTime-averaged statistics:")
print(f"Mean absolute difference: {np.abs(diff_mean).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_mean).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_mean):.4f}")

# Optionally, look at temporal variation
temporal_std = np.std(diff_full, axis=2)
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_std, cmap='viridis')
plt.title('Standard Deviation of Changes Across Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()
# Out:
# Full tensor statistics:
# Mean absolute difference: 0.0015
# Max absolute difference: 0.0232
# Standard deviation of differences: 0.0020
#
# Time-averaged statistics:
# Mean absolute difference: 0.0002
# Max absolute difference: 0.0015
# Standard deviation of differences: 0.0002

# %%
Y_global=Y

# %%
Y_global.shape

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")
# Out:
# Mean observed risk: 0.000439
# Mean predicted risk (original): 0.000173
# Mean predicted risk (calibrated): 0.000439
# Calibration scale factor: 2.531

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")
# Out:
# R^2: 0.551

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])
# Out:
# Top 10 diseases in Signature 0 (relative to baseline):
# Pleurisy; pleural effusion: effect=2.155 (OR=8.62), std=0.656
# Cardiomegaly: effect=1.461 (OR=4.31), std=1.104
# Other forms of chronic heart disease: effect=1.372 (OR=3.94), std=0.455
# Atrial fibrillation and flutter: effect=1.338 (OR=3.81), std=0.804
# Disease of tricuspid valve: effect=1.223 (OR=3.40), std=1.015
# Rheumatic disease of the heart valves: effect=1.172 (OR=3.23), std=0.443
# Congestive heart failure (CHF) NOS: effect=1.127 (OR=3.09), std=0.596
# Pericarditis: effect=0.806 (OR=2.24), std=0.558
# Paroxysmal ventricular tachycardia: effect=0.801 (OR=2.23), std=0.258
# Heart failure NOS: effect=0.610 (OR=1.84), std=0.774
#
# Top 10 diseases in Signature 1 (relative to baseline):
# Rheumatoid arthritis: effect=2.618 (OR=13.71), std=0.576
# Osteoarthritis; localized: effect=1.849 (OR=6.36), std=0.472
# Pain in joint: effect=1.846 (OR=6.33), std=0.241
# Hallux rigidus: effect=1.822 (OR=6.18), std=0.467
# Hammer toe (acquired): effect=1.582 (OR=4.87), std=0.457
# Enthesopathy: effect=1.525 (OR=4.60), std=0.282
# Other disorders of synovium, tendon, and bursa: effect=1.234 (OR=3.43), std=0.930
# Joint effusions: effect=1.024 (OR=2.79), std=1.404
# Acquired toe deformities: effect=1.003 (OR=2.73), std=0.442
# Other peripheral nerve disorders: effect=0.941 (OR=2.56), std=1.136
#
# Top 10 diseases in Signature 2 (relative to baseline):
# Duodenal ulcer: effect=2.591 (OR=13.35), std=0.507
# Gastritis and duodenitis: effect=2.344 (OR=10.43), std=0.457
# Stricture and stenosis of esophagus: effect=1.657 (OR=5.24), std=0.582
# Barrett's esophagus: effect=1.554 (OR=4.73), std=0.611
# Reflux esophagitis: effect=1.445 (OR=4.24), std=0.237
# Other specified gastritis: effect=1.426 (OR=4.16), std=0.654
# Other disorders of stomach and duodenum: effect=0.933 (OR=2.54), std=0.244
# Iron deficiency anemias, unspecified or not due to blood loss: effect=0.842 (OR=2.32), std=0.228
# Gastric ulcer: effect=0.814 (OR=2.26), std=1.209
# Diaphragmatic hernia: effect=0.677 (OR=1.97), std=0.527
#
# Top 10 diseases in Signature 3 (relative to baseline):
# Malunion and nonunion of fracture: effect=2.723 (OR=15.23), std=0.126
# Disturbances in tooth eruption: effect=2.592 (OR=13.36), std=0.945
# Umbilical hernia: effect=2.446 (OR=11.54), std=0.351
# Hemangioma and lymphangioma, any site: effect=2.370 (OR=10.69), std=0.466
# Ingrowing nail: effect=2.332 (OR=10.30), std=0.349
# Neoplasm of uncertain behavior: effect=2.261 (OR=9.59), std=0.446
# Hydrocele: effect=2.225 (OR=9.26), std=0.830
# Ptosis of eyelid: effect=2.092 (OR=8.10), std=0.046
# Gout: effect=2.065 (OR=7.88), std=0.408
# Hypertrophy of breast (Gynecomastia): effect=1.987 (OR=7.29), std=0.488
#
# Top 10 diseases in Signature 4 (relative to baseline):
# Other upper respiratory disease: effect=1.985 (OR=7.28), std=1.231
# Chronic sinusitis: effect=1.114 (OR=3.05), std=0.393
# Septal Deviations/Turbinate Hypertrophy: effect=0.874 (OR=2.40), std=0.245
# Chronic pharyngitis and nasopharyngitis: effect=0.666 (OR=1.95), std=0.863
# Other diseases of respiratory system, NEC: effect=0.379 (OR=1.46), std=1.288
# Epiphora: effect=0.294 (OR=1.34), std=0.427
# Synovitis and tenosynovitis: effect=0.116 (OR=1.12), std=1.097
# Other chronic ischemic heart disease, unspecified: effect=0.015 (OR=1.01), std=0.790
# Duodenal ulcer: effect=-0.100 (OR=0.91), std=0.260
# Lipoma: effect=-0.166 (OR=0.85), std=0.561
#
# Top 10 diseases in Signature 5 (relative to baseline):
# Coronary atherosclerosis: effect=2.089 (OR=8.08), std=1.076
# Myocardial infarction: effect=1.631 (OR=5.11), std=0.673
# Other acute and subacute forms of ischemic heart disease: effect=1.513 (OR=4.54), std=0.291
# Hypercholesterolemia: effect=1.154 (OR=3.17), std=1.076
# Unstable angina (intermediate coronary syndrome): effect=0.610 (OR=1.84), std=0.674
# Hearing loss: effect=-0.015 (OR=0.99), std=0.995
# Angina pectoris: effect=-0.193 (OR=0.82), std=0.120
# Congenital anomalies of great vessels: effect=-0.264 (OR=0.77), std=0.378
# Neutropenia: effect=-0.288 (OR=0.75), std=1.050
# Osteoporosis NOS: effect=-0.401 (OR=0.67), std=1.004
#
# Top 10 diseases in Signature 6 (relative to baseline):
# Secondary malignant neoplasm of digestive systems: effect=3.258 (OR=26.01), std=0.777
# Secondary malignancy of bone: effect=2.663 (OR=14.33), std=1.190
# Secondary malignant neoplasm: effect=1.097 (OR=2.99), std=0.579
# Malignant neoplasm, other: effect=0.955 (OR=2.60), std=0.741
# Secondary malignant neoplasm of liver: effect=0.624 (OR=1.87), std=0.291
# Cancer of bronchus; lung: effect=0.384 (OR=1.47), std=0.460
# Benign neoplasm of skin: effect=0.305 (OR=1.36), std=1.480
# Other diseases of the teeth and supporting structures: effect=0.240 (OR=1.27), std=0.295
# Allergic rhinitis: effect=-0.067 (OR=0.93), std=0.552
# Staphylococcus infections: effect=-0.232 (OR=0.79), std=0.684
#
# Top 10 diseases in Signature 7 (relative to baseline):
# Other disorders of soft tissues: effect=2.161 (OR=8.68), std=0.213
# Hypothyroidism NOS: effect=1.852 (OR=6.37), std=0.912
# GERD: effect=1.785 (OR=5.96), std=0.155
# Myalgia and myositis unspecified: effect=1.628 (OR=5.09), std=0.318
# Cervicalgia: effect=1.608 (OR=4.99), std=0.474
# Other inflammatory spondylopathies: effect=1.592 (OR=4.92), std=0.232
# Other chronic nonalcoholic liver disease: effect=1.565 (OR=4.78), std=0.522
# Asthma: effect=1.458 (OR=4.30), std=0.767
# Migraine: effect=1.331 (OR=3.78), std=0.759
# Sleep apnea: effect=1.291 (OR=3.64), std=0.257
#
# Top 10 diseases in Signature 8 (relative to baseline):
# Benign neoplasm of ovary: effect=2.484 (OR=11.99), std=0.642
# Mucous polyp of cervix: effect=1.979 (OR=7.23), std=0.407
# Noninflammatory disorders of cervix: effect=1.977 (OR=7.22), std=0.549
# Disorders of uterus, NEC: effect=1.971 (OR=7.18), std=0.364
# Malignant neoplasm of uterus: effect=1.968 (OR=7.16), std=0.583
# Polyp of corpus uteri: effect=1.872 (OR=6.50), std=0.913
# Uterine leiomyoma: effect=1.869 (OR=6.48), std=0.753
# Disorders of menstruation and other abnormal bleeding from female genital tract: effect=1.766 (OR=5.85), std=0.169
# Postmenopausal atrophic vaginitis: effect=1.569 (OR=4.80), std=0.480
# Endometriosis: effect=1.557 (OR=4.75), std=0.532
#
# Top 10 diseases in Signature 9 (relative to baseline):
# Degenerative disease of the spinal cord: effect=2.119 (OR=8.33), std=0.642
# Back pain: effect=2.113 (OR=8.27), std=0.562
# Neuralgia, neuritis, and radiculitis NOS: effect=1.873 (OR=6.51), std=0.924
# Displacement of intervertebral disc: effect=1.332 (OR=3.79), std=0.698
# Sciatica: effect=0.964 (OR=2.62), std=0.299
# Kyphoscoliosis and scoliosis: effect=0.809 (OR=2.25), std=0.469
# Other and unspecified disc disorder: effect=0.799 (OR=2.22), std=0.213
# Spondylosis without myelopathy: effect=0.760 (OR=2.14), std=0.647
# Acquired spondylolisthesis: effect=0.386 (OR=1.47), std=0.413
# Degeneration of intervertebral disc: effect=0.305 (OR=1.36), std=0.920
#
# Top 10 diseases in Signature 10 (relative to baseline):
# Disorders of vitreous body: effect=2.391 (OR=10.93), std=0.803
# Primary open angle glaucoma: effect=2.351 (OR=10.49), std=0.737
# Myopia: effect=0.818 (OR=2.27), std=0.525
# Macular degeneration (senile) of retina NOS: effect=0.687 (OR=1.99), std=0.390
# Senile cataract: effect=0.618 (OR=1.85), std=0.531
# Other peripheral nerve disorders: effect=0.556 (OR=1.74), std=1.292
# Other retinal disorders: effect=0.550 (OR=1.73), std=0.340
# Excessive or frequent menstruation: effect=0.464 (OR=1.59), std=0.389
# Glaucoma: effect=0.361 (OR=1.43), std=0.238
# Retinal detachment with retinal defect: effect=0.319 (OR=1.38), std=0.533
#
# Top 10 diseases in Signature 11 (relative to baseline):
# Cerebrovascular disease: effect=2.426 (OR=11.32), std=0.488
# Occlusion of cerebral arteries: effect=2.181 (OR=8.86), std=0.374
# Hemiplegia: effect=1.964 (OR=7.13), std=0.281
# Late effects of cerebrovascular disease: effect=0.961 (OR=2.61), std=0.372
# Cerebral ischemia: effect=0.451 (OR=1.57), std=0.453
# Cerebral artery occlusion, with cerebral infarction: effect=0.217 (OR=1.24), std=0.685
# Hyperpotassemia: effect=-0.009 (OR=0.99), std=0.568
# Occlusion and stenosis of precerebral arteries: effect=-0.013 (OR=0.99), std=0.505
# Hallux valgus (Bunion): effect=-0.069 (OR=0.93), std=0.891
# Other tests: effect=-0.084 (OR=0.92), std=1.270
#
# Top 10 diseases in Signature 12 (relative to baseline):
# Stricture/obstruction of ureter: effect=2.080 (OR=8.00), std=0.381
# Calculus of ureter: effect=1.846 (OR=6.34), std=0.263
# Other disorders of the kidney and ureters: effect=1.429 (OR=4.17), std=0.805
# Renal colic: effect=1.059 (OR=2.88), std=0.422
# Hydronephrosis: effect=0.817 (OR=2.26), std=0.380
# Pyelonephritis: effect=0.703 (OR=2.02), std=0.414
# Postmenopausal atrophic vaginitis: effect=0.583 (OR=1.79), std=0.971
# Noninflammatory disorders of cervix: effect=0.252 (OR=1.29), std=0.619
# Calculus of kidney: effect=0.106 (OR=1.11), std=0.455
# Obstructive chronic bronchitis: effect=-0.003 (OR=1.00), std=0.498
#
# Top 10 diseases in Signature 13 (relative to baseline):
# Malignant neoplasm of bladder: effect=2.486 (OR=12.01), std=0.471
# Bladder neck obstruction: effect=1.704 (OR=5.49), std=0.319
# Other disorders of bladder: effect=1.048 (OR=2.85), std=0.580
# Cancer of prostate: effect=1.043 (OR=2.84), std=0.461
# Other disorders of prostate: effect=0.939 (OR=2.56), std=0.845
# Chronic cystitis: effect=0.872 (OR=2.39), std=0.432
# Functional disorders of bladder: effect=0.699 (OR=2.01), std=0.384
# Urinary incontinence: effect=0.488 (OR=1.63), std=0.345
# Urethral stricture (not specified as infectious): effect=0.430 (OR=1.54), std=0.461
# Chronic prostatitis: effect=0.428 (OR=1.53), std=0.433
#
# Top 10 diseases in Signature 14 (relative to baseline):
# Pneumococcal pneumonia: effect=2.353 (OR=10.52), std=0.321
# Postinflammatory pulmonary fibrosis: effect=2.072 (OR=7.94), std=0.502
# Pneumonia: effect=1.463 (OR=4.32), std=0.461
# Chronic airway obstruction: effect=1.439 (OR=4.22), std=0.909
# Empyema and pneumothorax: effect=1.387 (OR=4.00), std=0.249
# Bronchiectasis: effect=1.381 (OR=3.98), std=0.125
# Emphysema: effect=1.028 (OR=2.80), std=0.199
# Respiratory failure: effect=0.955 (OR=2.60), std=0.757
# Tobacco use disorder: effect=0.518 (OR=1.68), std=0.457
# Obstructive chronic bronchitis: effect=0.487 (OR=1.63), std=0.506
#
# Top 10 diseases in Signature 15 (relative to baseline):
# Hypoglycemia: effect=1.360 (OR=3.89), std=0.411
# Type 2 diabetes with ophthalmic manifestations: effect=1.309 (OR=3.70), std=0.630
# Diabetic retinopathy: effect=0.882 (OR=2.41), std=0.758
# Type 1 diabetes: effect=0.740 (OR=2.10), std=0.456
# Type 2 diabetes: effect=0.329 (OR=1.39), std=0.384
# Alcoholic liver damage: effect=0.196 (OR=1.22), std=0.715
# Cardiac arrest: effect=0.068 (OR=1.07), std=0.619
# Inflammation of eyelids: effect=-0.043 (OR=0.96), std=0.716
# Tobacco use disorder: effect=-0.132 (OR=0.88), std=0.282
# Chronic cystitis: effect=-0.217 (OR=0.80), std=0.694
#
# Top 10 diseases in Signature 16 (relative to baseline):
# Thrombocytopenia: effect=3.078 (OR=21.71), std=0.404
# Hypopotassemia: effect=2.675 (OR=14.51), std=0.362
# Bacterial infection NOS: effect=2.355 (OR=10.54), std=0.157
# Peritonitis and retroperitoneal infections: effect=2.109 (OR=8.24), std=0.296
# Other anemias: effect=2.010 (OR=7.46), std=1.278
# Other diseases of respiratory system, NEC: effect=1.925 (OR=6.85), std=1.006
# Acidosis: effect=1.817 (OR=6.15), std=0.576
# Cellulitis and abscess of arm/hand: effect=1.684 (OR=5.39), std=0.300
# Hypovolemia: effect=1.601 (OR=4.96), std=0.728
# Orthostatic hypotension: effect=1.392 (OR=4.02), std=0.561
#
# Top 10 diseases in Signature 17 (relative to baseline):
# Colon cancer: effect=2.534 (OR=12.60), std=0.559
# Benign neoplasm of colon: effect=1.980 (OR=7.24), std=0.684
# Anal and rectal polyp: effect=1.436 (OR=4.20), std=0.493
# Hemorrhage of rectum and anus: effect=1.400 (OR=4.06), std=0.455
# Other intestinal obstruction: effect=1.083 (OR=2.95), std=0.303
# Hemorrhoids: effect=1.018 (OR=2.77), std=0.736
# Ventral hernia: effect=0.720 (OR=2.05), std=0.212
# Hemorrhage of gastrointestinal tract: effect=0.683 (OR=1.98), std=0.191
# Regional enteritis: effect=0.673 (OR=1.96), std=0.580
# Anal and rectal conditions: effect=0.610 (OR=1.84), std=0.577
#
# Top 10 diseases in Signature 18 (relative to baseline):
# Cholelithiasis with other cholecystitis: effect=2.141 (OR=8.50), std=0.700
# Other disorders of biliary tract: effect=1.847 (OR=6.34), std=0.408
# Cholelithiasis: effect=1.175 (OR=3.24), std=0.789
# Acute pancreatitis: effect=1.151 (OR=3.16), std=0.583
# Cholecystitis without cholelithiasis: effect=1.056 (OR=2.87), std=0.258
# Peritoneal adhesions (postoperative) (postinfection): effect=0.549 (OR=1.73), std=0.740
# Diseases and other conditions of the tongue: effect=-0.075 (OR=0.93), std=0.811
# Cholelithiasis with acute cholecystitis: effect=-0.120 (OR=0.89), std=0.454
# Hammer toe (acquired): effect=-0.231 (OR=0.79), std=0.555
# Disorders of uterus, NEC: effect=-0.272 (OR=0.76), std=0.769
#
# Top 10 diseases in Signature 19 (relative to baseline):
# Disorder of skin and subcutaneous tissue NOS: effect=3.111 (OR=22.43), std=0.400
# Other disorders of eyelids: effect=2.509 (OR=12.29), std=0.852
# Seborrheic keratosis: effect=2.138 (OR=8.48), std=0.589
# Epiphora: effect=2.039 (OR=7.68), std=0.579
# Viral warts & HPV: effect=1.785 (OR=5.96), std=0.806
# Other non-epithelial cancer of skin: effect=1.692 (OR=5.43), std=0.380
# Hypertensive chronic kidney disease: effect=1.629 (OR=5.10), std=0.317
# Scar conditions and fibrosis of skin: effect=1.604 (OR=4.97), std=0.664
# Chronic glomerulonephritis, NOS: effect=1.603 (OR=4.97), std=0.513
# Other hypertrophic and atrophic conditions of skin: effect=1.373 (OR=3.95), std=0.637

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])
# Out:
# Signature 0:
#
# Initial top diseases:
# 1. Aortic valve disease: 1.152
# 2. Paroxysmal ventricular tachycardia: 1.137
# 3. Heart failure NOS: 1.119
# 4. Congestive heart failure (CHF) NOS: 1.071
# 5. Left bundle branch block: 1.054
# 6. Atrial fibrillation and flutter: 1.005
# 7. Congenital anomalies of great vessels: 1.004
# 8. Pericarditis: 0.976
# 9. Cardiomegaly: 0.967
# 10. Mitral valve disease: 0.956
#
# Final top diseases:
# 1. Pleurisy; pleural effusion: 2.155
# 2. Cardiomegaly: 1.461
# 3. Other forms of chronic heart disease: 1.372
# 4. Atrial fibrillation and flutter: 1.338
# 5. Disease of tricuspid valve: 1.223
# 6. Rheumatic disease of the heart valves: 1.172
# 7. Congestive heart failure (CHF) NOS: 1.127
# 8. Pericarditis: 0.806
# 9. Paroxysmal ventricular tachycardia: 0.801
# 10. Heart failure NOS: 0.610
#
# Congestive heart failure (CHF) NOS changed from rank 4 to 7
#
# Heart failure NOS changed from rank 3 to 10
#
# Congenital anomalies of great vessels changed from rank 7 to 12
#
# Pleurisy; pleural effusion changed from rank 12 to 1
#
# Rheumatic disease of the heart valves changed from rank 12 to 6
#
# Aortic valve disease changed from rank 1 to 12
#
# Disease of tricuspid valve changed from rank 12 to 5
#
# Other forms of chronic heart disease changed from rank 12 to 3
#
# Cardiomegaly changed from rank 9 to 2
#
# Left bundle branch block changed from rank 5 to 12
#
# Paroxysmal ventricular tachycardia changed from rank 2 to 9
#
# Signature 1:
#
# Initial top diseases:
# 1. Other disorders of synovium, tendon, and bursa: 1.264
# 2. Enthesopathy: 1.164
# 3. Hallux valgus (Bunion): 1.162
# 4. Rheumatoid arthritis: 1.097
# 5. Pain in joint: 1.089
# 6. Peripheral enthesopathies and allied syndromes: 1.085
# 7. Hallux rigidus: 1.067
# 8. Other peripheral nerve disorders: 1.059
# 9. Acquired toe deformities: 1.051
# 10. Osteoarthrosis, generalized: 0.976
#
# Final top diseases:
# 1. Rheumatoid arthritis: 2.618
# 2. Osteoarthritis; localized: 1.849
# 3. Pain in joint: 1.846
# 4. Hallux rigidus: 1.822
# 5. Hammer toe (acquired): 1.582
# 6. Enthesopathy: 1.525
# 7. Other disorders of synovium, tendon, and bursa: 1.234
# 8. Joint effusions: 1.024
# 9. Acquired toe deformities: 1.003
# 10. Other peripheral nerve disorders: 0.941
#
# Hallux rigidus changed from rank 7 to 4
#
# Hallux valgus (Bunion) changed from rank 3 to 12
#
# Osteoarthritis; localized changed from rank 12 to 2
#
# Joint effusions changed from rank 12 to 8
#
# Rheumatoid arthritis changed from rank 4 to 1
#
# Peripheral enthesopathies and allied syndromes changed from rank 6 to 12
#
# Enthesopathy changed from rank 2 to 6
#
# Other disorders of synovium, tendon, and bursa changed from rank 1 to 7
#
# Hammer toe (acquired) changed from rank 12 to 5
#
# Signature 2:
#
# Initial top diseases:
# 1. Gastritis and duodenitis: 1.186
# 2. Gastric ulcer: 1.157
# 3. Reflux esophagitis: 1.053
# 4. Other disorders of stomach and duodenum: 1.010
# 5. Other specified gastritis: 1.005
# 6. Stricture and stenosis of esophagus: 0.984
# 7. Duodenitis: 0.982
# 8. Duodenal ulcer: 0.964
# 9. Barrett's esophagus: 0.951
# 10. Iron deficiency anemias, unspecified or not due to blood loss: 0.944
#
# Final top diseases:
# 1. Duodenal ulcer: 2.591
# 2. Gastritis and duodenitis: 2.344
# 3. Stricture and stenosis of esophagus: 1.657
# 4. Barrett's esophagus: 1.554
# 5. Reflux esophagitis: 1.445
# 6. Other specified gastritis: 1.426
# 7. Other disorders of stomach and duodenum: 0.933
# 8. Iron deficiency anemias, unspecified or not due to blood loss: 0.842
# 9. Gastric ulcer: 0.814
# 10. Diaphragmatic hernia: 0.677
#
# Other disorders of stomach and duodenum changed from rank 4 to 7
#
# Barrett's esophagus changed from rank 9 to 4
#
# Stricture and stenosis of esophagus changed from rank 6 to 3
#
# Gastric ulcer changed from rank 2 to 9
#
# Duodenal ulcer changed from rank 8 to 1
#
# Duodenitis changed from rank 7 to 12
#
# Signature 3:
#
# Initial top diseases:
# 1. Celiac disease: 1.249
# 2. Blood in stool: 1.190
# 3. Other tests: 1.178
# 4. Redundant prepuce and phimosis/BXO: 1.177
# 5. Hypertrophy of breast (Gynecomastia): 1.165
# 6. Diseases of the larynx and vocal cords: 1.147
# 7. Peripheral vascular disease, unspecified: 1.143
# 8. Atopic/contact dermatitis due to other or unspecified: 1.138
# 9. Alcohol-related disorders: 1.137
# 10. Hemangioma and lymphangioma, any site: 1.133
#
# Final top diseases:
# 1. Malunion and nonunion of fracture: 2.723
# 2. Disturbances in tooth eruption: 2.592
# 3. Umbilical hernia: 2.446
# 4. Hemangioma and lymphangioma, any site: 2.370
# 5. Ingrowing nail: 2.332
# 6. Neoplasm of uncertain behavior: 2.261
# 7. Hydrocele: 2.225
# 8. Ptosis of eyelid: 2.092
# 9. Gout: 2.065
# 10. Hypertrophy of breast (Gynecomastia): 1.987
#
# Hypertrophy of breast (Gynecomastia) changed from rank 5 to 10
#
# Alcohol-related disorders changed from rank 9 to 12
#
# Umbilical hernia changed from rank 12 to 3
#
# Celiac disease changed from rank 1 to 12
#
# Peripheral vascular disease, unspecified changed from rank 7 to 12
#
# Atopic/contact dermatitis due to other or unspecified changed from rank 8 to 12
#
# Diseases of the larynx and vocal cords changed from rank 6 to 12
#
# Other tests changed from rank 3 to 12
#
# Neoplasm of uncertain behavior changed from rank 12 to 6
#
# Blood in stool changed from rank 2 to 12
#
# Ptosis of eyelid changed from rank 12 to 8
#
# Ingrowing nail changed from rank 12 to 5
#
# Hemangioma and lymphangioma, any site changed from rank 10 to 4
#
# Disturbances in tooth eruption changed from rank 12 to 2
#
# Gout changed from rank 12 to 9
#
# Malunion and nonunion of fracture changed from rank 12 to 1
#
# Hydrocele changed from rank 12 to 7
#
# Redundant prepuce and phimosis/BXO changed from rank 4 to 12
#
# Signature 4:
#
# Initial top diseases:
# 1. Other upper respiratory disease: 1.047
# 2. Septal Deviations/Turbinate Hypertrophy: 0.952
# 3. Chronic sinusitis: 0.886
# 4. Chronic pharyngitis and nasopharyngitis: 0.883
# 5. Nasal polyps: 0.830
# 6. Secondary malignancy of bone: -1.950
# 7. Irregular menstrual cycle/bleeding: -1.951
# 8. Degeneration of intervertebral disc: -1.952
# 9. Abdominal aortic aneurysm: -1.953
# 10. Ventral hernia: -1.953
#
# Final top diseases:
# 1. Other upper respiratory disease: 1.985
# 2. Chronic sinusitis: 1.114
# 3. Septal Deviations/Turbinate Hypertrophy: 0.874
# 4. Chronic pharyngitis and nasopharyngitis: 0.666
# 5. Other diseases of respiratory system, NEC: 0.379
# 6. Epiphora: 0.294
# 7. Synovitis and tenosynovitis: 0.116
# 8. Other chronic ischemic heart disease, unspecified: 0.015
# 9. Duodenal ulcer: -0.100
# 10. Lipoma: -0.166
#
# Abdominal aortic aneurysm changed from rank 9 to 12
#
# Irregular menstrual cycle/bleeding changed from rank 7 to 12
#
# Nasal polyps changed from rank 5 to 12
#
# Secondary malignancy of bone changed from rank 6 to 12
#
# Epiphora changed from rank 12 to 6
#
# Other diseases of respiratory system, NEC changed from rank 12 to 5
#
# Degeneration of intervertebral disc changed from rank 8 to 12
#
# Other chronic ischemic heart disease, unspecified changed from rank 12 to 8
#
# Synovitis and tenosynovitis changed from rank 12 to 7
#
# Duodenal ulcer changed from rank 12 to 9
#
# Signature 5:
#
# Initial top diseases:
# 1. Coronary atherosclerosis: 1.207
# 2. Other acute and subacute forms of ischemic heart disease: 1.137
# 3. Hypercholesterolemia: 1.050
# 4. Other chronic ischemic heart disease, unspecified: 0.878
# 5. Unstable angina (intermediate coronary syndrome): 0.851
# 6. Myocardial infarction: 0.840
# 7. Angina pectoris: 0.809
# 8. Lipoma: -1.945
# 9. Cholelithiasis with acute cholecystitis: -1.948
# 10. Bladder neck obstruction: -1.949
#
# Final top diseases:
# 1. Coronary atherosclerosis: 2.089
# 2. Myocardial infarction: 1.631
# 3. Other acute and subacute forms of ischemic heart disease: 1.513
# 4. Hypercholesterolemia: 1.154
# 5. Unstable angina (intermediate coronary syndrome): 0.610
# 6. Hearing loss: -0.015
# 7. Angina pectoris: -0.193
# 8. Congenital anomalies of great vessels: -0.264
# 9. Neutropenia: -0.288
# 10. Osteoporosis NOS: -0.401
#
# Neutropenia changed from rank 12 to 9
#
# Congenital anomalies of great vessels changed from rank 12 to 8
#
# Cholelithiasis with acute cholecystitis changed from rank 9 to 12
#
# Lipoma changed from rank 8 to 12
#
# Hearing loss changed from rank 12 to 6
#
# Myocardial infarction changed from rank 6 to 2
#
# Other chronic ischemic heart disease, unspecified changed from rank 4 to 12
#
# Signature 6:
#
# Initial top diseases:
# 1. Secondary malignant neoplasm of digestive systems: 1.112
# 2. Secondary malignancy of bone: 1.077
# 3. Secondary malignancy of lymph nodes: 1.026
# 4. Secondary malignant neoplasm: 1.015
# 5. Secondary malignant neoplasm of liver: 0.977
# 6. Malignant neoplasm, other: 0.975
# 7. Cancer of bronchus; lung: 0.934
# 8. Secondary malignancy of respiratory organs: 0.780
# 9. Urinary incontinence: -1.943
# 10. Regional enteritis: -1.948
#
# Final top diseases:
# 1. Secondary malignant neoplasm of digestive systems: 3.258
# 2. Secondary malignancy of bone: 2.663
# 3. Secondary malignant neoplasm: 1.097
# 4. Malignant neoplasm, other: 0.955
# 5. Secondary malignant neoplasm of liver: 0.624
# 6. Cancer of bronchus; lung: 0.384
# 7. Benign neoplasm of skin: 0.305
# 8. Other diseases of the teeth and supporting structures: 0.240
# 9. Allergic rhinitis: -0.067
# 10. Staphylococcus infections: -0.232
#
# Secondary malignancy of lymph nodes changed from rank 3 to 12
#
# Secondary malignancy of respiratory organs changed from rank 8 to 12
#
# Allergic rhinitis changed from rank 12 to 9
#
# Benign neoplasm of skin changed from rank 12 to 7
#
# Other diseases of the teeth and supporting structures changed from rank 12 to 8
#
# Urinary incontinence changed from rank 9 to 12
#
# Signature 7:
#
# Initial top diseases:
# 1. Asthma: 1.355
# 2. Migraine: 1.236
# 3. Myalgia and myositis unspecified: 1.216
# 4. Osteoporosis NOS: 1.184
# 5. Major depressive disorder: 1.108
# 6. Spondylosis and allied disorders: 1.092
# 7. Abdominal pain: 1.080
# 8. Essential hypertension: 1.080
# 9. Hyperlipidemia: 1.064
# 10. Obesity: 1.060
#
# Final top diseases:
# 1. Other disorders of soft tissues: 2.161
# 2. Hypothyroidism NOS: 1.852
# 3. GERD: 1.785
# 4. Myalgia and myositis unspecified: 1.628
# 5. Cervicalgia: 1.608
# 6. Other inflammatory spondylopathies: 1.592
# 7. Other chronic nonalcoholic liver disease: 1.565
# 8. Asthma: 1.458
# 9. Migraine: 1.331
# 10. Sleep apnea: 1.291
#
# Major depressive disorder changed from rank 5 to 12
#
# Migraine changed from rank 2 to 9
#
# Osteoporosis NOS changed from rank 4 to 12
#
# Cervicalgia changed from rank 12 to 5
#
# Other chronic nonalcoholic liver disease changed from rank 12 to 7
#
# Abdominal pain changed from rank 7 to 12
#
# Asthma changed from rank 1 to 8
#
# Other inflammatory spondylopathies changed from rank 12 to 6
#
# Essential hypertension changed from rank 8 to 12
#
# Spondylosis and allied disorders changed from rank 6 to 12
#
# Hypothyroidism NOS changed from rank 12 to 2
#
# Hyperlipidemia changed from rank 9 to 12
#
# GERD changed from rank 12 to 3
#
# Other disorders of soft tissues changed from rank 12 to 1
#
# Signature 8:
#
# Initial top diseases:
# 1. Ovarian cyst: 1.231
# 2. Malignant neoplasm of uterus: 1.158
# 3. Polyp of corpus uteri: 1.131
# 4. Noninflammatory disorders of cervix: 1.117
# 5. Cervicitis and endocervicitis: 1.104
# 6. Noninflammatory disorders of vagina: 1.079
# 7. Hypertrophy of female genital organs: 1.066
# 8. Excessive or frequent menstruation: 1.049
# 9. Dyspareunia: 1.018
# 10. Uterine/Uterovaginal prolapse: 1.014
#
# Final top diseases:
# 1. Benign neoplasm of ovary: 2.484
# 2. Mucous polyp of cervix: 1.979
# 3. Noninflammatory disorders of cervix: 1.977
# 4. Disorders of uterus, NEC: 1.971
# 5. Malignant neoplasm of uterus: 1.968
# 6. Polyp of corpus uteri: 1.872
# 7. Uterine leiomyoma: 1.869
# 8. Disorders of menstruation and other abnormal bleeding from female genital tract: 1.766
# 9. Postmenopausal atrophic vaginitis: 1.569
# 10. Endometriosis: 1.557
#
# Cervicitis and endocervicitis changed from rank 5 to 12
#
# Disorders of uterus, NEC changed from rank 12 to 4
#
# Noninflammatory disorders of vagina changed from rank 6 to 12
#
# Polyp of corpus uteri changed from rank 3 to 6
#
# Mucous polyp of cervix changed from rank 12 to 2
#
# Hypertrophy of female genital organs changed from rank 7 to 12
#
# Dyspareunia changed from rank 9 to 12
#
# Disorders of menstruation and other abnormal bleeding from female genital tract changed from rank 12 to 8
#
# Malignant neoplasm of uterus changed from rank 2 to 5
#
# Excessive or frequent menstruation changed from rank 8 to 12
#
# Postmenopausal atrophic vaginitis changed from rank 12 to 9
#
# Ovarian cyst changed from rank 1 to 12
#
# Uterine leiomyoma changed from rank 12 to 7
#
# Benign neoplasm of ovary changed from rank 12 to 1
#
# Signature 9:
#
# Initial top diseases:
# 1. Back pain: 1.271
# 2. Neuralgia, neuritis, and radiculitis NOS: 1.086
# 3. Thoracic or lumbosacral neuritis or radiculitis, unspecified: 1.042
# 4. Degenerative disease of the spinal cord: 1.036
# 5. Spondylosis without myelopathy: 1.027
# 6. Displacement of intervertebral disc: 1.005
# 7. Kyphoscoliosis and scoliosis: 0.983
# 8. Acquired spondylolisthesis: 0.981
# 9. Other and unspecified disc disorder: 0.959
# 10. Sciatica: 0.949
#
# Final top diseases:
# 1. Degenerative disease of the spinal cord: 2.119
# 2. Back pain: 2.113
# 3. Neuralgia, neuritis, and radiculitis NOS: 1.873
# 4. Displacement of intervertebral disc: 1.332
# 5. Sciatica: 0.964
# 6. Kyphoscoliosis and scoliosis: 0.809
# 7. Other and unspecified disc disorder: 0.799
# 8. Spondylosis without myelopathy: 0.760
# 9. Acquired spondylolisthesis: 0.386
# 10. Degeneration of intervertebral disc: 0.305
#
# Degenerative disease of the spinal cord changed from rank 4 to 1
#
# Thoracic or lumbosacral neuritis or radiculitis, unspecified changed from rank 3 to 12
#
# Sciatica changed from rank 10 to 5
#
# Spondylosis without myelopathy changed from rank 5 to 8
#
# Signature 10:
#
# Initial top diseases:
# 1. Macular degeneration (senile) of retina NOS: 1.142
# 2. Retinal vascular changes and abnomalities: 1.139
# 3. Primary open angle glaucoma: 1.110
# 4. Other retinal disorders: 1.079
# 5. Glaucoma: 0.998
# 6. Myopia: 0.972
# 7. Disorders of vitreous body: 0.966
# 8. Cataract: 0.942
# 9. Senile cataract: 0.930
# 10. Retinal detachments and defects: 0.810
#
# Final top diseases:
# 1. Disorders of vitreous body: 2.391
# 2. Primary open angle glaucoma: 2.351
# 3. Myopia: 0.818
# 4. Macular degeneration (senile) of retina NOS: 0.687
# 5. Senile cataract: 0.618
# 6. Other peripheral nerve disorders: 0.556
# 7. Other retinal disorders: 0.550
# 8. Excessive or frequent menstruation: 0.464
# 9. Glaucoma: 0.361
# 10. Retinal detachment with retinal defect: 0.319
#
# Other peripheral nerve disorders changed from rank 12 to 6
#
# Other retinal disorders changed from rank 4 to 7
#
# Macular degeneration (senile) of retina NOS changed from rank 1 to 4
#
# Retinal vascular changes and abnomalities changed from rank 2 to 12
#
# Glaucoma changed from rank 5 to 9
#
# Cataract changed from rank 8 to 12
#
# Senile cataract changed from rank 9 to 5
#
# Myopia changed from rank 6 to 3
#
# Excessive or frequent menstruation changed from rank 12 to 8
#
# Disorders of vitreous body changed from rank 7 to 1
#
# Signature 11:
#
# Initial top diseases:
# 1. Hemiplegia: 1.141
# 2. Occlusion of cerebral arteries: 1.061
# 3. Late effects of cerebrovascular disease: 1.040
# 4. Cerebral ischemia: 1.024
# 5. Cerebrovascular disease: 0.997
# 6. Transient cerebral ischemia: 0.912
# 7. Cerebral artery occlusion, with cerebral infarction: 0.900
# 8. Occlusion and stenosis of precerebral arteries: 0.753
# 9. Anxiety disorder: -1.948
# 10. Myocardial infarction: -1.948
#
# Final top diseases:
# 1. Cerebrovascular disease: 2.426
# 2. Occlusion of cerebral arteries: 2.181
# 3. Hemiplegia: 1.964
# 4. Late effects of cerebrovascular disease: 0.961
# 5. Cerebral ischemia: 0.451
# 6. Cerebral artery occlusion, with cerebral infarction: 0.217
# 7. Hyperpotassemia: -0.009
# 8. Occlusion and stenosis of precerebral arteries: -0.013
# 9. Hallux valgus (Bunion): -0.069
# 10. Other tests: -0.084
#
# Hallux valgus (Bunion) changed from rank 12 to 9
#
# Anxiety disorder changed from rank 9 to 12
#
# Cerebrovascular disease changed from rank 5 to 1
#
# Transient cerebral ischemia changed from rank 6 to 12
#
# Hyperpotassemia changed from rank 12 to 7
#
# Signature 12:
#
# Initial top diseases:
# 1. Renal colic: 1.201
# 2. Calculus of ureter: 1.122
# 3. Stricture/obstruction of ureter: 1.094
# 4. Other disorders of the kidney and ureters: 0.988
# 5. Hydronephrosis: 0.987
# 6. Pyelonephritis: 0.921
# 7. Calculus of kidney: 0.823
# 8. Atrial fibrillation and flutter: -1.946
# 9. Chronic tonsillitis and adenoiditis: -1.949
# 10. Back pain: -1.949
#
# Final top diseases:
# 1. Stricture/obstruction of ureter: 2.080
# 2. Calculus of ureter: 1.846
# 3. Other disorders of the kidney and ureters: 1.429
# 4. Renal colic: 1.059
# 5. Hydronephrosis: 0.817
# 6. Pyelonephritis: 0.703
# 7. Postmenopausal atrophic vaginitis: 0.583
# 8. Noninflammatory disorders of cervix: 0.252
# 9. Calculus of kidney: 0.106
# 10. Obstructive chronic bronchitis: -0.003
#
# Noninflammatory disorders of cervix changed from rank 12 to 8
#
# Chronic tonsillitis and adenoiditis changed from rank 9 to 12
#
# Postmenopausal atrophic vaginitis changed from rank 12 to 7
#
# Renal colic changed from rank 1 to 4
#
# Atrial fibrillation and flutter changed from rank 8 to 12
#
# Signature 13:
#
# Initial top diseases:
# 1. Cystitis: 1.131
# 2. Urethral stricture (not specified as infectious): 1.115
# 3. Cancer of prostate: 1.103
# 4. Malignant neoplasm of bladder: 1.040
# 5. Other disorders of bladder: 0.978
# 6. Urinary incontinence: 0.965
# 7. Other symptoms/disorders or the urinary system: 0.961
# 8. Functional disorders of bladder: 0.949
# 9. Hyperplasia of prostate: 0.931
# 10. Chronic prostatitis: 0.914
#
# Final top diseases:
# 1. Malignant neoplasm of bladder: 2.486
# 2. Bladder neck obstruction: 1.704
# 3. Other disorders of bladder: 1.048
# 4. Cancer of prostate: 1.043
# 5. Other disorders of prostate: 0.939
# 6. Chronic cystitis: 0.872
# 7. Functional disorders of bladder: 0.699
# 8. Urinary incontinence: 0.488
# 9. Urethral stricture (not specified as infectious): 0.430
# 10. Chronic prostatitis: 0.428
#
# Malignant neoplasm of bladder changed from rank 4 to 1
#
# Cystitis changed from rank 1 to 12
#
# Chronic cystitis changed from rank 12 to 6
#
# Bladder neck obstruction changed from rank 12 to 2
#
# Urethral stricture (not specified as infectious) changed from rank 2 to 9
#
# Other symptoms/disorders or the urinary system changed from rank 7 to 12
#
# Hyperplasia of prostate changed from rank 9 to 12
#
# Other disorders of prostate changed from rank 12 to 5
#
# Signature 14:
#
# Initial top diseases:
# 1. Emphysema: 1.115
# 2. Pneumonia: 1.073
# 3. Bronchiectasis: 1.064
# 4. Empyema and pneumothorax: 1.056
# 5. Pneumococcal pneumonia: 0.948
# 6. Postinflammatory pulmonary fibrosis: 0.905
# 7. Tobacco use disorder: 0.894
# 8. Chronic airway obstruction: 0.847
# 9. Respiratory failure: 0.787
# 10. Obstructive chronic bronchitis: 0.782
#
# Final top diseases:
# 1. Pneumococcal pneumonia: 2.353
# 2. Postinflammatory pulmonary fibrosis: 2.072
# 3. Pneumonia: 1.463
# 4. Chronic airway obstruction: 1.439
# 5. Empyema and pneumothorax: 1.387
# 6. Bronchiectasis: 1.381
# 7. Emphysema: 1.028
# 8. Respiratory failure: 0.955
# 9. Tobacco use disorder: 0.518
# 10. Obstructive chronic bronchitis: 0.487
#
# Pneumococcal pneumonia changed from rank 5 to 1
#
# Chronic airway obstruction changed from rank 8 to 4
#
# Emphysema changed from rank 1 to 7
#
# Bronchiectasis changed from rank 3 to 6
#
# Postinflammatory pulmonary fibrosis changed from rank 6 to 2
#
# Signature 15:
#
# Initial top diseases:
# 1. Hypoglycemia: 1.133
# 2. Type 1 diabetes: 1.088
# 3. Type 2 diabetes with ophthalmic manifestations: 1.033
# 4. Diabetic retinopathy: 0.932
# 5. Type 2 diabetes: 0.915
# 6. Disorders of calcium/phosphorus metabolism: -1.946
# 7. Urethral stricture (not specified as infectious): -1.948
# 8. Peritonitis and retroperitoneal infections: -1.949
# 9. Sleep apnea: -1.950
# 10. Calculus of kidney: -1.951
#
# Final top diseases:
# 1. Hypoglycemia: 1.360
# 2. Type 2 diabetes with ophthalmic manifestations: 1.309
# 3. Diabetic retinopathy: 0.882
# 4. Type 1 diabetes: 0.740
# 5. Type 2 diabetes: 0.329
# 6. Alcoholic liver damage: 0.196
# 7. Cardiac arrest: 0.068
# 8. Inflammation of eyelids: -0.043
# 9. Tobacco use disorder: -0.132
# 10. Chronic cystitis: -0.217
#
# Cardiac arrest changed from rank 12 to 7
#
# Alcoholic liver damage changed from rank 12 to 6
#
# Tobacco use disorder changed from rank 12 to 9
#
# Sleep apnea changed from rank 9 to 12
#
# Peritonitis and retroperitoneal infections changed from rank 8 to 12
#
# Inflammation of eyelids changed from rank 12 to 8
#
# Disorders of calcium/phosphorus metabolism changed from rank 6 to 12
#
# Urethral stricture (not specified as infectious) changed from rank 7 to 12
#
# Signature 16:
#
# Initial top diseases:
# 1. Other diseases of respiratory system, NEC: 1.136
# 2. Peritonitis and retroperitoneal infections: 1.133
# 3. Hypopotassemia: 1.106
# 4. Chronic ulcer of skin: 1.084
# 5. Disorders of calcium/phosphorus metabolism: 1.028
# 6. Orthostatic hypotension: 1.027
# 7. Hypotension NOS: 1.026
# 8. E. coli: 1.020
# 9. Urinary tract infection: 1.019
# 10. Acute renal failure: 1.011
#
# Final top diseases:
# 1. Thrombocytopenia: 3.078
# 2. Hypopotassemia: 2.675
# 3. Bacterial infection NOS: 2.355
# 4. Peritonitis and retroperitoneal infections: 2.109
# 5. Other anemias: 2.010
# 6. Other diseases of respiratory system, NEC: 1.925
# 7. Acidosis: 1.817
# 8. Cellulitis and abscess of arm/hand: 1.684
# 9. Hypovolemia: 1.601
# 10. Orthostatic hypotension: 1.392
#
# Bacterial infection NOS changed from rank 12 to 3
#
# E. coli changed from rank 8 to 12
#
# Orthostatic hypotension changed from rank 6 to 10
#
# Hypotension NOS changed from rank 7 to 12
#
# Cellulitis and abscess of arm/hand changed from rank 12 to 8
#
# Chronic ulcer of skin changed from rank 4 to 12
#
# Other diseases of respiratory system, NEC changed from rank 1 to 6
#
# Urinary tract infection changed from rank 9 to 12
#
# Disorders of calcium/phosphorus metabolism changed from rank 5 to 12
#
# Acidosis changed from rank 12 to 7
#
# Hypovolemia changed from rank 12 to 9
#
# Other anemias changed from rank 12 to 5
#
# Thrombocytopenia changed from rank 12 to 1
#
# Signature 17:
#
# Initial top diseases:
# 1. Regional enteritis: 1.170
# 2. Ventral hernia: 1.142
# 3. Benign neoplasm of colon: 1.107
# 4. Hemorrhoids: 1.096
# 5. Hemorrhage of gastrointestinal tract: 1.084
# 6. Hemorrhage of rectum and anus: 1.072
# 7. Other intestinal obstruction: 1.024
# 8. Diverticulosis: 1.018
# 9. Neoplasm of unspecified nature of digestive system: 1.011
# 10. Noninfectious gastroenteritis: 1.002
#
# Final top diseases:
# 1. Colon cancer: 2.534
# 2. Benign neoplasm of colon: 1.980
# 3. Anal and rectal polyp: 1.436
# 4. Hemorrhage of rectum and anus: 1.400
# 5. Other intestinal obstruction: 1.083
# 6. Hemorrhoids: 1.018
# 7. Ventral hernia: 0.720
# 8. Hemorrhage of gastrointestinal tract: 0.683
# 9. Regional enteritis: 0.673
# 10. Anal and rectal conditions: 0.610
#
# Ventral hernia changed from rank 2 to 7
#
# Regional enteritis changed from rank 1 to 9
#
# Diverticulosis changed from rank 8 to 12
#
# Neoplasm of unspecified nature of digestive system changed from rank 9 to 12
#
# Colon cancer changed from rank 12 to 1
#
# Anal and rectal polyp changed from rank 12 to 3
#
# Hemorrhage of gastrointestinal tract changed from rank 5 to 8
#
# Signature 18:
#
# Initial top diseases:
# 1. Other disorders of gallbladder: 1.151
# 2. Other disorders of biliary tract: 1.031
# 3. Cholelithiasis with acute cholecystitis: 1.024
# 4. Acute pancreatitis: 1.021
# 5. Peritoneal adhesions (postoperative) (postinfection): 1.017
# 6. Cholelithiasis: 1.007
# 7. Calculus of bile duct: 0.981
# 8. Cholelithiasis with other cholecystitis: 0.925
# 9. Cholecystitis without cholelithiasis: 0.846
# 10. Atopic/contact dermatitis due to other or unspecified: -1.947
#
# Final top diseases:
# 1. Cholelithiasis with other cholecystitis: 2.141
# 2. Other disorders of biliary tract: 1.847
# 3. Cholelithiasis: 1.175
# 4. Acute pancreatitis: 1.151
# 5. Cholecystitis without cholelithiasis: 1.056
# 6. Peritoneal adhesions (postoperative) (postinfection): 0.549
# 7. Diseases and other conditions of the tongue: -0.075
# 8. Cholelithiasis with acute cholecystitis: -0.120
# 9. Hammer toe (acquired): -0.231
# 10. Disorders of uterus, NEC: -0.272
#
# Cholelithiasis changed from rank 6 to 3
#
# Cholelithiasis with acute cholecystitis changed from rank 3 to 8
#
# Cholelithiasis with other cholecystitis changed from rank 8 to 1
#
# Calculus of bile duct changed from rank 7 to 12
#
# Cholecystitis without cholelithiasis changed from rank 9 to 5
#
# Other disorders of gallbladder changed from rank 1 to 12
#
# Diseases and other conditions of the tongue changed from rank 12 to 7
#
# Hammer toe (acquired) changed from rank 12 to 9
#
# Signature 19:
#
# Initial top diseases:
# 1. Other disorders of eyelids: 1.203
# 2. Chronic glomerulonephritis, NOS: 1.189
# 3. Seborrheic keratosis: 1.183
# 4. Disorders of lacrimal system: 1.156
# 5. Thyrotoxicosis with or without goiter: 1.155
# 6. Other non-epithelial cancer of skin: 1.125
# 7. Hypertensive chronic kidney disease: 1.109
# 8. Viral warts & HPV: 1.068
# 9. Ectropion or entropion: 1.060
# 10. Lump or mass in breast: 1.025
#
# Final top diseases:
# 1. Disorder of skin and subcutaneous tissue NOS: 3.111
# 2. Other disorders of eyelids: 2.509
# 3. Seborrheic keratosis: 2.138
# 4. Epiphora: 2.039
# 5. Viral warts & HPV: 1.785
# 6. Other non-epithelial cancer of skin: 1.692
# 7. Hypertensive chronic kidney disease: 1.629
# 8. Scar conditions and fibrosis of skin: 1.604
# 9. Chronic glomerulonephritis, NOS: 1.603
# 10. Other hypertrophic and atrophic conditions of skin: 1.373
#
# Viral warts & HPV changed from rank 8 to 5
#
# Ectropion or entropion changed from rank 9 to 12
#
# Disorders of lacrimal system changed from rank 4 to 12
#
# Chronic glomerulonephritis, NOS changed from rank 2 to 9
#
# Scar conditions and fibrosis of skin changed from rank 12 to 8
#
# Epiphora changed from rank 12 to 4
#
# Disorder of skin and subcutaneous tissue NOS changed from rank 12 to 1
#
# Thyrotoxicosis with or without goiter changed from rank 5 to 12

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
disease_names=essentials['disease_names']
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,1,14,15,16,13,17])

# %%
Y_avg_global = torch.mean(torch.tensor(Y) if isinstance(Y,np.ndarray) else Y, dim=2)
Y_avg_batch = torch.mean(torch.tensor(Y_100k) if isinstance(Y_100k, np.ndarray) else Y_100k, dim=2)

# %%
def compare_disease_patterns(k, true_psi, Y_avg_global, Y_avg_batch):
    """Compare disease patterns between global and batch data"""
    strong_diseases = (true_psi[k] > 0)
    
    # Get mean pattern for each dataset (average across patients)
    pattern_large = Y_avg_global[:, strong_diseases].mean(dim=0)  # Average across all patients
    pattern_small = Y_avg_batch[:, strong_diseases].mean(dim=0)  # Average across batch patients
    
    # Now both patterns are just length of strong_diseases
    correlation = torch.corrcoef(
        torch.stack([pattern_large, pattern_small])
    )[0,1]
    
    print(f"Signature {k} pattern correlation: {correlation:.3f}")
    print(f"Mean pattern difference: {(pattern_large - pattern_small).abs().mean():.3f}")

# Now use it
print("Comparing disease sharing patterns between global and batch data:")
for k in range(model.K):
    print(f"\nSignature {k}:")
    compare_disease_patterns(k, model.psi, Y_avg_global, Y_avg_batch)
# Out:
# Comparing disease sharing patterns between global and batch data:
#
# Signature 0:
# Signature 0 pattern correlation: 0.993
# Mean pattern difference: 0.000
#
# Signature 1:
# Signature 1 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 2:
# Signature 2 pattern correlation: 0.996
# Mean pattern difference: 0.000
#
# Signature 3:
# Signature 3 pattern correlation: 0.987
# Mean pattern difference: 0.000
#
# Signature 4:
# Signature 4 pattern correlation: 0.998
# Mean pattern difference: 0.000
#
# Signature 5:
# Signature 5 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 6:
# Signature 6 pattern correlation: 0.998
# Mean pattern difference: 0.000
#
# Signature 7:
# Signature 7 pattern correlation: 0.999
# Mean pattern difference: 0.000
#
# Signature 8:
# Signature 8 pattern correlation: 0.986
# Mean pattern difference: 0.000
#
# Signature 9:
# Signature 9 pattern correlation: 0.993
# Mean pattern difference: 0.000
#
# Signature 10:
# Signature 10 pattern correlation: 1.000
# Mean pattern difference: 0.000
#
# Signature 11:
# Signature 11 pattern correlation: 0.972
# Mean pattern difference: 0.000
#
# Signature 12:
# Signature 12 pattern correlation: 0.919
# Mean pattern difference: 0.000
#
# Signature 13:
# Signature 13 pattern correlation: 0.997
# Mean pattern difference: 0.000
#
# Signature 14:
# Signature 14 pattern correlation: 0.998
# Mean pattern difference: 0.000
#
# Signature 15:
# Signature 15 pattern correlation: 1.000
# Mean pattern difference: 0.000
#
# Signature 16:
# Signature 16 pattern correlation: 0.996
# Mean pattern difference: 0.000
#
# Signature 17:
# Signature 17 pattern correlation: 0.998
# Mean pattern difference: 0.000
#
# Signature 18:
# Signature 18 pattern correlation: 0.996
# Mean pattern difference: 0.000
#
# Signature 19:
# Signature 19 pattern correlation: 0.991
# Mean pattern difference: 0.000
