# %%
# %load_ext autoreload
# %autoreload 2

from cluster_g_logit_init_acceptpsi import *


# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.spatial.distance import pdist, squareform
from scipy.special import expit
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering  # Add this import

def load_model_essentials(base_path='/Users/sarahurbut/Dropbox (Personal)/data_for_running/'):
    """
    Load all essential components
    """
    print("Loading components...")
    
    # Load large matrices
    Y = torch.load(base_path + 'Y_tensor.pt')
    E = torch.load(base_path + 'E_matrix.pt')
    G = torch.load(base_path + 'G_matrix.pt')
    
    # Load other components
    essentials = torch.load(base_path + 'model_essentials.pt')
    
    print("Loaded all components successfully!")
    
    return Y, E, G, essentials

# Load and initialize model:
Y, E, G, essentials = load_model_essentials()
# Out:
# Loading components...
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_51226/1069408875.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Y = torch.load(base_path + 'Y_tensor.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_51226/1069408875.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   E = torch.load(base_path + 'E_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_51226/1069408875.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G = torch.load(base_path + 'G_matrix.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_51226/1069408875.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   essentials = torch.load(base_path + 'model_essentials.pt')
# Loaded all components successfully!

# %%
def subset_data(Y, E, G, n_samples=50000, seed=42):
    """
    Subset the data to n_samples individuals while maintaining consistency
    
    Args:
        Y: tensor of shape [N, D, T]
        E: tensor of shape [N, D]
        G: tensor of shape [N, P]
        n_samples: number of individuals to keep
        seed: random seed for reproducibility
    
    Returns:
        Y_sub, E_sub, G_sub: subsetted tensors
    """
    torch.manual_seed(seed)
    
    # Get total number of individuals
    N = Y.shape[0]
    
    # Randomly select n_samples indices
    indices = torch.randperm(N)[:n_samples]
    
    # Subset all matrices using the same indices
    Y_sub = Y[indices]
    E_sub = E[indices]
    G_sub = G[indices]
    
    print(f"Original shapes: Y={Y.shape}, E={E.shape}, G={G.shape}")
    print(f"New shapes: Y={Y_sub.shape}, E={E_sub.shape}, G={G_sub.shape}")
    
    return Y_sub, E_sub, G_sub, indices

# Subset the data
Y_100k, E_100k, G_100k, indices = subset_data(Y, E, G, n_samples=10000,seed=1)

torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Initialize model with subsetted data
# Out:
# Original shapes: Y=torch.Size([407878, 348, 52]), E=torch.Size([407878, 348]), G=torch.Size([407878, 36])
# New shapes: Y=torch.Size([10000, 348, 52]), E=torch.Size([10000, 348]), G=torch.Size([10000, 36])

# %%
# When initializing the model:
original_G = G_100k.clone().detach()  # Store the original G - proper tensor copy

# Now in your batch run, load and verify:
initial_psi = torch.load('initial_psi_400k.pt')
initial_clusters = torch.load('initial_clusters_400k.pt')

original_cluster_sizes = {}
unique, counts = np.unique(initial_clusters, return_counts=True)
for k, count in zip(unique, counts):
    original_cluster_sizes[k] = count
print("\nOriginal cluster sizes:")
for k, count in original_cluster_sizes.items():
    print(f"Cluster {k}: {count} diseases")
# Out:
# Original cluster sizes:
# Cluster 0: 16 diseases
# Cluster 1: 21 diseases
# Cluster 2: 15 diseases
# Cluster 3: 82 diseases
# Cluster 4: 5 diseases
# Cluster 5: 7 diseases
# Cluster 6: 8 diseases
# Cluster 7: 22 diseases
# Cluster 8: 28 diseases
# Cluster 9: 12 diseases
# Cluster 10: 11 diseases
# Cluster 11: 8 diseases
# Cluster 12: 7 diseases
# Cluster 13: 13 diseases
# Cluster 14: 10 diseases
# Cluster 15: 5 diseases
# Cluster 16: 29 diseases
# Cluster 17: 17 diseases
# Cluster 18: 9 diseases
# Cluster 19: 23 diseases
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_51226/685643090.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_psi = torch.load('initial_psi_400k.pt')
# /var/folders/2f/nxrbr3pn1msgrl4ffyj33zd00000gn/T/ipykernel_51226/685643090.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   initial_clusters = torch.load('initial_clusters_400k.pt')

# %%
print("Initial psi stats:")
print(f"Shape: {initial_psi.shape}")
print(f"Range: [{initial_psi.min():.2f}, {initial_psi.max():.2f}]")
print(f"Number of positive values: {(initial_psi > 0).sum().item()}")
# Out:
# Initial psi stats:
# Shape: torch.Size([20, 348])
# Range: [-2.04, 1.33]
# Number of positive values: 348

# %%
torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = AladynSurvivalFixedKernelsAvgLoss_clust_logitInit_psitest(
    N=Y_100k.shape[0],
    D=Y_100k.shape[1],
    T=Y_100k.shape[2],
    K=essentials['K'],
    P=essentials['P'],
    G=G_100k,
    Y=Y_100k,
    prevalence_t=essentials['prevalence_t']
)

# Initialize and train
model.initialize_params(true_psi=initial_psi)
model.clusters = initial_clusters
clusters_match = np.array_equal(initial_clusters, model.clusters)
print(f"\nClusters match exactly: {clusters_match}")
# Out:
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.G = torch.tensor(G_scaled, dtype=torch.float32)
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.Y = torch.tensor(Y, dtype=torch.float32)
# Lambda kernel condition number: 56314924.00
# Phi kernel condition number: 59684776.00
#
# Cluster Sizes:
# Cluster 0: 11 diseases
# Cluster 1: 6 diseases
# Cluster 2: 13 diseases
# Cluster 3: 97 diseases
# Cluster 4: 22 diseases
# Cluster 5: 22 diseases
# Cluster 6: 15 diseases
# Cluster 7: 17 diseases
# Cluster 8: 35 diseases
# Cluster 9: 6 diseases
# Cluster 10: 13 diseases
# Cluster 11: 9 diseases
# Cluster 12: 11 diseases
# Cluster 13: 6 diseases
# Cluster 14: 17 diseases
# Cluster 15: 5 diseases
# Cluster 16: 15 diseases
# Cluster 17: 8 diseases
# Cluster 18: 17 diseases
# Cluster 19: 3 diseases
# Initialization complete!
#
# Using true psi from simulation
# Initialization complete!
#
# Clusters match exactly: True

# %%
model.phi[1,1,:]
# Out:
# tensor([-13.3536, -13.3847, -13.3609, -13.2947, -13.1985, -13.0819, -12.9570,
#         -12.8368, -12.7224, -12.6231, -12.5360, -12.4614, -12.3976, -12.3397,
#         -12.2819, -12.2289, -12.1717, -12.1157, -12.0542, -11.9904, -11.9242,
#         -11.8547, -11.7801, -11.7081, -11.6286, -11.5523, -11.4756, -11.3966,
#         -11.3185, -11.2424, -11.1665, -11.0922, -11.0137, -10.9377, -10.8639,
#         -10.7871, -10.7146, -10.6440, -10.5761, -10.5175, -10.4630, -10.4224,
#         -10.3956, -10.3801, -10.3754, -10.3802, -10.3969, -10.4189, -10.4377,
#         -10.4556, -10.4664, -10.4657], grad_fn=<SliceBackward0>)

# %%
# Plot both versions:
model.plot_genetic_scores(original_G)
print(model.G[:,3].mean())

print(original_G[:,3].mean())


# Check G matrix scaling
G_mean = model.G.mean(dim=0)
G_std = model.G.std(dim=0)
print("\nG matrix scaling check:")
print(f"Mean should be ~0: {G_mean.abs().max().item():.6f}")
print(f"Std should be ~1: {(G_std - 1).abs().max().item():.6f}")
do
# Out:
# Genetic Components Summary Statistics:
# Component  Original Mean Original Std  Trans. Mean  Trans. Std
# ------------------------------------------------------------
# 1                 -0.007        1.004       -0.000       1.000
# 2                 -0.001        1.011       -0.000       1.000
# 3                  0.018        1.005       -0.000       1.000
# 4                  0.009        0.977       -0.000       1.000
# 5                  0.000        1.005        0.000       1.000
# 6                 -0.013        1.007        0.000       1.000
# 7                  0.012        1.001       -0.000       1.000
# 8                  0.012        1.001       -0.000       1.000
# 9                  0.017        1.006        0.000       1.000
# 10                 0.010        1.001        0.000       1.000
# 11                 0.013        1.002       -0.000       1.000
# 12                 0.005        0.998        0.000       1.000
# 13                -0.001        0.998        0.000       1.000
# 14                -0.018        0.999        0.000       1.000
# 15                -0.009        1.002       -0.000       1.000
# 16                 0.001        1.013        0.000       1.000
# 17                -0.002        1.000       -0.000       1.000
# 18                -0.009        0.995        0.000       1.000
# 19                 0.026        0.997        0.000       1.000
# 20                -0.010        1.009       -0.000       1.000
# 21                 0.012        0.992       -0.000       1.000
# 22                 0.018        1.000       -0.000       1.000
# 23                 0.002        1.005       -0.000       1.000
# 24                 0.012        1.012       -0.000       1.000
# 25                -0.002        0.997        0.000       1.000
# 26                -0.011        1.001        0.000       1.000
# 27                 0.012        0.990        0.000       1.000
# 28                 0.015        0.997       -0.000       1.000
# 29                -0.005        0.994       -0.000       1.000
# 30                 0.010        1.006        0.000       1.000
# 31                 0.013        1.003        0.000       1.000
# 32                 0.006        0.996       -0.000       1.000
# 33                 0.010        1.004       -0.000       1.000
# 34                 0.029        0.998        0.000       1.000
# 35                -0.003        1.013       -0.000       1.000
# 36                 0.026        1.000        0.000       1.000
# tensor(-3.8147e-09)
# tensor(0.0093)
#
# G matrix scaling check:
# Mean should be ~0: 0.000000
# Std should be ~1: 0.000000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      12 print(f"Mean should be ~0: {G_mean.abs().max().item():.6f}")
#      13 print(f"Std should be ~1: {(G_std - 1).abs().max().item():.6f}")
# ---> 14 do
#
# NameError: name 'do' is not defined

# %%
initial_gamma = model.gamma.detach().clone()
initial_phi = model.phi.detach().clone()
initial_lambda = model.lambda_.detach().clone()
initial_psi = model.psi.detach().clone()

# %%
history_new = model.fit(E_100k, num_epochs=100, learning_rate=3e-3, lambda_reg=1e-2)
# Out:
# Starting training...
# /Users/sarahurbut/aladynoulli/pyScripts/cluster_g_logit_init_acceptpsi.py:209: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   event_times_tensor = torch.tensor(event_times, dtype=torch.long)
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 0
# Loss: 1107.0975
# Psi gradient stats:
# Mean: 6.3960e-05
# Std:  4.7301e-03
# Max:  1.6373e-02
# Min:  -2.1012e-02
# Epoch 0, Loss: 1107.0975, Gradients - Lambda: 5.410e-01, Phi: 1.418e+01, Gamma: 5.045e-02, Psi: 2.101e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 1
# Loss: 6705.5615
# Psi gradient stats:
# Mean: 6.8615e-05
# Std:  4.8029e-03
# Max:  1.6804e-02
# Min:  -2.0364e-02
# Epoch 1, Loss: 6705.5615, Gradients - Lambda: 1.190e+00, Phi: 2.576e+01, Gamma: 4.593e-02, Psi: 2.036e-02
#
# Estimated total training time: 53.5 minutes
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 2
# Loss: 1568.6649
# Psi gradient stats:
# Mean: 5.6542e-05
# Std:  4.6355e-03
# Max:  1.6424e-02
# Min:  -2.0537e-02
# Epoch 2, Loss: 1568.6649, Gradients - Lambda: 7.922e-01, Phi: 1.659e+01, Gamma: 3.952e-02, Psi: 2.054e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 3
# Loss: 1661.0168
# Psi gradient stats:
# Mean: 5.2633e-05
# Std:  4.5926e-03
# Max:  1.5906e-02
# Min:  -2.0882e-02
# Epoch 3, Loss: 1661.0168, Gradients - Lambda: 7.759e-01, Phi: 1.679e+01, Gamma: 2.909e-02, Psi: 2.088e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 4
# Loss: 3283.9204
# Psi gradient stats:
# Mean: 5.7861e-05
# Std:  4.5604e-03
# Max:  1.5954e-02
# Min:  -2.0637e-02
# Epoch 4, Loss: 3283.9204, Gradients - Lambda: 8.137e-01, Phi: 1.757e+01, Gamma: 2.503e-02, Psi: 2.064e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 5
# Loss: 2574.3794
# Psi gradient stats:
# Mean: 6.7248e-05
# Std:  4.4933e-03
# Max:  1.5820e-02
# Min:  -2.0350e-02
# Epoch 5, Loss: 2574.3794, Gradients - Lambda: 6.919e-01, Phi: 1.508e+01, Gamma: 2.416e-02, Psi: 2.035e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 6
# Loss: 1185.8787
# Psi gradient stats:
# Mean: 7.3813e-05
# Std:  4.4390e-03
# Max:  1.5615e-02
# Min:  -2.0200e-02
# Epoch 6, Loss: 1185.8787, Gradients - Lambda: 6.376e-01, Phi: 1.403e+01, Gamma: 2.367e-02, Psi: 2.020e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 7
# Loss: 845.1955
# Psi gradient stats:
# Mean: 7.6608e-05
# Std:  4.4272e-03
# Max:  1.5818e-02
# Min:  -2.0211e-02
# Epoch 7, Loss: 845.1955, Gradients - Lambda: 7.178e-01, Phi: 1.638e+01, Gamma: 2.385e-02, Psi: 2.021e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 8
# Loss: 1395.9614
# Psi gradient stats:
# Mean: 7.6985e-05
# Std:  4.4380e-03
# Max:  1.5753e-02
# Min:  -2.0383e-02
# Epoch 8, Loss: 1395.9614, Gradients - Lambda: 6.686e-01, Phi: 1.574e+01, Gamma: 2.331e-02, Psi: 2.038e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 9
# Loss: 1679.9834
# Psi gradient stats:
# Mean: 7.6603e-05
# Std:  4.4367e-03
# Max:  1.5629e-02
# Min:  -2.0608e-02
# Epoch 9, Loss: 1679.9834, Gradients - Lambda: 5.984e-01, Phi: 1.394e+01, Gamma: 2.121e-02, Psi: 2.061e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 10
# Loss: 1314.0933
# Psi gradient stats:
# Mean: 7.6405e-05
# Std:  4.4147e-03
# Max:  1.5647e-02
# Min:  -2.0818e-02
# Epoch 10, Loss: 1314.0933, Gradients - Lambda: 5.163e-01, Phi: 1.178e+01, Gamma: 1.949e-02, Psi: 2.082e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 11
# Loss: 811.6379
# Psi gradient stats:
# Mean: 7.6480e-05
# Std:  4.3855e-03
# Max:  1.5772e-02
# Min:  -2.0963e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 12
# Loss: 664.0497
# Psi gradient stats:
# Mean: 7.6544e-05
# Std:  4.3615e-03
# Max:  1.5831e-02
# Min:  -2.0994e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 13
# Loss: 831.1687
# Psi gradient stats:
# Mean: 7.6060e-05
# Std:  4.3431e-03
# Max:  1.5825e-02
# Min:  -2.0888e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 14
# Loss: 958.8903
# Psi gradient stats:
# Mean: 7.4971e-05
# Std:  4.3236e-03
# Max:  1.5805e-02
# Min:  -2.0698e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 15
# Loss: 858.8438
# Psi gradient stats:
# Mean: 7.3463e-05
# Std:  4.3003e-03
# Max:  1.5747e-02
# Min:  -2.0514e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 16
# Loss: 649.5207
# Psi gradient stats:
# Mean: 7.1779e-05
# Std:  4.2759e-03
# Max:  1.5658e-02
# Min:  -2.0392e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 17
# Loss: 528.9350
# Psi gradient stats:
# Mean: 7.0121e-05
# Std:  4.2545e-03
# Max:  1.5599e-02
# Min:  -2.0340e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 18
# Loss: 544.9637
# Psi gradient stats:
# Mean: 6.8739e-05
# Std:  4.2361e-03
# Max:  1.5512e-02
# Min:  -2.0333e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 19
# Loss: 595.3019
# Psi gradient stats:
# Mean: 6.7798e-05
# Std:  4.2185e-03
# Max:  1.5393e-02
# Min:  -2.0352e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 20
# Loss: 581.0839
# Psi gradient stats:
# Mean: 6.7222e-05
# Std:  4.2000e-03
# Max:  1.5241e-02
# Min:  -2.0363e-02
# Epoch 20, Loss: 581.0839, Gradients - Lambda: 3.113e-01, Phi: 7.320e+00, Gamma: 1.378e-02, Psi: 2.036e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 21
# Loss: 506.3257
# Psi gradient stats:
# Mean: 6.6698e-05
# Std:  4.1815e-03
# Max:  1.5089e-02
# Min:  -2.0347e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 22
# Loss: 438.8599
# Psi gradient stats:
# Mean: 6.5836e-05
# Std:  4.1647e-03
# Max:  1.5103e-02
# Min:  -2.0288e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 23
# Loss: 418.8220
# Psi gradient stats:
# Mean: 6.4386e-05
# Std:  4.1499e-03
# Max:  1.5071e-02
# Min:  -2.0191e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 24
# Loss: 426.1900
# Psi gradient stats:
# Mean: 6.2441e-05
# Std:  4.1354e-03
# Max:  1.4979e-02
# Min:  -2.0083e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 25
# Loss: 421.4475
# Psi gradient stats:
# Mean: 6.0542e-05
# Std:  4.1198e-03
# Max:  1.5092e-02
# Min:  -2.0006e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 26
# Loss: 393.2496
# Psi gradient stats:
# Mean: 5.9279e-05
# Std:  4.1025e-03
# Max:  1.5211e-02
# Min:  -1.9983e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 27
# Loss: 360.9365
# Psi gradient stats:
# Mean: 5.8978e-05
# Std:  4.0842e-03
# Max:  1.5281e-02
# Min:  -2.0007e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 28
# Loss: 343.7320
# Psi gradient stats:
# Mean: 5.9623e-05
# Std:  4.0655e-03
# Max:  1.5257e-02
# Min:  -2.0052e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 29
# Loss: 340.0428
# Psi gradient stats:
# Mean: 6.0960e-05
# Std:  4.0466e-03
# Max:  1.5137e-02
# Min:  -2.0094e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 30
# Loss: 335.6089
# Psi gradient stats:
# Mean: 6.2524e-05
# Std:  4.0272e-03
# Max:  1.4962e-02
# Min:  -2.0116e-02
# Epoch 30, Loss: 335.6089, Gradients - Lambda: 1.899e-01, Phi: 4.564e+00, Gamma: 8.498e-03, Psi: 2.012e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 31
# Loss: 322.7037
# Psi gradient stats:
# Mean: 6.3836e-05
# Std:  4.0076e-03
# Max:  1.4797e-02
# Min:  -2.0100e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 32
# Loss: 306.3116
# Psi gradient stats:
# Mean: 6.4569e-05
# Std:  3.9883e-03
# Max:  1.4696e-02
# Min:  -2.0032e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 33
# Loss: 294.6690
# Psi gradient stats:
# Mean: 6.4627e-05
# Std:  3.9701e-03
# Max:  1.4715e-02
# Min:  -1.9916e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 34
# Loss: 289.2463
# Psi gradient stats:
# Mean: 6.4266e-05
# Std:  3.9528e-03
# Max:  1.4801e-02
# Min:  -1.9786e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 35
# Loss: 285.1946
# Psi gradient stats:
# Mean: 6.3800e-05
# Std:  3.9362e-03
# Max:  1.4856e-02
# Min:  -1.9686e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 36
# Loss: 278.5939
# Psi gradient stats:
# Mean: 6.3466e-05
# Std:  3.9199e-03
# Max:  1.4937e-02
# Min:  -1.9649e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 37
# Loss: 270.3729
# Psi gradient stats:
# Mean: 6.3224e-05
# Std:  3.9037e-03
# Max:  1.4976e-02
# Min:  -1.9679e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 38
# Loss: 263.5983
# Psi gradient stats:
# Mean: 6.3067e-05
# Std:  3.8877e-03
# Max:  1.4957e-02
# Min:  -1.9756e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 39
# Loss: 259.2582
# Psi gradient stats:
# Mean: 6.2924e-05
# Std:  3.8719e-03
# Max:  1.4895e-02
# Min:  -1.9850e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 40
# Loss: 255.7735
# Psi gradient stats:
# Mean: 6.2799e-05
# Std:  3.8562e-03
# Max:  1.4821e-02
# Min:  -1.9917e-02
# Epoch 40, Loss: 255.7735, Gradients - Lambda: 1.209e-01, Phi: 2.962e+00, Gamma: 6.722e-03, Psi: 1.992e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 41
# Loss: 251.6102
# Psi gradient stats:
# Mean: 6.2700e-05
# Std:  3.8406e-03
# Max:  1.4765e-02
# Min:  -1.9921e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 42
# Loss: 247.0138
# Psi gradient stats:
# Mean: 6.2556e-05
# Std:  3.8247e-03
# Max:  1.4741e-02
# Min:  -1.9849e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 43
# Loss: 243.1026
# Psi gradient stats:
# Mean: 6.2173e-05
# Std:  3.8087e-03
# Max:  1.4740e-02
# Min:  -1.9727e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 44
# Loss: 240.2153
# Psi gradient stats:
# Mean: 6.1431e-05
# Std:  3.7926e-03
# Max:  1.4743e-02
# Min:  -1.9598e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 45
# Loss: 237.7117
# Psi gradient stats:
# Mean: 6.0415e-05
# Std:  3.7765e-03
# Max:  1.4730e-02
# Min:  -1.9496e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 46
# Loss: 235.0231
# Psi gradient stats:
# Mean: 5.9474e-05
# Std:  3.7605e-03
# Max:  1.4695e-02
# Min:  -1.9439e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 47
# Loss: 232.2915
# Psi gradient stats:
# Mean: 5.8782e-05
# Std:  3.7447e-03
# Max:  1.4644e-02
# Min:  -1.9426e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 48
# Loss: 229.9509
# Psi gradient stats:
# Mean: 5.8361e-05
# Std:  3.7292e-03
# Max:  1.4589e-02
# Min:  -1.9449e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 49
# Loss: 228.0784
# Psi gradient stats:
# Mean: 5.8059e-05
# Std:  3.7139e-03
# Max:  1.4545e-02
# Min:  -1.9486e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 50
# Loss: 226.3866
# Psi gradient stats:
# Mean: 5.7818e-05
# Std:  3.6988e-03
# Max:  1.4515e-02
# Min:  -1.9504e-02
# Epoch 50, Loss: 226.3866, Gradients - Lambda: 7.727e-02, Phi: 1.914e+00, Gamma: 4.516e-03, Psi: 1.950e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 51
# Loss: 224.6559
# Psi gradient stats:
# Mean: 5.7552e-05
# Std:  3.6837e-03
# Max:  1.4500e-02
# Min:  -1.9485e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 52
# Loss: 222.9610
# Psi gradient stats:
# Mean: 5.7273e-05
# Std:  3.6683e-03
# Max:  1.4492e-02
# Min:  -1.9430e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 53
# Loss: 221.4749
# Psi gradient stats:
# Mean: 5.6998e-05
# Std:  3.6526e-03
# Max:  1.4482e-02
# Min:  -1.9355e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 54
# Loss: 220.2169
# Psi gradient stats:
# Mean: 5.6792e-05
# Std:  3.6366e-03
# Max:  1.4462e-02
# Min:  -1.9280e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 55
# Loss: 219.0616
# Psi gradient stats:
# Mean: 5.6733e-05
# Std:  3.6206e-03
# Max:  1.4429e-02
# Min:  -1.9221e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 56
# Loss: 217.9198
# Psi gradient stats:
# Mean: 5.6875e-05
# Std:  3.6048e-03
# Max:  1.4382e-02
# Min:  -1.9190e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 57
# Loss: 216.8315
# Psi gradient stats:
# Mean: 5.7116e-05
# Std:  3.5892e-03
# Max:  1.4327e-02
# Min:  -1.9184e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 58
# Loss: 215.8641
# Psi gradient stats:
# Mean: 5.7252e-05
# Std:  3.5740e-03
# Max:  1.4304e-02
# Min:  -1.9185e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 59
# Loss: 215.0027
# Psi gradient stats:
# Mean: 5.7186e-05
# Std:  3.5589e-03
# Max:  1.4324e-02
# Min:  -1.9181e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 60
# Loss: 214.1885
# Psi gradient stats:
# Mean: 5.6985e-05
# Std:  3.5440e-03
# Max:  1.4331e-02
# Min:  -1.9161e-02
# Epoch 60, Loss: 214.1885, Gradients - Lambda: 4.756e-02, Phi: 1.078e+00, Gamma: 2.724e-03, Psi: 1.916e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 61
# Loss: 213.4044
# Psi gradient stats:
# Mean: 5.6688e-05
# Std:  3.5291e-03
# Max:  1.4310e-02
# Min:  -1.9126e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 62
# Loss: 212.6794
# Psi gradient stats:
# Mean: 5.6357e-05
# Std:  3.5145e-03
# Max:  1.4264e-02
# Min:  -1.9083e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 63
# Loss: 212.0240
# Psi gradient stats:
# Mean: 5.6048e-05
# Std:  3.4999e-03
# Max:  1.4259e-02
# Min:  -1.9038e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 64
# Loss: 211.4126
# Psi gradient stats:
# Mean: 5.5767e-05
# Std:  3.4855e-03
# Max:  1.4240e-02
# Min:  -1.8999e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 65
# Loss: 210.8233
# Psi gradient stats:
# Mean: 5.5493e-05
# Std:  3.4710e-03
# Max:  1.4193e-02
# Min:  -1.8974e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 66
# Loss: 210.2656
# Psi gradient stats:
# Mean: 5.5221e-05
# Std:  3.4565e-03
# Max:  1.4132e-02
# Min:  -1.8958e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 67
# Loss: 209.7545
# Psi gradient stats:
# Mean: 5.4929e-05
# Std:  3.4420e-03
# Max:  1.4104e-02
# Min:  -1.8944e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 68
# Loss: 209.2813
# Psi gradient stats:
# Mean: 5.4671e-05
# Std:  3.4277e-03
# Max:  1.4079e-02
# Min:  -1.8925e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 69
# Loss: 208.8269
# Psi gradient stats:
# Mean: 5.4367e-05
# Std:  3.4135e-03
# Max:  1.4058e-02
# Min:  -1.8895e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 70
# Loss: 208.3884
# Psi gradient stats:
# Mean: 5.4072e-05
# Std:  3.3995e-03
# Max:  1.4056e-02
# Min:  -1.8855e-02
# Epoch 70, Loss: 208.3884, Gradients - Lambda: 3.992e-02, Phi: 6.602e-01, Gamma: 2.057e-03, Psi: 1.886e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 71
# Loss: 207.9780
# Psi gradient stats:
# Mean: 5.3712e-05
# Std:  3.3856e-03
# Max:  1.4057e-02
# Min:  -1.8809e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 72
# Loss: 207.5972
# Psi gradient stats:
# Mean: 5.3302e-05
# Std:  3.3717e-03
# Max:  1.4036e-02
# Min:  -1.8763e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 73
# Loss: 207.2351
# Psi gradient stats:
# Mean: 5.2994e-05
# Std:  3.3576e-03
# Max:  1.3995e-02
# Min:  -1.8723e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 74
# Loss: 206.8844
# Psi gradient stats:
# Mean: 5.2703e-05
# Std:  3.3435e-03
# Max:  1.3976e-02
# Min:  -1.8692e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 75
# Loss: 206.5498
# Psi gradient stats:
# Mean: 5.2576e-05
# Std:  3.3293e-03
# Max:  1.3980e-02
# Min:  -1.8671e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 76
# Loss: 206.2308
# Psi gradient stats:
# Mean: 5.2454e-05
# Std:  3.3154e-03
# Max:  1.3985e-02
# Min:  -1.8658e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 77
# Loss: 205.9281
# Psi gradient stats:
# Mean: 5.2378e-05
# Std:  3.3015e-03
# Max:  1.3984e-02
# Min:  -1.8643e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 78
# Loss: 205.6361
# Psi gradient stats:
# Mean: 5.2275e-05
# Std:  3.2879e-03
# Max:  1.3977e-02
# Min:  -1.8617e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 79
# Loss: 205.3541
# Psi gradient stats:
# Mean: 5.2145e-05
# Std:  3.2742e-03
# Max:  1.3970e-02
# Min:  -1.8579e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 80
# Loss: 205.0823
# Psi gradient stats:
# Mean: 5.2022e-05
# Std:  3.2606e-03
# Max:  1.3962e-02
# Min:  -1.8533e-02
# Epoch 80, Loss: 205.0823, Gradients - Lambda: 4.569e-02, Phi: 1.108e+00, Gamma: 2.351e-03, Psi: 1.853e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 81
# Loss: 204.8220
# Psi gradient stats:
# Mean: 5.1860e-05
# Std:  3.2470e-03
# Max:  1.3948e-02
# Min:  -1.8487e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 82
# Loss: 204.5688
# Psi gradient stats:
# Mean: 5.1687e-05
# Std:  3.2335e-03
# Max:  1.3929e-02
# Min:  -1.8450e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 83
# Loss: 204.3241
# Psi gradient stats:
# Mean: 5.1458e-05
# Std:  3.2200e-03
# Max:  1.3908e-02
# Min:  -1.8424e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 84
# Loss: 204.0876
# Psi gradient stats:
# Mean: 5.1193e-05
# Std:  3.2068e-03
# Max:  1.3893e-02
# Min:  -1.8407e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 85
# Loss: 203.8571
# Psi gradient stats:
# Mean: 5.0945e-05
# Std:  3.1936e-03
# Max:  1.3876e-02
# Min:  -1.8394e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 86
# Loss: 203.6334
# Psi gradient stats:
# Mean: 5.0733e-05
# Std:  3.1805e-03
# Max:  1.3857e-02
# Min:  -1.8374e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 87
# Loss: 203.4154
# Psi gradient stats:
# Mean: 5.0543e-05
# Std:  3.1674e-03
# Max:  1.3835e-02
# Min:  -1.8345e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 88
# Loss: 203.2032
# Psi gradient stats:
# Mean: 5.0301e-05
# Std:  3.1544e-03
# Max:  1.3813e-02
# Min:  -1.8306e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 89
# Loss: 202.9954
# Psi gradient stats:
# Mean: 5.0056e-05
# Std:  3.1415e-03
# Max:  1.3793e-02
# Min:  -1.8264e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 90
# Loss: 202.7915
# Psi gradient stats:
# Mean: 4.9805e-05
# Std:  3.1286e-03
# Max:  1.3775e-02
# Min:  -1.8226e-02
# Epoch 90, Loss: 202.7915, Gradients - Lambda: 7.362e-02, Phi: 9.247e-01, Gamma: 2.335e-03, Psi: 1.823e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 91
# Loss: 202.5933
# Psi gradient stats:
# Mean: 4.9620e-05
# Std:  3.1158e-03
# Max:  1.3762e-02
# Min:  -1.8196e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 92
# Loss: 202.4003
# Psi gradient stats:
# Mean: 4.9387e-05
# Std:  3.1032e-03
# Max:  1.3753e-02
# Min:  -1.8174e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 93
# Loss: 202.2090
# Psi gradient stats:
# Mean: 4.9165e-05
# Std:  3.0906e-03
# Max:  1.3744e-02
# Min:  -1.8153e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 94
# Loss: 202.0214
# Psi gradient stats:
# Mean: 4.8957e-05
# Std:  3.0779e-03
# Max:  1.3734e-02
# Min:  -1.8127e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 95
# Loss: 201.8370
# Psi gradient stats:
# Mean: 4.8751e-05
# Std:  3.0653e-03
# Max:  1.3722e-02
# Min:  -1.8095e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 96
# Loss: 201.6562
# Psi gradient stats:
# Mean: 4.8589e-05
# Std:  3.0527e-03
# Max:  1.3710e-02
# Min:  -1.8058e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 97
# Loss: 201.4778
# Psi gradient stats:
# Mean: 4.8365e-05
# Std:  3.0401e-03
# Max:  1.3698e-02
# Min:  -1.8021e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 98
# Loss: 201.3037
# Psi gradient stats:
# Mean: 4.8209e-05
# Std:  3.0277e-03
# Max:  1.3688e-02
# Min:  -1.7989e-02
# mask_before_event shape: torch.Size([10000, 348, 52])
# mask_at_event shape: torch.Size([10000, 348, 52])
#
# Epoch 99
# Loss: 201.1310
# Psi gradient stats:
# Mean: 4.8015e-05
# Std:  3.0154e-03
# Max:  1.3679e-02
# Min:  -1.7962e-02

# %%
final_lambda = model.lambda_.detach().clone()
diff = torch.abs(final_lambda - initial_lambda)

print(f"Lambda changes with lr=3e-3:")
print(f"Mean absolute change: {torch.mean(diff):.3e}")
print(f"Max absolute change: {torch.max(diff):.3e}")
print(f"Std of changes: {torch.std(diff):.3e}")
# Out:
# Lambda changes with lr=3e-3:
# Mean absolute change: 2.018e-03
# Max absolute change: 5.263e-02
# Std of changes: 2.003e-03

# %%
print("Pretrained model stats:")
print(f"G stats: mean={self.G.mean():.3f}, std={self.G.std():.3f}")
print(f"gamma stats: mean={self.gamma.mean():.3f}, std={self.gamma.std():.3f}")
print(f"Initial lambda stats: mean={self.lambda_.mean():.3f}, std={self.lambda_.std():.3f}")
print(f"phi stats: mean={self.phi.mean():.3f}, std={self.phi.std():.3f}")

# %%
# First get the trained parameters from your existing model
pretrained_phi = model.phi.detach().clone()
pretrained_gamma = model.gamma.detach().clone()
pretrained_psi = model.psi.detach().clone()

# Get a new batch of 10k individuals
Y_new, E_new, G_new, new_indices = subset_data(Y, E, G, n_samples=10000, seed=43)  # Using different seed

# %%
from gp_clust_pretrained import *
del pretrained_model
# %load_ext autoreload
# %autoreload 2


# Create pretrained model for new data
pretrained_model = AladynSurvivalPretrainedModel(
    N=Y_new.shape[0],  # 10000
    D=Y_new.shape[1],  # same number of diseases
    T=Y_new.shape[2],  # same time points
    K=essentials['K'],  # same number of clusters
    P=essentials['P'],  # same number of genetic components
    G=G_new,           # genetic data for new individuals
    Y=Y_new,           # outcome data for new individuals
    prevalence_t=essentials['prevalence_t'],  # same prevalence
    pretrained_phi=pretrained_phi,
    pretrained_gamma=pretrained_gamma,
    pretrained_psi=pretrained_psi
)

# %%
# Fit only lambda parameters for new individuals
history_new = pretrained_model.fit(E_new, num_epochs=100, learning_rate=1e-3)

# %%
import matplotlib.pyplot as plt

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot loss
ax1.plot(history_new['loss'])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True)

# Plot gradients
ax2.plot(history_new['max_grad_lambda'], label='Lambda')

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Max Gradient Magnitude')
ax2.set_title('Parameter Gradients')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
disease_names=essentials['disease_names']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert gamma tensors to numpy arrays
initial_gamma_np = initial_gamma.detach().numpy()
final_gamma_np = model.gamma.detach().numpy()

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial gamma
sns.heatmap(initial_gamma_np, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Gamma')

# Plot final gamma
sns.heatmap(final_gamma_np, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Gamma')

# Add a title to the figure
plt.suptitle('Comparison of Initial vs Final Gamma Values', fontsize=16)

# You can also add a colorbar
plt.tight_layout()

# To see the actual difference, you can also create a difference heatmap
plt.figure(figsize=(10, 8))
diff = final_gamma_np - initial_gamma_np
sns.heatmap(diff, cmap='RdBu_r', center=0)
plt.title('Difference (Final - Initial Gamma)')
plt.show()

# Print some summary statistics
print(f"Mean absolute difference: {np.abs(diff).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff):.4f}")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Convert phi tensors to numpy arrays
initial_phi_np = initial_phi.detach().numpy()  # Shape: (K, D, T)
final_phi_np = model.phi.detach().numpy()

# Take mean over time dimension
initial_phi_mean = initial_phi_np.mean(axis=2)  # Shape: (K, D)
final_phi_mean = final_phi_np.mean(axis=2)

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plot initial phi (averaged over time)
sns.heatmap(initial_phi_mean, ax=ax1, cmap='RdBu_r', center=0)
ax1.set_title('Initial Phi (Mean over Time)')
ax1.set_xlabel('Disease')
ax1.set_ylabel('Signature')

# Plot final phi (averaged over time)
sns.heatmap(final_phi_mean, ax=ax2, cmap='RdBu_r', center=0)
ax2.set_title('Final Phi (Mean over Time)')
ax2.set_xlabel('Disease')
ax2.set_ylabel('Signature')

plt.suptitle('Comparison of Initial vs Final Phi Values (Averaged over Time)', fontsize=16)
plt.tight_layout()

# Plot difference
plt.figure(figsize=(10, 8))
diff_mean = final_phi_mean - initial_phi_mean
sns.heatmap(diff_mean, cmap='RdBu_r', center=0)
plt.title('Difference in Phi (Final - Initial), Mean over Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# Print summary statistics for both full tensor and time-averaged differences
print("Full tensor statistics:")
diff_full = final_phi_np - initial_phi_np
print(f"Mean absolute difference: {np.abs(diff_full).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_full).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_full):.4f}")

print("\nTime-averaged statistics:")
print(f"Mean absolute difference: {np.abs(diff_mean).mean():.4f}")
print(f"Max absolute difference: {np.abs(diff_mean).max():.4f}")
print(f"Standard deviation of differences: {np.std(diff_mean):.4f}")

# Optionally, look at temporal variation
temporal_std = np.std(diff_full, axis=2)
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_std, cmap='viridis')
plt.title('Standard Deviation of Changes Across Time')
plt.xlabel('Disease')
plt.ylabel('Signature')
plt.show()

# %%
Y_global=Y

# %%
Y_global.shape

# %%
# 1. Get predictions and actual values
predicted = model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")

# %%
# 1. Get predictions and actual values
predicted = pretrained_model.forward()
pi_pred = predicted[0] if isinstance(predicted, tuple) else predicted
pi_pred = pi_pred.cpu().detach().numpy()
Y = pretrained_model.Y.cpu().detach().numpy()

# 2. Calculate marginal risks directly
# Assuming dimensions are: [N, D, T] for both Y and pi_pred
observed_risk = Y.mean(axis=0).flatten()  # average across individuals
predicted_risk = pi_pred.mean(axis=0).flatten()

# 3. Apply calibration
scale_factor = np.mean(observed_risk) / np.mean(predicted_risk)
calibrated_risk = predicted_risk * scale_factor

# 4. Plot
plt.figure(figsize=(12, 5))

# Original predictions
plt.subplot(121)
plt.scatter(observed_risk, predicted_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Original Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Predicted Risk')

# Calibrated predictions
plt.subplot(122)
plt.scatter(observed_risk, calibrated_risk, alpha=0.5)
plt.plot([0, 0.02], [0, 0.02], 'r--')  # y=x line
plt.title('Calibrated Predictions')
plt.xlabel('Observed Risk')
plt.ylabel('Calibrated Risk')

plt.tight_layout()
plt.show()

# Print statistics
print(f"Mean observed risk: {np.mean(observed_risk):.6f}")
print(f"Mean predicted risk (original): {np.mean(predicted_risk):.6f}")
print(f"Mean predicted risk (calibrated): {np.mean(calibrated_risk):.6f}")
print(f"Calibration scale factor: {scale_factor:.3f}")

# %%
ss_res = np.sum((observed_risk - calibrated_risk) ** 2)
ss_tot = np.sum((observed_risk - np.mean(observed_risk)) ** 2)
r2 = 1 - (ss_res / ss_tot)

print(f"R^2: {r2:.3f}")

# %%
def plot_signature_top_diseases_centered(model, disease_names, n_top=10):
    """
    Show top diseases for each signature, centered relative to prevalence
    """
    # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # For each signature, get top diseases
    for k in range(phi_avg.shape[0]):
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        print(f"\nTop {n_top} diseases in Signature {k} (relative to baseline):")
        for idx in top_indices:
            avg_effect = scores[idx]
            temporal_std = np.std(phi_centered[k, idx, :])
            # Convert to odds ratio for interpretability
            odds_ratio = np.exp(avg_effect)
            print(f"{disease_names[idx]}: effect={avg_effect:.3f} (OR={odds_ratio:.2f}), std={temporal_std:.3f}")

# Run visualization
plot_signature_top_diseases_centered(model, essentials['disease_names'])

# %%
def compare_disease_rankings(model, disease_names, n_top=10):
    """
    Compare initial vs final disease rankings for each signature
    """
    # Get initial rankings from psi
    psi = model.psi.detach().numpy()  # Shape: (K, D)
    
    # Get final rankings from centered phi
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Compare rankings for each signature
    for k in range(phi_avg.shape[0]):
        print(f"\nSignature {k}:")
        
        # Get initial top diseases from psi
        initial_scores = psi[k, :]
        initial_top = np.argsort(initial_scores)[-n_top:][::-1]
        
        # Get final top diseases from phi
        final_scores = phi_avg[k, :]
        final_top = np.argsort(final_scores)[-n_top:][::-1]
        
        print("\nInitial top diseases:")
        for i, idx in enumerate(initial_top):
            print(f"{i+1}. {disease_names[idx]}: {initial_scores[idx]:.3f}")
            
        print("\nFinal top diseases:")
        for i, idx in enumerate(final_top):
            print(f"{i+1}. {disease_names[idx]}: {final_scores[idx]:.3f}")
            
        # Calculate rank changes
        initial_ranks = {disease: rank for rank, disease in enumerate(initial_top)}
        final_ranks = {disease: rank for rank, disease in enumerate(final_top)}
        
        # Find diseases that changed ranks significantly
        changed_diseases = set(initial_top) | set(final_top)
        for disease in changed_diseases:
            initial_rank = initial_ranks.get(disease, n_top+1)
            final_rank = final_ranks.get(disease, n_top+1)
            if abs(final_rank - initial_rank) > 2:  # Threshold for significant change
                print(f"\n{disease_names[disease]} changed from rank {initial_rank+1} to {final_rank+1}")

# Run comparison
compare_disease_rankings(model, essentials['disease_names'])

# %%
def plot_signature_temporal_patterns(model, disease_names, n_top=10, selected_signatures=None):
    """
    Show temporal patterns of top diseases for each signature
    """
    #phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    #phi_avg = phi.mean(axis=2)  # Average over time

     # Get phi and prevalence
    phi = model.phi.detach().numpy()  # Shape: (K, D, T)
    prevalence_logit = model.logit_prev_t.detach().numpy()  # Shape: (D, T)
    
    # Center phi relative to prevalence
    phi_centered = np.zeros_like(phi)
    for k in range(phi.shape[0]):
        for d in range(phi.shape[1]):
            phi_centered[k, d, :] = phi[k, d, :] - prevalence_logit[d, :]
    
    # Average over time
    phi_avg = phi_centered.mean(axis=2)  # Shape: (K, D)
    
    # Select which signatures to plot
    if selected_signatures is None:
        selected_signatures = range(phi_avg.shape[0])
    
    # Create subplots for each selected signature
    n_sigs = len(selected_signatures)
    fig, axes = plt.subplots(n_sigs, 1, figsize=(15, 5*n_sigs))
    if n_sigs == 1:
        axes = [axes]
    
    for i, k in enumerate(selected_signatures):
        # Get top diseases
        scores = phi_avg[k, :]
        top_indices = np.argsort(scores)[-n_top:][::-1]
        
        # Plot temporal patterns
        ax = axes[i]
        for idx in top_indices:
            temporal_pattern = phi[k, idx, :]
            ax.plot(temporal_pattern, label=disease_names[idx])
        
        ax.set_title(f'Signature {k} - Top Disease Temporal Patterns')
        ax.set_xlabel('Time')
        ax.set_ylabel('Phi Value')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# First show the top diseases


# Then show their temporal patterns
# You can select specific signatures of interest:
disease_names=essentials['disease_names']
plot_signature_temporal_patterns(model, disease_names, selected_signatures=[0,1,14,15,16,13,17])

# %%
Y_avg_global = torch.mean(torch.tensor(Y_global) if isinstance(Y_global, np.ndarray) else Y_global, dim=2)
Y_avg_batch = torch.mean(torch.tensor(Y_100k) if isinstance(Y_100k, np.ndarray) else Y_100k, dim=2)

# %%
def compare_disease_patterns(k, true_psi, Y_avg_global, Y_avg_batch):
    """Compare disease patterns between global and batch data"""
    strong_diseases = (true_psi[k] > 0)
    
    # Get mean pattern for each dataset (average across patients)
    pattern_large = Y_avg_global[:, strong_diseases].mean(dim=0)  # Average across all patients
    pattern_small = Y_avg_batch[:, strong_diseases].mean(dim=0)  # Average across batch patients
    
    # Now both patterns are just length of strong_diseases
    correlation = torch.corrcoef(
        torch.stack([pattern_large, pattern_small])
    )[0,1]
    
    print(f"Signature {k} pattern correlation: {correlation:.3f}")
    print(f"Mean pattern difference: {(pattern_large - pattern_small).abs().mean():.3f}")

# Now use it
print("Comparing disease sharing patterns between global and batch data:")
for k in range(model.K):
    print(f"\nSignature {k}:")
    compare_disease_patterns(k, model.psi, Y_avg_global, Y_avg_batch)
